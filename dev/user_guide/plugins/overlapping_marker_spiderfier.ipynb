# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc0e327ec021ba5678851ca9b6562c07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc0e327ec021ba5678851ca9b6562c07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc0e327ec021ba5678851ca9b6562c07 = L.map(
#                 &quot;map_dc0e327ec021ba5678851ca9b6562c07&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69f829caaa833448467b7e6797e33c2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69f829caaa833448467b7e6797e33c2d.addTo(map_dc0e327ec021ba5678851ca9b6562c07);
#
#
#             var marker_d77636bb4c7144943d148dfcef3d6f55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dc0e327ec021ba5678851ca9b6562c07);
#
#
#         var popup_701accb9b03aab96e422f5addc2f81eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e24e0b46c2a306cb0ddb8ab46313db3 = $(`&lt;div id=&quot;html_9e24e0b46c2a306cb0ddb8ab46313db3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_701accb9b03aab96e422f5addc2f81eb.setContent(html_9e24e0b46c2a306cb0ddb8ab46313db3);
#
#
#
#         marker_d77636bb4c7144943d148dfcef3d6f55.bindPopup(popup_701accb9b03aab96e422f5addc2f81eb)
#         ;
#
#
#
#
#             var marker_9fa807c00f8d2536241b4ccc3b4d1fe1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dc0e327ec021ba5678851ca9b6562c07);
#
#
#         var popup_ec9fe46d20277e9a5e81c37ffcd83a30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34dfbba30c6cfb709755cfec1f466c4c = $(`&lt;div id=&quot;html_34dfbba30c6cfb709755cfec1f466c4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ec9fe46d20277e9a5e81c37ffcd83a30.setContent(html_34dfbba30c6cfb709755cfec1f466c4c);
#
#
#
#         marker_9fa807c00f8d2536241b4ccc3b4d1fe1.bindPopup(popup_ec9fe46d20277e9a5e81c37ffcd83a30)
#         ;
#
#
#
#
#             var marker_cac4aae64c3c0fa0edae717e6ec08cbe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dc0e327ec021ba5678851ca9b6562c07);
#
#
#         var popup_2188c777a6ca79c15eca7e3ff2c748af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99ec996e35518f7c4d9238b0441a7839 = $(`&lt;div id=&quot;html_99ec996e35518f7c4d9238b0441a7839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2188c777a6ca79c15eca7e3ff2c748af.setContent(html_99ec996e35518f7c4d9238b0441a7839);
#
#
#
#         marker_cac4aae64c3c0fa0edae717e6ec08cbe.bindPopup(popup_2188c777a6ca79c15eca7e3ff2c748af)
#         ;
#
#
#
#
#             var marker_ec476bbcd1425ae58ad4358b83df03bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dc0e327ec021ba5678851ca9b6562c07);
#
#
#         var popup_9e7e76401fa3e54c99731f64f5fa3a4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce5b3439d3ed9ad75aa3a89e90701242 = $(`&lt;div id=&quot;html_ce5b3439d3ed9ad75aa3a89e90701242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9e7e76401fa3e54c99731f64f5fa3a4c.setContent(html_ce5b3439d3ed9ad75aa3a89e90701242);
#
#
#
#         marker_ec476bbcd1425ae58ad4358b83df03bc.bindPopup(popup_9e7e76401fa3e54c99731f64f5fa3a4c)
#         ;
#
#
#
#
#             var marker_5a4876b6fb3daad29ccb9d60e71dc728 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dc0e327ec021ba5678851ca9b6562c07);
#
#
#         var popup_45391f33637546abf4fee32cf998a2b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a55552afd67d6463e898bb9a86036336 = $(`&lt;div id=&quot;html_a55552afd67d6463e898bb9a86036336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_45391f33637546abf4fee32cf998a2b6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14373d195fa4bba02eab6b758d3c2757 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14373d195fa4bba02eab6b758d3c2757&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14373d195fa4bba02eab6b758d3c2757 = L.map(
#                 &quot;map_14373d195fa4bba02eab6b758d3c2757&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d0e46d4671d34bf203759cb2bccd239 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d0e46d4671d34bf203759cb2bccd239.addTo(map_14373d195fa4bba02eab6b758d3c2757);
#
#
#             var feature_group_a407523ef493a9c086a64cbfeac3f1ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cbec67866339b8f29553b2c7bdb3d657 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a407523ef493a9c086a64cbfeac3f1ee);
#
#
#         var popup_140568f3787b6ea5b719c5e91abcd44c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d5905febab246eef58658730ecc1d3e = $(`&lt;div id=&quot;html_7d5905febab246eef58658730ecc1d3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_140568f3787b6ea5b719c5e91abcd44c.setContent(html_7d5905febab246eef58658730ecc1d3e);
#
#
#
#         marker_cbec67866339b8f29553b2c7bdb3d657.bindPopup(popup_140568f3787b6ea5b719c5e91abcd44c)
#         ;
#
#
#
#
#             var marker_6f281dd5e936674212c4abba365fb13b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a407523ef493a9c086a64cbfeac3f1ee);
#
#
#         var popup_91d92b53f8aceaaff20760c4f5eaf350 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0556c6d29ec9aceafe7dfa3a30e10cb4 = $(`&lt;div id=&quot;html_0556c6d29ec9aceafe7dfa3a30e10cb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_91d92b53f8aceaaff20760c4f5eaf350.setContent(html_0556c6d29ec9aceafe7dfa3a30e10cb4);
#
#
#
#         marker_6f281dd5e936674212c4abba365fb13b.bindPopup(popup_91d92b53f8aceaaff20760c4f5eaf350)
#         ;
#
#
#
#
#             var marker_d35be74c0e0e00772bce4c8807bc2e3d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a407523ef493a9c086a64cbfeac3f1ee);
#
#
#         var popup_41292f577f7c1ffc875c187453f3871e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98558e66c0e2f5fd54fef424268da584 = $(`&lt;div id=&quot;html_98558e66c0e2f5fd54fef424268da584&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_41292f577f7c1ffc875c187453f3871e.setContent(html_98558e66c0e2f5fd54fef424268da584);
#
#
#
#         marker_d35be74c0e0e00772bce4c8807bc2e3d.bindPopup(popup_41292f577f7c1ffc875c187453f3871e)
#         ;
#
#
#
#
#             var marker_83aec3f4e10aac1d83d4a2d8307040f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a407523ef493a9c086a64cbfeac3f1ee);
#
#
#         var popup_e82024bc7d0a2adee42517d8be154850 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3632f94c6a23cc4ac251e27ea7519fa = $(`&lt;div id=&quot;html_b3632f94c6a23cc4ac251e27ea7519fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e82024bc7d0a2adee42517d8be154850.setContent(html_b3632f94c6a23cc4ac251e27ea7519fa);
#
#
#
#         marker_83aec3f4e10aac1d83d4a2d8307040f0.bindPopup(popup_e82024bc7d0a2adee42517d8be154850)
#         ;
#
#
#
#
#             var marker_88fe3cb78dca1eb04ac5717a6ae63259 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a407523ef493a9c086a64cbfeac3f1ee);
#
#
#         var popup_1607f8244ba246d657c6b38e9667cc54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77129df2b4c6001d15d7e38aec2e98d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77129df2b4c6001d15d7e38aec2e98d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77129df2b4c6001d15d7e38aec2e98d5 = L.map(
#                 &quot;map_77129df2b4c6001d15d7e38aec2e98d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d56741f4ece937471c74154ae844af6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d56741f4ece937471c74154ae844af6.addTo(map_77129df2b4c6001d15d7e38aec2e98d5);
#
#
#             var feature_group_d622fae6abe0ea215a369baa235cb01e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d622fae6abe0ea215a369baa235cb01e.addTo(map_77129df2b4c6001d15d7e38aec2e98d5);
#
#
#             var feature_group_sub_group_89e10993126518ef347a2c50a2b4f6ed = L.featureGroup.subGroup(
#                 feature_group_d622fae6abe0ea215a369baa235cb01e
#             );
#
#
#             var marker_143b24218bd4d2124fc252b1132481d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_89e10993126518ef347a2c50a2b4f6ed);
#
#
#         var popup_0bc260aedabf42e836ddad05cbcf2300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6d5622fa46b0757dba6330448033348 = $(`&lt;div id=&quot;html_c6d5622fa46b0757dba6330448033348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0bc260aedabf42e836ddad05cbcf2300.setContent(html_c6d5622fa46b0757dba6330448033348);
#
#
#
#         marker_143b24218bd4d2124fc252b1132481d7.bindPopup(popup_0bc260aedabf42e836ddad05cbcf2300)
#         ;
#
#
#
#
#             var marker_73e237c83a980486245803088d0c8f43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_89e10993126518ef347a2c50a2b4f6ed);
#
#
#         var popup_208b6c04450209f7bb0366e8515c50d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11f15c7e6b944a2c04ab9434dbad4aab = $(`&lt;div id=&quot;html_11f15c7e6b944a2c04ab9434dbad4aab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_208b6c04450209f7bb0366e8515c50d3.setContent(html_11f15c7e6b944a2c04ab9434dbad4aab);
#
#
#
#         marker_73e237c83a980486245803088d0c8f43.bindPopup(popup_208b6c04450209f7bb0366e8515c50d3)
#         ;
#
#
#
#
#             var marker_47d82bcc83c592ac028c5c853c65e046 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_89e10993126518ef347a2c50a2b4f6ed);
#
#
#         var popup_4665315e8754834d947637f73df747f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df883e7545391e519a0e6bc1a6041cac = $(`&lt;div id=&quot;html_df883e7545391e519a0e6bc1a6041cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4665315e8754834d947637f73df747f2.setContent(html_df883e7545391e519a0e6bc1a6041cac);
#
#
#
#         marker_47d82bcc83c592ac028c5c853c65e046.bindPopup(popup_4665315e8754834d947637f73df747f2)
#         ;
#
#
#
#
#             var marker_39e0375dc7cc9ec32894e694c2d67f91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_89e10993126518ef347a2c50a2b4f6ed);
#
#
#         var popup_aab8a680db51874574038427618948a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8832b3357bfd4e977ee556df0e3627be = $(`&lt;div id=&quot;html_8832b3357bfd4e977ee556df0e3627be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aab8a680db51874574038427618948a2.setContent(html_8832b3357bfd4e977ee556df0e3627be);
#
#
#
#         marker_
