# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_277f659e0911d161e0e3d39425da4d74 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_277f659e0911d161e0e3d39425da4d74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_277f659e0911d161e0e3d39425da4d74 = L.map(
#                 &quot;map_277f659e0911d161e0e3d39425da4d74&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45769ee58e9cf05f0a195745fc3eaba3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45769ee58e9cf05f0a195745fc3eaba3.addTo(map_277f659e0911d161e0e3d39425da4d74);
#
#
#             var marker_a6e4f8cc0aefd4f53bbe4eaba9635f42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_277f659e0911d161e0e3d39425da4d74);
#
#
#         var popup_7ef7ab1106751b22098912ad8daad62a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7fda1d79880ddbeff27c7946ea4e5c2 = $(`&lt;div id=&quot;html_e7fda1d79880ddbeff27c7946ea4e5c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7ef7ab1106751b22098912ad8daad62a.setContent(html_e7fda1d79880ddbeff27c7946ea4e5c2);
#
#
#
#         marker_a6e4f8cc0aefd4f53bbe4eaba9635f42.bindPopup(popup_7ef7ab1106751b22098912ad8daad62a)
#         ;
#
#
#
#
#             var marker_7e98bd0c3e92476da1124d5e42b9110a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_277f659e0911d161e0e3d39425da4d74);
#
#
#         var popup_92b226bc203edcdf9c386c33d90cb139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51528c9eac9e755ff6433a61279d0158 = $(`&lt;div id=&quot;html_51528c9eac9e755ff6433a61279d0158&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_92b226bc203edcdf9c386c33d90cb139.setContent(html_51528c9eac9e755ff6433a61279d0158);
#
#
#
#         marker_7e98bd0c3e92476da1124d5e42b9110a.bindPopup(popup_92b226bc203edcdf9c386c33d90cb139)
#         ;
#
#
#
#
#             var marker_a1f7c837b6bd2b6a8d00318be8342061 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_277f659e0911d161e0e3d39425da4d74);
#
#
#         var popup_95ef01dfc06f2ec668d31d29141f61fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92a048bc01000773f7b44c924457bf79 = $(`&lt;div id=&quot;html_92a048bc01000773f7b44c924457bf79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_95ef01dfc06f2ec668d31d29141f61fd.setContent(html_92a048bc01000773f7b44c924457bf79);
#
#
#
#         marker_a1f7c837b6bd2b6a8d00318be8342061.bindPopup(popup_95ef01dfc06f2ec668d31d29141f61fd)
#         ;
#
#
#
#
#             var marker_05569b6d210d8bede39669aca38af52b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_277f659e0911d161e0e3d39425da4d74);
#
#
#         var popup_55441d811ccf9c9687022eca7a914e7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173e6145ad7743adf9140aff95ed23ef = $(`&lt;div id=&quot;html_173e6145ad7743adf9140aff95ed23ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_55441d811ccf9c9687022eca7a914e7a.setContent(html_173e6145ad7743adf9140aff95ed23ef);
#
#
#
#         marker_05569b6d210d8bede39669aca38af52b.bindPopup(popup_55441d811ccf9c9687022eca7a914e7a)
#         ;
#
#
#
#
#             var marker_ff0eb1d0a1e2227032c79d46b1f39ee5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_277f659e0911d161e0e3d39425da4d74);
#
#
#         var popup_22fc1f02dec03d4916cf5cc15f430a80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_667b613de457c57248e25ad521d6a7dd = $(`&lt;div id=&quot;html_667b613de457c57248e25ad521d6a7dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_22fc1f02dec03d4916cf5cc15f430a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8487ac9fb125cc4485e0d611759ab8c0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8487ac9fb125cc4485e0d611759ab8c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8487ac9fb125cc4485e0d611759ab8c0 = L.map(
#                 &quot;map_8487ac9fb125cc4485e0d611759ab8c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_291a08b74676304332bfbc5803eb447f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_291a08b74676304332bfbc5803eb447f.addTo(map_8487ac9fb125cc4485e0d611759ab8c0);
#
#
#             var feature_group_f7d54735f9cb3da53da580d7b700c02a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_86b9b22d2f6d9ce897e77bf83324b4ba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f7d54735f9cb3da53da580d7b700c02a);
#
#
#         var popup_55c9c857d2ea9d1e8d2ac373e17abff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02582f6e1943d82c126131e77a4c8953 = $(`&lt;div id=&quot;html_02582f6e1943d82c126131e77a4c8953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_55c9c857d2ea9d1e8d2ac373e17abff4.setContent(html_02582f6e1943d82c126131e77a4c8953);
#
#
#
#         marker_86b9b22d2f6d9ce897e77bf83324b4ba.bindPopup(popup_55c9c857d2ea9d1e8d2ac373e17abff4)
#         ;
#
#
#
#
#             var marker_122fcc0c6e853436175d98024eed70d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f7d54735f9cb3da53da580d7b700c02a);
#
#
#         var popup_045a978e911d8eff634fcc9cd6640c35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e79d3c56956533f1328aa1a14d22a4e = $(`&lt;div id=&quot;html_5e79d3c56956533f1328aa1a14d22a4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_045a978e911d8eff634fcc9cd6640c35.setContent(html_5e79d3c56956533f1328aa1a14d22a4e);
#
#
#
#         marker_122fcc0c6e853436175d98024eed70d5.bindPopup(popup_045a978e911d8eff634fcc9cd6640c35)
#         ;
#
#
#
#
#             var marker_76bc655d7435a0ad893a32f49caef300 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f7d54735f9cb3da53da580d7b700c02a);
#
#
#         var popup_31a0d351f9e2f7c64e2f8f45e3e82cca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5356ca087a6b259f3c00b38a6774187a = $(`&lt;div id=&quot;html_5356ca087a6b259f3c00b38a6774187a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_31a0d351f9e2f7c64e2f8f45e3e82cca.setContent(html_5356ca087a6b259f3c00b38a6774187a);
#
#
#
#         marker_76bc655d7435a0ad893a32f49caef300.bindPopup(popup_31a0d351f9e2f7c64e2f8f45e3e82cca)
#         ;
#
#
#
#
#             var marker_1a9dee6a25a3da6591fffd003542d5fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f7d54735f9cb3da53da580d7b700c02a);
#
#
#         var popup_471b257124f847a9d0891473f091b905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef3066b40a7bc960f8dfde9826c4c0a9 = $(`&lt;div id=&quot;html_ef3066b40a7bc960f8dfde9826c4c0a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_471b257124f847a9d0891473f091b905.setContent(html_ef3066b40a7bc960f8dfde9826c4c0a9);
#
#
#
#         marker_1a9dee6a25a3da6591fffd003542d5fe.bindPopup(popup_471b257124f847a9d0891473f091b905)
#         ;
#
#
#
#
#             var marker_69f0864a7ee3ef21f2b468b24a3803d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f7d54735f9cb3da53da580d7b700c02a);
#
#
#         var popup_37c8adf6e6f3b24ec34c5853db1348d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72e23cd5984154c454da51369e72658f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72e23cd5984154c454da51369e72658f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72e23cd5984154c454da51369e72658f = L.map(
#                 &quot;map_72e23cd5984154c454da51369e72658f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71a51402f9b2213d92b7390bdaba843b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71a51402f9b2213d92b7390bdaba843b.addTo(map_72e23cd5984154c454da51369e72658f);
#
#
#             var feature_group_90277b2ddb0f6fb30948f5627ba9337e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_90277b2ddb0f6fb30948f5627ba9337e.addTo(map_72e23cd5984154c454da51369e72658f);
#
#
#             var feature_group_sub_group_9df3bc1550e97e157bdba9df950569c0 = L.featureGroup.subGroup(
#                 feature_group_90277b2ddb0f6fb30948f5627ba9337e
#             );
#
#
#             var marker_d6c22cc52ce0fb89653a656c7b5c67a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9df3bc1550e97e157bdba9df950569c0);
#
#
#         var popup_125a7ec2bf93b2d4f5be9c671f608df0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83babeea6c50ee7197d073fbcad7ac96 = $(`&lt;div id=&quot;html_83babeea6c50ee7197d073fbcad7ac96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_125a7ec2bf93b2d4f5be9c671f608df0.setContent(html_83babeea6c50ee7197d073fbcad7ac96);
#
#
#
#         marker_d6c22cc52ce0fb89653a656c7b5c67a6.bindPopup(popup_125a7ec2bf93b2d4f5be9c671f608df0)
#         ;
#
#
#
#
#             var marker_46f493e21871d05a142e40f60287ba0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9df3bc1550e97e157bdba9df950569c0);
#
#
#         var popup_c4c1f2de4a63fd23ef37b042d715a426 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01082e8df083f683c4a768deaba89bf3 = $(`&lt;div id=&quot;html_01082e8df083f683c4a768deaba89bf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c4c1f2de4a63fd23ef37b042d715a426.setContent(html_01082e8df083f683c4a768deaba89bf3);
#
#
#
#         marker_46f493e21871d05a142e40f60287ba0f.bindPopup(popup_c4c1f2de4a63fd23ef37b042d715a426)
#         ;
#
#
#
#
#             var marker_f3640da20251a643b04b2c9564ecf033 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9df3bc1550e97e157bdba9df950569c0);
#
#
#         var popup_d6832e4e6756f75f16ed8d3cdb4dd1de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16c7eb93358a48f52b41da2ceb0a4801 = $(`&lt;div id=&quot;html_16c7eb93358a48f52b41da2ceb0a4801&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d6832e4e6756f75f16ed8d3cdb4dd1de.setContent(html_16c7eb93358a48f52b41da2ceb0a4801);
#
#
#
#         marker_f3640da20251a643b04b2c9564ecf033.bindPopup(popup_d6832e4e6756f75f16ed8d3cdb4dd1de)
#         ;
#
#
#
#
#             var marker_896c26b7ecb071ab7d5a812fcc3e5aa6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9df3bc1550e97e157bdba9df950569c0);
#
#
#         var popup_be36fb8802135061fa30e09f7479eb6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f1fce3094a399ac7fc5e7791cbb855e = $(`&lt;div id=&quot;html_1f1fce3094a399ac7fc5e7791cbb855e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_be36fb8802135061fa30e09f7479eb6f.setContent(html_1f1fce3094a399ac7fc5e7791cbb855e);
#
#
#
#         mark
