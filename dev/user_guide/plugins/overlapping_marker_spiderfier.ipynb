# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7467432afaff88579937715edff39ceb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7467432afaff88579937715edff39ceb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7467432afaff88579937715edff39ceb = L.map(
#                 &quot;map_7467432afaff88579937715edff39ceb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a37c6a018bc84a996513ab214c57eb14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a37c6a018bc84a996513ab214c57eb14.addTo(map_7467432afaff88579937715edff39ceb);
#
#
#             var marker_04d4fa51da619929af292f049e5ba683 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7467432afaff88579937715edff39ceb);
#
#
#         var popup_63e6bf385ae76e60819fa0d9f3c58ab9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc864c7d58f2d5e3876aa5f95e307d25 = $(`&lt;div id=&quot;html_bc864c7d58f2d5e3876aa5f95e307d25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_63e6bf385ae76e60819fa0d9f3c58ab9.setContent(html_bc864c7d58f2d5e3876aa5f95e307d25);
#
#
#
#         marker_04d4fa51da619929af292f049e5ba683.bindPopup(popup_63e6bf385ae76e60819fa0d9f3c58ab9)
#         ;
#
#
#
#
#             var marker_23d5f755eb306ffcabdae6b5dc69dd94 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7467432afaff88579937715edff39ceb);
#
#
#         var popup_c0454a9b45f6033e816f6a1cbdc9ec3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81f275218d420308e0481cdcfa0f4c88 = $(`&lt;div id=&quot;html_81f275218d420308e0481cdcfa0f4c88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c0454a9b45f6033e816f6a1cbdc9ec3e.setContent(html_81f275218d420308e0481cdcfa0f4c88);
#
#
#
#         marker_23d5f755eb306ffcabdae6b5dc69dd94.bindPopup(popup_c0454a9b45f6033e816f6a1cbdc9ec3e)
#         ;
#
#
#
#
#             var marker_db207a16d0c2c4a2f82fb961185f5f00 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7467432afaff88579937715edff39ceb);
#
#
#         var popup_7bc77fc1d314f2b821264b86679bc851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05146a4fe31c7a49eeef81fad1b21f16 = $(`&lt;div id=&quot;html_05146a4fe31c7a49eeef81fad1b21f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7bc77fc1d314f2b821264b86679bc851.setContent(html_05146a4fe31c7a49eeef81fad1b21f16);
#
#
#
#         marker_db207a16d0c2c4a2f82fb961185f5f00.bindPopup(popup_7bc77fc1d314f2b821264b86679bc851)
#         ;
#
#
#
#
#             var marker_f51837bce37acaeecd4d8f909cf4b095 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7467432afaff88579937715edff39ceb);
#
#
#         var popup_4a1ac81721263a1cb2150334c4c43c76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8613904507296b6713ca5c4a783e5d4d = $(`&lt;div id=&quot;html_8613904507296b6713ca5c4a783e5d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4a1ac81721263a1cb2150334c4c43c76.setContent(html_8613904507296b6713ca5c4a783e5d4d);
#
#
#
#         marker_f51837bce37acaeecd4d8f909cf4b095.bindPopup(popup_4a1ac81721263a1cb2150334c4c43c76)
#         ;
#
#
#
#
#             var marker_c1a965b98c5df1a80133dd8fa7280932 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7467432afaff88579937715edff39ceb);
#
#
#         var popup_2cd218a111a8656612f15f3f216ae552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10f36e898430f37217c41841e43ac142 = $(`&lt;div id=&quot;html_10f36e898430f37217c41841e43ac142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2cd218a111a8656612f15f3f216ae5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f23d4ad380d4a4af38231197afd5111 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f23d4ad380d4a4af38231197afd5111&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f23d4ad380d4a4af38231197afd5111 = L.map(
#                 &quot;map_4f23d4ad380d4a4af38231197afd5111&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14ff5460e9b2cb82172282e89ce9deb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14ff5460e9b2cb82172282e89ce9deb7.addTo(map_4f23d4ad380d4a4af38231197afd5111);
#
#
#             var feature_group_24c06decf36583eddebbe573252ee08b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5999be9b1206bd61cdee66b55509582d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_24c06decf36583eddebbe573252ee08b);
#
#
#         var popup_ffc2f1aaa86369b183df67c4cd943a64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_953bec0243e2545cb23526bdaf3c6cd1 = $(`&lt;div id=&quot;html_953bec0243e2545cb23526bdaf3c6cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ffc2f1aaa86369b183df67c4cd943a64.setContent(html_953bec0243e2545cb23526bdaf3c6cd1);
#
#
#
#         marker_5999be9b1206bd61cdee66b55509582d.bindPopup(popup_ffc2f1aaa86369b183df67c4cd943a64)
#         ;
#
#
#
#
#             var marker_7efcd71605ac71da0c6c1b1bb53382d9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_24c06decf36583eddebbe573252ee08b);
#
#
#         var popup_a45606da54940f83c8641e3d108b2bf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_206fc8866e8714394b6e04a0d11f4570 = $(`&lt;div id=&quot;html_206fc8866e8714394b6e04a0d11f4570&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a45606da54940f83c8641e3d108b2bf2.setContent(html_206fc8866e8714394b6e04a0d11f4570);
#
#
#
#         marker_7efcd71605ac71da0c6c1b1bb53382d9.bindPopup(popup_a45606da54940f83c8641e3d108b2bf2)
#         ;
#
#
#
#
#             var marker_fa760e4763dfac8cb6f82ccd3325e1c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_24c06decf36583eddebbe573252ee08b);
#
#
#         var popup_62bca1966c714eaa68601e111a5cdd10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebcf670616494dda1f3129b1d3dc5997 = $(`&lt;div id=&quot;html_ebcf670616494dda1f3129b1d3dc5997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_62bca1966c714eaa68601e111a5cdd10.setContent(html_ebcf670616494dda1f3129b1d3dc5997);
#
#
#
#         marker_fa760e4763dfac8cb6f82ccd3325e1c6.bindPopup(popup_62bca1966c714eaa68601e111a5cdd10)
#         ;
#
#
#
#
#             var marker_372efcdba1067e3ab5d9a17e872e2049 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_24c06decf36583eddebbe573252ee08b);
#
#
#         var popup_10d64f74ed10d0681246ea4e36396812 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f799876a5a7c3bc91fa17f8099723f93 = $(`&lt;div id=&quot;html_f799876a5a7c3bc91fa17f8099723f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_10d64f74ed10d0681246ea4e36396812.setContent(html_f799876a5a7c3bc91fa17f8099723f93);
#
#
#
#         marker_372efcdba1067e3ab5d9a17e872e2049.bindPopup(popup_10d64f74ed10d0681246ea4e36396812)
#         ;
#
#
#
#
#             var marker_5f744f4d8b8bb3a15e806b1586de04f2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_24c06decf36583eddebbe573252ee08b);
#
#
#         var popup_1aa899daf230f543e8920ca517e514e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6d3e24a7285314e29d420346a009719 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6d3e24a7285314e29d420346a009719&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6d3e24a7285314e29d420346a009719 = L.map(
#                 &quot;map_b6d3e24a7285314e29d420346a009719&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10e9835b3acb00cd94b74feeb13927ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10e9835b3acb00cd94b74feeb13927ab.addTo(map_b6d3e24a7285314e29d420346a009719);
#
#
#             var feature_group_4da28dfb05d731ae0f0dec4dac73c288 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4da28dfb05d731ae0f0dec4dac73c288.addTo(map_b6d3e24a7285314e29d420346a009719);
#
#
#             var feature_group_sub_group_a9e8682e5884569e357d1a384760cf9f = L.featureGroup.subGroup(
#                 feature_group_4da28dfb05d731ae0f0dec4dac73c288
#             );
#
#
#             var marker_93e02d3aa6ba39b381a4f062dfcdc43c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a9e8682e5884569e357d1a384760cf9f);
#
#
#         var popup_048426f305f2b4c602691e64d356e53c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c48b5e2f1e4c23748abd74ef89fac36f = $(`&lt;div id=&quot;html_c48b5e2f1e4c23748abd74ef89fac36f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_048426f305f2b4c602691e64d356e53c.setContent(html_c48b5e2f1e4c23748abd74ef89fac36f);
#
#
#
#         marker_93e02d3aa6ba39b381a4f062dfcdc43c.bindPopup(popup_048426f305f2b4c602691e64d356e53c)
#         ;
#
#
#
#
#             var marker_8cfd178865c55831adf1d121763885ec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a9e8682e5884569e357d1a384760cf9f);
#
#
#         var popup_5244c248bf71baae0d29062ddbba1de5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01ec8a62b65f81e57b122768ddbb7952 = $(`&lt;div id=&quot;html_01ec8a62b65f81e57b122768ddbb7952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5244c248bf71baae0d29062ddbba1de5.setContent(html_01ec8a62b65f81e57b122768ddbb7952);
#
#
#
#         marker_8cfd178865c55831adf1d121763885ec.bindPopup(popup_5244c248bf71baae0d29062ddbba1de5)
#         ;
#
#
#
#
#             var marker_447ff2870fefc08b84dfb2a50e7e31d6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a9e8682e5884569e357d1a384760cf9f);
#
#
#         var popup_76a5722becb47c24570e429f423fdece = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d269951c45dc0bfe84d0d8dda22866b = $(`&lt;div id=&quot;html_4d269951c45dc0bfe84d0d8dda22866b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_76a5722becb47c24570e429f423fdece.setContent(html_4d269951c45dc0bfe84d0d8dda22866b);
#
#
#
#         marker_447ff2870fefc08b84dfb2a50e7e31d6.bindPopup(popup_76a5722becb47c24570e429f423fdece)
#         ;
#
#
#
#
#             var marker_dd2f61d1a8d81be1f340115ed39e63ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a9e8682e5884569e357d1a384760cf9f);
#
#
#         var popup_603c2dcc09ad6d8362297e845a42d0c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bce7ae48eff4bd8df3b606225aa345c1 = $(`&lt;div id=&quot;html_bce7ae48eff4bd8df3b606225aa345c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_603c2dcc09ad6d8362297e845a42d0c9.setContent(html_bce7ae48eff4bd8df3b606225aa345c1);
#
#
#
#         mark
