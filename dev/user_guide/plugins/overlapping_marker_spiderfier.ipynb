# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8f43c88dd6cfbdf0a7ae609e10d0bab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8f43c88dd6cfbdf0a7ae609e10d0bab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8f43c88dd6cfbdf0a7ae609e10d0bab = L.map(
#                 &quot;map_c8f43c88dd6cfbdf0a7ae609e10d0bab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98e2315f3866d2bd01019cbadf6e8139 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98e2315f3866d2bd01019cbadf6e8139.addTo(map_c8f43c88dd6cfbdf0a7ae609e10d0bab);
#
#
#             var marker_21c3d0383b058a0c5449b71946c48082 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c8f43c88dd6cfbdf0a7ae609e10d0bab);
#
#
#         var popup_c613ce566a39d4b37944224d043a00e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_576400a01e1f0edb99c6bd3650f11852 = $(`&lt;div id=&quot;html_576400a01e1f0edb99c6bd3650f11852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c613ce566a39d4b37944224d043a00e0.setContent(html_576400a01e1f0edb99c6bd3650f11852);
#
#
#
#         marker_21c3d0383b058a0c5449b71946c48082.bindPopup(popup_c613ce566a39d4b37944224d043a00e0)
#         ;
#
#
#
#
#             var marker_5a4e9d57b4817150207cd7e488c9e18a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c8f43c88dd6cfbdf0a7ae609e10d0bab);
#
#
#         var popup_9b99143760b534323f1f336a5d3bf176 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a815c965b11f3997064f7764f229b37 = $(`&lt;div id=&quot;html_6a815c965b11f3997064f7764f229b37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9b99143760b534323f1f336a5d3bf176.setContent(html_6a815c965b11f3997064f7764f229b37);
#
#
#
#         marker_5a4e9d57b4817150207cd7e488c9e18a.bindPopup(popup_9b99143760b534323f1f336a5d3bf176)
#         ;
#
#
#
#
#             var marker_d73deacc2651cf393c44f4b3e6394301 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c8f43c88dd6cfbdf0a7ae609e10d0bab);
#
#
#         var popup_3a94ccbc6c9cfd2c9662aafe65ada1db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30b267540a39ae66219f2cbb283745ac = $(`&lt;div id=&quot;html_30b267540a39ae66219f2cbb283745ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3a94ccbc6c9cfd2c9662aafe65ada1db.setContent(html_30b267540a39ae66219f2cbb283745ac);
#
#
#
#         marker_d73deacc2651cf393c44f4b3e6394301.bindPopup(popup_3a94ccbc6c9cfd2c9662aafe65ada1db)
#         ;
#
#
#
#
#             var marker_644ee41573ce6b5f8934408efa282bb5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c8f43c88dd6cfbdf0a7ae609e10d0bab);
#
#
#         var popup_2815c57fc3285bd8266ecf2426aa6f10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf779d75ee6342fca737266bca862a29 = $(`&lt;div id=&quot;html_cf779d75ee6342fca737266bca862a29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2815c57fc3285bd8266ecf2426aa6f10.setContent(html_cf779d75ee6342fca737266bca862a29);
#
#
#
#         marker_644ee41573ce6b5f8934408efa282bb5.bindPopup(popup_2815c57fc3285bd8266ecf2426aa6f10)
#         ;
#
#
#
#
#             var marker_12652570812afc7e4573479711d76b32 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c8f43c88dd6cfbdf0a7ae609e10d0bab);
#
#
#         var popup_70fc1ee74821ea792413a10640e561b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c47c9e1528ff6574aac7e4b4fb639bc2 = $(`&lt;div id=&quot;html_c47c9e1528ff6574aac7e4b4fb639bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_70fc1ee74821ea792413a10640e561

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfde61cefb359eff18a9df6f213bb74e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfde61cefb359eff18a9df6f213bb74e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfde61cefb359eff18a9df6f213bb74e = L.map(
#                 &quot;map_dfde61cefb359eff18a9df6f213bb74e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a633976d4f6d092125ac42f130c6f3d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a633976d4f6d092125ac42f130c6f3d8.addTo(map_dfde61cefb359eff18a9df6f213bb74e);
#
#
#             var feature_group_7d788e76922aa334b99bfc47d7077c98 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6274a24ac10013546037e9169ed97de5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7d788e76922aa334b99bfc47d7077c98);
#
#
#         var popup_c8184705c4a43a4c4cffeeeba8d44b83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43e0635e078bf5b508c9a652d8db91e1 = $(`&lt;div id=&quot;html_43e0635e078bf5b508c9a652d8db91e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c8184705c4a43a4c4cffeeeba8d44b83.setContent(html_43e0635e078bf5b508c9a652d8db91e1);
#
#
#
#         marker_6274a24ac10013546037e9169ed97de5.bindPopup(popup_c8184705c4a43a4c4cffeeeba8d44b83)
#         ;
#
#
#
#
#             var marker_930e920991098bb787846324bede07a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7d788e76922aa334b99bfc47d7077c98);
#
#
#         var popup_dde0f12fb48410aa72235d5b188b0c44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_792ab8fe6bad1f500095d97270457e78 = $(`&lt;div id=&quot;html_792ab8fe6bad1f500095d97270457e78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dde0f12fb48410aa72235d5b188b0c44.setContent(html_792ab8fe6bad1f500095d97270457e78);
#
#
#
#         marker_930e920991098bb787846324bede07a0.bindPopup(popup_dde0f12fb48410aa72235d5b188b0c44)
#         ;
#
#
#
#
#             var marker_5c83377b771292214652c8fb420b9a01 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7d788e76922aa334b99bfc47d7077c98);
#
#
#         var popup_1ff429f7a47891179839560ecb6ed21a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc592018ace8223347419089c2d4ba4 = $(`&lt;div id=&quot;html_7cc592018ace8223347419089c2d4ba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1ff429f7a47891179839560ecb6ed21a.setContent(html_7cc592018ace8223347419089c2d4ba4);
#
#
#
#         marker_5c83377b771292214652c8fb420b9a01.bindPopup(popup_1ff429f7a47891179839560ecb6ed21a)
#         ;
#
#
#
#
#             var marker_760e72e0385ad3f6bb93079a71761948 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7d788e76922aa334b99bfc47d7077c98);
#
#
#         var popup_6412e601b6214176c330c67db01213a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9965b15d504dcb4e634fef201c60adb9 = $(`&lt;div id=&quot;html_9965b15d504dcb4e634fef201c60adb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6412e601b6214176c330c67db01213a2.setContent(html_9965b15d504dcb4e634fef201c60adb9);
#
#
#
#         marker_760e72e0385ad3f6bb93079a71761948.bindPopup(popup_6412e601b6214176c330c67db01213a2)
#         ;
#
#
#
#
#             var marker_8c8b5ce2aedcafd3d44aeb684e022e65 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7d788e76922aa334b99bfc47d7077c98);
#
#
#         var popup_0bb28a0e2d8fe68b5f481ede4816c990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ac4c8601210c4ed23df2c71f3fff436 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ac4c8601210c4ed23df2c71f3fff436&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ac4c8601210c4ed23df2c71f3fff436 = L.map(
#                 &quot;map_0ac4c8601210c4ed23df2c71f3fff436&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02237de157f51c9d9c099cad693777ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02237de157f51c9d9c099cad693777ec.addTo(map_0ac4c8601210c4ed23df2c71f3fff436);
#
#
#             var feature_group_99cdc8d10f97c28ce9e5f33e21805877 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_99cdc8d10f97c28ce9e5f33e21805877.addTo(map_0ac4c8601210c4ed23df2c71f3fff436);
#
#
#             var feature_group_sub_group_c58f8f4136bbb9635315141170f9c0da = L.featureGroup.subGroup(
#                 feature_group_99cdc8d10f97c28ce9e5f33e21805877
#             );
#
#
#             var marker_b53f47e4103597d14ad369a95db824e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c58f8f4136bbb9635315141170f9c0da);
#
#
#         var popup_26fdd7b8dd4918b85ff4f7eb643e5b5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d35b7f2cef4e6bc96c10dae040a7b3 = $(`&lt;div id=&quot;html_27d35b7f2cef4e6bc96c10dae040a7b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_26fdd7b8dd4918b85ff4f7eb643e5b5f.setContent(html_27d35b7f2cef4e6bc96c10dae040a7b3);
#
#
#
#         marker_b53f47e4103597d14ad369a95db824e1.bindPopup(popup_26fdd7b8dd4918b85ff4f7eb643e5b5f)
#         ;
#
#
#
#
#             var marker_c846668b9e718323bc50f8e774a61837 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c58f8f4136bbb9635315141170f9c0da);
#
#
#         var popup_68f7a4676cb7103be56b370544eb31bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4637f5e71cf86d267266a2d6c584abce = $(`&lt;div id=&quot;html_4637f5e71cf86d267266a2d6c584abce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_68f7a4676cb7103be56b370544eb31bd.setContent(html_4637f5e71cf86d267266a2d6c584abce);
#
#
#
#         marker_c846668b9e718323bc50f8e774a61837.bindPopup(popup_68f7a4676cb7103be56b370544eb31bd)
#         ;
#
#
#
#
#             var marker_8e9c09744d638c65e4940461b8d38f9f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c58f8f4136bbb9635315141170f9c0da);
#
#
#         var popup_a75fd7d7600aacf0bdc4ed0077d573aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0b729e19e860b0c0d06243129d3de4a = $(`&lt;div id=&quot;html_d0b729e19e860b0c0d06243129d3de4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a75fd7d7600aacf0bdc4ed0077d573aa.setContent(html_d0b729e19e860b0c0d06243129d3de4a);
#
#
#
#         marker_8e9c09744d638c65e4940461b8d38f9f.bindPopup(popup_a75fd7d7600aacf0bdc4ed0077d573aa)
#         ;
#
#
#
#
#             var marker_a5b4fc81865b6584890a0afe6e88199c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c58f8f4136bbb9635315141170f9c0da);
#
#
#         var popup_a3cb392d6fd7b4e5cb902da585b6b3f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c17b70f0d6dc1b7ecf732e5d5dabe64d = $(`&lt;div id=&quot;html_c17b70f0d6dc1b7ecf732e5d5dabe64d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a3cb392d6fd7b4e5cb902da585b6b3f3.setContent(html_c17b70f0d6dc1b7ecf732e5d5dabe64d);
#
#
#
#         mark
