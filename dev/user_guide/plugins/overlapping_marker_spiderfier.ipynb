# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c30819cb62d9789a0723ff16a2191f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c30819cb62d9789a0723ff16a2191f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c30819cb62d9789a0723ff16a2191f7 = L.map(
#                 &quot;map_4c30819cb62d9789a0723ff16a2191f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d8f411581f1a42f03d331496913a57d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d8f411581f1a42f03d331496913a57d.addTo(map_4c30819cb62d9789a0723ff16a2191f7);
#
#
#             var marker_43dc988bfcd52de31997210063d573ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4c30819cb62d9789a0723ff16a2191f7);
#
#
#         var popup_bd821a374d27dc114b099cc34a4aec68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31615262d84a16e6c84717e16503411a = $(`&lt;div id=&quot;html_31615262d84a16e6c84717e16503411a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bd821a374d27dc114b099cc34a4aec68.setContent(html_31615262d84a16e6c84717e16503411a);
#
#
#
#         marker_43dc988bfcd52de31997210063d573ce.bindPopup(popup_bd821a374d27dc114b099cc34a4aec68)
#         ;
#
#
#
#
#             var marker_0f3946f1f10219c8018dd195b14be384 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4c30819cb62d9789a0723ff16a2191f7);
#
#
#         var popup_1d0a4697c2ef2b231877815a10341814 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3edc6ac334e1d8addcd10acb1348ca69 = $(`&lt;div id=&quot;html_3edc6ac334e1d8addcd10acb1348ca69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1d0a4697c2ef2b231877815a10341814.setContent(html_3edc6ac334e1d8addcd10acb1348ca69);
#
#
#
#         marker_0f3946f1f10219c8018dd195b14be384.bindPopup(popup_1d0a4697c2ef2b231877815a10341814)
#         ;
#
#
#
#
#             var marker_044a50433465adcec13f7b934e832c2e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4c30819cb62d9789a0723ff16a2191f7);
#
#
#         var popup_2e11b132b0646fbd14f71ec6c2a6d90f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fd049e879292176ca53ba65bac63cae = $(`&lt;div id=&quot;html_2fd049e879292176ca53ba65bac63cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2e11b132b0646fbd14f71ec6c2a6d90f.setContent(html_2fd049e879292176ca53ba65bac63cae);
#
#
#
#         marker_044a50433465adcec13f7b934e832c2e.bindPopup(popup_2e11b132b0646fbd14f71ec6c2a6d90f)
#         ;
#
#
#
#
#             var marker_01e1ddce9d1a01f64ebac526df5aba6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4c30819cb62d9789a0723ff16a2191f7);
#
#
#         var popup_977b37822a024d9242d3886224aaf756 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d017fbe700f0dd723944fe70e2fa1d06 = $(`&lt;div id=&quot;html_d017fbe700f0dd723944fe70e2fa1d06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_977b37822a024d9242d3886224aaf756.setContent(html_d017fbe700f0dd723944fe70e2fa1d06);
#
#
#
#         marker_01e1ddce9d1a01f64ebac526df5aba6d.bindPopup(popup_977b37822a024d9242d3886224aaf756)
#         ;
#
#
#
#
#             var marker_c8c35c8505eca36e32d91a12fea1764c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4c30819cb62d9789a0723ff16a2191f7);
#
#
#         var popup_b7ee2cc017cb1f49ef30c84bdfe6fc39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca099cab5a0dffb58b94cd80211b75ee = $(`&lt;div id=&quot;html_ca099cab5a0dffb58b94cd80211b75ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b7ee2cc017cb1f49ef30c84bdfe6fc39.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6bee6f2711a3ea75a2cca0499954a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6bee6f2711a3ea75a2cca0499954a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6bee6f2711a3ea75a2cca0499954a3 = L.map(
#                 &quot;map_cb6bee6f2711a3ea75a2cca0499954a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2dd2d8291f79adeccd528d5be034d2b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2dd2d8291f79adeccd528d5be034d2b3.addTo(map_cb6bee6f2711a3ea75a2cca0499954a3);
#
#
#             var feature_group_0901af3e30df1626ef99cb3129cba710 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3403272a7d61726b30bd558796ea81c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0901af3e30df1626ef99cb3129cba710);
#
#
#         var popup_d7fd8caf6c17a1b8826cf568232b341f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6da1ac8ad0f59e75cb7210e937d60851 = $(`&lt;div id=&quot;html_6da1ac8ad0f59e75cb7210e937d60851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d7fd8caf6c17a1b8826cf568232b341f.setContent(html_6da1ac8ad0f59e75cb7210e937d60851);
#
#
#
#         marker_3403272a7d61726b30bd558796ea81c7.bindPopup(popup_d7fd8caf6c17a1b8826cf568232b341f)
#         ;
#
#
#
#
#             var marker_c9f5e08c46cfc264a3f5f09d4896dabe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0901af3e30df1626ef99cb3129cba710);
#
#
#         var popup_d11f038e816a10e58da7417c0acdc25b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_262b519c015007c2e4f413a83164f622 = $(`&lt;div id=&quot;html_262b519c015007c2e4f413a83164f622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d11f038e816a10e58da7417c0acdc25b.setContent(html_262b519c015007c2e4f413a83164f622);
#
#
#
#         marker_c9f5e08c46cfc264a3f5f09d4896dabe.bindPopup(popup_d11f038e816a10e58da7417c0acdc25b)
#         ;
#
#
#
#
#             var marker_168e871710cb1b608d0a1ba74eb8df97 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0901af3e30df1626ef99cb3129cba710);
#
#
#         var popup_86bcfdb5ca9b8e81f5346fa8b055bc4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_024cb1f4ecd75526a3ad596037fbedea = $(`&lt;div id=&quot;html_024cb1f4ecd75526a3ad596037fbedea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_86bcfdb5ca9b8e81f5346fa8b055bc4b.setContent(html_024cb1f4ecd75526a3ad596037fbedea);
#
#
#
#         marker_168e871710cb1b608d0a1ba74eb8df97.bindPopup(popup_86bcfdb5ca9b8e81f5346fa8b055bc4b)
#         ;
#
#
#
#
#             var marker_9366a9cae1ca1e99ed7230c224084850 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0901af3e30df1626ef99cb3129cba710);
#
#
#         var popup_7ddf873e9a7eeda01cf290c6097745f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eb51503145ddf263875a1876690ee23 = $(`&lt;div id=&quot;html_5eb51503145ddf263875a1876690ee23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7ddf873e9a7eeda01cf290c6097745f1.setContent(html_5eb51503145ddf263875a1876690ee23);
#
#
#
#         marker_9366a9cae1ca1e99ed7230c224084850.bindPopup(popup_7ddf873e9a7eeda01cf290c6097745f1)
#         ;
#
#
#
#
#             var marker_d948447700c8876cec18f93237481c5f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0901af3e30df1626ef99cb3129cba710);
#
#
#         var popup_86afe028e7c6a97d80decad0e32cbcd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5055378827c00b2d7ea1cd29ba5a3df1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5055378827c00b2d7ea1cd29ba5a3df1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5055378827c00b2d7ea1cd29ba5a3df1 = L.map(
#                 &quot;map_5055378827c00b2d7ea1cd29ba5a3df1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85d6cd09e145628dab0ac1d6b9bc355c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85d6cd09e145628dab0ac1d6b9bc355c.addTo(map_5055378827c00b2d7ea1cd29ba5a3df1);
#
#
#             var feature_group_65e97df4c2d306affda599517e17542f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_65e97df4c2d306affda599517e17542f.addTo(map_5055378827c00b2d7ea1cd29ba5a3df1);
#
#
#             var feature_group_sub_group_634a253af92d925c50740336562ffbd1 = L.featureGroup.subGroup(
#                 feature_group_65e97df4c2d306affda599517e17542f
#             );
#
#
#             var marker_2ab119d854b8247572d743bafe70b1ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_634a253af92d925c50740336562ffbd1);
#
#
#         var popup_5acec93d552aa5f42dec9e318dd2232f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75185e573a76f9ed0bad2d22de19b4fc = $(`&lt;div id=&quot;html_75185e573a76f9ed0bad2d22de19b4fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5acec93d552aa5f42dec9e318dd2232f.setContent(html_75185e573a76f9ed0bad2d22de19b4fc);
#
#
#
#         marker_2ab119d854b8247572d743bafe70b1ef.bindPopup(popup_5acec93d552aa5f42dec9e318dd2232f)
#         ;
#
#
#
#
#             var marker_31124d8978c1d4bcdb87388729043f03 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_634a253af92d925c50740336562ffbd1);
#
#
#         var popup_642fc23d2f3f050bde477976de1d66ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eff12e9831eb53405808cb52f378c37 = $(`&lt;div id=&quot;html_5eff12e9831eb53405808cb52f378c37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_642fc23d2f3f050bde477976de1d66ee.setContent(html_5eff12e9831eb53405808cb52f378c37);
#
#
#
#         marker_31124d8978c1d4bcdb87388729043f03.bindPopup(popup_642fc23d2f3f050bde477976de1d66ee)
#         ;
#
#
#
#
#             var marker_91a4318313b64072212117384aebf228 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_634a253af92d925c50740336562ffbd1);
#
#
#         var popup_b709e23ab2b18f9f940581d9981e21b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94d8fb69ea5548f2a443009594d04105 = $(`&lt;div id=&quot;html_94d8fb69ea5548f2a443009594d04105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b709e23ab2b18f9f940581d9981e21b2.setContent(html_94d8fb69ea5548f2a443009594d04105);
#
#
#
#         marker_91a4318313b64072212117384aebf228.bindPopup(popup_b709e23ab2b18f9f940581d9981e21b2)
#         ;
#
#
#
#
#             var marker_40e25b15b13097ea33076d28f5516231 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_634a253af92d925c50740336562ffbd1);
#
#
#         var popup_2a6698da170bc187afa7b261d88fa183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fcb9f5f1f7bca0553b9c5b7fdace6a7 = $(`&lt;div id=&quot;html_5fcb9f5f1f7bca0553b9c5b7fdace6a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2a6698da170bc187afa7b261d88fa183.setContent(html_5fcb9f5f1f7bca0553b9c5b7fdace6a7);
#
#
#
#         marker_
