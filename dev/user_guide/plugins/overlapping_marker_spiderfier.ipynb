# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_576ea88bf83b3959fc1a424f929a0337 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_576ea88bf83b3959fc1a424f929a0337&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_576ea88bf83b3959fc1a424f929a0337 = L.map(
#                 &quot;map_576ea88bf83b3959fc1a424f929a0337&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45e7ac4972e1f9a78e21c5e4b87aba7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45e7ac4972e1f9a78e21c5e4b87aba7b.addTo(map_576ea88bf83b3959fc1a424f929a0337);
#
#
#             var marker_126745f028fe414074dc2a8cd0179532 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_576ea88bf83b3959fc1a424f929a0337);
#
#
#         var popup_b259aa3a3929585fd35134687940f44f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f27a6a2fe73a963b8bbd0f18b87345b = $(`&lt;div id=&quot;html_6f27a6a2fe73a963b8bbd0f18b87345b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b259aa3a3929585fd35134687940f44f.setContent(html_6f27a6a2fe73a963b8bbd0f18b87345b);
#
#
#
#         marker_126745f028fe414074dc2a8cd0179532.bindPopup(popup_b259aa3a3929585fd35134687940f44f)
#         ;
#
#
#
#
#             var marker_a9c1d9edef5da0800ff55cbe7488c2d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_576ea88bf83b3959fc1a424f929a0337);
#
#
#         var popup_0b4f9fce553dff0d0354abc2569f8a1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_380adb2303ebbb753ce999c5b9ada0ce = $(`&lt;div id=&quot;html_380adb2303ebbb753ce999c5b9ada0ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b4f9fce553dff0d0354abc2569f8a1c.setContent(html_380adb2303ebbb753ce999c5b9ada0ce);
#
#
#
#         marker_a9c1d9edef5da0800ff55cbe7488c2d8.bindPopup(popup_0b4f9fce553dff0d0354abc2569f8a1c)
#         ;
#
#
#
#
#             var marker_78e7e7d556931ed00bc362b88953fe18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_576ea88bf83b3959fc1a424f929a0337);
#
#
#         var popup_4b6739f9c3d6562a35b4641f9c18df54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b22c5732ee8cdab25a99ca730148a6a = $(`&lt;div id=&quot;html_4b22c5732ee8cdab25a99ca730148a6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4b6739f9c3d6562a35b4641f9c18df54.setContent(html_4b22c5732ee8cdab25a99ca730148a6a);
#
#
#
#         marker_78e7e7d556931ed00bc362b88953fe18.bindPopup(popup_4b6739f9c3d6562a35b4641f9c18df54)
#         ;
#
#
#
#
#             var marker_a746e16847a7e9eb0f5eb9cadde39799 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_576ea88bf83b3959fc1a424f929a0337);
#
#
#         var popup_3cc5c6ae75e4c8d7245548b4b4510aa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_234ba3ebe8864baa3412dfeb52d0c128 = $(`&lt;div id=&quot;html_234ba3ebe8864baa3412dfeb52d0c128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3cc5c6ae75e4c8d7245548b4b4510aa1.setContent(html_234ba3ebe8864baa3412dfeb52d0c128);
#
#
#
#         marker_a746e16847a7e9eb0f5eb9cadde39799.bindPopup(popup_3cc5c6ae75e4c8d7245548b4b4510aa1)
#         ;
#
#
#
#
#             var marker_5017d13a11448953aa9f07dda08b3aa6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_576ea88bf83b3959fc1a424f929a0337);
#
#
#         var popup_9db6d0730fb19e55e0992f843b7c49e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8e5e38ba944a7a885c28f6e810dc96d = $(`&lt;div id=&quot;html_b8e5e38ba944a7a885c28f6e810dc96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9db6d0730fb19e55e0992f843b7c49

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca176eb439645ab4cfc542942a292803 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca176eb439645ab4cfc542942a292803&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca176eb439645ab4cfc542942a292803 = L.map(
#                 &quot;map_ca176eb439645ab4cfc542942a292803&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cc5856e1bdb444ba7833ecbd0f24802 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cc5856e1bdb444ba7833ecbd0f24802.addTo(map_ca176eb439645ab4cfc542942a292803);
#
#
#             var feature_group_23f159382b97b97db14ecbc67aa3c149 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_708a88b76977ab956ed1c72abfca530b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_23f159382b97b97db14ecbc67aa3c149);
#
#
#         var popup_81264aa2ea2f2d9197ee81686016886a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8bd0cb0d8dd6903d754c6b8d8645813 = $(`&lt;div id=&quot;html_a8bd0cb0d8dd6903d754c6b8d8645813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_81264aa2ea2f2d9197ee81686016886a.setContent(html_a8bd0cb0d8dd6903d754c6b8d8645813);
#
#
#
#         marker_708a88b76977ab956ed1c72abfca530b.bindPopup(popup_81264aa2ea2f2d9197ee81686016886a)
#         ;
#
#
#
#
#             var marker_bbd44d07700364f18aea5b9817efcb4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_23f159382b97b97db14ecbc67aa3c149);
#
#
#         var popup_519b65cbcdaa3ca3ff5fc9795095b430 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e2106f7bae45f92f480016d249cc175 = $(`&lt;div id=&quot;html_3e2106f7bae45f92f480016d249cc175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_519b65cbcdaa3ca3ff5fc9795095b430.setContent(html_3e2106f7bae45f92f480016d249cc175);
#
#
#
#         marker_bbd44d07700364f18aea5b9817efcb4e.bindPopup(popup_519b65cbcdaa3ca3ff5fc9795095b430)
#         ;
#
#
#
#
#             var marker_5233c5e40a15f008abbf75fdd56f1ec5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_23f159382b97b97db14ecbc67aa3c149);
#
#
#         var popup_6fed42314b45c27f61b2b341ecf399b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea0d8aa5337020bfd8c6aea44038fc3 = $(`&lt;div id=&quot;html_bea0d8aa5337020bfd8c6aea44038fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6fed42314b45c27f61b2b341ecf399b4.setContent(html_bea0d8aa5337020bfd8c6aea44038fc3);
#
#
#
#         marker_5233c5e40a15f008abbf75fdd56f1ec5.bindPopup(popup_6fed42314b45c27f61b2b341ecf399b4)
#         ;
#
#
#
#
#             var marker_c454938f9b1a6081b50065313ac8ec15 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_23f159382b97b97db14ecbc67aa3c149);
#
#
#         var popup_2c02ea9b2ea3ac6a66f79b081c154d54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_117dc11269479d5d7ebf4fac1aa32974 = $(`&lt;div id=&quot;html_117dc11269479d5d7ebf4fac1aa32974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c02ea9b2ea3ac6a66f79b081c154d54.setContent(html_117dc11269479d5d7ebf4fac1aa32974);
#
#
#
#         marker_c454938f9b1a6081b50065313ac8ec15.bindPopup(popup_2c02ea9b2ea3ac6a66f79b081c154d54)
#         ;
#
#
#
#
#             var marker_0fadf5a8a50b6ab5ddc7dce6bc5649b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_23f159382b97b97db14ecbc67aa3c149);
#
#
#         var popup_a5a76d9e4e9ae4381893518c75cb88ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4496c0f9285474616c48b4c4137d4b2b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4496c0f9285474616c48b4c4137d4b2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4496c0f9285474616c48b4c4137d4b2b = L.map(
#                 &quot;map_4496c0f9285474616c48b4c4137d4b2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73e15ad9ead564b42d631bfc2fec0189 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73e15ad9ead564b42d631bfc2fec0189.addTo(map_4496c0f9285474616c48b4c4137d4b2b);
#
#
#             var feature_group_e01ae8a5af521bf89954d7d581bea137 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e01ae8a5af521bf89954d7d581bea137.addTo(map_4496c0f9285474616c48b4c4137d4b2b);
#
#
#             var feature_group_sub_group_a69d275e5600bdf46857b8a83f8ce8f7 = L.featureGroup.subGroup(
#                 feature_group_e01ae8a5af521bf89954d7d581bea137
#             );
#
#
#             var marker_31e07022477dbff702b288f429fdf5f7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a69d275e5600bdf46857b8a83f8ce8f7);
#
#
#         var popup_f2d083479e58d7a389a5169d087a37da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72027c981554e02fee8f0d910918bc2e = $(`&lt;div id=&quot;html_72027c981554e02fee8f0d910918bc2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f2d083479e58d7a389a5169d087a37da.setContent(html_72027c981554e02fee8f0d910918bc2e);
#
#
#
#         marker_31e07022477dbff702b288f429fdf5f7.bindPopup(popup_f2d083479e58d7a389a5169d087a37da)
#         ;
#
#
#
#
#             var marker_124574b92a704bdeec913c172ac03ea0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a69d275e5600bdf46857b8a83f8ce8f7);
#
#
#         var popup_d40e9c0f3b03c462d759126b0d174358 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e74777efe60654b99786534104a08d1f = $(`&lt;div id=&quot;html_e74777efe60654b99786534104a08d1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d40e9c0f3b03c462d759126b0d174358.setContent(html_e74777efe60654b99786534104a08d1f);
#
#
#
#         marker_124574b92a704bdeec913c172ac03ea0.bindPopup(popup_d40e9c0f3b03c462d759126b0d174358)
#         ;
#
#
#
#
#             var marker_f763fc850b372c3e0703c8cc1d270f8e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a69d275e5600bdf46857b8a83f8ce8f7);
#
#
#         var popup_37131bc7d1003b1e0d6d8c7493a0f0f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b736e10afb825bb4d8efa7afbf4b5203 = $(`&lt;div id=&quot;html_b736e10afb825bb4d8efa7afbf4b5203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_37131bc7d1003b1e0d6d8c7493a0f0f1.setContent(html_b736e10afb825bb4d8efa7afbf4b5203);
#
#
#
#         marker_f763fc850b372c3e0703c8cc1d270f8e.bindPopup(popup_37131bc7d1003b1e0d6d8c7493a0f0f1)
#         ;
#
#
#
#
#             var marker_48b45554e0d08a0786a80c739b852b52 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a69d275e5600bdf46857b8a83f8ce8f7);
#
#
#         var popup_67ceda2cda37275b935d99f698660cca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f880523a26d654ca89d5d6bf61508365 = $(`&lt;div id=&quot;html_f880523a26d654ca89d5d6bf61508365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_67ceda2cda37275b935d99f698660cca.setContent(html_f880523a26d654ca89d5d6bf61508365);
#
#
#
#         mark
