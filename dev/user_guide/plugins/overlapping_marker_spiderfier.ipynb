# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fc6660a0ee347c70e696c4bfdb5e26f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fc6660a0ee347c70e696c4bfdb5e26f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fc6660a0ee347c70e696c4bfdb5e26f = L.map(
#                 &quot;map_5fc6660a0ee347c70e696c4bfdb5e26f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb3a807fdf062eb6d07eb93c987920a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deb3a807fdf062eb6d07eb93c987920a.addTo(map_5fc6660a0ee347c70e696c4bfdb5e26f);
#
#
#             var marker_e945216253fdceb397b30eccadf1ab83 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5fc6660a0ee347c70e696c4bfdb5e26f);
#
#
#         var popup_19e49ba6b8db08bb357ee0290a0335d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc7ef5ce06c5de4b3d77d322617fc57b = $(`&lt;div id=&quot;html_cc7ef5ce06c5de4b3d77d322617fc57b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_19e49ba6b8db08bb357ee0290a0335d4.setContent(html_cc7ef5ce06c5de4b3d77d322617fc57b);
#
#
#
#         marker_e945216253fdceb397b30eccadf1ab83.bindPopup(popup_19e49ba6b8db08bb357ee0290a0335d4)
#         ;
#
#
#
#
#             var marker_322c9a879262a591737da0d930e3b2b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5fc6660a0ee347c70e696c4bfdb5e26f);
#
#
#         var popup_41eb2ec54f5c8817755580a753438da0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f3277d8cf12542222a505ff9b3b1d15 = $(`&lt;div id=&quot;html_6f3277d8cf12542222a505ff9b3b1d15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_41eb2ec54f5c8817755580a753438da0.setContent(html_6f3277d8cf12542222a505ff9b3b1d15);
#
#
#
#         marker_322c9a879262a591737da0d930e3b2b9.bindPopup(popup_41eb2ec54f5c8817755580a753438da0)
#         ;
#
#
#
#
#             var marker_706c6fe244784ed2587feab612ed5c72 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5fc6660a0ee347c70e696c4bfdb5e26f);
#
#
#         var popup_ba0ada1ccd26d6648a464bf7f3c4753e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c1330bcee7b86c24820c175f0f8d113 = $(`&lt;div id=&quot;html_2c1330bcee7b86c24820c175f0f8d113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ba0ada1ccd26d6648a464bf7f3c4753e.setContent(html_2c1330bcee7b86c24820c175f0f8d113);
#
#
#
#         marker_706c6fe244784ed2587feab612ed5c72.bindPopup(popup_ba0ada1ccd26d6648a464bf7f3c4753e)
#         ;
#
#
#
#
#             var marker_27898f8f344e2941e66501037c95387a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5fc6660a0ee347c70e696c4bfdb5e26f);
#
#
#         var popup_5f1172e64c452718bf78b779e05caf85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_866ec7f5d407620e19edf59fab796d79 = $(`&lt;div id=&quot;html_866ec7f5d407620e19edf59fab796d79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5f1172e64c452718bf78b779e05caf85.setContent(html_866ec7f5d407620e19edf59fab796d79);
#
#
#
#         marker_27898f8f344e2941e66501037c95387a.bindPopup(popup_5f1172e64c452718bf78b779e05caf85)
#         ;
#
#
#
#
#             var marker_ff9e25f962625d174928b9039f0ae076 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5fc6660a0ee347c70e696c4bfdb5e26f);
#
#
#         var popup_ebed64f2b3f389ae85599dcad9ad141a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e6761b25af6253f0f394f58696405dd = $(`&lt;div id=&quot;html_4e6761b25af6253f0f394f58696405dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ebed64f2b3f389ae85599dcad9ad14

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2272d5e6b2ae5b0157e4c8ef5bada96b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2272d5e6b2ae5b0157e4c8ef5bada96b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2272d5e6b2ae5b0157e4c8ef5bada96b = L.map(
#                 &quot;map_2272d5e6b2ae5b0157e4c8ef5bada96b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2e665e6e8912b85e66eb1872cfb8b43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2e665e6e8912b85e66eb1872cfb8b43.addTo(map_2272d5e6b2ae5b0157e4c8ef5bada96b);
#
#
#             var feature_group_d262bdc94bc06f9618db799efde1599f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9d76f18fbed2feaec91172df896be526 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d262bdc94bc06f9618db799efde1599f);
#
#
#         var popup_b90c085419ea92c75ed2df71d923eea5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d26913284235f7e0c4df047199bd8707 = $(`&lt;div id=&quot;html_d26913284235f7e0c4df047199bd8707&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b90c085419ea92c75ed2df71d923eea5.setContent(html_d26913284235f7e0c4df047199bd8707);
#
#
#
#         marker_9d76f18fbed2feaec91172df896be526.bindPopup(popup_b90c085419ea92c75ed2df71d923eea5)
#         ;
#
#
#
#
#             var marker_e428e13f9df31eff4b8613b5ea7c3e64 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d262bdc94bc06f9618db799efde1599f);
#
#
#         var popup_851c01d5e98216e9ddfa543ee66df954 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26f293b006739670fa483b6dc187bdf8 = $(`&lt;div id=&quot;html_26f293b006739670fa483b6dc187bdf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_851c01d5e98216e9ddfa543ee66df954.setContent(html_26f293b006739670fa483b6dc187bdf8);
#
#
#
#         marker_e428e13f9df31eff4b8613b5ea7c3e64.bindPopup(popup_851c01d5e98216e9ddfa543ee66df954)
#         ;
#
#
#
#
#             var marker_3d13d987b8c271c72e167088c9f837a1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d262bdc94bc06f9618db799efde1599f);
#
#
#         var popup_4b78f5eaf5c20d222306d655427138b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbd3957e75177e8691be1d13952923a4 = $(`&lt;div id=&quot;html_cbd3957e75177e8691be1d13952923a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4b78f5eaf5c20d222306d655427138b6.setContent(html_cbd3957e75177e8691be1d13952923a4);
#
#
#
#         marker_3d13d987b8c271c72e167088c9f837a1.bindPopup(popup_4b78f5eaf5c20d222306d655427138b6)
#         ;
#
#
#
#
#             var marker_a282bf0080b5a26c0e5ab358b8ea1826 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d262bdc94bc06f9618db799efde1599f);
#
#
#         var popup_66766f39f75787a3a0c8e91fccc7e64b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf18bd9588bb0d34c142b321535115e9 = $(`&lt;div id=&quot;html_bf18bd9588bb0d34c142b321535115e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_66766f39f75787a3a0c8e91fccc7e64b.setContent(html_bf18bd9588bb0d34c142b321535115e9);
#
#
#
#         marker_a282bf0080b5a26c0e5ab358b8ea1826.bindPopup(popup_66766f39f75787a3a0c8e91fccc7e64b)
#         ;
#
#
#
#
#             var marker_9d0b4189093965354d4d5a97dcb1f0c0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d262bdc94bc06f9618db799efde1599f);
#
#
#         var popup_ac3f35001db4f650e009536f600d56de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd1379f4507e043b4df5809cfd42990e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd1379f4507e043b4df5809cfd42990e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd1379f4507e043b4df5809cfd42990e = L.map(
#                 &quot;map_fd1379f4507e043b4df5809cfd42990e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d0b853f0a5d0719fabcfadb5a397dcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d0b853f0a5d0719fabcfadb5a397dcc.addTo(map_fd1379f4507e043b4df5809cfd42990e);
#
#
#             var feature_group_80b301a5f4c30ff19dba4974702312c1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_80b301a5f4c30ff19dba4974702312c1.addTo(map_fd1379f4507e043b4df5809cfd42990e);
#
#
#             var feature_group_sub_group_a47f3a4c4c859bee8dde92751ebe78a5 = L.featureGroup.subGroup(
#                 feature_group_80b301a5f4c30ff19dba4974702312c1
#             );
#
#
#             var marker_bb52a82cb8beba0c94902c148af76548 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a47f3a4c4c859bee8dde92751ebe78a5);
#
#
#         var popup_7ffdfe3cef2bf297fa57d543c35a54fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cec90078ab09cbbf2c90e226a51ca8fe = $(`&lt;div id=&quot;html_cec90078ab09cbbf2c90e226a51ca8fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7ffdfe3cef2bf297fa57d543c35a54fd.setContent(html_cec90078ab09cbbf2c90e226a51ca8fe);
#
#
#
#         marker_bb52a82cb8beba0c94902c148af76548.bindPopup(popup_7ffdfe3cef2bf297fa57d543c35a54fd)
#         ;
#
#
#
#
#             var marker_231f02669db4c618dae62705275cb256 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a47f3a4c4c859bee8dde92751ebe78a5);
#
#
#         var popup_ad1080dc69484239a3252412f3ef5318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cce511b3973262a4fc9ff95160c6884 = $(`&lt;div id=&quot;html_6cce511b3973262a4fc9ff95160c6884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ad1080dc69484239a3252412f3ef5318.setContent(html_6cce511b3973262a4fc9ff95160c6884);
#
#
#
#         marker_231f02669db4c618dae62705275cb256.bindPopup(popup_ad1080dc69484239a3252412f3ef5318)
#         ;
#
#
#
#
#             var marker_202fbc371125d8e81c946def3eeaef61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a47f3a4c4c859bee8dde92751ebe78a5);
#
#
#         var popup_bf1c389831bfb0149e4ba4de31a16eba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a9ebd69206e51b1c708f3d7d2dd565a = $(`&lt;div id=&quot;html_7a9ebd69206e51b1c708f3d7d2dd565a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bf1c389831bfb0149e4ba4de31a16eba.setContent(html_7a9ebd69206e51b1c708f3d7d2dd565a);
#
#
#
#         marker_202fbc371125d8e81c946def3eeaef61.bindPopup(popup_bf1c389831bfb0149e4ba4de31a16eba)
#         ;
#
#
#
#
#             var marker_eab329eb6931bbfeeb6459620db79a70 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a47f3a4c4c859bee8dde92751ebe78a5);
#
#
#         var popup_fc4f56f9c7254aa62da65f4e93cc9f88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f19feb892fdef8bba005335f1f87069 = $(`&lt;div id=&quot;html_2f19feb892fdef8bba005335f1f87069&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fc4f56f9c7254aa62da65f4e93cc9f88.setContent(html_2f19feb892fdef8bba005335f1f87069);
#
#
#
#         mark
