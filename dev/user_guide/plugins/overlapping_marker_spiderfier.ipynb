# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ece84582a162bde44f863c89395ca0d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ece84582a162bde44f863c89395ca0d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ece84582a162bde44f863c89395ca0d2 = L.map(
#                 &quot;map_ece84582a162bde44f863c89395ca0d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a907889562eadbfdfc656d54fc85dce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a907889562eadbfdfc656d54fc85dce.addTo(map_ece84582a162bde44f863c89395ca0d2);
#
#
#             var marker_0f4740acb59fbe58864e2ebebe9621d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ece84582a162bde44f863c89395ca0d2);
#
#
#         var popup_4a0c8225788f4d40248782797607979a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b85e1de90d2a68369d6b5337cbe5b790 = $(`&lt;div id=&quot;html_b85e1de90d2a68369d6b5337cbe5b790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4a0c8225788f4d40248782797607979a.setContent(html_b85e1de90d2a68369d6b5337cbe5b790);
#
#
#
#         marker_0f4740acb59fbe58864e2ebebe9621d8.bindPopup(popup_4a0c8225788f4d40248782797607979a)
#         ;
#
#
#
#
#             var marker_6d25fe1187881be1bf879b52b5ae8fcb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ece84582a162bde44f863c89395ca0d2);
#
#
#         var popup_4504e880a216a325c0181a57bbadd968 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4237cc274f7d66605121397e2c568131 = $(`&lt;div id=&quot;html_4237cc274f7d66605121397e2c568131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4504e880a216a325c0181a57bbadd968.setContent(html_4237cc274f7d66605121397e2c568131);
#
#
#
#         marker_6d25fe1187881be1bf879b52b5ae8fcb.bindPopup(popup_4504e880a216a325c0181a57bbadd968)
#         ;
#
#
#
#
#             var marker_0763b34fa3b0fbdee4d123a2b799f1e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ece84582a162bde44f863c89395ca0d2);
#
#
#         var popup_bb321aab434b999c5d5e788ed773cb32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5882f8bbf70b8cc24f084c8be26f1993 = $(`&lt;div id=&quot;html_5882f8bbf70b8cc24f084c8be26f1993&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bb321aab434b999c5d5e788ed773cb32.setContent(html_5882f8bbf70b8cc24f084c8be26f1993);
#
#
#
#         marker_0763b34fa3b0fbdee4d123a2b799f1e8.bindPopup(popup_bb321aab434b999c5d5e788ed773cb32)
#         ;
#
#
#
#
#             var marker_7f9d16e6857e578c59925ccfd0be65ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ece84582a162bde44f863c89395ca0d2);
#
#
#         var popup_936560c93afad9811fd441490ae29d95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf565b5318f493ee99f23919b3b9ef71 = $(`&lt;div id=&quot;html_cf565b5318f493ee99f23919b3b9ef71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_936560c93afad9811fd441490ae29d95.setContent(html_cf565b5318f493ee99f23919b3b9ef71);
#
#
#
#         marker_7f9d16e6857e578c59925ccfd0be65ab.bindPopup(popup_936560c93afad9811fd441490ae29d95)
#         ;
#
#
#
#
#             var marker_595cb3ee21452371b537f291261efd48 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ece84582a162bde44f863c89395ca0d2);
#
#
#         var popup_4b7ffbcecaca9465b660de611d452dc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66ccefc1ca563b9398d3bae285ff4369 = $(`&lt;div id=&quot;html_66ccefc1ca563b9398d3bae285ff4369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4b7ffbcecaca9465b660de611d452dc4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93656f367f02db1cce7cbf82e7f921de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93656f367f02db1cce7cbf82e7f921de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93656f367f02db1cce7cbf82e7f921de = L.map(
#                 &quot;map_93656f367f02db1cce7cbf82e7f921de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf82dc21e712ea4877c072ee4aad140e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf82dc21e712ea4877c072ee4aad140e.addTo(map_93656f367f02db1cce7cbf82e7f921de);
#
#
#             var feature_group_da425802aa88d393a62858d2dff65d62 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c982eefacf8d3ee4d5dc954a108de1e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_da425802aa88d393a62858d2dff65d62);
#
#
#         var popup_b642ab4c5c1097bb0f62ae63dacb6f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37eb7a2834dbb7dafea962948b6328f2 = $(`&lt;div id=&quot;html_37eb7a2834dbb7dafea962948b6328f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b642ab4c5c1097bb0f62ae63dacb6f17.setContent(html_37eb7a2834dbb7dafea962948b6328f2);
#
#
#
#         marker_c982eefacf8d3ee4d5dc954a108de1e7.bindPopup(popup_b642ab4c5c1097bb0f62ae63dacb6f17)
#         ;
#
#
#
#
#             var marker_04ecec44190ee637be3b3b378763c289 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_da425802aa88d393a62858d2dff65d62);
#
#
#         var popup_985992fd1862740d2657fc32197f9a28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c8c392dc5d9f58a19af1ec4ab1b7b19 = $(`&lt;div id=&quot;html_6c8c392dc5d9f58a19af1ec4ab1b7b19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_985992fd1862740d2657fc32197f9a28.setContent(html_6c8c392dc5d9f58a19af1ec4ab1b7b19);
#
#
#
#         marker_04ecec44190ee637be3b3b378763c289.bindPopup(popup_985992fd1862740d2657fc32197f9a28)
#         ;
#
#
#
#
#             var marker_2db3533cf855bd55297e9a0b07ae1ac2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_da425802aa88d393a62858d2dff65d62);
#
#
#         var popup_9fb7fe72b6e45c612a315a9eb2ec512f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52eeded42f8f070288109aff3147b030 = $(`&lt;div id=&quot;html_52eeded42f8f070288109aff3147b030&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9fb7fe72b6e45c612a315a9eb2ec512f.setContent(html_52eeded42f8f070288109aff3147b030);
#
#
#
#         marker_2db3533cf855bd55297e9a0b07ae1ac2.bindPopup(popup_9fb7fe72b6e45c612a315a9eb2ec512f)
#         ;
#
#
#
#
#             var marker_dabf11c5bcfce96c1be3b9c68a4c6d56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_da425802aa88d393a62858d2dff65d62);
#
#
#         var popup_0273f76682d71a218c38b4ed4ef86924 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec5fe9477ab898b0b2a61d8255a3d7f1 = $(`&lt;div id=&quot;html_ec5fe9477ab898b0b2a61d8255a3d7f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0273f76682d71a218c38b4ed4ef86924.setContent(html_ec5fe9477ab898b0b2a61d8255a3d7f1);
#
#
#
#         marker_dabf11c5bcfce96c1be3b9c68a4c6d56.bindPopup(popup_0273f76682d71a218c38b4ed4ef86924)
#         ;
#
#
#
#
#             var marker_ad24da7497d71aec27af40dbffcad2c4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_da425802aa88d393a62858d2dff65d62);
#
#
#         var popup_1351f04e19a10b83ca3eef351d3a8f7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cab2a5c0f8eaf6a84f50bf00d2ca9964 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cab2a5c0f8eaf6a84f50bf00d2ca9964&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cab2a5c0f8eaf6a84f50bf00d2ca9964 = L.map(
#                 &quot;map_cab2a5c0f8eaf6a84f50bf00d2ca9964&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1233c8fdbcc177d9ee72bb7425f363ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1233c8fdbcc177d9ee72bb7425f363ff.addTo(map_cab2a5c0f8eaf6a84f50bf00d2ca9964);
#
#
#             var feature_group_c1d34a5819d10ba5e1c5e1d8b1d4d9fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c1d34a5819d10ba5e1c5e1d8b1d4d9fa.addTo(map_cab2a5c0f8eaf6a84f50bf00d2ca9964);
#
#
#             var feature_group_sub_group_2b94f78911a5f8e551b087ddd112d369 = L.featureGroup.subGroup(
#                 feature_group_c1d34a5819d10ba5e1c5e1d8b1d4d9fa
#             );
#
#
#             var marker_c8846a7561597de628ca41aa94c27e16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b94f78911a5f8e551b087ddd112d369);
#
#
#         var popup_dbaf71e1dc875c90be79fed43fdcf567 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcf4f2026aca7bd1afcbb09012afc5f3 = $(`&lt;div id=&quot;html_fcf4f2026aca7bd1afcbb09012afc5f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dbaf71e1dc875c90be79fed43fdcf567.setContent(html_fcf4f2026aca7bd1afcbb09012afc5f3);
#
#
#
#         marker_c8846a7561597de628ca41aa94c27e16.bindPopup(popup_dbaf71e1dc875c90be79fed43fdcf567)
#         ;
#
#
#
#
#             var marker_2e6863c0aefe7f44492cc1a384cba7cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b94f78911a5f8e551b087ddd112d369);
#
#
#         var popup_5c80f3a45cdc8a1e45e638387237c305 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e734aafed47b73a283c7f9c4696a462c = $(`&lt;div id=&quot;html_e734aafed47b73a283c7f9c4696a462c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5c80f3a45cdc8a1e45e638387237c305.setContent(html_e734aafed47b73a283c7f9c4696a462c);
#
#
#
#         marker_2e6863c0aefe7f44492cc1a384cba7cd.bindPopup(popup_5c80f3a45cdc8a1e45e638387237c305)
#         ;
#
#
#
#
#             var marker_09039ca77649e538b2a39bfd7f778964 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b94f78911a5f8e551b087ddd112d369);
#
#
#         var popup_83668813bf4c8c0aa82e505c061c683d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa3914225a77e20a0c79377113d4f3a0 = $(`&lt;div id=&quot;html_fa3914225a77e20a0c79377113d4f3a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_83668813bf4c8c0aa82e505c061c683d.setContent(html_fa3914225a77e20a0c79377113d4f3a0);
#
#
#
#         marker_09039ca77649e538b2a39bfd7f778964.bindPopup(popup_83668813bf4c8c0aa82e505c061c683d)
#         ;
#
#
#
#
#             var marker_e4239598df1de8853f9313758c86e5bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b94f78911a5f8e551b087ddd112d369);
#
#
#         var popup_d58be11625313083c2663f38dd337d53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6478203fe934543ebfbd97ebf876dc51 = $(`&lt;div id=&quot;html_6478203fe934543ebfbd97ebf876dc51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d58be11625313083c2663f38dd337d53.setContent(html_6478203fe934543ebfbd97ebf876dc51);
#
#
#
#         marker_
