# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f70dbca71eed7c5de8d32d5ad2fc8fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f70dbca71eed7c5de8d32d5ad2fc8fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f70dbca71eed7c5de8d32d5ad2fc8fa = L.map(
#                 &quot;map_3f70dbca71eed7c5de8d32d5ad2fc8fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1645ac4fdd1861772f05d6bb41cfebb8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1645ac4fdd1861772f05d6bb41cfebb8.addTo(map_3f70dbca71eed7c5de8d32d5ad2fc8fa);
#
#
#             var marker_5816334f2b50154fb19d6ee81172b4ed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3f70dbca71eed7c5de8d32d5ad2fc8fa);
#
#
#         var popup_0a4500c912bff9c9ca6b54bff0b13f73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c193ad8d7469700381f52c0f2574abb1 = $(`&lt;div id=&quot;html_c193ad8d7469700381f52c0f2574abb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0a4500c912bff9c9ca6b54bff0b13f73.setContent(html_c193ad8d7469700381f52c0f2574abb1);
#
#
#
#         marker_5816334f2b50154fb19d6ee81172b4ed.bindPopup(popup_0a4500c912bff9c9ca6b54bff0b13f73)
#         ;
#
#
#
#
#             var marker_be6795ec7dcc08a56d3d275087495ee7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3f70dbca71eed7c5de8d32d5ad2fc8fa);
#
#
#         var popup_43526be80f0619a982b4520fcccbb9d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68df7acb546ff069abaa1f5af588b53f = $(`&lt;div id=&quot;html_68df7acb546ff069abaa1f5af588b53f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_43526be80f0619a982b4520fcccbb9d2.setContent(html_68df7acb546ff069abaa1f5af588b53f);
#
#
#
#         marker_be6795ec7dcc08a56d3d275087495ee7.bindPopup(popup_43526be80f0619a982b4520fcccbb9d2)
#         ;
#
#
#
#
#             var marker_033e2c934a292d3df30a0b3b68436f86 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3f70dbca71eed7c5de8d32d5ad2fc8fa);
#
#
#         var popup_f04957ed6e395539f298ec05d5333a02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d52793cd66548554558bb94287ba18f = $(`&lt;div id=&quot;html_7d52793cd66548554558bb94287ba18f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f04957ed6e395539f298ec05d5333a02.setContent(html_7d52793cd66548554558bb94287ba18f);
#
#
#
#         marker_033e2c934a292d3df30a0b3b68436f86.bindPopup(popup_f04957ed6e395539f298ec05d5333a02)
#         ;
#
#
#
#
#             var marker_5c58da49fff3e0f71de073767ca72745 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3f70dbca71eed7c5de8d32d5ad2fc8fa);
#
#
#         var popup_440839ce07c791c41f9b7d2f3de74d29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d01ac5d579eee46a0f7e0418fcbba90 = $(`&lt;div id=&quot;html_1d01ac5d579eee46a0f7e0418fcbba90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_440839ce07c791c41f9b7d2f3de74d29.setContent(html_1d01ac5d579eee46a0f7e0418fcbba90);
#
#
#
#         marker_5c58da49fff3e0f71de073767ca72745.bindPopup(popup_440839ce07c791c41f9b7d2f3de74d29)
#         ;
#
#
#
#
#             var marker_1ea7ce95c5d97b1d75c4b3b921912d8a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3f70dbca71eed7c5de8d32d5ad2fc8fa);
#
#
#         var popup_6e4a38e8af840e7e39e1dd753374e693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e8d583a560cad67005b176b9ac881cf = $(`&lt;div id=&quot;html_7e8d583a560cad67005b176b9ac881cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6e4a38e8af840e7e39e1dd753374e693.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_744bb8062d80e0c059fcbcc90094d0dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_744bb8062d80e0c059fcbcc90094d0dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_744bb8062d80e0c059fcbcc90094d0dd = L.map(
#                 &quot;map_744bb8062d80e0c059fcbcc90094d0dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fe1dccd5eba8ca4109c6a8fb1da0f7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fe1dccd5eba8ca4109c6a8fb1da0f7c.addTo(map_744bb8062d80e0c059fcbcc90094d0dd);
#
#
#             var feature_group_dc87dd057bd02e304aa37fcc6213c44b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e7c7178ee9d9a08458c12116e31d761c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dc87dd057bd02e304aa37fcc6213c44b);
#
#
#         var popup_122119c78fb3606d5e13d3462d1dfeae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fea7b8ac9981e0a9c6b46bd9062ac1c = $(`&lt;div id=&quot;html_4fea7b8ac9981e0a9c6b46bd9062ac1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_122119c78fb3606d5e13d3462d1dfeae.setContent(html_4fea7b8ac9981e0a9c6b46bd9062ac1c);
#
#
#
#         marker_e7c7178ee9d9a08458c12116e31d761c.bindPopup(popup_122119c78fb3606d5e13d3462d1dfeae)
#         ;
#
#
#
#
#             var marker_1bfe36909c2fcc5ded79c48dd3c8b841 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dc87dd057bd02e304aa37fcc6213c44b);
#
#
#         var popup_3353b72e50b44ac705f0941ed1475c2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f40c19aae04d9dd640e238056139280f = $(`&lt;div id=&quot;html_f40c19aae04d9dd640e238056139280f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3353b72e50b44ac705f0941ed1475c2c.setContent(html_f40c19aae04d9dd640e238056139280f);
#
#
#
#         marker_1bfe36909c2fcc5ded79c48dd3c8b841.bindPopup(popup_3353b72e50b44ac705f0941ed1475c2c)
#         ;
#
#
#
#
#             var marker_c077f1712ccf1d6aa4f743fc8b830a92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dc87dd057bd02e304aa37fcc6213c44b);
#
#
#         var popup_0b7533be4c5edcb0d6475a5ed11b21f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99644d80db018da79cc23fdea4ec2a26 = $(`&lt;div id=&quot;html_99644d80db018da79cc23fdea4ec2a26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0b7533be4c5edcb0d6475a5ed11b21f9.setContent(html_99644d80db018da79cc23fdea4ec2a26);
#
#
#
#         marker_c077f1712ccf1d6aa4f743fc8b830a92.bindPopup(popup_0b7533be4c5edcb0d6475a5ed11b21f9)
#         ;
#
#
#
#
#             var marker_83d3ee19a44d963c9880de5ca174337a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dc87dd057bd02e304aa37fcc6213c44b);
#
#
#         var popup_9b9872b3f11e3acc9447999c7e5e93f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80666a9e163682846f57dd3a907bb749 = $(`&lt;div id=&quot;html_80666a9e163682846f57dd3a907bb749&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9b9872b3f11e3acc9447999c7e5e93f2.setContent(html_80666a9e163682846f57dd3a907bb749);
#
#
#
#         marker_83d3ee19a44d963c9880de5ca174337a.bindPopup(popup_9b9872b3f11e3acc9447999c7e5e93f2)
#         ;
#
#
#
#
#             var marker_e54733239b23eb2f10402f94bb2433d6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dc87dd057bd02e304aa37fcc6213c44b);
#
#
#         var popup_ebc6e73ce1114636579de4d02b1a491f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c9b3009d5b4776f70cccd03d10c7590 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c9b3009d5b4776f70cccd03d10c7590&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c9b3009d5b4776f70cccd03d10c7590 = L.map(
#                 &quot;map_6c9b3009d5b4776f70cccd03d10c7590&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b782e5225f514935cc0e04e85a5c3622 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b782e5225f514935cc0e04e85a5c3622.addTo(map_6c9b3009d5b4776f70cccd03d10c7590);
#
#
#             var feature_group_f69d02c9ce862e7f84f3e2868165dada = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f69d02c9ce862e7f84f3e2868165dada.addTo(map_6c9b3009d5b4776f70cccd03d10c7590);
#
#
#             var feature_group_sub_group_f0e57851cf7aa865cf9207b661ba554c = L.featureGroup.subGroup(
#                 feature_group_f69d02c9ce862e7f84f3e2868165dada
#             );
#
#
#             var marker_7891f49bfbb67ae177b8e1acaa83a98f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0e57851cf7aa865cf9207b661ba554c);
#
#
#         var popup_f444e954fbcfc664eae9cfa9e97abb6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4edffea6fae1f2a74443af24b4798315 = $(`&lt;div id=&quot;html_4edffea6fae1f2a74443af24b4798315&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f444e954fbcfc664eae9cfa9e97abb6a.setContent(html_4edffea6fae1f2a74443af24b4798315);
#
#
#
#         marker_7891f49bfbb67ae177b8e1acaa83a98f.bindPopup(popup_f444e954fbcfc664eae9cfa9e97abb6a)
#         ;
#
#
#
#
#             var marker_751c5964b828334ef51722aa0eff39a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0e57851cf7aa865cf9207b661ba554c);
#
#
#         var popup_f9cc73a3fdfcb9065d82ebe338b37dd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e638784ed1e557fe73254c8c9b883d4 = $(`&lt;div id=&quot;html_0e638784ed1e557fe73254c8c9b883d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f9cc73a3fdfcb9065d82ebe338b37dd4.setContent(html_0e638784ed1e557fe73254c8c9b883d4);
#
#
#
#         marker_751c5964b828334ef51722aa0eff39a6.bindPopup(popup_f9cc73a3fdfcb9065d82ebe338b37dd4)
#         ;
#
#
#
#
#             var marker_b126471a314fe8a59cfdf9eb27c21bf4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0e57851cf7aa865cf9207b661ba554c);
#
#
#         var popup_7d3b39222b012850d60c18b5c5f2705a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a6cc4a92e47258a17ab2c97d51c0aea = $(`&lt;div id=&quot;html_2a6cc4a92e47258a17ab2c97d51c0aea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7d3b39222b012850d60c18b5c5f2705a.setContent(html_2a6cc4a92e47258a17ab2c97d51c0aea);
#
#
#
#         marker_b126471a314fe8a59cfdf9eb27c21bf4.bindPopup(popup_7d3b39222b012850d60c18b5c5f2705a)
#         ;
#
#
#
#
#             var marker_7c509519f228263f10cf7dabc90f5d61 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f0e57851cf7aa865cf9207b661ba554c);
#
#
#         var popup_9011863a07656c4ac5c1471d436f68d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82b2072ebb21d9c2581a0a01f805e471 = $(`&lt;div id=&quot;html_82b2072ebb21d9c2581a0a01f805e471&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9011863a07656c4ac5c1471d436f68d5.setContent(html_82b2072ebb21d9c2581a0a01f805e471);
#
#
#
#         marker_
