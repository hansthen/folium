# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_624fbe6fe8792a40c64b9b0fabe57f7a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_624fbe6fe8792a40c64b9b0fabe57f7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_624fbe6fe8792a40c64b9b0fabe57f7a = L.map(
#                 &quot;map_624fbe6fe8792a40c64b9b0fabe57f7a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f323172b9713ef38e83d4dd0a4846445 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f323172b9713ef38e83d4dd0a4846445.addTo(map_624fbe6fe8792a40c64b9b0fabe57f7a);
#
#
#             var marker_14c1d44fb04239afbd8ed97672c40b0c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_624fbe6fe8792a40c64b9b0fabe57f7a);
#
#
#         var popup_66af776451f7a07915aa0dab0c294a16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0547ad9b849d743855b35620e9456ce2 = $(`&lt;div id=&quot;html_0547ad9b849d743855b35620e9456ce2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_66af776451f7a07915aa0dab0c294a16.setContent(html_0547ad9b849d743855b35620e9456ce2);
#
#
#
#         marker_14c1d44fb04239afbd8ed97672c40b0c.bindPopup(popup_66af776451f7a07915aa0dab0c294a16)
#         ;
#
#
#
#
#             var marker_6bcc504744b29cdba6fb6947f3b4c0ad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_624fbe6fe8792a40c64b9b0fabe57f7a);
#
#
#         var popup_1476a99eae24d4c7ba7d03273e89b50c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c91695a8e563a6fc5ff922331e5c19f6 = $(`&lt;div id=&quot;html_c91695a8e563a6fc5ff922331e5c19f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1476a99eae24d4c7ba7d03273e89b50c.setContent(html_c91695a8e563a6fc5ff922331e5c19f6);
#
#
#
#         marker_6bcc504744b29cdba6fb6947f3b4c0ad.bindPopup(popup_1476a99eae24d4c7ba7d03273e89b50c)
#         ;
#
#
#
#
#             var marker_8f64c05e67b44d5c406f2b4e9645672e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_624fbe6fe8792a40c64b9b0fabe57f7a);
#
#
#         var popup_4d04a9542c282c54b5322bc73ea03fb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5d8df418d58fc58a9562042ceb5a91c = $(`&lt;div id=&quot;html_c5d8df418d58fc58a9562042ceb5a91c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4d04a9542c282c54b5322bc73ea03fb8.setContent(html_c5d8df418d58fc58a9562042ceb5a91c);
#
#
#
#         marker_8f64c05e67b44d5c406f2b4e9645672e.bindPopup(popup_4d04a9542c282c54b5322bc73ea03fb8)
#         ;
#
#
#
#
#             var marker_a3d3d759143e5bf2a6b4724c9b0e6b1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_624fbe6fe8792a40c64b9b0fabe57f7a);
#
#
#         var popup_1dfc1fd094a1c4af274c4d65c796827e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5025499c0b44f4494b6677b03b34c049 = $(`&lt;div id=&quot;html_5025499c0b44f4494b6677b03b34c049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1dfc1fd094a1c4af274c4d65c796827e.setContent(html_5025499c0b44f4494b6677b03b34c049);
#
#
#
#         marker_a3d3d759143e5bf2a6b4724c9b0e6b1d.bindPopup(popup_1dfc1fd094a1c4af274c4d65c796827e)
#         ;
#
#
#
#
#             var marker_a037b33755a175532a7abc0795900df8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_624fbe6fe8792a40c64b9b0fabe57f7a);
#
#
#         var popup_a1fedd253944fbd174826845983a9b73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5add79a73c5d11cec72ca27d5a05244d = $(`&lt;div id=&quot;html_5add79a73c5d11cec72ca27d5a05244d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a1fedd253944fbd174826845983a9b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3d1cb99215fa6c46288c62faa2cc8b8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3d1cb99215fa6c46288c62faa2cc8b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3d1cb99215fa6c46288c62faa2cc8b8 = L.map(
#                 &quot;map_b3d1cb99215fa6c46288c62faa2cc8b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a304c3394ad1cca46ff426925fc8647f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a304c3394ad1cca46ff426925fc8647f.addTo(map_b3d1cb99215fa6c46288c62faa2cc8b8);
#
#
#             var feature_group_75ad4bbb55946a730f168d80bbaef939 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9a38e52c4d99727486448171cadc1c0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_75ad4bbb55946a730f168d80bbaef939);
#
#
#         var popup_1f691231f355c9b61b9cd19526f81caf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f55deaafd3e3aa513af332add49627b9 = $(`&lt;div id=&quot;html_f55deaafd3e3aa513af332add49627b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1f691231f355c9b61b9cd19526f81caf.setContent(html_f55deaafd3e3aa513af332add49627b9);
#
#
#
#         marker_9a38e52c4d99727486448171cadc1c0f.bindPopup(popup_1f691231f355c9b61b9cd19526f81caf)
#         ;
#
#
#
#
#             var marker_f50b45fb5f13a51bb5745f555a5684a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_75ad4bbb55946a730f168d80bbaef939);
#
#
#         var popup_df822f95b8340b6c2c58f4b9788c6b4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92b22e7371457e5cadefd05a4fb11c38 = $(`&lt;div id=&quot;html_92b22e7371457e5cadefd05a4fb11c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_df822f95b8340b6c2c58f4b9788c6b4d.setContent(html_92b22e7371457e5cadefd05a4fb11c38);
#
#
#
#         marker_f50b45fb5f13a51bb5745f555a5684a1.bindPopup(popup_df822f95b8340b6c2c58f4b9788c6b4d)
#         ;
#
#
#
#
#             var marker_b33e43645f954053fcd3eda90024763b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_75ad4bbb55946a730f168d80bbaef939);
#
#
#         var popup_29dd146bcfacd5822f05d6f13e3f3f8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a14b7b7ec574225be4817c509ffc9dce = $(`&lt;div id=&quot;html_a14b7b7ec574225be4817c509ffc9dce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_29dd146bcfacd5822f05d6f13e3f3f8c.setContent(html_a14b7b7ec574225be4817c509ffc9dce);
#
#
#
#         marker_b33e43645f954053fcd3eda90024763b.bindPopup(popup_29dd146bcfacd5822f05d6f13e3f3f8c)
#         ;
#
#
#
#
#             var marker_e85c9e1e8ab9d0e0bb8c5c4721a96b1c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_75ad4bbb55946a730f168d80bbaef939);
#
#
#         var popup_a32f65459eee9e4eed5ae7f34de89616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7e1253f3717962c8e2b717fe183872c = $(`&lt;div id=&quot;html_c7e1253f3717962c8e2b717fe183872c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a32f65459eee9e4eed5ae7f34de89616.setContent(html_c7e1253f3717962c8e2b717fe183872c);
#
#
#
#         marker_e85c9e1e8ab9d0e0bb8c5c4721a96b1c.bindPopup(popup_a32f65459eee9e4eed5ae7f34de89616)
#         ;
#
#
#
#
#             var marker_9290df0b976c0c4e28798c8ea4b0edb3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_75ad4bbb55946a730f168d80bbaef939);
#
#
#         var popup_fe764b52d9a7de352b69cf8135f9c422 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fcca09a9483c3015eaac7e2517e7e49 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fcca09a9483c3015eaac7e2517e7e49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fcca09a9483c3015eaac7e2517e7e49 = L.map(
#                 &quot;map_8fcca09a9483c3015eaac7e2517e7e49&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2dd5e74869687acdd59473d196c2732 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2dd5e74869687acdd59473d196c2732.addTo(map_8fcca09a9483c3015eaac7e2517e7e49);
#
#
#             var feature_group_cc2dff1324402e5eed71c2fc0b910df9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cc2dff1324402e5eed71c2fc0b910df9.addTo(map_8fcca09a9483c3015eaac7e2517e7e49);
#
#
#             var feature_group_sub_group_391f927c6c20e7f6a42a67c97620db09 = L.featureGroup.subGroup(
#                 feature_group_cc2dff1324402e5eed71c2fc0b910df9
#             );
#
#
#             var marker_2cd5b5befdf9dff72d32f4776839b719 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_391f927c6c20e7f6a42a67c97620db09);
#
#
#         var popup_c5ada83b8b8f8b6d006bd516d3038323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1a14725f45d335210f6c11a9ba35e5 = $(`&lt;div id=&quot;html_5b1a14725f45d335210f6c11a9ba35e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c5ada83b8b8f8b6d006bd516d3038323.setContent(html_5b1a14725f45d335210f6c11a9ba35e5);
#
#
#
#         marker_2cd5b5befdf9dff72d32f4776839b719.bindPopup(popup_c5ada83b8b8f8b6d006bd516d3038323)
#         ;
#
#
#
#
#             var marker_96690784f51c0fec384df4b22e69aacd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_391f927c6c20e7f6a42a67c97620db09);
#
#
#         var popup_7bdca10d4ecbb40291aaa2a51fb6ec47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a6191bf2d400ae763231600614051e6 = $(`&lt;div id=&quot;html_5a6191bf2d400ae763231600614051e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7bdca10d4ecbb40291aaa2a51fb6ec47.setContent(html_5a6191bf2d400ae763231600614051e6);
#
#
#
#         marker_96690784f51c0fec384df4b22e69aacd.bindPopup(popup_7bdca10d4ecbb40291aaa2a51fb6ec47)
#         ;
#
#
#
#
#             var marker_5e8fd9222cb4865248e17bd307e640c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_391f927c6c20e7f6a42a67c97620db09);
#
#
#         var popup_07c64606242634d7f7c01ef6cbfe0bbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a684f559a3d141f0e31624ce846991f = $(`&lt;div id=&quot;html_7a684f559a3d141f0e31624ce846991f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_07c64606242634d7f7c01ef6cbfe0bbb.setContent(html_7a684f559a3d141f0e31624ce846991f);
#
#
#
#         marker_5e8fd9222cb4865248e17bd307e640c3.bindPopup(popup_07c64606242634d7f7c01ef6cbfe0bbb)
#         ;
#
#
#
#
#             var marker_1e2ff1870a03c1f71e4068804ccd5e27 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_391f927c6c20e7f6a42a67c97620db09);
#
#
#         var popup_cf99adc904f52a244839b43a24444168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fff2a156a728a9e0b5958ddfb37bfb93 = $(`&lt;div id=&quot;html_fff2a156a728a9e0b5958ddfb37bfb93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cf99adc904f52a244839b43a24444168.setContent(html_fff2a156a728a9e0b5958ddfb37bfb93);
#
#
#
#         mark
