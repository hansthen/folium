# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c738aec71c64869920aedd39440fa8d1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c738aec71c64869920aedd39440fa8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c738aec71c64869920aedd39440fa8d1 = L.map(
#                 &quot;map_c738aec71c64869920aedd39440fa8d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73dddf8ae7b7dbdc3482844cdcd8b686 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73dddf8ae7b7dbdc3482844cdcd8b686.addTo(map_c738aec71c64869920aedd39440fa8d1);
#
#
#             var marker_2dc09d9b4b27fe2e3d49b623a4b3ceee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c738aec71c64869920aedd39440fa8d1);
#
#
#         var popup_7cd4ce214824a4bb8648f63642feafe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f6df898a45975c04f970b4b87d2162a = $(`&lt;div id=&quot;html_6f6df898a45975c04f970b4b87d2162a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7cd4ce214824a4bb8648f63642feafe5.setContent(html_6f6df898a45975c04f970b4b87d2162a);
#
#
#
#         marker_2dc09d9b4b27fe2e3d49b623a4b3ceee.bindPopup(popup_7cd4ce214824a4bb8648f63642feafe5)
#         ;
#
#
#
#
#             var marker_7438c889a909e5cd7404598459b3d298 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c738aec71c64869920aedd39440fa8d1);
#
#
#         var popup_03561f71964950c72a054e7ddafb710f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72fbe6824fb95090c05b96444efa9083 = $(`&lt;div id=&quot;html_72fbe6824fb95090c05b96444efa9083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_03561f71964950c72a054e7ddafb710f.setContent(html_72fbe6824fb95090c05b96444efa9083);
#
#
#
#         marker_7438c889a909e5cd7404598459b3d298.bindPopup(popup_03561f71964950c72a054e7ddafb710f)
#         ;
#
#
#
#
#             var marker_23ffbe7c5f49284da7c0225e2e6e1c68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c738aec71c64869920aedd39440fa8d1);
#
#
#         var popup_fad46724f73a586d4cba371736f0d989 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3dd4f58261832498290d9c6aff21e0a = $(`&lt;div id=&quot;html_d3dd4f58261832498290d9c6aff21e0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fad46724f73a586d4cba371736f0d989.setContent(html_d3dd4f58261832498290d9c6aff21e0a);
#
#
#
#         marker_23ffbe7c5f49284da7c0225e2e6e1c68.bindPopup(popup_fad46724f73a586d4cba371736f0d989)
#         ;
#
#
#
#
#             var marker_90411a608a34432287db7b2ff365f052 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c738aec71c64869920aedd39440fa8d1);
#
#
#         var popup_85704f91ad6eb4b5dfbea55019415b0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8014d7ab7957be4b8d0eb34c23d17c2 = $(`&lt;div id=&quot;html_b8014d7ab7957be4b8d0eb34c23d17c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_85704f91ad6eb4b5dfbea55019415b0e.setContent(html_b8014d7ab7957be4b8d0eb34c23d17c2);
#
#
#
#         marker_90411a608a34432287db7b2ff365f052.bindPopup(popup_85704f91ad6eb4b5dfbea55019415b0e)
#         ;
#
#
#
#
#             var marker_43242463f3f3b1621cb47b5271c934c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c738aec71c64869920aedd39440fa8d1);
#
#
#         var popup_1af53b292e5e9258bac0a4711d6c5de8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd1cdbc9b7808e953a84a78d12c54274 = $(`&lt;div id=&quot;html_bd1cdbc9b7808e953a84a78d12c54274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1af53b292e5e9258bac0a4711d6c5d

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_311b6ceffa807124f6f525a8a3ea58c0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_311b6ceffa807124f6f525a8a3ea58c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_311b6ceffa807124f6f525a8a3ea58c0 = L.map(
#                 &quot;map_311b6ceffa807124f6f525a8a3ea58c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63992bec94376972aab93d02f35c1873 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63992bec94376972aab93d02f35c1873.addTo(map_311b6ceffa807124f6f525a8a3ea58c0);
#
#
#             var feature_group_9e3166129fc5b14d8eee0c1634d57ea0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_74cfb7b68c3405ddd89989f3a45e670f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9e3166129fc5b14d8eee0c1634d57ea0);
#
#
#         var popup_692825b9f587e2d44dddec738ea2ff26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2b14525c49be8149dbbc0f013a8b7db = $(`&lt;div id=&quot;html_a2b14525c49be8149dbbc0f013a8b7db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_692825b9f587e2d44dddec738ea2ff26.setContent(html_a2b14525c49be8149dbbc0f013a8b7db);
#
#
#
#         marker_74cfb7b68c3405ddd89989f3a45e670f.bindPopup(popup_692825b9f587e2d44dddec738ea2ff26)
#         ;
#
#
#
#
#             var marker_65021c36ac8688d5ad0b7a37d58c145c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9e3166129fc5b14d8eee0c1634d57ea0);
#
#
#         var popup_040a1e8548bbd2bf8489af8a30f65093 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_645259db566794f7f791c824a0913153 = $(`&lt;div id=&quot;html_645259db566794f7f791c824a0913153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_040a1e8548bbd2bf8489af8a30f65093.setContent(html_645259db566794f7f791c824a0913153);
#
#
#
#         marker_65021c36ac8688d5ad0b7a37d58c145c.bindPopup(popup_040a1e8548bbd2bf8489af8a30f65093)
#         ;
#
#
#
#
#             var marker_7bc6e4c70a4e7892c82610257b7f7ab4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9e3166129fc5b14d8eee0c1634d57ea0);
#
#
#         var popup_aa63bb6d34f47b61788e8f305dee9a17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4928fed165d3974e78ab200c5be2883f = $(`&lt;div id=&quot;html_4928fed165d3974e78ab200c5be2883f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_aa63bb6d34f47b61788e8f305dee9a17.setContent(html_4928fed165d3974e78ab200c5be2883f);
#
#
#
#         marker_7bc6e4c70a4e7892c82610257b7f7ab4.bindPopup(popup_aa63bb6d34f47b61788e8f305dee9a17)
#         ;
#
#
#
#
#             var marker_a680a167d247178425f99b39447d7fe7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9e3166129fc5b14d8eee0c1634d57ea0);
#
#
#         var popup_82db5ef9b01570c8a024060e5ab1c8cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ebfde0ed62017792056ced3ebed819d = $(`&lt;div id=&quot;html_6ebfde0ed62017792056ced3ebed819d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_82db5ef9b01570c8a024060e5ab1c8cd.setContent(html_6ebfde0ed62017792056ced3ebed819d);
#
#
#
#         marker_a680a167d247178425f99b39447d7fe7.bindPopup(popup_82db5ef9b01570c8a024060e5ab1c8cd)
#         ;
#
#
#
#
#             var marker_c1477c2e34a165d1f5260511abc4bf0c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9e3166129fc5b14d8eee0c1634d57ea0);
#
#
#         var popup_fc4065b561602f2534bf91686e9cad28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00645378369c3fdcb53a82a77a0c1e1e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00645378369c3fdcb53a82a77a0c1e1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00645378369c3fdcb53a82a77a0c1e1e = L.map(
#                 &quot;map_00645378369c3fdcb53a82a77a0c1e1e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1ce2a74a91f1622dbcd05e2e51b0ac7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1ce2a74a91f1622dbcd05e2e51b0ac7.addTo(map_00645378369c3fdcb53a82a77a0c1e1e);
#
#
#             var feature_group_35c2efa1b7d8a5ebe13800beceef1f84 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_35c2efa1b7d8a5ebe13800beceef1f84.addTo(map_00645378369c3fdcb53a82a77a0c1e1e);
#
#
#             var feature_group_sub_group_5623c80b85de6ec1d0908240471a6605 = L.featureGroup.subGroup(
#                 feature_group_35c2efa1b7d8a5ebe13800beceef1f84
#             );
#
#
#             var marker_419fed07e882fa45e9f6059ab7b9397e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5623c80b85de6ec1d0908240471a6605);
#
#
#         var popup_c66f026b023dcb505ff2056523825aa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44eb80e44a7dd80dc8620376f41eee28 = $(`&lt;div id=&quot;html_44eb80e44a7dd80dc8620376f41eee28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c66f026b023dcb505ff2056523825aa6.setContent(html_44eb80e44a7dd80dc8620376f41eee28);
#
#
#
#         marker_419fed07e882fa45e9f6059ab7b9397e.bindPopup(popup_c66f026b023dcb505ff2056523825aa6)
#         ;
#
#
#
#
#             var marker_e39d5b0839a8f268caac5bded72d5f0c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5623c80b85de6ec1d0908240471a6605);
#
#
#         var popup_af7bb8b77511a357bfdb38ea7f2f98a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_680ba17d34064fbda32d948cd1cf30f2 = $(`&lt;div id=&quot;html_680ba17d34064fbda32d948cd1cf30f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_af7bb8b77511a357bfdb38ea7f2f98a7.setContent(html_680ba17d34064fbda32d948cd1cf30f2);
#
#
#
#         marker_e39d5b0839a8f268caac5bded72d5f0c.bindPopup(popup_af7bb8b77511a357bfdb38ea7f2f98a7)
#         ;
#
#
#
#
#             var marker_21f4a33e04d8da841a14446243a7a304 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5623c80b85de6ec1d0908240471a6605);
#
#
#         var popup_2cfd2b048e8e714e153d386b280ac046 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56628da8103ef8eeb17087c7751e99ca = $(`&lt;div id=&quot;html_56628da8103ef8eeb17087c7751e99ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2cfd2b048e8e714e153d386b280ac046.setContent(html_56628da8103ef8eeb17087c7751e99ca);
#
#
#
#         marker_21f4a33e04d8da841a14446243a7a304.bindPopup(popup_2cfd2b048e8e714e153d386b280ac046)
#         ;
#
#
#
#
#             var marker_77ab32f8f7d1a56c05924b0366f0db3f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5623c80b85de6ec1d0908240471a6605);
#
#
#         var popup_fc523b508bd57690b638aeb7e467185c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea808ca515c22c10c38d2fbff57cfb6b = $(`&lt;div id=&quot;html_ea808ca515c22c10c38d2fbff57cfb6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fc523b508bd57690b638aeb7e467185c.setContent(html_ea808ca515c22c10c38d2fbff57cfb6b);
#
#
#
#         mark
