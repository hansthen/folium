# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_622b4dc254d002ec859d880c8152bc72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_622b4dc254d002ec859d880c8152bc72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_622b4dc254d002ec859d880c8152bc72 = L.map(
#                 &quot;map_622b4dc254d002ec859d880c8152bc72&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0ebb49275ada43ae0547b53c5712b62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0ebb49275ada43ae0547b53c5712b62.addTo(map_622b4dc254d002ec859d880c8152bc72);
#
#
#             var marker_107bd8644473fc8f88c262311356e90c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_622b4dc254d002ec859d880c8152bc72);
#
#
#         var popup_f60caa7f0d85c15fc5f16b5d7ee901b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_955aa94f3cce0ce886fdafe1fd218f94 = $(`&lt;div id=&quot;html_955aa94f3cce0ce886fdafe1fd218f94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f60caa7f0d85c15fc5f16b5d7ee901b7.setContent(html_955aa94f3cce0ce886fdafe1fd218f94);
#
#
#
#         marker_107bd8644473fc8f88c262311356e90c.bindPopup(popup_f60caa7f0d85c15fc5f16b5d7ee901b7)
#         ;
#
#
#
#
#             var marker_935c063a38de57f8f37e84494d9dcab1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_622b4dc254d002ec859d880c8152bc72);
#
#
#         var popup_7dc007823450d0f8c59011e276e28283 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05ad6c04c0cf39b417c8ca81b00a826a = $(`&lt;div id=&quot;html_05ad6c04c0cf39b417c8ca81b00a826a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7dc007823450d0f8c59011e276e28283.setContent(html_05ad6c04c0cf39b417c8ca81b00a826a);
#
#
#
#         marker_935c063a38de57f8f37e84494d9dcab1.bindPopup(popup_7dc007823450d0f8c59011e276e28283)
#         ;
#
#
#
#
#             var marker_21828014720d057876f648179f6fbc2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_622b4dc254d002ec859d880c8152bc72);
#
#
#         var popup_a982ffbabb5f6c1001416efb2514931b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ecb99a82f1b30b383bd36d6aa8524c2 = $(`&lt;div id=&quot;html_9ecb99a82f1b30b383bd36d6aa8524c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a982ffbabb5f6c1001416efb2514931b.setContent(html_9ecb99a82f1b30b383bd36d6aa8524c2);
#
#
#
#         marker_21828014720d057876f648179f6fbc2d.bindPopup(popup_a982ffbabb5f6c1001416efb2514931b)
#         ;
#
#
#
#
#             var marker_aa2db2587d9be693956d972f83216cf8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_622b4dc254d002ec859d880c8152bc72);
#
#
#         var popup_4c1b2959d84af0adf30d2b45a3ad34ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5e973de97f917c648eba59ac99204da = $(`&lt;div id=&quot;html_a5e973de97f917c648eba59ac99204da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4c1b2959d84af0adf30d2b45a3ad34ea.setContent(html_a5e973de97f917c648eba59ac99204da);
#
#
#
#         marker_aa2db2587d9be693956d972f83216cf8.bindPopup(popup_4c1b2959d84af0adf30d2b45a3ad34ea)
#         ;
#
#
#
#
#             var marker_b0346296a64c22a62cde00eb5d4856d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_622b4dc254d002ec859d880c8152bc72);
#
#
#         var popup_2789aaf00ecdc2552f73627eba4cf6bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a913637b2bed9d77cb45d68147fa0263 = $(`&lt;div id=&quot;html_a913637b2bed9d77cb45d68147fa0263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2789aaf00ecdc2552f73627eba4cf6bb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae0f9d4495fac106b00a35a0a16fe863 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae0f9d4495fac106b00a35a0a16fe863&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae0f9d4495fac106b00a35a0a16fe863 = L.map(
#                 &quot;map_ae0f9d4495fac106b00a35a0a16fe863&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ff537ed699b185a6527bb3f7128e857 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ff537ed699b185a6527bb3f7128e857.addTo(map_ae0f9d4495fac106b00a35a0a16fe863);
#
#
#             var feature_group_1ab076a3670c0075d2a37a5fa069b0bc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ccb0830d412f47d6fea90b1a63d083b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1ab076a3670c0075d2a37a5fa069b0bc);
#
#
#         var popup_92c338f8c839e2d492b99e921415d4ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_987423fac61cdacef060a38b9489d57c = $(`&lt;div id=&quot;html_987423fac61cdacef060a38b9489d57c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_92c338f8c839e2d492b99e921415d4ae.setContent(html_987423fac61cdacef060a38b9489d57c);
#
#
#
#         marker_ccb0830d412f47d6fea90b1a63d083b4.bindPopup(popup_92c338f8c839e2d492b99e921415d4ae)
#         ;
#
#
#
#
#             var marker_543bd758fd0e6f2a3619b613016665a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1ab076a3670c0075d2a37a5fa069b0bc);
#
#
#         var popup_ee70f026b76465ce31e1fab14aa0a0a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38cc19eb91a45c0e00517f0c13a84d6a = $(`&lt;div id=&quot;html_38cc19eb91a45c0e00517f0c13a84d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ee70f026b76465ce31e1fab14aa0a0a7.setContent(html_38cc19eb91a45c0e00517f0c13a84d6a);
#
#
#
#         marker_543bd758fd0e6f2a3619b613016665a0.bindPopup(popup_ee70f026b76465ce31e1fab14aa0a0a7)
#         ;
#
#
#
#
#             var marker_e51340c97e6590a812c60c9adbbb371f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1ab076a3670c0075d2a37a5fa069b0bc);
#
#
#         var popup_928473f9c49b848a62a8ee7aa10484c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8faf928fc72e8dcf085d97e6906751d1 = $(`&lt;div id=&quot;html_8faf928fc72e8dcf085d97e6906751d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_928473f9c49b848a62a8ee7aa10484c9.setContent(html_8faf928fc72e8dcf085d97e6906751d1);
#
#
#
#         marker_e51340c97e6590a812c60c9adbbb371f.bindPopup(popup_928473f9c49b848a62a8ee7aa10484c9)
#         ;
#
#
#
#
#             var marker_6c13fd4041ddfa43071ae287193d0bab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1ab076a3670c0075d2a37a5fa069b0bc);
#
#
#         var popup_31efae9735874749e175a5b35dd73e64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fed9c1492637d30bf34325bf2b99eaad = $(`&lt;div id=&quot;html_fed9c1492637d30bf34325bf2b99eaad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_31efae9735874749e175a5b35dd73e64.setContent(html_fed9c1492637d30bf34325bf2b99eaad);
#
#
#
#         marker_6c13fd4041ddfa43071ae287193d0bab.bindPopup(popup_31efae9735874749e175a5b35dd73e64)
#         ;
#
#
#
#
#             var marker_d96d314faf44d6acc3c4452c19ce7712 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1ab076a3670c0075d2a37a5fa069b0bc);
#
#
#         var popup_c0d47a85ef92017f6b226574ee820040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57422809c61abb8f95e0f5e2b5257cc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57422809c61abb8f95e0f5e2b5257cc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57422809c61abb8f95e0f5e2b5257cc0 = L.map(
#                 &quot;map_57422809c61abb8f95e0f5e2b5257cc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5652025da883d45a9c4d41e600c92326 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5652025da883d45a9c4d41e600c92326.addTo(map_57422809c61abb8f95e0f5e2b5257cc0);
#
#
#             var feature_group_3085f1d661a7ae31690f5fc36808075a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3085f1d661a7ae31690f5fc36808075a.addTo(map_57422809c61abb8f95e0f5e2b5257cc0);
#
#
#             var feature_group_sub_group_2f562d26a039c6527df0fd0445ffe534 = L.featureGroup.subGroup(
#                 feature_group_3085f1d661a7ae31690f5fc36808075a
#             );
#
#
#             var marker_0a2f3bbba3ccbef042f45e813390c930 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f562d26a039c6527df0fd0445ffe534);
#
#
#         var popup_a0d3159afc648003979bc04dc8fd40a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_915da36e44dacb36ee657ac51afb0977 = $(`&lt;div id=&quot;html_915da36e44dacb36ee657ac51afb0977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a0d3159afc648003979bc04dc8fd40a6.setContent(html_915da36e44dacb36ee657ac51afb0977);
#
#
#
#         marker_0a2f3bbba3ccbef042f45e813390c930.bindPopup(popup_a0d3159afc648003979bc04dc8fd40a6)
#         ;
#
#
#
#
#             var marker_05539562b0acbe3df708615316d8653d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f562d26a039c6527df0fd0445ffe534);
#
#
#         var popup_c94eb481a02683d86c520d24efb69a01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ec4a019b950784ad9642520b82bb250 = $(`&lt;div id=&quot;html_4ec4a019b950784ad9642520b82bb250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c94eb481a02683d86c520d24efb69a01.setContent(html_4ec4a019b950784ad9642520b82bb250);
#
#
#
#         marker_05539562b0acbe3df708615316d8653d.bindPopup(popup_c94eb481a02683d86c520d24efb69a01)
#         ;
#
#
#
#
#             var marker_b4e9d09c44fa5907e87943b98d8c59b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f562d26a039c6527df0fd0445ffe534);
#
#
#         var popup_279932d99ea4944ec5cc82027bf0e4bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_502d56f7300e8efc172a741d13a202d3 = $(`&lt;div id=&quot;html_502d56f7300e8efc172a741d13a202d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_279932d99ea4944ec5cc82027bf0e4bd.setContent(html_502d56f7300e8efc172a741d13a202d3);
#
#
#
#         marker_b4e9d09c44fa5907e87943b98d8c59b2.bindPopup(popup_279932d99ea4944ec5cc82027bf0e4bd)
#         ;
#
#
#
#
#             var marker_15d5f5c07cc7f7a62e7f7ac9f0865e83 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2f562d26a039c6527df0fd0445ffe534);
#
#
#         var popup_c3713874a93cf53465c7bc1df14de146 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29a0536cb9e3dc61fc3bc647dc23eebb = $(`&lt;div id=&quot;html_29a0536cb9e3dc61fc3bc647dc23eebb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c3713874a93cf53465c7bc1df14de146.setContent(html_29a0536cb9e3dc61fc3bc647dc23eebb);
#
#
#
#         marker_
