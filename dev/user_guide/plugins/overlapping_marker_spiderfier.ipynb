# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3b662b3148363e4ceebb63a7683e891 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3b662b3148363e4ceebb63a7683e891&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3b662b3148363e4ceebb63a7683e891 = L.map(
#                 &quot;map_a3b662b3148363e4ceebb63a7683e891&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3d93aa48ebc3a654e5b27543c4e80c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a3d93aa48ebc3a654e5b27543c4e80c0.addTo(map_a3b662b3148363e4ceebb63a7683e891);
#
#
#             var marker_c5b5c034273b3f22db76c0d172d4637e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a3b662b3148363e4ceebb63a7683e891);
#
#
#         var popup_9bf9c60d5390c83d3069eff0b6920567 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0434bdc4e8b1a43cabe2c4fc5de8521d = $(`&lt;div id=&quot;html_0434bdc4e8b1a43cabe2c4fc5de8521d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9bf9c60d5390c83d3069eff0b6920567.setContent(html_0434bdc4e8b1a43cabe2c4fc5de8521d);
#
#
#
#         marker_c5b5c034273b3f22db76c0d172d4637e.bindPopup(popup_9bf9c60d5390c83d3069eff0b6920567)
#         ;
#
#
#
#
#             var marker_51856819443f93731bb218cb7ccfa698 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a3b662b3148363e4ceebb63a7683e891);
#
#
#         var popup_e93cf5e5e9e9ef8c815c2b98c47185fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_052a701c2e4daf2375afeea5b7575a05 = $(`&lt;div id=&quot;html_052a701c2e4daf2375afeea5b7575a05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e93cf5e5e9e9ef8c815c2b98c47185fb.setContent(html_052a701c2e4daf2375afeea5b7575a05);
#
#
#
#         marker_51856819443f93731bb218cb7ccfa698.bindPopup(popup_e93cf5e5e9e9ef8c815c2b98c47185fb)
#         ;
#
#
#
#
#             var marker_8e3f446f66d266f19d673f1ef110fb18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a3b662b3148363e4ceebb63a7683e891);
#
#
#         var popup_2e00cb25b7b29b318dfb754f05329158 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0ebd4b663a628deca2c8e2756dfbbf0 = $(`&lt;div id=&quot;html_d0ebd4b663a628deca2c8e2756dfbbf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2e00cb25b7b29b318dfb754f05329158.setContent(html_d0ebd4b663a628deca2c8e2756dfbbf0);
#
#
#
#         marker_8e3f446f66d266f19d673f1ef110fb18.bindPopup(popup_2e00cb25b7b29b318dfb754f05329158)
#         ;
#
#
#
#
#             var marker_6ba5082218a2676d235b48eccf002763 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a3b662b3148363e4ceebb63a7683e891);
#
#
#         var popup_d69723f4dfcf75faaa122357f81d0d2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_161aa84b9022fcfc11bea035efa98336 = $(`&lt;div id=&quot;html_161aa84b9022fcfc11bea035efa98336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d69723f4dfcf75faaa122357f81d0d2d.setContent(html_161aa84b9022fcfc11bea035efa98336);
#
#
#
#         marker_6ba5082218a2676d235b48eccf002763.bindPopup(popup_d69723f4dfcf75faaa122357f81d0d2d)
#         ;
#
#
#
#
#             var marker_e73cd9b9d3826f1a713528ade9241014 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a3b662b3148363e4ceebb63a7683e891);
#
#
#         var popup_9cc73bb1a199be831ecc1a163f42bdeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aeb9b02e0994420d23a629f2ce12fc83 = $(`&lt;div id=&quot;html_aeb9b02e0994420d23a629f2ce12fc83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9cc73bb1a199be831ecc1a163f42bd

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09041e248d666372017cf102c8fbb1d9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09041e248d666372017cf102c8fbb1d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09041e248d666372017cf102c8fbb1d9 = L.map(
#                 &quot;map_09041e248d666372017cf102c8fbb1d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cce3695ab4b8dcca14af49dcca3a91e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cce3695ab4b8dcca14af49dcca3a91e4.addTo(map_09041e248d666372017cf102c8fbb1d9);
#
#
#             var feature_group_f8073756d6f7e2f88cba9e7b9b58b369 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d3c6549c581a9c06c3db9e850ac6649e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f8073756d6f7e2f88cba9e7b9b58b369);
#
#
#         var popup_9e84ed97cc0ad7c6aa91c554fa62ba9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ddb689f991f7ebcb8adb6e07e2e3049 = $(`&lt;div id=&quot;html_1ddb689f991f7ebcb8adb6e07e2e3049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9e84ed97cc0ad7c6aa91c554fa62ba9b.setContent(html_1ddb689f991f7ebcb8adb6e07e2e3049);
#
#
#
#         marker_d3c6549c581a9c06c3db9e850ac6649e.bindPopup(popup_9e84ed97cc0ad7c6aa91c554fa62ba9b)
#         ;
#
#
#
#
#             var marker_deb622779b1082a358f2572521dd2539 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f8073756d6f7e2f88cba9e7b9b58b369);
#
#
#         var popup_50bf4fa6fd4fbe0c872ec480561533e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46f475cbcaf05080127083c11b7fbdaf = $(`&lt;div id=&quot;html_46f475cbcaf05080127083c11b7fbdaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_50bf4fa6fd4fbe0c872ec480561533e2.setContent(html_46f475cbcaf05080127083c11b7fbdaf);
#
#
#
#         marker_deb622779b1082a358f2572521dd2539.bindPopup(popup_50bf4fa6fd4fbe0c872ec480561533e2)
#         ;
#
#
#
#
#             var marker_29fe7bce21ad475f3c3968b129358480 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f8073756d6f7e2f88cba9e7b9b58b369);
#
#
#         var popup_362749534180ab66d338ecbb43052b39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c780cc690fd5b0461687b3e816474e7 = $(`&lt;div id=&quot;html_9c780cc690fd5b0461687b3e816474e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_362749534180ab66d338ecbb43052b39.setContent(html_9c780cc690fd5b0461687b3e816474e7);
#
#
#
#         marker_29fe7bce21ad475f3c3968b129358480.bindPopup(popup_362749534180ab66d338ecbb43052b39)
#         ;
#
#
#
#
#             var marker_f001ff64b090297db4d5a7fcaf9d6477 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f8073756d6f7e2f88cba9e7b9b58b369);
#
#
#         var popup_2e6c4892bc6b1509153c4a7a4d1ac04f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3c8c861dbd37dd7f214c69208385301 = $(`&lt;div id=&quot;html_e3c8c861dbd37dd7f214c69208385301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2e6c4892bc6b1509153c4a7a4d1ac04f.setContent(html_e3c8c861dbd37dd7f214c69208385301);
#
#
#
#         marker_f001ff64b090297db4d5a7fcaf9d6477.bindPopup(popup_2e6c4892bc6b1509153c4a7a4d1ac04f)
#         ;
#
#
#
#
#             var marker_9d768d3966dc6664f8729d2ec1e89b36 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f8073756d6f7e2f88cba9e7b9b58b369);
#
#
#         var popup_4699a3f496c0f0700617de3f30f1ed46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e73e8e8f5cf5ec7508e60b8674ad2ec8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e73e8e8f5cf5ec7508e60b8674ad2ec8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e73e8e8f5cf5ec7508e60b8674ad2ec8 = L.map(
#                 &quot;map_e73e8e8f5cf5ec7508e60b8674ad2ec8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_579176eaf69d612477c66bc23bf4cd55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_579176eaf69d612477c66bc23bf4cd55.addTo(map_e73e8e8f5cf5ec7508e60b8674ad2ec8);
#
#
#             var feature_group_93521cd81f758ec47d2b85d7c9d5d5db = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_93521cd81f758ec47d2b85d7c9d5d5db.addTo(map_e73e8e8f5cf5ec7508e60b8674ad2ec8);
#
#
#             var feature_group_sub_group_c9bbb84d892a806ee9ba9fb0415fa58f = L.featureGroup.subGroup(
#                 feature_group_93521cd81f758ec47d2b85d7c9d5d5db
#             );
#
#
#             var marker_0e2daf6a92e44848026740669ffb74a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9bbb84d892a806ee9ba9fb0415fa58f);
#
#
#         var popup_20ebe847692a13e3aad2ee580a9b094d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96fd3c6f8ee114bd6cd4e7651bab62e4 = $(`&lt;div id=&quot;html_96fd3c6f8ee114bd6cd4e7651bab62e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_20ebe847692a13e3aad2ee580a9b094d.setContent(html_96fd3c6f8ee114bd6cd4e7651bab62e4);
#
#
#
#         marker_0e2daf6a92e44848026740669ffb74a6.bindPopup(popup_20ebe847692a13e3aad2ee580a9b094d)
#         ;
#
#
#
#
#             var marker_f9f4a8b9edd5618054834721e243a049 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9bbb84d892a806ee9ba9fb0415fa58f);
#
#
#         var popup_36a6aa116181f2f20220f19541438834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02e4c4da429f3838cdc282b0a7cf244f = $(`&lt;div id=&quot;html_02e4c4da429f3838cdc282b0a7cf244f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_36a6aa116181f2f20220f19541438834.setContent(html_02e4c4da429f3838cdc282b0a7cf244f);
#
#
#
#         marker_f9f4a8b9edd5618054834721e243a049.bindPopup(popup_36a6aa116181f2f20220f19541438834)
#         ;
#
#
#
#
#             var marker_49c4ce9f14686be365b6b8f5dcc4ef29 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9bbb84d892a806ee9ba9fb0415fa58f);
#
#
#         var popup_285f5e7798b7d97fba49edd0f218a2e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8415b04911c5c5d20715cb585d942b2b = $(`&lt;div id=&quot;html_8415b04911c5c5d20715cb585d942b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_285f5e7798b7d97fba49edd0f218a2e4.setContent(html_8415b04911c5c5d20715cb585d942b2b);
#
#
#
#         marker_49c4ce9f14686be365b6b8f5dcc4ef29.bindPopup(popup_285f5e7798b7d97fba49edd0f218a2e4)
#         ;
#
#
#
#
#             var marker_55a6eaf712b8ff698ecae42817f4faaa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c9bbb84d892a806ee9ba9fb0415fa58f);
#
#
#         var popup_cf0c9758d14d5c5fc0c9d8a557068718 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dbaddd2ae557990db11dd4c891a383c = $(`&lt;div id=&quot;html_7dbaddd2ae557990db11dd4c891a383c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cf0c9758d14d5c5fc0c9d8a557068718.setContent(html_7dbaddd2ae557990db11dd4c891a383c);
#
#
#
#         mark
