# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c87a7b07546d1bd0ad245a9169608032 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c87a7b07546d1bd0ad245a9169608032&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c87a7b07546d1bd0ad245a9169608032 = L.map(
#                 &quot;map_c87a7b07546d1bd0ad245a9169608032&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7727700c47e247ce587a872028f43c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7727700c47e247ce587a872028f43c7.addTo(map_c87a7b07546d1bd0ad245a9169608032);
#
#
#             var marker_9f9648d1694cca87aabf927cbe6dc998 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c87a7b07546d1bd0ad245a9169608032);
#
#
#         var popup_491fb0bde8fc91bb378636a64c055cfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fe7cc8fd77aa0b8f312c0b2a08cb3fb = $(`&lt;div id=&quot;html_7fe7cc8fd77aa0b8f312c0b2a08cb3fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_491fb0bde8fc91bb378636a64c055cfb.setContent(html_7fe7cc8fd77aa0b8f312c0b2a08cb3fb);
#
#
#
#         marker_9f9648d1694cca87aabf927cbe6dc998.bindPopup(popup_491fb0bde8fc91bb378636a64c055cfb)
#         ;
#
#
#
#
#             var marker_fb71d9d87af04db90f07f0afd6c2a98a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c87a7b07546d1bd0ad245a9169608032);
#
#
#         var popup_7f04745c4b2bb2a062e42b9c5deb3a56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49c3b8cd075b0c84de3a1cc34a06ee36 = $(`&lt;div id=&quot;html_49c3b8cd075b0c84de3a1cc34a06ee36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7f04745c4b2bb2a062e42b9c5deb3a56.setContent(html_49c3b8cd075b0c84de3a1cc34a06ee36);
#
#
#
#         marker_fb71d9d87af04db90f07f0afd6c2a98a.bindPopup(popup_7f04745c4b2bb2a062e42b9c5deb3a56)
#         ;
#
#
#
#
#             var marker_2c251c18f7e38f6894f10cb96e7bda4b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c87a7b07546d1bd0ad245a9169608032);
#
#
#         var popup_8919e90440c64c53c4c52d396b8785c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6574076f3de3e56fe76e4a19b51f3f6 = $(`&lt;div id=&quot;html_f6574076f3de3e56fe76e4a19b51f3f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8919e90440c64c53c4c52d396b8785c4.setContent(html_f6574076f3de3e56fe76e4a19b51f3f6);
#
#
#
#         marker_2c251c18f7e38f6894f10cb96e7bda4b.bindPopup(popup_8919e90440c64c53c4c52d396b8785c4)
#         ;
#
#
#
#
#             var marker_ff4826037f0307456c4f96eb4a757eb9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c87a7b07546d1bd0ad245a9169608032);
#
#
#         var popup_fc87ff25016355df3beb41498567af98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cab4bfec39e371e284eddb817c4be58f = $(`&lt;div id=&quot;html_cab4bfec39e371e284eddb817c4be58f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fc87ff25016355df3beb41498567af98.setContent(html_cab4bfec39e371e284eddb817c4be58f);
#
#
#
#         marker_ff4826037f0307456c4f96eb4a757eb9.bindPopup(popup_fc87ff25016355df3beb41498567af98)
#         ;
#
#
#
#
#             var marker_d7d8475d4493105088c9f9ed4375b6ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c87a7b07546d1bd0ad245a9169608032);
#
#
#         var popup_105e7aa8862cda09b3f643e0498001ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e5472cd669311f2561805d8f250dcdf = $(`&lt;div id=&quot;html_7e5472cd669311f2561805d8f250dcdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_105e7aa8862cda09b3f643e0498001

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe164e4b39991885364ba67d3f1b7a14 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe164e4b39991885364ba67d3f1b7a14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe164e4b39991885364ba67d3f1b7a14 = L.map(
#                 &quot;map_fe164e4b39991885364ba67d3f1b7a14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08a91087dbcfadace7ebb7239c69e496 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08a91087dbcfadace7ebb7239c69e496.addTo(map_fe164e4b39991885364ba67d3f1b7a14);
#
#
#             var feature_group_7e0ed54a301fa14e74d2c6a4a47d7bba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9f921f95aa2db3e107c9cd5c978c3619 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7e0ed54a301fa14e74d2c6a4a47d7bba);
#
#
#         var popup_50d541e3feb99b5f2f0b713cb47b809f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffd1bf97b64e801512962b1276a079c0 = $(`&lt;div id=&quot;html_ffd1bf97b64e801512962b1276a079c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_50d541e3feb99b5f2f0b713cb47b809f.setContent(html_ffd1bf97b64e801512962b1276a079c0);
#
#
#
#         marker_9f921f95aa2db3e107c9cd5c978c3619.bindPopup(popup_50d541e3feb99b5f2f0b713cb47b809f)
#         ;
#
#
#
#
#             var marker_eeec2c7631376e8de282af181776f3c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7e0ed54a301fa14e74d2c6a4a47d7bba);
#
#
#         var popup_083d9018344ace588fa6307d129f121c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_295c58df3421e75379e34bab3142765b = $(`&lt;div id=&quot;html_295c58df3421e75379e34bab3142765b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_083d9018344ace588fa6307d129f121c.setContent(html_295c58df3421e75379e34bab3142765b);
#
#
#
#         marker_eeec2c7631376e8de282af181776f3c2.bindPopup(popup_083d9018344ace588fa6307d129f121c)
#         ;
#
#
#
#
#             var marker_6ad3487ea5564b440af8b784e1aadd79 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7e0ed54a301fa14e74d2c6a4a47d7bba);
#
#
#         var popup_6541c1dab6392c1aca693701bde93fff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fcfa874d738e5f311794d1634a062b1 = $(`&lt;div id=&quot;html_6fcfa874d738e5f311794d1634a062b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6541c1dab6392c1aca693701bde93fff.setContent(html_6fcfa874d738e5f311794d1634a062b1);
#
#
#
#         marker_6ad3487ea5564b440af8b784e1aadd79.bindPopup(popup_6541c1dab6392c1aca693701bde93fff)
#         ;
#
#
#
#
#             var marker_9cdca0e2fb5118aceaaa29f5258952c7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7e0ed54a301fa14e74d2c6a4a47d7bba);
#
#
#         var popup_bfc476cc59e267b8cb643c3a3e8d8db6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96384bd9188ab10b615f68b780c04029 = $(`&lt;div id=&quot;html_96384bd9188ab10b615f68b780c04029&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bfc476cc59e267b8cb643c3a3e8d8db6.setContent(html_96384bd9188ab10b615f68b780c04029);
#
#
#
#         marker_9cdca0e2fb5118aceaaa29f5258952c7.bindPopup(popup_bfc476cc59e267b8cb643c3a3e8d8db6)
#         ;
#
#
#
#
#             var marker_c66298c1d3864d28df959236ce0ba948 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7e0ed54a301fa14e74d2c6a4a47d7bba);
#
#
#         var popup_24ad7fa38ffbd5863b16476f6b816c9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a38d54ec125fbb303bbaa1e5dea0453c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a38d54ec125fbb303bbaa1e5dea0453c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a38d54ec125fbb303bbaa1e5dea0453c = L.map(
#                 &quot;map_a38d54ec125fbb303bbaa1e5dea0453c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bce092561f7c95b09c83050c72651ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bce092561f7c95b09c83050c72651ca.addTo(map_a38d54ec125fbb303bbaa1e5dea0453c);
#
#
#             var feature_group_219f06e3e96e84167622b065f2eeea3b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_219f06e3e96e84167622b065f2eeea3b.addTo(map_a38d54ec125fbb303bbaa1e5dea0453c);
#
#
#             var feature_group_sub_group_d4dd02b9c47048a4d86f4c415cabcba9 = L.featureGroup.subGroup(
#                 feature_group_219f06e3e96e84167622b065f2eeea3b
#             );
#
#
#             var marker_74c307241db1c6a69b2691ac3f231f0b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4dd02b9c47048a4d86f4c415cabcba9);
#
#
#         var popup_6877ec4b875460ee5b7176a9d71bb3cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b98f45bd6eb4d05d82769eadc9445576 = $(`&lt;div id=&quot;html_b98f45bd6eb4d05d82769eadc9445576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6877ec4b875460ee5b7176a9d71bb3cb.setContent(html_b98f45bd6eb4d05d82769eadc9445576);
#
#
#
#         marker_74c307241db1c6a69b2691ac3f231f0b.bindPopup(popup_6877ec4b875460ee5b7176a9d71bb3cb)
#         ;
#
#
#
#
#             var marker_c6eae6cdd7b7725260237cf12209493a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4dd02b9c47048a4d86f4c415cabcba9);
#
#
#         var popup_879ee47406b073f944103040099fb746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0aa6c7f15fbec7457bc042b9ef4a4f0 = $(`&lt;div id=&quot;html_d0aa6c7f15fbec7457bc042b9ef4a4f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_879ee47406b073f944103040099fb746.setContent(html_d0aa6c7f15fbec7457bc042b9ef4a4f0);
#
#
#
#         marker_c6eae6cdd7b7725260237cf12209493a.bindPopup(popup_879ee47406b073f944103040099fb746)
#         ;
#
#
#
#
#             var marker_6e6d73854e578857ff23d936332490f9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4dd02b9c47048a4d86f4c415cabcba9);
#
#
#         var popup_ddccc09e5e409a59bf566f8d6b2476e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_703744b78138a9b74d9df701956b4691 = $(`&lt;div id=&quot;html_703744b78138a9b74d9df701956b4691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ddccc09e5e409a59bf566f8d6b2476e8.setContent(html_703744b78138a9b74d9df701956b4691);
#
#
#
#         marker_6e6d73854e578857ff23d936332490f9.bindPopup(popup_ddccc09e5e409a59bf566f8d6b2476e8)
#         ;
#
#
#
#
#             var marker_dd413e99751ac8805b376bdb4cb901a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4dd02b9c47048a4d86f4c415cabcba9);
#
#
#         var popup_4138b0c9ce18e477bd79b4cb4b4e97b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eb4b2b610858d686a94ab1542f51c2c = $(`&lt;div id=&quot;html_6eb4b2b610858d686a94ab1542f51c2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4138b0c9ce18e477bd79b4cb4b4e97b4.setContent(html_6eb4b2b610858d686a94ab1542f51c2c);
#
#
#
#         mark
