# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c6033b54b250edd424e71f8bd147a90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c6033b54b250edd424e71f8bd147a90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c6033b54b250edd424e71f8bd147a90 = L.map(
#                 &quot;map_2c6033b54b250edd424e71f8bd147a90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12a1c6881738134faebd36d5c528ebb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12a1c6881738134faebd36d5c528ebb2.addTo(map_2c6033b54b250edd424e71f8bd147a90);
#
#
#             var marker_eceb3ac905fbddd4317ad54a2c40a8bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2c6033b54b250edd424e71f8bd147a90);
#
#
#         var popup_26f541d97b438061613ceb1deedc4716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4370dcde17a039c1313966808d843d65 = $(`&lt;div id=&quot;html_4370dcde17a039c1313966808d843d65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_26f541d97b438061613ceb1deedc4716.setContent(html_4370dcde17a039c1313966808d843d65);
#
#
#
#         marker_eceb3ac905fbddd4317ad54a2c40a8bc.bindPopup(popup_26f541d97b438061613ceb1deedc4716)
#         ;
#
#
#
#
#             var marker_0c6cfc643bd008dd38fe9d83de159a9f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2c6033b54b250edd424e71f8bd147a90);
#
#
#         var popup_c3960afc8bc79c839350e6c95af97e52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b3206fe4face1c147eb24a7c3ebbf69 = $(`&lt;div id=&quot;html_3b3206fe4face1c147eb24a7c3ebbf69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c3960afc8bc79c839350e6c95af97e52.setContent(html_3b3206fe4face1c147eb24a7c3ebbf69);
#
#
#
#         marker_0c6cfc643bd008dd38fe9d83de159a9f.bindPopup(popup_c3960afc8bc79c839350e6c95af97e52)
#         ;
#
#
#
#
#             var marker_7f1ba3e5615c61a0b22aa1b49c14967b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2c6033b54b250edd424e71f8bd147a90);
#
#
#         var popup_a24954a77ad7b0371424d4b0d996b015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_317cb40786437258ee6e80654d4c0a8c = $(`&lt;div id=&quot;html_317cb40786437258ee6e80654d4c0a8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a24954a77ad7b0371424d4b0d996b015.setContent(html_317cb40786437258ee6e80654d4c0a8c);
#
#
#
#         marker_7f1ba3e5615c61a0b22aa1b49c14967b.bindPopup(popup_a24954a77ad7b0371424d4b0d996b015)
#         ;
#
#
#
#
#             var marker_cb4173c067100bd39ac34b939e1bfc96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2c6033b54b250edd424e71f8bd147a90);
#
#
#         var popup_d12f587cc14e3aefc60be0ee2e0f55d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4087bbe5c18bf249027586c7fd25f35 = $(`&lt;div id=&quot;html_c4087bbe5c18bf249027586c7fd25f35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d12f587cc14e3aefc60be0ee2e0f55d6.setContent(html_c4087bbe5c18bf249027586c7fd25f35);
#
#
#
#         marker_cb4173c067100bd39ac34b939e1bfc96.bindPopup(popup_d12f587cc14e3aefc60be0ee2e0f55d6)
#         ;
#
#
#
#
#             var marker_abd5514d0602cbe1b5f599ccdd121e0e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2c6033b54b250edd424e71f8bd147a90);
#
#
#         var popup_fdb2dbb6c3a42bdfacdfcba41765bd7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80b8c7261b0b5af4e8dc03a9313ca61c = $(`&lt;div id=&quot;html_80b8c7261b0b5af4e8dc03a9313ca61c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fdb2dbb6c3a42bdfacdfcba41765bd7a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5015ae225b362da323b0f423f7ce8628 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5015ae225b362da323b0f423f7ce8628&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5015ae225b362da323b0f423f7ce8628 = L.map(
#                 &quot;map_5015ae225b362da323b0f423f7ce8628&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aec8d3a3ff6e2446021abe4746381df0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aec8d3a3ff6e2446021abe4746381df0.addTo(map_5015ae225b362da323b0f423f7ce8628);
#
#
#             var feature_group_1f141a83ca238dca6bdc5ccfcf1c4740 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8850491c9e3d1a7f9c3acd8181301a4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1f141a83ca238dca6bdc5ccfcf1c4740);
#
#
#         var popup_331a83c25839a7ee136ab24df608adda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01ab8c95fef26dc21fe607c47eb7794b = $(`&lt;div id=&quot;html_01ab8c95fef26dc21fe607c47eb7794b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_331a83c25839a7ee136ab24df608adda.setContent(html_01ab8c95fef26dc21fe607c47eb7794b);
#
#
#
#         marker_8850491c9e3d1a7f9c3acd8181301a4d.bindPopup(popup_331a83c25839a7ee136ab24df608adda)
#         ;
#
#
#
#
#             var marker_ee93a9c5ef1768a3fda28a88feee3a73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1f141a83ca238dca6bdc5ccfcf1c4740);
#
#
#         var popup_6a516b7c287d43a02a7450202564c630 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eee5a3a64e8c9b4fa74b9cdafd3ee1a5 = $(`&lt;div id=&quot;html_eee5a3a64e8c9b4fa74b9cdafd3ee1a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6a516b7c287d43a02a7450202564c630.setContent(html_eee5a3a64e8c9b4fa74b9cdafd3ee1a5);
#
#
#
#         marker_ee93a9c5ef1768a3fda28a88feee3a73.bindPopup(popup_6a516b7c287d43a02a7450202564c630)
#         ;
#
#
#
#
#             var marker_2e483ff8816b876183c8a4c5f6542acd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1f141a83ca238dca6bdc5ccfcf1c4740);
#
#
#         var popup_545ba81c4ad13412aa1f155a3b49160e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da2ec327210990c73d8cac37cdf3eaf3 = $(`&lt;div id=&quot;html_da2ec327210990c73d8cac37cdf3eaf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_545ba81c4ad13412aa1f155a3b49160e.setContent(html_da2ec327210990c73d8cac37cdf3eaf3);
#
#
#
#         marker_2e483ff8816b876183c8a4c5f6542acd.bindPopup(popup_545ba81c4ad13412aa1f155a3b49160e)
#         ;
#
#
#
#
#             var marker_e3e49ca12dac9c620b36615a702e7e0e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1f141a83ca238dca6bdc5ccfcf1c4740);
#
#
#         var popup_7dac505142a1615100e97bbbc0babe25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c1c551960284393656ea56a6c7bfc63 = $(`&lt;div id=&quot;html_5c1c551960284393656ea56a6c7bfc63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7dac505142a1615100e97bbbc0babe25.setContent(html_5c1c551960284393656ea56a6c7bfc63);
#
#
#
#         marker_e3e49ca12dac9c620b36615a702e7e0e.bindPopup(popup_7dac505142a1615100e97bbbc0babe25)
#         ;
#
#
#
#
#             var marker_4777d0917ec9425527ab310ff7a73e9f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1f141a83ca238dca6bdc5ccfcf1c4740);
#
#
#         var popup_af913ee4a01d767abe1b1d214fde2a20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aee7bf7782ddf1ad2d57795e97919385 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aee7bf7782ddf1ad2d57795e97919385&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aee7bf7782ddf1ad2d57795e97919385 = L.map(
#                 &quot;map_aee7bf7782ddf1ad2d57795e97919385&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e3ffeaa7b2b02e684c096e09ac16ca3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e3ffeaa7b2b02e684c096e09ac16ca3.addTo(map_aee7bf7782ddf1ad2d57795e97919385);
#
#
#             var feature_group_25b5337d2fe722db610557e199e8b066 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_25b5337d2fe722db610557e199e8b066.addTo(map_aee7bf7782ddf1ad2d57795e97919385);
#
#
#             var feature_group_sub_group_5520b4fa4376993bea36cc2534b16578 = L.featureGroup.subGroup(
#                 feature_group_25b5337d2fe722db610557e199e8b066
#             );
#
#
#             var marker_e6722430a8dac4cbebf45b7be56c77dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5520b4fa4376993bea36cc2534b16578);
#
#
#         var popup_7aeba82117c5416776c62e8c6a1d51c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd2ee5f35a22ce571f2a1a6699cc61ac = $(`&lt;div id=&quot;html_dd2ee5f35a22ce571f2a1a6699cc61ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7aeba82117c5416776c62e8c6a1d51c5.setContent(html_dd2ee5f35a22ce571f2a1a6699cc61ac);
#
#
#
#         marker_e6722430a8dac4cbebf45b7be56c77dc.bindPopup(popup_7aeba82117c5416776c62e8c6a1d51c5)
#         ;
#
#
#
#
#             var marker_7cf8956446741c6e167b24d466409b93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5520b4fa4376993bea36cc2534b16578);
#
#
#         var popup_01650454e7e81bd9c9277499b766a707 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_499409a5ec15f0202dd29b076d52c6c3 = $(`&lt;div id=&quot;html_499409a5ec15f0202dd29b076d52c6c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_01650454e7e81bd9c9277499b766a707.setContent(html_499409a5ec15f0202dd29b076d52c6c3);
#
#
#
#         marker_7cf8956446741c6e167b24d466409b93.bindPopup(popup_01650454e7e81bd9c9277499b766a707)
#         ;
#
#
#
#
#             var marker_dc6e8d597e1cb12ef46f750dfea3f967 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5520b4fa4376993bea36cc2534b16578);
#
#
#         var popup_2e63607d82779225acf506028b45749c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ad5f8449c7e7a2a5abad675815fbece = $(`&lt;div id=&quot;html_2ad5f8449c7e7a2a5abad675815fbece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2e63607d82779225acf506028b45749c.setContent(html_2ad5f8449c7e7a2a5abad675815fbece);
#
#
#
#         marker_dc6e8d597e1cb12ef46f750dfea3f967.bindPopup(popup_2e63607d82779225acf506028b45749c)
#         ;
#
#
#
#
#             var marker_54ca2293b4bfee283c546e88c509363c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5520b4fa4376993bea36cc2534b16578);
#
#
#         var popup_57043d25e76271064e89d8273c6435fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4183a0cc9049f74dea694c38871e9d = $(`&lt;div id=&quot;html_6e4183a0cc9049f74dea694c38871e9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_57043d25e76271064e89d8273c6435fe.setContent(html_6e4183a0cc9049f74dea694c38871e9d);
#
#
#
#         marker_
