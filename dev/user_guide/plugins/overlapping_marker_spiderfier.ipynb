# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0439372b5c6154dd7e14a19e7ac2f62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0439372b5c6154dd7e14a19e7ac2f62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0439372b5c6154dd7e14a19e7ac2f62 = L.map(
#                 &quot;map_c0439372b5c6154dd7e14a19e7ac2f62&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44956151835c8fe105393bb79e71111b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44956151835c8fe105393bb79e71111b.addTo(map_c0439372b5c6154dd7e14a19e7ac2f62);
#
#
#             var marker_27a99fd15905872520651b5c49c54f81 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c0439372b5c6154dd7e14a19e7ac2f62);
#
#
#         var popup_d39ab904d882123c44236cf3743bf835 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00c6909fb98a4de64b2c05cca4af450f = $(`&lt;div id=&quot;html_00c6909fb98a4de64b2c05cca4af450f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d39ab904d882123c44236cf3743bf835.setContent(html_00c6909fb98a4de64b2c05cca4af450f);
#
#
#
#         marker_27a99fd15905872520651b5c49c54f81.bindPopup(popup_d39ab904d882123c44236cf3743bf835)
#         ;
#
#
#
#
#             var marker_e5569a42e03e4ee5f8c5084222f1e9b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c0439372b5c6154dd7e14a19e7ac2f62);
#
#
#         var popup_a7c3112af25a7dcc6c995aef603f9c43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcc305f456099537d837f4d52b0096ad = $(`&lt;div id=&quot;html_fcc305f456099537d837f4d52b0096ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a7c3112af25a7dcc6c995aef603f9c43.setContent(html_fcc305f456099537d837f4d52b0096ad);
#
#
#
#         marker_e5569a42e03e4ee5f8c5084222f1e9b7.bindPopup(popup_a7c3112af25a7dcc6c995aef603f9c43)
#         ;
#
#
#
#
#             var marker_6602c232bc5c9d326a79441655c0be3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c0439372b5c6154dd7e14a19e7ac2f62);
#
#
#         var popup_07acce789e1dfb9dac3cb5f261be1765 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c933014c9df767d09f2c244c7a9e8609 = $(`&lt;div id=&quot;html_c933014c9df767d09f2c244c7a9e8609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_07acce789e1dfb9dac3cb5f261be1765.setContent(html_c933014c9df767d09f2c244c7a9e8609);
#
#
#
#         marker_6602c232bc5c9d326a79441655c0be3e.bindPopup(popup_07acce789e1dfb9dac3cb5f261be1765)
#         ;
#
#
#
#
#             var marker_b99fef58a652be16b031a7fe5a050bf3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c0439372b5c6154dd7e14a19e7ac2f62);
#
#
#         var popup_0ee1a2162875aad8420ed67bd2811c9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c0034e54f773e5e30ddc24ec216fa70 = $(`&lt;div id=&quot;html_4c0034e54f773e5e30ddc24ec216fa70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0ee1a2162875aad8420ed67bd2811c9a.setContent(html_4c0034e54f773e5e30ddc24ec216fa70);
#
#
#
#         marker_b99fef58a652be16b031a7fe5a050bf3.bindPopup(popup_0ee1a2162875aad8420ed67bd2811c9a)
#         ;
#
#
#
#
#             var marker_1e2d0dc161d877c77347bf963e5b10b7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c0439372b5c6154dd7e14a19e7ac2f62);
#
#
#         var popup_5f4b446be94aba161890f3b82c094f90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e65232ef105f513c9955ec3b50e66a33 = $(`&lt;div id=&quot;html_e65232ef105f513c9955ec3b50e66a33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5f4b446be94aba161890f3b82c094f90.setContent(html_e65232ef105f513c9955ec3b50e66a33);
#
#
#
#         marker_1e2d0dc161d877c77347bf963e5b10b7.bindPopup(popup_5f4b446be94aba161890f3b82c094f90)
#         ;
#
#
#
#
#             var marker_4b2c4d7a94

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11e5307756d37401ef24cf9a892f070f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11e5307756d37401ef24cf9a892f070f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11e5307756d37401ef24cf9a892f070f = L.map(
#                 &quot;map_11e5307756d37401ef24cf9a892f070f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a9f6b47cba5a1333d3323a8a7fa7f83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a9f6b47cba5a1333d3323a8a7fa7f83.addTo(map_11e5307756d37401ef24cf9a892f070f);
#
#
#             var feature_group_57ce05a9711fa52eabb8e77ec20bb3b8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ddda63f9bcea41abc42f5da8a0f141e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_57ce05a9711fa52eabb8e77ec20bb3b8);
#
#
#         var popup_922a11b9c5ac6df44589a1331200e891 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bf28b471da393b95506125043b14cbe = $(`&lt;div id=&quot;html_2bf28b471da393b95506125043b14cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_922a11b9c5ac6df44589a1331200e891.setContent(html_2bf28b471da393b95506125043b14cbe);
#
#
#
#         marker_ddda63f9bcea41abc42f5da8a0f141e7.bindPopup(popup_922a11b9c5ac6df44589a1331200e891)
#         ;
#
#
#
#
#             var marker_7a756477ab461e72105f88df0370df56 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_57ce05a9711fa52eabb8e77ec20bb3b8);
#
#
#         var popup_3b252644b94bcf605d4cd5acb10e8d9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3059d5b92ff4498f4f0a0e8523ed0be0 = $(`&lt;div id=&quot;html_3059d5b92ff4498f4f0a0e8523ed0be0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3b252644b94bcf605d4cd5acb10e8d9b.setContent(html_3059d5b92ff4498f4f0a0e8523ed0be0);
#
#
#
#         marker_7a756477ab461e72105f88df0370df56.bindPopup(popup_3b252644b94bcf605d4cd5acb10e8d9b)
#         ;
#
#
#
#
#             var marker_57a537ab40387e0861f2fa143115e3fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_57ce05a9711fa52eabb8e77ec20bb3b8);
#
#
#         var popup_3cbf22e659de6d6a562f86f8410fab5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_febc7e19acbc3949ca9e711b4966c8de = $(`&lt;div id=&quot;html_febc7e19acbc3949ca9e711b4966c8de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3cbf22e659de6d6a562f86f8410fab5c.setContent(html_febc7e19acbc3949ca9e711b4966c8de);
#
#
#
#         marker_57a537ab40387e0861f2fa143115e3fd.bindPopup(popup_3cbf22e659de6d6a562f86f8410fab5c)
#         ;
#
#
#
#
#             var marker_75bd0d6f30900cdad1cf4a808bc79c3d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_57ce05a9711fa52eabb8e77ec20bb3b8);
#
#
#         var popup_b97d74332b813281d0cf31c21195e5f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eb90f49be581ec4ee214e0b8b871c61 = $(`&lt;div id=&quot;html_5eb90f49be581ec4ee214e0b8b871c61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b97d74332b813281d0cf31c21195e5f1.setContent(html_5eb90f49be581ec4ee214e0b8b871c61);
#
#
#
#         marker_75bd0d6f30900cdad1cf4a808bc79c3d.bindPopup(popup_b97d74332b813281d0cf31c21195e5f1)
#         ;
#
#
#
#
#             var marker_5ea524fb6b039cb5965f8255d7678fb4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_57ce05a9711fa52eabb8e77ec20bb3b8);
#
#
#         var popup_efa67e0bfacc3a015b7ac730865978b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6253f3efb07bc09abb5a52421643b4cd = $(`&lt;div id=&quot;html_6253f3efb07bc09abb5a52421643b4cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_efa67e0bfacc3a015b

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_726bd3f1aa09f396b9981a1dd80b8ba5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_726bd3f1aa09f396b9981a1dd80b8ba5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_726bd3f1aa09f396b9981a1dd80b8ba5 = L.map(
#                 &quot;map_726bd3f1aa09f396b9981a1dd80b8ba5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c68693785ff901dc765b05f695dd628 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c68693785ff901dc765b05f695dd628.addTo(map_726bd3f1aa09f396b9981a1dd80b8ba5);
#
#
#             var feature_group_9c3393e5eba9dfed62642377daa32af0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9c3393e5eba9dfed62642377daa32af0.addTo(map_726bd3f1aa09f396b9981a1dd80b8ba5);
#
#
#             var feature_group_sub_group_c74187151a493443a31b5f3c86cde470 = L.featureGroup.subGroup(
#                 feature_group_9c3393e5eba9dfed62642377daa32af0
#             );
#
#
#             var marker_aa040bfb388f8be3c2dd7514780e8767 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c74187151a493443a31b5f3c86cde470);
#
#
#         var popup_1df7230be7ab624dac6eecee63046d61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e75cf8b22380f779b1d53cc879ffdd51 = $(`&lt;div id=&quot;html_e75cf8b22380f779b1d53cc879ffdd51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1df7230be7ab624dac6eecee63046d61.setContent(html_e75cf8b22380f779b1d53cc879ffdd51);
#
#
#
#         marker_aa040bfb388f8be3c2dd7514780e8767.bindPopup(popup_1df7230be7ab624dac6eecee63046d61)
#         ;
#
#
#
#
#             var marker_f9e41011b05bfd5edf930dc53654502b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c74187151a493443a31b5f3c86cde470);
#
#
#         var popup_60338b01bdc1f994767eaddf62180874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9158445c333cd951f4214f90948082b3 = $(`&lt;div id=&quot;html_9158445c333cd951f4214f90948082b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_60338b01bdc1f994767eaddf62180874.setContent(html_9158445c333cd951f4214f90948082b3);
#
#
#
#         marker_f9e41011b05bfd5edf930dc53654502b.bindPopup(popup_60338b01bdc1f994767eaddf62180874)
#         ;
#
#
#
#
#             var marker_c798acf11ef41b0929d682706b75c211 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c74187151a493443a31b5f3c86cde470);
#
#
#         var popup_65c1f63d62bfc25d28171d3fb0400719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0182bfa50824e8113dee8fd1fa9a4816 = $(`&lt;div id=&quot;html_0182bfa50824e8113dee8fd1fa9a4816&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_65c1f63d62bfc25d28171d3fb0400719.setContent(html_0182bfa50824e8113dee8fd1fa9a4816);
#
#
#
#         marker_c798acf11ef41b0929d682706b75c211.bindPopup(popup_65c1f63d62bfc25d28171d3fb0400719)
#         ;
#
#
#
#
#             var marker_068b57623745dee14f15a08892cbdfd1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c74187151a493443a31b5f3c86cde470);
#
#
#         var popup_a6510a3e1d8217677d3c755a9c3eb2ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdfe9693d993072703cf59a7c75b1e45 = $(`&lt;div id=&quot;html_fdfe9693d993072703cf59a7c75b1e45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a6510a3e1d8217677d3c755a9c3eb2ce.setContent(html_fdfe9693d993072703cf59a7c75b1e45);
#
#
#
#         marker_068b57623745dee14f15a08892cbdfd1.bindPopup(popup_a6510a3e1d8217677d3c755a9c3eb2ce)
#         ;
#
#
#
#
#             var marker_53222e297ba04c1755e1f90e6d1f0b67 = L.marker(
#                 [45.050399999999996, 3.0504],
