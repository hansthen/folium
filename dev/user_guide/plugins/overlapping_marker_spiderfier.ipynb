# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79ec1b6c524b719bc4c3c0827491d7b2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79ec1b6c524b719bc4c3c0827491d7b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79ec1b6c524b719bc4c3c0827491d7b2 = L.map(
#                 &quot;map_79ec1b6c524b719bc4c3c0827491d7b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59429ecd2c3892775f29dcbb9c770d21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59429ecd2c3892775f29dcbb9c770d21.addTo(map_79ec1b6c524b719bc4c3c0827491d7b2);
#
#
#             var marker_e68efa8dd4e627bbbdcf3ddf273de38a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_79ec1b6c524b719bc4c3c0827491d7b2);
#
#
#         var popup_a0c087d4278511b8a0fe3950ecb72224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db559f1bfa3ea0ce3d3045db5ac0a475 = $(`&lt;div id=&quot;html_db559f1bfa3ea0ce3d3045db5ac0a475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a0c087d4278511b8a0fe3950ecb72224.setContent(html_db559f1bfa3ea0ce3d3045db5ac0a475);
#
#
#
#         marker_e68efa8dd4e627bbbdcf3ddf273de38a.bindPopup(popup_a0c087d4278511b8a0fe3950ecb72224)
#         ;
#
#
#
#
#             var marker_bcfc502cccd60151d72215872217dcc6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_79ec1b6c524b719bc4c3c0827491d7b2);
#
#
#         var popup_e344dd855dd32ed0ace6270f74e724e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b63bb731b0815f97d207c473813a930 = $(`&lt;div id=&quot;html_5b63bb731b0815f97d207c473813a930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e344dd855dd32ed0ace6270f74e724e9.setContent(html_5b63bb731b0815f97d207c473813a930);
#
#
#
#         marker_bcfc502cccd60151d72215872217dcc6.bindPopup(popup_e344dd855dd32ed0ace6270f74e724e9)
#         ;
#
#
#
#
#             var marker_ba685b9eaf8059c87499dec11f65bc59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_79ec1b6c524b719bc4c3c0827491d7b2);
#
#
#         var popup_4723a7e5493cdf0d0ead9693d0804ed6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5365fb6acbdde9c6a4b263fbfd13fe89 = $(`&lt;div id=&quot;html_5365fb6acbdde9c6a4b263fbfd13fe89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4723a7e5493cdf0d0ead9693d0804ed6.setContent(html_5365fb6acbdde9c6a4b263fbfd13fe89);
#
#
#
#         marker_ba685b9eaf8059c87499dec11f65bc59.bindPopup(popup_4723a7e5493cdf0d0ead9693d0804ed6)
#         ;
#
#
#
#
#             var marker_0644db1b8c9272b07c29fc7781f1898d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_79ec1b6c524b719bc4c3c0827491d7b2);
#
#
#         var popup_32518363c6d1fd31c82626236f8d08e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f6c5265f70e56b21a628ff49314200b = $(`&lt;div id=&quot;html_6f6c5265f70e56b21a628ff49314200b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_32518363c6d1fd31c82626236f8d08e8.setContent(html_6f6c5265f70e56b21a628ff49314200b);
#
#
#
#         marker_0644db1b8c9272b07c29fc7781f1898d.bindPopup(popup_32518363c6d1fd31c82626236f8d08e8)
#         ;
#
#
#
#
#             var marker_1d63b3c6e4196a087286d8ac6e660ade = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_79ec1b6c524b719bc4c3c0827491d7b2);
#
#
#         var popup_df78e9d94791bdf64e006be5d6992e94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52784c3710d5d2e72dbb334bb3d228a1 = $(`&lt;div id=&quot;html_52784c3710d5d2e72dbb334bb3d228a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_df78e9d94791bdf64e006be5d6992e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f76be4ba2277116c99902a3bf4224e2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f76be4ba2277116c99902a3bf4224e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f76be4ba2277116c99902a3bf4224e2 = L.map(
#                 &quot;map_2f76be4ba2277116c99902a3bf4224e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5cd261987cc410a312531b0ac7f5b00d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5cd261987cc410a312531b0ac7f5b00d.addTo(map_2f76be4ba2277116c99902a3bf4224e2);
#
#
#             var feature_group_d9cf8b969628741ff8864e8ddc1fa675 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1bc42e361ba618ea1e106268de64772c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d9cf8b969628741ff8864e8ddc1fa675);
#
#
#         var popup_28d85280fb2cbc406baebb99a303d7db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77bc04e58a346d9ac785655574390388 = $(`&lt;div id=&quot;html_77bc04e58a346d9ac785655574390388&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_28d85280fb2cbc406baebb99a303d7db.setContent(html_77bc04e58a346d9ac785655574390388);
#
#
#
#         marker_1bc42e361ba618ea1e106268de64772c.bindPopup(popup_28d85280fb2cbc406baebb99a303d7db)
#         ;
#
#
#
#
#             var marker_3309322ecf1aba7be0fc854081cdd21a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d9cf8b969628741ff8864e8ddc1fa675);
#
#
#         var popup_b0fe2932ca3b32e3504e8f40e5a6fb19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7a6d927ac3d0f9290752a92209403a8 = $(`&lt;div id=&quot;html_a7a6d927ac3d0f9290752a92209403a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b0fe2932ca3b32e3504e8f40e5a6fb19.setContent(html_a7a6d927ac3d0f9290752a92209403a8);
#
#
#
#         marker_3309322ecf1aba7be0fc854081cdd21a.bindPopup(popup_b0fe2932ca3b32e3504e8f40e5a6fb19)
#         ;
#
#
#
#
#             var marker_123ed738984871cd3d0d3a870a73a2bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d9cf8b969628741ff8864e8ddc1fa675);
#
#
#         var popup_8b5c5cba4a46f33e26f14177357526cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_151b3272c86778c20f4202d97fe3a28b = $(`&lt;div id=&quot;html_151b3272c86778c20f4202d97fe3a28b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8b5c5cba4a46f33e26f14177357526cc.setContent(html_151b3272c86778c20f4202d97fe3a28b);
#
#
#
#         marker_123ed738984871cd3d0d3a870a73a2bc.bindPopup(popup_8b5c5cba4a46f33e26f14177357526cc)
#         ;
#
#
#
#
#             var marker_64ecd0dff71644d61caa328b4732ae99 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d9cf8b969628741ff8864e8ddc1fa675);
#
#
#         var popup_f8a77fa4eae2d6b9f390543d87986d26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0cdb1ade0efb43796180e66fa601b0c = $(`&lt;div id=&quot;html_f0cdb1ade0efb43796180e66fa601b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f8a77fa4eae2d6b9f390543d87986d26.setContent(html_f0cdb1ade0efb43796180e66fa601b0c);
#
#
#
#         marker_64ecd0dff71644d61caa328b4732ae99.bindPopup(popup_f8a77fa4eae2d6b9f390543d87986d26)
#         ;
#
#
#
#
#             var marker_f36c1a97c3c37927c349ddfbb11eaaa0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d9cf8b969628741ff8864e8ddc1fa675);
#
#
#         var popup_3c77285bcd4c4276b8d5a1f70d866dd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44abcbf0a2d2604a9cd18211270de129 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44abcbf0a2d2604a9cd18211270de129&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44abcbf0a2d2604a9cd18211270de129 = L.map(
#                 &quot;map_44abcbf0a2d2604a9cd18211270de129&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21002edb81eb60914156c61233ec2737 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21002edb81eb60914156c61233ec2737.addTo(map_44abcbf0a2d2604a9cd18211270de129);
#
#
#             var feature_group_d63d6924f27d75a795186681bed69f82 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d63d6924f27d75a795186681bed69f82.addTo(map_44abcbf0a2d2604a9cd18211270de129);
#
#
#             var feature_group_sub_group_8cdb50893bd361ab4426d67b59760832 = L.featureGroup.subGroup(
#                 feature_group_d63d6924f27d75a795186681bed69f82
#             );
#
#
#             var marker_435b6c2b0d42e1085fc166cf69469f76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cdb50893bd361ab4426d67b59760832);
#
#
#         var popup_b86ba907a196b539c7c00985c56aeb78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cb8c1bff0c553c61ad7a55c789aa881 = $(`&lt;div id=&quot;html_6cb8c1bff0c553c61ad7a55c789aa881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b86ba907a196b539c7c00985c56aeb78.setContent(html_6cb8c1bff0c553c61ad7a55c789aa881);
#
#
#
#         marker_435b6c2b0d42e1085fc166cf69469f76.bindPopup(popup_b86ba907a196b539c7c00985c56aeb78)
#         ;
#
#
#
#
#             var marker_aab15febf8a352a1879009e2f570bb1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cdb50893bd361ab4426d67b59760832);
#
#
#         var popup_78a6fd59620aaab8baed06ef02cba08d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a716807fe66968df202dc59bbe2a7db = $(`&lt;div id=&quot;html_6a716807fe66968df202dc59bbe2a7db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_78a6fd59620aaab8baed06ef02cba08d.setContent(html_6a716807fe66968df202dc59bbe2a7db);
#
#
#
#         marker_aab15febf8a352a1879009e2f570bb1a.bindPopup(popup_78a6fd59620aaab8baed06ef02cba08d)
#         ;
#
#
#
#
#             var marker_0ef3c0eb7fe3934e8e79e0766616be63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cdb50893bd361ab4426d67b59760832);
#
#
#         var popup_2907deeda52abe0c8027af78bdffdc74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6083c0d8a9a044aaf22bf4d98a12fb66 = $(`&lt;div id=&quot;html_6083c0d8a9a044aaf22bf4d98a12fb66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2907deeda52abe0c8027af78bdffdc74.setContent(html_6083c0d8a9a044aaf22bf4d98a12fb66);
#
#
#
#         marker_0ef3c0eb7fe3934e8e79e0766616be63.bindPopup(popup_2907deeda52abe0c8027af78bdffdc74)
#         ;
#
#
#
#
#             var marker_936be95bd1e27aca30bfc3d4643d1bb2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8cdb50893bd361ab4426d67b59760832);
#
#
#         var popup_8233c42b2b134a4f060de70f50852209 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1062c84c52c3d7b65e2efd5db65989bb = $(`&lt;div id=&quot;html_1062c84c52c3d7b65e2efd5db65989bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8233c42b2b134a4f060de70f50852209.setContent(html_1062c84c52c3d7b65e2efd5db65989bb);
#
#
#
#         mark
