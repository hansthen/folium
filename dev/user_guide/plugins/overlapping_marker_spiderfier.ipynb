# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c14b0ca3009489371f8ebcd77dbcfa74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c14b0ca3009489371f8ebcd77dbcfa74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c14b0ca3009489371f8ebcd77dbcfa74 = L.map(
#                 &quot;map_c14b0ca3009489371f8ebcd77dbcfa74&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d8ac18065173ca3a6677fe9d9163e60 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d8ac18065173ca3a6677fe9d9163e60.addTo(map_c14b0ca3009489371f8ebcd77dbcfa74);
#
#
#             var marker_52e9882513e889071a74b3c3f45b65f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c14b0ca3009489371f8ebcd77dbcfa74);
#
#
#         var popup_bf581e6befa7bdfcdff923b314c644be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5558311320eb3f883a7feab0ca7c66bc = $(`&lt;div id=&quot;html_5558311320eb3f883a7feab0ca7c66bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bf581e6befa7bdfcdff923b314c644be.setContent(html_5558311320eb3f883a7feab0ca7c66bc);
#
#
#
#         marker_52e9882513e889071a74b3c3f45b65f0.bindPopup(popup_bf581e6befa7bdfcdff923b314c644be)
#         ;
#
#
#
#
#             var marker_d8b9249f4c9e215316e56104f283f0c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c14b0ca3009489371f8ebcd77dbcfa74);
#
#
#         var popup_2a98dd29d0e9516b21e114a61e3538a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d8a2ecbc92600299fd3aab212dfbaad = $(`&lt;div id=&quot;html_8d8a2ecbc92600299fd3aab212dfbaad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2a98dd29d0e9516b21e114a61e3538a0.setContent(html_8d8a2ecbc92600299fd3aab212dfbaad);
#
#
#
#         marker_d8b9249f4c9e215316e56104f283f0c9.bindPopup(popup_2a98dd29d0e9516b21e114a61e3538a0)
#         ;
#
#
#
#
#             var marker_d726a1edcc4ea36dc5c42a69e7356ae8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c14b0ca3009489371f8ebcd77dbcfa74);
#
#
#         var popup_0bddb8af41e81b8ef8a01a8173229f0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17c9774192babeba014f98f3266ec513 = $(`&lt;div id=&quot;html_17c9774192babeba014f98f3266ec513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0bddb8af41e81b8ef8a01a8173229f0c.setContent(html_17c9774192babeba014f98f3266ec513);
#
#
#
#         marker_d726a1edcc4ea36dc5c42a69e7356ae8.bindPopup(popup_0bddb8af41e81b8ef8a01a8173229f0c)
#         ;
#
#
#
#
#             var marker_4b085eda680d64634d4a4ee9baa7eed1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c14b0ca3009489371f8ebcd77dbcfa74);
#
#
#         var popup_ce539228df2828ce652fd9ebd9da9416 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ca3fe02cc5de9841c2b0303bf6ca95a = $(`&lt;div id=&quot;html_6ca3fe02cc5de9841c2b0303bf6ca95a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ce539228df2828ce652fd9ebd9da9416.setContent(html_6ca3fe02cc5de9841c2b0303bf6ca95a);
#
#
#
#         marker_4b085eda680d64634d4a4ee9baa7eed1.bindPopup(popup_ce539228df2828ce652fd9ebd9da9416)
#         ;
#
#
#
#
#             var marker_2b49b0e867b26c8ccdececb9738f1b2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c14b0ca3009489371f8ebcd77dbcfa74);
#
#
#         var popup_d7adf1036450e2bf0c6a92057cc2e2a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14a74cf3080620707688ab94ca4d8a19 = $(`&lt;div id=&quot;html_14a74cf3080620707688ab94ca4d8a19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d7adf1036450e2bf0c6a92057cc2e2a4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb029698c4424c1a1858eea718b35a42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb029698c4424c1a1858eea718b35a42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb029698c4424c1a1858eea718b35a42 = L.map(
#                 &quot;map_fb029698c4424c1a1858eea718b35a42&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10b453505c8722515913b72a41c3de53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10b453505c8722515913b72a41c3de53.addTo(map_fb029698c4424c1a1858eea718b35a42);
#
#
#             var feature_group_faba3e73bbf8e264a60cf57609e02b26 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f2dfe3a97b998f80e6b06fdb07639a5d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_faba3e73bbf8e264a60cf57609e02b26);
#
#
#         var popup_82cfc459bc950cb19d481ea5711e43bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_355ff73c383fcfea247d0839903f5de9 = $(`&lt;div id=&quot;html_355ff73c383fcfea247d0839903f5de9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_82cfc459bc950cb19d481ea5711e43bc.setContent(html_355ff73c383fcfea247d0839903f5de9);
#
#
#
#         marker_f2dfe3a97b998f80e6b06fdb07639a5d.bindPopup(popup_82cfc459bc950cb19d481ea5711e43bc)
#         ;
#
#
#
#
#             var marker_82fb6639bf151c5a0aa79facff5a9597 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_faba3e73bbf8e264a60cf57609e02b26);
#
#
#         var popup_19c72c5ed908006dc2d6848f0203307b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c488c6f829505bd10f96a9887f5833f = $(`&lt;div id=&quot;html_7c488c6f829505bd10f96a9887f5833f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_19c72c5ed908006dc2d6848f0203307b.setContent(html_7c488c6f829505bd10f96a9887f5833f);
#
#
#
#         marker_82fb6639bf151c5a0aa79facff5a9597.bindPopup(popup_19c72c5ed908006dc2d6848f0203307b)
#         ;
#
#
#
#
#             var marker_6c209e1eb4edd47a5192216ced8145b5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_faba3e73bbf8e264a60cf57609e02b26);
#
#
#         var popup_3bc748a79e642dfa6fe18c39f491f015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7484c6401c14b9281e21253b1675ca26 = $(`&lt;div id=&quot;html_7484c6401c14b9281e21253b1675ca26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3bc748a79e642dfa6fe18c39f491f015.setContent(html_7484c6401c14b9281e21253b1675ca26);
#
#
#
#         marker_6c209e1eb4edd47a5192216ced8145b5.bindPopup(popup_3bc748a79e642dfa6fe18c39f491f015)
#         ;
#
#
#
#
#             var marker_3f515f4b14314f680a5c22c9aa973e58 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_faba3e73bbf8e264a60cf57609e02b26);
#
#
#         var popup_8cde127d7804d8eb582a1500685f717c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6054e333e2a2e0d97523ed72e72518e = $(`&lt;div id=&quot;html_b6054e333e2a2e0d97523ed72e72518e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8cde127d7804d8eb582a1500685f717c.setContent(html_b6054e333e2a2e0d97523ed72e72518e);
#
#
#
#         marker_3f515f4b14314f680a5c22c9aa973e58.bindPopup(popup_8cde127d7804d8eb582a1500685f717c)
#         ;
#
#
#
#
#             var marker_240f752279dd3a4826453a0357d7b6e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_faba3e73bbf8e264a60cf57609e02b26);
#
#
#         var popup_70d8e9a761cc86e3298f6800e35075dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c543afbb22d516f0c7b3f838dcd9df2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c543afbb22d516f0c7b3f838dcd9df2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c543afbb22d516f0c7b3f838dcd9df2d = L.map(
#                 &quot;map_c543afbb22d516f0c7b3f838dcd9df2d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09b8570787a9e60f8dc722b4af8a1420 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09b8570787a9e60f8dc722b4af8a1420.addTo(map_c543afbb22d516f0c7b3f838dcd9df2d);
#
#
#             var feature_group_bfa12d157875b061b23e72df629fc37e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bfa12d157875b061b23e72df629fc37e.addTo(map_c543afbb22d516f0c7b3f838dcd9df2d);
#
#
#             var feature_group_sub_group_e9e2f8816f71261f5a163fe451d79744 = L.featureGroup.subGroup(
#                 feature_group_bfa12d157875b061b23e72df629fc37e
#             );
#
#
#             var marker_783e4ae43a221fefb26f735806237b46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e2f8816f71261f5a163fe451d79744);
#
#
#         var popup_6299837b4fb18af3a94574cadd472ccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01d14ad1d43e0fadb47e97bdfd3b59ed = $(`&lt;div id=&quot;html_01d14ad1d43e0fadb47e97bdfd3b59ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6299837b4fb18af3a94574cadd472ccc.setContent(html_01d14ad1d43e0fadb47e97bdfd3b59ed);
#
#
#
#         marker_783e4ae43a221fefb26f735806237b46.bindPopup(popup_6299837b4fb18af3a94574cadd472ccc)
#         ;
#
#
#
#
#             var marker_62262e8aaf44e5f692d774c76b33a655 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e2f8816f71261f5a163fe451d79744);
#
#
#         var popup_30a93c54ca3dd514e4d936f056f40b85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7e0463ec5d43ee971cf79eaadd7070c = $(`&lt;div id=&quot;html_b7e0463ec5d43ee971cf79eaadd7070c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_30a93c54ca3dd514e4d936f056f40b85.setContent(html_b7e0463ec5d43ee971cf79eaadd7070c);
#
#
#
#         marker_62262e8aaf44e5f692d774c76b33a655.bindPopup(popup_30a93c54ca3dd514e4d936f056f40b85)
#         ;
#
#
#
#
#             var marker_5ecf9d596893717489bba0268ec8f488 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e2f8816f71261f5a163fe451d79744);
#
#
#         var popup_d3881ef93ae63916f9f9ccee26461ec8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_939849e53a09ed8cad45bc6c3cb88141 = $(`&lt;div id=&quot;html_939849e53a09ed8cad45bc6c3cb88141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d3881ef93ae63916f9f9ccee26461ec8.setContent(html_939849e53a09ed8cad45bc6c3cb88141);
#
#
#
#         marker_5ecf9d596893717489bba0268ec8f488.bindPopup(popup_d3881ef93ae63916f9f9ccee26461ec8)
#         ;
#
#
#
#
#             var marker_36fa0010b3461b6486e1daa559493115 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e2f8816f71261f5a163fe451d79744);
#
#
#         var popup_d35918ffa833df4dd332103b4cff0068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bca2f7801a87bccd0a22c68086a5dff0 = $(`&lt;div id=&quot;html_bca2f7801a87bccd0a22c68086a5dff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d35918ffa833df4dd332103b4cff0068.setContent(html_bca2f7801a87bccd0a22c68086a5dff0);
#
#
#
#         marker_
