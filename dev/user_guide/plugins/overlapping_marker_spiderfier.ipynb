# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df89b22fbc51cc66f646d3354952d222 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df89b22fbc51cc66f646d3354952d222&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df89b22fbc51cc66f646d3354952d222 = L.map(
#                 &quot;map_df89b22fbc51cc66f646d3354952d222&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d968916dd992e12160de58a8990d4d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d968916dd992e12160de58a8990d4d3.addTo(map_df89b22fbc51cc66f646d3354952d222);
#
#
#             var marker_abacd90a179298e557b5dec33bb21fa3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_df89b22fbc51cc66f646d3354952d222);
#
#
#         var popup_9e64e4893376ec009d4af06916ff879d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74f9acfdb6225c8a737a213d0dcdc846 = $(`&lt;div id=&quot;html_74f9acfdb6225c8a737a213d0dcdc846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9e64e4893376ec009d4af06916ff879d.setContent(html_74f9acfdb6225c8a737a213d0dcdc846);
#
#
#
#         marker_abacd90a179298e557b5dec33bb21fa3.bindPopup(popup_9e64e4893376ec009d4af06916ff879d)
#         ;
#
#
#
#
#             var marker_00e1cefed5db37eedae079a661190291 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_df89b22fbc51cc66f646d3354952d222);
#
#
#         var popup_de11b7d019ca16b087b358c3ef1c36f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_184a01a1ab50dafaa40381a7793415f4 = $(`&lt;div id=&quot;html_184a01a1ab50dafaa40381a7793415f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_de11b7d019ca16b087b358c3ef1c36f8.setContent(html_184a01a1ab50dafaa40381a7793415f4);
#
#
#
#         marker_00e1cefed5db37eedae079a661190291.bindPopup(popup_de11b7d019ca16b087b358c3ef1c36f8)
#         ;
#
#
#
#
#             var marker_327fe33403dbe11eb0da3133d680b1e7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_df89b22fbc51cc66f646d3354952d222);
#
#
#         var popup_db95967408968b1c1536eba57312917c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b71bd177caaa9920ff14f30801f86bb = $(`&lt;div id=&quot;html_1b71bd177caaa9920ff14f30801f86bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_db95967408968b1c1536eba57312917c.setContent(html_1b71bd177caaa9920ff14f30801f86bb);
#
#
#
#         marker_327fe33403dbe11eb0da3133d680b1e7.bindPopup(popup_db95967408968b1c1536eba57312917c)
#         ;
#
#
#
#
#             var marker_e3c4b52074033079ba4d4799b75276dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_df89b22fbc51cc66f646d3354952d222);
#
#
#         var popup_04063bf72e72c2d258f3d459149e0937 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dcf3405ed622a954d8126f3cb0d4bfb = $(`&lt;div id=&quot;html_4dcf3405ed622a954d8126f3cb0d4bfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_04063bf72e72c2d258f3d459149e0937.setContent(html_4dcf3405ed622a954d8126f3cb0d4bfb);
#
#
#
#         marker_e3c4b52074033079ba4d4799b75276dd.bindPopup(popup_04063bf72e72c2d258f3d459149e0937)
#         ;
#
#
#
#
#             var marker_9035db03fcf8723a535e8849fede443e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_df89b22fbc51cc66f646d3354952d222);
#
#
#         var popup_33feaf1f58e670fab6cd0cc3be8c7506 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_466c72f043021fff8cc8e54a46ce2cda = $(`&lt;div id=&quot;html_466c72f043021fff8cc8e54a46ce2cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_33feaf1f58e670fab6cd0cc3be8c7506.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dc40e3d9ada258b76b890f3314e21c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dc40e3d9ada258b76b890f3314e21c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dc40e3d9ada258b76b890f3314e21c4 = L.map(
#                 &quot;map_6dc40e3d9ada258b76b890f3314e21c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88ec87fcb51fe8c64f9ce931206057ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88ec87fcb51fe8c64f9ce931206057ef.addTo(map_6dc40e3d9ada258b76b890f3314e21c4);
#
#
#             var feature_group_4a5dc1de2cf9e9a03de8c69a6c34ea57 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b534f0a233ae5546e4640fbaf4cb40ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4a5dc1de2cf9e9a03de8c69a6c34ea57);
#
#
#         var popup_c454501ac226390bda8a450b8c85d471 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9d7b72dcd43365632f1487867d3808 = $(`&lt;div id=&quot;html_dc9d7b72dcd43365632f1487867d3808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c454501ac226390bda8a450b8c85d471.setContent(html_dc9d7b72dcd43365632f1487867d3808);
#
#
#
#         marker_b534f0a233ae5546e4640fbaf4cb40ce.bindPopup(popup_c454501ac226390bda8a450b8c85d471)
#         ;
#
#
#
#
#             var marker_2336cc667fe355e45ba685a1be63bf44 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4a5dc1de2cf9e9a03de8c69a6c34ea57);
#
#
#         var popup_3ce5cd4f5691d8e10bd2d979bba7ffe8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1cd75993996dcac95756f95bc63d02d = $(`&lt;div id=&quot;html_d1cd75993996dcac95756f95bc63d02d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3ce5cd4f5691d8e10bd2d979bba7ffe8.setContent(html_d1cd75993996dcac95756f95bc63d02d);
#
#
#
#         marker_2336cc667fe355e45ba685a1be63bf44.bindPopup(popup_3ce5cd4f5691d8e10bd2d979bba7ffe8)
#         ;
#
#
#
#
#             var marker_ce2e19ccc30614aa747c2d689706ede8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4a5dc1de2cf9e9a03de8c69a6c34ea57);
#
#
#         var popup_b16023bc2629220bb666a301ac2789c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bca9b857ec5d1b776652201fcf91711 = $(`&lt;div id=&quot;html_6bca9b857ec5d1b776652201fcf91711&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b16023bc2629220bb666a301ac2789c0.setContent(html_6bca9b857ec5d1b776652201fcf91711);
#
#
#
#         marker_ce2e19ccc30614aa747c2d689706ede8.bindPopup(popup_b16023bc2629220bb666a301ac2789c0)
#         ;
#
#
#
#
#             var marker_29ee074a7491f29c721131aea5db8207 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4a5dc1de2cf9e9a03de8c69a6c34ea57);
#
#
#         var popup_9d4e23c3b267f3660e87756b66c3214b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a817a2c2947b6b68204135576d9b267d = $(`&lt;div id=&quot;html_a817a2c2947b6b68204135576d9b267d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9d4e23c3b267f3660e87756b66c3214b.setContent(html_a817a2c2947b6b68204135576d9b267d);
#
#
#
#         marker_29ee074a7491f29c721131aea5db8207.bindPopup(popup_9d4e23c3b267f3660e87756b66c3214b)
#         ;
#
#
#
#
#             var marker_32665208e5e01ec97c8679ae4e665ad7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4a5dc1de2cf9e9a03de8c69a6c34ea57);
#
#
#         var popup_103ddf704f8992590a991456b93d3ba2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6acc49a8a7f4f9592072bc572dd4c17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6acc49a8a7f4f9592072bc572dd4c17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6acc49a8a7f4f9592072bc572dd4c17 = L.map(
#                 &quot;map_d6acc49a8a7f4f9592072bc572dd4c17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a322cda68585e8986b43d593f032e432 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a322cda68585e8986b43d593f032e432.addTo(map_d6acc49a8a7f4f9592072bc572dd4c17);
#
#
#             var feature_group_5b6a6f60641cca3ded54392122a4b392 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5b6a6f60641cca3ded54392122a4b392.addTo(map_d6acc49a8a7f4f9592072bc572dd4c17);
#
#
#             var feature_group_sub_group_55e1b63abcc27b7d39772fd5641c03f2 = L.featureGroup.subGroup(
#                 feature_group_5b6a6f60641cca3ded54392122a4b392
#             );
#
#
#             var marker_7bdcabfa34e6af941d639883910addbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_55e1b63abcc27b7d39772fd5641c03f2);
#
#
#         var popup_0717ef02a805ea54123b140f32e439ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_101a7c3fb5f3968f3701af28887fe4cb = $(`&lt;div id=&quot;html_101a7c3fb5f3968f3701af28887fe4cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0717ef02a805ea54123b140f32e439ed.setContent(html_101a7c3fb5f3968f3701af28887fe4cb);
#
#
#
#         marker_7bdcabfa34e6af941d639883910addbd.bindPopup(popup_0717ef02a805ea54123b140f32e439ed)
#         ;
#
#
#
#
#             var marker_05f525cf77a20b9fac3e6f9868ed9057 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_55e1b63abcc27b7d39772fd5641c03f2);
#
#
#         var popup_c4c5b86e657e8231c6417bc0abd531fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad03e599a0525c47ef94a58a396e6670 = $(`&lt;div id=&quot;html_ad03e599a0525c47ef94a58a396e6670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c4c5b86e657e8231c6417bc0abd531fe.setContent(html_ad03e599a0525c47ef94a58a396e6670);
#
#
#
#         marker_05f525cf77a20b9fac3e6f9868ed9057.bindPopup(popup_c4c5b86e657e8231c6417bc0abd531fe)
#         ;
#
#
#
#
#             var marker_33aac0c7c243f10fe7f20d2509e4b6c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_55e1b63abcc27b7d39772fd5641c03f2);
#
#
#         var popup_1d1f5dcb5203f4ab35993cc7a729dfb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c04c9aa05c5386adaf21478fae96d76 = $(`&lt;div id=&quot;html_7c04c9aa05c5386adaf21478fae96d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1d1f5dcb5203f4ab35993cc7a729dfb0.setContent(html_7c04c9aa05c5386adaf21478fae96d76);
#
#
#
#         marker_33aac0c7c243f10fe7f20d2509e4b6c5.bindPopup(popup_1d1f5dcb5203f4ab35993cc7a729dfb0)
#         ;
#
#
#
#
#             var marker_73fd3b1dc871d7cd0c06af0632f22afc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_55e1b63abcc27b7d39772fd5641c03f2);
#
#
#         var popup_4a5d9f8fd850d4fdf7d27042df8f991b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1699ff335cad52afa224a17202156e8 = $(`&lt;div id=&quot;html_d1699ff335cad52afa224a17202156e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4a5d9f8fd850d4fdf7d27042df8f991b.setContent(html_d1699ff335cad52afa224a17202156e8);
#
#
#
#         marker_
