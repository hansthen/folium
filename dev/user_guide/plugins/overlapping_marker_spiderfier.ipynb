# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2144202542e96fc8f8ea3e076675e02c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2144202542e96fc8f8ea3e076675e02c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2144202542e96fc8f8ea3e076675e02c = L.map(
#                 &quot;map_2144202542e96fc8f8ea3e076675e02c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d271619fb58048471c57d28e9265b2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d271619fb58048471c57d28e9265b2d.addTo(map_2144202542e96fc8f8ea3e076675e02c);
#
#
#             var marker_8a67458aa25cefa346f85f9a1656a552 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2144202542e96fc8f8ea3e076675e02c);
#
#
#         var popup_2c25bbe8f06dd4f0db3d7b626f5718c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c034c7373f38dfaadc84526379b24a76 = $(`&lt;div id=&quot;html_c034c7373f38dfaadc84526379b24a76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2c25bbe8f06dd4f0db3d7b626f5718c4.setContent(html_c034c7373f38dfaadc84526379b24a76);
#
#
#
#         marker_8a67458aa25cefa346f85f9a1656a552.bindPopup(popup_2c25bbe8f06dd4f0db3d7b626f5718c4)
#         ;
#
#
#
#
#             var marker_099b469e1ed1144e144b11dae6731030 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2144202542e96fc8f8ea3e076675e02c);
#
#
#         var popup_371c932930622b1ae740cd2653ae7818 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efc3a22693642593cb068f1abe0e95cb = $(`&lt;div id=&quot;html_efc3a22693642593cb068f1abe0e95cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_371c932930622b1ae740cd2653ae7818.setContent(html_efc3a22693642593cb068f1abe0e95cb);
#
#
#
#         marker_099b469e1ed1144e144b11dae6731030.bindPopup(popup_371c932930622b1ae740cd2653ae7818)
#         ;
#
#
#
#
#             var marker_bc9503b831f1493680ad83513915d822 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2144202542e96fc8f8ea3e076675e02c);
#
#
#         var popup_209a93c6b9fd2ad5359a644f0f4aeee0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9358105717fd17aa9ebe70f20bf47561 = $(`&lt;div id=&quot;html_9358105717fd17aa9ebe70f20bf47561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_209a93c6b9fd2ad5359a644f0f4aeee0.setContent(html_9358105717fd17aa9ebe70f20bf47561);
#
#
#
#         marker_bc9503b831f1493680ad83513915d822.bindPopup(popup_209a93c6b9fd2ad5359a644f0f4aeee0)
#         ;
#
#
#
#
#             var marker_e7e72908c01810d41c8abea859fc2054 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2144202542e96fc8f8ea3e076675e02c);
#
#
#         var popup_fd734df34c387c84710ecaf31ab5bb71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_722e5469743880cdea1547aa68254c0c = $(`&lt;div id=&quot;html_722e5469743880cdea1547aa68254c0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fd734df34c387c84710ecaf31ab5bb71.setContent(html_722e5469743880cdea1547aa68254c0c);
#
#
#
#         marker_e7e72908c01810d41c8abea859fc2054.bindPopup(popup_fd734df34c387c84710ecaf31ab5bb71)
#         ;
#
#
#
#
#             var marker_9ae07f236ff7b48ebf7ebc254f0689bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2144202542e96fc8f8ea3e076675e02c);
#
#
#         var popup_66d1470f598864b902d25aa52700691d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eeb901ab241dd956451330f93013cb5 = $(`&lt;div id=&quot;html_4eeb901ab241dd956451330f93013cb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_66d1470f598864b902d25aa5270069

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de04e5723bcadc8ce65b7ba55e080906 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de04e5723bcadc8ce65b7ba55e080906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de04e5723bcadc8ce65b7ba55e080906 = L.map(
#                 &quot;map_de04e5723bcadc8ce65b7ba55e080906&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa75546262ca60ba112711e01800de74 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa75546262ca60ba112711e01800de74.addTo(map_de04e5723bcadc8ce65b7ba55e080906);
#
#
#             var feature_group_52041ccd88044fabc2666ce499157818 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dda80761442fce45bfd6bd3e1f7b6659 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_52041ccd88044fabc2666ce499157818);
#
#
#         var popup_bf3c9336d8992b1a3697a2fc82f43f31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b46c24f1abeeaa0e44e3a0f5ea58f59b = $(`&lt;div id=&quot;html_b46c24f1abeeaa0e44e3a0f5ea58f59b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bf3c9336d8992b1a3697a2fc82f43f31.setContent(html_b46c24f1abeeaa0e44e3a0f5ea58f59b);
#
#
#
#         marker_dda80761442fce45bfd6bd3e1f7b6659.bindPopup(popup_bf3c9336d8992b1a3697a2fc82f43f31)
#         ;
#
#
#
#
#             var marker_035d55c7972ddee50c57d34b9912272e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_52041ccd88044fabc2666ce499157818);
#
#
#         var popup_a79d09886b97cf36cca9709c2de017f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfe87c518e4856a5eddc5f7ac79c12a9 = $(`&lt;div id=&quot;html_dfe87c518e4856a5eddc5f7ac79c12a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a79d09886b97cf36cca9709c2de017f4.setContent(html_dfe87c518e4856a5eddc5f7ac79c12a9);
#
#
#
#         marker_035d55c7972ddee50c57d34b9912272e.bindPopup(popup_a79d09886b97cf36cca9709c2de017f4)
#         ;
#
#
#
#
#             var marker_58e7855e434b310ce4972c26a865d836 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_52041ccd88044fabc2666ce499157818);
#
#
#         var popup_91d4186628ce58e852e59359d7a90125 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01c9221edc71162785ecca3c2c9af44d = $(`&lt;div id=&quot;html_01c9221edc71162785ecca3c2c9af44d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_91d4186628ce58e852e59359d7a90125.setContent(html_01c9221edc71162785ecca3c2c9af44d);
#
#
#
#         marker_58e7855e434b310ce4972c26a865d836.bindPopup(popup_91d4186628ce58e852e59359d7a90125)
#         ;
#
#
#
#
#             var marker_121dff2922b46fa942b1c4b8ed0e79fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_52041ccd88044fabc2666ce499157818);
#
#
#         var popup_be26353b5c65044cabc7f7795b0d1f7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f42fa7229e7930d57a681297dc5b552b = $(`&lt;div id=&quot;html_f42fa7229e7930d57a681297dc5b552b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_be26353b5c65044cabc7f7795b0d1f7c.setContent(html_f42fa7229e7930d57a681297dc5b552b);
#
#
#
#         marker_121dff2922b46fa942b1c4b8ed0e79fe.bindPopup(popup_be26353b5c65044cabc7f7795b0d1f7c)
#         ;
#
#
#
#
#             var marker_5bf25ec6b12e6a6b9fdec909a0721240 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_52041ccd88044fabc2666ce499157818);
#
#
#         var popup_7119f43c739154794facc3a865e66b9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_770fad1f4239c704e75cae851d8c0e48 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_770fad1f4239c704e75cae851d8c0e48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_770fad1f4239c704e75cae851d8c0e48 = L.map(
#                 &quot;map_770fad1f4239c704e75cae851d8c0e48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86eb08c8809748c3e4febaef4b87133d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86eb08c8809748c3e4febaef4b87133d.addTo(map_770fad1f4239c704e75cae851d8c0e48);
#
#
#             var feature_group_d0615c56f347b3481f11e4f5faf3a0d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d0615c56f347b3481f11e4f5faf3a0d3.addTo(map_770fad1f4239c704e75cae851d8c0e48);
#
#
#             var feature_group_sub_group_6b7720213fb79fd6b30ec07306f76b98 = L.featureGroup.subGroup(
#                 feature_group_d0615c56f347b3481f11e4f5faf3a0d3
#             );
#
#
#             var marker_485cf3cce26b8e89bab905cd83aac648 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b7720213fb79fd6b30ec07306f76b98);
#
#
#         var popup_cbc965e28110f6b331374e938e7b85be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1497025db7c99eb7bd8ecb3575bfad79 = $(`&lt;div id=&quot;html_1497025db7c99eb7bd8ecb3575bfad79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cbc965e28110f6b331374e938e7b85be.setContent(html_1497025db7c99eb7bd8ecb3575bfad79);
#
#
#
#         marker_485cf3cce26b8e89bab905cd83aac648.bindPopup(popup_cbc965e28110f6b331374e938e7b85be)
#         ;
#
#
#
#
#             var marker_a889dc93f18c502eba06fb19b5f95b80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b7720213fb79fd6b30ec07306f76b98);
#
#
#         var popup_58885fdc594c3700cab20e43a5785185 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_046b495a3ad86ace73077b03fd77e9fb = $(`&lt;div id=&quot;html_046b495a3ad86ace73077b03fd77e9fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_58885fdc594c3700cab20e43a5785185.setContent(html_046b495a3ad86ace73077b03fd77e9fb);
#
#
#
#         marker_a889dc93f18c502eba06fb19b5f95b80.bindPopup(popup_58885fdc594c3700cab20e43a5785185)
#         ;
#
#
#
#
#             var marker_ed98380e29c13e5f0320726ac09b99aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b7720213fb79fd6b30ec07306f76b98);
#
#
#         var popup_b29efbb545d0d53e55f14640e08cf71a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd751233e11949f454b86975657dceac = $(`&lt;div id=&quot;html_cd751233e11949f454b86975657dceac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b29efbb545d0d53e55f14640e08cf71a.setContent(html_cd751233e11949f454b86975657dceac);
#
#
#
#         marker_ed98380e29c13e5f0320726ac09b99aa.bindPopup(popup_b29efbb545d0d53e55f14640e08cf71a)
#         ;
#
#
#
#
#             var marker_9bc16c6075366ea300d91af4797e7fae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b7720213fb79fd6b30ec07306f76b98);
#
#
#         var popup_4c9827b3acbfab9cd327ef2ca950cd76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1593beba99bcc4d3983694d31b86ff3 = $(`&lt;div id=&quot;html_f1593beba99bcc4d3983694d31b86ff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4c9827b3acbfab9cd327ef2ca950cd76.setContent(html_f1593beba99bcc4d3983694d31b86ff3);
#
#
#
#         mark
