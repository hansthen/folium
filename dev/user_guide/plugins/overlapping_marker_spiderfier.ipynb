# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19205acae10a32f45793dcb4745c1b49 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19205acae10a32f45793dcb4745c1b49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19205acae10a32f45793dcb4745c1b49 = L.map(
#                 &quot;map_19205acae10a32f45793dcb4745c1b49&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69a03a965f2599b4a947b9a276a8ae6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69a03a965f2599b4a947b9a276a8ae6e.addTo(map_19205acae10a32f45793dcb4745c1b49);
#
#
#             var marker_ee7f91bd305403b9ea1134cd663ccc7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_19205acae10a32f45793dcb4745c1b49);
#
#
#         var popup_cce7dbf84d344f18304490fd1d61a73d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc3e24d81952a72c731097dcfa13ce72 = $(`&lt;div id=&quot;html_fc3e24d81952a72c731097dcfa13ce72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cce7dbf84d344f18304490fd1d61a73d.setContent(html_fc3e24d81952a72c731097dcfa13ce72);
#
#
#
#         marker_ee7f91bd305403b9ea1134cd663ccc7e.bindPopup(popup_cce7dbf84d344f18304490fd1d61a73d)
#         ;
#
#
#
#
#             var marker_e11603f884c75a7cc2dc0d3d52068da7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_19205acae10a32f45793dcb4745c1b49);
#
#
#         var popup_533b6775aef04c569dad517d76602287 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d09172677a8db3b3497730430b7a8b = $(`&lt;div id=&quot;html_20d09172677a8db3b3497730430b7a8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_533b6775aef04c569dad517d76602287.setContent(html_20d09172677a8db3b3497730430b7a8b);
#
#
#
#         marker_e11603f884c75a7cc2dc0d3d52068da7.bindPopup(popup_533b6775aef04c569dad517d76602287)
#         ;
#
#
#
#
#             var marker_9f5a219338eec12d580744e04fc44bf3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_19205acae10a32f45793dcb4745c1b49);
#
#
#         var popup_c0609a4e14f60953ec41206054def896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c92725eb003ea6bf80d004cc6d9d58a2 = $(`&lt;div id=&quot;html_c92725eb003ea6bf80d004cc6d9d58a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c0609a4e14f60953ec41206054def896.setContent(html_c92725eb003ea6bf80d004cc6d9d58a2);
#
#
#
#         marker_9f5a219338eec12d580744e04fc44bf3.bindPopup(popup_c0609a4e14f60953ec41206054def896)
#         ;
#
#
#
#
#             var marker_7baedc52721210fa375e122ee9b3dc25 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_19205acae10a32f45793dcb4745c1b49);
#
#
#         var popup_dd94cfcfd4d43eb0be98c4b76c323512 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52fda55921932881f0713c7bd8c21d54 = $(`&lt;div id=&quot;html_52fda55921932881f0713c7bd8c21d54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dd94cfcfd4d43eb0be98c4b76c323512.setContent(html_52fda55921932881f0713c7bd8c21d54);
#
#
#
#         marker_7baedc52721210fa375e122ee9b3dc25.bindPopup(popup_dd94cfcfd4d43eb0be98c4b76c323512)
#         ;
#
#
#
#
#             var marker_6c0fd1e1832dd7b575ec611cab4eb3bd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_19205acae10a32f45793dcb4745c1b49);
#
#
#         var popup_257134988577c20d38127f383dbca534 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d50cd866dc7f6c3caa49dd82c74e9f7a = $(`&lt;div id=&quot;html_d50cd866dc7f6c3caa49dd82c74e9f7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_257134988577c20d38127f383dbca5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edadc69fcfb77b1289e4bf444a40ef2c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edadc69fcfb77b1289e4bf444a40ef2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edadc69fcfb77b1289e4bf444a40ef2c = L.map(
#                 &quot;map_edadc69fcfb77b1289e4bf444a40ef2c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4d38140cc2f7f15685a9f5fed209acc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4d38140cc2f7f15685a9f5fed209acc.addTo(map_edadc69fcfb77b1289e4bf444a40ef2c);
#
#
#             var feature_group_76815a5b4f9ae9fa5b2ef3e66d5ba49c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1592163f6313be16758fb40a9fb67655 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_76815a5b4f9ae9fa5b2ef3e66d5ba49c);
#
#
#         var popup_3ac03fbfaa13a5dc0fdd672dec3a00b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adced8d683646ce86bc9df904e40527c = $(`&lt;div id=&quot;html_adced8d683646ce86bc9df904e40527c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3ac03fbfaa13a5dc0fdd672dec3a00b9.setContent(html_adced8d683646ce86bc9df904e40527c);
#
#
#
#         marker_1592163f6313be16758fb40a9fb67655.bindPopup(popup_3ac03fbfaa13a5dc0fdd672dec3a00b9)
#         ;
#
#
#
#
#             var marker_d3e06c6b2ed268b2442b35fc0adcef22 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_76815a5b4f9ae9fa5b2ef3e66d5ba49c);
#
#
#         var popup_d97f16b09fd017a0c8a58a4828a8c3f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4443fdccd2f2a8c6fd7fa6878cdf75e4 = $(`&lt;div id=&quot;html_4443fdccd2f2a8c6fd7fa6878cdf75e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d97f16b09fd017a0c8a58a4828a8c3f9.setContent(html_4443fdccd2f2a8c6fd7fa6878cdf75e4);
#
#
#
#         marker_d3e06c6b2ed268b2442b35fc0adcef22.bindPopup(popup_d97f16b09fd017a0c8a58a4828a8c3f9)
#         ;
#
#
#
#
#             var marker_85336be05672d77b59938b51b8e8ecf7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_76815a5b4f9ae9fa5b2ef3e66d5ba49c);
#
#
#         var popup_66b384464f36afa5dde2e509b78280b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_879eb12969761e184b5f38b67f775633 = $(`&lt;div id=&quot;html_879eb12969761e184b5f38b67f775633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_66b384464f36afa5dde2e509b78280b8.setContent(html_879eb12969761e184b5f38b67f775633);
#
#
#
#         marker_85336be05672d77b59938b51b8e8ecf7.bindPopup(popup_66b384464f36afa5dde2e509b78280b8)
#         ;
#
#
#
#
#             var marker_189e5ea7944a155efdb7d2de146ab4dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_76815a5b4f9ae9fa5b2ef3e66d5ba49c);
#
#
#         var popup_c990ee3cb8921ce7789c05312d3c3bb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09d2a648e6e192b4b67311da02e6638f = $(`&lt;div id=&quot;html_09d2a648e6e192b4b67311da02e6638f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c990ee3cb8921ce7789c05312d3c3bb3.setContent(html_09d2a648e6e192b4b67311da02e6638f);
#
#
#
#         marker_189e5ea7944a155efdb7d2de146ab4dc.bindPopup(popup_c990ee3cb8921ce7789c05312d3c3bb3)
#         ;
#
#
#
#
#             var marker_b0b07b01fa325fcc874cd4a66b716ece = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_76815a5b4f9ae9fa5b2ef3e66d5ba49c);
#
#
#         var popup_c1e8a2a15ff4705fb79b422b3433e567 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfccfaa542e6553c76d54174b88d7b5c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfccfaa542e6553c76d54174b88d7b5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfccfaa542e6553c76d54174b88d7b5c = L.map(
#                 &quot;map_bfccfaa542e6553c76d54174b88d7b5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_990ce20d053eb1fbc189c4dfae12a230 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_990ce20d053eb1fbc189c4dfae12a230.addTo(map_bfccfaa542e6553c76d54174b88d7b5c);
#
#
#             var feature_group_5bcfafcb968c26796b47348c0f5cd09b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5bcfafcb968c26796b47348c0f5cd09b.addTo(map_bfccfaa542e6553c76d54174b88d7b5c);
#
#
#             var feature_group_sub_group_db7c85a55b1fa70d2c8d4b3694b5f570 = L.featureGroup.subGroup(
#                 feature_group_5bcfafcb968c26796b47348c0f5cd09b
#             );
#
#
#             var marker_4bf8758e958b5803c51284cc20d0aff3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_db7c85a55b1fa70d2c8d4b3694b5f570);
#
#
#         var popup_025dfff970017961cba7a7ba6be734bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b22988a0f900aa446c0cab9011cec40 = $(`&lt;div id=&quot;html_6b22988a0f900aa446c0cab9011cec40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_025dfff970017961cba7a7ba6be734bb.setContent(html_6b22988a0f900aa446c0cab9011cec40);
#
#
#
#         marker_4bf8758e958b5803c51284cc20d0aff3.bindPopup(popup_025dfff970017961cba7a7ba6be734bb)
#         ;
#
#
#
#
#             var marker_dae2679cfbf18d4522d622e37b326e19 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_db7c85a55b1fa70d2c8d4b3694b5f570);
#
#
#         var popup_6b7ffc4ed9c7be37a792aa2852a3dc29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c742ad5538f784fa30c48aee04d7da3 = $(`&lt;div id=&quot;html_2c742ad5538f784fa30c48aee04d7da3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6b7ffc4ed9c7be37a792aa2852a3dc29.setContent(html_2c742ad5538f784fa30c48aee04d7da3);
#
#
#
#         marker_dae2679cfbf18d4522d622e37b326e19.bindPopup(popup_6b7ffc4ed9c7be37a792aa2852a3dc29)
#         ;
#
#
#
#
#             var marker_a9e9010213fabbdae36c1d9bdcdc36a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_db7c85a55b1fa70d2c8d4b3694b5f570);
#
#
#         var popup_5dba9f674ced223decf1c348bc20fe94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82f09b576b155321e600af099765bdf6 = $(`&lt;div id=&quot;html_82f09b576b155321e600af099765bdf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5dba9f674ced223decf1c348bc20fe94.setContent(html_82f09b576b155321e600af099765bdf6);
#
#
#
#         marker_a9e9010213fabbdae36c1d9bdcdc36a4.bindPopup(popup_5dba9f674ced223decf1c348bc20fe94)
#         ;
#
#
#
#
#             var marker_2d8e24a6365ed14dde66e7b18dff03f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_db7c85a55b1fa70d2c8d4b3694b5f570);
#
#
#         var popup_a4c7d9d865240cd76cb7ada746be5df0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fe9493cf7c36dc6e217e1e880c60b04 = $(`&lt;div id=&quot;html_3fe9493cf7c36dc6e217e1e880c60b04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a4c7d9d865240cd76cb7ada746be5df0.setContent(html_3fe9493cf7c36dc6e217e1e880c60b04);
#
#
#
#         mark
