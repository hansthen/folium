# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9949c3df38f3736656a238502a0041d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9949c3df38f3736656a238502a0041d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9949c3df38f3736656a238502a0041d = L.map(
#                 &quot;map_e9949c3df38f3736656a238502a0041d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a24c07bb8df92fd2edf814e6f4e9f141 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a24c07bb8df92fd2edf814e6f4e9f141.addTo(map_e9949c3df38f3736656a238502a0041d);
#
#
#             var marker_822fc63bcb59f8d40d717436f35420fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e9949c3df38f3736656a238502a0041d);
#
#
#         var popup_e54ad42a2c7c1c8acae07802dd5fd1c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_886bbf4121034a41186dffccf1883c5f = $(`&lt;div id=&quot;html_886bbf4121034a41186dffccf1883c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e54ad42a2c7c1c8acae07802dd5fd1c2.setContent(html_886bbf4121034a41186dffccf1883c5f);
#
#
#
#         marker_822fc63bcb59f8d40d717436f35420fd.bindPopup(popup_e54ad42a2c7c1c8acae07802dd5fd1c2)
#         ;
#
#
#
#
#             var marker_81b3d572039d389eede2386386dba5bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e9949c3df38f3736656a238502a0041d);
#
#
#         var popup_0b283e39d3a11abb1c5d76b16d367290 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_361c55085b051d9fcd2a7b52e56c2b35 = $(`&lt;div id=&quot;html_361c55085b051d9fcd2a7b52e56c2b35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b283e39d3a11abb1c5d76b16d367290.setContent(html_361c55085b051d9fcd2a7b52e56c2b35);
#
#
#
#         marker_81b3d572039d389eede2386386dba5bf.bindPopup(popup_0b283e39d3a11abb1c5d76b16d367290)
#         ;
#
#
#
#
#             var marker_e1a501f73de721396ebdf963888057f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e9949c3df38f3736656a238502a0041d);
#
#
#         var popup_91542c7c04ccb24efaa2ba9a43bf5343 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bc9f965f191a482dff345c2ae45586c = $(`&lt;div id=&quot;html_1bc9f965f191a482dff345c2ae45586c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_91542c7c04ccb24efaa2ba9a43bf5343.setContent(html_1bc9f965f191a482dff345c2ae45586c);
#
#
#
#         marker_e1a501f73de721396ebdf963888057f3.bindPopup(popup_91542c7c04ccb24efaa2ba9a43bf5343)
#         ;
#
#
#
#
#             var marker_5497fde20611900f2944bab56c1b3940 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e9949c3df38f3736656a238502a0041d);
#
#
#         var popup_ad803cf86ea90d8449ebfe04ac89bc20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49ab5234faf425b75da373c6a1ad0df3 = $(`&lt;div id=&quot;html_49ab5234faf425b75da373c6a1ad0df3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ad803cf86ea90d8449ebfe04ac89bc20.setContent(html_49ab5234faf425b75da373c6a1ad0df3);
#
#
#
#         marker_5497fde20611900f2944bab56c1b3940.bindPopup(popup_ad803cf86ea90d8449ebfe04ac89bc20)
#         ;
#
#
#
#
#             var marker_bc4e466e5460707ec82e7d4f71247850 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e9949c3df38f3736656a238502a0041d);
#
#
#         var popup_f357125ca1ae17aaf4efa4f21f9305d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_267c2e273c29d7b985ef56a0c68fbd10 = $(`&lt;div id=&quot;html_267c2e273c29d7b985ef56a0c68fbd10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f357125ca1ae17aaf4efa4f21f9305d1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f6aaf7a97a3adbc3eb3a63e880c3cdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f6aaf7a97a3adbc3eb3a63e880c3cdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f6aaf7a97a3adbc3eb3a63e880c3cdd = L.map(
#                 &quot;map_5f6aaf7a97a3adbc3eb3a63e880c3cdd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6be4f06c32bfabc37fd61257d348bbb5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6be4f06c32bfabc37fd61257d348bbb5.addTo(map_5f6aaf7a97a3adbc3eb3a63e880c3cdd);
#
#
#             var feature_group_633901db03a540b247f8263e69bc8785 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e422be5cb635e5b63660445d6379853c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_633901db03a540b247f8263e69bc8785);
#
#
#         var popup_a250afedd086a6157fc2e267caf6856a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f70e620f94264d9a1544af1ff721bded = $(`&lt;div id=&quot;html_f70e620f94264d9a1544af1ff721bded&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a250afedd086a6157fc2e267caf6856a.setContent(html_f70e620f94264d9a1544af1ff721bded);
#
#
#
#         marker_e422be5cb635e5b63660445d6379853c.bindPopup(popup_a250afedd086a6157fc2e267caf6856a)
#         ;
#
#
#
#
#             var marker_9272889032a2d02809326762bfe0082b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_633901db03a540b247f8263e69bc8785);
#
#
#         var popup_b1be345ad6202e88e19d212fcbd2d540 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_827ce40361dd875dcd1e4aafa9a3b53e = $(`&lt;div id=&quot;html_827ce40361dd875dcd1e4aafa9a3b53e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b1be345ad6202e88e19d212fcbd2d540.setContent(html_827ce40361dd875dcd1e4aafa9a3b53e);
#
#
#
#         marker_9272889032a2d02809326762bfe0082b.bindPopup(popup_b1be345ad6202e88e19d212fcbd2d540)
#         ;
#
#
#
#
#             var marker_e69fb26ff995fe2223396d1d04367a3c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_633901db03a540b247f8263e69bc8785);
#
#
#         var popup_b513e8ca87e0d30fa1faa86f26a62c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caa7f97752e95bcf7a8e5ff53124b881 = $(`&lt;div id=&quot;html_caa7f97752e95bcf7a8e5ff53124b881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b513e8ca87e0d30fa1faa86f26a62c09.setContent(html_caa7f97752e95bcf7a8e5ff53124b881);
#
#
#
#         marker_e69fb26ff995fe2223396d1d04367a3c.bindPopup(popup_b513e8ca87e0d30fa1faa86f26a62c09)
#         ;
#
#
#
#
#             var marker_da2d5eec4b38176948a9557946a74552 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_633901db03a540b247f8263e69bc8785);
#
#
#         var popup_b0e3de8f5c910b5f87f8d1821a30524c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bb9223f21b4887b8918944656249e2a = $(`&lt;div id=&quot;html_1bb9223f21b4887b8918944656249e2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b0e3de8f5c910b5f87f8d1821a30524c.setContent(html_1bb9223f21b4887b8918944656249e2a);
#
#
#
#         marker_da2d5eec4b38176948a9557946a74552.bindPopup(popup_b0e3de8f5c910b5f87f8d1821a30524c)
#         ;
#
#
#
#
#             var marker_fdda1e462504a7eba6d0be66e7c27994 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_633901db03a540b247f8263e69bc8785);
#
#
#         var popup_3a71872db5f3d6e9d0f86bb42c909b69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c002c5094f9f0d70c6702c7c9dea7b70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c002c5094f9f0d70c6702c7c9dea7b70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c002c5094f9f0d70c6702c7c9dea7b70 = L.map(
#                 &quot;map_c002c5094f9f0d70c6702c7c9dea7b70&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2ac38bfaf14e65b903cbf13f343c9a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2ac38bfaf14e65b903cbf13f343c9a2.addTo(map_c002c5094f9f0d70c6702c7c9dea7b70);
#
#
#             var feature_group_b94e52217993c41b47ed1a962cc7ad38 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b94e52217993c41b47ed1a962cc7ad38.addTo(map_c002c5094f9f0d70c6702c7c9dea7b70);
#
#
#             var feature_group_sub_group_6c45bd8d4f7a7fc3f686b7d88308f5e8 = L.featureGroup.subGroup(
#                 feature_group_b94e52217993c41b47ed1a962cc7ad38
#             );
#
#
#             var marker_fc09b41b5420089ed9ce1276b82bbd52 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c45bd8d4f7a7fc3f686b7d88308f5e8);
#
#
#         var popup_6513360eb5a0f7db574d46cc14b27562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f718f88daf9d2a78ecd596f26578894b = $(`&lt;div id=&quot;html_f718f88daf9d2a78ecd596f26578894b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6513360eb5a0f7db574d46cc14b27562.setContent(html_f718f88daf9d2a78ecd596f26578894b);
#
#
#
#         marker_fc09b41b5420089ed9ce1276b82bbd52.bindPopup(popup_6513360eb5a0f7db574d46cc14b27562)
#         ;
#
#
#
#
#             var marker_f1ea79e7746dd131ed63dbde5245f6f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c45bd8d4f7a7fc3f686b7d88308f5e8);
#
#
#         var popup_a74edc4cd0ad9988366771c52c527105 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97c00e12718267e67e32548601f0ec43 = $(`&lt;div id=&quot;html_97c00e12718267e67e32548601f0ec43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a74edc4cd0ad9988366771c52c527105.setContent(html_97c00e12718267e67e32548601f0ec43);
#
#
#
#         marker_f1ea79e7746dd131ed63dbde5245f6f9.bindPopup(popup_a74edc4cd0ad9988366771c52c527105)
#         ;
#
#
#
#
#             var marker_d572fdfec888bd2ffc4df375de0bbb23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c45bd8d4f7a7fc3f686b7d88308f5e8);
#
#
#         var popup_9bc9babe53bd213486140ea545dc36b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e7a81de90c1d432b814a43b8d2c08ed = $(`&lt;div id=&quot;html_6e7a81de90c1d432b814a43b8d2c08ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9bc9babe53bd213486140ea545dc36b6.setContent(html_6e7a81de90c1d432b814a43b8d2c08ed);
#
#
#
#         marker_d572fdfec888bd2ffc4df375de0bbb23.bindPopup(popup_9bc9babe53bd213486140ea545dc36b6)
#         ;
#
#
#
#
#             var marker_5431eb6c5904a71982a69f7077f59dbe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c45bd8d4f7a7fc3f686b7d88308f5e8);
#
#
#         var popup_1e43a630d62bb8f74f3119fc26ce995b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24666b8d5415d0a86ee5a8423c368cda = $(`&lt;div id=&quot;html_24666b8d5415d0a86ee5a8423c368cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1e43a630d62bb8f74f3119fc26ce995b.setContent(html_24666b8d5415d0a86ee5a8423c368cda);
#
#
#
#         marker_
