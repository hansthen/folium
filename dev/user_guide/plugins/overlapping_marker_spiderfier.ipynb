# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08037c84919a7c934a5f18cfcf0d5421 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08037c84919a7c934a5f18cfcf0d5421&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08037c84919a7c934a5f18cfcf0d5421 = L.map(
#                 &quot;map_08037c84919a7c934a5f18cfcf0d5421&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a38e1558dd0f496e25b743d789bfb9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a38e1558dd0f496e25b743d789bfb9a.addTo(map_08037c84919a7c934a5f18cfcf0d5421);
#
#
#             var marker_e649f92e5cf8137f82a1fa4236fce54d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_08037c84919a7c934a5f18cfcf0d5421);
#
#
#         var popup_beebf2574670e9a89156e2010065b6cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75f61ade7c631fbfa267417fcb27d7af = $(`&lt;div id=&quot;html_75f61ade7c631fbfa267417fcb27d7af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_beebf2574670e9a89156e2010065b6cc.setContent(html_75f61ade7c631fbfa267417fcb27d7af);
#
#
#
#         marker_e649f92e5cf8137f82a1fa4236fce54d.bindPopup(popup_beebf2574670e9a89156e2010065b6cc)
#         ;
#
#
#
#
#             var marker_456e7948aa7fa4d3c1220437e01dc41f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_08037c84919a7c934a5f18cfcf0d5421);
#
#
#         var popup_a7c2b63fc382953e6e6478c993703da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f6ef89f4bf07fef49516518710490a9 = $(`&lt;div id=&quot;html_8f6ef89f4bf07fef49516518710490a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a7c2b63fc382953e6e6478c993703da8.setContent(html_8f6ef89f4bf07fef49516518710490a9);
#
#
#
#         marker_456e7948aa7fa4d3c1220437e01dc41f.bindPopup(popup_a7c2b63fc382953e6e6478c993703da8)
#         ;
#
#
#
#
#             var marker_a264756c97bd176c1fa681cede0bd6f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_08037c84919a7c934a5f18cfcf0d5421);
#
#
#         var popup_400fab72f4f64adce782da2ddf29b462 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f66d9820e2ad153565044de87fec5683 = $(`&lt;div id=&quot;html_f66d9820e2ad153565044de87fec5683&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_400fab72f4f64adce782da2ddf29b462.setContent(html_f66d9820e2ad153565044de87fec5683);
#
#
#
#         marker_a264756c97bd176c1fa681cede0bd6f3.bindPopup(popup_400fab72f4f64adce782da2ddf29b462)
#         ;
#
#
#
#
#             var marker_258965d4aa056c9a2dd42c125735db21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_08037c84919a7c934a5f18cfcf0d5421);
#
#
#         var popup_233fb63d5af2f14d9c58e361f7df72fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_273a9eac8a9d0df8f87cc68aaab388f7 = $(`&lt;div id=&quot;html_273a9eac8a9d0df8f87cc68aaab388f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_233fb63d5af2f14d9c58e361f7df72fd.setContent(html_273a9eac8a9d0df8f87cc68aaab388f7);
#
#
#
#         marker_258965d4aa056c9a2dd42c125735db21.bindPopup(popup_233fb63d5af2f14d9c58e361f7df72fd)
#         ;
#
#
#
#
#             var marker_2dea8a197b65e8b8f23b1f2c25bbfcc2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_08037c84919a7c934a5f18cfcf0d5421);
#
#
#         var popup_ebc76f2ddc49e173fb6653f5b8e88fc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f178a5a89596ab051045efb83c44d27d = $(`&lt;div id=&quot;html_f178a5a89596ab051045efb83c44d27d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ebc76f2ddc49e173fb6653f5b8e88fc4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7eefc787d0edb709ff1c58658c217397 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7eefc787d0edb709ff1c58658c217397&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7eefc787d0edb709ff1c58658c217397 = L.map(
#                 &quot;map_7eefc787d0edb709ff1c58658c217397&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a49671d207a10bd213e6d4edc33528fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a49671d207a10bd213e6d4edc33528fc.addTo(map_7eefc787d0edb709ff1c58658c217397);
#
#
#             var feature_group_8c96d70d73c40be427ccc573791b405f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2282e61b1cec94c0a6efe195f0c84e18 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8c96d70d73c40be427ccc573791b405f);
#
#
#         var popup_edaadc468c4b08f5229fc73d9564204d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7cad02765696bb4df2ae9ef88fff372 = $(`&lt;div id=&quot;html_c7cad02765696bb4df2ae9ef88fff372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_edaadc468c4b08f5229fc73d9564204d.setContent(html_c7cad02765696bb4df2ae9ef88fff372);
#
#
#
#         marker_2282e61b1cec94c0a6efe195f0c84e18.bindPopup(popup_edaadc468c4b08f5229fc73d9564204d)
#         ;
#
#
#
#
#             var marker_44cd06603f7897084583904e0e6ff83e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8c96d70d73c40be427ccc573791b405f);
#
#
#         var popup_efc07bcac457447f69d38801965b119d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80d6a3930a4b8c98e8bb83060359b90f = $(`&lt;div id=&quot;html_80d6a3930a4b8c98e8bb83060359b90f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_efc07bcac457447f69d38801965b119d.setContent(html_80d6a3930a4b8c98e8bb83060359b90f);
#
#
#
#         marker_44cd06603f7897084583904e0e6ff83e.bindPopup(popup_efc07bcac457447f69d38801965b119d)
#         ;
#
#
#
#
#             var marker_943bb2401607cf321f50a80ddefcd94f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8c96d70d73c40be427ccc573791b405f);
#
#
#         var popup_a08a13e9ebb1f2d6ea11db37fba342fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93d1be81139de05738630c5807b3372 = $(`&lt;div id=&quot;html_f93d1be81139de05738630c5807b3372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a08a13e9ebb1f2d6ea11db37fba342fb.setContent(html_f93d1be81139de05738630c5807b3372);
#
#
#
#         marker_943bb2401607cf321f50a80ddefcd94f.bindPopup(popup_a08a13e9ebb1f2d6ea11db37fba342fb)
#         ;
#
#
#
#
#             var marker_d6a576bdf362ad8bdbe053d4d9f0f805 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8c96d70d73c40be427ccc573791b405f);
#
#
#         var popup_d4b184dfc211a7fd341d0ba3a41aba24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03c89d9ca0449d64b29304a4723923dd = $(`&lt;div id=&quot;html_03c89d9ca0449d64b29304a4723923dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d4b184dfc211a7fd341d0ba3a41aba24.setContent(html_03c89d9ca0449d64b29304a4723923dd);
#
#
#
#         marker_d6a576bdf362ad8bdbe053d4d9f0f805.bindPopup(popup_d4b184dfc211a7fd341d0ba3a41aba24)
#         ;
#
#
#
#
#             var marker_9cbfe39ea3b3a11dc8bec056eecced78 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8c96d70d73c40be427ccc573791b405f);
#
#
#         var popup_14c072b53ed48d20703b9ac58b845869 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80eb7307e3f752b47a77a93b347f9847 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80eb7307e3f752b47a77a93b347f9847&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80eb7307e3f752b47a77a93b347f9847 = L.map(
#                 &quot;map_80eb7307e3f752b47a77a93b347f9847&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_561cf8bc56591fd6f64cb0e3dcb8494e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_561cf8bc56591fd6f64cb0e3dcb8494e.addTo(map_80eb7307e3f752b47a77a93b347f9847);
#
#
#             var feature_group_3f24c1eaccf199aa5c8ec23778eff923 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3f24c1eaccf199aa5c8ec23778eff923.addTo(map_80eb7307e3f752b47a77a93b347f9847);
#
#
#             var feature_group_sub_group_6b8f1d0267b0cd3b158ef88b1fa365d9 = L.featureGroup.subGroup(
#                 feature_group_3f24c1eaccf199aa5c8ec23778eff923
#             );
#
#
#             var marker_3b7ea6ccef27e65264e34f2c8ca1ebc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b8f1d0267b0cd3b158ef88b1fa365d9);
#
#
#         var popup_6b56578027777e3f4609f3034d53c2cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_925eb4e41d2e9bdb8e60f010808aa3cc = $(`&lt;div id=&quot;html_925eb4e41d2e9bdb8e60f010808aa3cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6b56578027777e3f4609f3034d53c2cf.setContent(html_925eb4e41d2e9bdb8e60f010808aa3cc);
#
#
#
#         marker_3b7ea6ccef27e65264e34f2c8ca1ebc7.bindPopup(popup_6b56578027777e3f4609f3034d53c2cf)
#         ;
#
#
#
#
#             var marker_cb46111d18c3b5788e1903cff2146b59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b8f1d0267b0cd3b158ef88b1fa365d9);
#
#
#         var popup_666fd81772a873ff122c757d3851b617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_106b5d24582dc32159ba96eadc1cc964 = $(`&lt;div id=&quot;html_106b5d24582dc32159ba96eadc1cc964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_666fd81772a873ff122c757d3851b617.setContent(html_106b5d24582dc32159ba96eadc1cc964);
#
#
#
#         marker_cb46111d18c3b5788e1903cff2146b59.bindPopup(popup_666fd81772a873ff122c757d3851b617)
#         ;
#
#
#
#
#             var marker_223e4b9ff9c3e21d5290901b1afbfc99 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b8f1d0267b0cd3b158ef88b1fa365d9);
#
#
#         var popup_db10a98a14a6d4c974b4b99e4640ca4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd7aaa41c2b8dfd6b08e283dc1eae52 = $(`&lt;div id=&quot;html_9bd7aaa41c2b8dfd6b08e283dc1eae52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_db10a98a14a6d4c974b4b99e4640ca4c.setContent(html_9bd7aaa41c2b8dfd6b08e283dc1eae52);
#
#
#
#         marker_223e4b9ff9c3e21d5290901b1afbfc99.bindPopup(popup_db10a98a14a6d4c974b4b99e4640ca4c)
#         ;
#
#
#
#
#             var marker_1f847921fa94f06f7dffbbc1bd66a40f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b8f1d0267b0cd3b158ef88b1fa365d9);
#
#
#         var popup_86202d183bcaecd38c4eeea621c38982 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bac1fb6d870bbb9e1b33c5228bde0ac = $(`&lt;div id=&quot;html_9bac1fb6d870bbb9e1b33c5228bde0ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_86202d183bcaecd38c4eeea621c38982.setContent(html_9bac1fb6d870bbb9e1b33c5228bde0ac);
#
#
#
#         marker_
