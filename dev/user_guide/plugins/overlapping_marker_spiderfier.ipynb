# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aba546b1d8161c46280ea848682c90d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aba546b1d8161c46280ea848682c90d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aba546b1d8161c46280ea848682c90d2 = L.map(
#                 &quot;map_aba546b1d8161c46280ea848682c90d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72cb046be2973d3bb881cedef96228ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72cb046be2973d3bb881cedef96228ae.addTo(map_aba546b1d8161c46280ea848682c90d2);
#
#
#             var marker_a1688bf35af9c899e484af02c374daed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aba546b1d8161c46280ea848682c90d2);
#
#
#         var popup_8ab792939f72f37651d2f698b49d2c61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68f908b1d30b75ff2b4a563610f86989 = $(`&lt;div id=&quot;html_68f908b1d30b75ff2b4a563610f86989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8ab792939f72f37651d2f698b49d2c61.setContent(html_68f908b1d30b75ff2b4a563610f86989);
#
#
#
#         marker_a1688bf35af9c899e484af02c374daed.bindPopup(popup_8ab792939f72f37651d2f698b49d2c61)
#         ;
#
#
#
#
#             var marker_595dbaa57040669728a9364c05e6b9e9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aba546b1d8161c46280ea848682c90d2);
#
#
#         var popup_a817176e037b0a73ea28c1eece6e0a14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24401253d84137cf42545fc3dde63f04 = $(`&lt;div id=&quot;html_24401253d84137cf42545fc3dde63f04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a817176e037b0a73ea28c1eece6e0a14.setContent(html_24401253d84137cf42545fc3dde63f04);
#
#
#
#         marker_595dbaa57040669728a9364c05e6b9e9.bindPopup(popup_a817176e037b0a73ea28c1eece6e0a14)
#         ;
#
#
#
#
#             var marker_44f8955277d3a8d542d0eb64d2ab7e95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aba546b1d8161c46280ea848682c90d2);
#
#
#         var popup_c6c15858539c95f564343ea3a1362a10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_868a427b53521b2ea7a05c411b85c9ad = $(`&lt;div id=&quot;html_868a427b53521b2ea7a05c411b85c9ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c6c15858539c95f564343ea3a1362a10.setContent(html_868a427b53521b2ea7a05c411b85c9ad);
#
#
#
#         marker_44f8955277d3a8d542d0eb64d2ab7e95.bindPopup(popup_c6c15858539c95f564343ea3a1362a10)
#         ;
#
#
#
#
#             var marker_0d782ca65743eb7c02d110d8d479ffe9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aba546b1d8161c46280ea848682c90d2);
#
#
#         var popup_dd50c9173bf94a241b6dc71dc8175eb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5027e2e479df67bc6d726a0cc281c7e0 = $(`&lt;div id=&quot;html_5027e2e479df67bc6d726a0cc281c7e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dd50c9173bf94a241b6dc71dc8175eb8.setContent(html_5027e2e479df67bc6d726a0cc281c7e0);
#
#
#
#         marker_0d782ca65743eb7c02d110d8d479ffe9.bindPopup(popup_dd50c9173bf94a241b6dc71dc8175eb8)
#         ;
#
#
#
#
#             var marker_7066a20d60607b06fd2bb9d275be2b71 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aba546b1d8161c46280ea848682c90d2);
#
#
#         var popup_9493b20b819be7cda03a24b5cd414a9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_819350a65c8d701f4da1174835397e57 = $(`&lt;div id=&quot;html_819350a65c8d701f4da1174835397e57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9493b20b819be7cda03a24b5cd414a9f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bed5a764ebc8226205d8c71452c322c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bed5a764ebc8226205d8c71452c322c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bed5a764ebc8226205d8c71452c322c4 = L.map(
#                 &quot;map_bed5a764ebc8226205d8c71452c322c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18a194f73460372ed7a05d6242adaf91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18a194f73460372ed7a05d6242adaf91.addTo(map_bed5a764ebc8226205d8c71452c322c4);
#
#
#             var feature_group_83ce9543226a9d0195a714a70e43b5ce = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_27d1579ba72331aacdf7dbe8e3cddf7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_83ce9543226a9d0195a714a70e43b5ce);
#
#
#         var popup_08c82b6cc183871e22edf229d31f31a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c15dde55c6516cff13be39cdab209d0 = $(`&lt;div id=&quot;html_5c15dde55c6516cff13be39cdab209d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_08c82b6cc183871e22edf229d31f31a0.setContent(html_5c15dde55c6516cff13be39cdab209d0);
#
#
#
#         marker_27d1579ba72331aacdf7dbe8e3cddf7e.bindPopup(popup_08c82b6cc183871e22edf229d31f31a0)
#         ;
#
#
#
#
#             var marker_aeecf8f752acbeec905338ed3e5324db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_83ce9543226a9d0195a714a70e43b5ce);
#
#
#         var popup_ef248b2d65dd35e2960d8dac9a084f14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68cfe7358b36d0a0370ad0ef731103d4 = $(`&lt;div id=&quot;html_68cfe7358b36d0a0370ad0ef731103d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ef248b2d65dd35e2960d8dac9a084f14.setContent(html_68cfe7358b36d0a0370ad0ef731103d4);
#
#
#
#         marker_aeecf8f752acbeec905338ed3e5324db.bindPopup(popup_ef248b2d65dd35e2960d8dac9a084f14)
#         ;
#
#
#
#
#             var marker_65ea947fdd105e1511652c66562da88c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_83ce9543226a9d0195a714a70e43b5ce);
#
#
#         var popup_89485387b59758496444fdc4789075f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3177ba7b568cd9bf6a51df2a3acdecbc = $(`&lt;div id=&quot;html_3177ba7b568cd9bf6a51df2a3acdecbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_89485387b59758496444fdc4789075f9.setContent(html_3177ba7b568cd9bf6a51df2a3acdecbc);
#
#
#
#         marker_65ea947fdd105e1511652c66562da88c.bindPopup(popup_89485387b59758496444fdc4789075f9)
#         ;
#
#
#
#
#             var marker_7c4e082f159dd08f7c3dd7e2e4390722 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_83ce9543226a9d0195a714a70e43b5ce);
#
#
#         var popup_c2ec38302a687eecbe59da2fb94ce0d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9537f633320ab7a5fef63c5523c13279 = $(`&lt;div id=&quot;html_9537f633320ab7a5fef63c5523c13279&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c2ec38302a687eecbe59da2fb94ce0d9.setContent(html_9537f633320ab7a5fef63c5523c13279);
#
#
#
#         marker_7c4e082f159dd08f7c3dd7e2e4390722.bindPopup(popup_c2ec38302a687eecbe59da2fb94ce0d9)
#         ;
#
#
#
#
#             var marker_6c2e1ac03f37ca6857392f84e156bf2e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_83ce9543226a9d0195a714a70e43b5ce);
#
#
#         var popup_3bc6c2fb583bdefd6a251a39aa4cdb6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1128e0824d930cf5ccb1bd20e69df16a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1128e0824d930cf5ccb1bd20e69df16a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1128e0824d930cf5ccb1bd20e69df16a = L.map(
#                 &quot;map_1128e0824d930cf5ccb1bd20e69df16a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b2133863dfcd54e202d9f0113b16a29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b2133863dfcd54e202d9f0113b16a29.addTo(map_1128e0824d930cf5ccb1bd20e69df16a);
#
#
#             var feature_group_444188c3ad273e52fd5a75dc37f7c733 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_444188c3ad273e52fd5a75dc37f7c733.addTo(map_1128e0824d930cf5ccb1bd20e69df16a);
#
#
#             var feature_group_sub_group_27e967a6c7de96dd1d6b4636ea3c1a3f = L.featureGroup.subGroup(
#                 feature_group_444188c3ad273e52fd5a75dc37f7c733
#             );
#
#
#             var marker_5af0a894fc3be0e9335324bde20f26b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_27e967a6c7de96dd1d6b4636ea3c1a3f);
#
#
#         var popup_83ffad9ab1d404562cf0ab693df1c186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_349ff5c242d7cb384a8ff70587ef88e3 = $(`&lt;div id=&quot;html_349ff5c242d7cb384a8ff70587ef88e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_83ffad9ab1d404562cf0ab693df1c186.setContent(html_349ff5c242d7cb384a8ff70587ef88e3);
#
#
#
#         marker_5af0a894fc3be0e9335324bde20f26b0.bindPopup(popup_83ffad9ab1d404562cf0ab693df1c186)
#         ;
#
#
#
#
#             var marker_cba0f2bb3315f9e2d4af7fc6ad995114 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_27e967a6c7de96dd1d6b4636ea3c1a3f);
#
#
#         var popup_25946ad5c515e0390b73d0faae51ac2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5def29566f6a23da0011c217dec12c38 = $(`&lt;div id=&quot;html_5def29566f6a23da0011c217dec12c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_25946ad5c515e0390b73d0faae51ac2b.setContent(html_5def29566f6a23da0011c217dec12c38);
#
#
#
#         marker_cba0f2bb3315f9e2d4af7fc6ad995114.bindPopup(popup_25946ad5c515e0390b73d0faae51ac2b)
#         ;
#
#
#
#
#             var marker_0ccd1e70082d0148f10d55c30d36000a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_27e967a6c7de96dd1d6b4636ea3c1a3f);
#
#
#         var popup_7a01ab3ad22e4a8b76952193dac7933e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_322f8138be70dd9039f4193e10168eb4 = $(`&lt;div id=&quot;html_322f8138be70dd9039f4193e10168eb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7a01ab3ad22e4a8b76952193dac7933e.setContent(html_322f8138be70dd9039f4193e10168eb4);
#
#
#
#         marker_0ccd1e70082d0148f10d55c30d36000a.bindPopup(popup_7a01ab3ad22e4a8b76952193dac7933e)
#         ;
#
#
#
#
#             var marker_a9979421a08541380d6da680c22c0b2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_27e967a6c7de96dd1d6b4636ea3c1a3f);
#
#
#         var popup_e77fbe70bba28eef55499e120daddac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e83746602355a37987b6bca16bc554f = $(`&lt;div id=&quot;html_3e83746602355a37987b6bca16bc554f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e77fbe70bba28eef55499e120daddac9.setContent(html_3e83746602355a37987b6bca16bc554f);
#
#
#
#         marker_
