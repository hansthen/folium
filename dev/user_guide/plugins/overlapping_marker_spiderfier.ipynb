# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aaa4eb7314d4e0a5ab895420370c7b11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aaa4eb7314d4e0a5ab895420370c7b11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aaa4eb7314d4e0a5ab895420370c7b11 = L.map(
#                 &quot;map_aaa4eb7314d4e0a5ab895420370c7b11&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4ae2c1a2de11661a88c4cba32150a66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4ae2c1a2de11661a88c4cba32150a66.addTo(map_aaa4eb7314d4e0a5ab895420370c7b11);
#
#
#             var marker_4013c5f2ae2524224598966902581a7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aaa4eb7314d4e0a5ab895420370c7b11);
#
#
#         var popup_b6267a6c4467c0eecd2306f08d1f67dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5246983ff57576bc6564d68012df769d = $(`&lt;div id=&quot;html_5246983ff57576bc6564d68012df769d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b6267a6c4467c0eecd2306f08d1f67dc.setContent(html_5246983ff57576bc6564d68012df769d);
#
#
#
#         marker_4013c5f2ae2524224598966902581a7b.bindPopup(popup_b6267a6c4467c0eecd2306f08d1f67dc)
#         ;
#
#
#
#
#             var marker_c34d8ed7537edad80d672b3c0edb9c70 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aaa4eb7314d4e0a5ab895420370c7b11);
#
#
#         var popup_c2b477714b417393555ca84181bce94d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_714e649a96aa29681355079f6f40d373 = $(`&lt;div id=&quot;html_714e649a96aa29681355079f6f40d373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c2b477714b417393555ca84181bce94d.setContent(html_714e649a96aa29681355079f6f40d373);
#
#
#
#         marker_c34d8ed7537edad80d672b3c0edb9c70.bindPopup(popup_c2b477714b417393555ca84181bce94d)
#         ;
#
#
#
#
#             var marker_46dca153fc480400e5213ca5ab1229dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aaa4eb7314d4e0a5ab895420370c7b11);
#
#
#         var popup_3d1d5e2f2a7cec5f809743bacf27d07b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f51009ebc9693e7be29d18c46388b4bf = $(`&lt;div id=&quot;html_f51009ebc9693e7be29d18c46388b4bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3d1d5e2f2a7cec5f809743bacf27d07b.setContent(html_f51009ebc9693e7be29d18c46388b4bf);
#
#
#
#         marker_46dca153fc480400e5213ca5ab1229dc.bindPopup(popup_3d1d5e2f2a7cec5f809743bacf27d07b)
#         ;
#
#
#
#
#             var marker_62166ffaad456d7ffaa3a956c6e378ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aaa4eb7314d4e0a5ab895420370c7b11);
#
#
#         var popup_18a15e2a2c98d4d2704bd099fe1aaacc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7499f605929a604cdbdb4f347d1685d3 = $(`&lt;div id=&quot;html_7499f605929a604cdbdb4f347d1685d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18a15e2a2c98d4d2704bd099fe1aaacc.setContent(html_7499f605929a604cdbdb4f347d1685d3);
#
#
#
#         marker_62166ffaad456d7ffaa3a956c6e378ac.bindPopup(popup_18a15e2a2c98d4d2704bd099fe1aaacc)
#         ;
#
#
#
#
#             var marker_358141a2f305c60f415380ba59f3bcd6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aaa4eb7314d4e0a5ab895420370c7b11);
#
#
#         var popup_bc1b00906e3e6890c1da93e9b5f7f0ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3abdfbaed47f3bd785042f18614ad5b = $(`&lt;div id=&quot;html_f3abdfbaed47f3bd785042f18614ad5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bc1b00906e3e6890c1da93e9b5f7f0ae.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79cd1ab091b35eb66153e7452479bb78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79cd1ab091b35eb66153e7452479bb78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79cd1ab091b35eb66153e7452479bb78 = L.map(
#                 &quot;map_79cd1ab091b35eb66153e7452479bb78&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c08e246a25f219ee5b95000123ee782 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c08e246a25f219ee5b95000123ee782.addTo(map_79cd1ab091b35eb66153e7452479bb78);
#
#
#             var feature_group_7a4c7cf54062f6dac02a2455a64c085a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_69aaf5508ef6c2dc281523816423ad78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7a4c7cf54062f6dac02a2455a64c085a);
#
#
#         var popup_cc2ba97127695fd9f9945eea5b631295 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec4127932ee90ac714aad24ebebfdec2 = $(`&lt;div id=&quot;html_ec4127932ee90ac714aad24ebebfdec2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cc2ba97127695fd9f9945eea5b631295.setContent(html_ec4127932ee90ac714aad24ebebfdec2);
#
#
#
#         marker_69aaf5508ef6c2dc281523816423ad78.bindPopup(popup_cc2ba97127695fd9f9945eea5b631295)
#         ;
#
#
#
#
#             var marker_5885243570c0fae96a7bbf3926b2e345 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7a4c7cf54062f6dac02a2455a64c085a);
#
#
#         var popup_4a321478038fd06fb9cb50b9583327e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d51d9c5a8e14b16188a59b25a405221 = $(`&lt;div id=&quot;html_5d51d9c5a8e14b16188a59b25a405221&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4a321478038fd06fb9cb50b9583327e3.setContent(html_5d51d9c5a8e14b16188a59b25a405221);
#
#
#
#         marker_5885243570c0fae96a7bbf3926b2e345.bindPopup(popup_4a321478038fd06fb9cb50b9583327e3)
#         ;
#
#
#
#
#             var marker_ebb89bed9e823c16ba0ca1ebe3ac6d57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7a4c7cf54062f6dac02a2455a64c085a);
#
#
#         var popup_7be1e0782a8a3aff2ee213ac693ac8d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_812b7e0ec15d844e7a92f11ae50494f2 = $(`&lt;div id=&quot;html_812b7e0ec15d844e7a92f11ae50494f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7be1e0782a8a3aff2ee213ac693ac8d8.setContent(html_812b7e0ec15d844e7a92f11ae50494f2);
#
#
#
#         marker_ebb89bed9e823c16ba0ca1ebe3ac6d57.bindPopup(popup_7be1e0782a8a3aff2ee213ac693ac8d8)
#         ;
#
#
#
#
#             var marker_67095334fef2ae34191dfb8c0fcf97fb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7a4c7cf54062f6dac02a2455a64c085a);
#
#
#         var popup_0ef00a113521f773b1e57a413f3a90ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e46870f5a6d92e61f986c63a5ccfae67 = $(`&lt;div id=&quot;html_e46870f5a6d92e61f986c63a5ccfae67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0ef00a113521f773b1e57a413f3a90ca.setContent(html_e46870f5a6d92e61f986c63a5ccfae67);
#
#
#
#         marker_67095334fef2ae34191dfb8c0fcf97fb.bindPopup(popup_0ef00a113521f773b1e57a413f3a90ca)
#         ;
#
#
#
#
#             var marker_d7f8c57a5f02bd04a361df871048294e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7a4c7cf54062f6dac02a2455a64c085a);
#
#
#         var popup_acd05951dd7edf3456043b2349331400 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb78ae9a3fabb9d51afba12d6d461a93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb78ae9a3fabb9d51afba12d6d461a93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb78ae9a3fabb9d51afba12d6d461a93 = L.map(
#                 &quot;map_eb78ae9a3fabb9d51afba12d6d461a93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_274a47b3f8857fbb00203d90b44c7d6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_274a47b3f8857fbb00203d90b44c7d6e.addTo(map_eb78ae9a3fabb9d51afba12d6d461a93);
#
#
#             var feature_group_78e93e91ee56929eeaace66f14a586a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_78e93e91ee56929eeaace66f14a586a7.addTo(map_eb78ae9a3fabb9d51afba12d6d461a93);
#
#
#             var feature_group_sub_group_69d12648c0a8434df26ad1098a7381c8 = L.featureGroup.subGroup(
#                 feature_group_78e93e91ee56929eeaace66f14a586a7
#             );
#
#
#             var marker_beff3515ae8b04b554b1faed97eba3c9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_69d12648c0a8434df26ad1098a7381c8);
#
#
#         var popup_cc75b4c628da94f4328e2be1ca1b2385 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22e0482a2c0de4ba985cc6299dfb6609 = $(`&lt;div id=&quot;html_22e0482a2c0de4ba985cc6299dfb6609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cc75b4c628da94f4328e2be1ca1b2385.setContent(html_22e0482a2c0de4ba985cc6299dfb6609);
#
#
#
#         marker_beff3515ae8b04b554b1faed97eba3c9.bindPopup(popup_cc75b4c628da94f4328e2be1ca1b2385)
#         ;
#
#
#
#
#             var marker_d1188df53ebbebda65960fb248249219 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_69d12648c0a8434df26ad1098a7381c8);
#
#
#         var popup_42efbabcd4158b23655111c27f3a9917 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daa30bb4648bce58b8b6e542fb9797b3 = $(`&lt;div id=&quot;html_daa30bb4648bce58b8b6e542fb9797b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_42efbabcd4158b23655111c27f3a9917.setContent(html_daa30bb4648bce58b8b6e542fb9797b3);
#
#
#
#         marker_d1188df53ebbebda65960fb248249219.bindPopup(popup_42efbabcd4158b23655111c27f3a9917)
#         ;
#
#
#
#
#             var marker_d8b48bd9a315740130d75811d3a9aacc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_69d12648c0a8434df26ad1098a7381c8);
#
#
#         var popup_f38d1499ec51bd42f6e70442b914e8e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c0bb81e66acc8020e1d01d6c5205887 = $(`&lt;div id=&quot;html_9c0bb81e66acc8020e1d01d6c5205887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f38d1499ec51bd42f6e70442b914e8e1.setContent(html_9c0bb81e66acc8020e1d01d6c5205887);
#
#
#
#         marker_d8b48bd9a315740130d75811d3a9aacc.bindPopup(popup_f38d1499ec51bd42f6e70442b914e8e1)
#         ;
#
#
#
#
#             var marker_96f607319aabdb6227a4d47d1d6d9bf5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_69d12648c0a8434df26ad1098a7381c8);
#
#
#         var popup_6f266f91cc0b4a898adec542d4603258 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6225f841aa9be39d058b998cb31ac17e = $(`&lt;div id=&quot;html_6225f841aa9be39d058b998cb31ac17e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6f266f91cc0b4a898adec542d4603258.setContent(html_6225f841aa9be39d058b998cb31ac17e);
#
#
#
#         marker_
