# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b570eb4a8c7d19aed9e2725cf898fba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b570eb4a8c7d19aed9e2725cf898fba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b570eb4a8c7d19aed9e2725cf898fba = L.map(
#                 &quot;map_0b570eb4a8c7d19aed9e2725cf898fba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf681065c96b53f6a83d106440c23ba3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf681065c96b53f6a83d106440c23ba3.addTo(map_0b570eb4a8c7d19aed9e2725cf898fba);
#
#
#             var marker_2ea5d7ca0b60da13db9a1525a996f40a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0b570eb4a8c7d19aed9e2725cf898fba);
#
#
#         var popup_9020d9614ad47929b9eb3f41ef300e59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a96ca584516f2cf7c16563d810865979 = $(`&lt;div id=&quot;html_a96ca584516f2cf7c16563d810865979&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9020d9614ad47929b9eb3f41ef300e59.setContent(html_a96ca584516f2cf7c16563d810865979);
#
#
#
#         marker_2ea5d7ca0b60da13db9a1525a996f40a.bindPopup(popup_9020d9614ad47929b9eb3f41ef300e59)
#         ;
#
#
#
#
#             var marker_58303fdd7981170ef0b8e5221604f502 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0b570eb4a8c7d19aed9e2725cf898fba);
#
#
#         var popup_222df9fe07bd1bbbcfc15be308ab0d21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55d1d8323e9882cc8f98f5a8958d5526 = $(`&lt;div id=&quot;html_55d1d8323e9882cc8f98f5a8958d5526&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_222df9fe07bd1bbbcfc15be308ab0d21.setContent(html_55d1d8323e9882cc8f98f5a8958d5526);
#
#
#
#         marker_58303fdd7981170ef0b8e5221604f502.bindPopup(popup_222df9fe07bd1bbbcfc15be308ab0d21)
#         ;
#
#
#
#
#             var marker_c42711fe69b0fbddc2c785adf202cd5b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0b570eb4a8c7d19aed9e2725cf898fba);
#
#
#         var popup_b804e7d69fe5100c65e0bf80866783c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24330cfbbbf586ca9ed321a877802bf8 = $(`&lt;div id=&quot;html_24330cfbbbf586ca9ed321a877802bf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b804e7d69fe5100c65e0bf80866783c8.setContent(html_24330cfbbbf586ca9ed321a877802bf8);
#
#
#
#         marker_c42711fe69b0fbddc2c785adf202cd5b.bindPopup(popup_b804e7d69fe5100c65e0bf80866783c8)
#         ;
#
#
#
#
#             var marker_aa3383c41bdc6546fc8a70db54d7962f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0b570eb4a8c7d19aed9e2725cf898fba);
#
#
#         var popup_d456cb931b987b964c21fd642bd196f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8c4e4e8c35965f55d4c52675deab5e7 = $(`&lt;div id=&quot;html_e8c4e4e8c35965f55d4c52675deab5e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d456cb931b987b964c21fd642bd196f2.setContent(html_e8c4e4e8c35965f55d4c52675deab5e7);
#
#
#
#         marker_aa3383c41bdc6546fc8a70db54d7962f.bindPopup(popup_d456cb931b987b964c21fd642bd196f2)
#         ;
#
#
#
#
#             var marker_3d3ec0ec5a958b06a70e04425c0bd7be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0b570eb4a8c7d19aed9e2725cf898fba);
#
#
#         var popup_dd3e5fd8bcde6ca7afb66478511b9453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8540ea487efb52793f5218575c8451f1 = $(`&lt;div id=&quot;html_8540ea487efb52793f5218575c8451f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dd3e5fd8bcde6ca7afb66478511b9453.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aeb24cedee71684d440b0410037c630d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aeb24cedee71684d440b0410037c630d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aeb24cedee71684d440b0410037c630d = L.map(
#                 &quot;map_aeb24cedee71684d440b0410037c630d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad1567dd3b53fc1154197673b1fe3ae8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad1567dd3b53fc1154197673b1fe3ae8.addTo(map_aeb24cedee71684d440b0410037c630d);
#
#
#             var feature_group_18b4af9b9cf9e907b1115d0befa4a7b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17c7fe977465269c411ef50ddbf95ef9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_18b4af9b9cf9e907b1115d0befa4a7b7);
#
#
#         var popup_e23ad3a0f18706f59cb8e43ad0dd44be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_429e48a472ca758acf7dd3b658867b41 = $(`&lt;div id=&quot;html_429e48a472ca758acf7dd3b658867b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e23ad3a0f18706f59cb8e43ad0dd44be.setContent(html_429e48a472ca758acf7dd3b658867b41);
#
#
#
#         marker_17c7fe977465269c411ef50ddbf95ef9.bindPopup(popup_e23ad3a0f18706f59cb8e43ad0dd44be)
#         ;
#
#
#
#
#             var marker_b7de3e7b084b6ca5907363b8acf46603 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_18b4af9b9cf9e907b1115d0befa4a7b7);
#
#
#         var popup_2529326e1fa36dfecf7dce97a10e5bbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4901470a2e623391c4d89cfb9ec4e0e = $(`&lt;div id=&quot;html_a4901470a2e623391c4d89cfb9ec4e0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2529326e1fa36dfecf7dce97a10e5bbd.setContent(html_a4901470a2e623391c4d89cfb9ec4e0e);
#
#
#
#         marker_b7de3e7b084b6ca5907363b8acf46603.bindPopup(popup_2529326e1fa36dfecf7dce97a10e5bbd)
#         ;
#
#
#
#
#             var marker_07bae665a1df58eb2ec6c115d187c16b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_18b4af9b9cf9e907b1115d0befa4a7b7);
#
#
#         var popup_bab53994dba6845aec5fe451b2e74a96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77e43438848968462f6ce2bc35b9cf1b = $(`&lt;div id=&quot;html_77e43438848968462f6ce2bc35b9cf1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bab53994dba6845aec5fe451b2e74a96.setContent(html_77e43438848968462f6ce2bc35b9cf1b);
#
#
#
#         marker_07bae665a1df58eb2ec6c115d187c16b.bindPopup(popup_bab53994dba6845aec5fe451b2e74a96)
#         ;
#
#
#
#
#             var marker_7ea00f9f6986d4893fc5dc8efc3f1462 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_18b4af9b9cf9e907b1115d0befa4a7b7);
#
#
#         var popup_e46141e6b9286480fe63c173e40cc36c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_790d13f481ac3852fc9b8979e3cb6c33 = $(`&lt;div id=&quot;html_790d13f481ac3852fc9b8979e3cb6c33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e46141e6b9286480fe63c173e40cc36c.setContent(html_790d13f481ac3852fc9b8979e3cb6c33);
#
#
#
#         marker_7ea00f9f6986d4893fc5dc8efc3f1462.bindPopup(popup_e46141e6b9286480fe63c173e40cc36c)
#         ;
#
#
#
#
#             var marker_91bc3176caf63bab675f6a89628552bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_18b4af9b9cf9e907b1115d0befa4a7b7);
#
#
#         var popup_f2d23828baa0e272f9554365218b1836 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894e84654c30da605392e444d3964d2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894e84654c30da605392e444d3964d2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894e84654c30da605392e444d3964d2f = L.map(
#                 &quot;map_894e84654c30da605392e444d3964d2f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ec0fe21a4f9e8bb74285c5ede0d4cb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ec0fe21a4f9e8bb74285c5ede0d4cb6.addTo(map_894e84654c30da605392e444d3964d2f);
#
#
#             var feature_group_e8b81e541c7945a3a2527e9caa9a3631 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e8b81e541c7945a3a2527e9caa9a3631.addTo(map_894e84654c30da605392e444d3964d2f);
#
#
#             var feature_group_sub_group_f28de4262c405755d82d2043e3c3a6b1 = L.featureGroup.subGroup(
#                 feature_group_e8b81e541c7945a3a2527e9caa9a3631
#             );
#
#
#             var marker_64d7431a747c974b1aa6997ee4a639ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f28de4262c405755d82d2043e3c3a6b1);
#
#
#         var popup_99d7e15232ef26f704168dc92a695e0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8155496636f1d41d3f5f443181c25dd9 = $(`&lt;div id=&quot;html_8155496636f1d41d3f5f443181c25dd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_99d7e15232ef26f704168dc92a695e0b.setContent(html_8155496636f1d41d3f5f443181c25dd9);
#
#
#
#         marker_64d7431a747c974b1aa6997ee4a639ff.bindPopup(popup_99d7e15232ef26f704168dc92a695e0b)
#         ;
#
#
#
#
#             var marker_223efc151fda951861dbb9f84f64ae61 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f28de4262c405755d82d2043e3c3a6b1);
#
#
#         var popup_26503a58e42ed52b9c86051f4e2b532f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_904d491848bd575a1d7a2ff7ffc49e6d = $(`&lt;div id=&quot;html_904d491848bd575a1d7a2ff7ffc49e6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_26503a58e42ed52b9c86051f4e2b532f.setContent(html_904d491848bd575a1d7a2ff7ffc49e6d);
#
#
#
#         marker_223efc151fda951861dbb9f84f64ae61.bindPopup(popup_26503a58e42ed52b9c86051f4e2b532f)
#         ;
#
#
#
#
#             var marker_3e0bc68e8b0c3cc6c55fd2218844107c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f28de4262c405755d82d2043e3c3a6b1);
#
#
#         var popup_9703fbc19f3c8f7da60fbfb522d5cd61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54772d44f96e59b9088d0f9c64c2bcca = $(`&lt;div id=&quot;html_54772d44f96e59b9088d0f9c64c2bcca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9703fbc19f3c8f7da60fbfb522d5cd61.setContent(html_54772d44f96e59b9088d0f9c64c2bcca);
#
#
#
#         marker_3e0bc68e8b0c3cc6c55fd2218844107c.bindPopup(popup_9703fbc19f3c8f7da60fbfb522d5cd61)
#         ;
#
#
#
#
#             var marker_0cc7b61be99f4a88811727fe5f760d0b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f28de4262c405755d82d2043e3c3a6b1);
#
#
#         var popup_a156151ea3244c98548a39a5aba3fc2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acf98b1ede51a591eab9feeac325bd01 = $(`&lt;div id=&quot;html_acf98b1ede51a591eab9feeac325bd01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a156151ea3244c98548a39a5aba3fc2d.setContent(html_acf98b1ede51a591eab9feeac325bd01);
#
#
#
#         marker_
