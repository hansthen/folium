# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6166812c0b99c0f6478d3c97ec26f688 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6166812c0b99c0f6478d3c97ec26f688&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6166812c0b99c0f6478d3c97ec26f688 = L.map(
#                 &quot;map_6166812c0b99c0f6478d3c97ec26f688&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed40a7c6470094dc6ee5d569ba2a6d87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed40a7c6470094dc6ee5d569ba2a6d87.addTo(map_6166812c0b99c0f6478d3c97ec26f688);
#
#
#             var marker_c59abfd0b41b94cd0bf21f45a94a581f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6166812c0b99c0f6478d3c97ec26f688);
#
#
#         var popup_a54f6aceea4c2d0981b93ca8600e5afb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0d8669b2674b180fce90de4d45ad2cb = $(`&lt;div id=&quot;html_c0d8669b2674b180fce90de4d45ad2cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a54f6aceea4c2d0981b93ca8600e5afb.setContent(html_c0d8669b2674b180fce90de4d45ad2cb);
#
#
#
#         marker_c59abfd0b41b94cd0bf21f45a94a581f.bindPopup(popup_a54f6aceea4c2d0981b93ca8600e5afb)
#         ;
#
#
#
#
#             var marker_5698156bcaab63b6ca1fe9b506f1253b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6166812c0b99c0f6478d3c97ec26f688);
#
#
#         var popup_24a74753a3c35eca86c130e3072a5905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bd9d0f489e1cd885c4246d6be6ff27e = $(`&lt;div id=&quot;html_8bd9d0f489e1cd885c4246d6be6ff27e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_24a74753a3c35eca86c130e3072a5905.setContent(html_8bd9d0f489e1cd885c4246d6be6ff27e);
#
#
#
#         marker_5698156bcaab63b6ca1fe9b506f1253b.bindPopup(popup_24a74753a3c35eca86c130e3072a5905)
#         ;
#
#
#
#
#             var marker_d81f6d0804770d9938136f8f96f32f2e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6166812c0b99c0f6478d3c97ec26f688);
#
#
#         var popup_e8bec941bcb04127d64fd2ede5b83531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a48cdc409aa1608fa119272ebe069f1b = $(`&lt;div id=&quot;html_a48cdc409aa1608fa119272ebe069f1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e8bec941bcb04127d64fd2ede5b83531.setContent(html_a48cdc409aa1608fa119272ebe069f1b);
#
#
#
#         marker_d81f6d0804770d9938136f8f96f32f2e.bindPopup(popup_e8bec941bcb04127d64fd2ede5b83531)
#         ;
#
#
#
#
#             var marker_edeb12d19f7b2b5ff91c6973ee030bd8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6166812c0b99c0f6478d3c97ec26f688);
#
#
#         var popup_537e6277e8c69794ce4635666d268da7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_095223e8a3bcecf41a04a0543bfa177a = $(`&lt;div id=&quot;html_095223e8a3bcecf41a04a0543bfa177a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_537e6277e8c69794ce4635666d268da7.setContent(html_095223e8a3bcecf41a04a0543bfa177a);
#
#
#
#         marker_edeb12d19f7b2b5ff91c6973ee030bd8.bindPopup(popup_537e6277e8c69794ce4635666d268da7)
#         ;
#
#
#
#
#             var marker_ba1df423d795a71e3d679288f1d6b81d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6166812c0b99c0f6478d3c97ec26f688);
#
#
#         var popup_b5fcadd486a9e48797ce7c27080e7da1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e56bd0aa71a4bf36e0899a28014a313b = $(`&lt;div id=&quot;html_e56bd0aa71a4bf36e0899a28014a313b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b5fcadd486a9e48797ce7c27080e7da1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_113956f1d568e2a13eb2635c4a7d7b72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_113956f1d568e2a13eb2635c4a7d7b72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_113956f1d568e2a13eb2635c4a7d7b72 = L.map(
#                 &quot;map_113956f1d568e2a13eb2635c4a7d7b72&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db102c5bfd78af6cb0272e161f6fef8f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db102c5bfd78af6cb0272e161f6fef8f.addTo(map_113956f1d568e2a13eb2635c4a7d7b72);
#
#
#             var feature_group_b1554d77f0c723b9636f398c8f008e5e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_79daeafe21c741e04b4b22221d78576e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b1554d77f0c723b9636f398c8f008e5e);
#
#
#         var popup_e4ce04e4425f1db4d9652978655d26f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2989e413b40fe3069bc625c5ebff87dc = $(`&lt;div id=&quot;html_2989e413b40fe3069bc625c5ebff87dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e4ce04e4425f1db4d9652978655d26f6.setContent(html_2989e413b40fe3069bc625c5ebff87dc);
#
#
#
#         marker_79daeafe21c741e04b4b22221d78576e.bindPopup(popup_e4ce04e4425f1db4d9652978655d26f6)
#         ;
#
#
#
#
#             var marker_0d8777f4df15e2e9cf701aa4374fa0ce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b1554d77f0c723b9636f398c8f008e5e);
#
#
#         var popup_5d1c72fd86930cb56cc7b20634054eac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61b4c7bd6b4c7e47e540dc7b366c0de7 = $(`&lt;div id=&quot;html_61b4c7bd6b4c7e47e540dc7b366c0de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5d1c72fd86930cb56cc7b20634054eac.setContent(html_61b4c7bd6b4c7e47e540dc7b366c0de7);
#
#
#
#         marker_0d8777f4df15e2e9cf701aa4374fa0ce.bindPopup(popup_5d1c72fd86930cb56cc7b20634054eac)
#         ;
#
#
#
#
#             var marker_34dced24cc3233bc2f9deebf7997d234 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b1554d77f0c723b9636f398c8f008e5e);
#
#
#         var popup_d3391518da6cd675e304e2f1fb8e9c8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_376c18723224c754ec795d05af34aeca = $(`&lt;div id=&quot;html_376c18723224c754ec795d05af34aeca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d3391518da6cd675e304e2f1fb8e9c8b.setContent(html_376c18723224c754ec795d05af34aeca);
#
#
#
#         marker_34dced24cc3233bc2f9deebf7997d234.bindPopup(popup_d3391518da6cd675e304e2f1fb8e9c8b)
#         ;
#
#
#
#
#             var marker_bf56c058cbe361883909cd91ae5ba44c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b1554d77f0c723b9636f398c8f008e5e);
#
#
#         var popup_5f29d5005b5e055389d27af1eef02fef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e08ea943d652c1bfabe785d93009eb47 = $(`&lt;div id=&quot;html_e08ea943d652c1bfabe785d93009eb47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5f29d5005b5e055389d27af1eef02fef.setContent(html_e08ea943d652c1bfabe785d93009eb47);
#
#
#
#         marker_bf56c058cbe361883909cd91ae5ba44c.bindPopup(popup_5f29d5005b5e055389d27af1eef02fef)
#         ;
#
#
#
#
#             var marker_ded5653309ecb33d7123fc9d5df100c8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b1554d77f0c723b9636f398c8f008e5e);
#
#
#         var popup_4813b1388694c7b7056879ef28dfe38c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca8964c5763c146bee2454d409ef673b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca8964c5763c146bee2454d409ef673b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca8964c5763c146bee2454d409ef673b = L.map(
#                 &quot;map_ca8964c5763c146bee2454d409ef673b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2c5ba8f0c9648fab034f56634abfe34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2c5ba8f0c9648fab034f56634abfe34.addTo(map_ca8964c5763c146bee2454d409ef673b);
#
#
#             var feature_group_7f3e606a9d6fbdb1a7b7ad4f968dcd8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7f3e606a9d6fbdb1a7b7ad4f968dcd8e.addTo(map_ca8964c5763c146bee2454d409ef673b);
#
#
#             var feature_group_sub_group_4e7af75e730f2e0b5ef96c3064c83b1c = L.featureGroup.subGroup(
#                 feature_group_7f3e606a9d6fbdb1a7b7ad4f968dcd8e
#             );
#
#
#             var marker_59c5cb9c50d7a45cda0848da87c4115a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e7af75e730f2e0b5ef96c3064c83b1c);
#
#
#         var popup_a803e48980d7cef9892947ab85147546 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9949cf2d9f3d5e704198f02f8fe9a2de = $(`&lt;div id=&quot;html_9949cf2d9f3d5e704198f02f8fe9a2de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a803e48980d7cef9892947ab85147546.setContent(html_9949cf2d9f3d5e704198f02f8fe9a2de);
#
#
#
#         marker_59c5cb9c50d7a45cda0848da87c4115a.bindPopup(popup_a803e48980d7cef9892947ab85147546)
#         ;
#
#
#
#
#             var marker_d85f8f486ec40e0f39d987c316eebae1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e7af75e730f2e0b5ef96c3064c83b1c);
#
#
#         var popup_26b49d31668cae2027ee127d52173599 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e54ecb1fe6894b1b132cbf75dfd4c0bd = $(`&lt;div id=&quot;html_e54ecb1fe6894b1b132cbf75dfd4c0bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_26b49d31668cae2027ee127d52173599.setContent(html_e54ecb1fe6894b1b132cbf75dfd4c0bd);
#
#
#
#         marker_d85f8f486ec40e0f39d987c316eebae1.bindPopup(popup_26b49d31668cae2027ee127d52173599)
#         ;
#
#
#
#
#             var marker_281753c36b097747b8a551a626e66047 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e7af75e730f2e0b5ef96c3064c83b1c);
#
#
#         var popup_696f0912bb4e382254ba5ddb717c0317 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2ee553bb2e95a26c177b35d1aff56d7 = $(`&lt;div id=&quot;html_c2ee553bb2e95a26c177b35d1aff56d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_696f0912bb4e382254ba5ddb717c0317.setContent(html_c2ee553bb2e95a26c177b35d1aff56d7);
#
#
#
#         marker_281753c36b097747b8a551a626e66047.bindPopup(popup_696f0912bb4e382254ba5ddb717c0317)
#         ;
#
#
#
#
#             var marker_0d5f982586635ddbdd247797c014c08f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4e7af75e730f2e0b5ef96c3064c83b1c);
#
#
#         var popup_b5fbfb992e73467b09435c80115bde42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd503497514399c4a8451cb05333c967 = $(`&lt;div id=&quot;html_fd503497514399c4a8451cb05333c967&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b5fbfb992e73467b09435c80115bde42.setContent(html_fd503497514399c4a8451cb05333c967);
#
#
#
#         marker_
