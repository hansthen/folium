# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c0c8a09ea0d9de50b6187d8a379b821 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c0c8a09ea0d9de50b6187d8a379b821&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c0c8a09ea0d9de50b6187d8a379b821 = L.map(
#                 &quot;map_9c0c8a09ea0d9de50b6187d8a379b821&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c940f6d41715c4613b205e28c7b39ed4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c940f6d41715c4613b205e28c7b39ed4.addTo(map_9c0c8a09ea0d9de50b6187d8a379b821);
#
#
#             var marker_7c16f602f28257291c4436cd1c3a102c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9c0c8a09ea0d9de50b6187d8a379b821);
#
#
#         var popup_844eb22eac33258253f165bd8eaeb5e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d81b13fe67279274854e223580cf574e = $(`&lt;div id=&quot;html_d81b13fe67279274854e223580cf574e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_844eb22eac33258253f165bd8eaeb5e4.setContent(html_d81b13fe67279274854e223580cf574e);
#
#
#
#         marker_7c16f602f28257291c4436cd1c3a102c.bindPopup(popup_844eb22eac33258253f165bd8eaeb5e4)
#         ;
#
#
#
#
#             var marker_5a74367e9579305a8d454fb8d265cf41 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9c0c8a09ea0d9de50b6187d8a379b821);
#
#
#         var popup_bd8c4d15095d528ca8d0d05dba48e062 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_544f5a73b713a746b51ceceaf0f0c063 = $(`&lt;div id=&quot;html_544f5a73b713a746b51ceceaf0f0c063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bd8c4d15095d528ca8d0d05dba48e062.setContent(html_544f5a73b713a746b51ceceaf0f0c063);
#
#
#
#         marker_5a74367e9579305a8d454fb8d265cf41.bindPopup(popup_bd8c4d15095d528ca8d0d05dba48e062)
#         ;
#
#
#
#
#             var marker_44d5a451198828ed707c687fa0f7b579 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9c0c8a09ea0d9de50b6187d8a379b821);
#
#
#         var popup_833434b092a6cb9c1e541a4e678d7e28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9576e58e02593f78938ca8f4973ce888 = $(`&lt;div id=&quot;html_9576e58e02593f78938ca8f4973ce888&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_833434b092a6cb9c1e541a4e678d7e28.setContent(html_9576e58e02593f78938ca8f4973ce888);
#
#
#
#         marker_44d5a451198828ed707c687fa0f7b579.bindPopup(popup_833434b092a6cb9c1e541a4e678d7e28)
#         ;
#
#
#
#
#             var marker_9ba907724ae20593929e710a9d65e3f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9c0c8a09ea0d9de50b6187d8a379b821);
#
#
#         var popup_558a426722cc9160cb45779894247d75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb6c2f4ee8da6547bf98fa7a447e9b5e = $(`&lt;div id=&quot;html_eb6c2f4ee8da6547bf98fa7a447e9b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_558a426722cc9160cb45779894247d75.setContent(html_eb6c2f4ee8da6547bf98fa7a447e9b5e);
#
#
#
#         marker_9ba907724ae20593929e710a9d65e3f1.bindPopup(popup_558a426722cc9160cb45779894247d75)
#         ;
#
#
#
#
#             var marker_391ddedcac8e40a24eef02db57c71a5c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9c0c8a09ea0d9de50b6187d8a379b821);
#
#
#         var popup_e3ec8e31fd185d467ae35ebe1e7ae4ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a19f4f7bfb329163f72ed840f15c1c97 = $(`&lt;div id=&quot;html_a19f4f7bfb329163f72ed840f15c1c97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e3ec8e31fd185d467ae35ebe1e7ae4ca.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9061f14303b8206bf5faca5ea355027b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9061f14303b8206bf5faca5ea355027b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9061f14303b8206bf5faca5ea355027b = L.map(
#                 &quot;map_9061f14303b8206bf5faca5ea355027b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37a20180f8b23bd7380724caf640a50f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_37a20180f8b23bd7380724caf640a50f.addTo(map_9061f14303b8206bf5faca5ea355027b);
#
#
#             var feature_group_1db55ac6d742243945924ae18e1fce2c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bb7516a88340d731933b8eb4ea8ee676 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1db55ac6d742243945924ae18e1fce2c);
#
#
#         var popup_bb09619afc11794c4cb71bff10627085 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_add56c9a019afada8618fea6d1c17774 = $(`&lt;div id=&quot;html_add56c9a019afada8618fea6d1c17774&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bb09619afc11794c4cb71bff10627085.setContent(html_add56c9a019afada8618fea6d1c17774);
#
#
#
#         marker_bb7516a88340d731933b8eb4ea8ee676.bindPopup(popup_bb09619afc11794c4cb71bff10627085)
#         ;
#
#
#
#
#             var marker_089ea8313ec850ceb29d26f70712f288 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1db55ac6d742243945924ae18e1fce2c);
#
#
#         var popup_c6dffa8cba0ed82934b180acaa31d3b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b75610715c8878b72afc7fed710a02e1 = $(`&lt;div id=&quot;html_b75610715c8878b72afc7fed710a02e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c6dffa8cba0ed82934b180acaa31d3b9.setContent(html_b75610715c8878b72afc7fed710a02e1);
#
#
#
#         marker_089ea8313ec850ceb29d26f70712f288.bindPopup(popup_c6dffa8cba0ed82934b180acaa31d3b9)
#         ;
#
#
#
#
#             var marker_457cb2d19159304e7c93baf023355119 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1db55ac6d742243945924ae18e1fce2c);
#
#
#         var popup_36d30028223f624413cebc562959e0b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9eb51c27fe74808bf46b74887e1c9408 = $(`&lt;div id=&quot;html_9eb51c27fe74808bf46b74887e1c9408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_36d30028223f624413cebc562959e0b4.setContent(html_9eb51c27fe74808bf46b74887e1c9408);
#
#
#
#         marker_457cb2d19159304e7c93baf023355119.bindPopup(popup_36d30028223f624413cebc562959e0b4)
#         ;
#
#
#
#
#             var marker_5318905bdc957ebfbb235c420fc00da1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1db55ac6d742243945924ae18e1fce2c);
#
#
#         var popup_2a4472d79ddd4548ef4ea8a1768840eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dc3a717d200e39776bb24d70d0fe16c = $(`&lt;div id=&quot;html_3dc3a717d200e39776bb24d70d0fe16c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2a4472d79ddd4548ef4ea8a1768840eb.setContent(html_3dc3a717d200e39776bb24d70d0fe16c);
#
#
#
#         marker_5318905bdc957ebfbb235c420fc00da1.bindPopup(popup_2a4472d79ddd4548ef4ea8a1768840eb)
#         ;
#
#
#
#
#             var marker_ca0b964dd679226c6c7b86eb54cb3302 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1db55ac6d742243945924ae18e1fce2c);
#
#
#         var popup_212ec74ffe1204a1bd6a0128c40e6f5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a2654539eab43d2f75efe652d49d867 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a2654539eab43d2f75efe652d49d867&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a2654539eab43d2f75efe652d49d867 = L.map(
#                 &quot;map_1a2654539eab43d2f75efe652d49d867&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad3784fdac4cbc9ef622c24c36964708 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad3784fdac4cbc9ef622c24c36964708.addTo(map_1a2654539eab43d2f75efe652d49d867);
#
#
#             var feature_group_bdf35bc264cdb86a3d104191fdf81493 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bdf35bc264cdb86a3d104191fdf81493.addTo(map_1a2654539eab43d2f75efe652d49d867);
#
#
#             var feature_group_sub_group_dcb5aa00d22a92579d0b1963d74f1a54 = L.featureGroup.subGroup(
#                 feature_group_bdf35bc264cdb86a3d104191fdf81493
#             );
#
#
#             var marker_90e73f79def4c7acfceb407fdd1e3c76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb5aa00d22a92579d0b1963d74f1a54);
#
#
#         var popup_fd12b5ee09e246124c799a0ea9211e78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7e309e35a6155b7546d596a65eb3573 = $(`&lt;div id=&quot;html_c7e309e35a6155b7546d596a65eb3573&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fd12b5ee09e246124c799a0ea9211e78.setContent(html_c7e309e35a6155b7546d596a65eb3573);
#
#
#
#         marker_90e73f79def4c7acfceb407fdd1e3c76.bindPopup(popup_fd12b5ee09e246124c799a0ea9211e78)
#         ;
#
#
#
#
#             var marker_472c203c3373794a1c39bed35b8a2744 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb5aa00d22a92579d0b1963d74f1a54);
#
#
#         var popup_bcf03d626cc0f02b0a91909ff4e860ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31f2fd91f1bb2b2934c4626585af16d9 = $(`&lt;div id=&quot;html_31f2fd91f1bb2b2934c4626585af16d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bcf03d626cc0f02b0a91909ff4e860ba.setContent(html_31f2fd91f1bb2b2934c4626585af16d9);
#
#
#
#         marker_472c203c3373794a1c39bed35b8a2744.bindPopup(popup_bcf03d626cc0f02b0a91909ff4e860ba)
#         ;
#
#
#
#
#             var marker_34af657697fcf4a61be6201fa55d2109 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb5aa00d22a92579d0b1963d74f1a54);
#
#
#         var popup_7bffe9f5b947741bb6f135fef96f1872 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b7afd74be0d0e3f6632b03693099bca = $(`&lt;div id=&quot;html_2b7afd74be0d0e3f6632b03693099bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7bffe9f5b947741bb6f135fef96f1872.setContent(html_2b7afd74be0d0e3f6632b03693099bca);
#
#
#
#         marker_34af657697fcf4a61be6201fa55d2109.bindPopup(popup_7bffe9f5b947741bb6f135fef96f1872)
#         ;
#
#
#
#
#             var marker_be09c48074dd0687ba8562b69de61b5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcb5aa00d22a92579d0b1963d74f1a54);
#
#
#         var popup_03608f0635e5bd286c65904ebdff0981 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7c876ceabafe4360cc18e62e841d97c = $(`&lt;div id=&quot;html_f7c876ceabafe4360cc18e62e841d97c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_03608f0635e5bd286c65904ebdff0981.setContent(html_f7c876ceabafe4360cc18e62e841d97c);
#
#
#
#         marker_
