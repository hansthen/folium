# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bca3216bc03f40e1e6a5a0bd576b896f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bca3216bc03f40e1e6a5a0bd576b896f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bca3216bc03f40e1e6a5a0bd576b896f = L.map(
#                 &quot;map_bca3216bc03f40e1e6a5a0bd576b896f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9eaded9ab47a401a3151023f801f89d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9eaded9ab47a401a3151023f801f89d5.addTo(map_bca3216bc03f40e1e6a5a0bd576b896f);
#
#
#             var marker_bc116dbe299488bc876434ae33324677 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bca3216bc03f40e1e6a5a0bd576b896f);
#
#
#         var popup_84cb44b7a525245f05d3bee1ffd095c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f18bdcf86f6577618dd53dfc48da9958 = $(`&lt;div id=&quot;html_f18bdcf86f6577618dd53dfc48da9958&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_84cb44b7a525245f05d3bee1ffd095c7.setContent(html_f18bdcf86f6577618dd53dfc48da9958);
#
#
#
#         marker_bc116dbe299488bc876434ae33324677.bindPopup(popup_84cb44b7a525245f05d3bee1ffd095c7)
#         ;
#
#
#
#
#             var marker_32839a1f4c618e7e9847dfcf6ffb90a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bca3216bc03f40e1e6a5a0bd576b896f);
#
#
#         var popup_b92b3ee4a1c9a99713ca2a796f629537 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c31848f7e7bf4e5b785343b47e030a3e = $(`&lt;div id=&quot;html_c31848f7e7bf4e5b785343b47e030a3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b92b3ee4a1c9a99713ca2a796f629537.setContent(html_c31848f7e7bf4e5b785343b47e030a3e);
#
#
#
#         marker_32839a1f4c618e7e9847dfcf6ffb90a5.bindPopup(popup_b92b3ee4a1c9a99713ca2a796f629537)
#         ;
#
#
#
#
#             var marker_d86a1f5e4c13116bb934f9398af7aee5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bca3216bc03f40e1e6a5a0bd576b896f);
#
#
#         var popup_daff28213cfb889d893fe26641c830fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e187284f9435a860b68058f8664b0e4b = $(`&lt;div id=&quot;html_e187284f9435a860b68058f8664b0e4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_daff28213cfb889d893fe26641c830fa.setContent(html_e187284f9435a860b68058f8664b0e4b);
#
#
#
#         marker_d86a1f5e4c13116bb934f9398af7aee5.bindPopup(popup_daff28213cfb889d893fe26641c830fa)
#         ;
#
#
#
#
#             var marker_b411fc3b2c9ceed9db74d896743f4520 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bca3216bc03f40e1e6a5a0bd576b896f);
#
#
#         var popup_47bd8dfb74b7a450c7f7e84d4add9fa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fee099bc0c66afeec8a4ba4aab39a1c9 = $(`&lt;div id=&quot;html_fee099bc0c66afeec8a4ba4aab39a1c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_47bd8dfb74b7a450c7f7e84d4add9fa1.setContent(html_fee099bc0c66afeec8a4ba4aab39a1c9);
#
#
#
#         marker_b411fc3b2c9ceed9db74d896743f4520.bindPopup(popup_47bd8dfb74b7a450c7f7e84d4add9fa1)
#         ;
#
#
#
#
#             var marker_faa8cfdd9514c42637102285cff2316d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bca3216bc03f40e1e6a5a0bd576b896f);
#
#
#         var popup_a8f9160c49af18dae429370b356b64d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84512ac4aa8a7abdb44cda4c688ce1d6 = $(`&lt;div id=&quot;html_84512ac4aa8a7abdb44cda4c688ce1d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a8f9160c49af18dae429370b356b64d2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8b6a1601206abf684cd79fe1772b990 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8b6a1601206abf684cd79fe1772b990&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8b6a1601206abf684cd79fe1772b990 = L.map(
#                 &quot;map_a8b6a1601206abf684cd79fe1772b990&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9e66fac8c63164c120d3ecdf495f687 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9e66fac8c63164c120d3ecdf495f687.addTo(map_a8b6a1601206abf684cd79fe1772b990);
#
#
#             var feature_group_ce13aa7622a4a5f8401aa5df35803cf5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2a0d933964380e624c099678c1be9fc5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce13aa7622a4a5f8401aa5df35803cf5);
#
#
#         var popup_0dbc73dd328d7269505c4cb75051d396 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e81a3cf7b50bdcf66abd4b01869cb33 = $(`&lt;div id=&quot;html_7e81a3cf7b50bdcf66abd4b01869cb33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0dbc73dd328d7269505c4cb75051d396.setContent(html_7e81a3cf7b50bdcf66abd4b01869cb33);
#
#
#
#         marker_2a0d933964380e624c099678c1be9fc5.bindPopup(popup_0dbc73dd328d7269505c4cb75051d396)
#         ;
#
#
#
#
#             var marker_25d63f81c51fd20b8b8220db5d8f2b9d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce13aa7622a4a5f8401aa5df35803cf5);
#
#
#         var popup_238e5d84e1e02d4fcac0811ca1cf8dda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a502ff72f3da71ff7656ad5ca67c1b25 = $(`&lt;div id=&quot;html_a502ff72f3da71ff7656ad5ca67c1b25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_238e5d84e1e02d4fcac0811ca1cf8dda.setContent(html_a502ff72f3da71ff7656ad5ca67c1b25);
#
#
#
#         marker_25d63f81c51fd20b8b8220db5d8f2b9d.bindPopup(popup_238e5d84e1e02d4fcac0811ca1cf8dda)
#         ;
#
#
#
#
#             var marker_1e3f41b8aff743419e24037f64094bc3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce13aa7622a4a5f8401aa5df35803cf5);
#
#
#         var popup_a45f9cc0a2dfea07a53f062468f7835a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28919bef670aa82127e8b1e4b8cfd39e = $(`&lt;div id=&quot;html_28919bef670aa82127e8b1e4b8cfd39e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a45f9cc0a2dfea07a53f062468f7835a.setContent(html_28919bef670aa82127e8b1e4b8cfd39e);
#
#
#
#         marker_1e3f41b8aff743419e24037f64094bc3.bindPopup(popup_a45f9cc0a2dfea07a53f062468f7835a)
#         ;
#
#
#
#
#             var marker_7384468ddde2a346e4e456460692f4d1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce13aa7622a4a5f8401aa5df35803cf5);
#
#
#         var popup_69e4f2c93a7870c4d7784db5db8ce2a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3042378bca4d6de8e002169376c391ef = $(`&lt;div id=&quot;html_3042378bca4d6de8e002169376c391ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_69e4f2c93a7870c4d7784db5db8ce2a6.setContent(html_3042378bca4d6de8e002169376c391ef);
#
#
#
#         marker_7384468ddde2a346e4e456460692f4d1.bindPopup(popup_69e4f2c93a7870c4d7784db5db8ce2a6)
#         ;
#
#
#
#
#             var marker_ec261094c665b2c3f57174680ee3e142 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce13aa7622a4a5f8401aa5df35803cf5);
#
#
#         var popup_89df4a2b866d7115c3cbe9e816be3633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b21256580d03bb99d2c0e700a4ba242 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b21256580d03bb99d2c0e700a4ba242&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b21256580d03bb99d2c0e700a4ba242 = L.map(
#                 &quot;map_1b21256580d03bb99d2c0e700a4ba242&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bebd5dfe227e6243c9ed239984e348d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bebd5dfe227e6243c9ed239984e348d.addTo(map_1b21256580d03bb99d2c0e700a4ba242);
#
#
#             var feature_group_0e8ba8364d726cf3af3785fb4e06cd7d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0e8ba8364d726cf3af3785fb4e06cd7d.addTo(map_1b21256580d03bb99d2c0e700a4ba242);
#
#
#             var feature_group_sub_group_bd20be48ad5cfa706ec199fc66f34a4e = L.featureGroup.subGroup(
#                 feature_group_0e8ba8364d726cf3af3785fb4e06cd7d
#             );
#
#
#             var marker_402bd67e24cb7047a64023c298b9a04a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd20be48ad5cfa706ec199fc66f34a4e);
#
#
#         var popup_e090fd63cab880f29c790ed2b94995c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19be64cf8fbac6c6a3063129fb1731f0 = $(`&lt;div id=&quot;html_19be64cf8fbac6c6a3063129fb1731f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e090fd63cab880f29c790ed2b94995c1.setContent(html_19be64cf8fbac6c6a3063129fb1731f0);
#
#
#
#         marker_402bd67e24cb7047a64023c298b9a04a.bindPopup(popup_e090fd63cab880f29c790ed2b94995c1)
#         ;
#
#
#
#
#             var marker_ae05f399d7dbbe5e20358e98bf7592b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd20be48ad5cfa706ec199fc66f34a4e);
#
#
#         var popup_a38b0dec0314ac9035179a1c8c6e62fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21717bbef2fa83ab8592012cf9569c0a = $(`&lt;div id=&quot;html_21717bbef2fa83ab8592012cf9569c0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a38b0dec0314ac9035179a1c8c6e62fa.setContent(html_21717bbef2fa83ab8592012cf9569c0a);
#
#
#
#         marker_ae05f399d7dbbe5e20358e98bf7592b6.bindPopup(popup_a38b0dec0314ac9035179a1c8c6e62fa)
#         ;
#
#
#
#
#             var marker_37ad6e6215524b4021a0b2fb340147de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd20be48ad5cfa706ec199fc66f34a4e);
#
#
#         var popup_edc1f92256d7b2fba528125fc4cbb64e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac77e0ae373953ac1175d10123352f77 = $(`&lt;div id=&quot;html_ac77e0ae373953ac1175d10123352f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_edc1f92256d7b2fba528125fc4cbb64e.setContent(html_ac77e0ae373953ac1175d10123352f77);
#
#
#
#         marker_37ad6e6215524b4021a0b2fb340147de.bindPopup(popup_edc1f92256d7b2fba528125fc4cbb64e)
#         ;
#
#
#
#
#             var marker_a1de7a1f2d3ecf6d44a20513f248553f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd20be48ad5cfa706ec199fc66f34a4e);
#
#
#         var popup_3ab9de20bf40ff9bfe1aa705fbd53d30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21b4b34c0a14f3ae31f1c8181b2be8a2 = $(`&lt;div id=&quot;html_21b4b34c0a14f3ae31f1c8181b2be8a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3ab9de20bf40ff9bfe1aa705fbd53d30.setContent(html_21b4b34c0a14f3ae31f1c8181b2be8a2);
#
#
#
#         marker_
