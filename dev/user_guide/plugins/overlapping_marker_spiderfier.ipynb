# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d48cccd49a8655040a17350e93b7f6f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d48cccd49a8655040a17350e93b7f6f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d48cccd49a8655040a17350e93b7f6f5 = L.map(
#                 &quot;map_d48cccd49a8655040a17350e93b7f6f5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5160c580eeea2f654c531173e95ebd1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5160c580eeea2f654c531173e95ebd1e.addTo(map_d48cccd49a8655040a17350e93b7f6f5);
#
#
#             var marker_b0de4c8a09a4b61539bc2dde030fce11 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d48cccd49a8655040a17350e93b7f6f5);
#
#
#         var popup_4705c57687d6940e78b420890d5f10bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_869443bae18c2ae7e4571643c4e2ffb2 = $(`&lt;div id=&quot;html_869443bae18c2ae7e4571643c4e2ffb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4705c57687d6940e78b420890d5f10bf.setContent(html_869443bae18c2ae7e4571643c4e2ffb2);
#
#
#
#         marker_b0de4c8a09a4b61539bc2dde030fce11.bindPopup(popup_4705c57687d6940e78b420890d5f10bf)
#         ;
#
#
#
#
#             var marker_734e32930271da9e50e58fb158cc6000 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d48cccd49a8655040a17350e93b7f6f5);
#
#
#         var popup_c91cad195bdabac6826d7effdde327d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10484072790ba0897e56191bbafd5eb0 = $(`&lt;div id=&quot;html_10484072790ba0897e56191bbafd5eb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c91cad195bdabac6826d7effdde327d1.setContent(html_10484072790ba0897e56191bbafd5eb0);
#
#
#
#         marker_734e32930271da9e50e58fb158cc6000.bindPopup(popup_c91cad195bdabac6826d7effdde327d1)
#         ;
#
#
#
#
#             var marker_c8efdd05f2aa87db0043cc445e71e49f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d48cccd49a8655040a17350e93b7f6f5);
#
#
#         var popup_02e69451f0781985bdddb7bee3542259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1f7bf385dddfc0431e3678feca6ceb0 = $(`&lt;div id=&quot;html_a1f7bf385dddfc0431e3678feca6ceb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_02e69451f0781985bdddb7bee3542259.setContent(html_a1f7bf385dddfc0431e3678feca6ceb0);
#
#
#
#         marker_c8efdd05f2aa87db0043cc445e71e49f.bindPopup(popup_02e69451f0781985bdddb7bee3542259)
#         ;
#
#
#
#
#             var marker_2c7926b9e5fb2d73f5537098222a51d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d48cccd49a8655040a17350e93b7f6f5);
#
#
#         var popup_20013cfc97d7d9591d3a0ca612336109 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a42883b65364a6328a46bd18e7076c0f = $(`&lt;div id=&quot;html_a42883b65364a6328a46bd18e7076c0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_20013cfc97d7d9591d3a0ca612336109.setContent(html_a42883b65364a6328a46bd18e7076c0f);
#
#
#
#         marker_2c7926b9e5fb2d73f5537098222a51d2.bindPopup(popup_20013cfc97d7d9591d3a0ca612336109)
#         ;
#
#
#
#
#             var marker_fb94084540c2a2d1d8a74bf62c65a364 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d48cccd49a8655040a17350e93b7f6f5);
#
#
#         var popup_7c82ee4dd4e645041110e443a8365bd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83510b55604c621b4925d7a66e5c8e89 = $(`&lt;div id=&quot;html_83510b55604c621b4925d7a66e5c8e89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c82ee4dd4e645041110e443a8365bd8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1e367870631b4afa37535214815680c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1e367870631b4afa37535214815680c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1e367870631b4afa37535214815680c = L.map(
#                 &quot;map_f1e367870631b4afa37535214815680c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01b38046fc9f45eb8478c3d9ca03708b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01b38046fc9f45eb8478c3d9ca03708b.addTo(map_f1e367870631b4afa37535214815680c);
#
#
#             var feature_group_b19ca3a4b26df573368c499a589c3de5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c3aad796a37af669a9a7ba364d9ccb17 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b19ca3a4b26df573368c499a589c3de5);
#
#
#         var popup_5bf6faf1603ececf6ecdf029de869e07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fbba0de0ec8e533137ec4a8f98e9634 = $(`&lt;div id=&quot;html_0fbba0de0ec8e533137ec4a8f98e9634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5bf6faf1603ececf6ecdf029de869e07.setContent(html_0fbba0de0ec8e533137ec4a8f98e9634);
#
#
#
#         marker_c3aad796a37af669a9a7ba364d9ccb17.bindPopup(popup_5bf6faf1603ececf6ecdf029de869e07)
#         ;
#
#
#
#
#             var marker_a5e65aa2ed52eae5b5e55a08237b2abb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b19ca3a4b26df573368c499a589c3de5);
#
#
#         var popup_1d5b367ce89f50549b2f5029492b1aa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58c51bbc90b04ceac97e713f48197a93 = $(`&lt;div id=&quot;html_58c51bbc90b04ceac97e713f48197a93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1d5b367ce89f50549b2f5029492b1aa0.setContent(html_58c51bbc90b04ceac97e713f48197a93);
#
#
#
#         marker_a5e65aa2ed52eae5b5e55a08237b2abb.bindPopup(popup_1d5b367ce89f50549b2f5029492b1aa0)
#         ;
#
#
#
#
#             var marker_b73aefbd3185e97b15e693c22ba4946a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b19ca3a4b26df573368c499a589c3de5);
#
#
#         var popup_4a52f9598b92687bd82e31a1b29d7dd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_456a4dab8a372f2779388eb673ac5270 = $(`&lt;div id=&quot;html_456a4dab8a372f2779388eb673ac5270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4a52f9598b92687bd82e31a1b29d7dd2.setContent(html_456a4dab8a372f2779388eb673ac5270);
#
#
#
#         marker_b73aefbd3185e97b15e693c22ba4946a.bindPopup(popup_4a52f9598b92687bd82e31a1b29d7dd2)
#         ;
#
#
#
#
#             var marker_d349695585a484c6bfdec59cbe9ee416 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b19ca3a4b26df573368c499a589c3de5);
#
#
#         var popup_2b85a40b71c5bdc11f924c75c4b6ddac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_668a53576bbb75709061ff46324379ec = $(`&lt;div id=&quot;html_668a53576bbb75709061ff46324379ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2b85a40b71c5bdc11f924c75c4b6ddac.setContent(html_668a53576bbb75709061ff46324379ec);
#
#
#
#         marker_d349695585a484c6bfdec59cbe9ee416.bindPopup(popup_2b85a40b71c5bdc11f924c75c4b6ddac)
#         ;
#
#
#
#
#             var marker_6764e05ba8f9c7ba8580e3aa271fff68 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b19ca3a4b26df573368c499a589c3de5);
#
#
#         var popup_ea655c3aad21abb5f057d22dc36ea021 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e315ff39455979b798d7839bdb17f018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e315ff39455979b798d7839bdb17f018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e315ff39455979b798d7839bdb17f018 = L.map(
#                 &quot;map_e315ff39455979b798d7839bdb17f018&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36fd8b30e7ec5901f7f7b109c1ef07c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36fd8b30e7ec5901f7f7b109c1ef07c1.addTo(map_e315ff39455979b798d7839bdb17f018);
#
#
#             var feature_group_4a73888e1218a05a5503987e06153e30 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4a73888e1218a05a5503987e06153e30.addTo(map_e315ff39455979b798d7839bdb17f018);
#
#
#             var feature_group_sub_group_a6bfabc3dd8de953d97fab39b7de19b1 = L.featureGroup.subGroup(
#                 feature_group_4a73888e1218a05a5503987e06153e30
#             );
#
#
#             var marker_1e8afddfac8888edaab07e21b1bb45a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a6bfabc3dd8de953d97fab39b7de19b1);
#
#
#         var popup_1052f20b0cc37dcb6420b8d08201da61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e71e4532e1d04221831703d404f9d874 = $(`&lt;div id=&quot;html_e71e4532e1d04221831703d404f9d874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1052f20b0cc37dcb6420b8d08201da61.setContent(html_e71e4532e1d04221831703d404f9d874);
#
#
#
#         marker_1e8afddfac8888edaab07e21b1bb45a0.bindPopup(popup_1052f20b0cc37dcb6420b8d08201da61)
#         ;
#
#
#
#
#             var marker_cae416c68ed07cd514649a1761ef697e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a6bfabc3dd8de953d97fab39b7de19b1);
#
#
#         var popup_978e763a2200f6bf4037af374e4a5f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcebc81345c0e07f66464b67cef3e36d = $(`&lt;div id=&quot;html_dcebc81345c0e07f66464b67cef3e36d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_978e763a2200f6bf4037af374e4a5f45.setContent(html_dcebc81345c0e07f66464b67cef3e36d);
#
#
#
#         marker_cae416c68ed07cd514649a1761ef697e.bindPopup(popup_978e763a2200f6bf4037af374e4a5f45)
#         ;
#
#
#
#
#             var marker_2613206bc20e3df996372db2754492e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a6bfabc3dd8de953d97fab39b7de19b1);
#
#
#         var popup_bc83197bffabfb5babdb1ac0764ffd70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c81c7202398d50be91214b3c28563c2 = $(`&lt;div id=&quot;html_6c81c7202398d50be91214b3c28563c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bc83197bffabfb5babdb1ac0764ffd70.setContent(html_6c81c7202398d50be91214b3c28563c2);
#
#
#
#         marker_2613206bc20e3df996372db2754492e9.bindPopup(popup_bc83197bffabfb5babdb1ac0764ffd70)
#         ;
#
#
#
#
#             var marker_34d185182ea24403172f16c667331828 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a6bfabc3dd8de953d97fab39b7de19b1);
#
#
#         var popup_388b951ccf0e14425d6acf519708e1b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12f31dff48ad83eededea1462b86ff36 = $(`&lt;div id=&quot;html_12f31dff48ad83eededea1462b86ff36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_388b951ccf0e14425d6acf519708e1b0.setContent(html_12f31dff48ad83eededea1462b86ff36);
#
#
#
#         marker_
