# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16a2faf102ef065cf58b37c6a86b5e08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16a2faf102ef065cf58b37c6a86b5e08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16a2faf102ef065cf58b37c6a86b5e08 = L.map(
#                 &quot;map_16a2faf102ef065cf58b37c6a86b5e08&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f82f69e5effcca253d00f7137ec1ab5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f82f69e5effcca253d00f7137ec1ab5.addTo(map_16a2faf102ef065cf58b37c6a86b5e08);
#
#
#             var marker_f40d2eb60f8a71ee75a35e684c517a08 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_16a2faf102ef065cf58b37c6a86b5e08);
#
#
#         var popup_d9837ba9c5309d0dbbe3cc338cdb7717 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99812f0e6a4a9c438820bc2ccb671d63 = $(`&lt;div id=&quot;html_99812f0e6a4a9c438820bc2ccb671d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d9837ba9c5309d0dbbe3cc338cdb7717.setContent(html_99812f0e6a4a9c438820bc2ccb671d63);
#
#
#
#         marker_f40d2eb60f8a71ee75a35e684c517a08.bindPopup(popup_d9837ba9c5309d0dbbe3cc338cdb7717)
#         ;
#
#
#
#
#             var marker_ff009909c3a8ffa26f6c1171b3d3673f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_16a2faf102ef065cf58b37c6a86b5e08);
#
#
#         var popup_0f975847085585f150f637ea0d8532bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48769b333f889aed32b72ebdbdbc4368 = $(`&lt;div id=&quot;html_48769b333f889aed32b72ebdbdbc4368&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0f975847085585f150f637ea0d8532bc.setContent(html_48769b333f889aed32b72ebdbdbc4368);
#
#
#
#         marker_ff009909c3a8ffa26f6c1171b3d3673f.bindPopup(popup_0f975847085585f150f637ea0d8532bc)
#         ;
#
#
#
#
#             var marker_4170b13f06a624da8b396c8ee8b0accd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_16a2faf102ef065cf58b37c6a86b5e08);
#
#
#         var popup_0a2c0d2ad12bfb54bcfb4f99ff4900c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed64763ee66ed5655e8206d4ebeca766 = $(`&lt;div id=&quot;html_ed64763ee66ed5655e8206d4ebeca766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0a2c0d2ad12bfb54bcfb4f99ff4900c8.setContent(html_ed64763ee66ed5655e8206d4ebeca766);
#
#
#
#         marker_4170b13f06a624da8b396c8ee8b0accd.bindPopup(popup_0a2c0d2ad12bfb54bcfb4f99ff4900c8)
#         ;
#
#
#
#
#             var marker_5219c29bf94125d989619adc5230b530 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_16a2faf102ef065cf58b37c6a86b5e08);
#
#
#         var popup_bbf59ae590fb90c47060c7deac9a4e4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_467c8017d8ed5ef9e4eae0b29d1205f7 = $(`&lt;div id=&quot;html_467c8017d8ed5ef9e4eae0b29d1205f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bbf59ae590fb90c47060c7deac9a4e4a.setContent(html_467c8017d8ed5ef9e4eae0b29d1205f7);
#
#
#
#         marker_5219c29bf94125d989619adc5230b530.bindPopup(popup_bbf59ae590fb90c47060c7deac9a4e4a)
#         ;
#
#
#
#
#             var marker_576f5bf0570f7c34e92a18971abc77f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_16a2faf102ef065cf58b37c6a86b5e08);
#
#
#         var popup_1b6affffa006b4dd0f777640d3556ddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f81edc144c59506513d62c9256197ca = $(`&lt;div id=&quot;html_7f81edc144c59506513d62c9256197ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1b6affffa006b4dd0f777640d3556ddc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c2c581c150eb043cc18a895d33aa70f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c2c581c150eb043cc18a895d33aa70f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c2c581c150eb043cc18a895d33aa70f = L.map(
#                 &quot;map_8c2c581c150eb043cc18a895d33aa70f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afedce0248ae94ac83e70467aaa79a63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afedce0248ae94ac83e70467aaa79a63.addTo(map_8c2c581c150eb043cc18a895d33aa70f);
#
#
#             var feature_group_fd864117a24d7cc8999344e7ce52028b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_de83cba7538caf618e31b033f7aa9f15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fd864117a24d7cc8999344e7ce52028b);
#
#
#         var popup_b9f3e6119cace551df8f2befb0172d9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddade04489f7bf6a6a7b5fc9678c7095 = $(`&lt;div id=&quot;html_ddade04489f7bf6a6a7b5fc9678c7095&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b9f3e6119cace551df8f2befb0172d9e.setContent(html_ddade04489f7bf6a6a7b5fc9678c7095);
#
#
#
#         marker_de83cba7538caf618e31b033f7aa9f15.bindPopup(popup_b9f3e6119cace551df8f2befb0172d9e)
#         ;
#
#
#
#
#             var marker_14255ddba3a7bc6b56abfd2dc94447ec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fd864117a24d7cc8999344e7ce52028b);
#
#
#         var popup_72383a3c92720d63190314f02bf1f070 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ad7fe13101715fad36877a6325a6829 = $(`&lt;div id=&quot;html_8ad7fe13101715fad36877a6325a6829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_72383a3c92720d63190314f02bf1f070.setContent(html_8ad7fe13101715fad36877a6325a6829);
#
#
#
#         marker_14255ddba3a7bc6b56abfd2dc94447ec.bindPopup(popup_72383a3c92720d63190314f02bf1f070)
#         ;
#
#
#
#
#             var marker_e86c9f7e136f0c8215043fd7fe960808 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fd864117a24d7cc8999344e7ce52028b);
#
#
#         var popup_bf578ad7c7be4ff1386bbc8e2a909b86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bf11750980ec80291916fb778504431 = $(`&lt;div id=&quot;html_5bf11750980ec80291916fb778504431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bf578ad7c7be4ff1386bbc8e2a909b86.setContent(html_5bf11750980ec80291916fb778504431);
#
#
#
#         marker_e86c9f7e136f0c8215043fd7fe960808.bindPopup(popup_bf578ad7c7be4ff1386bbc8e2a909b86)
#         ;
#
#
#
#
#             var marker_de45204fb6f990edbba7e59020719331 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fd864117a24d7cc8999344e7ce52028b);
#
#
#         var popup_0960c89845d06ac4692e6daaf50c961f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_553bd2fb73ee1ddcbe396ecd611fbddd = $(`&lt;div id=&quot;html_553bd2fb73ee1ddcbe396ecd611fbddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0960c89845d06ac4692e6daaf50c961f.setContent(html_553bd2fb73ee1ddcbe396ecd611fbddd);
#
#
#
#         marker_de45204fb6f990edbba7e59020719331.bindPopup(popup_0960c89845d06ac4692e6daaf50c961f)
#         ;
#
#
#
#
#             var marker_fa5fbef8c2365fb403ef8de1535a8be0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fd864117a24d7cc8999344e7ce52028b);
#
#
#         var popup_c403fd8fd532d088d3a981c36580a05c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f70c049a1033412c19be9a8d44c01339 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f70c049a1033412c19be9a8d44c01339&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f70c049a1033412c19be9a8d44c01339 = L.map(
#                 &quot;map_f70c049a1033412c19be9a8d44c01339&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82e8912dd767fd805760a42bfffff800 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82e8912dd767fd805760a42bfffff800.addTo(map_f70c049a1033412c19be9a8d44c01339);
#
#
#             var feature_group_b3f4f0a9dc6dcdf6e426b9bf783aece7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b3f4f0a9dc6dcdf6e426b9bf783aece7.addTo(map_f70c049a1033412c19be9a8d44c01339);
#
#
#             var feature_group_sub_group_5c5e9d33763365dda4d5f623978bd297 = L.featureGroup.subGroup(
#                 feature_group_b3f4f0a9dc6dcdf6e426b9bf783aece7
#             );
#
#
#             var marker_5c51794b707177a4bce98cb0dce3915d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c5e9d33763365dda4d5f623978bd297);
#
#
#         var popup_16eeccaf7430b4d94b5b6f596d7e585a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b477e83252dca489e0a5b2e417fc8ca3 = $(`&lt;div id=&quot;html_b477e83252dca489e0a5b2e417fc8ca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_16eeccaf7430b4d94b5b6f596d7e585a.setContent(html_b477e83252dca489e0a5b2e417fc8ca3);
#
#
#
#         marker_5c51794b707177a4bce98cb0dce3915d.bindPopup(popup_16eeccaf7430b4d94b5b6f596d7e585a)
#         ;
#
#
#
#
#             var marker_1e0c840c0824f8a265511681a86d88d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c5e9d33763365dda4d5f623978bd297);
#
#
#         var popup_7a2be8acadd0092bacd6b61053ee67a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4d36c73ea7f4b91387526f2dd5b09b5 = $(`&lt;div id=&quot;html_b4d36c73ea7f4b91387526f2dd5b09b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7a2be8acadd0092bacd6b61053ee67a7.setContent(html_b4d36c73ea7f4b91387526f2dd5b09b5);
#
#
#
#         marker_1e0c840c0824f8a265511681a86d88d7.bindPopup(popup_7a2be8acadd0092bacd6b61053ee67a7)
#         ;
#
#
#
#
#             var marker_aaa16bd2d3896432ebfda4e092f9f824 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c5e9d33763365dda4d5f623978bd297);
#
#
#         var popup_afdbe4a8459d69dc98741624d4f619f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5c3f51feff7b9771738bee989714885 = $(`&lt;div id=&quot;html_a5c3f51feff7b9771738bee989714885&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_afdbe4a8459d69dc98741624d4f619f3.setContent(html_a5c3f51feff7b9771738bee989714885);
#
#
#
#         marker_aaa16bd2d3896432ebfda4e092f9f824.bindPopup(popup_afdbe4a8459d69dc98741624d4f619f3)
#         ;
#
#
#
#
#             var marker_8c041d62d4c64bfa9d1646245f2df24c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5c5e9d33763365dda4d5f623978bd297);
#
#
#         var popup_bc8f5f29a255a7bbf6e9d6008fb99cdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fa96297951418e0102cb81ab7fa939b = $(`&lt;div id=&quot;html_0fa96297951418e0102cb81ab7fa939b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bc8f5f29a255a7bbf6e9d6008fb99cdc.setContent(html_0fa96297951418e0102cb81ab7fa939b);
#
#
#
#         marker_
