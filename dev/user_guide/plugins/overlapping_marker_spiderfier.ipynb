# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc3b09990424644a7a91ef8bba0617b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc3b09990424644a7a91ef8bba0617b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc3b09990424644a7a91ef8bba0617b4 = L.map(
#                 &quot;map_fc3b09990424644a7a91ef8bba0617b4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae4900f0afc992ac517246766916cd3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae4900f0afc992ac517246766916cd3d.addTo(map_fc3b09990424644a7a91ef8bba0617b4);
#
#
#             var marker_5aea1d90b50a8706e797c6a0bcc653ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fc3b09990424644a7a91ef8bba0617b4);
#
#
#         var popup_23fb163e8f61974f1c6fb8419b158411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c859c358cb459fa00f4b397038072f15 = $(`&lt;div id=&quot;html_c859c358cb459fa00f4b397038072f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_23fb163e8f61974f1c6fb8419b158411.setContent(html_c859c358cb459fa00f4b397038072f15);
#
#
#
#         marker_5aea1d90b50a8706e797c6a0bcc653ab.bindPopup(popup_23fb163e8f61974f1c6fb8419b158411)
#         ;
#
#
#
#
#             var marker_29d7cab73630c7f03be6f91a61c202e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fc3b09990424644a7a91ef8bba0617b4);
#
#
#         var popup_1dff7344ab594e898fedc4f8154ee1d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fb59e5f26d9c7ae701dfc784bad16a6 = $(`&lt;div id=&quot;html_4fb59e5f26d9c7ae701dfc784bad16a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1dff7344ab594e898fedc4f8154ee1d9.setContent(html_4fb59e5f26d9c7ae701dfc784bad16a6);
#
#
#
#         marker_29d7cab73630c7f03be6f91a61c202e8.bindPopup(popup_1dff7344ab594e898fedc4f8154ee1d9)
#         ;
#
#
#
#
#             var marker_8f76da8fe9990e145182e4aff01d9ee7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fc3b09990424644a7a91ef8bba0617b4);
#
#
#         var popup_dbeb7daac9a727df8e24e165f03783ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8d1234e986275bcba00f99d2a1c9d5b = $(`&lt;div id=&quot;html_c8d1234e986275bcba00f99d2a1c9d5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dbeb7daac9a727df8e24e165f03783ac.setContent(html_c8d1234e986275bcba00f99d2a1c9d5b);
#
#
#
#         marker_8f76da8fe9990e145182e4aff01d9ee7.bindPopup(popup_dbeb7daac9a727df8e24e165f03783ac)
#         ;
#
#
#
#
#             var marker_ac39812f537671bb0a04b84a85987248 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fc3b09990424644a7a91ef8bba0617b4);
#
#
#         var popup_e75cc2129536f7a23fb607baa8db5172 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa506ee83025e6816ce6040cf8bde0cf = $(`&lt;div id=&quot;html_fa506ee83025e6816ce6040cf8bde0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e75cc2129536f7a23fb607baa8db5172.setContent(html_fa506ee83025e6816ce6040cf8bde0cf);
#
#
#
#         marker_ac39812f537671bb0a04b84a85987248.bindPopup(popup_e75cc2129536f7a23fb607baa8db5172)
#         ;
#
#
#
#
#             var marker_c3864c6c78caae2387599e9533151c9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fc3b09990424644a7a91ef8bba0617b4);
#
#
#         var popup_add1d5d3829967d16cc789e0abb0c4df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4105b69be24bb397b0cd5ba1672f167d = $(`&lt;div id=&quot;html_4105b69be24bb397b0cd5ba1672f167d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_add1d5d3829967d16cc789e0abb0c4df.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a2a92db70b86ec75b40441dded9ddee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a2a92db70b86ec75b40441dded9ddee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a2a92db70b86ec75b40441dded9ddee = L.map(
#                 &quot;map_0a2a92db70b86ec75b40441dded9ddee&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_391be1df7406d7c3d4f96d7281798abc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_391be1df7406d7c3d4f96d7281798abc.addTo(map_0a2a92db70b86ec75b40441dded9ddee);
#
#
#             var feature_group_3224a4f6036241a7416366c9c69d3606 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9661191fb281445648032096402888b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3224a4f6036241a7416366c9c69d3606);
#
#
#         var popup_1cd34de153b5082ae2ccabbce22c444f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5268c02c6bfd811ca3234ccc63da5382 = $(`&lt;div id=&quot;html_5268c02c6bfd811ca3234ccc63da5382&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1cd34de153b5082ae2ccabbce22c444f.setContent(html_5268c02c6bfd811ca3234ccc63da5382);
#
#
#
#         marker_9661191fb281445648032096402888b2.bindPopup(popup_1cd34de153b5082ae2ccabbce22c444f)
#         ;
#
#
#
#
#             var marker_7dc4262d35af8b71629d77de40c785ce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3224a4f6036241a7416366c9c69d3606);
#
#
#         var popup_3b1175d2a0fb87e40079ffb34851324e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ddc0e0ee670d737ef46566ed41e63c4 = $(`&lt;div id=&quot;html_2ddc0e0ee670d737ef46566ed41e63c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3b1175d2a0fb87e40079ffb34851324e.setContent(html_2ddc0e0ee670d737ef46566ed41e63c4);
#
#
#
#         marker_7dc4262d35af8b71629d77de40c785ce.bindPopup(popup_3b1175d2a0fb87e40079ffb34851324e)
#         ;
#
#
#
#
#             var marker_3a215834f619802ea7137c5d98ed1128 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3224a4f6036241a7416366c9c69d3606);
#
#
#         var popup_3a0f0d02a09adbdf9ec4710bda1e4b56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d6d76f48e6ce8be65c911927eac632f = $(`&lt;div id=&quot;html_5d6d76f48e6ce8be65c911927eac632f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3a0f0d02a09adbdf9ec4710bda1e4b56.setContent(html_5d6d76f48e6ce8be65c911927eac632f);
#
#
#
#         marker_3a215834f619802ea7137c5d98ed1128.bindPopup(popup_3a0f0d02a09adbdf9ec4710bda1e4b56)
#         ;
#
#
#
#
#             var marker_93150bfbdf9ee433383f6d9ef5ec5053 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3224a4f6036241a7416366c9c69d3606);
#
#
#         var popup_f2ef865919b937811edf73957bba7c48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a010e3089eb58b7ec7c39c20915af1f6 = $(`&lt;div id=&quot;html_a010e3089eb58b7ec7c39c20915af1f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f2ef865919b937811edf73957bba7c48.setContent(html_a010e3089eb58b7ec7c39c20915af1f6);
#
#
#
#         marker_93150bfbdf9ee433383f6d9ef5ec5053.bindPopup(popup_f2ef865919b937811edf73957bba7c48)
#         ;
#
#
#
#
#             var marker_6f521297073ce7c94a043133af249e70 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3224a4f6036241a7416366c9c69d3606);
#
#
#         var popup_0347d0a43824ee579dadc970b9595da7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99adca293532a6b3b4fc14752f98ae92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99adca293532a6b3b4fc14752f98ae92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99adca293532a6b3b4fc14752f98ae92 = L.map(
#                 &quot;map_99adca293532a6b3b4fc14752f98ae92&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50b99c5e960c4865dc9c193776d2f86d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50b99c5e960c4865dc9c193776d2f86d.addTo(map_99adca293532a6b3b4fc14752f98ae92);
#
#
#             var feature_group_576b306f14313b6f2d49bce0db8e2984 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_576b306f14313b6f2d49bce0db8e2984.addTo(map_99adca293532a6b3b4fc14752f98ae92);
#
#
#             var feature_group_sub_group_9396b808767097859388611f0a50e923 = L.featureGroup.subGroup(
#                 feature_group_576b306f14313b6f2d49bce0db8e2984
#             );
#
#
#             var marker_1c6908ec499beb9e11bfd2128bac4fc1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9396b808767097859388611f0a50e923);
#
#
#         var popup_348ebb425e819414bb14b195bdd253aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78b1795923f41fb5e1492357f73fbed2 = $(`&lt;div id=&quot;html_78b1795923f41fb5e1492357f73fbed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_348ebb425e819414bb14b195bdd253aa.setContent(html_78b1795923f41fb5e1492357f73fbed2);
#
#
#
#         marker_1c6908ec499beb9e11bfd2128bac4fc1.bindPopup(popup_348ebb425e819414bb14b195bdd253aa)
#         ;
#
#
#
#
#             var marker_bcdc77837f66b95e079727192bfb7b4a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9396b808767097859388611f0a50e923);
#
#
#         var popup_13d1695ace10dc07b88436d9eec367dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a6ed7d588d513bd8a34984fbb6879c9 = $(`&lt;div id=&quot;html_4a6ed7d588d513bd8a34984fbb6879c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_13d1695ace10dc07b88436d9eec367dc.setContent(html_4a6ed7d588d513bd8a34984fbb6879c9);
#
#
#
#         marker_bcdc77837f66b95e079727192bfb7b4a.bindPopup(popup_13d1695ace10dc07b88436d9eec367dc)
#         ;
#
#
#
#
#             var marker_6d6fdc982f51239c9bb6daa10dc4f66d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9396b808767097859388611f0a50e923);
#
#
#         var popup_37b7b5b5cbfb40b86d70feb7ace83696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bb55bc724a5ced0002d3d9209a826ed = $(`&lt;div id=&quot;html_6bb55bc724a5ced0002d3d9209a826ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_37b7b5b5cbfb40b86d70feb7ace83696.setContent(html_6bb55bc724a5ced0002d3d9209a826ed);
#
#
#
#         marker_6d6fdc982f51239c9bb6daa10dc4f66d.bindPopup(popup_37b7b5b5cbfb40b86d70feb7ace83696)
#         ;
#
#
#
#
#             var marker_ae624e5eac3db5fb6ccea0874beec075 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9396b808767097859388611f0a50e923);
#
#
#         var popup_751ea49aafd19eeba7e742a6e3cf321d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_292227bda2cceb55025da483900835ca = $(`&lt;div id=&quot;html_292227bda2cceb55025da483900835ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_751ea49aafd19eeba7e742a6e3cf321d.setContent(html_292227bda2cceb55025da483900835ca);
#
#
#
#         marker_
