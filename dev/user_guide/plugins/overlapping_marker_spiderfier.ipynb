# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_788df43a4a652eea5100ca9cd12215d2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_788df43a4a652eea5100ca9cd12215d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_788df43a4a652eea5100ca9cd12215d2 = L.map(
#                 &quot;map_788df43a4a652eea5100ca9cd12215d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9af3dfcc3a23e141f27201251f3fb3f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9af3dfcc3a23e141f27201251f3fb3f7.addTo(map_788df43a4a652eea5100ca9cd12215d2);
#
#
#             var marker_7b1dceb860bbe878a05d45341e89124e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_788df43a4a652eea5100ca9cd12215d2);
#
#
#         var popup_d03c353b4a3ce906daf38ed861b034f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f90e94e9c65dafc5cb5ef8ae889f3ab4 = $(`&lt;div id=&quot;html_f90e94e9c65dafc5cb5ef8ae889f3ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d03c353b4a3ce906daf38ed861b034f6.setContent(html_f90e94e9c65dafc5cb5ef8ae889f3ab4);
#
#
#
#         marker_7b1dceb860bbe878a05d45341e89124e.bindPopup(popup_d03c353b4a3ce906daf38ed861b034f6)
#         ;
#
#
#
#
#             var marker_afd1443e65835369cf1fb4cfec1ec3c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_788df43a4a652eea5100ca9cd12215d2);
#
#
#         var popup_60caaa790af2de3812c50c8e76469293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_239ae64557ba2094adf6e6fc1fd8dc55 = $(`&lt;div id=&quot;html_239ae64557ba2094adf6e6fc1fd8dc55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_60caaa790af2de3812c50c8e76469293.setContent(html_239ae64557ba2094adf6e6fc1fd8dc55);
#
#
#
#         marker_afd1443e65835369cf1fb4cfec1ec3c4.bindPopup(popup_60caaa790af2de3812c50c8e76469293)
#         ;
#
#
#
#
#             var marker_677b25b7def5a89f57f9f4bc40b49b92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_788df43a4a652eea5100ca9cd12215d2);
#
#
#         var popup_a6aa56fb1f422e187c88fd63cfc0348f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c52e54717dd28bd49ccb6c50e8e969d6 = $(`&lt;div id=&quot;html_c52e54717dd28bd49ccb6c50e8e969d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a6aa56fb1f422e187c88fd63cfc0348f.setContent(html_c52e54717dd28bd49ccb6c50e8e969d6);
#
#
#
#         marker_677b25b7def5a89f57f9f4bc40b49b92.bindPopup(popup_a6aa56fb1f422e187c88fd63cfc0348f)
#         ;
#
#
#
#
#             var marker_1cc18b017be2f04809957d751420c263 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_788df43a4a652eea5100ca9cd12215d2);
#
#
#         var popup_825058d0fc7e49c560fe65d0f43e6416 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64ef24fc17d6b6c2ebcc59c2eaeafd7c = $(`&lt;div id=&quot;html_64ef24fc17d6b6c2ebcc59c2eaeafd7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_825058d0fc7e49c560fe65d0f43e6416.setContent(html_64ef24fc17d6b6c2ebcc59c2eaeafd7c);
#
#
#
#         marker_1cc18b017be2f04809957d751420c263.bindPopup(popup_825058d0fc7e49c560fe65d0f43e6416)
#         ;
#
#
#
#
#             var marker_04eed7d1a3af0434028dc1ade71036e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_788df43a4a652eea5100ca9cd12215d2);
#
#
#         var popup_a0a9869e0ec64a849ddf02a5356dd4f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_536c9231b0d3e541f9be0039097a9fbc = $(`&lt;div id=&quot;html_536c9231b0d3e541f9be0039097a9fbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a0a9869e0ec64a849ddf02a5356dd4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b07a8de474eb8263c65aa16eaabaa97 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b07a8de474eb8263c65aa16eaabaa97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b07a8de474eb8263c65aa16eaabaa97 = L.map(
#                 &quot;map_9b07a8de474eb8263c65aa16eaabaa97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_095f34172a3ed851a077e6fbbc76295f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_095f34172a3ed851a077e6fbbc76295f.addTo(map_9b07a8de474eb8263c65aa16eaabaa97);
#
#
#             var feature_group_97e8fc620ef6b2d85760cc910635b3c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0c1e4824938013ef0b613a5bd4be1fc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_97e8fc620ef6b2d85760cc910635b3c8);
#
#
#         var popup_eb1b5de92dc9b4fbdd75ee2544d435a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd15abe1d858fecf0c1de42eca3e66c7 = $(`&lt;div id=&quot;html_cd15abe1d858fecf0c1de42eca3e66c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_eb1b5de92dc9b4fbdd75ee2544d435a2.setContent(html_cd15abe1d858fecf0c1de42eca3e66c7);
#
#
#
#         marker_0c1e4824938013ef0b613a5bd4be1fc7.bindPopup(popup_eb1b5de92dc9b4fbdd75ee2544d435a2)
#         ;
#
#
#
#
#             var marker_8655464df3066b491bbcab81ac3d4d95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_97e8fc620ef6b2d85760cc910635b3c8);
#
#
#         var popup_396106c5dea3962ca83cdcb1a4600a3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7caa020756ce436b6d523e706ad8cde5 = $(`&lt;div id=&quot;html_7caa020756ce436b6d523e706ad8cde5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_396106c5dea3962ca83cdcb1a4600a3f.setContent(html_7caa020756ce436b6d523e706ad8cde5);
#
#
#
#         marker_8655464df3066b491bbcab81ac3d4d95.bindPopup(popup_396106c5dea3962ca83cdcb1a4600a3f)
#         ;
#
#
#
#
#             var marker_8ad4e623244dbed91e40ea3b7e87eced = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_97e8fc620ef6b2d85760cc910635b3c8);
#
#
#         var popup_3bd1525730188c55475dc569c2f4e506 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dd74b4b86994cfa2d82eb5adad0f8dc = $(`&lt;div id=&quot;html_3dd74b4b86994cfa2d82eb5adad0f8dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3bd1525730188c55475dc569c2f4e506.setContent(html_3dd74b4b86994cfa2d82eb5adad0f8dc);
#
#
#
#         marker_8ad4e623244dbed91e40ea3b7e87eced.bindPopup(popup_3bd1525730188c55475dc569c2f4e506)
#         ;
#
#
#
#
#             var marker_d4d609080f65904670355c71e6efce43 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_97e8fc620ef6b2d85760cc910635b3c8);
#
#
#         var popup_a7e3de32eb433001110597b6005d30c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe81338b56363ffbf001c316e31009b4 = $(`&lt;div id=&quot;html_fe81338b56363ffbf001c316e31009b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a7e3de32eb433001110597b6005d30c3.setContent(html_fe81338b56363ffbf001c316e31009b4);
#
#
#
#         marker_d4d609080f65904670355c71e6efce43.bindPopup(popup_a7e3de32eb433001110597b6005d30c3)
#         ;
#
#
#
#
#             var marker_d6f818e30f75b1db895d416a7d1603f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_97e8fc620ef6b2d85760cc910635b3c8);
#
#
#         var popup_a3b722167b8b551459dfdf657c511f4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a77d5277e21ccecf6c300d54a006d9d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a77d5277e21ccecf6c300d54a006d9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a77d5277e21ccecf6c300d54a006d9d = L.map(
#                 &quot;map_8a77d5277e21ccecf6c300d54a006d9d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45497ce26ecf5a1dc1f9eedeced8b7e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45497ce26ecf5a1dc1f9eedeced8b7e6.addTo(map_8a77d5277e21ccecf6c300d54a006d9d);
#
#
#             var feature_group_2f061b03340fed063784142c1b4ddada = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2f061b03340fed063784142c1b4ddada.addTo(map_8a77d5277e21ccecf6c300d54a006d9d);
#
#
#             var feature_group_sub_group_315dae1caad63cc972dee0a15fca27a0 = L.featureGroup.subGroup(
#                 feature_group_2f061b03340fed063784142c1b4ddada
#             );
#
#
#             var marker_77ae334696875bc9f5f3d0bad08e03f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_315dae1caad63cc972dee0a15fca27a0);
#
#
#         var popup_a6b4c82fa1f40175d286851f7deb4906 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42cb9857b4c8c19ba4d795f5a6e0f374 = $(`&lt;div id=&quot;html_42cb9857b4c8c19ba4d795f5a6e0f374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a6b4c82fa1f40175d286851f7deb4906.setContent(html_42cb9857b4c8c19ba4d795f5a6e0f374);
#
#
#
#         marker_77ae334696875bc9f5f3d0bad08e03f2.bindPopup(popup_a6b4c82fa1f40175d286851f7deb4906)
#         ;
#
#
#
#
#             var marker_4b5642031e4ec8576fd6eed27eb704d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_315dae1caad63cc972dee0a15fca27a0);
#
#
#         var popup_03526597ca54fca38fdef15c7c705055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57c42a0723650222c9d28454720f02fd = $(`&lt;div id=&quot;html_57c42a0723650222c9d28454720f02fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_03526597ca54fca38fdef15c7c705055.setContent(html_57c42a0723650222c9d28454720f02fd);
#
#
#
#         marker_4b5642031e4ec8576fd6eed27eb704d4.bindPopup(popup_03526597ca54fca38fdef15c7c705055)
#         ;
#
#
#
#
#             var marker_a5d7a019e8a8e71b4f187d79af85dee2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_315dae1caad63cc972dee0a15fca27a0);
#
#
#         var popup_af36f5fc81e74a9ec1d49b30997e7489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0604302a4c579ba7e8e968c65e484dfd = $(`&lt;div id=&quot;html_0604302a4c579ba7e8e968c65e484dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af36f5fc81e74a9ec1d49b30997e7489.setContent(html_0604302a4c579ba7e8e968c65e484dfd);
#
#
#
#         marker_a5d7a019e8a8e71b4f187d79af85dee2.bindPopup(popup_af36f5fc81e74a9ec1d49b30997e7489)
#         ;
#
#
#
#
#             var marker_cbed41f16120320d12357eb9c111be2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_315dae1caad63cc972dee0a15fca27a0);
#
#
#         var popup_86db7bd3486e8d880ed52fcb272e51c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0385830c0a3f63546f18ffab579acf0c = $(`&lt;div id=&quot;html_0385830c0a3f63546f18ffab579acf0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_86db7bd3486e8d880ed52fcb272e51c0.setContent(html_0385830c0a3f63546f18ffab579acf0c);
#
#
#
#         mark
