# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db23d563b2cde43d1b76c91f2887d251 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db23d563b2cde43d1b76c91f2887d251&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db23d563b2cde43d1b76c91f2887d251 = L.map(
#                 &quot;map_db23d563b2cde43d1b76c91f2887d251&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aebe3935b8a9483cdb8cb2fcae5bd02c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aebe3935b8a9483cdb8cb2fcae5bd02c.addTo(map_db23d563b2cde43d1b76c91f2887d251);
#
#
#             var marker_77acbcca6bd247fa2279dbcb1905dd53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_db23d563b2cde43d1b76c91f2887d251);
#
#
#         var popup_47a9b5bb38d4e785c401af8ecaeeebf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d4425bde26fc5292176049ba1507dd7 = $(`&lt;div id=&quot;html_9d4425bde26fc5292176049ba1507dd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_47a9b5bb38d4e785c401af8ecaeeebf5.setContent(html_9d4425bde26fc5292176049ba1507dd7);
#
#
#
#         marker_77acbcca6bd247fa2279dbcb1905dd53.bindPopup(popup_47a9b5bb38d4e785c401af8ecaeeebf5)
#         ;
#
#
#
#
#             var marker_61d0bad13a9393864f78ebf93617e6c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_db23d563b2cde43d1b76c91f2887d251);
#
#
#         var popup_58ba63c2bbf813ceb76c7cd0131aaf1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5f0d72abbaf420854d856d98039fb40 = $(`&lt;div id=&quot;html_b5f0d72abbaf420854d856d98039fb40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_58ba63c2bbf813ceb76c7cd0131aaf1c.setContent(html_b5f0d72abbaf420854d856d98039fb40);
#
#
#
#         marker_61d0bad13a9393864f78ebf93617e6c1.bindPopup(popup_58ba63c2bbf813ceb76c7cd0131aaf1c)
#         ;
#
#
#
#
#             var marker_5ac6194afddb3bba40ab41f649b3ba21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_db23d563b2cde43d1b76c91f2887d251);
#
#
#         var popup_3168d806bc900ea94b6c5c05fac35b6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c2f082fe285d3bd17682c2451dbce8a = $(`&lt;div id=&quot;html_3c2f082fe285d3bd17682c2451dbce8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3168d806bc900ea94b6c5c05fac35b6d.setContent(html_3c2f082fe285d3bd17682c2451dbce8a);
#
#
#
#         marker_5ac6194afddb3bba40ab41f649b3ba21.bindPopup(popup_3168d806bc900ea94b6c5c05fac35b6d)
#         ;
#
#
#
#
#             var marker_3c79f484bc51d909146adb2b85a2eefa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_db23d563b2cde43d1b76c91f2887d251);
#
#
#         var popup_0184488696bdecdd5a98acc6c688130f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abe447337378bd0a58258eb36295f6a3 = $(`&lt;div id=&quot;html_abe447337378bd0a58258eb36295f6a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0184488696bdecdd5a98acc6c688130f.setContent(html_abe447337378bd0a58258eb36295f6a3);
#
#
#
#         marker_3c79f484bc51d909146adb2b85a2eefa.bindPopup(popup_0184488696bdecdd5a98acc6c688130f)
#         ;
#
#
#
#
#             var marker_6cb050729ee1b97066aaee2e6f3406a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_db23d563b2cde43d1b76c91f2887d251);
#
#
#         var popup_7f38020c2fda5787df458ddb2c801e88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0f96197875fc6643f05549ea17f1b92 = $(`&lt;div id=&quot;html_e0f96197875fc6643f05549ea17f1b92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7f38020c2fda5787df458ddb2c801e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a899fb39fdaa644079a86e618560c6ad {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a899fb39fdaa644079a86e618560c6ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a899fb39fdaa644079a86e618560c6ad = L.map(
#                 &quot;map_a899fb39fdaa644079a86e618560c6ad&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3139941425c393be143a8a6a1b8b6245 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3139941425c393be143a8a6a1b8b6245.addTo(map_a899fb39fdaa644079a86e618560c6ad);
#
#
#             var feature_group_178ba4a80020713e78843636129b846e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9e712bc3d836e7cf441ec0f58b04a129 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_178ba4a80020713e78843636129b846e);
#
#
#         var popup_076e551cac2a15f27c97615309d32bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d5f9a2c3b64e3ab5776032e194b5491 = $(`&lt;div id=&quot;html_5d5f9a2c3b64e3ab5776032e194b5491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_076e551cac2a15f27c97615309d32bd4.setContent(html_5d5f9a2c3b64e3ab5776032e194b5491);
#
#
#
#         marker_9e712bc3d836e7cf441ec0f58b04a129.bindPopup(popup_076e551cac2a15f27c97615309d32bd4)
#         ;
#
#
#
#
#             var marker_b0e8c3a27410fa60a6164900ec172c8b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_178ba4a80020713e78843636129b846e);
#
#
#         var popup_174adc125b46048fd9ff017296333911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df9ef2f80cec9671edeedb32ee6e73cd = $(`&lt;div id=&quot;html_df9ef2f80cec9671edeedb32ee6e73cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_174adc125b46048fd9ff017296333911.setContent(html_df9ef2f80cec9671edeedb32ee6e73cd);
#
#
#
#         marker_b0e8c3a27410fa60a6164900ec172c8b.bindPopup(popup_174adc125b46048fd9ff017296333911)
#         ;
#
#
#
#
#             var marker_4c0724a3ef58098ecae5846cdbbfdb5e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_178ba4a80020713e78843636129b846e);
#
#
#         var popup_0961bc86a0047ca2f1dad5e6ab016ecf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98c77853ddd026adf0cdec36ad79e009 = $(`&lt;div id=&quot;html_98c77853ddd026adf0cdec36ad79e009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0961bc86a0047ca2f1dad5e6ab016ecf.setContent(html_98c77853ddd026adf0cdec36ad79e009);
#
#
#
#         marker_4c0724a3ef58098ecae5846cdbbfdb5e.bindPopup(popup_0961bc86a0047ca2f1dad5e6ab016ecf)
#         ;
#
#
#
#
#             var marker_bc2ddb4af5e6a98cf61fbdc38503476e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_178ba4a80020713e78843636129b846e);
#
#
#         var popup_4b6c5fd1a247ccf5ac91010df2ea0826 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afb02bab44876cc215547a3103593a66 = $(`&lt;div id=&quot;html_afb02bab44876cc215547a3103593a66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4b6c5fd1a247ccf5ac91010df2ea0826.setContent(html_afb02bab44876cc215547a3103593a66);
#
#
#
#         marker_bc2ddb4af5e6a98cf61fbdc38503476e.bindPopup(popup_4b6c5fd1a247ccf5ac91010df2ea0826)
#         ;
#
#
#
#
#             var marker_b1b5a37d101ae523a291a78008beb3b7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_178ba4a80020713e78843636129b846e);
#
#
#         var popup_63a453f239e6ada8ce0afcad600904d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d739a65e6e23f0d07091287da8d4f58 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d739a65e6e23f0d07091287da8d4f58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d739a65e6e23f0d07091287da8d4f58 = L.map(
#                 &quot;map_7d739a65e6e23f0d07091287da8d4f58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb780b74bf6be16f18965659ce5f58ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb780b74bf6be16f18965659ce5f58ba.addTo(map_7d739a65e6e23f0d07091287da8d4f58);
#
#
#             var feature_group_d166b7bb0b061551195a5cadf6a2337b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d166b7bb0b061551195a5cadf6a2337b.addTo(map_7d739a65e6e23f0d07091287da8d4f58);
#
#
#             var feature_group_sub_group_ef7946e47687ebf7929f6f97bcf9f6c7 = L.featureGroup.subGroup(
#                 feature_group_d166b7bb0b061551195a5cadf6a2337b
#             );
#
#
#             var marker_f65b79c272212cb0bb88f7d969daf102 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef7946e47687ebf7929f6f97bcf9f6c7);
#
#
#         var popup_b2c5266ad5904fc6aa7b96998c5428f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89711aebe118f518256bbe95e1ee4dc6 = $(`&lt;div id=&quot;html_89711aebe118f518256bbe95e1ee4dc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b2c5266ad5904fc6aa7b96998c5428f2.setContent(html_89711aebe118f518256bbe95e1ee4dc6);
#
#
#
#         marker_f65b79c272212cb0bb88f7d969daf102.bindPopup(popup_b2c5266ad5904fc6aa7b96998c5428f2)
#         ;
#
#
#
#
#             var marker_e56fbfb1710207c0169db196ccb72dfd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef7946e47687ebf7929f6f97bcf9f6c7);
#
#
#         var popup_764044e111df952faadd7291ab777218 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98a7a0d27dba6128ad38f3a46d709288 = $(`&lt;div id=&quot;html_98a7a0d27dba6128ad38f3a46d709288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_764044e111df952faadd7291ab777218.setContent(html_98a7a0d27dba6128ad38f3a46d709288);
#
#
#
#         marker_e56fbfb1710207c0169db196ccb72dfd.bindPopup(popup_764044e111df952faadd7291ab777218)
#         ;
#
#
#
#
#             var marker_21e927fcdc481909e64c895c1dda6cfb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef7946e47687ebf7929f6f97bcf9f6c7);
#
#
#         var popup_3c9321f58b6a7b01d9def50be18e4632 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bad2bf7d98b44b7668e86428e604811 = $(`&lt;div id=&quot;html_0bad2bf7d98b44b7668e86428e604811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3c9321f58b6a7b01d9def50be18e4632.setContent(html_0bad2bf7d98b44b7668e86428e604811);
#
#
#
#         marker_21e927fcdc481909e64c895c1dda6cfb.bindPopup(popup_3c9321f58b6a7b01d9def50be18e4632)
#         ;
#
#
#
#
#             var marker_2ceda38aaba0a62af3e9270e2ff54bd8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef7946e47687ebf7929f6f97bcf9f6c7);
#
#
#         var popup_14fd1bc7c8047a7f9a087f0152682511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d54cbf0ea41502db8dda267afc6e7883 = $(`&lt;div id=&quot;html_d54cbf0ea41502db8dda267afc6e7883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_14fd1bc7c8047a7f9a087f0152682511.setContent(html_d54cbf0ea41502db8dda267afc6e7883);
#
#
#
#         mark
