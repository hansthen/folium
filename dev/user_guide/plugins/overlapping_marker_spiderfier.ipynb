# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a47972da18a945d4ce94f998064f47d7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a47972da18a945d4ce94f998064f47d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a47972da18a945d4ce94f998064f47d7 = L.map(
#                 &quot;map_a47972da18a945d4ce94f998064f47d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6f23beaf6ce424cc6635cafd55b4664 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6f23beaf6ce424cc6635cafd55b4664.addTo(map_a47972da18a945d4ce94f998064f47d7);
#
#
#             var marker_ea182dda65a75c0decc6f668296ec988 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a47972da18a945d4ce94f998064f47d7);
#
#
#         var popup_8c1c2c75d82f8ea3018af86d67f4c2bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42ef84457ed533e908b0368cf137312c = $(`&lt;div id=&quot;html_42ef84457ed533e908b0368cf137312c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8c1c2c75d82f8ea3018af86d67f4c2bc.setContent(html_42ef84457ed533e908b0368cf137312c);
#
#
#
#         marker_ea182dda65a75c0decc6f668296ec988.bindPopup(popup_8c1c2c75d82f8ea3018af86d67f4c2bc)
#         ;
#
#
#
#
#             var marker_ff9e08164c41c9ab2f87258d7540e5bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a47972da18a945d4ce94f998064f47d7);
#
#
#         var popup_03dc2996a65d57b12bdcb3ac313a2bbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a483fadb88396012f189f01d2ba30845 = $(`&lt;div id=&quot;html_a483fadb88396012f189f01d2ba30845&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_03dc2996a65d57b12bdcb3ac313a2bbf.setContent(html_a483fadb88396012f189f01d2ba30845);
#
#
#
#         marker_ff9e08164c41c9ab2f87258d7540e5bb.bindPopup(popup_03dc2996a65d57b12bdcb3ac313a2bbf)
#         ;
#
#
#
#
#             var marker_5fee4f8ceb07b18573a15af6926be6cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a47972da18a945d4ce94f998064f47d7);
#
#
#         var popup_6fd32ba87f292b455297733c3082bb40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c5804a028520dc16fb4529679e4ec1c = $(`&lt;div id=&quot;html_7c5804a028520dc16fb4529679e4ec1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6fd32ba87f292b455297733c3082bb40.setContent(html_7c5804a028520dc16fb4529679e4ec1c);
#
#
#
#         marker_5fee4f8ceb07b18573a15af6926be6cf.bindPopup(popup_6fd32ba87f292b455297733c3082bb40)
#         ;
#
#
#
#
#             var marker_23a78834b951aad3f3773de1b1d59ba4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a47972da18a945d4ce94f998064f47d7);
#
#
#         var popup_e54f1a2d982e011c5e814bb104896485 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37d7caa2aec96925c8d3a6e11e5d1f41 = $(`&lt;div id=&quot;html_37d7caa2aec96925c8d3a6e11e5d1f41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e54f1a2d982e011c5e814bb104896485.setContent(html_37d7caa2aec96925c8d3a6e11e5d1f41);
#
#
#
#         marker_23a78834b951aad3f3773de1b1d59ba4.bindPopup(popup_e54f1a2d982e011c5e814bb104896485)
#         ;
#
#
#
#
#             var marker_c1e3a493346ea608e9157e8a878165ab = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a47972da18a945d4ce94f998064f47d7);
#
#
#         var popup_e198eda2d07a05327eebb63e30b0a1a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c925a58d4e927e8e10ac5add552db07 = $(`&lt;div id=&quot;html_2c925a58d4e927e8e10ac5add552db07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e198eda2d07a05327eebb63e30b0a1

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fcddd720fa126f0c80bddb6b6c643b7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fcddd720fa126f0c80bddb6b6c643b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fcddd720fa126f0c80bddb6b6c643b7 = L.map(
#                 &quot;map_9fcddd720fa126f0c80bddb6b6c643b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96afc9aabaaa6be791d982011e769286 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96afc9aabaaa6be791d982011e769286.addTo(map_9fcddd720fa126f0c80bddb6b6c643b7);
#
#
#             var feature_group_5435762397c8a427ded015e2a39cbab9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fb3a69e45cf94a7625d3577d6f55d018 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5435762397c8a427ded015e2a39cbab9);
#
#
#         var popup_514ff47ce191ddfd62957ec6a8e28a94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_605d03c7c2edc439a7f354f4c83f5e82 = $(`&lt;div id=&quot;html_605d03c7c2edc439a7f354f4c83f5e82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_514ff47ce191ddfd62957ec6a8e28a94.setContent(html_605d03c7c2edc439a7f354f4c83f5e82);
#
#
#
#         marker_fb3a69e45cf94a7625d3577d6f55d018.bindPopup(popup_514ff47ce191ddfd62957ec6a8e28a94)
#         ;
#
#
#
#
#             var marker_66d65a863e11481fdcca8f969968c684 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5435762397c8a427ded015e2a39cbab9);
#
#
#         var popup_fc87d160d69e7d26450a91f8ba348a86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_466c85d66e24cac13e2636c77c248c20 = $(`&lt;div id=&quot;html_466c85d66e24cac13e2636c77c248c20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fc87d160d69e7d26450a91f8ba348a86.setContent(html_466c85d66e24cac13e2636c77c248c20);
#
#
#
#         marker_66d65a863e11481fdcca8f969968c684.bindPopup(popup_fc87d160d69e7d26450a91f8ba348a86)
#         ;
#
#
#
#
#             var marker_4873ff2f6ae5f467d961c7e8dfca905a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5435762397c8a427ded015e2a39cbab9);
#
#
#         var popup_f533e4b0748849276cae7acbdea4ab97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f562105bab2f532b4fb154c08e15924 = $(`&lt;div id=&quot;html_3f562105bab2f532b4fb154c08e15924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f533e4b0748849276cae7acbdea4ab97.setContent(html_3f562105bab2f532b4fb154c08e15924);
#
#
#
#         marker_4873ff2f6ae5f467d961c7e8dfca905a.bindPopup(popup_f533e4b0748849276cae7acbdea4ab97)
#         ;
#
#
#
#
#             var marker_6a1f06687822ced90b3a8a4ec4bc79e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5435762397c8a427ded015e2a39cbab9);
#
#
#         var popup_1e5366bc3891620bdce621d18dcf9eda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0924b9f238c5b2f28222e0c90a807380 = $(`&lt;div id=&quot;html_0924b9f238c5b2f28222e0c90a807380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1e5366bc3891620bdce621d18dcf9eda.setContent(html_0924b9f238c5b2f28222e0c90a807380);
#
#
#
#         marker_6a1f06687822ced90b3a8a4ec4bc79e5.bindPopup(popup_1e5366bc3891620bdce621d18dcf9eda)
#         ;
#
#
#
#
#             var marker_b013cd1ff976d1fbc477df371da34739 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5435762397c8a427ded015e2a39cbab9);
#
#
#         var popup_fe3d985c6e395372742d82937ce34f9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7597f6297a778172eaba4207205dce97 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7597f6297a778172eaba4207205dce97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7597f6297a778172eaba4207205dce97 = L.map(
#                 &quot;map_7597f6297a778172eaba4207205dce97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f47fbcb319c883aa8372b740dd203e7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f47fbcb319c883aa8372b740dd203e7a.addTo(map_7597f6297a778172eaba4207205dce97);
#
#
#             var feature_group_e6d3d9cc7d335c9b2920eb1c5207c9ab = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e6d3d9cc7d335c9b2920eb1c5207c9ab.addTo(map_7597f6297a778172eaba4207205dce97);
#
#
#             var feature_group_sub_group_5f6e940ff395ce73b79c765ccbe24d4f = L.featureGroup.subGroup(
#                 feature_group_e6d3d9cc7d335c9b2920eb1c5207c9ab
#             );
#
#
#             var marker_306b3b91fc62d401b39447938cb84fa9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6e940ff395ce73b79c765ccbe24d4f);
#
#
#         var popup_1d7eeeffb0defc041132dc8f2af1543f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11d78bf3c97bbb982c51eea9708cd678 = $(`&lt;div id=&quot;html_11d78bf3c97bbb982c51eea9708cd678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1d7eeeffb0defc041132dc8f2af1543f.setContent(html_11d78bf3c97bbb982c51eea9708cd678);
#
#
#
#         marker_306b3b91fc62d401b39447938cb84fa9.bindPopup(popup_1d7eeeffb0defc041132dc8f2af1543f)
#         ;
#
#
#
#
#             var marker_56ee4b954129191d168c3ad354e1f12f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6e940ff395ce73b79c765ccbe24d4f);
#
#
#         var popup_3d9a1b8170fb9345958cb28a54b2d6e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01fc8f261416dbc493bfe54fcfbdfc67 = $(`&lt;div id=&quot;html_01fc8f261416dbc493bfe54fcfbdfc67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3d9a1b8170fb9345958cb28a54b2d6e5.setContent(html_01fc8f261416dbc493bfe54fcfbdfc67);
#
#
#
#         marker_56ee4b954129191d168c3ad354e1f12f.bindPopup(popup_3d9a1b8170fb9345958cb28a54b2d6e5)
#         ;
#
#
#
#
#             var marker_73e59460cd200b5fd3184791d071ddd7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6e940ff395ce73b79c765ccbe24d4f);
#
#
#         var popup_a3a106873e1728bc3cba6de797b4e13a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8043ba72644c768aa98fbd086c18240c = $(`&lt;div id=&quot;html_8043ba72644c768aa98fbd086c18240c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a3a106873e1728bc3cba6de797b4e13a.setContent(html_8043ba72644c768aa98fbd086c18240c);
#
#
#
#         marker_73e59460cd200b5fd3184791d071ddd7.bindPopup(popup_a3a106873e1728bc3cba6de797b4e13a)
#         ;
#
#
#
#
#             var marker_3542dbc118194bc4634e9d4f7f4543e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f6e940ff395ce73b79c765ccbe24d4f);
#
#
#         var popup_78c40a213645e051eb6a3e71ebb5bc99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11dd73af7ec8c42694a5ecbdf2ac4deb = $(`&lt;div id=&quot;html_11dd73af7ec8c42694a5ecbdf2ac4deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_78c40a213645e051eb6a3e71ebb5bc99.setContent(html_11dd73af7ec8c42694a5ecbdf2ac4deb);
#
#
#
#         mark
