# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_428e3ac228bdf6524c3874be77151ce8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_428e3ac228bdf6524c3874be77151ce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_428e3ac228bdf6524c3874be77151ce8 = L.map(
#                 &quot;map_428e3ac228bdf6524c3874be77151ce8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_813d6ee61b2295802f9e7b39dc3fe5cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_813d6ee61b2295802f9e7b39dc3fe5cb.addTo(map_428e3ac228bdf6524c3874be77151ce8);
#
#
#             var marker_61e5cb3acc11c91c2816c9aefa7a7943 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_428e3ac228bdf6524c3874be77151ce8);
#
#
#         var popup_320d50cccc020f81170f1cab77915676 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bab5707fec47135cfd8043097dd69b4 = $(`&lt;div id=&quot;html_0bab5707fec47135cfd8043097dd69b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_320d50cccc020f81170f1cab77915676.setContent(html_0bab5707fec47135cfd8043097dd69b4);
#
#
#
#         marker_61e5cb3acc11c91c2816c9aefa7a7943.bindPopup(popup_320d50cccc020f81170f1cab77915676)
#         ;
#
#
#
#
#             var marker_27fc2b06f40028ce5896666bbb8d68e7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_428e3ac228bdf6524c3874be77151ce8);
#
#
#         var popup_df91ff8b9c160ffd14217f7768c855ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4afdb814fdf8472ed86b603b520e6d8c = $(`&lt;div id=&quot;html_4afdb814fdf8472ed86b603b520e6d8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_df91ff8b9c160ffd14217f7768c855ad.setContent(html_4afdb814fdf8472ed86b603b520e6d8c);
#
#
#
#         marker_27fc2b06f40028ce5896666bbb8d68e7.bindPopup(popup_df91ff8b9c160ffd14217f7768c855ad)
#         ;
#
#
#
#
#             var marker_f6f81d58b1dd27ce57317a6fb1021e57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_428e3ac228bdf6524c3874be77151ce8);
#
#
#         var popup_44473eacc6db529a49e630c01585140e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f150b933f649e44c2434de3f45ba0c01 = $(`&lt;div id=&quot;html_f150b933f649e44c2434de3f45ba0c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_44473eacc6db529a49e630c01585140e.setContent(html_f150b933f649e44c2434de3f45ba0c01);
#
#
#
#         marker_f6f81d58b1dd27ce57317a6fb1021e57.bindPopup(popup_44473eacc6db529a49e630c01585140e)
#         ;
#
#
#
#
#             var marker_b7db0620c67a2173d085b0f3768c2531 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_428e3ac228bdf6524c3874be77151ce8);
#
#
#         var popup_e5c99aca224d69b87f0be938f682b9d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b51df8a4b6f3e31a0bee3320733395c = $(`&lt;div id=&quot;html_9b51df8a4b6f3e31a0bee3320733395c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e5c99aca224d69b87f0be938f682b9d9.setContent(html_9b51df8a4b6f3e31a0bee3320733395c);
#
#
#
#         marker_b7db0620c67a2173d085b0f3768c2531.bindPopup(popup_e5c99aca224d69b87f0be938f682b9d9)
#         ;
#
#
#
#
#             var marker_fb10bc47fd8a02310456028561025a4f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_428e3ac228bdf6524c3874be77151ce8);
#
#
#         var popup_851a0c74d3976097c9c9be6aede80ec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeaab4010e0567eff376c27206640746 = $(`&lt;div id=&quot;html_eeaab4010e0567eff376c27206640746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_851a0c74d3976097c9c9be6aede80e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_067095853cbf5e99b167df60329c01f0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_067095853cbf5e99b167df60329c01f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_067095853cbf5e99b167df60329c01f0 = L.map(
#                 &quot;map_067095853cbf5e99b167df60329c01f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eb8c30014b32490ba3b8d765e3bea98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5eb8c30014b32490ba3b8d765e3bea98.addTo(map_067095853cbf5e99b167df60329c01f0);
#
#
#             var feature_group_b1ce2aff28f9c0fa2dce9177af85fc92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_102efbdf00e2e85b38c10ce52c9a4186 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b1ce2aff28f9c0fa2dce9177af85fc92);
#
#
#         var popup_c6f56d1df1e45324af1435fd275c22c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c646256983d343f1272806c85f12ce7 = $(`&lt;div id=&quot;html_1c646256983d343f1272806c85f12ce7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c6f56d1df1e45324af1435fd275c22c6.setContent(html_1c646256983d343f1272806c85f12ce7);
#
#
#
#         marker_102efbdf00e2e85b38c10ce52c9a4186.bindPopup(popup_c6f56d1df1e45324af1435fd275c22c6)
#         ;
#
#
#
#
#             var marker_9018a72233fd978e90df34366fdda4a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b1ce2aff28f9c0fa2dce9177af85fc92);
#
#
#         var popup_44d58b287651df0c360f48aa74e8b325 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbe1b320ad2b3e9545fe92603cbb8c01 = $(`&lt;div id=&quot;html_bbe1b320ad2b3e9545fe92603cbb8c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_44d58b287651df0c360f48aa74e8b325.setContent(html_bbe1b320ad2b3e9545fe92603cbb8c01);
#
#
#
#         marker_9018a72233fd978e90df34366fdda4a7.bindPopup(popup_44d58b287651df0c360f48aa74e8b325)
#         ;
#
#
#
#
#             var marker_2ae4538275f7ce68aa934e26143ae84b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b1ce2aff28f9c0fa2dce9177af85fc92);
#
#
#         var popup_49885f1297369eefcf8b88c6178f737f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da2c33c2a3e645c5cbdd1b809ace744b = $(`&lt;div id=&quot;html_da2c33c2a3e645c5cbdd1b809ace744b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_49885f1297369eefcf8b88c6178f737f.setContent(html_da2c33c2a3e645c5cbdd1b809ace744b);
#
#
#
#         marker_2ae4538275f7ce68aa934e26143ae84b.bindPopup(popup_49885f1297369eefcf8b88c6178f737f)
#         ;
#
#
#
#
#             var marker_be27990fcf2d4c418c7777b9bf012af4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b1ce2aff28f9c0fa2dce9177af85fc92);
#
#
#         var popup_fcf4fb15150817db8320f34646fd4237 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2bfd1f6a153c295497002937de8596d = $(`&lt;div id=&quot;html_b2bfd1f6a153c295497002937de8596d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fcf4fb15150817db8320f34646fd4237.setContent(html_b2bfd1f6a153c295497002937de8596d);
#
#
#
#         marker_be27990fcf2d4c418c7777b9bf012af4.bindPopup(popup_fcf4fb15150817db8320f34646fd4237)
#         ;
#
#
#
#
#             var marker_81440109013c4844fd2e63857ad46249 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b1ce2aff28f9c0fa2dce9177af85fc92);
#
#
#         var popup_162ef906d8edb79f46918e774b530285 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57f41852bb8d557241bff42df4476c67 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57f41852bb8d557241bff42df4476c67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57f41852bb8d557241bff42df4476c67 = L.map(
#                 &quot;map_57f41852bb8d557241bff42df4476c67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad9ff78de9866b456203c39c4e5e1661 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad9ff78de9866b456203c39c4e5e1661.addTo(map_57f41852bb8d557241bff42df4476c67);
#
#
#             var feature_group_dc59d2d377c5562f97ef8e1a76eaae29 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dc59d2d377c5562f97ef8e1a76eaae29.addTo(map_57f41852bb8d557241bff42df4476c67);
#
#
#             var feature_group_sub_group_f5c33a9f00ff69b4fefb47a73b64e0ad = L.featureGroup.subGroup(
#                 feature_group_dc59d2d377c5562f97ef8e1a76eaae29
#             );
#
#
#             var marker_6c4345d6c677c12497596c0a263567ca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f5c33a9f00ff69b4fefb47a73b64e0ad);
#
#
#         var popup_bd3bf1b237d0454182ba602e19b5bff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7afc54a4da910c4b36e8bf16ef38cea9 = $(`&lt;div id=&quot;html_7afc54a4da910c4b36e8bf16ef38cea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bd3bf1b237d0454182ba602e19b5bff4.setContent(html_7afc54a4da910c4b36e8bf16ef38cea9);
#
#
#
#         marker_6c4345d6c677c12497596c0a263567ca.bindPopup(popup_bd3bf1b237d0454182ba602e19b5bff4)
#         ;
#
#
#
#
#             var marker_4796a1d767dec388afb02d97a716e308 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f5c33a9f00ff69b4fefb47a73b64e0ad);
#
#
#         var popup_cdd8126f6459e8494319b88857cfc064 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d66fe33b3de2e77da1509a10d9155495 = $(`&lt;div id=&quot;html_d66fe33b3de2e77da1509a10d9155495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cdd8126f6459e8494319b88857cfc064.setContent(html_d66fe33b3de2e77da1509a10d9155495);
#
#
#
#         marker_4796a1d767dec388afb02d97a716e308.bindPopup(popup_cdd8126f6459e8494319b88857cfc064)
#         ;
#
#
#
#
#             var marker_056b71ae11ad23346ab3b93dae2ae6fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f5c33a9f00ff69b4fefb47a73b64e0ad);
#
#
#         var popup_99e8277d9a5c2838851070d70d4e195c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2829a8985ad193214610a4687302050b = $(`&lt;div id=&quot;html_2829a8985ad193214610a4687302050b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_99e8277d9a5c2838851070d70d4e195c.setContent(html_2829a8985ad193214610a4687302050b);
#
#
#
#         marker_056b71ae11ad23346ab3b93dae2ae6fc.bindPopup(popup_99e8277d9a5c2838851070d70d4e195c)
#         ;
#
#
#
#
#             var marker_c02231253e3027a7ed9952806544ab23 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f5c33a9f00ff69b4fefb47a73b64e0ad);
#
#
#         var popup_77ceb40b25da52a4ee2f29754c8f813a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40d8fb039d7e7b4ca4cba16d7af075e6 = $(`&lt;div id=&quot;html_40d8fb039d7e7b4ca4cba16d7af075e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_77ceb40b25da52a4ee2f29754c8f813a.setContent(html_40d8fb039d7e7b4ca4cba16d7af075e6);
#
#
#
#         mark
