# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3dd5410bf7e3d4cadaa70bbad6408bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3dd5410bf7e3d4cadaa70bbad6408bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3dd5410bf7e3d4cadaa70bbad6408bb = L.map(
#                 &quot;map_c3dd5410bf7e3d4cadaa70bbad6408bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fec971cf1cab7562f289274a25f16b3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fec971cf1cab7562f289274a25f16b3d.addTo(map_c3dd5410bf7e3d4cadaa70bbad6408bb);
#
#
#             var marker_d1dfe57b2043415f1e77ea5b3cf84a2c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c3dd5410bf7e3d4cadaa70bbad6408bb);
#
#
#         var popup_b3201734a684c8947da00f121ede9083 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_480123b26bce6a1a744727736e485057 = $(`&lt;div id=&quot;html_480123b26bce6a1a744727736e485057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b3201734a684c8947da00f121ede9083.setContent(html_480123b26bce6a1a744727736e485057);
#
#
#
#         marker_d1dfe57b2043415f1e77ea5b3cf84a2c.bindPopup(popup_b3201734a684c8947da00f121ede9083)
#         ;
#
#
#
#
#             var marker_12b0002c2ac271ea28be523e3b1b5148 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c3dd5410bf7e3d4cadaa70bbad6408bb);
#
#
#         var popup_1a42319bfcfd34ca029a70cd3c624aff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d06fae0485b67cb931afa004b94250c = $(`&lt;div id=&quot;html_2d06fae0485b67cb931afa004b94250c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1a42319bfcfd34ca029a70cd3c624aff.setContent(html_2d06fae0485b67cb931afa004b94250c);
#
#
#
#         marker_12b0002c2ac271ea28be523e3b1b5148.bindPopup(popup_1a42319bfcfd34ca029a70cd3c624aff)
#         ;
#
#
#
#
#             var marker_c53139f384d97528788fcb3ebad77667 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c3dd5410bf7e3d4cadaa70bbad6408bb);
#
#
#         var popup_4f00dd16856f4b0155359660d3bbe166 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5a5dfb680cd131729ca3ea982729a31 = $(`&lt;div id=&quot;html_a5a5dfb680cd131729ca3ea982729a31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4f00dd16856f4b0155359660d3bbe166.setContent(html_a5a5dfb680cd131729ca3ea982729a31);
#
#
#
#         marker_c53139f384d97528788fcb3ebad77667.bindPopup(popup_4f00dd16856f4b0155359660d3bbe166)
#         ;
#
#
#
#
#             var marker_136126c9b28df0694cee797837eba4f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c3dd5410bf7e3d4cadaa70bbad6408bb);
#
#
#         var popup_8d78b83db2141d0293ab407a79262549 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84fb326ff5c8d5b5837b68165dd7a2fd = $(`&lt;div id=&quot;html_84fb326ff5c8d5b5837b68165dd7a2fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8d78b83db2141d0293ab407a79262549.setContent(html_84fb326ff5c8d5b5837b68165dd7a2fd);
#
#
#
#         marker_136126c9b28df0694cee797837eba4f4.bindPopup(popup_8d78b83db2141d0293ab407a79262549)
#         ;
#
#
#
#
#             var marker_b66860ded850a0a06615c01d71997900 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c3dd5410bf7e3d4cadaa70bbad6408bb);
#
#
#         var popup_0ee059fd19f21da8ee9b829e06ec24e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f63c0a63e4999ffc4694107d00baf8f = $(`&lt;div id=&quot;html_4f63c0a63e4999ffc4694107d00baf8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0ee059fd19f21da8ee9b829e06ec24e9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf1110c2236617fdb4ad8f103ff22097 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf1110c2236617fdb4ad8f103ff22097&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf1110c2236617fdb4ad8f103ff22097 = L.map(
#                 &quot;map_bf1110c2236617fdb4ad8f103ff22097&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6f49ac91f746a2ece9cec75e04648ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6f49ac91f746a2ece9cec75e04648ab.addTo(map_bf1110c2236617fdb4ad8f103ff22097);
#
#
#             var feature_group_3a5628581ea5545319166e9963fa814d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2572c9f2f6e312e95d90e40ff924a2b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3a5628581ea5545319166e9963fa814d);
#
#
#         var popup_4be77a8ae40bb53937a16291679161a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f420f3e9f49d95a254227a7aeb7fbe53 = $(`&lt;div id=&quot;html_f420f3e9f49d95a254227a7aeb7fbe53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4be77a8ae40bb53937a16291679161a0.setContent(html_f420f3e9f49d95a254227a7aeb7fbe53);
#
#
#
#         marker_2572c9f2f6e312e95d90e40ff924a2b2.bindPopup(popup_4be77a8ae40bb53937a16291679161a0)
#         ;
#
#
#
#
#             var marker_169961c3dcf12f61a9293832b4794297 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3a5628581ea5545319166e9963fa814d);
#
#
#         var popup_3d36adc08c2c01749a51c3987ac95d9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4038e2c018c09032b8ad815b20c44d83 = $(`&lt;div id=&quot;html_4038e2c018c09032b8ad815b20c44d83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3d36adc08c2c01749a51c3987ac95d9b.setContent(html_4038e2c018c09032b8ad815b20c44d83);
#
#
#
#         marker_169961c3dcf12f61a9293832b4794297.bindPopup(popup_3d36adc08c2c01749a51c3987ac95d9b)
#         ;
#
#
#
#
#             var marker_ae788954da8078bffcfb21f45f28a3d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3a5628581ea5545319166e9963fa814d);
#
#
#         var popup_7fe7bb8483eaf2728df8bbf9a089c5dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea74ac65f117496410777eb4062ee376 = $(`&lt;div id=&quot;html_ea74ac65f117496410777eb4062ee376&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7fe7bb8483eaf2728df8bbf9a089c5dc.setContent(html_ea74ac65f117496410777eb4062ee376);
#
#
#
#         marker_ae788954da8078bffcfb21f45f28a3d0.bindPopup(popup_7fe7bb8483eaf2728df8bbf9a089c5dc)
#         ;
#
#
#
#
#             var marker_6f3a8e949f678005ad918edfebe22957 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3a5628581ea5545319166e9963fa814d);
#
#
#         var popup_c80aa73f8d6748ed021c8c0e41af0d5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42e66a2b93117c3ad5e1cf93b8012061 = $(`&lt;div id=&quot;html_42e66a2b93117c3ad5e1cf93b8012061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c80aa73f8d6748ed021c8c0e41af0d5d.setContent(html_42e66a2b93117c3ad5e1cf93b8012061);
#
#
#
#         marker_6f3a8e949f678005ad918edfebe22957.bindPopup(popup_c80aa73f8d6748ed021c8c0e41af0d5d)
#         ;
#
#
#
#
#             var marker_05aed5704b7e51e8d6bff624445c6f9d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3a5628581ea5545319166e9963fa814d);
#
#
#         var popup_afa06c24d7d3e48fb4b560283f286ac2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1be7185ff7f4ca912b10cc922cba0ab8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1be7185ff7f4ca912b10cc922cba0ab8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1be7185ff7f4ca912b10cc922cba0ab8 = L.map(
#                 &quot;map_1be7185ff7f4ca912b10cc922cba0ab8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0da7592e53a0510cc999d6326f6b2738 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0da7592e53a0510cc999d6326f6b2738.addTo(map_1be7185ff7f4ca912b10cc922cba0ab8);
#
#
#             var feature_group_4fc95e7a2091eb0d8edf34e76619293f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4fc95e7a2091eb0d8edf34e76619293f.addTo(map_1be7185ff7f4ca912b10cc922cba0ab8);
#
#
#             var feature_group_sub_group_c55e194cc4736da189dedf0d76bbe3fb = L.featureGroup.subGroup(
#                 feature_group_4fc95e7a2091eb0d8edf34e76619293f
#             );
#
#
#             var marker_73e69610e0ae0cfc277ed984f3f6ff80 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c55e194cc4736da189dedf0d76bbe3fb);
#
#
#         var popup_0cdb59223cfc80f56fa595bda131f63f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5265c513a86bf28e9df279c5d05978ea = $(`&lt;div id=&quot;html_5265c513a86bf28e9df279c5d05978ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0cdb59223cfc80f56fa595bda131f63f.setContent(html_5265c513a86bf28e9df279c5d05978ea);
#
#
#
#         marker_73e69610e0ae0cfc277ed984f3f6ff80.bindPopup(popup_0cdb59223cfc80f56fa595bda131f63f)
#         ;
#
#
#
#
#             var marker_c59eacaa1cef02f20a0a8e896cda3a2c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c55e194cc4736da189dedf0d76bbe3fb);
#
#
#         var popup_0c066cb90f3383c4cad07f3ed57f3361 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d391058c2acab1f8821226ca8f0efff = $(`&lt;div id=&quot;html_2d391058c2acab1f8821226ca8f0efff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0c066cb90f3383c4cad07f3ed57f3361.setContent(html_2d391058c2acab1f8821226ca8f0efff);
#
#
#
#         marker_c59eacaa1cef02f20a0a8e896cda3a2c.bindPopup(popup_0c066cb90f3383c4cad07f3ed57f3361)
#         ;
#
#
#
#
#             var marker_3865f702b51d779037c46cdff0a03dc1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c55e194cc4736da189dedf0d76bbe3fb);
#
#
#         var popup_88c0c844f2a76332a9aa3a67af21bd1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_953da478949a14eb5ffe4af2a649132b = $(`&lt;div id=&quot;html_953da478949a14eb5ffe4af2a649132b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88c0c844f2a76332a9aa3a67af21bd1f.setContent(html_953da478949a14eb5ffe4af2a649132b);
#
#
#
#         marker_3865f702b51d779037c46cdff0a03dc1.bindPopup(popup_88c0c844f2a76332a9aa3a67af21bd1f)
#         ;
#
#
#
#
#             var marker_11be81ba09013b8818e9d0f2c82f16af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c55e194cc4736da189dedf0d76bbe3fb);
#
#
#         var popup_ab205d7fab827c0bf82063aeefd95c5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f58ca0bc6519f8ea2d6488fe734f843b = $(`&lt;div id=&quot;html_f58ca0bc6519f8ea2d6488fe734f843b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ab205d7fab827c0bf82063aeefd95c5d.setContent(html_f58ca0bc6519f8ea2d6488fe734f843b);
#
#
#
#         marker_
