# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bd55cc71a5470d1667279ec736e07d3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bd55cc71a5470d1667279ec736e07d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bd55cc71a5470d1667279ec736e07d3 = L.map(
#                 &quot;map_5bd55cc71a5470d1667279ec736e07d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bed925b2243bb80506d903b4763f130 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bed925b2243bb80506d903b4763f130.addTo(map_5bd55cc71a5470d1667279ec736e07d3);
#
#
#             var marker_b91fc7ee7d4c34482713566564d7491a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5bd55cc71a5470d1667279ec736e07d3);
#
#
#         var popup_35db382e7ec53943a095b6650488493e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_181431a57b50e574173afd543d99125e = $(`&lt;div id=&quot;html_181431a57b50e574173afd543d99125e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_35db382e7ec53943a095b6650488493e.setContent(html_181431a57b50e574173afd543d99125e);
#
#
#
#         marker_b91fc7ee7d4c34482713566564d7491a.bindPopup(popup_35db382e7ec53943a095b6650488493e)
#         ;
#
#
#
#
#             var marker_e4acc1610daa0fa598b5e0e3697611bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5bd55cc71a5470d1667279ec736e07d3);
#
#
#         var popup_8354b076cc308d0bbda5c3f74a400b84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42b6431730f778d054e5fa09e4e8aa9b = $(`&lt;div id=&quot;html_42b6431730f778d054e5fa09e4e8aa9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8354b076cc308d0bbda5c3f74a400b84.setContent(html_42b6431730f778d054e5fa09e4e8aa9b);
#
#
#
#         marker_e4acc1610daa0fa598b5e0e3697611bd.bindPopup(popup_8354b076cc308d0bbda5c3f74a400b84)
#         ;
#
#
#
#
#             var marker_53d5439a32749ee9c2db1848f256d89b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5bd55cc71a5470d1667279ec736e07d3);
#
#
#         var popup_26ef9e15908100bb51607d8cdb41ec32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d00b6ea1600933e73db467a9f6402c38 = $(`&lt;div id=&quot;html_d00b6ea1600933e73db467a9f6402c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_26ef9e15908100bb51607d8cdb41ec32.setContent(html_d00b6ea1600933e73db467a9f6402c38);
#
#
#
#         marker_53d5439a32749ee9c2db1848f256d89b.bindPopup(popup_26ef9e15908100bb51607d8cdb41ec32)
#         ;
#
#
#
#
#             var marker_17023455f1b640e2255069543a195a29 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5bd55cc71a5470d1667279ec736e07d3);
#
#
#         var popup_1a16f69127acf77def4c04c0c85855b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08ade641aad4a47b756e1ccc2b812801 = $(`&lt;div id=&quot;html_08ade641aad4a47b756e1ccc2b812801&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1a16f69127acf77def4c04c0c85855b7.setContent(html_08ade641aad4a47b756e1ccc2b812801);
#
#
#
#         marker_17023455f1b640e2255069543a195a29.bindPopup(popup_1a16f69127acf77def4c04c0c85855b7)
#         ;
#
#
#
#
#             var marker_9d990f573082fedeedeeba50b765493e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5bd55cc71a5470d1667279ec736e07d3);
#
#
#         var popup_a1d958a5be33d63be031bdfcb0baa0e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_103b4c29bc9b38f6ae04cb1095600655 = $(`&lt;div id=&quot;html_103b4c29bc9b38f6ae04cb1095600655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a1d958a5be33d63be031bdfcb0baa0

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fea1a062c7645dfbca7cda4ce961ab65 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fea1a062c7645dfbca7cda4ce961ab65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fea1a062c7645dfbca7cda4ce961ab65 = L.map(
#                 &quot;map_fea1a062c7645dfbca7cda4ce961ab65&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8433ec52d9fca8ca76ce058cc41218a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8433ec52d9fca8ca76ce058cc41218a.addTo(map_fea1a062c7645dfbca7cda4ce961ab65);
#
#
#             var feature_group_2aa194189d40ab87ff04911aaf4979c0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_10bac743e53073c360744b53c055c25d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2aa194189d40ab87ff04911aaf4979c0);
#
#
#         var popup_742f3f59209c35287bdfd8a0f2ab69d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2e6b1cfd7d729d39cc36d8ef7a6e102 = $(`&lt;div id=&quot;html_f2e6b1cfd7d729d39cc36d8ef7a6e102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_742f3f59209c35287bdfd8a0f2ab69d1.setContent(html_f2e6b1cfd7d729d39cc36d8ef7a6e102);
#
#
#
#         marker_10bac743e53073c360744b53c055c25d.bindPopup(popup_742f3f59209c35287bdfd8a0f2ab69d1)
#         ;
#
#
#
#
#             var marker_1aaa85c7c32fc8af6d2e0d8e331648c1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2aa194189d40ab87ff04911aaf4979c0);
#
#
#         var popup_7f4f3a0ae2456cc68e26c266f064aece = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0b5eb140fd0753602958b6290049be4 = $(`&lt;div id=&quot;html_c0b5eb140fd0753602958b6290049be4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7f4f3a0ae2456cc68e26c266f064aece.setContent(html_c0b5eb140fd0753602958b6290049be4);
#
#
#
#         marker_1aaa85c7c32fc8af6d2e0d8e331648c1.bindPopup(popup_7f4f3a0ae2456cc68e26c266f064aece)
#         ;
#
#
#
#
#             var marker_2ebcce887c4c02db67d9c695f4d655be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2aa194189d40ab87ff04911aaf4979c0);
#
#
#         var popup_0f0bfcc794b24910c4fca036c7ac0788 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f40acdd2c5110b9dc1b2a14c774204dc = $(`&lt;div id=&quot;html_f40acdd2c5110b9dc1b2a14c774204dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0f0bfcc794b24910c4fca036c7ac0788.setContent(html_f40acdd2c5110b9dc1b2a14c774204dc);
#
#
#
#         marker_2ebcce887c4c02db67d9c695f4d655be.bindPopup(popup_0f0bfcc794b24910c4fca036c7ac0788)
#         ;
#
#
#
#
#             var marker_bd5bd20d95f5249dad09b7c9d2d4b804 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2aa194189d40ab87ff04911aaf4979c0);
#
#
#         var popup_2d4bb9b3341dc0982f4f6bdc2d2cd827 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9539865ec4251a7418d62a05393f5180 = $(`&lt;div id=&quot;html_9539865ec4251a7418d62a05393f5180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2d4bb9b3341dc0982f4f6bdc2d2cd827.setContent(html_9539865ec4251a7418d62a05393f5180);
#
#
#
#         marker_bd5bd20d95f5249dad09b7c9d2d4b804.bindPopup(popup_2d4bb9b3341dc0982f4f6bdc2d2cd827)
#         ;
#
#
#
#
#             var marker_92aa2670492cb004476ceb0e6855a868 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2aa194189d40ab87ff04911aaf4979c0);
#
#
#         var popup_b3ff797a3ad7d0edc73cf92b6841911b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_febe89c39a8d6f9e287c7ae34a4cfcec {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_febe89c39a8d6f9e287c7ae34a4cfcec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_febe89c39a8d6f9e287c7ae34a4cfcec = L.map(
#                 &quot;map_febe89c39a8d6f9e287c7ae34a4cfcec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53f6d54bce1c7dad575b81ec44461cdd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53f6d54bce1c7dad575b81ec44461cdd.addTo(map_febe89c39a8d6f9e287c7ae34a4cfcec);
#
#
#             var feature_group_95c7676f3f505ff31cbee3a390b61c53 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_95c7676f3f505ff31cbee3a390b61c53.addTo(map_febe89c39a8d6f9e287c7ae34a4cfcec);
#
#
#             var feature_group_sub_group_ef32fcd842107fc35e6c3bf6946f001f = L.featureGroup.subGroup(
#                 feature_group_95c7676f3f505ff31cbee3a390b61c53
#             );
#
#
#             var marker_df5d371d1c90b5a13cc80a3e37bf10a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef32fcd842107fc35e6c3bf6946f001f);
#
#
#         var popup_33524e7561f7d7b89cbabc6d7138f132 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b363cae67c43db55353f739f8b1096ef = $(`&lt;div id=&quot;html_b363cae67c43db55353f739f8b1096ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_33524e7561f7d7b89cbabc6d7138f132.setContent(html_b363cae67c43db55353f739f8b1096ef);
#
#
#
#         marker_df5d371d1c90b5a13cc80a3e37bf10a2.bindPopup(popup_33524e7561f7d7b89cbabc6d7138f132)
#         ;
#
#
#
#
#             var marker_d20a591eff9f2e75c746b14667ab48ba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef32fcd842107fc35e6c3bf6946f001f);
#
#
#         var popup_cd348dc9674fdd2c5659a633c5a6bfcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55b97d7dc7cc86bb5f4d8801efa6647e = $(`&lt;div id=&quot;html_55b97d7dc7cc86bb5f4d8801efa6647e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cd348dc9674fdd2c5659a633c5a6bfcd.setContent(html_55b97d7dc7cc86bb5f4d8801efa6647e);
#
#
#
#         marker_d20a591eff9f2e75c746b14667ab48ba.bindPopup(popup_cd348dc9674fdd2c5659a633c5a6bfcd)
#         ;
#
#
#
#
#             var marker_71a7cf4212fda9015c2081f5b4fcba63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef32fcd842107fc35e6c3bf6946f001f);
#
#
#         var popup_b951678b4a3a7478de50721ac856d204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc5158072498c744b1eba1a379be7d20 = $(`&lt;div id=&quot;html_bc5158072498c744b1eba1a379be7d20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b951678b4a3a7478de50721ac856d204.setContent(html_bc5158072498c744b1eba1a379be7d20);
#
#
#
#         marker_71a7cf4212fda9015c2081f5b4fcba63.bindPopup(popup_b951678b4a3a7478de50721ac856d204)
#         ;
#
#
#
#
#             var marker_f68a259088afc161c38705ac3f191a58 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef32fcd842107fc35e6c3bf6946f001f);
#
#
#         var popup_73bda57a73592ed327d0568290c0d013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e72aa60e756aa3a2e3fd678195b1be3 = $(`&lt;div id=&quot;html_3e72aa60e756aa3a2e3fd678195b1be3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_73bda57a73592ed327d0568290c0d013.setContent(html_3e72aa60e756aa3a2e3fd678195b1be3);
#
#
#
#         mark
