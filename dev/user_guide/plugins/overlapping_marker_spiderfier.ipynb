# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6000a059e03cd79f573928691c05173 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6000a059e03cd79f573928691c05173&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6000a059e03cd79f573928691c05173 = L.map(
#                 &quot;map_c6000a059e03cd79f573928691c05173&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a0bdbb414cbab79d5fd2bc81afe9cde = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a0bdbb414cbab79d5fd2bc81afe9cde.addTo(map_c6000a059e03cd79f573928691c05173);
#
#
#             var marker_0c53b0b1236071a2838328cb6078d997 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c6000a059e03cd79f573928691c05173);
#
#
#         var popup_9bc1b43332526fd37db9a48e53989aea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2a6762bb914ef5f246d2b9119bbb884 = $(`&lt;div id=&quot;html_e2a6762bb914ef5f246d2b9119bbb884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9bc1b43332526fd37db9a48e53989aea.setContent(html_e2a6762bb914ef5f246d2b9119bbb884);
#
#
#
#         marker_0c53b0b1236071a2838328cb6078d997.bindPopup(popup_9bc1b43332526fd37db9a48e53989aea)
#         ;
#
#
#
#
#             var marker_9909fed7605b3c5880efa12461312c45 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c6000a059e03cd79f573928691c05173);
#
#
#         var popup_2097097ed6531149b9f717b99f400b70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b01c11dee847558cf00d89e78ccf8c5 = $(`&lt;div id=&quot;html_9b01c11dee847558cf00d89e78ccf8c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2097097ed6531149b9f717b99f400b70.setContent(html_9b01c11dee847558cf00d89e78ccf8c5);
#
#
#
#         marker_9909fed7605b3c5880efa12461312c45.bindPopup(popup_2097097ed6531149b9f717b99f400b70)
#         ;
#
#
#
#
#             var marker_68f416a59eb44797c24031d613ed0972 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c6000a059e03cd79f573928691c05173);
#
#
#         var popup_59268113022d161fbb57aa8fc972da1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78b4a0e9fdb6781da644b2543e581262 = $(`&lt;div id=&quot;html_78b4a0e9fdb6781da644b2543e581262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_59268113022d161fbb57aa8fc972da1e.setContent(html_78b4a0e9fdb6781da644b2543e581262);
#
#
#
#         marker_68f416a59eb44797c24031d613ed0972.bindPopup(popup_59268113022d161fbb57aa8fc972da1e)
#         ;
#
#
#
#
#             var marker_4ed9879442cda899e5f0dcabab171e0c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c6000a059e03cd79f573928691c05173);
#
#
#         var popup_78a1c059064864e959132992930eb203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_217a287eba5331b8b92c9a93aa308ec6 = $(`&lt;div id=&quot;html_217a287eba5331b8b92c9a93aa308ec6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_78a1c059064864e959132992930eb203.setContent(html_217a287eba5331b8b92c9a93aa308ec6);
#
#
#
#         marker_4ed9879442cda899e5f0dcabab171e0c.bindPopup(popup_78a1c059064864e959132992930eb203)
#         ;
#
#
#
#
#             var marker_c9e4c1efde2bb4720bb9e2e021cd0a2a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c6000a059e03cd79f573928691c05173);
#
#
#         var popup_9497f6f37dd00b3e360d7067225a7017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a550f3eb7b565c9604f7e70da7721b7 = $(`&lt;div id=&quot;html_4a550f3eb7b565c9604f7e70da7721b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9497f6f37dd00b3e360d7067225a70

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5aec4a138ea2ca6efd1c012085064431 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5aec4a138ea2ca6efd1c012085064431&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5aec4a138ea2ca6efd1c012085064431 = L.map(
#                 &quot;map_5aec4a138ea2ca6efd1c012085064431&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_990f751da06bd62dda2b5bed1f54962c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_990f751da06bd62dda2b5bed1f54962c.addTo(map_5aec4a138ea2ca6efd1c012085064431);
#
#
#             var feature_group_c613dcc8fb69f876945026ef9709208e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7a00929c1494dcc4dd59014b1d7fb357 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c613dcc8fb69f876945026ef9709208e);
#
#
#         var popup_69136982512edc426185ce4b7623d69f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c2fe798ce5acad6e00980fda7132d58 = $(`&lt;div id=&quot;html_1c2fe798ce5acad6e00980fda7132d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_69136982512edc426185ce4b7623d69f.setContent(html_1c2fe798ce5acad6e00980fda7132d58);
#
#
#
#         marker_7a00929c1494dcc4dd59014b1d7fb357.bindPopup(popup_69136982512edc426185ce4b7623d69f)
#         ;
#
#
#
#
#             var marker_5399ee688b6d69daed5a6a1a9ba65980 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c613dcc8fb69f876945026ef9709208e);
#
#
#         var popup_36be216ac2e75717d9688c2e09797ea2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a40b551964ca71793f57d499239f49 = $(`&lt;div id=&quot;html_f9a40b551964ca71793f57d499239f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_36be216ac2e75717d9688c2e09797ea2.setContent(html_f9a40b551964ca71793f57d499239f49);
#
#
#
#         marker_5399ee688b6d69daed5a6a1a9ba65980.bindPopup(popup_36be216ac2e75717d9688c2e09797ea2)
#         ;
#
#
#
#
#             var marker_40b97a3dee1600f4d257bf4b14a4b70d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c613dcc8fb69f876945026ef9709208e);
#
#
#         var popup_047bdb049c95b3b65ff59a0fc879d6f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7e978a19399d43288ebfacb39dc4b59 = $(`&lt;div id=&quot;html_b7e978a19399d43288ebfacb39dc4b59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_047bdb049c95b3b65ff59a0fc879d6f1.setContent(html_b7e978a19399d43288ebfacb39dc4b59);
#
#
#
#         marker_40b97a3dee1600f4d257bf4b14a4b70d.bindPopup(popup_047bdb049c95b3b65ff59a0fc879d6f1)
#         ;
#
#
#
#
#             var marker_e55c40070f6ec57c09c2164ad8f3cdfe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c613dcc8fb69f876945026ef9709208e);
#
#
#         var popup_8cabd5dcb8ff4e49760b4e21d447aa66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8405a9121b1755ee44ff7f17a2b31566 = $(`&lt;div id=&quot;html_8405a9121b1755ee44ff7f17a2b31566&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8cabd5dcb8ff4e49760b4e21d447aa66.setContent(html_8405a9121b1755ee44ff7f17a2b31566);
#
#
#
#         marker_e55c40070f6ec57c09c2164ad8f3cdfe.bindPopup(popup_8cabd5dcb8ff4e49760b4e21d447aa66)
#         ;
#
#
#
#
#             var marker_04156dd64ba866996dace283e8127fc8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c613dcc8fb69f876945026ef9709208e);
#
#
#         var popup_31da15c8de2dc47b4e7c9f4f54cfd242 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dedf413f643aef0166d3986d1aea84c9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dedf413f643aef0166d3986d1aea84c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dedf413f643aef0166d3986d1aea84c9 = L.map(
#                 &quot;map_dedf413f643aef0166d3986d1aea84c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3c115807d2f218bf94ef13908f7fd1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3c115807d2f218bf94ef13908f7fd1b.addTo(map_dedf413f643aef0166d3986d1aea84c9);
#
#
#             var feature_group_7a130441648ae12efedbbca536bc625e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7a130441648ae12efedbbca536bc625e.addTo(map_dedf413f643aef0166d3986d1aea84c9);
#
#
#             var feature_group_sub_group_dcbfd073eb3a24668bebd4db169a5fab = L.featureGroup.subGroup(
#                 feature_group_7a130441648ae12efedbbca536bc625e
#             );
#
#
#             var marker_f5f2c2c03af0b92903085c4f9c9ea747 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcbfd073eb3a24668bebd4db169a5fab);
#
#
#         var popup_1c9e7b170d8cacb440be31f69b1eef4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91748ccebe68f324a3a82ecd254f5bc4 = $(`&lt;div id=&quot;html_91748ccebe68f324a3a82ecd254f5bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1c9e7b170d8cacb440be31f69b1eef4a.setContent(html_91748ccebe68f324a3a82ecd254f5bc4);
#
#
#
#         marker_f5f2c2c03af0b92903085c4f9c9ea747.bindPopup(popup_1c9e7b170d8cacb440be31f69b1eef4a)
#         ;
#
#
#
#
#             var marker_e4d93991f0dca04f0ee13c725a28574f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcbfd073eb3a24668bebd4db169a5fab);
#
#
#         var popup_9cef1dce18a3d6636e72dff19d72f168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61295de23e19ce8807731a2424aaa827 = $(`&lt;div id=&quot;html_61295de23e19ce8807731a2424aaa827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9cef1dce18a3d6636e72dff19d72f168.setContent(html_61295de23e19ce8807731a2424aaa827);
#
#
#
#         marker_e4d93991f0dca04f0ee13c725a28574f.bindPopup(popup_9cef1dce18a3d6636e72dff19d72f168)
#         ;
#
#
#
#
#             var marker_5a689b7fdd781dd2a0083bfaffec5ea5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcbfd073eb3a24668bebd4db169a5fab);
#
#
#         var popup_24288afd5d02454a530a7722bd103489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c492e624258a167e16c6c2dbca02e47 = $(`&lt;div id=&quot;html_7c492e624258a167e16c6c2dbca02e47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_24288afd5d02454a530a7722bd103489.setContent(html_7c492e624258a167e16c6c2dbca02e47);
#
#
#
#         marker_5a689b7fdd781dd2a0083bfaffec5ea5.bindPopup(popup_24288afd5d02454a530a7722bd103489)
#         ;
#
#
#
#
#             var marker_e3afaabd9d6fd2eea29dc0cbb9b274b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dcbfd073eb3a24668bebd4db169a5fab);
#
#
#         var popup_37767c14fffda9a256db52abd7250a0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84036bb58670b67010b4479c325c8f56 = $(`&lt;div id=&quot;html_84036bb58670b67010b4479c325c8f56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_37767c14fffda9a256db52abd7250a0e.setContent(html_84036bb58670b67010b4479c325c8f56);
#
#
#
#         mark
