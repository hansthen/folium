# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b6cc8c2610873c5bc8813a849bcc997 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b6cc8c2610873c5bc8813a849bcc997&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b6cc8c2610873c5bc8813a849bcc997 = L.map(
#                 &quot;map_0b6cc8c2610873c5bc8813a849bcc997&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c08e0a9d5037fec2a12704058a2e6b47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c08e0a9d5037fec2a12704058a2e6b47.addTo(map_0b6cc8c2610873c5bc8813a849bcc997);
#
#
#             var marker_67a94986e871d39fff91729f8086f2d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0b6cc8c2610873c5bc8813a849bcc997);
#
#
#         var popup_3092fdf7fa4fe0fd82af83ecef28a33e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807c00eb9eb35f4b8ae06ba384446f28 = $(`&lt;div id=&quot;html_807c00eb9eb35f4b8ae06ba384446f28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3092fdf7fa4fe0fd82af83ecef28a33e.setContent(html_807c00eb9eb35f4b8ae06ba384446f28);
#
#
#
#         marker_67a94986e871d39fff91729f8086f2d8.bindPopup(popup_3092fdf7fa4fe0fd82af83ecef28a33e)
#         ;
#
#
#
#
#             var marker_d617067867482d2cb5591f96b3191b05 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0b6cc8c2610873c5bc8813a849bcc997);
#
#
#         var popup_78e664510ea55ccb67196aac897f7bf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdf110b83dd788f1e57c25bb34e6a9f3 = $(`&lt;div id=&quot;html_bdf110b83dd788f1e57c25bb34e6a9f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_78e664510ea55ccb67196aac897f7bf3.setContent(html_bdf110b83dd788f1e57c25bb34e6a9f3);
#
#
#
#         marker_d617067867482d2cb5591f96b3191b05.bindPopup(popup_78e664510ea55ccb67196aac897f7bf3)
#         ;
#
#
#
#
#             var marker_085305f3e5844fe3e9f6d3aeebc320de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0b6cc8c2610873c5bc8813a849bcc997);
#
#
#         var popup_8f832b92e13974b5d55e95e6addf0869 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d554a1ab22766508cea7294dafd2cd8f = $(`&lt;div id=&quot;html_d554a1ab22766508cea7294dafd2cd8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8f832b92e13974b5d55e95e6addf0869.setContent(html_d554a1ab22766508cea7294dafd2cd8f);
#
#
#
#         marker_085305f3e5844fe3e9f6d3aeebc320de.bindPopup(popup_8f832b92e13974b5d55e95e6addf0869)
#         ;
#
#
#
#
#             var marker_cf0720c466bf61b18afc71e3d836745a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0b6cc8c2610873c5bc8813a849bcc997);
#
#
#         var popup_06dcaf7b8836289f2bd37091f6c81ce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ac5f40318dfd95b09a47e90c7b8eea0 = $(`&lt;div id=&quot;html_9ac5f40318dfd95b09a47e90c7b8eea0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_06dcaf7b8836289f2bd37091f6c81ce5.setContent(html_9ac5f40318dfd95b09a47e90c7b8eea0);
#
#
#
#         marker_cf0720c466bf61b18afc71e3d836745a.bindPopup(popup_06dcaf7b8836289f2bd37091f6c81ce5)
#         ;
#
#
#
#
#             var marker_30e23f26225ffbaaa6ec774ca8def583 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0b6cc8c2610873c5bc8813a849bcc997);
#
#
#         var popup_95103c108c766bf7231ce3fb58fe1c73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2299b414ca333d0383983a1882f2e2ff = $(`&lt;div id=&quot;html_2299b414ca333d0383983a1882f2e2ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_95103c108c766bf7231ce3fb58fe1c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4911db628593806365fc96a05fce4333 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4911db628593806365fc96a05fce4333&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4911db628593806365fc96a05fce4333 = L.map(
#                 &quot;map_4911db628593806365fc96a05fce4333&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b0c9d7b7162eacb0775a0bf5cb70867 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b0c9d7b7162eacb0775a0bf5cb70867.addTo(map_4911db628593806365fc96a05fce4333);
#
#
#             var feature_group_074d34bb663bed04551c52ea773b3097 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d91f96fdb1098354b1b263231b36d09e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_074d34bb663bed04551c52ea773b3097);
#
#
#         var popup_84445262f116583a81a88b2a1f23e31a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ecf400a8d60a912097c591c4d22cef5 = $(`&lt;div id=&quot;html_3ecf400a8d60a912097c591c4d22cef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_84445262f116583a81a88b2a1f23e31a.setContent(html_3ecf400a8d60a912097c591c4d22cef5);
#
#
#
#         marker_d91f96fdb1098354b1b263231b36d09e.bindPopup(popup_84445262f116583a81a88b2a1f23e31a)
#         ;
#
#
#
#
#             var marker_2ba7ff06c4c4711a05e94d34d073c81f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_074d34bb663bed04551c52ea773b3097);
#
#
#         var popup_5d830d5ee1ef98b2e7b5cdda6e5feacd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_627f9e93f4910d69924bacdf30e2fd4c = $(`&lt;div id=&quot;html_627f9e93f4910d69924bacdf30e2fd4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5d830d5ee1ef98b2e7b5cdda6e5feacd.setContent(html_627f9e93f4910d69924bacdf30e2fd4c);
#
#
#
#         marker_2ba7ff06c4c4711a05e94d34d073c81f.bindPopup(popup_5d830d5ee1ef98b2e7b5cdda6e5feacd)
#         ;
#
#
#
#
#             var marker_074ce9c9794763d745029206bdfbcad4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_074d34bb663bed04551c52ea773b3097);
#
#
#         var popup_8c3b9276bab20c38ef723b92df77217c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a03d3eca554f68707f46f433b3754cfe = $(`&lt;div id=&quot;html_a03d3eca554f68707f46f433b3754cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8c3b9276bab20c38ef723b92df77217c.setContent(html_a03d3eca554f68707f46f433b3754cfe);
#
#
#
#         marker_074ce9c9794763d745029206bdfbcad4.bindPopup(popup_8c3b9276bab20c38ef723b92df77217c)
#         ;
#
#
#
#
#             var marker_2bf4ec01c792a4da4da4cb672501e6ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_074d34bb663bed04551c52ea773b3097);
#
#
#         var popup_ccc10220221a34e43297cdee58decd5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ba54f82226c92857be978a2437a0ae4 = $(`&lt;div id=&quot;html_9ba54f82226c92857be978a2437a0ae4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ccc10220221a34e43297cdee58decd5f.setContent(html_9ba54f82226c92857be978a2437a0ae4);
#
#
#
#         marker_2bf4ec01c792a4da4da4cb672501e6ca.bindPopup(popup_ccc10220221a34e43297cdee58decd5f)
#         ;
#
#
#
#
#             var marker_d26df17b7b017e566a749dff2caf38fb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_074d34bb663bed04551c52ea773b3097);
#
#
#         var popup_ce24bb7574bd2534b08469c2b39c69af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d721079e23ae87881a1f582098eaf854 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d721079e23ae87881a1f582098eaf854&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d721079e23ae87881a1f582098eaf854 = L.map(
#                 &quot;map_d721079e23ae87881a1f582098eaf854&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c81d5408d61a3e72507b796661fd7962 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c81d5408d61a3e72507b796661fd7962.addTo(map_d721079e23ae87881a1f582098eaf854);
#
#
#             var feature_group_c43f6d4d8e2d37c1855a26e22cc2780d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c43f6d4d8e2d37c1855a26e22cc2780d.addTo(map_d721079e23ae87881a1f582098eaf854);
#
#
#             var feature_group_sub_group_eaa8a9cd83573b451675742801281423 = L.featureGroup.subGroup(
#                 feature_group_c43f6d4d8e2d37c1855a26e22cc2780d
#             );
#
#
#             var marker_c770a0a088febc96574046d443465489 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_eaa8a9cd83573b451675742801281423);
#
#
#         var popup_9f64f6f6eb83bb088d4f95626afc748e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5820ede795700f203604532af0bc4cea = $(`&lt;div id=&quot;html_5820ede795700f203604532af0bc4cea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9f64f6f6eb83bb088d4f95626afc748e.setContent(html_5820ede795700f203604532af0bc4cea);
#
#
#
#         marker_c770a0a088febc96574046d443465489.bindPopup(popup_9f64f6f6eb83bb088d4f95626afc748e)
#         ;
#
#
#
#
#             var marker_bccb2edb03411114e697d6051fa856d9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_eaa8a9cd83573b451675742801281423);
#
#
#         var popup_ba6fd78bc71c1446fc3924850379fcf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4540d9f2a340174e785d7f9831e4bb5a = $(`&lt;div id=&quot;html_4540d9f2a340174e785d7f9831e4bb5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ba6fd78bc71c1446fc3924850379fcf1.setContent(html_4540d9f2a340174e785d7f9831e4bb5a);
#
#
#
#         marker_bccb2edb03411114e697d6051fa856d9.bindPopup(popup_ba6fd78bc71c1446fc3924850379fcf1)
#         ;
#
#
#
#
#             var marker_fb16c0ef6a0997013a01f8e46cddab15 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_eaa8a9cd83573b451675742801281423);
#
#
#         var popup_be63759c63dbfadcdc4decdfcdd1f6fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cda25ff81b13e143fbc08051a7c06b2 = $(`&lt;div id=&quot;html_4cda25ff81b13e143fbc08051a7c06b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_be63759c63dbfadcdc4decdfcdd1f6fe.setContent(html_4cda25ff81b13e143fbc08051a7c06b2);
#
#
#
#         marker_fb16c0ef6a0997013a01f8e46cddab15.bindPopup(popup_be63759c63dbfadcdc4decdfcdd1f6fe)
#         ;
#
#
#
#
#             var marker_da8a4cd42ede2cae3562362a51402fd7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_eaa8a9cd83573b451675742801281423);
#
#
#         var popup_dc5535f01017c690f32ab739cce73aae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6acb4ce0cb1ad5a6c33d8cedb4991ac4 = $(`&lt;div id=&quot;html_6acb4ce0cb1ad5a6c33d8cedb4991ac4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dc5535f01017c690f32ab739cce73aae.setContent(html_6acb4ce0cb1ad5a6c33d8cedb4991ac4);
#
#
#
#         mark
