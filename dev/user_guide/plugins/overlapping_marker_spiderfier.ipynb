# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e10a035380764a0290ebcbab829e12bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e10a035380764a0290ebcbab829e12bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e10a035380764a0290ebcbab829e12bb = L.map(
#                 &quot;map_e10a035380764a0290ebcbab829e12bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7029b4c1b834ec7a4f876be237840a50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7029b4c1b834ec7a4f876be237840a50.addTo(map_e10a035380764a0290ebcbab829e12bb);
#
#
#             var marker_c22af34f91669882c4b7beb4e924e283 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e10a035380764a0290ebcbab829e12bb);
#
#
#         var popup_ac347f3db9339a70ba4bfb7a4e14951a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45211c65d1bed69535e6b36aa3312102 = $(`&lt;div id=&quot;html_45211c65d1bed69535e6b36aa3312102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ac347f3db9339a70ba4bfb7a4e14951a.setContent(html_45211c65d1bed69535e6b36aa3312102);
#
#
#
#         marker_c22af34f91669882c4b7beb4e924e283.bindPopup(popup_ac347f3db9339a70ba4bfb7a4e14951a)
#         ;
#
#
#
#
#             var marker_3976a8f92854efec15d8169bb91b6d1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e10a035380764a0290ebcbab829e12bb);
#
#
#         var popup_6005aa153664b3f25e8c1b9a695b0606 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79c846218788fb688b91c04b29dcda65 = $(`&lt;div id=&quot;html_79c846218788fb688b91c04b29dcda65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6005aa153664b3f25e8c1b9a695b0606.setContent(html_79c846218788fb688b91c04b29dcda65);
#
#
#
#         marker_3976a8f92854efec15d8169bb91b6d1d.bindPopup(popup_6005aa153664b3f25e8c1b9a695b0606)
#         ;
#
#
#
#
#             var marker_d1a929a0a798aba2db1e90f3fc044636 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e10a035380764a0290ebcbab829e12bb);
#
#
#         var popup_dcffa48cf576fcd951d68d1a04d8e5e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_535eef77ed944b9664b69fb1b80901dd = $(`&lt;div id=&quot;html_535eef77ed944b9664b69fb1b80901dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dcffa48cf576fcd951d68d1a04d8e5e1.setContent(html_535eef77ed944b9664b69fb1b80901dd);
#
#
#
#         marker_d1a929a0a798aba2db1e90f3fc044636.bindPopup(popup_dcffa48cf576fcd951d68d1a04d8e5e1)
#         ;
#
#
#
#
#             var marker_08f587b4f56c5851d6935da395145921 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e10a035380764a0290ebcbab829e12bb);
#
#
#         var popup_5450ec8e6391f9b7a385d29f3d3b5a2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0229fe36c1b8f52a4f8abe6381d745b = $(`&lt;div id=&quot;html_f0229fe36c1b8f52a4f8abe6381d745b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5450ec8e6391f9b7a385d29f3d3b5a2a.setContent(html_f0229fe36c1b8f52a4f8abe6381d745b);
#
#
#
#         marker_08f587b4f56c5851d6935da395145921.bindPopup(popup_5450ec8e6391f9b7a385d29f3d3b5a2a)
#         ;
#
#
#
#
#             var marker_801f1e102d5b3bc8fe34625da8028fa9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e10a035380764a0290ebcbab829e12bb);
#
#
#         var popup_425c1c2b4c57b6c4d14c7490a008731f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6b574fbf4eb4216fbcbbe27eae4e7c8 = $(`&lt;div id=&quot;html_c6b574fbf4eb4216fbcbbe27eae4e7c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_425c1c2b4c57b6c4d14c7490a008731f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e41a5ec12773fdfc21790fe9d1c13431 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e41a5ec12773fdfc21790fe9d1c13431&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e41a5ec12773fdfc21790fe9d1c13431 = L.map(
#                 &quot;map_e41a5ec12773fdfc21790fe9d1c13431&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eefae298195bb4be6900a6a6f1800d72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eefae298195bb4be6900a6a6f1800d72.addTo(map_e41a5ec12773fdfc21790fe9d1c13431);
#
#
#             var feature_group_cb5df0c1fa0ad91f835b0721fb9fe444 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8baac576f8636ec52901937bf1e4099a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cb5df0c1fa0ad91f835b0721fb9fe444);
#
#
#         var popup_295bfefd73450de234982107ac34f4ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6599061c52fbd5ed3da3d52017efcb7c = $(`&lt;div id=&quot;html_6599061c52fbd5ed3da3d52017efcb7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_295bfefd73450de234982107ac34f4ed.setContent(html_6599061c52fbd5ed3da3d52017efcb7c);
#
#
#
#         marker_8baac576f8636ec52901937bf1e4099a.bindPopup(popup_295bfefd73450de234982107ac34f4ed)
#         ;
#
#
#
#
#             var marker_d0b4ae14bbaf61abfbc04503e6695bd3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cb5df0c1fa0ad91f835b0721fb9fe444);
#
#
#         var popup_3f3f6df1f909ac3fe78fbb405bf63350 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb1a32bf855be3d59546a3972a976d1f = $(`&lt;div id=&quot;html_eb1a32bf855be3d59546a3972a976d1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3f3f6df1f909ac3fe78fbb405bf63350.setContent(html_eb1a32bf855be3d59546a3972a976d1f);
#
#
#
#         marker_d0b4ae14bbaf61abfbc04503e6695bd3.bindPopup(popup_3f3f6df1f909ac3fe78fbb405bf63350)
#         ;
#
#
#
#
#             var marker_61fec2c389a6e33553eddc0ea9a89934 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cb5df0c1fa0ad91f835b0721fb9fe444);
#
#
#         var popup_3eb07f682db38a9faa54676c590dd100 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42a965da3a388073e3df73fa78be2ac4 = $(`&lt;div id=&quot;html_42a965da3a388073e3df73fa78be2ac4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3eb07f682db38a9faa54676c590dd100.setContent(html_42a965da3a388073e3df73fa78be2ac4);
#
#
#
#         marker_61fec2c389a6e33553eddc0ea9a89934.bindPopup(popup_3eb07f682db38a9faa54676c590dd100)
#         ;
#
#
#
#
#             var marker_4ca6d58cc121b22cd40585bf1829766b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cb5df0c1fa0ad91f835b0721fb9fe444);
#
#
#         var popup_3b2416ad35690ea28e33c2b680317e75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c3e8b45a38a232502cbfb61c9ea4fc9 = $(`&lt;div id=&quot;html_7c3e8b45a38a232502cbfb61c9ea4fc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3b2416ad35690ea28e33c2b680317e75.setContent(html_7c3e8b45a38a232502cbfb61c9ea4fc9);
#
#
#
#         marker_4ca6d58cc121b22cd40585bf1829766b.bindPopup(popup_3b2416ad35690ea28e33c2b680317e75)
#         ;
#
#
#
#
#             var marker_bcb0914d2816db5bcb81f933acf26747 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cb5df0c1fa0ad91f835b0721fb9fe444);
#
#
#         var popup_5c660262d68e41c9a2c4f2681498d4a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa1a04ff5772c3f83896eb2c3366e2f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa1a04ff5772c3f83896eb2c3366e2f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa1a04ff5772c3f83896eb2c3366e2f1 = L.map(
#                 &quot;map_aa1a04ff5772c3f83896eb2c3366e2f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4d1e0716a414a8a9488c64ee3184b77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4d1e0716a414a8a9488c64ee3184b77.addTo(map_aa1a04ff5772c3f83896eb2c3366e2f1);
#
#
#             var feature_group_99b4ec229c0b2ee8e6d70a1d6d1203e3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_99b4ec229c0b2ee8e6d70a1d6d1203e3.addTo(map_aa1a04ff5772c3f83896eb2c3366e2f1);
#
#
#             var feature_group_sub_group_4b17a756f3655abedbc88b087114671c = L.featureGroup.subGroup(
#                 feature_group_99b4ec229c0b2ee8e6d70a1d6d1203e3
#             );
#
#
#             var marker_64408c4d36bcbed0384fe84c0ec78a57 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b17a756f3655abedbc88b087114671c);
#
#
#         var popup_be4898adaf3a523f16e8a69d364453d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f213acead94f4e17e869eb0b20dac2aa = $(`&lt;div id=&quot;html_f213acead94f4e17e869eb0b20dac2aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_be4898adaf3a523f16e8a69d364453d7.setContent(html_f213acead94f4e17e869eb0b20dac2aa);
#
#
#
#         marker_64408c4d36bcbed0384fe84c0ec78a57.bindPopup(popup_be4898adaf3a523f16e8a69d364453d7)
#         ;
#
#
#
#
#             var marker_ad7b63c3f8a17f2bab3d449de4f7ee37 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b17a756f3655abedbc88b087114671c);
#
#
#         var popup_1f1f9486d35768b311e1ea1f28e4618c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6131c91a46715e912557d5d3c71cdfb = $(`&lt;div id=&quot;html_d6131c91a46715e912557d5d3c71cdfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1f1f9486d35768b311e1ea1f28e4618c.setContent(html_d6131c91a46715e912557d5d3c71cdfb);
#
#
#
#         marker_ad7b63c3f8a17f2bab3d449de4f7ee37.bindPopup(popup_1f1f9486d35768b311e1ea1f28e4618c)
#         ;
#
#
#
#
#             var marker_d11b3d05e51fe5068f56fda049459983 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b17a756f3655abedbc88b087114671c);
#
#
#         var popup_b5d0bcfdfc59760580fca7c10da3076d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be064b8987f41021085ea2ac262d5501 = $(`&lt;div id=&quot;html_be064b8987f41021085ea2ac262d5501&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b5d0bcfdfc59760580fca7c10da3076d.setContent(html_be064b8987f41021085ea2ac262d5501);
#
#
#
#         marker_d11b3d05e51fe5068f56fda049459983.bindPopup(popup_b5d0bcfdfc59760580fca7c10da3076d)
#         ;
#
#
#
#
#             var marker_962ac900af3fe81b4f8e4d6bd837cc6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b17a756f3655abedbc88b087114671c);
#
#
#         var popup_2b510e8948e65fe398badfeb54c8f99f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27feb3e4b642b8308f45e7f9ff7accd8 = $(`&lt;div id=&quot;html_27feb3e4b642b8308f45e7f9ff7accd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2b510e8948e65fe398badfeb54c8f99f.setContent(html_27feb3e4b642b8308f45e7f9ff7accd8);
#
#
#
#         marker_
