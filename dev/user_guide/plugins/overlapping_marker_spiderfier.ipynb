# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f5272e3ec64fd14361af8552a602565 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f5272e3ec64fd14361af8552a602565&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f5272e3ec64fd14361af8552a602565 = L.map(
#                 &quot;map_8f5272e3ec64fd14361af8552a602565&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a2c925674551b2e6700c4c2683f555f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a2c925674551b2e6700c4c2683f555f.addTo(map_8f5272e3ec64fd14361af8552a602565);
#
#
#             var marker_dbee049d0e6c8f6bd7734400e29e4094 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8f5272e3ec64fd14361af8552a602565);
#
#
#         var popup_4c641d8910eb0e882f71c2c629b0a951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_561b6a3c1f17b89f7452f2490d8bedbd = $(`&lt;div id=&quot;html_561b6a3c1f17b89f7452f2490d8bedbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4c641d8910eb0e882f71c2c629b0a951.setContent(html_561b6a3c1f17b89f7452f2490d8bedbd);
#
#
#
#         marker_dbee049d0e6c8f6bd7734400e29e4094.bindPopup(popup_4c641d8910eb0e882f71c2c629b0a951)
#         ;
#
#
#
#
#             var marker_1ea595b291020b94f7b3855a4a925ae0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8f5272e3ec64fd14361af8552a602565);
#
#
#         var popup_e39a073d9a7281f069f2f7e0198d2880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16afaa9cfb0f58e622b492f5135fa05a = $(`&lt;div id=&quot;html_16afaa9cfb0f58e622b492f5135fa05a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e39a073d9a7281f069f2f7e0198d2880.setContent(html_16afaa9cfb0f58e622b492f5135fa05a);
#
#
#
#         marker_1ea595b291020b94f7b3855a4a925ae0.bindPopup(popup_e39a073d9a7281f069f2f7e0198d2880)
#         ;
#
#
#
#
#             var marker_584fa0b4074c5ddf63a6f17c69c9a34d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8f5272e3ec64fd14361af8552a602565);
#
#
#         var popup_3077c3dc0f3cbe36d1458a4b0abbc23e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_187baecbbdff6f70fc7d6d755826596c = $(`&lt;div id=&quot;html_187baecbbdff6f70fc7d6d755826596c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3077c3dc0f3cbe36d1458a4b0abbc23e.setContent(html_187baecbbdff6f70fc7d6d755826596c);
#
#
#
#         marker_584fa0b4074c5ddf63a6f17c69c9a34d.bindPopup(popup_3077c3dc0f3cbe36d1458a4b0abbc23e)
#         ;
#
#
#
#
#             var marker_5b0cb47728a0599f8546d5bdcbcf7c6c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8f5272e3ec64fd14361af8552a602565);
#
#
#         var popup_e0251f75b32203a0877f75f48d59c3a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a71b2d9a844d312130d9ff8b8d32523d = $(`&lt;div id=&quot;html_a71b2d9a844d312130d9ff8b8d32523d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e0251f75b32203a0877f75f48d59c3a3.setContent(html_a71b2d9a844d312130d9ff8b8d32523d);
#
#
#
#         marker_5b0cb47728a0599f8546d5bdcbcf7c6c.bindPopup(popup_e0251f75b32203a0877f75f48d59c3a3)
#         ;
#
#
#
#
#             var marker_0d18ebd7d39449a0793bd2d2172e593d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8f5272e3ec64fd14361af8552a602565);
#
#
#         var popup_9783b7744155ea4cc2008c8b0cfea3a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b29c644904b9bbc355ae847a198d7e0 = $(`&lt;div id=&quot;html_0b29c644904b9bbc355ae847a198d7e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9783b7744155ea4cc2008c8b0cfea3a4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bb80edfcf12c25aaaddd36c96d1c518 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bb80edfcf12c25aaaddd36c96d1c518&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bb80edfcf12c25aaaddd36c96d1c518 = L.map(
#                 &quot;map_6bb80edfcf12c25aaaddd36c96d1c518&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e2e0d8742335723093801ce6b2a3782 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e2e0d8742335723093801ce6b2a3782.addTo(map_6bb80edfcf12c25aaaddd36c96d1c518);
#
#
#             var feature_group_cae3f786ed766961a96cc5526ad09aec = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dde54d9efee5512da86787ca86b38b01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cae3f786ed766961a96cc5526ad09aec);
#
#
#         var popup_5299aa3666e4d883b4b3c3c512ad7031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61377ab9f17d3dbb215495ffb80d5a2c = $(`&lt;div id=&quot;html_61377ab9f17d3dbb215495ffb80d5a2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5299aa3666e4d883b4b3c3c512ad7031.setContent(html_61377ab9f17d3dbb215495ffb80d5a2c);
#
#
#
#         marker_dde54d9efee5512da86787ca86b38b01.bindPopup(popup_5299aa3666e4d883b4b3c3c512ad7031)
#         ;
#
#
#
#
#             var marker_35a796a7d8c9b2d0acd121fb6da271a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cae3f786ed766961a96cc5526ad09aec);
#
#
#         var popup_504d786d81a3a759f7e175240e9a3d28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbd5feb1793ec4c305ae734591fd115a = $(`&lt;div id=&quot;html_bbd5feb1793ec4c305ae734591fd115a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_504d786d81a3a759f7e175240e9a3d28.setContent(html_bbd5feb1793ec4c305ae734591fd115a);
#
#
#
#         marker_35a796a7d8c9b2d0acd121fb6da271a8.bindPopup(popup_504d786d81a3a759f7e175240e9a3d28)
#         ;
#
#
#
#
#             var marker_49619105d1b7c4205509c41e211a3481 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cae3f786ed766961a96cc5526ad09aec);
#
#
#         var popup_4595da74f65532cbcdf5bad48ec48504 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faac25b392ab5769959f18d7729a7a2c = $(`&lt;div id=&quot;html_faac25b392ab5769959f18d7729a7a2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4595da74f65532cbcdf5bad48ec48504.setContent(html_faac25b392ab5769959f18d7729a7a2c);
#
#
#
#         marker_49619105d1b7c4205509c41e211a3481.bindPopup(popup_4595da74f65532cbcdf5bad48ec48504)
#         ;
#
#
#
#
#             var marker_d0ee4bbc19957cea99b13b9ff565e858 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cae3f786ed766961a96cc5526ad09aec);
#
#
#         var popup_fcbd5703294074a969b8a487f32e26b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57eca0ec448a409aa77f330030adc9a7 = $(`&lt;div id=&quot;html_57eca0ec448a409aa77f330030adc9a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fcbd5703294074a969b8a487f32e26b8.setContent(html_57eca0ec448a409aa77f330030adc9a7);
#
#
#
#         marker_d0ee4bbc19957cea99b13b9ff565e858.bindPopup(popup_fcbd5703294074a969b8a487f32e26b8)
#         ;
#
#
#
#
#             var marker_7aeb913f41013dcbabd9518ba62b0226 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cae3f786ed766961a96cc5526ad09aec);
#
#
#         var popup_df7d912a7752fcfe7425473c0a2b911b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ca189a5136f66140768c33e0fc56dbd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ca189a5136f66140768c33e0fc56dbd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ca189a5136f66140768c33e0fc56dbd = L.map(
#                 &quot;map_7ca189a5136f66140768c33e0fc56dbd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cd5a261fdd78e09b2d81fd1e89f3e3a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cd5a261fdd78e09b2d81fd1e89f3e3a.addTo(map_7ca189a5136f66140768c33e0fc56dbd);
#
#
#             var feature_group_949ca4d6c922c80d0f8107e3dd775c1c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_949ca4d6c922c80d0f8107e3dd775c1c.addTo(map_7ca189a5136f66140768c33e0fc56dbd);
#
#
#             var feature_group_sub_group_a140c6809c3a1a68a72bddc6eea592c5 = L.featureGroup.subGroup(
#                 feature_group_949ca4d6c922c80d0f8107e3dd775c1c
#             );
#
#
#             var marker_6be598c6f761c6a11d830c3194b4256a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a140c6809c3a1a68a72bddc6eea592c5);
#
#
#         var popup_a4a0b7b32d7d6e0ebf4cd40f3b70db50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2583153ea5150f990692b944e3512be5 = $(`&lt;div id=&quot;html_2583153ea5150f990692b944e3512be5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a4a0b7b32d7d6e0ebf4cd40f3b70db50.setContent(html_2583153ea5150f990692b944e3512be5);
#
#
#
#         marker_6be598c6f761c6a11d830c3194b4256a.bindPopup(popup_a4a0b7b32d7d6e0ebf4cd40f3b70db50)
#         ;
#
#
#
#
#             var marker_d66d026524877206447b2c97c96a7c01 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a140c6809c3a1a68a72bddc6eea592c5);
#
#
#         var popup_e107bdaf4459d68a37d28cc00c18174f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7ec9feb67cef3c1de92935a2a293668 = $(`&lt;div id=&quot;html_c7ec9feb67cef3c1de92935a2a293668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e107bdaf4459d68a37d28cc00c18174f.setContent(html_c7ec9feb67cef3c1de92935a2a293668);
#
#
#
#         marker_d66d026524877206447b2c97c96a7c01.bindPopup(popup_e107bdaf4459d68a37d28cc00c18174f)
#         ;
#
#
#
#
#             var marker_1f5013046ab9c6f4263a25b2de85dff1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a140c6809c3a1a68a72bddc6eea592c5);
#
#
#         var popup_73c33d807e9261efed16a2214effc906 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2605ebff9031cce5e5b4770f457ad418 = $(`&lt;div id=&quot;html_2605ebff9031cce5e5b4770f457ad418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_73c33d807e9261efed16a2214effc906.setContent(html_2605ebff9031cce5e5b4770f457ad418);
#
#
#
#         marker_1f5013046ab9c6f4263a25b2de85dff1.bindPopup(popup_73c33d807e9261efed16a2214effc906)
#         ;
#
#
#
#
#             var marker_b08e257431907d0527fe05ec36295ddb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a140c6809c3a1a68a72bddc6eea592c5);
#
#
#         var popup_f65d5596aebb72889c89afc232064f6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db74f04dfe252fa17e368638e5ee7a47 = $(`&lt;div id=&quot;html_db74f04dfe252fa17e368638e5ee7a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f65d5596aebb72889c89afc232064f6c.setContent(html_db74f04dfe252fa17e368638e5ee7a47);
#
#
#
#         marker_
