# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c70da8c062c7aff5cc9950db9a93f82 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c70da8c062c7aff5cc9950db9a93f82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c70da8c062c7aff5cc9950db9a93f82 = L.map(
#                 &quot;map_7c70da8c062c7aff5cc9950db9a93f82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7814d50e80ca72400cda9b6bfd14e4b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7814d50e80ca72400cda9b6bfd14e4b9.addTo(map_7c70da8c062c7aff5cc9950db9a93f82);
#
#
#             var marker_43d0f5a1e5b9d8916ca60f234db5898b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7c70da8c062c7aff5cc9950db9a93f82);
#
#
#         var popup_94bd750bb483f2fcabb176902252c794 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16fdb10296c37eb455003a9ac1db9977 = $(`&lt;div id=&quot;html_16fdb10296c37eb455003a9ac1db9977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_94bd750bb483f2fcabb176902252c794.setContent(html_16fdb10296c37eb455003a9ac1db9977);
#
#
#
#         marker_43d0f5a1e5b9d8916ca60f234db5898b.bindPopup(popup_94bd750bb483f2fcabb176902252c794)
#         ;
#
#
#
#
#             var marker_831df409454bb98d9eca44e591c88fd2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7c70da8c062c7aff5cc9950db9a93f82);
#
#
#         var popup_ea7032fdf04d6fe1d43efce2bf89f8b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_934cc1eb85166d6513f714b1f13e9e68 = $(`&lt;div id=&quot;html_934cc1eb85166d6513f714b1f13e9e68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ea7032fdf04d6fe1d43efce2bf89f8b9.setContent(html_934cc1eb85166d6513f714b1f13e9e68);
#
#
#
#         marker_831df409454bb98d9eca44e591c88fd2.bindPopup(popup_ea7032fdf04d6fe1d43efce2bf89f8b9)
#         ;
#
#
#
#
#             var marker_2d6c71692a45944b95b9e7b8d977488e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7c70da8c062c7aff5cc9950db9a93f82);
#
#
#         var popup_adaf26eae70c2d24991b7ccd4c53b536 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_373c0deeb56abf25181541c3f34ba599 = $(`&lt;div id=&quot;html_373c0deeb56abf25181541c3f34ba599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_adaf26eae70c2d24991b7ccd4c53b536.setContent(html_373c0deeb56abf25181541c3f34ba599);
#
#
#
#         marker_2d6c71692a45944b95b9e7b8d977488e.bindPopup(popup_adaf26eae70c2d24991b7ccd4c53b536)
#         ;
#
#
#
#
#             var marker_540c370fe28e08b9f67576ceba0975c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7c70da8c062c7aff5cc9950db9a93f82);
#
#
#         var popup_56c54198dd45551d12895196d4969a9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e148d8f2c128de336fdb069a5892320 = $(`&lt;div id=&quot;html_0e148d8f2c128de336fdb069a5892320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_56c54198dd45551d12895196d4969a9b.setContent(html_0e148d8f2c128de336fdb069a5892320);
#
#
#
#         marker_540c370fe28e08b9f67576ceba0975c5.bindPopup(popup_56c54198dd45551d12895196d4969a9b)
#         ;
#
#
#
#
#             var marker_5ecf23e6de600762f28dc43e9828658a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7c70da8c062c7aff5cc9950db9a93f82);
#
#
#         var popup_c54b7eb20672dbb6e3a6fb79fc332e5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99a2203ed2046f396b3d5ac2d0d93e9f = $(`&lt;div id=&quot;html_99a2203ed2046f396b3d5ac2d0d93e9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c54b7eb20672dbb6e3a6fb79fc332e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d46e30c41b2613eb772881514f9d284d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d46e30c41b2613eb772881514f9d284d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d46e30c41b2613eb772881514f9d284d = L.map(
#                 &quot;map_d46e30c41b2613eb772881514f9d284d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bafabeeb18fdb1509da71326e1761741 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bafabeeb18fdb1509da71326e1761741.addTo(map_d46e30c41b2613eb772881514f9d284d);
#
#
#             var feature_group_752e6e8dd77d829f2630fd4827a296ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aa0f7a42d6578557b2216f6fe8032840 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_752e6e8dd77d829f2630fd4827a296ca);
#
#
#         var popup_b2d8949edc586db1975bd74e2e774c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbc17edec9aea543370cc218e3e50633 = $(`&lt;div id=&quot;html_fbc17edec9aea543370cc218e3e50633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b2d8949edc586db1975bd74e2e774c01.setContent(html_fbc17edec9aea543370cc218e3e50633);
#
#
#
#         marker_aa0f7a42d6578557b2216f6fe8032840.bindPopup(popup_b2d8949edc586db1975bd74e2e774c01)
#         ;
#
#
#
#
#             var marker_99f358fa2a47096fe95cc4d3194631ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_752e6e8dd77d829f2630fd4827a296ca);
#
#
#         var popup_7b2e91228bd7a5abd1f178d3dba27386 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43c43df5470bf708c048d6d529fbfe0f = $(`&lt;div id=&quot;html_43c43df5470bf708c048d6d529fbfe0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7b2e91228bd7a5abd1f178d3dba27386.setContent(html_43c43df5470bf708c048d6d529fbfe0f);
#
#
#
#         marker_99f358fa2a47096fe95cc4d3194631ab.bindPopup(popup_7b2e91228bd7a5abd1f178d3dba27386)
#         ;
#
#
#
#
#             var marker_8fcf58965c645b44117ef83fed208227 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_752e6e8dd77d829f2630fd4827a296ca);
#
#
#         var popup_e2ff69074e9f859af4001f8261ee5459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dae5c7fbab7575c6b6fa4325e2f47181 = $(`&lt;div id=&quot;html_dae5c7fbab7575c6b6fa4325e2f47181&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e2ff69074e9f859af4001f8261ee5459.setContent(html_dae5c7fbab7575c6b6fa4325e2f47181);
#
#
#
#         marker_8fcf58965c645b44117ef83fed208227.bindPopup(popup_e2ff69074e9f859af4001f8261ee5459)
#         ;
#
#
#
#
#             var marker_1c0c2430edfde98a515cfa0a71b75c35 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_752e6e8dd77d829f2630fd4827a296ca);
#
#
#         var popup_eaabb09a59519aa2bdb9b6f5b823eb28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf57495d7173fa3a9925ce550fc354af = $(`&lt;div id=&quot;html_bf57495d7173fa3a9925ce550fc354af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_eaabb09a59519aa2bdb9b6f5b823eb28.setContent(html_bf57495d7173fa3a9925ce550fc354af);
#
#
#
#         marker_1c0c2430edfde98a515cfa0a71b75c35.bindPopup(popup_eaabb09a59519aa2bdb9b6f5b823eb28)
#         ;
#
#
#
#
#             var marker_df36d8d2f30a93218d543d68f8b28639 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_752e6e8dd77d829f2630fd4827a296ca);
#
#
#         var popup_53fbca0f769b74d7e12719d8495a8a8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c63d3b71036a77738e3a17018c0766d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c63d3b71036a77738e3a17018c0766d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c63d3b71036a77738e3a17018c0766d = L.map(
#                 &quot;map_1c63d3b71036a77738e3a17018c0766d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4233adde22697b6f0fb7a39bbb63ecad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4233adde22697b6f0fb7a39bbb63ecad.addTo(map_1c63d3b71036a77738e3a17018c0766d);
#
#
#             var feature_group_4064c1fd76f590fe626757024d5f666b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4064c1fd76f590fe626757024d5f666b.addTo(map_1c63d3b71036a77738e3a17018c0766d);
#
#
#             var feature_group_sub_group_da69f8f39de78712fc8518112c624c7c = L.featureGroup.subGroup(
#                 feature_group_4064c1fd76f590fe626757024d5f666b
#             );
#
#
#             var marker_af849018920390ac1b3730ef9032ddd5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_da69f8f39de78712fc8518112c624c7c);
#
#
#         var popup_d58c63192a09a85459bc5d257ffd0873 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53f41184ccf012c3df8ed436f23f3d9a = $(`&lt;div id=&quot;html_53f41184ccf012c3df8ed436f23f3d9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d58c63192a09a85459bc5d257ffd0873.setContent(html_53f41184ccf012c3df8ed436f23f3d9a);
#
#
#
#         marker_af849018920390ac1b3730ef9032ddd5.bindPopup(popup_d58c63192a09a85459bc5d257ffd0873)
#         ;
#
#
#
#
#             var marker_763f3f73a1c8c9572e142e44f9e408d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_da69f8f39de78712fc8518112c624c7c);
#
#
#         var popup_3b2a5bec654ce5502efc7b6351c644ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b587997fd09b3e169379886a985ba561 = $(`&lt;div id=&quot;html_b587997fd09b3e169379886a985ba561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3b2a5bec654ce5502efc7b6351c644ce.setContent(html_b587997fd09b3e169379886a985ba561);
#
#
#
#         marker_763f3f73a1c8c9572e142e44f9e408d5.bindPopup(popup_3b2a5bec654ce5502efc7b6351c644ce)
#         ;
#
#
#
#
#             var marker_b591f6dd441a6bcba4c9e4937f141c68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_da69f8f39de78712fc8518112c624c7c);
#
#
#         var popup_8e0ab79936dc292b86c650dc66a6183e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c4cb818a18af089aee13a04da27d7ac = $(`&lt;div id=&quot;html_3c4cb818a18af089aee13a04da27d7ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8e0ab79936dc292b86c650dc66a6183e.setContent(html_3c4cb818a18af089aee13a04da27d7ac);
#
#
#
#         marker_b591f6dd441a6bcba4c9e4937f141c68.bindPopup(popup_8e0ab79936dc292b86c650dc66a6183e)
#         ;
#
#
#
#
#             var marker_2f2c37f4aa9f8d750044b6792dd65bd0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_da69f8f39de78712fc8518112c624c7c);
#
#
#         var popup_ac3e5a0e9cd887b39f0dc39de068fe54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4debbc3e673a4736719b148c0a71b142 = $(`&lt;div id=&quot;html_4debbc3e673a4736719b148c0a71b142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ac3e5a0e9cd887b39f0dc39de068fe54.setContent(html_4debbc3e673a4736719b148c0a71b142);
#
#
#
#         mark
