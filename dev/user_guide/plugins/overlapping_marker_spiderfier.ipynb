# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d96b6b34223d592c5c96225030c9b9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d96b6b34223d592c5c96225030c9b9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d96b6b34223d592c5c96225030c9b9a = L.map(
#                 &quot;map_1d96b6b34223d592c5c96225030c9b9a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b24e769a40af66a0c003efd793525e1e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b24e769a40af66a0c003efd793525e1e.addTo(map_1d96b6b34223d592c5c96225030c9b9a);
#
#
#             var marker_0161b41956b6d6a1d1d65d2df898b5a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1d96b6b34223d592c5c96225030c9b9a);
#
#
#         var popup_96f7a73345326bc0b1015f2c855f4d7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6746b75be8499cc33c484e6734bda33 = $(`&lt;div id=&quot;html_a6746b75be8499cc33c484e6734bda33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_96f7a73345326bc0b1015f2c855f4d7c.setContent(html_a6746b75be8499cc33c484e6734bda33);
#
#
#
#         marker_0161b41956b6d6a1d1d65d2df898b5a9.bindPopup(popup_96f7a73345326bc0b1015f2c855f4d7c)
#         ;
#
#
#
#
#             var marker_8d2e3f6616d09ccfa36706160e39933d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1d96b6b34223d592c5c96225030c9b9a);
#
#
#         var popup_bc27496129f4035da04966c7e0cfea3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05b7b9c10642449387d9810ef3c18f65 = $(`&lt;div id=&quot;html_05b7b9c10642449387d9810ef3c18f65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bc27496129f4035da04966c7e0cfea3e.setContent(html_05b7b9c10642449387d9810ef3c18f65);
#
#
#
#         marker_8d2e3f6616d09ccfa36706160e39933d.bindPopup(popup_bc27496129f4035da04966c7e0cfea3e)
#         ;
#
#
#
#
#             var marker_0818425ac301acc78d44ea3d139c025e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1d96b6b34223d592c5c96225030c9b9a);
#
#
#         var popup_b862c3c6f4d2a6e1ba56a8fc0376afd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_416ad029115643b4e6d74de4e9339b51 = $(`&lt;div id=&quot;html_416ad029115643b4e6d74de4e9339b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b862c3c6f4d2a6e1ba56a8fc0376afd9.setContent(html_416ad029115643b4e6d74de4e9339b51);
#
#
#
#         marker_0818425ac301acc78d44ea3d139c025e.bindPopup(popup_b862c3c6f4d2a6e1ba56a8fc0376afd9)
#         ;
#
#
#
#
#             var marker_3541063e7768cf9ce95e3be47a55dd69 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1d96b6b34223d592c5c96225030c9b9a);
#
#
#         var popup_918ead73d74a5bf78ca20936c63df8ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23457357e36ccab6c4c535a3f4031ac0 = $(`&lt;div id=&quot;html_23457357e36ccab6c4c535a3f4031ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_918ead73d74a5bf78ca20936c63df8ec.setContent(html_23457357e36ccab6c4c535a3f4031ac0);
#
#
#
#         marker_3541063e7768cf9ce95e3be47a55dd69.bindPopup(popup_918ead73d74a5bf78ca20936c63df8ec)
#         ;
#
#
#
#
#             var marker_cee3d7737a7d74cf9c0cddbebc264304 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1d96b6b34223d592c5c96225030c9b9a);
#
#
#         var popup_12c492089109baf990ad9105f93c2af1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a7d861c77ca7143c932ff7237f81a69 = $(`&lt;div id=&quot;html_3a7d861c77ca7143c932ff7237f81a69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_12c492089109baf990ad9105f93c2af1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82d1afeabd1af5f0096c0aed7fd56b46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82d1afeabd1af5f0096c0aed7fd56b46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82d1afeabd1af5f0096c0aed7fd56b46 = L.map(
#                 &quot;map_82d1afeabd1af5f0096c0aed7fd56b46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_636583a3e753356c812c25c77447cea0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_636583a3e753356c812c25c77447cea0.addTo(map_82d1afeabd1af5f0096c0aed7fd56b46);
#
#
#             var feature_group_a883ae020d0106f8e41ccf7b97d3fe11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7988e7081b54e03aeb9c8232a83422ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a883ae020d0106f8e41ccf7b97d3fe11);
#
#
#         var popup_8658b0dc3bc169a0feeba795e2d22035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a32a6ff0deecf13ec24d7037419f4d5f = $(`&lt;div id=&quot;html_a32a6ff0deecf13ec24d7037419f4d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8658b0dc3bc169a0feeba795e2d22035.setContent(html_a32a6ff0deecf13ec24d7037419f4d5f);
#
#
#
#         marker_7988e7081b54e03aeb9c8232a83422ec.bindPopup(popup_8658b0dc3bc169a0feeba795e2d22035)
#         ;
#
#
#
#
#             var marker_b93928fc4559c1bbb6db11e7e9806884 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a883ae020d0106f8e41ccf7b97d3fe11);
#
#
#         var popup_52c6b9e311b2e502a790842145f0b0e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_733fb12b1e69692a180551f63b06b0cc = $(`&lt;div id=&quot;html_733fb12b1e69692a180551f63b06b0cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52c6b9e311b2e502a790842145f0b0e0.setContent(html_733fb12b1e69692a180551f63b06b0cc);
#
#
#
#         marker_b93928fc4559c1bbb6db11e7e9806884.bindPopup(popup_52c6b9e311b2e502a790842145f0b0e0)
#         ;
#
#
#
#
#             var marker_9b686f8275062889ae7910ef0f141a5c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a883ae020d0106f8e41ccf7b97d3fe11);
#
#
#         var popup_599fe80f34db535595d5cd37a71a7fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5f18f7cd24ffcd5c297668962d3e98b = $(`&lt;div id=&quot;html_b5f18f7cd24ffcd5c297668962d3e98b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_599fe80f34db535595d5cd37a71a7fcf.setContent(html_b5f18f7cd24ffcd5c297668962d3e98b);
#
#
#
#         marker_9b686f8275062889ae7910ef0f141a5c.bindPopup(popup_599fe80f34db535595d5cd37a71a7fcf)
#         ;
#
#
#
#
#             var marker_30926a884a468c05b99037db7925434c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a883ae020d0106f8e41ccf7b97d3fe11);
#
#
#         var popup_ca7a39417dfae72c31115053a3853676 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70927c9a0347f8cfee77d20332c458af = $(`&lt;div id=&quot;html_70927c9a0347f8cfee77d20332c458af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ca7a39417dfae72c31115053a3853676.setContent(html_70927c9a0347f8cfee77d20332c458af);
#
#
#
#         marker_30926a884a468c05b99037db7925434c.bindPopup(popup_ca7a39417dfae72c31115053a3853676)
#         ;
#
#
#
#
#             var marker_a7c32524adb707385164a1ef83ce849f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a883ae020d0106f8e41ccf7b97d3fe11);
#
#
#         var popup_1a00eeda17ad125faaeca96ea91f6a82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df760d19308a02dcae80aee3b9dd8806 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df760d19308a02dcae80aee3b9dd8806&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df760d19308a02dcae80aee3b9dd8806 = L.map(
#                 &quot;map_df760d19308a02dcae80aee3b9dd8806&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0d3b5896c7d83f547e67cb9968f93a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0d3b5896c7d83f547e67cb9968f93a9.addTo(map_df760d19308a02dcae80aee3b9dd8806);
#
#
#             var feature_group_3e008c96529c36205095cad2d8aab6e5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3e008c96529c36205095cad2d8aab6e5.addTo(map_df760d19308a02dcae80aee3b9dd8806);
#
#
#             var feature_group_sub_group_930c48907d4eefd3ffefe2c627e41015 = L.featureGroup.subGroup(
#                 feature_group_3e008c96529c36205095cad2d8aab6e5
#             );
#
#
#             var marker_d96079a48985ee40b3f08cb228599878 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_930c48907d4eefd3ffefe2c627e41015);
#
#
#         var popup_70fac7b1bf0972ca9ca28b87e7632de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d160db21027d05f7ae590274b4cccd4 = $(`&lt;div id=&quot;html_7d160db21027d05f7ae590274b4cccd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_70fac7b1bf0972ca9ca28b87e7632de3.setContent(html_7d160db21027d05f7ae590274b4cccd4);
#
#
#
#         marker_d96079a48985ee40b3f08cb228599878.bindPopup(popup_70fac7b1bf0972ca9ca28b87e7632de3)
#         ;
#
#
#
#
#             var marker_82f0f52bc891622e9d8ecf907683d801 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_930c48907d4eefd3ffefe2c627e41015);
#
#
#         var popup_0df2b2efd925cf39a8f297c2b1bf6512 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9bdf33583b521d68ac9cd7aca097a25 = $(`&lt;div id=&quot;html_d9bdf33583b521d68ac9cd7aca097a25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0df2b2efd925cf39a8f297c2b1bf6512.setContent(html_d9bdf33583b521d68ac9cd7aca097a25);
#
#
#
#         marker_82f0f52bc891622e9d8ecf907683d801.bindPopup(popup_0df2b2efd925cf39a8f297c2b1bf6512)
#         ;
#
#
#
#
#             var marker_30b08b0cd05dfb51b1f4c2df20e61f48 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_930c48907d4eefd3ffefe2c627e41015);
#
#
#         var popup_7f8bfdbadc55c981532fc7fd243d208f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ebea6aa927fde5650899b8598f09009 = $(`&lt;div id=&quot;html_9ebea6aa927fde5650899b8598f09009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7f8bfdbadc55c981532fc7fd243d208f.setContent(html_9ebea6aa927fde5650899b8598f09009);
#
#
#
#         marker_30b08b0cd05dfb51b1f4c2df20e61f48.bindPopup(popup_7f8bfdbadc55c981532fc7fd243d208f)
#         ;
#
#
#
#
#             var marker_d22b1fe699f7de95f37c4021063961e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_930c48907d4eefd3ffefe2c627e41015);
#
#
#         var popup_4ccedae1547dc91105cf55ece7b8582a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc77f13f7674dcab6dec692d017e69a9 = $(`&lt;div id=&quot;html_bc77f13f7674dcab6dec692d017e69a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4ccedae1547dc91105cf55ece7b8582a.setContent(html_bc77f13f7674dcab6dec692d017e69a9);
#
#
#
#         marker_
