# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cba1d0cb1d297168163713b7e9e5f6bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cba1d0cb1d297168163713b7e9e5f6bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cba1d0cb1d297168163713b7e9e5f6bd = L.map(
#                 &quot;map_cba1d0cb1d297168163713b7e9e5f6bd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bea94f44c94bedc95147bb6c8b56376a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bea94f44c94bedc95147bb6c8b56376a.addTo(map_cba1d0cb1d297168163713b7e9e5f6bd);
#
#
#             var marker_fb4820fccd47860fbbd80a2e6edd136d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cba1d0cb1d297168163713b7e9e5f6bd);
#
#
#         var popup_84e2e8129f68eaaecbce6cb5f325ad5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97fea62c4a3bd215765d251f16dec568 = $(`&lt;div id=&quot;html_97fea62c4a3bd215765d251f16dec568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_84e2e8129f68eaaecbce6cb5f325ad5c.setContent(html_97fea62c4a3bd215765d251f16dec568);
#
#
#
#         marker_fb4820fccd47860fbbd80a2e6edd136d.bindPopup(popup_84e2e8129f68eaaecbce6cb5f325ad5c)
#         ;
#
#
#
#
#             var marker_346026525bf42049f096e9ae7bc40538 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cba1d0cb1d297168163713b7e9e5f6bd);
#
#
#         var popup_8875f0698c442585baf8b830dbe242b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e42301801c4975d0e76c50fb11d4ed0c = $(`&lt;div id=&quot;html_e42301801c4975d0e76c50fb11d4ed0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8875f0698c442585baf8b830dbe242b4.setContent(html_e42301801c4975d0e76c50fb11d4ed0c);
#
#
#
#         marker_346026525bf42049f096e9ae7bc40538.bindPopup(popup_8875f0698c442585baf8b830dbe242b4)
#         ;
#
#
#
#
#             var marker_068489bc3eaa9d4494f5084e69f58284 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cba1d0cb1d297168163713b7e9e5f6bd);
#
#
#         var popup_949431212dcee4063fdf344228b56773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86ab511dcbfe198d8ddb5b1508a2aa3e = $(`&lt;div id=&quot;html_86ab511dcbfe198d8ddb5b1508a2aa3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_949431212dcee4063fdf344228b56773.setContent(html_86ab511dcbfe198d8ddb5b1508a2aa3e);
#
#
#
#         marker_068489bc3eaa9d4494f5084e69f58284.bindPopup(popup_949431212dcee4063fdf344228b56773)
#         ;
#
#
#
#
#             var marker_2bfd57809d41a759700bad6fc38c12db = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cba1d0cb1d297168163713b7e9e5f6bd);
#
#
#         var popup_22848f0fc1a800f389ec0f62245c11d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bd7dc374f68404a745830bbfd32b0de = $(`&lt;div id=&quot;html_2bd7dc374f68404a745830bbfd32b0de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_22848f0fc1a800f389ec0f62245c11d8.setContent(html_2bd7dc374f68404a745830bbfd32b0de);
#
#
#
#         marker_2bfd57809d41a759700bad6fc38c12db.bindPopup(popup_22848f0fc1a800f389ec0f62245c11d8)
#         ;
#
#
#
#
#             var marker_64c81652de505367ff775704293930e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cba1d0cb1d297168163713b7e9e5f6bd);
#
#
#         var popup_aa84694159bbf32ce9e79dfde437c131 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0dd68f0d899bdccd6ba52beab7aeb29 = $(`&lt;div id=&quot;html_e0dd68f0d899bdccd6ba52beab7aeb29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa84694159bbf32ce9e79dfde437c131.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc5362dee095186a69c45ff0455049ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc5362dee095186a69c45ff0455049ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc5362dee095186a69c45ff0455049ac = L.map(
#                 &quot;map_bc5362dee095186a69c45ff0455049ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c44e7831717ccbbfd36fc3573e531d3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c44e7831717ccbbfd36fc3573e531d3d.addTo(map_bc5362dee095186a69c45ff0455049ac);
#
#
#             var feature_group_003a0fbbc8891ea4207dd2107249099f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_85358ed1354f5e97e4e097c0e5443549 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_003a0fbbc8891ea4207dd2107249099f);
#
#
#         var popup_8ade9152def9faa3e1801fa5652e5a44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53ceb238afceebe6832aebdb1f1c4892 = $(`&lt;div id=&quot;html_53ceb238afceebe6832aebdb1f1c4892&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8ade9152def9faa3e1801fa5652e5a44.setContent(html_53ceb238afceebe6832aebdb1f1c4892);
#
#
#
#         marker_85358ed1354f5e97e4e097c0e5443549.bindPopup(popup_8ade9152def9faa3e1801fa5652e5a44)
#         ;
#
#
#
#
#             var marker_88eaf2258ea935d9d2bee91dd597d7f2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_003a0fbbc8891ea4207dd2107249099f);
#
#
#         var popup_d3bb7b10726f7b940bbee0e1a58c5e99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3687b850e46d537d27dec1c29e4a05b4 = $(`&lt;div id=&quot;html_3687b850e46d537d27dec1c29e4a05b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d3bb7b10726f7b940bbee0e1a58c5e99.setContent(html_3687b850e46d537d27dec1c29e4a05b4);
#
#
#
#         marker_88eaf2258ea935d9d2bee91dd597d7f2.bindPopup(popup_d3bb7b10726f7b940bbee0e1a58c5e99)
#         ;
#
#
#
#
#             var marker_da64a76f02ee220f71f03dd25f31a92f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_003a0fbbc8891ea4207dd2107249099f);
#
#
#         var popup_2918ec599fc904e005056de21a4c690e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0969afb224eb1e38b9bf6ea8e351dd9c = $(`&lt;div id=&quot;html_0969afb224eb1e38b9bf6ea8e351dd9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2918ec599fc904e005056de21a4c690e.setContent(html_0969afb224eb1e38b9bf6ea8e351dd9c);
#
#
#
#         marker_da64a76f02ee220f71f03dd25f31a92f.bindPopup(popup_2918ec599fc904e005056de21a4c690e)
#         ;
#
#
#
#
#             var marker_4f4b45aa2d26aebffbb6d9fcf2ff0ce6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_003a0fbbc8891ea4207dd2107249099f);
#
#
#         var popup_7651b620913861c6da75e28d1cd8ecce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1e4a0014ce62bfaabd5535672d148e9 = $(`&lt;div id=&quot;html_b1e4a0014ce62bfaabd5535672d148e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7651b620913861c6da75e28d1cd8ecce.setContent(html_b1e4a0014ce62bfaabd5535672d148e9);
#
#
#
#         marker_4f4b45aa2d26aebffbb6d9fcf2ff0ce6.bindPopup(popup_7651b620913861c6da75e28d1cd8ecce)
#         ;
#
#
#
#
#             var marker_375b2c3c8cca1a1f416244419505ccfb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_003a0fbbc8891ea4207dd2107249099f);
#
#
#         var popup_0d43fd035e4e8d9642804d5e0232ebc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee0a8b92dbf666cf93343d354f91c55e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee0a8b92dbf666cf93343d354f91c55e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee0a8b92dbf666cf93343d354f91c55e = L.map(
#                 &quot;map_ee0a8b92dbf666cf93343d354f91c55e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b431ec645c87870fb549472cad6b98b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b431ec645c87870fb549472cad6b98b0.addTo(map_ee0a8b92dbf666cf93343d354f91c55e);
#
#
#             var feature_group_9bfe4bf61d3cfd50df4e899a2bcbec53 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9bfe4bf61d3cfd50df4e899a2bcbec53.addTo(map_ee0a8b92dbf666cf93343d354f91c55e);
#
#
#             var feature_group_sub_group_caeba2ed47cd1ad60f16b1d0d2181e20 = L.featureGroup.subGroup(
#                 feature_group_9bfe4bf61d3cfd50df4e899a2bcbec53
#             );
#
#
#             var marker_0b977de991368ed1e843a28ee5b35dde = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_caeba2ed47cd1ad60f16b1d0d2181e20);
#
#
#         var popup_f388beb2d4943c3dc5c347dab636058c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_288a430f0a185c2c9f2dccbc509ce347 = $(`&lt;div id=&quot;html_288a430f0a185c2c9f2dccbc509ce347&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f388beb2d4943c3dc5c347dab636058c.setContent(html_288a430f0a185c2c9f2dccbc509ce347);
#
#
#
#         marker_0b977de991368ed1e843a28ee5b35dde.bindPopup(popup_f388beb2d4943c3dc5c347dab636058c)
#         ;
#
#
#
#
#             var marker_8447a77af6ea3e092940d1861cc714bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_caeba2ed47cd1ad60f16b1d0d2181e20);
#
#
#         var popup_ab977ed864aa366fd1b3119348f88352 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9037d71e098118f533cedc414fc1784 = $(`&lt;div id=&quot;html_c9037d71e098118f533cedc414fc1784&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ab977ed864aa366fd1b3119348f88352.setContent(html_c9037d71e098118f533cedc414fc1784);
#
#
#
#         marker_8447a77af6ea3e092940d1861cc714bf.bindPopup(popup_ab977ed864aa366fd1b3119348f88352)
#         ;
#
#
#
#
#             var marker_a321138930b57002c2baa39d5904aa45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_caeba2ed47cd1ad60f16b1d0d2181e20);
#
#
#         var popup_7b65476da9947369ef5ef9081841a4b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0df7f2a61b132159afc5f505e29144fd = $(`&lt;div id=&quot;html_0df7f2a61b132159afc5f505e29144fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7b65476da9947369ef5ef9081841a4b7.setContent(html_0df7f2a61b132159afc5f505e29144fd);
#
#
#
#         marker_a321138930b57002c2baa39d5904aa45.bindPopup(popup_7b65476da9947369ef5ef9081841a4b7)
#         ;
#
#
#
#
#             var marker_83f2555f75dfa553a802eaa16a50004d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_caeba2ed47cd1ad60f16b1d0d2181e20);
#
#
#         var popup_1181e2512c11e6b61e6bb97315ab57c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8e94b15a4980b213973bf16b38f6dcb = $(`&lt;div id=&quot;html_c8e94b15a4980b213973bf16b38f6dcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1181e2512c11e6b61e6bb97315ab57c9.setContent(html_c8e94b15a4980b213973bf16b38f6dcb);
#
#
#
#         marker_
