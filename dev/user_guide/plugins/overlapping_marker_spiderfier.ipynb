# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67a5c8650655d4abd92aeb4a77531bc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67a5c8650655d4abd92aeb4a77531bc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67a5c8650655d4abd92aeb4a77531bc7 = L.map(
#                 &quot;map_67a5c8650655d4abd92aeb4a77531bc7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_102cf4dd3943eca43eb0c0c181d29fb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_102cf4dd3943eca43eb0c0c181d29fb7.addTo(map_67a5c8650655d4abd92aeb4a77531bc7);
#
#
#             var marker_fef470ad83428ba06aa4451292e832b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_67a5c8650655d4abd92aeb4a77531bc7);
#
#
#         var popup_1d53609f9605db159e9c30615d16eeaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_222ce709ad301498635507d29bec0c53 = $(`&lt;div id=&quot;html_222ce709ad301498635507d29bec0c53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d53609f9605db159e9c30615d16eeaa.setContent(html_222ce709ad301498635507d29bec0c53);
#
#
#
#         marker_fef470ad83428ba06aa4451292e832b8.bindPopup(popup_1d53609f9605db159e9c30615d16eeaa)
#         ;
#
#
#
#
#             var marker_579b2368a7bce627bfa67b426b180cd7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_67a5c8650655d4abd92aeb4a77531bc7);
#
#
#         var popup_e317c7146381b78ab025ab2879babc0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c06e932960035d79bf5757712ff13606 = $(`&lt;div id=&quot;html_c06e932960035d79bf5757712ff13606&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e317c7146381b78ab025ab2879babc0b.setContent(html_c06e932960035d79bf5757712ff13606);
#
#
#
#         marker_579b2368a7bce627bfa67b426b180cd7.bindPopup(popup_e317c7146381b78ab025ab2879babc0b)
#         ;
#
#
#
#
#             var marker_d017c41dc1f3ac6f78a1de8228b7773c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_67a5c8650655d4abd92aeb4a77531bc7);
#
#
#         var popup_cc4e4a16dd16b9f8f12d07318bf73f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c609912e99ee6804faf0e26ce353998 = $(`&lt;div id=&quot;html_1c609912e99ee6804faf0e26ce353998&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cc4e4a16dd16b9f8f12d07318bf73f71.setContent(html_1c609912e99ee6804faf0e26ce353998);
#
#
#
#         marker_d017c41dc1f3ac6f78a1de8228b7773c.bindPopup(popup_cc4e4a16dd16b9f8f12d07318bf73f71)
#         ;
#
#
#
#
#             var marker_a9dd9ff92be092a6da1d5dd703081f3d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_67a5c8650655d4abd92aeb4a77531bc7);
#
#
#         var popup_371e8f3667d89b113ded92aaa08a5f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5913eca7318ab7532f562e2db4992666 = $(`&lt;div id=&quot;html_5913eca7318ab7532f562e2db4992666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_371e8f3667d89b113ded92aaa08a5f71.setContent(html_5913eca7318ab7532f562e2db4992666);
#
#
#
#         marker_a9dd9ff92be092a6da1d5dd703081f3d.bindPopup(popup_371e8f3667d89b113ded92aaa08a5f71)
#         ;
#
#
#
#
#             var marker_c2d52664806870cdf00e6d77e5098cf0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_67a5c8650655d4abd92aeb4a77531bc7);
#
#
#         var popup_be47a0f6bd91cabe892d5c921f3b7161 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c918dccba18f775cd171cd98780c7302 = $(`&lt;div id=&quot;html_c918dccba18f775cd171cd98780c7302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_be47a0f6bd91cabe892d5c921f3b7161.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97a6ae1faf0a938cac9141ad3c8158ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97a6ae1faf0a938cac9141ad3c8158ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97a6ae1faf0a938cac9141ad3c8158ae = L.map(
#                 &quot;map_97a6ae1faf0a938cac9141ad3c8158ae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_455b88104a4d921071b4d3bc4fe6f8ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_455b88104a4d921071b4d3bc4fe6f8ad.addTo(map_97a6ae1faf0a938cac9141ad3c8158ae);
#
#
#             var feature_group_dd9a165d337ec51897256caa1f278206 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2dd188ef40844a7da12550d8d720d35b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dd9a165d337ec51897256caa1f278206);
#
#
#         var popup_3b015deaf32893a8b8de9c29fccc1f67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a482db044b1d3ae64f880df309e143e = $(`&lt;div id=&quot;html_0a482db044b1d3ae64f880df309e143e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3b015deaf32893a8b8de9c29fccc1f67.setContent(html_0a482db044b1d3ae64f880df309e143e);
#
#
#
#         marker_2dd188ef40844a7da12550d8d720d35b.bindPopup(popup_3b015deaf32893a8b8de9c29fccc1f67)
#         ;
#
#
#
#
#             var marker_60e8476dc40d9f2a98e2be3edadce0af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dd9a165d337ec51897256caa1f278206);
#
#
#         var popup_3c4bfaad66d43e1e0a1d236e44b6956c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e977be551b90296ee651f5857d609f98 = $(`&lt;div id=&quot;html_e977be551b90296ee651f5857d609f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3c4bfaad66d43e1e0a1d236e44b6956c.setContent(html_e977be551b90296ee651f5857d609f98);
#
#
#
#         marker_60e8476dc40d9f2a98e2be3edadce0af.bindPopup(popup_3c4bfaad66d43e1e0a1d236e44b6956c)
#         ;
#
#
#
#
#             var marker_6d43a788e6393484e8101c89edbc1885 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dd9a165d337ec51897256caa1f278206);
#
#
#         var popup_d9de3b07dfdd277a7edd98c32a9565a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fc546bc376074ecd2e773e7922023bc = $(`&lt;div id=&quot;html_3fc546bc376074ecd2e773e7922023bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d9de3b07dfdd277a7edd98c32a9565a5.setContent(html_3fc546bc376074ecd2e773e7922023bc);
#
#
#
#         marker_6d43a788e6393484e8101c89edbc1885.bindPopup(popup_d9de3b07dfdd277a7edd98c32a9565a5)
#         ;
#
#
#
#
#             var marker_080fe95b7eaeab7a3d83a6702a712566 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dd9a165d337ec51897256caa1f278206);
#
#
#         var popup_75666a58e181b85ab0edd218625671f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b00f01dfb6ec6cc6bd6cee7c576b7246 = $(`&lt;div id=&quot;html_b00f01dfb6ec6cc6bd6cee7c576b7246&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_75666a58e181b85ab0edd218625671f5.setContent(html_b00f01dfb6ec6cc6bd6cee7c576b7246);
#
#
#
#         marker_080fe95b7eaeab7a3d83a6702a712566.bindPopup(popup_75666a58e181b85ab0edd218625671f5)
#         ;
#
#
#
#
#             var marker_2ed35b00f791651369af3c0c0fffa172 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dd9a165d337ec51897256caa1f278206);
#
#
#         var popup_ff6f9b59bcbaa28091c6a18c173833f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cd4aa536137ea25595b6dae7630070b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cd4aa536137ea25595b6dae7630070b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cd4aa536137ea25595b6dae7630070b = L.map(
#                 &quot;map_8cd4aa536137ea25595b6dae7630070b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2adae00b0e8d56932ebe366ab240faa8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2adae00b0e8d56932ebe366ab240faa8.addTo(map_8cd4aa536137ea25595b6dae7630070b);
#
#
#             var feature_group_9bc3414cd315bf7be2f4b2d0fdd1ffb1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9bc3414cd315bf7be2f4b2d0fdd1ffb1.addTo(map_8cd4aa536137ea25595b6dae7630070b);
#
#
#             var feature_group_sub_group_3576904fe99e0c8d1323937460874225 = L.featureGroup.subGroup(
#                 feature_group_9bc3414cd315bf7be2f4b2d0fdd1ffb1
#             );
#
#
#             var marker_9b3527e3539a653b56f04c9656ce8a65 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3576904fe99e0c8d1323937460874225);
#
#
#         var popup_78e7671ae7d5bdd53dba14dcbb98408d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a097ba7100508dfeeaaa8320f4df20d3 = $(`&lt;div id=&quot;html_a097ba7100508dfeeaaa8320f4df20d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_78e7671ae7d5bdd53dba14dcbb98408d.setContent(html_a097ba7100508dfeeaaa8320f4df20d3);
#
#
#
#         marker_9b3527e3539a653b56f04c9656ce8a65.bindPopup(popup_78e7671ae7d5bdd53dba14dcbb98408d)
#         ;
#
#
#
#
#             var marker_57227d5361c3be79e105931856c7bdd4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3576904fe99e0c8d1323937460874225);
#
#
#         var popup_b2573b46ddb2f42cec0f5931d09f5f44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37cc3c65b02adb3cd3acb0a324117a92 = $(`&lt;div id=&quot;html_37cc3c65b02adb3cd3acb0a324117a92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b2573b46ddb2f42cec0f5931d09f5f44.setContent(html_37cc3c65b02adb3cd3acb0a324117a92);
#
#
#
#         marker_57227d5361c3be79e105931856c7bdd4.bindPopup(popup_b2573b46ddb2f42cec0f5931d09f5f44)
#         ;
#
#
#
#
#             var marker_f7079552fc0b150bfd624d5f6411cf21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3576904fe99e0c8d1323937460874225);
#
#
#         var popup_444145f31810c276f70403ad99f3fcb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3824d0b51a3e7860a6f3ada43d67202e = $(`&lt;div id=&quot;html_3824d0b51a3e7860a6f3ada43d67202e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_444145f31810c276f70403ad99f3fcb6.setContent(html_3824d0b51a3e7860a6f3ada43d67202e);
#
#
#
#         marker_f7079552fc0b150bfd624d5f6411cf21.bindPopup(popup_444145f31810c276f70403ad99f3fcb6)
#         ;
#
#
#
#
#             var marker_d1d1143b3b515305b6778809381c934e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3576904fe99e0c8d1323937460874225);
#
#
#         var popup_097d7be3790f1bb8345e80e54c82dcf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_650c7e4636b9271d3c366de8b7789222 = $(`&lt;div id=&quot;html_650c7e4636b9271d3c366de8b7789222&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_097d7be3790f1bb8345e80e54c82dcf7.setContent(html_650c7e4636b9271d3c366de8b7789222);
#
#
#
#         marker_
