# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a635b17fbb4981ab0f1ab325f881a38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a635b17fbb4981ab0f1ab325f881a38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a635b17fbb4981ab0f1ab325f881a38 = L.map(
#                 &quot;map_1a635b17fbb4981ab0f1ab325f881a38&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bba8220f0d604e050ab6fe3797f9a57b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bba8220f0d604e050ab6fe3797f9a57b.addTo(map_1a635b17fbb4981ab0f1ab325f881a38);
#
#
#             var marker_e9a159f1ade31c95cd1657d2b79352ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1a635b17fbb4981ab0f1ab325f881a38);
#
#
#         var popup_55cd8d0966b91fcb3ae981252976b685 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_202ca7d8ea4885bab0f9d84c592d03c8 = $(`&lt;div id=&quot;html_202ca7d8ea4885bab0f9d84c592d03c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_55cd8d0966b91fcb3ae981252976b685.setContent(html_202ca7d8ea4885bab0f9d84c592d03c8);
#
#
#
#         marker_e9a159f1ade31c95cd1657d2b79352ff.bindPopup(popup_55cd8d0966b91fcb3ae981252976b685)
#         ;
#
#
#
#
#             var marker_9c617b1100ac72cd228ffc437fb47cda = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1a635b17fbb4981ab0f1ab325f881a38);
#
#
#         var popup_3c084f6d00a227a109a8996d8d030069 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_585c4c848f41303c59fb2a69ec6073eb = $(`&lt;div id=&quot;html_585c4c848f41303c59fb2a69ec6073eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3c084f6d00a227a109a8996d8d030069.setContent(html_585c4c848f41303c59fb2a69ec6073eb);
#
#
#
#         marker_9c617b1100ac72cd228ffc437fb47cda.bindPopup(popup_3c084f6d00a227a109a8996d8d030069)
#         ;
#
#
#
#
#             var marker_695dc9b0b3da6abb767f6dba9cded4df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1a635b17fbb4981ab0f1ab325f881a38);
#
#
#         var popup_67d80c1f2a3327dbf931243064dfb042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de0f2a6323511033b9ff1285f13f5391 = $(`&lt;div id=&quot;html_de0f2a6323511033b9ff1285f13f5391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_67d80c1f2a3327dbf931243064dfb042.setContent(html_de0f2a6323511033b9ff1285f13f5391);
#
#
#
#         marker_695dc9b0b3da6abb767f6dba9cded4df.bindPopup(popup_67d80c1f2a3327dbf931243064dfb042)
#         ;
#
#
#
#
#             var marker_cda3c5b980d310126672ce147a662ced = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1a635b17fbb4981ab0f1ab325f881a38);
#
#
#         var popup_60372d96756ba418608464db2ad63e9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bc4ac6c009ae366259e73394a477010 = $(`&lt;div id=&quot;html_5bc4ac6c009ae366259e73394a477010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60372d96756ba418608464db2ad63e9a.setContent(html_5bc4ac6c009ae366259e73394a477010);
#
#
#
#         marker_cda3c5b980d310126672ce147a662ced.bindPopup(popup_60372d96756ba418608464db2ad63e9a)
#         ;
#
#
#
#
#             var marker_68a68bf4b324f68d67c313cc40b49563 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1a635b17fbb4981ab0f1ab325f881a38);
#
#
#         var popup_5e87b6f3646fc6d41c62dc2cf061bcf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa95ee7465115f2ffabd730677883a17 = $(`&lt;div id=&quot;html_aa95ee7465115f2ffabd730677883a17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e87b6f3646fc6d41c62dc2cf061bcf6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70ec608b51c67c52ddb24ec4fc510806 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70ec608b51c67c52ddb24ec4fc510806&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70ec608b51c67c52ddb24ec4fc510806 = L.map(
#                 &quot;map_70ec608b51c67c52ddb24ec4fc510806&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a789f6c6648a92c7bdc37abf9ad1e4d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a789f6c6648a92c7bdc37abf9ad1e4d5.addTo(map_70ec608b51c67c52ddb24ec4fc510806);
#
#
#             var feature_group_b98bb72c6a47415bdb26287ae78fbb22 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1598ed45a87b4e8300484268627fc423 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b98bb72c6a47415bdb26287ae78fbb22);
#
#
#         var popup_ebce5c9ed1b42b78b749571ef41d5640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1df0a209399705a6810529ca0ef48a6 = $(`&lt;div id=&quot;html_b1df0a209399705a6810529ca0ef48a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ebce5c9ed1b42b78b749571ef41d5640.setContent(html_b1df0a209399705a6810529ca0ef48a6);
#
#
#
#         marker_1598ed45a87b4e8300484268627fc423.bindPopup(popup_ebce5c9ed1b42b78b749571ef41d5640)
#         ;
#
#
#
#
#             var marker_56553da53e67d9986b7c8e4e5f88005e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b98bb72c6a47415bdb26287ae78fbb22);
#
#
#         var popup_87a81cb837a2e621ba0b55d73315d2c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_624c721907dbf649d607eaef88ecb9e0 = $(`&lt;div id=&quot;html_624c721907dbf649d607eaef88ecb9e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_87a81cb837a2e621ba0b55d73315d2c5.setContent(html_624c721907dbf649d607eaef88ecb9e0);
#
#
#
#         marker_56553da53e67d9986b7c8e4e5f88005e.bindPopup(popup_87a81cb837a2e621ba0b55d73315d2c5)
#         ;
#
#
#
#
#             var marker_9153dee854d68887c3a1f2a6fb822e68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b98bb72c6a47415bdb26287ae78fbb22);
#
#
#         var popup_f6284a9b0c8667b817e0b24c241c022a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce8b98c94b73fd2778a10f54a1bf6306 = $(`&lt;div id=&quot;html_ce8b98c94b73fd2778a10f54a1bf6306&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f6284a9b0c8667b817e0b24c241c022a.setContent(html_ce8b98c94b73fd2778a10f54a1bf6306);
#
#
#
#         marker_9153dee854d68887c3a1f2a6fb822e68.bindPopup(popup_f6284a9b0c8667b817e0b24c241c022a)
#         ;
#
#
#
#
#             var marker_f8ffb0ea2d105a0fe2fdd8852c8a83a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b98bb72c6a47415bdb26287ae78fbb22);
#
#
#         var popup_32a402860166043e865fc90387999785 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_820deaba00cedb2189adbb92be1d1db5 = $(`&lt;div id=&quot;html_820deaba00cedb2189adbb92be1d1db5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_32a402860166043e865fc90387999785.setContent(html_820deaba00cedb2189adbb92be1d1db5);
#
#
#
#         marker_f8ffb0ea2d105a0fe2fdd8852c8a83a3.bindPopup(popup_32a402860166043e865fc90387999785)
#         ;
#
#
#
#
#             var marker_eec31ad762de74fdbfa4ef79dce0a637 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b98bb72c6a47415bdb26287ae78fbb22);
#
#
#         var popup_c44344b7585a3cbd8d0cbafffa3eb891 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91449fa47e7f730503052091158736ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91449fa47e7f730503052091158736ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91449fa47e7f730503052091158736ac = L.map(
#                 &quot;map_91449fa47e7f730503052091158736ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70cb1443b4b99edaf1260b1874939eba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70cb1443b4b99edaf1260b1874939eba.addTo(map_91449fa47e7f730503052091158736ac);
#
#
#             var feature_group_2fbc82a1b9a0ee4bf2036b83f306482c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2fbc82a1b9a0ee4bf2036b83f306482c.addTo(map_91449fa47e7f730503052091158736ac);
#
#
#             var feature_group_sub_group_e0840d3b479ae03e305f1ee4cf3a3fe8 = L.featureGroup.subGroup(
#                 feature_group_2fbc82a1b9a0ee4bf2036b83f306482c
#             );
#
#
#             var marker_9849ca7676b3c83aeaaf4960f6e006ac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e0840d3b479ae03e305f1ee4cf3a3fe8);
#
#
#         var popup_b4aefe3de03e799fd71828d67b320491 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c3b947ca78f12aeac0f8b1801f4ab51 = $(`&lt;div id=&quot;html_7c3b947ca78f12aeac0f8b1801f4ab51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b4aefe3de03e799fd71828d67b320491.setContent(html_7c3b947ca78f12aeac0f8b1801f4ab51);
#
#
#
#         marker_9849ca7676b3c83aeaaf4960f6e006ac.bindPopup(popup_b4aefe3de03e799fd71828d67b320491)
#         ;
#
#
#
#
#             var marker_391d78e5cc33210fa36feacaa36cb061 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e0840d3b479ae03e305f1ee4cf3a3fe8);
#
#
#         var popup_a9e9a305001646210afeb4753e961ede = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8b80b3ea8111accdadb67ca16942288 = $(`&lt;div id=&quot;html_a8b80b3ea8111accdadb67ca16942288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a9e9a305001646210afeb4753e961ede.setContent(html_a8b80b3ea8111accdadb67ca16942288);
#
#
#
#         marker_391d78e5cc33210fa36feacaa36cb061.bindPopup(popup_a9e9a305001646210afeb4753e961ede)
#         ;
#
#
#
#
#             var marker_69a4137faf5b3f35eaef213c4fee0f17 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e0840d3b479ae03e305f1ee4cf3a3fe8);
#
#
#         var popup_6e1cc8bd8642f50bee764b97f792ff35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_247cc0fea5e764b606d55592d9847a16 = $(`&lt;div id=&quot;html_247cc0fea5e764b606d55592d9847a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6e1cc8bd8642f50bee764b97f792ff35.setContent(html_247cc0fea5e764b606d55592d9847a16);
#
#
#
#         marker_69a4137faf5b3f35eaef213c4fee0f17.bindPopup(popup_6e1cc8bd8642f50bee764b97f792ff35)
#         ;
#
#
#
#
#             var marker_6749f26be50c05ee7a90149e1ec2f239 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e0840d3b479ae03e305f1ee4cf3a3fe8);
#
#
#         var popup_59b95978f65f1388d83ce1e6d1b7a2e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d812b0e69a624e727c99f435d2c2f57 = $(`&lt;div id=&quot;html_3d812b0e69a624e727c99f435d2c2f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_59b95978f65f1388d83ce1e6d1b7a2e8.setContent(html_3d812b0e69a624e727c99f435d2c2f57);
#
#
#
#         marker_
