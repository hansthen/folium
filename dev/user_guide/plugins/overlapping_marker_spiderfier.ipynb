# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ec90b6c7706a55ee3f3e53b0d7201b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ec90b6c7706a55ee3f3e53b0d7201b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ec90b6c7706a55ee3f3e53b0d7201b0 = L.map(
#                 &quot;map_9ec90b6c7706a55ee3f3e53b0d7201b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93aa0aed758eb4d56d1a173f022fcaad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93aa0aed758eb4d56d1a173f022fcaad.addTo(map_9ec90b6c7706a55ee3f3e53b0d7201b0);
#
#
#             var marker_ebf5100996e084a5125c7d7c30c0ad80 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9ec90b6c7706a55ee3f3e53b0d7201b0);
#
#
#         var popup_39e2a7aae483f7da76fee8f9b7c83215 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_600bc004393b3ca7f36f80521b4506d3 = $(`&lt;div id=&quot;html_600bc004393b3ca7f36f80521b4506d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_39e2a7aae483f7da76fee8f9b7c83215.setContent(html_600bc004393b3ca7f36f80521b4506d3);
#
#
#
#         marker_ebf5100996e084a5125c7d7c30c0ad80.bindPopup(popup_39e2a7aae483f7da76fee8f9b7c83215)
#         ;
#
#
#
#
#             var marker_863d389df04455126a167f8f4fa18df8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9ec90b6c7706a55ee3f3e53b0d7201b0);
#
#
#         var popup_dccec8c94b771445e7025c9f0079aaec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6074c65d212b9ed1fa19dca4218c25fc = $(`&lt;div id=&quot;html_6074c65d212b9ed1fa19dca4218c25fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dccec8c94b771445e7025c9f0079aaec.setContent(html_6074c65d212b9ed1fa19dca4218c25fc);
#
#
#
#         marker_863d389df04455126a167f8f4fa18df8.bindPopup(popup_dccec8c94b771445e7025c9f0079aaec)
#         ;
#
#
#
#
#             var marker_9f1cbd2e15ee188ab4b039d3a2b8f4ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9ec90b6c7706a55ee3f3e53b0d7201b0);
#
#
#         var popup_a01f9efe0db78e14a27119cb9b5b6191 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f71a03feb56a4fea49ba37e886f19fba = $(`&lt;div id=&quot;html_f71a03feb56a4fea49ba37e886f19fba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a01f9efe0db78e14a27119cb9b5b6191.setContent(html_f71a03feb56a4fea49ba37e886f19fba);
#
#
#
#         marker_9f1cbd2e15ee188ab4b039d3a2b8f4ed.bindPopup(popup_a01f9efe0db78e14a27119cb9b5b6191)
#         ;
#
#
#
#
#             var marker_436db81f46cb45707f382bb8385c2fba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9ec90b6c7706a55ee3f3e53b0d7201b0);
#
#
#         var popup_e21868db64188e9302d6307455b88aa2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6d3e8b76d6fab9c08baf72245c4398d = $(`&lt;div id=&quot;html_d6d3e8b76d6fab9c08baf72245c4398d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e21868db64188e9302d6307455b88aa2.setContent(html_d6d3e8b76d6fab9c08baf72245c4398d);
#
#
#
#         marker_436db81f46cb45707f382bb8385c2fba.bindPopup(popup_e21868db64188e9302d6307455b88aa2)
#         ;
#
#
#
#
#             var marker_f3d7e4ded02ea9ab2c6574ab49df09c9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9ec90b6c7706a55ee3f3e53b0d7201b0);
#
#
#         var popup_42dba29cd4db30e60992ba60be971b60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2854ed51d4d3d6b0340e364908c40ec1 = $(`&lt;div id=&quot;html_2854ed51d4d3d6b0340e364908c40ec1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_42dba29cd4db30e60992ba60be971b60.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cf6e9775e0b98b08908b9f52c3c699b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cf6e9775e0b98b08908b9f52c3c699b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cf6e9775e0b98b08908b9f52c3c699b = L.map(
#                 &quot;map_0cf6e9775e0b98b08908b9f52c3c699b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c92d23279319ee7d64b582aec732c46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c92d23279319ee7d64b582aec732c46.addTo(map_0cf6e9775e0b98b08908b9f52c3c699b);
#
#
#             var feature_group_483a00a95be7cf39f8f881b188e399c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e5b54fb81454b87c02a83df702a4a453 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_483a00a95be7cf39f8f881b188e399c6);
#
#
#         var popup_4fb1a9c06870e60e0552d3f13a97b1ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9ca1e0ccde4f41ad5b546e4d4aa53a = $(`&lt;div id=&quot;html_dc9ca1e0ccde4f41ad5b546e4d4aa53a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4fb1a9c06870e60e0552d3f13a97b1ec.setContent(html_dc9ca1e0ccde4f41ad5b546e4d4aa53a);
#
#
#
#         marker_e5b54fb81454b87c02a83df702a4a453.bindPopup(popup_4fb1a9c06870e60e0552d3f13a97b1ec)
#         ;
#
#
#
#
#             var marker_1a3b8ba6b06f606c7edc60dd601c6089 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_483a00a95be7cf39f8f881b188e399c6);
#
#
#         var popup_96095a49d8f18f38e0d6452675a54c4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9723bd7f830b5b1d0bd422e90641380 = $(`&lt;div id=&quot;html_e9723bd7f830b5b1d0bd422e90641380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_96095a49d8f18f38e0d6452675a54c4e.setContent(html_e9723bd7f830b5b1d0bd422e90641380);
#
#
#
#         marker_1a3b8ba6b06f606c7edc60dd601c6089.bindPopup(popup_96095a49d8f18f38e0d6452675a54c4e)
#         ;
#
#
#
#
#             var marker_9b9449d3e46ece542ab6143c3b7084c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_483a00a95be7cf39f8f881b188e399c6);
#
#
#         var popup_e8d87595ff82c57feb6bc72e7b1e59da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89fcb8c03b73a71509cd35bad31fe937 = $(`&lt;div id=&quot;html_89fcb8c03b73a71509cd35bad31fe937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e8d87595ff82c57feb6bc72e7b1e59da.setContent(html_89fcb8c03b73a71509cd35bad31fe937);
#
#
#
#         marker_9b9449d3e46ece542ab6143c3b7084c6.bindPopup(popup_e8d87595ff82c57feb6bc72e7b1e59da)
#         ;
#
#
#
#
#             var marker_c807a879d7338ed4ff4699321dce0c1e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_483a00a95be7cf39f8f881b188e399c6);
#
#
#         var popup_86ca620ad3191d9ad82c02c0ca091cd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95f745dc03f5f6ae21d6ce6a3954824c = $(`&lt;div id=&quot;html_95f745dc03f5f6ae21d6ce6a3954824c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_86ca620ad3191d9ad82c02c0ca091cd7.setContent(html_95f745dc03f5f6ae21d6ce6a3954824c);
#
#
#
#         marker_c807a879d7338ed4ff4699321dce0c1e.bindPopup(popup_86ca620ad3191d9ad82c02c0ca091cd7)
#         ;
#
#
#
#
#             var marker_db4ad8b5d733814abae0f1f677586b27 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_483a00a95be7cf39f8f881b188e399c6);
#
#
#         var popup_f7db3bbed455bead6d8243920acade2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_149d1f4193e00315ee34c4fd3147f793 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_149d1f4193e00315ee34c4fd3147f793&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_149d1f4193e00315ee34c4fd3147f793 = L.map(
#                 &quot;map_149d1f4193e00315ee34c4fd3147f793&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_350217ab90c9c45eea95399e59683dc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_350217ab90c9c45eea95399e59683dc4.addTo(map_149d1f4193e00315ee34c4fd3147f793);
#
#
#             var feature_group_77bae7252e476c1ff171b5d8b2d61985 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_77bae7252e476c1ff171b5d8b2d61985.addTo(map_149d1f4193e00315ee34c4fd3147f793);
#
#
#             var feature_group_sub_group_b32ea8f42ee5aed0ca556b9e5b0f977d = L.featureGroup.subGroup(
#                 feature_group_77bae7252e476c1ff171b5d8b2d61985
#             );
#
#
#             var marker_f9c0e362c454fdfbede6884e4b5dad20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b32ea8f42ee5aed0ca556b9e5b0f977d);
#
#
#         var popup_8a0f9b2386ec01ebd7fa6779e467a07d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_317605a38c0255ec413cae80ff1ca73e = $(`&lt;div id=&quot;html_317605a38c0255ec413cae80ff1ca73e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8a0f9b2386ec01ebd7fa6779e467a07d.setContent(html_317605a38c0255ec413cae80ff1ca73e);
#
#
#
#         marker_f9c0e362c454fdfbede6884e4b5dad20.bindPopup(popup_8a0f9b2386ec01ebd7fa6779e467a07d)
#         ;
#
#
#
#
#             var marker_8cdda848108dc87fe38147feb1e0dcb8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b32ea8f42ee5aed0ca556b9e5b0f977d);
#
#
#         var popup_fdec2a90cfcffa4e2940f3d8a9a69d88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d2329f8c88f367c03f6d2b30fff3d82 = $(`&lt;div id=&quot;html_8d2329f8c88f367c03f6d2b30fff3d82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fdec2a90cfcffa4e2940f3d8a9a69d88.setContent(html_8d2329f8c88f367c03f6d2b30fff3d82);
#
#
#
#         marker_8cdda848108dc87fe38147feb1e0dcb8.bindPopup(popup_fdec2a90cfcffa4e2940f3d8a9a69d88)
#         ;
#
#
#
#
#             var marker_594218620e72ead3a914b6ce3ed6a3fe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b32ea8f42ee5aed0ca556b9e5b0f977d);
#
#
#         var popup_d0e76241e6bdcdc2cdf80692ca320b81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_738d389f65aaae8f8aece67d7304b3a8 = $(`&lt;div id=&quot;html_738d389f65aaae8f8aece67d7304b3a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d0e76241e6bdcdc2cdf80692ca320b81.setContent(html_738d389f65aaae8f8aece67d7304b3a8);
#
#
#
#         marker_594218620e72ead3a914b6ce3ed6a3fe.bindPopup(popup_d0e76241e6bdcdc2cdf80692ca320b81)
#         ;
#
#
#
#
#             var marker_f7434dfb2d5f3b36aa51249773618f40 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b32ea8f42ee5aed0ca556b9e5b0f977d);
#
#
#         var popup_59daa71f7ce3a472e0f39bb26b1b59f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fb033dc2a84c3e71643e6716517884a = $(`&lt;div id=&quot;html_4fb033dc2a84c3e71643e6716517884a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_59daa71f7ce3a472e0f39bb26b1b59f8.setContent(html_4fb033dc2a84c3e71643e6716517884a);
#
#
#
#         marker_
