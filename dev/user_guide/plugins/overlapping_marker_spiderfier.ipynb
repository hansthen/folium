# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c73af9ceab2e75020dd934ee187cd940 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c73af9ceab2e75020dd934ee187cd940&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c73af9ceab2e75020dd934ee187cd940 = L.map(
#                 &quot;map_c73af9ceab2e75020dd934ee187cd940&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a76501d928b30de23ced81e4e832add = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a76501d928b30de23ced81e4e832add.addTo(map_c73af9ceab2e75020dd934ee187cd940);
#
#
#             var marker_852a0a3eff380a396a5d2f9c7f73fac0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c73af9ceab2e75020dd934ee187cd940);
#
#
#         var popup_8527c91b1b3d8b82903b416dee6c07c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_092a86515663d0e82bbe5e04e978b002 = $(`&lt;div id=&quot;html_092a86515663d0e82bbe5e04e978b002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8527c91b1b3d8b82903b416dee6c07c1.setContent(html_092a86515663d0e82bbe5e04e978b002);
#
#
#
#         marker_852a0a3eff380a396a5d2f9c7f73fac0.bindPopup(popup_8527c91b1b3d8b82903b416dee6c07c1)
#         ;
#
#
#
#
#             var marker_66020c40a84c7ae366eb46624bbc5015 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c73af9ceab2e75020dd934ee187cd940);
#
#
#         var popup_e71eee4d1c92a41a25c326dd910bfa4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf63a07867e83073257b7597633f3fed = $(`&lt;div id=&quot;html_bf63a07867e83073257b7597633f3fed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e71eee4d1c92a41a25c326dd910bfa4b.setContent(html_bf63a07867e83073257b7597633f3fed);
#
#
#
#         marker_66020c40a84c7ae366eb46624bbc5015.bindPopup(popup_e71eee4d1c92a41a25c326dd910bfa4b)
#         ;
#
#
#
#
#             var marker_d66d1374b21c20c76f4238489d4157ba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c73af9ceab2e75020dd934ee187cd940);
#
#
#         var popup_c7e654c94bfcf9bed69dd66c3fcc72a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1e6e604c636f33183da62e2fd168349 = $(`&lt;div id=&quot;html_c1e6e604c636f33183da62e2fd168349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c7e654c94bfcf9bed69dd66c3fcc72a4.setContent(html_c1e6e604c636f33183da62e2fd168349);
#
#
#
#         marker_d66d1374b21c20c76f4238489d4157ba.bindPopup(popup_c7e654c94bfcf9bed69dd66c3fcc72a4)
#         ;
#
#
#
#
#             var marker_5d07e4a74d7c34a67a31c6201469d2d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c73af9ceab2e75020dd934ee187cd940);
#
#
#         var popup_18a0efa94260516fbedc72790f0ebf33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2b673076d7654cb57808053c1865dd4 = $(`&lt;div id=&quot;html_a2b673076d7654cb57808053c1865dd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18a0efa94260516fbedc72790f0ebf33.setContent(html_a2b673076d7654cb57808053c1865dd4);
#
#
#
#         marker_5d07e4a74d7c34a67a31c6201469d2d8.bindPopup(popup_18a0efa94260516fbedc72790f0ebf33)
#         ;
#
#
#
#
#             var marker_bea5f2d1e3cc6e58f6d35f72bb9e33e1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c73af9ceab2e75020dd934ee187cd940);
#
#
#         var popup_29d659285bd888f03c073e48b6083fa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de5b0c7458915473486dd18d30086cf1 = $(`&lt;div id=&quot;html_de5b0c7458915473486dd18d30086cf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_29d659285bd888f03c073e48b6083fa9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9426d778e7323ebd32cdbeb4f742c34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9426d778e7323ebd32cdbeb4f742c34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9426d778e7323ebd32cdbeb4f742c34 = L.map(
#                 &quot;map_a9426d778e7323ebd32cdbeb4f742c34&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c93a6bd8a8a6be94d3c3bab1d08ec50b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c93a6bd8a8a6be94d3c3bab1d08ec50b.addTo(map_a9426d778e7323ebd32cdbeb4f742c34);
#
#
#             var feature_group_82bfde15990e5c11505f5cfd7e01f92e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aefa998ed3795b5a02d7ac01206c8ab7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_82bfde15990e5c11505f5cfd7e01f92e);
#
#
#         var popup_f32ac86a4ce45ae349979552fb6bc06b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94cf4fccf9980603061fb7529bd4bcbe = $(`&lt;div id=&quot;html_94cf4fccf9980603061fb7529bd4bcbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f32ac86a4ce45ae349979552fb6bc06b.setContent(html_94cf4fccf9980603061fb7529bd4bcbe);
#
#
#
#         marker_aefa998ed3795b5a02d7ac01206c8ab7.bindPopup(popup_f32ac86a4ce45ae349979552fb6bc06b)
#         ;
#
#
#
#
#             var marker_a530c53199c5e74689ad04533d99dbb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_82bfde15990e5c11505f5cfd7e01f92e);
#
#
#         var popup_9ab9d77842896773d9d940db2d9f1782 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_467db6835b535a69f582ccd430b20a98 = $(`&lt;div id=&quot;html_467db6835b535a69f582ccd430b20a98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9ab9d77842896773d9d940db2d9f1782.setContent(html_467db6835b535a69f582ccd430b20a98);
#
#
#
#         marker_a530c53199c5e74689ad04533d99dbb0.bindPopup(popup_9ab9d77842896773d9d940db2d9f1782)
#         ;
#
#
#
#
#             var marker_6a548bb0bec88e07a8a717c7f8930ca2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_82bfde15990e5c11505f5cfd7e01f92e);
#
#
#         var popup_6525f5b8f08349e145f61c4bca52a5c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5895d79cffa71ddf79fe754425c8e4a9 = $(`&lt;div id=&quot;html_5895d79cffa71ddf79fe754425c8e4a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6525f5b8f08349e145f61c4bca52a5c4.setContent(html_5895d79cffa71ddf79fe754425c8e4a9);
#
#
#
#         marker_6a548bb0bec88e07a8a717c7f8930ca2.bindPopup(popup_6525f5b8f08349e145f61c4bca52a5c4)
#         ;
#
#
#
#
#             var marker_a70dd562e30626045a52c8268f3e7dd7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_82bfde15990e5c11505f5cfd7e01f92e);
#
#
#         var popup_3c1741c686c7cf15c37666f1705517d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01aa258a8b96cc3e8498ef3bf99c221e = $(`&lt;div id=&quot;html_01aa258a8b96cc3e8498ef3bf99c221e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c1741c686c7cf15c37666f1705517d9.setContent(html_01aa258a8b96cc3e8498ef3bf99c221e);
#
#
#
#         marker_a70dd562e30626045a52c8268f3e7dd7.bindPopup(popup_3c1741c686c7cf15c37666f1705517d9)
#         ;
#
#
#
#
#             var marker_8ee195a01c611aa0e7b48af6f11263da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_82bfde15990e5c11505f5cfd7e01f92e);
#
#
#         var popup_f586fdd5a1a39e40f3846694fd327e50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_159b15927395f96fc19d3a9df7bbd01e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_159b15927395f96fc19d3a9df7bbd01e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_159b15927395f96fc19d3a9df7bbd01e = L.map(
#                 &quot;map_159b15927395f96fc19d3a9df7bbd01e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5943b2d84280b26650289c36fabc14bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5943b2d84280b26650289c36fabc14bc.addTo(map_159b15927395f96fc19d3a9df7bbd01e);
#
#
#             var feature_group_cdbf7f9c1316786fc418347052fd027e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cdbf7f9c1316786fc418347052fd027e.addTo(map_159b15927395f96fc19d3a9df7bbd01e);
#
#
#             var feature_group_sub_group_c5315bb5e24bfdb0c685a8fbd84c4bd0 = L.featureGroup.subGroup(
#                 feature_group_cdbf7f9c1316786fc418347052fd027e
#             );
#
#
#             var marker_f9cfc54a770134ac7384cb1e83fa3c5b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5315bb5e24bfdb0c685a8fbd84c4bd0);
#
#
#         var popup_918a229b01375e151c5fae2cd4c821eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_906e98e158ca74789ef90c2dcce84bf6 = $(`&lt;div id=&quot;html_906e98e158ca74789ef90c2dcce84bf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_918a229b01375e151c5fae2cd4c821eb.setContent(html_906e98e158ca74789ef90c2dcce84bf6);
#
#
#
#         marker_f9cfc54a770134ac7384cb1e83fa3c5b.bindPopup(popup_918a229b01375e151c5fae2cd4c821eb)
#         ;
#
#
#
#
#             var marker_8b3933c57ded624b809a7943c353ec32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5315bb5e24bfdb0c685a8fbd84c4bd0);
#
#
#         var popup_81e2ce25c29b4d3e91df958d46f3e080 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbacc4f9f52ce31ddc90a27d54f75d27 = $(`&lt;div id=&quot;html_fbacc4f9f52ce31ddc90a27d54f75d27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_81e2ce25c29b4d3e91df958d46f3e080.setContent(html_fbacc4f9f52ce31ddc90a27d54f75d27);
#
#
#
#         marker_8b3933c57ded624b809a7943c353ec32.bindPopup(popup_81e2ce25c29b4d3e91df958d46f3e080)
#         ;
#
#
#
#
#             var marker_790a6ddd95a296485c212c6eaede5fff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5315bb5e24bfdb0c685a8fbd84c4bd0);
#
#
#         var popup_f41be072e524531f0e07ce847eb48833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24d12e11ed85f57ec781bcb25d28c011 = $(`&lt;div id=&quot;html_24d12e11ed85f57ec781bcb25d28c011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f41be072e524531f0e07ce847eb48833.setContent(html_24d12e11ed85f57ec781bcb25d28c011);
#
#
#
#         marker_790a6ddd95a296485c212c6eaede5fff.bindPopup(popup_f41be072e524531f0e07ce847eb48833)
#         ;
#
#
#
#
#             var marker_878df37c17e1657380b6998b2fabe347 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5315bb5e24bfdb0c685a8fbd84c4bd0);
#
#
#         var popup_01a21d077377007d00ed0cc031ce6809 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5c61b1807be08006ef0f5337ded3990 = $(`&lt;div id=&quot;html_a5c61b1807be08006ef0f5337ded3990&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_01a21d077377007d00ed0cc031ce6809.setContent(html_a5c61b1807be08006ef0f5337ded3990);
#
#
#
#         marker_
