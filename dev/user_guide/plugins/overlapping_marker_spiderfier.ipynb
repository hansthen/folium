# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42173a3e7cdfc80515367a0976d0dab7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42173a3e7cdfc80515367a0976d0dab7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42173a3e7cdfc80515367a0976d0dab7 = L.map(
#                 &quot;map_42173a3e7cdfc80515367a0976d0dab7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_415ba6d8bb6a7a3f5f2d5ad238cef643 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_415ba6d8bb6a7a3f5f2d5ad238cef643.addTo(map_42173a3e7cdfc80515367a0976d0dab7);
#
#
#             var marker_a42b55c1c49d92a48930e1658f37f706 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_42173a3e7cdfc80515367a0976d0dab7);
#
#
#         var popup_537de2694b692a7b83e08c3572319bf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40685055565f0dbe4ab4ddafd2dc9d3a = $(`&lt;div id=&quot;html_40685055565f0dbe4ab4ddafd2dc9d3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_537de2694b692a7b83e08c3572319bf0.setContent(html_40685055565f0dbe4ab4ddafd2dc9d3a);
#
#
#
#         marker_a42b55c1c49d92a48930e1658f37f706.bindPopup(popup_537de2694b692a7b83e08c3572319bf0)
#         ;
#
#
#
#
#             var marker_3db965dc6d98bd2b13c8fbbb8eb5c366 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_42173a3e7cdfc80515367a0976d0dab7);
#
#
#         var popup_97ee97e8c67b4905c33a92df02ad70ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1c1a8aa665f827c07abee159a2e119e = $(`&lt;div id=&quot;html_e1c1a8aa665f827c07abee159a2e119e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_97ee97e8c67b4905c33a92df02ad70ff.setContent(html_e1c1a8aa665f827c07abee159a2e119e);
#
#
#
#         marker_3db965dc6d98bd2b13c8fbbb8eb5c366.bindPopup(popup_97ee97e8c67b4905c33a92df02ad70ff)
#         ;
#
#
#
#
#             var marker_3018c49838a533da9da63f71f7953e31 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_42173a3e7cdfc80515367a0976d0dab7);
#
#
#         var popup_2f3f8ded2e9a4786936dd38338c9c86e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb2f86bcb6db971b6bfc289a1b33d107 = $(`&lt;div id=&quot;html_eb2f86bcb6db971b6bfc289a1b33d107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2f3f8ded2e9a4786936dd38338c9c86e.setContent(html_eb2f86bcb6db971b6bfc289a1b33d107);
#
#
#
#         marker_3018c49838a533da9da63f71f7953e31.bindPopup(popup_2f3f8ded2e9a4786936dd38338c9c86e)
#         ;
#
#
#
#
#             var marker_c4f9193d5441d0708265bb2f025ababf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_42173a3e7cdfc80515367a0976d0dab7);
#
#
#         var popup_35c4356db4b802eddeadd6620aa9788c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f38d152b0c3416bcac3d9301fc3b7793 = $(`&lt;div id=&quot;html_f38d152b0c3416bcac3d9301fc3b7793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_35c4356db4b802eddeadd6620aa9788c.setContent(html_f38d152b0c3416bcac3d9301fc3b7793);
#
#
#
#         marker_c4f9193d5441d0708265bb2f025ababf.bindPopup(popup_35c4356db4b802eddeadd6620aa9788c)
#         ;
#
#
#
#
#             var marker_1ec0fcf34f6b7bf34d3c0a98009fcc02 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_42173a3e7cdfc80515367a0976d0dab7);
#
#
#         var popup_5e89651b390418f22875d6cf59004e3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da9fb1ddac532629b4661105c8cd833d = $(`&lt;div id=&quot;html_da9fb1ddac532629b4661105c8cd833d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e89651b390418f22875d6cf59004e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9453b123db2b3809fdc0df95d3eed19d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9453b123db2b3809fdc0df95d3eed19d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9453b123db2b3809fdc0df95d3eed19d = L.map(
#                 &quot;map_9453b123db2b3809fdc0df95d3eed19d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0af446615e61c3e5bb344d220ebee4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0af446615e61c3e5bb344d220ebee4b.addTo(map_9453b123db2b3809fdc0df95d3eed19d);
#
#
#             var feature_group_e09f61b526b2e0e4797574ab66475411 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b7f137986da934c819402daa34646af8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e09f61b526b2e0e4797574ab66475411);
#
#
#         var popup_5e3cb350033377e40ba24c88751f17fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_288d05e93f897e579cf640a86d736c37 = $(`&lt;div id=&quot;html_288d05e93f897e579cf640a86d736c37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5e3cb350033377e40ba24c88751f17fc.setContent(html_288d05e93f897e579cf640a86d736c37);
#
#
#
#         marker_b7f137986da934c819402daa34646af8.bindPopup(popup_5e3cb350033377e40ba24c88751f17fc)
#         ;
#
#
#
#
#             var marker_9d96ec995a58746dac2a970f701a3c42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e09f61b526b2e0e4797574ab66475411);
#
#
#         var popup_92f26570645dca046cd052b746f37a94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c76202b1238a5837158049aceaf61989 = $(`&lt;div id=&quot;html_c76202b1238a5837158049aceaf61989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_92f26570645dca046cd052b746f37a94.setContent(html_c76202b1238a5837158049aceaf61989);
#
#
#
#         marker_9d96ec995a58746dac2a970f701a3c42.bindPopup(popup_92f26570645dca046cd052b746f37a94)
#         ;
#
#
#
#
#             var marker_eeaed1bb3f61a42d53181806bbae5378 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e09f61b526b2e0e4797574ab66475411);
#
#
#         var popup_1a6b0500653b57d6c74fce4d2bf4b6b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_501507f83f9ff625fa2fe2f6b410d591 = $(`&lt;div id=&quot;html_501507f83f9ff625fa2fe2f6b410d591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1a6b0500653b57d6c74fce4d2bf4b6b7.setContent(html_501507f83f9ff625fa2fe2f6b410d591);
#
#
#
#         marker_eeaed1bb3f61a42d53181806bbae5378.bindPopup(popup_1a6b0500653b57d6c74fce4d2bf4b6b7)
#         ;
#
#
#
#
#             var marker_0a3f8f4d31bdfc07a92075986b726e24 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e09f61b526b2e0e4797574ab66475411);
#
#
#         var popup_ba89d254a080511814dd3b65be448c78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de2f644d872df493e153177dbfaecad5 = $(`&lt;div id=&quot;html_de2f644d872df493e153177dbfaecad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ba89d254a080511814dd3b65be448c78.setContent(html_de2f644d872df493e153177dbfaecad5);
#
#
#
#         marker_0a3f8f4d31bdfc07a92075986b726e24.bindPopup(popup_ba89d254a080511814dd3b65be448c78)
#         ;
#
#
#
#
#             var marker_0074a3402dd641c14e906af19a972a32 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e09f61b526b2e0e4797574ab66475411);
#
#
#         var popup_b048531be3e748439ea13ca99bdf3a5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e49b09f4a315ea5d1fa3fe6af85bca3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e49b09f4a315ea5d1fa3fe6af85bca3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e49b09f4a315ea5d1fa3fe6af85bca3 = L.map(
#                 &quot;map_5e49b09f4a315ea5d1fa3fe6af85bca3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78e18dceb3a74c3d408384a35f5e5737 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78e18dceb3a74c3d408384a35f5e5737.addTo(map_5e49b09f4a315ea5d1fa3fe6af85bca3);
#
#
#             var feature_group_0816f8e8ced4ddf93dfb15798c6ee509 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0816f8e8ced4ddf93dfb15798c6ee509.addTo(map_5e49b09f4a315ea5d1fa3fe6af85bca3);
#
#
#             var feature_group_sub_group_182641decc530a2f7c6715766cc4f470 = L.featureGroup.subGroup(
#                 feature_group_0816f8e8ced4ddf93dfb15798c6ee509
#             );
#
#
#             var marker_1d955a49af6798258e6fd5098fc40509 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_182641decc530a2f7c6715766cc4f470);
#
#
#         var popup_fae61fe180765b298e56e3138600d0ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8880193934b4c122e365743b7b5676bb = $(`&lt;div id=&quot;html_8880193934b4c122e365743b7b5676bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fae61fe180765b298e56e3138600d0ed.setContent(html_8880193934b4c122e365743b7b5676bb);
#
#
#
#         marker_1d955a49af6798258e6fd5098fc40509.bindPopup(popup_fae61fe180765b298e56e3138600d0ed)
#         ;
#
#
#
#
#             var marker_d88713f544e43d75cc58ef64ee0ac312 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_182641decc530a2f7c6715766cc4f470);
#
#
#         var popup_e46ae3a3c5ed3f5c3d5e310fa246e732 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16063ae5d89d125c3e9d51653e3b90bd = $(`&lt;div id=&quot;html_16063ae5d89d125c3e9d51653e3b90bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e46ae3a3c5ed3f5c3d5e310fa246e732.setContent(html_16063ae5d89d125c3e9d51653e3b90bd);
#
#
#
#         marker_d88713f544e43d75cc58ef64ee0ac312.bindPopup(popup_e46ae3a3c5ed3f5c3d5e310fa246e732)
#         ;
#
#
#
#
#             var marker_91fd39f79061aca918e590b3a5fccea4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_182641decc530a2f7c6715766cc4f470);
#
#
#         var popup_792a46e2f3f4f9a2d2f36209aba315f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813736ce812b7e47618bf55f2840e78b = $(`&lt;div id=&quot;html_813736ce812b7e47618bf55f2840e78b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_792a46e2f3f4f9a2d2f36209aba315f3.setContent(html_813736ce812b7e47618bf55f2840e78b);
#
#
#
#         marker_91fd39f79061aca918e590b3a5fccea4.bindPopup(popup_792a46e2f3f4f9a2d2f36209aba315f3)
#         ;
#
#
#
#
#             var marker_580d4e6841b05fb1c9203dab762bdb99 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_182641decc530a2f7c6715766cc4f470);
#
#
#         var popup_05cc73de4004c775c8c647a09c49bf04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6c26ade706039e132e6f3cca229c930 = $(`&lt;div id=&quot;html_d6c26ade706039e132e6f3cca229c930&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_05cc73de4004c775c8c647a09c49bf04.setContent(html_d6c26ade706039e132e6f3cca229c930);
#
#
#
#         mark
