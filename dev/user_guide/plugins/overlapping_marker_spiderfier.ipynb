# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8298a00dec9b4abbcd51e40fb30834e6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8298a00dec9b4abbcd51e40fb30834e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8298a00dec9b4abbcd51e40fb30834e6 = L.map(
#                 &quot;map_8298a00dec9b4abbcd51e40fb30834e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ad1d67b00e7184b1308a5244dfb41b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ad1d67b00e7184b1308a5244dfb41b4.addTo(map_8298a00dec9b4abbcd51e40fb30834e6);
#
#
#             var marker_3a243661c224e3a1bfafe1659df2cf06 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8298a00dec9b4abbcd51e40fb30834e6);
#
#
#         var popup_efc023266ce118a2fdb9f4730d38e114 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f548da37692533b223e50c62cee747c = $(`&lt;div id=&quot;html_5f548da37692533b223e50c62cee747c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_efc023266ce118a2fdb9f4730d38e114.setContent(html_5f548da37692533b223e50c62cee747c);
#
#
#
#         marker_3a243661c224e3a1bfafe1659df2cf06.bindPopup(popup_efc023266ce118a2fdb9f4730d38e114)
#         ;
#
#
#
#
#             var marker_8b245aea872c2e23045e44fb32db3173 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8298a00dec9b4abbcd51e40fb30834e6);
#
#
#         var popup_6a265429a86ccc0032e4acd5ef83c120 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4977be869028c041b15194d29233778e = $(`&lt;div id=&quot;html_4977be869028c041b15194d29233778e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6a265429a86ccc0032e4acd5ef83c120.setContent(html_4977be869028c041b15194d29233778e);
#
#
#
#         marker_8b245aea872c2e23045e44fb32db3173.bindPopup(popup_6a265429a86ccc0032e4acd5ef83c120)
#         ;
#
#
#
#
#             var marker_c431d1fd951a929e6a577361c8ec6f2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8298a00dec9b4abbcd51e40fb30834e6);
#
#
#         var popup_121800c93d7be8779e6cac88ca169734 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1cf17b38836d6cf07210958c90f1e01 = $(`&lt;div id=&quot;html_e1cf17b38836d6cf07210958c90f1e01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_121800c93d7be8779e6cac88ca169734.setContent(html_e1cf17b38836d6cf07210958c90f1e01);
#
#
#
#         marker_c431d1fd951a929e6a577361c8ec6f2d.bindPopup(popup_121800c93d7be8779e6cac88ca169734)
#         ;
#
#
#
#
#             var marker_3ea3c5bd209531805c867aab58542e55 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8298a00dec9b4abbcd51e40fb30834e6);
#
#
#         var popup_1c95113fe8b3f86b05a4cbbd6eeb92b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8788307e2006a29253205105c4b5dc10 = $(`&lt;div id=&quot;html_8788307e2006a29253205105c4b5dc10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1c95113fe8b3f86b05a4cbbd6eeb92b3.setContent(html_8788307e2006a29253205105c4b5dc10);
#
#
#
#         marker_3ea3c5bd209531805c867aab58542e55.bindPopup(popup_1c95113fe8b3f86b05a4cbbd6eeb92b3)
#         ;
#
#
#
#
#             var marker_0d0b25ac4349e95320e12d39d1453ba6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8298a00dec9b4abbcd51e40fb30834e6);
#
#
#         var popup_50947e5d22c465a623c11a6fe18a04e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f56e714b6e441e4008290d5db2fc982a = $(`&lt;div id=&quot;html_f56e714b6e441e4008290d5db2fc982a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_50947e5d22c465a623c11a6fe18a04

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3454e97884b0f5b12dd132cbfee8cbdc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3454e97884b0f5b12dd132cbfee8cbdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3454e97884b0f5b12dd132cbfee8cbdc = L.map(
#                 &quot;map_3454e97884b0f5b12dd132cbfee8cbdc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_207ac4730bdd6d06d6d18e3536b8c3f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_207ac4730bdd6d06d6d18e3536b8c3f0.addTo(map_3454e97884b0f5b12dd132cbfee8cbdc);
#
#
#             var feature_group_d90540c6401b9b5b71a87d22fd2e917b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_325ac64752826330b5b845ee35db4910 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d90540c6401b9b5b71a87d22fd2e917b);
#
#
#         var popup_d308032e54c731292fa73dfd2e4a1f39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffe09a1114c359642f3a699984e61cf2 = $(`&lt;div id=&quot;html_ffe09a1114c359642f3a699984e61cf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d308032e54c731292fa73dfd2e4a1f39.setContent(html_ffe09a1114c359642f3a699984e61cf2);
#
#
#
#         marker_325ac64752826330b5b845ee35db4910.bindPopup(popup_d308032e54c731292fa73dfd2e4a1f39)
#         ;
#
#
#
#
#             var marker_2751f0d494f37a6e4782326adc356030 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d90540c6401b9b5b71a87d22fd2e917b);
#
#
#         var popup_c8c70d130875e173adb51145e9c1bc10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47a6c5aeebc4ce87e3d34118fef91c83 = $(`&lt;div id=&quot;html_47a6c5aeebc4ce87e3d34118fef91c83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c8c70d130875e173adb51145e9c1bc10.setContent(html_47a6c5aeebc4ce87e3d34118fef91c83);
#
#
#
#         marker_2751f0d494f37a6e4782326adc356030.bindPopup(popup_c8c70d130875e173adb51145e9c1bc10)
#         ;
#
#
#
#
#             var marker_4428dcc0f1ef55c67f73d627259422ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d90540c6401b9b5b71a87d22fd2e917b);
#
#
#         var popup_b60b3c46219be063b7772c8e58c710dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bb44abf40df2dafc9653c847feb0922 = $(`&lt;div id=&quot;html_0bb44abf40df2dafc9653c847feb0922&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b60b3c46219be063b7772c8e58c710dd.setContent(html_0bb44abf40df2dafc9653c847feb0922);
#
#
#
#         marker_4428dcc0f1ef55c67f73d627259422ec.bindPopup(popup_b60b3c46219be063b7772c8e58c710dd)
#         ;
#
#
#
#
#             var marker_6915ffc066987f24dfa6ceda2e544ca7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d90540c6401b9b5b71a87d22fd2e917b);
#
#
#         var popup_5ae86e3168d97af96ff787a991f6a770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b22d8bff3cd6dd7e3b1d50fbd6e3aa2 = $(`&lt;div id=&quot;html_2b22d8bff3cd6dd7e3b1d50fbd6e3aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ae86e3168d97af96ff787a991f6a770.setContent(html_2b22d8bff3cd6dd7e3b1d50fbd6e3aa2);
#
#
#
#         marker_6915ffc066987f24dfa6ceda2e544ca7.bindPopup(popup_5ae86e3168d97af96ff787a991f6a770)
#         ;
#
#
#
#
#             var marker_f0eea475a0cec7948b63e8a2594968a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d90540c6401b9b5b71a87d22fd2e917b);
#
#
#         var popup_54940d932a4799daa63204d5cfbbed34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a63d2adf96acbde0d0ead647fdfb500 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a63d2adf96acbde0d0ead647fdfb500&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a63d2adf96acbde0d0ead647fdfb500 = L.map(
#                 &quot;map_4a63d2adf96acbde0d0ead647fdfb500&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83e0a2dde3f510cac29e90f880b2a300 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83e0a2dde3f510cac29e90f880b2a300.addTo(map_4a63d2adf96acbde0d0ead647fdfb500);
#
#
#             var feature_group_8a5842b52b90e92131478eff7b242217 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8a5842b52b90e92131478eff7b242217.addTo(map_4a63d2adf96acbde0d0ead647fdfb500);
#
#
#             var feature_group_sub_group_f2a236ead462ff888ab9dd4976f63462 = L.featureGroup.subGroup(
#                 feature_group_8a5842b52b90e92131478eff7b242217
#             );
#
#
#             var marker_30d5747bee344778816079cd402720cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f2a236ead462ff888ab9dd4976f63462);
#
#
#         var popup_b1f76dad96b33591c0513f12799f3275 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f834fb4bcdbbac258ecc80a72371023 = $(`&lt;div id=&quot;html_9f834fb4bcdbbac258ecc80a72371023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b1f76dad96b33591c0513f12799f3275.setContent(html_9f834fb4bcdbbac258ecc80a72371023);
#
#
#
#         marker_30d5747bee344778816079cd402720cf.bindPopup(popup_b1f76dad96b33591c0513f12799f3275)
#         ;
#
#
#
#
#             var marker_655f9f51a80d183625fd4b759fcc0baa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f2a236ead462ff888ab9dd4976f63462);
#
#
#         var popup_2c07f1e2e4895d64e37378151466803d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf981513d17152d52af7284fe866537c = $(`&lt;div id=&quot;html_cf981513d17152d52af7284fe866537c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2c07f1e2e4895d64e37378151466803d.setContent(html_cf981513d17152d52af7284fe866537c);
#
#
#
#         marker_655f9f51a80d183625fd4b759fcc0baa.bindPopup(popup_2c07f1e2e4895d64e37378151466803d)
#         ;
#
#
#
#
#             var marker_737575c6e9abb0e01db3742d4b419384 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f2a236ead462ff888ab9dd4976f63462);
#
#
#         var popup_33e5bcb403344387f43bb3012c2c1759 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_320e8d0c03b0fbd0f3ab77c00b15c4ee = $(`&lt;div id=&quot;html_320e8d0c03b0fbd0f3ab77c00b15c4ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_33e5bcb403344387f43bb3012c2c1759.setContent(html_320e8d0c03b0fbd0f3ab77c00b15c4ee);
#
#
#
#         marker_737575c6e9abb0e01db3742d4b419384.bindPopup(popup_33e5bcb403344387f43bb3012c2c1759)
#         ;
#
#
#
#
#             var marker_7b1487926963b1a3767d041ad976b84f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f2a236ead462ff888ab9dd4976f63462);
#
#
#         var popup_3e4303019055464e038fbfa91841fca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0acbc5a43e5747409b4bd27f68bc58e2 = $(`&lt;div id=&quot;html_0acbc5a43e5747409b4bd27f68bc58e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3e4303019055464e038fbfa91841fca9.setContent(html_0acbc5a43e5747409b4bd27f68bc58e2);
#
#
#
#         mark
