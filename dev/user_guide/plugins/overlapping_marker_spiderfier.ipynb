# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48d02ac397386e6150369bc78739606b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48d02ac397386e6150369bc78739606b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48d02ac397386e6150369bc78739606b = L.map(
#                 &quot;map_48d02ac397386e6150369bc78739606b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc7df4466c52cdbc28009557f6f950e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc7df4466c52cdbc28009557f6f950e1.addTo(map_48d02ac397386e6150369bc78739606b);
#
#
#             var marker_0e3c700302bb32856afb8f4a74740894 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_48d02ac397386e6150369bc78739606b);
#
#
#         var popup_afff61280f440badb9c55c95f5be25a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bd06b3768ab59da92f1dd5cdb26036e = $(`&lt;div id=&quot;html_3bd06b3768ab59da92f1dd5cdb26036e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_afff61280f440badb9c55c95f5be25a2.setContent(html_3bd06b3768ab59da92f1dd5cdb26036e);
#
#
#
#         marker_0e3c700302bb32856afb8f4a74740894.bindPopup(popup_afff61280f440badb9c55c95f5be25a2)
#         ;
#
#
#
#
#             var marker_deed271aa508a84bb0835eaf06b8d2f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_48d02ac397386e6150369bc78739606b);
#
#
#         var popup_191bdaded28e394107e062b7637e412f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feef90a1882381e40483bc3aa1070550 = $(`&lt;div id=&quot;html_feef90a1882381e40483bc3aa1070550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_191bdaded28e394107e062b7637e412f.setContent(html_feef90a1882381e40483bc3aa1070550);
#
#
#
#         marker_deed271aa508a84bb0835eaf06b8d2f9.bindPopup(popup_191bdaded28e394107e062b7637e412f)
#         ;
#
#
#
#
#             var marker_444ccc6d41ea6b5665f33899874b704f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_48d02ac397386e6150369bc78739606b);
#
#
#         var popup_414a9332f62735b68612d5074f8b477c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9255c93b6c03403ffd773158433760f4 = $(`&lt;div id=&quot;html_9255c93b6c03403ffd773158433760f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_414a9332f62735b68612d5074f8b477c.setContent(html_9255c93b6c03403ffd773158433760f4);
#
#
#
#         marker_444ccc6d41ea6b5665f33899874b704f.bindPopup(popup_414a9332f62735b68612d5074f8b477c)
#         ;
#
#
#
#
#             var marker_0ed9bf9f933f3cd754a626850e0eb4c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_48d02ac397386e6150369bc78739606b);
#
#
#         var popup_7fe80d5f4c6b53c641bf41491970576c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a05181a9754573a9ae77144853ae13f8 = $(`&lt;div id=&quot;html_a05181a9754573a9ae77144853ae13f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7fe80d5f4c6b53c641bf41491970576c.setContent(html_a05181a9754573a9ae77144853ae13f8);
#
#
#
#         marker_0ed9bf9f933f3cd754a626850e0eb4c9.bindPopup(popup_7fe80d5f4c6b53c641bf41491970576c)
#         ;
#
#
#
#
#             var marker_599dc4620987dfefb5583b2536627870 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_48d02ac397386e6150369bc78739606b);
#
#
#         var popup_c1efede3dae9d2d20a5dfa2e679a1508 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e80480e7abb3a26fb6f9f519f96898c4 = $(`&lt;div id=&quot;html_e80480e7abb3a26fb6f9f519f96898c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c1efede3dae9d2d20a5dfa2e679a15

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d57eba83ef9e0da41842097a5ba31d3d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d57eba83ef9e0da41842097a5ba31d3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d57eba83ef9e0da41842097a5ba31d3d = L.map(
#                 &quot;map_d57eba83ef9e0da41842097a5ba31d3d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c3cae5c9b80bd06f76f3289d0824ff3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c3cae5c9b80bd06f76f3289d0824ff3.addTo(map_d57eba83ef9e0da41842097a5ba31d3d);
#
#
#             var feature_group_bf0b565d7a9bd02d6900f43af9ccc20a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2ee00053530a0adfe83042c7d3822e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bf0b565d7a9bd02d6900f43af9ccc20a);
#
#
#         var popup_71e74aac7849f446e7078bf815248614 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e5d08e50deee52ac79de45995ba0f57 = $(`&lt;div id=&quot;html_7e5d08e50deee52ac79de45995ba0f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_71e74aac7849f446e7078bf815248614.setContent(html_7e5d08e50deee52ac79de45995ba0f57);
#
#
#
#         marker_b2ee00053530a0adfe83042c7d3822e2.bindPopup(popup_71e74aac7849f446e7078bf815248614)
#         ;
#
#
#
#
#             var marker_9301d937f33e92a72e14d7d2681a8dd2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bf0b565d7a9bd02d6900f43af9ccc20a);
#
#
#         var popup_913a2cef931b8136224d82373ce2c668 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfc1eb6396c0b7454b331bdbcca6e574 = $(`&lt;div id=&quot;html_cfc1eb6396c0b7454b331bdbcca6e574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_913a2cef931b8136224d82373ce2c668.setContent(html_cfc1eb6396c0b7454b331bdbcca6e574);
#
#
#
#         marker_9301d937f33e92a72e14d7d2681a8dd2.bindPopup(popup_913a2cef931b8136224d82373ce2c668)
#         ;
#
#
#
#
#             var marker_5644d9e82ae0080c3271b7cf6c5f3e1a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bf0b565d7a9bd02d6900f43af9ccc20a);
#
#
#         var popup_b4d3eae840fdfb1284b1ded04c066fb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0189d23e863578daa66663fb115d1019 = $(`&lt;div id=&quot;html_0189d23e863578daa66663fb115d1019&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b4d3eae840fdfb1284b1ded04c066fb1.setContent(html_0189d23e863578daa66663fb115d1019);
#
#
#
#         marker_5644d9e82ae0080c3271b7cf6c5f3e1a.bindPopup(popup_b4d3eae840fdfb1284b1ded04c066fb1)
#         ;
#
#
#
#
#             var marker_05b93c2e0940e3f4213e522d20acea9b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bf0b565d7a9bd02d6900f43af9ccc20a);
#
#
#         var popup_0313795226b93e30828065f886dc8151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65a4af4a9fd232eebe29d8d87652fb00 = $(`&lt;div id=&quot;html_65a4af4a9fd232eebe29d8d87652fb00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0313795226b93e30828065f886dc8151.setContent(html_65a4af4a9fd232eebe29d8d87652fb00);
#
#
#
#         marker_05b93c2e0940e3f4213e522d20acea9b.bindPopup(popup_0313795226b93e30828065f886dc8151)
#         ;
#
#
#
#
#             var marker_ab6fc48d68898ad338390a552e3fe611 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bf0b565d7a9bd02d6900f43af9ccc20a);
#
#
#         var popup_89ffeacc49e6bdaae2e88257bdac5c50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbb735f943cb560ed2c6dda755caa2e6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbb735f943cb560ed2c6dda755caa2e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbb735f943cb560ed2c6dda755caa2e6 = L.map(
#                 &quot;map_bbb735f943cb560ed2c6dda755caa2e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cedd52009be1cca926ed0789378ab25 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cedd52009be1cca926ed0789378ab25.addTo(map_bbb735f943cb560ed2c6dda755caa2e6);
#
#
#             var feature_group_caa7e8dbbe1ce26330732ad2ec18411a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_caa7e8dbbe1ce26330732ad2ec18411a.addTo(map_bbb735f943cb560ed2c6dda755caa2e6);
#
#
#             var feature_group_sub_group_6b4e592abac4bfe78753c8854c884bc3 = L.featureGroup.subGroup(
#                 feature_group_caa7e8dbbe1ce26330732ad2ec18411a
#             );
#
#
#             var marker_6493b552fb77a459b1057257da78b205 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b4e592abac4bfe78753c8854c884bc3);
#
#
#         var popup_ae38ef6e2ad0a1f9f775c886801f50b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_877fa280005ba7b022fa955b143d1dca = $(`&lt;div id=&quot;html_877fa280005ba7b022fa955b143d1dca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ae38ef6e2ad0a1f9f775c886801f50b1.setContent(html_877fa280005ba7b022fa955b143d1dca);
#
#
#
#         marker_6493b552fb77a459b1057257da78b205.bindPopup(popup_ae38ef6e2ad0a1f9f775c886801f50b1)
#         ;
#
#
#
#
#             var marker_862665a0c70cfb2560ff00f1c131ed9b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b4e592abac4bfe78753c8854c884bc3);
#
#
#         var popup_ac862e3351e81102ee845d198e8ebd77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19be7ce02821cc1c98cb19ffb727774f = $(`&lt;div id=&quot;html_19be7ce02821cc1c98cb19ffb727774f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ac862e3351e81102ee845d198e8ebd77.setContent(html_19be7ce02821cc1c98cb19ffb727774f);
#
#
#
#         marker_862665a0c70cfb2560ff00f1c131ed9b.bindPopup(popup_ac862e3351e81102ee845d198e8ebd77)
#         ;
#
#
#
#
#             var marker_019d9b03fc3ac7b2b32bbb55f2d11b6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b4e592abac4bfe78753c8854c884bc3);
#
#
#         var popup_6b2eec74319f947978f22c7e1cae74fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ff9e8d84d46cf8a81847adcb4b67144 = $(`&lt;div id=&quot;html_9ff9e8d84d46cf8a81847adcb4b67144&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6b2eec74319f947978f22c7e1cae74fd.setContent(html_9ff9e8d84d46cf8a81847adcb4b67144);
#
#
#
#         marker_019d9b03fc3ac7b2b32bbb55f2d11b6a.bindPopup(popup_6b2eec74319f947978f22c7e1cae74fd)
#         ;
#
#
#
#
#             var marker_a07bc511dabf6b54414701a9395edc51 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b4e592abac4bfe78753c8854c884bc3);
#
#
#         var popup_2727a4b39d1a03eeb637ba7f53356527 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57db837431735f2dab52a2701fd2deaf = $(`&lt;div id=&quot;html_57db837431735f2dab52a2701fd2deaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2727a4b39d1a03eeb637ba7f53356527.setContent(html_57db837431735f2dab52a2701fd2deaf);
#
#
#
#         mark
