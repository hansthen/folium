# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8912bd86016ada998d222916393daee6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8912bd86016ada998d222916393daee6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8912bd86016ada998d222916393daee6 = L.map(
#                 &quot;map_8912bd86016ada998d222916393daee6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef9ff639d6587d2c875610396c961d1c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef9ff639d6587d2c875610396c961d1c.addTo(map_8912bd86016ada998d222916393daee6);
#
#
#             var marker_485977f3ea57202d456a28f05b937762 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8912bd86016ada998d222916393daee6);
#
#
#         var popup_8d9cbc3392c5d50936ae95737a055b6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14eee6d0ced73f718c7b099de50c98d4 = $(`&lt;div id=&quot;html_14eee6d0ced73f718c7b099de50c98d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8d9cbc3392c5d50936ae95737a055b6e.setContent(html_14eee6d0ced73f718c7b099de50c98d4);
#
#
#
#         marker_485977f3ea57202d456a28f05b937762.bindPopup(popup_8d9cbc3392c5d50936ae95737a055b6e)
#         ;
#
#
#
#
#             var marker_785e83da1ca58126f8b55ffc8ac81a44 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8912bd86016ada998d222916393daee6);
#
#
#         var popup_8fc6e232bdfccd94ed120db41a6405cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_047aed7f1b89fe1d71d32dc143ff79ef = $(`&lt;div id=&quot;html_047aed7f1b89fe1d71d32dc143ff79ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8fc6e232bdfccd94ed120db41a6405cf.setContent(html_047aed7f1b89fe1d71d32dc143ff79ef);
#
#
#
#         marker_785e83da1ca58126f8b55ffc8ac81a44.bindPopup(popup_8fc6e232bdfccd94ed120db41a6405cf)
#         ;
#
#
#
#
#             var marker_a6c3ba9474a4e110aae3876a73d99b69 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8912bd86016ada998d222916393daee6);
#
#
#         var popup_8fe006c92446779db3134f8c5675c0ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a60d96e3bf76daeebf0e3553f2295f8 = $(`&lt;div id=&quot;html_6a60d96e3bf76daeebf0e3553f2295f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8fe006c92446779db3134f8c5675c0ee.setContent(html_6a60d96e3bf76daeebf0e3553f2295f8);
#
#
#
#         marker_a6c3ba9474a4e110aae3876a73d99b69.bindPopup(popup_8fe006c92446779db3134f8c5675c0ee)
#         ;
#
#
#
#
#             var marker_fe4e3e96be09eb088a788d9b48bcfafe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8912bd86016ada998d222916393daee6);
#
#
#         var popup_a3452a5e9da81dbcb64a01c5c0f109d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1785689c6f2113215bb410925fb77155 = $(`&lt;div id=&quot;html_1785689c6f2113215bb410925fb77155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a3452a5e9da81dbcb64a01c5c0f109d9.setContent(html_1785689c6f2113215bb410925fb77155);
#
#
#
#         marker_fe4e3e96be09eb088a788d9b48bcfafe.bindPopup(popup_a3452a5e9da81dbcb64a01c5c0f109d9)
#         ;
#
#
#
#
#             var marker_d85362b4556fd957adc6c69965592692 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8912bd86016ada998d222916393daee6);
#
#
#         var popup_352e2701a9e653b1bba2c96f169dc5a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b698a194fe3f30a51d778edd4e175d2 = $(`&lt;div id=&quot;html_4b698a194fe3f30a51d778edd4e175d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_352e2701a9e653b1bba2c96f169dc5a1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00ad941df778e5d5ef8766c33af36b49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00ad941df778e5d5ef8766c33af36b49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00ad941df778e5d5ef8766c33af36b49 = L.map(
#                 &quot;map_00ad941df778e5d5ef8766c33af36b49&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc5e2eef550ff580a774e6b6ac1b543f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc5e2eef550ff580a774e6b6ac1b543f.addTo(map_00ad941df778e5d5ef8766c33af36b49);
#
#
#             var feature_group_95dab18effcd824464360ef5e2684c6b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c5d663e0db959532900299e6eebcd60e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_95dab18effcd824464360ef5e2684c6b);
#
#
#         var popup_cc708a9bdc5e32e06b6d388400cc82e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08f4dd98e109103c0200782115b5e13c = $(`&lt;div id=&quot;html_08f4dd98e109103c0200782115b5e13c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cc708a9bdc5e32e06b6d388400cc82e5.setContent(html_08f4dd98e109103c0200782115b5e13c);
#
#
#
#         marker_c5d663e0db959532900299e6eebcd60e.bindPopup(popup_cc708a9bdc5e32e06b6d388400cc82e5)
#         ;
#
#
#
#
#             var marker_c069977c5e4b0a6432f27d7ff27a230c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_95dab18effcd824464360ef5e2684c6b);
#
#
#         var popup_bc184bf0cebe093df84dfe568f2972e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1817f98df1e7a40021f2a453ccc74e5 = $(`&lt;div id=&quot;html_a1817f98df1e7a40021f2a453ccc74e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bc184bf0cebe093df84dfe568f2972e7.setContent(html_a1817f98df1e7a40021f2a453ccc74e5);
#
#
#
#         marker_c069977c5e4b0a6432f27d7ff27a230c.bindPopup(popup_bc184bf0cebe093df84dfe568f2972e7)
#         ;
#
#
#
#
#             var marker_6cecdf2c23b7f92b49c6ef54181efc4d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_95dab18effcd824464360ef5e2684c6b);
#
#
#         var popup_1dfd94df3cc9a585a52a39e66dafa936 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa2aeaca7e422cc58a244169eb456f17 = $(`&lt;div id=&quot;html_aa2aeaca7e422cc58a244169eb456f17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1dfd94df3cc9a585a52a39e66dafa936.setContent(html_aa2aeaca7e422cc58a244169eb456f17);
#
#
#
#         marker_6cecdf2c23b7f92b49c6ef54181efc4d.bindPopup(popup_1dfd94df3cc9a585a52a39e66dafa936)
#         ;
#
#
#
#
#             var marker_a78283f27aa61fca84c2fbe69ff5cb99 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_95dab18effcd824464360ef5e2684c6b);
#
#
#         var popup_6ecb09f0fae4ecb41b5c13bb675189f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2eef91c7c9197478117de3a5b884698f = $(`&lt;div id=&quot;html_2eef91c7c9197478117de3a5b884698f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6ecb09f0fae4ecb41b5c13bb675189f1.setContent(html_2eef91c7c9197478117de3a5b884698f);
#
#
#
#         marker_a78283f27aa61fca84c2fbe69ff5cb99.bindPopup(popup_6ecb09f0fae4ecb41b5c13bb675189f1)
#         ;
#
#
#
#
#             var marker_fc1204ba1839ba533541f92464882b70 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_95dab18effcd824464360ef5e2684c6b);
#
#
#         var popup_5d65fad0765047c659ea48d16ba0b29d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfe89b03eeb455d1852488265536e625 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfe89b03eeb455d1852488265536e625&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfe89b03eeb455d1852488265536e625 = L.map(
#                 &quot;map_cfe89b03eeb455d1852488265536e625&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d337cc1c05be56566442335602e584ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d337cc1c05be56566442335602e584ba.addTo(map_cfe89b03eeb455d1852488265536e625);
#
#
#             var feature_group_b12cd9a524c5da96f113071e5ac0d471 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b12cd9a524c5da96f113071e5ac0d471.addTo(map_cfe89b03eeb455d1852488265536e625);
#
#
#             var feature_group_sub_group_4b23681f716584f718950229ceda813a = L.featureGroup.subGroup(
#                 feature_group_b12cd9a524c5da96f113071e5ac0d471
#             );
#
#
#             var marker_0923ab8b31560574e1a046d61707d63e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b23681f716584f718950229ceda813a);
#
#
#         var popup_95d6e122a568a15a42f6096dac60a47c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebab8bf020a8e2887bb0498d89076b23 = $(`&lt;div id=&quot;html_ebab8bf020a8e2887bb0498d89076b23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_95d6e122a568a15a42f6096dac60a47c.setContent(html_ebab8bf020a8e2887bb0498d89076b23);
#
#
#
#         marker_0923ab8b31560574e1a046d61707d63e.bindPopup(popup_95d6e122a568a15a42f6096dac60a47c)
#         ;
#
#
#
#
#             var marker_89b8360d71583959cb374358ae0b772a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b23681f716584f718950229ceda813a);
#
#
#         var popup_da93fc676087bdfc5cec7c2209280654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0967eac8a54adffaa9835c53a9f36ac7 = $(`&lt;div id=&quot;html_0967eac8a54adffaa9835c53a9f36ac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_da93fc676087bdfc5cec7c2209280654.setContent(html_0967eac8a54adffaa9835c53a9f36ac7);
#
#
#
#         marker_89b8360d71583959cb374358ae0b772a.bindPopup(popup_da93fc676087bdfc5cec7c2209280654)
#         ;
#
#
#
#
#             var marker_149bcbc38526e3985d9b2a5f4f01e03c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b23681f716584f718950229ceda813a);
#
#
#         var popup_ef100b5c146a24fb0761ae8790bc1e17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a81d01afc8ac636fff16f8f7b1aae2a1 = $(`&lt;div id=&quot;html_a81d01afc8ac636fff16f8f7b1aae2a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef100b5c146a24fb0761ae8790bc1e17.setContent(html_a81d01afc8ac636fff16f8f7b1aae2a1);
#
#
#
#         marker_149bcbc38526e3985d9b2a5f4f01e03c.bindPopup(popup_ef100b5c146a24fb0761ae8790bc1e17)
#         ;
#
#
#
#
#             var marker_c7ff0500912563694cff9286636993b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b23681f716584f718950229ceda813a);
#
#
#         var popup_9e7f7d7d3415b5bebe4e9d63ea1be738 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee49580b59d4430e4d9c23f16138ad96 = $(`&lt;div id=&quot;html_ee49580b59d4430e4d9c23f16138ad96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9e7f7d7d3415b5bebe4e9d63ea1be738.setContent(html_ee49580b59d4430e4d9c23f16138ad96);
#
#
#
#         marker_
