# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_365031aff40a991a7965db6759c87129 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_365031aff40a991a7965db6759c87129&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_365031aff40a991a7965db6759c87129 = L.map(
#                 &quot;map_365031aff40a991a7965db6759c87129&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6079f6f2b6181108593a5167d3ea378b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6079f6f2b6181108593a5167d3ea378b.addTo(map_365031aff40a991a7965db6759c87129);
#
#
#             var marker_ac0a81566e783661f1500d3ae84478cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_365031aff40a991a7965db6759c87129);
#
#
#         var popup_d4be8e16aa47ea9e7e215b89ca03dc08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_581d5506978bdbc35d0399d8ed4003f9 = $(`&lt;div id=&quot;html_581d5506978bdbc35d0399d8ed4003f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d4be8e16aa47ea9e7e215b89ca03dc08.setContent(html_581d5506978bdbc35d0399d8ed4003f9);
#
#
#
#         marker_ac0a81566e783661f1500d3ae84478cc.bindPopup(popup_d4be8e16aa47ea9e7e215b89ca03dc08)
#         ;
#
#
#
#
#             var marker_e718b4dc9acdb872af3f01845f03c0c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_365031aff40a991a7965db6759c87129);
#
#
#         var popup_8c474f2c7bb30d393f0b08850d5070ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e84fa8281f8baf0829535fc153b9e1e = $(`&lt;div id=&quot;html_7e84fa8281f8baf0829535fc153b9e1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8c474f2c7bb30d393f0b08850d5070ef.setContent(html_7e84fa8281f8baf0829535fc153b9e1e);
#
#
#
#         marker_e718b4dc9acdb872af3f01845f03c0c4.bindPopup(popup_8c474f2c7bb30d393f0b08850d5070ef)
#         ;
#
#
#
#
#             var marker_b81ac1658e24a84e2c18708541d0298e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_365031aff40a991a7965db6759c87129);
#
#
#         var popup_ed262c22f0b7b0a1823861a020177797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7146cb0b842364b0c28468eda4c746e8 = $(`&lt;div id=&quot;html_7146cb0b842364b0c28468eda4c746e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ed262c22f0b7b0a1823861a020177797.setContent(html_7146cb0b842364b0c28468eda4c746e8);
#
#
#
#         marker_b81ac1658e24a84e2c18708541d0298e.bindPopup(popup_ed262c22f0b7b0a1823861a020177797)
#         ;
#
#
#
#
#             var marker_097e55f3b11502c9836a4926bd40cde6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_365031aff40a991a7965db6759c87129);
#
#
#         var popup_7699245b6ac80510cd849fb98ec0e065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f145777654534be94d5095713c9856a5 = $(`&lt;div id=&quot;html_f145777654534be94d5095713c9856a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7699245b6ac80510cd849fb98ec0e065.setContent(html_f145777654534be94d5095713c9856a5);
#
#
#
#         marker_097e55f3b11502c9836a4926bd40cde6.bindPopup(popup_7699245b6ac80510cd849fb98ec0e065)
#         ;
#
#
#
#
#             var marker_f133f864cd6f88ca39800ba8a84e6c87 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_365031aff40a991a7965db6759c87129);
#
#
#         var popup_8d5d06f62809d509fdd7ea3246e671f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c22c5dbe5fb4a57d82ddba12240b765 = $(`&lt;div id=&quot;html_4c22c5dbe5fb4a57d82ddba12240b765&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8d5d06f62809d509fdd7ea3246e671

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8cd9a8c9dfd780f86ca1b7d4aa1832b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8cd9a8c9dfd780f86ca1b7d4aa1832b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8cd9a8c9dfd780f86ca1b7d4aa1832b = L.map(
#                 &quot;map_b8cd9a8c9dfd780f86ca1b7d4aa1832b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d981b7a46678fd8b7c9d57d4bc272b8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d981b7a46678fd8b7c9d57d4bc272b8b.addTo(map_b8cd9a8c9dfd780f86ca1b7d4aa1832b);
#
#
#             var feature_group_c317d5558ba4b2b837e28ef4c62bb8d3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_65368bb3f883234a3ea84fcac056285e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c317d5558ba4b2b837e28ef4c62bb8d3);
#
#
#         var popup_1b01ee2531c62f444ebcde04969b2697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de2701c001ca51edf1b775582368da91 = $(`&lt;div id=&quot;html_de2701c001ca51edf1b775582368da91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1b01ee2531c62f444ebcde04969b2697.setContent(html_de2701c001ca51edf1b775582368da91);
#
#
#
#         marker_65368bb3f883234a3ea84fcac056285e.bindPopup(popup_1b01ee2531c62f444ebcde04969b2697)
#         ;
#
#
#
#
#             var marker_5579e244d691b27b0030a3f9504ffb26 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c317d5558ba4b2b837e28ef4c62bb8d3);
#
#
#         var popup_d74e151dfba47cc484d9644ef04996f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbd0f5abb33b251411ea542f0d60ba3e = $(`&lt;div id=&quot;html_fbd0f5abb33b251411ea542f0d60ba3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d74e151dfba47cc484d9644ef04996f0.setContent(html_fbd0f5abb33b251411ea542f0d60ba3e);
#
#
#
#         marker_5579e244d691b27b0030a3f9504ffb26.bindPopup(popup_d74e151dfba47cc484d9644ef04996f0)
#         ;
#
#
#
#
#             var marker_97be2591269ee362bbcbd87d2412fdb0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c317d5558ba4b2b837e28ef4c62bb8d3);
#
#
#         var popup_0afe6bc5df80212b9d638d4ddee39a19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbcb0767d052bb7e2efe76c6253f79ec = $(`&lt;div id=&quot;html_cbcb0767d052bb7e2efe76c6253f79ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0afe6bc5df80212b9d638d4ddee39a19.setContent(html_cbcb0767d052bb7e2efe76c6253f79ec);
#
#
#
#         marker_97be2591269ee362bbcbd87d2412fdb0.bindPopup(popup_0afe6bc5df80212b9d638d4ddee39a19)
#         ;
#
#
#
#
#             var marker_b6a5114c9a75ac677bfcf32d6c552b5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c317d5558ba4b2b837e28ef4c62bb8d3);
#
#
#         var popup_eeb58a5d9b4fe53d60d73f0086ceed53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b96a67bb5042a72edba0a193d45ae7f = $(`&lt;div id=&quot;html_6b96a67bb5042a72edba0a193d45ae7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_eeb58a5d9b4fe53d60d73f0086ceed53.setContent(html_6b96a67bb5042a72edba0a193d45ae7f);
#
#
#
#         marker_b6a5114c9a75ac677bfcf32d6c552b5d.bindPopup(popup_eeb58a5d9b4fe53d60d73f0086ceed53)
#         ;
#
#
#
#
#             var marker_60d7175a89d56eb034d495bb6d52625b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c317d5558ba4b2b837e28ef4c62bb8d3);
#
#
#         var popup_32ee4650a6419d6bf995286fcbe4846b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd70bf439b1a7089a2dd735e5f493b03 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd70bf439b1a7089a2dd735e5f493b03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd70bf439b1a7089a2dd735e5f493b03 = L.map(
#                 &quot;map_cd70bf439b1a7089a2dd735e5f493b03&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08b473e1746cbb7a0b71474b8e6b99d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08b473e1746cbb7a0b71474b8e6b99d4.addTo(map_cd70bf439b1a7089a2dd735e5f493b03);
#
#
#             var feature_group_1b14b50e15f3b3289f8f524d3aeddbd1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1b14b50e15f3b3289f8f524d3aeddbd1.addTo(map_cd70bf439b1a7089a2dd735e5f493b03);
#
#
#             var feature_group_sub_group_1bb9a62ac102dd133de0c5c66236da56 = L.featureGroup.subGroup(
#                 feature_group_1b14b50e15f3b3289f8f524d3aeddbd1
#             );
#
#
#             var marker_cf86bfcd0e74c9d55c43375ecfe6e1ed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb9a62ac102dd133de0c5c66236da56);
#
#
#         var popup_c6988cf1be76e40d82096307aaa01688 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f82b8bada82083088ead772a0f2d6cf = $(`&lt;div id=&quot;html_8f82b8bada82083088ead772a0f2d6cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c6988cf1be76e40d82096307aaa01688.setContent(html_8f82b8bada82083088ead772a0f2d6cf);
#
#
#
#         marker_cf86bfcd0e74c9d55c43375ecfe6e1ed.bindPopup(popup_c6988cf1be76e40d82096307aaa01688)
#         ;
#
#
#
#
#             var marker_e377362e0c4747ae53e618633a0863fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb9a62ac102dd133de0c5c66236da56);
#
#
#         var popup_d3e95ab5caaf22a5f01a81586bd069bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2f67439d5d2ce9352687a0523c744b1 = $(`&lt;div id=&quot;html_b2f67439d5d2ce9352687a0523c744b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d3e95ab5caaf22a5f01a81586bd069bb.setContent(html_b2f67439d5d2ce9352687a0523c744b1);
#
#
#
#         marker_e377362e0c4747ae53e618633a0863fb.bindPopup(popup_d3e95ab5caaf22a5f01a81586bd069bb)
#         ;
#
#
#
#
#             var marker_f109cada1e1a1bea1260bb371149a2b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb9a62ac102dd133de0c5c66236da56);
#
#
#         var popup_d051bb5be0d7c536d4373ec4653363ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c956871ece5d7c56e65f8693af0a2989 = $(`&lt;div id=&quot;html_c956871ece5d7c56e65f8693af0a2989&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d051bb5be0d7c536d4373ec4653363ab.setContent(html_c956871ece5d7c56e65f8693af0a2989);
#
#
#
#         marker_f109cada1e1a1bea1260bb371149a2b2.bindPopup(popup_d051bb5be0d7c536d4373ec4653363ab)
#         ;
#
#
#
#
#             var marker_c53611e312c1df366b3b199b8665ad01 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1bb9a62ac102dd133de0c5c66236da56);
#
#
#         var popup_2da22a9a22010958b6896492bacd1bbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13167d91760a063ade275e975a149631 = $(`&lt;div id=&quot;html_13167d91760a063ade275e975a149631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2da22a9a22010958b6896492bacd1bbd.setContent(html_13167d91760a063ade275e975a149631);
#
#
#
#         mark
