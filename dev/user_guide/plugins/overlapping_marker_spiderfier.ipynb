# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e026cc02013eba0b262ae4e6820b473c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e026cc02013eba0b262ae4e6820b473c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e026cc02013eba0b262ae4e6820b473c = L.map(
#                 &quot;map_e026cc02013eba0b262ae4e6820b473c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_544f054b6b8531ddc0de34a0b92aa73f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_544f054b6b8531ddc0de34a0b92aa73f.addTo(map_e026cc02013eba0b262ae4e6820b473c);
#
#
#             var marker_f1826d19200656726af4fd07e98b6588 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e026cc02013eba0b262ae4e6820b473c);
#
#
#         var popup_605b12f9d107a68f28229117d7932bd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_437095ae84820a342eb0eeb2b9cdff9b = $(`&lt;div id=&quot;html_437095ae84820a342eb0eeb2b9cdff9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_605b12f9d107a68f28229117d7932bd7.setContent(html_437095ae84820a342eb0eeb2b9cdff9b);
#
#
#
#         marker_f1826d19200656726af4fd07e98b6588.bindPopup(popup_605b12f9d107a68f28229117d7932bd7)
#         ;
#
#
#
#
#             var marker_edf1ab5338299879697461d46a5a029c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e026cc02013eba0b262ae4e6820b473c);
#
#
#         var popup_ba07468f8dc06490b35a38855eed11af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80cce0aef4e0d0425c5ee17bb21f463b = $(`&lt;div id=&quot;html_80cce0aef4e0d0425c5ee17bb21f463b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ba07468f8dc06490b35a38855eed11af.setContent(html_80cce0aef4e0d0425c5ee17bb21f463b);
#
#
#
#         marker_edf1ab5338299879697461d46a5a029c.bindPopup(popup_ba07468f8dc06490b35a38855eed11af)
#         ;
#
#
#
#
#             var marker_795e69231bdefa442664db7d644350c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e026cc02013eba0b262ae4e6820b473c);
#
#
#         var popup_eecb60b0bd9bf252ede9584fa05a8c30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3b31bd3178a9d170fd4e9f3cfe0346b = $(`&lt;div id=&quot;html_a3b31bd3178a9d170fd4e9f3cfe0346b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_eecb60b0bd9bf252ede9584fa05a8c30.setContent(html_a3b31bd3178a9d170fd4e9f3cfe0346b);
#
#
#
#         marker_795e69231bdefa442664db7d644350c5.bindPopup(popup_eecb60b0bd9bf252ede9584fa05a8c30)
#         ;
#
#
#
#
#             var marker_58b937af5deec857bf6bf3d4ddf5b1bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e026cc02013eba0b262ae4e6820b473c);
#
#
#         var popup_fe9aee8d750a5f0cb590ac1ca6dc4584 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b7cf729a2bb4e96b6b4835e7ad1cb45 = $(`&lt;div id=&quot;html_0b7cf729a2bb4e96b6b4835e7ad1cb45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fe9aee8d750a5f0cb590ac1ca6dc4584.setContent(html_0b7cf729a2bb4e96b6b4835e7ad1cb45);
#
#
#
#         marker_58b937af5deec857bf6bf3d4ddf5b1bb.bindPopup(popup_fe9aee8d750a5f0cb590ac1ca6dc4584)
#         ;
#
#
#
#
#             var marker_63f7868182b757040d67e5d7c1188db5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e026cc02013eba0b262ae4e6820b473c);
#
#
#         var popup_ef92ccba906d9a1c2ed958844d8d9858 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31832bb179ef37630cdd7cfa8532e1a4 = $(`&lt;div id=&quot;html_31832bb179ef37630cdd7cfa8532e1a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ef92ccba906d9a1c2ed958844d8d9858.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_023c62cea1edc060e503500f90e338d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_023c62cea1edc060e503500f90e338d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_023c62cea1edc060e503500f90e338d5 = L.map(
#                 &quot;map_023c62cea1edc060e503500f90e338d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_911ad236bfb3ebebd4862d7835b26121 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_911ad236bfb3ebebd4862d7835b26121.addTo(map_023c62cea1edc060e503500f90e338d5);
#
#
#             var feature_group_a5882e350ca012252e1f5f0d257dc688 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2bed21765598e7bb48f90dc109790e6d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a5882e350ca012252e1f5f0d257dc688);
#
#
#         var popup_44823e41fa7b29f42402454b4dd52fd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94824ae9c69624caea9539d413bf8fbc = $(`&lt;div id=&quot;html_94824ae9c69624caea9539d413bf8fbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_44823e41fa7b29f42402454b4dd52fd6.setContent(html_94824ae9c69624caea9539d413bf8fbc);
#
#
#
#         marker_2bed21765598e7bb48f90dc109790e6d.bindPopup(popup_44823e41fa7b29f42402454b4dd52fd6)
#         ;
#
#
#
#
#             var marker_ae57d0cede0266fa80d36f6f3d328355 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a5882e350ca012252e1f5f0d257dc688);
#
#
#         var popup_31aea05a2aa0ee43d2dcef00f9d4126b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_627e994df9b6a3d3d3ffca8fb44a5bb3 = $(`&lt;div id=&quot;html_627e994df9b6a3d3d3ffca8fb44a5bb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_31aea05a2aa0ee43d2dcef00f9d4126b.setContent(html_627e994df9b6a3d3d3ffca8fb44a5bb3);
#
#
#
#         marker_ae57d0cede0266fa80d36f6f3d328355.bindPopup(popup_31aea05a2aa0ee43d2dcef00f9d4126b)
#         ;
#
#
#
#
#             var marker_f59057a353a0417a5efc677a3dc97c63 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a5882e350ca012252e1f5f0d257dc688);
#
#
#         var popup_d53ff05ef8b054ca2c63fac0d3495ce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_469f44d726fe00742f9cd5464bff7a18 = $(`&lt;div id=&quot;html_469f44d726fe00742f9cd5464bff7a18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d53ff05ef8b054ca2c63fac0d3495ce7.setContent(html_469f44d726fe00742f9cd5464bff7a18);
#
#
#
#         marker_f59057a353a0417a5efc677a3dc97c63.bindPopup(popup_d53ff05ef8b054ca2c63fac0d3495ce7)
#         ;
#
#
#
#
#             var marker_5da4ab29b7c5b1c6bd63759a7a23e9c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a5882e350ca012252e1f5f0d257dc688);
#
#
#         var popup_1fb7b860db594a7e1a22453d96c74875 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_924ead56143ea5c27b937b2ae5cdef2f = $(`&lt;div id=&quot;html_924ead56143ea5c27b937b2ae5cdef2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1fb7b860db594a7e1a22453d96c74875.setContent(html_924ead56143ea5c27b937b2ae5cdef2f);
#
#
#
#         marker_5da4ab29b7c5b1c6bd63759a7a23e9c1.bindPopup(popup_1fb7b860db594a7e1a22453d96c74875)
#         ;
#
#
#
#
#             var marker_8f43e7125b943240d04e7d638e14ddcd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a5882e350ca012252e1f5f0d257dc688);
#
#
#         var popup_1395df1248dda6ccab07fb60177bbfba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8257ae5c9ea518446624cb5c1847bb16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8257ae5c9ea518446624cb5c1847bb16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8257ae5c9ea518446624cb5c1847bb16 = L.map(
#                 &quot;map_8257ae5c9ea518446624cb5c1847bb16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb9d89b47a9230b253f9b0cb4486252c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb9d89b47a9230b253f9b0cb4486252c.addTo(map_8257ae5c9ea518446624cb5c1847bb16);
#
#
#             var feature_group_38911aedb6275e0cc1b57562b3169cb4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_38911aedb6275e0cc1b57562b3169cb4.addTo(map_8257ae5c9ea518446624cb5c1847bb16);
#
#
#             var feature_group_sub_group_91c3898df3ed00b90730c4500683e7a7 = L.featureGroup.subGroup(
#                 feature_group_38911aedb6275e0cc1b57562b3169cb4
#             );
#
#
#             var marker_6755c6e077d74ce07824aeb8453149eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_91c3898df3ed00b90730c4500683e7a7);
#
#
#         var popup_6afcf6d719094a831899a320ef143fa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f970492e576250516fafede5554703a = $(`&lt;div id=&quot;html_8f970492e576250516fafede5554703a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6afcf6d719094a831899a320ef143fa8.setContent(html_8f970492e576250516fafede5554703a);
#
#
#
#         marker_6755c6e077d74ce07824aeb8453149eb.bindPopup(popup_6afcf6d719094a831899a320ef143fa8)
#         ;
#
#
#
#
#             var marker_0776239db91e51885490caa234f5db69 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_91c3898df3ed00b90730c4500683e7a7);
#
#
#         var popup_0dd4d4cec6f4544e161a48503fe472b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d68052afd9d2591e0ef707b3c610c50 = $(`&lt;div id=&quot;html_7d68052afd9d2591e0ef707b3c610c50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0dd4d4cec6f4544e161a48503fe472b3.setContent(html_7d68052afd9d2591e0ef707b3c610c50);
#
#
#
#         marker_0776239db91e51885490caa234f5db69.bindPopup(popup_0dd4d4cec6f4544e161a48503fe472b3)
#         ;
#
#
#
#
#             var marker_9d24b88a3ef60fbc8eadfc003c4da7c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_91c3898df3ed00b90730c4500683e7a7);
#
#
#         var popup_07d0533f06be6c2e71ca83dfa83649ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69e4059f576f9631da0e452a4baed2bf = $(`&lt;div id=&quot;html_69e4059f576f9631da0e452a4baed2bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_07d0533f06be6c2e71ca83dfa83649ec.setContent(html_69e4059f576f9631da0e452a4baed2bf);
#
#
#
#         marker_9d24b88a3ef60fbc8eadfc003c4da7c1.bindPopup(popup_07d0533f06be6c2e71ca83dfa83649ec)
#         ;
#
#
#
#
#             var marker_b089c093c57055e95dce8f5a88fa5a9e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_91c3898df3ed00b90730c4500683e7a7);
#
#
#         var popup_877dc9fade5cea61e8a930e85b046fd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7fcadd1c09f29f67f20dd4165b742d7 = $(`&lt;div id=&quot;html_b7fcadd1c09f29f67f20dd4165b742d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_877dc9fade5cea61e8a930e85b046fd4.setContent(html_b7fcadd1c09f29f67f20dd4165b742d7);
#
#
#
#         marker_
