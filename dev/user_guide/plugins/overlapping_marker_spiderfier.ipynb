# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9f442b0c0bc9c4fd243a8284afac5fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9f442b0c0bc9c4fd243a8284afac5fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9f442b0c0bc9c4fd243a8284afac5fa = L.map(
#                 &quot;map_b9f442b0c0bc9c4fd243a8284afac5fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6485359592e47b6f7d527ca3199cfbff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6485359592e47b6f7d527ca3199cfbff.addTo(map_b9f442b0c0bc9c4fd243a8284afac5fa);
#
#
#             var marker_b93cf9485145a4d9e6da6cea5f419bec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b9f442b0c0bc9c4fd243a8284afac5fa);
#
#
#         var popup_67e84d66ad2e5abf9b83ba34279be8bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67a2b9e842f7ee51ab13e8e274d445e0 = $(`&lt;div id=&quot;html_67a2b9e842f7ee51ab13e8e274d445e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_67e84d66ad2e5abf9b83ba34279be8bb.setContent(html_67a2b9e842f7ee51ab13e8e274d445e0);
#
#
#
#         marker_b93cf9485145a4d9e6da6cea5f419bec.bindPopup(popup_67e84d66ad2e5abf9b83ba34279be8bb)
#         ;
#
#
#
#
#             var marker_abbcb4d7d4a8683b6cf1602983e8f2b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b9f442b0c0bc9c4fd243a8284afac5fa);
#
#
#         var popup_597705e3450e2ceef5d057b4ec630708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d14d6b7a8ad68b5ccd109282109922e7 = $(`&lt;div id=&quot;html_d14d6b7a8ad68b5ccd109282109922e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_597705e3450e2ceef5d057b4ec630708.setContent(html_d14d6b7a8ad68b5ccd109282109922e7);
#
#
#
#         marker_abbcb4d7d4a8683b6cf1602983e8f2b5.bindPopup(popup_597705e3450e2ceef5d057b4ec630708)
#         ;
#
#
#
#
#             var marker_b75ebc24a97873fd6221c40876dc0860 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b9f442b0c0bc9c4fd243a8284afac5fa);
#
#
#         var popup_ee293ac2a173ba6faa239a2071cec439 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_841953f51e1e35faad1231b34853d011 = $(`&lt;div id=&quot;html_841953f51e1e35faad1231b34853d011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee293ac2a173ba6faa239a2071cec439.setContent(html_841953f51e1e35faad1231b34853d011);
#
#
#
#         marker_b75ebc24a97873fd6221c40876dc0860.bindPopup(popup_ee293ac2a173ba6faa239a2071cec439)
#         ;
#
#
#
#
#             var marker_46fb18230bbf9b439a9545bae3b2dced = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b9f442b0c0bc9c4fd243a8284afac5fa);
#
#
#         var popup_805f78d3fdd7a5fa121df56b18f47180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a993a16f36cfbd1a4246a7daba618c47 = $(`&lt;div id=&quot;html_a993a16f36cfbd1a4246a7daba618c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_805f78d3fdd7a5fa121df56b18f47180.setContent(html_a993a16f36cfbd1a4246a7daba618c47);
#
#
#
#         marker_46fb18230bbf9b439a9545bae3b2dced.bindPopup(popup_805f78d3fdd7a5fa121df56b18f47180)
#         ;
#
#
#
#
#             var marker_2c254d5d17582c5efcd71de09b7ae1b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b9f442b0c0bc9c4fd243a8284afac5fa);
#
#
#         var popup_efd4b57afef2d2294ac99b618ed63ccf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4bbe7604a836c7af01c7d59a982bdd8 = $(`&lt;div id=&quot;html_d4bbe7604a836c7af01c7d59a982bdd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_efd4b57afef2d2294ac99b618ed63ccf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aebb678af54c26837b95a08adbefcdd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aebb678af54c26837b95a08adbefcdd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aebb678af54c26837b95a08adbefcdd1 = L.map(
#                 &quot;map_aebb678af54c26837b95a08adbefcdd1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31faa4d4700fde5d3e87ab72f6e44dff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31faa4d4700fde5d3e87ab72f6e44dff.addTo(map_aebb678af54c26837b95a08adbefcdd1);
#
#
#             var feature_group_9f2869f1a4f1ef22c85972804e4b6d90 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4657b74229734eaabf1262aaeabe6d49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9f2869f1a4f1ef22c85972804e4b6d90);
#
#
#         var popup_33708ad39d2b69bf99df7064634378ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57dc85e66f730c48c62f634b700fa4b6 = $(`&lt;div id=&quot;html_57dc85e66f730c48c62f634b700fa4b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_33708ad39d2b69bf99df7064634378ee.setContent(html_57dc85e66f730c48c62f634b700fa4b6);
#
#
#
#         marker_4657b74229734eaabf1262aaeabe6d49.bindPopup(popup_33708ad39d2b69bf99df7064634378ee)
#         ;
#
#
#
#
#             var marker_3532fe0aeb9878036e0da38d03accfac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9f2869f1a4f1ef22c85972804e4b6d90);
#
#
#         var popup_eac004bea0534f08fdbba29427335b30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e33a2760d34cd64d31e7ceb6c0af0ff = $(`&lt;div id=&quot;html_7e33a2760d34cd64d31e7ceb6c0af0ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eac004bea0534f08fdbba29427335b30.setContent(html_7e33a2760d34cd64d31e7ceb6c0af0ff);
#
#
#
#         marker_3532fe0aeb9878036e0da38d03accfac.bindPopup(popup_eac004bea0534f08fdbba29427335b30)
#         ;
#
#
#
#
#             var marker_717bc1303e8ec44a5e0c9f2a0b26e40f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9f2869f1a4f1ef22c85972804e4b6d90);
#
#
#         var popup_2c4db3e732fa4e9bf47167736ef6de47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b56ba9c7f0c4765ff099b92e7eccaf91 = $(`&lt;div id=&quot;html_b56ba9c7f0c4765ff099b92e7eccaf91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2c4db3e732fa4e9bf47167736ef6de47.setContent(html_b56ba9c7f0c4765ff099b92e7eccaf91);
#
#
#
#         marker_717bc1303e8ec44a5e0c9f2a0b26e40f.bindPopup(popup_2c4db3e732fa4e9bf47167736ef6de47)
#         ;
#
#
#
#
#             var marker_493909117cc875f5ff5791df8a9dc09b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9f2869f1a4f1ef22c85972804e4b6d90);
#
#
#         var popup_014e641cfde44158afb37fb05aa1ebd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea0d373b0271406c4bb29232c2c9ca48 = $(`&lt;div id=&quot;html_ea0d373b0271406c4bb29232c2c9ca48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_014e641cfde44158afb37fb05aa1ebd5.setContent(html_ea0d373b0271406c4bb29232c2c9ca48);
#
#
#
#         marker_493909117cc875f5ff5791df8a9dc09b.bindPopup(popup_014e641cfde44158afb37fb05aa1ebd5)
#         ;
#
#
#
#
#             var marker_9c6dfffcd049db7ffb8be50a153f88bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9f2869f1a4f1ef22c85972804e4b6d90);
#
#
#         var popup_39aa86ac8dcb20620901f8552693abf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb11da09cc2d7eca971bb5e96fa6eb52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb11da09cc2d7eca971bb5e96fa6eb52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb11da09cc2d7eca971bb5e96fa6eb52 = L.map(
#                 &quot;map_cb11da09cc2d7eca971bb5e96fa6eb52&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcc840253f8a8fb9e674b8b48da0e005 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcc840253f8a8fb9e674b8b48da0e005.addTo(map_cb11da09cc2d7eca971bb5e96fa6eb52);
#
#
#             var feature_group_cfbfdc73d58b65b99312dfa0c19a627e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cfbfdc73d58b65b99312dfa0c19a627e.addTo(map_cb11da09cc2d7eca971bb5e96fa6eb52);
#
#
#             var feature_group_sub_group_fb960e50c006ad7f06cb13419bb84b53 = L.featureGroup.subGroup(
#                 feature_group_cfbfdc73d58b65b99312dfa0c19a627e
#             );
#
#
#             var marker_55bcd5270cbcdf668302ebea83e47dba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb960e50c006ad7f06cb13419bb84b53);
#
#
#         var popup_e830c4d68961cdf3790eb59dcad87fd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d3e7c4e447ef0174b777c102002fa51 = $(`&lt;div id=&quot;html_8d3e7c4e447ef0174b777c102002fa51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e830c4d68961cdf3790eb59dcad87fd9.setContent(html_8d3e7c4e447ef0174b777c102002fa51);
#
#
#
#         marker_55bcd5270cbcdf668302ebea83e47dba.bindPopup(popup_e830c4d68961cdf3790eb59dcad87fd9)
#         ;
#
#
#
#
#             var marker_7752a5820e1ec0539036747808711943 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb960e50c006ad7f06cb13419bb84b53);
#
#
#         var popup_011bdfa5908206a5afc649d8f0a33bc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df4e89d7862a25988dd01b5eb1c490a8 = $(`&lt;div id=&quot;html_df4e89d7862a25988dd01b5eb1c490a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_011bdfa5908206a5afc649d8f0a33bc5.setContent(html_df4e89d7862a25988dd01b5eb1c490a8);
#
#
#
#         marker_7752a5820e1ec0539036747808711943.bindPopup(popup_011bdfa5908206a5afc649d8f0a33bc5)
#         ;
#
#
#
#
#             var marker_df75485339a4ee35cbbc881e5a377375 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb960e50c006ad7f06cb13419bb84b53);
#
#
#         var popup_88f2ccaf7f8f6f13a3f816165ef0c48c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac6a3330da6bc95a70f8893f3500f74c = $(`&lt;div id=&quot;html_ac6a3330da6bc95a70f8893f3500f74c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88f2ccaf7f8f6f13a3f816165ef0c48c.setContent(html_ac6a3330da6bc95a70f8893f3500f74c);
#
#
#
#         marker_df75485339a4ee35cbbc881e5a377375.bindPopup(popup_88f2ccaf7f8f6f13a3f816165ef0c48c)
#         ;
#
#
#
#
#             var marker_f172ed9a0f33cfa6f93b1a47979f8d8d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb960e50c006ad7f06cb13419bb84b53);
#
#
#         var popup_d324119919bb2b4468df55a6b0144172 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d590a32ee1cd716abec614e2bb826eb = $(`&lt;div id=&quot;html_7d590a32ee1cd716abec614e2bb826eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d324119919bb2b4468df55a6b0144172.setContent(html_7d590a32ee1cd716abec614e2bb826eb);
#
#
#
#         marker_
