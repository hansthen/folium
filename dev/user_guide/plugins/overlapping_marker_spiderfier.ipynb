# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94a47ad6328bac8a86a16fa25e81f3fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94a47ad6328bac8a86a16fa25e81f3fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94a47ad6328bac8a86a16fa25e81f3fb = L.map(
#                 &quot;map_94a47ad6328bac8a86a16fa25e81f3fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c12019fc39fbbf695a784eff12cf156 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c12019fc39fbbf695a784eff12cf156.addTo(map_94a47ad6328bac8a86a16fa25e81f3fb);
#
#
#             var marker_c6df66ae7a010f8196f3b9cf6e0cd9e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94a47ad6328bac8a86a16fa25e81f3fb);
#
#
#         var popup_3a2ae48a5113804cd878ec982310a1b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1bad336d18f1f7e818c4360ede273be = $(`&lt;div id=&quot;html_d1bad336d18f1f7e818c4360ede273be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3a2ae48a5113804cd878ec982310a1b8.setContent(html_d1bad336d18f1f7e818c4360ede273be);
#
#
#
#         marker_c6df66ae7a010f8196f3b9cf6e0cd9e0.bindPopup(popup_3a2ae48a5113804cd878ec982310a1b8)
#         ;
#
#
#
#
#             var marker_9e4c4e57bb5a856078e121193cc8f65f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94a47ad6328bac8a86a16fa25e81f3fb);
#
#
#         var popup_e8bfca86f5063517b00cea8cc9a6b67c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f618382c1f77b96dbb207d0e0e31fd1 = $(`&lt;div id=&quot;html_9f618382c1f77b96dbb207d0e0e31fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e8bfca86f5063517b00cea8cc9a6b67c.setContent(html_9f618382c1f77b96dbb207d0e0e31fd1);
#
#
#
#         marker_9e4c4e57bb5a856078e121193cc8f65f.bindPopup(popup_e8bfca86f5063517b00cea8cc9a6b67c)
#         ;
#
#
#
#
#             var marker_5714c4b5a76236eb7da483ba40a1acac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94a47ad6328bac8a86a16fa25e81f3fb);
#
#
#         var popup_e39c1fbde883e43c556504c8c624a2fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5468e00f608b2480e2747b17e6d752af = $(`&lt;div id=&quot;html_5468e00f608b2480e2747b17e6d752af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e39c1fbde883e43c556504c8c624a2fd.setContent(html_5468e00f608b2480e2747b17e6d752af);
#
#
#
#         marker_5714c4b5a76236eb7da483ba40a1acac.bindPopup(popup_e39c1fbde883e43c556504c8c624a2fd)
#         ;
#
#
#
#
#             var marker_fc18ad0e62b6b394930e23b188d4dd0f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94a47ad6328bac8a86a16fa25e81f3fb);
#
#
#         var popup_517923a7f6c8f41a4e80abb945929e47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70ac3a40e099a85472b5a6f899437af0 = $(`&lt;div id=&quot;html_70ac3a40e099a85472b5a6f899437af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_517923a7f6c8f41a4e80abb945929e47.setContent(html_70ac3a40e099a85472b5a6f899437af0);
#
#
#
#         marker_fc18ad0e62b6b394930e23b188d4dd0f.bindPopup(popup_517923a7f6c8f41a4e80abb945929e47)
#         ;
#
#
#
#
#             var marker_349f7a690897f49c45b947155681c568 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94a47ad6328bac8a86a16fa25e81f3fb);
#
#
#         var popup_ecee09efe21af07d65540ecf9859ca1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a37cdcb0dfcaa86c8044ddf27039d0c6 = $(`&lt;div id=&quot;html_a37cdcb0dfcaa86c8044ddf27039d0c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ecee09efe21af07d65540ecf9859ca1d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_693ed4ca207a46ed50ee790fd398709a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_693ed4ca207a46ed50ee790fd398709a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_693ed4ca207a46ed50ee790fd398709a = L.map(
#                 &quot;map_693ed4ca207a46ed50ee790fd398709a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ebaca9f42d3a1f2c35a7012a5800e77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ebaca9f42d3a1f2c35a7012a5800e77.addTo(map_693ed4ca207a46ed50ee790fd398709a);
#
#
#             var feature_group_945a17366152e9c6ae5bd2277d6557f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_419454847dcd404a8f2c8a41ccc0bafb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_945a17366152e9c6ae5bd2277d6557f1);
#
#
#         var popup_7005c3841db9faad5b55363c29d64055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01ea32f3e9c1eb6434a9d7b6788164e7 = $(`&lt;div id=&quot;html_01ea32f3e9c1eb6434a9d7b6788164e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7005c3841db9faad5b55363c29d64055.setContent(html_01ea32f3e9c1eb6434a9d7b6788164e7);
#
#
#
#         marker_419454847dcd404a8f2c8a41ccc0bafb.bindPopup(popup_7005c3841db9faad5b55363c29d64055)
#         ;
#
#
#
#
#             var marker_34993ddbbad9bd16590479f17892fb07 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_945a17366152e9c6ae5bd2277d6557f1);
#
#
#         var popup_194e706d6ddd2f675c830ad2d13dbb48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6628ff440943f5f21247cfa8ca77b3a1 = $(`&lt;div id=&quot;html_6628ff440943f5f21247cfa8ca77b3a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_194e706d6ddd2f675c830ad2d13dbb48.setContent(html_6628ff440943f5f21247cfa8ca77b3a1);
#
#
#
#         marker_34993ddbbad9bd16590479f17892fb07.bindPopup(popup_194e706d6ddd2f675c830ad2d13dbb48)
#         ;
#
#
#
#
#             var marker_30eba94e8ad102315c69a9cdda2d9614 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_945a17366152e9c6ae5bd2277d6557f1);
#
#
#         var popup_45a0bdc7d94c79e2e2172c8ca7ce3e41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c132484dd97ec0658224838d6f6917bb = $(`&lt;div id=&quot;html_c132484dd97ec0658224838d6f6917bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_45a0bdc7d94c79e2e2172c8ca7ce3e41.setContent(html_c132484dd97ec0658224838d6f6917bb);
#
#
#
#         marker_30eba94e8ad102315c69a9cdda2d9614.bindPopup(popup_45a0bdc7d94c79e2e2172c8ca7ce3e41)
#         ;
#
#
#
#
#             var marker_b557d84ae172b6e35c563454e30f59ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_945a17366152e9c6ae5bd2277d6557f1);
#
#
#         var popup_23ecc23016c92a3e2ba6cb7e89d2410d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0e5cd6fd4d56924101a7bbdea6fafdd = $(`&lt;div id=&quot;html_f0e5cd6fd4d56924101a7bbdea6fafdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_23ecc23016c92a3e2ba6cb7e89d2410d.setContent(html_f0e5cd6fd4d56924101a7bbdea6fafdd);
#
#
#
#         marker_b557d84ae172b6e35c563454e30f59ec.bindPopup(popup_23ecc23016c92a3e2ba6cb7e89d2410d)
#         ;
#
#
#
#
#             var marker_66bfb0bb7903238bed2fa647c3311b94 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_945a17366152e9c6ae5bd2277d6557f1);
#
#
#         var popup_7eda921bd8024a7eb2acf55ed604baa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3c74ddbea52ad77337714b2270152ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3c74ddbea52ad77337714b2270152ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3c74ddbea52ad77337714b2270152ac = L.map(
#                 &quot;map_d3c74ddbea52ad77337714b2270152ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9470c9ead8b6ec9990e1fc56041621c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9470c9ead8b6ec9990e1fc56041621c.addTo(map_d3c74ddbea52ad77337714b2270152ac);
#
#
#             var feature_group_31dff86b8ad331a42e65545613ed68aa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_31dff86b8ad331a42e65545613ed68aa.addTo(map_d3c74ddbea52ad77337714b2270152ac);
#
#
#             var feature_group_sub_group_8c60d23749fd8e0c168e261e9246ad25 = L.featureGroup.subGroup(
#                 feature_group_31dff86b8ad331a42e65545613ed68aa
#             );
#
#
#             var marker_5e2f29e91d0251e3538c34ae8df089a7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c60d23749fd8e0c168e261e9246ad25);
#
#
#         var popup_7796512abe07dcae5b6f850a1d245f8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f1adbff98f62ad40b8ca93704b35327 = $(`&lt;div id=&quot;html_9f1adbff98f62ad40b8ca93704b35327&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7796512abe07dcae5b6f850a1d245f8e.setContent(html_9f1adbff98f62ad40b8ca93704b35327);
#
#
#
#         marker_5e2f29e91d0251e3538c34ae8df089a7.bindPopup(popup_7796512abe07dcae5b6f850a1d245f8e)
#         ;
#
#
#
#
#             var marker_04e83fac4293f4ae8dbdd562ae91de6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c60d23749fd8e0c168e261e9246ad25);
#
#
#         var popup_71a6fbd6d3eea72d01d5d48d58856446 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa0173521e872fa66c825a7b67169ed8 = $(`&lt;div id=&quot;html_aa0173521e872fa66c825a7b67169ed8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_71a6fbd6d3eea72d01d5d48d58856446.setContent(html_aa0173521e872fa66c825a7b67169ed8);
#
#
#
#         marker_04e83fac4293f4ae8dbdd562ae91de6a.bindPopup(popup_71a6fbd6d3eea72d01d5d48d58856446)
#         ;
#
#
#
#
#             var marker_48d0f0fa9061c2d5561bdd107b135a90 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c60d23749fd8e0c168e261e9246ad25);
#
#
#         var popup_89ca3da69f176e33bc6f17d3686b6921 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3aec88fb5994d7f584915f7c679658f = $(`&lt;div id=&quot;html_a3aec88fb5994d7f584915f7c679658f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_89ca3da69f176e33bc6f17d3686b6921.setContent(html_a3aec88fb5994d7f584915f7c679658f);
#
#
#
#         marker_48d0f0fa9061c2d5561bdd107b135a90.bindPopup(popup_89ca3da69f176e33bc6f17d3686b6921)
#         ;
#
#
#
#
#             var marker_e70da32151c2ff951e8b1735ca96b825 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c60d23749fd8e0c168e261e9246ad25);
#
#
#         var popup_5aa98102c9641a137e24b65a812bc34c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c2cf1e0e3c98245d775915b1af38480 = $(`&lt;div id=&quot;html_8c2cf1e0e3c98245d775915b1af38480&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5aa98102c9641a137e24b65a812bc34c.setContent(html_8c2cf1e0e3c98245d775915b1af38480);
#
#
#
#         marker_
