# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28acf7b43d73b8308513aab12d645038 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28acf7b43d73b8308513aab12d645038&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28acf7b43d73b8308513aab12d645038 = L.map(
#                 &quot;map_28acf7b43d73b8308513aab12d645038&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92a4cc8dd68dfebc60fc1df592c3b19b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92a4cc8dd68dfebc60fc1df592c3b19b.addTo(map_28acf7b43d73b8308513aab12d645038);
#
#
#             var marker_400ad457a72f9d6e8b7b7087b56513ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_28acf7b43d73b8308513aab12d645038);
#
#
#         var popup_931af6bba3659c2ca613dba237b10a95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb1dff44c957a09e6d6d81ef513d7984 = $(`&lt;div id=&quot;html_eb1dff44c957a09e6d6d81ef513d7984&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_931af6bba3659c2ca613dba237b10a95.setContent(html_eb1dff44c957a09e6d6d81ef513d7984);
#
#
#
#         marker_400ad457a72f9d6e8b7b7087b56513ee.bindPopup(popup_931af6bba3659c2ca613dba237b10a95)
#         ;
#
#
#
#
#             var marker_8e7d2ded249e45967cc3ac72ea370fa7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_28acf7b43d73b8308513aab12d645038);
#
#
#         var popup_7519c380bd8c34a063ae0517f9236b8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a124d2085b628c1047a78abc1880f6d = $(`&lt;div id=&quot;html_3a124d2085b628c1047a78abc1880f6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7519c380bd8c34a063ae0517f9236b8b.setContent(html_3a124d2085b628c1047a78abc1880f6d);
#
#
#
#         marker_8e7d2ded249e45967cc3ac72ea370fa7.bindPopup(popup_7519c380bd8c34a063ae0517f9236b8b)
#         ;
#
#
#
#
#             var marker_c3a5eef277b76b907b3a26bbad7fe52f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_28acf7b43d73b8308513aab12d645038);
#
#
#         var popup_c8487e9f7e48f8b6e27f66d294ad8ad7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2889a2b8270de96a768ea365dc3f9128 = $(`&lt;div id=&quot;html_2889a2b8270de96a768ea365dc3f9128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c8487e9f7e48f8b6e27f66d294ad8ad7.setContent(html_2889a2b8270de96a768ea365dc3f9128);
#
#
#
#         marker_c3a5eef277b76b907b3a26bbad7fe52f.bindPopup(popup_c8487e9f7e48f8b6e27f66d294ad8ad7)
#         ;
#
#
#
#
#             var marker_e4bef52629a9f7a9e1e883a3b64eeae6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_28acf7b43d73b8308513aab12d645038);
#
#
#         var popup_0cdf39645545e6d3adf1a4eeb6f1629b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3678abfd95a89470deaef94e29296919 = $(`&lt;div id=&quot;html_3678abfd95a89470deaef94e29296919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0cdf39645545e6d3adf1a4eeb6f1629b.setContent(html_3678abfd95a89470deaef94e29296919);
#
#
#
#         marker_e4bef52629a9f7a9e1e883a3b64eeae6.bindPopup(popup_0cdf39645545e6d3adf1a4eeb6f1629b)
#         ;
#
#
#
#
#             var marker_34242722e7d448ab4cba26d45b17b808 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_28acf7b43d73b8308513aab12d645038);
#
#
#         var popup_9dc5fc08d4987781ef875d1a8b0a09b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3067da43260a9700ee7e1fcb48d21832 = $(`&lt;div id=&quot;html_3067da43260a9700ee7e1fcb48d21832&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9dc5fc08d4987781ef875d1a8b0a09b8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dd0334f1cae85f4daf4407592a15e7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dd0334f1cae85f4daf4407592a15e7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dd0334f1cae85f4daf4407592a15e7e = L.map(
#                 &quot;map_2dd0334f1cae85f4daf4407592a15e7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eec77c235101f2a41071c5cb2a9d110e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eec77c235101f2a41071c5cb2a9d110e.addTo(map_2dd0334f1cae85f4daf4407592a15e7e);
#
#
#             var feature_group_0eeae6c6b31dd5b3c9b437c2b39046ea = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_20bae0d531aec403b9c8cdfe5d68127e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0eeae6c6b31dd5b3c9b437c2b39046ea);
#
#
#         var popup_178e63a9da6e5a19e684884cdb3344d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3faeee8896dd244b5af6cdb07a864fc = $(`&lt;div id=&quot;html_b3faeee8896dd244b5af6cdb07a864fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_178e63a9da6e5a19e684884cdb3344d1.setContent(html_b3faeee8896dd244b5af6cdb07a864fc);
#
#
#
#         marker_20bae0d531aec403b9c8cdfe5d68127e.bindPopup(popup_178e63a9da6e5a19e684884cdb3344d1)
#         ;
#
#
#
#
#             var marker_8dc0863534e923dad7263ae7f9269e90 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0eeae6c6b31dd5b3c9b437c2b39046ea);
#
#
#         var popup_dce0636df6c7a3e076d13a14811b57c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_452b31acc06bb9ee70319fa1ea497997 = $(`&lt;div id=&quot;html_452b31acc06bb9ee70319fa1ea497997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dce0636df6c7a3e076d13a14811b57c0.setContent(html_452b31acc06bb9ee70319fa1ea497997);
#
#
#
#         marker_8dc0863534e923dad7263ae7f9269e90.bindPopup(popup_dce0636df6c7a3e076d13a14811b57c0)
#         ;
#
#
#
#
#             var marker_a39eee4a2caa154efffb3ad856d710cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0eeae6c6b31dd5b3c9b437c2b39046ea);
#
#
#         var popup_1b3f803eb15e49a1b97757b8b66076de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c061a88e4261b07a70e272c5922536d = $(`&lt;div id=&quot;html_2c061a88e4261b07a70e272c5922536d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1b3f803eb15e49a1b97757b8b66076de.setContent(html_2c061a88e4261b07a70e272c5922536d);
#
#
#
#         marker_a39eee4a2caa154efffb3ad856d710cf.bindPopup(popup_1b3f803eb15e49a1b97757b8b66076de)
#         ;
#
#
#
#
#             var marker_6797adf80e856b24f0fdca6c1c115350 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0eeae6c6b31dd5b3c9b437c2b39046ea);
#
#
#         var popup_5b43503c29ff88694e7a1127d16c5758 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b0e495c5c4238a3f5ef6076057fed70 = $(`&lt;div id=&quot;html_7b0e495c5c4238a3f5ef6076057fed70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5b43503c29ff88694e7a1127d16c5758.setContent(html_7b0e495c5c4238a3f5ef6076057fed70);
#
#
#
#         marker_6797adf80e856b24f0fdca6c1c115350.bindPopup(popup_5b43503c29ff88694e7a1127d16c5758)
#         ;
#
#
#
#
#             var marker_efed9a9fa5f8810da8b3678aec082f7d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0eeae6c6b31dd5b3c9b437c2b39046ea);
#
#
#         var popup_500732a4f59a511b1c498b4a3b9e3b00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae0a932ad8cd6814f836eab3993a6598 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae0a932ad8cd6814f836eab3993a6598&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae0a932ad8cd6814f836eab3993a6598 = L.map(
#                 &quot;map_ae0a932ad8cd6814f836eab3993a6598&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d19660c871d12b6a848e9532510c139d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d19660c871d12b6a848e9532510c139d.addTo(map_ae0a932ad8cd6814f836eab3993a6598);
#
#
#             var feature_group_f14348e0f491613c54f280a7f6d95255 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f14348e0f491613c54f280a7f6d95255.addTo(map_ae0a932ad8cd6814f836eab3993a6598);
#
#
#             var feature_group_sub_group_b409fe1fddba7d5ec3eda2d2e81d061f = L.featureGroup.subGroup(
#                 feature_group_f14348e0f491613c54f280a7f6d95255
#             );
#
#
#             var marker_464a078f2667944f003b8c302bf909c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b409fe1fddba7d5ec3eda2d2e81d061f);
#
#
#         var popup_99b4a8a3a990112e3181b0aacbd6f3ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21100c187acf2571b78c224ddcca4420 = $(`&lt;div id=&quot;html_21100c187acf2571b78c224ddcca4420&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_99b4a8a3a990112e3181b0aacbd6f3ed.setContent(html_21100c187acf2571b78c224ddcca4420);
#
#
#
#         marker_464a078f2667944f003b8c302bf909c3.bindPopup(popup_99b4a8a3a990112e3181b0aacbd6f3ed)
#         ;
#
#
#
#
#             var marker_c8b1c486e760dd909d150d33a51a397c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b409fe1fddba7d5ec3eda2d2e81d061f);
#
#
#         var popup_d1fb913dd3d1fcb1cf1a0d3f97ab4b15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e170f0b848c15ead54d61e467532afaa = $(`&lt;div id=&quot;html_e170f0b848c15ead54d61e467532afaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d1fb913dd3d1fcb1cf1a0d3f97ab4b15.setContent(html_e170f0b848c15ead54d61e467532afaa);
#
#
#
#         marker_c8b1c486e760dd909d150d33a51a397c.bindPopup(popup_d1fb913dd3d1fcb1cf1a0d3f97ab4b15)
#         ;
#
#
#
#
#             var marker_8b08e34d6ed277a2c664486986326e21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b409fe1fddba7d5ec3eda2d2e81d061f);
#
#
#         var popup_3e65967f2cfc2810873ed4c9cbe01061 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51f559e486cc4b38146611c8a0317ad9 = $(`&lt;div id=&quot;html_51f559e486cc4b38146611c8a0317ad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3e65967f2cfc2810873ed4c9cbe01061.setContent(html_51f559e486cc4b38146611c8a0317ad9);
#
#
#
#         marker_8b08e34d6ed277a2c664486986326e21.bindPopup(popup_3e65967f2cfc2810873ed4c9cbe01061)
#         ;
#
#
#
#
#             var marker_9840982eb8ab2e7d6c65690f64b42f9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b409fe1fddba7d5ec3eda2d2e81d061f);
#
#
#         var popup_373760223849cce2b0fc890a719f7720 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd206381161e3abb83bdbc103d402ef6 = $(`&lt;div id=&quot;html_cd206381161e3abb83bdbc103d402ef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_373760223849cce2b0fc890a719f7720.setContent(html_cd206381161e3abb83bdbc103d402ef6);
#
#
#
#         marker_
