# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_587df44404671c7a881da3dcb01864f4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_587df44404671c7a881da3dcb01864f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_587df44404671c7a881da3dcb01864f4 = L.map(
#                 &quot;map_587df44404671c7a881da3dcb01864f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbb8e2eac83c5a8f8077bfbbe407fa61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbb8e2eac83c5a8f8077bfbbe407fa61.addTo(map_587df44404671c7a881da3dcb01864f4);
#
#
#             var marker_0deca9ebd4fa2ba34babf373976b845c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_587df44404671c7a881da3dcb01864f4);
#
#
#         var popup_af773230b2f8883d053eeea92fc862e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ad9faf06b70939784e4452f0603e8a5 = $(`&lt;div id=&quot;html_6ad9faf06b70939784e4452f0603e8a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_af773230b2f8883d053eeea92fc862e6.setContent(html_6ad9faf06b70939784e4452f0603e8a5);
#
#
#
#         marker_0deca9ebd4fa2ba34babf373976b845c.bindPopup(popup_af773230b2f8883d053eeea92fc862e6)
#         ;
#
#
#
#
#             var marker_55ccef2eeeef98252070a61cb513f8c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_587df44404671c7a881da3dcb01864f4);
#
#
#         var popup_76faa1bbec347d1b411d759a3956cc9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7a49ea22a1728c651ef9726e3299058 = $(`&lt;div id=&quot;html_c7a49ea22a1728c651ef9726e3299058&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_76faa1bbec347d1b411d759a3956cc9e.setContent(html_c7a49ea22a1728c651ef9726e3299058);
#
#
#
#         marker_55ccef2eeeef98252070a61cb513f8c3.bindPopup(popup_76faa1bbec347d1b411d759a3956cc9e)
#         ;
#
#
#
#
#             var marker_5e45f4baf5d73fab4cf4a41945d72c47 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_587df44404671c7a881da3dcb01864f4);
#
#
#         var popup_e3571b23ec125c0faef84fca2f7d9bd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46b208089642aba9f81a18b05b89f3e7 = $(`&lt;div id=&quot;html_46b208089642aba9f81a18b05b89f3e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e3571b23ec125c0faef84fca2f7d9bd6.setContent(html_46b208089642aba9f81a18b05b89f3e7);
#
#
#
#         marker_5e45f4baf5d73fab4cf4a41945d72c47.bindPopup(popup_e3571b23ec125c0faef84fca2f7d9bd6)
#         ;
#
#
#
#
#             var marker_17e7b8b68aaf6be149cf71bc80248f1c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_587df44404671c7a881da3dcb01864f4);
#
#
#         var popup_07f54f5e2ef42c2f9ad6890ac8c2a38b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c941ad61fa4f4adb2d98e7d0422ede1 = $(`&lt;div id=&quot;html_2c941ad61fa4f4adb2d98e7d0422ede1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_07f54f5e2ef42c2f9ad6890ac8c2a38b.setContent(html_2c941ad61fa4f4adb2d98e7d0422ede1);
#
#
#
#         marker_17e7b8b68aaf6be149cf71bc80248f1c.bindPopup(popup_07f54f5e2ef42c2f9ad6890ac8c2a38b)
#         ;
#
#
#
#
#             var marker_39d93c63b98c18a32dc15d079dfdbe4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_587df44404671c7a881da3dcb01864f4);
#
#
#         var popup_e158a86584cb93b08ba5f16f2c92f407 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91b668fec63c033a2eca0c5221faf577 = $(`&lt;div id=&quot;html_91b668fec63c033a2eca0c5221faf577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e158a86584cb93b08ba5f16f2c92f4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4943ad4b841c38af56ad9f4bcc7380a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4943ad4b841c38af56ad9f4bcc7380a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4943ad4b841c38af56ad9f4bcc7380a = L.map(
#                 &quot;map_c4943ad4b841c38af56ad9f4bcc7380a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad35e7d99a2f18d82debfac5794b60c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad35e7d99a2f18d82debfac5794b60c8.addTo(map_c4943ad4b841c38af56ad9f4bcc7380a);
#
#
#             var feature_group_b05ea056a21b94c3648283f274a222d2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cbd32538793b397cc1eb82dee220c680 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b05ea056a21b94c3648283f274a222d2);
#
#
#         var popup_7655a7943c704c483d8de7b55bf69493 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da69089d6250b06a6a94274314a98478 = $(`&lt;div id=&quot;html_da69089d6250b06a6a94274314a98478&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7655a7943c704c483d8de7b55bf69493.setContent(html_da69089d6250b06a6a94274314a98478);
#
#
#
#         marker_cbd32538793b397cc1eb82dee220c680.bindPopup(popup_7655a7943c704c483d8de7b55bf69493)
#         ;
#
#
#
#
#             var marker_480972b33e79f35bcf883a4ba625a347 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b05ea056a21b94c3648283f274a222d2);
#
#
#         var popup_bf1d5af810d1c5fe2d50aa5c370b7e4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a4a1100df1ac0eb59753de20e382c1c = $(`&lt;div id=&quot;html_5a4a1100df1ac0eb59753de20e382c1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bf1d5af810d1c5fe2d50aa5c370b7e4b.setContent(html_5a4a1100df1ac0eb59753de20e382c1c);
#
#
#
#         marker_480972b33e79f35bcf883a4ba625a347.bindPopup(popup_bf1d5af810d1c5fe2d50aa5c370b7e4b)
#         ;
#
#
#
#
#             var marker_9014a1a15c135a1ba8dda23753607f09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b05ea056a21b94c3648283f274a222d2);
#
#
#         var popup_459dcb8e772105a961903afda91691be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be8fd608fd3b5b1b8320b08a47303373 = $(`&lt;div id=&quot;html_be8fd608fd3b5b1b8320b08a47303373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_459dcb8e772105a961903afda91691be.setContent(html_be8fd608fd3b5b1b8320b08a47303373);
#
#
#
#         marker_9014a1a15c135a1ba8dda23753607f09.bindPopup(popup_459dcb8e772105a961903afda91691be)
#         ;
#
#
#
#
#             var marker_a29303f6363a507646a7100ed90e9abe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b05ea056a21b94c3648283f274a222d2);
#
#
#         var popup_ff3c0d3030b0321b77725b9dedf6266d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6779a81ab2ee48bfe327923b2596174a = $(`&lt;div id=&quot;html_6779a81ab2ee48bfe327923b2596174a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ff3c0d3030b0321b77725b9dedf6266d.setContent(html_6779a81ab2ee48bfe327923b2596174a);
#
#
#
#         marker_a29303f6363a507646a7100ed90e9abe.bindPopup(popup_ff3c0d3030b0321b77725b9dedf6266d)
#         ;
#
#
#
#
#             var marker_703753cd54a6a4f1f96b25bc20d389d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b05ea056a21b94c3648283f274a222d2);
#
#
#         var popup_ea1f324259ceca2da50829d32361ed6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebd139de8f29985e6fd59e6723336ef1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebd139de8f29985e6fd59e6723336ef1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebd139de8f29985e6fd59e6723336ef1 = L.map(
#                 &quot;map_ebd139de8f29985e6fd59e6723336ef1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5261645f1ec7d897802fcb9dcca05723 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5261645f1ec7d897802fcb9dcca05723.addTo(map_ebd139de8f29985e6fd59e6723336ef1);
#
#
#             var feature_group_bfe17e472daf25e05f3a703945efe597 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bfe17e472daf25e05f3a703945efe597.addTo(map_ebd139de8f29985e6fd59e6723336ef1);
#
#
#             var feature_group_sub_group_62de4ca56ed1247e4011fb870b59ef3c = L.featureGroup.subGroup(
#                 feature_group_bfe17e472daf25e05f3a703945efe597
#             );
#
#
#             var marker_354ece4da0daa91d6913ab72709ef649 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_62de4ca56ed1247e4011fb870b59ef3c);
#
#
#         var popup_495bacc5a134491664b4d4585fdb1b3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_827c5c7174ad03dc6da7a33b8443b47e = $(`&lt;div id=&quot;html_827c5c7174ad03dc6da7a33b8443b47e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_495bacc5a134491664b4d4585fdb1b3c.setContent(html_827c5c7174ad03dc6da7a33b8443b47e);
#
#
#
#         marker_354ece4da0daa91d6913ab72709ef649.bindPopup(popup_495bacc5a134491664b4d4585fdb1b3c)
#         ;
#
#
#
#
#             var marker_280c0dfc5857a4ccc059cfe04e3c7ee7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_62de4ca56ed1247e4011fb870b59ef3c);
#
#
#         var popup_214bc9ccad8c9eb4e722ee14c67fd8f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb2733550e212c7470a54dd4bb4d5721 = $(`&lt;div id=&quot;html_eb2733550e212c7470a54dd4bb4d5721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_214bc9ccad8c9eb4e722ee14c67fd8f4.setContent(html_eb2733550e212c7470a54dd4bb4d5721);
#
#
#
#         marker_280c0dfc5857a4ccc059cfe04e3c7ee7.bindPopup(popup_214bc9ccad8c9eb4e722ee14c67fd8f4)
#         ;
#
#
#
#
#             var marker_8176cb10e41e8c42c7278a71dbac1f42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_62de4ca56ed1247e4011fb870b59ef3c);
#
#
#         var popup_bc520a546d9040f9eeb251835588ac32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e48b687ac7270e0b7cba0a2a42b7559 = $(`&lt;div id=&quot;html_6e48b687ac7270e0b7cba0a2a42b7559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bc520a546d9040f9eeb251835588ac32.setContent(html_6e48b687ac7270e0b7cba0a2a42b7559);
#
#
#
#         marker_8176cb10e41e8c42c7278a71dbac1f42.bindPopup(popup_bc520a546d9040f9eeb251835588ac32)
#         ;
#
#
#
#
#             var marker_739c771cbefae67f9f50180f315fa3a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_62de4ca56ed1247e4011fb870b59ef3c);
#
#
#         var popup_ef0e9f513099df1a2e4e571cb7d74a3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d3020b9b2b4cdfefdf6d37324d3a1fb = $(`&lt;div id=&quot;html_9d3020b9b2b4cdfefdf6d37324d3a1fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ef0e9f513099df1a2e4e571cb7d74a3c.setContent(html_9d3020b9b2b4cdfefdf6d37324d3a1fb);
#
#
#
#         mark
