# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_556ad27a63b532a312caf56b1705267a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_556ad27a63b532a312caf56b1705267a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_556ad27a63b532a312caf56b1705267a = L.map(
#                 &quot;map_556ad27a63b532a312caf56b1705267a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef4df8e4b1bc9dfa9fbb0b93838c59b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef4df8e4b1bc9dfa9fbb0b93838c59b5.addTo(map_556ad27a63b532a312caf56b1705267a);
#
#
#             var marker_896eae1e049cd071f86fbc77de5b4464 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_556ad27a63b532a312caf56b1705267a);
#
#
#         var popup_88e97d1f733d46a4a5d4ddd9034165b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8187008219249185e867fea773994434 = $(`&lt;div id=&quot;html_8187008219249185e867fea773994434&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_88e97d1f733d46a4a5d4ddd9034165b9.setContent(html_8187008219249185e867fea773994434);
#
#
#
#         marker_896eae1e049cd071f86fbc77de5b4464.bindPopup(popup_88e97d1f733d46a4a5d4ddd9034165b9)
#         ;
#
#
#
#
#             var marker_b6b51b1172cb63f954665b161068ff7f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_556ad27a63b532a312caf56b1705267a);
#
#
#         var popup_c653212fccc36f8b04d6437e22124478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fd51cf98d5cf8d5644dedbb8561e9d6 = $(`&lt;div id=&quot;html_0fd51cf98d5cf8d5644dedbb8561e9d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c653212fccc36f8b04d6437e22124478.setContent(html_0fd51cf98d5cf8d5644dedbb8561e9d6);
#
#
#
#         marker_b6b51b1172cb63f954665b161068ff7f.bindPopup(popup_c653212fccc36f8b04d6437e22124478)
#         ;
#
#
#
#
#             var marker_c8cf1b44f15103f1e5982c0e6a22013d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_556ad27a63b532a312caf56b1705267a);
#
#
#         var popup_a879c13062ea57072a56b74f7b737fa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edafe2dc35d6bfd2261107cd5fc0b7c4 = $(`&lt;div id=&quot;html_edafe2dc35d6bfd2261107cd5fc0b7c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a879c13062ea57072a56b74f7b737fa5.setContent(html_edafe2dc35d6bfd2261107cd5fc0b7c4);
#
#
#
#         marker_c8cf1b44f15103f1e5982c0e6a22013d.bindPopup(popup_a879c13062ea57072a56b74f7b737fa5)
#         ;
#
#
#
#
#             var marker_967a9e6bfb04d607237e30de44125b78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_556ad27a63b532a312caf56b1705267a);
#
#
#         var popup_d15cad16f0e15d3ae2305e09a9dad9d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86be99d04275024db4c8a4feaad9bfe0 = $(`&lt;div id=&quot;html_86be99d04275024db4c8a4feaad9bfe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d15cad16f0e15d3ae2305e09a9dad9d5.setContent(html_86be99d04275024db4c8a4feaad9bfe0);
#
#
#
#         marker_967a9e6bfb04d607237e30de44125b78.bindPopup(popup_d15cad16f0e15d3ae2305e09a9dad9d5)
#         ;
#
#
#
#
#             var marker_d4fbfb8d46e639c53aee084c1a909817 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_556ad27a63b532a312caf56b1705267a);
#
#
#         var popup_57838efa3c6c4c4b3d751bcb5962a289 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_678ee87111f678c341ab0833ea2c9c8c = $(`&lt;div id=&quot;html_678ee87111f678c341ab0833ea2c9c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_57838efa3c6c4c4b3d751bcb5962a289.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16d312d9997ed496d6dc0bed5bd86759 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16d312d9997ed496d6dc0bed5bd86759&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16d312d9997ed496d6dc0bed5bd86759 = L.map(
#                 &quot;map_16d312d9997ed496d6dc0bed5bd86759&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3aa8c242206d87cae894ad3b4aba6240 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3aa8c242206d87cae894ad3b4aba6240.addTo(map_16d312d9997ed496d6dc0bed5bd86759);
#
#
#             var feature_group_dabec736d0418c890856be86c6f4a66d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fedd95d44b84a37e849c2438068249ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dabec736d0418c890856be86c6f4a66d);
#
#
#         var popup_f720f59daf1049d815a02e1d9798c618 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41cf702ed11fe5659778d82b496db9aa = $(`&lt;div id=&quot;html_41cf702ed11fe5659778d82b496db9aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f720f59daf1049d815a02e1d9798c618.setContent(html_41cf702ed11fe5659778d82b496db9aa);
#
#
#
#         marker_fedd95d44b84a37e849c2438068249ce.bindPopup(popup_f720f59daf1049d815a02e1d9798c618)
#         ;
#
#
#
#
#             var marker_1644b3eb648e3c1600317634c1cb32cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dabec736d0418c890856be86c6f4a66d);
#
#
#         var popup_a4067236399f37d50dc85868397e748d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c964cd7fbaf61919babc32cbfde78852 = $(`&lt;div id=&quot;html_c964cd7fbaf61919babc32cbfde78852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a4067236399f37d50dc85868397e748d.setContent(html_c964cd7fbaf61919babc32cbfde78852);
#
#
#
#         marker_1644b3eb648e3c1600317634c1cb32cc.bindPopup(popup_a4067236399f37d50dc85868397e748d)
#         ;
#
#
#
#
#             var marker_c517a11987ab6f701be235101e70aa6d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dabec736d0418c890856be86c6f4a66d);
#
#
#         var popup_9a88c2b3040b5f95a8da2b1d202377ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e146e74775b320b42623258a6c720719 = $(`&lt;div id=&quot;html_e146e74775b320b42623258a6c720719&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9a88c2b3040b5f95a8da2b1d202377ef.setContent(html_e146e74775b320b42623258a6c720719);
#
#
#
#         marker_c517a11987ab6f701be235101e70aa6d.bindPopup(popup_9a88c2b3040b5f95a8da2b1d202377ef)
#         ;
#
#
#
#
#             var marker_369c743116476b9ee86938235c1d54f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dabec736d0418c890856be86c6f4a66d);
#
#
#         var popup_7784e8e93c07725ab24493647d9969c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3424de6331fe81f0c7b33f9b477ed1b0 = $(`&lt;div id=&quot;html_3424de6331fe81f0c7b33f9b477ed1b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7784e8e93c07725ab24493647d9969c3.setContent(html_3424de6331fe81f0c7b33f9b477ed1b0);
#
#
#
#         marker_369c743116476b9ee86938235c1d54f8.bindPopup(popup_7784e8e93c07725ab24493647d9969c3)
#         ;
#
#
#
#
#             var marker_f734611e099f9258f00652897c2104be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dabec736d0418c890856be86c6f4a66d);
#
#
#         var popup_5a5c3ae39fec6f921f5113026b2442e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb27a2527548f8c88a1cf2140e338a17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb27a2527548f8c88a1cf2140e338a17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb27a2527548f8c88a1cf2140e338a17 = L.map(
#                 &quot;map_fb27a2527548f8c88a1cf2140e338a17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2de80602cf796608666a463bb7e687f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2de80602cf796608666a463bb7e687f.addTo(map_fb27a2527548f8c88a1cf2140e338a17);
#
#
#             var feature_group_01e6c99cab8fa085d11a01989cf2fc38 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_01e6c99cab8fa085d11a01989cf2fc38.addTo(map_fb27a2527548f8c88a1cf2140e338a17);
#
#
#             var feature_group_sub_group_2005090cd6fc060c757f03c0f284e539 = L.featureGroup.subGroup(
#                 feature_group_01e6c99cab8fa085d11a01989cf2fc38
#             );
#
#
#             var marker_70045a30e2038293702e30a74e7bf075 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2005090cd6fc060c757f03c0f284e539);
#
#
#         var popup_f5695d68ff499ae8879bce5528c125e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a102d2994c70c0863f90865bff4022ed = $(`&lt;div id=&quot;html_a102d2994c70c0863f90865bff4022ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f5695d68ff499ae8879bce5528c125e5.setContent(html_a102d2994c70c0863f90865bff4022ed);
#
#
#
#         marker_70045a30e2038293702e30a74e7bf075.bindPopup(popup_f5695d68ff499ae8879bce5528c125e5)
#         ;
#
#
#
#
#             var marker_e1f034692a5494694a311c55b55d87b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2005090cd6fc060c757f03c0f284e539);
#
#
#         var popup_6dc40162f4c7a6e4160cd2ac667a7edd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee065d38ba0c11ab7fd685816b6d691 = $(`&lt;div id=&quot;html_cee065d38ba0c11ab7fd685816b6d691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6dc40162f4c7a6e4160cd2ac667a7edd.setContent(html_cee065d38ba0c11ab7fd685816b6d691);
#
#
#
#         marker_e1f034692a5494694a311c55b55d87b4.bindPopup(popup_6dc40162f4c7a6e4160cd2ac667a7edd)
#         ;
#
#
#
#
#             var marker_aefa6b8681c1dbe61f122aecc5e757a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2005090cd6fc060c757f03c0f284e539);
#
#
#         var popup_3fc752e49618adb826dccfc5edd6557e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_172ba4724782b9d15153fac702307a09 = $(`&lt;div id=&quot;html_172ba4724782b9d15153fac702307a09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3fc752e49618adb826dccfc5edd6557e.setContent(html_172ba4724782b9d15153fac702307a09);
#
#
#
#         marker_aefa6b8681c1dbe61f122aecc5e757a2.bindPopup(popup_3fc752e49618adb826dccfc5edd6557e)
#         ;
#
#
#
#
#             var marker_865c9cc1b1d180df84efab991d5f149f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2005090cd6fc060c757f03c0f284e539);
#
#
#         var popup_b3ba27d503e4019789de266b3a64cdbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1cf9d13971e29800f0f72f9229da948 = $(`&lt;div id=&quot;html_d1cf9d13971e29800f0f72f9229da948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b3ba27d503e4019789de266b3a64cdbe.setContent(html_d1cf9d13971e29800f0f72f9229da948);
#
#
#
#         marker_
