# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd8ca64dee761e7ffc6f524162facdc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd8ca64dee761e7ffc6f524162facdc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd8ca64dee761e7ffc6f524162facdc7 = L.map(
#                 &quot;map_fd8ca64dee761e7ffc6f524162facdc7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61b93651127c2d90cca020cf55d0cc93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61b93651127c2d90cca020cf55d0cc93.addTo(map_fd8ca64dee761e7ffc6f524162facdc7);
#
#
#             var marker_873eb3ae2be4f070f95683ee80227c42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fd8ca64dee761e7ffc6f524162facdc7);
#
#
#         var popup_ae6d4c9ce6d4a31ef1e83daa60b78843 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d15edfa7e5f8c8b737a511d74272f1b = $(`&lt;div id=&quot;html_3d15edfa7e5f8c8b737a511d74272f1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ae6d4c9ce6d4a31ef1e83daa60b78843.setContent(html_3d15edfa7e5f8c8b737a511d74272f1b);
#
#
#
#         marker_873eb3ae2be4f070f95683ee80227c42.bindPopup(popup_ae6d4c9ce6d4a31ef1e83daa60b78843)
#         ;
#
#
#
#
#             var marker_7fb7576faa0e42c5b1b509abc09c1284 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fd8ca64dee761e7ffc6f524162facdc7);
#
#
#         var popup_83fc6dc4948d7aeca739ee0c72ad378d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0b3489aee0a489d5091e97bf7d1296f = $(`&lt;div id=&quot;html_c0b3489aee0a489d5091e97bf7d1296f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_83fc6dc4948d7aeca739ee0c72ad378d.setContent(html_c0b3489aee0a489d5091e97bf7d1296f);
#
#
#
#         marker_7fb7576faa0e42c5b1b509abc09c1284.bindPopup(popup_83fc6dc4948d7aeca739ee0c72ad378d)
#         ;
#
#
#
#
#             var marker_ce17f799c9ddb8164a03d1876a040ed0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fd8ca64dee761e7ffc6f524162facdc7);
#
#
#         var popup_05bd0d0ef126e0623e96b18782d477ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a29d36337fd7084c8bf1c93700901a3 = $(`&lt;div id=&quot;html_5a29d36337fd7084c8bf1c93700901a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_05bd0d0ef126e0623e96b18782d477ee.setContent(html_5a29d36337fd7084c8bf1c93700901a3);
#
#
#
#         marker_ce17f799c9ddb8164a03d1876a040ed0.bindPopup(popup_05bd0d0ef126e0623e96b18782d477ee)
#         ;
#
#
#
#
#             var marker_458d35aed6da60d1ec1f42deb7179540 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fd8ca64dee761e7ffc6f524162facdc7);
#
#
#         var popup_1753bfab3ad61eefccad7f64280631ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_297686f196eddcaf77f8120214f0ca9c = $(`&lt;div id=&quot;html_297686f196eddcaf77f8120214f0ca9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1753bfab3ad61eefccad7f64280631ad.setContent(html_297686f196eddcaf77f8120214f0ca9c);
#
#
#
#         marker_458d35aed6da60d1ec1f42deb7179540.bindPopup(popup_1753bfab3ad61eefccad7f64280631ad)
#         ;
#
#
#
#
#             var marker_1c5d3a9bf27dc5aecb11f699135ae9f6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fd8ca64dee761e7ffc6f524162facdc7);
#
#
#         var popup_dcce448445d1b2bd0933549b035491d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4de479dba18e33f9fe2fdb6f45db56d5 = $(`&lt;div id=&quot;html_4de479dba18e33f9fe2fdb6f45db56d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dcce448445d1b2bd0933549b035491d7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_511607217c46a322137a12101e4f5af5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_511607217c46a322137a12101e4f5af5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_511607217c46a322137a12101e4f5af5 = L.map(
#                 &quot;map_511607217c46a322137a12101e4f5af5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_610dcef15e95fa25ffd418d2f5ebeed2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_610dcef15e95fa25ffd418d2f5ebeed2.addTo(map_511607217c46a322137a12101e4f5af5);
#
#
#             var feature_group_b3b9c4cab6c0feaafc04ae27a6ff8955 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_db3f5eee00dd1cf3bca0ed93cdd329c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b3b9c4cab6c0feaafc04ae27a6ff8955);
#
#
#         var popup_1529a4104ffe419f3d697728aeaf97fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ed7f5e26ba3b4e5a21e5dbd0d2e09f9 = $(`&lt;div id=&quot;html_7ed7f5e26ba3b4e5a21e5dbd0d2e09f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1529a4104ffe419f3d697728aeaf97fc.setContent(html_7ed7f5e26ba3b4e5a21e5dbd0d2e09f9);
#
#
#
#         marker_db3f5eee00dd1cf3bca0ed93cdd329c7.bindPopup(popup_1529a4104ffe419f3d697728aeaf97fc)
#         ;
#
#
#
#
#             var marker_86cc86efb60bd9056a091ba355c356bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b3b9c4cab6c0feaafc04ae27a6ff8955);
#
#
#         var popup_aa3ea3de62948c8653faa2b298551e6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2721696d5848eaf6bcbe46312ccdf811 = $(`&lt;div id=&quot;html_2721696d5848eaf6bcbe46312ccdf811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_aa3ea3de62948c8653faa2b298551e6c.setContent(html_2721696d5848eaf6bcbe46312ccdf811);
#
#
#
#         marker_86cc86efb60bd9056a091ba355c356bb.bindPopup(popup_aa3ea3de62948c8653faa2b298551e6c)
#         ;
#
#
#
#
#             var marker_b10c2bc30475098609673874dd164e50 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b3b9c4cab6c0feaafc04ae27a6ff8955);
#
#
#         var popup_2b4090571341a9b4d06bd2548f94eb8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22bbba7536263113ac022ac471d76882 = $(`&lt;div id=&quot;html_22bbba7536263113ac022ac471d76882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2b4090571341a9b4d06bd2548f94eb8e.setContent(html_22bbba7536263113ac022ac471d76882);
#
#
#
#         marker_b10c2bc30475098609673874dd164e50.bindPopup(popup_2b4090571341a9b4d06bd2548f94eb8e)
#         ;
#
#
#
#
#             var marker_1fb1ff0356fa39a43c72f73b02b4accb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b3b9c4cab6c0feaafc04ae27a6ff8955);
#
#
#         var popup_03ae126765f1f78dc8cd6401c282f018 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48417c1b7e8e9ebfe2dbce79019bf977 = $(`&lt;div id=&quot;html_48417c1b7e8e9ebfe2dbce79019bf977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_03ae126765f1f78dc8cd6401c282f018.setContent(html_48417c1b7e8e9ebfe2dbce79019bf977);
#
#
#
#         marker_1fb1ff0356fa39a43c72f73b02b4accb.bindPopup(popup_03ae126765f1f78dc8cd6401c282f018)
#         ;
#
#
#
#
#             var marker_c8a6da137ac2753ccf71dc6a2009483e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b3b9c4cab6c0feaafc04ae27a6ff8955);
#
#
#         var popup_2deba3fa6697a20062d71f9da64b66a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba2712419a7df8e5946fa39d7fb48d30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba2712419a7df8e5946fa39d7fb48d30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba2712419a7df8e5946fa39d7fb48d30 = L.map(
#                 &quot;map_ba2712419a7df8e5946fa39d7fb48d30&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67f11843d561d6dab97cea7f4d2f655f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67f11843d561d6dab97cea7f4d2f655f.addTo(map_ba2712419a7df8e5946fa39d7fb48d30);
#
#
#             var feature_group_533608375b87a6cd51acda436056eb9a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_533608375b87a6cd51acda436056eb9a.addTo(map_ba2712419a7df8e5946fa39d7fb48d30);
#
#
#             var feature_group_sub_group_fff611c4e1848bc832493c7cfbcf4ee7 = L.featureGroup.subGroup(
#                 feature_group_533608375b87a6cd51acda436056eb9a
#             );
#
#
#             var marker_73e5fa5343581e653dc339ddef1a2a2e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fff611c4e1848bc832493c7cfbcf4ee7);
#
#
#         var popup_7a8c3a54ee45b67d3ab805c379ba103a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3249d6fd5cd9c2f976db2af31bddb5f = $(`&lt;div id=&quot;html_a3249d6fd5cd9c2f976db2af31bddb5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7a8c3a54ee45b67d3ab805c379ba103a.setContent(html_a3249d6fd5cd9c2f976db2af31bddb5f);
#
#
#
#         marker_73e5fa5343581e653dc339ddef1a2a2e.bindPopup(popup_7a8c3a54ee45b67d3ab805c379ba103a)
#         ;
#
#
#
#
#             var marker_5f4f5943b35c63d5adb5c29bfa56a332 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fff611c4e1848bc832493c7cfbcf4ee7);
#
#
#         var popup_2a84a67654178ab0e6ec0b39ffd4c3e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a5456f776de50cff3857298081ec454 = $(`&lt;div id=&quot;html_0a5456f776de50cff3857298081ec454&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2a84a67654178ab0e6ec0b39ffd4c3e4.setContent(html_0a5456f776de50cff3857298081ec454);
#
#
#
#         marker_5f4f5943b35c63d5adb5c29bfa56a332.bindPopup(popup_2a84a67654178ab0e6ec0b39ffd4c3e4)
#         ;
#
#
#
#
#             var marker_e3f599a08372f356c0ecf619d48873a5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fff611c4e1848bc832493c7cfbcf4ee7);
#
#
#         var popup_066a17b7f7cd161195a8c1ad4143bf02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36d35ef798dc2e4cfb250604f3b3a65f = $(`&lt;div id=&quot;html_36d35ef798dc2e4cfb250604f3b3a65f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_066a17b7f7cd161195a8c1ad4143bf02.setContent(html_36d35ef798dc2e4cfb250604f3b3a65f);
#
#
#
#         marker_e3f599a08372f356c0ecf619d48873a5.bindPopup(popup_066a17b7f7cd161195a8c1ad4143bf02)
#         ;
#
#
#
#
#             var marker_a21d988f62cb0fd40f00ceefb04474ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fff611c4e1848bc832493c7cfbcf4ee7);
#
#
#         var popup_c60953752d4caeb56d8cac83ebd84064 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8c848980c4d5111b3b333a0af731d5c = $(`&lt;div id=&quot;html_c8c848980c4d5111b3b333a0af731d5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c60953752d4caeb56d8cac83ebd84064.setContent(html_c8c848980c4d5111b3b333a0af731d5c);
#
#
#
#         marker_
