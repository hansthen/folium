# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d86a4f3a9bf26c673c790be167a9b928 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d86a4f3a9bf26c673c790be167a9b928&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d86a4f3a9bf26c673c790be167a9b928 = L.map(
#                 &quot;map_d86a4f3a9bf26c673c790be167a9b928&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce9eefe979fcec4cc14a594eb7db1bab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce9eefe979fcec4cc14a594eb7db1bab.addTo(map_d86a4f3a9bf26c673c790be167a9b928);
#
#
#             var marker_e1b009389dd8d9b1cd7b9f554275675e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d86a4f3a9bf26c673c790be167a9b928);
#
#
#         var popup_c52538c5a24595a11460f8a6d26ae0a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00700d902289b80db2f18e6c3fc13c53 = $(`&lt;div id=&quot;html_00700d902289b80db2f18e6c3fc13c53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c52538c5a24595a11460f8a6d26ae0a7.setContent(html_00700d902289b80db2f18e6c3fc13c53);
#
#
#
#         marker_e1b009389dd8d9b1cd7b9f554275675e.bindPopup(popup_c52538c5a24595a11460f8a6d26ae0a7)
#         ;
#
#
#
#
#             var marker_cebe8728b05296d45adff5025c486ac4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d86a4f3a9bf26c673c790be167a9b928);
#
#
#         var popup_eedafc09dd214bab99e5d237f8c69976 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6fee0822b385bd1ce4bc3a7ae6758c7 = $(`&lt;div id=&quot;html_c6fee0822b385bd1ce4bc3a7ae6758c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eedafc09dd214bab99e5d237f8c69976.setContent(html_c6fee0822b385bd1ce4bc3a7ae6758c7);
#
#
#
#         marker_cebe8728b05296d45adff5025c486ac4.bindPopup(popup_eedafc09dd214bab99e5d237f8c69976)
#         ;
#
#
#
#
#             var marker_81537895d0208fbbce26e78baa183a86 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d86a4f3a9bf26c673c790be167a9b928);
#
#
#         var popup_d06f84add90e35f9078e86017f47caa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c4462f7005120a6089c4236f2cbc04f = $(`&lt;div id=&quot;html_8c4462f7005120a6089c4236f2cbc04f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d06f84add90e35f9078e86017f47caa3.setContent(html_8c4462f7005120a6089c4236f2cbc04f);
#
#
#
#         marker_81537895d0208fbbce26e78baa183a86.bindPopup(popup_d06f84add90e35f9078e86017f47caa3)
#         ;
#
#
#
#
#             var marker_e7970df45e57e2bcf3b7a1ea67a69e21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d86a4f3a9bf26c673c790be167a9b928);
#
#
#         var popup_cdf8534d89fa9ae1b493c7994f1150df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee17bc95c718702091f30e5971ef3cb = $(`&lt;div id=&quot;html_cee17bc95c718702091f30e5971ef3cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cdf8534d89fa9ae1b493c7994f1150df.setContent(html_cee17bc95c718702091f30e5971ef3cb);
#
#
#
#         marker_e7970df45e57e2bcf3b7a1ea67a69e21.bindPopup(popup_cdf8534d89fa9ae1b493c7994f1150df)
#         ;
#
#
#
#
#             var marker_a00053330573fff5dcd8d83c8724f4eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d86a4f3a9bf26c673c790be167a9b928);
#
#
#         var popup_c1863cf0ce3b12c223153666c0538c10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e3a0f8afb204e6e4129e89d1d7df814 = $(`&lt;div id=&quot;html_4e3a0f8afb204e6e4129e89d1d7df814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c1863cf0ce3b12c223153666c0538c10.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9674a3997bbb9cb64cc339de6435ca90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9674a3997bbb9cb64cc339de6435ca90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9674a3997bbb9cb64cc339de6435ca90 = L.map(
#                 &quot;map_9674a3997bbb9cb64cc339de6435ca90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c20860755a27d7872d52a45b1cc1eb54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c20860755a27d7872d52a45b1cc1eb54.addTo(map_9674a3997bbb9cb64cc339de6435ca90);
#
#
#             var feature_group_0063276e9452d895dfb90ce1895b223d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a4774f04ee0f89679c9ed8ea0da3c0a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0063276e9452d895dfb90ce1895b223d);
#
#
#         var popup_6ab6169c99722b3d5ba6ca2c66adeee2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c58434b3956dfde01f6af0c5da7774fa = $(`&lt;div id=&quot;html_c58434b3956dfde01f6af0c5da7774fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6ab6169c99722b3d5ba6ca2c66adeee2.setContent(html_c58434b3956dfde01f6af0c5da7774fa);
#
#
#
#         marker_0a4774f04ee0f89679c9ed8ea0da3c0a.bindPopup(popup_6ab6169c99722b3d5ba6ca2c66adeee2)
#         ;
#
#
#
#
#             var marker_691ccc96442dea91ac26c8be7472c1bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0063276e9452d895dfb90ce1895b223d);
#
#
#         var popup_7bd97f9ef429b334f1c77dc5f3c2f554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28d50f1975c3d0bd373ab9e885caa5d7 = $(`&lt;div id=&quot;html_28d50f1975c3d0bd373ab9e885caa5d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7bd97f9ef429b334f1c77dc5f3c2f554.setContent(html_28d50f1975c3d0bd373ab9e885caa5d7);
#
#
#
#         marker_691ccc96442dea91ac26c8be7472c1bc.bindPopup(popup_7bd97f9ef429b334f1c77dc5f3c2f554)
#         ;
#
#
#
#
#             var marker_fb5cbca920432b091ae023a9c3a6e65a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0063276e9452d895dfb90ce1895b223d);
#
#
#         var popup_1661e072db890885eb15f7bbbb391d0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_989c123ea7417ea6b71907029da20a49 = $(`&lt;div id=&quot;html_989c123ea7417ea6b71907029da20a49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1661e072db890885eb15f7bbbb391d0f.setContent(html_989c123ea7417ea6b71907029da20a49);
#
#
#
#         marker_fb5cbca920432b091ae023a9c3a6e65a.bindPopup(popup_1661e072db890885eb15f7bbbb391d0f)
#         ;
#
#
#
#
#             var marker_f6b068c01e65c09374bbe3ede1be8889 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0063276e9452d895dfb90ce1895b223d);
#
#
#         var popup_ff18afc38ebf2d3916c9fc5b46094a59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03ca6eec618b6162e2265efade3f33fc = $(`&lt;div id=&quot;html_03ca6eec618b6162e2265efade3f33fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ff18afc38ebf2d3916c9fc5b46094a59.setContent(html_03ca6eec618b6162e2265efade3f33fc);
#
#
#
#         marker_f6b068c01e65c09374bbe3ede1be8889.bindPopup(popup_ff18afc38ebf2d3916c9fc5b46094a59)
#         ;
#
#
#
#
#             var marker_12e296a4df70f3be3c9ef34eead0724f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0063276e9452d895dfb90ce1895b223d);
#
#
#         var popup_df670e7eb62c288959203f68272ebf2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43a57576367523a461d938587d3b84fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43a57576367523a461d938587d3b84fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43a57576367523a461d938587d3b84fb = L.map(
#                 &quot;map_43a57576367523a461d938587d3b84fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8963515582b416e23cda3865da29e0a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8963515582b416e23cda3865da29e0a0.addTo(map_43a57576367523a461d938587d3b84fb);
#
#
#             var feature_group_f8231e5db43b3dbdb83bc30be9072b69 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f8231e5db43b3dbdb83bc30be9072b69.addTo(map_43a57576367523a461d938587d3b84fb);
#
#
#             var feature_group_sub_group_3e0fa021cec7ca2dabe87cfcc9921038 = L.featureGroup.subGroup(
#                 feature_group_f8231e5db43b3dbdb83bc30be9072b69
#             );
#
#
#             var marker_047d95ef8c4493a8644a4d99ce780de9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e0fa021cec7ca2dabe87cfcc9921038);
#
#
#         var popup_665e1a77dc8dc82f096be47e5d82f848 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a15ba898381e55bc91d6fa27a819146 = $(`&lt;div id=&quot;html_8a15ba898381e55bc91d6fa27a819146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_665e1a77dc8dc82f096be47e5d82f848.setContent(html_8a15ba898381e55bc91d6fa27a819146);
#
#
#
#         marker_047d95ef8c4493a8644a4d99ce780de9.bindPopup(popup_665e1a77dc8dc82f096be47e5d82f848)
#         ;
#
#
#
#
#             var marker_1cb5a2c65e2699ad0923d964fd38837f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e0fa021cec7ca2dabe87cfcc9921038);
#
#
#         var popup_cc78de36b2200441e1cab342ea7a24d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b507ef9010cec33a2f4fbeeadbd0108c = $(`&lt;div id=&quot;html_b507ef9010cec33a2f4fbeeadbd0108c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cc78de36b2200441e1cab342ea7a24d8.setContent(html_b507ef9010cec33a2f4fbeeadbd0108c);
#
#
#
#         marker_1cb5a2c65e2699ad0923d964fd38837f.bindPopup(popup_cc78de36b2200441e1cab342ea7a24d8)
#         ;
#
#
#
#
#             var marker_45a28a861131787dc5ef2599e0560644 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e0fa021cec7ca2dabe87cfcc9921038);
#
#
#         var popup_b0c982d38b93be752cbd6b9f0426e6d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff8bf3a0b78d7874424fc80930557fbb = $(`&lt;div id=&quot;html_ff8bf3a0b78d7874424fc80930557fbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b0c982d38b93be752cbd6b9f0426e6d5.setContent(html_ff8bf3a0b78d7874424fc80930557fbb);
#
#
#
#         marker_45a28a861131787dc5ef2599e0560644.bindPopup(popup_b0c982d38b93be752cbd6b9f0426e6d5)
#         ;
#
#
#
#
#             var marker_af54498ab4dc8c981f36ea47589f5961 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e0fa021cec7ca2dabe87cfcc9921038);
#
#
#         var popup_29761f30be56ec07c947885a747f8124 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2408f9ee93d0bd6f1bf34794fba4babc = $(`&lt;div id=&quot;html_2408f9ee93d0bd6f1bf34794fba4babc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_29761f30be56ec07c947885a747f8124.setContent(html_2408f9ee93d0bd6f1bf34794fba4babc);
#
#
#
#         marker_
