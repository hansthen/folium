# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_914813c5965fc4be8834c081b6dad06a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_914813c5965fc4be8834c081b6dad06a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_914813c5965fc4be8834c081b6dad06a = L.map(
#                 &quot;map_914813c5965fc4be8834c081b6dad06a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94728b6d843a83ca6e7534dfb7dc4c4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94728b6d843a83ca6e7534dfb7dc4c4b.addTo(map_914813c5965fc4be8834c081b6dad06a);
#
#
#             var marker_3416d59d1baccda19da3b7f271651876 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_914813c5965fc4be8834c081b6dad06a);
#
#
#         var popup_00a7207a461944b7fc84673944570afd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c83e193fa3cadb3e8e894be735ed37e = $(`&lt;div id=&quot;html_4c83e193fa3cadb3e8e894be735ed37e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_00a7207a461944b7fc84673944570afd.setContent(html_4c83e193fa3cadb3e8e894be735ed37e);
#
#
#
#         marker_3416d59d1baccda19da3b7f271651876.bindPopup(popup_00a7207a461944b7fc84673944570afd)
#         ;
#
#
#
#
#             var marker_1b48a1c1ad3f1083ded23b638d5c3372 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_914813c5965fc4be8834c081b6dad06a);
#
#
#         var popup_56ea9858d1b0b312867b965302667cc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b8ae1349b7b911945754566a883f8a0 = $(`&lt;div id=&quot;html_9b8ae1349b7b911945754566a883f8a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_56ea9858d1b0b312867b965302667cc7.setContent(html_9b8ae1349b7b911945754566a883f8a0);
#
#
#
#         marker_1b48a1c1ad3f1083ded23b638d5c3372.bindPopup(popup_56ea9858d1b0b312867b965302667cc7)
#         ;
#
#
#
#
#             var marker_4bc684852aba8ebba808ea6ffffc3900 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_914813c5965fc4be8834c081b6dad06a);
#
#
#         var popup_d5d9b379b4a1999f30c5aa06b06153ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986905bd7fee5d4d3f0c02302c6dd577 = $(`&lt;div id=&quot;html_986905bd7fee5d4d3f0c02302c6dd577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d5d9b379b4a1999f30c5aa06b06153ea.setContent(html_986905bd7fee5d4d3f0c02302c6dd577);
#
#
#
#         marker_4bc684852aba8ebba808ea6ffffc3900.bindPopup(popup_d5d9b379b4a1999f30c5aa06b06153ea)
#         ;
#
#
#
#
#             var marker_88281d9396e4d94916c1c59a561a5613 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_914813c5965fc4be8834c081b6dad06a);
#
#
#         var popup_7c8d265d6743c65c04e072c571e7321f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_769aad5932cc73ca5f9d52a79ef5ce7a = $(`&lt;div id=&quot;html_769aad5932cc73ca5f9d52a79ef5ce7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7c8d265d6743c65c04e072c571e7321f.setContent(html_769aad5932cc73ca5f9d52a79ef5ce7a);
#
#
#
#         marker_88281d9396e4d94916c1c59a561a5613.bindPopup(popup_7c8d265d6743c65c04e072c571e7321f)
#         ;
#
#
#
#
#             var marker_fe04939de33478ff4be27b34e120fb05 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_914813c5965fc4be8834c081b6dad06a);
#
#
#         var popup_38560a4ec782140e486dd228a34e3699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba704662aa83028fcf7e2a65658b91d8 = $(`&lt;div id=&quot;html_ba704662aa83028fcf7e2a65658b91d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_38560a4ec782140e486dd228a34e3699.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f2ac7580dd4f13f13b121e1a992243b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f2ac7580dd4f13f13b121e1a992243b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f2ac7580dd4f13f13b121e1a992243b = L.map(
#                 &quot;map_3f2ac7580dd4f13f13b121e1a992243b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70a7ce8282faa31b5ba2e56bfd0fafb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70a7ce8282faa31b5ba2e56bfd0fafb1.addTo(map_3f2ac7580dd4f13f13b121e1a992243b);
#
#
#             var feature_group_f041277503b009ab8228d654915be371 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fafe75abd9fb4155999d82d6e174b03b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f041277503b009ab8228d654915be371);
#
#
#         var popup_60b09d6fbe66f39b41c40228aa30658a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c98ce9093a5d0249aeea35b685eb7102 = $(`&lt;div id=&quot;html_c98ce9093a5d0249aeea35b685eb7102&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_60b09d6fbe66f39b41c40228aa30658a.setContent(html_c98ce9093a5d0249aeea35b685eb7102);
#
#
#
#         marker_fafe75abd9fb4155999d82d6e174b03b.bindPopup(popup_60b09d6fbe66f39b41c40228aa30658a)
#         ;
#
#
#
#
#             var marker_c0f4679b93262be55df7aa2fc6ff8e42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f041277503b009ab8228d654915be371);
#
#
#         var popup_b21aea38bc7c695d42994961c694304b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea8762dae1b96efd32f1d0869edf426 = $(`&lt;div id=&quot;html_bea8762dae1b96efd32f1d0869edf426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b21aea38bc7c695d42994961c694304b.setContent(html_bea8762dae1b96efd32f1d0869edf426);
#
#
#
#         marker_c0f4679b93262be55df7aa2fc6ff8e42.bindPopup(popup_b21aea38bc7c695d42994961c694304b)
#         ;
#
#
#
#
#             var marker_eb9e45e2757e27109cf69ea8288f43da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f041277503b009ab8228d654915be371);
#
#
#         var popup_531501a1afc2b182df66ef20818975c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f7b8cb85950492c8ca0e41949720e92 = $(`&lt;div id=&quot;html_3f7b8cb85950492c8ca0e41949720e92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_531501a1afc2b182df66ef20818975c5.setContent(html_3f7b8cb85950492c8ca0e41949720e92);
#
#
#
#         marker_eb9e45e2757e27109cf69ea8288f43da.bindPopup(popup_531501a1afc2b182df66ef20818975c5)
#         ;
#
#
#
#
#             var marker_3adcfd23a74fbce9ba2639cd466f9a5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f041277503b009ab8228d654915be371);
#
#
#         var popup_302c6ce45f217b42dc41cdc7652a1c66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f028d907500044cd662ffde0bcde065 = $(`&lt;div id=&quot;html_2f028d907500044cd662ffde0bcde065&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_302c6ce45f217b42dc41cdc7652a1c66.setContent(html_2f028d907500044cd662ffde0bcde065);
#
#
#
#         marker_3adcfd23a74fbce9ba2639cd466f9a5e.bindPopup(popup_302c6ce45f217b42dc41cdc7652a1c66)
#         ;
#
#
#
#
#             var marker_f022049ad39e1fc3735dd1e5424bc523 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f041277503b009ab8228d654915be371);
#
#
#         var popup_dc93a763a388a0a0474b2e9f0be898bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26788c29f9da842bb2bf1b68163e1652 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26788c29f9da842bb2bf1b68163e1652&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26788c29f9da842bb2bf1b68163e1652 = L.map(
#                 &quot;map_26788c29f9da842bb2bf1b68163e1652&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb9e9c9fa944b122f71ce4b23a68d325 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb9e9c9fa944b122f71ce4b23a68d325.addTo(map_26788c29f9da842bb2bf1b68163e1652);
#
#
#             var feature_group_cca716825eb5e5229c9a4328c83e4870 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cca716825eb5e5229c9a4328c83e4870.addTo(map_26788c29f9da842bb2bf1b68163e1652);
#
#
#             var feature_group_sub_group_c2223b720d159b0b3462be17e2182246 = L.featureGroup.subGroup(
#                 feature_group_cca716825eb5e5229c9a4328c83e4870
#             );
#
#
#             var marker_d8a98687145f5082ac6ffb0d456eac8c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2223b720d159b0b3462be17e2182246);
#
#
#         var popup_3b24e29450812f83781b1556aacc0da5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33d1c2bd05006614058d7cfe73400155 = $(`&lt;div id=&quot;html_33d1c2bd05006614058d7cfe73400155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3b24e29450812f83781b1556aacc0da5.setContent(html_33d1c2bd05006614058d7cfe73400155);
#
#
#
#         marker_d8a98687145f5082ac6ffb0d456eac8c.bindPopup(popup_3b24e29450812f83781b1556aacc0da5)
#         ;
#
#
#
#
#             var marker_eb8f5504274f3696989fe37b4aab87ef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2223b720d159b0b3462be17e2182246);
#
#
#         var popup_6f8e50d8e3d17d102a0d7e2b11ed6932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1beb663969b5b37707ccdf0a570c7dd = $(`&lt;div id=&quot;html_e1beb663969b5b37707ccdf0a570c7dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6f8e50d8e3d17d102a0d7e2b11ed6932.setContent(html_e1beb663969b5b37707ccdf0a570c7dd);
#
#
#
#         marker_eb8f5504274f3696989fe37b4aab87ef.bindPopup(popup_6f8e50d8e3d17d102a0d7e2b11ed6932)
#         ;
#
#
#
#
#             var marker_663d18ef70e04dbb928ddbb0649d678c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2223b720d159b0b3462be17e2182246);
#
#
#         var popup_3d012755083205598c4c97f721f52e55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d945e6de16f38d3ef07ae826dd32405 = $(`&lt;div id=&quot;html_1d945e6de16f38d3ef07ae826dd32405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3d012755083205598c4c97f721f52e55.setContent(html_1d945e6de16f38d3ef07ae826dd32405);
#
#
#
#         marker_663d18ef70e04dbb928ddbb0649d678c.bindPopup(popup_3d012755083205598c4c97f721f52e55)
#         ;
#
#
#
#
#             var marker_2775fd7cd5e2c9e46ce0461f078fee55 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2223b720d159b0b3462be17e2182246);
#
#
#         var popup_265d432740e7c14a446730dfba088127 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccbab0683fe49c26c53845045652a19c = $(`&lt;div id=&quot;html_ccbab0683fe49c26c53845045652a19c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_265d432740e7c14a446730dfba088127.setContent(html_ccbab0683fe49c26c53845045652a19c);
#
#
#
#         marker_
