# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76c64536d8460e5d70caa8e94deb44e8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76c64536d8460e5d70caa8e94deb44e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76c64536d8460e5d70caa8e94deb44e8 = L.map(
#                 &quot;map_76c64536d8460e5d70caa8e94deb44e8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c2dbd7040795c60b827ba37311bd930 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c2dbd7040795c60b827ba37311bd930.addTo(map_76c64536d8460e5d70caa8e94deb44e8);
#
#
#             var marker_0b74e89d4b1923121ff9fd3d2b48291b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_76c64536d8460e5d70caa8e94deb44e8);
#
#
#         var popup_a26691a782bd9eb1cb3fc26595529fbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7861a65a533eccb13085aa4f6ba38b53 = $(`&lt;div id=&quot;html_7861a65a533eccb13085aa4f6ba38b53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a26691a782bd9eb1cb3fc26595529fbd.setContent(html_7861a65a533eccb13085aa4f6ba38b53);
#
#
#
#         marker_0b74e89d4b1923121ff9fd3d2b48291b.bindPopup(popup_a26691a782bd9eb1cb3fc26595529fbd)
#         ;
#
#
#
#
#             var marker_335f1dcde0774da5d97ba7a308213eec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_76c64536d8460e5d70caa8e94deb44e8);
#
#
#         var popup_1889aef924ba7e369edae1b349ccc9c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb4c692ceb4f486c1eb2ec77db3c17a0 = $(`&lt;div id=&quot;html_cb4c692ceb4f486c1eb2ec77db3c17a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1889aef924ba7e369edae1b349ccc9c5.setContent(html_cb4c692ceb4f486c1eb2ec77db3c17a0);
#
#
#
#         marker_335f1dcde0774da5d97ba7a308213eec.bindPopup(popup_1889aef924ba7e369edae1b349ccc9c5)
#         ;
#
#
#
#
#             var marker_fb0b30820970e74cbecf18b319b7d14e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_76c64536d8460e5d70caa8e94deb44e8);
#
#
#         var popup_f24b2823b673dc2cc8d7289a3710cc6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f90ccc043cd6dc4954946ed981dd311 = $(`&lt;div id=&quot;html_2f90ccc043cd6dc4954946ed981dd311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f24b2823b673dc2cc8d7289a3710cc6a.setContent(html_2f90ccc043cd6dc4954946ed981dd311);
#
#
#
#         marker_fb0b30820970e74cbecf18b319b7d14e.bindPopup(popup_f24b2823b673dc2cc8d7289a3710cc6a)
#         ;
#
#
#
#
#             var marker_2756bb50822cad97fa54c87229e94461 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_76c64536d8460e5d70caa8e94deb44e8);
#
#
#         var popup_002f91fd6cb928da5bae2192d81ef903 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ebe9a9d76ebd3a33b6ecf975c019a66 = $(`&lt;div id=&quot;html_7ebe9a9d76ebd3a33b6ecf975c019a66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_002f91fd6cb928da5bae2192d81ef903.setContent(html_7ebe9a9d76ebd3a33b6ecf975c019a66);
#
#
#
#         marker_2756bb50822cad97fa54c87229e94461.bindPopup(popup_002f91fd6cb928da5bae2192d81ef903)
#         ;
#
#
#
#
#             var marker_f9f85975bd2f33c0d44e5e9cacc21dd3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_76c64536d8460e5d70caa8e94deb44e8);
#
#
#         var popup_3ebab9f1b1b4e9cc05d48e55a4228f02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_230a1744d854efc4c2d0e694af81feb5 = $(`&lt;div id=&quot;html_230a1744d854efc4c2d0e694af81feb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3ebab9f1b1b4e9cc05d48e55a4228f

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a827764a57c8182ad8db79141abb3801 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a827764a57c8182ad8db79141abb3801&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a827764a57c8182ad8db79141abb3801 = L.map(
#                 &quot;map_a827764a57c8182ad8db79141abb3801&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68ce8658d07c4cbff0291cef8a08ca43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_68ce8658d07c4cbff0291cef8a08ca43.addTo(map_a827764a57c8182ad8db79141abb3801);
#
#
#             var feature_group_ccd18b4e95f78671d038b72f4326096d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_25fa7fae779efc6effa40a1d56aa4932 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ccd18b4e95f78671d038b72f4326096d);
#
#
#         var popup_d436956a008315ef7b6302b3e753b716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e280a7ab7c8e9a3633fb23a7ed57eab = $(`&lt;div id=&quot;html_7e280a7ab7c8e9a3633fb23a7ed57eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d436956a008315ef7b6302b3e753b716.setContent(html_7e280a7ab7c8e9a3633fb23a7ed57eab);
#
#
#
#         marker_25fa7fae779efc6effa40a1d56aa4932.bindPopup(popup_d436956a008315ef7b6302b3e753b716)
#         ;
#
#
#
#
#             var marker_8974c82532bc53c7f2f5d92a1f5b60b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ccd18b4e95f78671d038b72f4326096d);
#
#
#         var popup_75ccb8d0d069549ce35b3b71e98f78a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b00b7c36a2eb374cd90b028268ef730 = $(`&lt;div id=&quot;html_8b00b7c36a2eb374cd90b028268ef730&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_75ccb8d0d069549ce35b3b71e98f78a0.setContent(html_8b00b7c36a2eb374cd90b028268ef730);
#
#
#
#         marker_8974c82532bc53c7f2f5d92a1f5b60b7.bindPopup(popup_75ccb8d0d069549ce35b3b71e98f78a0)
#         ;
#
#
#
#
#             var marker_d25a86e42a494306f0a6c40637fe6274 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ccd18b4e95f78671d038b72f4326096d);
#
#
#         var popup_ca796c7512aab9416323455c9d3a92b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a56ab6d8c02347570a16431bf8a13655 = $(`&lt;div id=&quot;html_a56ab6d8c02347570a16431bf8a13655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ca796c7512aab9416323455c9d3a92b2.setContent(html_a56ab6d8c02347570a16431bf8a13655);
#
#
#
#         marker_d25a86e42a494306f0a6c40637fe6274.bindPopup(popup_ca796c7512aab9416323455c9d3a92b2)
#         ;
#
#
#
#
#             var marker_d58745f5c67cdc03961a0fbb35df9733 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ccd18b4e95f78671d038b72f4326096d);
#
#
#         var popup_b33b5eba2cde6be1729e478b7fae3fb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c1487d7b1842646a9e72a9a0cffe5d2 = $(`&lt;div id=&quot;html_4c1487d7b1842646a9e72a9a0cffe5d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b33b5eba2cde6be1729e478b7fae3fb1.setContent(html_4c1487d7b1842646a9e72a9a0cffe5d2);
#
#
#
#         marker_d58745f5c67cdc03961a0fbb35df9733.bindPopup(popup_b33b5eba2cde6be1729e478b7fae3fb1)
#         ;
#
#
#
#
#             var marker_e1fbc531d048a1df8c9ade0c4b7f33d8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ccd18b4e95f78671d038b72f4326096d);
#
#
#         var popup_64496ab408a2f09fcffd3611b1603028 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebf6ef73ce18b86eb23f64b82b0f3095 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebf6ef73ce18b86eb23f64b82b0f3095&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebf6ef73ce18b86eb23f64b82b0f3095 = L.map(
#                 &quot;map_ebf6ef73ce18b86eb23f64b82b0f3095&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ba33cd19bdea3c90e8971901b03ae62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ba33cd19bdea3c90e8971901b03ae62.addTo(map_ebf6ef73ce18b86eb23f64b82b0f3095);
#
#
#             var feature_group_2588125c334a32aa36348ce0619047dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2588125c334a32aa36348ce0619047dc.addTo(map_ebf6ef73ce18b86eb23f64b82b0f3095);
#
#
#             var feature_group_sub_group_fa1f0234bfb062d95c4f63b47bdd606d = L.featureGroup.subGroup(
#                 feature_group_2588125c334a32aa36348ce0619047dc
#             );
#
#
#             var marker_ff372c23d6ecab5b6581ce734e76d75b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa1f0234bfb062d95c4f63b47bdd606d);
#
#
#         var popup_bb61001a6ad7a44198d4da2250fc1014 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcfbd160b9ea2f01fae958ccc2850879 = $(`&lt;div id=&quot;html_bcfbd160b9ea2f01fae958ccc2850879&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bb61001a6ad7a44198d4da2250fc1014.setContent(html_bcfbd160b9ea2f01fae958ccc2850879);
#
#
#
#         marker_ff372c23d6ecab5b6581ce734e76d75b.bindPopup(popup_bb61001a6ad7a44198d4da2250fc1014)
#         ;
#
#
#
#
#             var marker_a02542c63514f7aa25cd94ca660aa2ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa1f0234bfb062d95c4f63b47bdd606d);
#
#
#         var popup_0e7f24fbf7de2389172de1bb529b9adb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5642e1ed45512cd67f1960f96ed833e8 = $(`&lt;div id=&quot;html_5642e1ed45512cd67f1960f96ed833e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0e7f24fbf7de2389172de1bb529b9adb.setContent(html_5642e1ed45512cd67f1960f96ed833e8);
#
#
#
#         marker_a02542c63514f7aa25cd94ca660aa2ed.bindPopup(popup_0e7f24fbf7de2389172de1bb529b9adb)
#         ;
#
#
#
#
#             var marker_557c6df0d59dd7240e3bf47378757a83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa1f0234bfb062d95c4f63b47bdd606d);
#
#
#         var popup_34635cee15994e4b8b16df56a6f20af0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adb4e710848167864524f36ea8d3f4a3 = $(`&lt;div id=&quot;html_adb4e710848167864524f36ea8d3f4a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_34635cee15994e4b8b16df56a6f20af0.setContent(html_adb4e710848167864524f36ea8d3f4a3);
#
#
#
#         marker_557c6df0d59dd7240e3bf47378757a83.bindPopup(popup_34635cee15994e4b8b16df56a6f20af0)
#         ;
#
#
#
#
#             var marker_9a5fcdf86d0fed6d96c272ca8a2562dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa1f0234bfb062d95c4f63b47bdd606d);
#
#
#         var popup_1478e6dd29987efc7596284a8bf1e8c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c9e1e5d7da24a29a5c47d8908ab9cd0 = $(`&lt;div id=&quot;html_3c9e1e5d7da24a29a5c47d8908ab9cd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1478e6dd29987efc7596284a8bf1e8c5.setContent(html_3c9e1e5d7da24a29a5c47d8908ab9cd0);
#
#
#
#         mark
