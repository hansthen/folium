# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b33f3e9dfdcfc64c3c54ba61a0afc88 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b33f3e9dfdcfc64c3c54ba61a0afc88&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b33f3e9dfdcfc64c3c54ba61a0afc88 = L.map(
#                 &quot;map_1b33f3e9dfdcfc64c3c54ba61a0afc88&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15f75960dfdc590953f1b1e7c2508588 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15f75960dfdc590953f1b1e7c2508588.addTo(map_1b33f3e9dfdcfc64c3c54ba61a0afc88);
#
#
#             var marker_8047775de87e406bd6e6af6141a6771b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1b33f3e9dfdcfc64c3c54ba61a0afc88);
#
#
#         var popup_d18db3603af02afc88e75661c0b65bf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8340c4dae7fce5555d98ade1358d2d9f = $(`&lt;div id=&quot;html_8340c4dae7fce5555d98ade1358d2d9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d18db3603af02afc88e75661c0b65bf2.setContent(html_8340c4dae7fce5555d98ade1358d2d9f);
#
#
#
#         marker_8047775de87e406bd6e6af6141a6771b.bindPopup(popup_d18db3603af02afc88e75661c0b65bf2)
#         ;
#
#
#
#
#             var marker_0906636de5016da611882cc68247d34e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1b33f3e9dfdcfc64c3c54ba61a0afc88);
#
#
#         var popup_21a35597bbdf99048ce925a1d8de8461 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f98682cf2a3b4724c05e33ed181410bb = $(`&lt;div id=&quot;html_f98682cf2a3b4724c05e33ed181410bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_21a35597bbdf99048ce925a1d8de8461.setContent(html_f98682cf2a3b4724c05e33ed181410bb);
#
#
#
#         marker_0906636de5016da611882cc68247d34e.bindPopup(popup_21a35597bbdf99048ce925a1d8de8461)
#         ;
#
#
#
#
#             var marker_867deafb40a4cdd242069361f0969a8d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1b33f3e9dfdcfc64c3c54ba61a0afc88);
#
#
#         var popup_e5578ed9b48322cf83195c8f63215db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_810903d391f0e399ffdbae87bd517a2a = $(`&lt;div id=&quot;html_810903d391f0e399ffdbae87bd517a2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e5578ed9b48322cf83195c8f63215db2.setContent(html_810903d391f0e399ffdbae87bd517a2a);
#
#
#
#         marker_867deafb40a4cdd242069361f0969a8d.bindPopup(popup_e5578ed9b48322cf83195c8f63215db2)
#         ;
#
#
#
#
#             var marker_327dbd040a750b4c5dacc149b0a3e842 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1b33f3e9dfdcfc64c3c54ba61a0afc88);
#
#
#         var popup_2b2c6b0236661984aa583827320d73a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6cc46a56badf4a3ae4a45de6992d164 = $(`&lt;div id=&quot;html_b6cc46a56badf4a3ae4a45de6992d164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2b2c6b0236661984aa583827320d73a3.setContent(html_b6cc46a56badf4a3ae4a45de6992d164);
#
#
#
#         marker_327dbd040a750b4c5dacc149b0a3e842.bindPopup(popup_2b2c6b0236661984aa583827320d73a3)
#         ;
#
#
#
#
#             var marker_0743df5b0f12a35ab3a3d9586557b7b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1b33f3e9dfdcfc64c3c54ba61a0afc88);
#
#
#         var popup_0f52fa3f5d229e6fb4c62003828ba918 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4a61e3d4e0f93f772b84ae94a1bdc18 = $(`&lt;div id=&quot;html_a4a61e3d4e0f93f772b84ae94a1bdc18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0f52fa3f5d229e6fb4c62003828ba918.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58fed9cdb9fe5c6b00372791b9693b6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58fed9cdb9fe5c6b00372791b9693b6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58fed9cdb9fe5c6b00372791b9693b6e = L.map(
#                 &quot;map_58fed9cdb9fe5c6b00372791b9693b6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4103653c1f0b50345ad29e29ca94a4bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4103653c1f0b50345ad29e29ca94a4bf.addTo(map_58fed9cdb9fe5c6b00372791b9693b6e);
#
#
#             var feature_group_c4b5e6eaa8c641b70e2736cf0c12673c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b1403afae48c65e255dd7e31f178513e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c4b5e6eaa8c641b70e2736cf0c12673c);
#
#
#         var popup_a690a757ca68aa3be201f154f6f7cd43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ba2aee882c2db7559e8d7d8274de566 = $(`&lt;div id=&quot;html_5ba2aee882c2db7559e8d7d8274de566&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a690a757ca68aa3be201f154f6f7cd43.setContent(html_5ba2aee882c2db7559e8d7d8274de566);
#
#
#
#         marker_b1403afae48c65e255dd7e31f178513e.bindPopup(popup_a690a757ca68aa3be201f154f6f7cd43)
#         ;
#
#
#
#
#             var marker_9a466b0d367946d925eb5cf26a1e2bb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c4b5e6eaa8c641b70e2736cf0c12673c);
#
#
#         var popup_1d188db6b5dfd2ea48d0ffcf9f6fa401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec37ba90f63927460091286ccf421f5 = $(`&lt;div id=&quot;html_eec37ba90f63927460091286ccf421f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1d188db6b5dfd2ea48d0ffcf9f6fa401.setContent(html_eec37ba90f63927460091286ccf421f5);
#
#
#
#         marker_9a466b0d367946d925eb5cf26a1e2bb0.bindPopup(popup_1d188db6b5dfd2ea48d0ffcf9f6fa401)
#         ;
#
#
#
#
#             var marker_32f95f8397bf9050c67a505d69c2cc85 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c4b5e6eaa8c641b70e2736cf0c12673c);
#
#
#         var popup_faaa82913497e5505b5e16aa49d03dec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75dda3b8aa2fbaa9b2cb398e07d08c6b = $(`&lt;div id=&quot;html_75dda3b8aa2fbaa9b2cb398e07d08c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_faaa82913497e5505b5e16aa49d03dec.setContent(html_75dda3b8aa2fbaa9b2cb398e07d08c6b);
#
#
#
#         marker_32f95f8397bf9050c67a505d69c2cc85.bindPopup(popup_faaa82913497e5505b5e16aa49d03dec)
#         ;
#
#
#
#
#             var marker_7d7311b305eef7da04978360ecc2bdc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c4b5e6eaa8c641b70e2736cf0c12673c);
#
#
#         var popup_7e42ba1ef8332be2a23698fdef05fce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6be47824332f49382086fa3013fc067c = $(`&lt;div id=&quot;html_6be47824332f49382086fa3013fc067c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7e42ba1ef8332be2a23698fdef05fce7.setContent(html_6be47824332f49382086fa3013fc067c);
#
#
#
#         marker_7d7311b305eef7da04978360ecc2bdc2.bindPopup(popup_7e42ba1ef8332be2a23698fdef05fce7)
#         ;
#
#
#
#
#             var marker_1396c9e961ff33f330fbe789afa0186e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c4b5e6eaa8c641b70e2736cf0c12673c);
#
#
#         var popup_5255a59c8a8685105bc62d14bc4b34f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78ea13aeb13d7fef8194ed73ece51491 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78ea13aeb13d7fef8194ed73ece51491&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78ea13aeb13d7fef8194ed73ece51491 = L.map(
#                 &quot;map_78ea13aeb13d7fef8194ed73ece51491&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fd747b0af30e86a5ac9ed3d4ef4a99b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fd747b0af30e86a5ac9ed3d4ef4a99b.addTo(map_78ea13aeb13d7fef8194ed73ece51491);
#
#
#             var feature_group_aea07d9d0868a4fca96aab7714dbd172 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_aea07d9d0868a4fca96aab7714dbd172.addTo(map_78ea13aeb13d7fef8194ed73ece51491);
#
#
#             var feature_group_sub_group_3b2b11229545c66377818b79c9265052 = L.featureGroup.subGroup(
#                 feature_group_aea07d9d0868a4fca96aab7714dbd172
#             );
#
#
#             var marker_9127508c5a4cf7bb2f6b1288dea7b2fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2b11229545c66377818b79c9265052);
#
#
#         var popup_bcec40c83a89eacccbcdf0d2ddb409f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_032cccb3ed61aac7a18b06b7c201ffb1 = $(`&lt;div id=&quot;html_032cccb3ed61aac7a18b06b7c201ffb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bcec40c83a89eacccbcdf0d2ddb409f0.setContent(html_032cccb3ed61aac7a18b06b7c201ffb1);
#
#
#
#         marker_9127508c5a4cf7bb2f6b1288dea7b2fe.bindPopup(popup_bcec40c83a89eacccbcdf0d2ddb409f0)
#         ;
#
#
#
#
#             var marker_0f3f2136d0d0d72d78bbbf7c13bfd43c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2b11229545c66377818b79c9265052);
#
#
#         var popup_fbc4d7ee228099583ae41f5280223d96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb6e49ab78bc068e3c510cbce0be5587 = $(`&lt;div id=&quot;html_eb6e49ab78bc068e3c510cbce0be5587&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fbc4d7ee228099583ae41f5280223d96.setContent(html_eb6e49ab78bc068e3c510cbce0be5587);
#
#
#
#         marker_0f3f2136d0d0d72d78bbbf7c13bfd43c.bindPopup(popup_fbc4d7ee228099583ae41f5280223d96)
#         ;
#
#
#
#
#             var marker_701df89bf688084e27276cbd8dd62306 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2b11229545c66377818b79c9265052);
#
#
#         var popup_86cfd9493103e48988fe8a82822161b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4991748010fdb918113a07fe500fca9 = $(`&lt;div id=&quot;html_b4991748010fdb918113a07fe500fca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_86cfd9493103e48988fe8a82822161b3.setContent(html_b4991748010fdb918113a07fe500fca9);
#
#
#
#         marker_701df89bf688084e27276cbd8dd62306.bindPopup(popup_86cfd9493103e48988fe8a82822161b3)
#         ;
#
#
#
#
#             var marker_ead70d7c120b7e20283ae468dff6eaf1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2b11229545c66377818b79c9265052);
#
#
#         var popup_d6cf59b32b1fe55a478cc36e02a5b83c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1090f6c0b640b91183b65c162819b26 = $(`&lt;div id=&quot;html_c1090f6c0b640b91183b65c162819b26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d6cf59b32b1fe55a478cc36e02a5b83c.setContent(html_c1090f6c0b640b91183b65c162819b26);
#
#
#
#         marker_
