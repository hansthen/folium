# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8c361bd795f438e769548db39ef2371 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8c361bd795f438e769548db39ef2371&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8c361bd795f438e769548db39ef2371 = L.map(
#                 &quot;map_d8c361bd795f438e769548db39ef2371&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a6676aa83b2931c210449759d5f22cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a6676aa83b2931c210449759d5f22cf.addTo(map_d8c361bd795f438e769548db39ef2371);
#
#
#             var marker_fe4bf1af6baab31090e55148113ae5e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d8c361bd795f438e769548db39ef2371);
#
#
#         var popup_637dce3160feb8add029d3cecca1fcb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dbdc444dde46c3fce92763f9e67eaac = $(`&lt;div id=&quot;html_4dbdc444dde46c3fce92763f9e67eaac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_637dce3160feb8add029d3cecca1fcb8.setContent(html_4dbdc444dde46c3fce92763f9e67eaac);
#
#
#
#         marker_fe4bf1af6baab31090e55148113ae5e6.bindPopup(popup_637dce3160feb8add029d3cecca1fcb8)
#         ;
#
#
#
#
#             var marker_5b904cbb34180e71457ab738896f2e40 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d8c361bd795f438e769548db39ef2371);
#
#
#         var popup_33c72a18be82167e619ddeb5a77e8151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7448f7d02e968a62c8111ff3515668de = $(`&lt;div id=&quot;html_7448f7d02e968a62c8111ff3515668de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_33c72a18be82167e619ddeb5a77e8151.setContent(html_7448f7d02e968a62c8111ff3515668de);
#
#
#
#         marker_5b904cbb34180e71457ab738896f2e40.bindPopup(popup_33c72a18be82167e619ddeb5a77e8151)
#         ;
#
#
#
#
#             var marker_66ef041a55527673309a51ca86fd1720 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d8c361bd795f438e769548db39ef2371);
#
#
#         var popup_85658e7490d6ffb7d0c02dd79575368a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d14c766ad7e85b985af65c80d26cc61d = $(`&lt;div id=&quot;html_d14c766ad7e85b985af65c80d26cc61d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_85658e7490d6ffb7d0c02dd79575368a.setContent(html_d14c766ad7e85b985af65c80d26cc61d);
#
#
#
#         marker_66ef041a55527673309a51ca86fd1720.bindPopup(popup_85658e7490d6ffb7d0c02dd79575368a)
#         ;
#
#
#
#
#             var marker_a5250388bb4abcd83b2dbd17e2fb718f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d8c361bd795f438e769548db39ef2371);
#
#
#         var popup_0135192f36a5ac298759161fe69628d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3f8433e3021f84656f7f4335c82a86d = $(`&lt;div id=&quot;html_d3f8433e3021f84656f7f4335c82a86d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0135192f36a5ac298759161fe69628d9.setContent(html_d3f8433e3021f84656f7f4335c82a86d);
#
#
#
#         marker_a5250388bb4abcd83b2dbd17e2fb718f.bindPopup(popup_0135192f36a5ac298759161fe69628d9)
#         ;
#
#
#
#
#             var marker_d3a733eb5025dba85b8f0e3d21e2afa0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d8c361bd795f438e769548db39ef2371);
#
#
#         var popup_6981252e753b6ddf2f57c1f66a254da0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51f06eb0a10311c3d4faa656e43c2793 = $(`&lt;div id=&quot;html_51f06eb0a10311c3d4faa656e43c2793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6981252e753b6ddf2f57c1f66a254d

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c14d203844be7b5176c6a2228126c0ec {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c14d203844be7b5176c6a2228126c0ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c14d203844be7b5176c6a2228126c0ec = L.map(
#                 &quot;map_c14d203844be7b5176c6a2228126c0ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ede59c6256aac8bdd3f4e0d60ad743d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ede59c6256aac8bdd3f4e0d60ad743d4.addTo(map_c14d203844be7b5176c6a2228126c0ec);
#
#
#             var feature_group_56e9ce9ce46ff36d9e176fc533b24524 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3e3eb49079de8ce1fb2b01209453dccc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_56e9ce9ce46ff36d9e176fc533b24524);
#
#
#         var popup_ce938e3c954dc4dd3a17147ebbab2c29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daaaceb8a703062230b8deb5585642b9 = $(`&lt;div id=&quot;html_daaaceb8a703062230b8deb5585642b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ce938e3c954dc4dd3a17147ebbab2c29.setContent(html_daaaceb8a703062230b8deb5585642b9);
#
#
#
#         marker_3e3eb49079de8ce1fb2b01209453dccc.bindPopup(popup_ce938e3c954dc4dd3a17147ebbab2c29)
#         ;
#
#
#
#
#             var marker_2aa6bc8ab6602bb20adaa535025496e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_56e9ce9ce46ff36d9e176fc533b24524);
#
#
#         var popup_e90d7403312a57769c28d3545ebb4dd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8c74da1b9996138bdc7515971a07a9d = $(`&lt;div id=&quot;html_b8c74da1b9996138bdc7515971a07a9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e90d7403312a57769c28d3545ebb4dd1.setContent(html_b8c74da1b9996138bdc7515971a07a9d);
#
#
#
#         marker_2aa6bc8ab6602bb20adaa535025496e6.bindPopup(popup_e90d7403312a57769c28d3545ebb4dd1)
#         ;
#
#
#
#
#             var marker_b4fd0c5a0cc731d9754ab8200d7c777d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_56e9ce9ce46ff36d9e176fc533b24524);
#
#
#         var popup_23156fe3cd4bf180457b9374a9522835 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_195f8f6db3753a0f43e1b8bbe4aaf283 = $(`&lt;div id=&quot;html_195f8f6db3753a0f43e1b8bbe4aaf283&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_23156fe3cd4bf180457b9374a9522835.setContent(html_195f8f6db3753a0f43e1b8bbe4aaf283);
#
#
#
#         marker_b4fd0c5a0cc731d9754ab8200d7c777d.bindPopup(popup_23156fe3cd4bf180457b9374a9522835)
#         ;
#
#
#
#
#             var marker_ad31428820a6ce954517148d20ecadf5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_56e9ce9ce46ff36d9e176fc533b24524);
#
#
#         var popup_0826a92deb93d44cdfdf600167d2a159 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4203f2698283d705221062b880932117 = $(`&lt;div id=&quot;html_4203f2698283d705221062b880932117&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0826a92deb93d44cdfdf600167d2a159.setContent(html_4203f2698283d705221062b880932117);
#
#
#
#         marker_ad31428820a6ce954517148d20ecadf5.bindPopup(popup_0826a92deb93d44cdfdf600167d2a159)
#         ;
#
#
#
#
#             var marker_e4311fd4ec80b548403efbd1270b998b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_56e9ce9ce46ff36d9e176fc533b24524);
#
#
#         var popup_5dc389df16674662c45736399dc2ba6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55c6597eacfb22ddf5e4bed0515a6cbe {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55c6597eacfb22ddf5e4bed0515a6cbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55c6597eacfb22ddf5e4bed0515a6cbe = L.map(
#                 &quot;map_55c6597eacfb22ddf5e4bed0515a6cbe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a78d2c5f11d02b961d5ce33f5861ff95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a78d2c5f11d02b961d5ce33f5861ff95.addTo(map_55c6597eacfb22ddf5e4bed0515a6cbe);
#
#
#             var feature_group_53028c4bc127828700b5b85f16996ac6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_53028c4bc127828700b5b85f16996ac6.addTo(map_55c6597eacfb22ddf5e4bed0515a6cbe);
#
#
#             var feature_group_sub_group_28ba794c75a400d7b28e87bbd7f439a1 = L.featureGroup.subGroup(
#                 feature_group_53028c4bc127828700b5b85f16996ac6
#             );
#
#
#             var marker_1cc5a8b87e76ecdc9037ba2f41ba9ac1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_28ba794c75a400d7b28e87bbd7f439a1);
#
#
#         var popup_97892ebd8c3099c14e124d98eb6dbb0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e208aef066d73d849c953b84304b84ed = $(`&lt;div id=&quot;html_e208aef066d73d849c953b84304b84ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_97892ebd8c3099c14e124d98eb6dbb0a.setContent(html_e208aef066d73d849c953b84304b84ed);
#
#
#
#         marker_1cc5a8b87e76ecdc9037ba2f41ba9ac1.bindPopup(popup_97892ebd8c3099c14e124d98eb6dbb0a)
#         ;
#
#
#
#
#             var marker_fb95c0ed5f39b881bd9bb89159d533ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_28ba794c75a400d7b28e87bbd7f439a1);
#
#
#         var popup_e2d96f807b5957293c5e27be16bb126d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e79b24019994434c85f98d17312f83d1 = $(`&lt;div id=&quot;html_e79b24019994434c85f98d17312f83d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e2d96f807b5957293c5e27be16bb126d.setContent(html_e79b24019994434c85f98d17312f83d1);
#
#
#
#         marker_fb95c0ed5f39b881bd9bb89159d533ed.bindPopup(popup_e2d96f807b5957293c5e27be16bb126d)
#         ;
#
#
#
#
#             var marker_8401a09e9190b39cfa923058238ce076 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_28ba794c75a400d7b28e87bbd7f439a1);
#
#
#         var popup_d73460f45c731c7634407e745276b253 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c66645dbc2f3790ae2e9e6876af31d04 = $(`&lt;div id=&quot;html_c66645dbc2f3790ae2e9e6876af31d04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d73460f45c731c7634407e745276b253.setContent(html_c66645dbc2f3790ae2e9e6876af31d04);
#
#
#
#         marker_8401a09e9190b39cfa923058238ce076.bindPopup(popup_d73460f45c731c7634407e745276b253)
#         ;
#
#
#
#
#             var marker_9c06c3789656a6aec2d0b93343dcd9be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_28ba794c75a400d7b28e87bbd7f439a1);
#
#
#         var popup_65ff4b296aa8776095696900c547aaf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b86112541cdaf5e883b0b923a5c4d135 = $(`&lt;div id=&quot;html_b86112541cdaf5e883b0b923a5c4d135&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_65ff4b296aa8776095696900c547aaf3.setContent(html_b86112541cdaf5e883b0b923a5c4d135);
#
#
#
#         mark
