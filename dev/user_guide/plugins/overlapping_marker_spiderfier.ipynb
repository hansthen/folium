# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19c814af5cce00ac9596d37b5254ba2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19c814af5cce00ac9596d37b5254ba2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19c814af5cce00ac9596d37b5254ba2c = L.map(
#                 &quot;map_19c814af5cce00ac9596d37b5254ba2c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5de7f7f8a1d003f3c2e28b40589b78a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5de7f7f8a1d003f3c2e28b40589b78a.addTo(map_19c814af5cce00ac9596d37b5254ba2c);
#
#
#             var marker_b5b492292050a220345de48c68e87222 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_19c814af5cce00ac9596d37b5254ba2c);
#
#
#         var popup_42f35fda7eaf14b5c1dcba7e2d5b9f08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ec80fdbd9825e38743bc1ba85b0e507 = $(`&lt;div id=&quot;html_8ec80fdbd9825e38743bc1ba85b0e507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_42f35fda7eaf14b5c1dcba7e2d5b9f08.setContent(html_8ec80fdbd9825e38743bc1ba85b0e507);
#
#
#
#         marker_b5b492292050a220345de48c68e87222.bindPopup(popup_42f35fda7eaf14b5c1dcba7e2d5b9f08)
#         ;
#
#
#
#
#             var marker_a23499974670af85f16c4908929fbadc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_19c814af5cce00ac9596d37b5254ba2c);
#
#
#         var popup_2802a4f61699c3274ffbe01aaf0283bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69695feb3d8d5bfa75489cb28df455b4 = $(`&lt;div id=&quot;html_69695feb3d8d5bfa75489cb28df455b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2802a4f61699c3274ffbe01aaf0283bb.setContent(html_69695feb3d8d5bfa75489cb28df455b4);
#
#
#
#         marker_a23499974670af85f16c4908929fbadc.bindPopup(popup_2802a4f61699c3274ffbe01aaf0283bb)
#         ;
#
#
#
#
#             var marker_b22a68d1b5b9ac5666bc8231fc920f93 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_19c814af5cce00ac9596d37b5254ba2c);
#
#
#         var popup_15db14a4b5bc1d2a086884a0e44b77ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebfcfb925769031d536a8a728defdf5e = $(`&lt;div id=&quot;html_ebfcfb925769031d536a8a728defdf5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_15db14a4b5bc1d2a086884a0e44b77ab.setContent(html_ebfcfb925769031d536a8a728defdf5e);
#
#
#
#         marker_b22a68d1b5b9ac5666bc8231fc920f93.bindPopup(popup_15db14a4b5bc1d2a086884a0e44b77ab)
#         ;
#
#
#
#
#             var marker_8ab74627da2089dd578c327feace693d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_19c814af5cce00ac9596d37b5254ba2c);
#
#
#         var popup_9468140ea6a20b366f49260bec25e7c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d223f8f44510c4fb34c2b27176e0827 = $(`&lt;div id=&quot;html_1d223f8f44510c4fb34c2b27176e0827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9468140ea6a20b366f49260bec25e7c1.setContent(html_1d223f8f44510c4fb34c2b27176e0827);
#
#
#
#         marker_8ab74627da2089dd578c327feace693d.bindPopup(popup_9468140ea6a20b366f49260bec25e7c1)
#         ;
#
#
#
#
#             var marker_80247d441bbf47a7bd19a9019034dc88 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_19c814af5cce00ac9596d37b5254ba2c);
#
#
#         var popup_aa4523c6c48abdf31ac81f681edc0675 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c7fa42cc287a13399f2b70736784380 = $(`&lt;div id=&quot;html_7c7fa42cc287a13399f2b70736784380&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa4523c6c48abdf31ac81f681edc0675.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4599f772e524c2ddf87f8beb5a099cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4599f772e524c2ddf87f8beb5a099cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4599f772e524c2ddf87f8beb5a099cb = L.map(
#                 &quot;map_d4599f772e524c2ddf87f8beb5a099cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39026685861b60edeffb82bdb601c430 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39026685861b60edeffb82bdb601c430.addTo(map_d4599f772e524c2ddf87f8beb5a099cb);
#
#
#             var feature_group_bdea6e0e5c0ae02f06bc8e7f0cd40ba3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c4f0b26703abe4865da11155b40231dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bdea6e0e5c0ae02f06bc8e7f0cd40ba3);
#
#
#         var popup_9d12ac7da75b07dbe2f1163113dfe8cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d89137bf811e9e708721439f8dd1fd1 = $(`&lt;div id=&quot;html_0d89137bf811e9e708721439f8dd1fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9d12ac7da75b07dbe2f1163113dfe8cd.setContent(html_0d89137bf811e9e708721439f8dd1fd1);
#
#
#
#         marker_c4f0b26703abe4865da11155b40231dd.bindPopup(popup_9d12ac7da75b07dbe2f1163113dfe8cd)
#         ;
#
#
#
#
#             var marker_1749af5d5023938c7f2756c4f39e1e77 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bdea6e0e5c0ae02f06bc8e7f0cd40ba3);
#
#
#         var popup_96fecfddd067e32f3327c4ff05ee8f69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88b9953c60d3179f7c49106777158560 = $(`&lt;div id=&quot;html_88b9953c60d3179f7c49106777158560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_96fecfddd067e32f3327c4ff05ee8f69.setContent(html_88b9953c60d3179f7c49106777158560);
#
#
#
#         marker_1749af5d5023938c7f2756c4f39e1e77.bindPopup(popup_96fecfddd067e32f3327c4ff05ee8f69)
#         ;
#
#
#
#
#             var marker_2c32abe939bc6d176729e0660997bacd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bdea6e0e5c0ae02f06bc8e7f0cd40ba3);
#
#
#         var popup_9ef0c7b9d1c788f2e617ffb73bafda59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2f1fd0571355a98f44ab598d605bf70 = $(`&lt;div id=&quot;html_e2f1fd0571355a98f44ab598d605bf70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9ef0c7b9d1c788f2e617ffb73bafda59.setContent(html_e2f1fd0571355a98f44ab598d605bf70);
#
#
#
#         marker_2c32abe939bc6d176729e0660997bacd.bindPopup(popup_9ef0c7b9d1c788f2e617ffb73bafda59)
#         ;
#
#
#
#
#             var marker_e1fd8d2e7a6de0dfb8811ef4f0304b9a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bdea6e0e5c0ae02f06bc8e7f0cd40ba3);
#
#
#         var popup_f207bb59877ed67b2900b0627de6401b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79f5a357891832f7730e1011ad92e9fb = $(`&lt;div id=&quot;html_79f5a357891832f7730e1011ad92e9fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f207bb59877ed67b2900b0627de6401b.setContent(html_79f5a357891832f7730e1011ad92e9fb);
#
#
#
#         marker_e1fd8d2e7a6de0dfb8811ef4f0304b9a.bindPopup(popup_f207bb59877ed67b2900b0627de6401b)
#         ;
#
#
#
#
#             var marker_8a942f18ab8164a07e7322a80cb9c46a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bdea6e0e5c0ae02f06bc8e7f0cd40ba3);
#
#
#         var popup_c11352b1326bb1abc0a8d369ae81e2d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_598f9de4fd8de1760a6aa1dd8eef9390 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_598f9de4fd8de1760a6aa1dd8eef9390&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_598f9de4fd8de1760a6aa1dd8eef9390 = L.map(
#                 &quot;map_598f9de4fd8de1760a6aa1dd8eef9390&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4ae782288537ccc7c15c85714e351fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4ae782288537ccc7c15c85714e351fd.addTo(map_598f9de4fd8de1760a6aa1dd8eef9390);
#
#
#             var feature_group_9d5d48ba756e9e2bb1af30dd99204611 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9d5d48ba756e9e2bb1af30dd99204611.addTo(map_598f9de4fd8de1760a6aa1dd8eef9390);
#
#
#             var feature_group_sub_group_a87d8f75bec0f4d1fed488919f4be12b = L.featureGroup.subGroup(
#                 feature_group_9d5d48ba756e9e2bb1af30dd99204611
#             );
#
#
#             var marker_25586563a26d51fa48f5f336beede0af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a87d8f75bec0f4d1fed488919f4be12b);
#
#
#         var popup_6cea9fb1d831cca40d0f03f03ff0691c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92d84fa80d36d7281f22456424d63828 = $(`&lt;div id=&quot;html_92d84fa80d36d7281f22456424d63828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6cea9fb1d831cca40d0f03f03ff0691c.setContent(html_92d84fa80d36d7281f22456424d63828);
#
#
#
#         marker_25586563a26d51fa48f5f336beede0af.bindPopup(popup_6cea9fb1d831cca40d0f03f03ff0691c)
#         ;
#
#
#
#
#             var marker_29082f83aef4b0cb610ba673182419c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a87d8f75bec0f4d1fed488919f4be12b);
#
#
#         var popup_903e2aab630f9f120313beb2e2760eaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90cb13462406102c3c276b24e8ea1e79 = $(`&lt;div id=&quot;html_90cb13462406102c3c276b24e8ea1e79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_903e2aab630f9f120313beb2e2760eaf.setContent(html_90cb13462406102c3c276b24e8ea1e79);
#
#
#
#         marker_29082f83aef4b0cb610ba673182419c5.bindPopup(popup_903e2aab630f9f120313beb2e2760eaf)
#         ;
#
#
#
#
#             var marker_4a24672da801f559fe312c6f92919bbf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a87d8f75bec0f4d1fed488919f4be12b);
#
#
#         var popup_4530650a2b9926646d3a57fedcb3c5d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea91217b96eeab6d058d783f69a2836b = $(`&lt;div id=&quot;html_ea91217b96eeab6d058d783f69a2836b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4530650a2b9926646d3a57fedcb3c5d3.setContent(html_ea91217b96eeab6d058d783f69a2836b);
#
#
#
#         marker_4a24672da801f559fe312c6f92919bbf.bindPopup(popup_4530650a2b9926646d3a57fedcb3c5d3)
#         ;
#
#
#
#
#             var marker_845d5fbe86e3182792f8643792412e13 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a87d8f75bec0f4d1fed488919f4be12b);
#
#
#         var popup_82966b4bf9b306d6461535ab85a7e245 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4656806a5f5f79139d46a9631f2252d = $(`&lt;div id=&quot;html_f4656806a5f5f79139d46a9631f2252d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_82966b4bf9b306d6461535ab85a7e245.setContent(html_f4656806a5f5f79139d46a9631f2252d);
#
#
#
#         marker_
