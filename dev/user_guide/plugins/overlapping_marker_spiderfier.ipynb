# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e04f98e7afc6e82288f943ce8eaeadf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e04f98e7afc6e82288f943ce8eaeadf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e04f98e7afc6e82288f943ce8eaeadf2 = L.map(
#                 &quot;map_e04f98e7afc6e82288f943ce8eaeadf2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2805e4e589616fbdde7c596ff3261b7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2805e4e589616fbdde7c596ff3261b7d.addTo(map_e04f98e7afc6e82288f943ce8eaeadf2);
#
#
#             var marker_d6c40a6780989559ceda169e7b3315dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e04f98e7afc6e82288f943ce8eaeadf2);
#
#
#         var popup_2475a6a4c6694ec3fac952328175ce7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecdd26d34940dec4fa0d0e929c229510 = $(`&lt;div id=&quot;html_ecdd26d34940dec4fa0d0e929c229510&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2475a6a4c6694ec3fac952328175ce7e.setContent(html_ecdd26d34940dec4fa0d0e929c229510);
#
#
#
#         marker_d6c40a6780989559ceda169e7b3315dc.bindPopup(popup_2475a6a4c6694ec3fac952328175ce7e)
#         ;
#
#
#
#
#             var marker_17d42afeb8a3f89831b3e5918c717b11 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e04f98e7afc6e82288f943ce8eaeadf2);
#
#
#         var popup_e9ba2ab5d7faa13a0181a80bcc0e3482 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_287f537bb5189a334bd834a848c13ccb = $(`&lt;div id=&quot;html_287f537bb5189a334bd834a848c13ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e9ba2ab5d7faa13a0181a80bcc0e3482.setContent(html_287f537bb5189a334bd834a848c13ccb);
#
#
#
#         marker_17d42afeb8a3f89831b3e5918c717b11.bindPopup(popup_e9ba2ab5d7faa13a0181a80bcc0e3482)
#         ;
#
#
#
#
#             var marker_0cb75ba5d1569f4a6ecf74820fe72b9a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e04f98e7afc6e82288f943ce8eaeadf2);
#
#
#         var popup_14e6c892e77138f48df7555a2b098a37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a44e6da741def23454418b1c2764f1cf = $(`&lt;div id=&quot;html_a44e6da741def23454418b1c2764f1cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_14e6c892e77138f48df7555a2b098a37.setContent(html_a44e6da741def23454418b1c2764f1cf);
#
#
#
#         marker_0cb75ba5d1569f4a6ecf74820fe72b9a.bindPopup(popup_14e6c892e77138f48df7555a2b098a37)
#         ;
#
#
#
#
#             var marker_09b459031ed555b422dfdefcb3fa0ad8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e04f98e7afc6e82288f943ce8eaeadf2);
#
#
#         var popup_4ecb379bcf3c41102ae1d432cac070b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1888c2008760b406513331454754d94 = $(`&lt;div id=&quot;html_e1888c2008760b406513331454754d94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4ecb379bcf3c41102ae1d432cac070b3.setContent(html_e1888c2008760b406513331454754d94);
#
#
#
#         marker_09b459031ed555b422dfdefcb3fa0ad8.bindPopup(popup_4ecb379bcf3c41102ae1d432cac070b3)
#         ;
#
#
#
#
#             var marker_61870fd697810b816a2febaa86ebc666 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e04f98e7afc6e82288f943ce8eaeadf2);
#
#
#         var popup_625666fbc6fcb20fc9442a8ace48302b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_645f5c03d6e80e1167f1bed7dfcf2fee = $(`&lt;div id=&quot;html_645f5c03d6e80e1167f1bed7dfcf2fee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_625666fbc6fcb20fc9442a8ace48302b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d5342f2af1efcca75a82cba1f61a9f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d5342f2af1efcca75a82cba1f61a9f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d5342f2af1efcca75a82cba1f61a9f9 = L.map(
#                 &quot;map_2d5342f2af1efcca75a82cba1f61a9f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13d53a4a39be4ef00f7e0fb02583c778 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13d53a4a39be4ef00f7e0fb02583c778.addTo(map_2d5342f2af1efcca75a82cba1f61a9f9);
#
#
#             var feature_group_3b8010c40c44c61a337390861c182cd1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_133fe3e884ff1cbe1cd48eab6ba1f7f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3b8010c40c44c61a337390861c182cd1);
#
#
#         var popup_01d54659850d0b27a6f10d4d24d709f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79523e6c9e5dc56d7f192759a7957a4f = $(`&lt;div id=&quot;html_79523e6c9e5dc56d7f192759a7957a4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_01d54659850d0b27a6f10d4d24d709f3.setContent(html_79523e6c9e5dc56d7f192759a7957a4f);
#
#
#
#         marker_133fe3e884ff1cbe1cd48eab6ba1f7f9.bindPopup(popup_01d54659850d0b27a6f10d4d24d709f3)
#         ;
#
#
#
#
#             var marker_15592500711e99780d374d98bbec1b0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3b8010c40c44c61a337390861c182cd1);
#
#
#         var popup_93593f23702d5a64075e01bbeab22b17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a9d4db67a8949c5a1e2fe95852d3913 = $(`&lt;div id=&quot;html_5a9d4db67a8949c5a1e2fe95852d3913&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_93593f23702d5a64075e01bbeab22b17.setContent(html_5a9d4db67a8949c5a1e2fe95852d3913);
#
#
#
#         marker_15592500711e99780d374d98bbec1b0e.bindPopup(popup_93593f23702d5a64075e01bbeab22b17)
#         ;
#
#
#
#
#             var marker_d7f4e219b6564977a01b4dc27b0b334d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3b8010c40c44c61a337390861c182cd1);
#
#
#         var popup_4b9a8809bf4fbc0f541b633ab293db4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8748cc1686bc295af519f48bcec8b9d2 = $(`&lt;div id=&quot;html_8748cc1686bc295af519f48bcec8b9d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4b9a8809bf4fbc0f541b633ab293db4d.setContent(html_8748cc1686bc295af519f48bcec8b9d2);
#
#
#
#         marker_d7f4e219b6564977a01b4dc27b0b334d.bindPopup(popup_4b9a8809bf4fbc0f541b633ab293db4d)
#         ;
#
#
#
#
#             var marker_df0761b912e8b3e4d078d65a036c970c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3b8010c40c44c61a337390861c182cd1);
#
#
#         var popup_2cea58c3245ca6ed299086437d00f02e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a86ce8beeef8bad433394609238346a2 = $(`&lt;div id=&quot;html_a86ce8beeef8bad433394609238346a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2cea58c3245ca6ed299086437d00f02e.setContent(html_a86ce8beeef8bad433394609238346a2);
#
#
#
#         marker_df0761b912e8b3e4d078d65a036c970c.bindPopup(popup_2cea58c3245ca6ed299086437d00f02e)
#         ;
#
#
#
#
#             var marker_259ccd7a6e023b7bc1fed9bd3c213c7b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3b8010c40c44c61a337390861c182cd1);
#
#
#         var popup_0cd5a2cba3c8f74edad44ee62ad4e6da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cabfbb6803f512f2038e822f61ad53b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cabfbb6803f512f2038e822f61ad53b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cabfbb6803f512f2038e822f61ad53b5 = L.map(
#                 &quot;map_cabfbb6803f512f2038e822f61ad53b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c88a1045f73900a5da8ae2a0e21a4e7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c88a1045f73900a5da8ae2a0e21a4e7b.addTo(map_cabfbb6803f512f2038e822f61ad53b5);
#
#
#             var feature_group_31839153c627c42156e1fd6e5b67c02e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_31839153c627c42156e1fd6e5b67c02e.addTo(map_cabfbb6803f512f2038e822f61ad53b5);
#
#
#             var feature_group_sub_group_be3c103110bcbf617a0f3dc28d24c400 = L.featureGroup.subGroup(
#                 feature_group_31839153c627c42156e1fd6e5b67c02e
#             );
#
#
#             var marker_fb5c63f38947f39712f15f978169de22 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3c103110bcbf617a0f3dc28d24c400);
#
#
#         var popup_593dade934d11ac6e119c572c36195fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8cb86e07d8f4bba512cec30168e030e = $(`&lt;div id=&quot;html_f8cb86e07d8f4bba512cec30168e030e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_593dade934d11ac6e119c572c36195fc.setContent(html_f8cb86e07d8f4bba512cec30168e030e);
#
#
#
#         marker_fb5c63f38947f39712f15f978169de22.bindPopup(popup_593dade934d11ac6e119c572c36195fc)
#         ;
#
#
#
#
#             var marker_d0b0f7de127f6b25e12cbb2d0273e514 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3c103110bcbf617a0f3dc28d24c400);
#
#
#         var popup_f2ab64a3d833c4759442d22c3369768b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf0c5f803b66675ef5f0d1776171d3f9 = $(`&lt;div id=&quot;html_cf0c5f803b66675ef5f0d1776171d3f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2ab64a3d833c4759442d22c3369768b.setContent(html_cf0c5f803b66675ef5f0d1776171d3f9);
#
#
#
#         marker_d0b0f7de127f6b25e12cbb2d0273e514.bindPopup(popup_f2ab64a3d833c4759442d22c3369768b)
#         ;
#
#
#
#
#             var marker_15f129310c8c6bff6a36142eb95ecd0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3c103110bcbf617a0f3dc28d24c400);
#
#
#         var popup_24075ee9accf0db97de56d53f864471f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1956e9aca1c9ae130f175924315cb42c = $(`&lt;div id=&quot;html_1956e9aca1c9ae130f175924315cb42c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_24075ee9accf0db97de56d53f864471f.setContent(html_1956e9aca1c9ae130f175924315cb42c);
#
#
#
#         marker_15f129310c8c6bff6a36142eb95ecd0f.bindPopup(popup_24075ee9accf0db97de56d53f864471f)
#         ;
#
#
#
#
#             var marker_885293bd5bad93109de6c0904ac97909 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3c103110bcbf617a0f3dc28d24c400);
#
#
#         var popup_5aa5f441dad98de7f4194a71e8b2a750 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46e932397405f04f5abf7cc9968894d9 = $(`&lt;div id=&quot;html_46e932397405f04f5abf7cc9968894d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5aa5f441dad98de7f4194a71e8b2a750.setContent(html_46e932397405f04f5abf7cc9968894d9);
#
#
#
#         marker_
