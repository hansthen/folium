# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b2d45c7342fe4b44831e99afebcad45 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b2d45c7342fe4b44831e99afebcad45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b2d45c7342fe4b44831e99afebcad45 = L.map(
#                 &quot;map_7b2d45c7342fe4b44831e99afebcad45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_556a56fa43b3ac8337bcde29e7424707 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_556a56fa43b3ac8337bcde29e7424707.addTo(map_7b2d45c7342fe4b44831e99afebcad45);
#
#
#             var marker_4573eab6732f16b2b677e1d71f615194 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7b2d45c7342fe4b44831e99afebcad45);
#
#
#         var popup_dd8c9d99b3330466ea13b01c39c364aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f6765b105c12888f448e810276d42d9 = $(`&lt;div id=&quot;html_0f6765b105c12888f448e810276d42d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dd8c9d99b3330466ea13b01c39c364aa.setContent(html_0f6765b105c12888f448e810276d42d9);
#
#
#
#         marker_4573eab6732f16b2b677e1d71f615194.bindPopup(popup_dd8c9d99b3330466ea13b01c39c364aa)
#         ;
#
#
#
#
#             var marker_a935b0333cde52e45d3a561a2461c350 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7b2d45c7342fe4b44831e99afebcad45);
#
#
#         var popup_624e296734c3709d8bf6a6f44d2c8eff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8adfa217d077b1429a204d1c878f3270 = $(`&lt;div id=&quot;html_8adfa217d077b1429a204d1c878f3270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_624e296734c3709d8bf6a6f44d2c8eff.setContent(html_8adfa217d077b1429a204d1c878f3270);
#
#
#
#         marker_a935b0333cde52e45d3a561a2461c350.bindPopup(popup_624e296734c3709d8bf6a6f44d2c8eff)
#         ;
#
#
#
#
#             var marker_facc367e4834c51afb4921c6049881b8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7b2d45c7342fe4b44831e99afebcad45);
#
#
#         var popup_a9e7bafa6bcce789456831441283de48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ade2cea82053bbe84955eb172b002de1 = $(`&lt;div id=&quot;html_ade2cea82053bbe84955eb172b002de1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a9e7bafa6bcce789456831441283de48.setContent(html_ade2cea82053bbe84955eb172b002de1);
#
#
#
#         marker_facc367e4834c51afb4921c6049881b8.bindPopup(popup_a9e7bafa6bcce789456831441283de48)
#         ;
#
#
#
#
#             var marker_f71bf23f54533a02d511a3fb01a55564 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7b2d45c7342fe4b44831e99afebcad45);
#
#
#         var popup_1d660b524a5a23c47417344e49cf9907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6106e38f10f6b57bbdf25d6bfeee8eca = $(`&lt;div id=&quot;html_6106e38f10f6b57bbdf25d6bfeee8eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1d660b524a5a23c47417344e49cf9907.setContent(html_6106e38f10f6b57bbdf25d6bfeee8eca);
#
#
#
#         marker_f71bf23f54533a02d511a3fb01a55564.bindPopup(popup_1d660b524a5a23c47417344e49cf9907)
#         ;
#
#
#
#
#             var marker_e926bfea270b1dfa910162902171e3e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7b2d45c7342fe4b44831e99afebcad45);
#
#
#         var popup_978bb1f74bc887d4c9f01feb3214612e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1233bc2201d7bf0659e540732f4d491a = $(`&lt;div id=&quot;html_1233bc2201d7bf0659e540732f4d491a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_978bb1f74bc887d4c9f01feb321461

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35d9c546d6f03b0f66614d17dd62d518 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35d9c546d6f03b0f66614d17dd62d518&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35d9c546d6f03b0f66614d17dd62d518 = L.map(
#                 &quot;map_35d9c546d6f03b0f66614d17dd62d518&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff61166f0b13a72c4cc9dff5a5cf462c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff61166f0b13a72c4cc9dff5a5cf462c.addTo(map_35d9c546d6f03b0f66614d17dd62d518);
#
#
#             var feature_group_d28ab8780c1a9b4ad6915b93f315addd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c467857aecf91bd1ad9bd0caf02de710 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d28ab8780c1a9b4ad6915b93f315addd);
#
#
#         var popup_37d7cd6ba0ac6bdf4f6dcfff596af980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_863cebd31b079b0944f2f171ac625bc6 = $(`&lt;div id=&quot;html_863cebd31b079b0944f2f171ac625bc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_37d7cd6ba0ac6bdf4f6dcfff596af980.setContent(html_863cebd31b079b0944f2f171ac625bc6);
#
#
#
#         marker_c467857aecf91bd1ad9bd0caf02de710.bindPopup(popup_37d7cd6ba0ac6bdf4f6dcfff596af980)
#         ;
#
#
#
#
#             var marker_871e5163727b40d8c79c6f9088085ab6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d28ab8780c1a9b4ad6915b93f315addd);
#
#
#         var popup_eb0944760a83e1359bc9dff711d34677 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07d62e69bb7953f446d9562d9b35b684 = $(`&lt;div id=&quot;html_07d62e69bb7953f446d9562d9b35b684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eb0944760a83e1359bc9dff711d34677.setContent(html_07d62e69bb7953f446d9562d9b35b684);
#
#
#
#         marker_871e5163727b40d8c79c6f9088085ab6.bindPopup(popup_eb0944760a83e1359bc9dff711d34677)
#         ;
#
#
#
#
#             var marker_e02e423b4b32f0a1bea162dbee6eb42d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d28ab8780c1a9b4ad6915b93f315addd);
#
#
#         var popup_6d833265d1450bedca64f0a960cdbcd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6274b0e7f5344b891b0c1a5bb291aa5 = $(`&lt;div id=&quot;html_d6274b0e7f5344b891b0c1a5bb291aa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6d833265d1450bedca64f0a960cdbcd3.setContent(html_d6274b0e7f5344b891b0c1a5bb291aa5);
#
#
#
#         marker_e02e423b4b32f0a1bea162dbee6eb42d.bindPopup(popup_6d833265d1450bedca64f0a960cdbcd3)
#         ;
#
#
#
#
#             var marker_100e5492af8eeeb520d560d97cf34941 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d28ab8780c1a9b4ad6915b93f315addd);
#
#
#         var popup_ba420e53de385db7423b693d4750b553 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cdb339757f5744412785c8292fe3d91 = $(`&lt;div id=&quot;html_3cdb339757f5744412785c8292fe3d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ba420e53de385db7423b693d4750b553.setContent(html_3cdb339757f5744412785c8292fe3d91);
#
#
#
#         marker_100e5492af8eeeb520d560d97cf34941.bindPopup(popup_ba420e53de385db7423b693d4750b553)
#         ;
#
#
#
#
#             var marker_0718aa2482e519580c870541e6bb2aca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d28ab8780c1a9b4ad6915b93f315addd);
#
#
#         var popup_2649a38a7cdb07b2c62524a42c2c6969 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4d7a6f2d100b04901a771a21589b507 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4d7a6f2d100b04901a771a21589b507&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4d7a6f2d100b04901a771a21589b507 = L.map(
#                 &quot;map_d4d7a6f2d100b04901a771a21589b507&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a25278fcd40ce414776dcabdac66ebc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a25278fcd40ce414776dcabdac66ebc.addTo(map_d4d7a6f2d100b04901a771a21589b507);
#
#
#             var feature_group_57f786c51610f4633c277f81ac849862 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_57f786c51610f4633c277f81ac849862.addTo(map_d4d7a6f2d100b04901a771a21589b507);
#
#
#             var feature_group_sub_group_58ccd55b68c4c7ae283fa5c61c89cd2a = L.featureGroup.subGroup(
#                 feature_group_57f786c51610f4633c277f81ac849862
#             );
#
#
#             var marker_c07eb6bc3db1474572dbba2234baf031 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_58ccd55b68c4c7ae283fa5c61c89cd2a);
#
#
#         var popup_10986f647781faecf9f8adefbab98565 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef67b1200c183f30a6e68cd8ff3f4b2e = $(`&lt;div id=&quot;html_ef67b1200c183f30a6e68cd8ff3f4b2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_10986f647781faecf9f8adefbab98565.setContent(html_ef67b1200c183f30a6e68cd8ff3f4b2e);
#
#
#
#         marker_c07eb6bc3db1474572dbba2234baf031.bindPopup(popup_10986f647781faecf9f8adefbab98565)
#         ;
#
#
#
#
#             var marker_9ab433ca00944e04debd55edc1b9f79f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_58ccd55b68c4c7ae283fa5c61c89cd2a);
#
#
#         var popup_d1a6fb108fcf4fd7b4df89e1f5698d48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5cee92f0df55f8d298b93185f579cdc = $(`&lt;div id=&quot;html_c5cee92f0df55f8d298b93185f579cdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d1a6fb108fcf4fd7b4df89e1f5698d48.setContent(html_c5cee92f0df55f8d298b93185f579cdc);
#
#
#
#         marker_9ab433ca00944e04debd55edc1b9f79f.bindPopup(popup_d1a6fb108fcf4fd7b4df89e1f5698d48)
#         ;
#
#
#
#
#             var marker_5cba5a45eaa3506a31ceeee82aeaa08a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_58ccd55b68c4c7ae283fa5c61c89cd2a);
#
#
#         var popup_88ad504a4d66243e724110cf24b4d81d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fab7c525ac027a87960bee968d633808 = $(`&lt;div id=&quot;html_fab7c525ac027a87960bee968d633808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_88ad504a4d66243e724110cf24b4d81d.setContent(html_fab7c525ac027a87960bee968d633808);
#
#
#
#         marker_5cba5a45eaa3506a31ceeee82aeaa08a.bindPopup(popup_88ad504a4d66243e724110cf24b4d81d)
#         ;
#
#
#
#
#             var marker_36ca8ec47cebbe3c44cc438c57d164c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_58ccd55b68c4c7ae283fa5c61c89cd2a);
#
#
#         var popup_f64dc38a291e6c76e1010743b3a3fa88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3815849d03111460f76bbc363593e92c = $(`&lt;div id=&quot;html_3815849d03111460f76bbc363593e92c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f64dc38a291e6c76e1010743b3a3fa88.setContent(html_3815849d03111460f76bbc363593e92c);
#
#
#
#         mark
