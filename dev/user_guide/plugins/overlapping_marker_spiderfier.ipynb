# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04c9416bac52b3232d9ca5f613d58225 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04c9416bac52b3232d9ca5f613d58225&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04c9416bac52b3232d9ca5f613d58225 = L.map(
#                 &quot;map_04c9416bac52b3232d9ca5f613d58225&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34d00c297560c2b369245246aaed7988 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34d00c297560c2b369245246aaed7988.addTo(map_04c9416bac52b3232d9ca5f613d58225);
#
#
#             var marker_7ec7bd71971d908b641f7c5c0e74d07f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_04c9416bac52b3232d9ca5f613d58225);
#
#
#         var popup_e2442f911438a3ac1bfec38be502142f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa812eba3c80f336fc3f9d662dfdac93 = $(`&lt;div id=&quot;html_fa812eba3c80f336fc3f9d662dfdac93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e2442f911438a3ac1bfec38be502142f.setContent(html_fa812eba3c80f336fc3f9d662dfdac93);
#
#
#
#         marker_7ec7bd71971d908b641f7c5c0e74d07f.bindPopup(popup_e2442f911438a3ac1bfec38be502142f)
#         ;
#
#
#
#
#             var marker_df6213996fe97f61648af03eff1c5aa2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_04c9416bac52b3232d9ca5f613d58225);
#
#
#         var popup_994100c00bb6f380faf24eec7c2618eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0476632ffbf41279b20cfe091626273e = $(`&lt;div id=&quot;html_0476632ffbf41279b20cfe091626273e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_994100c00bb6f380faf24eec7c2618eb.setContent(html_0476632ffbf41279b20cfe091626273e);
#
#
#
#         marker_df6213996fe97f61648af03eff1c5aa2.bindPopup(popup_994100c00bb6f380faf24eec7c2618eb)
#         ;
#
#
#
#
#             var marker_24a047aeeb2dd915fdcd30f33d2bbc60 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_04c9416bac52b3232d9ca5f613d58225);
#
#
#         var popup_29bec7165ab844596fbe78e37a813392 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47d948a51d4b28b31373e7a99d9c67f5 = $(`&lt;div id=&quot;html_47d948a51d4b28b31373e7a99d9c67f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_29bec7165ab844596fbe78e37a813392.setContent(html_47d948a51d4b28b31373e7a99d9c67f5);
#
#
#
#         marker_24a047aeeb2dd915fdcd30f33d2bbc60.bindPopup(popup_29bec7165ab844596fbe78e37a813392)
#         ;
#
#
#
#
#             var marker_4da34d1f7834a9e3996ac8191b856292 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_04c9416bac52b3232d9ca5f613d58225);
#
#
#         var popup_b664ef5c6f10b9800893759c31cb4169 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d64b49fcad7c1be29ecb42fbfcd0a732 = $(`&lt;div id=&quot;html_d64b49fcad7c1be29ecb42fbfcd0a732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b664ef5c6f10b9800893759c31cb4169.setContent(html_d64b49fcad7c1be29ecb42fbfcd0a732);
#
#
#
#         marker_4da34d1f7834a9e3996ac8191b856292.bindPopup(popup_b664ef5c6f10b9800893759c31cb4169)
#         ;
#
#
#
#
#             var marker_c999e7c900a994863605c3df76d33440 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_04c9416bac52b3232d9ca5f613d58225);
#
#
#         var popup_dfd568b877692a8c84a0f3e87c2dea6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_688d06a09f8f72fdac730574c3bc0e5b = $(`&lt;div id=&quot;html_688d06a09f8f72fdac730574c3bc0e5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dfd568b877692a8c84a0f3e87c2dea

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8e7ab075eeeba659a2dee359f44c25c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8e7ab075eeeba659a2dee359f44c25c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8e7ab075eeeba659a2dee359f44c25c = L.map(
#                 &quot;map_c8e7ab075eeeba659a2dee359f44c25c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd274b1cc402a1b54af5ab5c5ed4f401 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd274b1cc402a1b54af5ab5c5ed4f401.addTo(map_c8e7ab075eeeba659a2dee359f44c25c);
#
#
#             var feature_group_e7099998b998e79d0465a90a1dac7764 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ffe8693edd90fb1c99d2554d188f4ef5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e7099998b998e79d0465a90a1dac7764);
#
#
#         var popup_768c0d98a51ac1a240f84d582f62a812 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2508984c8363c48cc1297a8687096984 = $(`&lt;div id=&quot;html_2508984c8363c48cc1297a8687096984&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_768c0d98a51ac1a240f84d582f62a812.setContent(html_2508984c8363c48cc1297a8687096984);
#
#
#
#         marker_ffe8693edd90fb1c99d2554d188f4ef5.bindPopup(popup_768c0d98a51ac1a240f84d582f62a812)
#         ;
#
#
#
#
#             var marker_de0ac592e6e74f5e04cf4adae59f1b49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e7099998b998e79d0465a90a1dac7764);
#
#
#         var popup_98ab91e851833f040f6adbc3fa09ed94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c78c0bb3ce1b18298ad16eb94f20ce20 = $(`&lt;div id=&quot;html_c78c0bb3ce1b18298ad16eb94f20ce20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_98ab91e851833f040f6adbc3fa09ed94.setContent(html_c78c0bb3ce1b18298ad16eb94f20ce20);
#
#
#
#         marker_de0ac592e6e74f5e04cf4adae59f1b49.bindPopup(popup_98ab91e851833f040f6adbc3fa09ed94)
#         ;
#
#
#
#
#             var marker_d67e14a3d943d08dc5b5cb604df6a803 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e7099998b998e79d0465a90a1dac7764);
#
#
#         var popup_1ab38f245e3be445a3af0cb0edab302b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e49c76e5b51a9de87be12fed3632040d = $(`&lt;div id=&quot;html_e49c76e5b51a9de87be12fed3632040d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1ab38f245e3be445a3af0cb0edab302b.setContent(html_e49c76e5b51a9de87be12fed3632040d);
#
#
#
#         marker_d67e14a3d943d08dc5b5cb604df6a803.bindPopup(popup_1ab38f245e3be445a3af0cb0edab302b)
#         ;
#
#
#
#
#             var marker_3d7b3a13a0d93a0f7f67922f76531945 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e7099998b998e79d0465a90a1dac7764);
#
#
#         var popup_c54d8304f47a73f4ba8e840431bc110f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bc06d3f39769a622c95243b4cfdd154 = $(`&lt;div id=&quot;html_1bc06d3f39769a622c95243b4cfdd154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c54d8304f47a73f4ba8e840431bc110f.setContent(html_1bc06d3f39769a622c95243b4cfdd154);
#
#
#
#         marker_3d7b3a13a0d93a0f7f67922f76531945.bindPopup(popup_c54d8304f47a73f4ba8e840431bc110f)
#         ;
#
#
#
#
#             var marker_9423e62bc8b220b5348540a72048f692 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e7099998b998e79d0465a90a1dac7764);
#
#
#         var popup_99abed55420ac891c180a4e884579cf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a33d5c572d10396a27a398d5c7e09ec9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a33d5c572d10396a27a398d5c7e09ec9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a33d5c572d10396a27a398d5c7e09ec9 = L.map(
#                 &quot;map_a33d5c572d10396a27a398d5c7e09ec9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4317755f7a0b4da7483b2bb4cee9d474 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4317755f7a0b4da7483b2bb4cee9d474.addTo(map_a33d5c572d10396a27a398d5c7e09ec9);
#
#
#             var feature_group_98670ddb62274c0730be06c2837080c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_98670ddb62274c0730be06c2837080c6.addTo(map_a33d5c572d10396a27a398d5c7e09ec9);
#
#
#             var feature_group_sub_group_09b5cf728a442082562460506a0f9a0f = L.featureGroup.subGroup(
#                 feature_group_98670ddb62274c0730be06c2837080c6
#             );
#
#
#             var marker_07c1723969116967f7278660eeb1dc66 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b5cf728a442082562460506a0f9a0f);
#
#
#         var popup_cc588ad266b44568ee288294379dcc6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45e832699d7e2f4ec52b5d09d229e654 = $(`&lt;div id=&quot;html_45e832699d7e2f4ec52b5d09d229e654&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cc588ad266b44568ee288294379dcc6b.setContent(html_45e832699d7e2f4ec52b5d09d229e654);
#
#
#
#         marker_07c1723969116967f7278660eeb1dc66.bindPopup(popup_cc588ad266b44568ee288294379dcc6b)
#         ;
#
#
#
#
#             var marker_c6fb031e20c1b4ed8c7306bd17ddd215 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b5cf728a442082562460506a0f9a0f);
#
#
#         var popup_9eebcd486dc5f38a1ffc1041e772b507 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f726cc4d26e733193150a159d1951395 = $(`&lt;div id=&quot;html_f726cc4d26e733193150a159d1951395&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9eebcd486dc5f38a1ffc1041e772b507.setContent(html_f726cc4d26e733193150a159d1951395);
#
#
#
#         marker_c6fb031e20c1b4ed8c7306bd17ddd215.bindPopup(popup_9eebcd486dc5f38a1ffc1041e772b507)
#         ;
#
#
#
#
#             var marker_65835d593b18ba6dab04e1a2d55a45bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b5cf728a442082562460506a0f9a0f);
#
#
#         var popup_1620fe3b4565b2a23715aff4b614a56d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19422ac3ea9994b55d28a5694c9fcf69 = $(`&lt;div id=&quot;html_19422ac3ea9994b55d28a5694c9fcf69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1620fe3b4565b2a23715aff4b614a56d.setContent(html_19422ac3ea9994b55d28a5694c9fcf69);
#
#
#
#         marker_65835d593b18ba6dab04e1a2d55a45bf.bindPopup(popup_1620fe3b4565b2a23715aff4b614a56d)
#         ;
#
#
#
#
#             var marker_21c2a88368feb91f36829e630d521a6e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b5cf728a442082562460506a0f9a0f);
#
#
#         var popup_d3d563721d2e8f263e8db7903ee7179b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7ab4943d1ad2c2d3f6045fdf6f34a56 = $(`&lt;div id=&quot;html_c7ab4943d1ad2c2d3f6045fdf6f34a56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d3d563721d2e8f263e8db7903ee7179b.setContent(html_c7ab4943d1ad2c2d3f6045fdf6f34a56);
#
#
#
#         mark
