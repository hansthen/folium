# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0a2cd546da136d9e49241bfa6d50934 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0a2cd546da136d9e49241bfa6d50934&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0a2cd546da136d9e49241bfa6d50934 = L.map(
#                 &quot;map_a0a2cd546da136d9e49241bfa6d50934&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d5ce2178bff712874b74b49dcd85624 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d5ce2178bff712874b74b49dcd85624.addTo(map_a0a2cd546da136d9e49241bfa6d50934);
#
#
#             var marker_7726af246a503b737abc2cc3ff8dbe8f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a0a2cd546da136d9e49241bfa6d50934);
#
#
#         var popup_1860c8ec0204c53664dde09ca14d9f50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5aa5f9a6b608491ed9152f507e701f79 = $(`&lt;div id=&quot;html_5aa5f9a6b608491ed9152f507e701f79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1860c8ec0204c53664dde09ca14d9f50.setContent(html_5aa5f9a6b608491ed9152f507e701f79);
#
#
#
#         marker_7726af246a503b737abc2cc3ff8dbe8f.bindPopup(popup_1860c8ec0204c53664dde09ca14d9f50)
#         ;
#
#
#
#
#             var marker_c686fcad65f62b75ee20eb3c6ea6538f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a0a2cd546da136d9e49241bfa6d50934);
#
#
#         var popup_2a6aafe8086a21417a1939075aed6047 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86dd50ed133d5c15a864e30812a51859 = $(`&lt;div id=&quot;html_86dd50ed133d5c15a864e30812a51859&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2a6aafe8086a21417a1939075aed6047.setContent(html_86dd50ed133d5c15a864e30812a51859);
#
#
#
#         marker_c686fcad65f62b75ee20eb3c6ea6538f.bindPopup(popup_2a6aafe8086a21417a1939075aed6047)
#         ;
#
#
#
#
#             var marker_73aac784369017509de0b6aea7cba246 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a0a2cd546da136d9e49241bfa6d50934);
#
#
#         var popup_cf1255090a7892c33fb28b04f02abbec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8ac91b1c587d2abe8c4001c7d8482e0 = $(`&lt;div id=&quot;html_e8ac91b1c587d2abe8c4001c7d8482e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cf1255090a7892c33fb28b04f02abbec.setContent(html_e8ac91b1c587d2abe8c4001c7d8482e0);
#
#
#
#         marker_73aac784369017509de0b6aea7cba246.bindPopup(popup_cf1255090a7892c33fb28b04f02abbec)
#         ;
#
#
#
#
#             var marker_fd51220397bdc1b9fde83150de3e46da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a0a2cd546da136d9e49241bfa6d50934);
#
#
#         var popup_3c1489619fdfeb1d03b202f4b313e53e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10f089c7c8bf0a0223b5323bcc230387 = $(`&lt;div id=&quot;html_10f089c7c8bf0a0223b5323bcc230387&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3c1489619fdfeb1d03b202f4b313e53e.setContent(html_10f089c7c8bf0a0223b5323bcc230387);
#
#
#
#         marker_fd51220397bdc1b9fde83150de3e46da.bindPopup(popup_3c1489619fdfeb1d03b202f4b313e53e)
#         ;
#
#
#
#
#             var marker_6d3b2f3438612d9d1e16807be22d15e1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a0a2cd546da136d9e49241bfa6d50934);
#
#
#         var popup_ba61b6f801275b26e5296ea83bd201c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bbbaa47c24c5318e23403459a883983 = $(`&lt;div id=&quot;html_1bbbaa47c24c5318e23403459a883983&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ba61b6f801275b26e5296ea83bd201c0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65bd21d7829c8983e7e33ab535bc6125 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65bd21d7829c8983e7e33ab535bc6125&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65bd21d7829c8983e7e33ab535bc6125 = L.map(
#                 &quot;map_65bd21d7829c8983e7e33ab535bc6125&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4eefdcb585926d9019694804c7af8ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4eefdcb585926d9019694804c7af8ee.addTo(map_65bd21d7829c8983e7e33ab535bc6125);
#
#
#             var feature_group_26ea097367c5882cf64aceae0bc27ede = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_db9d89d6f102223993584cf42c9b068b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_26ea097367c5882cf64aceae0bc27ede);
#
#
#         var popup_8bd88a13da7d7a37bb6456a83dfa830d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ef44dd15bf8165dae6ade9cd8555c01 = $(`&lt;div id=&quot;html_1ef44dd15bf8165dae6ade9cd8555c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8bd88a13da7d7a37bb6456a83dfa830d.setContent(html_1ef44dd15bf8165dae6ade9cd8555c01);
#
#
#
#         marker_db9d89d6f102223993584cf42c9b068b.bindPopup(popup_8bd88a13da7d7a37bb6456a83dfa830d)
#         ;
#
#
#
#
#             var marker_a8a90c389311f3a3958ff0838113c883 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_26ea097367c5882cf64aceae0bc27ede);
#
#
#         var popup_2a33bf83d3b8c44f0a4bac46aaad8114 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40125651e21915886017f4a8eb07e8a6 = $(`&lt;div id=&quot;html_40125651e21915886017f4a8eb07e8a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2a33bf83d3b8c44f0a4bac46aaad8114.setContent(html_40125651e21915886017f4a8eb07e8a6);
#
#
#
#         marker_a8a90c389311f3a3958ff0838113c883.bindPopup(popup_2a33bf83d3b8c44f0a4bac46aaad8114)
#         ;
#
#
#
#
#             var marker_5e87cebefa8c8ccdc30431b986e2f5e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_26ea097367c5882cf64aceae0bc27ede);
#
#
#         var popup_0011fe5f8b25226466d117a930410a98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8155bb37f7428943ae96bb59629ec18 = $(`&lt;div id=&quot;html_a8155bb37f7428943ae96bb59629ec18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0011fe5f8b25226466d117a930410a98.setContent(html_a8155bb37f7428943ae96bb59629ec18);
#
#
#
#         marker_5e87cebefa8c8ccdc30431b986e2f5e9.bindPopup(popup_0011fe5f8b25226466d117a930410a98)
#         ;
#
#
#
#
#             var marker_ef15d6ca65f72a0712c6b74fdabd2e8f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_26ea097367c5882cf64aceae0bc27ede);
#
#
#         var popup_ba39263d4f6e3ce7e687a47856fe4d94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b38e8639ba51a301194482849f9a3f2a = $(`&lt;div id=&quot;html_b38e8639ba51a301194482849f9a3f2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ba39263d4f6e3ce7e687a47856fe4d94.setContent(html_b38e8639ba51a301194482849f9a3f2a);
#
#
#
#         marker_ef15d6ca65f72a0712c6b74fdabd2e8f.bindPopup(popup_ba39263d4f6e3ce7e687a47856fe4d94)
#         ;
#
#
#
#
#             var marker_795a238a1aa79374e7948161d7d20716 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_26ea097367c5882cf64aceae0bc27ede);
#
#
#         var popup_440baf172e465a9d869640a64ca9260c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65156ee457edaab5f03c5f104d8cfe97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65156ee457edaab5f03c5f104d8cfe97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65156ee457edaab5f03c5f104d8cfe97 = L.map(
#                 &quot;map_65156ee457edaab5f03c5f104d8cfe97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_405c0159d7bee0159fb8fd3e9b5d6d14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_405c0159d7bee0159fb8fd3e9b5d6d14.addTo(map_65156ee457edaab5f03c5f104d8cfe97);
#
#
#             var feature_group_028b8c4e7f71d91867ad54a524f57dcf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_028b8c4e7f71d91867ad54a524f57dcf.addTo(map_65156ee457edaab5f03c5f104d8cfe97);
#
#
#             var feature_group_sub_group_3760c570eefe24218b2069e5bf5a6ab8 = L.featureGroup.subGroup(
#                 feature_group_028b8c4e7f71d91867ad54a524f57dcf
#             );
#
#
#             var marker_8cb0fbdf0377ff4a94640cf8e3435ef5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3760c570eefe24218b2069e5bf5a6ab8);
#
#
#         var popup_17620d16870c185f36f0d29a017c7489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bb27ab565f9fac957672bb678362c63 = $(`&lt;div id=&quot;html_9bb27ab565f9fac957672bb678362c63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_17620d16870c185f36f0d29a017c7489.setContent(html_9bb27ab565f9fac957672bb678362c63);
#
#
#
#         marker_8cb0fbdf0377ff4a94640cf8e3435ef5.bindPopup(popup_17620d16870c185f36f0d29a017c7489)
#         ;
#
#
#
#
#             var marker_e1a7d1c1209c9d51fb860f398cb52bf5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3760c570eefe24218b2069e5bf5a6ab8);
#
#
#         var popup_429a0de2d9ce9951c871a9a84ae699b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dfe0957501a72f1ee77a944a82853e5 = $(`&lt;div id=&quot;html_2dfe0957501a72f1ee77a944a82853e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_429a0de2d9ce9951c871a9a84ae699b3.setContent(html_2dfe0957501a72f1ee77a944a82853e5);
#
#
#
#         marker_e1a7d1c1209c9d51fb860f398cb52bf5.bindPopup(popup_429a0de2d9ce9951c871a9a84ae699b3)
#         ;
#
#
#
#
#             var marker_dcafe8f170e16a7a663337075e04bd91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3760c570eefe24218b2069e5bf5a6ab8);
#
#
#         var popup_77f251856cb6abc42734732410a46418 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c58d07d58e99cc859cafa2a6e7b59b74 = $(`&lt;div id=&quot;html_c58d07d58e99cc859cafa2a6e7b59b74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_77f251856cb6abc42734732410a46418.setContent(html_c58d07d58e99cc859cafa2a6e7b59b74);
#
#
#
#         marker_dcafe8f170e16a7a663337075e04bd91.bindPopup(popup_77f251856cb6abc42734732410a46418)
#         ;
#
#
#
#
#             var marker_5b15ca3b45e377d8c3725e465e768718 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3760c570eefe24218b2069e5bf5a6ab8);
#
#
#         var popup_60755c045d01a8e136261795a5829d14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c90bbb62e19a3f175d255d88788f5442 = $(`&lt;div id=&quot;html_c90bbb62e19a3f175d255d88788f5442&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_60755c045d01a8e136261795a5829d14.setContent(html_c90bbb62e19a3f175d255d88788f5442);
#
#
#
#         marker_
