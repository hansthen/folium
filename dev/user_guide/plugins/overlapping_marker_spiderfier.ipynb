# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5fd3141695032e361ddf828d015c8ef {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5fd3141695032e361ddf828d015c8ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5fd3141695032e361ddf828d015c8ef = L.map(
#                 &quot;map_c5fd3141695032e361ddf828d015c8ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2e966234b8b3c1190426b750de5a8ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2e966234b8b3c1190426b750de5a8ee.addTo(map_c5fd3141695032e361ddf828d015c8ef);
#
#
#             var marker_d4221973544c3413af870aa6daa383ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c5fd3141695032e361ddf828d015c8ef);
#
#
#         var popup_f2c029a7dccf465311044cea4a07a618 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec1fda77ff78d2b8e1bca2b1cad6f179 = $(`&lt;div id=&quot;html_ec1fda77ff78d2b8e1bca2b1cad6f179&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f2c029a7dccf465311044cea4a07a618.setContent(html_ec1fda77ff78d2b8e1bca2b1cad6f179);
#
#
#
#         marker_d4221973544c3413af870aa6daa383ec.bindPopup(popup_f2c029a7dccf465311044cea4a07a618)
#         ;
#
#
#
#
#             var marker_dd8e9734cdc8404131e0238ac5adb61f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c5fd3141695032e361ddf828d015c8ef);
#
#
#         var popup_98a55a58dd82d3f55c81319421fd338c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_116d87494084fc99b01d0eab093d4182 = $(`&lt;div id=&quot;html_116d87494084fc99b01d0eab093d4182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_98a55a58dd82d3f55c81319421fd338c.setContent(html_116d87494084fc99b01d0eab093d4182);
#
#
#
#         marker_dd8e9734cdc8404131e0238ac5adb61f.bindPopup(popup_98a55a58dd82d3f55c81319421fd338c)
#         ;
#
#
#
#
#             var marker_0df13c38ad7e6977147c832d1c957916 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c5fd3141695032e361ddf828d015c8ef);
#
#
#         var popup_234f08ad6b84b4ea343fc8747a9e4883 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8ca28dff2c4fc522ef5fd4d26a47ebc = $(`&lt;div id=&quot;html_b8ca28dff2c4fc522ef5fd4d26a47ebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_234f08ad6b84b4ea343fc8747a9e4883.setContent(html_b8ca28dff2c4fc522ef5fd4d26a47ebc);
#
#
#
#         marker_0df13c38ad7e6977147c832d1c957916.bindPopup(popup_234f08ad6b84b4ea343fc8747a9e4883)
#         ;
#
#
#
#
#             var marker_662d4705a08cc71fa75463ae515d30bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c5fd3141695032e361ddf828d015c8ef);
#
#
#         var popup_a772715bae9793626ba017564b332056 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e0a12bd6a0f8c57f0cfb1e70680f44f = $(`&lt;div id=&quot;html_4e0a12bd6a0f8c57f0cfb1e70680f44f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a772715bae9793626ba017564b332056.setContent(html_4e0a12bd6a0f8c57f0cfb1e70680f44f);
#
#
#
#         marker_662d4705a08cc71fa75463ae515d30bb.bindPopup(popup_a772715bae9793626ba017564b332056)
#         ;
#
#
#
#
#             var marker_79c80ca005205a063387f27a04c8acf2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c5fd3141695032e361ddf828d015c8ef);
#
#
#         var popup_e5630583c9e9a8ac3af93b49eaaf2cf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3453720434113253e913f23dcecada63 = $(`&lt;div id=&quot;html_3453720434113253e913f23dcecada63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e5630583c9e9a8ac3af93b49eaaf2c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66708423514651594401e715a4b3ec2e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66708423514651594401e715a4b3ec2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66708423514651594401e715a4b3ec2e = L.map(
#                 &quot;map_66708423514651594401e715a4b3ec2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7413e6a5a627a25c7c8d759a679fef5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7413e6a5a627a25c7c8d759a679fef5.addTo(map_66708423514651594401e715a4b3ec2e);
#
#
#             var feature_group_70c57e12cb23c6ce0b186aa8bf6ef8fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_93f57b3abfe3c55f27557adb3dda7cf1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_70c57e12cb23c6ce0b186aa8bf6ef8fb);
#
#
#         var popup_e658d09361217857695709c226037174 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e744a6932140c4704f073ad7fb26f61 = $(`&lt;div id=&quot;html_2e744a6932140c4704f073ad7fb26f61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e658d09361217857695709c226037174.setContent(html_2e744a6932140c4704f073ad7fb26f61);
#
#
#
#         marker_93f57b3abfe3c55f27557adb3dda7cf1.bindPopup(popup_e658d09361217857695709c226037174)
#         ;
#
#
#
#
#             var marker_e2e5fce449cd63e6bf7fc12fb81bc109 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_70c57e12cb23c6ce0b186aa8bf6ef8fb);
#
#
#         var popup_3787615bcb2ffe8aa9ebbce902755fe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0f8dd3f96476bf95be4f882270635c9 = $(`&lt;div id=&quot;html_c0f8dd3f96476bf95be4f882270635c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3787615bcb2ffe8aa9ebbce902755fe4.setContent(html_c0f8dd3f96476bf95be4f882270635c9);
#
#
#
#         marker_e2e5fce449cd63e6bf7fc12fb81bc109.bindPopup(popup_3787615bcb2ffe8aa9ebbce902755fe4)
#         ;
#
#
#
#
#             var marker_681758dec59eea1fc2a8748d1fb9c90d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_70c57e12cb23c6ce0b186aa8bf6ef8fb);
#
#
#         var popup_435ec31fa78370b64e289bece60e9300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_476434d5f6ee43b8357c03bc307fa27f = $(`&lt;div id=&quot;html_476434d5f6ee43b8357c03bc307fa27f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_435ec31fa78370b64e289bece60e9300.setContent(html_476434d5f6ee43b8357c03bc307fa27f);
#
#
#
#         marker_681758dec59eea1fc2a8748d1fb9c90d.bindPopup(popup_435ec31fa78370b64e289bece60e9300)
#         ;
#
#
#
#
#             var marker_cd3ccd211911ae020c30aec8356d4158 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_70c57e12cb23c6ce0b186aa8bf6ef8fb);
#
#
#         var popup_51b9aa32d298d8b86323c3bda59c57ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2aad0877ab040a6c0f391d580a9766e0 = $(`&lt;div id=&quot;html_2aad0877ab040a6c0f391d580a9766e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_51b9aa32d298d8b86323c3bda59c57ff.setContent(html_2aad0877ab040a6c0f391d580a9766e0);
#
#
#
#         marker_cd3ccd211911ae020c30aec8356d4158.bindPopup(popup_51b9aa32d298d8b86323c3bda59c57ff)
#         ;
#
#
#
#
#             var marker_a9b9ffd6788bb2985af7843f06b7c272 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_70c57e12cb23c6ce0b186aa8bf6ef8fb);
#
#
#         var popup_5e1e2ebfac5bf43377547a8530141b1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a1dc437e359835d1649ecf528174905 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a1dc437e359835d1649ecf528174905&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a1dc437e359835d1649ecf528174905 = L.map(
#                 &quot;map_9a1dc437e359835d1649ecf528174905&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_000cd3d0369cf153712b6b80863f02ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_000cd3d0369cf153712b6b80863f02ac.addTo(map_9a1dc437e359835d1649ecf528174905);
#
#
#             var feature_group_1e3dedc6c93ef7973ec5322fb93ca6db = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1e3dedc6c93ef7973ec5322fb93ca6db.addTo(map_9a1dc437e359835d1649ecf528174905);
#
#
#             var feature_group_sub_group_fb7f566bf2551eae5fe8b01632c61d37 = L.featureGroup.subGroup(
#                 feature_group_1e3dedc6c93ef7973ec5322fb93ca6db
#             );
#
#
#             var marker_288c91f2a8f15f586e756ffbe072367c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb7f566bf2551eae5fe8b01632c61d37);
#
#
#         var popup_cd5b6b4b95dd6d714d3547395bf45b1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbee9ec71fd624a45117a6eb8233b4d1 = $(`&lt;div id=&quot;html_dbee9ec71fd624a45117a6eb8233b4d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cd5b6b4b95dd6d714d3547395bf45b1a.setContent(html_dbee9ec71fd624a45117a6eb8233b4d1);
#
#
#
#         marker_288c91f2a8f15f586e756ffbe072367c.bindPopup(popup_cd5b6b4b95dd6d714d3547395bf45b1a)
#         ;
#
#
#
#
#             var marker_223fd25691bfba2c89c4d75c7b6e4af9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb7f566bf2551eae5fe8b01632c61d37);
#
#
#         var popup_27fac9b65d58a3513cdb1c725298354e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce67434c55fd7fa334ec67a5fc6cbe37 = $(`&lt;div id=&quot;html_ce67434c55fd7fa334ec67a5fc6cbe37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_27fac9b65d58a3513cdb1c725298354e.setContent(html_ce67434c55fd7fa334ec67a5fc6cbe37);
#
#
#
#         marker_223fd25691bfba2c89c4d75c7b6e4af9.bindPopup(popup_27fac9b65d58a3513cdb1c725298354e)
#         ;
#
#
#
#
#             var marker_5f680fcf413e7cfb2c85a5af91577f6b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb7f566bf2551eae5fe8b01632c61d37);
#
#
#         var popup_d2e3a92899c19b3d5e59927dbb4cbf41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14d3f80ddaa57c7f90503e80e8245444 = $(`&lt;div id=&quot;html_14d3f80ddaa57c7f90503e80e8245444&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d2e3a92899c19b3d5e59927dbb4cbf41.setContent(html_14d3f80ddaa57c7f90503e80e8245444);
#
#
#
#         marker_5f680fcf413e7cfb2c85a5af91577f6b.bindPopup(popup_d2e3a92899c19b3d5e59927dbb4cbf41)
#         ;
#
#
#
#
#             var marker_b3ce38645f59d8696f7971ff59862cee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb7f566bf2551eae5fe8b01632c61d37);
#
#
#         var popup_7566734ed46e8abe4247d2614e8aac73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ffd38d8fd1627bcf79c352b2f77907a = $(`&lt;div id=&quot;html_6ffd38d8fd1627bcf79c352b2f77907a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7566734ed46e8abe4247d2614e8aac73.setContent(html_6ffd38d8fd1627bcf79c352b2f77907a);
#
#
#
#         mark
