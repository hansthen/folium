# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48572d5ae53b9c916fa30325879128a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48572d5ae53b9c916fa30325879128a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48572d5ae53b9c916fa30325879128a5 = L.map(
#                 &quot;map_48572d5ae53b9c916fa30325879128a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a87a2980f3a5b65913e4494acbdbc2de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a87a2980f3a5b65913e4494acbdbc2de.addTo(map_48572d5ae53b9c916fa30325879128a5);
#
#
#             var marker_1d41fbb190df302800820eb4f9f77e78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_48572d5ae53b9c916fa30325879128a5);
#
#
#         var popup_a518f8fe740c3e52ebe77eee47381d97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91871af10106740829185d1e0ecabe7a = $(`&lt;div id=&quot;html_91871af10106740829185d1e0ecabe7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a518f8fe740c3e52ebe77eee47381d97.setContent(html_91871af10106740829185d1e0ecabe7a);
#
#
#
#         marker_1d41fbb190df302800820eb4f9f77e78.bindPopup(popup_a518f8fe740c3e52ebe77eee47381d97)
#         ;
#
#
#
#
#             var marker_6ed8b33cab92d024319a7bb96d2c5af4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_48572d5ae53b9c916fa30325879128a5);
#
#
#         var popup_b0eef8dd9f4ae3ed8e0e05fe3f848a25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0820cb6191cef3b21c2bae820e71c9c = $(`&lt;div id=&quot;html_c0820cb6191cef3b21c2bae820e71c9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b0eef8dd9f4ae3ed8e0e05fe3f848a25.setContent(html_c0820cb6191cef3b21c2bae820e71c9c);
#
#
#
#         marker_6ed8b33cab92d024319a7bb96d2c5af4.bindPopup(popup_b0eef8dd9f4ae3ed8e0e05fe3f848a25)
#         ;
#
#
#
#
#             var marker_16ab20d041a62cd3af6c8ed058a7bf1c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_48572d5ae53b9c916fa30325879128a5);
#
#
#         var popup_5e750fc3511af5db160341fcb82bbbd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e67358943b2d1302da6c0fe86a74c513 = $(`&lt;div id=&quot;html_e67358943b2d1302da6c0fe86a74c513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5e750fc3511af5db160341fcb82bbbd9.setContent(html_e67358943b2d1302da6c0fe86a74c513);
#
#
#
#         marker_16ab20d041a62cd3af6c8ed058a7bf1c.bindPopup(popup_5e750fc3511af5db160341fcb82bbbd9)
#         ;
#
#
#
#
#             var marker_b5c7e774774185c9953d9700e0665f00 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_48572d5ae53b9c916fa30325879128a5);
#
#
#         var popup_f479b71c2573c7177cafe03f92e309e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59ede150e526d1dab2388e0b0932677b = $(`&lt;div id=&quot;html_59ede150e526d1dab2388e0b0932677b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f479b71c2573c7177cafe03f92e309e1.setContent(html_59ede150e526d1dab2388e0b0932677b);
#
#
#
#         marker_b5c7e774774185c9953d9700e0665f00.bindPopup(popup_f479b71c2573c7177cafe03f92e309e1)
#         ;
#
#
#
#
#             var marker_92bb626900593140cadbf464f8b0a12e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_48572d5ae53b9c916fa30325879128a5);
#
#
#         var popup_fed316854dff783592d3436d17f3270a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_398f6549ea3d43edd674b04ba443b8e7 = $(`&lt;div id=&quot;html_398f6549ea3d43edd674b04ba443b8e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fed316854dff783592d3436d17f3270a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef1d7c2f2d993fae3f884c2293fed02b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef1d7c2f2d993fae3f884c2293fed02b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef1d7c2f2d993fae3f884c2293fed02b = L.map(
#                 &quot;map_ef1d7c2f2d993fae3f884c2293fed02b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9fdf378db2634bfc9bb205e9d24de80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9fdf378db2634bfc9bb205e9d24de80.addTo(map_ef1d7c2f2d993fae3f884c2293fed02b);
#
#
#             var feature_group_54a34e090c2ed458e1ef1e3d8bca2c33 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_181f5e8f893fac2b5423d5e7327213cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_54a34e090c2ed458e1ef1e3d8bca2c33);
#
#
#         var popup_500f42bff7f766b8250d5e386761544f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc372b7a3d447c469f7eabd006b81c11 = $(`&lt;div id=&quot;html_bc372b7a3d447c469f7eabd006b81c11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_500f42bff7f766b8250d5e386761544f.setContent(html_bc372b7a3d447c469f7eabd006b81c11);
#
#
#
#         marker_181f5e8f893fac2b5423d5e7327213cf.bindPopup(popup_500f42bff7f766b8250d5e386761544f)
#         ;
#
#
#
#
#             var marker_954442dfe423903895e837e401040640 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_54a34e090c2ed458e1ef1e3d8bca2c33);
#
#
#         var popup_ff0b29a6d77cc683286c14a36e53ec42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be339dc2feaa62cb0ae0657723e16100 = $(`&lt;div id=&quot;html_be339dc2feaa62cb0ae0657723e16100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ff0b29a6d77cc683286c14a36e53ec42.setContent(html_be339dc2feaa62cb0ae0657723e16100);
#
#
#
#         marker_954442dfe423903895e837e401040640.bindPopup(popup_ff0b29a6d77cc683286c14a36e53ec42)
#         ;
#
#
#
#
#             var marker_763991c3972e525f56e5fd03e0a9e92e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_54a34e090c2ed458e1ef1e3d8bca2c33);
#
#
#         var popup_4798465639aa496caee357137e521eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52bbf7f362fb43ec6f78f46f8a6cad0e = $(`&lt;div id=&quot;html_52bbf7f362fb43ec6f78f46f8a6cad0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4798465639aa496caee357137e521eb9.setContent(html_52bbf7f362fb43ec6f78f46f8a6cad0e);
#
#
#
#         marker_763991c3972e525f56e5fd03e0a9e92e.bindPopup(popup_4798465639aa496caee357137e521eb9)
#         ;
#
#
#
#
#             var marker_623cb65cd22bba53a517209b5d78bb5a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_54a34e090c2ed458e1ef1e3d8bca2c33);
#
#
#         var popup_25c86ce4f69482aeb087ee7d281bf976 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c383ad14969c68c3c1bd7d06c3c3c318 = $(`&lt;div id=&quot;html_c383ad14969c68c3c1bd7d06c3c3c318&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_25c86ce4f69482aeb087ee7d281bf976.setContent(html_c383ad14969c68c3c1bd7d06c3c3c318);
#
#
#
#         marker_623cb65cd22bba53a517209b5d78bb5a.bindPopup(popup_25c86ce4f69482aeb087ee7d281bf976)
#         ;
#
#
#
#
#             var marker_ea04bf3d66fcfbe2f349c6fcfdc8309f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_54a34e090c2ed458e1ef1e3d8bca2c33);
#
#
#         var popup_1882fb9f068b505bcb8797969090c866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6550955644d5fc1a4b6f65d6b64aa2da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6550955644d5fc1a4b6f65d6b64aa2da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6550955644d5fc1a4b6f65d6b64aa2da = L.map(
#                 &quot;map_6550955644d5fc1a4b6f65d6b64aa2da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_825107e42a6f74146b846e0fa39c874d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_825107e42a6f74146b846e0fa39c874d.addTo(map_6550955644d5fc1a4b6f65d6b64aa2da);
#
#
#             var feature_group_a6bcc6adfc33b93568ea7fc115c398ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a6bcc6adfc33b93568ea7fc115c398ee.addTo(map_6550955644d5fc1a4b6f65d6b64aa2da);
#
#
#             var feature_group_sub_group_e145e891d217dfc4cc09473492327135 = L.featureGroup.subGroup(
#                 feature_group_a6bcc6adfc33b93568ea7fc115c398ee
#             );
#
#
#             var marker_e6388c278a70a03a0d5a7a887875fd58 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e145e891d217dfc4cc09473492327135);
#
#
#         var popup_b5312937bb7173d4b972719ac30c4515 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2bfd1f0d940e831bd9ef2ee211abd47 = $(`&lt;div id=&quot;html_a2bfd1f0d940e831bd9ef2ee211abd47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b5312937bb7173d4b972719ac30c4515.setContent(html_a2bfd1f0d940e831bd9ef2ee211abd47);
#
#
#
#         marker_e6388c278a70a03a0d5a7a887875fd58.bindPopup(popup_b5312937bb7173d4b972719ac30c4515)
#         ;
#
#
#
#
#             var marker_3dc7794449896a18f5b359e173814ad8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e145e891d217dfc4cc09473492327135);
#
#
#         var popup_e0aad4037ed9887faf09851e2e9334c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b7ec6a9fe39a68834c43c01c479bc46 = $(`&lt;div id=&quot;html_0b7ec6a9fe39a68834c43c01c479bc46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0aad4037ed9887faf09851e2e9334c2.setContent(html_0b7ec6a9fe39a68834c43c01c479bc46);
#
#
#
#         marker_3dc7794449896a18f5b359e173814ad8.bindPopup(popup_e0aad4037ed9887faf09851e2e9334c2)
#         ;
#
#
#
#
#             var marker_0c66b8d3c695c44ebe7212eba2c8b159 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e145e891d217dfc4cc09473492327135);
#
#
#         var popup_c3a7be59c2b07175ba0e0345ba331c48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40570afd96b59101084991f13ae33b68 = $(`&lt;div id=&quot;html_40570afd96b59101084991f13ae33b68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c3a7be59c2b07175ba0e0345ba331c48.setContent(html_40570afd96b59101084991f13ae33b68);
#
#
#
#         marker_0c66b8d3c695c44ebe7212eba2c8b159.bindPopup(popup_c3a7be59c2b07175ba0e0345ba331c48)
#         ;
#
#
#
#
#             var marker_3a81ddfec5a5bfe81bb6772266cbcee8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e145e891d217dfc4cc09473492327135);
#
#
#         var popup_dadb70d9b658b80beacef23ebf575283 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3908a64ff53aceca7ec88d64e23d35bb = $(`&lt;div id=&quot;html_3908a64ff53aceca7ec88d64e23d35bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dadb70d9b658b80beacef23ebf575283.setContent(html_3908a64ff53aceca7ec88d64e23d35bb);
#
#
#
#         marker_
