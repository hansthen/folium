# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfe2ad14dae7aaf78c4c5d1518842a50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfe2ad14dae7aaf78c4c5d1518842a50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfe2ad14dae7aaf78c4c5d1518842a50 = L.map(
#                 &quot;map_dfe2ad14dae7aaf78c4c5d1518842a50&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39885ac8853c5d99601a3e20f8f52385 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39885ac8853c5d99601a3e20f8f52385.addTo(map_dfe2ad14dae7aaf78c4c5d1518842a50);
#
#
#             var marker_9b02601123447ef52ad7d8c947af92b6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dfe2ad14dae7aaf78c4c5d1518842a50);
#
#
#         var popup_9bebd9d9711748b9a67d652c0907ba89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e0a2ca87123ac0f063740cad6acd0d5 = $(`&lt;div id=&quot;html_7e0a2ca87123ac0f063740cad6acd0d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9bebd9d9711748b9a67d652c0907ba89.setContent(html_7e0a2ca87123ac0f063740cad6acd0d5);
#
#
#
#         marker_9b02601123447ef52ad7d8c947af92b6.bindPopup(popup_9bebd9d9711748b9a67d652c0907ba89)
#         ;
#
#
#
#
#             var marker_646c6472a674653131cfc15b17343100 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dfe2ad14dae7aaf78c4c5d1518842a50);
#
#
#         var popup_5d7538d6c1126e5c705bc375c54939ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17be1ca2f2f3a009ebff9cb643bb3a25 = $(`&lt;div id=&quot;html_17be1ca2f2f3a009ebff9cb643bb3a25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5d7538d6c1126e5c705bc375c54939ab.setContent(html_17be1ca2f2f3a009ebff9cb643bb3a25);
#
#
#
#         marker_646c6472a674653131cfc15b17343100.bindPopup(popup_5d7538d6c1126e5c705bc375c54939ab)
#         ;
#
#
#
#
#             var marker_684f8370bd0bda76910e6d306c1cf447 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dfe2ad14dae7aaf78c4c5d1518842a50);
#
#
#         var popup_a2343d66c56261a9cf14790feea7c1db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95946f53c741e53be646212236a88e47 = $(`&lt;div id=&quot;html_95946f53c741e53be646212236a88e47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a2343d66c56261a9cf14790feea7c1db.setContent(html_95946f53c741e53be646212236a88e47);
#
#
#
#         marker_684f8370bd0bda76910e6d306c1cf447.bindPopup(popup_a2343d66c56261a9cf14790feea7c1db)
#         ;
#
#
#
#
#             var marker_6224ca506ce13135db028735355f1853 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dfe2ad14dae7aaf78c4c5d1518842a50);
#
#
#         var popup_c295984fed3225dfe7aabedf43237b8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6b774cfae813175f8bb401c40fbaf90 = $(`&lt;div id=&quot;html_e6b774cfae813175f8bb401c40fbaf90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c295984fed3225dfe7aabedf43237b8e.setContent(html_e6b774cfae813175f8bb401c40fbaf90);
#
#
#
#         marker_6224ca506ce13135db028735355f1853.bindPopup(popup_c295984fed3225dfe7aabedf43237b8e)
#         ;
#
#
#
#
#             var marker_8f76b91b8d9b4c0710a5db2d25b37260 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dfe2ad14dae7aaf78c4c5d1518842a50);
#
#
#         var popup_dcc036b1e79e9d8ac9fd82ff38c1bae5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_300736edccdf0dc6a7cdd1eff2fa5bb4 = $(`&lt;div id=&quot;html_300736edccdf0dc6a7cdd1eff2fa5bb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dcc036b1e79e9d8ac9fd82ff38c1bae5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db948a262bb9c66ac68e0101fa35cbe0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db948a262bb9c66ac68e0101fa35cbe0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db948a262bb9c66ac68e0101fa35cbe0 = L.map(
#                 &quot;map_db948a262bb9c66ac68e0101fa35cbe0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d16394cce3c39c87fad6b0591efc495a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d16394cce3c39c87fad6b0591efc495a.addTo(map_db948a262bb9c66ac68e0101fa35cbe0);
#
#
#             var feature_group_19ab2c61c0e7593e0d7fb900ed5276ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4dc3c05d3aabc4ccabd9417be68bdd24 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_19ab2c61c0e7593e0d7fb900ed5276ee);
#
#
#         var popup_b369f75b626047b76062b7c70e61ef30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e094ea353f2407bcb1292dbbcb4912f = $(`&lt;div id=&quot;html_8e094ea353f2407bcb1292dbbcb4912f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b369f75b626047b76062b7c70e61ef30.setContent(html_8e094ea353f2407bcb1292dbbcb4912f);
#
#
#
#         marker_4dc3c05d3aabc4ccabd9417be68bdd24.bindPopup(popup_b369f75b626047b76062b7c70e61ef30)
#         ;
#
#
#
#
#             var marker_81e429717ab7822491d843893ed8c79c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_19ab2c61c0e7593e0d7fb900ed5276ee);
#
#
#         var popup_a909e0a07202ff58e9a3e9fa42f61d8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6b7e3223bf64ce3440fd41a4c53fe10 = $(`&lt;div id=&quot;html_b6b7e3223bf64ce3440fd41a4c53fe10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a909e0a07202ff58e9a3e9fa42f61d8a.setContent(html_b6b7e3223bf64ce3440fd41a4c53fe10);
#
#
#
#         marker_81e429717ab7822491d843893ed8c79c.bindPopup(popup_a909e0a07202ff58e9a3e9fa42f61d8a)
#         ;
#
#
#
#
#             var marker_4c1dbe7d1b1f0161d911487a5a671bb4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_19ab2c61c0e7593e0d7fb900ed5276ee);
#
#
#         var popup_7668b63d18766254d01af64ee7c94cc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b0ed2326c99391cdaa8f45aebcdb12c = $(`&lt;div id=&quot;html_3b0ed2326c99391cdaa8f45aebcdb12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7668b63d18766254d01af64ee7c94cc8.setContent(html_3b0ed2326c99391cdaa8f45aebcdb12c);
#
#
#
#         marker_4c1dbe7d1b1f0161d911487a5a671bb4.bindPopup(popup_7668b63d18766254d01af64ee7c94cc8)
#         ;
#
#
#
#
#             var marker_68caf53a224b9ad6b9064860bf0ff683 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_19ab2c61c0e7593e0d7fb900ed5276ee);
#
#
#         var popup_42db6b8d9b0ac5c5d037a15b2c117fbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_613dcbf1594ecd909ff90cbd9bddaf94 = $(`&lt;div id=&quot;html_613dcbf1594ecd909ff90cbd9bddaf94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_42db6b8d9b0ac5c5d037a15b2c117fbc.setContent(html_613dcbf1594ecd909ff90cbd9bddaf94);
#
#
#
#         marker_68caf53a224b9ad6b9064860bf0ff683.bindPopup(popup_42db6b8d9b0ac5c5d037a15b2c117fbc)
#         ;
#
#
#
#
#             var marker_6b5e435193f2833c85aa79dd70165212 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_19ab2c61c0e7593e0d7fb900ed5276ee);
#
#
#         var popup_1a8b15525196143fa9871385cf311dfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41dbfff7aee50142209e052eb8a01f2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41dbfff7aee50142209e052eb8a01f2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41dbfff7aee50142209e052eb8a01f2b = L.map(
#                 &quot;map_41dbfff7aee50142209e052eb8a01f2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99d9ed82cb3d7e676c8c218bf7f8beb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99d9ed82cb3d7e676c8c218bf7f8beb6.addTo(map_41dbfff7aee50142209e052eb8a01f2b);
#
#
#             var feature_group_d93096195030f7242568ba010b8a645b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d93096195030f7242568ba010b8a645b.addTo(map_41dbfff7aee50142209e052eb8a01f2b);
#
#
#             var feature_group_sub_group_b2e102fb4bd07868cfc58ae2b682d0ea = L.featureGroup.subGroup(
#                 feature_group_d93096195030f7242568ba010b8a645b
#             );
#
#
#             var marker_05bcb99bda756933aa1ddd84588ca9a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2e102fb4bd07868cfc58ae2b682d0ea);
#
#
#         var popup_0c4cca553ae8090c4243e7369ed9fc6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f55c5c2c09c66341915dd8e61a7eb17 = $(`&lt;div id=&quot;html_3f55c5c2c09c66341915dd8e61a7eb17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0c4cca553ae8090c4243e7369ed9fc6b.setContent(html_3f55c5c2c09c66341915dd8e61a7eb17);
#
#
#
#         marker_05bcb99bda756933aa1ddd84588ca9a2.bindPopup(popup_0c4cca553ae8090c4243e7369ed9fc6b)
#         ;
#
#
#
#
#             var marker_6c1ce68d142c6e6d06acb50884dbf83d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2e102fb4bd07868cfc58ae2b682d0ea);
#
#
#         var popup_03769872436182d57defeda629fce813 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6baffb076573f8caffef56295e805c40 = $(`&lt;div id=&quot;html_6baffb076573f8caffef56295e805c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_03769872436182d57defeda629fce813.setContent(html_6baffb076573f8caffef56295e805c40);
#
#
#
#         marker_6c1ce68d142c6e6d06acb50884dbf83d.bindPopup(popup_03769872436182d57defeda629fce813)
#         ;
#
#
#
#
#             var marker_01741ede0f98fa3508c6cd6ecd47fd81 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2e102fb4bd07868cfc58ae2b682d0ea);
#
#
#         var popup_42879bf9c0f58cf61e0e9c2aac09baec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0eb196d4f480b83cde249bff6dd4a7d9 = $(`&lt;div id=&quot;html_0eb196d4f480b83cde249bff6dd4a7d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_42879bf9c0f58cf61e0e9c2aac09baec.setContent(html_0eb196d4f480b83cde249bff6dd4a7d9);
#
#
#
#         marker_01741ede0f98fa3508c6cd6ecd47fd81.bindPopup(popup_42879bf9c0f58cf61e0e9c2aac09baec)
#         ;
#
#
#
#
#             var marker_8f44f9787563ba18f5cbbf8edf2346e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2e102fb4bd07868cfc58ae2b682d0ea);
#
#
#         var popup_ddaa3a9e7b3a6d037898a57c91d7f29a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d307d25150730989286440dab6e6d36 = $(`&lt;div id=&quot;html_6d307d25150730989286440dab6e6d36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ddaa3a9e7b3a6d037898a57c91d7f29a.setContent(html_6d307d25150730989286440dab6e6d36);
#
#
#
#         marker_
