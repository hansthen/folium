# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94d96ead7e12383219f32fc9544281ce {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94d96ead7e12383219f32fc9544281ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94d96ead7e12383219f32fc9544281ce = L.map(
#                 &quot;map_94d96ead7e12383219f32fc9544281ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14a14ee7a2d4d32dc1bd05238b8e487f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14a14ee7a2d4d32dc1bd05238b8e487f.addTo(map_94d96ead7e12383219f32fc9544281ce);
#
#
#             var marker_7869d4797027c871da466faa990cacdf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94d96ead7e12383219f32fc9544281ce);
#
#
#         var popup_b4b52236c13c805bae3b3a8372a7329b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca5af32eb6a7356f0cf85695db739055 = $(`&lt;div id=&quot;html_ca5af32eb6a7356f0cf85695db739055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b4b52236c13c805bae3b3a8372a7329b.setContent(html_ca5af32eb6a7356f0cf85695db739055);
#
#
#
#         marker_7869d4797027c871da466faa990cacdf.bindPopup(popup_b4b52236c13c805bae3b3a8372a7329b)
#         ;
#
#
#
#
#             var marker_b654c331c102334677ec3980840e3def = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94d96ead7e12383219f32fc9544281ce);
#
#
#         var popup_2a427fdd8fc76c5d2edf80744afe1101 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0bfd6a9ea58d10b71b469529f59cd19 = $(`&lt;div id=&quot;html_f0bfd6a9ea58d10b71b469529f59cd19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2a427fdd8fc76c5d2edf80744afe1101.setContent(html_f0bfd6a9ea58d10b71b469529f59cd19);
#
#
#
#         marker_b654c331c102334677ec3980840e3def.bindPopup(popup_2a427fdd8fc76c5d2edf80744afe1101)
#         ;
#
#
#
#
#             var marker_171219234b2ef3b6f38d87c33f87c0ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94d96ead7e12383219f32fc9544281ce);
#
#
#         var popup_c00d0c45bbd013f478fc59e1784b96de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8086c09745c82fb7207d9eed1b977602 = $(`&lt;div id=&quot;html_8086c09745c82fb7207d9eed1b977602&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c00d0c45bbd013f478fc59e1784b96de.setContent(html_8086c09745c82fb7207d9eed1b977602);
#
#
#
#         marker_171219234b2ef3b6f38d87c33f87c0ad.bindPopup(popup_c00d0c45bbd013f478fc59e1784b96de)
#         ;
#
#
#
#
#             var marker_082afa99418fbfe76032f92a7f53449f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94d96ead7e12383219f32fc9544281ce);
#
#
#         var popup_fd4319ba36834d657c7727ef05e090ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef3b5e7c5a946b10882a4117107ac890 = $(`&lt;div id=&quot;html_ef3b5e7c5a946b10882a4117107ac890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fd4319ba36834d657c7727ef05e090ec.setContent(html_ef3b5e7c5a946b10882a4117107ac890);
#
#
#
#         marker_082afa99418fbfe76032f92a7f53449f.bindPopup(popup_fd4319ba36834d657c7727ef05e090ec)
#         ;
#
#
#
#
#             var marker_6545250c6ce1ff16dc8e7cec58ee6687 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94d96ead7e12383219f32fc9544281ce);
#
#
#         var popup_cbaf6e17df6118275f3cbf8ad897ef2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d30aff215ad71ec172f9add841bb920 = $(`&lt;div id=&quot;html_2d30aff215ad71ec172f9add841bb920&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cbaf6e17df6118275f3cbf8ad897ef

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baf2686e3d4b9564413ea6d74ce7a932 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baf2686e3d4b9564413ea6d74ce7a932&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_baf2686e3d4b9564413ea6d74ce7a932 = L.map(
#                 &quot;map_baf2686e3d4b9564413ea6d74ce7a932&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c662d893c6c4d16b8352061d9303d08d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c662d893c6c4d16b8352061d9303d08d.addTo(map_baf2686e3d4b9564413ea6d74ce7a932);
#
#
#             var feature_group_f7995518a5c52018f32fc6aa3b436418 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6ae47b703bc40dbe3257efc8dcce9cdb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f7995518a5c52018f32fc6aa3b436418);
#
#
#         var popup_55b45273ec5eded105c63e10044fba71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bfe9e0220f958b9fd18e77fb4a13760 = $(`&lt;div id=&quot;html_2bfe9e0220f958b9fd18e77fb4a13760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_55b45273ec5eded105c63e10044fba71.setContent(html_2bfe9e0220f958b9fd18e77fb4a13760);
#
#
#
#         marker_6ae47b703bc40dbe3257efc8dcce9cdb.bindPopup(popup_55b45273ec5eded105c63e10044fba71)
#         ;
#
#
#
#
#             var marker_b1cdac8951d8de2e65b3f0a8a192bed0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f7995518a5c52018f32fc6aa3b436418);
#
#
#         var popup_bcf3ea18c408982d673987f2c32d1c98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cd89ed08ebbfae400d7aee090372fad = $(`&lt;div id=&quot;html_8cd89ed08ebbfae400d7aee090372fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bcf3ea18c408982d673987f2c32d1c98.setContent(html_8cd89ed08ebbfae400d7aee090372fad);
#
#
#
#         marker_b1cdac8951d8de2e65b3f0a8a192bed0.bindPopup(popup_bcf3ea18c408982d673987f2c32d1c98)
#         ;
#
#
#
#
#             var marker_4ae71cbc245f89d00f835bba7a685b65 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f7995518a5c52018f32fc6aa3b436418);
#
#
#         var popup_d797fc54c76d7a6a6ee731bdd6890aec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8f4d11b13d090979c1c477921c09728 = $(`&lt;div id=&quot;html_b8f4d11b13d090979c1c477921c09728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d797fc54c76d7a6a6ee731bdd6890aec.setContent(html_b8f4d11b13d090979c1c477921c09728);
#
#
#
#         marker_4ae71cbc245f89d00f835bba7a685b65.bindPopup(popup_d797fc54c76d7a6a6ee731bdd6890aec)
#         ;
#
#
#
#
#             var marker_3c400de015407ebbed63447315ac0369 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f7995518a5c52018f32fc6aa3b436418);
#
#
#         var popup_7aeaed3cd6812c97c0726e7cf2d8e79c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab44458900d67e00f6325b3d7d95152f = $(`&lt;div id=&quot;html_ab44458900d67e00f6325b3d7d95152f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7aeaed3cd6812c97c0726e7cf2d8e79c.setContent(html_ab44458900d67e00f6325b3d7d95152f);
#
#
#
#         marker_3c400de015407ebbed63447315ac0369.bindPopup(popup_7aeaed3cd6812c97c0726e7cf2d8e79c)
#         ;
#
#
#
#
#             var marker_60f1ef498399a6606e6e4ad4e7233ac5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f7995518a5c52018f32fc6aa3b436418);
#
#
#         var popup_5c55f49b2e928fd14fbd943edbbee743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e624343855bc18bbd28454b2e6e1b85d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e624343855bc18bbd28454b2e6e1b85d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e624343855bc18bbd28454b2e6e1b85d = L.map(
#                 &quot;map_e624343855bc18bbd28454b2e6e1b85d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9d41a68fd0ff6fbf4c46f13e7368f08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f9d41a68fd0ff6fbf4c46f13e7368f08.addTo(map_e624343855bc18bbd28454b2e6e1b85d);
#
#
#             var feature_group_d34fcd76ec89d2cdd22b04b4251346d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d34fcd76ec89d2cdd22b04b4251346d0.addTo(map_e624343855bc18bbd28454b2e6e1b85d);
#
#
#             var feature_group_sub_group_551ba0a96783249df158bad2be55a856 = L.featureGroup.subGroup(
#                 feature_group_d34fcd76ec89d2cdd22b04b4251346d0
#             );
#
#
#             var marker_e53f17d4c937065d31d1f9462dd5d7be = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_551ba0a96783249df158bad2be55a856);
#
#
#         var popup_c0d54550262cd0e6a80836d5f230f9c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c60e392617c310c13c06a8b7db1f1b6e = $(`&lt;div id=&quot;html_c60e392617c310c13c06a8b7db1f1b6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c0d54550262cd0e6a80836d5f230f9c3.setContent(html_c60e392617c310c13c06a8b7db1f1b6e);
#
#
#
#         marker_e53f17d4c937065d31d1f9462dd5d7be.bindPopup(popup_c0d54550262cd0e6a80836d5f230f9c3)
#         ;
#
#
#
#
#             var marker_6500742bfdecaa7f2221ce5966c943d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_551ba0a96783249df158bad2be55a856);
#
#
#         var popup_210aabd3e56584baf3751b624fcb55a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_931ff3ea1865ee84b74a88eef99f70c6 = $(`&lt;div id=&quot;html_931ff3ea1865ee84b74a88eef99f70c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_210aabd3e56584baf3751b624fcb55a0.setContent(html_931ff3ea1865ee84b74a88eef99f70c6);
#
#
#
#         marker_6500742bfdecaa7f2221ce5966c943d3.bindPopup(popup_210aabd3e56584baf3751b624fcb55a0)
#         ;
#
#
#
#
#             var marker_bae1f2e503f2667b22719e3e49669d1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_551ba0a96783249df158bad2be55a856);
#
#
#         var popup_06a3c394601e5b9565548ecd6a659717 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_871bad9ea6e231897aea7bd0a0b7fcba = $(`&lt;div id=&quot;html_871bad9ea6e231897aea7bd0a0b7fcba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_06a3c394601e5b9565548ecd6a659717.setContent(html_871bad9ea6e231897aea7bd0a0b7fcba);
#
#
#
#         marker_bae1f2e503f2667b22719e3e49669d1b.bindPopup(popup_06a3c394601e5b9565548ecd6a659717)
#         ;
#
#
#
#
#             var marker_04d12594126c59220dad5203c7c87567 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_551ba0a96783249df158bad2be55a856);
#
#
#         var popup_fe770ca82ed5361abd21850e4b958921 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5b5c3b0d0d706b797b796e2d5db30a9 = $(`&lt;div id=&quot;html_e5b5c3b0d0d706b797b796e2d5db30a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fe770ca82ed5361abd21850e4b958921.setContent(html_e5b5c3b0d0d706b797b796e2d5db30a9);
#
#
#
#         mark
