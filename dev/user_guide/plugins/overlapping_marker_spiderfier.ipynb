# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acea6c9dfd04b1b8123224d7cfdad19d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acea6c9dfd04b1b8123224d7cfdad19d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acea6c9dfd04b1b8123224d7cfdad19d = L.map(
#                 &quot;map_acea6c9dfd04b1b8123224d7cfdad19d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b26cdc75864a059004f7c3b9c6f980d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b26cdc75864a059004f7c3b9c6f980d.addTo(map_acea6c9dfd04b1b8123224d7cfdad19d);
#
#
#             var marker_7bc193377ba5e7493a06876e53f35e1b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_acea6c9dfd04b1b8123224d7cfdad19d);
#
#
#         var popup_d68311dfb9a30a0bb392531d7b29444d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b85852f7e949ceec89da069faafe9488 = $(`&lt;div id=&quot;html_b85852f7e949ceec89da069faafe9488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d68311dfb9a30a0bb392531d7b29444d.setContent(html_b85852f7e949ceec89da069faafe9488);
#
#
#
#         marker_7bc193377ba5e7493a06876e53f35e1b.bindPopup(popup_d68311dfb9a30a0bb392531d7b29444d)
#         ;
#
#
#
#
#             var marker_e91da5b34f5b0f3a9c0fff69b992b8fa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_acea6c9dfd04b1b8123224d7cfdad19d);
#
#
#         var popup_74c337111fee1aae3bf712feb40525ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceb3ed89832d44703a5320aef5127a34 = $(`&lt;div id=&quot;html_ceb3ed89832d44703a5320aef5127a34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_74c337111fee1aae3bf712feb40525ea.setContent(html_ceb3ed89832d44703a5320aef5127a34);
#
#
#
#         marker_e91da5b34f5b0f3a9c0fff69b992b8fa.bindPopup(popup_74c337111fee1aae3bf712feb40525ea)
#         ;
#
#
#
#
#             var marker_5df6ddfef4bfb1d86ef667df021d191f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_acea6c9dfd04b1b8123224d7cfdad19d);
#
#
#         var popup_9a2d7af08c4bdfb6131f560d46a6ac31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb056b3dee1322d14a034309c7828d6d = $(`&lt;div id=&quot;html_fb056b3dee1322d14a034309c7828d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9a2d7af08c4bdfb6131f560d46a6ac31.setContent(html_fb056b3dee1322d14a034309c7828d6d);
#
#
#
#         marker_5df6ddfef4bfb1d86ef667df021d191f.bindPopup(popup_9a2d7af08c4bdfb6131f560d46a6ac31)
#         ;
#
#
#
#
#             var marker_1141a6682d7b7cfdac6e815ad1bc3377 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_acea6c9dfd04b1b8123224d7cfdad19d);
#
#
#         var popup_6991d100f54122c0596b6a0a425f37d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94e3e85fbad67f4b72d3f351060bf940 = $(`&lt;div id=&quot;html_94e3e85fbad67f4b72d3f351060bf940&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6991d100f54122c0596b6a0a425f37d9.setContent(html_94e3e85fbad67f4b72d3f351060bf940);
#
#
#
#         marker_1141a6682d7b7cfdac6e815ad1bc3377.bindPopup(popup_6991d100f54122c0596b6a0a425f37d9)
#         ;
#
#
#
#
#             var marker_f1c04ae871177802d261e87b0c3c2315 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_acea6c9dfd04b1b8123224d7cfdad19d);
#
#
#         var popup_a5ae5a40692b0b914ee9dd6257c5cc2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_542234e9e05acc03d5f7ffa4b85b935f = $(`&lt;div id=&quot;html_542234e9e05acc03d5f7ffa4b85b935f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a5ae5a40692b0b914ee9dd6257c5cc2e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cc7f752b58e395b2925df2aed70349e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cc7f752b58e395b2925df2aed70349e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cc7f752b58e395b2925df2aed70349e = L.map(
#                 &quot;map_2cc7f752b58e395b2925df2aed70349e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91eaab99b01c9f79791837e0bceb201f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91eaab99b01c9f79791837e0bceb201f.addTo(map_2cc7f752b58e395b2925df2aed70349e);
#
#
#             var feature_group_4047c38d378c2b4d80ddd89efa19e105 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fba73df54aae8831d842f7e1e6fca496 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4047c38d378c2b4d80ddd89efa19e105);
#
#
#         var popup_282921856c0e1dca9fcc7d160892030e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39bd3de2f4ebd2fd12be06ce7da2e3e2 = $(`&lt;div id=&quot;html_39bd3de2f4ebd2fd12be06ce7da2e3e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_282921856c0e1dca9fcc7d160892030e.setContent(html_39bd3de2f4ebd2fd12be06ce7da2e3e2);
#
#
#
#         marker_fba73df54aae8831d842f7e1e6fca496.bindPopup(popup_282921856c0e1dca9fcc7d160892030e)
#         ;
#
#
#
#
#             var marker_fbd3b666887e87ead326f39bb57d5593 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4047c38d378c2b4d80ddd89efa19e105);
#
#
#         var popup_5bd6989b1d75c3160947ed7619aaa92c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_636762f18d1380e077dbce2ce9a6a59e = $(`&lt;div id=&quot;html_636762f18d1380e077dbce2ce9a6a59e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5bd6989b1d75c3160947ed7619aaa92c.setContent(html_636762f18d1380e077dbce2ce9a6a59e);
#
#
#
#         marker_fbd3b666887e87ead326f39bb57d5593.bindPopup(popup_5bd6989b1d75c3160947ed7619aaa92c)
#         ;
#
#
#
#
#             var marker_c60853f3f1bc62d7764077e47d63af66 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4047c38d378c2b4d80ddd89efa19e105);
#
#
#         var popup_1c461d843c22bfebf131069f591e5c52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cc544c7795308351af7011ff18d4186 = $(`&lt;div id=&quot;html_8cc544c7795308351af7011ff18d4186&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1c461d843c22bfebf131069f591e5c52.setContent(html_8cc544c7795308351af7011ff18d4186);
#
#
#
#         marker_c60853f3f1bc62d7764077e47d63af66.bindPopup(popup_1c461d843c22bfebf131069f591e5c52)
#         ;
#
#
#
#
#             var marker_f4628c7f923de7d7155ca75d253aa5a6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4047c38d378c2b4d80ddd89efa19e105);
#
#
#         var popup_81a27596673a78f080eb6be59af023d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_122c20513671cd5bf45fe43bde4e46d3 = $(`&lt;div id=&quot;html_122c20513671cd5bf45fe43bde4e46d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_81a27596673a78f080eb6be59af023d8.setContent(html_122c20513671cd5bf45fe43bde4e46d3);
#
#
#
#         marker_f4628c7f923de7d7155ca75d253aa5a6.bindPopup(popup_81a27596673a78f080eb6be59af023d8)
#         ;
#
#
#
#
#             var marker_1e32b504f185628a7ffcf52414fe83c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4047c38d378c2b4d80ddd89efa19e105);
#
#
#         var popup_c6a7439a85d18dbe8c12f337db9f5478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e855e003db81b57b70ee0e2ece1a6e2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e855e003db81b57b70ee0e2ece1a6e2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e855e003db81b57b70ee0e2ece1a6e2c = L.map(
#                 &quot;map_e855e003db81b57b70ee0e2ece1a6e2c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91fbb8bc4c1a8aa51dd77e22a3e80edd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91fbb8bc4c1a8aa51dd77e22a3e80edd.addTo(map_e855e003db81b57b70ee0e2ece1a6e2c);
#
#
#             var feature_group_b504e21fcc5304b18a618afe84622ce2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b504e21fcc5304b18a618afe84622ce2.addTo(map_e855e003db81b57b70ee0e2ece1a6e2c);
#
#
#             var feature_group_sub_group_bd0aa28ab756186683bda93147d3b36e = L.featureGroup.subGroup(
#                 feature_group_b504e21fcc5304b18a618afe84622ce2
#             );
#
#
#             var marker_88acfcbfd274bcdd74b298ac8dbd1d53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0aa28ab756186683bda93147d3b36e);
#
#
#         var popup_afa102a0662f7f4422254d33a797372f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d33054911999916a8a257e06eb2b41 = $(`&lt;div id=&quot;html_89d33054911999916a8a257e06eb2b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_afa102a0662f7f4422254d33a797372f.setContent(html_89d33054911999916a8a257e06eb2b41);
#
#
#
#         marker_88acfcbfd274bcdd74b298ac8dbd1d53.bindPopup(popup_afa102a0662f7f4422254d33a797372f)
#         ;
#
#
#
#
#             var marker_e467eda6e3201f93c8c8e3b7bbf035cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0aa28ab756186683bda93147d3b36e);
#
#
#         var popup_aa0cb03fee582b8c1b822222da296c34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d47b92ec5c935322af9fd12abc9528c = $(`&lt;div id=&quot;html_3d47b92ec5c935322af9fd12abc9528c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aa0cb03fee582b8c1b822222da296c34.setContent(html_3d47b92ec5c935322af9fd12abc9528c);
#
#
#
#         marker_e467eda6e3201f93c8c8e3b7bbf035cc.bindPopup(popup_aa0cb03fee582b8c1b822222da296c34)
#         ;
#
#
#
#
#             var marker_c51af3dfb0a306d94dec17edfa32e3dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0aa28ab756186683bda93147d3b36e);
#
#
#         var popup_d784596cb5cad643e8dd2f41bc62e7cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bc3dc96ec385e2be7014ec87758a95b = $(`&lt;div id=&quot;html_5bc3dc96ec385e2be7014ec87758a95b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d784596cb5cad643e8dd2f41bc62e7cf.setContent(html_5bc3dc96ec385e2be7014ec87758a95b);
#
#
#
#         marker_c51af3dfb0a306d94dec17edfa32e3dc.bindPopup(popup_d784596cb5cad643e8dd2f41bc62e7cf)
#         ;
#
#
#
#
#             var marker_2c88d7b703f1a15303fb6f74749c64ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bd0aa28ab756186683bda93147d3b36e);
#
#
#         var popup_60d8c4c70329c66a730c5422a0d228e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b68b2c607bab76954e4af8cf6154873 = $(`&lt;div id=&quot;html_7b68b2c607bab76954e4af8cf6154873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_60d8c4c70329c66a730c5422a0d228e7.setContent(html_7b68b2c607bab76954e4af8cf6154873);
#
#
#
#         marker_
