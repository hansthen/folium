# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_730ab20b95d6ddefa404e77c4d14e773 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_730ab20b95d6ddefa404e77c4d14e773&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_730ab20b95d6ddefa404e77c4d14e773 = L.map(
#                 &quot;map_730ab20b95d6ddefa404e77c4d14e773&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e82af7400e9e527cc7ece62870026bb5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e82af7400e9e527cc7ece62870026bb5.addTo(map_730ab20b95d6ddefa404e77c4d14e773);
#
#
#             var marker_553252e55f14bd10a2995ff26f7af3b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_730ab20b95d6ddefa404e77c4d14e773);
#
#
#         var popup_62f098cf5c1b7423d1c71bfe7658b016 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f58f793a8e8340ad818e3efd6f1923e9 = $(`&lt;div id=&quot;html_f58f793a8e8340ad818e3efd6f1923e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_62f098cf5c1b7423d1c71bfe7658b016.setContent(html_f58f793a8e8340ad818e3efd6f1923e9);
#
#
#
#         marker_553252e55f14bd10a2995ff26f7af3b3.bindPopup(popup_62f098cf5c1b7423d1c71bfe7658b016)
#         ;
#
#
#
#
#             var marker_7aaaf6055379521a67971278d7c07098 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_730ab20b95d6ddefa404e77c4d14e773);
#
#
#         var popup_20dcc38c970561a4f0cf81e269aea332 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47bdbbb603e20004223650639fdc70c1 = $(`&lt;div id=&quot;html_47bdbbb603e20004223650639fdc70c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_20dcc38c970561a4f0cf81e269aea332.setContent(html_47bdbbb603e20004223650639fdc70c1);
#
#
#
#         marker_7aaaf6055379521a67971278d7c07098.bindPopup(popup_20dcc38c970561a4f0cf81e269aea332)
#         ;
#
#
#
#
#             var marker_0cdaeb8b9b79095bb3dcaa6e1d16b622 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_730ab20b95d6ddefa404e77c4d14e773);
#
#
#         var popup_5c28dcfddc3755ebf4969580788d18ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee14fe1cdd325bc079f8d39e6f2620c = $(`&lt;div id=&quot;html_cee14fe1cdd325bc079f8d39e6f2620c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5c28dcfddc3755ebf4969580788d18ca.setContent(html_cee14fe1cdd325bc079f8d39e6f2620c);
#
#
#
#         marker_0cdaeb8b9b79095bb3dcaa6e1d16b622.bindPopup(popup_5c28dcfddc3755ebf4969580788d18ca)
#         ;
#
#
#
#
#             var marker_748499fef38f517ece6a90037d7bf0d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_730ab20b95d6ddefa404e77c4d14e773);
#
#
#         var popup_97ab2b564a8881ec9ec205c1261bb165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40febbba02b592fe5ad90697a5c501d3 = $(`&lt;div id=&quot;html_40febbba02b592fe5ad90697a5c501d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_97ab2b564a8881ec9ec205c1261bb165.setContent(html_40febbba02b592fe5ad90697a5c501d3);
#
#
#
#         marker_748499fef38f517ece6a90037d7bf0d9.bindPopup(popup_97ab2b564a8881ec9ec205c1261bb165)
#         ;
#
#
#
#
#             var marker_68bd1495a16387e747819dc37777c74d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_730ab20b95d6ddefa404e77c4d14e773);
#
#
#         var popup_e93e005e53700d28276df90d4a8b623a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb5f69deabac32a7297e573b6bf794a6 = $(`&lt;div id=&quot;html_fb5f69deabac32a7297e573b6bf794a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e93e005e53700d28276df90d4a8b623a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebad9eacaa5fde5419e322a4be5f3762 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebad9eacaa5fde5419e322a4be5f3762&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebad9eacaa5fde5419e322a4be5f3762 = L.map(
#                 &quot;map_ebad9eacaa5fde5419e322a4be5f3762&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19513e131a84d96a184279f0492dd994 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19513e131a84d96a184279f0492dd994.addTo(map_ebad9eacaa5fde5419e322a4be5f3762);
#
#
#             var feature_group_bf19267f3b7810719b28d1106eab4362 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1b0574b2aa2cb10027cff807b7a5e0a5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bf19267f3b7810719b28d1106eab4362);
#
#
#         var popup_ac9f12aad03faaac1ef213b0a813043b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d69b395cc54df27478c807c7e9c53dc0 = $(`&lt;div id=&quot;html_d69b395cc54df27478c807c7e9c53dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ac9f12aad03faaac1ef213b0a813043b.setContent(html_d69b395cc54df27478c807c7e9c53dc0);
#
#
#
#         marker_1b0574b2aa2cb10027cff807b7a5e0a5.bindPopup(popup_ac9f12aad03faaac1ef213b0a813043b)
#         ;
#
#
#
#
#             var marker_e9198efe03c0643b1141120d25b3dc7f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bf19267f3b7810719b28d1106eab4362);
#
#
#         var popup_be319839158898b58dd5d60d0956d876 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06742f0a7f4db01772b0a2cf43a40407 = $(`&lt;div id=&quot;html_06742f0a7f4db01772b0a2cf43a40407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_be319839158898b58dd5d60d0956d876.setContent(html_06742f0a7f4db01772b0a2cf43a40407);
#
#
#
#         marker_e9198efe03c0643b1141120d25b3dc7f.bindPopup(popup_be319839158898b58dd5d60d0956d876)
#         ;
#
#
#
#
#             var marker_0dbf9a48bcdeb876bf219c0a9736f68a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bf19267f3b7810719b28d1106eab4362);
#
#
#         var popup_04252f1d283e1d6e0541ee563c841956 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc4a5e82b91da934fce6da1896fd86c0 = $(`&lt;div id=&quot;html_bc4a5e82b91da934fce6da1896fd86c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_04252f1d283e1d6e0541ee563c841956.setContent(html_bc4a5e82b91da934fce6da1896fd86c0);
#
#
#
#         marker_0dbf9a48bcdeb876bf219c0a9736f68a.bindPopup(popup_04252f1d283e1d6e0541ee563c841956)
#         ;
#
#
#
#
#             var marker_f465c27ccaa5587902a4480b07a059e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bf19267f3b7810719b28d1106eab4362);
#
#
#         var popup_2d23bb6f75fed9f5a3fc260ba5e096fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ee66f0975e3a577cd6dc4a9e632e1b9 = $(`&lt;div id=&quot;html_7ee66f0975e3a577cd6dc4a9e632e1b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2d23bb6f75fed9f5a3fc260ba5e096fc.setContent(html_7ee66f0975e3a577cd6dc4a9e632e1b9);
#
#
#
#         marker_f465c27ccaa5587902a4480b07a059e4.bindPopup(popup_2d23bb6f75fed9f5a3fc260ba5e096fc)
#         ;
#
#
#
#
#             var marker_f57562a9b77fdbf32a7939d3d5152840 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bf19267f3b7810719b28d1106eab4362);
#
#
#         var popup_c26a7c51ec2dcb92351c7e5a9c7b2dad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40ce3369016f1a325e67db72f0aa9315 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40ce3369016f1a325e67db72f0aa9315&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40ce3369016f1a325e67db72f0aa9315 = L.map(
#                 &quot;map_40ce3369016f1a325e67db72f0aa9315&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8c7604f8a5bc1a26b5d8086db7c3f9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8c7604f8a5bc1a26b5d8086db7c3f9b.addTo(map_40ce3369016f1a325e67db72f0aa9315);
#
#
#             var feature_group_dff3c7101fdaf2245753fbb9fc34317f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dff3c7101fdaf2245753fbb9fc34317f.addTo(map_40ce3369016f1a325e67db72f0aa9315);
#
#
#             var feature_group_sub_group_539e857b77f5940bd10987e5f81f5365 = L.featureGroup.subGroup(
#                 feature_group_dff3c7101fdaf2245753fbb9fc34317f
#             );
#
#
#             var marker_704f755503e9d1dc9c7709063f3ac251 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_539e857b77f5940bd10987e5f81f5365);
#
#
#         var popup_11ddf02d94440e38a9743cd46c442d8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9419eaa74e48efe19ad1d56cf4aac25d = $(`&lt;div id=&quot;html_9419eaa74e48efe19ad1d56cf4aac25d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_11ddf02d94440e38a9743cd46c442d8a.setContent(html_9419eaa74e48efe19ad1d56cf4aac25d);
#
#
#
#         marker_704f755503e9d1dc9c7709063f3ac251.bindPopup(popup_11ddf02d94440e38a9743cd46c442d8a)
#         ;
#
#
#
#
#             var marker_8be96af994799fda642509cab25c7848 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_539e857b77f5940bd10987e5f81f5365);
#
#
#         var popup_9878fb34c26d2ed8f816720893de3fea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a8b0e5eff23159a9a9b12d48797001e = $(`&lt;div id=&quot;html_5a8b0e5eff23159a9a9b12d48797001e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9878fb34c26d2ed8f816720893de3fea.setContent(html_5a8b0e5eff23159a9a9b12d48797001e);
#
#
#
#         marker_8be96af994799fda642509cab25c7848.bindPopup(popup_9878fb34c26d2ed8f816720893de3fea)
#         ;
#
#
#
#
#             var marker_a6b3b093b0b520532c13af329365ab2f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_539e857b77f5940bd10987e5f81f5365);
#
#
#         var popup_38e02468f585de42fea9e68087cb0e4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0088f4a7b4bc4545af84d1db3bad9ead = $(`&lt;div id=&quot;html_0088f4a7b4bc4545af84d1db3bad9ead&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_38e02468f585de42fea9e68087cb0e4b.setContent(html_0088f4a7b4bc4545af84d1db3bad9ead);
#
#
#
#         marker_a6b3b093b0b520532c13af329365ab2f.bindPopup(popup_38e02468f585de42fea9e68087cb0e4b)
#         ;
#
#
#
#
#             var marker_5bd1cc95d9663264bb0d7adc39904483 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_539e857b77f5940bd10987e5f81f5365);
#
#
#         var popup_e92ae74cc282b9f59990f206dbc59d33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd3a194788649506e342dc9057b12042 = $(`&lt;div id=&quot;html_cd3a194788649506e342dc9057b12042&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e92ae74cc282b9f59990f206dbc59d33.setContent(html_cd3a194788649506e342dc9057b12042);
#
#
#
#         marker_
