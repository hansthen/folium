# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ce457d5a7abd14c671dc7787dc03798 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ce457d5a7abd14c671dc7787dc03798&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ce457d5a7abd14c671dc7787dc03798 = L.map(
#                 &quot;map_9ce457d5a7abd14c671dc7787dc03798&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72f4d1f1d8367010458b4bebc8d63813 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72f4d1f1d8367010458b4bebc8d63813.addTo(map_9ce457d5a7abd14c671dc7787dc03798);
#
#
#             var marker_a81561f1c51e6883411de8ad93c1cbb2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9ce457d5a7abd14c671dc7787dc03798);
#
#
#         var popup_54cd84f62c3306efeb7504f2ef534389 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e989fcce5da0a931349c2392ed4fa6a6 = $(`&lt;div id=&quot;html_e989fcce5da0a931349c2392ed4fa6a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_54cd84f62c3306efeb7504f2ef534389.setContent(html_e989fcce5da0a931349c2392ed4fa6a6);
#
#
#
#         marker_a81561f1c51e6883411de8ad93c1cbb2.bindPopup(popup_54cd84f62c3306efeb7504f2ef534389)
#         ;
#
#
#
#
#             var marker_f2f5359ac985b27f6d2e92e09ae07f2a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9ce457d5a7abd14c671dc7787dc03798);
#
#
#         var popup_9c707bc2e2ca30a57e1e429ff929a943 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f44a10cd08e7dc1ae2e19f1ecaaf713b = $(`&lt;div id=&quot;html_f44a10cd08e7dc1ae2e19f1ecaaf713b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9c707bc2e2ca30a57e1e429ff929a943.setContent(html_f44a10cd08e7dc1ae2e19f1ecaaf713b);
#
#
#
#         marker_f2f5359ac985b27f6d2e92e09ae07f2a.bindPopup(popup_9c707bc2e2ca30a57e1e429ff929a943)
#         ;
#
#
#
#
#             var marker_9745624eb05d1c2c966b531b9d3c59f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9ce457d5a7abd14c671dc7787dc03798);
#
#
#         var popup_a60409e461b095e949a6202730d271cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3409a05a480e0a714731c47dd0495028 = $(`&lt;div id=&quot;html_3409a05a480e0a714731c47dd0495028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a60409e461b095e949a6202730d271cf.setContent(html_3409a05a480e0a714731c47dd0495028);
#
#
#
#         marker_9745624eb05d1c2c966b531b9d3c59f4.bindPopup(popup_a60409e461b095e949a6202730d271cf)
#         ;
#
#
#
#
#             var marker_dd7da891c9f4cfa515c5197b62763751 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9ce457d5a7abd14c671dc7787dc03798);
#
#
#         var popup_835ddc889ed09d3135a2f7300701d03e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07bfb2301d43dae81f1752a695b41572 = $(`&lt;div id=&quot;html_07bfb2301d43dae81f1752a695b41572&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_835ddc889ed09d3135a2f7300701d03e.setContent(html_07bfb2301d43dae81f1752a695b41572);
#
#
#
#         marker_dd7da891c9f4cfa515c5197b62763751.bindPopup(popup_835ddc889ed09d3135a2f7300701d03e)
#         ;
#
#
#
#
#             var marker_6e6000aa9b9001d8c2eec6d831dd0365 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9ce457d5a7abd14c671dc7787dc03798);
#
#
#         var popup_d12801d34c99ce7a3176dcecf9d31599 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_439b4bf03295eb35a0ac2c0862d0ac34 = $(`&lt;div id=&quot;html_439b4bf03295eb35a0ac2c0862d0ac34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d12801d34c99ce7a3176dcecf9d31599.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d86e19ab8d3e74c1a6562263f20d57c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d86e19ab8d3e74c1a6562263f20d57c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d86e19ab8d3e74c1a6562263f20d57c8 = L.map(
#                 &quot;map_d86e19ab8d3e74c1a6562263f20d57c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e309c42d1fb22ee382a08654c9bb1e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e309c42d1fb22ee382a08654c9bb1e3.addTo(map_d86e19ab8d3e74c1a6562263f20d57c8);
#
#
#             var feature_group_6de2c690b84594be8c4df9701141e252 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0dde6db38f8b969afdaddb14081a3eef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6de2c690b84594be8c4df9701141e252);
#
#
#         var popup_253102f6dcd6bd90af1b97b228eba1a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_571ea8dac602208794ed53395bffe8d9 = $(`&lt;div id=&quot;html_571ea8dac602208794ed53395bffe8d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_253102f6dcd6bd90af1b97b228eba1a3.setContent(html_571ea8dac602208794ed53395bffe8d9);
#
#
#
#         marker_0dde6db38f8b969afdaddb14081a3eef.bindPopup(popup_253102f6dcd6bd90af1b97b228eba1a3)
#         ;
#
#
#
#
#             var marker_0eadddcddd3c103952a1ed34fd7cb74f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6de2c690b84594be8c4df9701141e252);
#
#
#         var popup_94487f67bab39529b37f8e2b831e1ccb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f52e80df16ece134ce98de7e7aa03475 = $(`&lt;div id=&quot;html_f52e80df16ece134ce98de7e7aa03475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_94487f67bab39529b37f8e2b831e1ccb.setContent(html_f52e80df16ece134ce98de7e7aa03475);
#
#
#
#         marker_0eadddcddd3c103952a1ed34fd7cb74f.bindPopup(popup_94487f67bab39529b37f8e2b831e1ccb)
#         ;
#
#
#
#
#             var marker_fa4ff4ec90bd262d52df14aebfbbd748 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6de2c690b84594be8c4df9701141e252);
#
#
#         var popup_430343b3e91ebd2e261faa523412c3a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81deb7e07e9eb4644eb4ce011b24b199 = $(`&lt;div id=&quot;html_81deb7e07e9eb4644eb4ce011b24b199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_430343b3e91ebd2e261faa523412c3a5.setContent(html_81deb7e07e9eb4644eb4ce011b24b199);
#
#
#
#         marker_fa4ff4ec90bd262d52df14aebfbbd748.bindPopup(popup_430343b3e91ebd2e261faa523412c3a5)
#         ;
#
#
#
#
#             var marker_a88ef2093454d0443d8d93c6c4e34d0c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6de2c690b84594be8c4df9701141e252);
#
#
#         var popup_0e9167d2f9d6c925bc9a52e33992dd47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2c3657fe91513f6037a342abd1f5a88 = $(`&lt;div id=&quot;html_f2c3657fe91513f6037a342abd1f5a88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0e9167d2f9d6c925bc9a52e33992dd47.setContent(html_f2c3657fe91513f6037a342abd1f5a88);
#
#
#
#         marker_a88ef2093454d0443d8d93c6c4e34d0c.bindPopup(popup_0e9167d2f9d6c925bc9a52e33992dd47)
#         ;
#
#
#
#
#             var marker_f6354cbcf26e19842ef40f82ec822a6f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6de2c690b84594be8c4df9701141e252);
#
#
#         var popup_e7ae417bc6b8bc5457e0d0bf517c3bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31188bed38248af9ac9a4dd5e7c79ebd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31188bed38248af9ac9a4dd5e7c79ebd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31188bed38248af9ac9a4dd5e7c79ebd = L.map(
#                 &quot;map_31188bed38248af9ac9a4dd5e7c79ebd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9e4e3b2775faa72348fcfb84db15905 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9e4e3b2775faa72348fcfb84db15905.addTo(map_31188bed38248af9ac9a4dd5e7c79ebd);
#
#
#             var feature_group_7ff92ad9a4e19b6f3b86c172b886bc7a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7ff92ad9a4e19b6f3b86c172b886bc7a.addTo(map_31188bed38248af9ac9a4dd5e7c79ebd);
#
#
#             var feature_group_sub_group_462291e0a12be349a5c49e379cf4bb72 = L.featureGroup.subGroup(
#                 feature_group_7ff92ad9a4e19b6f3b86c172b886bc7a
#             );
#
#
#             var marker_70da825b853027a0001ed16810ef7e8f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_462291e0a12be349a5c49e379cf4bb72);
#
#
#         var popup_6211f8bf08850074c49a7bf29e2d50a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f695383f331f6189cb8915146bc1d91 = $(`&lt;div id=&quot;html_1f695383f331f6189cb8915146bc1d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6211f8bf08850074c49a7bf29e2d50a9.setContent(html_1f695383f331f6189cb8915146bc1d91);
#
#
#
#         marker_70da825b853027a0001ed16810ef7e8f.bindPopup(popup_6211f8bf08850074c49a7bf29e2d50a9)
#         ;
#
#
#
#
#             var marker_5b99a70ba74f929b0492256685819f29 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_462291e0a12be349a5c49e379cf4bb72);
#
#
#         var popup_c3d8473c2ec751cbb725d66a48437273 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94d6fe241dbc5edbbef4b096a38b014e = $(`&lt;div id=&quot;html_94d6fe241dbc5edbbef4b096a38b014e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3d8473c2ec751cbb725d66a48437273.setContent(html_94d6fe241dbc5edbbef4b096a38b014e);
#
#
#
#         marker_5b99a70ba74f929b0492256685819f29.bindPopup(popup_c3d8473c2ec751cbb725d66a48437273)
#         ;
#
#
#
#
#             var marker_0e52b730c65b05f12ce128c17d1ea7fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_462291e0a12be349a5c49e379cf4bb72);
#
#
#         var popup_8fbd2270174bbf6cb57aef4281344efd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79e233fad706463e75520371f0a7dd56 = $(`&lt;div id=&quot;html_79e233fad706463e75520371f0a7dd56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8fbd2270174bbf6cb57aef4281344efd.setContent(html_79e233fad706463e75520371f0a7dd56);
#
#
#
#         marker_0e52b730c65b05f12ce128c17d1ea7fd.bindPopup(popup_8fbd2270174bbf6cb57aef4281344efd)
#         ;
#
#
#
#
#             var marker_77ae7dda69cf65fc2f193caa1ee0ec1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_462291e0a12be349a5c49e379cf4bb72);
#
#
#         var popup_f76cccf0e405b5c565fc61119be57da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44e47bae214cd763eee4ce463e94e193 = $(`&lt;div id=&quot;html_44e47bae214cd763eee4ce463e94e193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f76cccf0e405b5c565fc61119be57da8.setContent(html_44e47bae214cd763eee4ce463e94e193);
#
#
#
#         marker_
