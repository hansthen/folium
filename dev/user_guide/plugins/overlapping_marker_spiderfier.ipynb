# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f26411969fb966ef99259ad6c0248ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f26411969fb966ef99259ad6c0248ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f26411969fb966ef99259ad6c0248ac = L.map(
#                 &quot;map_1f26411969fb966ef99259ad6c0248ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec0c432ef7edc0ef5e25e57b07ff9da2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec0c432ef7edc0ef5e25e57b07ff9da2.addTo(map_1f26411969fb966ef99259ad6c0248ac);
#
#
#             var marker_3b3b5ce030dc93477d807849c040f4c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1f26411969fb966ef99259ad6c0248ac);
#
#
#         var popup_572c903a2cc606199c7fdeaf25001b6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c97bb86b768ac1a9d5d77d5adeb23760 = $(`&lt;div id=&quot;html_c97bb86b768ac1a9d5d77d5adeb23760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_572c903a2cc606199c7fdeaf25001b6f.setContent(html_c97bb86b768ac1a9d5d77d5adeb23760);
#
#
#
#         marker_3b3b5ce030dc93477d807849c040f4c7.bindPopup(popup_572c903a2cc606199c7fdeaf25001b6f)
#         ;
#
#
#
#
#             var marker_86b0f163e976dc7befc982f41bab8c05 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1f26411969fb966ef99259ad6c0248ac);
#
#
#         var popup_8dbf0cd3bfb5ff05be929cca985b4242 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6045cd2c013ad29db452584dc59b9f6 = $(`&lt;div id=&quot;html_c6045cd2c013ad29db452584dc59b9f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8dbf0cd3bfb5ff05be929cca985b4242.setContent(html_c6045cd2c013ad29db452584dc59b9f6);
#
#
#
#         marker_86b0f163e976dc7befc982f41bab8c05.bindPopup(popup_8dbf0cd3bfb5ff05be929cca985b4242)
#         ;
#
#
#
#
#             var marker_f4cd89057699249730fd81db47c3469d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1f26411969fb966ef99259ad6c0248ac);
#
#
#         var popup_ab5c29a0654c5f7fe0e9503425d9062d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_479ec282f3236f8b97079a995d1f92fa = $(`&lt;div id=&quot;html_479ec282f3236f8b97079a995d1f92fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ab5c29a0654c5f7fe0e9503425d9062d.setContent(html_479ec282f3236f8b97079a995d1f92fa);
#
#
#
#         marker_f4cd89057699249730fd81db47c3469d.bindPopup(popup_ab5c29a0654c5f7fe0e9503425d9062d)
#         ;
#
#
#
#
#             var marker_3b418a08c20b4361bcc1786df88f464d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1f26411969fb966ef99259ad6c0248ac);
#
#
#         var popup_46e3da20777d6b1ee944c492a0024447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15a7923adae5a4acac0ce27da56134e2 = $(`&lt;div id=&quot;html_15a7923adae5a4acac0ce27da56134e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_46e3da20777d6b1ee944c492a0024447.setContent(html_15a7923adae5a4acac0ce27da56134e2);
#
#
#
#         marker_3b418a08c20b4361bcc1786df88f464d.bindPopup(popup_46e3da20777d6b1ee944c492a0024447)
#         ;
#
#
#
#
#             var marker_21624d33e46c175a40d1f6b699c7753b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1f26411969fb966ef99259ad6c0248ac);
#
#
#         var popup_81985144c2ddc09adfdda89eadab1e3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5144bfc3916c463ff9567123e9892aeb = $(`&lt;div id=&quot;html_5144bfc3916c463ff9567123e9892aeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_81985144c2ddc09adfdda89eadab1e3b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bef5a455f41c19053f2cb0d49c09a23e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bef5a455f41c19053f2cb0d49c09a23e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bef5a455f41c19053f2cb0d49c09a23e = L.map(
#                 &quot;map_bef5a455f41c19053f2cb0d49c09a23e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2f70883ee557156b2c711418132dede = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2f70883ee557156b2c711418132dede.addTo(map_bef5a455f41c19053f2cb0d49c09a23e);
#
#
#             var feature_group_f78b018fca320929cd2bdcbccf4f89c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1c0cf751cc5182f22301e7d311b00dc2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f78b018fca320929cd2bdcbccf4f89c4);
#
#
#         var popup_e57459f5ec4143fba8e77114f2d0c53d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a99d718bf6214813a6760738a0b637 = $(`&lt;div id=&quot;html_b2a99d718bf6214813a6760738a0b637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e57459f5ec4143fba8e77114f2d0c53d.setContent(html_b2a99d718bf6214813a6760738a0b637);
#
#
#
#         marker_1c0cf751cc5182f22301e7d311b00dc2.bindPopup(popup_e57459f5ec4143fba8e77114f2d0c53d)
#         ;
#
#
#
#
#             var marker_61b4d456b9805082360e22bbde9106a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f78b018fca320929cd2bdcbccf4f89c4);
#
#
#         var popup_85e942b9275ff766e802fbccd9131d79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0462859ceef29823935fc24e745249f0 = $(`&lt;div id=&quot;html_0462859ceef29823935fc24e745249f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_85e942b9275ff766e802fbccd9131d79.setContent(html_0462859ceef29823935fc24e745249f0);
#
#
#
#         marker_61b4d456b9805082360e22bbde9106a4.bindPopup(popup_85e942b9275ff766e802fbccd9131d79)
#         ;
#
#
#
#
#             var marker_d10c4dd7667ef47aaf580c50dce7b903 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f78b018fca320929cd2bdcbccf4f89c4);
#
#
#         var popup_e618f16d9da7b115bda23c56c117d558 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_965425d2d577899b44831eb105be1416 = $(`&lt;div id=&quot;html_965425d2d577899b44831eb105be1416&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e618f16d9da7b115bda23c56c117d558.setContent(html_965425d2d577899b44831eb105be1416);
#
#
#
#         marker_d10c4dd7667ef47aaf580c50dce7b903.bindPopup(popup_e618f16d9da7b115bda23c56c117d558)
#         ;
#
#
#
#
#             var marker_efd82b160384b117f4d5cfb0ef5960dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f78b018fca320929cd2bdcbccf4f89c4);
#
#
#         var popup_afbcf58056c867f7d26a88cb18c1f9b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a617e211e103530892e67a7406a6005 = $(`&lt;div id=&quot;html_8a617e211e103530892e67a7406a6005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_afbcf58056c867f7d26a88cb18c1f9b9.setContent(html_8a617e211e103530892e67a7406a6005);
#
#
#
#         marker_efd82b160384b117f4d5cfb0ef5960dd.bindPopup(popup_afbcf58056c867f7d26a88cb18c1f9b9)
#         ;
#
#
#
#
#             var marker_bf70af4584adc74b254f98e5db0e5de5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f78b018fca320929cd2bdcbccf4f89c4);
#
#
#         var popup_94b9c97513a2030f4d121e4ed5739569 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8226a08aa0a1415ecba211f04a0017df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8226a08aa0a1415ecba211f04a0017df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8226a08aa0a1415ecba211f04a0017df = L.map(
#                 &quot;map_8226a08aa0a1415ecba211f04a0017df&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55a8f15ea4c291418d9acf08406658f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55a8f15ea4c291418d9acf08406658f6.addTo(map_8226a08aa0a1415ecba211f04a0017df);
#
#
#             var feature_group_308afc6741e172c5ad7e87c39c3857e4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_308afc6741e172c5ad7e87c39c3857e4.addTo(map_8226a08aa0a1415ecba211f04a0017df);
#
#
#             var feature_group_sub_group_4c0c0d4628826c85800b168ccb412601 = L.featureGroup.subGroup(
#                 feature_group_308afc6741e172c5ad7e87c39c3857e4
#             );
#
#
#             var marker_430a9245ca7078322454d04b67f53aac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4c0c0d4628826c85800b168ccb412601);
#
#
#         var popup_40a279922b24b5b4cd66404ca96e4187 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e8a5f7473d1bf45bc762c3dc2b51eb3 = $(`&lt;div id=&quot;html_3e8a5f7473d1bf45bc762c3dc2b51eb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_40a279922b24b5b4cd66404ca96e4187.setContent(html_3e8a5f7473d1bf45bc762c3dc2b51eb3);
#
#
#
#         marker_430a9245ca7078322454d04b67f53aac.bindPopup(popup_40a279922b24b5b4cd66404ca96e4187)
#         ;
#
#
#
#
#             var marker_ee1ab880c07e51a254fb75d502fa6a8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4c0c0d4628826c85800b168ccb412601);
#
#
#         var popup_292344ba7a54c2a4715f1eb2c4f17bf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8b306a95f3431139c90c826673e6afd = $(`&lt;div id=&quot;html_c8b306a95f3431139c90c826673e6afd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_292344ba7a54c2a4715f1eb2c4f17bf8.setContent(html_c8b306a95f3431139c90c826673e6afd);
#
#
#
#         marker_ee1ab880c07e51a254fb75d502fa6a8e.bindPopup(popup_292344ba7a54c2a4715f1eb2c4f17bf8)
#         ;
#
#
#
#
#             var marker_30185f57a5488ea2d352b9080b3f7251 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4c0c0d4628826c85800b168ccb412601);
#
#
#         var popup_c73a94d4d13a5a4fd7b5784dbe0f0ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f35051a1d50579fbcd6f452597d1e2a0 = $(`&lt;div id=&quot;html_f35051a1d50579fbcd6f452597d1e2a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c73a94d4d13a5a4fd7b5784dbe0f0ca5.setContent(html_f35051a1d50579fbcd6f452597d1e2a0);
#
#
#
#         marker_30185f57a5488ea2d352b9080b3f7251.bindPopup(popup_c73a94d4d13a5a4fd7b5784dbe0f0ca5)
#         ;
#
#
#
#
#             var marker_fb8ade71c432444a196a8887ccfc01b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4c0c0d4628826c85800b168ccb412601);
#
#
#         var popup_e2e5f9a39ed9e26217cc5f01901efa06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80014de6df1502d3cbf28d869d97b426 = $(`&lt;div id=&quot;html_80014de6df1502d3cbf28d869d97b426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e2e5f9a39ed9e26217cc5f01901efa06.setContent(html_80014de6df1502d3cbf28d869d97b426);
#
#
#
#         marker_
