# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76a77cac26d5208be8f83488232d5ef2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76a77cac26d5208be8f83488232d5ef2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76a77cac26d5208be8f83488232d5ef2 = L.map(
#                 &quot;map_76a77cac26d5208be8f83488232d5ef2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ca672e57cdabe6e3af4a6969acef56b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ca672e57cdabe6e3af4a6969acef56b.addTo(map_76a77cac26d5208be8f83488232d5ef2);
#
#
#             var marker_a318cb9a9ca2c068f22c302b5686afa3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_76a77cac26d5208be8f83488232d5ef2);
#
#
#         var popup_882cb338a13d075acc05e481cbe4490c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d2b0a97a42bc38205d8e73ec6b63a3d = $(`&lt;div id=&quot;html_7d2b0a97a42bc38205d8e73ec6b63a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_882cb338a13d075acc05e481cbe4490c.setContent(html_7d2b0a97a42bc38205d8e73ec6b63a3d);
#
#
#
#         marker_a318cb9a9ca2c068f22c302b5686afa3.bindPopup(popup_882cb338a13d075acc05e481cbe4490c)
#         ;
#
#
#
#
#             var marker_a4be19e3c680f91d60d85cd1c4a3ab73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_76a77cac26d5208be8f83488232d5ef2);
#
#
#         var popup_5b7a08e23990e780d79fc26c2aeba7d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cd51e471c3a49d6a38c29d21292d270 = $(`&lt;div id=&quot;html_1cd51e471c3a49d6a38c29d21292d270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5b7a08e23990e780d79fc26c2aeba7d8.setContent(html_1cd51e471c3a49d6a38c29d21292d270);
#
#
#
#         marker_a4be19e3c680f91d60d85cd1c4a3ab73.bindPopup(popup_5b7a08e23990e780d79fc26c2aeba7d8)
#         ;
#
#
#
#
#             var marker_2629525363bd8c8bbf895eb5622082f5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_76a77cac26d5208be8f83488232d5ef2);
#
#
#         var popup_1affc7912e7e6f9d3f2e432e99b96805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c81621fd96c7efee0ada17ab4002b7c = $(`&lt;div id=&quot;html_3c81621fd96c7efee0ada17ab4002b7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1affc7912e7e6f9d3f2e432e99b96805.setContent(html_3c81621fd96c7efee0ada17ab4002b7c);
#
#
#
#         marker_2629525363bd8c8bbf895eb5622082f5.bindPopup(popup_1affc7912e7e6f9d3f2e432e99b96805)
#         ;
#
#
#
#
#             var marker_3a148a484b72011f09050fb8947dd7c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_76a77cac26d5208be8f83488232d5ef2);
#
#
#         var popup_8023aea797fa616dff2d14026e605c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9009f43ff64925000046861ad2738142 = $(`&lt;div id=&quot;html_9009f43ff64925000046861ad2738142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8023aea797fa616dff2d14026e605c09.setContent(html_9009f43ff64925000046861ad2738142);
#
#
#
#         marker_3a148a484b72011f09050fb8947dd7c6.bindPopup(popup_8023aea797fa616dff2d14026e605c09)
#         ;
#
#
#
#
#             var marker_78a22f8b30e3b9f1c4205f3265e4788a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_76a77cac26d5208be8f83488232d5ef2);
#
#
#         var popup_70a15953ea70ad919d1dabbdbb56cafd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7955ba7b1a20e9abe0ae090a77e05cad = $(`&lt;div id=&quot;html_7955ba7b1a20e9abe0ae090a77e05cad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_70a15953ea70ad919d1dabbdbb56ca

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f41ec6ad038c46f73c2885054eed4f66 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f41ec6ad038c46f73c2885054eed4f66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f41ec6ad038c46f73c2885054eed4f66 = L.map(
#                 &quot;map_f41ec6ad038c46f73c2885054eed4f66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9960581ec802c1ebf0415cf20193894 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9960581ec802c1ebf0415cf20193894.addTo(map_f41ec6ad038c46f73c2885054eed4f66);
#
#
#             var feature_group_593b03e681a41011c8953e87f4b67c3f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e741eab01e58b0b60cf8b35fc88cd4f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_593b03e681a41011c8953e87f4b67c3f);
#
#
#         var popup_a18f4bf3974ee7990f8db643fafcb08d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a51bbd984985afb541441f5d4c7199db = $(`&lt;div id=&quot;html_a51bbd984985afb541441f5d4c7199db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a18f4bf3974ee7990f8db643fafcb08d.setContent(html_a51bbd984985afb541441f5d4c7199db);
#
#
#
#         marker_e741eab01e58b0b60cf8b35fc88cd4f6.bindPopup(popup_a18f4bf3974ee7990f8db643fafcb08d)
#         ;
#
#
#
#
#             var marker_8db5e3d9637444aa8b7c561b36e6351b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_593b03e681a41011c8953e87f4b67c3f);
#
#
#         var popup_3d63a46de63504de2cf72f46ec8c47b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a869fa296a6ab798d1bede608559d56b = $(`&lt;div id=&quot;html_a869fa296a6ab798d1bede608559d56b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3d63a46de63504de2cf72f46ec8c47b4.setContent(html_a869fa296a6ab798d1bede608559d56b);
#
#
#
#         marker_8db5e3d9637444aa8b7c561b36e6351b.bindPopup(popup_3d63a46de63504de2cf72f46ec8c47b4)
#         ;
#
#
#
#
#             var marker_8c5a39d9d43aeef2f8d4156861a91dae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_593b03e681a41011c8953e87f4b67c3f);
#
#
#         var popup_24bdbb0d426527f4b99b31c57ecac7f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddbef1fa1cda5fa913e960929030c001 = $(`&lt;div id=&quot;html_ddbef1fa1cda5fa913e960929030c001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_24bdbb0d426527f4b99b31c57ecac7f2.setContent(html_ddbef1fa1cda5fa913e960929030c001);
#
#
#
#         marker_8c5a39d9d43aeef2f8d4156861a91dae.bindPopup(popup_24bdbb0d426527f4b99b31c57ecac7f2)
#         ;
#
#
#
#
#             var marker_bf4ad6d4b92a5ef128c928d2f9718d97 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_593b03e681a41011c8953e87f4b67c3f);
#
#
#         var popup_685868277726fd83db4e556c9d50e2ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_057bce42cee9a0c6c716faecf4f9b214 = $(`&lt;div id=&quot;html_057bce42cee9a0c6c716faecf4f9b214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_685868277726fd83db4e556c9d50e2ee.setContent(html_057bce42cee9a0c6c716faecf4f9b214);
#
#
#
#         marker_bf4ad6d4b92a5ef128c928d2f9718d97.bindPopup(popup_685868277726fd83db4e556c9d50e2ee)
#         ;
#
#
#
#
#             var marker_5e10829149c4bb50558e08fc4fcd6e96 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_593b03e681a41011c8953e87f4b67c3f);
#
#
#         var popup_77d1fd268a94c33eecf9a84b7cf1258f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_454d57ec2e463c1932de1818e454d753 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_454d57ec2e463c1932de1818e454d753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_454d57ec2e463c1932de1818e454d753 = L.map(
#                 &quot;map_454d57ec2e463c1932de1818e454d753&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_777059261d91e777ce1f69ae01289956 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_777059261d91e777ce1f69ae01289956.addTo(map_454d57ec2e463c1932de1818e454d753);
#
#
#             var feature_group_0061deb851aa16f7f4a6a07e44fb39f4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0061deb851aa16f7f4a6a07e44fb39f4.addTo(map_454d57ec2e463c1932de1818e454d753);
#
#
#             var feature_group_sub_group_3fb0eeb781c4fd9e0bf0cebc510c6c85 = L.featureGroup.subGroup(
#                 feature_group_0061deb851aa16f7f4a6a07e44fb39f4
#             );
#
#
#             var marker_b36dd38ac7cfd95136f78a88ac29acf9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3fb0eeb781c4fd9e0bf0cebc510c6c85);
#
#
#         var popup_a8522fef06da461897df1a1cf3720837 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3d2da9344c80a380ddf08437503e3f0 = $(`&lt;div id=&quot;html_b3d2da9344c80a380ddf08437503e3f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a8522fef06da461897df1a1cf3720837.setContent(html_b3d2da9344c80a380ddf08437503e3f0);
#
#
#
#         marker_b36dd38ac7cfd95136f78a88ac29acf9.bindPopup(popup_a8522fef06da461897df1a1cf3720837)
#         ;
#
#
#
#
#             var marker_9f88d881a48daebb073656b336e1f3d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3fb0eeb781c4fd9e0bf0cebc510c6c85);
#
#
#         var popup_97b78968768681b019131fa4e22c11a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2b97c54cccb91ac11a2be78dc21744a = $(`&lt;div id=&quot;html_f2b97c54cccb91ac11a2be78dc21744a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_97b78968768681b019131fa4e22c11a6.setContent(html_f2b97c54cccb91ac11a2be78dc21744a);
#
#
#
#         marker_9f88d881a48daebb073656b336e1f3d8.bindPopup(popup_97b78968768681b019131fa4e22c11a6)
#         ;
#
#
#
#
#             var marker_dfa42f02bd138d730ce57c1631d7e2e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3fb0eeb781c4fd9e0bf0cebc510c6c85);
#
#
#         var popup_0d3b9b4a0cd1f2594b3d89b03bacd389 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bba677f6611596f9d1454e1c23cb05e1 = $(`&lt;div id=&quot;html_bba677f6611596f9d1454e1c23cb05e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0d3b9b4a0cd1f2594b3d89b03bacd389.setContent(html_bba677f6611596f9d1454e1c23cb05e1);
#
#
#
#         marker_dfa42f02bd138d730ce57c1631d7e2e5.bindPopup(popup_0d3b9b4a0cd1f2594b3d89b03bacd389)
#         ;
#
#
#
#
#             var marker_bc85e7bad48ac15e8d57fe368ab9e4ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3fb0eeb781c4fd9e0bf0cebc510c6c85);
#
#
#         var popup_7b81089fedd6da6e58c2acd9c6a0293c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f7f0db5670f1c37a3c7d8a05b9d90f5 = $(`&lt;div id=&quot;html_7f7f0db5670f1c37a3c7d8a05b9d90f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7b81089fedd6da6e58c2acd9c6a0293c.setContent(html_7f7f0db5670f1c37a3c7d8a05b9d90f5);
#
#
#
#         mark
