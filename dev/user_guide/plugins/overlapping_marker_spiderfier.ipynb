# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2f7a6d635ed34a3c4ddd8d34b8861d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2f7a6d635ed34a3c4ddd8d34b8861d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2f7a6d635ed34a3c4ddd8d34b8861d9 = L.map(
#                 &quot;map_e2f7a6d635ed34a3c4ddd8d34b8861d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f1bd4f30d96e59048c64c374b8fcf1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f1bd4f30d96e59048c64c374b8fcf1f.addTo(map_e2f7a6d635ed34a3c4ddd8d34b8861d9);
#
#
#             var marker_f9aa8843b29c22fbe4dba5001f743d5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e2f7a6d635ed34a3c4ddd8d34b8861d9);
#
#
#         var popup_ad0d16b90d85495dcb9bd56a264dbe78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01cb5a0a9409e52ceb9b9d686fbdc326 = $(`&lt;div id=&quot;html_01cb5a0a9409e52ceb9b9d686fbdc326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ad0d16b90d85495dcb9bd56a264dbe78.setContent(html_01cb5a0a9409e52ceb9b9d686fbdc326);
#
#
#
#         marker_f9aa8843b29c22fbe4dba5001f743d5c.bindPopup(popup_ad0d16b90d85495dcb9bd56a264dbe78)
#         ;
#
#
#
#
#             var marker_7650d63dfa868bed781c3114828e2f12 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e2f7a6d635ed34a3c4ddd8d34b8861d9);
#
#
#         var popup_cdc3c68f201b1ff4207c2a8a837e4101 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef8e9a8363cc5683394c834b36f348fa = $(`&lt;div id=&quot;html_ef8e9a8363cc5683394c834b36f348fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cdc3c68f201b1ff4207c2a8a837e4101.setContent(html_ef8e9a8363cc5683394c834b36f348fa);
#
#
#
#         marker_7650d63dfa868bed781c3114828e2f12.bindPopup(popup_cdc3c68f201b1ff4207c2a8a837e4101)
#         ;
#
#
#
#
#             var marker_4131a98acd15b815d77668a09db5313a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e2f7a6d635ed34a3c4ddd8d34b8861d9);
#
#
#         var popup_43038f8679cbfaa42204e54ba60ce810 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f5c494fe434b60c442cd94e28ece82e = $(`&lt;div id=&quot;html_5f5c494fe434b60c442cd94e28ece82e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_43038f8679cbfaa42204e54ba60ce810.setContent(html_5f5c494fe434b60c442cd94e28ece82e);
#
#
#
#         marker_4131a98acd15b815d77668a09db5313a.bindPopup(popup_43038f8679cbfaa42204e54ba60ce810)
#         ;
#
#
#
#
#             var marker_fc9670fdabdd613acdd4a0eeea4288ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e2f7a6d635ed34a3c4ddd8d34b8861d9);
#
#
#         var popup_fba952586ae77477e8bf3a3b3f741394 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98ca67247fac3e542bfc71d01390156b = $(`&lt;div id=&quot;html_98ca67247fac3e542bfc71d01390156b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fba952586ae77477e8bf3a3b3f741394.setContent(html_98ca67247fac3e542bfc71d01390156b);
#
#
#
#         marker_fc9670fdabdd613acdd4a0eeea4288ea.bindPopup(popup_fba952586ae77477e8bf3a3b3f741394)
#         ;
#
#
#
#
#             var marker_4ad1c41821881d6408099818c7c35311 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e2f7a6d635ed34a3c4ddd8d34b8861d9);
#
#
#         var popup_cc0eee6078ddab6bafc8a23047ab5dc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ceb0619baaaae0cf1d41c5ac734fa0f = $(`&lt;div id=&quot;html_1ceb0619baaaae0cf1d41c5ac734fa0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cc0eee6078ddab6bafc8a23047ab5dc2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce2fc942fe9618ec2322679b1afb5b0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce2fc942fe9618ec2322679b1afb5b0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce2fc942fe9618ec2322679b1afb5b0b = L.map(
#                 &quot;map_ce2fc942fe9618ec2322679b1afb5b0b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21eec86d3ad9e052a2cc0d623918c145 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21eec86d3ad9e052a2cc0d623918c145.addTo(map_ce2fc942fe9618ec2322679b1afb5b0b);
#
#
#             var feature_group_9ff9ac24ea85b926cfbf6123ca643e75 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c8b5efa48c5337ff3d547e28fbcf76f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9ff9ac24ea85b926cfbf6123ca643e75);
#
#
#         var popup_444d2d0ab72c5c5ccebe3f17199100ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8e6bdc688888fea5801778bedf61d5b = $(`&lt;div id=&quot;html_f8e6bdc688888fea5801778bedf61d5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_444d2d0ab72c5c5ccebe3f17199100ac.setContent(html_f8e6bdc688888fea5801778bedf61d5b);
#
#
#
#         marker_c8b5efa48c5337ff3d547e28fbcf76f8.bindPopup(popup_444d2d0ab72c5c5ccebe3f17199100ac)
#         ;
#
#
#
#
#             var marker_8a4a7a90e51559e696b4d5d3fc8c5448 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9ff9ac24ea85b926cfbf6123ca643e75);
#
#
#         var popup_7390a732e301d1709f18444279289d7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87ad6488733e6e2bb882cdb8e86bd1a2 = $(`&lt;div id=&quot;html_87ad6488733e6e2bb882cdb8e86bd1a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7390a732e301d1709f18444279289d7c.setContent(html_87ad6488733e6e2bb882cdb8e86bd1a2);
#
#
#
#         marker_8a4a7a90e51559e696b4d5d3fc8c5448.bindPopup(popup_7390a732e301d1709f18444279289d7c)
#         ;
#
#
#
#
#             var marker_853a6a910bd405e8023d1e8875e15134 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9ff9ac24ea85b926cfbf6123ca643e75);
#
#
#         var popup_b17c8387bbec0241a12a29a6bf1b5a01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46e8574aa81dd5c8af2702909e157326 = $(`&lt;div id=&quot;html_46e8574aa81dd5c8af2702909e157326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b17c8387bbec0241a12a29a6bf1b5a01.setContent(html_46e8574aa81dd5c8af2702909e157326);
#
#
#
#         marker_853a6a910bd405e8023d1e8875e15134.bindPopup(popup_b17c8387bbec0241a12a29a6bf1b5a01)
#         ;
#
#
#
#
#             var marker_e0cc02c3e1ece4f39704552b8c0867f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9ff9ac24ea85b926cfbf6123ca643e75);
#
#
#         var popup_c486b7425de6e77bdebc14f714e8eccd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61d8022ab0085e9341206203dbe64055 = $(`&lt;div id=&quot;html_61d8022ab0085e9341206203dbe64055&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c486b7425de6e77bdebc14f714e8eccd.setContent(html_61d8022ab0085e9341206203dbe64055);
#
#
#
#         marker_e0cc02c3e1ece4f39704552b8c0867f4.bindPopup(popup_c486b7425de6e77bdebc14f714e8eccd)
#         ;
#
#
#
#
#             var marker_7114e5541d9ca205395109a1f9390d9e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9ff9ac24ea85b926cfbf6123ca643e75);
#
#
#         var popup_9034bb35dfff47b4eedbd10dc87d5d7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d6431e761599e5b2a4fa1871e8209ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d6431e761599e5b2a4fa1871e8209ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d6431e761599e5b2a4fa1871e8209ef = L.map(
#                 &quot;map_8d6431e761599e5b2a4fa1871e8209ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d047090a96ec603d1686b2bc2147bf3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d047090a96ec603d1686b2bc2147bf3.addTo(map_8d6431e761599e5b2a4fa1871e8209ef);
#
#
#             var feature_group_be88ed697364f9ceacb7789c46ad65cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_be88ed697364f9ceacb7789c46ad65cf.addTo(map_8d6431e761599e5b2a4fa1871e8209ef);
#
#
#             var feature_group_sub_group_cfb6f8149b8cd2cfbb3fe237221c6247 = L.featureGroup.subGroup(
#                 feature_group_be88ed697364f9ceacb7789c46ad65cf
#             );
#
#
#             var marker_4e2992063c223fa8b1586c7032e28298 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cfb6f8149b8cd2cfbb3fe237221c6247);
#
#
#         var popup_bfa3309e445bfd3f819904b0cbb82f6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e45c3be180a859d8764d47bea34da2a = $(`&lt;div id=&quot;html_9e45c3be180a859d8764d47bea34da2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bfa3309e445bfd3f819904b0cbb82f6d.setContent(html_9e45c3be180a859d8764d47bea34da2a);
#
#
#
#         marker_4e2992063c223fa8b1586c7032e28298.bindPopup(popup_bfa3309e445bfd3f819904b0cbb82f6d)
#         ;
#
#
#
#
#             var marker_83ad21cb89635102df9daa2c7d906ec6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cfb6f8149b8cd2cfbb3fe237221c6247);
#
#
#         var popup_a89e5d57d51d97e79162288d225ef1ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54e8039a48cc1b4decc87a58061fbbe3 = $(`&lt;div id=&quot;html_54e8039a48cc1b4decc87a58061fbbe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a89e5d57d51d97e79162288d225ef1ad.setContent(html_54e8039a48cc1b4decc87a58061fbbe3);
#
#
#
#         marker_83ad21cb89635102df9daa2c7d906ec6.bindPopup(popup_a89e5d57d51d97e79162288d225ef1ad)
#         ;
#
#
#
#
#             var marker_5f38c7ce9664b6250e8d359524b05748 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cfb6f8149b8cd2cfbb3fe237221c6247);
#
#
#         var popup_ef8dc899b327c1bdf309ca607d6ca9f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ea5419362b69c4ae8b3f0db9e9f260f = $(`&lt;div id=&quot;html_0ea5419362b69c4ae8b3f0db9e9f260f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef8dc899b327c1bdf309ca607d6ca9f4.setContent(html_0ea5419362b69c4ae8b3f0db9e9f260f);
#
#
#
#         marker_5f38c7ce9664b6250e8d359524b05748.bindPopup(popup_ef8dc899b327c1bdf309ca607d6ca9f4)
#         ;
#
#
#
#
#             var marker_05f1c8b90e5bbf3a5890b470a478bb4a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cfb6f8149b8cd2cfbb3fe237221c6247);
#
#
#         var popup_0381e39b1c11a3c8f012671e614e3c7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15b65f500a6fd709aea287b7aa0d9b83 = $(`&lt;div id=&quot;html_15b65f500a6fd709aea287b7aa0d9b83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0381e39b1c11a3c8f012671e614e3c7e.setContent(html_15b65f500a6fd709aea287b7aa0d9b83);
#
#
#
#         marker_
