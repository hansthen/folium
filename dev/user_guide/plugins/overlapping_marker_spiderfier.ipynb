# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ee9f907a943a44dfed90f77a10f869d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ee9f907a943a44dfed90f77a10f869d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ee9f907a943a44dfed90f77a10f869d = L.map(
#                 &quot;map_9ee9f907a943a44dfed90f77a10f869d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c54664e441ea38209eae0171f0ab87d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c54664e441ea38209eae0171f0ab87d6.addTo(map_9ee9f907a943a44dfed90f77a10f869d);
#
#
#             var marker_82982657ecd89edaef7fa323499b56fb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9ee9f907a943a44dfed90f77a10f869d);
#
#
#         var popup_08de9bccfbb558b523f83be732d2c647 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9af7c35423893b611ee8becba908d8cf = $(`&lt;div id=&quot;html_9af7c35423893b611ee8becba908d8cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_08de9bccfbb558b523f83be732d2c647.setContent(html_9af7c35423893b611ee8becba908d8cf);
#
#
#
#         marker_82982657ecd89edaef7fa323499b56fb.bindPopup(popup_08de9bccfbb558b523f83be732d2c647)
#         ;
#
#
#
#
#             var marker_7d8dccd1d52e2914beff26f8fc052649 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9ee9f907a943a44dfed90f77a10f869d);
#
#
#         var popup_0b88d018a2cbf7755620eee79c2ee431 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e10e2243d0ec7ff507bb0bac6062c84 = $(`&lt;div id=&quot;html_5e10e2243d0ec7ff507bb0bac6062c84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b88d018a2cbf7755620eee79c2ee431.setContent(html_5e10e2243d0ec7ff507bb0bac6062c84);
#
#
#
#         marker_7d8dccd1d52e2914beff26f8fc052649.bindPopup(popup_0b88d018a2cbf7755620eee79c2ee431)
#         ;
#
#
#
#
#             var marker_9ab52bb630f63a49caa652b3c8a0c373 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9ee9f907a943a44dfed90f77a10f869d);
#
#
#         var popup_7a65d1d8836ce2475153e4f15a9e5441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb90fded75d1b52b6c63d75359f85193 = $(`&lt;div id=&quot;html_eb90fded75d1b52b6c63d75359f85193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7a65d1d8836ce2475153e4f15a9e5441.setContent(html_eb90fded75d1b52b6c63d75359f85193);
#
#
#
#         marker_9ab52bb630f63a49caa652b3c8a0c373.bindPopup(popup_7a65d1d8836ce2475153e4f15a9e5441)
#         ;
#
#
#
#
#             var marker_fb237b5a05c275e184f3ab6311321b53 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9ee9f907a943a44dfed90f77a10f869d);
#
#
#         var popup_66919451d56bab37a216e87600fc7624 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68da5192b84fb1fdaaa5b1c105e8954b = $(`&lt;div id=&quot;html_68da5192b84fb1fdaaa5b1c105e8954b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_66919451d56bab37a216e87600fc7624.setContent(html_68da5192b84fb1fdaaa5b1c105e8954b);
#
#
#
#         marker_fb237b5a05c275e184f3ab6311321b53.bindPopup(popup_66919451d56bab37a216e87600fc7624)
#         ;
#
#
#
#
#             var marker_de79f74c1224a40af5bf01e4c49198ef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9ee9f907a943a44dfed90f77a10f869d);
#
#
#         var popup_8a6e2f9c35ecdfd56e1e46023d8dd8d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a3e8c81f4dbcce5eb57963b340d13d8 = $(`&lt;div id=&quot;html_0a3e8c81f4dbcce5eb57963b340d13d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8a6e2f9c35ecdfd56e1e46023d8dd8d9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f762c434f9460f2b3058c81fd0fb4aa6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f762c434f9460f2b3058c81fd0fb4aa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f762c434f9460f2b3058c81fd0fb4aa6 = L.map(
#                 &quot;map_f762c434f9460f2b3058c81fd0fb4aa6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20d7bd91e518ff6b515740068321bcea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20d7bd91e518ff6b515740068321bcea.addTo(map_f762c434f9460f2b3058c81fd0fb4aa6);
#
#
#             var feature_group_78c0d8dd60baf087f88e4f80c7573e5b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6b8ffc50fdec161624fb61850eb2d02c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_78c0d8dd60baf087f88e4f80c7573e5b);
#
#
#         var popup_b530c885f0d3051263ada624ab72992f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99f69d6ecc9cb9d8b010e5f17ad229e6 = $(`&lt;div id=&quot;html_99f69d6ecc9cb9d8b010e5f17ad229e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b530c885f0d3051263ada624ab72992f.setContent(html_99f69d6ecc9cb9d8b010e5f17ad229e6);
#
#
#
#         marker_6b8ffc50fdec161624fb61850eb2d02c.bindPopup(popup_b530c885f0d3051263ada624ab72992f)
#         ;
#
#
#
#
#             var marker_c1cb3b6ec19845f86c254dd120600060 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_78c0d8dd60baf087f88e4f80c7573e5b);
#
#
#         var popup_5e51ccee18ce42f7daa187bea1878cd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc38f4b9d1384cb2a19effaa7aeeb406 = $(`&lt;div id=&quot;html_bc38f4b9d1384cb2a19effaa7aeeb406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5e51ccee18ce42f7daa187bea1878cd9.setContent(html_bc38f4b9d1384cb2a19effaa7aeeb406);
#
#
#
#         marker_c1cb3b6ec19845f86c254dd120600060.bindPopup(popup_5e51ccee18ce42f7daa187bea1878cd9)
#         ;
#
#
#
#
#             var marker_af287cf946d227dafa059ee4de06da5d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_78c0d8dd60baf087f88e4f80c7573e5b);
#
#
#         var popup_011fe2b26d7e87ec3818f79736ed276b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc545f57f706d0058b4a4e17eef07c28 = $(`&lt;div id=&quot;html_fc545f57f706d0058b4a4e17eef07c28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_011fe2b26d7e87ec3818f79736ed276b.setContent(html_fc545f57f706d0058b4a4e17eef07c28);
#
#
#
#         marker_af287cf946d227dafa059ee4de06da5d.bindPopup(popup_011fe2b26d7e87ec3818f79736ed276b)
#         ;
#
#
#
#
#             var marker_c26e38027332abfdcf5ff8b28f0d65da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_78c0d8dd60baf087f88e4f80c7573e5b);
#
#
#         var popup_8dcc42fa3b8aec039c96b2a3ad66cc4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_253c1be417485f2fd71e4e2db5be51aa = $(`&lt;div id=&quot;html_253c1be417485f2fd71e4e2db5be51aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8dcc42fa3b8aec039c96b2a3ad66cc4c.setContent(html_253c1be417485f2fd71e4e2db5be51aa);
#
#
#
#         marker_c26e38027332abfdcf5ff8b28f0d65da.bindPopup(popup_8dcc42fa3b8aec039c96b2a3ad66cc4c)
#         ;
#
#
#
#
#             var marker_e7cda21932d0065075545c5f2333362c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_78c0d8dd60baf087f88e4f80c7573e5b);
#
#
#         var popup_ed5a9167f2c1ea361658c12fd57a8b3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4b0d174e17c7aa3602608b6afe23b89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4b0d174e17c7aa3602608b6afe23b89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4b0d174e17c7aa3602608b6afe23b89 = L.map(
#                 &quot;map_e4b0d174e17c7aa3602608b6afe23b89&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_006e2e5b77f88f02bb61c2e08d067c9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_006e2e5b77f88f02bb61c2e08d067c9d.addTo(map_e4b0d174e17c7aa3602608b6afe23b89);
#
#
#             var feature_group_40f1737cf76bdf2c5d43b10b94683799 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_40f1737cf76bdf2c5d43b10b94683799.addTo(map_e4b0d174e17c7aa3602608b6afe23b89);
#
#
#             var feature_group_sub_group_16d4ea107815ec0aed7e5352c0638d40 = L.featureGroup.subGroup(
#                 feature_group_40f1737cf76bdf2c5d43b10b94683799
#             );
#
#
#             var marker_af6d40ad276f7ef5a057f986e6f793c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_16d4ea107815ec0aed7e5352c0638d40);
#
#
#         var popup_c61b43e9c4000ff9551a5b8e77e8e21b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a705a2446c01d080a9f1177a12c6a5d = $(`&lt;div id=&quot;html_6a705a2446c01d080a9f1177a12c6a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c61b43e9c4000ff9551a5b8e77e8e21b.setContent(html_6a705a2446c01d080a9f1177a12c6a5d);
#
#
#
#         marker_af6d40ad276f7ef5a057f986e6f793c6.bindPopup(popup_c61b43e9c4000ff9551a5b8e77e8e21b)
#         ;
#
#
#
#
#             var marker_95d0ad5b7f2fa33c4157d2dd2c31f9ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_16d4ea107815ec0aed7e5352c0638d40);
#
#
#         var popup_92a095b0b545edf968e04a868e0f0f35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa732af3b88d7bac9c50696876215e05 = $(`&lt;div id=&quot;html_fa732af3b88d7bac9c50696876215e05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_92a095b0b545edf968e04a868e0f0f35.setContent(html_fa732af3b88d7bac9c50696876215e05);
#
#
#
#         marker_95d0ad5b7f2fa33c4157d2dd2c31f9ee.bindPopup(popup_92a095b0b545edf968e04a868e0f0f35)
#         ;
#
#
#
#
#             var marker_196fa405711a57dd736c99ed96fda78f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_16d4ea107815ec0aed7e5352c0638d40);
#
#
#         var popup_983ce7a2932c787a7b9497edf4a72718 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6346b29aaf7921c590782f8480839b07 = $(`&lt;div id=&quot;html_6346b29aaf7921c590782f8480839b07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_983ce7a2932c787a7b9497edf4a72718.setContent(html_6346b29aaf7921c590782f8480839b07);
#
#
#
#         marker_196fa405711a57dd736c99ed96fda78f.bindPopup(popup_983ce7a2932c787a7b9497edf4a72718)
#         ;
#
#
#
#
#             var marker_d79c65aea91f4319f9a07580d815c459 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_16d4ea107815ec0aed7e5352c0638d40);
#
#
#         var popup_554c45367b1cb4cac194de49ef2a07f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e775a74ef0982ceae22c3802d7d9f69 = $(`&lt;div id=&quot;html_2e775a74ef0982ceae22c3802d7d9f69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_554c45367b1cb4cac194de49ef2a07f7.setContent(html_2e775a74ef0982ceae22c3802d7d9f69);
#
#
#
#         marker_
