# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_625c32adbe1808e5a29f5cffa14f91f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_625c32adbe1808e5a29f5cffa14f91f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_625c32adbe1808e5a29f5cffa14f91f4 = L.map(
#                 &quot;map_625c32adbe1808e5a29f5cffa14f91f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c5d406114420ce8d5c42f3449170cc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c5d406114420ce8d5c42f3449170cc3.addTo(map_625c32adbe1808e5a29f5cffa14f91f4);
#
#
#             var marker_eb7d8ddb88296e8ef51d958029b9ed3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_625c32adbe1808e5a29f5cffa14f91f4);
#
#
#         var popup_1c244eac952ff373d212d13eba1714bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78bbe38963735814c808aa2770477b28 = $(`&lt;div id=&quot;html_78bbe38963735814c808aa2770477b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1c244eac952ff373d212d13eba1714bc.setContent(html_78bbe38963735814c808aa2770477b28);
#
#
#
#         marker_eb7d8ddb88296e8ef51d958029b9ed3b.bindPopup(popup_1c244eac952ff373d212d13eba1714bc)
#         ;
#
#
#
#
#             var marker_00315a777a83fcf938aec22a83af0f53 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_625c32adbe1808e5a29f5cffa14f91f4);
#
#
#         var popup_92f4154f2b5a3376db37df9e0d59f1e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c4eed60bd3c3c0d01ef944f34985bac = $(`&lt;div id=&quot;html_0c4eed60bd3c3c0d01ef944f34985bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_92f4154f2b5a3376db37df9e0d59f1e0.setContent(html_0c4eed60bd3c3c0d01ef944f34985bac);
#
#
#
#         marker_00315a777a83fcf938aec22a83af0f53.bindPopup(popup_92f4154f2b5a3376db37df9e0d59f1e0)
#         ;
#
#
#
#
#             var marker_ebeff181a673c9c0b91ca4c1b1de5c9f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_625c32adbe1808e5a29f5cffa14f91f4);
#
#
#         var popup_91093d8b57501157285f4f1e8d720f0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78a883ef496ece0ff54f1096948648f1 = $(`&lt;div id=&quot;html_78a883ef496ece0ff54f1096948648f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_91093d8b57501157285f4f1e8d720f0d.setContent(html_78a883ef496ece0ff54f1096948648f1);
#
#
#
#         marker_ebeff181a673c9c0b91ca4c1b1de5c9f.bindPopup(popup_91093d8b57501157285f4f1e8d720f0d)
#         ;
#
#
#
#
#             var marker_a9c8eb7f5e7ad7f333a5c62bf07dacef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_625c32adbe1808e5a29f5cffa14f91f4);
#
#
#         var popup_74465cd23cb6917e752b5aaf8ad0b856 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_954c3d34171b7abf01a04f98e09463b7 = $(`&lt;div id=&quot;html_954c3d34171b7abf01a04f98e09463b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_74465cd23cb6917e752b5aaf8ad0b856.setContent(html_954c3d34171b7abf01a04f98e09463b7);
#
#
#
#         marker_a9c8eb7f5e7ad7f333a5c62bf07dacef.bindPopup(popup_74465cd23cb6917e752b5aaf8ad0b856)
#         ;
#
#
#
#
#             var marker_76b72b2530b70b422acacd3d262f73c4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_625c32adbe1808e5a29f5cffa14f91f4);
#
#
#         var popup_d2651dca9a2bc814f9f3d1c97111c6da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d54ca365f3507f4fd650cd40b177ed0 = $(`&lt;div id=&quot;html_9d54ca365f3507f4fd650cd40b177ed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d2651dca9a2bc814f9f3d1c97111c6da.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5859e4b2ecca40c7b3a1cdfa6539d82 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5859e4b2ecca40c7b3a1cdfa6539d82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5859e4b2ecca40c7b3a1cdfa6539d82 = L.map(
#                 &quot;map_b5859e4b2ecca40c7b3a1cdfa6539d82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2748d955b60a503d7b03ade14262f182 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2748d955b60a503d7b03ade14262f182.addTo(map_b5859e4b2ecca40c7b3a1cdfa6539d82);
#
#
#             var feature_group_20000558419e49a943b4c12b044770ce = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_18c69710681141d5cdec5dbeb15c3058 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_20000558419e49a943b4c12b044770ce);
#
#
#         var popup_6f5e2706f93a08a8c2b95b461941f950 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_175f85401423325e1d4511efb8e6665e = $(`&lt;div id=&quot;html_175f85401423325e1d4511efb8e6665e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6f5e2706f93a08a8c2b95b461941f950.setContent(html_175f85401423325e1d4511efb8e6665e);
#
#
#
#         marker_18c69710681141d5cdec5dbeb15c3058.bindPopup(popup_6f5e2706f93a08a8c2b95b461941f950)
#         ;
#
#
#
#
#             var marker_0144cade09fb40a3fd13019ba0fef694 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_20000558419e49a943b4c12b044770ce);
#
#
#         var popup_6220888301c6b87993ff2e27422ebff6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d362bf9b2dc498723ee68c05b8f88af3 = $(`&lt;div id=&quot;html_d362bf9b2dc498723ee68c05b8f88af3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6220888301c6b87993ff2e27422ebff6.setContent(html_d362bf9b2dc498723ee68c05b8f88af3);
#
#
#
#         marker_0144cade09fb40a3fd13019ba0fef694.bindPopup(popup_6220888301c6b87993ff2e27422ebff6)
#         ;
#
#
#
#
#             var marker_30a664aebd1e522711b882dc7041d4ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_20000558419e49a943b4c12b044770ce);
#
#
#         var popup_40886c56f26f47767ccd57fe5bd2db55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1edfc613375af45ad273fb015476009 = $(`&lt;div id=&quot;html_c1edfc613375af45ad273fb015476009&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_40886c56f26f47767ccd57fe5bd2db55.setContent(html_c1edfc613375af45ad273fb015476009);
#
#
#
#         marker_30a664aebd1e522711b882dc7041d4ac.bindPopup(popup_40886c56f26f47767ccd57fe5bd2db55)
#         ;
#
#
#
#
#             var marker_fdec8b767742b1de59572d0d99e3a913 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_20000558419e49a943b4c12b044770ce);
#
#
#         var popup_0222b4c5b02b956bf9fead268159864c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8f3813fd000df1a4bf28216f5f9834e = $(`&lt;div id=&quot;html_d8f3813fd000df1a4bf28216f5f9834e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0222b4c5b02b956bf9fead268159864c.setContent(html_d8f3813fd000df1a4bf28216f5f9834e);
#
#
#
#         marker_fdec8b767742b1de59572d0d99e3a913.bindPopup(popup_0222b4c5b02b956bf9fead268159864c)
#         ;
#
#
#
#
#             var marker_797c54415cb15d15e7ec4bead1201063 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_20000558419e49a943b4c12b044770ce);
#
#
#         var popup_9dc194672e1bb8d781aefde126ee2de4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d8418b30ad818bd649983fe9f4eeaf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d8418b30ad818bd649983fe9f4eeaf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d8418b30ad818bd649983fe9f4eeaf6 = L.map(
#                 &quot;map_7d8418b30ad818bd649983fe9f4eeaf6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3ace238061b4315c223acd1bcde4be7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3ace238061b4315c223acd1bcde4be7.addTo(map_7d8418b30ad818bd649983fe9f4eeaf6);
#
#
#             var feature_group_2d71920c773ec01c0c1d08337dddf150 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2d71920c773ec01c0c1d08337dddf150.addTo(map_7d8418b30ad818bd649983fe9f4eeaf6);
#
#
#             var feature_group_sub_group_133f37bfa58149e18cc1516f46f2a4a5 = L.featureGroup.subGroup(
#                 feature_group_2d71920c773ec01c0c1d08337dddf150
#             );
#
#
#             var marker_22de9f9aeaab4d6d9bf1a823a71c7279 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_133f37bfa58149e18cc1516f46f2a4a5);
#
#
#         var popup_1b7f4562f64d59130cf509baea51152f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a908d8b60e032b175fc4f21fe278b21 = $(`&lt;div id=&quot;html_8a908d8b60e032b175fc4f21fe278b21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1b7f4562f64d59130cf509baea51152f.setContent(html_8a908d8b60e032b175fc4f21fe278b21);
#
#
#
#         marker_22de9f9aeaab4d6d9bf1a823a71c7279.bindPopup(popup_1b7f4562f64d59130cf509baea51152f)
#         ;
#
#
#
#
#             var marker_99691073d9825c14ed172a6af6b089b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_133f37bfa58149e18cc1516f46f2a4a5);
#
#
#         var popup_5596e71ce8357259df9ef066427be7b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca7e292dd02bb680cd0367aa52a76251 = $(`&lt;div id=&quot;html_ca7e292dd02bb680cd0367aa52a76251&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5596e71ce8357259df9ef066427be7b5.setContent(html_ca7e292dd02bb680cd0367aa52a76251);
#
#
#
#         marker_99691073d9825c14ed172a6af6b089b9.bindPopup(popup_5596e71ce8357259df9ef066427be7b5)
#         ;
#
#
#
#
#             var marker_189baf5b715087e0ca8a564233344d9b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_133f37bfa58149e18cc1516f46f2a4a5);
#
#
#         var popup_ea5938d52e8602c7c49a4bb8581226c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f008e6d2afe58a653d3e9a5b928e66e9 = $(`&lt;div id=&quot;html_f008e6d2afe58a653d3e9a5b928e66e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ea5938d52e8602c7c49a4bb8581226c9.setContent(html_f008e6d2afe58a653d3e9a5b928e66e9);
#
#
#
#         marker_189baf5b715087e0ca8a564233344d9b.bindPopup(popup_ea5938d52e8602c7c49a4bb8581226c9)
#         ;
#
#
#
#
#             var marker_44614c18ef012aff1e7f0b5ed9a8c5b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_133f37bfa58149e18cc1516f46f2a4a5);
#
#
#         var popup_84eb4430619edb295657e7263d8c441d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e1871d6fe4beaf0e092627c72ce0aa9 = $(`&lt;div id=&quot;html_3e1871d6fe4beaf0e092627c72ce0aa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_84eb4430619edb295657e7263d8c441d.setContent(html_3e1871d6fe4beaf0e092627c72ce0aa9);
#
#
#
#         marker_
