# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d9b2465f2876736bac2df471abb172a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d9b2465f2876736bac2df471abb172a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d9b2465f2876736bac2df471abb172a = L.map(
#                 &quot;map_2d9b2465f2876736bac2df471abb172a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7b9ffb4213d8af17e4102d05e87c589 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7b9ffb4213d8af17e4102d05e87c589.addTo(map_2d9b2465f2876736bac2df471abb172a);
#
#
#             var marker_3eefeb3510cac520dc7f29cbbde42f7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2d9b2465f2876736bac2df471abb172a);
#
#
#         var popup_396008c1409bd86dc8a7c3d18b16394d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c1c18f8c626b550587587b1eb0e3c38 = $(`&lt;div id=&quot;html_0c1c18f8c626b550587587b1eb0e3c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_396008c1409bd86dc8a7c3d18b16394d.setContent(html_0c1c18f8c626b550587587b1eb0e3c38);
#
#
#
#         marker_3eefeb3510cac520dc7f29cbbde42f7d.bindPopup(popup_396008c1409bd86dc8a7c3d18b16394d)
#         ;
#
#
#
#
#             var marker_9bebce5b25d2ea20a6305c796b4471cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2d9b2465f2876736bac2df471abb172a);
#
#
#         var popup_f30d392ebe3bd7646d4dd1a1cee43af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ec3a45b589807eb702337bf6ad781a = $(`&lt;div id=&quot;html_e2ec3a45b589807eb702337bf6ad781a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f30d392ebe3bd7646d4dd1a1cee43af7.setContent(html_e2ec3a45b589807eb702337bf6ad781a);
#
#
#
#         marker_9bebce5b25d2ea20a6305c796b4471cc.bindPopup(popup_f30d392ebe3bd7646d4dd1a1cee43af7)
#         ;
#
#
#
#
#             var marker_f6b966f1cec3eb876042d906bee68099 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2d9b2465f2876736bac2df471abb172a);
#
#
#         var popup_d32837ccd9d30b2a1cb532c4933192d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87d3dbe918a8f41d9b9a829132cac83a = $(`&lt;div id=&quot;html_87d3dbe918a8f41d9b9a829132cac83a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d32837ccd9d30b2a1cb532c4933192d9.setContent(html_87d3dbe918a8f41d9b9a829132cac83a);
#
#
#
#         marker_f6b966f1cec3eb876042d906bee68099.bindPopup(popup_d32837ccd9d30b2a1cb532c4933192d9)
#         ;
#
#
#
#
#             var marker_88a23f5b9219f580efb72b82dbc58572 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2d9b2465f2876736bac2df471abb172a);
#
#
#         var popup_e5def4078b026a974a3a29c60f5fe693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63ffa42cbc92d4d7f1ba43225547895c = $(`&lt;div id=&quot;html_63ffa42cbc92d4d7f1ba43225547895c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e5def4078b026a974a3a29c60f5fe693.setContent(html_63ffa42cbc92d4d7f1ba43225547895c);
#
#
#
#         marker_88a23f5b9219f580efb72b82dbc58572.bindPopup(popup_e5def4078b026a974a3a29c60f5fe693)
#         ;
#
#
#
#
#             var marker_1c942f81cde3ff63161ff692f8a26256 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2d9b2465f2876736bac2df471abb172a);
#
#
#         var popup_8025a3fdfeb0a64616f2bdf6e96ae252 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64190d588457b84251666bcd565d7754 = $(`&lt;div id=&quot;html_64190d588457b84251666bcd565d7754&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8025a3fdfeb0a64616f2bdf6e96ae252.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9445d969a0d1cd5a195832158efb0b4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9445d969a0d1cd5a195832158efb0b4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9445d969a0d1cd5a195832158efb0b4d = L.map(
#                 &quot;map_9445d969a0d1cd5a195832158efb0b4d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea219c746ab911cfbd6915c8bf13529b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea219c746ab911cfbd6915c8bf13529b.addTo(map_9445d969a0d1cd5a195832158efb0b4d);
#
#
#             var feature_group_ce93fddbadbadc96a9da1847baec91e5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e7e38fa745cf60a4dfde789e5a40f30f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce93fddbadbadc96a9da1847baec91e5);
#
#
#         var popup_82171d6f91802ca7159066db817504f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd033badc8b768e6da09b590ebd332fb = $(`&lt;div id=&quot;html_bd033badc8b768e6da09b590ebd332fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_82171d6f91802ca7159066db817504f3.setContent(html_bd033badc8b768e6da09b590ebd332fb);
#
#
#
#         marker_e7e38fa745cf60a4dfde789e5a40f30f.bindPopup(popup_82171d6f91802ca7159066db817504f3)
#         ;
#
#
#
#
#             var marker_424e44d5e783a071b39b99ef6a335192 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce93fddbadbadc96a9da1847baec91e5);
#
#
#         var popup_845014f4357a574864bb61538926d81f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_639b1fabcaac9a7ae6d3c71c6cec970c = $(`&lt;div id=&quot;html_639b1fabcaac9a7ae6d3c71c6cec970c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_845014f4357a574864bb61538926d81f.setContent(html_639b1fabcaac9a7ae6d3c71c6cec970c);
#
#
#
#         marker_424e44d5e783a071b39b99ef6a335192.bindPopup(popup_845014f4357a574864bb61538926d81f)
#         ;
#
#
#
#
#             var marker_c5c6aece846d155472fadbe6027cc5d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce93fddbadbadc96a9da1847baec91e5);
#
#
#         var popup_010459bfceea74fa9ef156bf4321ad99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fbab4d687374bddd32df8f8ee542d1a = $(`&lt;div id=&quot;html_7fbab4d687374bddd32df8f8ee542d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_010459bfceea74fa9ef156bf4321ad99.setContent(html_7fbab4d687374bddd32df8f8ee542d1a);
#
#
#
#         marker_c5c6aece846d155472fadbe6027cc5d7.bindPopup(popup_010459bfceea74fa9ef156bf4321ad99)
#         ;
#
#
#
#
#             var marker_9a7cef70bc5baa6fbf153c4d2e91cb0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce93fddbadbadc96a9da1847baec91e5);
#
#
#         var popup_fa962efb8dc8ed5481586dc7dea43978 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_779ca5886418e706616f4f6064167b92 = $(`&lt;div id=&quot;html_779ca5886418e706616f4f6064167b92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fa962efb8dc8ed5481586dc7dea43978.setContent(html_779ca5886418e706616f4f6064167b92);
#
#
#
#         marker_9a7cef70bc5baa6fbf153c4d2e91cb0d.bindPopup(popup_fa962efb8dc8ed5481586dc7dea43978)
#         ;
#
#
#
#
#             var marker_3422fe27ec429b06ee83e398671b7924 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce93fddbadbadc96a9da1847baec91e5);
#
#
#         var popup_e5ce65f5da2aeb93c16a20bdd40b3adc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80f74f0775c6b144aeb55ea371cddfb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80f74f0775c6b144aeb55ea371cddfb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80f74f0775c6b144aeb55ea371cddfb7 = L.map(
#                 &quot;map_80f74f0775c6b144aeb55ea371cddfb7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_667984629e0302cf82f11f4eba4183a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_667984629e0302cf82f11f4eba4183a0.addTo(map_80f74f0775c6b144aeb55ea371cddfb7);
#
#
#             var feature_group_235683e8b5e3670ce98328722d2b58f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_235683e8b5e3670ce98328722d2b58f1.addTo(map_80f74f0775c6b144aeb55ea371cddfb7);
#
#
#             var feature_group_sub_group_4452f16f65a30c9fb006d4851d88de74 = L.featureGroup.subGroup(
#                 feature_group_235683e8b5e3670ce98328722d2b58f1
#             );
#
#
#             var marker_a193999653eb71efbf0cbe39142c8476 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4452f16f65a30c9fb006d4851d88de74);
#
#
#         var popup_0ac04e33bfba141a41f4485eb3846ad6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3b3467e5deb31ab3c7827fc028fe557 = $(`&lt;div id=&quot;html_e3b3467e5deb31ab3c7827fc028fe557&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0ac04e33bfba141a41f4485eb3846ad6.setContent(html_e3b3467e5deb31ab3c7827fc028fe557);
#
#
#
#         marker_a193999653eb71efbf0cbe39142c8476.bindPopup(popup_0ac04e33bfba141a41f4485eb3846ad6)
#         ;
#
#
#
#
#             var marker_52dc0e065c2c7555f6aeb85c8576436f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4452f16f65a30c9fb006d4851d88de74);
#
#
#         var popup_71d7af5abf0e2634b275933c2bbf5d23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d0e3f7dd3360b6db6e9d95c4c6a236 = $(`&lt;div id=&quot;html_c7d0e3f7dd3360b6db6e9d95c4c6a236&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_71d7af5abf0e2634b275933c2bbf5d23.setContent(html_c7d0e3f7dd3360b6db6e9d95c4c6a236);
#
#
#
#         marker_52dc0e065c2c7555f6aeb85c8576436f.bindPopup(popup_71d7af5abf0e2634b275933c2bbf5d23)
#         ;
#
#
#
#
#             var marker_c2ff620fec90be870d3b94bc119cdab2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4452f16f65a30c9fb006d4851d88de74);
#
#
#         var popup_1ddedb7d19ed5b0281363e83a8a0b4bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c795821498cbed481efc1c10376431e7 = $(`&lt;div id=&quot;html_c795821498cbed481efc1c10376431e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1ddedb7d19ed5b0281363e83a8a0b4bc.setContent(html_c795821498cbed481efc1c10376431e7);
#
#
#
#         marker_c2ff620fec90be870d3b94bc119cdab2.bindPopup(popup_1ddedb7d19ed5b0281363e83a8a0b4bc)
#         ;
#
#
#
#
#             var marker_456f7253728d3fdae5efe999293e9a3d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4452f16f65a30c9fb006d4851d88de74);
#
#
#         var popup_4ba8f250ef08345aab21a5804850011e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1646ee0e4ce69e101e9dc59001901e63 = $(`&lt;div id=&quot;html_1646ee0e4ce69e101e9dc59001901e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4ba8f250ef08345aab21a5804850011e.setContent(html_1646ee0e4ce69e101e9dc59001901e63);
#
#
#
#         marker_
