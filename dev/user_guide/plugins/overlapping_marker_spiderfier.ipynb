# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1cd9e2d9df2e7bd61f9a0523b6c94de {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1cd9e2d9df2e7bd61f9a0523b6c94de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1cd9e2d9df2e7bd61f9a0523b6c94de = L.map(
#                 &quot;map_d1cd9e2d9df2e7bd61f9a0523b6c94de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_097d688b34427f73d9590d6cff3c6454 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_097d688b34427f73d9590d6cff3c6454.addTo(map_d1cd9e2d9df2e7bd61f9a0523b6c94de);
#
#
#             var marker_c2179e44a8528ef24aed6875e3baed96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d1cd9e2d9df2e7bd61f9a0523b6c94de);
#
#
#         var popup_6eb82d07c7185afc6ce7675e33dbebe0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61838dc710e40f9f3124096b77da0817 = $(`&lt;div id=&quot;html_61838dc710e40f9f3124096b77da0817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6eb82d07c7185afc6ce7675e33dbebe0.setContent(html_61838dc710e40f9f3124096b77da0817);
#
#
#
#         marker_c2179e44a8528ef24aed6875e3baed96.bindPopup(popup_6eb82d07c7185afc6ce7675e33dbebe0)
#         ;
#
#
#
#
#             var marker_72f5276c4d965fbae9aae2b8492e0225 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d1cd9e2d9df2e7bd61f9a0523b6c94de);
#
#
#         var popup_09c5d86e54a6271a19a6055147d209b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cc74c5cec464179bf5df98ec81ebb72 = $(`&lt;div id=&quot;html_8cc74c5cec464179bf5df98ec81ebb72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_09c5d86e54a6271a19a6055147d209b8.setContent(html_8cc74c5cec464179bf5df98ec81ebb72);
#
#
#
#         marker_72f5276c4d965fbae9aae2b8492e0225.bindPopup(popup_09c5d86e54a6271a19a6055147d209b8)
#         ;
#
#
#
#
#             var marker_283b7f08e11442832c187876cfaae3cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d1cd9e2d9df2e7bd61f9a0523b6c94de);
#
#
#         var popup_1b67c1b6c93e1b6ea9d9b2ecc872719c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b6d6c250108d2bb1764f305e20ebcb1 = $(`&lt;div id=&quot;html_8b6d6c250108d2bb1764f305e20ebcb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1b67c1b6c93e1b6ea9d9b2ecc872719c.setContent(html_8b6d6c250108d2bb1764f305e20ebcb1);
#
#
#
#         marker_283b7f08e11442832c187876cfaae3cc.bindPopup(popup_1b67c1b6c93e1b6ea9d9b2ecc872719c)
#         ;
#
#
#
#
#             var marker_7bf2e51606630f6b39b4736384da0dce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d1cd9e2d9df2e7bd61f9a0523b6c94de);
#
#
#         var popup_d91bcd6fcf0a3f94957a6af47e1e074a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0769c3cead825d0a2226a135ee78f06 = $(`&lt;div id=&quot;html_a0769c3cead825d0a2226a135ee78f06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d91bcd6fcf0a3f94957a6af47e1e074a.setContent(html_a0769c3cead825d0a2226a135ee78f06);
#
#
#
#         marker_7bf2e51606630f6b39b4736384da0dce.bindPopup(popup_d91bcd6fcf0a3f94957a6af47e1e074a)
#         ;
#
#
#
#
#             var marker_0669973c033dee1decc1842a278e245b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d1cd9e2d9df2e7bd61f9a0523b6c94de);
#
#
#         var popup_27f838f0cad86675df1022d00b82de91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd390bc729323e606b626898cedd5ccc = $(`&lt;div id=&quot;html_bd390bc729323e606b626898cedd5ccc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_27f838f0cad86675df1022d00b82de

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_861533c63248fb587ebd14d493624da7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_861533c63248fb587ebd14d493624da7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_861533c63248fb587ebd14d493624da7 = L.map(
#                 &quot;map_861533c63248fb587ebd14d493624da7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e0ce0f452049370492c092ffb3cf667 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e0ce0f452049370492c092ffb3cf667.addTo(map_861533c63248fb587ebd14d493624da7);
#
#
#             var feature_group_0217d4afbe48f60296f0f3b4369c1449 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_41c7ec8d246838d39cfc431d471d0e78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0217d4afbe48f60296f0f3b4369c1449);
#
#
#         var popup_da641f1c8995354c658d9a6023d613e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b03d38a9a3d7cbb1d5e45df7b9011fcf = $(`&lt;div id=&quot;html_b03d38a9a3d7cbb1d5e45df7b9011fcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_da641f1c8995354c658d9a6023d613e6.setContent(html_b03d38a9a3d7cbb1d5e45df7b9011fcf);
#
#
#
#         marker_41c7ec8d246838d39cfc431d471d0e78.bindPopup(popup_da641f1c8995354c658d9a6023d613e6)
#         ;
#
#
#
#
#             var marker_9970b6502653498289b92df74a7ee2e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0217d4afbe48f60296f0f3b4369c1449);
#
#
#         var popup_3bcb63e03f350b982006c796b2e2a168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_190adba77744fe5c754d96d8e82a3fb5 = $(`&lt;div id=&quot;html_190adba77744fe5c754d96d8e82a3fb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3bcb63e03f350b982006c796b2e2a168.setContent(html_190adba77744fe5c754d96d8e82a3fb5);
#
#
#
#         marker_9970b6502653498289b92df74a7ee2e0.bindPopup(popup_3bcb63e03f350b982006c796b2e2a168)
#         ;
#
#
#
#
#             var marker_08a7ae6f0e3e21f96c85daf351fa8b95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0217d4afbe48f60296f0f3b4369c1449);
#
#
#         var popup_2ea337adcba229ade10fe0107a975b77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2db2af7103e49825fb72ad8a476df6c5 = $(`&lt;div id=&quot;html_2db2af7103e49825fb72ad8a476df6c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2ea337adcba229ade10fe0107a975b77.setContent(html_2db2af7103e49825fb72ad8a476df6c5);
#
#
#
#         marker_08a7ae6f0e3e21f96c85daf351fa8b95.bindPopup(popup_2ea337adcba229ade10fe0107a975b77)
#         ;
#
#
#
#
#             var marker_32909a406af255eda977504310129cd5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0217d4afbe48f60296f0f3b4369c1449);
#
#
#         var popup_a3a65b7d8e19b694df54b6afdc6ef849 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e717ea8b021ffa0a50ce455cacdb24ad = $(`&lt;div id=&quot;html_e717ea8b021ffa0a50ce455cacdb24ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a3a65b7d8e19b694df54b6afdc6ef849.setContent(html_e717ea8b021ffa0a50ce455cacdb24ad);
#
#
#
#         marker_32909a406af255eda977504310129cd5.bindPopup(popup_a3a65b7d8e19b694df54b6afdc6ef849)
#         ;
#
#
#
#
#             var marker_1c05e5d3fb3ca8f1d476eaee9556393c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0217d4afbe48f60296f0f3b4369c1449);
#
#
#         var popup_18e1b3cd1a83b2ea77fa9024c7dfa330 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34633994cf908b10a959371e9dc25be1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34633994cf908b10a959371e9dc25be1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34633994cf908b10a959371e9dc25be1 = L.map(
#                 &quot;map_34633994cf908b10a959371e9dc25be1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a17631f80a0ed2354757200360cfe910 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a17631f80a0ed2354757200360cfe910.addTo(map_34633994cf908b10a959371e9dc25be1);
#
#
#             var feature_group_77a43d1b0f07672bc9ac3ed080b812e5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_77a43d1b0f07672bc9ac3ed080b812e5.addTo(map_34633994cf908b10a959371e9dc25be1);
#
#
#             var feature_group_sub_group_2bbc561e91336a5fa37cb749e2f90b9c = L.featureGroup.subGroup(
#                 feature_group_77a43d1b0f07672bc9ac3ed080b812e5
#             );
#
#
#             var marker_2dc3c6569775d224ae397ce6a3a7fa3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbc561e91336a5fa37cb749e2f90b9c);
#
#
#         var popup_cb681bfe3294512531bd6b985ef7606c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0358fc6af8b3ed4a4c048c9201f2dd93 = $(`&lt;div id=&quot;html_0358fc6af8b3ed4a4c048c9201f2dd93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb681bfe3294512531bd6b985ef7606c.setContent(html_0358fc6af8b3ed4a4c048c9201f2dd93);
#
#
#
#         marker_2dc3c6569775d224ae397ce6a3a7fa3d.bindPopup(popup_cb681bfe3294512531bd6b985ef7606c)
#         ;
#
#
#
#
#             var marker_5c670318b765c4459987b0cff6d85df0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbc561e91336a5fa37cb749e2f90b9c);
#
#
#         var popup_e392d71f8eee80d74ee3ba314587c3dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51cdbe6832e9a587cbfeac3fa1b17b96 = $(`&lt;div id=&quot;html_51cdbe6832e9a587cbfeac3fa1b17b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e392d71f8eee80d74ee3ba314587c3dd.setContent(html_51cdbe6832e9a587cbfeac3fa1b17b96);
#
#
#
#         marker_5c670318b765c4459987b0cff6d85df0.bindPopup(popup_e392d71f8eee80d74ee3ba314587c3dd)
#         ;
#
#
#
#
#             var marker_7beda33ce1995e9cabb99ef23f7ca2bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbc561e91336a5fa37cb749e2f90b9c);
#
#
#         var popup_d8a29d8e804fa9e249c5d72bfe6c7256 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1fe483d9ede893fea893070ec0a1ffe = $(`&lt;div id=&quot;html_e1fe483d9ede893fea893070ec0a1ffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d8a29d8e804fa9e249c5d72bfe6c7256.setContent(html_e1fe483d9ede893fea893070ec0a1ffe);
#
#
#
#         marker_7beda33ce1995e9cabb99ef23f7ca2bc.bindPopup(popup_d8a29d8e804fa9e249c5d72bfe6c7256)
#         ;
#
#
#
#
#             var marker_dddd3286fa97ae3607116460c1587fdf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2bbc561e91336a5fa37cb749e2f90b9c);
#
#
#         var popup_ffd733b92721a7b67fbb7bd6cc0109c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae84a8ebe9491a26ae9191621bddda6b = $(`&lt;div id=&quot;html_ae84a8ebe9491a26ae9191621bddda6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ffd733b92721a7b67fbb7bd6cc0109c5.setContent(html_ae84a8ebe9491a26ae9191621bddda6b);
#
#
#
#         mark
