# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e6cb65e848c57ac7018ab4de7b8071a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e6cb65e848c57ac7018ab4de7b8071a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e6cb65e848c57ac7018ab4de7b8071a = L.map(
#                 &quot;map_7e6cb65e848c57ac7018ab4de7b8071a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_302a996e4c6766d24f7428a6a477fc49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_302a996e4c6766d24f7428a6a477fc49.addTo(map_7e6cb65e848c57ac7018ab4de7b8071a);
#
#
#             var marker_47283ea51ebf73eea39b6db81f2eef4e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7e6cb65e848c57ac7018ab4de7b8071a);
#
#
#         var popup_0885094986bddd336fb2a396261d30ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3778e460a43c9a45589c825a67c893ac = $(`&lt;div id=&quot;html_3778e460a43c9a45589c825a67c893ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0885094986bddd336fb2a396261d30ba.setContent(html_3778e460a43c9a45589c825a67c893ac);
#
#
#
#         marker_47283ea51ebf73eea39b6db81f2eef4e.bindPopup(popup_0885094986bddd336fb2a396261d30ba)
#         ;
#
#
#
#
#             var marker_e57d9fe4d0c57e115ea158bee5eab507 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7e6cb65e848c57ac7018ab4de7b8071a);
#
#
#         var popup_b9c1306f7239b51de9eb595a9816c2f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2ac0a819767b8fecd6a6fc7d39fb905 = $(`&lt;div id=&quot;html_a2ac0a819767b8fecd6a6fc7d39fb905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b9c1306f7239b51de9eb595a9816c2f9.setContent(html_a2ac0a819767b8fecd6a6fc7d39fb905);
#
#
#
#         marker_e57d9fe4d0c57e115ea158bee5eab507.bindPopup(popup_b9c1306f7239b51de9eb595a9816c2f9)
#         ;
#
#
#
#
#             var marker_932c3fed26ebedc95defae9c2deaff1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7e6cb65e848c57ac7018ab4de7b8071a);
#
#
#         var popup_c32c91bc5cb7147cdbcf2d3f06417c73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68eac045503073afe70654b51cc24f9d = $(`&lt;div id=&quot;html_68eac045503073afe70654b51cc24f9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c32c91bc5cb7147cdbcf2d3f06417c73.setContent(html_68eac045503073afe70654b51cc24f9d);
#
#
#
#         marker_932c3fed26ebedc95defae9c2deaff1b.bindPopup(popup_c32c91bc5cb7147cdbcf2d3f06417c73)
#         ;
#
#
#
#
#             var marker_9a10a6112666b30d4130736decc92931 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7e6cb65e848c57ac7018ab4de7b8071a);
#
#
#         var popup_240131de9f2add47224b1cd65732c899 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75c4a72f09a1d400b266a74c071ac1b6 = $(`&lt;div id=&quot;html_75c4a72f09a1d400b266a74c071ac1b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_240131de9f2add47224b1cd65732c899.setContent(html_75c4a72f09a1d400b266a74c071ac1b6);
#
#
#
#         marker_9a10a6112666b30d4130736decc92931.bindPopup(popup_240131de9f2add47224b1cd65732c899)
#         ;
#
#
#
#
#             var marker_a6bcbe82f943a265201358a1f4a9748e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7e6cb65e848c57ac7018ab4de7b8071a);
#
#
#         var popup_67575c9ac08ed7456c98fecc5a55db35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1663f91bc49006a3d21aa939f203869a = $(`&lt;div id=&quot;html_1663f91bc49006a3d21aa939f203869a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_67575c9ac08ed7456c98fecc5a55db

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc588d15af0ed20243a4ee97b8918f9b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc588d15af0ed20243a4ee97b8918f9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc588d15af0ed20243a4ee97b8918f9b = L.map(
#                 &quot;map_fc588d15af0ed20243a4ee97b8918f9b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8c939c5ddf493b27880b989c1e8c2dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8c939c5ddf493b27880b989c1e8c2dc.addTo(map_fc588d15af0ed20243a4ee97b8918f9b);
#
#
#             var feature_group_6d01fda51c10fb630b17693dc81420ce = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a1b35429599c37c61bb2612895536259 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6d01fda51c10fb630b17693dc81420ce);
#
#
#         var popup_da5535d76c3bd5801e3d2b45b00c0560 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce779f4f3f3ec8f9f357e93fb1728fe7 = $(`&lt;div id=&quot;html_ce779f4f3f3ec8f9f357e93fb1728fe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_da5535d76c3bd5801e3d2b45b00c0560.setContent(html_ce779f4f3f3ec8f9f357e93fb1728fe7);
#
#
#
#         marker_a1b35429599c37c61bb2612895536259.bindPopup(popup_da5535d76c3bd5801e3d2b45b00c0560)
#         ;
#
#
#
#
#             var marker_28966fc1cb55aef371f427efe1535cb2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6d01fda51c10fb630b17693dc81420ce);
#
#
#         var popup_92679d004e3f87c0970909376976eb4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55b67af440258c8bc6b9bf1292d31838 = $(`&lt;div id=&quot;html_55b67af440258c8bc6b9bf1292d31838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_92679d004e3f87c0970909376976eb4c.setContent(html_55b67af440258c8bc6b9bf1292d31838);
#
#
#
#         marker_28966fc1cb55aef371f427efe1535cb2.bindPopup(popup_92679d004e3f87c0970909376976eb4c)
#         ;
#
#
#
#
#             var marker_3d3e969770905bed923c3b167664dd8d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6d01fda51c10fb630b17693dc81420ce);
#
#
#         var popup_8a7e20a5a1f748f4eb0904e0003494bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fc64e30a7277841a28f92abddae7be9 = $(`&lt;div id=&quot;html_3fc64e30a7277841a28f92abddae7be9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8a7e20a5a1f748f4eb0904e0003494bb.setContent(html_3fc64e30a7277841a28f92abddae7be9);
#
#
#
#         marker_3d3e969770905bed923c3b167664dd8d.bindPopup(popup_8a7e20a5a1f748f4eb0904e0003494bb)
#         ;
#
#
#
#
#             var marker_ff3ec362d30780be77bae418d049458c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6d01fda51c10fb630b17693dc81420ce);
#
#
#         var popup_1ab89e051e876ca200b538be49d8455a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84dcc7eabcf3f78dd263c0f66d46bec7 = $(`&lt;div id=&quot;html_84dcc7eabcf3f78dd263c0f66d46bec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1ab89e051e876ca200b538be49d8455a.setContent(html_84dcc7eabcf3f78dd263c0f66d46bec7);
#
#
#
#         marker_ff3ec362d30780be77bae418d049458c.bindPopup(popup_1ab89e051e876ca200b538be49d8455a)
#         ;
#
#
#
#
#             var marker_f3afeae8573b563a377e62aeef0f85ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6d01fda51c10fb630b17693dc81420ce);
#
#
#         var popup_afbbd9fd358ce16d598524daeb91151f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2256b5cff356668b27e5e5d70111c332 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2256b5cff356668b27e5e5d70111c332&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2256b5cff356668b27e5e5d70111c332 = L.map(
#                 &quot;map_2256b5cff356668b27e5e5d70111c332&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_653821cdf0193e501e832915982fed8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_653821cdf0193e501e832915982fed8d.addTo(map_2256b5cff356668b27e5e5d70111c332);
#
#
#             var feature_group_4b8c4cefbfecb9a28f1490015e0fc5c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4b8c4cefbfecb9a28f1490015e0fc5c2.addTo(map_2256b5cff356668b27e5e5d70111c332);
#
#
#             var feature_group_sub_group_d8382ac2f9d4fed17c4c7b96c0531ce8 = L.featureGroup.subGroup(
#                 feature_group_4b8c4cefbfecb9a28f1490015e0fc5c2
#             );
#
#
#             var marker_4d5f70bedeac6f073d3582c52af6dfa0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8382ac2f9d4fed17c4c7b96c0531ce8);
#
#
#         var popup_68b0bd3d52314d66030b573fca36e04a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_758b8147764375eb6eed09d5595c45fb = $(`&lt;div id=&quot;html_758b8147764375eb6eed09d5595c45fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_68b0bd3d52314d66030b573fca36e04a.setContent(html_758b8147764375eb6eed09d5595c45fb);
#
#
#
#         marker_4d5f70bedeac6f073d3582c52af6dfa0.bindPopup(popup_68b0bd3d52314d66030b573fca36e04a)
#         ;
#
#
#
#
#             var marker_7f429deaa48b406525d0c4d6bd7332ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8382ac2f9d4fed17c4c7b96c0531ce8);
#
#
#         var popup_431209e1e6ae659b36378ea4e7c2da75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b279265dd8fdd6564f0363cee7abb859 = $(`&lt;div id=&quot;html_b279265dd8fdd6564f0363cee7abb859&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_431209e1e6ae659b36378ea4e7c2da75.setContent(html_b279265dd8fdd6564f0363cee7abb859);
#
#
#
#         marker_7f429deaa48b406525d0c4d6bd7332ff.bindPopup(popup_431209e1e6ae659b36378ea4e7c2da75)
#         ;
#
#
#
#
#             var marker_f61ac3bf8a03c81196a579ce4e7c129d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8382ac2f9d4fed17c4c7b96c0531ce8);
#
#
#         var popup_dd19e03ad7edda579a2738131dd2b11a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a1246d1998a52a89fdc2c3f4075e6bb = $(`&lt;div id=&quot;html_8a1246d1998a52a89fdc2c3f4075e6bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dd19e03ad7edda579a2738131dd2b11a.setContent(html_8a1246d1998a52a89fdc2c3f4075e6bb);
#
#
#
#         marker_f61ac3bf8a03c81196a579ce4e7c129d.bindPopup(popup_dd19e03ad7edda579a2738131dd2b11a)
#         ;
#
#
#
#
#             var marker_64d2fd8d9130a5ef57b2d25d555801ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d8382ac2f9d4fed17c4c7b96c0531ce8);
#
#
#         var popup_4c0c2d71c29dd19ea20168d2ac789c3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_172adcbf086525654fcb8ceead2c85a2 = $(`&lt;div id=&quot;html_172adcbf086525654fcb8ceead2c85a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4c0c2d71c29dd19ea20168d2ac789c3b.setContent(html_172adcbf086525654fcb8ceead2c85a2);
#
#
#
#         mark
