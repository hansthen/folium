# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbe33bc4fe9955e8dff6e7566b26b369 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbe33bc4fe9955e8dff6e7566b26b369&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbe33bc4fe9955e8dff6e7566b26b369 = L.map(
#                 &quot;map_cbe33bc4fe9955e8dff6e7566b26b369&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c648ad61ba2a98061573fbece87fdec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c648ad61ba2a98061573fbece87fdec.addTo(map_cbe33bc4fe9955e8dff6e7566b26b369);
#
#
#             var marker_8c27e94cf4bc0c8086519f9790d44e50 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cbe33bc4fe9955e8dff6e7566b26b369);
#
#
#         var popup_8dc2c6077b30d9944bb591bc31af97ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fd1759ae1afa3bdfee3f3ce5374a58e = $(`&lt;div id=&quot;html_9fd1759ae1afa3bdfee3f3ce5374a58e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8dc2c6077b30d9944bb591bc31af97ae.setContent(html_9fd1759ae1afa3bdfee3f3ce5374a58e);
#
#
#
#         marker_8c27e94cf4bc0c8086519f9790d44e50.bindPopup(popup_8dc2c6077b30d9944bb591bc31af97ae)
#         ;
#
#
#
#
#             var marker_07ee4d3f2f8a490dd1e80bb8c0aea1a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cbe33bc4fe9955e8dff6e7566b26b369);
#
#
#         var popup_516d49adfa04fd6852b95aa2605dc09b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87507689c1de8cd45bbea8a0bfbd7bc6 = $(`&lt;div id=&quot;html_87507689c1de8cd45bbea8a0bfbd7bc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_516d49adfa04fd6852b95aa2605dc09b.setContent(html_87507689c1de8cd45bbea8a0bfbd7bc6);
#
#
#
#         marker_07ee4d3f2f8a490dd1e80bb8c0aea1a1.bindPopup(popup_516d49adfa04fd6852b95aa2605dc09b)
#         ;
#
#
#
#
#             var marker_7eccf8b5db859ced824639bb8cd01a5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cbe33bc4fe9955e8dff6e7566b26b369);
#
#
#         var popup_25dd882d4e698cdff09c8f20e501b433 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_935d5e124937499ae0479562ef3dbbb2 = $(`&lt;div id=&quot;html_935d5e124937499ae0479562ef3dbbb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_25dd882d4e698cdff09c8f20e501b433.setContent(html_935d5e124937499ae0479562ef3dbbb2);
#
#
#
#         marker_7eccf8b5db859ced824639bb8cd01a5a.bindPopup(popup_25dd882d4e698cdff09c8f20e501b433)
#         ;
#
#
#
#
#             var marker_a39cd0126a26f3c00ba4ccef0fa08d09 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cbe33bc4fe9955e8dff6e7566b26b369);
#
#
#         var popup_5055d26258c36ca04610829fcbe1476b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b43f7e665cb22ea3013db247be1aabf0 = $(`&lt;div id=&quot;html_b43f7e665cb22ea3013db247be1aabf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5055d26258c36ca04610829fcbe1476b.setContent(html_b43f7e665cb22ea3013db247be1aabf0);
#
#
#
#         marker_a39cd0126a26f3c00ba4ccef0fa08d09.bindPopup(popup_5055d26258c36ca04610829fcbe1476b)
#         ;
#
#
#
#
#             var marker_535aeb829360fa3529daae2615bcafa9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cbe33bc4fe9955e8dff6e7566b26b369);
#
#
#         var popup_f8ae4e941286d3cd902402c6009d2665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e195b85909124d246b474eb4f4f0c48 = $(`&lt;div id=&quot;html_0e195b85909124d246b474eb4f4f0c48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f8ae4e941286d3cd902402c6009d2665.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eceff090df50481257f67a83cb7a24d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eceff090df50481257f67a83cb7a24d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eceff090df50481257f67a83cb7a24d1 = L.map(
#                 &quot;map_eceff090df50481257f67a83cb7a24d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_038a496da1ffcd7996e16800ae7455d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_038a496da1ffcd7996e16800ae7455d2.addTo(map_eceff090df50481257f67a83cb7a24d1);
#
#
#             var feature_group_9d292c2824c3dbb1ee57694e769758a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_70f3b8be6ec91e3c801e41dd6ec2ad16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9d292c2824c3dbb1ee57694e769758a0);
#
#
#         var popup_709415663016a47aeb06241abdfc310d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ee43c695171ce6a4ab62d3e51ae327c = $(`&lt;div id=&quot;html_9ee43c695171ce6a4ab62d3e51ae327c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_709415663016a47aeb06241abdfc310d.setContent(html_9ee43c695171ce6a4ab62d3e51ae327c);
#
#
#
#         marker_70f3b8be6ec91e3c801e41dd6ec2ad16.bindPopup(popup_709415663016a47aeb06241abdfc310d)
#         ;
#
#
#
#
#             var marker_df1dee32e6c80e2dee273d9d7e3c83a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9d292c2824c3dbb1ee57694e769758a0);
#
#
#         var popup_1ff7b7a22c69500cde5b29bd8d04de9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fff8be025ba652544feb64d1085f13bb = $(`&lt;div id=&quot;html_fff8be025ba652544feb64d1085f13bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1ff7b7a22c69500cde5b29bd8d04de9c.setContent(html_fff8be025ba652544feb64d1085f13bb);
#
#
#
#         marker_df1dee32e6c80e2dee273d9d7e3c83a8.bindPopup(popup_1ff7b7a22c69500cde5b29bd8d04de9c)
#         ;
#
#
#
#
#             var marker_7eb4ca3db9bf588bc6616db8b004778e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9d292c2824c3dbb1ee57694e769758a0);
#
#
#         var popup_1e3ef51e0f7ef903ab491957520ea6a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca388b1d28f3c3ea78cbf479998ce310 = $(`&lt;div id=&quot;html_ca388b1d28f3c3ea78cbf479998ce310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1e3ef51e0f7ef903ab491957520ea6a4.setContent(html_ca388b1d28f3c3ea78cbf479998ce310);
#
#
#
#         marker_7eb4ca3db9bf588bc6616db8b004778e.bindPopup(popup_1e3ef51e0f7ef903ab491957520ea6a4)
#         ;
#
#
#
#
#             var marker_7dba0fedd4ab160b3fbcf1f20186f102 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9d292c2824c3dbb1ee57694e769758a0);
#
#
#         var popup_2a0e318d5d2550941ca78cf958044591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b27aa8f93bd02b129e33cd242b4c07da = $(`&lt;div id=&quot;html_b27aa8f93bd02b129e33cd242b4c07da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2a0e318d5d2550941ca78cf958044591.setContent(html_b27aa8f93bd02b129e33cd242b4c07da);
#
#
#
#         marker_7dba0fedd4ab160b3fbcf1f20186f102.bindPopup(popup_2a0e318d5d2550941ca78cf958044591)
#         ;
#
#
#
#
#             var marker_684a351a42961581d95979f75f6d9db2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9d292c2824c3dbb1ee57694e769758a0);
#
#
#         var popup_0821c4d8162da7bf4c31ac53ad44ceb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef897d0a70698ead1719384c4652600c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef897d0a70698ead1719384c4652600c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef897d0a70698ead1719384c4652600c = L.map(
#                 &quot;map_ef897d0a70698ead1719384c4652600c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e197210c74fa927ab61677bf6a33278 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e197210c74fa927ab61677bf6a33278.addTo(map_ef897d0a70698ead1719384c4652600c);
#
#
#             var feature_group_f3258d7a4bdc356082cfc3ae58f44aab = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f3258d7a4bdc356082cfc3ae58f44aab.addTo(map_ef897d0a70698ead1719384c4652600c);
#
#
#             var feature_group_sub_group_f9ceccb71b262ea44c5773d8dfdcf06f = L.featureGroup.subGroup(
#                 feature_group_f3258d7a4bdc356082cfc3ae58f44aab
#             );
#
#
#             var marker_f61301db26d55521b8965a3ddbaa7dde = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f9ceccb71b262ea44c5773d8dfdcf06f);
#
#
#         var popup_4da8939eec7d7c43625c0ef4dc0a2ac3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7097764f8695f26824ac3cdc292ab033 = $(`&lt;div id=&quot;html_7097764f8695f26824ac3cdc292ab033&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4da8939eec7d7c43625c0ef4dc0a2ac3.setContent(html_7097764f8695f26824ac3cdc292ab033);
#
#
#
#         marker_f61301db26d55521b8965a3ddbaa7dde.bindPopup(popup_4da8939eec7d7c43625c0ef4dc0a2ac3)
#         ;
#
#
#
#
#             var marker_dd4c55ea3bc40a44e31eba37a7d116ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f9ceccb71b262ea44c5773d8dfdcf06f);
#
#
#         var popup_d8c81b8ddf01d6d1aacab7a69a60fe07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a2a0e2f2e58e96919e66d443ef9fbe4 = $(`&lt;div id=&quot;html_1a2a0e2f2e58e96919e66d443ef9fbe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d8c81b8ddf01d6d1aacab7a69a60fe07.setContent(html_1a2a0e2f2e58e96919e66d443ef9fbe4);
#
#
#
#         marker_dd4c55ea3bc40a44e31eba37a7d116ea.bindPopup(popup_d8c81b8ddf01d6d1aacab7a69a60fe07)
#         ;
#
#
#
#
#             var marker_eec27d8c166e563cda46bce7b86d1486 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f9ceccb71b262ea44c5773d8dfdcf06f);
#
#
#         var popup_e9f8c8fb36f11c81d9a549d4441d4045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f723870bff6ce81682a34605f3ae4736 = $(`&lt;div id=&quot;html_f723870bff6ce81682a34605f3ae4736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e9f8c8fb36f11c81d9a549d4441d4045.setContent(html_f723870bff6ce81682a34605f3ae4736);
#
#
#
#         marker_eec27d8c166e563cda46bce7b86d1486.bindPopup(popup_e9f8c8fb36f11c81d9a549d4441d4045)
#         ;
#
#
#
#
#             var marker_bb82532c6ffbeccc780f1772ea7b9486 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f9ceccb71b262ea44c5773d8dfdcf06f);
#
#
#         var popup_2d770151b20e4bfd75d7f843cf9170e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf93c2f5e7c6882f7ffef416c3a76495 = $(`&lt;div id=&quot;html_bf93c2f5e7c6882f7ffef416c3a76495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2d770151b20e4bfd75d7f843cf9170e5.setContent(html_bf93c2f5e7c6882f7ffef416c3a76495);
#
#
#
#         marker_
