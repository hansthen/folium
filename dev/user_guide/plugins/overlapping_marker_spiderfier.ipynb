# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecd057e3513754c1415d0d2da2f66903 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecd057e3513754c1415d0d2da2f66903&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecd057e3513754c1415d0d2da2f66903 = L.map(
#                 &quot;map_ecd057e3513754c1415d0d2da2f66903&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f583c9b3398ae96d249c7ca1611079b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f583c9b3398ae96d249c7ca1611079b.addTo(map_ecd057e3513754c1415d0d2da2f66903);
#
#
#             var marker_2efbf45b78c252ae1e192010335e3d2c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ecd057e3513754c1415d0d2da2f66903);
#
#
#         var popup_f1285c2093ad931eed53aa5303276d72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ae8e12012c0289e51489ceeeaf47418 = $(`&lt;div id=&quot;html_7ae8e12012c0289e51489ceeeaf47418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f1285c2093ad931eed53aa5303276d72.setContent(html_7ae8e12012c0289e51489ceeeaf47418);
#
#
#
#         marker_2efbf45b78c252ae1e192010335e3d2c.bindPopup(popup_f1285c2093ad931eed53aa5303276d72)
#         ;
#
#
#
#
#             var marker_ce12314138ec73407415e8e3c635249f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ecd057e3513754c1415d0d2da2f66903);
#
#
#         var popup_c78dbc2ce0a1369dcd40a1b461b9be1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a30339cec6385fdc0b7413b47238873 = $(`&lt;div id=&quot;html_2a30339cec6385fdc0b7413b47238873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c78dbc2ce0a1369dcd40a1b461b9be1a.setContent(html_2a30339cec6385fdc0b7413b47238873);
#
#
#
#         marker_ce12314138ec73407415e8e3c635249f.bindPopup(popup_c78dbc2ce0a1369dcd40a1b461b9be1a)
#         ;
#
#
#
#
#             var marker_8e82e1c4003f41fea6002e4bbc4695c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ecd057e3513754c1415d0d2da2f66903);
#
#
#         var popup_582251618620029649f0a41e841f30a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f0fefcd26dd59326e94a65a16125b45 = $(`&lt;div id=&quot;html_1f0fefcd26dd59326e94a65a16125b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_582251618620029649f0a41e841f30a4.setContent(html_1f0fefcd26dd59326e94a65a16125b45);
#
#
#
#         marker_8e82e1c4003f41fea6002e4bbc4695c7.bindPopup(popup_582251618620029649f0a41e841f30a4)
#         ;
#
#
#
#
#             var marker_58ae716ee2db2f2c154243f31c84ddde = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ecd057e3513754c1415d0d2da2f66903);
#
#
#         var popup_18912acb3d6b083d1bb24d5e0a79714a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c243f52eb6778478bf898acdc482ae81 = $(`&lt;div id=&quot;html_c243f52eb6778478bf898acdc482ae81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18912acb3d6b083d1bb24d5e0a79714a.setContent(html_c243f52eb6778478bf898acdc482ae81);
#
#
#
#         marker_58ae716ee2db2f2c154243f31c84ddde.bindPopup(popup_18912acb3d6b083d1bb24d5e0a79714a)
#         ;
#
#
#
#
#             var marker_3ebd1fa3a330dff9596605943012ecb6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ecd057e3513754c1415d0d2da2f66903);
#
#
#         var popup_21ecb7dedbe677d7e208b38d4c451aa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_515d92f982b7b1536ae34f332eeaa079 = $(`&lt;div id=&quot;html_515d92f982b7b1536ae34f332eeaa079&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_21ecb7dedbe677d7e208b38d4c451a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0619fe7c354fb93b6a55a6a560bbe4f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0619fe7c354fb93b6a55a6a560bbe4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0619fe7c354fb93b6a55a6a560bbe4f = L.map(
#                 &quot;map_f0619fe7c354fb93b6a55a6a560bbe4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbf4953f25297b61ce74c67f39d36f64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbf4953f25297b61ce74c67f39d36f64.addTo(map_f0619fe7c354fb93b6a55a6a560bbe4f);
#
#
#             var feature_group_19a4a3275814ee86b1e3d97880710d22 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7208fb88f700a1af6b8bf117613d3d76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_19a4a3275814ee86b1e3d97880710d22);
#
#
#         var popup_5e107ac95f58919aac5c0285fb04c46f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8efea226d5155c94001ac4eaef57462 = $(`&lt;div id=&quot;html_d8efea226d5155c94001ac4eaef57462&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5e107ac95f58919aac5c0285fb04c46f.setContent(html_d8efea226d5155c94001ac4eaef57462);
#
#
#
#         marker_7208fb88f700a1af6b8bf117613d3d76.bindPopup(popup_5e107ac95f58919aac5c0285fb04c46f)
#         ;
#
#
#
#
#             var marker_b04f351e57cb0040bee49bbf56f66cd1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_19a4a3275814ee86b1e3d97880710d22);
#
#
#         var popup_b0ad3a23e816ea272d198323a3fb4772 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76060623de8bb0f0010b4153c4e50c83 = $(`&lt;div id=&quot;html_76060623de8bb0f0010b4153c4e50c83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b0ad3a23e816ea272d198323a3fb4772.setContent(html_76060623de8bb0f0010b4153c4e50c83);
#
#
#
#         marker_b04f351e57cb0040bee49bbf56f66cd1.bindPopup(popup_b0ad3a23e816ea272d198323a3fb4772)
#         ;
#
#
#
#
#             var marker_8227e20f34aef7870c3bee4c6d25eb4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_19a4a3275814ee86b1e3d97880710d22);
#
#
#         var popup_14322075e15b524657b865af7e555ee2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7698b573279c9790fb06899be7e25448 = $(`&lt;div id=&quot;html_7698b573279c9790fb06899be7e25448&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_14322075e15b524657b865af7e555ee2.setContent(html_7698b573279c9790fb06899be7e25448);
#
#
#
#         marker_8227e20f34aef7870c3bee4c6d25eb4e.bindPopup(popup_14322075e15b524657b865af7e555ee2)
#         ;
#
#
#
#
#             var marker_f5d88c39e06ade10f0ab783a4a98a97e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_19a4a3275814ee86b1e3d97880710d22);
#
#
#         var popup_a5e9acf897679c9b38d76ffc78f1d506 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93064911697d3b8411b667016b9b608c = $(`&lt;div id=&quot;html_93064911697d3b8411b667016b9b608c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a5e9acf897679c9b38d76ffc78f1d506.setContent(html_93064911697d3b8411b667016b9b608c);
#
#
#
#         marker_f5d88c39e06ade10f0ab783a4a98a97e.bindPopup(popup_a5e9acf897679c9b38d76ffc78f1d506)
#         ;
#
#
#
#
#             var marker_ff7141e0f52a492729a36fb70199840f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_19a4a3275814ee86b1e3d97880710d22);
#
#
#         var popup_e6ae514a12745ecb124d6f21d6282da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d74715ee00cce08c132298f5ea0813e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d74715ee00cce08c132298f5ea0813e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d74715ee00cce08c132298f5ea0813e = L.map(
#                 &quot;map_5d74715ee00cce08c132298f5ea0813e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7029e647d56c35e48562b999d3e4c2ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7029e647d56c35e48562b999d3e4c2ba.addTo(map_5d74715ee00cce08c132298f5ea0813e);
#
#
#             var feature_group_491c2f1fd5a4d264ffe9e34d740894f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_491c2f1fd5a4d264ffe9e34d740894f9.addTo(map_5d74715ee00cce08c132298f5ea0813e);
#
#
#             var feature_group_sub_group_82612ba1a68c398fc3c62e5226257c4c = L.featureGroup.subGroup(
#                 feature_group_491c2f1fd5a4d264ffe9e34d740894f9
#             );
#
#
#             var marker_fc4d7723f70c78e87c965e1d99ec1c08 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_82612ba1a68c398fc3c62e5226257c4c);
#
#
#         var popup_b877511e9395357ca1dde0b314781309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a5eec8abe78f377c51cdae041cad5c0 = $(`&lt;div id=&quot;html_9a5eec8abe78f377c51cdae041cad5c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b877511e9395357ca1dde0b314781309.setContent(html_9a5eec8abe78f377c51cdae041cad5c0);
#
#
#
#         marker_fc4d7723f70c78e87c965e1d99ec1c08.bindPopup(popup_b877511e9395357ca1dde0b314781309)
#         ;
#
#
#
#
#             var marker_4f5523a1de723183f3bcbc2e475215a1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_82612ba1a68c398fc3c62e5226257c4c);
#
#
#         var popup_eea7e214c45f09d59997c87dca070a82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd92e48937334919488d4cf59e200e5f = $(`&lt;div id=&quot;html_fd92e48937334919488d4cf59e200e5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_eea7e214c45f09d59997c87dca070a82.setContent(html_fd92e48937334919488d4cf59e200e5f);
#
#
#
#         marker_4f5523a1de723183f3bcbc2e475215a1.bindPopup(popup_eea7e214c45f09d59997c87dca070a82)
#         ;
#
#
#
#
#             var marker_ab3551588b7cf72e12b0c18b440d47b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_82612ba1a68c398fc3c62e5226257c4c);
#
#
#         var popup_3cf9f6f7daa8b122e4c84a9ee3ec72b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad9c94d10d41aa1a7873f752fd2c6ae4 = $(`&lt;div id=&quot;html_ad9c94d10d41aa1a7873f752fd2c6ae4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3cf9f6f7daa8b122e4c84a9ee3ec72b0.setContent(html_ad9c94d10d41aa1a7873f752fd2c6ae4);
#
#
#
#         marker_ab3551588b7cf72e12b0c18b440d47b4.bindPopup(popup_3cf9f6f7daa8b122e4c84a9ee3ec72b0)
#         ;
#
#
#
#
#             var marker_b8ca7f34d11b3c66f66d11beecc1bbc5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_82612ba1a68c398fc3c62e5226257c4c);
#
#
#         var popup_c4a6f27416e6de7ed5ead3f676cdcfa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5883fa99b5221340c9d967c1b4d3e98 = $(`&lt;div id=&quot;html_d5883fa99b5221340c9d967c1b4d3e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c4a6f27416e6de7ed5ead3f676cdcfa4.setContent(html_d5883fa99b5221340c9d967c1b4d3e98);
#
#
#
#         mark
