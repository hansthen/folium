# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39f6606758114c6707236ccc3b635ae5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39f6606758114c6707236ccc3b635ae5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39f6606758114c6707236ccc3b635ae5 = L.map(
#                 &quot;map_39f6606758114c6707236ccc3b635ae5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a3ed479b88ad40c67e0d1638fb74c8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a3ed479b88ad40c67e0d1638fb74c8c.addTo(map_39f6606758114c6707236ccc3b635ae5);
#
#
#             var marker_cf67e229b251af737b6e29d651b1c5fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_39f6606758114c6707236ccc3b635ae5);
#
#
#         var popup_fc65a6890ce0341a2435ea92390bc93b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f896c63d6213419ac363724ddb084e96 = $(`&lt;div id=&quot;html_f896c63d6213419ac363724ddb084e96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fc65a6890ce0341a2435ea92390bc93b.setContent(html_f896c63d6213419ac363724ddb084e96);
#
#
#
#         marker_cf67e229b251af737b6e29d651b1c5fe.bindPopup(popup_fc65a6890ce0341a2435ea92390bc93b)
#         ;
#
#
#
#
#             var marker_e7096e9fb075cf7623589f4e00cf7cbc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_39f6606758114c6707236ccc3b635ae5);
#
#
#         var popup_2e2ed946aeedfdbfa503eede50e81827 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a617448540aa9ee043760f25c73e044 = $(`&lt;div id=&quot;html_2a617448540aa9ee043760f25c73e044&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2e2ed946aeedfdbfa503eede50e81827.setContent(html_2a617448540aa9ee043760f25c73e044);
#
#
#
#         marker_e7096e9fb075cf7623589f4e00cf7cbc.bindPopup(popup_2e2ed946aeedfdbfa503eede50e81827)
#         ;
#
#
#
#
#             var marker_ce72e92ca5a419cc93a029af76f8fc0c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_39f6606758114c6707236ccc3b635ae5);
#
#
#         var popup_0d489d37ad0b847cd615232aaa3cd4ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f014d77d2af1b73e28cbfb56bb1b1c0a = $(`&lt;div id=&quot;html_f014d77d2af1b73e28cbfb56bb1b1c0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0d489d37ad0b847cd615232aaa3cd4ab.setContent(html_f014d77d2af1b73e28cbfb56bb1b1c0a);
#
#
#
#         marker_ce72e92ca5a419cc93a029af76f8fc0c.bindPopup(popup_0d489d37ad0b847cd615232aaa3cd4ab)
#         ;
#
#
#
#
#             var marker_946a07afbafbf84095bac7fee0cb4d7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_39f6606758114c6707236ccc3b635ae5);
#
#
#         var popup_d3bc410b1dc80c63d67c25828f84677d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10eacc12a949450d56672fe72a74fe03 = $(`&lt;div id=&quot;html_10eacc12a949450d56672fe72a74fe03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d3bc410b1dc80c63d67c25828f84677d.setContent(html_10eacc12a949450d56672fe72a74fe03);
#
#
#
#         marker_946a07afbafbf84095bac7fee0cb4d7c.bindPopup(popup_d3bc410b1dc80c63d67c25828f84677d)
#         ;
#
#
#
#
#             var marker_1dd4d1bc160ce27c560ece636fa4592b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_39f6606758114c6707236ccc3b635ae5);
#
#
#         var popup_aeab034b37b8be4a55292afc2059f24b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aca809fcac3f07316c85cf209b3ee0c1 = $(`&lt;div id=&quot;html_aca809fcac3f07316c85cf209b3ee0c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aeab034b37b8be4a55292afc2059f24b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_372a3bb1bd23814b6fddb657835bcd7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_372a3bb1bd23814b6fddb657835bcd7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_372a3bb1bd23814b6fddb657835bcd7c = L.map(
#                 &quot;map_372a3bb1bd23814b6fddb657835bcd7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ead533ed52fd58e39d4abd7131b8aece = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ead533ed52fd58e39d4abd7131b8aece.addTo(map_372a3bb1bd23814b6fddb657835bcd7c);
#
#
#             var feature_group_2bd85b5353b81616e13e4c84072721d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6fdc8a71dd5eee350bfd06385d7f759d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2bd85b5353b81616e13e4c84072721d0);
#
#
#         var popup_ebe1732607b889ccee6a7aa98ad96d70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e9c9fa085be9d51dc1c3f8edec25fe9 = $(`&lt;div id=&quot;html_4e9c9fa085be9d51dc1c3f8edec25fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ebe1732607b889ccee6a7aa98ad96d70.setContent(html_4e9c9fa085be9d51dc1c3f8edec25fe9);
#
#
#
#         marker_6fdc8a71dd5eee350bfd06385d7f759d.bindPopup(popup_ebe1732607b889ccee6a7aa98ad96d70)
#         ;
#
#
#
#
#             var marker_afbfb85375d9c90128cd7b154f2e2a9f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2bd85b5353b81616e13e4c84072721d0);
#
#
#         var popup_01a39ead5ee0cd5a32a911fc28a8d69a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db941ccef673789476bea10f7d42298e = $(`&lt;div id=&quot;html_db941ccef673789476bea10f7d42298e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_01a39ead5ee0cd5a32a911fc28a8d69a.setContent(html_db941ccef673789476bea10f7d42298e);
#
#
#
#         marker_afbfb85375d9c90128cd7b154f2e2a9f.bindPopup(popup_01a39ead5ee0cd5a32a911fc28a8d69a)
#         ;
#
#
#
#
#             var marker_851d672673c59e5677ae2c11d407b1cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2bd85b5353b81616e13e4c84072721d0);
#
#
#         var popup_490c6510ea7eea36acd7a8d27e0b9993 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a10318dc91cb823b401b3fec031c927 = $(`&lt;div id=&quot;html_6a10318dc91cb823b401b3fec031c927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_490c6510ea7eea36acd7a8d27e0b9993.setContent(html_6a10318dc91cb823b401b3fec031c927);
#
#
#
#         marker_851d672673c59e5677ae2c11d407b1cb.bindPopup(popup_490c6510ea7eea36acd7a8d27e0b9993)
#         ;
#
#
#
#
#             var marker_9ed1015529999c737e9f211b0eb42406 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2bd85b5353b81616e13e4c84072721d0);
#
#
#         var popup_6bb14184e8034497671670202faac4f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9edf88c3d6e8129e560235d8ce9e6be = $(`&lt;div id=&quot;html_f9edf88c3d6e8129e560235d8ce9e6be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6bb14184e8034497671670202faac4f9.setContent(html_f9edf88c3d6e8129e560235d8ce9e6be);
#
#
#
#         marker_9ed1015529999c737e9f211b0eb42406.bindPopup(popup_6bb14184e8034497671670202faac4f9)
#         ;
#
#
#
#
#             var marker_40939d704ee78446ccd1b6b93085f50b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2bd85b5353b81616e13e4c84072721d0);
#
#
#         var popup_f22934951c63463c9ff77fe1c2d11d1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6fc69d956e4f8af0511def3a308ed45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6fc69d956e4f8af0511def3a308ed45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6fc69d956e4f8af0511def3a308ed45 = L.map(
#                 &quot;map_d6fc69d956e4f8af0511def3a308ed45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b53842e11afa2ee91586a299cf28bb02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b53842e11afa2ee91586a299cf28bb02.addTo(map_d6fc69d956e4f8af0511def3a308ed45);
#
#
#             var feature_group_9bb45567952dc5119b007268dcef57e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9bb45567952dc5119b007268dcef57e2.addTo(map_d6fc69d956e4f8af0511def3a308ed45);
#
#
#             var feature_group_sub_group_788f9c657d04fb9522d4dd49d3fe54b9 = L.featureGroup.subGroup(
#                 feature_group_9bb45567952dc5119b007268dcef57e2
#             );
#
#
#             var marker_79bbed4d02aee9c294e471977f13a256 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_788f9c657d04fb9522d4dd49d3fe54b9);
#
#
#         var popup_a9835218c52a5bd5c08a994c06628a57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6581367dc06ee264d216b1d1dc71d893 = $(`&lt;div id=&quot;html_6581367dc06ee264d216b1d1dc71d893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a9835218c52a5bd5c08a994c06628a57.setContent(html_6581367dc06ee264d216b1d1dc71d893);
#
#
#
#         marker_79bbed4d02aee9c294e471977f13a256.bindPopup(popup_a9835218c52a5bd5c08a994c06628a57)
#         ;
#
#
#
#
#             var marker_83b8bfe6f3c5a2e2f864e51aadcda338 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_788f9c657d04fb9522d4dd49d3fe54b9);
#
#
#         var popup_0d39b3c8ec7e0195871a67bd90abf059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f0164c0453bb1a81e96988d761bc0ad = $(`&lt;div id=&quot;html_2f0164c0453bb1a81e96988d761bc0ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0d39b3c8ec7e0195871a67bd90abf059.setContent(html_2f0164c0453bb1a81e96988d761bc0ad);
#
#
#
#         marker_83b8bfe6f3c5a2e2f864e51aadcda338.bindPopup(popup_0d39b3c8ec7e0195871a67bd90abf059)
#         ;
#
#
#
#
#             var marker_638b9b7b14bee271aaa058e8aa9d83f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_788f9c657d04fb9522d4dd49d3fe54b9);
#
#
#         var popup_14b3278f64673dc8cbadb47cc843f65c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07b03dc123f464515b9e0fc92d130e36 = $(`&lt;div id=&quot;html_07b03dc123f464515b9e0fc92d130e36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_14b3278f64673dc8cbadb47cc843f65c.setContent(html_07b03dc123f464515b9e0fc92d130e36);
#
#
#
#         marker_638b9b7b14bee271aaa058e8aa9d83f0.bindPopup(popup_14b3278f64673dc8cbadb47cc843f65c)
#         ;
#
#
#
#
#             var marker_20442cfd3ab27af67929b69183622252 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_788f9c657d04fb9522d4dd49d3fe54b9);
#
#
#         var popup_902cc54cabeafa1c03e48082c980c7c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60feb8c687bc4f74165d916798cd900a = $(`&lt;div id=&quot;html_60feb8c687bc4f74165d916798cd900a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_902cc54cabeafa1c03e48082c980c7c0.setContent(html_60feb8c687bc4f74165d916798cd900a);
#
#
#
#         marker_
