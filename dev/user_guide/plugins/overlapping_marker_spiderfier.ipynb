# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccc1afee627a79fc476d92600a224fa9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccc1afee627a79fc476d92600a224fa9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccc1afee627a79fc476d92600a224fa9 = L.map(
#                 &quot;map_ccc1afee627a79fc476d92600a224fa9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89c602e6cd00138fd3278a1ac62d013e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_89c602e6cd00138fd3278a1ac62d013e.addTo(map_ccc1afee627a79fc476d92600a224fa9);
#
#
#             var marker_9c6fe2e6d15f8a166e2aab8d8781b0ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ccc1afee627a79fc476d92600a224fa9);
#
#
#         var popup_7f4d4660dff7264fa909d1835df06318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b14eba543867b555160d98badc024360 = $(`&lt;div id=&quot;html_b14eba543867b555160d98badc024360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7f4d4660dff7264fa909d1835df06318.setContent(html_b14eba543867b555160d98badc024360);
#
#
#
#         marker_9c6fe2e6d15f8a166e2aab8d8781b0ef.bindPopup(popup_7f4d4660dff7264fa909d1835df06318)
#         ;
#
#
#
#
#             var marker_3bfb943790534cb1adf6f29b692eec32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ccc1afee627a79fc476d92600a224fa9);
#
#
#         var popup_c9dba6260d3a472e26d8157d9ab77b52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4035e6562464d0a3fe8f651806cf8954 = $(`&lt;div id=&quot;html_4035e6562464d0a3fe8f651806cf8954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c9dba6260d3a472e26d8157d9ab77b52.setContent(html_4035e6562464d0a3fe8f651806cf8954);
#
#
#
#         marker_3bfb943790534cb1adf6f29b692eec32.bindPopup(popup_c9dba6260d3a472e26d8157d9ab77b52)
#         ;
#
#
#
#
#             var marker_bf86a201c2b53b31f0a6d620267f7884 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ccc1afee627a79fc476d92600a224fa9);
#
#
#         var popup_2dd3c5f5009fddacec0bc5abd9d6cd54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf4c85bc0ce5be16b6a521cd6c809dfb = $(`&lt;div id=&quot;html_bf4c85bc0ce5be16b6a521cd6c809dfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2dd3c5f5009fddacec0bc5abd9d6cd54.setContent(html_bf4c85bc0ce5be16b6a521cd6c809dfb);
#
#
#
#         marker_bf86a201c2b53b31f0a6d620267f7884.bindPopup(popup_2dd3c5f5009fddacec0bc5abd9d6cd54)
#         ;
#
#
#
#
#             var marker_54092df0e6d769a2a6321cfde06f9792 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ccc1afee627a79fc476d92600a224fa9);
#
#
#         var popup_8c923bce5d85d087dcec33fb2caf4030 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0709205313a8b7443ffa46252bc58261 = $(`&lt;div id=&quot;html_0709205313a8b7443ffa46252bc58261&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8c923bce5d85d087dcec33fb2caf4030.setContent(html_0709205313a8b7443ffa46252bc58261);
#
#
#
#         marker_54092df0e6d769a2a6321cfde06f9792.bindPopup(popup_8c923bce5d85d087dcec33fb2caf4030)
#         ;
#
#
#
#
#             var marker_9b2b4fad7cd23842e607ea0452fc1b3d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ccc1afee627a79fc476d92600a224fa9);
#
#
#         var popup_3665c56e1172e996dbbb41df444ff9b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d88975831008a9e4dbd76bc277bb031d = $(`&lt;div id=&quot;html_d88975831008a9e4dbd76bc277bb031d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3665c56e1172e996dbbb41df444ff9b0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c3c793e0e0c8bc3fbf6d5ba47d5d093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c3c793e0e0c8bc3fbf6d5ba47d5d093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c3c793e0e0c8bc3fbf6d5ba47d5d093 = L.map(
#                 &quot;map_2c3c793e0e0c8bc3fbf6d5ba47d5d093&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1e31b4865d5ac291a89abfde16d0ace = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1e31b4865d5ac291a89abfde16d0ace.addTo(map_2c3c793e0e0c8bc3fbf6d5ba47d5d093);
#
#
#             var feature_group_f2f19fdb12601dc90ba1d0a0ee27f75e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3f43040696d21a8a5d8b336bbc695950 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f2f19fdb12601dc90ba1d0a0ee27f75e);
#
#
#         var popup_8566acd9805eadc09d9cd18f2f6cb145 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ed9ce510808c50957f7be7af545c476 = $(`&lt;div id=&quot;html_4ed9ce510808c50957f7be7af545c476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8566acd9805eadc09d9cd18f2f6cb145.setContent(html_4ed9ce510808c50957f7be7af545c476);
#
#
#
#         marker_3f43040696d21a8a5d8b336bbc695950.bindPopup(popup_8566acd9805eadc09d9cd18f2f6cb145)
#         ;
#
#
#
#
#             var marker_71b2d72d1560d38d41e23bd83903b301 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f2f19fdb12601dc90ba1d0a0ee27f75e);
#
#
#         var popup_8af593b9dff11c4294a1e3833ab67aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c2206933f248d6d0dbc7caf6ecb986b = $(`&lt;div id=&quot;html_7c2206933f248d6d0dbc7caf6ecb986b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8af593b9dff11c4294a1e3833ab67aee.setContent(html_7c2206933f248d6d0dbc7caf6ecb986b);
#
#
#
#         marker_71b2d72d1560d38d41e23bd83903b301.bindPopup(popup_8af593b9dff11c4294a1e3833ab67aee)
#         ;
#
#
#
#
#             var marker_448d792fd25750dffe25a648007ddff4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f2f19fdb12601dc90ba1d0a0ee27f75e);
#
#
#         var popup_8a8aa9ddf42ab718b49ecd7d06c3a6a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22987f72e86c47bf56f0cdff57c3c0b8 = $(`&lt;div id=&quot;html_22987f72e86c47bf56f0cdff57c3c0b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8a8aa9ddf42ab718b49ecd7d06c3a6a5.setContent(html_22987f72e86c47bf56f0cdff57c3c0b8);
#
#
#
#         marker_448d792fd25750dffe25a648007ddff4.bindPopup(popup_8a8aa9ddf42ab718b49ecd7d06c3a6a5)
#         ;
#
#
#
#
#             var marker_c99c968ad1eb4666713952f8d8df7352 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f2f19fdb12601dc90ba1d0a0ee27f75e);
#
#
#         var popup_50da9c085884fab90ed3822fc82d4a23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37cf30f4c63e59b89e67decbfbc8be73 = $(`&lt;div id=&quot;html_37cf30f4c63e59b89e67decbfbc8be73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_50da9c085884fab90ed3822fc82d4a23.setContent(html_37cf30f4c63e59b89e67decbfbc8be73);
#
#
#
#         marker_c99c968ad1eb4666713952f8d8df7352.bindPopup(popup_50da9c085884fab90ed3822fc82d4a23)
#         ;
#
#
#
#
#             var marker_c8bd9f7bbf9972094df5fed08547d607 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f2f19fdb12601dc90ba1d0a0ee27f75e);
#
#
#         var popup_febc8f813dc00b3d307ae536d2b96737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bef49ecba63fb4cc9f1ae39b31fa8ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bef49ecba63fb4cc9f1ae39b31fa8ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bef49ecba63fb4cc9f1ae39b31fa8ea = L.map(
#                 &quot;map_4bef49ecba63fb4cc9f1ae39b31fa8ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e82928540a172d66d5893a1329d35eba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e82928540a172d66d5893a1329d35eba.addTo(map_4bef49ecba63fb4cc9f1ae39b31fa8ea);
#
#
#             var feature_group_af42f5f88e57045724cb95ea8f3b2313 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_af42f5f88e57045724cb95ea8f3b2313.addTo(map_4bef49ecba63fb4cc9f1ae39b31fa8ea);
#
#
#             var feature_group_sub_group_a04d7287dc3927563f9c6f2a68b5fc2b = L.featureGroup.subGroup(
#                 feature_group_af42f5f88e57045724cb95ea8f3b2313
#             );
#
#
#             var marker_36f6f47acde2faf9ce27376f5800473d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a04d7287dc3927563f9c6f2a68b5fc2b);
#
#
#         var popup_bd412d1be8fa93b5b5a6e2b0254afc37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30f8f2c40127fd650f22e33ac36a01bc = $(`&lt;div id=&quot;html_30f8f2c40127fd650f22e33ac36a01bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bd412d1be8fa93b5b5a6e2b0254afc37.setContent(html_30f8f2c40127fd650f22e33ac36a01bc);
#
#
#
#         marker_36f6f47acde2faf9ce27376f5800473d.bindPopup(popup_bd412d1be8fa93b5b5a6e2b0254afc37)
#         ;
#
#
#
#
#             var marker_1e4c5538057b491807f94d98919565bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a04d7287dc3927563f9c6f2a68b5fc2b);
#
#
#         var popup_b536ed9107c4ff77d188775b4750ed84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b03bcc59e2b60891ad619bf4857f2ed = $(`&lt;div id=&quot;html_6b03bcc59e2b60891ad619bf4857f2ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b536ed9107c4ff77d188775b4750ed84.setContent(html_6b03bcc59e2b60891ad619bf4857f2ed);
#
#
#
#         marker_1e4c5538057b491807f94d98919565bc.bindPopup(popup_b536ed9107c4ff77d188775b4750ed84)
#         ;
#
#
#
#
#             var marker_ebe4c383cdd07f8cc72a28fdc5956e19 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a04d7287dc3927563f9c6f2a68b5fc2b);
#
#
#         var popup_fdda8e10bb7f6e764e8edb305a0e6040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_400f7a3cf637af8743dc362d96a2c527 = $(`&lt;div id=&quot;html_400f7a3cf637af8743dc362d96a2c527&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fdda8e10bb7f6e764e8edb305a0e6040.setContent(html_400f7a3cf637af8743dc362d96a2c527);
#
#
#
#         marker_ebe4c383cdd07f8cc72a28fdc5956e19.bindPopup(popup_fdda8e10bb7f6e764e8edb305a0e6040)
#         ;
#
#
#
#
#             var marker_7adf7226a58e8ae26b0b91bdb7ee48b9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a04d7287dc3927563f9c6f2a68b5fc2b);
#
#
#         var popup_d63bf655c446cde25a5cee3a172cab0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3712f49a8c074408221a9c7b21aad1aa = $(`&lt;div id=&quot;html_3712f49a8c074408221a9c7b21aad1aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d63bf655c446cde25a5cee3a172cab0d.setContent(html_3712f49a8c074408221a9c7b21aad1aa);
#
#
#
#         marker_
