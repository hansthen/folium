# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1a51ca21eeacf24036b596675489cda {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1a51ca21eeacf24036b596675489cda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1a51ca21eeacf24036b596675489cda = L.map(
#                 &quot;map_d1a51ca21eeacf24036b596675489cda&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8813ff3f9d6fc01e3969d79b44940b8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8813ff3f9d6fc01e3969d79b44940b8b.addTo(map_d1a51ca21eeacf24036b596675489cda);
#
#
#             var marker_eea4ce4ef52742da4fd9f68d179cf3ed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d1a51ca21eeacf24036b596675489cda);
#
#
#         var popup_0d4960a7bd9b70b9ee4e3653ab4fb705 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49533c006f4f7ccd05e3065b11826912 = $(`&lt;div id=&quot;html_49533c006f4f7ccd05e3065b11826912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0d4960a7bd9b70b9ee4e3653ab4fb705.setContent(html_49533c006f4f7ccd05e3065b11826912);
#
#
#
#         marker_eea4ce4ef52742da4fd9f68d179cf3ed.bindPopup(popup_0d4960a7bd9b70b9ee4e3653ab4fb705)
#         ;
#
#
#
#
#             var marker_4c97d4e36e84b4a773bad5d0436fdd0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d1a51ca21eeacf24036b596675489cda);
#
#
#         var popup_116ef60a214ec3483e8cc4aa3af618ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_980a2f7bffeb14490fe6d8f47eec3b00 = $(`&lt;div id=&quot;html_980a2f7bffeb14490fe6d8f47eec3b00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_116ef60a214ec3483e8cc4aa3af618ac.setContent(html_980a2f7bffeb14490fe6d8f47eec3b00);
#
#
#
#         marker_4c97d4e36e84b4a773bad5d0436fdd0e.bindPopup(popup_116ef60a214ec3483e8cc4aa3af618ac)
#         ;
#
#
#
#
#             var marker_dfe57eed166c36add566117b28e1bd12 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d1a51ca21eeacf24036b596675489cda);
#
#
#         var popup_f1926e43d420b19d441ca37e46c5c6fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e11faca21835fd4b08b3bff07952b9a = $(`&lt;div id=&quot;html_8e11faca21835fd4b08b3bff07952b9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f1926e43d420b19d441ca37e46c5c6fa.setContent(html_8e11faca21835fd4b08b3bff07952b9a);
#
#
#
#         marker_dfe57eed166c36add566117b28e1bd12.bindPopup(popup_f1926e43d420b19d441ca37e46c5c6fa)
#         ;
#
#
#
#
#             var marker_717743305e170d0fe21dbcfd385e9cc7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d1a51ca21eeacf24036b596675489cda);
#
#
#         var popup_4231b4a270d06adb5570d491adf841d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af6bdcb91b7b99a35d2216226e8f7e13 = $(`&lt;div id=&quot;html_af6bdcb91b7b99a35d2216226e8f7e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4231b4a270d06adb5570d491adf841d7.setContent(html_af6bdcb91b7b99a35d2216226e8f7e13);
#
#
#
#         marker_717743305e170d0fe21dbcfd385e9cc7.bindPopup(popup_4231b4a270d06adb5570d491adf841d7)
#         ;
#
#
#
#
#             var marker_2c66f47b2168e4fce3ed114eb987fea3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d1a51ca21eeacf24036b596675489cda);
#
#
#         var popup_2d666d22c8ceb590af9f6739d2faba54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a90bc05384bb0a5f4b0d6479d3738df0 = $(`&lt;div id=&quot;html_a90bc05384bb0a5f4b0d6479d3738df0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2d666d22c8ceb590af9f6739d2faba

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f244a032a5ab89066c57330fb8f7186 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f244a032a5ab89066c57330fb8f7186&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f244a032a5ab89066c57330fb8f7186 = L.map(
#                 &quot;map_0f244a032a5ab89066c57330fb8f7186&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d308e2245533fedee440c928f6fb52bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d308e2245533fedee440c928f6fb52bd.addTo(map_0f244a032a5ab89066c57330fb8f7186);
#
#
#             var feature_group_0b723cb25bd4c6c80e682709db0789ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0ca3cf9fe3735016d59222d306effb78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0b723cb25bd4c6c80e682709db0789ee);
#
#
#         var popup_f3cb14af3d64816aa2da093ff4a7d4be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_981e9c8fd3225c6c8f420bbf746934a9 = $(`&lt;div id=&quot;html_981e9c8fd3225c6c8f420bbf746934a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f3cb14af3d64816aa2da093ff4a7d4be.setContent(html_981e9c8fd3225c6c8f420bbf746934a9);
#
#
#
#         marker_0ca3cf9fe3735016d59222d306effb78.bindPopup(popup_f3cb14af3d64816aa2da093ff4a7d4be)
#         ;
#
#
#
#
#             var marker_ba59f0d203da29883fa5c76ee772413c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0b723cb25bd4c6c80e682709db0789ee);
#
#
#         var popup_f0a28f364cce5d015f1abd2258afe1bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e14ec43becded60b00e14ea744393197 = $(`&lt;div id=&quot;html_e14ec43becded60b00e14ea744393197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f0a28f364cce5d015f1abd2258afe1bb.setContent(html_e14ec43becded60b00e14ea744393197);
#
#
#
#         marker_ba59f0d203da29883fa5c76ee772413c.bindPopup(popup_f0a28f364cce5d015f1abd2258afe1bb)
#         ;
#
#
#
#
#             var marker_dabc95024f7ef767eb5194efed62e341 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0b723cb25bd4c6c80e682709db0789ee);
#
#
#         var popup_de09af6058d5c34c080628bfc8c380bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a639681aa2016845bd6b4b94870062a = $(`&lt;div id=&quot;html_9a639681aa2016845bd6b4b94870062a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_de09af6058d5c34c080628bfc8c380bd.setContent(html_9a639681aa2016845bd6b4b94870062a);
#
#
#
#         marker_dabc95024f7ef767eb5194efed62e341.bindPopup(popup_de09af6058d5c34c080628bfc8c380bd)
#         ;
#
#
#
#
#             var marker_45abf0c1bb11cad37214916bc9ae81bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0b723cb25bd4c6c80e682709db0789ee);
#
#
#         var popup_a0c63c5e048a46e36902d44210c22416 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6482ead0934e82dee87709bb1a5c77a = $(`&lt;div id=&quot;html_a6482ead0934e82dee87709bb1a5c77a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a0c63c5e048a46e36902d44210c22416.setContent(html_a6482ead0934e82dee87709bb1a5c77a);
#
#
#
#         marker_45abf0c1bb11cad37214916bc9ae81bf.bindPopup(popup_a0c63c5e048a46e36902d44210c22416)
#         ;
#
#
#
#
#             var marker_4065fa158ac8cd52a6c64c713f18cbc4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0b723cb25bd4c6c80e682709db0789ee);
#
#
#         var popup_a16b385088df492150c31fe7168b5797 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6322fee6a3ddae153a82fcf57131604 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6322fee6a3ddae153a82fcf57131604&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6322fee6a3ddae153a82fcf57131604 = L.map(
#                 &quot;map_a6322fee6a3ddae153a82fcf57131604&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dee605267fe1ca06b86c85bc4f049f26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dee605267fe1ca06b86c85bc4f049f26.addTo(map_a6322fee6a3ddae153a82fcf57131604);
#
#
#             var feature_group_d53ddbfd2c290280c7f8fbfc42e8dfb7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d53ddbfd2c290280c7f8fbfc42e8dfb7.addTo(map_a6322fee6a3ddae153a82fcf57131604);
#
#
#             var feature_group_sub_group_5a40eac6d7bdc20029979497393ab6c4 = L.featureGroup.subGroup(
#                 feature_group_d53ddbfd2c290280c7f8fbfc42e8dfb7
#             );
#
#
#             var marker_3596f1fd6e8ddfde4034410828eb30c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a40eac6d7bdc20029979497393ab6c4);
#
#
#         var popup_44347759b50782b99b1f7e9025809ab2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c8fb64efc8e9174e89aa4fee437e960 = $(`&lt;div id=&quot;html_7c8fb64efc8e9174e89aa4fee437e960&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_44347759b50782b99b1f7e9025809ab2.setContent(html_7c8fb64efc8e9174e89aa4fee437e960);
#
#
#
#         marker_3596f1fd6e8ddfde4034410828eb30c5.bindPopup(popup_44347759b50782b99b1f7e9025809ab2)
#         ;
#
#
#
#
#             var marker_1bd535927c3dbcf6bce5eb1783ec6313 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a40eac6d7bdc20029979497393ab6c4);
#
#
#         var popup_aaa0c45f8f4502babfee3bcfae0f8a52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19f2e77e2e4edfd7df581e1769639690 = $(`&lt;div id=&quot;html_19f2e77e2e4edfd7df581e1769639690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aaa0c45f8f4502babfee3bcfae0f8a52.setContent(html_19f2e77e2e4edfd7df581e1769639690);
#
#
#
#         marker_1bd535927c3dbcf6bce5eb1783ec6313.bindPopup(popup_aaa0c45f8f4502babfee3bcfae0f8a52)
#         ;
#
#
#
#
#             var marker_1b339a4d0d260cc1b7efce021c391827 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a40eac6d7bdc20029979497393ab6c4);
#
#
#         var popup_b1ea29a390337b0fe2a0326fbddfa0f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c87a75e298accd6a258b6fc75341a3b8 = $(`&lt;div id=&quot;html_c87a75e298accd6a258b6fc75341a3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b1ea29a390337b0fe2a0326fbddfa0f9.setContent(html_c87a75e298accd6a258b6fc75341a3b8);
#
#
#
#         marker_1b339a4d0d260cc1b7efce021c391827.bindPopup(popup_b1ea29a390337b0fe2a0326fbddfa0f9)
#         ;
#
#
#
#
#             var marker_1b98b71211299f3eae017bce191d10d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5a40eac6d7bdc20029979497393ab6c4);
#
#
#         var popup_2d9bd78ec54e64eb59c18b5eca9e6da8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47d74274160ac370fe1bef680f878cca = $(`&lt;div id=&quot;html_47d74274160ac370fe1bef680f878cca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2d9bd78ec54e64eb59c18b5eca9e6da8.setContent(html_47d74274160ac370fe1bef680f878cca);
#
#
#
#         mark
