# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d840c8cfa92c9ef7449fdf7762079d12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d840c8cfa92c9ef7449fdf7762079d12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d840c8cfa92c9ef7449fdf7762079d12 = L.map(
#                 &quot;map_d840c8cfa92c9ef7449fdf7762079d12&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b3f62781218d62aaf32df3092386386 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b3f62781218d62aaf32df3092386386.addTo(map_d840c8cfa92c9ef7449fdf7762079d12);
#
#
#             var marker_4ad0cdd9e05f411e9bca258b9aeb5b4a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d840c8cfa92c9ef7449fdf7762079d12);
#
#
#         var popup_5f140703ec5f2004c4befcde2dbb10c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ba8e8554a3b6a12ebc4430806433974 = $(`&lt;div id=&quot;html_8ba8e8554a3b6a12ebc4430806433974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5f140703ec5f2004c4befcde2dbb10c8.setContent(html_8ba8e8554a3b6a12ebc4430806433974);
#
#
#
#         marker_4ad0cdd9e05f411e9bca258b9aeb5b4a.bindPopup(popup_5f140703ec5f2004c4befcde2dbb10c8)
#         ;
#
#
#
#
#             var marker_de502eb1cb09e88afe347fa9d8f01eab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d840c8cfa92c9ef7449fdf7762079d12);
#
#
#         var popup_c918b5c1fae9108cef1645b4373e40fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6cfd6f21198bc7df2f17d184d8b7341 = $(`&lt;div id=&quot;html_e6cfd6f21198bc7df2f17d184d8b7341&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c918b5c1fae9108cef1645b4373e40fe.setContent(html_e6cfd6f21198bc7df2f17d184d8b7341);
#
#
#
#         marker_de502eb1cb09e88afe347fa9d8f01eab.bindPopup(popup_c918b5c1fae9108cef1645b4373e40fe)
#         ;
#
#
#
#
#             var marker_981e5fdf85cc8479fc13465c014ddb4f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d840c8cfa92c9ef7449fdf7762079d12);
#
#
#         var popup_effe47b2cd8b49366329c4984d908a87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c37059035d62d091945cf4173c7e495 = $(`&lt;div id=&quot;html_7c37059035d62d091945cf4173c7e495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_effe47b2cd8b49366329c4984d908a87.setContent(html_7c37059035d62d091945cf4173c7e495);
#
#
#
#         marker_981e5fdf85cc8479fc13465c014ddb4f.bindPopup(popup_effe47b2cd8b49366329c4984d908a87)
#         ;
#
#
#
#
#             var marker_da2d68ab163177d7cf031893dc72b510 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d840c8cfa92c9ef7449fdf7762079d12);
#
#
#         var popup_4b0605616eab96be4f05c1c12de4893c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea1715b970a0d20f5dfd14405bffebf = $(`&lt;div id=&quot;html_bea1715b970a0d20f5dfd14405bffebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4b0605616eab96be4f05c1c12de4893c.setContent(html_bea1715b970a0d20f5dfd14405bffebf);
#
#
#
#         marker_da2d68ab163177d7cf031893dc72b510.bindPopup(popup_4b0605616eab96be4f05c1c12de4893c)
#         ;
#
#
#
#
#             var marker_1a3dbe0f347aa1bfb7e2136c4d1d9b46 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d840c8cfa92c9ef7449fdf7762079d12);
#
#
#         var popup_c762311995052903185550272a554f32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8d100fe61934c7d459b39ca1493d06a = $(`&lt;div id=&quot;html_c8d100fe61934c7d459b39ca1493d06a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c762311995052903185550272a554f32.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c463dcc5fa6edafc7d48843f02fc6c3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c463dcc5fa6edafc7d48843f02fc6c3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c463dcc5fa6edafc7d48843f02fc6c3b = L.map(
#                 &quot;map_c463dcc5fa6edafc7d48843f02fc6c3b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_100dc7b7daee986d9fb02df0d589b310 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_100dc7b7daee986d9fb02df0d589b310.addTo(map_c463dcc5fa6edafc7d48843f02fc6c3b);
#
#
#             var feature_group_87a6658b65f0df487041c06c6d2a025e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_38765a809d9a1a202eca771a0ee955f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_87a6658b65f0df487041c06c6d2a025e);
#
#
#         var popup_f09bc36614d70655048329e512884d98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece2659f9a5a568fc5a975e1d0ca4074 = $(`&lt;div id=&quot;html_ece2659f9a5a568fc5a975e1d0ca4074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f09bc36614d70655048329e512884d98.setContent(html_ece2659f9a5a568fc5a975e1d0ca4074);
#
#
#
#         marker_38765a809d9a1a202eca771a0ee955f8.bindPopup(popup_f09bc36614d70655048329e512884d98)
#         ;
#
#
#
#
#             var marker_130c6e2c1a688fb2a5b906df642307d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_87a6658b65f0df487041c06c6d2a025e);
#
#
#         var popup_bda424f4064b5e2e57f70ba488b1082f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22db187efecd63ea60b9202b3364ca62 = $(`&lt;div id=&quot;html_22db187efecd63ea60b9202b3364ca62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bda424f4064b5e2e57f70ba488b1082f.setContent(html_22db187efecd63ea60b9202b3364ca62);
#
#
#
#         marker_130c6e2c1a688fb2a5b906df642307d1.bindPopup(popup_bda424f4064b5e2e57f70ba488b1082f)
#         ;
#
#
#
#
#             var marker_20b97e55ee611375d584a5c31963a7f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_87a6658b65f0df487041c06c6d2a025e);
#
#
#         var popup_f96e2216dff95824ef4405f15ad197f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0825ee9891620ea02486ca8e94d3f3c = $(`&lt;div id=&quot;html_e0825ee9891620ea02486ca8e94d3f3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f96e2216dff95824ef4405f15ad197f8.setContent(html_e0825ee9891620ea02486ca8e94d3f3c);
#
#
#
#         marker_20b97e55ee611375d584a5c31963a7f3.bindPopup(popup_f96e2216dff95824ef4405f15ad197f8)
#         ;
#
#
#
#
#             var marker_89a6b1883000dbb886e1bd89d339fb53 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_87a6658b65f0df487041c06c6d2a025e);
#
#
#         var popup_28516cdb8c97af58b3d7d357cc3d4a3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60f3cfd4ded6d68b921e80f7815299f7 = $(`&lt;div id=&quot;html_60f3cfd4ded6d68b921e80f7815299f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_28516cdb8c97af58b3d7d357cc3d4a3a.setContent(html_60f3cfd4ded6d68b921e80f7815299f7);
#
#
#
#         marker_89a6b1883000dbb886e1bd89d339fb53.bindPopup(popup_28516cdb8c97af58b3d7d357cc3d4a3a)
#         ;
#
#
#
#
#             var marker_9ea5bd9d6ee8e46824b9a2c9190e361a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_87a6658b65f0df487041c06c6d2a025e);
#
#
#         var popup_195a4e7414dfc348406fdfc55167f515 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d23af886217be0f02cb7797e1310ed5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d23af886217be0f02cb7797e1310ed5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d23af886217be0f02cb7797e1310ed5d = L.map(
#                 &quot;map_d23af886217be0f02cb7797e1310ed5d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df567fdbb5e090602d9d1414677c5dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9df567fdbb5e090602d9d1414677c5dc.addTo(map_d23af886217be0f02cb7797e1310ed5d);
#
#
#             var feature_group_2e4cd619ade1eb83e2e3341ccb10a9f8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2e4cd619ade1eb83e2e3341ccb10a9f8.addTo(map_d23af886217be0f02cb7797e1310ed5d);
#
#
#             var feature_group_sub_group_e511b32688a31105b1c94011ece13fcd = L.featureGroup.subGroup(
#                 feature_group_2e4cd619ade1eb83e2e3341ccb10a9f8
#             );
#
#
#             var marker_5179da01910ae91039ce642d6a717c55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e511b32688a31105b1c94011ece13fcd);
#
#
#         var popup_6c840dbdb22d68f980e6c08659f55bb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf1c466d3e746fa19976ee387f93bf42 = $(`&lt;div id=&quot;html_bf1c466d3e746fa19976ee387f93bf42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6c840dbdb22d68f980e6c08659f55bb1.setContent(html_bf1c466d3e746fa19976ee387f93bf42);
#
#
#
#         marker_5179da01910ae91039ce642d6a717c55.bindPopup(popup_6c840dbdb22d68f980e6c08659f55bb1)
#         ;
#
#
#
#
#             var marker_c9d0b3dc0fcdbe6e24f3a09b02345e15 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e511b32688a31105b1c94011ece13fcd);
#
#
#         var popup_0c4d20e951dfe45019c0561a8fed029d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_282be9d89e9f22bad4515ef87270679b = $(`&lt;div id=&quot;html_282be9d89e9f22bad4515ef87270679b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0c4d20e951dfe45019c0561a8fed029d.setContent(html_282be9d89e9f22bad4515ef87270679b);
#
#
#
#         marker_c9d0b3dc0fcdbe6e24f3a09b02345e15.bindPopup(popup_0c4d20e951dfe45019c0561a8fed029d)
#         ;
#
#
#
#
#             var marker_17458ed5d38bce0f8c0748ddec91cea9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e511b32688a31105b1c94011ece13fcd);
#
#
#         var popup_77cc8f119a09766a23bbbd281ad358c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e685c2b90a85038250b13cba9cbb5e3 = $(`&lt;div id=&quot;html_9e685c2b90a85038250b13cba9cbb5e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_77cc8f119a09766a23bbbd281ad358c6.setContent(html_9e685c2b90a85038250b13cba9cbb5e3);
#
#
#
#         marker_17458ed5d38bce0f8c0748ddec91cea9.bindPopup(popup_77cc8f119a09766a23bbbd281ad358c6)
#         ;
#
#
#
#
#             var marker_33bb379b1afa9349df6ab5c0d642f5e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e511b32688a31105b1c94011ece13fcd);
#
#
#         var popup_5fb561fab481aa689f1b43f0f3ba17ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_795dbda6f20d9149849d458d465b54ec = $(`&lt;div id=&quot;html_795dbda6f20d9149849d458d465b54ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5fb561fab481aa689f1b43f0f3ba17ac.setContent(html_795dbda6f20d9149849d458d465b54ec);
#
#
#
#         marker_
