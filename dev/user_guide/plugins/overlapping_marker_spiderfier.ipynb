# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0108084f8b40c636bdc86c9ce37c59c7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0108084f8b40c636bdc86c9ce37c59c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0108084f8b40c636bdc86c9ce37c59c7 = L.map(
#                 &quot;map_0108084f8b40c636bdc86c9ce37c59c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3bfa205d875719c8568d3618f5cb99a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3bfa205d875719c8568d3618f5cb99a.addTo(map_0108084f8b40c636bdc86c9ce37c59c7);
#
#
#             var marker_c1f9716f038b9580529537ecae247f4a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0108084f8b40c636bdc86c9ce37c59c7);
#
#
#         var popup_8b20405df3a82495f60abe9a54c00c79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5c3474232e0fc62417dfc156d10c185 = $(`&lt;div id=&quot;html_a5c3474232e0fc62417dfc156d10c185&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8b20405df3a82495f60abe9a54c00c79.setContent(html_a5c3474232e0fc62417dfc156d10c185);
#
#
#
#         marker_c1f9716f038b9580529537ecae247f4a.bindPopup(popup_8b20405df3a82495f60abe9a54c00c79)
#         ;
#
#
#
#
#             var marker_dcdbdfdf7a97db565ea36ee06d1ac429 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0108084f8b40c636bdc86c9ce37c59c7);
#
#
#         var popup_5a0bd0c7f55bf2205c40d9fb41ec6a7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ea65a115b4fed7e0db26203d3024b04 = $(`&lt;div id=&quot;html_7ea65a115b4fed7e0db26203d3024b04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5a0bd0c7f55bf2205c40d9fb41ec6a7b.setContent(html_7ea65a115b4fed7e0db26203d3024b04);
#
#
#
#         marker_dcdbdfdf7a97db565ea36ee06d1ac429.bindPopup(popup_5a0bd0c7f55bf2205c40d9fb41ec6a7b)
#         ;
#
#
#
#
#             var marker_b1332ec051f7429d257659d403cc9e9b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0108084f8b40c636bdc86c9ce37c59c7);
#
#
#         var popup_3147ec178152c446a9e7362ae553743e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2f32a68b7fe514fb6f6e6edd9b18234 = $(`&lt;div id=&quot;html_d2f32a68b7fe514fb6f6e6edd9b18234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3147ec178152c446a9e7362ae553743e.setContent(html_d2f32a68b7fe514fb6f6e6edd9b18234);
#
#
#
#         marker_b1332ec051f7429d257659d403cc9e9b.bindPopup(popup_3147ec178152c446a9e7362ae553743e)
#         ;
#
#
#
#
#             var marker_2641c3759059bd10fb87ba365e0a3ad1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0108084f8b40c636bdc86c9ce37c59c7);
#
#
#         var popup_2131bd1a8d55c260766c92071fa6a2b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d41e9418ba1edf7f3e41b388c50e70d9 = $(`&lt;div id=&quot;html_d41e9418ba1edf7f3e41b388c50e70d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2131bd1a8d55c260766c92071fa6a2b4.setContent(html_d41e9418ba1edf7f3e41b388c50e70d9);
#
#
#
#         marker_2641c3759059bd10fb87ba365e0a3ad1.bindPopup(popup_2131bd1a8d55c260766c92071fa6a2b4)
#         ;
#
#
#
#
#             var marker_dcc47153218635e6f9583a607c7db03d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0108084f8b40c636bdc86c9ce37c59c7);
#
#
#         var popup_6d05e9b8992c4a309c9efde519772ebb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c8761a468a62edf3cfd62e4018cf6ef = $(`&lt;div id=&quot;html_4c8761a468a62edf3cfd62e4018cf6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6d05e9b8992c4a309c9efde519772e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f89a85cb4a5679aa9434da3ac2384f2e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f89a85cb4a5679aa9434da3ac2384f2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f89a85cb4a5679aa9434da3ac2384f2e = L.map(
#                 &quot;map_f89a85cb4a5679aa9434da3ac2384f2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f00e78c691355c2151b38c5846c15f56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f00e78c691355c2151b38c5846c15f56.addTo(map_f89a85cb4a5679aa9434da3ac2384f2e);
#
#
#             var feature_group_ab0c44e44d98148696a21cd74fa81d67 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d0278315c1cd2254d0b22150fe2fa703 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ab0c44e44d98148696a21cd74fa81d67);
#
#
#         var popup_4d39560faf2c5f8d6efb337d23742704 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b628e8f37cf1e32a92ef1bcd690a5677 = $(`&lt;div id=&quot;html_b628e8f37cf1e32a92ef1bcd690a5677&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4d39560faf2c5f8d6efb337d23742704.setContent(html_b628e8f37cf1e32a92ef1bcd690a5677);
#
#
#
#         marker_d0278315c1cd2254d0b22150fe2fa703.bindPopup(popup_4d39560faf2c5f8d6efb337d23742704)
#         ;
#
#
#
#
#             var marker_e7d5861bfe1e0bc651038685d2c0b3c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ab0c44e44d98148696a21cd74fa81d67);
#
#
#         var popup_65981ffdd4573f40fc1847e4513ca36c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac61e4aed6569378eb2dcc79b50608f2 = $(`&lt;div id=&quot;html_ac61e4aed6569378eb2dcc79b50608f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_65981ffdd4573f40fc1847e4513ca36c.setContent(html_ac61e4aed6569378eb2dcc79b50608f2);
#
#
#
#         marker_e7d5861bfe1e0bc651038685d2c0b3c8.bindPopup(popup_65981ffdd4573f40fc1847e4513ca36c)
#         ;
#
#
#
#
#             var marker_40ce8151a1612cc1daf80fe773ed0ad4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ab0c44e44d98148696a21cd74fa81d67);
#
#
#         var popup_ee4423b8734c1e30b7118f268e59798d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d4f26d2aa9c1b804d940e968aa2e5b = $(`&lt;div id=&quot;html_89d4f26d2aa9c1b804d940e968aa2e5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ee4423b8734c1e30b7118f268e59798d.setContent(html_89d4f26d2aa9c1b804d940e968aa2e5b);
#
#
#
#         marker_40ce8151a1612cc1daf80fe773ed0ad4.bindPopup(popup_ee4423b8734c1e30b7118f268e59798d)
#         ;
#
#
#
#
#             var marker_61c83e3d663c70b6f02aafadeb98c369 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ab0c44e44d98148696a21cd74fa81d67);
#
#
#         var popup_2e8b68d00c331d7b8239e37fa1914c7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0b1f96916baf28a944f8b8130e13d59 = $(`&lt;div id=&quot;html_a0b1f96916baf28a944f8b8130e13d59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2e8b68d00c331d7b8239e37fa1914c7c.setContent(html_a0b1f96916baf28a944f8b8130e13d59);
#
#
#
#         marker_61c83e3d663c70b6f02aafadeb98c369.bindPopup(popup_2e8b68d00c331d7b8239e37fa1914c7c)
#         ;
#
#
#
#
#             var marker_0f38fc7b53a20d0f357cdee8a1cd3728 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ab0c44e44d98148696a21cd74fa81d67);
#
#
#         var popup_54438f210ae5d4809cb2f4d10d2c2f72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce36f37c76be27daa4d6f7c55fde57b5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce36f37c76be27daa4d6f7c55fde57b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce36f37c76be27daa4d6f7c55fde57b5 = L.map(
#                 &quot;map_ce36f37c76be27daa4d6f7c55fde57b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6481b95dcf09d3df6e434e42631d65bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6481b95dcf09d3df6e434e42631d65bc.addTo(map_ce36f37c76be27daa4d6f7c55fde57b5);
#
#
#             var feature_group_1503d83e1198b2a0f5d113d56b6cd3b8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1503d83e1198b2a0f5d113d56b6cd3b8.addTo(map_ce36f37c76be27daa4d6f7c55fde57b5);
#
#
#             var feature_group_sub_group_10e5979883e15dd96267a729736f5344 = L.featureGroup.subGroup(
#                 feature_group_1503d83e1198b2a0f5d113d56b6cd3b8
#             );
#
#
#             var marker_1edccadf4caeaf92626b2276094d92b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e5979883e15dd96267a729736f5344);
#
#
#         var popup_f5477abfb8c42c64373e3655b4d78975 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_750b5fb377f2c7105f1ace58a29895c9 = $(`&lt;div id=&quot;html_750b5fb377f2c7105f1ace58a29895c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f5477abfb8c42c64373e3655b4d78975.setContent(html_750b5fb377f2c7105f1ace58a29895c9);
#
#
#
#         marker_1edccadf4caeaf92626b2276094d92b3.bindPopup(popup_f5477abfb8c42c64373e3655b4d78975)
#         ;
#
#
#
#
#             var marker_819aea3fbbdf124f06b5528d133319c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e5979883e15dd96267a729736f5344);
#
#
#         var popup_324bd73e4d94ebdfee9acbc6b2b9688d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c670f2545e4fe35bce784118ccda9b7d = $(`&lt;div id=&quot;html_c670f2545e4fe35bce784118ccda9b7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_324bd73e4d94ebdfee9acbc6b2b9688d.setContent(html_c670f2545e4fe35bce784118ccda9b7d);
#
#
#
#         marker_819aea3fbbdf124f06b5528d133319c5.bindPopup(popup_324bd73e4d94ebdfee9acbc6b2b9688d)
#         ;
#
#
#
#
#             var marker_e414522295276018134801332dfd264e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e5979883e15dd96267a729736f5344);
#
#
#         var popup_8a8cbc11962a87ee271669a37d4a4512 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d788c0b6978ed919a1042913dbab8d1b = $(`&lt;div id=&quot;html_d788c0b6978ed919a1042913dbab8d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8a8cbc11962a87ee271669a37d4a4512.setContent(html_d788c0b6978ed919a1042913dbab8d1b);
#
#
#
#         marker_e414522295276018134801332dfd264e.bindPopup(popup_8a8cbc11962a87ee271669a37d4a4512)
#         ;
#
#
#
#
#             var marker_eea3a7fdd6ad9cc162c170e024f2e3c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e5979883e15dd96267a729736f5344);
#
#
#         var popup_8b45043467bcaed446f27548bbef160e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25728c96b1868acb8596f6c1f839b3ee = $(`&lt;div id=&quot;html_25728c96b1868acb8596f6c1f839b3ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8b45043467bcaed446f27548bbef160e.setContent(html_25728c96b1868acb8596f6c1f839b3ee);
#
#
#
#         mark
