# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81bc97618ce85c6428cc130a925de220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81bc97618ce85c6428cc130a925de220&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81bc97618ce85c6428cc130a925de220 = L.map(
#                 &quot;map_81bc97618ce85c6428cc130a925de220&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15b4acfaf4d6ed24b956de2443e9107b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15b4acfaf4d6ed24b956de2443e9107b.addTo(map_81bc97618ce85c6428cc130a925de220);
#
#
#             var marker_e2eda8a95ab630ac0667f7652eea3bb5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_81bc97618ce85c6428cc130a925de220);
#
#
#         var popup_f611e737a6a1f8f6cb058f486e692782 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d96909f711d93d819212339dfcc74a7a = $(`&lt;div id=&quot;html_d96909f711d93d819212339dfcc74a7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f611e737a6a1f8f6cb058f486e692782.setContent(html_d96909f711d93d819212339dfcc74a7a);
#
#
#
#         marker_e2eda8a95ab630ac0667f7652eea3bb5.bindPopup(popup_f611e737a6a1f8f6cb058f486e692782)
#         ;
#
#
#
#
#             var marker_4afb1ba8edb89e3292620f17f21c340b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_81bc97618ce85c6428cc130a925de220);
#
#
#         var popup_3807c8e2d72f1e10ed6ebb0b7a55cd2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cacdfc843c24327243daec927fd7936f = $(`&lt;div id=&quot;html_cacdfc843c24327243daec927fd7936f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3807c8e2d72f1e10ed6ebb0b7a55cd2d.setContent(html_cacdfc843c24327243daec927fd7936f);
#
#
#
#         marker_4afb1ba8edb89e3292620f17f21c340b.bindPopup(popup_3807c8e2d72f1e10ed6ebb0b7a55cd2d)
#         ;
#
#
#
#
#             var marker_5ed712f2efd36e74139ec182e6932d96 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_81bc97618ce85c6428cc130a925de220);
#
#
#         var popup_dc0dcb29231eb7b9b459f9964f1963b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a329995f108bab9d8c698a36b8257192 = $(`&lt;div id=&quot;html_a329995f108bab9d8c698a36b8257192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dc0dcb29231eb7b9b459f9964f1963b8.setContent(html_a329995f108bab9d8c698a36b8257192);
#
#
#
#         marker_5ed712f2efd36e74139ec182e6932d96.bindPopup(popup_dc0dcb29231eb7b9b459f9964f1963b8)
#         ;
#
#
#
#
#             var marker_8771b4ae0f8db131f02ea8498af32980 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_81bc97618ce85c6428cc130a925de220);
#
#
#         var popup_07687f16fae0a6b6a4f6594e74907207 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d2f424d30a42effec6184cbfbe78507 = $(`&lt;div id=&quot;html_0d2f424d30a42effec6184cbfbe78507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_07687f16fae0a6b6a4f6594e74907207.setContent(html_0d2f424d30a42effec6184cbfbe78507);
#
#
#
#         marker_8771b4ae0f8db131f02ea8498af32980.bindPopup(popup_07687f16fae0a6b6a4f6594e74907207)
#         ;
#
#
#
#
#             var marker_37cdd31bb59817954f4d308fbb9028a1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_81bc97618ce85c6428cc130a925de220);
#
#
#         var popup_4323b534f2be166467a9c85eb23ef147 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c52aa4baf0ed5d3c8491854180560ecf = $(`&lt;div id=&quot;html_c52aa4baf0ed5d3c8491854180560ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4323b534f2be166467a9c85eb23ef147.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_483796fd57698ff8e776f2b4fa04be99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_483796fd57698ff8e776f2b4fa04be99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_483796fd57698ff8e776f2b4fa04be99 = L.map(
#                 &quot;map_483796fd57698ff8e776f2b4fa04be99&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_addecf9c2f948ed00343b3d5c30dac34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_addecf9c2f948ed00343b3d5c30dac34.addTo(map_483796fd57698ff8e776f2b4fa04be99);
#
#
#             var feature_group_2c5ce70548697bfbc321f2f2209019c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c3b3f7540dc3c48b95524f7eb1b3160e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2c5ce70548697bfbc321f2f2209019c7);
#
#
#         var popup_7caff9b647ecc3ec67ddcb948f363467 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2d340e9bc5905c8e386959257ba2f93 = $(`&lt;div id=&quot;html_d2d340e9bc5905c8e386959257ba2f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7caff9b647ecc3ec67ddcb948f363467.setContent(html_d2d340e9bc5905c8e386959257ba2f93);
#
#
#
#         marker_c3b3f7540dc3c48b95524f7eb1b3160e.bindPopup(popup_7caff9b647ecc3ec67ddcb948f363467)
#         ;
#
#
#
#
#             var marker_3d34fbb5f3cab9a1a4b809693c88a25b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2c5ce70548697bfbc321f2f2209019c7);
#
#
#         var popup_7cfbf2bc45a1ccd6715d213f78c49688 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5fc3a50045e493a078db7f4e4de9eec = $(`&lt;div id=&quot;html_c5fc3a50045e493a078db7f4e4de9eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7cfbf2bc45a1ccd6715d213f78c49688.setContent(html_c5fc3a50045e493a078db7f4e4de9eec);
#
#
#
#         marker_3d34fbb5f3cab9a1a4b809693c88a25b.bindPopup(popup_7cfbf2bc45a1ccd6715d213f78c49688)
#         ;
#
#
#
#
#             var marker_c97ab5c6b5cb44ed5e8f0b14369ea04c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2c5ce70548697bfbc321f2f2209019c7);
#
#
#         var popup_22fdf00125b80ae04a671206c34e1c54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b74ce81523cd8e5387f51b3f07877ca = $(`&lt;div id=&quot;html_6b74ce81523cd8e5387f51b3f07877ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_22fdf00125b80ae04a671206c34e1c54.setContent(html_6b74ce81523cd8e5387f51b3f07877ca);
#
#
#
#         marker_c97ab5c6b5cb44ed5e8f0b14369ea04c.bindPopup(popup_22fdf00125b80ae04a671206c34e1c54)
#         ;
#
#
#
#
#             var marker_4f4c32fa6a52775f8a5997d8ff843557 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2c5ce70548697bfbc321f2f2209019c7);
#
#
#         var popup_5993932b101aeb71378c6de6ecd4336e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ab3da1040e0d62032acc352db486175 = $(`&lt;div id=&quot;html_7ab3da1040e0d62032acc352db486175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5993932b101aeb71378c6de6ecd4336e.setContent(html_7ab3da1040e0d62032acc352db486175);
#
#
#
#         marker_4f4c32fa6a52775f8a5997d8ff843557.bindPopup(popup_5993932b101aeb71378c6de6ecd4336e)
#         ;
#
#
#
#
#             var marker_476ce272bd95c5170a6245bc81692c32 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2c5ce70548697bfbc321f2f2209019c7);
#
#
#         var popup_03ade5f9d0a98c4cada4d07d9d5b8248 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70da64f19951b0c022a0c3b4be0d9029 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70da64f19951b0c022a0c3b4be0d9029&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70da64f19951b0c022a0c3b4be0d9029 = L.map(
#                 &quot;map_70da64f19951b0c022a0c3b4be0d9029&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23edfea2ddc735055678a1265c719a5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23edfea2ddc735055678a1265c719a5b.addTo(map_70da64f19951b0c022a0c3b4be0d9029);
#
#
#             var feature_group_e9b9f48bb52db4d2d55f1e40f3f5679f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e9b9f48bb52db4d2d55f1e40f3f5679f.addTo(map_70da64f19951b0c022a0c3b4be0d9029);
#
#
#             var feature_group_sub_group_79481014ecfb0bb066d6dfa8ec1d768a = L.featureGroup.subGroup(
#                 feature_group_e9b9f48bb52db4d2d55f1e40f3f5679f
#             );
#
#
#             var marker_4a7c8b574ef397504858262d5629292d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_79481014ecfb0bb066d6dfa8ec1d768a);
#
#
#         var popup_ede44554ac53a7824d6e1b1bee81c696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4779b54f5de968d79e55a9baa5ce2955 = $(`&lt;div id=&quot;html_4779b54f5de968d79e55a9baa5ce2955&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ede44554ac53a7824d6e1b1bee81c696.setContent(html_4779b54f5de968d79e55a9baa5ce2955);
#
#
#
#         marker_4a7c8b574ef397504858262d5629292d.bindPopup(popup_ede44554ac53a7824d6e1b1bee81c696)
#         ;
#
#
#
#
#             var marker_dfbe008e6349957d888c407b3c8f4a5f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_79481014ecfb0bb066d6dfa8ec1d768a);
#
#
#         var popup_553950c48356f56cb19af59da03a5c23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a83cad2363d1d492306a5214a1e96d63 = $(`&lt;div id=&quot;html_a83cad2363d1d492306a5214a1e96d63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_553950c48356f56cb19af59da03a5c23.setContent(html_a83cad2363d1d492306a5214a1e96d63);
#
#
#
#         marker_dfbe008e6349957d888c407b3c8f4a5f.bindPopup(popup_553950c48356f56cb19af59da03a5c23)
#         ;
#
#
#
#
#             var marker_ca2b2bbc3b97860f110e8644bd043e7d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_79481014ecfb0bb066d6dfa8ec1d768a);
#
#
#         var popup_adb93d06495e660ebf69043193af478c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90264af688f470e015ac4672e8a19dc5 = $(`&lt;div id=&quot;html_90264af688f470e015ac4672e8a19dc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_adb93d06495e660ebf69043193af478c.setContent(html_90264af688f470e015ac4672e8a19dc5);
#
#
#
#         marker_ca2b2bbc3b97860f110e8644bd043e7d.bindPopup(popup_adb93d06495e660ebf69043193af478c)
#         ;
#
#
#
#
#             var marker_ea2d8d6a84e5c6b137991e6b0acf0c54 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_79481014ecfb0bb066d6dfa8ec1d768a);
#
#
#         var popup_189afd64d5c1463b0282db85e1ed3c02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1dd65dca6d3ebf4534c19879e16a9c5 = $(`&lt;div id=&quot;html_e1dd65dca6d3ebf4534c19879e16a9c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_189afd64d5c1463b0282db85e1ed3c02.setContent(html_e1dd65dca6d3ebf4534c19879e16a9c5);
#
#
#
#         marker_
