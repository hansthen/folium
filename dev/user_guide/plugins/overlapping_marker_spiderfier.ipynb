# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_56288f0494574f7f896a55c34e362ded {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_56288f0494574f7f896a55c34e362ded&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_56288f0494574f7f896a55c34e362ded = L.map(
#                 &quot;map_56288f0494574f7f896a55c34e362ded&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd68239283be7357087cc6af0988e3c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd68239283be7357087cc6af0988e3c1.addTo(map_56288f0494574f7f896a55c34e362ded);
#
#
#             var marker_85358c3066c1353b79e578bfd9c909ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_56288f0494574f7f896a55c34e362ded);
#
#
#         var popup_3c6b4f374c7e57efd3679ed5972af509 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8bef934a89e7d660a2aa179872efebf = $(`&lt;div id=&quot;html_b8bef934a89e7d660a2aa179872efebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c6b4f374c7e57efd3679ed5972af509.setContent(html_b8bef934a89e7d660a2aa179872efebf);
#
#
#
#         marker_85358c3066c1353b79e578bfd9c909ab.bindPopup(popup_3c6b4f374c7e57efd3679ed5972af509)
#         ;
#
#
#
#
#             var marker_a612f509ae2e0bf65e0c8cfd713718cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_56288f0494574f7f896a55c34e362ded);
#
#
#         var popup_929834437d7ee4b05aa032e1bd0f4306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15ed39d4761233766f1d5109b46626a9 = $(`&lt;div id=&quot;html_15ed39d4761233766f1d5109b46626a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_929834437d7ee4b05aa032e1bd0f4306.setContent(html_15ed39d4761233766f1d5109b46626a9);
#
#
#
#         marker_a612f509ae2e0bf65e0c8cfd713718cc.bindPopup(popup_929834437d7ee4b05aa032e1bd0f4306)
#         ;
#
#
#
#
#             var marker_319a29c343c8a4f5a7648517b310bf44 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_56288f0494574f7f896a55c34e362ded);
#
#
#         var popup_efc196ad931033fc366c3a422cd0b28f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f5ef2e96aa1889d725087a046f78554 = $(`&lt;div id=&quot;html_4f5ef2e96aa1889d725087a046f78554&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_efc196ad931033fc366c3a422cd0b28f.setContent(html_4f5ef2e96aa1889d725087a046f78554);
#
#
#
#         marker_319a29c343c8a4f5a7648517b310bf44.bindPopup(popup_efc196ad931033fc366c3a422cd0b28f)
#         ;
#
#
#
#
#             var marker_ddb8b044ea61b4088090900848695cd1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_56288f0494574f7f896a55c34e362ded);
#
#
#         var popup_2f596b62d4a0ee4b871821c526e857a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8197aee830718048fa612ded515ad4c0 = $(`&lt;div id=&quot;html_8197aee830718048fa612ded515ad4c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2f596b62d4a0ee4b871821c526e857a0.setContent(html_8197aee830718048fa612ded515ad4c0);
#
#
#
#         marker_ddb8b044ea61b4088090900848695cd1.bindPopup(popup_2f596b62d4a0ee4b871821c526e857a0)
#         ;
#
#
#
#
#             var marker_8ce4dfe8821ae87ce23d777df7eacb44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_56288f0494574f7f896a55c34e362ded);
#
#
#         var popup_ef584979a47db472eed64156e168afa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a00b2d85152e83b76c7ba475ce1b6a7 = $(`&lt;div id=&quot;html_1a00b2d85152e83b76c7ba475ce1b6a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ef584979a47db472eed64156e168afa0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ace2d1b5b202b06b94433e663b93eef9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ace2d1b5b202b06b94433e663b93eef9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ace2d1b5b202b06b94433e663b93eef9 = L.map(
#                 &quot;map_ace2d1b5b202b06b94433e663b93eef9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b51dfde7a01f3ef21547574fdc3f2a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b51dfde7a01f3ef21547574fdc3f2a4.addTo(map_ace2d1b5b202b06b94433e663b93eef9);
#
#
#             var feature_group_88ec20eed02255a9aa69f6a0684e7bd2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_392b5a0410bc5256f0bb94f0565d63d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_88ec20eed02255a9aa69f6a0684e7bd2);
#
#
#         var popup_44d05a0b929010f3a0e1a2af0ec522dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_109426a8eb6d982505e296caec0d95dd = $(`&lt;div id=&quot;html_109426a8eb6d982505e296caec0d95dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_44d05a0b929010f3a0e1a2af0ec522dc.setContent(html_109426a8eb6d982505e296caec0d95dd);
#
#
#
#         marker_392b5a0410bc5256f0bb94f0565d63d7.bindPopup(popup_44d05a0b929010f3a0e1a2af0ec522dc)
#         ;
#
#
#
#
#             var marker_ba5d8bcdb6c80d78dd1d5410d13502ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_88ec20eed02255a9aa69f6a0684e7bd2);
#
#
#         var popup_b423722c6723dcdde0f5011a1f06ef8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23d3ae49b0324f8003a363ad5b5398e5 = $(`&lt;div id=&quot;html_23d3ae49b0324f8003a363ad5b5398e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b423722c6723dcdde0f5011a1f06ef8c.setContent(html_23d3ae49b0324f8003a363ad5b5398e5);
#
#
#
#         marker_ba5d8bcdb6c80d78dd1d5410d13502ca.bindPopup(popup_b423722c6723dcdde0f5011a1f06ef8c)
#         ;
#
#
#
#
#             var marker_c3a52e8c7821679e2fbb62be53ce9344 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_88ec20eed02255a9aa69f6a0684e7bd2);
#
#
#         var popup_2b402ad0e58f134d8ce6c589cb1a50fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76e0777f7bb201383629f133746931f5 = $(`&lt;div id=&quot;html_76e0777f7bb201383629f133746931f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2b402ad0e58f134d8ce6c589cb1a50fe.setContent(html_76e0777f7bb201383629f133746931f5);
#
#
#
#         marker_c3a52e8c7821679e2fbb62be53ce9344.bindPopup(popup_2b402ad0e58f134d8ce6c589cb1a50fe)
#         ;
#
#
#
#
#             var marker_5d86f72c76b6a5c584585ff6ed832b1a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_88ec20eed02255a9aa69f6a0684e7bd2);
#
#
#         var popup_b92362f8c813577caccc60f4b4be2dd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb51e6a84b2ba75c8101fe14ca2beeb3 = $(`&lt;div id=&quot;html_bb51e6a84b2ba75c8101fe14ca2beeb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b92362f8c813577caccc60f4b4be2dd1.setContent(html_bb51e6a84b2ba75c8101fe14ca2beeb3);
#
#
#
#         marker_5d86f72c76b6a5c584585ff6ed832b1a.bindPopup(popup_b92362f8c813577caccc60f4b4be2dd1)
#         ;
#
#
#
#
#             var marker_f4781df660f34b7740176f60831a7842 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_88ec20eed02255a9aa69f6a0684e7bd2);
#
#
#         var popup_b3182f26b4049c4b900e11e518684c45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae481d572cf903fad20895a719b2a046 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae481d572cf903fad20895a719b2a046&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae481d572cf903fad20895a719b2a046 = L.map(
#                 &quot;map_ae481d572cf903fad20895a719b2a046&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_967bcf0dd362215de5d5ee9f5c919346 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_967bcf0dd362215de5d5ee9f5c919346.addTo(map_ae481d572cf903fad20895a719b2a046);
#
#
#             var feature_group_fd89318f253ca1d23e858cbd876aa84b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fd89318f253ca1d23e858cbd876aa84b.addTo(map_ae481d572cf903fad20895a719b2a046);
#
#
#             var feature_group_sub_group_5f3ef06524b822df538533e49866c503 = L.featureGroup.subGroup(
#                 feature_group_fd89318f253ca1d23e858cbd876aa84b
#             );
#
#
#             var marker_3435015c5e610ced19e02a84c1247d00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f3ef06524b822df538533e49866c503);
#
#
#         var popup_db01910026cd7b7bc6818387960a208b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eb6facc4b4a79eb143f58b4fc0a7b34 = $(`&lt;div id=&quot;html_7eb6facc4b4a79eb143f58b4fc0a7b34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_db01910026cd7b7bc6818387960a208b.setContent(html_7eb6facc4b4a79eb143f58b4fc0a7b34);
#
#
#
#         marker_3435015c5e610ced19e02a84c1247d00.bindPopup(popup_db01910026cd7b7bc6818387960a208b)
#         ;
#
#
#
#
#             var marker_dbcd1e0e36fa9391210e3a53c3c31de4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f3ef06524b822df538533e49866c503);
#
#
#         var popup_bf691e9df8a46d025c0841b19101723c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79f0f4d78a8c8328a0ef91dd746e7f9a = $(`&lt;div id=&quot;html_79f0f4d78a8c8328a0ef91dd746e7f9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bf691e9df8a46d025c0841b19101723c.setContent(html_79f0f4d78a8c8328a0ef91dd746e7f9a);
#
#
#
#         marker_dbcd1e0e36fa9391210e3a53c3c31de4.bindPopup(popup_bf691e9df8a46d025c0841b19101723c)
#         ;
#
#
#
#
#             var marker_a79a26883af4672682274202c9afc25c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f3ef06524b822df538533e49866c503);
#
#
#         var popup_86b100b289718154c7c5f4c4096a6077 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf3bb412abecdab9808815de1f8ac7d5 = $(`&lt;div id=&quot;html_cf3bb412abecdab9808815de1f8ac7d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_86b100b289718154c7c5f4c4096a6077.setContent(html_cf3bb412abecdab9808815de1f8ac7d5);
#
#
#
#         marker_a79a26883af4672682274202c9afc25c.bindPopup(popup_86b100b289718154c7c5f4c4096a6077)
#         ;
#
#
#
#
#             var marker_d967723b14ed1d68f418708a7a627d50 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f3ef06524b822df538533e49866c503);
#
#
#         var popup_dbbabd6ca243a758c107cc647d0ee5a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e360fcdc4ff64ac03cd136d30547b3e = $(`&lt;div id=&quot;html_4e360fcdc4ff64ac03cd136d30547b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dbbabd6ca243a758c107cc647d0ee5a9.setContent(html_4e360fcdc4ff64ac03cd136d30547b3e);
#
#
#
#         marker_
