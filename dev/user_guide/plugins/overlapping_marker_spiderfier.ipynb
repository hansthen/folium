# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a02394469e7c3c42f5a5b863b2c3e089 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a02394469e7c3c42f5a5b863b2c3e089&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a02394469e7c3c42f5a5b863b2c3e089 = L.map(
#                 &quot;map_a02394469e7c3c42f5a5b863b2c3e089&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8c43a6a3501ce1658b90ec7e25183ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8c43a6a3501ce1658b90ec7e25183ce.addTo(map_a02394469e7c3c42f5a5b863b2c3e089);
#
#
#             var marker_bc36710890cc0cb09eab32e4d68ac8af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a02394469e7c3c42f5a5b863b2c3e089);
#
#
#         var popup_56a371820946a8bbf1c290729728c390 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf88b1f4681674764d7f3ead9088853e = $(`&lt;div id=&quot;html_bf88b1f4681674764d7f3ead9088853e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_56a371820946a8bbf1c290729728c390.setContent(html_bf88b1f4681674764d7f3ead9088853e);
#
#
#
#         marker_bc36710890cc0cb09eab32e4d68ac8af.bindPopup(popup_56a371820946a8bbf1c290729728c390)
#         ;
#
#
#
#
#             var marker_3427e46082234ace061822cc61261c13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a02394469e7c3c42f5a5b863b2c3e089);
#
#
#         var popup_19f387e971df6d03bac5fd094da21b18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b83341bea3e78e06a2b38616f0626db3 = $(`&lt;div id=&quot;html_b83341bea3e78e06a2b38616f0626db3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_19f387e971df6d03bac5fd094da21b18.setContent(html_b83341bea3e78e06a2b38616f0626db3);
#
#
#
#         marker_3427e46082234ace061822cc61261c13.bindPopup(popup_19f387e971df6d03bac5fd094da21b18)
#         ;
#
#
#
#
#             var marker_800bba6217965872e7a706db371970dd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a02394469e7c3c42f5a5b863b2c3e089);
#
#
#         var popup_c94b175e05f1fbf1df19cb2deab6b2a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bbe18d199e95fc364822f14085ac0d9 = $(`&lt;div id=&quot;html_7bbe18d199e95fc364822f14085ac0d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c94b175e05f1fbf1df19cb2deab6b2a0.setContent(html_7bbe18d199e95fc364822f14085ac0d9);
#
#
#
#         marker_800bba6217965872e7a706db371970dd.bindPopup(popup_c94b175e05f1fbf1df19cb2deab6b2a0)
#         ;
#
#
#
#
#             var marker_3e83e559d1fd58c5d13c8487513e7f8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a02394469e7c3c42f5a5b863b2c3e089);
#
#
#         var popup_1670a43800f7f92c6ddd0492d2f1fe0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7200adfa98ce1823a5216a042098872a = $(`&lt;div id=&quot;html_7200adfa98ce1823a5216a042098872a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1670a43800f7f92c6ddd0492d2f1fe0c.setContent(html_7200adfa98ce1823a5216a042098872a);
#
#
#
#         marker_3e83e559d1fd58c5d13c8487513e7f8b.bindPopup(popup_1670a43800f7f92c6ddd0492d2f1fe0c)
#         ;
#
#
#
#
#             var marker_cea68becb77811dd933aec4fed019451 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a02394469e7c3c42f5a5b863b2c3e089);
#
#
#         var popup_5ea03f408ab308dc695ec29f708fb6ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5034ad491ed17866cc579f999ad171d = $(`&lt;div id=&quot;html_f5034ad491ed17866cc579f999ad171d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5ea03f408ab308dc695ec29f708fb6ed.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ff306cf3dc6eef734a2d52e846cce86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ff306cf3dc6eef734a2d52e846cce86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ff306cf3dc6eef734a2d52e846cce86 = L.map(
#                 &quot;map_1ff306cf3dc6eef734a2d52e846cce86&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73ef54e119a36699d7ac9a99727a57d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73ef54e119a36699d7ac9a99727a57d7.addTo(map_1ff306cf3dc6eef734a2d52e846cce86);
#
#
#             var feature_group_b9ee6de69be4cf3e8d6a7aa5617d7880 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d94cd728112998e04d0a16aeefcea3e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b9ee6de69be4cf3e8d6a7aa5617d7880);
#
#
#         var popup_cbd067ce35b2f5d5f6575c5123c2c7f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5092d5e7a88ea36713a579dd2feb7e78 = $(`&lt;div id=&quot;html_5092d5e7a88ea36713a579dd2feb7e78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cbd067ce35b2f5d5f6575c5123c2c7f7.setContent(html_5092d5e7a88ea36713a579dd2feb7e78);
#
#
#
#         marker_d94cd728112998e04d0a16aeefcea3e1.bindPopup(popup_cbd067ce35b2f5d5f6575c5123c2c7f7)
#         ;
#
#
#
#
#             var marker_5fd7df35a6b2d1b7a24ed7f80836ebd0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b9ee6de69be4cf3e8d6a7aa5617d7880);
#
#
#         var popup_1819fb647282c07e0073f6dc58e90534 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be9132d51b5c258dc02534b15a130133 = $(`&lt;div id=&quot;html_be9132d51b5c258dc02534b15a130133&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1819fb647282c07e0073f6dc58e90534.setContent(html_be9132d51b5c258dc02534b15a130133);
#
#
#
#         marker_5fd7df35a6b2d1b7a24ed7f80836ebd0.bindPopup(popup_1819fb647282c07e0073f6dc58e90534)
#         ;
#
#
#
#
#             var marker_0b025f3087c771a13e24f506f31cc2b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b9ee6de69be4cf3e8d6a7aa5617d7880);
#
#
#         var popup_c47050f3c50dce44160e34be290d7cf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_441f58421dc6cb0d2dd23508f5b77056 = $(`&lt;div id=&quot;html_441f58421dc6cb0d2dd23508f5b77056&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c47050f3c50dce44160e34be290d7cf2.setContent(html_441f58421dc6cb0d2dd23508f5b77056);
#
#
#
#         marker_0b025f3087c771a13e24f506f31cc2b6.bindPopup(popup_c47050f3c50dce44160e34be290d7cf2)
#         ;
#
#
#
#
#             var marker_ddf43db3d0825015146df894a279de3c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b9ee6de69be4cf3e8d6a7aa5617d7880);
#
#
#         var popup_490a8c9d4bcf051bbde9c1f7b6e412a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53e84cf5325e4a91c73cb604a7eb2741 = $(`&lt;div id=&quot;html_53e84cf5325e4a91c73cb604a7eb2741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_490a8c9d4bcf051bbde9c1f7b6e412a5.setContent(html_53e84cf5325e4a91c73cb604a7eb2741);
#
#
#
#         marker_ddf43db3d0825015146df894a279de3c.bindPopup(popup_490a8c9d4bcf051bbde9c1f7b6e412a5)
#         ;
#
#
#
#
#             var marker_e69ae1b39e53e07952050460ddcbcaee = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b9ee6de69be4cf3e8d6a7aa5617d7880);
#
#
#         var popup_3127cb2d3fef0613f005cda22bbc86a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83e59cced1fe8cc2a68416b0affe062a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83e59cced1fe8cc2a68416b0affe062a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83e59cced1fe8cc2a68416b0affe062a = L.map(
#                 &quot;map_83e59cced1fe8cc2a68416b0affe062a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b45ef12e893a40761d568c420e9a4926 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b45ef12e893a40761d568c420e9a4926.addTo(map_83e59cced1fe8cc2a68416b0affe062a);
#
#
#             var feature_group_304816399bbd28d6818994e751b95a39 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_304816399bbd28d6818994e751b95a39.addTo(map_83e59cced1fe8cc2a68416b0affe062a);
#
#
#             var feature_group_sub_group_fa0fc77abbbf1ab3401d674fb2c3bb26 = L.featureGroup.subGroup(
#                 feature_group_304816399bbd28d6818994e751b95a39
#             );
#
#
#             var marker_5f7a383c168fefc7994c0bc53f5ef593 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa0fc77abbbf1ab3401d674fb2c3bb26);
#
#
#         var popup_cb99cf254c4f7141bc6860d46e6c7dcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_959fc0d04e3e46ebfe8031b849dc7863 = $(`&lt;div id=&quot;html_959fc0d04e3e46ebfe8031b849dc7863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb99cf254c4f7141bc6860d46e6c7dcd.setContent(html_959fc0d04e3e46ebfe8031b849dc7863);
#
#
#
#         marker_5f7a383c168fefc7994c0bc53f5ef593.bindPopup(popup_cb99cf254c4f7141bc6860d46e6c7dcd)
#         ;
#
#
#
#
#             var marker_e67cd2158866cdfe96bfc140270393d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa0fc77abbbf1ab3401d674fb2c3bb26);
#
#
#         var popup_e9d05c5097d18d852932029a62d3358b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46578e1853de37a705348d941b792876 = $(`&lt;div id=&quot;html_46578e1853de37a705348d941b792876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e9d05c5097d18d852932029a62d3358b.setContent(html_46578e1853de37a705348d941b792876);
#
#
#
#         marker_e67cd2158866cdfe96bfc140270393d8.bindPopup(popup_e9d05c5097d18d852932029a62d3358b)
#         ;
#
#
#
#
#             var marker_ca834effacbd50dbb9efa36be51de84c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa0fc77abbbf1ab3401d674fb2c3bb26);
#
#
#         var popup_f8f8ca36efd962b98ee40d683b631adf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb06be6821593a05891a64cb40aabc00 = $(`&lt;div id=&quot;html_eb06be6821593a05891a64cb40aabc00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f8f8ca36efd962b98ee40d683b631adf.setContent(html_eb06be6821593a05891a64cb40aabc00);
#
#
#
#         marker_ca834effacbd50dbb9efa36be51de84c.bindPopup(popup_f8f8ca36efd962b98ee40d683b631adf)
#         ;
#
#
#
#
#             var marker_5009d93f3384f3c411f2e864800ab142 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fa0fc77abbbf1ab3401d674fb2c3bb26);
#
#
#         var popup_ebf9c200443bbacf1c8726d08e107c0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a46eee83ed60b90bc35171e30ec11a71 = $(`&lt;div id=&quot;html_a46eee83ed60b90bc35171e30ec11a71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ebf9c200443bbacf1c8726d08e107c0f.setContent(html_a46eee83ed60b90bc35171e30ec11a71);
#
#
#
#         marker_
