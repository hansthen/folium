# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfb212fa911591aca1b3b121a123244a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfb212fa911591aca1b3b121a123244a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfb212fa911591aca1b3b121a123244a = L.map(
#                 &quot;map_bfb212fa911591aca1b3b121a123244a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2013893a896326eea3246950cf5bc0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2013893a896326eea3246950cf5bc0e.addTo(map_bfb212fa911591aca1b3b121a123244a);
#
#
#             var marker_695154aa0950eb4dde680c619d7a57b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bfb212fa911591aca1b3b121a123244a);
#
#
#         var popup_f42e8668054343853096b31faf325a86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b3861dde3414babab26f2213c8e2fb7 = $(`&lt;div id=&quot;html_3b3861dde3414babab26f2213c8e2fb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f42e8668054343853096b31faf325a86.setContent(html_3b3861dde3414babab26f2213c8e2fb7);
#
#
#
#         marker_695154aa0950eb4dde680c619d7a57b0.bindPopup(popup_f42e8668054343853096b31faf325a86)
#         ;
#
#
#
#
#             var marker_0cf84d557a989e2f9688535eb6bdccea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bfb212fa911591aca1b3b121a123244a);
#
#
#         var popup_74d245009ae3e1c7b124567aacf84a63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e431940b19f0fdd09e6b179818562ba = $(`&lt;div id=&quot;html_0e431940b19f0fdd09e6b179818562ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_74d245009ae3e1c7b124567aacf84a63.setContent(html_0e431940b19f0fdd09e6b179818562ba);
#
#
#
#         marker_0cf84d557a989e2f9688535eb6bdccea.bindPopup(popup_74d245009ae3e1c7b124567aacf84a63)
#         ;
#
#
#
#
#             var marker_83b029544df7e83d2d2960df7a4b6cac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bfb212fa911591aca1b3b121a123244a);
#
#
#         var popup_f9160880758de319d57f54845cd257fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d63464728c0ee0365d38d2f221383149 = $(`&lt;div id=&quot;html_d63464728c0ee0365d38d2f221383149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f9160880758de319d57f54845cd257fc.setContent(html_d63464728c0ee0365d38d2f221383149);
#
#
#
#         marker_83b029544df7e83d2d2960df7a4b6cac.bindPopup(popup_f9160880758de319d57f54845cd257fc)
#         ;
#
#
#
#
#             var marker_a1592e6cf16ca03b5d1b1b4c3c971b27 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bfb212fa911591aca1b3b121a123244a);
#
#
#         var popup_61a5226f9d18926df32b410e2e2beaab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccce9353b5a269eb47dc08567dd0c4d6 = $(`&lt;div id=&quot;html_ccce9353b5a269eb47dc08567dd0c4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_61a5226f9d18926df32b410e2e2beaab.setContent(html_ccce9353b5a269eb47dc08567dd0c4d6);
#
#
#
#         marker_a1592e6cf16ca03b5d1b1b4c3c971b27.bindPopup(popup_61a5226f9d18926df32b410e2e2beaab)
#         ;
#
#
#
#
#             var marker_0625888c1c37e906986f68a2d68362d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bfb212fa911591aca1b3b121a123244a);
#
#
#         var popup_c69a345f2e193d88ad10ed8a506dee0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db0da0b7b22b1afa9f7d54b91e789e1f = $(`&lt;div id=&quot;html_db0da0b7b22b1afa9f7d54b91e789e1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c69a345f2e193d88ad10ed8a506dee0d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b0477be7b321dd5268e4604246163ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b0477be7b321dd5268e4604246163ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b0477be7b321dd5268e4604246163ed = L.map(
#                 &quot;map_7b0477be7b321dd5268e4604246163ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8228030c144a1de00e55dfd742e2f0cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8228030c144a1de00e55dfd742e2f0cf.addTo(map_7b0477be7b321dd5268e4604246163ed);
#
#
#             var feature_group_c04bb7a9407782e2199dbe308d2cb980 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d1fcec35af1169bb265dc2103d7fcccb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c04bb7a9407782e2199dbe308d2cb980);
#
#
#         var popup_9ed80922f8c3cffa7c63ee2eba0fdbad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b44ecbe87b2d097e68044935bdb6e4fd = $(`&lt;div id=&quot;html_b44ecbe87b2d097e68044935bdb6e4fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9ed80922f8c3cffa7c63ee2eba0fdbad.setContent(html_b44ecbe87b2d097e68044935bdb6e4fd);
#
#
#
#         marker_d1fcec35af1169bb265dc2103d7fcccb.bindPopup(popup_9ed80922f8c3cffa7c63ee2eba0fdbad)
#         ;
#
#
#
#
#             var marker_655142822ba9aa7a936d0359e2bdab8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c04bb7a9407782e2199dbe308d2cb980);
#
#
#         var popup_019ddd52d15f881f680f5d44b3c68771 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f826666a809b620994271dab289bdc7 = $(`&lt;div id=&quot;html_2f826666a809b620994271dab289bdc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_019ddd52d15f881f680f5d44b3c68771.setContent(html_2f826666a809b620994271dab289bdc7);
#
#
#
#         marker_655142822ba9aa7a936d0359e2bdab8e.bindPopup(popup_019ddd52d15f881f680f5d44b3c68771)
#         ;
#
#
#
#
#             var marker_84ab0c1001be2a2fe3badaa685abb6a8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c04bb7a9407782e2199dbe308d2cb980);
#
#
#         var popup_99bc3cc2911ee9a32826ad55f7f9c0b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb03a0a48a7b0a9b21f45eac16d10b99 = $(`&lt;div id=&quot;html_cb03a0a48a7b0a9b21f45eac16d10b99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_99bc3cc2911ee9a32826ad55f7f9c0b8.setContent(html_cb03a0a48a7b0a9b21f45eac16d10b99);
#
#
#
#         marker_84ab0c1001be2a2fe3badaa685abb6a8.bindPopup(popup_99bc3cc2911ee9a32826ad55f7f9c0b8)
#         ;
#
#
#
#
#             var marker_4d677598e8327e657cd95da2ed88ec96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c04bb7a9407782e2199dbe308d2cb980);
#
#
#         var popup_25d34c4eaf7e049ae6182950f354004c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61abae169ce672aa27f4c14bfc9d2bbe = $(`&lt;div id=&quot;html_61abae169ce672aa27f4c14bfc9d2bbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_25d34c4eaf7e049ae6182950f354004c.setContent(html_61abae169ce672aa27f4c14bfc9d2bbe);
#
#
#
#         marker_4d677598e8327e657cd95da2ed88ec96.bindPopup(popup_25d34c4eaf7e049ae6182950f354004c)
#         ;
#
#
#
#
#             var marker_b2aa3ffd5b0f01f0c54ea1678121a978 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c04bb7a9407782e2199dbe308d2cb980);
#
#
#         var popup_b34770573c9225b5e5a31a64ce9045eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d40d98e79a1488db31c3ede787d07e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d40d98e79a1488db31c3ede787d07e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d40d98e79a1488db31c3ede787d07e9 = L.map(
#                 &quot;map_2d40d98e79a1488db31c3ede787d07e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95d1789f6f2ad6b427d367f6170fedbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95d1789f6f2ad6b427d367f6170fedbc.addTo(map_2d40d98e79a1488db31c3ede787d07e9);
#
#
#             var feature_group_c48532c5306aa068ddffd2076c24fa94 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c48532c5306aa068ddffd2076c24fa94.addTo(map_2d40d98e79a1488db31c3ede787d07e9);
#
#
#             var feature_group_sub_group_b2221a7cd1d81270f2b5d04583241828 = L.featureGroup.subGroup(
#                 feature_group_c48532c5306aa068ddffd2076c24fa94
#             );
#
#
#             var marker_cd5e6da652efedcaa1ba435002a75af9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2221a7cd1d81270f2b5d04583241828);
#
#
#         var popup_1b0c4dacc9f04910948f83abe1d9a59b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cb5f83e9d6a93c0b58bc536aa7ab7db = $(`&lt;div id=&quot;html_9cb5f83e9d6a93c0b58bc536aa7ab7db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1b0c4dacc9f04910948f83abe1d9a59b.setContent(html_9cb5f83e9d6a93c0b58bc536aa7ab7db);
#
#
#
#         marker_cd5e6da652efedcaa1ba435002a75af9.bindPopup(popup_1b0c4dacc9f04910948f83abe1d9a59b)
#         ;
#
#
#
#
#             var marker_c2a2401a14ec8459b4264d9a5374b846 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2221a7cd1d81270f2b5d04583241828);
#
#
#         var popup_f16ffe915660fe587778dfed919c95fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_713334001b3c38a686e9fbeaffff3b7f = $(`&lt;div id=&quot;html_713334001b3c38a686e9fbeaffff3b7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f16ffe915660fe587778dfed919c95fa.setContent(html_713334001b3c38a686e9fbeaffff3b7f);
#
#
#
#         marker_c2a2401a14ec8459b4264d9a5374b846.bindPopup(popup_f16ffe915660fe587778dfed919c95fa)
#         ;
#
#
#
#
#             var marker_d29b157b322b80ee28e0ae55bed15048 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2221a7cd1d81270f2b5d04583241828);
#
#
#         var popup_4c762e97f08eef2394357467f9971be4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abd705f558bd0a4bf5df6b9d658841c4 = $(`&lt;div id=&quot;html_abd705f558bd0a4bf5df6b9d658841c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4c762e97f08eef2394357467f9971be4.setContent(html_abd705f558bd0a4bf5df6b9d658841c4);
#
#
#
#         marker_d29b157b322b80ee28e0ae55bed15048.bindPopup(popup_4c762e97f08eef2394357467f9971be4)
#         ;
#
#
#
#
#             var marker_f0e98af8e80c55c62398f59060e75bdc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2221a7cd1d81270f2b5d04583241828);
#
#
#         var popup_555f1912324834f4839d2b7d60410108 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07eb67e422d76e434fb8d615bf30c8a8 = $(`&lt;div id=&quot;html_07eb67e422d76e434fb8d615bf30c8a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_555f1912324834f4839d2b7d60410108.setContent(html_07eb67e422d76e434fb8d615bf30c8a8);
#
#
#
#         marker_
