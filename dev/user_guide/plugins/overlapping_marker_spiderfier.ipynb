# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b5e321b8c36412add75f600bb72d530 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b5e321b8c36412add75f600bb72d530&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b5e321b8c36412add75f600bb72d530 = L.map(
#                 &quot;map_8b5e321b8c36412add75f600bb72d530&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33556bc27f92b19be3ae4611efeb247b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33556bc27f92b19be3ae4611efeb247b.addTo(map_8b5e321b8c36412add75f600bb72d530);
#
#
#             var marker_5e9925de4827a4c982de10fcac82bf81 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8b5e321b8c36412add75f600bb72d530);
#
#
#         var popup_90c801a7ccbe6635bce0999d70b05c0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87f4473c25f6ad0b558f968e952acd99 = $(`&lt;div id=&quot;html_87f4473c25f6ad0b558f968e952acd99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_90c801a7ccbe6635bce0999d70b05c0c.setContent(html_87f4473c25f6ad0b558f968e952acd99);
#
#
#
#         marker_5e9925de4827a4c982de10fcac82bf81.bindPopup(popup_90c801a7ccbe6635bce0999d70b05c0c)
#         ;
#
#
#
#
#             var marker_b79c6438e4e529867c54284febebda88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8b5e321b8c36412add75f600bb72d530);
#
#
#         var popup_dddc0ee423965c631c8004a4bba60700 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89399c1322c899aa443d1448f996043d = $(`&lt;div id=&quot;html_89399c1322c899aa443d1448f996043d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dddc0ee423965c631c8004a4bba60700.setContent(html_89399c1322c899aa443d1448f996043d);
#
#
#
#         marker_b79c6438e4e529867c54284febebda88.bindPopup(popup_dddc0ee423965c631c8004a4bba60700)
#         ;
#
#
#
#
#             var marker_de98d95ce1e1037490941176a81c7d94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8b5e321b8c36412add75f600bb72d530);
#
#
#         var popup_16c52f31bfc5f05316736356efb944f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b93b55fa2743017982bc5431f28fdb1 = $(`&lt;div id=&quot;html_5b93b55fa2743017982bc5431f28fdb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_16c52f31bfc5f05316736356efb944f8.setContent(html_5b93b55fa2743017982bc5431f28fdb1);
#
#
#
#         marker_de98d95ce1e1037490941176a81c7d94.bindPopup(popup_16c52f31bfc5f05316736356efb944f8)
#         ;
#
#
#
#
#             var marker_8be1b74864d9cadadb6dd923d711a777 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8b5e321b8c36412add75f600bb72d530);
#
#
#         var popup_69e670d0afb07857dff9d5a880ccfb98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4ee1d3ce8ce56260f2108905be76948 = $(`&lt;div id=&quot;html_e4ee1d3ce8ce56260f2108905be76948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_69e670d0afb07857dff9d5a880ccfb98.setContent(html_e4ee1d3ce8ce56260f2108905be76948);
#
#
#
#         marker_8be1b74864d9cadadb6dd923d711a777.bindPopup(popup_69e670d0afb07857dff9d5a880ccfb98)
#         ;
#
#
#
#
#             var marker_f9a95b615b8bb0a8922c844e0ab29cf6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8b5e321b8c36412add75f600bb72d530);
#
#
#         var popup_99022925744af4d60a32ace7d4ae1cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_268b2b814454ca849907eb420b4acb7d = $(`&lt;div id=&quot;html_268b2b814454ca849907eb420b4acb7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_99022925744af4d60a32ace7d4ae1cb7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d050458f8c15c9d95fab2add2ec9bd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d050458f8c15c9d95fab2add2ec9bd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d050458f8c15c9d95fab2add2ec9bd2 = L.map(
#                 &quot;map_0d050458f8c15c9d95fab2add2ec9bd2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_571e5c4477fd503c74c23dbf6ec6e5ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_571e5c4477fd503c74c23dbf6ec6e5ae.addTo(map_0d050458f8c15c9d95fab2add2ec9bd2);
#
#
#             var feature_group_6575713d1079a386ee7c392ea989a23e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7253c5da6e839ec9bd2e0f6348cec1b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6575713d1079a386ee7c392ea989a23e);
#
#
#         var popup_bfe57bdca03f1054866626a072e49474 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27594f6d9ce03aec4aa4d675edee793c = $(`&lt;div id=&quot;html_27594f6d9ce03aec4aa4d675edee793c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bfe57bdca03f1054866626a072e49474.setContent(html_27594f6d9ce03aec4aa4d675edee793c);
#
#
#
#         marker_7253c5da6e839ec9bd2e0f6348cec1b3.bindPopup(popup_bfe57bdca03f1054866626a072e49474)
#         ;
#
#
#
#
#             var marker_79dac6795c7bd4658fee7ea5fdb4fc04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6575713d1079a386ee7c392ea989a23e);
#
#
#         var popup_3c3773df14381c3f543af3c2c81f84e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_685c492eb1b7a3af40c23b9f29b86938 = $(`&lt;div id=&quot;html_685c492eb1b7a3af40c23b9f29b86938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3c3773df14381c3f543af3c2c81f84e9.setContent(html_685c492eb1b7a3af40c23b9f29b86938);
#
#
#
#         marker_79dac6795c7bd4658fee7ea5fdb4fc04.bindPopup(popup_3c3773df14381c3f543af3c2c81f84e9)
#         ;
#
#
#
#
#             var marker_1b30b77f1913ebf5e893ec2d625cc01e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6575713d1079a386ee7c392ea989a23e);
#
#
#         var popup_e055a322a2652a6d209b832aa268f384 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00cc817b9ac510b974bdf985e48df909 = $(`&lt;div id=&quot;html_00cc817b9ac510b974bdf985e48df909&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e055a322a2652a6d209b832aa268f384.setContent(html_00cc817b9ac510b974bdf985e48df909);
#
#
#
#         marker_1b30b77f1913ebf5e893ec2d625cc01e.bindPopup(popup_e055a322a2652a6d209b832aa268f384)
#         ;
#
#
#
#
#             var marker_27eda634012e19bfa8a828adc0dd9acc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6575713d1079a386ee7c392ea989a23e);
#
#
#         var popup_ac8e0b255c4bf8fcde16fe3f812a7001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4e2ebc96250fe1fdbf68b6af7c3ccfa = $(`&lt;div id=&quot;html_a4e2ebc96250fe1fdbf68b6af7c3ccfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ac8e0b255c4bf8fcde16fe3f812a7001.setContent(html_a4e2ebc96250fe1fdbf68b6af7c3ccfa);
#
#
#
#         marker_27eda634012e19bfa8a828adc0dd9acc.bindPopup(popup_ac8e0b255c4bf8fcde16fe3f812a7001)
#         ;
#
#
#
#
#             var marker_55cdedbcb9ce41f42de34451e5326d9d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6575713d1079a386ee7c392ea989a23e);
#
#
#         var popup_6d950e193238d28c0c06e9f7de93515d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ded9055ec2bdd9e836baf3cae8fc73f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ded9055ec2bdd9e836baf3cae8fc73f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ded9055ec2bdd9e836baf3cae8fc73f3 = L.map(
#                 &quot;map_ded9055ec2bdd9e836baf3cae8fc73f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_227ac4213e4ad647c66e7cbc6fe5b907 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_227ac4213e4ad647c66e7cbc6fe5b907.addTo(map_ded9055ec2bdd9e836baf3cae8fc73f3);
#
#
#             var feature_group_eaf79617eab9429e9da0e3aae308ff33 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eaf79617eab9429e9da0e3aae308ff33.addTo(map_ded9055ec2bdd9e836baf3cae8fc73f3);
#
#
#             var feature_group_sub_group_c3b0490d222b0692abc621ad42aa30b4 = L.featureGroup.subGroup(
#                 feature_group_eaf79617eab9429e9da0e3aae308ff33
#             );
#
#
#             var marker_a5d8a7251774163ed0767fef1533f326 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3b0490d222b0692abc621ad42aa30b4);
#
#
#         var popup_09dd4c642f22805fcc612269a29debb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_832fc1e14f2c8665fae016a713fd1d14 = $(`&lt;div id=&quot;html_832fc1e14f2c8665fae016a713fd1d14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_09dd4c642f22805fcc612269a29debb2.setContent(html_832fc1e14f2c8665fae016a713fd1d14);
#
#
#
#         marker_a5d8a7251774163ed0767fef1533f326.bindPopup(popup_09dd4c642f22805fcc612269a29debb2)
#         ;
#
#
#
#
#             var marker_cd360be0639e3b9eed0f0b472df166f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3b0490d222b0692abc621ad42aa30b4);
#
#
#         var popup_b00449adf8a0d3d7b6ab7daf556b9d4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_706567f9f39fc7a295db35edd84528c8 = $(`&lt;div id=&quot;html_706567f9f39fc7a295db35edd84528c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b00449adf8a0d3d7b6ab7daf556b9d4f.setContent(html_706567f9f39fc7a295db35edd84528c8);
#
#
#
#         marker_cd360be0639e3b9eed0f0b472df166f1.bindPopup(popup_b00449adf8a0d3d7b6ab7daf556b9d4f)
#         ;
#
#
#
#
#             var marker_9ea5c361f76e9d8e277bb418c55a162d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3b0490d222b0692abc621ad42aa30b4);
#
#
#         var popup_caee58935541d688f608fa16230a6ce9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acee96ea54d912589c6e6f41cc424d39 = $(`&lt;div id=&quot;html_acee96ea54d912589c6e6f41cc424d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_caee58935541d688f608fa16230a6ce9.setContent(html_acee96ea54d912589c6e6f41cc424d39);
#
#
#
#         marker_9ea5c361f76e9d8e277bb418c55a162d.bindPopup(popup_caee58935541d688f608fa16230a6ce9)
#         ;
#
#
#
#
#             var marker_a62481b11fe075c4b7cd9f23870191ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c3b0490d222b0692abc621ad42aa30b4);
#
#
#         var popup_45b4afd3bd803b5bd9a42e1e6a80fe22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5f70ccf8a8b8c9aa9349b82a0a3d5b6 = $(`&lt;div id=&quot;html_c5f70ccf8a8b8c9aa9349b82a0a3d5b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_45b4afd3bd803b5bd9a42e1e6a80fe22.setContent(html_c5f70ccf8a8b8c9aa9349b82a0a3d5b6);
#
#
#
#         marker_
