# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3771aad542b5d6a651a6e0270606847d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3771aad542b5d6a651a6e0270606847d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3771aad542b5d6a651a6e0270606847d = L.map(
#                 &quot;map_3771aad542b5d6a651a6e0270606847d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_388af9a31a7693a88905cf6e3d6d3bb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_388af9a31a7693a88905cf6e3d6d3bb6.addTo(map_3771aad542b5d6a651a6e0270606847d);
#
#
#             var marker_c7169cab45f39ef31515b45ac15c0087 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3771aad542b5d6a651a6e0270606847d);
#
#
#         var popup_fb49fb83d2f15a8f04964ff4eac8a42d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ab6ce5d5ab320923befd6e1a744013c = $(`&lt;div id=&quot;html_0ab6ce5d5ab320923befd6e1a744013c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fb49fb83d2f15a8f04964ff4eac8a42d.setContent(html_0ab6ce5d5ab320923befd6e1a744013c);
#
#
#
#         marker_c7169cab45f39ef31515b45ac15c0087.bindPopup(popup_fb49fb83d2f15a8f04964ff4eac8a42d)
#         ;
#
#
#
#
#             var marker_a31cd410c50fa52652b6277705fc217b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3771aad542b5d6a651a6e0270606847d);
#
#
#         var popup_bc5d4b53374e70dbc816dc7031a07b3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3d4ac39dbd0fb07eed0c48729870f05 = $(`&lt;div id=&quot;html_c3d4ac39dbd0fb07eed0c48729870f05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bc5d4b53374e70dbc816dc7031a07b3d.setContent(html_c3d4ac39dbd0fb07eed0c48729870f05);
#
#
#
#         marker_a31cd410c50fa52652b6277705fc217b.bindPopup(popup_bc5d4b53374e70dbc816dc7031a07b3d)
#         ;
#
#
#
#
#             var marker_d0ff0a1b667710b3077176cd330032dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3771aad542b5d6a651a6e0270606847d);
#
#
#         var popup_4479295d35a0ea0ab74cea32338f43df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e51b7bb00f97e332584b7548346958c = $(`&lt;div id=&quot;html_4e51b7bb00f97e332584b7548346958c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4479295d35a0ea0ab74cea32338f43df.setContent(html_4e51b7bb00f97e332584b7548346958c);
#
#
#
#         marker_d0ff0a1b667710b3077176cd330032dc.bindPopup(popup_4479295d35a0ea0ab74cea32338f43df)
#         ;
#
#
#
#
#             var marker_d03fe9349aaba567d7953846f7c015e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3771aad542b5d6a651a6e0270606847d);
#
#
#         var popup_eea9561bd6c746ad35703f35f9e0e1cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dc5cd3e3ff4501bdabf22ad71c116ed = $(`&lt;div id=&quot;html_4dc5cd3e3ff4501bdabf22ad71c116ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eea9561bd6c746ad35703f35f9e0e1cb.setContent(html_4dc5cd3e3ff4501bdabf22ad71c116ed);
#
#
#
#         marker_d03fe9349aaba567d7953846f7c015e1.bindPopup(popup_eea9561bd6c746ad35703f35f9e0e1cb)
#         ;
#
#
#
#
#             var marker_211ee66691103fc2b932396d8df9cd01 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3771aad542b5d6a651a6e0270606847d);
#
#
#         var popup_2ba0ae993885ebb60a99d59791a6aae4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de1bf71df29f2a5365cded0b54d894e8 = $(`&lt;div id=&quot;html_de1bf71df29f2a5365cded0b54d894e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2ba0ae993885ebb60a99d59791a6aae4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1216c1c813866b8cab7afac85eefa898 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1216c1c813866b8cab7afac85eefa898&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1216c1c813866b8cab7afac85eefa898 = L.map(
#                 &quot;map_1216c1c813866b8cab7afac85eefa898&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fe6909a3d80d5ad2662891e7bf3324a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6fe6909a3d80d5ad2662891e7bf3324a.addTo(map_1216c1c813866b8cab7afac85eefa898);
#
#
#             var feature_group_29664a2d31f45207c9fa927b4a51a61d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dedd5f1c877e83dc3cd74a41fec63589 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_29664a2d31f45207c9fa927b4a51a61d);
#
#
#         var popup_7102d9a25490224d4b54687fa9b7368d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da0e17ec0ab7200bae989d6caf09c3ca = $(`&lt;div id=&quot;html_da0e17ec0ab7200bae989d6caf09c3ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7102d9a25490224d4b54687fa9b7368d.setContent(html_da0e17ec0ab7200bae989d6caf09c3ca);
#
#
#
#         marker_dedd5f1c877e83dc3cd74a41fec63589.bindPopup(popup_7102d9a25490224d4b54687fa9b7368d)
#         ;
#
#
#
#
#             var marker_b60c6c290d9243ad091845c8d65705d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_29664a2d31f45207c9fa927b4a51a61d);
#
#
#         var popup_61d7cbb88d0c08bfff4200e981b92a79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_952cb21978691bb460fa86f5e19f0376 = $(`&lt;div id=&quot;html_952cb21978691bb460fa86f5e19f0376&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_61d7cbb88d0c08bfff4200e981b92a79.setContent(html_952cb21978691bb460fa86f5e19f0376);
#
#
#
#         marker_b60c6c290d9243ad091845c8d65705d6.bindPopup(popup_61d7cbb88d0c08bfff4200e981b92a79)
#         ;
#
#
#
#
#             var marker_624ac4ceb762f216b9ba47e784d2ff0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_29664a2d31f45207c9fa927b4a51a61d);
#
#
#         var popup_554b7ec70150f88f7d84331127fe353a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53dd39cba61a23738f393b79230dc1b0 = $(`&lt;div id=&quot;html_53dd39cba61a23738f393b79230dc1b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_554b7ec70150f88f7d84331127fe353a.setContent(html_53dd39cba61a23738f393b79230dc1b0);
#
#
#
#         marker_624ac4ceb762f216b9ba47e784d2ff0e.bindPopup(popup_554b7ec70150f88f7d84331127fe353a)
#         ;
#
#
#
#
#             var marker_f5dfb86af77a9a152f2cbb12bb67f838 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_29664a2d31f45207c9fa927b4a51a61d);
#
#
#         var popup_43a2c735babe83b543de810a198a7cd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85477911587085a5784a18654e81a12b = $(`&lt;div id=&quot;html_85477911587085a5784a18654e81a12b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_43a2c735babe83b543de810a198a7cd8.setContent(html_85477911587085a5784a18654e81a12b);
#
#
#
#         marker_f5dfb86af77a9a152f2cbb12bb67f838.bindPopup(popup_43a2c735babe83b543de810a198a7cd8)
#         ;
#
#
#
#
#             var marker_0281540311f9c9db0c60bfdea6b78132 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_29664a2d31f45207c9fa927b4a51a61d);
#
#
#         var popup_0a73a6647413a0f15793debfb6e9a919 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27d340f61a0d0a8536376115abe6796d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27d340f61a0d0a8536376115abe6796d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27d340f61a0d0a8536376115abe6796d = L.map(
#                 &quot;map_27d340f61a0d0a8536376115abe6796d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4d1f79b65955f66a2d04c690494ad06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4d1f79b65955f66a2d04c690494ad06.addTo(map_27d340f61a0d0a8536376115abe6796d);
#
#
#             var feature_group_86b3fe69283706d80deb72de1e6e4a7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_86b3fe69283706d80deb72de1e6e4a7b.addTo(map_27d340f61a0d0a8536376115abe6796d);
#
#
#             var feature_group_sub_group_53c226daaeec0eb9f217e43a19da937c = L.featureGroup.subGroup(
#                 feature_group_86b3fe69283706d80deb72de1e6e4a7b
#             );
#
#
#             var marker_034104d9dcba3c04734ba68c750441eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_53c226daaeec0eb9f217e43a19da937c);
#
#
#         var popup_7d3074e3f181b42084a1f569be398bcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1aa2df8a422929197d54d9012f7b202c = $(`&lt;div id=&quot;html_1aa2df8a422929197d54d9012f7b202c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7d3074e3f181b42084a1f569be398bcd.setContent(html_1aa2df8a422929197d54d9012f7b202c);
#
#
#
#         marker_034104d9dcba3c04734ba68c750441eb.bindPopup(popup_7d3074e3f181b42084a1f569be398bcd)
#         ;
#
#
#
#
#             var marker_8d8413ae8596ece06279c34376d3f4c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_53c226daaeec0eb9f217e43a19da937c);
#
#
#         var popup_2892da8f72356ee0e60455bd0bbbefec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1e0e0c55b2c82ef4274474661b41a29 = $(`&lt;div id=&quot;html_a1e0e0c55b2c82ef4274474661b41a29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2892da8f72356ee0e60455bd0bbbefec.setContent(html_a1e0e0c55b2c82ef4274474661b41a29);
#
#
#
#         marker_8d8413ae8596ece06279c34376d3f4c4.bindPopup(popup_2892da8f72356ee0e60455bd0bbbefec)
#         ;
#
#
#
#
#             var marker_be1c2c09083c06d63f5b77965ca5490d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_53c226daaeec0eb9f217e43a19da937c);
#
#
#         var popup_b54a9e4f8044d7264e54927606a04896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c319795cee6b7c35462b621f03d783a = $(`&lt;div id=&quot;html_4c319795cee6b7c35462b621f03d783a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b54a9e4f8044d7264e54927606a04896.setContent(html_4c319795cee6b7c35462b621f03d783a);
#
#
#
#         marker_be1c2c09083c06d63f5b77965ca5490d.bindPopup(popup_b54a9e4f8044d7264e54927606a04896)
#         ;
#
#
#
#
#             var marker_a53c8389758c2499a16778ba9a61de5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_53c226daaeec0eb9f217e43a19da937c);
#
#
#         var popup_487410ab6e70be01bf832be2ab34f719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5610f16c3da9c21c57389ed763720a6f = $(`&lt;div id=&quot;html_5610f16c3da9c21c57389ed763720a6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_487410ab6e70be01bf832be2ab34f719.setContent(html_5610f16c3da9c21c57389ed763720a6f);
#
#
#
#         marker_
