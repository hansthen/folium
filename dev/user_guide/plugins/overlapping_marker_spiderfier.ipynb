# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24f4e18f0159bced9e93123829f7ac3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24f4e18f0159bced9e93123829f7ac3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24f4e18f0159bced9e93123829f7ac3c = L.map(
#                 &quot;map_24f4e18f0159bced9e93123829f7ac3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c994e132ff9bfa41c3ef9056641ae2ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c994e132ff9bfa41c3ef9056641ae2ca.addTo(map_24f4e18f0159bced9e93123829f7ac3c);
#
#
#             var marker_cfdfbddd29736867807e9ee62bde1a19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_24f4e18f0159bced9e93123829f7ac3c);
#
#
#         var popup_20d9357fe321ded9dd39e08b2f0a1b8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81e91812d822fabf6de2115cd13aa48d = $(`&lt;div id=&quot;html_81e91812d822fabf6de2115cd13aa48d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_20d9357fe321ded9dd39e08b2f0a1b8e.setContent(html_81e91812d822fabf6de2115cd13aa48d);
#
#
#
#         marker_cfdfbddd29736867807e9ee62bde1a19.bindPopup(popup_20d9357fe321ded9dd39e08b2f0a1b8e)
#         ;
#
#
#
#
#             var marker_6eb8b2cc076693d7798f21c0ecb95853 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_24f4e18f0159bced9e93123829f7ac3c);
#
#
#         var popup_cf0e36a826a300ebd608acc4a43e2194 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39c0be94ea961052cb56447675edf637 = $(`&lt;div id=&quot;html_39c0be94ea961052cb56447675edf637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cf0e36a826a300ebd608acc4a43e2194.setContent(html_39c0be94ea961052cb56447675edf637);
#
#
#
#         marker_6eb8b2cc076693d7798f21c0ecb95853.bindPopup(popup_cf0e36a826a300ebd608acc4a43e2194)
#         ;
#
#
#
#
#             var marker_f1a3417c332cc4d12860bf683feb1128 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_24f4e18f0159bced9e93123829f7ac3c);
#
#
#         var popup_d16cdf67592f5b9cb54f806c20473f19 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6b03e47b26679f793fde177e27f7d58 = $(`&lt;div id=&quot;html_f6b03e47b26679f793fde177e27f7d58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d16cdf67592f5b9cb54f806c20473f19.setContent(html_f6b03e47b26679f793fde177e27f7d58);
#
#
#
#         marker_f1a3417c332cc4d12860bf683feb1128.bindPopup(popup_d16cdf67592f5b9cb54f806c20473f19)
#         ;
#
#
#
#
#             var marker_e8c15ecf2ae13ea97880fede27005f20 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_24f4e18f0159bced9e93123829f7ac3c);
#
#
#         var popup_8d8990607a8835b311220267ad52fddb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2517e3278b23c4e384f9763c4f7334f = $(`&lt;div id=&quot;html_a2517e3278b23c4e384f9763c4f7334f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8d8990607a8835b311220267ad52fddb.setContent(html_a2517e3278b23c4e384f9763c4f7334f);
#
#
#
#         marker_e8c15ecf2ae13ea97880fede27005f20.bindPopup(popup_8d8990607a8835b311220267ad52fddb)
#         ;
#
#
#
#
#             var marker_a63402c347b09b5efb099e3687f5f3fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_24f4e18f0159bced9e93123829f7ac3c);
#
#
#         var popup_aa093866bfdd5d86e3aa98e3c648d529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd75b9f98d9b10b3ab9f06a46f2047a7 = $(`&lt;div id=&quot;html_fd75b9f98d9b10b3ab9f06a46f2047a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa093866bfdd5d86e3aa98e3c648d529.setContent(html_fd75b9f98d9b10b3ab9f06a46f2047a7);
#
#
#
#         marker_a63402c347b09b5efb099e3687f5f3fe.bindPopup(popup_aa093866bfdd5d86e3aa98e3c648d529)
#         ;
#
#
#
#
#             var marker_b9b25eaf11

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcdd0062867801a23b1f83558fc45e34 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcdd0062867801a23b1f83558fc45e34&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcdd0062867801a23b1f83558fc45e34 = L.map(
#                 &quot;map_dcdd0062867801a23b1f83558fc45e34&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_269501067e503cc4a8eddede5c724cc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_269501067e503cc4a8eddede5c724cc3.addTo(map_dcdd0062867801a23b1f83558fc45e34);
#
#
#             var feature_group_6ab01ca2f94c720a6cb67b59acbdb40e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_665a967b003ed827cb3958b3676da9c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6ab01ca2f94c720a6cb67b59acbdb40e);
#
#
#         var popup_3a6481839df977c774ddd416743027ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_753f9851beb222972cb05d148c6f8401 = $(`&lt;div id=&quot;html_753f9851beb222972cb05d148c6f8401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3a6481839df977c774ddd416743027ea.setContent(html_753f9851beb222972cb05d148c6f8401);
#
#
#
#         marker_665a967b003ed827cb3958b3676da9c7.bindPopup(popup_3a6481839df977c774ddd416743027ea)
#         ;
#
#
#
#
#             var marker_6402307b40f46997d1c0bac03b4892fe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6ab01ca2f94c720a6cb67b59acbdb40e);
#
#
#         var popup_3a218261a5f7fbda5d0c9c0ed29b69ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56cdf627767efafe9d8f6ac6064c3abb = $(`&lt;div id=&quot;html_56cdf627767efafe9d8f6ac6064c3abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3a218261a5f7fbda5d0c9c0ed29b69ad.setContent(html_56cdf627767efafe9d8f6ac6064c3abb);
#
#
#
#         marker_6402307b40f46997d1c0bac03b4892fe.bindPopup(popup_3a218261a5f7fbda5d0c9c0ed29b69ad)
#         ;
#
#
#
#
#             var marker_5302da9b3c44f5e41bb1dae87f65badd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6ab01ca2f94c720a6cb67b59acbdb40e);
#
#
#         var popup_14b86713226e39a630e829d75de525af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d7e31eb77eeeb9032edbcf502c80f5f = $(`&lt;div id=&quot;html_8d7e31eb77eeeb9032edbcf502c80f5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_14b86713226e39a630e829d75de525af.setContent(html_8d7e31eb77eeeb9032edbcf502c80f5f);
#
#
#
#         marker_5302da9b3c44f5e41bb1dae87f65badd.bindPopup(popup_14b86713226e39a630e829d75de525af)
#         ;
#
#
#
#
#             var marker_1b2fcc0d49b37d0696693080572adcba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6ab01ca2f94c720a6cb67b59acbdb40e);
#
#
#         var popup_ff0eb7f7a061392fa42c650121832774 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f93592bb0b3832a5755e5da3cf3ccb81 = $(`&lt;div id=&quot;html_f93592bb0b3832a5755e5da3cf3ccb81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ff0eb7f7a061392fa42c650121832774.setContent(html_f93592bb0b3832a5755e5da3cf3ccb81);
#
#
#
#         marker_1b2fcc0d49b37d0696693080572adcba.bindPopup(popup_ff0eb7f7a061392fa42c650121832774)
#         ;
#
#
#
#
#             var marker_de193e7d5bd0402135f9ced772722f3e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6ab01ca2f94c720a6cb67b59acbdb40e);
#
#
#         var popup_cc5d317c2f8e3771d54cd688e2a4ffba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_135de9016df5e94b73cc2d518d379b85 = $(`&lt;div id=&quot;html_135de9016df5e94b73cc2d518d379b85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_cc5d317c2f8e3771d5

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b26ac096d8cf84ad6c06acba6e03a4ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b26ac096d8cf84ad6c06acba6e03a4ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b26ac096d8cf84ad6c06acba6e03a4ff = L.map(
#                 &quot;map_b26ac096d8cf84ad6c06acba6e03a4ff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73756463c148a20188388a38ffeaf133 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73756463c148a20188388a38ffeaf133.addTo(map_b26ac096d8cf84ad6c06acba6e03a4ff);
#
#
#             var feature_group_5a631f772fda7e71dd47ebf48fa674b2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5a631f772fda7e71dd47ebf48fa674b2.addTo(map_b26ac096d8cf84ad6c06acba6e03a4ff);
#
#
#             var feature_group_sub_group_2a2ff6fbbed717770a1f396dd589709e = L.featureGroup.subGroup(
#                 feature_group_5a631f772fda7e71dd47ebf48fa674b2
#             );
#
#
#             var marker_ed2d8b6c66772d75d2ceefb7b10fe142 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a2ff6fbbed717770a1f396dd589709e);
#
#
#         var popup_186cd6bbc7aaa9b3c24756633c826107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e9b1a5e3f25e0ec61cde63c0edc1546 = $(`&lt;div id=&quot;html_8e9b1a5e3f25e0ec61cde63c0edc1546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_186cd6bbc7aaa9b3c24756633c826107.setContent(html_8e9b1a5e3f25e0ec61cde63c0edc1546);
#
#
#
#         marker_ed2d8b6c66772d75d2ceefb7b10fe142.bindPopup(popup_186cd6bbc7aaa9b3c24756633c826107)
#         ;
#
#
#
#
#             var marker_18b5b5d9b4c742a3f0d0b90cbb08751f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a2ff6fbbed717770a1f396dd589709e);
#
#
#         var popup_e3d81c9dd32d469ecd40d42813dd3991 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d27dc8594de37052a5a44e0810f25c6 = $(`&lt;div id=&quot;html_2d27dc8594de37052a5a44e0810f25c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e3d81c9dd32d469ecd40d42813dd3991.setContent(html_2d27dc8594de37052a5a44e0810f25c6);
#
#
#
#         marker_18b5b5d9b4c742a3f0d0b90cbb08751f.bindPopup(popup_e3d81c9dd32d469ecd40d42813dd3991)
#         ;
#
#
#
#
#             var marker_822bfca4fb59ac2dbe9fe021215c8324 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a2ff6fbbed717770a1f396dd589709e);
#
#
#         var popup_57fa9c1f64008dc48497e6092b143520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26920865293e828150a9f9593a85f16c = $(`&lt;div id=&quot;html_26920865293e828150a9f9593a85f16c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_57fa9c1f64008dc48497e6092b143520.setContent(html_26920865293e828150a9f9593a85f16c);
#
#
#
#         marker_822bfca4fb59ac2dbe9fe021215c8324.bindPopup(popup_57fa9c1f64008dc48497e6092b143520)
#         ;
#
#
#
#
#             var marker_6a7af47683f5b2b13d34c67f9f85c820 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a2ff6fbbed717770a1f396dd589709e);
#
#
#         var popup_8ae0f200217cfcd87d28f772561a00f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8062aaf6ce51fcecefd7a77f1cb8bcc6 = $(`&lt;div id=&quot;html_8062aaf6ce51fcecefd7a77f1cb8bcc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8ae0f200217cfcd87d28f772561a00f7.setContent(html_8062aaf6ce51fcecefd7a77f1cb8bcc6);
#
#
#
#         marker_6a7af47683f5b2b13d34c67f9f85c820.bindPopup(popup_8ae0f200217cfcd87d28f772561a00f7)
#         ;
#
#
#
#
#             var marker_1acb41d05a6e60cffb4ff653ff637984 = L.marker(
#                 [45.050399999999996, 3.0504],
