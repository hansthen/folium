# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b854f75a936650574e4226082df888da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b854f75a936650574e4226082df888da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b854f75a936650574e4226082df888da = L.map(
#                 &quot;map_b854f75a936650574e4226082df888da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_663881da018b3fd902a9ae9185ad0fc6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_663881da018b3fd902a9ae9185ad0fc6.addTo(map_b854f75a936650574e4226082df888da);
#
#
#             var marker_45687155818970e96ecadd1fb1623ce9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b854f75a936650574e4226082df888da);
#
#
#         var popup_5188fcc6c4db4cda767d9c83517f7308 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fcd4d8fa13bd274162b1452d1dc78da = $(`&lt;div id=&quot;html_3fcd4d8fa13bd274162b1452d1dc78da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5188fcc6c4db4cda767d9c83517f7308.setContent(html_3fcd4d8fa13bd274162b1452d1dc78da);
#
#
#
#         marker_45687155818970e96ecadd1fb1623ce9.bindPopup(popup_5188fcc6c4db4cda767d9c83517f7308)
#         ;
#
#
#
#
#             var marker_4ae9d184f845e731f040980c7618ed4b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b854f75a936650574e4226082df888da);
#
#
#         var popup_004f4765c834e5a88f271a2bf4601ba5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0360eb7f605d3b73bfadb0e24824d580 = $(`&lt;div id=&quot;html_0360eb7f605d3b73bfadb0e24824d580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_004f4765c834e5a88f271a2bf4601ba5.setContent(html_0360eb7f605d3b73bfadb0e24824d580);
#
#
#
#         marker_4ae9d184f845e731f040980c7618ed4b.bindPopup(popup_004f4765c834e5a88f271a2bf4601ba5)
#         ;
#
#
#
#
#             var marker_55bb2fa89bcdc6f114281f602ff1955e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b854f75a936650574e4226082df888da);
#
#
#         var popup_70b7b0e49dc8cfca3ee2294ce6ebf229 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74bfadbd2539d921bf65b0259d6b2dfb = $(`&lt;div id=&quot;html_74bfadbd2539d921bf65b0259d6b2dfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_70b7b0e49dc8cfca3ee2294ce6ebf229.setContent(html_74bfadbd2539d921bf65b0259d6b2dfb);
#
#
#
#         marker_55bb2fa89bcdc6f114281f602ff1955e.bindPopup(popup_70b7b0e49dc8cfca3ee2294ce6ebf229)
#         ;
#
#
#
#
#             var marker_ee399a3cadbe52db37c6e98cd1c48d0c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b854f75a936650574e4226082df888da);
#
#
#         var popup_c06a29d8bb218c6baf07c8ab6e32c6b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c4334531878d95faf443353585fbdb2 = $(`&lt;div id=&quot;html_4c4334531878d95faf443353585fbdb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c06a29d8bb218c6baf07c8ab6e32c6b5.setContent(html_4c4334531878d95faf443353585fbdb2);
#
#
#
#         marker_ee399a3cadbe52db37c6e98cd1c48d0c.bindPopup(popup_c06a29d8bb218c6baf07c8ab6e32c6b5)
#         ;
#
#
#
#
#             var marker_65d12728da22ea65dccf075e8821cd33 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b854f75a936650574e4226082df888da);
#
#
#         var popup_e22fc9edd8ba213273eb7fba17b3c053 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0674d9e78551e1842d2e7e236f763af8 = $(`&lt;div id=&quot;html_0674d9e78551e1842d2e7e236f763af8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e22fc9edd8ba213273eb7fba17b3c053.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27c673e129a024a0585b14bced1dfd2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27c673e129a024a0585b14bced1dfd2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27c673e129a024a0585b14bced1dfd2a = L.map(
#                 &quot;map_27c673e129a024a0585b14bced1dfd2a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48666fe0a0396bd3d2ec730085bf73e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48666fe0a0396bd3d2ec730085bf73e1.addTo(map_27c673e129a024a0585b14bced1dfd2a);
#
#
#             var feature_group_051351b76d43b2178267bf5f0f7d383c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_70d3b31073faee7bdcfea1c19d1f3d20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_051351b76d43b2178267bf5f0f7d383c);
#
#
#         var popup_0467b433e7c8ef8c990bb9bce88f89d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46c159a9064bdfcc417d0f23d6727912 = $(`&lt;div id=&quot;html_46c159a9064bdfcc417d0f23d6727912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0467b433e7c8ef8c990bb9bce88f89d7.setContent(html_46c159a9064bdfcc417d0f23d6727912);
#
#
#
#         marker_70d3b31073faee7bdcfea1c19d1f3d20.bindPopup(popup_0467b433e7c8ef8c990bb9bce88f89d7)
#         ;
#
#
#
#
#             var marker_fed28492906cc8fb9a2d254ccc57a5bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_051351b76d43b2178267bf5f0f7d383c);
#
#
#         var popup_58146e2e6a215f22eb160592af0a0e2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a5c376aa2bbaeb74dd69bcd4e2ebdc4 = $(`&lt;div id=&quot;html_6a5c376aa2bbaeb74dd69bcd4e2ebdc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_58146e2e6a215f22eb160592af0a0e2c.setContent(html_6a5c376aa2bbaeb74dd69bcd4e2ebdc4);
#
#
#
#         marker_fed28492906cc8fb9a2d254ccc57a5bd.bindPopup(popup_58146e2e6a215f22eb160592af0a0e2c)
#         ;
#
#
#
#
#             var marker_65db24e989c02cecaab38cad66bdbdbc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_051351b76d43b2178267bf5f0f7d383c);
#
#
#         var popup_a3845d3bd28ca33e02dd93e6825e607b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_111ccb4301e294e45744fd0850c4cdfb = $(`&lt;div id=&quot;html_111ccb4301e294e45744fd0850c4cdfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a3845d3bd28ca33e02dd93e6825e607b.setContent(html_111ccb4301e294e45744fd0850c4cdfb);
#
#
#
#         marker_65db24e989c02cecaab38cad66bdbdbc.bindPopup(popup_a3845d3bd28ca33e02dd93e6825e607b)
#         ;
#
#
#
#
#             var marker_7c9ac589d6e64723d9420f21912acb04 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_051351b76d43b2178267bf5f0f7d383c);
#
#
#         var popup_d74d200caf45f3873c9aaa9a4414a142 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b51489414b37354dc670fac4bf380e86 = $(`&lt;div id=&quot;html_b51489414b37354dc670fac4bf380e86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d74d200caf45f3873c9aaa9a4414a142.setContent(html_b51489414b37354dc670fac4bf380e86);
#
#
#
#         marker_7c9ac589d6e64723d9420f21912acb04.bindPopup(popup_d74d200caf45f3873c9aaa9a4414a142)
#         ;
#
#
#
#
#             var marker_80f896f2467a741f7693058e5f1a1007 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_051351b76d43b2178267bf5f0f7d383c);
#
#
#         var popup_2cac9f8654b0be9431a5269b4df9bc26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d24fb651c23d195c98ac33989a998e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d24fb651c23d195c98ac33989a998e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d24fb651c23d195c98ac33989a998e9 = L.map(
#                 &quot;map_8d24fb651c23d195c98ac33989a998e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec33d71f17d966244e86cf5e5652e400 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec33d71f17d966244e86cf5e5652e400.addTo(map_8d24fb651c23d195c98ac33989a998e9);
#
#
#             var feature_group_d329e00c03cd0fbd677248c55788b94b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d329e00c03cd0fbd677248c55788b94b.addTo(map_8d24fb651c23d195c98ac33989a998e9);
#
#
#             var feature_group_sub_group_79676315b3b747cb9892f49e3d30fcb3 = L.featureGroup.subGroup(
#                 feature_group_d329e00c03cd0fbd677248c55788b94b
#             );
#
#
#             var marker_a1e6f9cdab223dbcc3c124cce9e88328 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_79676315b3b747cb9892f49e3d30fcb3);
#
#
#         var popup_47b2cc497c900eb1b618cf1203ba2a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66259453cb79149996b1dd0002e119eb = $(`&lt;div id=&quot;html_66259453cb79149996b1dd0002e119eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_47b2cc497c900eb1b618cf1203ba2a4f.setContent(html_66259453cb79149996b1dd0002e119eb);
#
#
#
#         marker_a1e6f9cdab223dbcc3c124cce9e88328.bindPopup(popup_47b2cc497c900eb1b618cf1203ba2a4f)
#         ;
#
#
#
#
#             var marker_dbc16adfa83720aac09ff62b4ef7d964 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_79676315b3b747cb9892f49e3d30fcb3);
#
#
#         var popup_29ec57b3ec558cf63b6722776a880775 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea1e6f7daf96fc4575148624c34bea11 = $(`&lt;div id=&quot;html_ea1e6f7daf96fc4575148624c34bea11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_29ec57b3ec558cf63b6722776a880775.setContent(html_ea1e6f7daf96fc4575148624c34bea11);
#
#
#
#         marker_dbc16adfa83720aac09ff62b4ef7d964.bindPopup(popup_29ec57b3ec558cf63b6722776a880775)
#         ;
#
#
#
#
#             var marker_5ad5577ad2f9ce151a2890979e0616cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_79676315b3b747cb9892f49e3d30fcb3);
#
#
#         var popup_0bbd1e1e907d9f1c28ea2d26e952889b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_952f110cff82a3d2eafbc4b030a730ac = $(`&lt;div id=&quot;html_952f110cff82a3d2eafbc4b030a730ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0bbd1e1e907d9f1c28ea2d26e952889b.setContent(html_952f110cff82a3d2eafbc4b030a730ac);
#
#
#
#         marker_5ad5577ad2f9ce151a2890979e0616cf.bindPopup(popup_0bbd1e1e907d9f1c28ea2d26e952889b)
#         ;
#
#
#
#
#             var marker_7b6a3f49e37de6ccbc23e68ef5a0826c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_79676315b3b747cb9892f49e3d30fcb3);
#
#
#         var popup_ec90cc0e4eda4fa98d373fd6a8af377e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84b6b235d54e2726eee8ec6f815129d6 = $(`&lt;div id=&quot;html_84b6b235d54e2726eee8ec6f815129d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ec90cc0e4eda4fa98d373fd6a8af377e.setContent(html_84b6b235d54e2726eee8ec6f815129d6);
#
#
#
#         marker_
