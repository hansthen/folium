# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58cd88f526d3fff0111470cded17d0a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58cd88f526d3fff0111470cded17d0a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58cd88f526d3fff0111470cded17d0a6 = L.map(
#                 &quot;map_58cd88f526d3fff0111470cded17d0a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c7f41ea5685643922196cd68a445f81 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c7f41ea5685643922196cd68a445f81.addTo(map_58cd88f526d3fff0111470cded17d0a6);
#
#
#             var marker_2d1f83785189d2ea7f8766538b077a0e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_58cd88f526d3fff0111470cded17d0a6);
#
#
#         var popup_1d9d571c003c6146d8ad3689a30ce380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00fed78cc6eec99f748dedcdcb9d0f07 = $(`&lt;div id=&quot;html_00fed78cc6eec99f748dedcdcb9d0f07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d9d571c003c6146d8ad3689a30ce380.setContent(html_00fed78cc6eec99f748dedcdcb9d0f07);
#
#
#
#         marker_2d1f83785189d2ea7f8766538b077a0e.bindPopup(popup_1d9d571c003c6146d8ad3689a30ce380)
#         ;
#
#
#
#
#             var marker_3380346538d13ea3006daea30e5aabbd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_58cd88f526d3fff0111470cded17d0a6);
#
#
#         var popup_cef5a09ec02ad3a3d42b1793b8f8ab2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8a61a8b38da0f2a7cf49d75d8a875cc = $(`&lt;div id=&quot;html_f8a61a8b38da0f2a7cf49d75d8a875cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cef5a09ec02ad3a3d42b1793b8f8ab2f.setContent(html_f8a61a8b38da0f2a7cf49d75d8a875cc);
#
#
#
#         marker_3380346538d13ea3006daea30e5aabbd.bindPopup(popup_cef5a09ec02ad3a3d42b1793b8f8ab2f)
#         ;
#
#
#
#
#             var marker_0cdd72037bcd1d4ce199774670454110 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_58cd88f526d3fff0111470cded17d0a6);
#
#
#         var popup_9035ef2ebce4659fe1216d3949162b61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_347b1ac5558c9ff8bfc18b215d6c203d = $(`&lt;div id=&quot;html_347b1ac5558c9ff8bfc18b215d6c203d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9035ef2ebce4659fe1216d3949162b61.setContent(html_347b1ac5558c9ff8bfc18b215d6c203d);
#
#
#
#         marker_0cdd72037bcd1d4ce199774670454110.bindPopup(popup_9035ef2ebce4659fe1216d3949162b61)
#         ;
#
#
#
#
#             var marker_c441bc32d7f975ab49b43958238d67f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_58cd88f526d3fff0111470cded17d0a6);
#
#
#         var popup_6e20a63fd44e8d2f1c4e34f2ca547669 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aac1c8541ca59511f48a1cb2b0512672 = $(`&lt;div id=&quot;html_aac1c8541ca59511f48a1cb2b0512672&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e20a63fd44e8d2f1c4e34f2ca547669.setContent(html_aac1c8541ca59511f48a1cb2b0512672);
#
#
#
#         marker_c441bc32d7f975ab49b43958238d67f5.bindPopup(popup_6e20a63fd44e8d2f1c4e34f2ca547669)
#         ;
#
#
#
#
#             var marker_741d836679eacc496055ff1e85b76e09 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_58cd88f526d3fff0111470cded17d0a6);
#
#
#         var popup_e04dbe96b51a934c5f4d741129abc4e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8890300a75814ad9b253095642eab9db = $(`&lt;div id=&quot;html_8890300a75814ad9b253095642eab9db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e04dbe96b51a934c5f4d741129abc4e3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0197bf1ed98a56748bd4130271eb2e7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0197bf1ed98a56748bd4130271eb2e7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0197bf1ed98a56748bd4130271eb2e7c = L.map(
#                 &quot;map_0197bf1ed98a56748bd4130271eb2e7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb8bf2a51c5ab0928bd0c9c6456d254e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb8bf2a51c5ab0928bd0c9c6456d254e.addTo(map_0197bf1ed98a56748bd4130271eb2e7c);
#
#
#             var feature_group_851513da9789a97570cf21da31e2590e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6cd96b567af26c1c1c5872e22e1fbd95 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_851513da9789a97570cf21da31e2590e);
#
#
#         var popup_be49d718de898d54b7728412492d395c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e96ce614d4a6922f3c42fa74ba0b7e28 = $(`&lt;div id=&quot;html_e96ce614d4a6922f3c42fa74ba0b7e28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_be49d718de898d54b7728412492d395c.setContent(html_e96ce614d4a6922f3c42fa74ba0b7e28);
#
#
#
#         marker_6cd96b567af26c1c1c5872e22e1fbd95.bindPopup(popup_be49d718de898d54b7728412492d395c)
#         ;
#
#
#
#
#             var marker_b1158be018c27fc96f3919d1ef27944f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_851513da9789a97570cf21da31e2590e);
#
#
#         var popup_4908bb25d734eaa2cbf46ae93983a195 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8dde1919a296eebac846a85014b9db8 = $(`&lt;div id=&quot;html_d8dde1919a296eebac846a85014b9db8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4908bb25d734eaa2cbf46ae93983a195.setContent(html_d8dde1919a296eebac846a85014b9db8);
#
#
#
#         marker_b1158be018c27fc96f3919d1ef27944f.bindPopup(popup_4908bb25d734eaa2cbf46ae93983a195)
#         ;
#
#
#
#
#             var marker_e0cf4d8abdb601eab570ccf9faf2ca38 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_851513da9789a97570cf21da31e2590e);
#
#
#         var popup_02341c312138cbe92fdae9bc5c7294ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_608a1774ad0721106bce830e519bb642 = $(`&lt;div id=&quot;html_608a1774ad0721106bce830e519bb642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_02341c312138cbe92fdae9bc5c7294ee.setContent(html_608a1774ad0721106bce830e519bb642);
#
#
#
#         marker_e0cf4d8abdb601eab570ccf9faf2ca38.bindPopup(popup_02341c312138cbe92fdae9bc5c7294ee)
#         ;
#
#
#
#
#             var marker_352ac535c799a2f8aac6f129d58c678c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_851513da9789a97570cf21da31e2590e);
#
#
#         var popup_6126a58a20d5d39deff3646d5b064998 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1575dfc838746752ed52631bdc1ea8a4 = $(`&lt;div id=&quot;html_1575dfc838746752ed52631bdc1ea8a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6126a58a20d5d39deff3646d5b064998.setContent(html_1575dfc838746752ed52631bdc1ea8a4);
#
#
#
#         marker_352ac535c799a2f8aac6f129d58c678c.bindPopup(popup_6126a58a20d5d39deff3646d5b064998)
#         ;
#
#
#
#
#             var marker_3c3c7850776afa28abe92f6b1e34a465 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_851513da9789a97570cf21da31e2590e);
#
#
#         var popup_64a6ec3ac03de605134467194e587303 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0f369396436a24cffccb50eebc84b04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0f369396436a24cffccb50eebc84b04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0f369396436a24cffccb50eebc84b04 = L.map(
#                 &quot;map_d0f369396436a24cffccb50eebc84b04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86343c1a260d0e4fe0c5b899027491da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86343c1a260d0e4fe0c5b899027491da.addTo(map_d0f369396436a24cffccb50eebc84b04);
#
#
#             var feature_group_51a7293a2ab4b4e803f2aca7abc19aae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_51a7293a2ab4b4e803f2aca7abc19aae.addTo(map_d0f369396436a24cffccb50eebc84b04);
#
#
#             var feature_group_sub_group_266424846ca3b1394123e870b90dca32 = L.featureGroup.subGroup(
#                 feature_group_51a7293a2ab4b4e803f2aca7abc19aae
#             );
#
#
#             var marker_4885bf464a81c4bd8aa2e800e7f8ed65 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_266424846ca3b1394123e870b90dca32);
#
#
#         var popup_59b92d9e954dcd9734d6d9a805152fd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60f99762065bce1776b608983d60eb7d = $(`&lt;div id=&quot;html_60f99762065bce1776b608983d60eb7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_59b92d9e954dcd9734d6d9a805152fd3.setContent(html_60f99762065bce1776b608983d60eb7d);
#
#
#
#         marker_4885bf464a81c4bd8aa2e800e7f8ed65.bindPopup(popup_59b92d9e954dcd9734d6d9a805152fd3)
#         ;
#
#
#
#
#             var marker_0072f568053c15fd26b8638f6e58699f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_266424846ca3b1394123e870b90dca32);
#
#
#         var popup_11c2eb8337213460f39e64a118f381ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c52ca800d4ca6ffd3308bfa1757ecd3a = $(`&lt;div id=&quot;html_c52ca800d4ca6ffd3308bfa1757ecd3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_11c2eb8337213460f39e64a118f381ec.setContent(html_c52ca800d4ca6ffd3308bfa1757ecd3a);
#
#
#
#         marker_0072f568053c15fd26b8638f6e58699f.bindPopup(popup_11c2eb8337213460f39e64a118f381ec)
#         ;
#
#
#
#
#             var marker_4edf2c1cd82ad97a8a1e4478869acc92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_266424846ca3b1394123e870b90dca32);
#
#
#         var popup_a6a3f4eaa130afa55eac4154e7a858c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_028f1870d418705014845e5424da4e1c = $(`&lt;div id=&quot;html_028f1870d418705014845e5424da4e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a6a3f4eaa130afa55eac4154e7a858c0.setContent(html_028f1870d418705014845e5424da4e1c);
#
#
#
#         marker_4edf2c1cd82ad97a8a1e4478869acc92.bindPopup(popup_a6a3f4eaa130afa55eac4154e7a858c0)
#         ;
#
#
#
#
#             var marker_e71753ec967ce83a4ad134c330cbd66d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_266424846ca3b1394123e870b90dca32);
#
#
#         var popup_e9001035b70ef4cd9e3a4d4eab7b34c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf391698e8c0ebb6366a6f96408ef282 = $(`&lt;div id=&quot;html_bf391698e8c0ebb6366a6f96408ef282&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e9001035b70ef4cd9e3a4d4eab7b34c0.setContent(html_bf391698e8c0ebb6366a6f96408ef282);
#
#
#
#         marker_
