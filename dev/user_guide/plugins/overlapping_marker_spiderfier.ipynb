# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a245272a7134b47f36062c9107da8f7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a245272a7134b47f36062c9107da8f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a245272a7134b47f36062c9107da8f7 = L.map(
#                 &quot;map_7a245272a7134b47f36062c9107da8f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59da2dc6ac0fa4a2830567ab16b079b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59da2dc6ac0fa4a2830567ab16b079b3.addTo(map_7a245272a7134b47f36062c9107da8f7);
#
#
#             var marker_a842f3ec73fc9e0b22ea809fa1bfdc6b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7a245272a7134b47f36062c9107da8f7);
#
#
#         var popup_fe4a025dbfe5d81ed0bd441347bb79c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_454c4bc3dadd443377c96bdfbca5208f = $(`&lt;div id=&quot;html_454c4bc3dadd443377c96bdfbca5208f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fe4a025dbfe5d81ed0bd441347bb79c3.setContent(html_454c4bc3dadd443377c96bdfbca5208f);
#
#
#
#         marker_a842f3ec73fc9e0b22ea809fa1bfdc6b.bindPopup(popup_fe4a025dbfe5d81ed0bd441347bb79c3)
#         ;
#
#
#
#
#             var marker_4810e1a32b55a787cb8fd74bea5f2415 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7a245272a7134b47f36062c9107da8f7);
#
#
#         var popup_e15d369d5faab6bde2b2a7949ccd5c47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfe720fe5e4434d88280473a1c87a28b = $(`&lt;div id=&quot;html_dfe720fe5e4434d88280473a1c87a28b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e15d369d5faab6bde2b2a7949ccd5c47.setContent(html_dfe720fe5e4434d88280473a1c87a28b);
#
#
#
#         marker_4810e1a32b55a787cb8fd74bea5f2415.bindPopup(popup_e15d369d5faab6bde2b2a7949ccd5c47)
#         ;
#
#
#
#
#             var marker_eb3ec1a69cc71a55bf39e4f01e961140 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7a245272a7134b47f36062c9107da8f7);
#
#
#         var popup_82b15e18b9147d141e63b3d66a903f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd19d516e38e94296ee994141fb1e6f9 = $(`&lt;div id=&quot;html_dd19d516e38e94296ee994141fb1e6f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_82b15e18b9147d141e63b3d66a903f45.setContent(html_dd19d516e38e94296ee994141fb1e6f9);
#
#
#
#         marker_eb3ec1a69cc71a55bf39e4f01e961140.bindPopup(popup_82b15e18b9147d141e63b3d66a903f45)
#         ;
#
#
#
#
#             var marker_9350f5687efa13405e9bceb6b6de9b0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7a245272a7134b47f36062c9107da8f7);
#
#
#         var popup_e55f139de0edf8eb3d06cf6ba4df9268 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_275927cfdc200e46b8d4a73383ff1d8b = $(`&lt;div id=&quot;html_275927cfdc200e46b8d4a73383ff1d8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e55f139de0edf8eb3d06cf6ba4df9268.setContent(html_275927cfdc200e46b8d4a73383ff1d8b);
#
#
#
#         marker_9350f5687efa13405e9bceb6b6de9b0d.bindPopup(popup_e55f139de0edf8eb3d06cf6ba4df9268)
#         ;
#
#
#
#
#             var marker_64ce29102d1277c14a567fb193ca36f1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7a245272a7134b47f36062c9107da8f7);
#
#
#         var popup_968c4e081231b38deacaf2dcdcf4c114 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a73733882d84ff956862bab0b23161bc = $(`&lt;div id=&quot;html_a73733882d84ff956862bab0b23161bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_968c4e081231b38deacaf2dcdcf4c1

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f240f364707c9861e23c6bbd9267e75b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f240f364707c9861e23c6bbd9267e75b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f240f364707c9861e23c6bbd9267e75b = L.map(
#                 &quot;map_f240f364707c9861e23c6bbd9267e75b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9016a164b73e8533376997232f4f3439 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9016a164b73e8533376997232f4f3439.addTo(map_f240f364707c9861e23c6bbd9267e75b);
#
#
#             var feature_group_fc77f42d06ca4856e89789c24b3e9fa9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_94d6fe16564bb50cfda9db1070635350 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fc77f42d06ca4856e89789c24b3e9fa9);
#
#
#         var popup_debd69d318c2a01926c466c2082bd59a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9c28c6d8986b31313567bebf9602617 = $(`&lt;div id=&quot;html_b9c28c6d8986b31313567bebf9602617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_debd69d318c2a01926c466c2082bd59a.setContent(html_b9c28c6d8986b31313567bebf9602617);
#
#
#
#         marker_94d6fe16564bb50cfda9db1070635350.bindPopup(popup_debd69d318c2a01926c466c2082bd59a)
#         ;
#
#
#
#
#             var marker_764b760e85ed10195c73dea618ef01ef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fc77f42d06ca4856e89789c24b3e9fa9);
#
#
#         var popup_cf76e940b48a25d52186bfade64df45c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38a419c782d8a2bfebdc4469a4df26ec = $(`&lt;div id=&quot;html_38a419c782d8a2bfebdc4469a4df26ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cf76e940b48a25d52186bfade64df45c.setContent(html_38a419c782d8a2bfebdc4469a4df26ec);
#
#
#
#         marker_764b760e85ed10195c73dea618ef01ef.bindPopup(popup_cf76e940b48a25d52186bfade64df45c)
#         ;
#
#
#
#
#             var marker_e65d2ea5f900b8c81643631d038a8947 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fc77f42d06ca4856e89789c24b3e9fa9);
#
#
#         var popup_dfb476aac459e909ca5da33ccd2e5b9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58babc0d0c8f2ac5150ddb7df898592b = $(`&lt;div id=&quot;html_58babc0d0c8f2ac5150ddb7df898592b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dfb476aac459e909ca5da33ccd2e5b9e.setContent(html_58babc0d0c8f2ac5150ddb7df898592b);
#
#
#
#         marker_e65d2ea5f900b8c81643631d038a8947.bindPopup(popup_dfb476aac459e909ca5da33ccd2e5b9e)
#         ;
#
#
#
#
#             var marker_a6b2819797f36a443265765da598906b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fc77f42d06ca4856e89789c24b3e9fa9);
#
#
#         var popup_ff49a4a53ea0ce02a4c92341c1e043c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3a5b91b684f0880c7a3c1f433b4eb50 = $(`&lt;div id=&quot;html_f3a5b91b684f0880c7a3c1f433b4eb50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ff49a4a53ea0ce02a4c92341c1e043c5.setContent(html_f3a5b91b684f0880c7a3c1f433b4eb50);
#
#
#
#         marker_a6b2819797f36a443265765da598906b.bindPopup(popup_ff49a4a53ea0ce02a4c92341c1e043c5)
#         ;
#
#
#
#
#             var marker_6958f712d06d2f7e3ce59bb83317b35d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fc77f42d06ca4856e89789c24b3e9fa9);
#
#
#         var popup_f280de5cf946dba641871ad0af6906a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12fea41945d982dde4f0f7e874e2b868 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12fea41945d982dde4f0f7e874e2b868&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12fea41945d982dde4f0f7e874e2b868 = L.map(
#                 &quot;map_12fea41945d982dde4f0f7e874e2b868&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c058f44cc3693235898ee975350ffa42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c058f44cc3693235898ee975350ffa42.addTo(map_12fea41945d982dde4f0f7e874e2b868);
#
#
#             var feature_group_b88f085c27aba628082c86e6a0d98a42 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b88f085c27aba628082c86e6a0d98a42.addTo(map_12fea41945d982dde4f0f7e874e2b868);
#
#
#             var feature_group_sub_group_2297da17dc0dda28247ca221c8949753 = L.featureGroup.subGroup(
#                 feature_group_b88f085c27aba628082c86e6a0d98a42
#             );
#
#
#             var marker_4a73f04e2a5141cccca6061bed5e35f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2297da17dc0dda28247ca221c8949753);
#
#
#         var popup_ce3f7b850880a3b2544b0ea583d60c27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b9dfa70ca4ce2e2c29898ecbdde410b = $(`&lt;div id=&quot;html_8b9dfa70ca4ce2e2c29898ecbdde410b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ce3f7b850880a3b2544b0ea583d60c27.setContent(html_8b9dfa70ca4ce2e2c29898ecbdde410b);
#
#
#
#         marker_4a73f04e2a5141cccca6061bed5e35f8.bindPopup(popup_ce3f7b850880a3b2544b0ea583d60c27)
#         ;
#
#
#
#
#             var marker_d3b4dc91f4df6632e40cb812e610a83c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2297da17dc0dda28247ca221c8949753);
#
#
#         var popup_5b19ad70c9e314c128c72d5585d6796a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e32a8ea3e9ecbd25f996caa7022e145 = $(`&lt;div id=&quot;html_5e32a8ea3e9ecbd25f996caa7022e145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5b19ad70c9e314c128c72d5585d6796a.setContent(html_5e32a8ea3e9ecbd25f996caa7022e145);
#
#
#
#         marker_d3b4dc91f4df6632e40cb812e610a83c.bindPopup(popup_5b19ad70c9e314c128c72d5585d6796a)
#         ;
#
#
#
#
#             var marker_f8c4d78e787f4f104710fdf768cd7322 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2297da17dc0dda28247ca221c8949753);
#
#
#         var popup_217e45e9b8e68ec8d4477577bef90c98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acb67db7856ac43c6caaa8c892beb610 = $(`&lt;div id=&quot;html_acb67db7856ac43c6caaa8c892beb610&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_217e45e9b8e68ec8d4477577bef90c98.setContent(html_acb67db7856ac43c6caaa8c892beb610);
#
#
#
#         marker_f8c4d78e787f4f104710fdf768cd7322.bindPopup(popup_217e45e9b8e68ec8d4477577bef90c98)
#         ;
#
#
#
#
#             var marker_d4fa1cc9159cf3311e9cee16f8d8d1f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2297da17dc0dda28247ca221c8949753);
#
#
#         var popup_8548865337f22b6040b1bc96b5216df6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33aef568d71c801b02131a3807445903 = $(`&lt;div id=&quot;html_33aef568d71c801b02131a3807445903&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8548865337f22b6040b1bc96b5216df6.setContent(html_33aef568d71c801b02131a3807445903);
#
#
#
#         mark
