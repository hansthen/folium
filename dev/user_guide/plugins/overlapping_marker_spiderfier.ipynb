# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2930b6a1ca7295362ecaf75d46547c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2930b6a1ca7295362ecaf75d46547c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2930b6a1ca7295362ecaf75d46547c0 = L.map(
#                 &quot;map_b2930b6a1ca7295362ecaf75d46547c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b7d18bd9415b75bf969818dad9a7f22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b7d18bd9415b75bf969818dad9a7f22.addTo(map_b2930b6a1ca7295362ecaf75d46547c0);
#
#
#             var marker_d0113a032d4f0c72c9775fdd9cf2f453 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b2930b6a1ca7295362ecaf75d46547c0);
#
#
#         var popup_d0a1265a91c34a927e299f444d1b58cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2d7b2c3e0b63c7a74fd09bb7218940b = $(`&lt;div id=&quot;html_a2d7b2c3e0b63c7a74fd09bb7218940b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d0a1265a91c34a927e299f444d1b58cb.setContent(html_a2d7b2c3e0b63c7a74fd09bb7218940b);
#
#
#
#         marker_d0113a032d4f0c72c9775fdd9cf2f453.bindPopup(popup_d0a1265a91c34a927e299f444d1b58cb)
#         ;
#
#
#
#
#             var marker_88d60cbdec3c0a4e9fd230d5e4a0f6bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b2930b6a1ca7295362ecaf75d46547c0);
#
#
#         var popup_3c527cce5157e1b577c2f1176ccf3a62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a96256d4e55791501025bf791d1045f1 = $(`&lt;div id=&quot;html_a96256d4e55791501025bf791d1045f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3c527cce5157e1b577c2f1176ccf3a62.setContent(html_a96256d4e55791501025bf791d1045f1);
#
#
#
#         marker_88d60cbdec3c0a4e9fd230d5e4a0f6bd.bindPopup(popup_3c527cce5157e1b577c2f1176ccf3a62)
#         ;
#
#
#
#
#             var marker_01c121cf5775927643bf4bde0a4f1814 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b2930b6a1ca7295362ecaf75d46547c0);
#
#
#         var popup_b209d50ef89116adb5ef31e48078fd8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d411cfce286c07409db3e711522a17da = $(`&lt;div id=&quot;html_d411cfce286c07409db3e711522a17da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b209d50ef89116adb5ef31e48078fd8d.setContent(html_d411cfce286c07409db3e711522a17da);
#
#
#
#         marker_01c121cf5775927643bf4bde0a4f1814.bindPopup(popup_b209d50ef89116adb5ef31e48078fd8d)
#         ;
#
#
#
#
#             var marker_e50d5f7c9a4a05dff046be978bb7046c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b2930b6a1ca7295362ecaf75d46547c0);
#
#
#         var popup_36c9b2dd605ecce796f80ad87b64e585 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97275509efd0d681d4922deee545acf1 = $(`&lt;div id=&quot;html_97275509efd0d681d4922deee545acf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_36c9b2dd605ecce796f80ad87b64e585.setContent(html_97275509efd0d681d4922deee545acf1);
#
#
#
#         marker_e50d5f7c9a4a05dff046be978bb7046c.bindPopup(popup_36c9b2dd605ecce796f80ad87b64e585)
#         ;
#
#
#
#
#             var marker_4cdb7381a83a50f35dcbf078f5333dad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b2930b6a1ca7295362ecaf75d46547c0);
#
#
#         var popup_d257a681092c2a6f85a305f6630bd398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5999dc52fefb8f60b391604fdb60954 = $(`&lt;div id=&quot;html_b5999dc52fefb8f60b391604fdb60954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d257a681092c2a6f85a305f6630bd398.setContent(html_b5999dc52fefb8f60b391604fdb60954);
#
#
#
#         marker_4cdb7381a83a50f35dcbf078f5333dad.bindPopup(popup_d257a681092c2a6f85a305f6630bd398)
#         ;
#
#
#
#
#             var marker_67ce938e71

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d816135009272788f16da789a03453e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d816135009272788f16da789a03453e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d816135009272788f16da789a03453e2 = L.map(
#                 &quot;map_d816135009272788f16da789a03453e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c66a59cafa6a73247ee320c361cec65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c66a59cafa6a73247ee320c361cec65.addTo(map_d816135009272788f16da789a03453e2);
#
#
#             var feature_group_c586ec18a092f15f77e3f4790309f8d4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_86a86e3fb9dac3ed9435526787866f96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c586ec18a092f15f77e3f4790309f8d4);
#
#
#         var popup_87be317685972f0a333e93ddd67146cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e53d4f382bb82a9cde6c7805ffee10a9 = $(`&lt;div id=&quot;html_e53d4f382bb82a9cde6c7805ffee10a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_87be317685972f0a333e93ddd67146cf.setContent(html_e53d4f382bb82a9cde6c7805ffee10a9);
#
#
#
#         marker_86a86e3fb9dac3ed9435526787866f96.bindPopup(popup_87be317685972f0a333e93ddd67146cf)
#         ;
#
#
#
#
#             var marker_b1c8ba5331cc87ae02ebe075c920585d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c586ec18a092f15f77e3f4790309f8d4);
#
#
#         var popup_b631e389f1a255974eab7106e34e5cd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b289eb4c443c194846f143d5faa91f5b = $(`&lt;div id=&quot;html_b289eb4c443c194846f143d5faa91f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b631e389f1a255974eab7106e34e5cd7.setContent(html_b289eb4c443c194846f143d5faa91f5b);
#
#
#
#         marker_b1c8ba5331cc87ae02ebe075c920585d.bindPopup(popup_b631e389f1a255974eab7106e34e5cd7)
#         ;
#
#
#
#
#             var marker_cc91de02548aa594158c827aba759e13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c586ec18a092f15f77e3f4790309f8d4);
#
#
#         var popup_4821da0944406ae7ce83285b40d02e6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10674a1f04d819109eaa5ac2851e635e = $(`&lt;div id=&quot;html_10674a1f04d819109eaa5ac2851e635e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4821da0944406ae7ce83285b40d02e6e.setContent(html_10674a1f04d819109eaa5ac2851e635e);
#
#
#
#         marker_cc91de02548aa594158c827aba759e13.bindPopup(popup_4821da0944406ae7ce83285b40d02e6e)
#         ;
#
#
#
#
#             var marker_5bfcb7803592dbb59c644f16e16565c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c586ec18a092f15f77e3f4790309f8d4);
#
#
#         var popup_f3b5f9146b0247c7d8ff9859cb03908b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db4d24cf4ca5d3280affd778d9c2d7ed = $(`&lt;div id=&quot;html_db4d24cf4ca5d3280affd778d9c2d7ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f3b5f9146b0247c7d8ff9859cb03908b.setContent(html_db4d24cf4ca5d3280affd778d9c2d7ed);
#
#
#
#         marker_5bfcb7803592dbb59c644f16e16565c2.bindPopup(popup_f3b5f9146b0247c7d8ff9859cb03908b)
#         ;
#
#
#
#
#             var marker_47fd5349b5260b17d64fc350f6fb007a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c586ec18a092f15f77e3f4790309f8d4);
#
#
#         var popup_43fdf9b89dbe2426414cd6466adcfc27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83b21435cb5a4e1111add8d026b7b9a7 = $(`&lt;div id=&quot;html_83b21435cb5a4e1111add8d026b7b9a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_43fdf9b89dbe242641

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c09f8888a29c9bcb1055db486f67eed5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c09f8888a29c9bcb1055db486f67eed5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c09f8888a29c9bcb1055db486f67eed5 = L.map(
#                 &quot;map_c09f8888a29c9bcb1055db486f67eed5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_958be1598e4432d7817b8f9c32b76444 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_958be1598e4432d7817b8f9c32b76444.addTo(map_c09f8888a29c9bcb1055db486f67eed5);
#
#
#             var feature_group_87edc94011d5eba15724baf3c6e44249 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_87edc94011d5eba15724baf3c6e44249.addTo(map_c09f8888a29c9bcb1055db486f67eed5);
#
#
#             var feature_group_sub_group_e8204155d93f4e555a9bd82410d9c30c = L.featureGroup.subGroup(
#                 feature_group_87edc94011d5eba15724baf3c6e44249
#             );
#
#
#             var marker_75fa54c1891cb4e5ce8e648a23242b57 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8204155d93f4e555a9bd82410d9c30c);
#
#
#         var popup_752feeebf23889e00d53bb07f5c04989 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91f95fef1090f6349274919d3eb7368a = $(`&lt;div id=&quot;html_91f95fef1090f6349274919d3eb7368a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_752feeebf23889e00d53bb07f5c04989.setContent(html_91f95fef1090f6349274919d3eb7368a);
#
#
#
#         marker_75fa54c1891cb4e5ce8e648a23242b57.bindPopup(popup_752feeebf23889e00d53bb07f5c04989)
#         ;
#
#
#
#
#             var marker_a7d7e0e89fab8174c5e1e084db9e2f81 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8204155d93f4e555a9bd82410d9c30c);
#
#
#         var popup_20b5875b613d1a34c0179d3a73b5e51e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ab9f77be0cbd707287f213efc531cfe = $(`&lt;div id=&quot;html_7ab9f77be0cbd707287f213efc531cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_20b5875b613d1a34c0179d3a73b5e51e.setContent(html_7ab9f77be0cbd707287f213efc531cfe);
#
#
#
#         marker_a7d7e0e89fab8174c5e1e084db9e2f81.bindPopup(popup_20b5875b613d1a34c0179d3a73b5e51e)
#         ;
#
#
#
#
#             var marker_4a42915174d7904ff0e780b191b03261 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8204155d93f4e555a9bd82410d9c30c);
#
#
#         var popup_6349e0b2abb38a4cefc88c47eb9d0297 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbfeface9a3cdd65114e4d7bdc7fdcea = $(`&lt;div id=&quot;html_bbfeface9a3cdd65114e4d7bdc7fdcea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6349e0b2abb38a4cefc88c47eb9d0297.setContent(html_bbfeface9a3cdd65114e4d7bdc7fdcea);
#
#
#
#         marker_4a42915174d7904ff0e780b191b03261.bindPopup(popup_6349e0b2abb38a4cefc88c47eb9d0297)
#         ;
#
#
#
#
#             var marker_6a30b729b7a088eadebc8e3a527f2b28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8204155d93f4e555a9bd82410d9c30c);
#
#
#         var popup_5953ce77d49ab8731d156775f72f8dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12f7a7fe7bdb1f82c2066e4898f02868 = $(`&lt;div id=&quot;html_12f7a7fe7bdb1f82c2066e4898f02868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5953ce77d49ab8731d156775f72f8dcb.setContent(html_12f7a7fe7bdb1f82c2066e4898f02868);
#
#
#
#         marker_6a30b729b7a088eadebc8e3a527f2b28.bindPopup(popup_5953ce77d49ab8731d156775f72f8dcb)
#         ;
#
#
#
#
#             var marker_cbb5bedc8d5a721e73014566293ff06f = L.marker(
#                 [45.050399999999996, 3.0504],
