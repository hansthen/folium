# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4171139d830912481c3f7643468a9496 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4171139d830912481c3f7643468a9496&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4171139d830912481c3f7643468a9496 = L.map(
#                 &quot;map_4171139d830912481c3f7643468a9496&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf5898b8fe1b3209cd6a88e2b41f9ad4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf5898b8fe1b3209cd6a88e2b41f9ad4.addTo(map_4171139d830912481c3f7643468a9496);
#
#
#             var marker_00545807f8608141e516c222080ed4c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4171139d830912481c3f7643468a9496);
#
#
#         var popup_f74b87b3f47bb13365d21fde2819a7a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a80fc0e1acfec792481d789bf61288c = $(`&lt;div id=&quot;html_4a80fc0e1acfec792481d789bf61288c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f74b87b3f47bb13365d21fde2819a7a9.setContent(html_4a80fc0e1acfec792481d789bf61288c);
#
#
#
#         marker_00545807f8608141e516c222080ed4c4.bindPopup(popup_f74b87b3f47bb13365d21fde2819a7a9)
#         ;
#
#
#
#
#             var marker_56c9b28a6c4975c2f5b04158c47f9cf6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4171139d830912481c3f7643468a9496);
#
#
#         var popup_ea7102bed2c88fdfe65ec7c899dc160b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06aadfa0ed9540cd368b16357f7651a9 = $(`&lt;div id=&quot;html_06aadfa0ed9540cd368b16357f7651a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ea7102bed2c88fdfe65ec7c899dc160b.setContent(html_06aadfa0ed9540cd368b16357f7651a9);
#
#
#
#         marker_56c9b28a6c4975c2f5b04158c47f9cf6.bindPopup(popup_ea7102bed2c88fdfe65ec7c899dc160b)
#         ;
#
#
#
#
#             var marker_f3bab5e278615739d0b1500c62bcf7aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4171139d830912481c3f7643468a9496);
#
#
#         var popup_09f360d4ebef1db4e2b0a3be78f7b479 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_195c69ebe90505bbb419f123a376943e = $(`&lt;div id=&quot;html_195c69ebe90505bbb419f123a376943e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_09f360d4ebef1db4e2b0a3be78f7b479.setContent(html_195c69ebe90505bbb419f123a376943e);
#
#
#
#         marker_f3bab5e278615739d0b1500c62bcf7aa.bindPopup(popup_09f360d4ebef1db4e2b0a3be78f7b479)
#         ;
#
#
#
#
#             var marker_a80f3c6dd2780b4febef25b849a682a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4171139d830912481c3f7643468a9496);
#
#
#         var popup_1639723a6743a1a3930d98165a9093e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1a5c564cbb5114e68346a9b451907d1 = $(`&lt;div id=&quot;html_a1a5c564cbb5114e68346a9b451907d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1639723a6743a1a3930d98165a9093e8.setContent(html_a1a5c564cbb5114e68346a9b451907d1);
#
#
#
#         marker_a80f3c6dd2780b4febef25b849a682a3.bindPopup(popup_1639723a6743a1a3930d98165a9093e8)
#         ;
#
#
#
#
#             var marker_02466a0daa428272dcf3add6113cc7d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4171139d830912481c3f7643468a9496);
#
#
#         var popup_276324167465fd69724b9a6dd2683582 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dcfa5dbcf61556947b9d7a224c729ea = $(`&lt;div id=&quot;html_9dcfa5dbcf61556947b9d7a224c729ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_276324167465fd69724b9a6dd2683582.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21e258c9eb497c944d593718c362ebe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21e258c9eb497c944d593718c362ebe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21e258c9eb497c944d593718c362ebe8 = L.map(
#                 &quot;map_21e258c9eb497c944d593718c362ebe8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50876a438ce7ff4dede3f5b8d0ccdea1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50876a438ce7ff4dede3f5b8d0ccdea1.addTo(map_21e258c9eb497c944d593718c362ebe8);
#
#
#             var feature_group_c7315cb1f6a82420da283cdc374fe208 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a50b9282388103c234b2e3fbfbc95804 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c7315cb1f6a82420da283cdc374fe208);
#
#
#         var popup_f15f498c9ab83edd2dc9e42c7e733a54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a053b79f20a724aa79c16ae153099b3 = $(`&lt;div id=&quot;html_7a053b79f20a724aa79c16ae153099b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f15f498c9ab83edd2dc9e42c7e733a54.setContent(html_7a053b79f20a724aa79c16ae153099b3);
#
#
#
#         marker_a50b9282388103c234b2e3fbfbc95804.bindPopup(popup_f15f498c9ab83edd2dc9e42c7e733a54)
#         ;
#
#
#
#
#             var marker_de2d7188ccc21b85b842e465dd772ef6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c7315cb1f6a82420da283cdc374fe208);
#
#
#         var popup_f67ce35e60d2a50fd85a1c28153f2f5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c78e96703336c41a1302d0181ab01e5d = $(`&lt;div id=&quot;html_c78e96703336c41a1302d0181ab01e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f67ce35e60d2a50fd85a1c28153f2f5f.setContent(html_c78e96703336c41a1302d0181ab01e5d);
#
#
#
#         marker_de2d7188ccc21b85b842e465dd772ef6.bindPopup(popup_f67ce35e60d2a50fd85a1c28153f2f5f)
#         ;
#
#
#
#
#             var marker_6fed94c699e97277daccaf84fc51367e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c7315cb1f6a82420da283cdc374fe208);
#
#
#         var popup_1860e19de26c99a33a825b39c9439f60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f83a2a9ce07f14dad4a0af56044a95b = $(`&lt;div id=&quot;html_8f83a2a9ce07f14dad4a0af56044a95b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1860e19de26c99a33a825b39c9439f60.setContent(html_8f83a2a9ce07f14dad4a0af56044a95b);
#
#
#
#         marker_6fed94c699e97277daccaf84fc51367e.bindPopup(popup_1860e19de26c99a33a825b39c9439f60)
#         ;
#
#
#
#
#             var marker_38b814bccbfa15975650dad6cb073b2d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c7315cb1f6a82420da283cdc374fe208);
#
#
#         var popup_c617c5b6aec27fb6add9f67ec3157739 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f0430b822065850b3122fdb6ee5fd5d = $(`&lt;div id=&quot;html_5f0430b822065850b3122fdb6ee5fd5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c617c5b6aec27fb6add9f67ec3157739.setContent(html_5f0430b822065850b3122fdb6ee5fd5d);
#
#
#
#         marker_38b814bccbfa15975650dad6cb073b2d.bindPopup(popup_c617c5b6aec27fb6add9f67ec3157739)
#         ;
#
#
#
#
#             var marker_44aff67116f006988f30c4ba77ea39c2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c7315cb1f6a82420da283cdc374fe208);
#
#
#         var popup_819506ce99f9db41043201f8200ea432 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_705d30c397fdcea86be248c9d250fd8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_705d30c397fdcea86be248c9d250fd8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_705d30c397fdcea86be248c9d250fd8d = L.map(
#                 &quot;map_705d30c397fdcea86be248c9d250fd8d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de069878fc61d5e930f20d6f846447f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de069878fc61d5e930f20d6f846447f9.addTo(map_705d30c397fdcea86be248c9d250fd8d);
#
#
#             var feature_group_477d4c553bb6295672c2b0768cdcb952 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_477d4c553bb6295672c2b0768cdcb952.addTo(map_705d30c397fdcea86be248c9d250fd8d);
#
#
#             var feature_group_sub_group_1ff7952f1652670438a35ad75340ca1d = L.featureGroup.subGroup(
#                 feature_group_477d4c553bb6295672c2b0768cdcb952
#             );
#
#
#             var marker_9d0070aa927824481eb6ae1291ecdbf4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ff7952f1652670438a35ad75340ca1d);
#
#
#         var popup_9e235d3757ea4f3acfe4b6fc78d8043b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c3ddc2e4b54a5d4cc676e7cb70d8fe0 = $(`&lt;div id=&quot;html_7c3ddc2e4b54a5d4cc676e7cb70d8fe0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9e235d3757ea4f3acfe4b6fc78d8043b.setContent(html_7c3ddc2e4b54a5d4cc676e7cb70d8fe0);
#
#
#
#         marker_9d0070aa927824481eb6ae1291ecdbf4.bindPopup(popup_9e235d3757ea4f3acfe4b6fc78d8043b)
#         ;
#
#
#
#
#             var marker_827f7fb9c7a2ce866a3bd479eb55faae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ff7952f1652670438a35ad75340ca1d);
#
#
#         var popup_cb6a21105a3ef86fbe03b42dc367bdf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1bc3303f6f218f8e2717be7f82c97fe = $(`&lt;div id=&quot;html_b1bc3303f6f218f8e2717be7f82c97fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cb6a21105a3ef86fbe03b42dc367bdf3.setContent(html_b1bc3303f6f218f8e2717be7f82c97fe);
#
#
#
#         marker_827f7fb9c7a2ce866a3bd479eb55faae.bindPopup(popup_cb6a21105a3ef86fbe03b42dc367bdf3)
#         ;
#
#
#
#
#             var marker_803660d607d4cc33b41ea40aa9e730d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ff7952f1652670438a35ad75340ca1d);
#
#
#         var popup_7a82a118521831f5a6ea0d78e05be6d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d68cfb94d39e557e51bbde51012a56d = $(`&lt;div id=&quot;html_5d68cfb94d39e557e51bbde51012a56d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7a82a118521831f5a6ea0d78e05be6d5.setContent(html_5d68cfb94d39e557e51bbde51012a56d);
#
#
#
#         marker_803660d607d4cc33b41ea40aa9e730d2.bindPopup(popup_7a82a118521831f5a6ea0d78e05be6d5)
#         ;
#
#
#
#
#             var marker_e0400b78bdea709ca8a6f5e65ca159b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1ff7952f1652670438a35ad75340ca1d);
#
#
#         var popup_879eafd6cacf6c9405f750518ac63ae7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5de914e65f5a2d40780ce310d5f7ef4 = $(`&lt;div id=&quot;html_e5de914e65f5a2d40780ce310d5f7ef4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_879eafd6cacf6c9405f750518ac63ae7.setContent(html_e5de914e65f5a2d40780ce310d5f7ef4);
#
#
#
#         marker_
