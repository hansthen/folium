# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5ad0b89277a3251565a8a36f4a6def7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5ad0b89277a3251565a8a36f4a6def7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5ad0b89277a3251565a8a36f4a6def7 = L.map(
#                 &quot;map_e5ad0b89277a3251565a8a36f4a6def7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5876051b6bdac0af203050e263d929ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5876051b6bdac0af203050e263d929ff.addTo(map_e5ad0b89277a3251565a8a36f4a6def7);
#
#
#             var marker_103fedcb236033a9591f78bdf9332b29 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e5ad0b89277a3251565a8a36f4a6def7);
#
#
#         var popup_91ef50cbf3da68840e420e184a34d5cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4db215c0e34486abc18a7c3594d4f34 = $(`&lt;div id=&quot;html_e4db215c0e34486abc18a7c3594d4f34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_91ef50cbf3da68840e420e184a34d5cc.setContent(html_e4db215c0e34486abc18a7c3594d4f34);
#
#
#
#         marker_103fedcb236033a9591f78bdf9332b29.bindPopup(popup_91ef50cbf3da68840e420e184a34d5cc)
#         ;
#
#
#
#
#             var marker_6f525b7f986fd9b438fd590c31de935a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e5ad0b89277a3251565a8a36f4a6def7);
#
#
#         var popup_4dc061615fbb136d8b7d524c8f429caf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_952cc32cdff24970657115cedc24f781 = $(`&lt;div id=&quot;html_952cc32cdff24970657115cedc24f781&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4dc061615fbb136d8b7d524c8f429caf.setContent(html_952cc32cdff24970657115cedc24f781);
#
#
#
#         marker_6f525b7f986fd9b438fd590c31de935a.bindPopup(popup_4dc061615fbb136d8b7d524c8f429caf)
#         ;
#
#
#
#
#             var marker_252f537d049924ac1817934d736c6943 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e5ad0b89277a3251565a8a36f4a6def7);
#
#
#         var popup_7de4ea8bb7bbd6b39fc58a98dc0ef3ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03816c1a07f55848c7acb0a978e5a761 = $(`&lt;div id=&quot;html_03816c1a07f55848c7acb0a978e5a761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7de4ea8bb7bbd6b39fc58a98dc0ef3ce.setContent(html_03816c1a07f55848c7acb0a978e5a761);
#
#
#
#         marker_252f537d049924ac1817934d736c6943.bindPopup(popup_7de4ea8bb7bbd6b39fc58a98dc0ef3ce)
#         ;
#
#
#
#
#             var marker_17cfeacf34676c8ac50aa8329128cfd8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e5ad0b89277a3251565a8a36f4a6def7);
#
#
#         var popup_29273a350959198004dfc3fdf38deefc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8378f9b9518ee20513c9427179d81d56 = $(`&lt;div id=&quot;html_8378f9b9518ee20513c9427179d81d56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_29273a350959198004dfc3fdf38deefc.setContent(html_8378f9b9518ee20513c9427179d81d56);
#
#
#
#         marker_17cfeacf34676c8ac50aa8329128cfd8.bindPopup(popup_29273a350959198004dfc3fdf38deefc)
#         ;
#
#
#
#
#             var marker_3e0e991c18d0dd4e6dc74f693dedc44c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e5ad0b89277a3251565a8a36f4a6def7);
#
#
#         var popup_7d45e4c308fbeb13b222eef7c3a72315 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_317abd3f4c306695a7900e23cfe0ee6f = $(`&lt;div id=&quot;html_317abd3f4c306695a7900e23cfe0ee6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7d45e4c308fbeb13b222eef7c3a72315.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80a394c2788d102ffb6a3b7b07494033 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80a394c2788d102ffb6a3b7b07494033&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80a394c2788d102ffb6a3b7b07494033 = L.map(
#                 &quot;map_80a394c2788d102ffb6a3b7b07494033&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49a284601618914c646085a41ce9a92b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49a284601618914c646085a41ce9a92b.addTo(map_80a394c2788d102ffb6a3b7b07494033);
#
#
#             var feature_group_96865e83261307be44d54f3233ca6c7f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fe8d8190baa2f0262783b563bc90290f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_96865e83261307be44d54f3233ca6c7f);
#
#
#         var popup_8c6d20fa9df778bb7c16ddbccc027f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74850a614c6f848b58e0a95d3310b6d8 = $(`&lt;div id=&quot;html_74850a614c6f848b58e0a95d3310b6d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8c6d20fa9df778bb7c16ddbccc027f45.setContent(html_74850a614c6f848b58e0a95d3310b6d8);
#
#
#
#         marker_fe8d8190baa2f0262783b563bc90290f.bindPopup(popup_8c6d20fa9df778bb7c16ddbccc027f45)
#         ;
#
#
#
#
#             var marker_ab1b3970ff137720ba602590149a261b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_96865e83261307be44d54f3233ca6c7f);
#
#
#         var popup_46e2aa7a87324a7ee57bda33caa4e027 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0a31b0e24c3e802f9edacf0d8178ac2 = $(`&lt;div id=&quot;html_d0a31b0e24c3e802f9edacf0d8178ac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_46e2aa7a87324a7ee57bda33caa4e027.setContent(html_d0a31b0e24c3e802f9edacf0d8178ac2);
#
#
#
#         marker_ab1b3970ff137720ba602590149a261b.bindPopup(popup_46e2aa7a87324a7ee57bda33caa4e027)
#         ;
#
#
#
#
#             var marker_40179175dc302050d9c67a64bdbc1605 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_96865e83261307be44d54f3233ca6c7f);
#
#
#         var popup_71192223e3f8981e2b9bb62bec76c397 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5043809030ee16ba6de7cfde46237ac0 = $(`&lt;div id=&quot;html_5043809030ee16ba6de7cfde46237ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_71192223e3f8981e2b9bb62bec76c397.setContent(html_5043809030ee16ba6de7cfde46237ac0);
#
#
#
#         marker_40179175dc302050d9c67a64bdbc1605.bindPopup(popup_71192223e3f8981e2b9bb62bec76c397)
#         ;
#
#
#
#
#             var marker_56466d1da8d2e2e88795238dacd54793 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_96865e83261307be44d54f3233ca6c7f);
#
#
#         var popup_24fd842154d8e805dd3a9db8ab11393c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a931c531484a7b2c28164b823399346 = $(`&lt;div id=&quot;html_3a931c531484a7b2c28164b823399346&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_24fd842154d8e805dd3a9db8ab11393c.setContent(html_3a931c531484a7b2c28164b823399346);
#
#
#
#         marker_56466d1da8d2e2e88795238dacd54793.bindPopup(popup_24fd842154d8e805dd3a9db8ab11393c)
#         ;
#
#
#
#
#             var marker_31c280fe813e77e57914593e4b6780fb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_96865e83261307be44d54f3233ca6c7f);
#
#
#         var popup_cd3012180bb2aed73ae9e38503f1fe8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d6dd9861a0effa9f71abfcb535a3567 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d6dd9861a0effa9f71abfcb535a3567&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d6dd9861a0effa9f71abfcb535a3567 = L.map(
#                 &quot;map_4d6dd9861a0effa9f71abfcb535a3567&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ba5674b410090d62b95632913f95825 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ba5674b410090d62b95632913f95825.addTo(map_4d6dd9861a0effa9f71abfcb535a3567);
#
#
#             var feature_group_6687064c6afdc234ccd816ece7ef2a95 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6687064c6afdc234ccd816ece7ef2a95.addTo(map_4d6dd9861a0effa9f71abfcb535a3567);
#
#
#             var feature_group_sub_group_a36976088ad62439c7370d48ab819c85 = L.featureGroup.subGroup(
#                 feature_group_6687064c6afdc234ccd816ece7ef2a95
#             );
#
#
#             var marker_8143f8f6b5ede3065a0e321c567e9e2b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36976088ad62439c7370d48ab819c85);
#
#
#         var popup_f0aa498a2adc2a640e79bb182fbcc84c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26d4b05822d35295024a975cc0e85203 = $(`&lt;div id=&quot;html_26d4b05822d35295024a975cc0e85203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f0aa498a2adc2a640e79bb182fbcc84c.setContent(html_26d4b05822d35295024a975cc0e85203);
#
#
#
#         marker_8143f8f6b5ede3065a0e321c567e9e2b.bindPopup(popup_f0aa498a2adc2a640e79bb182fbcc84c)
#         ;
#
#
#
#
#             var marker_539bed11add37951161a4236f48ea0b2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36976088ad62439c7370d48ab819c85);
#
#
#         var popup_3d5a10edf6829be5ccd62a734d1f2d29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6477b1efdace2e693213831d6dc66e6 = $(`&lt;div id=&quot;html_b6477b1efdace2e693213831d6dc66e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3d5a10edf6829be5ccd62a734d1f2d29.setContent(html_b6477b1efdace2e693213831d6dc66e6);
#
#
#
#         marker_539bed11add37951161a4236f48ea0b2.bindPopup(popup_3d5a10edf6829be5ccd62a734d1f2d29)
#         ;
#
#
#
#
#             var marker_e3435df1525cba4252e2cdbac3177ceb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36976088ad62439c7370d48ab819c85);
#
#
#         var popup_ded3a093bbc63304b67e0fe678593d6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31e780351614c7ad46267ae6f2a1f2a6 = $(`&lt;div id=&quot;html_31e780351614c7ad46267ae6f2a1f2a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ded3a093bbc63304b67e0fe678593d6b.setContent(html_31e780351614c7ad46267ae6f2a1f2a6);
#
#
#
#         marker_e3435df1525cba4252e2cdbac3177ceb.bindPopup(popup_ded3a093bbc63304b67e0fe678593d6b)
#         ;
#
#
#
#
#             var marker_94b51790fa956eebd3dee26a707fe15e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a36976088ad62439c7370d48ab819c85);
#
#
#         var popup_d1960a8b1f040c7b5ae0c3aaf8ee189f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4628e0d34124100df19e36453bf02bef = $(`&lt;div id=&quot;html_4628e0d34124100df19e36453bf02bef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d1960a8b1f040c7b5ae0c3aaf8ee189f.setContent(html_4628e0d34124100df19e36453bf02bef);
#
#
#
#         marker_
