# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd75e6010235a4fc87985b34f49b18ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd75e6010235a4fc87985b34f49b18ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd75e6010235a4fc87985b34f49b18ac = L.map(
#                 &quot;map_fd75e6010235a4fc87985b34f49b18ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34905ed092c1369df4554221d998ef3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34905ed092c1369df4554221d998ef3b.addTo(map_fd75e6010235a4fc87985b34f49b18ac);
#
#
#             var marker_7db62b1ba48c9799eb6ed91b878f6a42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fd75e6010235a4fc87985b34f49b18ac);
#
#
#         var popup_8ba0f97205083906b8d79cebec599f18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ac98c8157a6f400c0356dea0ba718ae = $(`&lt;div id=&quot;html_1ac98c8157a6f400c0356dea0ba718ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8ba0f97205083906b8d79cebec599f18.setContent(html_1ac98c8157a6f400c0356dea0ba718ae);
#
#
#
#         marker_7db62b1ba48c9799eb6ed91b878f6a42.bindPopup(popup_8ba0f97205083906b8d79cebec599f18)
#         ;
#
#
#
#
#             var marker_757cf568e33f110702ddc02e7fac196b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fd75e6010235a4fc87985b34f49b18ac);
#
#
#         var popup_675b1d0f8901aa1ec64cd29c405a55b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c374ba2b0f787b5fbfb0e04051deeb14 = $(`&lt;div id=&quot;html_c374ba2b0f787b5fbfb0e04051deeb14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_675b1d0f8901aa1ec64cd29c405a55b3.setContent(html_c374ba2b0f787b5fbfb0e04051deeb14);
#
#
#
#         marker_757cf568e33f110702ddc02e7fac196b.bindPopup(popup_675b1d0f8901aa1ec64cd29c405a55b3)
#         ;
#
#
#
#
#             var marker_f98e235ecd6c0a2a54d5a5cb51e958f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fd75e6010235a4fc87985b34f49b18ac);
#
#
#         var popup_4c59bc05cf52d33bbf36796da3ed5e88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13b17d7f94ba4b8042294550fc28e644 = $(`&lt;div id=&quot;html_13b17d7f94ba4b8042294550fc28e644&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4c59bc05cf52d33bbf36796da3ed5e88.setContent(html_13b17d7f94ba4b8042294550fc28e644);
#
#
#
#         marker_f98e235ecd6c0a2a54d5a5cb51e958f2.bindPopup(popup_4c59bc05cf52d33bbf36796da3ed5e88)
#         ;
#
#
#
#
#             var marker_10354fa14958e18f88cacab09c6ea9a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fd75e6010235a4fc87985b34f49b18ac);
#
#
#         var popup_313a0e949f0ea903bea10f78843da219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c64d7296f66f522f413e81312ad8d123 = $(`&lt;div id=&quot;html_c64d7296f66f522f413e81312ad8d123&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_313a0e949f0ea903bea10f78843da219.setContent(html_c64d7296f66f522f413e81312ad8d123);
#
#
#
#         marker_10354fa14958e18f88cacab09c6ea9a3.bindPopup(popup_313a0e949f0ea903bea10f78843da219)
#         ;
#
#
#
#
#             var marker_73733c398a96077f4f1c832f567d6914 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fd75e6010235a4fc87985b34f49b18ac);
#
#
#         var popup_26f54d0f3bc4fb653b57881e79ecf6ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_546a1701aa451efe8662d984f3b86b28 = $(`&lt;div id=&quot;html_546a1701aa451efe8662d984f3b86b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_26f54d0f3bc4fb653b57881e79ecf6ed.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b05084934c527572b8d5bb204619dc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b05084934c527572b8d5bb204619dc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b05084934c527572b8d5bb204619dc4 = L.map(
#                 &quot;map_6b05084934c527572b8d5bb204619dc4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31d4335c0bdf49645afc7dc6ffd7b689 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31d4335c0bdf49645afc7dc6ffd7b689.addTo(map_6b05084934c527572b8d5bb204619dc4);
#
#
#             var feature_group_9e04610e8172b4f6675cc108a1d7935a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_980a360bea1208a5096e30789fd83128 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9e04610e8172b4f6675cc108a1d7935a);
#
#
#         var popup_3e4a5187ed9f21a4e34ab640eac8d210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e484f601e9f63d752c1ad3148e9020 = $(`&lt;div id=&quot;html_d0e484f601e9f63d752c1ad3148e9020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3e4a5187ed9f21a4e34ab640eac8d210.setContent(html_d0e484f601e9f63d752c1ad3148e9020);
#
#
#
#         marker_980a360bea1208a5096e30789fd83128.bindPopup(popup_3e4a5187ed9f21a4e34ab640eac8d210)
#         ;
#
#
#
#
#             var marker_6510fb483ee784e21d04f974669b7c75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9e04610e8172b4f6675cc108a1d7935a);
#
#
#         var popup_d7316b00c28018b477044b8b57305359 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_084d9dcf3c49ec83bbd45c9f9df6729b = $(`&lt;div id=&quot;html_084d9dcf3c49ec83bbd45c9f9df6729b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d7316b00c28018b477044b8b57305359.setContent(html_084d9dcf3c49ec83bbd45c9f9df6729b);
#
#
#
#         marker_6510fb483ee784e21d04f974669b7c75.bindPopup(popup_d7316b00c28018b477044b8b57305359)
#         ;
#
#
#
#
#             var marker_be5cbc3ad946d094f396d87142298c57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9e04610e8172b4f6675cc108a1d7935a);
#
#
#         var popup_88b766ce5720504b61c0ac8c4ed95398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bd59f1d8397c24103163cccda1137cc = $(`&lt;div id=&quot;html_6bd59f1d8397c24103163cccda1137cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_88b766ce5720504b61c0ac8c4ed95398.setContent(html_6bd59f1d8397c24103163cccda1137cc);
#
#
#
#         marker_be5cbc3ad946d094f396d87142298c57.bindPopup(popup_88b766ce5720504b61c0ac8c4ed95398)
#         ;
#
#
#
#
#             var marker_5061475afe02200ff4400ad56856f889 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9e04610e8172b4f6675cc108a1d7935a);
#
#
#         var popup_c9f941a8b6a0232d50481b212da86771 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db27eb535762e6b04e0b883c3028c4d4 = $(`&lt;div id=&quot;html_db27eb535762e6b04e0b883c3028c4d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c9f941a8b6a0232d50481b212da86771.setContent(html_db27eb535762e6b04e0b883c3028c4d4);
#
#
#
#         marker_5061475afe02200ff4400ad56856f889.bindPopup(popup_c9f941a8b6a0232d50481b212da86771)
#         ;
#
#
#
#
#             var marker_036080f4a24170aaea93939629a6a613 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9e04610e8172b4f6675cc108a1d7935a);
#
#
#         var popup_6b649067b2512c94c9ae575309b6dc69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_adb390d3e4ab5cdd9d49e02ef9af6284 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_adb390d3e4ab5cdd9d49e02ef9af6284&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_adb390d3e4ab5cdd9d49e02ef9af6284 = L.map(
#                 &quot;map_adb390d3e4ab5cdd9d49e02ef9af6284&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c5544510b8f851694f80ff5cde4fa29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c5544510b8f851694f80ff5cde4fa29.addTo(map_adb390d3e4ab5cdd9d49e02ef9af6284);
#
#
#             var feature_group_daa85681df7e6ce6d86ea0d6b0d0a38e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_daa85681df7e6ce6d86ea0d6b0d0a38e.addTo(map_adb390d3e4ab5cdd9d49e02ef9af6284);
#
#
#             var feature_group_sub_group_d107fe5d4f87bbadbf725f99839e771e = L.featureGroup.subGroup(
#                 feature_group_daa85681df7e6ce6d86ea0d6b0d0a38e
#             );
#
#
#             var marker_317f2e75c5ccafc9aa3537236f7533df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d107fe5d4f87bbadbf725f99839e771e);
#
#
#         var popup_81bd6c0c161b22756f9de718b0ecafd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daf6cbaddb16241bc2a62ccc198e6a95 = $(`&lt;div id=&quot;html_daf6cbaddb16241bc2a62ccc198e6a95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_81bd6c0c161b22756f9de718b0ecafd5.setContent(html_daf6cbaddb16241bc2a62ccc198e6a95);
#
#
#
#         marker_317f2e75c5ccafc9aa3537236f7533df.bindPopup(popup_81bd6c0c161b22756f9de718b0ecafd5)
#         ;
#
#
#
#
#             var marker_a0ddc6c09709ce1a8d1f9c648ce41283 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d107fe5d4f87bbadbf725f99839e771e);
#
#
#         var popup_92ac4f7d467f93e723119bfe81ccbe2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_094ad8b1baadabba05fbcb2a2337dfba = $(`&lt;div id=&quot;html_094ad8b1baadabba05fbcb2a2337dfba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_92ac4f7d467f93e723119bfe81ccbe2b.setContent(html_094ad8b1baadabba05fbcb2a2337dfba);
#
#
#
#         marker_a0ddc6c09709ce1a8d1f9c648ce41283.bindPopup(popup_92ac4f7d467f93e723119bfe81ccbe2b)
#         ;
#
#
#
#
#             var marker_abb7ab51780ce9389877de4367a28bfa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d107fe5d4f87bbadbf725f99839e771e);
#
#
#         var popup_f8b09bc5a6f8d6134a02b22340801ba1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecfea73f63700e2216a36db877fb3d0e = $(`&lt;div id=&quot;html_ecfea73f63700e2216a36db877fb3d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f8b09bc5a6f8d6134a02b22340801ba1.setContent(html_ecfea73f63700e2216a36db877fb3d0e);
#
#
#
#         marker_abb7ab51780ce9389877de4367a28bfa.bindPopup(popup_f8b09bc5a6f8d6134a02b22340801ba1)
#         ;
#
#
#
#
#             var marker_b566ee8db241e20d2963a2dab8e22264 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d107fe5d4f87bbadbf725f99839e771e);
#
#
#         var popup_114575d65d5632c11f480910a043c5b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_572ec2a6c59e94c16eb08abd383032a7 = $(`&lt;div id=&quot;html_572ec2a6c59e94c16eb08abd383032a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_114575d65d5632c11f480910a043c5b6.setContent(html_572ec2a6c59e94c16eb08abd383032a7);
#
#
#
#         marker_
