# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06ae56abee92f31157f6f41fab410568 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06ae56abee92f31157f6f41fab410568&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06ae56abee92f31157f6f41fab410568 = L.map(
#                 &quot;map_06ae56abee92f31157f6f41fab410568&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e014b3ac140317b9623c88b7dad470ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e014b3ac140317b9623c88b7dad470ea.addTo(map_06ae56abee92f31157f6f41fab410568);
#
#
#             var marker_a8439dd80db37f4729f78a2d33cf2648 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_06ae56abee92f31157f6f41fab410568);
#
#
#         var popup_86b68df0155392a98b825ee69c56cd9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fd8e44d48d88cc2b171052529a43215 = $(`&lt;div id=&quot;html_8fd8e44d48d88cc2b171052529a43215&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_86b68df0155392a98b825ee69c56cd9a.setContent(html_8fd8e44d48d88cc2b171052529a43215);
#
#
#
#         marker_a8439dd80db37f4729f78a2d33cf2648.bindPopup(popup_86b68df0155392a98b825ee69c56cd9a)
#         ;
#
#
#
#
#             var marker_fe27a49b8bd4821d705b1f43c679c6b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_06ae56abee92f31157f6f41fab410568);
#
#
#         var popup_59fab4186540fcdaedd7763936ff1f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c82a629418682b257b80ccaee48368da = $(`&lt;div id=&quot;html_c82a629418682b257b80ccaee48368da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_59fab4186540fcdaedd7763936ff1f45.setContent(html_c82a629418682b257b80ccaee48368da);
#
#
#
#         marker_fe27a49b8bd4821d705b1f43c679c6b7.bindPopup(popup_59fab4186540fcdaedd7763936ff1f45)
#         ;
#
#
#
#
#             var marker_a44dbde68bcc0ec4e583001af68304f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_06ae56abee92f31157f6f41fab410568);
#
#
#         var popup_9fbe1a225d67b037b1245b9b25daff95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f726a229d8cd15a021cc3648be30bc4 = $(`&lt;div id=&quot;html_9f726a229d8cd15a021cc3648be30bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9fbe1a225d67b037b1245b9b25daff95.setContent(html_9f726a229d8cd15a021cc3648be30bc4);
#
#
#
#         marker_a44dbde68bcc0ec4e583001af68304f6.bindPopup(popup_9fbe1a225d67b037b1245b9b25daff95)
#         ;
#
#
#
#
#             var marker_aa0692b0d820cf42daec01874a7a7509 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_06ae56abee92f31157f6f41fab410568);
#
#
#         var popup_9aa547774d568a213f4fc538fbae267a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4446ca0b39b1195d059585d7605a2d05 = $(`&lt;div id=&quot;html_4446ca0b39b1195d059585d7605a2d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9aa547774d568a213f4fc538fbae267a.setContent(html_4446ca0b39b1195d059585d7605a2d05);
#
#
#
#         marker_aa0692b0d820cf42daec01874a7a7509.bindPopup(popup_9aa547774d568a213f4fc538fbae267a)
#         ;
#
#
#
#
#             var marker_f2b027ad2458713038ff4426f3549495 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_06ae56abee92f31157f6f41fab410568);
#
#
#         var popup_1cdc3052a5c135516412328eb814e121 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84bb9d4275e8c5407af41d3b520e79d5 = $(`&lt;div id=&quot;html_84bb9d4275e8c5407af41d3b520e79d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1cdc3052a5c135516412328eb814e121.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2af7ccfb6177ffe2fabf7590923339b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2af7ccfb6177ffe2fabf7590923339b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2af7ccfb6177ffe2fabf7590923339b = L.map(
#                 &quot;map_e2af7ccfb6177ffe2fabf7590923339b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02574cbd5e7ddafd3b1a8ebe85a114d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02574cbd5e7ddafd3b1a8ebe85a114d8.addTo(map_e2af7ccfb6177ffe2fabf7590923339b);
#
#
#             var feature_group_4bd2bb1f59f4cc67a2d8b44b712cb99d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ec4594728ff34e1e9a64a539d7cefb22 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4bd2bb1f59f4cc67a2d8b44b712cb99d);
#
#
#         var popup_4a831f74f5ff97e4d372622caa7d1fac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf56b23540e269f81b4188f1b1d9a0c4 = $(`&lt;div id=&quot;html_bf56b23540e269f81b4188f1b1d9a0c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4a831f74f5ff97e4d372622caa7d1fac.setContent(html_bf56b23540e269f81b4188f1b1d9a0c4);
#
#
#
#         marker_ec4594728ff34e1e9a64a539d7cefb22.bindPopup(popup_4a831f74f5ff97e4d372622caa7d1fac)
#         ;
#
#
#
#
#             var marker_950b700aafc6b563c98c09a85a060cbf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4bd2bb1f59f4cc67a2d8b44b712cb99d);
#
#
#         var popup_0f67913a4bf8da93a22974f3ae8509e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cf9cdaf068db0c7fab0c5caa59c86a0 = $(`&lt;div id=&quot;html_6cf9cdaf068db0c7fab0c5caa59c86a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0f67913a4bf8da93a22974f3ae8509e0.setContent(html_6cf9cdaf068db0c7fab0c5caa59c86a0);
#
#
#
#         marker_950b700aafc6b563c98c09a85a060cbf.bindPopup(popup_0f67913a4bf8da93a22974f3ae8509e0)
#         ;
#
#
#
#
#             var marker_67fac28b39a9bd40d5f8c10085d5c3a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4bd2bb1f59f4cc67a2d8b44b712cb99d);
#
#
#         var popup_1cf25fef81a68d040a87e5e1c3b6b32b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e66e854c3368f97ea90e537f74d746c = $(`&lt;div id=&quot;html_1e66e854c3368f97ea90e537f74d746c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1cf25fef81a68d040a87e5e1c3b6b32b.setContent(html_1e66e854c3368f97ea90e537f74d746c);
#
#
#
#         marker_67fac28b39a9bd40d5f8c10085d5c3a2.bindPopup(popup_1cf25fef81a68d040a87e5e1c3b6b32b)
#         ;
#
#
#
#
#             var marker_e56505f1f508d5af8f144e639ef0c063 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4bd2bb1f59f4cc67a2d8b44b712cb99d);
#
#
#         var popup_d10da56d3a000312ce5ee735152a0863 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bac42181dada6213fbb6b88849f3a53c = $(`&lt;div id=&quot;html_bac42181dada6213fbb6b88849f3a53c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d10da56d3a000312ce5ee735152a0863.setContent(html_bac42181dada6213fbb6b88849f3a53c);
#
#
#
#         marker_e56505f1f508d5af8f144e639ef0c063.bindPopup(popup_d10da56d3a000312ce5ee735152a0863)
#         ;
#
#
#
#
#             var marker_23d016cc9e82e16f853000d739255ff6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4bd2bb1f59f4cc67a2d8b44b712cb99d);
#
#
#         var popup_4fca4562bac4798a7b286b2dccbca746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_754fbc00fd8a34cac3e6dd60320772bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_754fbc00fd8a34cac3e6dd60320772bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_754fbc00fd8a34cac3e6dd60320772bc = L.map(
#                 &quot;map_754fbc00fd8a34cac3e6dd60320772bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8acb82c2689a2fac5064f0750e40142 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8acb82c2689a2fac5064f0750e40142.addTo(map_754fbc00fd8a34cac3e6dd60320772bc);
#
#
#             var feature_group_abdb81a5f4ed5a4e9b8a1a89d333380c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_abdb81a5f4ed5a4e9b8a1a89d333380c.addTo(map_754fbc00fd8a34cac3e6dd60320772bc);
#
#
#             var feature_group_sub_group_2270c3794bc9554f9c09a5a01d8e944c = L.featureGroup.subGroup(
#                 feature_group_abdb81a5f4ed5a4e9b8a1a89d333380c
#             );
#
#
#             var marker_16eef343aac0a00a1b83873662b95ce1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2270c3794bc9554f9c09a5a01d8e944c);
#
#
#         var popup_fe1c1c8158e6166884d66b3459b7f1fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2a419412c4ba0443718065c081301a0 = $(`&lt;div id=&quot;html_c2a419412c4ba0443718065c081301a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fe1c1c8158e6166884d66b3459b7f1fa.setContent(html_c2a419412c4ba0443718065c081301a0);
#
#
#
#         marker_16eef343aac0a00a1b83873662b95ce1.bindPopup(popup_fe1c1c8158e6166884d66b3459b7f1fa)
#         ;
#
#
#
#
#             var marker_3a9f564de385fa1a702d03afbf8c2ba6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2270c3794bc9554f9c09a5a01d8e944c);
#
#
#         var popup_19e4d2b3d8beb98760c0400800701d92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8f3b95676312ec5ed60c4e1cfb74f8f = $(`&lt;div id=&quot;html_e8f3b95676312ec5ed60c4e1cfb74f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_19e4d2b3d8beb98760c0400800701d92.setContent(html_e8f3b95676312ec5ed60c4e1cfb74f8f);
#
#
#
#         marker_3a9f564de385fa1a702d03afbf8c2ba6.bindPopup(popup_19e4d2b3d8beb98760c0400800701d92)
#         ;
#
#
#
#
#             var marker_a03142e2d4f37c4e337c5721aaa37665 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2270c3794bc9554f9c09a5a01d8e944c);
#
#
#         var popup_7f5ecfa880f272fe3435c85afeca2b60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bd6ea00836f57513ab80ade00cd2bbf = $(`&lt;div id=&quot;html_5bd6ea00836f57513ab80ade00cd2bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7f5ecfa880f272fe3435c85afeca2b60.setContent(html_5bd6ea00836f57513ab80ade00cd2bbf);
#
#
#
#         marker_a03142e2d4f37c4e337c5721aaa37665.bindPopup(popup_7f5ecfa880f272fe3435c85afeca2b60)
#         ;
#
#
#
#
#             var marker_d468cfa44cc14b5a80a48456d1cec8ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2270c3794bc9554f9c09a5a01d8e944c);
#
#
#         var popup_7dfe84493b5b1275feda548db7abdd49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_349633ad9dda3a920f18771632c76893 = $(`&lt;div id=&quot;html_349633ad9dda3a920f18771632c76893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7dfe84493b5b1275feda548db7abdd49.setContent(html_349633ad9dda3a920f18771632c76893);
#
#
#
#         marker_
