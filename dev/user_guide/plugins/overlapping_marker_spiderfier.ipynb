# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dad1aa81fd2235872f48503f83bb1495 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dad1aa81fd2235872f48503f83bb1495&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dad1aa81fd2235872f48503f83bb1495 = L.map(
#                 &quot;map_dad1aa81fd2235872f48503f83bb1495&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c700ae7cbf0c930c408d9c8fecf3cea6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c700ae7cbf0c930c408d9c8fecf3cea6.addTo(map_dad1aa81fd2235872f48503f83bb1495);
#
#
#             var marker_24a886f812c1654fee8092fcfb02ebf8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dad1aa81fd2235872f48503f83bb1495);
#
#
#         var popup_b273826d867f70ae5ae02c7d7fb64b63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02432af4818d58f19247631cc966467a = $(`&lt;div id=&quot;html_02432af4818d58f19247631cc966467a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b273826d867f70ae5ae02c7d7fb64b63.setContent(html_02432af4818d58f19247631cc966467a);
#
#
#
#         marker_24a886f812c1654fee8092fcfb02ebf8.bindPopup(popup_b273826d867f70ae5ae02c7d7fb64b63)
#         ;
#
#
#
#
#             var marker_cf140fc8e86bb8b788ff37230d46bf9e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dad1aa81fd2235872f48503f83bb1495);
#
#
#         var popup_41a2cd3a8d7bf83af27dae7ed4759fb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4b61e082772172c246dd35d4da8900d = $(`&lt;div id=&quot;html_f4b61e082772172c246dd35d4da8900d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_41a2cd3a8d7bf83af27dae7ed4759fb8.setContent(html_f4b61e082772172c246dd35d4da8900d);
#
#
#
#         marker_cf140fc8e86bb8b788ff37230d46bf9e.bindPopup(popup_41a2cd3a8d7bf83af27dae7ed4759fb8)
#         ;
#
#
#
#
#             var marker_b3e96d85686ff6384552c4c248284f29 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dad1aa81fd2235872f48503f83bb1495);
#
#
#         var popup_71d9412c884965e74e2f333aa3cc5f21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e09b9b196050113b34ee4685d7f5ddfd = $(`&lt;div id=&quot;html_e09b9b196050113b34ee4685d7f5ddfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_71d9412c884965e74e2f333aa3cc5f21.setContent(html_e09b9b196050113b34ee4685d7f5ddfd);
#
#
#
#         marker_b3e96d85686ff6384552c4c248284f29.bindPopup(popup_71d9412c884965e74e2f333aa3cc5f21)
#         ;
#
#
#
#
#             var marker_2cb7949a25ce9a4dd1a0c269751756c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dad1aa81fd2235872f48503f83bb1495);
#
#
#         var popup_32affce17acec672d6f066fa2c8afe79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae7b069a3b7a1ed287bda8b317619d3c = $(`&lt;div id=&quot;html_ae7b069a3b7a1ed287bda8b317619d3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_32affce17acec672d6f066fa2c8afe79.setContent(html_ae7b069a3b7a1ed287bda8b317619d3c);
#
#
#
#         marker_2cb7949a25ce9a4dd1a0c269751756c8.bindPopup(popup_32affce17acec672d6f066fa2c8afe79)
#         ;
#
#
#
#
#             var marker_9bb4abbfc76ff12512ae732f1cedc830 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dad1aa81fd2235872f48503f83bb1495);
#
#
#         var popup_1082821d2bbb281440c7447d0702d696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_085566383d0e5345b3b3926d6dfb5cc8 = $(`&lt;div id=&quot;html_085566383d0e5345b3b3926d6dfb5cc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1082821d2bbb281440c7447d0702d696.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6243a53278b4a223e36fe4efe719e16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6243a53278b4a223e36fe4efe719e16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6243a53278b4a223e36fe4efe719e16 = L.map(
#                 &quot;map_b6243a53278b4a223e36fe4efe719e16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81fcf6d1bd305da8959604f825588b05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81fcf6d1bd305da8959604f825588b05.addTo(map_b6243a53278b4a223e36fe4efe719e16);
#
#
#             var feature_group_cbfe59ac3e957face93e38fd769471bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5a469454acfa476a02d1dafe14e2a97 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cbfe59ac3e957face93e38fd769471bd);
#
#
#         var popup_ed5cc8e12b24a89119a76f57c489ef7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d159cdd6092add805f40708d88fe103 = $(`&lt;div id=&quot;html_3d159cdd6092add805f40708d88fe103&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ed5cc8e12b24a89119a76f57c489ef7c.setContent(html_3d159cdd6092add805f40708d88fe103);
#
#
#
#         marker_d5a469454acfa476a02d1dafe14e2a97.bindPopup(popup_ed5cc8e12b24a89119a76f57c489ef7c)
#         ;
#
#
#
#
#             var marker_53573d236cb2d88198671644473bcb20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cbfe59ac3e957face93e38fd769471bd);
#
#
#         var popup_4ee430e54e7fce8cbe21e1357bdf8938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c91e0da7619fb41282f0ca046daa4a54 = $(`&lt;div id=&quot;html_c91e0da7619fb41282f0ca046daa4a54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4ee430e54e7fce8cbe21e1357bdf8938.setContent(html_c91e0da7619fb41282f0ca046daa4a54);
#
#
#
#         marker_53573d236cb2d88198671644473bcb20.bindPopup(popup_4ee430e54e7fce8cbe21e1357bdf8938)
#         ;
#
#
#
#
#             var marker_9ffa5390232887c396aeb4461b786ede = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cbfe59ac3e957face93e38fd769471bd);
#
#
#         var popup_ae706b1781b29d90dbfc8120121b32ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4393a961313b720f7266d4f936be6b4 = $(`&lt;div id=&quot;html_e4393a961313b720f7266d4f936be6b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ae706b1781b29d90dbfc8120121b32ac.setContent(html_e4393a961313b720f7266d4f936be6b4);
#
#
#
#         marker_9ffa5390232887c396aeb4461b786ede.bindPopup(popup_ae706b1781b29d90dbfc8120121b32ac)
#         ;
#
#
#
#
#             var marker_93d744479d5b36f8cddbf5a9ea23e4fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cbfe59ac3e957face93e38fd769471bd);
#
#
#         var popup_fb55019c2d5ff03db7ddee8039197d8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ae73184c481bcbd639a07030a8681bd = $(`&lt;div id=&quot;html_5ae73184c481bcbd639a07030a8681bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fb55019c2d5ff03db7ddee8039197d8d.setContent(html_5ae73184c481bcbd639a07030a8681bd);
#
#
#
#         marker_93d744479d5b36f8cddbf5a9ea23e4fe.bindPopup(popup_fb55019c2d5ff03db7ddee8039197d8d)
#         ;
#
#
#
#
#             var marker_769d175f1e8ee7ee7106c841ae771b8f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cbfe59ac3e957face93e38fd769471bd);
#
#
#         var popup_5a4bab3bde819852f98e6034bde8ab76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bca49b67b7fc0b2d96287fa11c0a0fd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bca49b67b7fc0b2d96287fa11c0a0fd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bca49b67b7fc0b2d96287fa11c0a0fd6 = L.map(
#                 &quot;map_bca49b67b7fc0b2d96287fa11c0a0fd6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47dd89b7901ed69e013af42d46d7a9ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_47dd89b7901ed69e013af42d46d7a9ea.addTo(map_bca49b67b7fc0b2d96287fa11c0a0fd6);
#
#
#             var feature_group_3707e59440e70bb6a982101e93efccb7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3707e59440e70bb6a982101e93efccb7.addTo(map_bca49b67b7fc0b2d96287fa11c0a0fd6);
#
#
#             var feature_group_sub_group_ed9a2137748cf6c39ecd76417f53e0c5 = L.featureGroup.subGroup(
#                 feature_group_3707e59440e70bb6a982101e93efccb7
#             );
#
#
#             var marker_d0b046c66f8a9294c09cbfd5eb14d939 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed9a2137748cf6c39ecd76417f53e0c5);
#
#
#         var popup_9f5ad9b19bab5a4e346224d485a2be9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f29b0501e17ace8ba083ab48928c23 = $(`&lt;div id=&quot;html_01f29b0501e17ace8ba083ab48928c23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9f5ad9b19bab5a4e346224d485a2be9b.setContent(html_01f29b0501e17ace8ba083ab48928c23);
#
#
#
#         marker_d0b046c66f8a9294c09cbfd5eb14d939.bindPopup(popup_9f5ad9b19bab5a4e346224d485a2be9b)
#         ;
#
#
#
#
#             var marker_d44b1b7e6e6920e59f2a802be99c4473 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed9a2137748cf6c39ecd76417f53e0c5);
#
#
#         var popup_a22bb77a71fd6c06d0e516c843a07a83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c25fd0612812505f462bd7bb3d58e60c = $(`&lt;div id=&quot;html_c25fd0612812505f462bd7bb3d58e60c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a22bb77a71fd6c06d0e516c843a07a83.setContent(html_c25fd0612812505f462bd7bb3d58e60c);
#
#
#
#         marker_d44b1b7e6e6920e59f2a802be99c4473.bindPopup(popup_a22bb77a71fd6c06d0e516c843a07a83)
#         ;
#
#
#
#
#             var marker_bf1e9f2da12f1047713c0e9080efa9bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed9a2137748cf6c39ecd76417f53e0c5);
#
#
#         var popup_062cabb5ab71eaf4a43fdc9309497a0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0807d058690897b0d594e04ea47ba77d = $(`&lt;div id=&quot;html_0807d058690897b0d594e04ea47ba77d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_062cabb5ab71eaf4a43fdc9309497a0c.setContent(html_0807d058690897b0d594e04ea47ba77d);
#
#
#
#         marker_bf1e9f2da12f1047713c0e9080efa9bc.bindPopup(popup_062cabb5ab71eaf4a43fdc9309497a0c)
#         ;
#
#
#
#
#             var marker_32371450772984c61660d31ecea8c80e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed9a2137748cf6c39ecd76417f53e0c5);
#
#
#         var popup_afb0f0f25215478ed2d3550abd93eb5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_099097d5b626d06c2ab59241066e51ea = $(`&lt;div id=&quot;html_099097d5b626d06c2ab59241066e51ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_afb0f0f25215478ed2d3550abd93eb5a.setContent(html_099097d5b626d06c2ab59241066e51ea);
#
#
#
#         marker_
