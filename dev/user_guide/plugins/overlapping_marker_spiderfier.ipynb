# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_151a172df6055d2b57864e5a1bdee265 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_151a172df6055d2b57864e5a1bdee265&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_151a172df6055d2b57864e5a1bdee265 = L.map(
#                 &quot;map_151a172df6055d2b57864e5a1bdee265&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cd9649506f80eb1177f69f846406450 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cd9649506f80eb1177f69f846406450.addTo(map_151a172df6055d2b57864e5a1bdee265);
#
#
#             var marker_10545135edab000d423af281b03f3430 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_151a172df6055d2b57864e5a1bdee265);
#
#
#         var popup_95dff1a9d746b3f7c19d151dcbad1461 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc46906c850b8adcc63d8deac24da50c = $(`&lt;div id=&quot;html_fc46906c850b8adcc63d8deac24da50c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_95dff1a9d746b3f7c19d151dcbad1461.setContent(html_fc46906c850b8adcc63d8deac24da50c);
#
#
#
#         marker_10545135edab000d423af281b03f3430.bindPopup(popup_95dff1a9d746b3f7c19d151dcbad1461)
#         ;
#
#
#
#
#             var marker_49ba0849644b9a9b72996e5f1f4746ba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_151a172df6055d2b57864e5a1bdee265);
#
#
#         var popup_985180d7ff3299b37373cecba3faccad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d28be18faaae2b6e989fc66298ae5e2 = $(`&lt;div id=&quot;html_7d28be18faaae2b6e989fc66298ae5e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_985180d7ff3299b37373cecba3faccad.setContent(html_7d28be18faaae2b6e989fc66298ae5e2);
#
#
#
#         marker_49ba0849644b9a9b72996e5f1f4746ba.bindPopup(popup_985180d7ff3299b37373cecba3faccad)
#         ;
#
#
#
#
#             var marker_da2888c7b113b495174bdfe8204f5d04 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_151a172df6055d2b57864e5a1bdee265);
#
#
#         var popup_00837faaff2a9c33e7728ef069cc45a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d54a7df1f5530e7bd14c9815dc21de94 = $(`&lt;div id=&quot;html_d54a7df1f5530e7bd14c9815dc21de94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_00837faaff2a9c33e7728ef069cc45a9.setContent(html_d54a7df1f5530e7bd14c9815dc21de94);
#
#
#
#         marker_da2888c7b113b495174bdfe8204f5d04.bindPopup(popup_00837faaff2a9c33e7728ef069cc45a9)
#         ;
#
#
#
#
#             var marker_4ba8bd45715bad93a468b149400c13c3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_151a172df6055d2b57864e5a1bdee265);
#
#
#         var popup_8fd2c87f38fc1c01eb4e4afcf96b40c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac7c3cfb141baf5806c5123df6ada351 = $(`&lt;div id=&quot;html_ac7c3cfb141baf5806c5123df6ada351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8fd2c87f38fc1c01eb4e4afcf96b40c1.setContent(html_ac7c3cfb141baf5806c5123df6ada351);
#
#
#
#         marker_4ba8bd45715bad93a468b149400c13c3.bindPopup(popup_8fd2c87f38fc1c01eb4e4afcf96b40c1)
#         ;
#
#
#
#
#             var marker_f5c553e20aee4b73a35d14a250781e47 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_151a172df6055d2b57864e5a1bdee265);
#
#
#         var popup_aa066b3a8e02594f7fb4631e4e75eb4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad927e1792c19c8669766e66983f4e3f = $(`&lt;div id=&quot;html_ad927e1792c19c8669766e66983f4e3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa066b3a8e02594f7fb4631e4e75eb4b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b3a9bff1145ddb983d369449cd40250 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b3a9bff1145ddb983d369449cd40250&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b3a9bff1145ddb983d369449cd40250 = L.map(
#                 &quot;map_2b3a9bff1145ddb983d369449cd40250&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a079eb74b4075a3ba4548999f5ffeae8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a079eb74b4075a3ba4548999f5ffeae8.addTo(map_2b3a9bff1145ddb983d369449cd40250);
#
#
#             var feature_group_e9a4d63ab0fcebcb8354fc54bfc5f1c5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0ac397704c1290c0a98281e87fd8a6b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e9a4d63ab0fcebcb8354fc54bfc5f1c5);
#
#
#         var popup_9e544cba20ac5787941a5481526a2c12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dd8d6e32b3af3761271f470d94ab14f = $(`&lt;div id=&quot;html_8dd8d6e32b3af3761271f470d94ab14f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9e544cba20ac5787941a5481526a2c12.setContent(html_8dd8d6e32b3af3761271f470d94ab14f);
#
#
#
#         marker_0ac397704c1290c0a98281e87fd8a6b4.bindPopup(popup_9e544cba20ac5787941a5481526a2c12)
#         ;
#
#
#
#
#             var marker_ca37332da2f376e95460c63ac6415236 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e9a4d63ab0fcebcb8354fc54bfc5f1c5);
#
#
#         var popup_9c624f71358a72930ef0674b23395330 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d03f14eeab1b2122756d716059e3ac8c = $(`&lt;div id=&quot;html_d03f14eeab1b2122756d716059e3ac8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9c624f71358a72930ef0674b23395330.setContent(html_d03f14eeab1b2122756d716059e3ac8c);
#
#
#
#         marker_ca37332da2f376e95460c63ac6415236.bindPopup(popup_9c624f71358a72930ef0674b23395330)
#         ;
#
#
#
#
#             var marker_299ab9b25358ef5b6c2ad28c8699b791 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e9a4d63ab0fcebcb8354fc54bfc5f1c5);
#
#
#         var popup_ad42bf60c76e102135755a7e4c254e9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ccf6f030c6cded8def66d44368efd55 = $(`&lt;div id=&quot;html_1ccf6f030c6cded8def66d44368efd55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ad42bf60c76e102135755a7e4c254e9b.setContent(html_1ccf6f030c6cded8def66d44368efd55);
#
#
#
#         marker_299ab9b25358ef5b6c2ad28c8699b791.bindPopup(popup_ad42bf60c76e102135755a7e4c254e9b)
#         ;
#
#
#
#
#             var marker_4b7fe34bffd98cd27abb8976cc0abf4c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e9a4d63ab0fcebcb8354fc54bfc5f1c5);
#
#
#         var popup_747318533b030354ef56d73b70c5da63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50dbd10fe8caf916a8a7eb4bf1d01573 = $(`&lt;div id=&quot;html_50dbd10fe8caf916a8a7eb4bf1d01573&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_747318533b030354ef56d73b70c5da63.setContent(html_50dbd10fe8caf916a8a7eb4bf1d01573);
#
#
#
#         marker_4b7fe34bffd98cd27abb8976cc0abf4c.bindPopup(popup_747318533b030354ef56d73b70c5da63)
#         ;
#
#
#
#
#             var marker_2c211d358d91541bf0f0ec0148b816ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e9a4d63ab0fcebcb8354fc54bfc5f1c5);
#
#
#         var popup_568a923c6636cb157d5e1f62912f4c3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f6236950235ff947dbdabd65218c1f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f6236950235ff947dbdabd65218c1f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f6236950235ff947dbdabd65218c1f9 = L.map(
#                 &quot;map_3f6236950235ff947dbdabd65218c1f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e95a7fa97ebd8cb2689fc8d70dbece8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e95a7fa97ebd8cb2689fc8d70dbece8.addTo(map_3f6236950235ff947dbdabd65218c1f9);
#
#
#             var feature_group_c6980020bb1aed5a7e979b33aa4066e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c6980020bb1aed5a7e979b33aa4066e2.addTo(map_3f6236950235ff947dbdabd65218c1f9);
#
#
#             var feature_group_sub_group_df3d65b428004cccbbaef67d956a8df9 = L.featureGroup.subGroup(
#                 feature_group_c6980020bb1aed5a7e979b33aa4066e2
#             );
#
#
#             var marker_9c8ac8dba6466413bc2156a192b6f86d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_df3d65b428004cccbbaef67d956a8df9);
#
#
#         var popup_9cec154ad9e21795fa7672f60eae5183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c32257cadbf9789d8bdde6fe94c62090 = $(`&lt;div id=&quot;html_c32257cadbf9789d8bdde6fe94c62090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9cec154ad9e21795fa7672f60eae5183.setContent(html_c32257cadbf9789d8bdde6fe94c62090);
#
#
#
#         marker_9c8ac8dba6466413bc2156a192b6f86d.bindPopup(popup_9cec154ad9e21795fa7672f60eae5183)
#         ;
#
#
#
#
#             var marker_9bd17f707c1155e0724ef5ee9cf8d997 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_df3d65b428004cccbbaef67d956a8df9);
#
#
#         var popup_37c4088bab832970d25e60e6d2285541 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b99b86b69d43b0fcf446ea9f4023794 = $(`&lt;div id=&quot;html_8b99b86b69d43b0fcf446ea9f4023794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_37c4088bab832970d25e60e6d2285541.setContent(html_8b99b86b69d43b0fcf446ea9f4023794);
#
#
#
#         marker_9bd17f707c1155e0724ef5ee9cf8d997.bindPopup(popup_37c4088bab832970d25e60e6d2285541)
#         ;
#
#
#
#
#             var marker_d773600aa513f2b9ad44b3cacb35bc39 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_df3d65b428004cccbbaef67d956a8df9);
#
#
#         var popup_0b0d3eb3941f99403e6a432450b9ea54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ed198446294ac2a655be63f003a3529 = $(`&lt;div id=&quot;html_6ed198446294ac2a655be63f003a3529&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0b0d3eb3941f99403e6a432450b9ea54.setContent(html_6ed198446294ac2a655be63f003a3529);
#
#
#
#         marker_d773600aa513f2b9ad44b3cacb35bc39.bindPopup(popup_0b0d3eb3941f99403e6a432450b9ea54)
#         ;
#
#
#
#
#             var marker_e207603ae362fe255eb2416c48888a74 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_df3d65b428004cccbbaef67d956a8df9);
#
#
#         var popup_54cca04bbebdfbe392c07dcaea1b1f3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdd6797f5669e07759bbc6f9df2e4b2c = $(`&lt;div id=&quot;html_bdd6797f5669e07759bbc6f9df2e4b2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_54cca04bbebdfbe392c07dcaea1b1f3c.setContent(html_bdd6797f5669e07759bbc6f9df2e4b2c);
#
#
#
#         marker_
