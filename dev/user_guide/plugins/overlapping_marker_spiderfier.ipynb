# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7ddd61a7fa77673189061aa7b828915 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7ddd61a7fa77673189061aa7b828915&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7ddd61a7fa77673189061aa7b828915 = L.map(
#                 &quot;map_e7ddd61a7fa77673189061aa7b828915&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbd5e6b20ae7e14f0d3b9047699cfdc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbd5e6b20ae7e14f0d3b9047699cfdc2.addTo(map_e7ddd61a7fa77673189061aa7b828915);
#
#
#             var marker_32b3b4cad51feb03be4f54d07bb528e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e7ddd61a7fa77673189061aa7b828915);
#
#
#         var popup_1f711067df0c5b1f632163ec88a184c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acd789b38aa4e81a40940973f2c61d77 = $(`&lt;div id=&quot;html_acd789b38aa4e81a40940973f2c61d77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1f711067df0c5b1f632163ec88a184c2.setContent(html_acd789b38aa4e81a40940973f2c61d77);
#
#
#
#         marker_32b3b4cad51feb03be4f54d07bb528e9.bindPopup(popup_1f711067df0c5b1f632163ec88a184c2)
#         ;
#
#
#
#
#             var marker_317919003c8e9206f7743a184de591c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e7ddd61a7fa77673189061aa7b828915);
#
#
#         var popup_f72af763540aec51fd965bf9340571be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_280497c439aed5d3ecf585dd672e65de = $(`&lt;div id=&quot;html_280497c439aed5d3ecf585dd672e65de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f72af763540aec51fd965bf9340571be.setContent(html_280497c439aed5d3ecf585dd672e65de);
#
#
#
#         marker_317919003c8e9206f7743a184de591c6.bindPopup(popup_f72af763540aec51fd965bf9340571be)
#         ;
#
#
#
#
#             var marker_a7d6d771c5e5398c1983acfadd47f381 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e7ddd61a7fa77673189061aa7b828915);
#
#
#         var popup_5f813a094722eb91f15a4dd1e230abec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34ba57ef8a475d0744d19538ddd3bf92 = $(`&lt;div id=&quot;html_34ba57ef8a475d0744d19538ddd3bf92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5f813a094722eb91f15a4dd1e230abec.setContent(html_34ba57ef8a475d0744d19538ddd3bf92);
#
#
#
#         marker_a7d6d771c5e5398c1983acfadd47f381.bindPopup(popup_5f813a094722eb91f15a4dd1e230abec)
#         ;
#
#
#
#
#             var marker_9b60c2f443d92e0c6438b5addf9269e5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e7ddd61a7fa77673189061aa7b828915);
#
#
#         var popup_50363038a14e360efe508255e1b2c7b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7109009c7d8fb225d5d7a00937ac9806 = $(`&lt;div id=&quot;html_7109009c7d8fb225d5d7a00937ac9806&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_50363038a14e360efe508255e1b2c7b1.setContent(html_7109009c7d8fb225d5d7a00937ac9806);
#
#
#
#         marker_9b60c2f443d92e0c6438b5addf9269e5.bindPopup(popup_50363038a14e360efe508255e1b2c7b1)
#         ;
#
#
#
#
#             var marker_3d83881c821d8c081da1badca8e847df = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e7ddd61a7fa77673189061aa7b828915);
#
#
#         var popup_05a3edc2ac1400976c76be2c9d156b05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_163897cf53ed4b2f163bbcae335109f0 = $(`&lt;div id=&quot;html_163897cf53ed4b2f163bbcae335109f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05a3edc2ac1400976c76be2c9d156b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23c8cae2c5a6a033ef98f8f354cf7933 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23c8cae2c5a6a033ef98f8f354cf7933&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23c8cae2c5a6a033ef98f8f354cf7933 = L.map(
#                 &quot;map_23c8cae2c5a6a033ef98f8f354cf7933&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afa560b63454afb99a3343df7fbe050e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afa560b63454afb99a3343df7fbe050e.addTo(map_23c8cae2c5a6a033ef98f8f354cf7933);
#
#
#             var feature_group_4d25a511f6859f6202f7aefdab649a81 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_eba01050a385c42f8d9cd8e4e71953f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4d25a511f6859f6202f7aefdab649a81);
#
#
#         var popup_13de3990c2b1dced9358ba849e4584f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6985b6f5d4c9f2d0ea37790c4bc15872 = $(`&lt;div id=&quot;html_6985b6f5d4c9f2d0ea37790c4bc15872&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_13de3990c2b1dced9358ba849e4584f8.setContent(html_6985b6f5d4c9f2d0ea37790c4bc15872);
#
#
#
#         marker_eba01050a385c42f8d9cd8e4e71953f6.bindPopup(popup_13de3990c2b1dced9358ba849e4584f8)
#         ;
#
#
#
#
#             var marker_c0c4241b14b363a6feb81bfa90fcee05 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4d25a511f6859f6202f7aefdab649a81);
#
#
#         var popup_b5da9ae4a0a2097419d1fcd49830b2fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f436acf0fb8d6646611d205b2b5ba3d2 = $(`&lt;div id=&quot;html_f436acf0fb8d6646611d205b2b5ba3d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b5da9ae4a0a2097419d1fcd49830b2fb.setContent(html_f436acf0fb8d6646611d205b2b5ba3d2);
#
#
#
#         marker_c0c4241b14b363a6feb81bfa90fcee05.bindPopup(popup_b5da9ae4a0a2097419d1fcd49830b2fb)
#         ;
#
#
#
#
#             var marker_dc31632a6bb3589f522d681afec25302 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4d25a511f6859f6202f7aefdab649a81);
#
#
#         var popup_d4f2e8ceb2c73183e9d3c75fa871efb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0df4fd468228a1eca013c8ea9f57645 = $(`&lt;div id=&quot;html_c0df4fd468228a1eca013c8ea9f57645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d4f2e8ceb2c73183e9d3c75fa871efb5.setContent(html_c0df4fd468228a1eca013c8ea9f57645);
#
#
#
#         marker_dc31632a6bb3589f522d681afec25302.bindPopup(popup_d4f2e8ceb2c73183e9d3c75fa871efb5)
#         ;
#
#
#
#
#             var marker_221c5583b3b3140d183af2f3f0bf47df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4d25a511f6859f6202f7aefdab649a81);
#
#
#         var popup_2beae11a5c9d5939bf1b7fbeb3cfcbea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d2cb7b89388d00dfca53ce901f6d229 = $(`&lt;div id=&quot;html_4d2cb7b89388d00dfca53ce901f6d229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2beae11a5c9d5939bf1b7fbeb3cfcbea.setContent(html_4d2cb7b89388d00dfca53ce901f6d229);
#
#
#
#         marker_221c5583b3b3140d183af2f3f0bf47df.bindPopup(popup_2beae11a5c9d5939bf1b7fbeb3cfcbea)
#         ;
#
#
#
#
#             var marker_ae3cca299d622a3035971df73af2fa3f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4d25a511f6859f6202f7aefdab649a81);
#
#
#         var popup_fdbdb5803d62f9e0947d70ebbf1b15eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64c85ffb2175ecb3524710e13f0332cf {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64c85ffb2175ecb3524710e13f0332cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64c85ffb2175ecb3524710e13f0332cf = L.map(
#                 &quot;map_64c85ffb2175ecb3524710e13f0332cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6767f829f85a3d3ddd044d83f5957f1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6767f829f85a3d3ddd044d83f5957f1d.addTo(map_64c85ffb2175ecb3524710e13f0332cf);
#
#
#             var feature_group_811b660056209261b199d6aa2ddd6263 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_811b660056209261b199d6aa2ddd6263.addTo(map_64c85ffb2175ecb3524710e13f0332cf);
#
#
#             var feature_group_sub_group_76b93e024e9d15ad80161d7acb1aae99 = L.featureGroup.subGroup(
#                 feature_group_811b660056209261b199d6aa2ddd6263
#             );
#
#
#             var marker_1a23167e94bd533e8113938fb850fd1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_76b93e024e9d15ad80161d7acb1aae99);
#
#
#         var popup_72d6e41233c8747bd695fec4765f39ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50bc996e3258b916d0de2629e68b99dc = $(`&lt;div id=&quot;html_50bc996e3258b916d0de2629e68b99dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_72d6e41233c8747bd695fec4765f39ac.setContent(html_50bc996e3258b916d0de2629e68b99dc);
#
#
#
#         marker_1a23167e94bd533e8113938fb850fd1f.bindPopup(popup_72d6e41233c8747bd695fec4765f39ac)
#         ;
#
#
#
#
#             var marker_79d87b69e94d3a5f3827599854708c1e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_76b93e024e9d15ad80161d7acb1aae99);
#
#
#         var popup_696e94cf788c6c2c13cb099c2a30e58d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b55d3e561a4a09a2e5234204b89fca1 = $(`&lt;div id=&quot;html_4b55d3e561a4a09a2e5234204b89fca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_696e94cf788c6c2c13cb099c2a30e58d.setContent(html_4b55d3e561a4a09a2e5234204b89fca1);
#
#
#
#         marker_79d87b69e94d3a5f3827599854708c1e.bindPopup(popup_696e94cf788c6c2c13cb099c2a30e58d)
#         ;
#
#
#
#
#             var marker_a2b4d0279986bc08dcae287161d2daa1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_76b93e024e9d15ad80161d7acb1aae99);
#
#
#         var popup_64ac3f7890c43ffe98adf2f937dc8376 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a460d1bb249e7de969eecdda94c12786 = $(`&lt;div id=&quot;html_a460d1bb249e7de969eecdda94c12786&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_64ac3f7890c43ffe98adf2f937dc8376.setContent(html_a460d1bb249e7de969eecdda94c12786);
#
#
#
#         marker_a2b4d0279986bc08dcae287161d2daa1.bindPopup(popup_64ac3f7890c43ffe98adf2f937dc8376)
#         ;
#
#
#
#
#             var marker_f9388b9d9b517295594000d39ae4ab0e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_76b93e024e9d15ad80161d7acb1aae99);
#
#
#         var popup_f69a2557d85afc28838309d66294bcb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a7c9ba95e74605b4a41e3376b319b28 = $(`&lt;div id=&quot;html_1a7c9ba95e74605b4a41e3376b319b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f69a2557d85afc28838309d66294bcb5.setContent(html_1a7c9ba95e74605b4a41e3376b319b28);
#
#
#
#         mark
