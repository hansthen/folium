# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4c99d0525012256badbe37f01ec8fd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4c99d0525012256badbe37f01ec8fd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4c99d0525012256badbe37f01ec8fd1 = L.map(
#                 &quot;map_f4c99d0525012256badbe37f01ec8fd1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67e827801fbe07f719983d0ea24e85a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67e827801fbe07f719983d0ea24e85a8.addTo(map_f4c99d0525012256badbe37f01ec8fd1);
#
#
#             var marker_3d2d24546a8b5efbf6e25043f49e3e15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f4c99d0525012256badbe37f01ec8fd1);
#
#
#         var popup_76a10497436a86210b28a9e2da096ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26f327a4a29e2fa40bb62ccc2be25f5b = $(`&lt;div id=&quot;html_26f327a4a29e2fa40bb62ccc2be25f5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_76a10497436a86210b28a9e2da096ae2.setContent(html_26f327a4a29e2fa40bb62ccc2be25f5b);
#
#
#
#         marker_3d2d24546a8b5efbf6e25043f49e3e15.bindPopup(popup_76a10497436a86210b28a9e2da096ae2)
#         ;
#
#
#
#
#             var marker_fe7e6f2fec544ed30ed0860b59ec19ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f4c99d0525012256badbe37f01ec8fd1);
#
#
#         var popup_6d55d15dfba29728abff7242e7766800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_061b529533b1e129bf34d37594571e14 = $(`&lt;div id=&quot;html_061b529533b1e129bf34d37594571e14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6d55d15dfba29728abff7242e7766800.setContent(html_061b529533b1e129bf34d37594571e14);
#
#
#
#         marker_fe7e6f2fec544ed30ed0860b59ec19ea.bindPopup(popup_6d55d15dfba29728abff7242e7766800)
#         ;
#
#
#
#
#             var marker_388074b8fea20ccf19431b5318f72589 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f4c99d0525012256badbe37f01ec8fd1);
#
#
#         var popup_b8719d20c73b4e61e83f8e27a13de15f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2acfc8f1d88b049a643c827ee2b66220 = $(`&lt;div id=&quot;html_2acfc8f1d88b049a643c827ee2b66220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b8719d20c73b4e61e83f8e27a13de15f.setContent(html_2acfc8f1d88b049a643c827ee2b66220);
#
#
#
#         marker_388074b8fea20ccf19431b5318f72589.bindPopup(popup_b8719d20c73b4e61e83f8e27a13de15f)
#         ;
#
#
#
#
#             var marker_bf9c3e63859f8bc7e3289e5bccc26ea9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f4c99d0525012256badbe37f01ec8fd1);
#
#
#         var popup_3c486446069a1fac74319fdd4645e347 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24fb3e5ffae0d9de0d45a53391a6b0db = $(`&lt;div id=&quot;html_24fb3e5ffae0d9de0d45a53391a6b0db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3c486446069a1fac74319fdd4645e347.setContent(html_24fb3e5ffae0d9de0d45a53391a6b0db);
#
#
#
#         marker_bf9c3e63859f8bc7e3289e5bccc26ea9.bindPopup(popup_3c486446069a1fac74319fdd4645e347)
#         ;
#
#
#
#
#             var marker_a2a0813a60dde4f2699d14018aeaa11c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f4c99d0525012256badbe37f01ec8fd1);
#
#
#         var popup_16700d3eb14b1f50b3cdb405c93ac7db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f801535acf4a2493ccf2c6a6c3b32b2 = $(`&lt;div id=&quot;html_8f801535acf4a2493ccf2c6a6c3b32b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_16700d3eb14b1f50b3cdb405c93ac7db.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_487fce47dd3782f8be606b60d944b8b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_487fce47dd3782f8be606b60d944b8b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_487fce47dd3782f8be606b60d944b8b3 = L.map(
#                 &quot;map_487fce47dd3782f8be606b60d944b8b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_974c09c2795e0e74c471ffb8a7f08a7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_974c09c2795e0e74c471ffb8a7f08a7c.addTo(map_487fce47dd3782f8be606b60d944b8b3);
#
#
#             var feature_group_ab11be058b4c35d3de05556e253ee213 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6b9394cc6dcf768147265baca968ee8a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ab11be058b4c35d3de05556e253ee213);
#
#
#         var popup_8b566a7ee66e06d710e0b638ca3cc156 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d2cba89dcbcc8274c820cec1d40c534 = $(`&lt;div id=&quot;html_5d2cba89dcbcc8274c820cec1d40c534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8b566a7ee66e06d710e0b638ca3cc156.setContent(html_5d2cba89dcbcc8274c820cec1d40c534);
#
#
#
#         marker_6b9394cc6dcf768147265baca968ee8a.bindPopup(popup_8b566a7ee66e06d710e0b638ca3cc156)
#         ;
#
#
#
#
#             var marker_e1563dbb45220a83a092f455f2d19c5e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ab11be058b4c35d3de05556e253ee213);
#
#
#         var popup_e0d59d0357f76f872bbcd996a68738bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef98b98e92fa3451041edb303b8fd7d1 = $(`&lt;div id=&quot;html_ef98b98e92fa3451041edb303b8fd7d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e0d59d0357f76f872bbcd996a68738bd.setContent(html_ef98b98e92fa3451041edb303b8fd7d1);
#
#
#
#         marker_e1563dbb45220a83a092f455f2d19c5e.bindPopup(popup_e0d59d0357f76f872bbcd996a68738bd)
#         ;
#
#
#
#
#             var marker_e0683b15cc6b05d11e394fa0e3456005 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ab11be058b4c35d3de05556e253ee213);
#
#
#         var popup_7187eafe27c6cad21a5fc065cd22671f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b790c24871dd7cde2415977b6fd38727 = $(`&lt;div id=&quot;html_b790c24871dd7cde2415977b6fd38727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7187eafe27c6cad21a5fc065cd22671f.setContent(html_b790c24871dd7cde2415977b6fd38727);
#
#
#
#         marker_e0683b15cc6b05d11e394fa0e3456005.bindPopup(popup_7187eafe27c6cad21a5fc065cd22671f)
#         ;
#
#
#
#
#             var marker_975f69e2a6a6f183ac2a9a2f937aed2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ab11be058b4c35d3de05556e253ee213);
#
#
#         var popup_2a8a47b20183f081817761a4e9b286ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7aa22aad83d788bb66ad055b15237400 = $(`&lt;div id=&quot;html_7aa22aad83d788bb66ad055b15237400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2a8a47b20183f081817761a4e9b286ea.setContent(html_7aa22aad83d788bb66ad055b15237400);
#
#
#
#         marker_975f69e2a6a6f183ac2a9a2f937aed2f.bindPopup(popup_2a8a47b20183f081817761a4e9b286ea)
#         ;
#
#
#
#
#             var marker_8bf32e3a76681d2bbec6e480b68fecd5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ab11be058b4c35d3de05556e253ee213);
#
#
#         var popup_9720643eb8a89772137ce0137d00a7d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_556680afbe05418daf5bc7d8d05aa93b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_556680afbe05418daf5bc7d8d05aa93b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_556680afbe05418daf5bc7d8d05aa93b = L.map(
#                 &quot;map_556680afbe05418daf5bc7d8d05aa93b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_870fbf35c7dea3e461da26daa24e949e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_870fbf35c7dea3e461da26daa24e949e.addTo(map_556680afbe05418daf5bc7d8d05aa93b);
#
#
#             var feature_group_a6e1ac3c924e332424cb91b5a2e47236 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a6e1ac3c924e332424cb91b5a2e47236.addTo(map_556680afbe05418daf5bc7d8d05aa93b);
#
#
#             var feature_group_sub_group_50afcbcaad1ade5c4acda0e268b767b5 = L.featureGroup.subGroup(
#                 feature_group_a6e1ac3c924e332424cb91b5a2e47236
#             );
#
#
#             var marker_aa115b1f91c1a030651d50c64409d048 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_50afcbcaad1ade5c4acda0e268b767b5);
#
#
#         var popup_f93b8efbc029900f39e086b4bd6fe519 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f56465b20a34668c7156a612fe9f0c6d = $(`&lt;div id=&quot;html_f56465b20a34668c7156a612fe9f0c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f93b8efbc029900f39e086b4bd6fe519.setContent(html_f56465b20a34668c7156a612fe9f0c6d);
#
#
#
#         marker_aa115b1f91c1a030651d50c64409d048.bindPopup(popup_f93b8efbc029900f39e086b4bd6fe519)
#         ;
#
#
#
#
#             var marker_f4b348f070b7f5861fc55191a47349c0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_50afcbcaad1ade5c4acda0e268b767b5);
#
#
#         var popup_7c69c6e858209e13322d74c1ac6b17e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff2e557b0d8ce40dfb3067cbe08b8562 = $(`&lt;div id=&quot;html_ff2e557b0d8ce40dfb3067cbe08b8562&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7c69c6e858209e13322d74c1ac6b17e3.setContent(html_ff2e557b0d8ce40dfb3067cbe08b8562);
#
#
#
#         marker_f4b348f070b7f5861fc55191a47349c0.bindPopup(popup_7c69c6e858209e13322d74c1ac6b17e3)
#         ;
#
#
#
#
#             var marker_9fd2f078892c2598d61929cc556d334e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_50afcbcaad1ade5c4acda0e268b767b5);
#
#
#         var popup_15c3eadce1934839a113d6a94b07cb4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b335a02f684968fd86fe978ed509d2d4 = $(`&lt;div id=&quot;html_b335a02f684968fd86fe978ed509d2d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_15c3eadce1934839a113d6a94b07cb4d.setContent(html_b335a02f684968fd86fe978ed509d2d4);
#
#
#
#         marker_9fd2f078892c2598d61929cc556d334e.bindPopup(popup_15c3eadce1934839a113d6a94b07cb4d)
#         ;
#
#
#
#
#             var marker_5ecdbf96db39ffeeec4810f90131acaa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_50afcbcaad1ade5c4acda0e268b767b5);
#
#
#         var popup_4a0ac99ad73617e15169ab408e5930c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39cb0d9f48a7dd6271507b03d5bf0ef8 = $(`&lt;div id=&quot;html_39cb0d9f48a7dd6271507b03d5bf0ef8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4a0ac99ad73617e15169ab408e5930c1.setContent(html_39cb0d9f48a7dd6271507b03d5bf0ef8);
#
#
#
#         marker_
