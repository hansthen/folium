# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d4c025a701641e95a1b329f5343bf83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d4c025a701641e95a1b329f5343bf83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d4c025a701641e95a1b329f5343bf83 = L.map(
#                 &quot;map_8d4c025a701641e95a1b329f5343bf83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_069e409d6d5f7245308bd87303df63c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_069e409d6d5f7245308bd87303df63c0.addTo(map_8d4c025a701641e95a1b329f5343bf83);
#
#
#             var marker_bf3afe7ee62af089fb87ed9a83e09a56 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8d4c025a701641e95a1b329f5343bf83);
#
#
#         var popup_3c978a8f335d72488b157396532496d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27cc92f6889b0f7d38d7c2571adc1cef = $(`&lt;div id=&quot;html_27cc92f6889b0f7d38d7c2571adc1cef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3c978a8f335d72488b157396532496d4.setContent(html_27cc92f6889b0f7d38d7c2571adc1cef);
#
#
#
#         marker_bf3afe7ee62af089fb87ed9a83e09a56.bindPopup(popup_3c978a8f335d72488b157396532496d4)
#         ;
#
#
#
#
#             var marker_f3aa70e3cbffed45247341250b68c42e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8d4c025a701641e95a1b329f5343bf83);
#
#
#         var popup_b799cba01036b28c9b0b0ab51b8a4816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d2f7527232ef9b69dd7cc236922f160 = $(`&lt;div id=&quot;html_8d2f7527232ef9b69dd7cc236922f160&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b799cba01036b28c9b0b0ab51b8a4816.setContent(html_8d2f7527232ef9b69dd7cc236922f160);
#
#
#
#         marker_f3aa70e3cbffed45247341250b68c42e.bindPopup(popup_b799cba01036b28c9b0b0ab51b8a4816)
#         ;
#
#
#
#
#             var marker_65ac3eb8377b6d4e23a741a34c3e7d6e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8d4c025a701641e95a1b329f5343bf83);
#
#
#         var popup_faea6a25f99c6de6790b966bbfc53e0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0055b07bc543adb2d85f7f5e7f76e2dd = $(`&lt;div id=&quot;html_0055b07bc543adb2d85f7f5e7f76e2dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_faea6a25f99c6de6790b966bbfc53e0b.setContent(html_0055b07bc543adb2d85f7f5e7f76e2dd);
#
#
#
#         marker_65ac3eb8377b6d4e23a741a34c3e7d6e.bindPopup(popup_faea6a25f99c6de6790b966bbfc53e0b)
#         ;
#
#
#
#
#             var marker_e23498bafd5fe82e91df57fad2a8b566 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8d4c025a701641e95a1b329f5343bf83);
#
#
#         var popup_de55e3ff15ac752ca1a87081298cdfc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b41635fadf720c66915b841681ac74e9 = $(`&lt;div id=&quot;html_b41635fadf720c66915b841681ac74e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_de55e3ff15ac752ca1a87081298cdfc7.setContent(html_b41635fadf720c66915b841681ac74e9);
#
#
#
#         marker_e23498bafd5fe82e91df57fad2a8b566.bindPopup(popup_de55e3ff15ac752ca1a87081298cdfc7)
#         ;
#
#
#
#
#             var marker_2cb53ed39635b50793bf5c51e47b41f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8d4c025a701641e95a1b329f5343bf83);
#
#
#         var popup_60f34c662269dbb30ed443b37b520a16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a370a155a250e47f67a104a68dbc968 = $(`&lt;div id=&quot;html_3a370a155a250e47f67a104a68dbc968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_60f34c662269dbb30ed443b37b520a16.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0b7ac1d6f1c1ca62b8bf0a6d310cf5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0b7ac1d6f1c1ca62b8bf0a6d310cf5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0b7ac1d6f1c1ca62b8bf0a6d310cf5a = L.map(
#                 &quot;map_f0b7ac1d6f1c1ca62b8bf0a6d310cf5a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13f82960d4c7d82d4161a4a50c4fc623 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13f82960d4c7d82d4161a4a50c4fc623.addTo(map_f0b7ac1d6f1c1ca62b8bf0a6d310cf5a);
#
#
#             var feature_group_63a302857e6dd23740750809238ba8e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a92caefb67705667b2a4fefcaa74c08c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_63a302857e6dd23740750809238ba8e2);
#
#
#         var popup_5ab90022edaa612b17f24ec73ac294e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3a7ad2f461084ec9645095479d41c89 = $(`&lt;div id=&quot;html_b3a7ad2f461084ec9645095479d41c89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5ab90022edaa612b17f24ec73ac294e5.setContent(html_b3a7ad2f461084ec9645095479d41c89);
#
#
#
#         marker_a92caefb67705667b2a4fefcaa74c08c.bindPopup(popup_5ab90022edaa612b17f24ec73ac294e5)
#         ;
#
#
#
#
#             var marker_e7cc1d08883bff0bc5052ba0fdbe88ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_63a302857e6dd23740750809238ba8e2);
#
#
#         var popup_70f6062ce63f55f7710451f873beb140 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0aff1b0eeddba7ebfcff1551bfa9bf5 = $(`&lt;div id=&quot;html_f0aff1b0eeddba7ebfcff1551bfa9bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_70f6062ce63f55f7710451f873beb140.setContent(html_f0aff1b0eeddba7ebfcff1551bfa9bf5);
#
#
#
#         marker_e7cc1d08883bff0bc5052ba0fdbe88ac.bindPopup(popup_70f6062ce63f55f7710451f873beb140)
#         ;
#
#
#
#
#             var marker_11572eff18a65282be36da22f1edcf41 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_63a302857e6dd23740750809238ba8e2);
#
#
#         var popup_55d10f4002a76a900208c8c46ac63f1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3626b776db5692fadda95289e47f602d = $(`&lt;div id=&quot;html_3626b776db5692fadda95289e47f602d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_55d10f4002a76a900208c8c46ac63f1e.setContent(html_3626b776db5692fadda95289e47f602d);
#
#
#
#         marker_11572eff18a65282be36da22f1edcf41.bindPopup(popup_55d10f4002a76a900208c8c46ac63f1e)
#         ;
#
#
#
#
#             var marker_ac27bf7b9af4915b140b15d53bd25128 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_63a302857e6dd23740750809238ba8e2);
#
#
#         var popup_9d8bea00be14a837dfc84b2e3807eb9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1193dc33d312e03ab604f0179a5f16b = $(`&lt;div id=&quot;html_c1193dc33d312e03ab604f0179a5f16b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9d8bea00be14a837dfc84b2e3807eb9f.setContent(html_c1193dc33d312e03ab604f0179a5f16b);
#
#
#
#         marker_ac27bf7b9af4915b140b15d53bd25128.bindPopup(popup_9d8bea00be14a837dfc84b2e3807eb9f)
#         ;
#
#
#
#
#             var marker_66b45df4bcb59a58ee94a19500188050 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_63a302857e6dd23740750809238ba8e2);
#
#
#         var popup_dddb25e4ea5e216e7ecb97b325a322dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0f8d66ddc9c703d73e720d739e04e44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0f8d66ddc9c703d73e720d739e04e44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0f8d66ddc9c703d73e720d739e04e44 = L.map(
#                 &quot;map_b0f8d66ddc9c703d73e720d739e04e44&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e60f916d1b64be16d3620323dd71de97 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e60f916d1b64be16d3620323dd71de97.addTo(map_b0f8d66ddc9c703d73e720d739e04e44);
#
#
#             var feature_group_7c4a64d43c8e84d07c94bc361b4603cc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7c4a64d43c8e84d07c94bc361b4603cc.addTo(map_b0f8d66ddc9c703d73e720d739e04e44);
#
#
#             var feature_group_sub_group_1f8da6c2dc26325dc82fea2268c64f6c = L.featureGroup.subGroup(
#                 feature_group_7c4a64d43c8e84d07c94bc361b4603cc
#             );
#
#
#             var marker_1214c9ad8f6fd9fde3f86390a227f9cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8da6c2dc26325dc82fea2268c64f6c);
#
#
#         var popup_124058ee98d6f1e860657ad27d4557ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f50cecb1ea03031498ceb17726be09c5 = $(`&lt;div id=&quot;html_f50cecb1ea03031498ceb17726be09c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_124058ee98d6f1e860657ad27d4557ee.setContent(html_f50cecb1ea03031498ceb17726be09c5);
#
#
#
#         marker_1214c9ad8f6fd9fde3f86390a227f9cc.bindPopup(popup_124058ee98d6f1e860657ad27d4557ee)
#         ;
#
#
#
#
#             var marker_ad4419cacea809f718fc5c03b41ba35e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8da6c2dc26325dc82fea2268c64f6c);
#
#
#         var popup_0b6f3d6dedb526e321b641709337353e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80784837603e813a53b0661bab41f10c = $(`&lt;div id=&quot;html_80784837603e813a53b0661bab41f10c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0b6f3d6dedb526e321b641709337353e.setContent(html_80784837603e813a53b0661bab41f10c);
#
#
#
#         marker_ad4419cacea809f718fc5c03b41ba35e.bindPopup(popup_0b6f3d6dedb526e321b641709337353e)
#         ;
#
#
#
#
#             var marker_85faf626161565d97acad933a7010d6f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8da6c2dc26325dc82fea2268c64f6c);
#
#
#         var popup_4f799dff959d5eabb90849bf0003a105 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d60586d5c72afc1af63e3335faec5f2e = $(`&lt;div id=&quot;html_d60586d5c72afc1af63e3335faec5f2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4f799dff959d5eabb90849bf0003a105.setContent(html_d60586d5c72afc1af63e3335faec5f2e);
#
#
#
#         marker_85faf626161565d97acad933a7010d6f.bindPopup(popup_4f799dff959d5eabb90849bf0003a105)
#         ;
#
#
#
#
#             var marker_16c5dbc19d13469f19a07c6dd24a88ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8da6c2dc26325dc82fea2268c64f6c);
#
#
#         var popup_948579516159e3a78ae67cfb0aa7edb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f865c11bdbb6f378e122772e8994546 = $(`&lt;div id=&quot;html_9f865c11bdbb6f378e122772e8994546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_948579516159e3a78ae67cfb0aa7edb5.setContent(html_9f865c11bdbb6f378e122772e8994546);
#
#
#
#         marker_
