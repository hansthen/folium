# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45a622c7a0fbf3d25f512eff4285f130 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45a622c7a0fbf3d25f512eff4285f130&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45a622c7a0fbf3d25f512eff4285f130 = L.map(
#                 &quot;map_45a622c7a0fbf3d25f512eff4285f130&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_383c041368e42e2627e2c066f43e66b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_383c041368e42e2627e2c066f43e66b6.addTo(map_45a622c7a0fbf3d25f512eff4285f130);
#
#
#             var marker_2847316453dd029d6892b1fc9c2c941c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_45a622c7a0fbf3d25f512eff4285f130);
#
#
#         var popup_26997e07a3eb9d49556630cdc2593bea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9778153688445b1670fd7f2a149f5bec = $(`&lt;div id=&quot;html_9778153688445b1670fd7f2a149f5bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_26997e07a3eb9d49556630cdc2593bea.setContent(html_9778153688445b1670fd7f2a149f5bec);
#
#
#
#         marker_2847316453dd029d6892b1fc9c2c941c.bindPopup(popup_26997e07a3eb9d49556630cdc2593bea)
#         ;
#
#
#
#
#             var marker_c5166358e41eef937924362e13f7cd38 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_45a622c7a0fbf3d25f512eff4285f130);
#
#
#         var popup_ddd041db8993eef33ace87d28353f685 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7d1d9545990c2fc7f3f99a7e73fae5c = $(`&lt;div id=&quot;html_a7d1d9545990c2fc7f3f99a7e73fae5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ddd041db8993eef33ace87d28353f685.setContent(html_a7d1d9545990c2fc7f3f99a7e73fae5c);
#
#
#
#         marker_c5166358e41eef937924362e13f7cd38.bindPopup(popup_ddd041db8993eef33ace87d28353f685)
#         ;
#
#
#
#
#             var marker_8a4b17609ce0f3f2b0c092a2ba54ff3a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_45a622c7a0fbf3d25f512eff4285f130);
#
#
#         var popup_332f92b3a1e882a175513bcd34775f0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ce3e0724bdf980269dab6ad7eeaef65 = $(`&lt;div id=&quot;html_7ce3e0724bdf980269dab6ad7eeaef65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_332f92b3a1e882a175513bcd34775f0f.setContent(html_7ce3e0724bdf980269dab6ad7eeaef65);
#
#
#
#         marker_8a4b17609ce0f3f2b0c092a2ba54ff3a.bindPopup(popup_332f92b3a1e882a175513bcd34775f0f)
#         ;
#
#
#
#
#             var marker_294a03783606bb3839db2db1060a0139 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_45a622c7a0fbf3d25f512eff4285f130);
#
#
#         var popup_c8dd1c658c38091213581b3b2a799834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7d193ba7db480499354344347a977ad = $(`&lt;div id=&quot;html_b7d193ba7db480499354344347a977ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c8dd1c658c38091213581b3b2a799834.setContent(html_b7d193ba7db480499354344347a977ad);
#
#
#
#         marker_294a03783606bb3839db2db1060a0139.bindPopup(popup_c8dd1c658c38091213581b3b2a799834)
#         ;
#
#
#
#
#             var marker_0778fdc1b09885b9abb4e418215033fe = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_45a622c7a0fbf3d25f512eff4285f130);
#
#
#         var popup_0ea8d356ce5ddb5ad5a37689ed71533c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfe1b4c20579c249d671daf67b624571 = $(`&lt;div id=&quot;html_dfe1b4c20579c249d671daf67b624571&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0ea8d356ce5ddb5ad5a37689ed71533c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc1dd869878720a108ac199c3710b6d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc1dd869878720a108ac199c3710b6d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc1dd869878720a108ac199c3710b6d1 = L.map(
#                 &quot;map_bc1dd869878720a108ac199c3710b6d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f0ab8f554b2e384e3995e87af40ce91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f0ab8f554b2e384e3995e87af40ce91.addTo(map_bc1dd869878720a108ac199c3710b6d1);
#
#
#             var feature_group_91dd48cac2d2d3671854e3de0ee48f94 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8ec0f69fc2ffebaa896b7d7b6d9dcab2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_91dd48cac2d2d3671854e3de0ee48f94);
#
#
#         var popup_0d9d981095210ac9a06092b6f7e569cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5ff9b270340d5a45eb95dc63a7f4c13 = $(`&lt;div id=&quot;html_d5ff9b270340d5a45eb95dc63a7f4c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0d9d981095210ac9a06092b6f7e569cf.setContent(html_d5ff9b270340d5a45eb95dc63a7f4c13);
#
#
#
#         marker_8ec0f69fc2ffebaa896b7d7b6d9dcab2.bindPopup(popup_0d9d981095210ac9a06092b6f7e569cf)
#         ;
#
#
#
#
#             var marker_d397e7193643813170b28c477d078016 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_91dd48cac2d2d3671854e3de0ee48f94);
#
#
#         var popup_b00f2a4fb22c41e56290f9d7943b8bcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c945eb49d8da6c8e1784d2536e5e9f51 = $(`&lt;div id=&quot;html_c945eb49d8da6c8e1784d2536e5e9f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b00f2a4fb22c41e56290f9d7943b8bcd.setContent(html_c945eb49d8da6c8e1784d2536e5e9f51);
#
#
#
#         marker_d397e7193643813170b28c477d078016.bindPopup(popup_b00f2a4fb22c41e56290f9d7943b8bcd)
#         ;
#
#
#
#
#             var marker_3f85fefac84c831106ae9866215a80c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_91dd48cac2d2d3671854e3de0ee48f94);
#
#
#         var popup_0ca2c80ab195d0e98be1ae9efe6260a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff66d1cefdd998deb21cd8df76f8c36e = $(`&lt;div id=&quot;html_ff66d1cefdd998deb21cd8df76f8c36e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0ca2c80ab195d0e98be1ae9efe6260a0.setContent(html_ff66d1cefdd998deb21cd8df76f8c36e);
#
#
#
#         marker_3f85fefac84c831106ae9866215a80c2.bindPopup(popup_0ca2c80ab195d0e98be1ae9efe6260a0)
#         ;
#
#
#
#
#             var marker_34cc289b581325c9a14b9baa1df0e95a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_91dd48cac2d2d3671854e3de0ee48f94);
#
#
#         var popup_0293a9a4f53fabc03576315267e85c6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7074c49313c08a0f973a074a98630c6a = $(`&lt;div id=&quot;html_7074c49313c08a0f973a074a98630c6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0293a9a4f53fabc03576315267e85c6a.setContent(html_7074c49313c08a0f973a074a98630c6a);
#
#
#
#         marker_34cc289b581325c9a14b9baa1df0e95a.bindPopup(popup_0293a9a4f53fabc03576315267e85c6a)
#         ;
#
#
#
#
#             var marker_84010eca49ee787606320944e1a9bc5a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_91dd48cac2d2d3671854e3de0ee48f94);
#
#
#         var popup_26f84c8ef980a7bf600ee92610636a13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62d121ad5e7b03f7eb67c7f2beb05761 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62d121ad5e7b03f7eb67c7f2beb05761&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62d121ad5e7b03f7eb67c7f2beb05761 = L.map(
#                 &quot;map_62d121ad5e7b03f7eb67c7f2beb05761&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_926e53fd349a295d31f30f9701e2a61f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_926e53fd349a295d31f30f9701e2a61f.addTo(map_62d121ad5e7b03f7eb67c7f2beb05761);
#
#
#             var feature_group_eb0316f24554fcb46c5fda3ec85b4bfa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eb0316f24554fcb46c5fda3ec85b4bfa.addTo(map_62d121ad5e7b03f7eb67c7f2beb05761);
#
#
#             var feature_group_sub_group_1cf51ba08306461cd1f73eaa132a9678 = L.featureGroup.subGroup(
#                 feature_group_eb0316f24554fcb46c5fda3ec85b4bfa
#             );
#
#
#             var marker_194e3280eede789e669b2d23b7c650d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cf51ba08306461cd1f73eaa132a9678);
#
#
#         var popup_31a4d6266e06a339a0ba2b9aa2c5f9e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fc0203ba26b8d775f47173c241f643b = $(`&lt;div id=&quot;html_9fc0203ba26b8d775f47173c241f643b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_31a4d6266e06a339a0ba2b9aa2c5f9e3.setContent(html_9fc0203ba26b8d775f47173c241f643b);
#
#
#
#         marker_194e3280eede789e669b2d23b7c650d9.bindPopup(popup_31a4d6266e06a339a0ba2b9aa2c5f9e3)
#         ;
#
#
#
#
#             var marker_9b527275806195653d8c98ef50cbe204 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cf51ba08306461cd1f73eaa132a9678);
#
#
#         var popup_615ee3a53bbc1834edc524f063b6e511 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2945567f07a1e04aa26dc7ac936b5d7c = $(`&lt;div id=&quot;html_2945567f07a1e04aa26dc7ac936b5d7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_615ee3a53bbc1834edc524f063b6e511.setContent(html_2945567f07a1e04aa26dc7ac936b5d7c);
#
#
#
#         marker_9b527275806195653d8c98ef50cbe204.bindPopup(popup_615ee3a53bbc1834edc524f063b6e511)
#         ;
#
#
#
#
#             var marker_bc0260650067da1fcdc80f8e15ba8eb3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cf51ba08306461cd1f73eaa132a9678);
#
#
#         var popup_c2dd28ae1e9135c2ade600e67b1e1e1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b780c2b04bab2aa8772274c88bc23839 = $(`&lt;div id=&quot;html_b780c2b04bab2aa8772274c88bc23839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c2dd28ae1e9135c2ade600e67b1e1e1f.setContent(html_b780c2b04bab2aa8772274c88bc23839);
#
#
#
#         marker_bc0260650067da1fcdc80f8e15ba8eb3.bindPopup(popup_c2dd28ae1e9135c2ade600e67b1e1e1f)
#         ;
#
#
#
#
#             var marker_2b2269574ef22d8f84312cc0f3add68a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cf51ba08306461cd1f73eaa132a9678);
#
#
#         var popup_efeb04912cc7d79208303b422aafb69a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bc5589ad24f0e4bd8efbd12b901c308 = $(`&lt;div id=&quot;html_7bc5589ad24f0e4bd8efbd12b901c308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_efeb04912cc7d79208303b422aafb69a.setContent(html_7bc5589ad24f0e4bd8efbd12b901c308);
#
#
#
#         marker_
