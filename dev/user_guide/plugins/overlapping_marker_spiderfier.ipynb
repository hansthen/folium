# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f10390964107712c01ce90934348802c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f10390964107712c01ce90934348802c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f10390964107712c01ce90934348802c = L.map(
#                 &quot;map_f10390964107712c01ce90934348802c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_052d6befb072ce3daaef697922d765f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_052d6befb072ce3daaef697922d765f3.addTo(map_f10390964107712c01ce90934348802c);
#
#
#             var marker_5aea79f7d3f8c3704735524d81801387 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f10390964107712c01ce90934348802c);
#
#
#         var popup_28195e99713d35a87580aaf521a06657 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79993414756969c83e36556bcaed914f = $(`&lt;div id=&quot;html_79993414756969c83e36556bcaed914f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_28195e99713d35a87580aaf521a06657.setContent(html_79993414756969c83e36556bcaed914f);
#
#
#
#         marker_5aea79f7d3f8c3704735524d81801387.bindPopup(popup_28195e99713d35a87580aaf521a06657)
#         ;
#
#
#
#
#             var marker_f00f1c1d029d1c4af80fc83e8d1977a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f10390964107712c01ce90934348802c);
#
#
#         var popup_99f83867ce7c80220902b248a957f9b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3775b72122cd8551de4c0ffbd87c339 = $(`&lt;div id=&quot;html_e3775b72122cd8551de4c0ffbd87c339&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_99f83867ce7c80220902b248a957f9b0.setContent(html_e3775b72122cd8551de4c0ffbd87c339);
#
#
#
#         marker_f00f1c1d029d1c4af80fc83e8d1977a7.bindPopup(popup_99f83867ce7c80220902b248a957f9b0)
#         ;
#
#
#
#
#             var marker_3c91938cebdcc4668f14d09b9604e996 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f10390964107712c01ce90934348802c);
#
#
#         var popup_c3527fd5f77d9945fa242b825edf195e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a429fa28b73e5ae94ce9749b146c2845 = $(`&lt;div id=&quot;html_a429fa28b73e5ae94ce9749b146c2845&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c3527fd5f77d9945fa242b825edf195e.setContent(html_a429fa28b73e5ae94ce9749b146c2845);
#
#
#
#         marker_3c91938cebdcc4668f14d09b9604e996.bindPopup(popup_c3527fd5f77d9945fa242b825edf195e)
#         ;
#
#
#
#
#             var marker_2b6327fdce8294567aa72832bfe73b8e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f10390964107712c01ce90934348802c);
#
#
#         var popup_d121a50a4364955694b4f63c2cd29650 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3922ef7b739e5c89f0ab790328719214 = $(`&lt;div id=&quot;html_3922ef7b739e5c89f0ab790328719214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d121a50a4364955694b4f63c2cd29650.setContent(html_3922ef7b739e5c89f0ab790328719214);
#
#
#
#         marker_2b6327fdce8294567aa72832bfe73b8e.bindPopup(popup_d121a50a4364955694b4f63c2cd29650)
#         ;
#
#
#
#
#             var marker_5dcb59c5ae09481b4437b8009fb121d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f10390964107712c01ce90934348802c);
#
#
#         var popup_e01eac1df4271c3c29c2fdc374e1906f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d2266c33fdd27fa51a3e84f3c10b3e8 = $(`&lt;div id=&quot;html_4d2266c33fdd27fa51a3e84f3c10b3e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e01eac1df4271c3c29c2fdc374e190

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ba145578eb1172b6ec03d8120fea30d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ba145578eb1172b6ec03d8120fea30d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ba145578eb1172b6ec03d8120fea30d = L.map(
#                 &quot;map_4ba145578eb1172b6ec03d8120fea30d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17f62de3be24bc24d07dc3481f19d5e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17f62de3be24bc24d07dc3481f19d5e1.addTo(map_4ba145578eb1172b6ec03d8120fea30d);
#
#
#             var feature_group_513a7a32bfb58eb690a211b4e43f1e17 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_268b746c2e94a2699028d2f5f6da7e02 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_513a7a32bfb58eb690a211b4e43f1e17);
#
#
#         var popup_37fd46b722dbfd41f1a95cefe4e519cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8366cf6c67e707456d6b2890d42af7de = $(`&lt;div id=&quot;html_8366cf6c67e707456d6b2890d42af7de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_37fd46b722dbfd41f1a95cefe4e519cf.setContent(html_8366cf6c67e707456d6b2890d42af7de);
#
#
#
#         marker_268b746c2e94a2699028d2f5f6da7e02.bindPopup(popup_37fd46b722dbfd41f1a95cefe4e519cf)
#         ;
#
#
#
#
#             var marker_00a3215755c6540dedbed4d1f360ff13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_513a7a32bfb58eb690a211b4e43f1e17);
#
#
#         var popup_b21256eb218a1347353ec9984a2169b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e0019a285f163269d95f446a08eb138 = $(`&lt;div id=&quot;html_6e0019a285f163269d95f446a08eb138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b21256eb218a1347353ec9984a2169b2.setContent(html_6e0019a285f163269d95f446a08eb138);
#
#
#
#         marker_00a3215755c6540dedbed4d1f360ff13.bindPopup(popup_b21256eb218a1347353ec9984a2169b2)
#         ;
#
#
#
#
#             var marker_26d7b41f0fae666dbed3cc5cf606a269 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_513a7a32bfb58eb690a211b4e43f1e17);
#
#
#         var popup_931f8337d2b3223b06e500a0d1f7629a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0472d2febc3fa351d0070696e771b85 = $(`&lt;div id=&quot;html_e0472d2febc3fa351d0070696e771b85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_931f8337d2b3223b06e500a0d1f7629a.setContent(html_e0472d2febc3fa351d0070696e771b85);
#
#
#
#         marker_26d7b41f0fae666dbed3cc5cf606a269.bindPopup(popup_931f8337d2b3223b06e500a0d1f7629a)
#         ;
#
#
#
#
#             var marker_f5b876841f6e4ca043240b607ff696a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_513a7a32bfb58eb690a211b4e43f1e17);
#
#
#         var popup_26a5201c8441f6cc7ea1bec3d3b794c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be7364bfd66a1aa1c49f9599d651e921 = $(`&lt;div id=&quot;html_be7364bfd66a1aa1c49f9599d651e921&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_26a5201c8441f6cc7ea1bec3d3b794c9.setContent(html_be7364bfd66a1aa1c49f9599d651e921);
#
#
#
#         marker_f5b876841f6e4ca043240b607ff696a2.bindPopup(popup_26a5201c8441f6cc7ea1bec3d3b794c9)
#         ;
#
#
#
#
#             var marker_44a323fd3478b43b9fea76c55836d2d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_513a7a32bfb58eb690a211b4e43f1e17);
#
#
#         var popup_daf2f41a5b31cb23bf6f6f07b796db72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d66bafc58d3ba378b0522513b51e4cc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d66bafc58d3ba378b0522513b51e4cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d66bafc58d3ba378b0522513b51e4cc = L.map(
#                 &quot;map_6d66bafc58d3ba378b0522513b51e4cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1cbd1becab110daeee67f41b9af26eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1cbd1becab110daeee67f41b9af26eb.addTo(map_6d66bafc58d3ba378b0522513b51e4cc);
#
#
#             var feature_group_bb3946ae4af7fe701e4daeb004c6f812 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bb3946ae4af7fe701e4daeb004c6f812.addTo(map_6d66bafc58d3ba378b0522513b51e4cc);
#
#
#             var feature_group_sub_group_b20f449cabaa0676618571bbbce6d56b = L.featureGroup.subGroup(
#                 feature_group_bb3946ae4af7fe701e4daeb004c6f812
#             );
#
#
#             var marker_ceef8eb2cc97329523fd5b8ab778c05d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b20f449cabaa0676618571bbbce6d56b);
#
#
#         var popup_36954bd6740c156cbebf311b5b608580 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5997dea163d68c6dda787ee2255d83d6 = $(`&lt;div id=&quot;html_5997dea163d68c6dda787ee2255d83d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_36954bd6740c156cbebf311b5b608580.setContent(html_5997dea163d68c6dda787ee2255d83d6);
#
#
#
#         marker_ceef8eb2cc97329523fd5b8ab778c05d.bindPopup(popup_36954bd6740c156cbebf311b5b608580)
#         ;
#
#
#
#
#             var marker_e33ee1aa3a52301e8410896df77e50e3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b20f449cabaa0676618571bbbce6d56b);
#
#
#         var popup_e73e63f83c77e65380ffec5a968b413a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f93cf357cb24eaaa877408e50de13e7 = $(`&lt;div id=&quot;html_5f93cf357cb24eaaa877408e50de13e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e73e63f83c77e65380ffec5a968b413a.setContent(html_5f93cf357cb24eaaa877408e50de13e7);
#
#
#
#         marker_e33ee1aa3a52301e8410896df77e50e3.bindPopup(popup_e73e63f83c77e65380ffec5a968b413a)
#         ;
#
#
#
#
#             var marker_bf7f12717dbc833a2b4a2184445023cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b20f449cabaa0676618571bbbce6d56b);
#
#
#         var popup_bc80a1096d12b1fcc9b9f5029f136fc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99cb1aa12182b67af2110ad35bbca8ff = $(`&lt;div id=&quot;html_99cb1aa12182b67af2110ad35bbca8ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bc80a1096d12b1fcc9b9f5029f136fc1.setContent(html_99cb1aa12182b67af2110ad35bbca8ff);
#
#
#
#         marker_bf7f12717dbc833a2b4a2184445023cf.bindPopup(popup_bc80a1096d12b1fcc9b9f5029f136fc1)
#         ;
#
#
#
#
#             var marker_4db9d695f68f680bed35b6a808f5e3af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b20f449cabaa0676618571bbbce6d56b);
#
#
#         var popup_b1ba649560a0b0ee0c3ebbc1e86dd8f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cf10a0c56286a32c23e7f2bc456c334 = $(`&lt;div id=&quot;html_4cf10a0c56286a32c23e7f2bc456c334&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b1ba649560a0b0ee0c3ebbc1e86dd8f5.setContent(html_4cf10a0c56286a32c23e7f2bc456c334);
#
#
#
#         mark
