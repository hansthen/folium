# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b233772d59c2d6964533233629e5a0f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b233772d59c2d6964533233629e5a0f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b233772d59c2d6964533233629e5a0f1 = L.map(
#                 &quot;map_b233772d59c2d6964533233629e5a0f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21285dfb1fba019e07edb505e31bdea9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21285dfb1fba019e07edb505e31bdea9.addTo(map_b233772d59c2d6964533233629e5a0f1);
#
#
#             var marker_062a2c15649e4137a589ffdc0f63a171 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b233772d59c2d6964533233629e5a0f1);
#
#
#         var popup_01259c525ecb3a7f92214bdcae898fc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f1eb39b42e75680b3cbddcac4a1711a = $(`&lt;div id=&quot;html_5f1eb39b42e75680b3cbddcac4a1711a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_01259c525ecb3a7f92214bdcae898fc8.setContent(html_5f1eb39b42e75680b3cbddcac4a1711a);
#
#
#
#         marker_062a2c15649e4137a589ffdc0f63a171.bindPopup(popup_01259c525ecb3a7f92214bdcae898fc8)
#         ;
#
#
#
#
#             var marker_490727351bf318ee8f5344140e941194 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b233772d59c2d6964533233629e5a0f1);
#
#
#         var popup_822f657208e3712235eafaa06237a7ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4f2e42551525b3958ef0b7506f61b24 = $(`&lt;div id=&quot;html_d4f2e42551525b3958ef0b7506f61b24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_822f657208e3712235eafaa06237a7ca.setContent(html_d4f2e42551525b3958ef0b7506f61b24);
#
#
#
#         marker_490727351bf318ee8f5344140e941194.bindPopup(popup_822f657208e3712235eafaa06237a7ca)
#         ;
#
#
#
#
#             var marker_bc470c15502d5e4059ee0641b9d5784e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b233772d59c2d6964533233629e5a0f1);
#
#
#         var popup_fb1b5bd6015c580b83ade9c587439358 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79757b40a7e42be33b080127fb2571c4 = $(`&lt;div id=&quot;html_79757b40a7e42be33b080127fb2571c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fb1b5bd6015c580b83ade9c587439358.setContent(html_79757b40a7e42be33b080127fb2571c4);
#
#
#
#         marker_bc470c15502d5e4059ee0641b9d5784e.bindPopup(popup_fb1b5bd6015c580b83ade9c587439358)
#         ;
#
#
#
#
#             var marker_cf68667470588d165b0c360495d87631 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b233772d59c2d6964533233629e5a0f1);
#
#
#         var popup_88409e227a8c6be778fb3221a1e300b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35810df622a41444c91c2abeb4974f6a = $(`&lt;div id=&quot;html_35810df622a41444c91c2abeb4974f6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_88409e227a8c6be778fb3221a1e300b7.setContent(html_35810df622a41444c91c2abeb4974f6a);
#
#
#
#         marker_cf68667470588d165b0c360495d87631.bindPopup(popup_88409e227a8c6be778fb3221a1e300b7)
#         ;
#
#
#
#
#             var marker_de68c0c62765863cfc9604c305ebc15b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b233772d59c2d6964533233629e5a0f1);
#
#
#         var popup_3f68ec8f80898b9a1081c82aa79af5ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef4f599e93f5737674760db2eef7ca9d = $(`&lt;div id=&quot;html_ef4f599e93f5737674760db2eef7ca9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3f68ec8f80898b9a1081c82aa79af5ab.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f6c0b61e4793446367466a668b0df2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f6c0b61e4793446367466a668b0df2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f6c0b61e4793446367466a668b0df2f = L.map(
#                 &quot;map_5f6c0b61e4793446367466a668b0df2f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a15ef3c3816f4792d36bb8f7340394c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a15ef3c3816f4792d36bb8f7340394c.addTo(map_5f6c0b61e4793446367466a668b0df2f);
#
#
#             var feature_group_77e7ca351b3f5d46a3f4d40791bf5486 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3b81d01bd56f4b25dd6e8ff311fa2f2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_77e7ca351b3f5d46a3f4d40791bf5486);
#
#
#         var popup_cdc47ef6dfe7e7dc8d147ecb428f2113 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7685e19b0c760127fca7724c968ada60 = $(`&lt;div id=&quot;html_7685e19b0c760127fca7724c968ada60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cdc47ef6dfe7e7dc8d147ecb428f2113.setContent(html_7685e19b0c760127fca7724c968ada60);
#
#
#
#         marker_3b81d01bd56f4b25dd6e8ff311fa2f2d.bindPopup(popup_cdc47ef6dfe7e7dc8d147ecb428f2113)
#         ;
#
#
#
#
#             var marker_8eeb54d1a0fae3c012bae88fd974ce56 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_77e7ca351b3f5d46a3f4d40791bf5486);
#
#
#         var popup_0bef7ba42e7b1ed8097324b807a01701 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef19b0f1584cd68a1f0ab32138cd1653 = $(`&lt;div id=&quot;html_ef19b0f1584cd68a1f0ab32138cd1653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0bef7ba42e7b1ed8097324b807a01701.setContent(html_ef19b0f1584cd68a1f0ab32138cd1653);
#
#
#
#         marker_8eeb54d1a0fae3c012bae88fd974ce56.bindPopup(popup_0bef7ba42e7b1ed8097324b807a01701)
#         ;
#
#
#
#
#             var marker_062c069a7ff7c1d39c34912f33bc8190 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_77e7ca351b3f5d46a3f4d40791bf5486);
#
#
#         var popup_882d57f9de1b3954a6f0f9b11ce40301 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f2046b2f4cf776aa1609eb430a22dd0 = $(`&lt;div id=&quot;html_4f2046b2f4cf776aa1609eb430a22dd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_882d57f9de1b3954a6f0f9b11ce40301.setContent(html_4f2046b2f4cf776aa1609eb430a22dd0);
#
#
#
#         marker_062c069a7ff7c1d39c34912f33bc8190.bindPopup(popup_882d57f9de1b3954a6f0f9b11ce40301)
#         ;
#
#
#
#
#             var marker_7f23fe4cfc27aae36e1f386f5c104e22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_77e7ca351b3f5d46a3f4d40791bf5486);
#
#
#         var popup_0381cb188a4504afa53940f36f7b4412 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_810e58426f0f49fef25c0792411bf473 = $(`&lt;div id=&quot;html_810e58426f0f49fef25c0792411bf473&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0381cb188a4504afa53940f36f7b4412.setContent(html_810e58426f0f49fef25c0792411bf473);
#
#
#
#         marker_7f23fe4cfc27aae36e1f386f5c104e22.bindPopup(popup_0381cb188a4504afa53940f36f7b4412)
#         ;
#
#
#
#
#             var marker_11bda5a21c89677c9a54ba3e12acf290 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_77e7ca351b3f5d46a3f4d40791bf5486);
#
#
#         var popup_eea0587b0bac0e1eb9b407676eaac202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3bcc0b173c74b51faef6bcd405cdeeb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3bcc0b173c74b51faef6bcd405cdeeb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3bcc0b173c74b51faef6bcd405cdeeb0 = L.map(
#                 &quot;map_3bcc0b173c74b51faef6bcd405cdeeb0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c29b8d4eeea0c68106cddf9dc69ccf31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c29b8d4eeea0c68106cddf9dc69ccf31.addTo(map_3bcc0b173c74b51faef6bcd405cdeeb0);
#
#
#             var feature_group_e79d4ec82c5cc61700b440b1c8563b5c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e79d4ec82c5cc61700b440b1c8563b5c.addTo(map_3bcc0b173c74b51faef6bcd405cdeeb0);
#
#
#             var feature_group_sub_group_5eb1b494d03ac2f92391a3147c8ffbed = L.featureGroup.subGroup(
#                 feature_group_e79d4ec82c5cc61700b440b1c8563b5c
#             );
#
#
#             var marker_5f06d79e42304225ccac81101ec0118d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5eb1b494d03ac2f92391a3147c8ffbed);
#
#
#         var popup_441853c91e47a692bbc8f8d385b89a48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd6533c689eb9cb631efb0d2c2877195 = $(`&lt;div id=&quot;html_cd6533c689eb9cb631efb0d2c2877195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_441853c91e47a692bbc8f8d385b89a48.setContent(html_cd6533c689eb9cb631efb0d2c2877195);
#
#
#
#         marker_5f06d79e42304225ccac81101ec0118d.bindPopup(popup_441853c91e47a692bbc8f8d385b89a48)
#         ;
#
#
#
#
#             var marker_6b0082ebafd1f22a0a834699763dca3d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5eb1b494d03ac2f92391a3147c8ffbed);
#
#
#         var popup_e86af9a5afd004957fb82f48f3650ba6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6428115881dc2f6e2d1701cc9c7b6fb8 = $(`&lt;div id=&quot;html_6428115881dc2f6e2d1701cc9c7b6fb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e86af9a5afd004957fb82f48f3650ba6.setContent(html_6428115881dc2f6e2d1701cc9c7b6fb8);
#
#
#
#         marker_6b0082ebafd1f22a0a834699763dca3d.bindPopup(popup_e86af9a5afd004957fb82f48f3650ba6)
#         ;
#
#
#
#
#             var marker_0ba505dc092d9a7b33d35968f4e4db91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5eb1b494d03ac2f92391a3147c8ffbed);
#
#
#         var popup_31ec2ae3f0c2482f20d89b00e8a59633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1680adcaa52767ae65038f78dcb1f54 = $(`&lt;div id=&quot;html_d1680adcaa52767ae65038f78dcb1f54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_31ec2ae3f0c2482f20d89b00e8a59633.setContent(html_d1680adcaa52767ae65038f78dcb1f54);
#
#
#
#         marker_0ba505dc092d9a7b33d35968f4e4db91.bindPopup(popup_31ec2ae3f0c2482f20d89b00e8a59633)
#         ;
#
#
#
#
#             var marker_359a1675c007a67634d9294cc9911fa1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5eb1b494d03ac2f92391a3147c8ffbed);
#
#
#         var popup_e7a5b1e784c7e67f5a37ae7f1b8cd4f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14518489ece0c59cbd3d7d6ab9386e11 = $(`&lt;div id=&quot;html_14518489ece0c59cbd3d7d6ab9386e11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e7a5b1e784c7e67f5a37ae7f1b8cd4f6.setContent(html_14518489ece0c59cbd3d7d6ab9386e11);
#
#
#
#         marker_
