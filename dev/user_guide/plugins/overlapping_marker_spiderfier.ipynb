# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ad3ea6dbbc29c97d077f952cda7262d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ad3ea6dbbc29c97d077f952cda7262d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ad3ea6dbbc29c97d077f952cda7262d = L.map(
#                 &quot;map_5ad3ea6dbbc29c97d077f952cda7262d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a25a534ebca537f021709baba19b089b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a25a534ebca537f021709baba19b089b.addTo(map_5ad3ea6dbbc29c97d077f952cda7262d);
#
#
#             var marker_3f8138bf6c043fd8d4f19f2f77c51f15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5ad3ea6dbbc29c97d077f952cda7262d);
#
#
#         var popup_11c71a7d63af7e97e02b7b44b40e3af2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe4b170c35cfedb4a5719143c54e71d3 = $(`&lt;div id=&quot;html_fe4b170c35cfedb4a5719143c54e71d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_11c71a7d63af7e97e02b7b44b40e3af2.setContent(html_fe4b170c35cfedb4a5719143c54e71d3);
#
#
#
#         marker_3f8138bf6c043fd8d4f19f2f77c51f15.bindPopup(popup_11c71a7d63af7e97e02b7b44b40e3af2)
#         ;
#
#
#
#
#             var marker_e04a2b3fe2a2dff7d6504fbec006ad24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5ad3ea6dbbc29c97d077f952cda7262d);
#
#
#         var popup_de4eeb39d35de85ee588fa845dee38ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03d0b12cc4c8a0c08a0ff481df6e1310 = $(`&lt;div id=&quot;html_03d0b12cc4c8a0c08a0ff481df6e1310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_de4eeb39d35de85ee588fa845dee38ce.setContent(html_03d0b12cc4c8a0c08a0ff481df6e1310);
#
#
#
#         marker_e04a2b3fe2a2dff7d6504fbec006ad24.bindPopup(popup_de4eeb39d35de85ee588fa845dee38ce)
#         ;
#
#
#
#
#             var marker_bf5825500d92a2180c6023513d752297 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5ad3ea6dbbc29c97d077f952cda7262d);
#
#
#         var popup_3a8754298f8a5db683ada01def9eba22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39a7181312d035b11afff7ec842f2921 = $(`&lt;div id=&quot;html_39a7181312d035b11afff7ec842f2921&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3a8754298f8a5db683ada01def9eba22.setContent(html_39a7181312d035b11afff7ec842f2921);
#
#
#
#         marker_bf5825500d92a2180c6023513d752297.bindPopup(popup_3a8754298f8a5db683ada01def9eba22)
#         ;
#
#
#
#
#             var marker_41ad04b856566226ec6cc5ccaa0d032e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5ad3ea6dbbc29c97d077f952cda7262d);
#
#
#         var popup_7b8108354facbe0f3937b90d31d59182 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_917dfbd0c7c24bf1df583d93a4fc96c6 = $(`&lt;div id=&quot;html_917dfbd0c7c24bf1df583d93a4fc96c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7b8108354facbe0f3937b90d31d59182.setContent(html_917dfbd0c7c24bf1df583d93a4fc96c6);
#
#
#
#         marker_41ad04b856566226ec6cc5ccaa0d032e.bindPopup(popup_7b8108354facbe0f3937b90d31d59182)
#         ;
#
#
#
#
#             var marker_8315496c31dbaf03cf2690e81f1d0838 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5ad3ea6dbbc29c97d077f952cda7262d);
#
#
#         var popup_30c4f34847393292372ce943b8f127d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a229fa91332ac6576a9402550d8fcee = $(`&lt;div id=&quot;html_5a229fa91332ac6576a9402550d8fcee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_30c4f34847393292372ce943b8f127

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00ae309bc35204310450279f9724489a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00ae309bc35204310450279f9724489a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00ae309bc35204310450279f9724489a = L.map(
#                 &quot;map_00ae309bc35204310450279f9724489a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64738d01050b9fdb784e9cb633714d8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64738d01050b9fdb784e9cb633714d8c.addTo(map_00ae309bc35204310450279f9724489a);
#
#
#             var feature_group_e378f93e4f5ba1cea9466abd9ebf0578 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1e958daf36d36be58f5874fc0f998ecc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e378f93e4f5ba1cea9466abd9ebf0578);
#
#
#         var popup_84a6d13eb449d1f24a5166aaea3dd2d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9109f730b0f62adbbb763717945ee07 = $(`&lt;div id=&quot;html_c9109f730b0f62adbbb763717945ee07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_84a6d13eb449d1f24a5166aaea3dd2d5.setContent(html_c9109f730b0f62adbbb763717945ee07);
#
#
#
#         marker_1e958daf36d36be58f5874fc0f998ecc.bindPopup(popup_84a6d13eb449d1f24a5166aaea3dd2d5)
#         ;
#
#
#
#
#             var marker_f35323cd80f0c454106e45be929b22b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e378f93e4f5ba1cea9466abd9ebf0578);
#
#
#         var popup_b05b64f2ae407934682ce53b8a467773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f88fdb53958955c789a216a79f4dfa78 = $(`&lt;div id=&quot;html_f88fdb53958955c789a216a79f4dfa78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b05b64f2ae407934682ce53b8a467773.setContent(html_f88fdb53958955c789a216a79f4dfa78);
#
#
#
#         marker_f35323cd80f0c454106e45be929b22b3.bindPopup(popup_b05b64f2ae407934682ce53b8a467773)
#         ;
#
#
#
#
#             var marker_c9886abf1c2507aabb6707c1421283c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e378f93e4f5ba1cea9466abd9ebf0578);
#
#
#         var popup_4665ba75c32aa65a853480369e1fad14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89e17cee11430fdea3b981aeb5e60e8d = $(`&lt;div id=&quot;html_89e17cee11430fdea3b981aeb5e60e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4665ba75c32aa65a853480369e1fad14.setContent(html_89e17cee11430fdea3b981aeb5e60e8d);
#
#
#
#         marker_c9886abf1c2507aabb6707c1421283c1.bindPopup(popup_4665ba75c32aa65a853480369e1fad14)
#         ;
#
#
#
#
#             var marker_7563ad2c99bde4efa489079aa9b03d19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e378f93e4f5ba1cea9466abd9ebf0578);
#
#
#         var popup_a0e8005f8935be1541d133e821dd422d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d56be192bee7b1eb315c3dbd4e742bf = $(`&lt;div id=&quot;html_1d56be192bee7b1eb315c3dbd4e742bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a0e8005f8935be1541d133e821dd422d.setContent(html_1d56be192bee7b1eb315c3dbd4e742bf);
#
#
#
#         marker_7563ad2c99bde4efa489079aa9b03d19.bindPopup(popup_a0e8005f8935be1541d133e821dd422d)
#         ;
#
#
#
#
#             var marker_600588268b39696416fb75d55d96e6ea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e378f93e4f5ba1cea9466abd9ebf0578);
#
#
#         var popup_accc8afcc672f072d8bd43b27f9801e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3482e0e145ae8e5e23e7b4304bd96f82 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3482e0e145ae8e5e23e7b4304bd96f82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3482e0e145ae8e5e23e7b4304bd96f82 = L.map(
#                 &quot;map_3482e0e145ae8e5e23e7b4304bd96f82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84156e3c0929a86341cbad02a33c21c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84156e3c0929a86341cbad02a33c21c3.addTo(map_3482e0e145ae8e5e23e7b4304bd96f82);
#
#
#             var feature_group_c7bfb10d89c74d365e47270effd74d07 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c7bfb10d89c74d365e47270effd74d07.addTo(map_3482e0e145ae8e5e23e7b4304bd96f82);
#
#
#             var feature_group_sub_group_8be8e2e9b1cb5531f2d2be5ee8a3efb2 = L.featureGroup.subGroup(
#                 feature_group_c7bfb10d89c74d365e47270effd74d07
#             );
#
#
#             var marker_798d832a4cc95e02dcfb750b71a831ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be8e2e9b1cb5531f2d2be5ee8a3efb2);
#
#
#         var popup_9f6cf28fb1fdaff4de560b0de46b8b9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c939c59b70b6a377f32317ae7345325 = $(`&lt;div id=&quot;html_5c939c59b70b6a377f32317ae7345325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9f6cf28fb1fdaff4de560b0de46b8b9b.setContent(html_5c939c59b70b6a377f32317ae7345325);
#
#
#
#         marker_798d832a4cc95e02dcfb750b71a831ea.bindPopup(popup_9f6cf28fb1fdaff4de560b0de46b8b9b)
#         ;
#
#
#
#
#             var marker_e92060e6ec352082955f3c25fca7c508 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be8e2e9b1cb5531f2d2be5ee8a3efb2);
#
#
#         var popup_3cd7f671fb69e08edc19b0c5a4111313 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec72ab73ab41e11e1708d3b70599a2ad = $(`&lt;div id=&quot;html_ec72ab73ab41e11e1708d3b70599a2ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3cd7f671fb69e08edc19b0c5a4111313.setContent(html_ec72ab73ab41e11e1708d3b70599a2ad);
#
#
#
#         marker_e92060e6ec352082955f3c25fca7c508.bindPopup(popup_3cd7f671fb69e08edc19b0c5a4111313)
#         ;
#
#
#
#
#             var marker_69f3821b4287c9e350d5deff46343196 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be8e2e9b1cb5531f2d2be5ee8a3efb2);
#
#
#         var popup_0734aad61f4bace53a58dbdca49a7921 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3057c87f8852169143f473d2960bc3c = $(`&lt;div id=&quot;html_c3057c87f8852169143f473d2960bc3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0734aad61f4bace53a58dbdca49a7921.setContent(html_c3057c87f8852169143f473d2960bc3c);
#
#
#
#         marker_69f3821b4287c9e350d5deff46343196.bindPopup(popup_0734aad61f4bace53a58dbdca49a7921)
#         ;
#
#
#
#
#             var marker_db236ced002c015d95dd913e8d83872c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8be8e2e9b1cb5531f2d2be5ee8a3efb2);
#
#
#         var popup_07127a525be666f77780e48030e5f71e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33f9d4cdd3bd0ae52580fbc97cce8e8d = $(`&lt;div id=&quot;html_33f9d4cdd3bd0ae52580fbc97cce8e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_07127a525be666f77780e48030e5f71e.setContent(html_33f9d4cdd3bd0ae52580fbc97cce8e8d);
#
#
#
#         mark
