# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f856cace69c93dbebefdd8aa0d2e498 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f856cace69c93dbebefdd8aa0d2e498&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f856cace69c93dbebefdd8aa0d2e498 = L.map(
#                 &quot;map_8f856cace69c93dbebefdd8aa0d2e498&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5dbcf4e1d4e061e6322c75ea9b41d18c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5dbcf4e1d4e061e6322c75ea9b41d18c.addTo(map_8f856cace69c93dbebefdd8aa0d2e498);
#
#
#             var marker_0993b0316273dd9156f175ba393cd277 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8f856cace69c93dbebefdd8aa0d2e498);
#
#
#         var popup_9f41e6dee77dcfb2e3f2a0a4c3eb9e55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51df20f66ff8354e5a910d2cdf536afc = $(`&lt;div id=&quot;html_51df20f66ff8354e5a910d2cdf536afc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9f41e6dee77dcfb2e3f2a0a4c3eb9e55.setContent(html_51df20f66ff8354e5a910d2cdf536afc);
#
#
#
#         marker_0993b0316273dd9156f175ba393cd277.bindPopup(popup_9f41e6dee77dcfb2e3f2a0a4c3eb9e55)
#         ;
#
#
#
#
#             var marker_619241bc195e9bff064d1c4d692c71ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8f856cace69c93dbebefdd8aa0d2e498);
#
#
#         var popup_6bb64473bc73c799baa4210b5f6c0ca1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_741f657319b03f4ac75abe6448491a1f = $(`&lt;div id=&quot;html_741f657319b03f4ac75abe6448491a1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6bb64473bc73c799baa4210b5f6c0ca1.setContent(html_741f657319b03f4ac75abe6448491a1f);
#
#
#
#         marker_619241bc195e9bff064d1c4d692c71ab.bindPopup(popup_6bb64473bc73c799baa4210b5f6c0ca1)
#         ;
#
#
#
#
#             var marker_7a8949ec4598fc595aebf005d105bc34 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8f856cace69c93dbebefdd8aa0d2e498);
#
#
#         var popup_9e20c22c11e40b7f9a6aaaf87173037a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_557779754c19fccdab18e22f8c63e5b7 = $(`&lt;div id=&quot;html_557779754c19fccdab18e22f8c63e5b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9e20c22c11e40b7f9a6aaaf87173037a.setContent(html_557779754c19fccdab18e22f8c63e5b7);
#
#
#
#         marker_7a8949ec4598fc595aebf005d105bc34.bindPopup(popup_9e20c22c11e40b7f9a6aaaf87173037a)
#         ;
#
#
#
#
#             var marker_1ac18db0b130ca51ea473e771cc8b6a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8f856cace69c93dbebefdd8aa0d2e498);
#
#
#         var popup_699c2bcfbbfdc2308c43a35619181977 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7891b480393123ffd4a5da70f0d51a84 = $(`&lt;div id=&quot;html_7891b480393123ffd4a5da70f0d51a84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_699c2bcfbbfdc2308c43a35619181977.setContent(html_7891b480393123ffd4a5da70f0d51a84);
#
#
#
#         marker_1ac18db0b130ca51ea473e771cc8b6a5.bindPopup(popup_699c2bcfbbfdc2308c43a35619181977)
#         ;
#
#
#
#
#             var marker_7f65929f16895b30e7d99ebcccdf1010 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8f856cace69c93dbebefdd8aa0d2e498);
#
#
#         var popup_1c97517d37602e04ac7eab8e9489bf1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d757acb5e0a41708c2adf264e76fdab3 = $(`&lt;div id=&quot;html_d757acb5e0a41708c2adf264e76fdab3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1c97517d37602e04ac7eab8e9489bf1a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88335424cd97be0af829404474cade4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88335424cd97be0af829404474cade4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88335424cd97be0af829404474cade4c = L.map(
#                 &quot;map_88335424cd97be0af829404474cade4c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd3ec63a1c3072e19dce33cc436cd1b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd3ec63a1c3072e19dce33cc436cd1b0.addTo(map_88335424cd97be0af829404474cade4c);
#
#
#             var feature_group_8c1db15653d84382a646b4b7b398ff1a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1aba1aa326e56e1ce15f3c645be3472e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8c1db15653d84382a646b4b7b398ff1a);
#
#
#         var popup_dd3a1fa73b03279332310f5f54e10b56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6127d4e7e5581ca92dc41fbab3c2de4 = $(`&lt;div id=&quot;html_a6127d4e7e5581ca92dc41fbab3c2de4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dd3a1fa73b03279332310f5f54e10b56.setContent(html_a6127d4e7e5581ca92dc41fbab3c2de4);
#
#
#
#         marker_1aba1aa326e56e1ce15f3c645be3472e.bindPopup(popup_dd3a1fa73b03279332310f5f54e10b56)
#         ;
#
#
#
#
#             var marker_6f135a279fcded23cc998f4ca7f73b85 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8c1db15653d84382a646b4b7b398ff1a);
#
#
#         var popup_7da78d4131a25a3b72619ad4b10c698e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc01484a0884ddc2a30323f20f6e9929 = $(`&lt;div id=&quot;html_bc01484a0884ddc2a30323f20f6e9929&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7da78d4131a25a3b72619ad4b10c698e.setContent(html_bc01484a0884ddc2a30323f20f6e9929);
#
#
#
#         marker_6f135a279fcded23cc998f4ca7f73b85.bindPopup(popup_7da78d4131a25a3b72619ad4b10c698e)
#         ;
#
#
#
#
#             var marker_1d9e58a87fb8ad7ed1e06a5cc78dec1b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8c1db15653d84382a646b4b7b398ff1a);
#
#
#         var popup_7762ec073ab5fe87ab771a9da6232055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_339bfbdcc1566e4fc59f8f4ac0f023d3 = $(`&lt;div id=&quot;html_339bfbdcc1566e4fc59f8f4ac0f023d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7762ec073ab5fe87ab771a9da6232055.setContent(html_339bfbdcc1566e4fc59f8f4ac0f023d3);
#
#
#
#         marker_1d9e58a87fb8ad7ed1e06a5cc78dec1b.bindPopup(popup_7762ec073ab5fe87ab771a9da6232055)
#         ;
#
#
#
#
#             var marker_11a807680c3dbba3a2c6af19eb3187eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8c1db15653d84382a646b4b7b398ff1a);
#
#
#         var popup_0b7a22e7064935e7d0bb55d6418d4a81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6f6a168bb2d5e2cc794cf8c092f423d = $(`&lt;div id=&quot;html_e6f6a168bb2d5e2cc794cf8c092f423d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0b7a22e7064935e7d0bb55d6418d4a81.setContent(html_e6f6a168bb2d5e2cc794cf8c092f423d);
#
#
#
#         marker_11a807680c3dbba3a2c6af19eb3187eb.bindPopup(popup_0b7a22e7064935e7d0bb55d6418d4a81)
#         ;
#
#
#
#
#             var marker_a47494d62907fd26c5fe80fb968b43f8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8c1db15653d84382a646b4b7b398ff1a);
#
#
#         var popup_a00958a65a9e11e0c148508597f113d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c2fb2c02b676e65e8aa931b4bbce5e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c2fb2c02b676e65e8aa931b4bbce5e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c2fb2c02b676e65e8aa931b4bbce5e7 = L.map(
#                 &quot;map_7c2fb2c02b676e65e8aa931b4bbce5e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f57e21cd3a7192fa20940c342568344d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f57e21cd3a7192fa20940c342568344d.addTo(map_7c2fb2c02b676e65e8aa931b4bbce5e7);
#
#
#             var feature_group_535f49ab88716e5261f1e296727e02c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_535f49ab88716e5261f1e296727e02c2.addTo(map_7c2fb2c02b676e65e8aa931b4bbce5e7);
#
#
#             var feature_group_sub_group_050ef97477aaf59390acc1460b2dc99e = L.featureGroup.subGroup(
#                 feature_group_535f49ab88716e5261f1e296727e02c2
#             );
#
#
#             var marker_57ac8fa427bee3adeca52947917f19e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_050ef97477aaf59390acc1460b2dc99e);
#
#
#         var popup_cd84ee77639a37d7cb50503cf9d5aa4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2619d12e4e17db776ea5194f5088f7e0 = $(`&lt;div id=&quot;html_2619d12e4e17db776ea5194f5088f7e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cd84ee77639a37d7cb50503cf9d5aa4f.setContent(html_2619d12e4e17db776ea5194f5088f7e0);
#
#
#
#         marker_57ac8fa427bee3adeca52947917f19e8.bindPopup(popup_cd84ee77639a37d7cb50503cf9d5aa4f)
#         ;
#
#
#
#
#             var marker_b08f04e6f5c7c1891d0725ef56829772 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_050ef97477aaf59390acc1460b2dc99e);
#
#
#         var popup_47a4d684c377bb3f8490b4a172008bc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_640c00181425f59d5c97869697bb1bb5 = $(`&lt;div id=&quot;html_640c00181425f59d5c97869697bb1bb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_47a4d684c377bb3f8490b4a172008bc5.setContent(html_640c00181425f59d5c97869697bb1bb5);
#
#
#
#         marker_b08f04e6f5c7c1891d0725ef56829772.bindPopup(popup_47a4d684c377bb3f8490b4a172008bc5)
#         ;
#
#
#
#
#             var marker_779caa39c31e2cd728388eead7ed30da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_050ef97477aaf59390acc1460b2dc99e);
#
#
#         var popup_72aae2a2cf557a70ebc2eae288d33785 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f50c0830d533a7bd5574ec159cd485bc = $(`&lt;div id=&quot;html_f50c0830d533a7bd5574ec159cd485bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_72aae2a2cf557a70ebc2eae288d33785.setContent(html_f50c0830d533a7bd5574ec159cd485bc);
#
#
#
#         marker_779caa39c31e2cd728388eead7ed30da.bindPopup(popup_72aae2a2cf557a70ebc2eae288d33785)
#         ;
#
#
#
#
#             var marker_c8376ac02bfc941a3c4db1ec72c24acc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_050ef97477aaf59390acc1460b2dc99e);
#
#
#         var popup_0e9e1db460a3116cac6a5fd87bbd63f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16e4208803b784ace9b611dd6d8bf16e = $(`&lt;div id=&quot;html_16e4208803b784ace9b611dd6d8bf16e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0e9e1db460a3116cac6a5fd87bbd63f5.setContent(html_16e4208803b784ace9b611dd6d8bf16e);
#
#
#
#         marker_
