# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_010d4b90ba916d125fa1b588275cc017 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_010d4b90ba916d125fa1b588275cc017&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_010d4b90ba916d125fa1b588275cc017 = L.map(
#                 &quot;map_010d4b90ba916d125fa1b588275cc017&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e160060904f052d879b03b7979cb457b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e160060904f052d879b03b7979cb457b.addTo(map_010d4b90ba916d125fa1b588275cc017);
#
#
#             var marker_f34bdd1382723cda7223cceae22c3946 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_010d4b90ba916d125fa1b588275cc017);
#
#
#         var popup_812cf5474dc901465efa4865130edca6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8678acc969be08ce8873d453345181f1 = $(`&lt;div id=&quot;html_8678acc969be08ce8873d453345181f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_812cf5474dc901465efa4865130edca6.setContent(html_8678acc969be08ce8873d453345181f1);
#
#
#
#         marker_f34bdd1382723cda7223cceae22c3946.bindPopup(popup_812cf5474dc901465efa4865130edca6)
#         ;
#
#
#
#
#             var marker_e986f8a109bcf67eeb8547f4fb8a4fd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_010d4b90ba916d125fa1b588275cc017);
#
#
#         var popup_48f5e793a843241ea444e6335f70d5be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d6cadb6c1e2b6ef3e5792e5095f6715 = $(`&lt;div id=&quot;html_7d6cadb6c1e2b6ef3e5792e5095f6715&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_48f5e793a843241ea444e6335f70d5be.setContent(html_7d6cadb6c1e2b6ef3e5792e5095f6715);
#
#
#
#         marker_e986f8a109bcf67eeb8547f4fb8a4fd6.bindPopup(popup_48f5e793a843241ea444e6335f70d5be)
#         ;
#
#
#
#
#             var marker_017709680a1f670d6a5b7190ed93aa7a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_010d4b90ba916d125fa1b588275cc017);
#
#
#         var popup_15779f9e58bbefd2aece82df28322a0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1456951d0590449e61d6a7eb0e92f30f = $(`&lt;div id=&quot;html_1456951d0590449e61d6a7eb0e92f30f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_15779f9e58bbefd2aece82df28322a0c.setContent(html_1456951d0590449e61d6a7eb0e92f30f);
#
#
#
#         marker_017709680a1f670d6a5b7190ed93aa7a.bindPopup(popup_15779f9e58bbefd2aece82df28322a0c)
#         ;
#
#
#
#
#             var marker_97fd69cc49a465f44bb41c887247cfae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_010d4b90ba916d125fa1b588275cc017);
#
#
#         var popup_8f5fa6a160b54454947d4e3f8b1b9399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27bf6039d2542b94908dd1d7fc66d1a3 = $(`&lt;div id=&quot;html_27bf6039d2542b94908dd1d7fc66d1a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8f5fa6a160b54454947d4e3f8b1b9399.setContent(html_27bf6039d2542b94908dd1d7fc66d1a3);
#
#
#
#         marker_97fd69cc49a465f44bb41c887247cfae.bindPopup(popup_8f5fa6a160b54454947d4e3f8b1b9399)
#         ;
#
#
#
#
#             var marker_a30d3312a467395afaf1941473b82b62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_010d4b90ba916d125fa1b588275cc017);
#
#
#         var popup_b418506b702daff33a9d8e25eab61c16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63b4aed411192a998d8fba9d5165d3fe = $(`&lt;div id=&quot;html_63b4aed411192a998d8fba9d5165d3fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b418506b702daff33a9d8e25eab61c16.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20c3b2bd3a2943ca94fa7031b35dd0c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20c3b2bd3a2943ca94fa7031b35dd0c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20c3b2bd3a2943ca94fa7031b35dd0c7 = L.map(
#                 &quot;map_20c3b2bd3a2943ca94fa7031b35dd0c7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79f0d7322c87d868a4e90e1aabf176dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79f0d7322c87d868a4e90e1aabf176dc.addTo(map_20c3b2bd3a2943ca94fa7031b35dd0c7);
#
#
#             var feature_group_0aeadb294c9c2b59099fba2df94c4133 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_60e370b6def547b9d7b10b125e53682c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0aeadb294c9c2b59099fba2df94c4133);
#
#
#         var popup_c3b0ac8b0ac10fe35bf8ab544e697ca1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ad5410fd36c2d74821aea5b5501e401 = $(`&lt;div id=&quot;html_3ad5410fd36c2d74821aea5b5501e401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c3b0ac8b0ac10fe35bf8ab544e697ca1.setContent(html_3ad5410fd36c2d74821aea5b5501e401);
#
#
#
#         marker_60e370b6def547b9d7b10b125e53682c.bindPopup(popup_c3b0ac8b0ac10fe35bf8ab544e697ca1)
#         ;
#
#
#
#
#             var marker_8e3d7ab3b2a9198c76fa19e48121fe59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0aeadb294c9c2b59099fba2df94c4133);
#
#
#         var popup_6292b6d9a95f0f0675759f4923f49267 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7937317125f71ec5fb0844aecc9b632a = $(`&lt;div id=&quot;html_7937317125f71ec5fb0844aecc9b632a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6292b6d9a95f0f0675759f4923f49267.setContent(html_7937317125f71ec5fb0844aecc9b632a);
#
#
#
#         marker_8e3d7ab3b2a9198c76fa19e48121fe59.bindPopup(popup_6292b6d9a95f0f0675759f4923f49267)
#         ;
#
#
#
#
#             var marker_e4662d945cc16ebf5c428be2c982f88f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0aeadb294c9c2b59099fba2df94c4133);
#
#
#         var popup_0c7b47e4e01dc21f353d5f907dd565b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7553154ba6aa936bdc0c22f942fa5a10 = $(`&lt;div id=&quot;html_7553154ba6aa936bdc0c22f942fa5a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0c7b47e4e01dc21f353d5f907dd565b1.setContent(html_7553154ba6aa936bdc0c22f942fa5a10);
#
#
#
#         marker_e4662d945cc16ebf5c428be2c982f88f.bindPopup(popup_0c7b47e4e01dc21f353d5f907dd565b1)
#         ;
#
#
#
#
#             var marker_695838071f88e75301aad078e7e3041b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0aeadb294c9c2b59099fba2df94c4133);
#
#
#         var popup_5556c5a1b46444f46cf0979167d3d932 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f295253e036c795c756424ff563ec94 = $(`&lt;div id=&quot;html_4f295253e036c795c756424ff563ec94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5556c5a1b46444f46cf0979167d3d932.setContent(html_4f295253e036c795c756424ff563ec94);
#
#
#
#         marker_695838071f88e75301aad078e7e3041b.bindPopup(popup_5556c5a1b46444f46cf0979167d3d932)
#         ;
#
#
#
#
#             var marker_b8d843c3875283925e082c42ce48661c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0aeadb294c9c2b59099fba2df94c4133);
#
#
#         var popup_d5abe88e1132c61d0c73da20fa90197a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27a4f57249d06b83b339f14912fd4dc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27a4f57249d06b83b339f14912fd4dc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27a4f57249d06b83b339f14912fd4dc8 = L.map(
#                 &quot;map_27a4f57249d06b83b339f14912fd4dc8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bbb0e0c7c472d45cf7a8303ddc62ccb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bbb0e0c7c472d45cf7a8303ddc62ccb.addTo(map_27a4f57249d06b83b339f14912fd4dc8);
#
#
#             var feature_group_bbcc843567c4c6bd38f28be1c30b03b2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bbcc843567c4c6bd38f28be1c30b03b2.addTo(map_27a4f57249d06b83b339f14912fd4dc8);
#
#
#             var feature_group_sub_group_100c8139ea0646a09f4ac9c566acf81d = L.featureGroup.subGroup(
#                 feature_group_bbcc843567c4c6bd38f28be1c30b03b2
#             );
#
#
#             var marker_f8d08b9f3e8333d34abd372fd1980f50 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_100c8139ea0646a09f4ac9c566acf81d);
#
#
#         var popup_65368239381cc378da9a144477deb296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_382ad4dbb46d2a9e6ca248badf1119e9 = $(`&lt;div id=&quot;html_382ad4dbb46d2a9e6ca248badf1119e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_65368239381cc378da9a144477deb296.setContent(html_382ad4dbb46d2a9e6ca248badf1119e9);
#
#
#
#         marker_f8d08b9f3e8333d34abd372fd1980f50.bindPopup(popup_65368239381cc378da9a144477deb296)
#         ;
#
#
#
#
#             var marker_f171ad8f3ca387068f7c4b94511a9a3c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_100c8139ea0646a09f4ac9c566acf81d);
#
#
#         var popup_aa9ba99951ea3c2c5bb9ee94e8c704d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44254656898770904008f5a81a9f0b1e = $(`&lt;div id=&quot;html_44254656898770904008f5a81a9f0b1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aa9ba99951ea3c2c5bb9ee94e8c704d0.setContent(html_44254656898770904008f5a81a9f0b1e);
#
#
#
#         marker_f171ad8f3ca387068f7c4b94511a9a3c.bindPopup(popup_aa9ba99951ea3c2c5bb9ee94e8c704d0)
#         ;
#
#
#
#
#             var marker_aa57021b8fdec271ec5ad72f66b5e7d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_100c8139ea0646a09f4ac9c566acf81d);
#
#
#         var popup_1c6bf719d81f77859d6b4efcea14965a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad04833b04383363d7d1ef9bbdc6c503 = $(`&lt;div id=&quot;html_ad04833b04383363d7d1ef9bbdc6c503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1c6bf719d81f77859d6b4efcea14965a.setContent(html_ad04833b04383363d7d1ef9bbdc6c503);
#
#
#
#         marker_aa57021b8fdec271ec5ad72f66b5e7d0.bindPopup(popup_1c6bf719d81f77859d6b4efcea14965a)
#         ;
#
#
#
#
#             var marker_ee17192385e6dcc339abcc3ad28c9721 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_100c8139ea0646a09f4ac9c566acf81d);
#
#
#         var popup_63adaf08e6eebb13f9dcd726e565e056 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb990ddb40d41d9902212225231980c3 = $(`&lt;div id=&quot;html_fb990ddb40d41d9902212225231980c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_63adaf08e6eebb13f9dcd726e565e056.setContent(html_fb990ddb40d41d9902212225231980c3);
#
#
#
#         marker_
