# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_338e832519fa97edb27088fe2cea7bc9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_338e832519fa97edb27088fe2cea7bc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_338e832519fa97edb27088fe2cea7bc9 = L.map(
#                 &quot;map_338e832519fa97edb27088fe2cea7bc9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1758d678a87cbe588d549eb1ddb3b39f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1758d678a87cbe588d549eb1ddb3b39f.addTo(map_338e832519fa97edb27088fe2cea7bc9);
#
#
#             var marker_4dd5962d581c7d71627759f33da021e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_338e832519fa97edb27088fe2cea7bc9);
#
#
#         var popup_15d7e29e78ae80ee9fb88a075bc37386 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90ef95576e8e64da03c69ffef03a87a3 = $(`&lt;div id=&quot;html_90ef95576e8e64da03c69ffef03a87a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_15d7e29e78ae80ee9fb88a075bc37386.setContent(html_90ef95576e8e64da03c69ffef03a87a3);
#
#
#
#         marker_4dd5962d581c7d71627759f33da021e4.bindPopup(popup_15d7e29e78ae80ee9fb88a075bc37386)
#         ;
#
#
#
#
#             var marker_ef3902d25fd5ed864ebb8cd17513d091 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_338e832519fa97edb27088fe2cea7bc9);
#
#
#         var popup_ff7e308f6dc5fdd498bd5650c3495ddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e3fbbaeadd09712fea60d964ec125cb = $(`&lt;div id=&quot;html_6e3fbbaeadd09712fea60d964ec125cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ff7e308f6dc5fdd498bd5650c3495ddc.setContent(html_6e3fbbaeadd09712fea60d964ec125cb);
#
#
#
#         marker_ef3902d25fd5ed864ebb8cd17513d091.bindPopup(popup_ff7e308f6dc5fdd498bd5650c3495ddc)
#         ;
#
#
#
#
#             var marker_f8f996fa933fff5e16bff13f52ca873e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_338e832519fa97edb27088fe2cea7bc9);
#
#
#         var popup_b0fd4bfde8ec2839ad9cf479738147ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_704866f59fe092af2df79fd704bd059c = $(`&lt;div id=&quot;html_704866f59fe092af2df79fd704bd059c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b0fd4bfde8ec2839ad9cf479738147ea.setContent(html_704866f59fe092af2df79fd704bd059c);
#
#
#
#         marker_f8f996fa933fff5e16bff13f52ca873e.bindPopup(popup_b0fd4bfde8ec2839ad9cf479738147ea)
#         ;
#
#
#
#
#             var marker_2c49adbbb571ba08ae4c0be6cede2a91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_338e832519fa97edb27088fe2cea7bc9);
#
#
#         var popup_ba45c2dfe6799ee414770c7108306a56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e81c56a92761a301ae80a746621d40ff = $(`&lt;div id=&quot;html_e81c56a92761a301ae80a746621d40ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ba45c2dfe6799ee414770c7108306a56.setContent(html_e81c56a92761a301ae80a746621d40ff);
#
#
#
#         marker_2c49adbbb571ba08ae4c0be6cede2a91.bindPopup(popup_ba45c2dfe6799ee414770c7108306a56)
#         ;
#
#
#
#
#             var marker_6b3a4dd25d451ea310823246033270f0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_338e832519fa97edb27088fe2cea7bc9);
#
#
#         var popup_1e9c2ddc32ed171519081d5bebf53e35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_651265fa4efcf234d458d2245b730ab7 = $(`&lt;div id=&quot;html_651265fa4efcf234d458d2245b730ab7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1e9c2ddc32ed171519081d5bebf53e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72c6f2f800cc7dac5887350cf829766c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72c6f2f800cc7dac5887350cf829766c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72c6f2f800cc7dac5887350cf829766c = L.map(
#                 &quot;map_72c6f2f800cc7dac5887350cf829766c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a059902cf9ae2ecb2a28305d008e50bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a059902cf9ae2ecb2a28305d008e50bf.addTo(map_72c6f2f800cc7dac5887350cf829766c);
#
#
#             var feature_group_4ff7950d9a08ec0fe73be671b5c7b4b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_35f2fca86de6af75b5c697165115dbf1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4ff7950d9a08ec0fe73be671b5c7b4b1);
#
#
#         var popup_29ec4a6453e16ece7f571856f47c358f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ebaec06611d8c57e0e687a7c8d35428 = $(`&lt;div id=&quot;html_7ebaec06611d8c57e0e687a7c8d35428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_29ec4a6453e16ece7f571856f47c358f.setContent(html_7ebaec06611d8c57e0e687a7c8d35428);
#
#
#
#         marker_35f2fca86de6af75b5c697165115dbf1.bindPopup(popup_29ec4a6453e16ece7f571856f47c358f)
#         ;
#
#
#
#
#             var marker_392d0f2c47c37dca90e376eaf8eb16e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4ff7950d9a08ec0fe73be671b5c7b4b1);
#
#
#         var popup_71c3b140062d5beb20d1cc933b692c92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e672a32b764c090e722521085d59da1 = $(`&lt;div id=&quot;html_0e672a32b764c090e722521085d59da1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_71c3b140062d5beb20d1cc933b692c92.setContent(html_0e672a32b764c090e722521085d59da1);
#
#
#
#         marker_392d0f2c47c37dca90e376eaf8eb16e5.bindPopup(popup_71c3b140062d5beb20d1cc933b692c92)
#         ;
#
#
#
#
#             var marker_9b6341f9a4e54b527b9cb8f42a8d3bb4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4ff7950d9a08ec0fe73be671b5c7b4b1);
#
#
#         var popup_057e48eec568300fded5e6ddd9131bc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96d9127198d9683bf04d8fe9cd6583cf = $(`&lt;div id=&quot;html_96d9127198d9683bf04d8fe9cd6583cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_057e48eec568300fded5e6ddd9131bc0.setContent(html_96d9127198d9683bf04d8fe9cd6583cf);
#
#
#
#         marker_9b6341f9a4e54b527b9cb8f42a8d3bb4.bindPopup(popup_057e48eec568300fded5e6ddd9131bc0)
#         ;
#
#
#
#
#             var marker_699a2a53937c6c51f9cdef20efdedc62 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4ff7950d9a08ec0fe73be671b5c7b4b1);
#
#
#         var popup_3a07286a8af1e3fa409fae7c8c742163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e6bbd96dffa51a6c1b66588b46105c2 = $(`&lt;div id=&quot;html_6e6bbd96dffa51a6c1b66588b46105c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3a07286a8af1e3fa409fae7c8c742163.setContent(html_6e6bbd96dffa51a6c1b66588b46105c2);
#
#
#
#         marker_699a2a53937c6c51f9cdef20efdedc62.bindPopup(popup_3a07286a8af1e3fa409fae7c8c742163)
#         ;
#
#
#
#
#             var marker_533f16678cf67dc9bf0f5ddea8b0db7d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4ff7950d9a08ec0fe73be671b5c7b4b1);
#
#
#         var popup_28f912fefdfbb95026c43ef0ee4e7c95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9df1adda8927eafb94a8e068570dd73 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9df1adda8927eafb94a8e068570dd73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9df1adda8927eafb94a8e068570dd73 = L.map(
#                 &quot;map_d9df1adda8927eafb94a8e068570dd73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6986a1e0426f88c602bf0e2231fa088 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6986a1e0426f88c602bf0e2231fa088.addTo(map_d9df1adda8927eafb94a8e068570dd73);
#
#
#             var feature_group_17cb1a1eedf5dd307366e8e1ddfcb825 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_17cb1a1eedf5dd307366e8e1ddfcb825.addTo(map_d9df1adda8927eafb94a8e068570dd73);
#
#
#             var feature_group_sub_group_ffaaea2239876295f76cc99c8b572269 = L.featureGroup.subGroup(
#                 feature_group_17cb1a1eedf5dd307366e8e1ddfcb825
#             );
#
#
#             var marker_f32cbcec7f43275ee2c7a6aaeb51e1c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffaaea2239876295f76cc99c8b572269);
#
#
#         var popup_5865b6c65777dde10f18205e49004abc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1e2059a49169d78bc41af9f9266a040 = $(`&lt;div id=&quot;html_b1e2059a49169d78bc41af9f9266a040&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5865b6c65777dde10f18205e49004abc.setContent(html_b1e2059a49169d78bc41af9f9266a040);
#
#
#
#         marker_f32cbcec7f43275ee2c7a6aaeb51e1c5.bindPopup(popup_5865b6c65777dde10f18205e49004abc)
#         ;
#
#
#
#
#             var marker_e1de028e10d72f9777290cb61099339a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffaaea2239876295f76cc99c8b572269);
#
#
#         var popup_160b3e995010b13662f36af0cb4c9e69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27631358017db0255f963bff09e905cf = $(`&lt;div id=&quot;html_27631358017db0255f963bff09e905cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_160b3e995010b13662f36af0cb4c9e69.setContent(html_27631358017db0255f963bff09e905cf);
#
#
#
#         marker_e1de028e10d72f9777290cb61099339a.bindPopup(popup_160b3e995010b13662f36af0cb4c9e69)
#         ;
#
#
#
#
#             var marker_187b2f1150cffd0a6b3600268c261a7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffaaea2239876295f76cc99c8b572269);
#
#
#         var popup_8274f3ddf5f0c4ebf30fcec78bbc72b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f119753a46070f43aab9fba80283a6e8 = $(`&lt;div id=&quot;html_f119753a46070f43aab9fba80283a6e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8274f3ddf5f0c4ebf30fcec78bbc72b9.setContent(html_f119753a46070f43aab9fba80283a6e8);
#
#
#
#         marker_187b2f1150cffd0a6b3600268c261a7c.bindPopup(popup_8274f3ddf5f0c4ebf30fcec78bbc72b9)
#         ;
#
#
#
#
#             var marker_b5d3fc6d1e2990e94de05cd474ae8133 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ffaaea2239876295f76cc99c8b572269);
#
#
#         var popup_49462e4ee8ca6d89120f05fb143ede69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5fb53367e9036944c87e76c5d269094 = $(`&lt;div id=&quot;html_c5fb53367e9036944c87e76c5d269094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_49462e4ee8ca6d89120f05fb143ede69.setContent(html_c5fb53367e9036944c87e76c5d269094);
#
#
#
#         mark
