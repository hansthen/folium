# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1bd153edc5963a1b21a39f6fad1c9e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1bd153edc5963a1b21a39f6fad1c9e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1bd153edc5963a1b21a39f6fad1c9e0 = L.map(
#                 &quot;map_c1bd153edc5963a1b21a39f6fad1c9e0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45dbfc226aea57af6ea957311d027e58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45dbfc226aea57af6ea957311d027e58.addTo(map_c1bd153edc5963a1b21a39f6fad1c9e0);
#
#
#             var marker_fde915a06828e7cd4990ae03810a3018 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c1bd153edc5963a1b21a39f6fad1c9e0);
#
#
#         var popup_4c5139f8947d1f6bf342d76af8dc6b52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3db3d68da423a6d4f3c90dd82fd3f774 = $(`&lt;div id=&quot;html_3db3d68da423a6d4f3c90dd82fd3f774&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4c5139f8947d1f6bf342d76af8dc6b52.setContent(html_3db3d68da423a6d4f3c90dd82fd3f774);
#
#
#
#         marker_fde915a06828e7cd4990ae03810a3018.bindPopup(popup_4c5139f8947d1f6bf342d76af8dc6b52)
#         ;
#
#
#
#
#             var marker_cfe99be72e24d288fc4b1e8e12847aa9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c1bd153edc5963a1b21a39f6fad1c9e0);
#
#
#         var popup_1d5a56065348e0642707e0b2163a479d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_440c65bc88b1d9ea636e21a00c10a2df = $(`&lt;div id=&quot;html_440c65bc88b1d9ea636e21a00c10a2df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1d5a56065348e0642707e0b2163a479d.setContent(html_440c65bc88b1d9ea636e21a00c10a2df);
#
#
#
#         marker_cfe99be72e24d288fc4b1e8e12847aa9.bindPopup(popup_1d5a56065348e0642707e0b2163a479d)
#         ;
#
#
#
#
#             var marker_c1b9a392eb70c4903b5dd7412b3dffdd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c1bd153edc5963a1b21a39f6fad1c9e0);
#
#
#         var popup_3f9d44da76eadcb3d2f437652a539098 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece17d09a64306adee0b171ea1e8bf4b = $(`&lt;div id=&quot;html_ece17d09a64306adee0b171ea1e8bf4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3f9d44da76eadcb3d2f437652a539098.setContent(html_ece17d09a64306adee0b171ea1e8bf4b);
#
#
#
#         marker_c1b9a392eb70c4903b5dd7412b3dffdd.bindPopup(popup_3f9d44da76eadcb3d2f437652a539098)
#         ;
#
#
#
#
#             var marker_b439106927f2d5c401f1adac3c18e235 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c1bd153edc5963a1b21a39f6fad1c9e0);
#
#
#         var popup_ef45b019d94fd672b66b91be7b98239d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1df8309a2291ef11ebb47855537378a = $(`&lt;div id=&quot;html_b1df8309a2291ef11ebb47855537378a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ef45b019d94fd672b66b91be7b98239d.setContent(html_b1df8309a2291ef11ebb47855537378a);
#
#
#
#         marker_b439106927f2d5c401f1adac3c18e235.bindPopup(popup_ef45b019d94fd672b66b91be7b98239d)
#         ;
#
#
#
#
#             var marker_6e1de3fb0b3fe06f7e9271c06eb616f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c1bd153edc5963a1b21a39f6fad1c9e0);
#
#
#         var popup_e86b34f0f1619b2342d6756af8c09c2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1de82b2eec0b5ab56c0cf802b3c3446b = $(`&lt;div id=&quot;html_1de82b2eec0b5ab56c0cf802b3c3446b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e86b34f0f1619b2342d6756af8c09c2b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a6bce1dc52096a4a8ab0884241a9d70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a6bce1dc52096a4a8ab0884241a9d70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a6bce1dc52096a4a8ab0884241a9d70 = L.map(
#                 &quot;map_9a6bce1dc52096a4a8ab0884241a9d70&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_917e7bff903daf3c9717bd42b3b9a1f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_917e7bff903daf3c9717bd42b3b9a1f7.addTo(map_9a6bce1dc52096a4a8ab0884241a9d70);
#
#
#             var feature_group_73c35bc7071df57dbb1dcb2f19edfa3e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f80a26f229966386f218c1f6e2fcaeca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_73c35bc7071df57dbb1dcb2f19edfa3e);
#
#
#         var popup_a87835916491955743cc749a9f44dd49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfc909e19f60f2ff1c2d0db92828ec72 = $(`&lt;div id=&quot;html_dfc909e19f60f2ff1c2d0db92828ec72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a87835916491955743cc749a9f44dd49.setContent(html_dfc909e19f60f2ff1c2d0db92828ec72);
#
#
#
#         marker_f80a26f229966386f218c1f6e2fcaeca.bindPopup(popup_a87835916491955743cc749a9f44dd49)
#         ;
#
#
#
#
#             var marker_212fdd90f9763e0eab0bc72298ff3f5a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_73c35bc7071df57dbb1dcb2f19edfa3e);
#
#
#         var popup_23b20eedca780e5b96583ed385719b62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc771cdca3fe03ee718007dd20f6e1ed = $(`&lt;div id=&quot;html_bc771cdca3fe03ee718007dd20f6e1ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_23b20eedca780e5b96583ed385719b62.setContent(html_bc771cdca3fe03ee718007dd20f6e1ed);
#
#
#
#         marker_212fdd90f9763e0eab0bc72298ff3f5a.bindPopup(popup_23b20eedca780e5b96583ed385719b62)
#         ;
#
#
#
#
#             var marker_2e780eadc7e28ba50c8e34adaf86358d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_73c35bc7071df57dbb1dcb2f19edfa3e);
#
#
#         var popup_7f4ab206557887ed80f040ee2e32ba94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ab6e2734b41bfa14cf70e246c4d5966 = $(`&lt;div id=&quot;html_2ab6e2734b41bfa14cf70e246c4d5966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7f4ab206557887ed80f040ee2e32ba94.setContent(html_2ab6e2734b41bfa14cf70e246c4d5966);
#
#
#
#         marker_2e780eadc7e28ba50c8e34adaf86358d.bindPopup(popup_7f4ab206557887ed80f040ee2e32ba94)
#         ;
#
#
#
#
#             var marker_83c05733df1799be154d3ab782bf2376 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_73c35bc7071df57dbb1dcb2f19edfa3e);
#
#
#         var popup_1d57b38ec1c6e21cc66d5b04f4e61ec0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1478a883485d1bc37382529e444630da = $(`&lt;div id=&quot;html_1478a883485d1bc37382529e444630da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1d57b38ec1c6e21cc66d5b04f4e61ec0.setContent(html_1478a883485d1bc37382529e444630da);
#
#
#
#         marker_83c05733df1799be154d3ab782bf2376.bindPopup(popup_1d57b38ec1c6e21cc66d5b04f4e61ec0)
#         ;
#
#
#
#
#             var marker_1d286a15e8ef1e133552b7b27a786f9d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_73c35bc7071df57dbb1dcb2f19edfa3e);
#
#
#         var popup_d75c883ec50af6d15fe445c233cd35c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2e44f2b666b5a86c6d76339c5b6f912 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2e44f2b666b5a86c6d76339c5b6f912&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2e44f2b666b5a86c6d76339c5b6f912 = L.map(
#                 &quot;map_e2e44f2b666b5a86c6d76339c5b6f912&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d2c4442dca038ab13cbb8bb7643db1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d2c4442dca038ab13cbb8bb7643db1b.addTo(map_e2e44f2b666b5a86c6d76339c5b6f912);
#
#
#             var feature_group_be08bf37ac395b6660a3981f49d94df4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_be08bf37ac395b6660a3981f49d94df4.addTo(map_e2e44f2b666b5a86c6d76339c5b6f912);
#
#
#             var feature_group_sub_group_c1e2be0ccb3ecbb439062821c0842879 = L.featureGroup.subGroup(
#                 feature_group_be08bf37ac395b6660a3981f49d94df4
#             );
#
#
#             var marker_6d4106f8495621263afb456e8829aa51 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c1e2be0ccb3ecbb439062821c0842879);
#
#
#         var popup_c515b30cc0a1fecf214fffe3f818ee8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce04dcacb13eeee5313c4651e6a98f60 = $(`&lt;div id=&quot;html_ce04dcacb13eeee5313c4651e6a98f60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c515b30cc0a1fecf214fffe3f818ee8a.setContent(html_ce04dcacb13eeee5313c4651e6a98f60);
#
#
#
#         marker_6d4106f8495621263afb456e8829aa51.bindPopup(popup_c515b30cc0a1fecf214fffe3f818ee8a)
#         ;
#
#
#
#
#             var marker_3e06646c419b90eba47bc636df95a77a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c1e2be0ccb3ecbb439062821c0842879);
#
#
#         var popup_74b0355884a20e1e9e6d7eff0b8de585 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6597a2a326880590fa983b66a3e8940c = $(`&lt;div id=&quot;html_6597a2a326880590fa983b66a3e8940c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_74b0355884a20e1e9e6d7eff0b8de585.setContent(html_6597a2a326880590fa983b66a3e8940c);
#
#
#
#         marker_3e06646c419b90eba47bc636df95a77a.bindPopup(popup_74b0355884a20e1e9e6d7eff0b8de585)
#         ;
#
#
#
#
#             var marker_99e520d3fccb1e4e8dc3452a9e649cfc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c1e2be0ccb3ecbb439062821c0842879);
#
#
#         var popup_4329d7f5541e2fc8acda82bc108e35f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3d73e8823f7654a6296aa8aaa63dc2a = $(`&lt;div id=&quot;html_a3d73e8823f7654a6296aa8aaa63dc2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4329d7f5541e2fc8acda82bc108e35f6.setContent(html_a3d73e8823f7654a6296aa8aaa63dc2a);
#
#
#
#         marker_99e520d3fccb1e4e8dc3452a9e649cfc.bindPopup(popup_4329d7f5541e2fc8acda82bc108e35f6)
#         ;
#
#
#
#
#             var marker_7e1542e7ddbb8c9b4fff7ab2897868c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c1e2be0ccb3ecbb439062821c0842879);
#
#
#         var popup_e4556ada4d1929761e75e3e04b801570 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cda3b0875910f02cd5fe26f632f7052a = $(`&lt;div id=&quot;html_cda3b0875910f02cd5fe26f632f7052a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e4556ada4d1929761e75e3e04b801570.setContent(html_cda3b0875910f02cd5fe26f632f7052a);
#
#
#
#         marker_
