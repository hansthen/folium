# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_898d708ae6f8f630b9f6a78c4b01ac95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_898d708ae6f8f630b9f6a78c4b01ac95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_898d708ae6f8f630b9f6a78c4b01ac95 = L.map(
#                 &quot;map_898d708ae6f8f630b9f6a78c4b01ac95&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4716c02e6cad4f0f5ebe7b23f52713f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4716c02e6cad4f0f5ebe7b23f52713f.addTo(map_898d708ae6f8f630b9f6a78c4b01ac95);
#
#
#             var marker_20bb4315d2802d85ebdfcb09c054607a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_898d708ae6f8f630b9f6a78c4b01ac95);
#
#
#         var popup_10a1b177310cd818e51931962aea5d87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d8f5f91405a1dfc8e56c48016a1fdc8 = $(`&lt;div id=&quot;html_9d8f5f91405a1dfc8e56c48016a1fdc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_10a1b177310cd818e51931962aea5d87.setContent(html_9d8f5f91405a1dfc8e56c48016a1fdc8);
#
#
#
#         marker_20bb4315d2802d85ebdfcb09c054607a.bindPopup(popup_10a1b177310cd818e51931962aea5d87)
#         ;
#
#
#
#
#             var marker_5be0d4a15fcd2120da51dbbfd6f4ff16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_898d708ae6f8f630b9f6a78c4b01ac95);
#
#
#         var popup_45224958856bf8f3620be654846ee4ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f4f9e5289a12f329cadd44e78223ef7 = $(`&lt;div id=&quot;html_5f4f9e5289a12f329cadd44e78223ef7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_45224958856bf8f3620be654846ee4ea.setContent(html_5f4f9e5289a12f329cadd44e78223ef7);
#
#
#
#         marker_5be0d4a15fcd2120da51dbbfd6f4ff16.bindPopup(popup_45224958856bf8f3620be654846ee4ea)
#         ;
#
#
#
#
#             var marker_923fbf7071f0865d0a4165d32fb3be5e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_898d708ae6f8f630b9f6a78c4b01ac95);
#
#
#         var popup_b7f654069ee7511138e3a4402d150425 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f2abe1279a3d1b397db91d451cfe4ec = $(`&lt;div id=&quot;html_9f2abe1279a3d1b397db91d451cfe4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b7f654069ee7511138e3a4402d150425.setContent(html_9f2abe1279a3d1b397db91d451cfe4ec);
#
#
#
#         marker_923fbf7071f0865d0a4165d32fb3be5e.bindPopup(popup_b7f654069ee7511138e3a4402d150425)
#         ;
#
#
#
#
#             var marker_272ac752c6454f1f0dca8f80c2334e1e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_898d708ae6f8f630b9f6a78c4b01ac95);
#
#
#         var popup_837bc8d03ae40b85ecdd339a6157749b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a87bac2b0369ca3b70fd024dfedb6688 = $(`&lt;div id=&quot;html_a87bac2b0369ca3b70fd024dfedb6688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_837bc8d03ae40b85ecdd339a6157749b.setContent(html_a87bac2b0369ca3b70fd024dfedb6688);
#
#
#
#         marker_272ac752c6454f1f0dca8f80c2334e1e.bindPopup(popup_837bc8d03ae40b85ecdd339a6157749b)
#         ;
#
#
#
#
#             var marker_e521876fdc28914c4e55bbad721d313a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_898d708ae6f8f630b9f6a78c4b01ac95);
#
#
#         var popup_ca6f9b74ed6a41bc41c48b9bafcf1e6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f7387f18b7e3d4a3c82b6a716167f54 = $(`&lt;div id=&quot;html_6f7387f18b7e3d4a3c82b6a716167f54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ca6f9b74ed6a41bc41c48b9bafcf1e6e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a4155553a5a8e7c20813119033a6430 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a4155553a5a8e7c20813119033a6430&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a4155553a5a8e7c20813119033a6430 = L.map(
#                 &quot;map_1a4155553a5a8e7c20813119033a6430&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff9f5cd2ced10d30dfeedef947fbaa34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff9f5cd2ced10d30dfeedef947fbaa34.addTo(map_1a4155553a5a8e7c20813119033a6430);
#
#
#             var feature_group_61792d57e3ea420690958ffa97da7ecf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_30b528c6a4d2b4dc5e53bd86ed490b86 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_61792d57e3ea420690958ffa97da7ecf);
#
#
#         var popup_f54d8fcbf9c56c679cd9689aee254cfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_409d2d3815cbfb7e55343ba2cd638d96 = $(`&lt;div id=&quot;html_409d2d3815cbfb7e55343ba2cd638d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f54d8fcbf9c56c679cd9689aee254cfa.setContent(html_409d2d3815cbfb7e55343ba2cd638d96);
#
#
#
#         marker_30b528c6a4d2b4dc5e53bd86ed490b86.bindPopup(popup_f54d8fcbf9c56c679cd9689aee254cfa)
#         ;
#
#
#
#
#             var marker_d9481c88cd7575c21d6c19b9a2593f20 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_61792d57e3ea420690958ffa97da7ecf);
#
#
#         var popup_57357066e3a136da9ca55bcdd490e153 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_442b6c7128db63a23fa0fa8bf481f7bc = $(`&lt;div id=&quot;html_442b6c7128db63a23fa0fa8bf481f7bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_57357066e3a136da9ca55bcdd490e153.setContent(html_442b6c7128db63a23fa0fa8bf481f7bc);
#
#
#
#         marker_d9481c88cd7575c21d6c19b9a2593f20.bindPopup(popup_57357066e3a136da9ca55bcdd490e153)
#         ;
#
#
#
#
#             var marker_87996f30cc5539228176de2acb7f8a39 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_61792d57e3ea420690958ffa97da7ecf);
#
#
#         var popup_0eba36fd945e1af440168db4a3920a01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee676e30708c75e14f24a4adb7ed162f = $(`&lt;div id=&quot;html_ee676e30708c75e14f24a4adb7ed162f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0eba36fd945e1af440168db4a3920a01.setContent(html_ee676e30708c75e14f24a4adb7ed162f);
#
#
#
#         marker_87996f30cc5539228176de2acb7f8a39.bindPopup(popup_0eba36fd945e1af440168db4a3920a01)
#         ;
#
#
#
#
#             var marker_899176e6add43b34affd390eda2a0e26 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_61792d57e3ea420690958ffa97da7ecf);
#
#
#         var popup_95f1e5a07bb7f2afb9f6add586c6284c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e60dd1128747ee4525bc867d5b4912 = $(`&lt;div id=&quot;html_b0e60dd1128747ee4525bc867d5b4912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_95f1e5a07bb7f2afb9f6add586c6284c.setContent(html_b0e60dd1128747ee4525bc867d5b4912);
#
#
#
#         marker_899176e6add43b34affd390eda2a0e26.bindPopup(popup_95f1e5a07bb7f2afb9f6add586c6284c)
#         ;
#
#
#
#
#             var marker_1d6daacbe2a0d6c53021b28a09e32146 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_61792d57e3ea420690958ffa97da7ecf);
#
#
#         var popup_4aad823e561837a9b81976bdd8ca9987 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d84f6227c5b8974c034459610b6dbc5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d84f6227c5b8974c034459610b6dbc5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d84f6227c5b8974c034459610b6dbc5b = L.map(
#                 &quot;map_d84f6227c5b8974c034459610b6dbc5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ab2fee9de065a7014fa6fe5820f03a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ab2fee9de065a7014fa6fe5820f03a5.addTo(map_d84f6227c5b8974c034459610b6dbc5b);
#
#
#             var feature_group_f9b36d8a2d785f73ed1c8b56ffac3730 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f9b36d8a2d785f73ed1c8b56ffac3730.addTo(map_d84f6227c5b8974c034459610b6dbc5b);
#
#
#             var feature_group_sub_group_c2ac573ca6a023f926abc85a8ab048ef = L.featureGroup.subGroup(
#                 feature_group_f9b36d8a2d785f73ed1c8b56ffac3730
#             );
#
#
#             var marker_fa08fb3487cab465d9c47771f0e66e60 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2ac573ca6a023f926abc85a8ab048ef);
#
#
#         var popup_b7ced70751638b5ed88aa4091b456e91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341853f3ebdee23e5fab26d4467501a1 = $(`&lt;div id=&quot;html_341853f3ebdee23e5fab26d4467501a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b7ced70751638b5ed88aa4091b456e91.setContent(html_341853f3ebdee23e5fab26d4467501a1);
#
#
#
#         marker_fa08fb3487cab465d9c47771f0e66e60.bindPopup(popup_b7ced70751638b5ed88aa4091b456e91)
#         ;
#
#
#
#
#             var marker_f1c1b681936146ec20c8b166b8e6cfc8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2ac573ca6a023f926abc85a8ab048ef);
#
#
#         var popup_2be5398d3075fb152a585f8867ea8645 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a5d2bbc7542228221cb643ff2c7bf06 = $(`&lt;div id=&quot;html_6a5d2bbc7542228221cb643ff2c7bf06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2be5398d3075fb152a585f8867ea8645.setContent(html_6a5d2bbc7542228221cb643ff2c7bf06);
#
#
#
#         marker_f1c1b681936146ec20c8b166b8e6cfc8.bindPopup(popup_2be5398d3075fb152a585f8867ea8645)
#         ;
#
#
#
#
#             var marker_5e282857ad9ac9c088d9cd3b9e2eea0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2ac573ca6a023f926abc85a8ab048ef);
#
#
#         var popup_014cef9d67801099cc403bf4dac1bd5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed7bdbfa602d18a1859b3fa27316f292 = $(`&lt;div id=&quot;html_ed7bdbfa602d18a1859b3fa27316f292&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_014cef9d67801099cc403bf4dac1bd5b.setContent(html_ed7bdbfa602d18a1859b3fa27316f292);
#
#
#
#         marker_5e282857ad9ac9c088d9cd3b9e2eea0a.bindPopup(popup_014cef9d67801099cc403bf4dac1bd5b)
#         ;
#
#
#
#
#             var marker_98fe37287a8495a605542bb027e54702 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c2ac573ca6a023f926abc85a8ab048ef);
#
#
#         var popup_c4e8d8cd25b1831f99a4e14c51a2165c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_820b9cb6499eac32732204fea9d9f99d = $(`&lt;div id=&quot;html_820b9cb6499eac32732204fea9d9f99d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c4e8d8cd25b1831f99a4e14c51a2165c.setContent(html_820b9cb6499eac32732204fea9d9f99d);
#
#
#
#         marker_
