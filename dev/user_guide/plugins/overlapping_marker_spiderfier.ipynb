# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_625041a323fbd59ec820c51ec2ca8aa1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_625041a323fbd59ec820c51ec2ca8aa1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_625041a323fbd59ec820c51ec2ca8aa1 = L.map(
#                 &quot;map_625041a323fbd59ec820c51ec2ca8aa1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb98fd04e5fc94cd57c63412a1ad3066 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fb98fd04e5fc94cd57c63412a1ad3066.addTo(map_625041a323fbd59ec820c51ec2ca8aa1);
#
#
#             var marker_9574c24cc5a857a128046b3327f6b3a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_625041a323fbd59ec820c51ec2ca8aa1);
#
#
#         var popup_52f9270f62ffd924c3c1feccf26f5e13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3ed4039cb681f892a35948e4172687c = $(`&lt;div id=&quot;html_c3ed4039cb681f892a35948e4172687c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_52f9270f62ffd924c3c1feccf26f5e13.setContent(html_c3ed4039cb681f892a35948e4172687c);
#
#
#
#         marker_9574c24cc5a857a128046b3327f6b3a0.bindPopup(popup_52f9270f62ffd924c3c1feccf26f5e13)
#         ;
#
#
#
#
#             var marker_57bff52e675bfa1f845d666fe8ed452c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_625041a323fbd59ec820c51ec2ca8aa1);
#
#
#         var popup_49188024a0d68d88c7094911408b22f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1367c2934df38400901ab9dedf060780 = $(`&lt;div id=&quot;html_1367c2934df38400901ab9dedf060780&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_49188024a0d68d88c7094911408b22f2.setContent(html_1367c2934df38400901ab9dedf060780);
#
#
#
#         marker_57bff52e675bfa1f845d666fe8ed452c.bindPopup(popup_49188024a0d68d88c7094911408b22f2)
#         ;
#
#
#
#
#             var marker_46ff5599c941301f2b973fb8f22ec816 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_625041a323fbd59ec820c51ec2ca8aa1);
#
#
#         var popup_dbdeff54e859b5385958063f45baae7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33b6f281e1e6aa93645eb2a3bc58b199 = $(`&lt;div id=&quot;html_33b6f281e1e6aa93645eb2a3bc58b199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dbdeff54e859b5385958063f45baae7c.setContent(html_33b6f281e1e6aa93645eb2a3bc58b199);
#
#
#
#         marker_46ff5599c941301f2b973fb8f22ec816.bindPopup(popup_dbdeff54e859b5385958063f45baae7c)
#         ;
#
#
#
#
#             var marker_dde3b24c4a0cde4142a8ca6a1181d2bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_625041a323fbd59ec820c51ec2ca8aa1);
#
#
#         var popup_7e7a3b98953919f47ed944446e5a1ca4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb184b80dabbe5b1ee6035ce649036b7 = $(`&lt;div id=&quot;html_cb184b80dabbe5b1ee6035ce649036b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7e7a3b98953919f47ed944446e5a1ca4.setContent(html_cb184b80dabbe5b1ee6035ce649036b7);
#
#
#
#         marker_dde3b24c4a0cde4142a8ca6a1181d2bb.bindPopup(popup_7e7a3b98953919f47ed944446e5a1ca4)
#         ;
#
#
#
#
#             var marker_47bc1147e4aa129130768a120175f47b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_625041a323fbd59ec820c51ec2ca8aa1);
#
#
#         var popup_cf229570364f650f5d8e51dc0f347735 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b330276e615dcbb5a985b3fa9b29b85f = $(`&lt;div id=&quot;html_b330276e615dcbb5a985b3fa9b29b85f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cf229570364f650f5d8e51dc0f347735.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c21a099b8222bf490ea13033d7bf0ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c21a099b8222bf490ea13033d7bf0ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c21a099b8222bf490ea13033d7bf0ad = L.map(
#                 &quot;map_0c21a099b8222bf490ea13033d7bf0ad&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71844647440df74b85a623e80a92bdcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71844647440df74b85a623e80a92bdcb.addTo(map_0c21a099b8222bf490ea13033d7bf0ad);
#
#
#             var feature_group_86f854932f54274d37cbe226f9d925f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a6b7445be532f583ec62a4289ba20aeb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_86f854932f54274d37cbe226f9d925f0);
#
#
#         var popup_ff82257c426a84ec3757d5a2cee034e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_961bafaa95b1e84cd242aa89429711eb = $(`&lt;div id=&quot;html_961bafaa95b1e84cd242aa89429711eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ff82257c426a84ec3757d5a2cee034e4.setContent(html_961bafaa95b1e84cd242aa89429711eb);
#
#
#
#         marker_a6b7445be532f583ec62a4289ba20aeb.bindPopup(popup_ff82257c426a84ec3757d5a2cee034e4)
#         ;
#
#
#
#
#             var marker_22d70fce1760a080026cec2b01a19351 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_86f854932f54274d37cbe226f9d925f0);
#
#
#         var popup_b999c1a697c640c8fabefeeefeae9817 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ae167afd07f536daa7bc8514dad6165 = $(`&lt;div id=&quot;html_8ae167afd07f536daa7bc8514dad6165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b999c1a697c640c8fabefeeefeae9817.setContent(html_8ae167afd07f536daa7bc8514dad6165);
#
#
#
#         marker_22d70fce1760a080026cec2b01a19351.bindPopup(popup_b999c1a697c640c8fabefeeefeae9817)
#         ;
#
#
#
#
#             var marker_1f6506a19dc5ae5de0bef79391690363 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_86f854932f54274d37cbe226f9d925f0);
#
#
#         var popup_3d3f859bcd055e7128a9e4e2cd9ff2e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_687035df5ead9b862469c183829a8710 = $(`&lt;div id=&quot;html_687035df5ead9b862469c183829a8710&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3d3f859bcd055e7128a9e4e2cd9ff2e3.setContent(html_687035df5ead9b862469c183829a8710);
#
#
#
#         marker_1f6506a19dc5ae5de0bef79391690363.bindPopup(popup_3d3f859bcd055e7128a9e4e2cd9ff2e3)
#         ;
#
#
#
#
#             var marker_8aa635bad8b99e8b36113402cafc6436 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_86f854932f54274d37cbe226f9d925f0);
#
#
#         var popup_b1a731bc534b39baa0eca78a94503b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2587f9d50d33da1498161d4e1baf5a7 = $(`&lt;div id=&quot;html_e2587f9d50d33da1498161d4e1baf5a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b1a731bc534b39baa0eca78a94503b1d.setContent(html_e2587f9d50d33da1498161d4e1baf5a7);
#
#
#
#         marker_8aa635bad8b99e8b36113402cafc6436.bindPopup(popup_b1a731bc534b39baa0eca78a94503b1d)
#         ;
#
#
#
#
#             var marker_f43f9889ad2d66a963bf436046586036 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_86f854932f54274d37cbe226f9d925f0);
#
#
#         var popup_4012df0475b47c1380b375269ad8c1cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bea3c7642c275d945ddf9ed08fb43c97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bea3c7642c275d945ddf9ed08fb43c97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bea3c7642c275d945ddf9ed08fb43c97 = L.map(
#                 &quot;map_bea3c7642c275d945ddf9ed08fb43c97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cc28ebf8565235222eb06d068148e32 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cc28ebf8565235222eb06d068148e32.addTo(map_bea3c7642c275d945ddf9ed08fb43c97);
#
#
#             var feature_group_ad0628f717f4464cbfc13cc13b1c3dc5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ad0628f717f4464cbfc13cc13b1c3dc5.addTo(map_bea3c7642c275d945ddf9ed08fb43c97);
#
#
#             var feature_group_sub_group_85e975fb0910c3e62c7967d7cb9ef458 = L.featureGroup.subGroup(
#                 feature_group_ad0628f717f4464cbfc13cc13b1c3dc5
#             );
#
#
#             var marker_90ae97788d25337fa799954477e55d12 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_85e975fb0910c3e62c7967d7cb9ef458);
#
#
#         var popup_ee8775b4aeb1b055708b8ae3bdab61fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cf38f106dea2c4866276a54aac7b266 = $(`&lt;div id=&quot;html_0cf38f106dea2c4866276a54aac7b266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ee8775b4aeb1b055708b8ae3bdab61fb.setContent(html_0cf38f106dea2c4866276a54aac7b266);
#
#
#
#         marker_90ae97788d25337fa799954477e55d12.bindPopup(popup_ee8775b4aeb1b055708b8ae3bdab61fb)
#         ;
#
#
#
#
#             var marker_648617e50d84c3fdd96373bcc67813e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_85e975fb0910c3e62c7967d7cb9ef458);
#
#
#         var popup_903003d03c0183d98d74e7c4032d3170 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_008a40b59c88a0f74ce5aa812d8c1452 = $(`&lt;div id=&quot;html_008a40b59c88a0f74ce5aa812d8c1452&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_903003d03c0183d98d74e7c4032d3170.setContent(html_008a40b59c88a0f74ce5aa812d8c1452);
#
#
#
#         marker_648617e50d84c3fdd96373bcc67813e8.bindPopup(popup_903003d03c0183d98d74e7c4032d3170)
#         ;
#
#
#
#
#             var marker_a803ead989e039e741729d91db30d421 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_85e975fb0910c3e62c7967d7cb9ef458);
#
#
#         var popup_6413e2370aee8076946fa53668ab607b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db9402fe2ec2193ffec40a0949961acc = $(`&lt;div id=&quot;html_db9402fe2ec2193ffec40a0949961acc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6413e2370aee8076946fa53668ab607b.setContent(html_db9402fe2ec2193ffec40a0949961acc);
#
#
#
#         marker_a803ead989e039e741729d91db30d421.bindPopup(popup_6413e2370aee8076946fa53668ab607b)
#         ;
#
#
#
#
#             var marker_39642045f56477ba2ddbe263b812c043 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_85e975fb0910c3e62c7967d7cb9ef458);
#
#
#         var popup_6dd66108676a9d3c9eceb79fcfd0557b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caaf75707482e61d8e3a0723ca13e01b = $(`&lt;div id=&quot;html_caaf75707482e61d8e3a0723ca13e01b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6dd66108676a9d3c9eceb79fcfd0557b.setContent(html_caaf75707482e61d8e3a0723ca13e01b);
#
#
#
#         marker_
