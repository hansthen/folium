# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85d9ec9fef1ad36ef6c0cb35476e3638 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85d9ec9fef1ad36ef6c0cb35476e3638&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85d9ec9fef1ad36ef6c0cb35476e3638 = L.map(
#                 &quot;map_85d9ec9fef1ad36ef6c0cb35476e3638&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63fde9beb41bb52fad4317f785f33728 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63fde9beb41bb52fad4317f785f33728.addTo(map_85d9ec9fef1ad36ef6c0cb35476e3638);
#
#
#             var marker_acf7991b7f3d3de77b6e83a13827e5e3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_85d9ec9fef1ad36ef6c0cb35476e3638);
#
#
#         var popup_43ae1f9bc638991d247fc0ef2d01e3cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2906650484c6336dd7977cf82a6ee2f = $(`&lt;div id=&quot;html_e2906650484c6336dd7977cf82a6ee2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_43ae1f9bc638991d247fc0ef2d01e3cb.setContent(html_e2906650484c6336dd7977cf82a6ee2f);
#
#
#
#         marker_acf7991b7f3d3de77b6e83a13827e5e3.bindPopup(popup_43ae1f9bc638991d247fc0ef2d01e3cb)
#         ;
#
#
#
#
#             var marker_157aed33565d8100e9d5ea1f65e66836 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_85d9ec9fef1ad36ef6c0cb35476e3638);
#
#
#         var popup_675fee4691d432f7bc3a9159c30f06eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f90f6d203aa43deac971c0e69d029bc6 = $(`&lt;div id=&quot;html_f90f6d203aa43deac971c0e69d029bc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_675fee4691d432f7bc3a9159c30f06eb.setContent(html_f90f6d203aa43deac971c0e69d029bc6);
#
#
#
#         marker_157aed33565d8100e9d5ea1f65e66836.bindPopup(popup_675fee4691d432f7bc3a9159c30f06eb)
#         ;
#
#
#
#
#             var marker_b87afd0afe7b2ffb168ddb408de39617 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_85d9ec9fef1ad36ef6c0cb35476e3638);
#
#
#         var popup_497fd987cc100f6230544fb7a7ee335b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5545d5b69ea5d69512df6d315fd7ae42 = $(`&lt;div id=&quot;html_5545d5b69ea5d69512df6d315fd7ae42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_497fd987cc100f6230544fb7a7ee335b.setContent(html_5545d5b69ea5d69512df6d315fd7ae42);
#
#
#
#         marker_b87afd0afe7b2ffb168ddb408de39617.bindPopup(popup_497fd987cc100f6230544fb7a7ee335b)
#         ;
#
#
#
#
#             var marker_563c887ef74b561366904fd1de3c3939 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_85d9ec9fef1ad36ef6c0cb35476e3638);
#
#
#         var popup_8a4e2873ba62d0ad72738aa6818cdd76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21eaadbecfaf9d0772f8b86e77c8a874 = $(`&lt;div id=&quot;html_21eaadbecfaf9d0772f8b86e77c8a874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8a4e2873ba62d0ad72738aa6818cdd76.setContent(html_21eaadbecfaf9d0772f8b86e77c8a874);
#
#
#
#         marker_563c887ef74b561366904fd1de3c3939.bindPopup(popup_8a4e2873ba62d0ad72738aa6818cdd76)
#         ;
#
#
#
#
#             var marker_1acfad24f00cd5367eff4b35a187f0da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_85d9ec9fef1ad36ef6c0cb35476e3638);
#
#
#         var popup_43220f449e61bbd7811a032fb3df08ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e680feadc40b26853694fd0e2538c7b = $(`&lt;div id=&quot;html_7e680feadc40b26853694fd0e2538c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_43220f449e61bbd7811a032fb3df08ca.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d56d9e10e4ae8a14bb868d5a1d725b81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d56d9e10e4ae8a14bb868d5a1d725b81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d56d9e10e4ae8a14bb868d5a1d725b81 = L.map(
#                 &quot;map_d56d9e10e4ae8a14bb868d5a1d725b81&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f336ae49f4084b319a4e5ad54cf0655 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f336ae49f4084b319a4e5ad54cf0655.addTo(map_d56d9e10e4ae8a14bb868d5a1d725b81);
#
#
#             var feature_group_9c934d45363c5baa8b33009dfb37e8cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9e6f51196918678e070d5f3a017647d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9c934d45363c5baa8b33009dfb37e8cf);
#
#
#         var popup_8ed763dd8806f13b59187d74646ef200 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60249b06da1bc9a3d48645883b86c8ab = $(`&lt;div id=&quot;html_60249b06da1bc9a3d48645883b86c8ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8ed763dd8806f13b59187d74646ef200.setContent(html_60249b06da1bc9a3d48645883b86c8ab);
#
#
#
#         marker_9e6f51196918678e070d5f3a017647d4.bindPopup(popup_8ed763dd8806f13b59187d74646ef200)
#         ;
#
#
#
#
#             var marker_bd80ad43cf824a17a9d2df6384119c6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9c934d45363c5baa8b33009dfb37e8cf);
#
#
#         var popup_6a20061b54063eafc65b6ab29fb05fdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d803c4a116b58245bd0fda527125f63 = $(`&lt;div id=&quot;html_5d803c4a116b58245bd0fda527125f63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6a20061b54063eafc65b6ab29fb05fdc.setContent(html_5d803c4a116b58245bd0fda527125f63);
#
#
#
#         marker_bd80ad43cf824a17a9d2df6384119c6a.bindPopup(popup_6a20061b54063eafc65b6ab29fb05fdc)
#         ;
#
#
#
#
#             var marker_9b9ad05735280cfeedade7e142f3e23b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9c934d45363c5baa8b33009dfb37e8cf);
#
#
#         var popup_23093fab96e1936844ade1223d052c55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7378e9f89142ebf9630433069db07c8c = $(`&lt;div id=&quot;html_7378e9f89142ebf9630433069db07c8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_23093fab96e1936844ade1223d052c55.setContent(html_7378e9f89142ebf9630433069db07c8c);
#
#
#
#         marker_9b9ad05735280cfeedade7e142f3e23b.bindPopup(popup_23093fab96e1936844ade1223d052c55)
#         ;
#
#
#
#
#             var marker_39f01ea7a9c411786fbf4037bfe6b227 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9c934d45363c5baa8b33009dfb37e8cf);
#
#
#         var popup_85f0833297d74b93f2dd9ed841c6faa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79e7b9424b8abae07cd3bca1ca755fb3 = $(`&lt;div id=&quot;html_79e7b9424b8abae07cd3bca1ca755fb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_85f0833297d74b93f2dd9ed841c6faa5.setContent(html_79e7b9424b8abae07cd3bca1ca755fb3);
#
#
#
#         marker_39f01ea7a9c411786fbf4037bfe6b227.bindPopup(popup_85f0833297d74b93f2dd9ed841c6faa5)
#         ;
#
#
#
#
#             var marker_206cc8905d064c3448d84eda87232216 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9c934d45363c5baa8b33009dfb37e8cf);
#
#
#         var popup_53a5bce2de73792482d1baa2e68eb617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1c28c80f5514234beb8f394fd824b80 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1c28c80f5514234beb8f394fd824b80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1c28c80f5514234beb8f394fd824b80 = L.map(
#                 &quot;map_b1c28c80f5514234beb8f394fd824b80&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ce9a6b525c9f008ecba191f28d05d8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ce9a6b525c9f008ecba191f28d05d8d.addTo(map_b1c28c80f5514234beb8f394fd824b80);
#
#
#             var feature_group_714e918c4a63fdcb9b5b0e4891dd5738 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_714e918c4a63fdcb9b5b0e4891dd5738.addTo(map_b1c28c80f5514234beb8f394fd824b80);
#
#
#             var feature_group_sub_group_8aa48752e303214cedc42252253d85f9 = L.featureGroup.subGroup(
#                 feature_group_714e918c4a63fdcb9b5b0e4891dd5738
#             );
#
#
#             var marker_9aee6cdef7f85cd907f986859f6587c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aa48752e303214cedc42252253d85f9);
#
#
#         var popup_e033d51080f0e36387bc3b137ad88b11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c4489047295b9c47ac4164314735733 = $(`&lt;div id=&quot;html_4c4489047295b9c47ac4164314735733&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e033d51080f0e36387bc3b137ad88b11.setContent(html_4c4489047295b9c47ac4164314735733);
#
#
#
#         marker_9aee6cdef7f85cd907f986859f6587c5.bindPopup(popup_e033d51080f0e36387bc3b137ad88b11)
#         ;
#
#
#
#
#             var marker_2f1b087a83867e930fcb2617da874c93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aa48752e303214cedc42252253d85f9);
#
#
#         var popup_9eb5835bffdc769ecb415fc0a2d97c16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09769d71a5e239caa0df1d9ccee001d7 = $(`&lt;div id=&quot;html_09769d71a5e239caa0df1d9ccee001d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9eb5835bffdc769ecb415fc0a2d97c16.setContent(html_09769d71a5e239caa0df1d9ccee001d7);
#
#
#
#         marker_2f1b087a83867e930fcb2617da874c93.bindPopup(popup_9eb5835bffdc769ecb415fc0a2d97c16)
#         ;
#
#
#
#
#             var marker_85d75f406fe7d63be4182d8b5ca1d445 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aa48752e303214cedc42252253d85f9);
#
#
#         var popup_9ff678cc42f87fafd72a50a57889b712 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28fe711f7a649c64f715caceb97b6b97 = $(`&lt;div id=&quot;html_28fe711f7a649c64f715caceb97b6b97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9ff678cc42f87fafd72a50a57889b712.setContent(html_28fe711f7a649c64f715caceb97b6b97);
#
#
#
#         marker_85d75f406fe7d63be4182d8b5ca1d445.bindPopup(popup_9ff678cc42f87fafd72a50a57889b712)
#         ;
#
#
#
#
#             var marker_e263881d922b0fdb9446c47e9cc195c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8aa48752e303214cedc42252253d85f9);
#
#
#         var popup_b4b022acf42da468ddf42dc9065f38db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c96bfc9f03bf6ea382df6ca64317397b = $(`&lt;div id=&quot;html_c96bfc9f03bf6ea382df6ca64317397b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b4b022acf42da468ddf42dc9065f38db.setContent(html_c96bfc9f03bf6ea382df6ca64317397b);
#
#
#
#         marker_
