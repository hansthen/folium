# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4889cd185876be37e3b8b90b3bd7c914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4889cd185876be37e3b8b90b3bd7c914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4889cd185876be37e3b8b90b3bd7c914 = L.map(
#                 &quot;map_4889cd185876be37e3b8b90b3bd7c914&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc028797de06bae6f46075a862b86805 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc028797de06bae6f46075a862b86805.addTo(map_4889cd185876be37e3b8b90b3bd7c914);
#
#
#             var marker_61f413979ccf68c9ddbf26feeb3b5677 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4889cd185876be37e3b8b90b3bd7c914);
#
#
#         var popup_6db23ff95611f7b5dd7a5d58e6e77e07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f15301ea13607ea546af6c82f6d5b090 = $(`&lt;div id=&quot;html_f15301ea13607ea546af6c82f6d5b090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6db23ff95611f7b5dd7a5d58e6e77e07.setContent(html_f15301ea13607ea546af6c82f6d5b090);
#
#
#
#         marker_61f413979ccf68c9ddbf26feeb3b5677.bindPopup(popup_6db23ff95611f7b5dd7a5d58e6e77e07)
#         ;
#
#
#
#
#             var marker_502dc7bc3a5faf544027344a0cad0efb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4889cd185876be37e3b8b90b3bd7c914);
#
#
#         var popup_269a01917bcc7352cc2f47a3e2b0d481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_598409bb33759df128db3f32b3889db2 = $(`&lt;div id=&quot;html_598409bb33759df128db3f32b3889db2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_269a01917bcc7352cc2f47a3e2b0d481.setContent(html_598409bb33759df128db3f32b3889db2);
#
#
#
#         marker_502dc7bc3a5faf544027344a0cad0efb.bindPopup(popup_269a01917bcc7352cc2f47a3e2b0d481)
#         ;
#
#
#
#
#             var marker_f4921662954301c96b2397b370f6ff31 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4889cd185876be37e3b8b90b3bd7c914);
#
#
#         var popup_ab5ecc1cc5c06cb3b62b63ca7b2a9225 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2d98cac85bbeb567f01301ff8633697 = $(`&lt;div id=&quot;html_f2d98cac85bbeb567f01301ff8633697&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ab5ecc1cc5c06cb3b62b63ca7b2a9225.setContent(html_f2d98cac85bbeb567f01301ff8633697);
#
#
#
#         marker_f4921662954301c96b2397b370f6ff31.bindPopup(popup_ab5ecc1cc5c06cb3b62b63ca7b2a9225)
#         ;
#
#
#
#
#             var marker_bbca2c6e7f01bec4f8cd4d16fd24d7d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4889cd185876be37e3b8b90b3bd7c914);
#
#
#         var popup_c91b03a2dbc065025f6419362599a7b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b2f71ee5e37c5ea25dd59a46e6c2bca = $(`&lt;div id=&quot;html_1b2f71ee5e37c5ea25dd59a46e6c2bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c91b03a2dbc065025f6419362599a7b3.setContent(html_1b2f71ee5e37c5ea25dd59a46e6c2bca);
#
#
#
#         marker_bbca2c6e7f01bec4f8cd4d16fd24d7d8.bindPopup(popup_c91b03a2dbc065025f6419362599a7b3)
#         ;
#
#
#
#
#             var marker_68db290fec4dee94e4b7b3ad4a425fd2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4889cd185876be37e3b8b90b3bd7c914);
#
#
#         var popup_41849fff4480a04e80505eb9adb2a380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87fd6b42e7a60d58f16e70275f0b1968 = $(`&lt;div id=&quot;html_87fd6b42e7a60d58f16e70275f0b1968&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_41849fff4480a04e80505eb9adb2a380.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d384fa046ad74d5d1f798a4e09a66a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d384fa046ad74d5d1f798a4e09a66a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d384fa046ad74d5d1f798a4e09a66a9 = L.map(
#                 &quot;map_1d384fa046ad74d5d1f798a4e09a66a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3cb9669aa1c7d7e97cc83db38f5a089 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3cb9669aa1c7d7e97cc83db38f5a089.addTo(map_1d384fa046ad74d5d1f798a4e09a66a9);
#
#
#             var feature_group_e1e982f112fcf37d2af1de34b53be2e9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e03df93a1f1383e42c38834129a23016 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e1e982f112fcf37d2af1de34b53be2e9);
#
#
#         var popup_80e0b0289bd88f80a09cea2764c1d54f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b3e937858299700142027ccda5480f4 = $(`&lt;div id=&quot;html_3b3e937858299700142027ccda5480f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_80e0b0289bd88f80a09cea2764c1d54f.setContent(html_3b3e937858299700142027ccda5480f4);
#
#
#
#         marker_e03df93a1f1383e42c38834129a23016.bindPopup(popup_80e0b0289bd88f80a09cea2764c1d54f)
#         ;
#
#
#
#
#             var marker_a03063a531e29d41cd35c9e7ee0b41e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e1e982f112fcf37d2af1de34b53be2e9);
#
#
#         var popup_b1cf41544b34d92f2af921d755349307 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5db1fb17b9f73518fab089fd8180871e = $(`&lt;div id=&quot;html_5db1fb17b9f73518fab089fd8180871e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b1cf41544b34d92f2af921d755349307.setContent(html_5db1fb17b9f73518fab089fd8180871e);
#
#
#
#         marker_a03063a531e29d41cd35c9e7ee0b41e5.bindPopup(popup_b1cf41544b34d92f2af921d755349307)
#         ;
#
#
#
#
#             var marker_be3bdc51f40b9e174988338946980a34 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e1e982f112fcf37d2af1de34b53be2e9);
#
#
#         var popup_e728cccd22d54ebe4a595bb1221b8164 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a783161c8d7ca132b9a4e8106609421f = $(`&lt;div id=&quot;html_a783161c8d7ca132b9a4e8106609421f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e728cccd22d54ebe4a595bb1221b8164.setContent(html_a783161c8d7ca132b9a4e8106609421f);
#
#
#
#         marker_be3bdc51f40b9e174988338946980a34.bindPopup(popup_e728cccd22d54ebe4a595bb1221b8164)
#         ;
#
#
#
#
#             var marker_b0b4607967ec688613011bdde25e5420 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e1e982f112fcf37d2af1de34b53be2e9);
#
#
#         var popup_3daa259821dfa4e8360a10f3dc49f69c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed9c8e0e7e9932f964c1f00da343d2db = $(`&lt;div id=&quot;html_ed9c8e0e7e9932f964c1f00da343d2db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3daa259821dfa4e8360a10f3dc49f69c.setContent(html_ed9c8e0e7e9932f964c1f00da343d2db);
#
#
#
#         marker_b0b4607967ec688613011bdde25e5420.bindPopup(popup_3daa259821dfa4e8360a10f3dc49f69c)
#         ;
#
#
#
#
#             var marker_9552bee10f1d56ee02567e6002a22f44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e1e982f112fcf37d2af1de34b53be2e9);
#
#
#         var popup_e9ad686e5d819092cfc350333fbf9d94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb56cb535d1df9ebfc6ac0eba59d637d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb56cb535d1df9ebfc6ac0eba59d637d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb56cb535d1df9ebfc6ac0eba59d637d = L.map(
#                 &quot;map_fb56cb535d1df9ebfc6ac0eba59d637d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0be0f67b5aba4fd270eadb54215e226 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0be0f67b5aba4fd270eadb54215e226.addTo(map_fb56cb535d1df9ebfc6ac0eba59d637d);
#
#
#             var feature_group_c4e16f16203982dea956d3fca83cda89 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c4e16f16203982dea956d3fca83cda89.addTo(map_fb56cb535d1df9ebfc6ac0eba59d637d);
#
#
#             var feature_group_sub_group_0ebe15a522383c873dfc1c7f73cb9e9a = L.featureGroup.subGroup(
#                 feature_group_c4e16f16203982dea956d3fca83cda89
#             );
#
#
#             var marker_76ed2fc3c154d812ea367bc0f306ca59 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ebe15a522383c873dfc1c7f73cb9e9a);
#
#
#         var popup_1f2d25056b7fb843a4b22a4db6a9500f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3db38cfb4fa8483235aad27182370fdb = $(`&lt;div id=&quot;html_3db38cfb4fa8483235aad27182370fdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1f2d25056b7fb843a4b22a4db6a9500f.setContent(html_3db38cfb4fa8483235aad27182370fdb);
#
#
#
#         marker_76ed2fc3c154d812ea367bc0f306ca59.bindPopup(popup_1f2d25056b7fb843a4b22a4db6a9500f)
#         ;
#
#
#
#
#             var marker_2bacf333ae1e85781ee03e44b0974b6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ebe15a522383c873dfc1c7f73cb9e9a);
#
#
#         var popup_3e63d0839d3a8b3ef6b7026c4fc64074 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7fb4a3ea5e01839440e2835bc9a374b = $(`&lt;div id=&quot;html_e7fb4a3ea5e01839440e2835bc9a374b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3e63d0839d3a8b3ef6b7026c4fc64074.setContent(html_e7fb4a3ea5e01839440e2835bc9a374b);
#
#
#
#         marker_2bacf333ae1e85781ee03e44b0974b6d.bindPopup(popup_3e63d0839d3a8b3ef6b7026c4fc64074)
#         ;
#
#
#
#
#             var marker_0af2ca689b17a17a9cd38eb82dd74136 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ebe15a522383c873dfc1c7f73cb9e9a);
#
#
#         var popup_e242aad667bd426989f86fdd51dc5fbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcad0fedbd806e4e7718928ac6830be9 = $(`&lt;div id=&quot;html_dcad0fedbd806e4e7718928ac6830be9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e242aad667bd426989f86fdd51dc5fbf.setContent(html_dcad0fedbd806e4e7718928ac6830be9);
#
#
#
#         marker_0af2ca689b17a17a9cd38eb82dd74136.bindPopup(popup_e242aad667bd426989f86fdd51dc5fbf)
#         ;
#
#
#
#
#             var marker_020dbe2106bc8479ccbd8170d62aac1c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0ebe15a522383c873dfc1c7f73cb9e9a);
#
#
#         var popup_8213da1aaa5f0b489becbbefbd032e1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ebf97a5b7e256b330d131251537185a = $(`&lt;div id=&quot;html_2ebf97a5b7e256b330d131251537185a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8213da1aaa5f0b489becbbefbd032e1c.setContent(html_2ebf97a5b7e256b330d131251537185a);
#
#
#
#         marker_
