# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_724e87218fbc14ba1c2a529dc339a37e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_724e87218fbc14ba1c2a529dc339a37e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_724e87218fbc14ba1c2a529dc339a37e = L.map(
#                 &quot;map_724e87218fbc14ba1c2a529dc339a37e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb3dad6471ec2ec7aa1ddfb8772d2340 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb3dad6471ec2ec7aa1ddfb8772d2340.addTo(map_724e87218fbc14ba1c2a529dc339a37e);
#
#
#             var marker_98a5434f17263494ceb12e555389f7f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_724e87218fbc14ba1c2a529dc339a37e);
#
#
#         var popup_530d110d880e73c3f25dae6b95718cdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7773666dba8d65741871333d3450ede3 = $(`&lt;div id=&quot;html_7773666dba8d65741871333d3450ede3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_530d110d880e73c3f25dae6b95718cdc.setContent(html_7773666dba8d65741871333d3450ede3);
#
#
#
#         marker_98a5434f17263494ceb12e555389f7f9.bindPopup(popup_530d110d880e73c3f25dae6b95718cdc)
#         ;
#
#
#
#
#             var marker_f5b61b0004de4be2830c3b104adab482 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_724e87218fbc14ba1c2a529dc339a37e);
#
#
#         var popup_0cc4baa212f2a5b46fe4218a14fad576 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6787e4e6737b4997f9adf16bcdc3bb1 = $(`&lt;div id=&quot;html_e6787e4e6737b4997f9adf16bcdc3bb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0cc4baa212f2a5b46fe4218a14fad576.setContent(html_e6787e4e6737b4997f9adf16bcdc3bb1);
#
#
#
#         marker_f5b61b0004de4be2830c3b104adab482.bindPopup(popup_0cc4baa212f2a5b46fe4218a14fad576)
#         ;
#
#
#
#
#             var marker_4c6332d8c0f5ae90b61005bb5572d00f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_724e87218fbc14ba1c2a529dc339a37e);
#
#
#         var popup_8ec6440ae5d17e2f3a3794afb226bf64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62335295527b10a310ce81b3cd81637f = $(`&lt;div id=&quot;html_62335295527b10a310ce81b3cd81637f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ec6440ae5d17e2f3a3794afb226bf64.setContent(html_62335295527b10a310ce81b3cd81637f);
#
#
#
#         marker_4c6332d8c0f5ae90b61005bb5572d00f.bindPopup(popup_8ec6440ae5d17e2f3a3794afb226bf64)
#         ;
#
#
#
#
#             var marker_398fc6155e3ceb5ab1cc669e6c71af72 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_724e87218fbc14ba1c2a529dc339a37e);
#
#
#         var popup_e993dc336d224a3c10d17acde504dbab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fa542dbc81ca430a027437008ca0a95 = $(`&lt;div id=&quot;html_6fa542dbc81ca430a027437008ca0a95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e993dc336d224a3c10d17acde504dbab.setContent(html_6fa542dbc81ca430a027437008ca0a95);
#
#
#
#         marker_398fc6155e3ceb5ab1cc669e6c71af72.bindPopup(popup_e993dc336d224a3c10d17acde504dbab)
#         ;
#
#
#
#
#             var marker_4db19850337c015757f242ad83c99c78 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_724e87218fbc14ba1c2a529dc339a37e);
#
#
#         var popup_789ba4c11327e69a2bd8e06bd00ee506 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2cb95db54e152a2354c0fbcba61bb99 = $(`&lt;div id=&quot;html_b2cb95db54e152a2354c0fbcba61bb99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_789ba4c11327e69a2bd8e06bd00ee5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db6f1cb2ec96b21adda2fa5262db100b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db6f1cb2ec96b21adda2fa5262db100b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db6f1cb2ec96b21adda2fa5262db100b = L.map(
#                 &quot;map_db6f1cb2ec96b21adda2fa5262db100b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10d82468bfaa48f0ee72ffbfdd6248f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10d82468bfaa48f0ee72ffbfdd6248f3.addTo(map_db6f1cb2ec96b21adda2fa5262db100b);
#
#
#             var feature_group_078397331a43d81c8a8fc90fd5431222 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a970fd704b956529786f2a8721752f6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_078397331a43d81c8a8fc90fd5431222);
#
#
#         var popup_382f214e5991821246b4735c9512265a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_251aa768d7ab8c028522b281f5ec866e = $(`&lt;div id=&quot;html_251aa768d7ab8c028522b281f5ec866e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_382f214e5991821246b4735c9512265a.setContent(html_251aa768d7ab8c028522b281f5ec866e);
#
#
#
#         marker_a970fd704b956529786f2a8721752f6a.bindPopup(popup_382f214e5991821246b4735c9512265a)
#         ;
#
#
#
#
#             var marker_64568832842624274cd905fb2cdb39eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_078397331a43d81c8a8fc90fd5431222);
#
#
#         var popup_479ef0fd9e711368c4778f669de7bfbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d281b7d9902049e465e4996253d0da5a = $(`&lt;div id=&quot;html_d281b7d9902049e465e4996253d0da5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_479ef0fd9e711368c4778f669de7bfbc.setContent(html_d281b7d9902049e465e4996253d0da5a);
#
#
#
#         marker_64568832842624274cd905fb2cdb39eb.bindPopup(popup_479ef0fd9e711368c4778f669de7bfbc)
#         ;
#
#
#
#
#             var marker_143438b1e54ffe71f1945570bbfe5c9d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_078397331a43d81c8a8fc90fd5431222);
#
#
#         var popup_1243db952d4e2a5151ef3a83d77e524f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4732a399226e25f12a39473a3baf39a1 = $(`&lt;div id=&quot;html_4732a399226e25f12a39473a3baf39a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1243db952d4e2a5151ef3a83d77e524f.setContent(html_4732a399226e25f12a39473a3baf39a1);
#
#
#
#         marker_143438b1e54ffe71f1945570bbfe5c9d.bindPopup(popup_1243db952d4e2a5151ef3a83d77e524f)
#         ;
#
#
#
#
#             var marker_6b57626591034f1c87b0a0f88fffa232 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_078397331a43d81c8a8fc90fd5431222);
#
#
#         var popup_c685e41562522b599e7ed7e4bd487a3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52b624b62c6d2324c606d2ea77d7bf58 = $(`&lt;div id=&quot;html_52b624b62c6d2324c606d2ea77d7bf58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c685e41562522b599e7ed7e4bd487a3e.setContent(html_52b624b62c6d2324c606d2ea77d7bf58);
#
#
#
#         marker_6b57626591034f1c87b0a0f88fffa232.bindPopup(popup_c685e41562522b599e7ed7e4bd487a3e)
#         ;
#
#
#
#
#             var marker_94ab767639efdb7b4b198cd0374cd60e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_078397331a43d81c8a8fc90fd5431222);
#
#
#         var popup_d2dcd0c47b7e41e29d4568e259921404 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6b7dfc829b402d1f40c371f1ac85b10 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6b7dfc829b402d1f40c371f1ac85b10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6b7dfc829b402d1f40c371f1ac85b10 = L.map(
#                 &quot;map_c6b7dfc829b402d1f40c371f1ac85b10&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b05770c126eb9de82df153ff16c3a8ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b05770c126eb9de82df153ff16c3a8ef.addTo(map_c6b7dfc829b402d1f40c371f1ac85b10);
#
#
#             var feature_group_cc09c47283908e961ce7ddca440e5f33 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cc09c47283908e961ce7ddca440e5f33.addTo(map_c6b7dfc829b402d1f40c371f1ac85b10);
#
#
#             var feature_group_sub_group_32f4ce641f945b9ae0cf324f35ef5ae4 = L.featureGroup.subGroup(
#                 feature_group_cc09c47283908e961ce7ddca440e5f33
#             );
#
#
#             var marker_e30bd9ff7053e332f4deb3b284cc939d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_32f4ce641f945b9ae0cf324f35ef5ae4);
#
#
#         var popup_fcb0a9cd29efb98160f6da30092846b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a0a565903a77875849dc91c06536a6f = $(`&lt;div id=&quot;html_0a0a565903a77875849dc91c06536a6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fcb0a9cd29efb98160f6da30092846b7.setContent(html_0a0a565903a77875849dc91c06536a6f);
#
#
#
#         marker_e30bd9ff7053e332f4deb3b284cc939d.bindPopup(popup_fcb0a9cd29efb98160f6da30092846b7)
#         ;
#
#
#
#
#             var marker_b0b75db128d15f6a05405012c93a04d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_32f4ce641f945b9ae0cf324f35ef5ae4);
#
#
#         var popup_9ff00a1467b9895f7dd511660baf73e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfc6781c2683d34c243bcea862187593 = $(`&lt;div id=&quot;html_bfc6781c2683d34c243bcea862187593&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9ff00a1467b9895f7dd511660baf73e9.setContent(html_bfc6781c2683d34c243bcea862187593);
#
#
#
#         marker_b0b75db128d15f6a05405012c93a04d8.bindPopup(popup_9ff00a1467b9895f7dd511660baf73e9)
#         ;
#
#
#
#
#             var marker_7d19836a5653042221ac59bd5972ceb7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_32f4ce641f945b9ae0cf324f35ef5ae4);
#
#
#         var popup_e4ec4fe5393948987469b4f7c7ac17bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2be195d81d526dc3fbcb1e8c7abdb07 = $(`&lt;div id=&quot;html_d2be195d81d526dc3fbcb1e8c7abdb07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e4ec4fe5393948987469b4f7c7ac17bb.setContent(html_d2be195d81d526dc3fbcb1e8c7abdb07);
#
#
#
#         marker_7d19836a5653042221ac59bd5972ceb7.bindPopup(popup_e4ec4fe5393948987469b4f7c7ac17bb)
#         ;
#
#
#
#
#             var marker_ab98c9c4c00b288f60cc5151e6a701df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_32f4ce641f945b9ae0cf324f35ef5ae4);
#
#
#         var popup_303c2f8091a0bad814fe9f00d6b64da2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55581c79e15735461b9f7be571294be6 = $(`&lt;div id=&quot;html_55581c79e15735461b9f7be571294be6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_303c2f8091a0bad814fe9f00d6b64da2.setContent(html_55581c79e15735461b9f7be571294be6);
#
#
#
#         mark
