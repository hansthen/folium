# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cdf38ea9c01ce4b814b47a474b843d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cdf38ea9c01ce4b814b47a474b843d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7cdf38ea9c01ce4b814b47a474b843d7 = L.map(
#                 &quot;map_7cdf38ea9c01ce4b814b47a474b843d7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_318e57dc8e5aa012af1a193aab1724e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_318e57dc8e5aa012af1a193aab1724e2.addTo(map_7cdf38ea9c01ce4b814b47a474b843d7);
#
#
#             var marker_134ee3d6af7df6b6ea4ef8b0baa2efac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7cdf38ea9c01ce4b814b47a474b843d7);
#
#
#         var popup_c4ce43e1b13e01bfb818e7d2f04ae2a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe075f3b317d70135d67a9ce32cf65f3 = $(`&lt;div id=&quot;html_fe075f3b317d70135d67a9ce32cf65f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c4ce43e1b13e01bfb818e7d2f04ae2a8.setContent(html_fe075f3b317d70135d67a9ce32cf65f3);
#
#
#
#         marker_134ee3d6af7df6b6ea4ef8b0baa2efac.bindPopup(popup_c4ce43e1b13e01bfb818e7d2f04ae2a8)
#         ;
#
#
#
#
#             var marker_7502309f4ddecc0024e4bdad71009c57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7cdf38ea9c01ce4b814b47a474b843d7);
#
#
#         var popup_3488ce6c519c49be8be482225c56aff0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9e5fe58c3ddad8c1187a515e09432db = $(`&lt;div id=&quot;html_a9e5fe58c3ddad8c1187a515e09432db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3488ce6c519c49be8be482225c56aff0.setContent(html_a9e5fe58c3ddad8c1187a515e09432db);
#
#
#
#         marker_7502309f4ddecc0024e4bdad71009c57.bindPopup(popup_3488ce6c519c49be8be482225c56aff0)
#         ;
#
#
#
#
#             var marker_5f5e0581469848e16df03768c7f2ac95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7cdf38ea9c01ce4b814b47a474b843d7);
#
#
#         var popup_ea69d3ab959a1524fff2338872442750 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd7ba12cebfbe546ee4a951acdee0d28 = $(`&lt;div id=&quot;html_dd7ba12cebfbe546ee4a951acdee0d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ea69d3ab959a1524fff2338872442750.setContent(html_dd7ba12cebfbe546ee4a951acdee0d28);
#
#
#
#         marker_5f5e0581469848e16df03768c7f2ac95.bindPopup(popup_ea69d3ab959a1524fff2338872442750)
#         ;
#
#
#
#
#             var marker_07e5a636fea02942686ae2cfff5b7799 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7cdf38ea9c01ce4b814b47a474b843d7);
#
#
#         var popup_f57d524cb5f06f76be4bd0f813fb4016 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0aec7a1bf0073cc68b1a3ea53d141566 = $(`&lt;div id=&quot;html_0aec7a1bf0073cc68b1a3ea53d141566&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f57d524cb5f06f76be4bd0f813fb4016.setContent(html_0aec7a1bf0073cc68b1a3ea53d141566);
#
#
#
#         marker_07e5a636fea02942686ae2cfff5b7799.bindPopup(popup_f57d524cb5f06f76be4bd0f813fb4016)
#         ;
#
#
#
#
#             var marker_125ed34918ff69ae08ef7abc2b76db3e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7cdf38ea9c01ce4b814b47a474b843d7);
#
#
#         var popup_e48438afeb79dc601122844ceb211a47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b076d8a7f771226126e672eb27dc1eb = $(`&lt;div id=&quot;html_4b076d8a7f771226126e672eb27dc1eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e48438afeb79dc601122844ceb211a47.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5be7d0bd0f4f58a0a118fa15f7381b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5be7d0bd0f4f58a0a118fa15f7381b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5be7d0bd0f4f58a0a118fa15f7381b1 = L.map(
#                 &quot;map_a5be7d0bd0f4f58a0a118fa15f7381b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ceaa2c67aabc89554b07baff2eb6621a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ceaa2c67aabc89554b07baff2eb6621a.addTo(map_a5be7d0bd0f4f58a0a118fa15f7381b1);
#
#
#             var feature_group_87387a5a33b6928c47132e847232bf73 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7d0f87d726e7c03076fb741d66784f85 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_87387a5a33b6928c47132e847232bf73);
#
#
#         var popup_41a4bb986c6b5bb81c4f5be2a768f7c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86cd933e2ef3d14f695dc127baa7ffdb = $(`&lt;div id=&quot;html_86cd933e2ef3d14f695dc127baa7ffdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_41a4bb986c6b5bb81c4f5be2a768f7c9.setContent(html_86cd933e2ef3d14f695dc127baa7ffdb);
#
#
#
#         marker_7d0f87d726e7c03076fb741d66784f85.bindPopup(popup_41a4bb986c6b5bb81c4f5be2a768f7c9)
#         ;
#
#
#
#
#             var marker_e5f83a594faa0a0582959dba521a6d73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_87387a5a33b6928c47132e847232bf73);
#
#
#         var popup_8eb8dfb8f32696bfbfe34989d656140d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be7e2a349078e35fc945c6b7df390cbe = $(`&lt;div id=&quot;html_be7e2a349078e35fc945c6b7df390cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8eb8dfb8f32696bfbfe34989d656140d.setContent(html_be7e2a349078e35fc945c6b7df390cbe);
#
#
#
#         marker_e5f83a594faa0a0582959dba521a6d73.bindPopup(popup_8eb8dfb8f32696bfbfe34989d656140d)
#         ;
#
#
#
#
#             var marker_5ae3ddef1cdda0077f7ba183224aa7c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_87387a5a33b6928c47132e847232bf73);
#
#
#         var popup_9c06559ca0b18296221b3cb1a5afbc9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42fb1b80910b59da9fca32ce46b4dc85 = $(`&lt;div id=&quot;html_42fb1b80910b59da9fca32ce46b4dc85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9c06559ca0b18296221b3cb1a5afbc9b.setContent(html_42fb1b80910b59da9fca32ce46b4dc85);
#
#
#
#         marker_5ae3ddef1cdda0077f7ba183224aa7c2.bindPopup(popup_9c06559ca0b18296221b3cb1a5afbc9b)
#         ;
#
#
#
#
#             var marker_d3eed9d313034439b943eea9be9a6da5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_87387a5a33b6928c47132e847232bf73);
#
#
#         var popup_cc2b5b05a62d73156f3bb882ae41f63f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a168b98de339a4d1aeac8c1c7e2d9af = $(`&lt;div id=&quot;html_1a168b98de339a4d1aeac8c1c7e2d9af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc2b5b05a62d73156f3bb882ae41f63f.setContent(html_1a168b98de339a4d1aeac8c1c7e2d9af);
#
#
#
#         marker_d3eed9d313034439b943eea9be9a6da5.bindPopup(popup_cc2b5b05a62d73156f3bb882ae41f63f)
#         ;
#
#
#
#
#             var marker_78d76c3e1fbd4fdde24077eae17b950c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_87387a5a33b6928c47132e847232bf73);
#
#
#         var popup_9a89e71b7a09c6a483fcb3b9b886f749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e30fc25df1cfb776f739233abde3e3ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e30fc25df1cfb776f739233abde3e3ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e30fc25df1cfb776f739233abde3e3ed = L.map(
#                 &quot;map_e30fc25df1cfb776f739233abde3e3ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b7978807c6776623eb35986fbd5da4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b7978807c6776623eb35986fbd5da4c.addTo(map_e30fc25df1cfb776f739233abde3e3ed);
#
#
#             var feature_group_f81d95236c3d5523053692f3a9c0e2c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f81d95236c3d5523053692f3a9c0e2c6.addTo(map_e30fc25df1cfb776f739233abde3e3ed);
#
#
#             var feature_group_sub_group_0914be53eddd8da6093cfde7bc31a8d7 = L.featureGroup.subGroup(
#                 feature_group_f81d95236c3d5523053692f3a9c0e2c6
#             );
#
#
#             var marker_8609311324fcc0ad88753fc689cc49fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0914be53eddd8da6093cfde7bc31a8d7);
#
#
#         var popup_651935204dd635cb7b4fdb49669b071b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4f1afd0fb1a553fa4c4a83fca004406 = $(`&lt;div id=&quot;html_a4f1afd0fb1a553fa4c4a83fca004406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_651935204dd635cb7b4fdb49669b071b.setContent(html_a4f1afd0fb1a553fa4c4a83fca004406);
#
#
#
#         marker_8609311324fcc0ad88753fc689cc49fa.bindPopup(popup_651935204dd635cb7b4fdb49669b071b)
#         ;
#
#
#
#
#             var marker_5537dcdb4a206ced26b25ec36693702f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0914be53eddd8da6093cfde7bc31a8d7);
#
#
#         var popup_932110a6f73937b7457fe18263ad3f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_574caa3254c46b6d1dd1f2f54807c4bd = $(`&lt;div id=&quot;html_574caa3254c46b6d1dd1f2f54807c4bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_932110a6f73937b7457fe18263ad3f7a.setContent(html_574caa3254c46b6d1dd1f2f54807c4bd);
#
#
#
#         marker_5537dcdb4a206ced26b25ec36693702f.bindPopup(popup_932110a6f73937b7457fe18263ad3f7a)
#         ;
#
#
#
#
#             var marker_0bfb9ee8ac88c44bd19adee682b9f109 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0914be53eddd8da6093cfde7bc31a8d7);
#
#
#         var popup_976a943a8c13a5e7145e3f946b768f92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60b02e5f5a2285d607c752705577fada = $(`&lt;div id=&quot;html_60b02e5f5a2285d607c752705577fada&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_976a943a8c13a5e7145e3f946b768f92.setContent(html_60b02e5f5a2285d607c752705577fada);
#
#
#
#         marker_0bfb9ee8ac88c44bd19adee682b9f109.bindPopup(popup_976a943a8c13a5e7145e3f946b768f92)
#         ;
#
#
#
#
#             var marker_0596d552e16ac60dc6044cecb33b4eba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0914be53eddd8da6093cfde7bc31a8d7);
#
#
#         var popup_7e3effd79c8084247a130e534b1afd36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1ac7c11e44b1d6f35bfc3bdf0b23775 = $(`&lt;div id=&quot;html_f1ac7c11e44b1d6f35bfc3bdf0b23775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7e3effd79c8084247a130e534b1afd36.setContent(html_f1ac7c11e44b1d6f35bfc3bdf0b23775);
#
#
#
#         marker_
