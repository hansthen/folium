# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cacfeda92fd1a97ebcd765926b1178c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cacfeda92fd1a97ebcd765926b1178c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cacfeda92fd1a97ebcd765926b1178c = L.map(
#                 &quot;map_0cacfeda92fd1a97ebcd765926b1178c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dabe9f7441cb38c3d64cf088cc447681 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dabe9f7441cb38c3d64cf088cc447681.addTo(map_0cacfeda92fd1a97ebcd765926b1178c);
#
#
#             var marker_df20414ae217f5725eaa3de29120c7ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0cacfeda92fd1a97ebcd765926b1178c);
#
#
#         var popup_c43ef1f6508a78dd8976a6b29a2ee160 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_121162668bc05f7cae6f9b6a68e8d789 = $(`&lt;div id=&quot;html_121162668bc05f7cae6f9b6a68e8d789&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c43ef1f6508a78dd8976a6b29a2ee160.setContent(html_121162668bc05f7cae6f9b6a68e8d789);
#
#
#
#         marker_df20414ae217f5725eaa3de29120c7ce.bindPopup(popup_c43ef1f6508a78dd8976a6b29a2ee160)
#         ;
#
#
#
#
#             var marker_f02fa404d3c6bacbac57d975ac40dcb4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0cacfeda92fd1a97ebcd765926b1178c);
#
#
#         var popup_916be9897f48d4a9a9ebf5f6b17bfaf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9e6fec6fe2179ee600389855f4e1f25 = $(`&lt;div id=&quot;html_a9e6fec6fe2179ee600389855f4e1f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_916be9897f48d4a9a9ebf5f6b17bfaf3.setContent(html_a9e6fec6fe2179ee600389855f4e1f25);
#
#
#
#         marker_f02fa404d3c6bacbac57d975ac40dcb4.bindPopup(popup_916be9897f48d4a9a9ebf5f6b17bfaf3)
#         ;
#
#
#
#
#             var marker_b64c1ec80e6a6790b482a1fe2a3cac08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0cacfeda92fd1a97ebcd765926b1178c);
#
#
#         var popup_be5e99929ee55fff238a5b6a14af3964 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9c1a69e4515cc6a9c4c6ab6ba37d798 = $(`&lt;div id=&quot;html_f9c1a69e4515cc6a9c4c6ab6ba37d798&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_be5e99929ee55fff238a5b6a14af3964.setContent(html_f9c1a69e4515cc6a9c4c6ab6ba37d798);
#
#
#
#         marker_b64c1ec80e6a6790b482a1fe2a3cac08.bindPopup(popup_be5e99929ee55fff238a5b6a14af3964)
#         ;
#
#
#
#
#             var marker_ea01f5c8302cb004e65d4e5d72286e28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0cacfeda92fd1a97ebcd765926b1178c);
#
#
#         var popup_0d0f881ac48718d9bd540ff837b0d3c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91644ecab7831dd14b3bbe0fb7e4fcb4 = $(`&lt;div id=&quot;html_91644ecab7831dd14b3bbe0fb7e4fcb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d0f881ac48718d9bd540ff837b0d3c2.setContent(html_91644ecab7831dd14b3bbe0fb7e4fcb4);
#
#
#
#         marker_ea01f5c8302cb004e65d4e5d72286e28.bindPopup(popup_0d0f881ac48718d9bd540ff837b0d3c2)
#         ;
#
#
#
#
#             var marker_4dc4c0e1230d32e07493a267dcf90eba = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0cacfeda92fd1a97ebcd765926b1178c);
#
#
#         var popup_b2a97a0d91761f0f341f511f971f5054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_254e01199cc95ea7753d5c6968770a42 = $(`&lt;div id=&quot;html_254e01199cc95ea7753d5c6968770a42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b2a97a0d91761f0f341f511f971f50

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62b321d716886e8e6e80043777c57d46 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62b321d716886e8e6e80043777c57d46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62b321d716886e8e6e80043777c57d46 = L.map(
#                 &quot;map_62b321d716886e8e6e80043777c57d46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17a657a6603d11b9be7543798bd1cd76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17a657a6603d11b9be7543798bd1cd76.addTo(map_62b321d716886e8e6e80043777c57d46);
#
#
#             var feature_group_f756238c042fde924aadf572357537a9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4d850238ad2b012b8c636a78731a9704 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f756238c042fde924aadf572357537a9);
#
#
#         var popup_cd18c08f573d79ea0b9e6b156185611a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b954f7bd70552b48ab0c414a5b5f3357 = $(`&lt;div id=&quot;html_b954f7bd70552b48ab0c414a5b5f3357&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cd18c08f573d79ea0b9e6b156185611a.setContent(html_b954f7bd70552b48ab0c414a5b5f3357);
#
#
#
#         marker_4d850238ad2b012b8c636a78731a9704.bindPopup(popup_cd18c08f573d79ea0b9e6b156185611a)
#         ;
#
#
#
#
#             var marker_d0e1939c266cbc411c04553743542521 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f756238c042fde924aadf572357537a9);
#
#
#         var popup_9819206ec825c171cfd4144b158bf159 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b694dceb904eb4b32d69834db98c0fc7 = $(`&lt;div id=&quot;html_b694dceb904eb4b32d69834db98c0fc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9819206ec825c171cfd4144b158bf159.setContent(html_b694dceb904eb4b32d69834db98c0fc7);
#
#
#
#         marker_d0e1939c266cbc411c04553743542521.bindPopup(popup_9819206ec825c171cfd4144b158bf159)
#         ;
#
#
#
#
#             var marker_f3bdf8bc36e771d93205b452e4561f59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f756238c042fde924aadf572357537a9);
#
#
#         var popup_96154640a439545d28d05cdc80c273fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f14807eee6c2e91f1cb35ec58e8ecfee = $(`&lt;div id=&quot;html_f14807eee6c2e91f1cb35ec58e8ecfee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_96154640a439545d28d05cdc80c273fa.setContent(html_f14807eee6c2e91f1cb35ec58e8ecfee);
#
#
#
#         marker_f3bdf8bc36e771d93205b452e4561f59.bindPopup(popup_96154640a439545d28d05cdc80c273fa)
#         ;
#
#
#
#
#             var marker_de262e0b000e64575f92789008c9fd86 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f756238c042fde924aadf572357537a9);
#
#
#         var popup_577bbfa4dda531993657a97991d221b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_983deb34c7f6192e9aac15fbe282dde2 = $(`&lt;div id=&quot;html_983deb34c7f6192e9aac15fbe282dde2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_577bbfa4dda531993657a97991d221b8.setContent(html_983deb34c7f6192e9aac15fbe282dde2);
#
#
#
#         marker_de262e0b000e64575f92789008c9fd86.bindPopup(popup_577bbfa4dda531993657a97991d221b8)
#         ;
#
#
#
#
#             var marker_0c4b11065a3944a8985fbff78d35bf23 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f756238c042fde924aadf572357537a9);
#
#
#         var popup_9b187c98167525c358983f25a82cc2f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08fb913d2e5a36b6f220a08d23b32c93 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08fb913d2e5a36b6f220a08d23b32c93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08fb913d2e5a36b6f220a08d23b32c93 = L.map(
#                 &quot;map_08fb913d2e5a36b6f220a08d23b32c93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d73c02f0d3b23c10d7849c2fa12783cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d73c02f0d3b23c10d7849c2fa12783cf.addTo(map_08fb913d2e5a36b6f220a08d23b32c93);
#
#
#             var feature_group_722b862db0f74ffcc86571c174241fc4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_722b862db0f74ffcc86571c174241fc4.addTo(map_08fb913d2e5a36b6f220a08d23b32c93);
#
#
#             var feature_group_sub_group_54a405a242008eba11618129c31f9f1b = L.featureGroup.subGroup(
#                 feature_group_722b862db0f74ffcc86571c174241fc4
#             );
#
#
#             var marker_0c1a3cf30b82b2f10848df5630ae5e06 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_54a405a242008eba11618129c31f9f1b);
#
#
#         var popup_1f1d74871b8818368e1512488f7e0ec4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ce817b999033cb53ea21556afb31d21 = $(`&lt;div id=&quot;html_2ce817b999033cb53ea21556afb31d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1f1d74871b8818368e1512488f7e0ec4.setContent(html_2ce817b999033cb53ea21556afb31d21);
#
#
#
#         marker_0c1a3cf30b82b2f10848df5630ae5e06.bindPopup(popup_1f1d74871b8818368e1512488f7e0ec4)
#         ;
#
#
#
#
#             var marker_c4166af619ede5f7f15b7cc25c0d502a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_54a405a242008eba11618129c31f9f1b);
#
#
#         var popup_7ea63240c5c73928a971cd59812df5d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a174bffb1b5e9ccf09707f9fabe5e1e = $(`&lt;div id=&quot;html_0a174bffb1b5e9ccf09707f9fabe5e1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7ea63240c5c73928a971cd59812df5d9.setContent(html_0a174bffb1b5e9ccf09707f9fabe5e1e);
#
#
#
#         marker_c4166af619ede5f7f15b7cc25c0d502a.bindPopup(popup_7ea63240c5c73928a971cd59812df5d9)
#         ;
#
#
#
#
#             var marker_3da1e56fd586af919c94cf70f48ed6fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_54a405a242008eba11618129c31f9f1b);
#
#
#         var popup_a25e7eb7e7f15288b45a2220b57827a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_544924e46c34f13203f591d8f24b6874 = $(`&lt;div id=&quot;html_544924e46c34f13203f591d8f24b6874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a25e7eb7e7f15288b45a2220b57827a6.setContent(html_544924e46c34f13203f591d8f24b6874);
#
#
#
#         marker_3da1e56fd586af919c94cf70f48ed6fd.bindPopup(popup_a25e7eb7e7f15288b45a2220b57827a6)
#         ;
#
#
#
#
#             var marker_ce3baf047c4991ed0355ad9ea9b1b0f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_54a405a242008eba11618129c31f9f1b);
#
#
#         var popup_2fbcccc4aac913ad80c1d8b5bf1c3a84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f38ed03b1b49104800c72c8f53786151 = $(`&lt;div id=&quot;html_f38ed03b1b49104800c72c8f53786151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2fbcccc4aac913ad80c1d8b5bf1c3a84.setContent(html_f38ed03b1b49104800c72c8f53786151);
#
#
#
#         mark
