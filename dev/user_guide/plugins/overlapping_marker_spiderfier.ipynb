# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2faca05b6da2338c6507a8852664f01b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2faca05b6da2338c6507a8852664f01b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2faca05b6da2338c6507a8852664f01b = L.map(
#                 &quot;map_2faca05b6da2338c6507a8852664f01b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcc8cd1c7ed9c68f67923edfaf570c6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcc8cd1c7ed9c68f67923edfaf570c6d.addTo(map_2faca05b6da2338c6507a8852664f01b);
#
#
#             var marker_55e1dbf23e2f2d72c17c363eb9a4b84e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2faca05b6da2338c6507a8852664f01b);
#
#
#         var popup_fd560f3e466ab7b316f53b7e5787e4e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72bcb915902a6264c1b35a40bbc3fda7 = $(`&lt;div id=&quot;html_72bcb915902a6264c1b35a40bbc3fda7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fd560f3e466ab7b316f53b7e5787e4e2.setContent(html_72bcb915902a6264c1b35a40bbc3fda7);
#
#
#
#         marker_55e1dbf23e2f2d72c17c363eb9a4b84e.bindPopup(popup_fd560f3e466ab7b316f53b7e5787e4e2)
#         ;
#
#
#
#
#             var marker_2b5f323d6da2168a892d4eaaf91b267d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2faca05b6da2338c6507a8852664f01b);
#
#
#         var popup_baa267412752845f857bf73366eb1ce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b069a61e12aa0372ded795d94b597360 = $(`&lt;div id=&quot;html_b069a61e12aa0372ded795d94b597360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_baa267412752845f857bf73366eb1ce7.setContent(html_b069a61e12aa0372ded795d94b597360);
#
#
#
#         marker_2b5f323d6da2168a892d4eaaf91b267d.bindPopup(popup_baa267412752845f857bf73366eb1ce7)
#         ;
#
#
#
#
#             var marker_082f4711851e72691c688ea2c821627e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2faca05b6da2338c6507a8852664f01b);
#
#
#         var popup_8e79451f3c26deea05beda79719faff4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fce7bb963fa8c15ea3dea577c45f493 = $(`&lt;div id=&quot;html_3fce7bb963fa8c15ea3dea577c45f493&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8e79451f3c26deea05beda79719faff4.setContent(html_3fce7bb963fa8c15ea3dea577c45f493);
#
#
#
#         marker_082f4711851e72691c688ea2c821627e.bindPopup(popup_8e79451f3c26deea05beda79719faff4)
#         ;
#
#
#
#
#             var marker_b4e180143e89a2708b80732c2f8da582 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2faca05b6da2338c6507a8852664f01b);
#
#
#         var popup_58a888c628aae19b78bff507343463c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_070741fa49b167b8043335c4a640e297 = $(`&lt;div id=&quot;html_070741fa49b167b8043335c4a640e297&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_58a888c628aae19b78bff507343463c0.setContent(html_070741fa49b167b8043335c4a640e297);
#
#
#
#         marker_b4e180143e89a2708b80732c2f8da582.bindPopup(popup_58a888c628aae19b78bff507343463c0)
#         ;
#
#
#
#
#             var marker_f71e6a92e87451911dee38c2cb8ac778 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2faca05b6da2338c6507a8852664f01b);
#
#
#         var popup_3a45d3b49ef166dc5f876ad95d291f58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6807e2cc6e1734142d21107668631134 = $(`&lt;div id=&quot;html_6807e2cc6e1734142d21107668631134&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3a45d3b49ef166dc5f876ad95d291f

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3591a5e7fdb33e01b60f14366ab427d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3591a5e7fdb33e01b60f14366ab427d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3591a5e7fdb33e01b60f14366ab427d = L.map(
#                 &quot;map_e3591a5e7fdb33e01b60f14366ab427d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_657f34c9ed1f263683c3b440c2b7dfe7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_657f34c9ed1f263683c3b440c2b7dfe7.addTo(map_e3591a5e7fdb33e01b60f14366ab427d);
#
#
#             var feature_group_eec2c209497223a734f5bb7d1906daf3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_97017aa9e442165c480818e2cedf0582 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eec2c209497223a734f5bb7d1906daf3);
#
#
#         var popup_33fdde3c45bfa0738a10e8f6a1fb54bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d7f27c10467b70a6bff5c5a6fe4f2fe = $(`&lt;div id=&quot;html_1d7f27c10467b70a6bff5c5a6fe4f2fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_33fdde3c45bfa0738a10e8f6a1fb54bd.setContent(html_1d7f27c10467b70a6bff5c5a6fe4f2fe);
#
#
#
#         marker_97017aa9e442165c480818e2cedf0582.bindPopup(popup_33fdde3c45bfa0738a10e8f6a1fb54bd)
#         ;
#
#
#
#
#             var marker_cd57b318d564b34792fc3a896f75c4e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eec2c209497223a734f5bb7d1906daf3);
#
#
#         var popup_db45e52997e6e72fcc8a51f1ac34b334 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f9f1417238550814e761ff0b760e14a = $(`&lt;div id=&quot;html_6f9f1417238550814e761ff0b760e14a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_db45e52997e6e72fcc8a51f1ac34b334.setContent(html_6f9f1417238550814e761ff0b760e14a);
#
#
#
#         marker_cd57b318d564b34792fc3a896f75c4e8.bindPopup(popup_db45e52997e6e72fcc8a51f1ac34b334)
#         ;
#
#
#
#
#             var marker_dff8b7d5136945e7a1fda2dcf4adeed0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eec2c209497223a734f5bb7d1906daf3);
#
#
#         var popup_5c5c0aada0863a5fb1dc85f2e5c77e2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7059e89bec5a955475351d4b6af7115 = $(`&lt;div id=&quot;html_e7059e89bec5a955475351d4b6af7115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5c5c0aada0863a5fb1dc85f2e5c77e2d.setContent(html_e7059e89bec5a955475351d4b6af7115);
#
#
#
#         marker_dff8b7d5136945e7a1fda2dcf4adeed0.bindPopup(popup_5c5c0aada0863a5fb1dc85f2e5c77e2d)
#         ;
#
#
#
#
#             var marker_123eea03d57fa14ad3235211e30d262b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eec2c209497223a734f5bb7d1906daf3);
#
#
#         var popup_4a4573eef7e03044859c439afcbcdbb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96684eefc235599172e8382732f3c2c5 = $(`&lt;div id=&quot;html_96684eefc235599172e8382732f3c2c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4a4573eef7e03044859c439afcbcdbb9.setContent(html_96684eefc235599172e8382732f3c2c5);
#
#
#
#         marker_123eea03d57fa14ad3235211e30d262b.bindPopup(popup_4a4573eef7e03044859c439afcbcdbb9)
#         ;
#
#
#
#
#             var marker_ef71995514e9315d1b561fb4186f335f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eec2c209497223a734f5bb7d1906daf3);
#
#
#         var popup_56f9040232b0ffe22b98faf84a2675d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44e6cd1502d9e4bc51b07e2dbb3a261c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44e6cd1502d9e4bc51b07e2dbb3a261c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44e6cd1502d9e4bc51b07e2dbb3a261c = L.map(
#                 &quot;map_44e6cd1502d9e4bc51b07e2dbb3a261c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3519db4c2dead54cfdfc14d69b785e2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3519db4c2dead54cfdfc14d69b785e2d.addTo(map_44e6cd1502d9e4bc51b07e2dbb3a261c);
#
#
#             var feature_group_04a57af1762b6888b3fa180962956920 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_04a57af1762b6888b3fa180962956920.addTo(map_44e6cd1502d9e4bc51b07e2dbb3a261c);
#
#
#             var feature_group_sub_group_d1ef63bcc690b5f57d55fe7889a2be1a = L.featureGroup.subGroup(
#                 feature_group_04a57af1762b6888b3fa180962956920
#             );
#
#
#             var marker_be85818b5f6101c67b3ead8187b3a828 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d1ef63bcc690b5f57d55fe7889a2be1a);
#
#
#         var popup_3cc090873102edeabb60b9a9b575b8d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1434df2aea5d4e55c81feb6307cddf44 = $(`&lt;div id=&quot;html_1434df2aea5d4e55c81feb6307cddf44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3cc090873102edeabb60b9a9b575b8d6.setContent(html_1434df2aea5d4e55c81feb6307cddf44);
#
#
#
#         marker_be85818b5f6101c67b3ead8187b3a828.bindPopup(popup_3cc090873102edeabb60b9a9b575b8d6)
#         ;
#
#
#
#
#             var marker_15f642906ad1e7e29d57e9b74c1af178 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d1ef63bcc690b5f57d55fe7889a2be1a);
#
#
#         var popup_e0ccfd6c420f0e5cbc6d2d0fbd449dad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_758ede2004216599888c6ee95e815f10 = $(`&lt;div id=&quot;html_758ede2004216599888c6ee95e815f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0ccfd6c420f0e5cbc6d2d0fbd449dad.setContent(html_758ede2004216599888c6ee95e815f10);
#
#
#
#         marker_15f642906ad1e7e29d57e9b74c1af178.bindPopup(popup_e0ccfd6c420f0e5cbc6d2d0fbd449dad)
#         ;
#
#
#
#
#             var marker_2064513531041c12bcc4c4d898ffb461 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d1ef63bcc690b5f57d55fe7889a2be1a);
#
#
#         var popup_62fc940d95c4af50f48cf50dedee08d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_594d341d5be71dcd9716e3a4b93cd270 = $(`&lt;div id=&quot;html_594d341d5be71dcd9716e3a4b93cd270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_62fc940d95c4af50f48cf50dedee08d2.setContent(html_594d341d5be71dcd9716e3a4b93cd270);
#
#
#
#         marker_2064513531041c12bcc4c4d898ffb461.bindPopup(popup_62fc940d95c4af50f48cf50dedee08d2)
#         ;
#
#
#
#
#             var marker_c348a2a8f8591ae0c2846bf54b00f2d4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d1ef63bcc690b5f57d55fe7889a2be1a);
#
#
#         var popup_24f69ad6ff2af3c1575e3af3f812532b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1aa70c26ab3b776133076e3523e38462 = $(`&lt;div id=&quot;html_1aa70c26ab3b776133076e3523e38462&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_24f69ad6ff2af3c1575e3af3f812532b.setContent(html_1aa70c26ab3b776133076e3523e38462);
#
#
#
#         mark
