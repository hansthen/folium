# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e92b78719839831edeaf8c53540eeef {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e92b78719839831edeaf8c53540eeef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e92b78719839831edeaf8c53540eeef = L.map(
#                 &quot;map_5e92b78719839831edeaf8c53540eeef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_269e1604ed3ea527b4bc3a3945fad53a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_269e1604ed3ea527b4bc3a3945fad53a.addTo(map_5e92b78719839831edeaf8c53540eeef);
#
#
#             var marker_4d770d6cc71afaac9f0eee60e45e8e60 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5e92b78719839831edeaf8c53540eeef);
#
#
#         var popup_c964107fcb785e4c721f84a2cca6ecfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a980d91fd723472c5aa3c1db337c90c4 = $(`&lt;div id=&quot;html_a980d91fd723472c5aa3c1db337c90c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c964107fcb785e4c721f84a2cca6ecfb.setContent(html_a980d91fd723472c5aa3c1db337c90c4);
#
#
#
#         marker_4d770d6cc71afaac9f0eee60e45e8e60.bindPopup(popup_c964107fcb785e4c721f84a2cca6ecfb)
#         ;
#
#
#
#
#             var marker_ece1781f24069b962aefca169ffb1a92 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5e92b78719839831edeaf8c53540eeef);
#
#
#         var popup_c6b34253f1cee8762b0f111630043271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1177c14a853d7941c15d38e68ada87ca = $(`&lt;div id=&quot;html_1177c14a853d7941c15d38e68ada87ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c6b34253f1cee8762b0f111630043271.setContent(html_1177c14a853d7941c15d38e68ada87ca);
#
#
#
#         marker_ece1781f24069b962aefca169ffb1a92.bindPopup(popup_c6b34253f1cee8762b0f111630043271)
#         ;
#
#
#
#
#             var marker_6b8ab5cb748a2e34034e4507cec6705c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5e92b78719839831edeaf8c53540eeef);
#
#
#         var popup_b3fc33fb81221f4c524074337baec54f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e4f38954b29c5d74fefcd9e6e0f1e30 = $(`&lt;div id=&quot;html_2e4f38954b29c5d74fefcd9e6e0f1e30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b3fc33fb81221f4c524074337baec54f.setContent(html_2e4f38954b29c5d74fefcd9e6e0f1e30);
#
#
#
#         marker_6b8ab5cb748a2e34034e4507cec6705c.bindPopup(popup_b3fc33fb81221f4c524074337baec54f)
#         ;
#
#
#
#
#             var marker_a571d0f452482729019bd75b25d5bb82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5e92b78719839831edeaf8c53540eeef);
#
#
#         var popup_e89282d169b52deb1508820be0afe691 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9abef78b685ef788fbb8c5ecb9246894 = $(`&lt;div id=&quot;html_9abef78b685ef788fbb8c5ecb9246894&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e89282d169b52deb1508820be0afe691.setContent(html_9abef78b685ef788fbb8c5ecb9246894);
#
#
#
#         marker_a571d0f452482729019bd75b25d5bb82.bindPopup(popup_e89282d169b52deb1508820be0afe691)
#         ;
#
#
#
#
#             var marker_d45756b75f2ed97e5dd04b0ee01a9f4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5e92b78719839831edeaf8c53540eeef);
#
#
#         var popup_d2003234de2b9a9d729d5da9f74f456e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe9ede06acd8cfb6fa9c490d5e16ffc4 = $(`&lt;div id=&quot;html_fe9ede06acd8cfb6fa9c490d5e16ffc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d2003234de2b9a9d729d5da9f74f45

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccf71e59f804ad988f0ef0f1119528ef {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccf71e59f804ad988f0ef0f1119528ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccf71e59f804ad988f0ef0f1119528ef = L.map(
#                 &quot;map_ccf71e59f804ad988f0ef0f1119528ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b18b6ffd1c5ae4173ddc3a367a05d260 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b18b6ffd1c5ae4173ddc3a367a05d260.addTo(map_ccf71e59f804ad988f0ef0f1119528ef);
#
#
#             var feature_group_676aa16f783a96d38a4c67927d57289e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_53e6991d6d08786fd5f1b7526a79b592 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_676aa16f783a96d38a4c67927d57289e);
#
#
#         var popup_b28647df1ca65a2e21ead9871c5461fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c0361b79c76010f45ec867fa3122731 = $(`&lt;div id=&quot;html_8c0361b79c76010f45ec867fa3122731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b28647df1ca65a2e21ead9871c5461fd.setContent(html_8c0361b79c76010f45ec867fa3122731);
#
#
#
#         marker_53e6991d6d08786fd5f1b7526a79b592.bindPopup(popup_b28647df1ca65a2e21ead9871c5461fd)
#         ;
#
#
#
#
#             var marker_1e94f3f8decd59f04f8557f83fb7fbbd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_676aa16f783a96d38a4c67927d57289e);
#
#
#         var popup_4720289d13929232963a1e70af1a5da6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a2f469834000fd92d6911ff9ffddd6e = $(`&lt;div id=&quot;html_8a2f469834000fd92d6911ff9ffddd6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4720289d13929232963a1e70af1a5da6.setContent(html_8a2f469834000fd92d6911ff9ffddd6e);
#
#
#
#         marker_1e94f3f8decd59f04f8557f83fb7fbbd.bindPopup(popup_4720289d13929232963a1e70af1a5da6)
#         ;
#
#
#
#
#             var marker_0d69c5757a9827924661c5506d4e366a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_676aa16f783a96d38a4c67927d57289e);
#
#
#         var popup_bc6c45e2564a52ba8a6a891406c4749a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56dafff4ab46341ce7e79d25dbea7b6d = $(`&lt;div id=&quot;html_56dafff4ab46341ce7e79d25dbea7b6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bc6c45e2564a52ba8a6a891406c4749a.setContent(html_56dafff4ab46341ce7e79d25dbea7b6d);
#
#
#
#         marker_0d69c5757a9827924661c5506d4e366a.bindPopup(popup_bc6c45e2564a52ba8a6a891406c4749a)
#         ;
#
#
#
#
#             var marker_c05141695b2dd6e2858d92645592f4da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_676aa16f783a96d38a4c67927d57289e);
#
#
#         var popup_ccacc533c874c8f2948bf81a538492b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4831617720c90a29fd4d9dbc3f6d0b5b = $(`&lt;div id=&quot;html_4831617720c90a29fd4d9dbc3f6d0b5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ccacc533c874c8f2948bf81a538492b9.setContent(html_4831617720c90a29fd4d9dbc3f6d0b5b);
#
#
#
#         marker_c05141695b2dd6e2858d92645592f4da.bindPopup(popup_ccacc533c874c8f2948bf81a538492b9)
#         ;
#
#
#
#
#             var marker_822a688777fe53d334f1810e31285ee4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_676aa16f783a96d38a4c67927d57289e);
#
#
#         var popup_dc4c5b8fe7cb4d123f52188cdbf1cd4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fb458275a4fcdffd6ea161f3f4c8e62 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fb458275a4fcdffd6ea161f3f4c8e62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fb458275a4fcdffd6ea161f3f4c8e62 = L.map(
#                 &quot;map_3fb458275a4fcdffd6ea161f3f4c8e62&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6aaff0c5ed9284c77710597af38d316c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6aaff0c5ed9284c77710597af38d316c.addTo(map_3fb458275a4fcdffd6ea161f3f4c8e62);
#
#
#             var feature_group_ca603fc9ea6b3fcff926aacc59a1ed1b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ca603fc9ea6b3fcff926aacc59a1ed1b.addTo(map_3fb458275a4fcdffd6ea161f3f4c8e62);
#
#
#             var feature_group_sub_group_cbbbe1984304b58fe142f59583f2a1f3 = L.featureGroup.subGroup(
#                 feature_group_ca603fc9ea6b3fcff926aacc59a1ed1b
#             );
#
#
#             var marker_6e2e38c94575214989338de8796bacc8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbbbe1984304b58fe142f59583f2a1f3);
#
#
#         var popup_20ef778fa0776a1196a59c6b0dadf70c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_594753069f383dc754945f2caa363ec3 = $(`&lt;div id=&quot;html_594753069f383dc754945f2caa363ec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_20ef778fa0776a1196a59c6b0dadf70c.setContent(html_594753069f383dc754945f2caa363ec3);
#
#
#
#         marker_6e2e38c94575214989338de8796bacc8.bindPopup(popup_20ef778fa0776a1196a59c6b0dadf70c)
#         ;
#
#
#
#
#             var marker_fc299f7e65c74c4a50b83eb543ea6185 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbbbe1984304b58fe142f59583f2a1f3);
#
#
#         var popup_efe27e27cf7e6798c958308bc2809246 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca0ac4573f827123da72bb694f9ebbc9 = $(`&lt;div id=&quot;html_ca0ac4573f827123da72bb694f9ebbc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_efe27e27cf7e6798c958308bc2809246.setContent(html_ca0ac4573f827123da72bb694f9ebbc9);
#
#
#
#         marker_fc299f7e65c74c4a50b83eb543ea6185.bindPopup(popup_efe27e27cf7e6798c958308bc2809246)
#         ;
#
#
#
#
#             var marker_4f6500b6ce00ba742192a951bb7f9665 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbbbe1984304b58fe142f59583f2a1f3);
#
#
#         var popup_920d7e198b39411e7894b31930c3db73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76afb8421008c523fc76d85bcb3c80f7 = $(`&lt;div id=&quot;html_76afb8421008c523fc76d85bcb3c80f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_920d7e198b39411e7894b31930c3db73.setContent(html_76afb8421008c523fc76d85bcb3c80f7);
#
#
#
#         marker_4f6500b6ce00ba742192a951bb7f9665.bindPopup(popup_920d7e198b39411e7894b31930c3db73)
#         ;
#
#
#
#
#             var marker_52206b8d9d655ea567120cf1c4e778af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbbbe1984304b58fe142f59583f2a1f3);
#
#
#         var popup_47ee3ec613657b19f3c95fe6ff73c454 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20e4763dbcd2a90d1e7125e3f1bec8a9 = $(`&lt;div id=&quot;html_20e4763dbcd2a90d1e7125e3f1bec8a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_47ee3ec613657b19f3c95fe6ff73c454.setContent(html_20e4763dbcd2a90d1e7125e3f1bec8a9);
#
#
#
#         mark
