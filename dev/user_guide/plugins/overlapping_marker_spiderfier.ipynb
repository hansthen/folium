# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bfeb456417d27c804acbba19751995e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bfeb456417d27c804acbba19751995e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bfeb456417d27c804acbba19751995e = L.map(
#                 &quot;map_4bfeb456417d27c804acbba19751995e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10e8c1525de01f2475d59d147c6a6133 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10e8c1525de01f2475d59d147c6a6133.addTo(map_4bfeb456417d27c804acbba19751995e);
#
#
#             var marker_67c298d3236c448a54272b32bc9f142f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4bfeb456417d27c804acbba19751995e);
#
#
#         var popup_a3b74601559acff5d06cab6a3ce23686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7006f3c487f96a537d5e79ec47cb003 = $(`&lt;div id=&quot;html_a7006f3c487f96a537d5e79ec47cb003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a3b74601559acff5d06cab6a3ce23686.setContent(html_a7006f3c487f96a537d5e79ec47cb003);
#
#
#
#         marker_67c298d3236c448a54272b32bc9f142f.bindPopup(popup_a3b74601559acff5d06cab6a3ce23686)
#         ;
#
#
#
#
#             var marker_f8d686feb49e358f825fde857648ae88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4bfeb456417d27c804acbba19751995e);
#
#
#         var popup_52f7e33cce839f37ce7f6502f070488e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c71378614bea16e2bc9e9d3f687455a4 = $(`&lt;div id=&quot;html_c71378614bea16e2bc9e9d3f687455a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_52f7e33cce839f37ce7f6502f070488e.setContent(html_c71378614bea16e2bc9e9d3f687455a4);
#
#
#
#         marker_f8d686feb49e358f825fde857648ae88.bindPopup(popup_52f7e33cce839f37ce7f6502f070488e)
#         ;
#
#
#
#
#             var marker_2d1ec114c5cf73f041104cfb441220b0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4bfeb456417d27c804acbba19751995e);
#
#
#         var popup_abcd46c516da2c5e01cde19c5c75f3d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99d19c67b002bf1ea433b3c6f060f0d4 = $(`&lt;div id=&quot;html_99d19c67b002bf1ea433b3c6f060f0d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_abcd46c516da2c5e01cde19c5c75f3d4.setContent(html_99d19c67b002bf1ea433b3c6f060f0d4);
#
#
#
#         marker_2d1ec114c5cf73f041104cfb441220b0.bindPopup(popup_abcd46c516da2c5e01cde19c5c75f3d4)
#         ;
#
#
#
#
#             var marker_2561915a0767216333b8849fc35ef514 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4bfeb456417d27c804acbba19751995e);
#
#
#         var popup_4c19684d6adb55d517dcec526b668704 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea56d7756ce15a1da80410b3d3e9a423 = $(`&lt;div id=&quot;html_ea56d7756ce15a1da80410b3d3e9a423&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4c19684d6adb55d517dcec526b668704.setContent(html_ea56d7756ce15a1da80410b3d3e9a423);
#
#
#
#         marker_2561915a0767216333b8849fc35ef514.bindPopup(popup_4c19684d6adb55d517dcec526b668704)
#         ;
#
#
#
#
#             var marker_9cd3658436b5c3f4cad00ab06bf0c9aa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4bfeb456417d27c804acbba19751995e);
#
#
#         var popup_410e3177ebb9da9e531f470d560b1b6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5d14edb1e1787fda0880e0c71eda7b1 = $(`&lt;div id=&quot;html_f5d14edb1e1787fda0880e0c71eda7b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_410e3177ebb9da9e531f470d560b1b6c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_494d124981c134729b23fe3af595bbbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_494d124981c134729b23fe3af595bbbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_494d124981c134729b23fe3af595bbbb = L.map(
#                 &quot;map_494d124981c134729b23fe3af595bbbb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30a604d423865f268c0ed0a2848493b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30a604d423865f268c0ed0a2848493b5.addTo(map_494d124981c134729b23fe3af595bbbb);
#
#
#             var feature_group_11c38f1ae0bc9353c49e350473138197 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_83d5765e6d7cb58b3be6f8dd8fdb6f53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_11c38f1ae0bc9353c49e350473138197);
#
#
#         var popup_f9fa24782eb1d5bf3fc11449725e5141 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ad94ce72b8fd16dffd5d1ac930f1bd7 = $(`&lt;div id=&quot;html_3ad94ce72b8fd16dffd5d1ac930f1bd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f9fa24782eb1d5bf3fc11449725e5141.setContent(html_3ad94ce72b8fd16dffd5d1ac930f1bd7);
#
#
#
#         marker_83d5765e6d7cb58b3be6f8dd8fdb6f53.bindPopup(popup_f9fa24782eb1d5bf3fc11449725e5141)
#         ;
#
#
#
#
#             var marker_fa0110377424edf78c175470ed214505 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_11c38f1ae0bc9353c49e350473138197);
#
#
#         var popup_79f4e03b6fab0675a977cdb793c1c3cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3be43e8f08238395c8b9162bbd8e27a = $(`&lt;div id=&quot;html_e3be43e8f08238395c8b9162bbd8e27a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_79f4e03b6fab0675a977cdb793c1c3cb.setContent(html_e3be43e8f08238395c8b9162bbd8e27a);
#
#
#
#         marker_fa0110377424edf78c175470ed214505.bindPopup(popup_79f4e03b6fab0675a977cdb793c1c3cb)
#         ;
#
#
#
#
#             var marker_617b6e4b1bdc7bb6e9548d8de35ba51f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_11c38f1ae0bc9353c49e350473138197);
#
#
#         var popup_56918edc843486777156d95454d61db7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff838c7dca6718d767fcc861159976e1 = $(`&lt;div id=&quot;html_ff838c7dca6718d767fcc861159976e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_56918edc843486777156d95454d61db7.setContent(html_ff838c7dca6718d767fcc861159976e1);
#
#
#
#         marker_617b6e4b1bdc7bb6e9548d8de35ba51f.bindPopup(popup_56918edc843486777156d95454d61db7)
#         ;
#
#
#
#
#             var marker_aefc13e0f0c1faa81cbd5d75966620f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_11c38f1ae0bc9353c49e350473138197);
#
#
#         var popup_0987a2fdc901ccd91b32e4d0d9245786 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9caf3c784e39c3c94d55656c945abcbd = $(`&lt;div id=&quot;html_9caf3c784e39c3c94d55656c945abcbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0987a2fdc901ccd91b32e4d0d9245786.setContent(html_9caf3c784e39c3c94d55656c945abcbd);
#
#
#
#         marker_aefc13e0f0c1faa81cbd5d75966620f2.bindPopup(popup_0987a2fdc901ccd91b32e4d0d9245786)
#         ;
#
#
#
#
#             var marker_7aa814358699a0fd418740719f34da97 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_11c38f1ae0bc9353c49e350473138197);
#
#
#         var popup_b41982963ddb0816f660933d46dd9afd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3e83a25344bfd650fedb134c9c4872e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3e83a25344bfd650fedb134c9c4872e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3e83a25344bfd650fedb134c9c4872e = L.map(
#                 &quot;map_c3e83a25344bfd650fedb134c9c4872e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d3d53ee169dbb1d4a6091f29635d1c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d3d53ee169dbb1d4a6091f29635d1c7.addTo(map_c3e83a25344bfd650fedb134c9c4872e);
#
#
#             var feature_group_4ebb180102b66a0922189f9d310fd878 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4ebb180102b66a0922189f9d310fd878.addTo(map_c3e83a25344bfd650fedb134c9c4872e);
#
#
#             var feature_group_sub_group_9c7389fd88a65bdda4225c55acd5a748 = L.featureGroup.subGroup(
#                 feature_group_4ebb180102b66a0922189f9d310fd878
#             );
#
#
#             var marker_1f1a3b0c6934f33ca257bb7ffca5e475 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c7389fd88a65bdda4225c55acd5a748);
#
#
#         var popup_4f5c45f181e9f3fc5d2d7ddf6e079e02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a35abf5a54691423385997abe225383a = $(`&lt;div id=&quot;html_a35abf5a54691423385997abe225383a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4f5c45f181e9f3fc5d2d7ddf6e079e02.setContent(html_a35abf5a54691423385997abe225383a);
#
#
#
#         marker_1f1a3b0c6934f33ca257bb7ffca5e475.bindPopup(popup_4f5c45f181e9f3fc5d2d7ddf6e079e02)
#         ;
#
#
#
#
#             var marker_b8fd654761d0fc8924728876cb0727b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c7389fd88a65bdda4225c55acd5a748);
#
#
#         var popup_26f0ad61897ff5f182b93766300656ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f7cb2a985caea6535d53824cf82f712 = $(`&lt;div id=&quot;html_5f7cb2a985caea6535d53824cf82f712&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_26f0ad61897ff5f182b93766300656ec.setContent(html_5f7cb2a985caea6535d53824cf82f712);
#
#
#
#         marker_b8fd654761d0fc8924728876cb0727b6.bindPopup(popup_26f0ad61897ff5f182b93766300656ec)
#         ;
#
#
#
#
#             var marker_26ec62c6e9440916df5d0bf28314a996 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c7389fd88a65bdda4225c55acd5a748);
#
#
#         var popup_2200b5d9606360ab0dd95abfec395579 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c501b5a3f41d828b770d3b0ea626690 = $(`&lt;div id=&quot;html_4c501b5a3f41d828b770d3b0ea626690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2200b5d9606360ab0dd95abfec395579.setContent(html_4c501b5a3f41d828b770d3b0ea626690);
#
#
#
#         marker_26ec62c6e9440916df5d0bf28314a996.bindPopup(popup_2200b5d9606360ab0dd95abfec395579)
#         ;
#
#
#
#
#             var marker_9063203f0fce12f4a7e2f56577120a82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9c7389fd88a65bdda4225c55acd5a748);
#
#
#         var popup_a6dbd9429ca547f6cf6f5cc04f9aa67c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63134c07b832cde5258abf6dd1cfe995 = $(`&lt;div id=&quot;html_63134c07b832cde5258abf6dd1cfe995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a6dbd9429ca547f6cf6f5cc04f9aa67c.setContent(html_63134c07b832cde5258abf6dd1cfe995);
#
#
#
#         marker_
