# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e02c58c7b26754198df3eed61a0d9802 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e02c58c7b26754198df3eed61a0d9802&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e02c58c7b26754198df3eed61a0d9802 = L.map(
#                 &quot;map_e02c58c7b26754198df3eed61a0d9802&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d62eae904bc36ae6910e0e413fa63fc9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d62eae904bc36ae6910e0e413fa63fc9.addTo(map_e02c58c7b26754198df3eed61a0d9802);
#
#
#             var marker_786ff067a9126c4010c07783a07033aa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e02c58c7b26754198df3eed61a0d9802);
#
#
#         var popup_35ca208f81d0bf0168a9ce1c50e74fb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_379ee0f40f8f3a131bcc6e9c582de74f = $(`&lt;div id=&quot;html_379ee0f40f8f3a131bcc6e9c582de74f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_35ca208f81d0bf0168a9ce1c50e74fb3.setContent(html_379ee0f40f8f3a131bcc6e9c582de74f);
#
#
#
#         marker_786ff067a9126c4010c07783a07033aa.bindPopup(popup_35ca208f81d0bf0168a9ce1c50e74fb3)
#         ;
#
#
#
#
#             var marker_54adc754be933e228d8db37ece7a6db9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e02c58c7b26754198df3eed61a0d9802);
#
#
#         var popup_2f77d6b56a8738235d581ab53655c7ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fc6889bd98d02a882b2c626673227f8 = $(`&lt;div id=&quot;html_4fc6889bd98d02a882b2c626673227f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2f77d6b56a8738235d581ab53655c7ab.setContent(html_4fc6889bd98d02a882b2c626673227f8);
#
#
#
#         marker_54adc754be933e228d8db37ece7a6db9.bindPopup(popup_2f77d6b56a8738235d581ab53655c7ab)
#         ;
#
#
#
#
#             var marker_63c5657bd173f3cbca3b312077a2935e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e02c58c7b26754198df3eed61a0d9802);
#
#
#         var popup_3967f9f984ffd0cf1b0a632ba0708f3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f4ebdd795ea24030b646482aebdf895 = $(`&lt;div id=&quot;html_4f4ebdd795ea24030b646482aebdf895&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3967f9f984ffd0cf1b0a632ba0708f3c.setContent(html_4f4ebdd795ea24030b646482aebdf895);
#
#
#
#         marker_63c5657bd173f3cbca3b312077a2935e.bindPopup(popup_3967f9f984ffd0cf1b0a632ba0708f3c)
#         ;
#
#
#
#
#             var marker_f82e0a6099ca83264a8e49e63fa1c945 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e02c58c7b26754198df3eed61a0d9802);
#
#
#         var popup_62f561d4cf7e64e32a473d93581ada35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_466cc657f92878015a4811934c85e85f = $(`&lt;div id=&quot;html_466cc657f92878015a4811934c85e85f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_62f561d4cf7e64e32a473d93581ada35.setContent(html_466cc657f92878015a4811934c85e85f);
#
#
#
#         marker_f82e0a6099ca83264a8e49e63fa1c945.bindPopup(popup_62f561d4cf7e64e32a473d93581ada35)
#         ;
#
#
#
#
#             var marker_57dcbacce2c3a814ea4d372be35b112b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e02c58c7b26754198df3eed61a0d9802);
#
#
#         var popup_4bd78ce12638dc8b04f77d55fe4470ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb2b80f05f2e5dbc3f5447f36054811f = $(`&lt;div id=&quot;html_eb2b80f05f2e5dbc3f5447f36054811f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4bd78ce12638dc8b04f77d55fe4470

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4a3a3f5cde07970f95d65662aa2ba39 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4a3a3f5cde07970f95d65662aa2ba39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4a3a3f5cde07970f95d65662aa2ba39 = L.map(
#                 &quot;map_e4a3a3f5cde07970f95d65662aa2ba39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74cbc841d83d56ba97e9847d6883320a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74cbc841d83d56ba97e9847d6883320a.addTo(map_e4a3a3f5cde07970f95d65662aa2ba39);
#
#
#             var feature_group_2f5edb0a9e4c6dd400d1a7cfde386e15 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_25e2089fb156fdcbb8280d7e4dd96b1b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2f5edb0a9e4c6dd400d1a7cfde386e15);
#
#
#         var popup_b2840cf947014949027ded6e0e698d4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1813433ac98b4fd75eebbe788565be4e = $(`&lt;div id=&quot;html_1813433ac98b4fd75eebbe788565be4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b2840cf947014949027ded6e0e698d4b.setContent(html_1813433ac98b4fd75eebbe788565be4e);
#
#
#
#         marker_25e2089fb156fdcbb8280d7e4dd96b1b.bindPopup(popup_b2840cf947014949027ded6e0e698d4b)
#         ;
#
#
#
#
#             var marker_daf9dab05a4fd94e33a50539d3033553 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2f5edb0a9e4c6dd400d1a7cfde386e15);
#
#
#         var popup_3cb85da93f01fa497b6a6503556d305c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1131c09d67a4865dadd514536a970d78 = $(`&lt;div id=&quot;html_1131c09d67a4865dadd514536a970d78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3cb85da93f01fa497b6a6503556d305c.setContent(html_1131c09d67a4865dadd514536a970d78);
#
#
#
#         marker_daf9dab05a4fd94e33a50539d3033553.bindPopup(popup_3cb85da93f01fa497b6a6503556d305c)
#         ;
#
#
#
#
#             var marker_a2c5591b51e9d7911cfb0ba1014a29dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2f5edb0a9e4c6dd400d1a7cfde386e15);
#
#
#         var popup_51a6419fa19ffb7abd7f5b533c33d254 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c35c2f68f846b7c38f604426d35be996 = $(`&lt;div id=&quot;html_c35c2f68f846b7c38f604426d35be996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_51a6419fa19ffb7abd7f5b533c33d254.setContent(html_c35c2f68f846b7c38f604426d35be996);
#
#
#
#         marker_a2c5591b51e9d7911cfb0ba1014a29dc.bindPopup(popup_51a6419fa19ffb7abd7f5b533c33d254)
#         ;
#
#
#
#
#             var marker_d079a74c9809829609f0ed853d219edc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2f5edb0a9e4c6dd400d1a7cfde386e15);
#
#
#         var popup_2d420884f8ac94c76d36a73e1139881f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ef90102b85432635212de4b1e094734 = $(`&lt;div id=&quot;html_7ef90102b85432635212de4b1e094734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2d420884f8ac94c76d36a73e1139881f.setContent(html_7ef90102b85432635212de4b1e094734);
#
#
#
#         marker_d079a74c9809829609f0ed853d219edc.bindPopup(popup_2d420884f8ac94c76d36a73e1139881f)
#         ;
#
#
#
#
#             var marker_30e3165a622a7337b46872d82f988dc7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2f5edb0a9e4c6dd400d1a7cfde386e15);
#
#
#         var popup_26ad4be2029565a463565b4323eef1d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9ef88ffe057e2972f0936c961362022 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9ef88ffe057e2972f0936c961362022&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9ef88ffe057e2972f0936c961362022 = L.map(
#                 &quot;map_a9ef88ffe057e2972f0936c961362022&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5a416c2be0d2356193c706be16cfb6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5a416c2be0d2356193c706be16cfb6d.addTo(map_a9ef88ffe057e2972f0936c961362022);
#
#
#             var feature_group_fc748054d4ef3099df19f541f6edfd7c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fc748054d4ef3099df19f541f6edfd7c.addTo(map_a9ef88ffe057e2972f0936c961362022);
#
#
#             var feature_group_sub_group_cdf7d15daf0abbe779a08278e349d825 = L.featureGroup.subGroup(
#                 feature_group_fc748054d4ef3099df19f541f6edfd7c
#             );
#
#
#             var marker_d54fe07c313d8734b47aed732e1b987c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdf7d15daf0abbe779a08278e349d825);
#
#
#         var popup_a278f889e2a01024b87c50ac18579361 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_685421621d1ebd5a4b7cc07d1d43282f = $(`&lt;div id=&quot;html_685421621d1ebd5a4b7cc07d1d43282f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a278f889e2a01024b87c50ac18579361.setContent(html_685421621d1ebd5a4b7cc07d1d43282f);
#
#
#
#         marker_d54fe07c313d8734b47aed732e1b987c.bindPopup(popup_a278f889e2a01024b87c50ac18579361)
#         ;
#
#
#
#
#             var marker_5c533b9bc89610fa1c97652ea50b7ef6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdf7d15daf0abbe779a08278e349d825);
#
#
#         var popup_b4d44ed344ebfd759399a3a4b6724101 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a006308b49eb8e2affa419579b5f7b = $(`&lt;div id=&quot;html_f9a006308b49eb8e2affa419579b5f7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b4d44ed344ebfd759399a3a4b6724101.setContent(html_f9a006308b49eb8e2affa419579b5f7b);
#
#
#
#         marker_5c533b9bc89610fa1c97652ea50b7ef6.bindPopup(popup_b4d44ed344ebfd759399a3a4b6724101)
#         ;
#
#
#
#
#             var marker_210113e0c6d3a9aa004bb73e9291616d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdf7d15daf0abbe779a08278e349d825);
#
#
#         var popup_b5ee79bd553774ad0d2dec031ed5fcb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bda4786616f666049bfbdaa64179e59e = $(`&lt;div id=&quot;html_bda4786616f666049bfbdaa64179e59e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b5ee79bd553774ad0d2dec031ed5fcb6.setContent(html_bda4786616f666049bfbdaa64179e59e);
#
#
#
#         marker_210113e0c6d3a9aa004bb73e9291616d.bindPopup(popup_b5ee79bd553774ad0d2dec031ed5fcb6)
#         ;
#
#
#
#
#             var marker_9835c605c8264cc35fe354fe0d120dfb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cdf7d15daf0abbe779a08278e349d825);
#
#
#         var popup_a39846d288d4c1e71d736c8c2e9159fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e5e0d3c63649d024a467fc4b35b099e = $(`&lt;div id=&quot;html_5e5e0d3c63649d024a467fc4b35b099e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a39846d288d4c1e71d736c8c2e9159fb.setContent(html_5e5e0d3c63649d024a467fc4b35b099e);
#
#
#
#         mark
