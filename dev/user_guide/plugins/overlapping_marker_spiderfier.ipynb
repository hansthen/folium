# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d3d4733b632d5a73170c7ec69580945 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d3d4733b632d5a73170c7ec69580945&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d3d4733b632d5a73170c7ec69580945 = L.map(
#                 &quot;map_4d3d4733b632d5a73170c7ec69580945&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84604d3186939c4a24b2b1c80d9ef683 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84604d3186939c4a24b2b1c80d9ef683.addTo(map_4d3d4733b632d5a73170c7ec69580945);
#
#
#             var marker_52417597001e60d23e178bfa9edc8758 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4d3d4733b632d5a73170c7ec69580945);
#
#
#         var popup_5e18192731d5c2dd1bd1f4875c26483d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fb959fc2c7a2ecd2d7232e07f8d3d33 = $(`&lt;div id=&quot;html_8fb959fc2c7a2ecd2d7232e07f8d3d33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5e18192731d5c2dd1bd1f4875c26483d.setContent(html_8fb959fc2c7a2ecd2d7232e07f8d3d33);
#
#
#
#         marker_52417597001e60d23e178bfa9edc8758.bindPopup(popup_5e18192731d5c2dd1bd1f4875c26483d)
#         ;
#
#
#
#
#             var marker_5ab0207c7a5f348801e9f501d888c738 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4d3d4733b632d5a73170c7ec69580945);
#
#
#         var popup_ca19da9a235125133b077163e9a160a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_689d1100e6578324d2d4a9225f46e459 = $(`&lt;div id=&quot;html_689d1100e6578324d2d4a9225f46e459&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ca19da9a235125133b077163e9a160a7.setContent(html_689d1100e6578324d2d4a9225f46e459);
#
#
#
#         marker_5ab0207c7a5f348801e9f501d888c738.bindPopup(popup_ca19da9a235125133b077163e9a160a7)
#         ;
#
#
#
#
#             var marker_c6adb06482458e399786a19d9fa4335f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4d3d4733b632d5a73170c7ec69580945);
#
#
#         var popup_e3f8d038f905c51a25f1b3a5aa13f464 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_173fe774c4aff0f26c654f78471167f8 = $(`&lt;div id=&quot;html_173fe774c4aff0f26c654f78471167f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e3f8d038f905c51a25f1b3a5aa13f464.setContent(html_173fe774c4aff0f26c654f78471167f8);
#
#
#
#         marker_c6adb06482458e399786a19d9fa4335f.bindPopup(popup_e3f8d038f905c51a25f1b3a5aa13f464)
#         ;
#
#
#
#
#             var marker_95c7cbe0d9662a34022ec20bae9f92fb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4d3d4733b632d5a73170c7ec69580945);
#
#
#         var popup_8503d5da5e48ad381f22f1d8d46cd594 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dcbc2bfd78f319db5edd8cdfaae7f90 = $(`&lt;div id=&quot;html_0dcbc2bfd78f319db5edd8cdfaae7f90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8503d5da5e48ad381f22f1d8d46cd594.setContent(html_0dcbc2bfd78f319db5edd8cdfaae7f90);
#
#
#
#         marker_95c7cbe0d9662a34022ec20bae9f92fb.bindPopup(popup_8503d5da5e48ad381f22f1d8d46cd594)
#         ;
#
#
#
#
#             var marker_8f1db943c6d36e816f6553a2b295ce70 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4d3d4733b632d5a73170c7ec69580945);
#
#
#         var popup_2045b81d557838b0681b55f0168f8a0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69279f8a782cec876f61040de9886811 = $(`&lt;div id=&quot;html_69279f8a782cec876f61040de9886811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2045b81d557838b0681b55f0168f8a0b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63269e73fcb266eb080188e6de474bff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63269e73fcb266eb080188e6de474bff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63269e73fcb266eb080188e6de474bff = L.map(
#                 &quot;map_63269e73fcb266eb080188e6de474bff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9193187cab899af69b7b253e027da976 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9193187cab899af69b7b253e027da976.addTo(map_63269e73fcb266eb080188e6de474bff);
#
#
#             var feature_group_f818884c1505ffb0a1876844d64072ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ae12611dcba11a7b5ba564ed5b6a49b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f818884c1505ffb0a1876844d64072ac);
#
#
#         var popup_2baf406dcb3056de7e5baad9de668be5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b3e62745968f592ac75167af175ddcb = $(`&lt;div id=&quot;html_3b3e62745968f592ac75167af175ddcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2baf406dcb3056de7e5baad9de668be5.setContent(html_3b3e62745968f592ac75167af175ddcb);
#
#
#
#         marker_ae12611dcba11a7b5ba564ed5b6a49b4.bindPopup(popup_2baf406dcb3056de7e5baad9de668be5)
#         ;
#
#
#
#
#             var marker_0b34ceb89ed1e57ab2d46abc6b7cbcca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f818884c1505ffb0a1876844d64072ac);
#
#
#         var popup_08bf353c2794087ca657c157e645f169 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f246e5091b78b93ac55fd7d94ce7cdce = $(`&lt;div id=&quot;html_f246e5091b78b93ac55fd7d94ce7cdce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_08bf353c2794087ca657c157e645f169.setContent(html_f246e5091b78b93ac55fd7d94ce7cdce);
#
#
#
#         marker_0b34ceb89ed1e57ab2d46abc6b7cbcca.bindPopup(popup_08bf353c2794087ca657c157e645f169)
#         ;
#
#
#
#
#             var marker_13449e6f2d3f531e584204bc4b6ce0e7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f818884c1505ffb0a1876844d64072ac);
#
#
#         var popup_7c0fdbe71f12b56013b32e2962b2ff3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b0088335695373f28e375418de20d2c = $(`&lt;div id=&quot;html_4b0088335695373f28e375418de20d2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7c0fdbe71f12b56013b32e2962b2ff3b.setContent(html_4b0088335695373f28e375418de20d2c);
#
#
#
#         marker_13449e6f2d3f531e584204bc4b6ce0e7.bindPopup(popup_7c0fdbe71f12b56013b32e2962b2ff3b)
#         ;
#
#
#
#
#             var marker_b675a1c51ef90227b8ba9547cc4c3dce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f818884c1505ffb0a1876844d64072ac);
#
#
#         var popup_7cd18d088803615f6041109eb9445e4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f598849609a0dff0cbdf06946e303880 = $(`&lt;div id=&quot;html_f598849609a0dff0cbdf06946e303880&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7cd18d088803615f6041109eb9445e4a.setContent(html_f598849609a0dff0cbdf06946e303880);
#
#
#
#         marker_b675a1c51ef90227b8ba9547cc4c3dce.bindPopup(popup_7cd18d088803615f6041109eb9445e4a)
#         ;
#
#
#
#
#             var marker_634cb48c2c94dfe0541a8b73442fda30 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f818884c1505ffb0a1876844d64072ac);
#
#
#         var popup_2ecce7a35ef080defe9ec1cb0ca30a7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3395d1ace0495e3018135f52d7f0df8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3395d1ace0495e3018135f52d7f0df8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3395d1ace0495e3018135f52d7f0df8a = L.map(
#                 &quot;map_3395d1ace0495e3018135f52d7f0df8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59f63573de708e3b230a5b551221912f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59f63573de708e3b230a5b551221912f.addTo(map_3395d1ace0495e3018135f52d7f0df8a);
#
#
#             var feature_group_7c548351665d67e64452e41749816c77 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7c548351665d67e64452e41749816c77.addTo(map_3395d1ace0495e3018135f52d7f0df8a);
#
#
#             var feature_group_sub_group_c5ae3d0a3d04cbebe2c3f88944ff5b02 = L.featureGroup.subGroup(
#                 feature_group_7c548351665d67e64452e41749816c77
#             );
#
#
#             var marker_44d11b639902571067c064942697036b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5ae3d0a3d04cbebe2c3f88944ff5b02);
#
#
#         var popup_30b688dfdab73ce03fa20fd43a81584b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95ae12b2ecf043471ddd7cb6fc1f4ea0 = $(`&lt;div id=&quot;html_95ae12b2ecf043471ddd7cb6fc1f4ea0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_30b688dfdab73ce03fa20fd43a81584b.setContent(html_95ae12b2ecf043471ddd7cb6fc1f4ea0);
#
#
#
#         marker_44d11b639902571067c064942697036b.bindPopup(popup_30b688dfdab73ce03fa20fd43a81584b)
#         ;
#
#
#
#
#             var marker_850c3a9fd2f921b5e593a01763ca8f0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5ae3d0a3d04cbebe2c3f88944ff5b02);
#
#
#         var popup_0ff4d2151dc6af8675175ef130c9698e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5031aae605adafd4af6548537d386c9c = $(`&lt;div id=&quot;html_5031aae605adafd4af6548537d386c9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0ff4d2151dc6af8675175ef130c9698e.setContent(html_5031aae605adafd4af6548537d386c9c);
#
#
#
#         marker_850c3a9fd2f921b5e593a01763ca8f0e.bindPopup(popup_0ff4d2151dc6af8675175ef130c9698e)
#         ;
#
#
#
#
#             var marker_f34c80fc43c538e777196f43ef3599fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5ae3d0a3d04cbebe2c3f88944ff5b02);
#
#
#         var popup_48a2e6272ee7422daf42ef0647a51f45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ccec1c083be3934f46e5e0fe2cf2a94 = $(`&lt;div id=&quot;html_4ccec1c083be3934f46e5e0fe2cf2a94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_48a2e6272ee7422daf42ef0647a51f45.setContent(html_4ccec1c083be3934f46e5e0fe2cf2a94);
#
#
#
#         marker_f34c80fc43c538e777196f43ef3599fa.bindPopup(popup_48a2e6272ee7422daf42ef0647a51f45)
#         ;
#
#
#
#
#             var marker_d8ac649a79683b391472d7640f1fe82c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c5ae3d0a3d04cbebe2c3f88944ff5b02);
#
#
#         var popup_08fd6c2e7869730e4d5e61cffa63893f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbb966aaeba2e30a70c5c3c9e114463d = $(`&lt;div id=&quot;html_bbb966aaeba2e30a70c5c3c9e114463d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_08fd6c2e7869730e4d5e61cffa63893f.setContent(html_bbb966aaeba2e30a70c5c3c9e114463d);
#
#
#
#         marker_
