# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_072ac32f7196d8265b58b4bac664fa39 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_072ac32f7196d8265b58b4bac664fa39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_072ac32f7196d8265b58b4bac664fa39 = L.map(
#                 &quot;map_072ac32f7196d8265b58b4bac664fa39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c6f3a7b858bc68301e5f58f346f5310 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c6f3a7b858bc68301e5f58f346f5310.addTo(map_072ac32f7196d8265b58b4bac664fa39);
#
#
#             var marker_eda5232e93e5d6b46c43f185bb5f65bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_072ac32f7196d8265b58b4bac664fa39);
#
#
#         var popup_dc8e2c34a8ae814eab35967f9a576aa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd44a8f77a74e9e7b15336e5e62d5a73 = $(`&lt;div id=&quot;html_bd44a8f77a74e9e7b15336e5e62d5a73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_dc8e2c34a8ae814eab35967f9a576aa7.setContent(html_bd44a8f77a74e9e7b15336e5e62d5a73);
#
#
#
#         marker_eda5232e93e5d6b46c43f185bb5f65bf.bindPopup(popup_dc8e2c34a8ae814eab35967f9a576aa7)
#         ;
#
#
#
#
#             var marker_399383f4811a3a3e26fe826599ba4011 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_072ac32f7196d8265b58b4bac664fa39);
#
#
#         var popup_f4a1ff5c2d69e8c6ddd5f04fdd8d5dd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4aef8930a18562045e89f36590bfe59a = $(`&lt;div id=&quot;html_4aef8930a18562045e89f36590bfe59a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f4a1ff5c2d69e8c6ddd5f04fdd8d5dd9.setContent(html_4aef8930a18562045e89f36590bfe59a);
#
#
#
#         marker_399383f4811a3a3e26fe826599ba4011.bindPopup(popup_f4a1ff5c2d69e8c6ddd5f04fdd8d5dd9)
#         ;
#
#
#
#
#             var marker_42ca6763fd3720475e1d61bc1c1386a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_072ac32f7196d8265b58b4bac664fa39);
#
#
#         var popup_b24b2d38d5b4e19e56b41489e5f7c114 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ffe2822b2e4264aa3330ddefff99776 = $(`&lt;div id=&quot;html_4ffe2822b2e4264aa3330ddefff99776&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b24b2d38d5b4e19e56b41489e5f7c114.setContent(html_4ffe2822b2e4264aa3330ddefff99776);
#
#
#
#         marker_42ca6763fd3720475e1d61bc1c1386a2.bindPopup(popup_b24b2d38d5b4e19e56b41489e5f7c114)
#         ;
#
#
#
#
#             var marker_edf8c4584219f03aed7ad0ebb8d2624e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_072ac32f7196d8265b58b4bac664fa39);
#
#
#         var popup_50e909e938a32bda4d5144ecea84bce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a882f6eefa45685f2bf7fcb3449d0264 = $(`&lt;div id=&quot;html_a882f6eefa45685f2bf7fcb3449d0264&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_50e909e938a32bda4d5144ecea84bce6.setContent(html_a882f6eefa45685f2bf7fcb3449d0264);
#
#
#
#         marker_edf8c4584219f03aed7ad0ebb8d2624e.bindPopup(popup_50e909e938a32bda4d5144ecea84bce6)
#         ;
#
#
#
#
#             var marker_88538f6778b9831cef1c914116a62d72 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_072ac32f7196d8265b58b4bac664fa39);
#
#
#         var popup_f6096a85516c35f803cf4c425236af14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f67c26936bf1096e11d68102a6c84ad7 = $(`&lt;div id=&quot;html_f67c26936bf1096e11d68102a6c84ad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f6096a85516c35f803cf4c425236af

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5fa968637e9ff56c2e2b0a0c6910e19 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5fa968637e9ff56c2e2b0a0c6910e19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5fa968637e9ff56c2e2b0a0c6910e19 = L.map(
#                 &quot;map_d5fa968637e9ff56c2e2b0a0c6910e19&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2fde481f419046875878c4bb791e9277 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fde481f419046875878c4bb791e9277.addTo(map_d5fa968637e9ff56c2e2b0a0c6910e19);
#
#
#             var feature_group_4dc296a0768cf98788ca9dfc4172c5f5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_322a6c064db86766f69f0a8c420312af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4dc296a0768cf98788ca9dfc4172c5f5);
#
#
#         var popup_74927159a4fc9aebfce67baf0a09cb4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a839d5506d1fd7b10cc95853019638e = $(`&lt;div id=&quot;html_2a839d5506d1fd7b10cc95853019638e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_74927159a4fc9aebfce67baf0a09cb4d.setContent(html_2a839d5506d1fd7b10cc95853019638e);
#
#
#
#         marker_322a6c064db86766f69f0a8c420312af.bindPopup(popup_74927159a4fc9aebfce67baf0a09cb4d)
#         ;
#
#
#
#
#             var marker_7d07606038f40a4ae0dd19d8f8d84a29 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4dc296a0768cf98788ca9dfc4172c5f5);
#
#
#         var popup_85cd0beaf20ec46e01103ee9450999f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ad14c34a776751e16293c230069b12b = $(`&lt;div id=&quot;html_7ad14c34a776751e16293c230069b12b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_85cd0beaf20ec46e01103ee9450999f8.setContent(html_7ad14c34a776751e16293c230069b12b);
#
#
#
#         marker_7d07606038f40a4ae0dd19d8f8d84a29.bindPopup(popup_85cd0beaf20ec46e01103ee9450999f8)
#         ;
#
#
#
#
#             var marker_9ecfd54aa79b513a1e7266919c754ae7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4dc296a0768cf98788ca9dfc4172c5f5);
#
#
#         var popup_bb468b50f490fbd7fceb2f5e08e105bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14c8bb9dbfd948195bccc3d10f1cd22c = $(`&lt;div id=&quot;html_14c8bb9dbfd948195bccc3d10f1cd22c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bb468b50f490fbd7fceb2f5e08e105bd.setContent(html_14c8bb9dbfd948195bccc3d10f1cd22c);
#
#
#
#         marker_9ecfd54aa79b513a1e7266919c754ae7.bindPopup(popup_bb468b50f490fbd7fceb2f5e08e105bd)
#         ;
#
#
#
#
#             var marker_cf7d8bcd8b78c65005d5ed45de749558 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4dc296a0768cf98788ca9dfc4172c5f5);
#
#
#         var popup_d7212ded0e582f49455c7af5d4ef3a6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed6ae686a096c6ffaddffb1bf09338cd = $(`&lt;div id=&quot;html_ed6ae686a096c6ffaddffb1bf09338cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d7212ded0e582f49455c7af5d4ef3a6e.setContent(html_ed6ae686a096c6ffaddffb1bf09338cd);
#
#
#
#         marker_cf7d8bcd8b78c65005d5ed45de749558.bindPopup(popup_d7212ded0e582f49455c7af5d4ef3a6e)
#         ;
#
#
#
#
#             var marker_bc940f00c1b16881f4b4c3f5188fa3d5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4dc296a0768cf98788ca9dfc4172c5f5);
#
#
#         var popup_3922df6730ca1bf8730c28fcdcd9f9bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4972a1bfae89b805703b3e2ef0c77de5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4972a1bfae89b805703b3e2ef0c77de5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4972a1bfae89b805703b3e2ef0c77de5 = L.map(
#                 &quot;map_4972a1bfae89b805703b3e2ef0c77de5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6bce1372ad78ebf1a4ab7e6c1d0182f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6bce1372ad78ebf1a4ab7e6c1d0182f1.addTo(map_4972a1bfae89b805703b3e2ef0c77de5);
#
#
#             var feature_group_78fbfebd32ddf3ea72419b15ed1a8824 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_78fbfebd32ddf3ea72419b15ed1a8824.addTo(map_4972a1bfae89b805703b3e2ef0c77de5);
#
#
#             var feature_group_sub_group_6e699be8949c2c5a4272ac72163e2740 = L.featureGroup.subGroup(
#                 feature_group_78fbfebd32ddf3ea72419b15ed1a8824
#             );
#
#
#             var marker_7e063e16e7add4c655bc5a94d22bfd53 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e699be8949c2c5a4272ac72163e2740);
#
#
#         var popup_c507931180b0304fd46c70fdfdc4b7d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77581191c2474b9878261afd2d3d88a8 = $(`&lt;div id=&quot;html_77581191c2474b9878261afd2d3d88a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c507931180b0304fd46c70fdfdc4b7d0.setContent(html_77581191c2474b9878261afd2d3d88a8);
#
#
#
#         marker_7e063e16e7add4c655bc5a94d22bfd53.bindPopup(popup_c507931180b0304fd46c70fdfdc4b7d0)
#         ;
#
#
#
#
#             var marker_f62cb336baa4fb83c9199675c5a1fd90 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e699be8949c2c5a4272ac72163e2740);
#
#
#         var popup_8334f0e8ccb493ceb46441eb3d97e3f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d880879578b76c6be11aa20be94a9a6 = $(`&lt;div id=&quot;html_4d880879578b76c6be11aa20be94a9a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8334f0e8ccb493ceb46441eb3d97e3f5.setContent(html_4d880879578b76c6be11aa20be94a9a6);
#
#
#
#         marker_f62cb336baa4fb83c9199675c5a1fd90.bindPopup(popup_8334f0e8ccb493ceb46441eb3d97e3f5)
#         ;
#
#
#
#
#             var marker_41351df754a73fe3aeee7491f41314e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e699be8949c2c5a4272ac72163e2740);
#
#
#         var popup_46988c15de946d4b23d738710b851a2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd00583245b7b606677f66f6848a6b3d = $(`&lt;div id=&quot;html_fd00583245b7b606677f66f6848a6b3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_46988c15de946d4b23d738710b851a2c.setContent(html_fd00583245b7b606677f66f6848a6b3d);
#
#
#
#         marker_41351df754a73fe3aeee7491f41314e9.bindPopup(popup_46988c15de946d4b23d738710b851a2c)
#         ;
#
#
#
#
#             var marker_ecb50464c52077469ef97e8be2f68398 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6e699be8949c2c5a4272ac72163e2740);
#
#
#         var popup_0a727f172169c437d8fd7eddabb74621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b6f7252fd6cbf04fbad4294ed812ac5 = $(`&lt;div id=&quot;html_7b6f7252fd6cbf04fbad4294ed812ac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0a727f172169c437d8fd7eddabb74621.setContent(html_7b6f7252fd6cbf04fbad4294ed812ac5);
#
#
#
#         mark
