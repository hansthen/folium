# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6b123e50ae436497e133d0952397061 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6b123e50ae436497e133d0952397061&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6b123e50ae436497e133d0952397061 = L.map(
#                 &quot;map_a6b123e50ae436497e133d0952397061&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_910ac9ed1de39e30e5e365d97be0d72f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_910ac9ed1de39e30e5e365d97be0d72f.addTo(map_a6b123e50ae436497e133d0952397061);
#
#
#             var marker_49af34a8805fb9538d1dc5e7bd2bf851 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a6b123e50ae436497e133d0952397061);
#
#
#         var popup_028b75ca47efe039b1a8aed4447af3c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a84ca618839efe0c291522ed44bed6b3 = $(`&lt;div id=&quot;html_a84ca618839efe0c291522ed44bed6b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_028b75ca47efe039b1a8aed4447af3c6.setContent(html_a84ca618839efe0c291522ed44bed6b3);
#
#
#
#         marker_49af34a8805fb9538d1dc5e7bd2bf851.bindPopup(popup_028b75ca47efe039b1a8aed4447af3c6)
#         ;
#
#
#
#
#             var marker_3451d0bb178a120abdc5644905fd80ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a6b123e50ae436497e133d0952397061);
#
#
#         var popup_94c64e35a96c901f4e66ffdf124bbd97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa45249385e46c33b92f4f571798bfe4 = $(`&lt;div id=&quot;html_aa45249385e46c33b92f4f571798bfe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_94c64e35a96c901f4e66ffdf124bbd97.setContent(html_aa45249385e46c33b92f4f571798bfe4);
#
#
#
#         marker_3451d0bb178a120abdc5644905fd80ac.bindPopup(popup_94c64e35a96c901f4e66ffdf124bbd97)
#         ;
#
#
#
#
#             var marker_fe4a8834782b8b1caad7c8d0eebaeea0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a6b123e50ae436497e133d0952397061);
#
#
#         var popup_0a41eeeddc34c8be2d1a6cc3190a0238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f9454bf8b510bd4bfda72e7c5b9f450 = $(`&lt;div id=&quot;html_5f9454bf8b510bd4bfda72e7c5b9f450&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0a41eeeddc34c8be2d1a6cc3190a0238.setContent(html_5f9454bf8b510bd4bfda72e7c5b9f450);
#
#
#
#         marker_fe4a8834782b8b1caad7c8d0eebaeea0.bindPopup(popup_0a41eeeddc34c8be2d1a6cc3190a0238)
#         ;
#
#
#
#
#             var marker_a8213b9e58e8d0eaf2a65423a56b8f80 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a6b123e50ae436497e133d0952397061);
#
#
#         var popup_1c6599c7010be97d52a7b70222f4a80c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1b9522ae9f5bc9bc81617dc4e504a28 = $(`&lt;div id=&quot;html_f1b9522ae9f5bc9bc81617dc4e504a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1c6599c7010be97d52a7b70222f4a80c.setContent(html_f1b9522ae9f5bc9bc81617dc4e504a28);
#
#
#
#         marker_a8213b9e58e8d0eaf2a65423a56b8f80.bindPopup(popup_1c6599c7010be97d52a7b70222f4a80c)
#         ;
#
#
#
#
#             var marker_c1b7423b5be423bba888783cc16d697c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a6b123e50ae436497e133d0952397061);
#
#
#         var popup_122992d833b6ccd5fb900aa7e950fc0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa7d5d38946012c84654e18c90f4d55e = $(`&lt;div id=&quot;html_aa7d5d38946012c84654e18c90f4d55e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_122992d833b6ccd5fb900aa7e950fc0a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ed60209c3d1d877660b7908bc8c5fab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ed60209c3d1d877660b7908bc8c5fab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ed60209c3d1d877660b7908bc8c5fab = L.map(
#                 &quot;map_7ed60209c3d1d877660b7908bc8c5fab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a10185bacf1ef9bf121a543f1b03c4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a10185bacf1ef9bf121a543f1b03c4a.addTo(map_7ed60209c3d1d877660b7908bc8c5fab);
#
#
#             var feature_group_cca20a0b7487d1e0ed2064dfef832e03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_30866d4cfd56d6181b3d95c91583931b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cca20a0b7487d1e0ed2064dfef832e03);
#
#
#         var popup_ef462baf2bfc3cc720648040e64ac78a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9641f2437a3ea33f2d1c3568279de4df = $(`&lt;div id=&quot;html_9641f2437a3ea33f2d1c3568279de4df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ef462baf2bfc3cc720648040e64ac78a.setContent(html_9641f2437a3ea33f2d1c3568279de4df);
#
#
#
#         marker_30866d4cfd56d6181b3d95c91583931b.bindPopup(popup_ef462baf2bfc3cc720648040e64ac78a)
#         ;
#
#
#
#
#             var marker_2a12211cb5088b3776f98d9b847f076b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cca20a0b7487d1e0ed2064dfef832e03);
#
#
#         var popup_fe1ed4097500ebbe2ed49c85098b628c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53257db4a4a4bee5c89d19635b44748b = $(`&lt;div id=&quot;html_53257db4a4a4bee5c89d19635b44748b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fe1ed4097500ebbe2ed49c85098b628c.setContent(html_53257db4a4a4bee5c89d19635b44748b);
#
#
#
#         marker_2a12211cb5088b3776f98d9b847f076b.bindPopup(popup_fe1ed4097500ebbe2ed49c85098b628c)
#         ;
#
#
#
#
#             var marker_7f7aa09d15084d203a8e70a1d6dce902 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cca20a0b7487d1e0ed2064dfef832e03);
#
#
#         var popup_d081986e9d44b43b2da6427039246e1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68f46fd8d4a2de8e5e31cc7e84aaaf63 = $(`&lt;div id=&quot;html_68f46fd8d4a2de8e5e31cc7e84aaaf63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d081986e9d44b43b2da6427039246e1b.setContent(html_68f46fd8d4a2de8e5e31cc7e84aaaf63);
#
#
#
#         marker_7f7aa09d15084d203a8e70a1d6dce902.bindPopup(popup_d081986e9d44b43b2da6427039246e1b)
#         ;
#
#
#
#
#             var marker_06fbef35630190ae41b67dadd8a0e81e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cca20a0b7487d1e0ed2064dfef832e03);
#
#
#         var popup_6db801c361c735b2ceff9dc329c8ec97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_474713284870fc5c6887798936176308 = $(`&lt;div id=&quot;html_474713284870fc5c6887798936176308&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6db801c361c735b2ceff9dc329c8ec97.setContent(html_474713284870fc5c6887798936176308);
#
#
#
#         marker_06fbef35630190ae41b67dadd8a0e81e.bindPopup(popup_6db801c361c735b2ceff9dc329c8ec97)
#         ;
#
#
#
#
#             var marker_1bbcdbbe4fef03fdce06512acd8b0278 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cca20a0b7487d1e0ed2064dfef832e03);
#
#
#         var popup_c32e95244761b1ae2ce004731f708e1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1e35e20483cf3f15381a90acec3885e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1e35e20483cf3f15381a90acec3885e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1e35e20483cf3f15381a90acec3885e = L.map(
#                 &quot;map_f1e35e20483cf3f15381a90acec3885e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_281b020cc7a082726abd7fd2a34084ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_281b020cc7a082726abd7fd2a34084ec.addTo(map_f1e35e20483cf3f15381a90acec3885e);
#
#
#             var feature_group_a5de88d01cdea5d1a951f5c78045744d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a5de88d01cdea5d1a951f5c78045744d.addTo(map_f1e35e20483cf3f15381a90acec3885e);
#
#
#             var feature_group_sub_group_f6e8ef8f6aecc34fac357bbb4a0698c4 = L.featureGroup.subGroup(
#                 feature_group_a5de88d01cdea5d1a951f5c78045744d
#             );
#
#
#             var marker_b30af332ea747de7bb4633731186d296 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6e8ef8f6aecc34fac357bbb4a0698c4);
#
#
#         var popup_6fcdb86671e2a1f86c412d3610eda5be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12b5d3973be4b705106671391c7dfb20 = $(`&lt;div id=&quot;html_12b5d3973be4b705106671391c7dfb20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6fcdb86671e2a1f86c412d3610eda5be.setContent(html_12b5d3973be4b705106671391c7dfb20);
#
#
#
#         marker_b30af332ea747de7bb4633731186d296.bindPopup(popup_6fcdb86671e2a1f86c412d3610eda5be)
#         ;
#
#
#
#
#             var marker_f8b1ec7f1950186e3d62a488437b96fe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6e8ef8f6aecc34fac357bbb4a0698c4);
#
#
#         var popup_f9bd35da8ed15b604ce56bc797cad22e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5569c9e0c02432b3c9ce134e67e8ad78 = $(`&lt;div id=&quot;html_5569c9e0c02432b3c9ce134e67e8ad78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f9bd35da8ed15b604ce56bc797cad22e.setContent(html_5569c9e0c02432b3c9ce134e67e8ad78);
#
#
#
#         marker_f8b1ec7f1950186e3d62a488437b96fe.bindPopup(popup_f9bd35da8ed15b604ce56bc797cad22e)
#         ;
#
#
#
#
#             var marker_a7069e91eecf436e2d5f6d4f6f8b7a55 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6e8ef8f6aecc34fac357bbb4a0698c4);
#
#
#         var popup_880cdc7e95023f665e350448f94658ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04557dc3fa2cf742c61ca0c96f8de2e5 = $(`&lt;div id=&quot;html_04557dc3fa2cf742c61ca0c96f8de2e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_880cdc7e95023f665e350448f94658ac.setContent(html_04557dc3fa2cf742c61ca0c96f8de2e5);
#
#
#
#         marker_a7069e91eecf436e2d5f6d4f6f8b7a55.bindPopup(popup_880cdc7e95023f665e350448f94658ac)
#         ;
#
#
#
#
#             var marker_46d7515aa7365674c51408188f5089dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6e8ef8f6aecc34fac357bbb4a0698c4);
#
#
#         var popup_4546522d3c849ae817790cfcf33c1aab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23a4934eba8c31b5d9e068ef99272679 = $(`&lt;div id=&quot;html_23a4934eba8c31b5d9e068ef99272679&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4546522d3c849ae817790cfcf33c1aab.setContent(html_23a4934eba8c31b5d9e068ef99272679);
#
#
#
#         marker_
