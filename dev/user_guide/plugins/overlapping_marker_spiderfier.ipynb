# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e753f5198de580cf3e9bd1bb1bd727d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e753f5198de580cf3e9bd1bb1bd727d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e753f5198de580cf3e9bd1bb1bd727d0 = L.map(
#                 &quot;map_e753f5198de580cf3e9bd1bb1bd727d0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a6852380073a3864f166800291b5f4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a6852380073a3864f166800291b5f4c.addTo(map_e753f5198de580cf3e9bd1bb1bd727d0);
#
#
#             var marker_ba651eb44607f5888643f8ed8f1d9e88 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e753f5198de580cf3e9bd1bb1bd727d0);
#
#
#         var popup_8ec5bf5336c8e05596e3d534fefd63b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1ae51a37fc018931628be5213a514b9 = $(`&lt;div id=&quot;html_d1ae51a37fc018931628be5213a514b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8ec5bf5336c8e05596e3d534fefd63b6.setContent(html_d1ae51a37fc018931628be5213a514b9);
#
#
#
#         marker_ba651eb44607f5888643f8ed8f1d9e88.bindPopup(popup_8ec5bf5336c8e05596e3d534fefd63b6)
#         ;
#
#
#
#
#             var marker_ea25d4e02c52f865d83de5027051fc51 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e753f5198de580cf3e9bd1bb1bd727d0);
#
#
#         var popup_55e4b3d882d0893b6d93802163273d56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89a306e627876f736d6c28039c978f98 = $(`&lt;div id=&quot;html_89a306e627876f736d6c28039c978f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_55e4b3d882d0893b6d93802163273d56.setContent(html_89a306e627876f736d6c28039c978f98);
#
#
#
#         marker_ea25d4e02c52f865d83de5027051fc51.bindPopup(popup_55e4b3d882d0893b6d93802163273d56)
#         ;
#
#
#
#
#             var marker_c06bdec1eb7824c9c21e4b22a8e0971e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e753f5198de580cf3e9bd1bb1bd727d0);
#
#
#         var popup_f260abeeae7ddc45b59e886d7c413939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5320fb5429abc3c37144a2fa9272bbb0 = $(`&lt;div id=&quot;html_5320fb5429abc3c37144a2fa9272bbb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f260abeeae7ddc45b59e886d7c413939.setContent(html_5320fb5429abc3c37144a2fa9272bbb0);
#
#
#
#         marker_c06bdec1eb7824c9c21e4b22a8e0971e.bindPopup(popup_f260abeeae7ddc45b59e886d7c413939)
#         ;
#
#
#
#
#             var marker_4af2339d92de55d037b3239d666d7588 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e753f5198de580cf3e9bd1bb1bd727d0);
#
#
#         var popup_0b6b824a5e5c36f4d607eb9a43064a05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3f1858cfe5e365b26e80133f1da9176 = $(`&lt;div id=&quot;html_d3f1858cfe5e365b26e80133f1da9176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0b6b824a5e5c36f4d607eb9a43064a05.setContent(html_d3f1858cfe5e365b26e80133f1da9176);
#
#
#
#         marker_4af2339d92de55d037b3239d666d7588.bindPopup(popup_0b6b824a5e5c36f4d607eb9a43064a05)
#         ;
#
#
#
#
#             var marker_d52a9677a29129c88b4f99920763a98b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e753f5198de580cf3e9bd1bb1bd727d0);
#
#
#         var popup_b4aed72751a3e5173228801b147ef9ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_396b4b3efd64ad623f80765148b64fc6 = $(`&lt;div id=&quot;html_396b4b3efd64ad623f80765148b64fc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b4aed72751a3e5173228801b147ef9ee.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e998a915f796febfb482babdf56a547c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e998a915f796febfb482babdf56a547c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e998a915f796febfb482babdf56a547c = L.map(
#                 &quot;map_e998a915f796febfb482babdf56a547c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_042317bb49c85bdd65c07c7aaca73bb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_042317bb49c85bdd65c07c7aaca73bb7.addTo(map_e998a915f796febfb482babdf56a547c);
#
#
#             var feature_group_ca3fefbb2ea46dfa34cefe108a83d555 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4a62be334b8345480d4df32ce2c335ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ca3fefbb2ea46dfa34cefe108a83d555);
#
#
#         var popup_d3ecdf046857e025d708b59e54025217 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8964cc77c39fd1e6c64c278234b027d6 = $(`&lt;div id=&quot;html_8964cc77c39fd1e6c64c278234b027d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d3ecdf046857e025d708b59e54025217.setContent(html_8964cc77c39fd1e6c64c278234b027d6);
#
#
#
#         marker_4a62be334b8345480d4df32ce2c335ef.bindPopup(popup_d3ecdf046857e025d708b59e54025217)
#         ;
#
#
#
#
#             var marker_1abc2988c01b939b1aca1bc8dfb2735a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ca3fefbb2ea46dfa34cefe108a83d555);
#
#
#         var popup_1ffc6f139f32039f22c3c371a9797a1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_251fd539344e0b908f7cd3f95e5bc5b4 = $(`&lt;div id=&quot;html_251fd539344e0b908f7cd3f95e5bc5b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1ffc6f139f32039f22c3c371a9797a1a.setContent(html_251fd539344e0b908f7cd3f95e5bc5b4);
#
#
#
#         marker_1abc2988c01b939b1aca1bc8dfb2735a.bindPopup(popup_1ffc6f139f32039f22c3c371a9797a1a)
#         ;
#
#
#
#
#             var marker_88ca173c3f4259e92e1a92b9910b821f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ca3fefbb2ea46dfa34cefe108a83d555);
#
#
#         var popup_1b8c8ca8689c57e4413c7081a723e9bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_832280ad93a9db1b16babecd88161132 = $(`&lt;div id=&quot;html_832280ad93a9db1b16babecd88161132&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1b8c8ca8689c57e4413c7081a723e9bd.setContent(html_832280ad93a9db1b16babecd88161132);
#
#
#
#         marker_88ca173c3f4259e92e1a92b9910b821f.bindPopup(popup_1b8c8ca8689c57e4413c7081a723e9bd)
#         ;
#
#
#
#
#             var marker_fedd19235b96b206b65c01814fcdb19f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ca3fefbb2ea46dfa34cefe108a83d555);
#
#
#         var popup_5483ea0d1d9ec70f572c0479e46b453a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ded83419d630e00549c61bd92a80ab0 = $(`&lt;div id=&quot;html_1ded83419d630e00549c61bd92a80ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5483ea0d1d9ec70f572c0479e46b453a.setContent(html_1ded83419d630e00549c61bd92a80ab0);
#
#
#
#         marker_fedd19235b96b206b65c01814fcdb19f.bindPopup(popup_5483ea0d1d9ec70f572c0479e46b453a)
#         ;
#
#
#
#
#             var marker_d41bd7e1a83109491f2d8067efb037b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ca3fefbb2ea46dfa34cefe108a83d555);
#
#
#         var popup_04fb6d8872893a3c070500fb9f20f5e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e142f843c124f024968694f307803d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e142f843c124f024968694f307803d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e142f843c124f024968694f307803d2 = L.map(
#                 &quot;map_0e142f843c124f024968694f307803d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82eb659ebe13cf85df435b6a9c785637 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82eb659ebe13cf85df435b6a9c785637.addTo(map_0e142f843c124f024968694f307803d2);
#
#
#             var feature_group_32768a278daff23a341cdf83a5df4916 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_32768a278daff23a341cdf83a5df4916.addTo(map_0e142f843c124f024968694f307803d2);
#
#
#             var feature_group_sub_group_59054a72bbd7e2330a54c28889357b75 = L.featureGroup.subGroup(
#                 feature_group_32768a278daff23a341cdf83a5df4916
#             );
#
#
#             var marker_fc14a39aa699b996b786ddd3de120aa5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_59054a72bbd7e2330a54c28889357b75);
#
#
#         var popup_22bd769820e0009a52b158a8a659a915 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f8040832906dbbcc96b6a12bc8ce6c1 = $(`&lt;div id=&quot;html_8f8040832906dbbcc96b6a12bc8ce6c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_22bd769820e0009a52b158a8a659a915.setContent(html_8f8040832906dbbcc96b6a12bc8ce6c1);
#
#
#
#         marker_fc14a39aa699b996b786ddd3de120aa5.bindPopup(popup_22bd769820e0009a52b158a8a659a915)
#         ;
#
#
#
#
#             var marker_f8b33ca99f529d91a4ffdf5a7046f547 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_59054a72bbd7e2330a54c28889357b75);
#
#
#         var popup_ea1fb056b8bfdd6cce40a78ee200f2a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fb9263877417ea1b6c96063e0c5163b = $(`&lt;div id=&quot;html_8fb9263877417ea1b6c96063e0c5163b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ea1fb056b8bfdd6cce40a78ee200f2a0.setContent(html_8fb9263877417ea1b6c96063e0c5163b);
#
#
#
#         marker_f8b33ca99f529d91a4ffdf5a7046f547.bindPopup(popup_ea1fb056b8bfdd6cce40a78ee200f2a0)
#         ;
#
#
#
#
#             var marker_02712d22299b810ef7225c09fddc3600 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_59054a72bbd7e2330a54c28889357b75);
#
#
#         var popup_186738bf840e6604fe8f283b43d9c66a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c43541b9e576265367b9778469dda494 = $(`&lt;div id=&quot;html_c43541b9e576265367b9778469dda494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_186738bf840e6604fe8f283b43d9c66a.setContent(html_c43541b9e576265367b9778469dda494);
#
#
#
#         marker_02712d22299b810ef7225c09fddc3600.bindPopup(popup_186738bf840e6604fe8f283b43d9c66a)
#         ;
#
#
#
#
#             var marker_ba32acd2fb12740bd6093c733cce3b03 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_59054a72bbd7e2330a54c28889357b75);
#
#
#         var popup_3b1f36455391b40d74e43fc77c3e94e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_246cee123777be0771350748892e0b1b = $(`&lt;div id=&quot;html_246cee123777be0771350748892e0b1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3b1f36455391b40d74e43fc77c3e94e3.setContent(html_246cee123777be0771350748892e0b1b);
#
#
#
#         marker_
