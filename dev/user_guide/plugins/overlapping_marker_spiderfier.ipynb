# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1ec4788917fb05c2c8e964a12c4f9ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1ec4788917fb05c2c8e964a12c4f9ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1ec4788917fb05c2c8e964a12c4f9ed = L.map(
#                 &quot;map_a1ec4788917fb05c2c8e964a12c4f9ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10be354954e4d576db3e94add61ccba6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10be354954e4d576db3e94add61ccba6.addTo(map_a1ec4788917fb05c2c8e964a12c4f9ed);
#
#
#             var marker_3341f4952ea95a4d5c871bf81abf2a33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a1ec4788917fb05c2c8e964a12c4f9ed);
#
#
#         var popup_18b40922640555c9bac5c9be8e52aecf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11a3863e161edd80d8d3f543b52d3dee = $(`&lt;div id=&quot;html_11a3863e161edd80d8d3f543b52d3dee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_18b40922640555c9bac5c9be8e52aecf.setContent(html_11a3863e161edd80d8d3f543b52d3dee);
#
#
#
#         marker_3341f4952ea95a4d5c871bf81abf2a33.bindPopup(popup_18b40922640555c9bac5c9be8e52aecf)
#         ;
#
#
#
#
#             var marker_c12c3805f4b8aab891a31cf1badabd27 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a1ec4788917fb05c2c8e964a12c4f9ed);
#
#
#         var popup_6dcbb184d9bbb7b70316f225a022d459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acde72431939795125c0cab18f57504d = $(`&lt;div id=&quot;html_acde72431939795125c0cab18f57504d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6dcbb184d9bbb7b70316f225a022d459.setContent(html_acde72431939795125c0cab18f57504d);
#
#
#
#         marker_c12c3805f4b8aab891a31cf1badabd27.bindPopup(popup_6dcbb184d9bbb7b70316f225a022d459)
#         ;
#
#
#
#
#             var marker_821458d6b4a0b52a5ddb3666c8784643 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a1ec4788917fb05c2c8e964a12c4f9ed);
#
#
#         var popup_ad64f611863851b480a6808ce6f0c7f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd4672a504bfdd36f2749199cab7f58d = $(`&lt;div id=&quot;html_bd4672a504bfdd36f2749199cab7f58d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ad64f611863851b480a6808ce6f0c7f8.setContent(html_bd4672a504bfdd36f2749199cab7f58d);
#
#
#
#         marker_821458d6b4a0b52a5ddb3666c8784643.bindPopup(popup_ad64f611863851b480a6808ce6f0c7f8)
#         ;
#
#
#
#
#             var marker_a8f9e50150fc78ee7bada408c1bcc431 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a1ec4788917fb05c2c8e964a12c4f9ed);
#
#
#         var popup_bbb941c02752f3cc4d894f5db6e9cb4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95f35c469c3f5b2949a718391a167fa9 = $(`&lt;div id=&quot;html_95f35c469c3f5b2949a718391a167fa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bbb941c02752f3cc4d894f5db6e9cb4e.setContent(html_95f35c469c3f5b2949a718391a167fa9);
#
#
#
#         marker_a8f9e50150fc78ee7bada408c1bcc431.bindPopup(popup_bbb941c02752f3cc4d894f5db6e9cb4e)
#         ;
#
#
#
#
#             var marker_c2e4b0d43da4ac03ee6268fe47ebce96 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a1ec4788917fb05c2c8e964a12c4f9ed);
#
#
#         var popup_7285a57074175a3177dbe6a484f88c8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d726a7767546668d3e7ee2ba36c56fb = $(`&lt;div id=&quot;html_2d726a7767546668d3e7ee2ba36c56fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7285a57074175a3177dbe6a484f88c8f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea2c6eb9e36d747f80653fef99dec5dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea2c6eb9e36d747f80653fef99dec5dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea2c6eb9e36d747f80653fef99dec5dd = L.map(
#                 &quot;map_ea2c6eb9e36d747f80653fef99dec5dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4032af80146f6f228a6bd2dd024117eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4032af80146f6f228a6bd2dd024117eb.addTo(map_ea2c6eb9e36d747f80653fef99dec5dd);
#
#
#             var feature_group_3b2749dc5e43397933b93b8ae27d88a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_259d9194590dcb4f3ef5b746d8b08a18 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3b2749dc5e43397933b93b8ae27d88a8);
#
#
#         var popup_feedc47937fb8ba2b60635b2c11550f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bad2e2025a5cb763c9ee971c85d7320 = $(`&lt;div id=&quot;html_0bad2e2025a5cb763c9ee971c85d7320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_feedc47937fb8ba2b60635b2c11550f3.setContent(html_0bad2e2025a5cb763c9ee971c85d7320);
#
#
#
#         marker_259d9194590dcb4f3ef5b746d8b08a18.bindPopup(popup_feedc47937fb8ba2b60635b2c11550f3)
#         ;
#
#
#
#
#             var marker_8f25e3f65db1865ff49ccc19038eea96 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3b2749dc5e43397933b93b8ae27d88a8);
#
#
#         var popup_e32ecebd568eb43d5035c76e98444604 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fc76746d63ce156e33e6b94b2a5dcde = $(`&lt;div id=&quot;html_6fc76746d63ce156e33e6b94b2a5dcde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e32ecebd568eb43d5035c76e98444604.setContent(html_6fc76746d63ce156e33e6b94b2a5dcde);
#
#
#
#         marker_8f25e3f65db1865ff49ccc19038eea96.bindPopup(popup_e32ecebd568eb43d5035c76e98444604)
#         ;
#
#
#
#
#             var marker_5d72c89242acef4b82dbe6a1d0e97a9a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3b2749dc5e43397933b93b8ae27d88a8);
#
#
#         var popup_5b8bad9215847e2a54382362f91225f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecb579fd63901558a297db54581a9694 = $(`&lt;div id=&quot;html_ecb579fd63901558a297db54581a9694&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5b8bad9215847e2a54382362f91225f4.setContent(html_ecb579fd63901558a297db54581a9694);
#
#
#
#         marker_5d72c89242acef4b82dbe6a1d0e97a9a.bindPopup(popup_5b8bad9215847e2a54382362f91225f4)
#         ;
#
#
#
#
#             var marker_e55824698bb795fb01fab6275427b00b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3b2749dc5e43397933b93b8ae27d88a8);
#
#
#         var popup_f5dc2b3c11ddf4a755a502cd8db6709f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9570cde49af5f3c2b69c19fcc81ceb5b = $(`&lt;div id=&quot;html_9570cde49af5f3c2b69c19fcc81ceb5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f5dc2b3c11ddf4a755a502cd8db6709f.setContent(html_9570cde49af5f3c2b69c19fcc81ceb5b);
#
#
#
#         marker_e55824698bb795fb01fab6275427b00b.bindPopup(popup_f5dc2b3c11ddf4a755a502cd8db6709f)
#         ;
#
#
#
#
#             var marker_9aa324fdd961338a433d79d5c36766d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3b2749dc5e43397933b93b8ae27d88a8);
#
#
#         var popup_4f0cbb77ca785202fc64a358f8692f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00929efdd60bc4dab1c2e3587e124eb6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00929efdd60bc4dab1c2e3587e124eb6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00929efdd60bc4dab1c2e3587e124eb6 = L.map(
#                 &quot;map_00929efdd60bc4dab1c2e3587e124eb6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cee5284bfc0c237e7d7ddde67a515d33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cee5284bfc0c237e7d7ddde67a515d33.addTo(map_00929efdd60bc4dab1c2e3587e124eb6);
#
#
#             var feature_group_786e605506157f5772a29f570e5bdaec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_786e605506157f5772a29f570e5bdaec.addTo(map_00929efdd60bc4dab1c2e3587e124eb6);
#
#
#             var feature_group_sub_group_fb93438193121ad466300bf06c3323ed = L.featureGroup.subGroup(
#                 feature_group_786e605506157f5772a29f570e5bdaec
#             );
#
#
#             var marker_63ae0ee56e98c949e249e1936f16d368 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb93438193121ad466300bf06c3323ed);
#
#
#         var popup_6f2798093f83ed77f3f8865faa926244 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc91db8fe450a2417039226307cb986e = $(`&lt;div id=&quot;html_dc91db8fe450a2417039226307cb986e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6f2798093f83ed77f3f8865faa926244.setContent(html_dc91db8fe450a2417039226307cb986e);
#
#
#
#         marker_63ae0ee56e98c949e249e1936f16d368.bindPopup(popup_6f2798093f83ed77f3f8865faa926244)
#         ;
#
#
#
#
#             var marker_c40cebfc63aa9f0cb6f1151828ab99d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb93438193121ad466300bf06c3323ed);
#
#
#         var popup_41dded33fdd5481869f8097d5cb50572 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdf71b6fbf6e84e38a5bbe15b8a1696a = $(`&lt;div id=&quot;html_cdf71b6fbf6e84e38a5bbe15b8a1696a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_41dded33fdd5481869f8097d5cb50572.setContent(html_cdf71b6fbf6e84e38a5bbe15b8a1696a);
#
#
#
#         marker_c40cebfc63aa9f0cb6f1151828ab99d2.bindPopup(popup_41dded33fdd5481869f8097d5cb50572)
#         ;
#
#
#
#
#             var marker_55acdd2ac6f9a8ee92657a2bf2588df3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb93438193121ad466300bf06c3323ed);
#
#
#         var popup_6c9721cc8596b6ffa993e33abadecf48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e375492d710f4df8e29ffaae1254f629 = $(`&lt;div id=&quot;html_e375492d710f4df8e29ffaae1254f629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6c9721cc8596b6ffa993e33abadecf48.setContent(html_e375492d710f4df8e29ffaae1254f629);
#
#
#
#         marker_55acdd2ac6f9a8ee92657a2bf2588df3.bindPopup(popup_6c9721cc8596b6ffa993e33abadecf48)
#         ;
#
#
#
#
#             var marker_cbf151c6359c3823cba573a7602453b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fb93438193121ad466300bf06c3323ed);
#
#
#         var popup_83e13df950c9c8640829fd62051f652b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b8b52e7df19e639b82188b1eefc4185 = $(`&lt;div id=&quot;html_6b8b52e7df19e639b82188b1eefc4185&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_83e13df950c9c8640829fd62051f652b.setContent(html_6b8b52e7df19e639b82188b1eefc4185);
#
#
#
#         marker_
