# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69dd9a6624d8c9a4f3a53ee5866991b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69dd9a6624d8c9a4f3a53ee5866991b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69dd9a6624d8c9a4f3a53ee5866991b2 = L.map(
#                 &quot;map_69dd9a6624d8c9a4f3a53ee5866991b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_992d5904c78d99b9d848535812e4cce2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_992d5904c78d99b9d848535812e4cce2.addTo(map_69dd9a6624d8c9a4f3a53ee5866991b2);
#
#
#             var marker_749daad1073de4d51b2f1360ee61d6cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_69dd9a6624d8c9a4f3a53ee5866991b2);
#
#
#         var popup_533c914d51ae686e3611ff10278dc3b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6f7e954f8fcd09f7a523ff5c6d90f7f = $(`&lt;div id=&quot;html_d6f7e954f8fcd09f7a523ff5c6d90f7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_533c914d51ae686e3611ff10278dc3b4.setContent(html_d6f7e954f8fcd09f7a523ff5c6d90f7f);
#
#
#
#         marker_749daad1073de4d51b2f1360ee61d6cf.bindPopup(popup_533c914d51ae686e3611ff10278dc3b4)
#         ;
#
#
#
#
#             var marker_a67a2e3648ed43ad21d899d992e7e607 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_69dd9a6624d8c9a4f3a53ee5866991b2);
#
#
#         var popup_f214f73750e473f23dde652913f4a630 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93bcd141dff3706323dd466bad896691 = $(`&lt;div id=&quot;html_93bcd141dff3706323dd466bad896691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f214f73750e473f23dde652913f4a630.setContent(html_93bcd141dff3706323dd466bad896691);
#
#
#
#         marker_a67a2e3648ed43ad21d899d992e7e607.bindPopup(popup_f214f73750e473f23dde652913f4a630)
#         ;
#
#
#
#
#             var marker_0b6006777d86638af8173bdb1442efda = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_69dd9a6624d8c9a4f3a53ee5866991b2);
#
#
#         var popup_8cdf9c20036d367f5be8282059d6055d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd146906ab0e5c5f957456ad764a99be = $(`&lt;div id=&quot;html_dd146906ab0e5c5f957456ad764a99be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8cdf9c20036d367f5be8282059d6055d.setContent(html_dd146906ab0e5c5f957456ad764a99be);
#
#
#
#         marker_0b6006777d86638af8173bdb1442efda.bindPopup(popup_8cdf9c20036d367f5be8282059d6055d)
#         ;
#
#
#
#
#             var marker_1967c0abf95cbb0ec4acf065ee6c165c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_69dd9a6624d8c9a4f3a53ee5866991b2);
#
#
#         var popup_1a37c299d5b269f20de99a1366584e55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8322bda3e37a3ab554a381a37edf71ee = $(`&lt;div id=&quot;html_8322bda3e37a3ab554a381a37edf71ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1a37c299d5b269f20de99a1366584e55.setContent(html_8322bda3e37a3ab554a381a37edf71ee);
#
#
#
#         marker_1967c0abf95cbb0ec4acf065ee6c165c.bindPopup(popup_1a37c299d5b269f20de99a1366584e55)
#         ;
#
#
#
#
#             var marker_d3450f2a3faf1cb7e30624d9b1a4d3bb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_69dd9a6624d8c9a4f3a53ee5866991b2);
#
#
#         var popup_c2d25b803971c1bccb883e0488b04e0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90c05ea354504085a311cc03d1204851 = $(`&lt;div id=&quot;html_90c05ea354504085a311cc03d1204851&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c2d25b803971c1bccb883e0488b04e0d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af2b09bb55d6c51f201a141ec3e477d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af2b09bb55d6c51f201a141ec3e477d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af2b09bb55d6c51f201a141ec3e477d9 = L.map(
#                 &quot;map_af2b09bb55d6c51f201a141ec3e477d9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4874fb9abdb2b11900c03bbfbc54a729 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4874fb9abdb2b11900c03bbfbc54a729.addTo(map_af2b09bb55d6c51f201a141ec3e477d9);
#
#
#             var feature_group_57701224aa683678f4a4d46a3d3f64d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6851667f07fee0f241d8a47c92d1f1ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_57701224aa683678f4a4d46a3d3f64d6);
#
#
#         var popup_8d7d4204b76e59be05315245c61ae2d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79582637542e2a560c1ff9056be4309a = $(`&lt;div id=&quot;html_79582637542e2a560c1ff9056be4309a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8d7d4204b76e59be05315245c61ae2d7.setContent(html_79582637542e2a560c1ff9056be4309a);
#
#
#
#         marker_6851667f07fee0f241d8a47c92d1f1ce.bindPopup(popup_8d7d4204b76e59be05315245c61ae2d7)
#         ;
#
#
#
#
#             var marker_1add481362dbc4b14f93cac84bbf90b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_57701224aa683678f4a4d46a3d3f64d6);
#
#
#         var popup_ef04936220daeb7ff64793a121bd6c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa7295c8ba297c08daa1b69664ae21e8 = $(`&lt;div id=&quot;html_aa7295c8ba297c08daa1b69664ae21e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ef04936220daeb7ff64793a121bd6c9f.setContent(html_aa7295c8ba297c08daa1b69664ae21e8);
#
#
#
#         marker_1add481362dbc4b14f93cac84bbf90b3.bindPopup(popup_ef04936220daeb7ff64793a121bd6c9f)
#         ;
#
#
#
#
#             var marker_fbd3f308531e6f195c2253844dc0fcbe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_57701224aa683678f4a4d46a3d3f64d6);
#
#
#         var popup_4bf5c60a3171a5ec09d87cebf0165c1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06a456f5a3fd09c4220ab2889156e86d = $(`&lt;div id=&quot;html_06a456f5a3fd09c4220ab2889156e86d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4bf5c60a3171a5ec09d87cebf0165c1e.setContent(html_06a456f5a3fd09c4220ab2889156e86d);
#
#
#
#         marker_fbd3f308531e6f195c2253844dc0fcbe.bindPopup(popup_4bf5c60a3171a5ec09d87cebf0165c1e)
#         ;
#
#
#
#
#             var marker_eafc15b43454f1a6ce49ff6c2172ceaf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_57701224aa683678f4a4d46a3d3f64d6);
#
#
#         var popup_f8720f7b1217cf59a9d9678386056312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73555f4819803feeff34590c15ab5053 = $(`&lt;div id=&quot;html_73555f4819803feeff34590c15ab5053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f8720f7b1217cf59a9d9678386056312.setContent(html_73555f4819803feeff34590c15ab5053);
#
#
#
#         marker_eafc15b43454f1a6ce49ff6c2172ceaf.bindPopup(popup_f8720f7b1217cf59a9d9678386056312)
#         ;
#
#
#
#
#             var marker_d6cfc3c5fa0a95a46bea623b988ebb67 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_57701224aa683678f4a4d46a3d3f64d6);
#
#
#         var popup_1395e5d5c636dc36ea27277830bac7e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d71e3b76379a25e042637696967890cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d71e3b76379a25e042637696967890cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d71e3b76379a25e042637696967890cd = L.map(
#                 &quot;map_d71e3b76379a25e042637696967890cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8c27f8217bcb9788d5d6103a07c92f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8c27f8217bcb9788d5d6103a07c92f7.addTo(map_d71e3b76379a25e042637696967890cd);
#
#
#             var feature_group_d55e23908cb46e1ea13bc9f53d214414 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d55e23908cb46e1ea13bc9f53d214414.addTo(map_d71e3b76379a25e042637696967890cd);
#
#
#             var feature_group_sub_group_3b86f3f1091e2f69d1c18260965985c1 = L.featureGroup.subGroup(
#                 feature_group_d55e23908cb46e1ea13bc9f53d214414
#             );
#
#
#             var marker_ec4acf0494381031c89d79a59e7e2aca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b86f3f1091e2f69d1c18260965985c1);
#
#
#         var popup_47e60e02c9edf92c3ea5cc38a4b1b990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e802448ab6f30a07f3a98f8bd1765dcb = $(`&lt;div id=&quot;html_e802448ab6f30a07f3a98f8bd1765dcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_47e60e02c9edf92c3ea5cc38a4b1b990.setContent(html_e802448ab6f30a07f3a98f8bd1765dcb);
#
#
#
#         marker_ec4acf0494381031c89d79a59e7e2aca.bindPopup(popup_47e60e02c9edf92c3ea5cc38a4b1b990)
#         ;
#
#
#
#
#             var marker_70875915d112695161c6419ddcaf8183 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b86f3f1091e2f69d1c18260965985c1);
#
#
#         var popup_d7ec88c998729af45db413bbadf291ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15c1a41699f3d40507283ad4995d1860 = $(`&lt;div id=&quot;html_15c1a41699f3d40507283ad4995d1860&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d7ec88c998729af45db413bbadf291ae.setContent(html_15c1a41699f3d40507283ad4995d1860);
#
#
#
#         marker_70875915d112695161c6419ddcaf8183.bindPopup(popup_d7ec88c998729af45db413bbadf291ae)
#         ;
#
#
#
#
#             var marker_d1414ac906e07e810a14aafb01a03b30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b86f3f1091e2f69d1c18260965985c1);
#
#
#         var popup_4cabbda4de87a080c02cb223bbfffd56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6819748607d4c5ee7fcae9581f4e556 = $(`&lt;div id=&quot;html_d6819748607d4c5ee7fcae9581f4e556&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4cabbda4de87a080c02cb223bbfffd56.setContent(html_d6819748607d4c5ee7fcae9581f4e556);
#
#
#
#         marker_d1414ac906e07e810a14aafb01a03b30.bindPopup(popup_4cabbda4de87a080c02cb223bbfffd56)
#         ;
#
#
#
#
#             var marker_2187dd13b18a9af5eb15e3c52ec54802 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b86f3f1091e2f69d1c18260965985c1);
#
#
#         var popup_b900ea24daaa3c1c9ba657652f2dbe6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e4f41071d72cf30be42a856ae29b635 = $(`&lt;div id=&quot;html_0e4f41071d72cf30be42a856ae29b635&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b900ea24daaa3c1c9ba657652f2dbe6f.setContent(html_0e4f41071d72cf30be42a856ae29b635);
#
#
#
#         marker_
