# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b092b40111f29bea3f6a82bccf9a5df4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b092b40111f29bea3f6a82bccf9a5df4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b092b40111f29bea3f6a82bccf9a5df4 = L.map(
#                 &quot;map_b092b40111f29bea3f6a82bccf9a5df4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc2e5dd449ae0285fb4ffcc9a680c10c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc2e5dd449ae0285fb4ffcc9a680c10c.addTo(map_b092b40111f29bea3f6a82bccf9a5df4);
#
#
#             var marker_1d1fa1577e68ca3232e3ce48ac7fca48 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b092b40111f29bea3f6a82bccf9a5df4);
#
#
#         var popup_9c8644222441ea2edefd1b7911cce2ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_573f266f5ac8f2bd6b5f6243c3f056c9 = $(`&lt;div id=&quot;html_573f266f5ac8f2bd6b5f6243c3f056c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9c8644222441ea2edefd1b7911cce2ae.setContent(html_573f266f5ac8f2bd6b5f6243c3f056c9);
#
#
#
#         marker_1d1fa1577e68ca3232e3ce48ac7fca48.bindPopup(popup_9c8644222441ea2edefd1b7911cce2ae)
#         ;
#
#
#
#
#             var marker_5ca4a9cae8ff3ad433d28e6effb489cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b092b40111f29bea3f6a82bccf9a5df4);
#
#
#         var popup_5e224421f04d312d8048cc293c7de314 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3e8a9718da53892abcb3969f11bea74 = $(`&lt;div id=&quot;html_d3e8a9718da53892abcb3969f11bea74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5e224421f04d312d8048cc293c7de314.setContent(html_d3e8a9718da53892abcb3969f11bea74);
#
#
#
#         marker_5ca4a9cae8ff3ad433d28e6effb489cd.bindPopup(popup_5e224421f04d312d8048cc293c7de314)
#         ;
#
#
#
#
#             var marker_b2deaa9e187213cd44ba5c9ba48edace = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b092b40111f29bea3f6a82bccf9a5df4);
#
#
#         var popup_ceafaee6d429c326c2f23fb853fcb616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae55b60889b0f9bafcc01b1aabe76609 = $(`&lt;div id=&quot;html_ae55b60889b0f9bafcc01b1aabe76609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ceafaee6d429c326c2f23fb853fcb616.setContent(html_ae55b60889b0f9bafcc01b1aabe76609);
#
#
#
#         marker_b2deaa9e187213cd44ba5c9ba48edace.bindPopup(popup_ceafaee6d429c326c2f23fb853fcb616)
#         ;
#
#
#
#
#             var marker_9043a0e1a30fdb5b453d0549402f5e2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b092b40111f29bea3f6a82bccf9a5df4);
#
#
#         var popup_2aaa20878d6faa5d60fa4649dad2d785 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a261ebc859369f667b79d9d13a4ceae = $(`&lt;div id=&quot;html_9a261ebc859369f667b79d9d13a4ceae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2aaa20878d6faa5d60fa4649dad2d785.setContent(html_9a261ebc859369f667b79d9d13a4ceae);
#
#
#
#         marker_9043a0e1a30fdb5b453d0549402f5e2f.bindPopup(popup_2aaa20878d6faa5d60fa4649dad2d785)
#         ;
#
#
#
#
#             var marker_f4f36ea8227ea2a7db2e0d0a8ee623bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b092b40111f29bea3f6a82bccf9a5df4);
#
#
#         var popup_8bab7d06b99a45ff286a459814a6e814 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16b10a46073bcb3cb8dfe02a73c663ce = $(`&lt;div id=&quot;html_16b10a46073bcb3cb8dfe02a73c663ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8bab7d06b99a45ff286a459814a6e814.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37badb78def11c2c2eaaeac84a3d7cd5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37badb78def11c2c2eaaeac84a3d7cd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37badb78def11c2c2eaaeac84a3d7cd5 = L.map(
#                 &quot;map_37badb78def11c2c2eaaeac84a3d7cd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d48a971f6cc21f7ce71e21194a1d9eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d48a971f6cc21f7ce71e21194a1d9eb.addTo(map_37badb78def11c2c2eaaeac84a3d7cd5);
#
#
#             var feature_group_82fba38d2b7618515b056164d5ab1ab1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_52b89a19c947fd2d9b043b20469ba65e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_82fba38d2b7618515b056164d5ab1ab1);
#
#
#         var popup_3ee27470ebd813d5663a86b0503a7dc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2a91f91c0a6da9741ebe2612fa3ad65 = $(`&lt;div id=&quot;html_a2a91f91c0a6da9741ebe2612fa3ad65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3ee27470ebd813d5663a86b0503a7dc3.setContent(html_a2a91f91c0a6da9741ebe2612fa3ad65);
#
#
#
#         marker_52b89a19c947fd2d9b043b20469ba65e.bindPopup(popup_3ee27470ebd813d5663a86b0503a7dc3)
#         ;
#
#
#
#
#             var marker_da5ffcbd11cad3fe3946b3703b90e4e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_82fba38d2b7618515b056164d5ab1ab1);
#
#
#         var popup_98345e7e81bd7c0c63c8040bd3af64f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_188327606efc922dd896cc334b8c1ae5 = $(`&lt;div id=&quot;html_188327606efc922dd896cc334b8c1ae5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_98345e7e81bd7c0c63c8040bd3af64f7.setContent(html_188327606efc922dd896cc334b8c1ae5);
#
#
#
#         marker_da5ffcbd11cad3fe3946b3703b90e4e8.bindPopup(popup_98345e7e81bd7c0c63c8040bd3af64f7)
#         ;
#
#
#
#
#             var marker_aae114e37762f3f73f5b31c3c24fe7ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_82fba38d2b7618515b056164d5ab1ab1);
#
#
#         var popup_8f4fb15ec3e3432c69e59f6faccd7cf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4ccb35e27171bb7e1f221223be9a3c9 = $(`&lt;div id=&quot;html_e4ccb35e27171bb7e1f221223be9a3c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8f4fb15ec3e3432c69e59f6faccd7cf1.setContent(html_e4ccb35e27171bb7e1f221223be9a3c9);
#
#
#
#         marker_aae114e37762f3f73f5b31c3c24fe7ef.bindPopup(popup_8f4fb15ec3e3432c69e59f6faccd7cf1)
#         ;
#
#
#
#
#             var marker_a5cafc0376ad6009cdd2dd4522797b9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_82fba38d2b7618515b056164d5ab1ab1);
#
#
#         var popup_a3993256471bdaf1cb16406f66474314 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0de0d981bc0bb293ff843393e1b6b5f = $(`&lt;div id=&quot;html_c0de0d981bc0bb293ff843393e1b6b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a3993256471bdaf1cb16406f66474314.setContent(html_c0de0d981bc0bb293ff843393e1b6b5f);
#
#
#
#         marker_a5cafc0376ad6009cdd2dd4522797b9d.bindPopup(popup_a3993256471bdaf1cb16406f66474314)
#         ;
#
#
#
#
#             var marker_85c15d6ae49282f8fa859505e5520f23 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_82fba38d2b7618515b056164d5ab1ab1);
#
#
#         var popup_787d202b501d0311ba24b7f031b6e85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75056f2443c6e30ffdc5f906023c573e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75056f2443c6e30ffdc5f906023c573e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75056f2443c6e30ffdc5f906023c573e = L.map(
#                 &quot;map_75056f2443c6e30ffdc5f906023c573e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9c07b94cf2a3d2ae3c1b5a16833e0f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9c07b94cf2a3d2ae3c1b5a16833e0f7.addTo(map_75056f2443c6e30ffdc5f906023c573e);
#
#
#             var feature_group_25e1101829d45e179edd30729634b3e6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_25e1101829d45e179edd30729634b3e6.addTo(map_75056f2443c6e30ffdc5f906023c573e);
#
#
#             var feature_group_sub_group_d87a957e1cb832608e5f6479442f6698 = L.featureGroup.subGroup(
#                 feature_group_25e1101829d45e179edd30729634b3e6
#             );
#
#
#             var marker_109b1ee421bc64971542ce63fc013813 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d87a957e1cb832608e5f6479442f6698);
#
#
#         var popup_e97d4c0b05ef9f30eec161940fa844b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c65eaa3ce2fc33105a10fbf2c2d4137 = $(`&lt;div id=&quot;html_5c65eaa3ce2fc33105a10fbf2c2d4137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e97d4c0b05ef9f30eec161940fa844b9.setContent(html_5c65eaa3ce2fc33105a10fbf2c2d4137);
#
#
#
#         marker_109b1ee421bc64971542ce63fc013813.bindPopup(popup_e97d4c0b05ef9f30eec161940fa844b9)
#         ;
#
#
#
#
#             var marker_606111f485b10dbee40ea027dfa4d064 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d87a957e1cb832608e5f6479442f6698);
#
#
#         var popup_f9bf227838d3350893574c4c962f99f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c76b3250ecd3a0b1eb3b4bbd57e7ca51 = $(`&lt;div id=&quot;html_c76b3250ecd3a0b1eb3b4bbd57e7ca51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f9bf227838d3350893574c4c962f99f6.setContent(html_c76b3250ecd3a0b1eb3b4bbd57e7ca51);
#
#
#
#         marker_606111f485b10dbee40ea027dfa4d064.bindPopup(popup_f9bf227838d3350893574c4c962f99f6)
#         ;
#
#
#
#
#             var marker_9819899b66ace9403b973f772e1fad7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d87a957e1cb832608e5f6479442f6698);
#
#
#         var popup_24132e0adeb774dc04b563934bec0cd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_270e3d213d6858257b97c024a9e6b392 = $(`&lt;div id=&quot;html_270e3d213d6858257b97c024a9e6b392&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_24132e0adeb774dc04b563934bec0cd3.setContent(html_270e3d213d6858257b97c024a9e6b392);
#
#
#
#         marker_9819899b66ace9403b973f772e1fad7c.bindPopup(popup_24132e0adeb774dc04b563934bec0cd3)
#         ;
#
#
#
#
#             var marker_bec54f849663cdffa86fcf6c0f3496df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d87a957e1cb832608e5f6479442f6698);
#
#
#         var popup_1a81ae9d0aeef37b07f7eb7308a574fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc1ba95c82231a8e29eca6524294c05d = $(`&lt;div id=&quot;html_cc1ba95c82231a8e29eca6524294c05d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1a81ae9d0aeef37b07f7eb7308a574fd.setContent(html_cc1ba95c82231a8e29eca6524294c05d);
#
#
#
#         marker_
