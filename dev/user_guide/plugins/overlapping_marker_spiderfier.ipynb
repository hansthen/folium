# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e381fdf3799c9c6198137e279d83d9ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e381fdf3799c9c6198137e279d83d9ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e381fdf3799c9c6198137e279d83d9ce = L.map(
#                 &quot;map_e381fdf3799c9c6198137e279d83d9ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25859c204b42dce20d1ce36910bc3c31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_25859c204b42dce20d1ce36910bc3c31.addTo(map_e381fdf3799c9c6198137e279d83d9ce);
#
#
#             var marker_a55db12764a310ecd2f0d8301dbd4cbe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e381fdf3799c9c6198137e279d83d9ce);
#
#
#         var popup_9bd511425b4e3d30f52be8785cb8009d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8931835475410828ec25e207b9cf094b = $(`&lt;div id=&quot;html_8931835475410828ec25e207b9cf094b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9bd511425b4e3d30f52be8785cb8009d.setContent(html_8931835475410828ec25e207b9cf094b);
#
#
#
#         marker_a55db12764a310ecd2f0d8301dbd4cbe.bindPopup(popup_9bd511425b4e3d30f52be8785cb8009d)
#         ;
#
#
#
#
#             var marker_b3df83583510776b9ff53335cdee8742 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e381fdf3799c9c6198137e279d83d9ce);
#
#
#         var popup_898860993e07a16039f4505d0f78c6b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cceb5bcb43434b4d8f85a13bfef6ec7e = $(`&lt;div id=&quot;html_cceb5bcb43434b4d8f85a13bfef6ec7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_898860993e07a16039f4505d0f78c6b2.setContent(html_cceb5bcb43434b4d8f85a13bfef6ec7e);
#
#
#
#         marker_b3df83583510776b9ff53335cdee8742.bindPopup(popup_898860993e07a16039f4505d0f78c6b2)
#         ;
#
#
#
#
#             var marker_e32b91cd532547afdecad838889ec5d8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e381fdf3799c9c6198137e279d83d9ce);
#
#
#         var popup_272f3920db22e6d6ed6e4ee10a747441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae6df226ecee7ffdc9e4e4f4a52a521e = $(`&lt;div id=&quot;html_ae6df226ecee7ffdc9e4e4f4a52a521e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_272f3920db22e6d6ed6e4ee10a747441.setContent(html_ae6df226ecee7ffdc9e4e4f4a52a521e);
#
#
#
#         marker_e32b91cd532547afdecad838889ec5d8.bindPopup(popup_272f3920db22e6d6ed6e4ee10a747441)
#         ;
#
#
#
#
#             var marker_b31a70507d456d5bf67eb22f9d121323 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e381fdf3799c9c6198137e279d83d9ce);
#
#
#         var popup_b698d239cf6ee6f5f29a65c1411e3275 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6272c7cd588eab0198580da854fee734 = $(`&lt;div id=&quot;html_6272c7cd588eab0198580da854fee734&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b698d239cf6ee6f5f29a65c1411e3275.setContent(html_6272c7cd588eab0198580da854fee734);
#
#
#
#         marker_b31a70507d456d5bf67eb22f9d121323.bindPopup(popup_b698d239cf6ee6f5f29a65c1411e3275)
#         ;
#
#
#
#
#             var marker_1d3b3dc3b5a9e3a29ecd0a06813f3b91 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e381fdf3799c9c6198137e279d83d9ce);
#
#
#         var popup_52eb514496e36f64b4f93adaeb9c6f82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31c60825ba7f8d561c851bc0614fc8be = $(`&lt;div id=&quot;html_31c60825ba7f8d561c851bc0614fc8be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_52eb514496e36f64b4f93adaeb9c6f82.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faf1ceb53e5ff61126dcff481f871f13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faf1ceb53e5ff61126dcff481f871f13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faf1ceb53e5ff61126dcff481f871f13 = L.map(
#                 &quot;map_faf1ceb53e5ff61126dcff481f871f13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4af20e2b033e840cc0284569b48007c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4af20e2b033e840cc0284569b48007c3.addTo(map_faf1ceb53e5ff61126dcff481f871f13);
#
#
#             var feature_group_db7445b15ef3a07e496cd26705ab2a53 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a0957cf1fbc7340e555c4dbf19696d98 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_db7445b15ef3a07e496cd26705ab2a53);
#
#
#         var popup_40f2374cf2272723a385460cd2ff9a81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c67c2c52e16ed655b1a04c24376f6d30 = $(`&lt;div id=&quot;html_c67c2c52e16ed655b1a04c24376f6d30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_40f2374cf2272723a385460cd2ff9a81.setContent(html_c67c2c52e16ed655b1a04c24376f6d30);
#
#
#
#         marker_a0957cf1fbc7340e555c4dbf19696d98.bindPopup(popup_40f2374cf2272723a385460cd2ff9a81)
#         ;
#
#
#
#
#             var marker_6158e3faf00b4c983e9f3e64f21e6eaf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_db7445b15ef3a07e496cd26705ab2a53);
#
#
#         var popup_49bba1946127d67f5d3e0be733c4f730 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ac8f636ef101c03db9227df7fc18aec = $(`&lt;div id=&quot;html_2ac8f636ef101c03db9227df7fc18aec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_49bba1946127d67f5d3e0be733c4f730.setContent(html_2ac8f636ef101c03db9227df7fc18aec);
#
#
#
#         marker_6158e3faf00b4c983e9f3e64f21e6eaf.bindPopup(popup_49bba1946127d67f5d3e0be733c4f730)
#         ;
#
#
#
#
#             var marker_3bf941d29caaf86aa41c6871ce43b367 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_db7445b15ef3a07e496cd26705ab2a53);
#
#
#         var popup_3d01e2cfc290b2c8b4094de2b70dead8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2adb32021e8bf10499e52cd2ed1e8b5 = $(`&lt;div id=&quot;html_b2adb32021e8bf10499e52cd2ed1e8b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3d01e2cfc290b2c8b4094de2b70dead8.setContent(html_b2adb32021e8bf10499e52cd2ed1e8b5);
#
#
#
#         marker_3bf941d29caaf86aa41c6871ce43b367.bindPopup(popup_3d01e2cfc290b2c8b4094de2b70dead8)
#         ;
#
#
#
#
#             var marker_e79a06495c286eeee744dd45dee826ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_db7445b15ef3a07e496cd26705ab2a53);
#
#
#         var popup_95fe2d84ad62b163d41ca7b1e8ce52e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df4ad397024326798ae345ce6e5fe612 = $(`&lt;div id=&quot;html_df4ad397024326798ae345ce6e5fe612&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_95fe2d84ad62b163d41ca7b1e8ce52e3.setContent(html_df4ad397024326798ae345ce6e5fe612);
#
#
#
#         marker_e79a06495c286eeee744dd45dee826ba.bindPopup(popup_95fe2d84ad62b163d41ca7b1e8ce52e3)
#         ;
#
#
#
#
#             var marker_398274fdd496b98533325e898d3a2269 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_db7445b15ef3a07e496cd26705ab2a53);
#
#
#         var popup_fd282d915c636b483cc4f6fce9878cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03f3aef5569c46bf027df0ac9a3c1fc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03f3aef5569c46bf027df0ac9a3c1fc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03f3aef5569c46bf027df0ac9a3c1fc0 = L.map(
#                 &quot;map_03f3aef5569c46bf027df0ac9a3c1fc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42f9775f72fb162ae1b03d2d7b28d882 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42f9775f72fb162ae1b03d2d7b28d882.addTo(map_03f3aef5569c46bf027df0ac9a3c1fc0);
#
#
#             var feature_group_fa1af32742b57f8e6aac61e2387e038b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fa1af32742b57f8e6aac61e2387e038b.addTo(map_03f3aef5569c46bf027df0ac9a3c1fc0);
#
#
#             var feature_group_sub_group_17eea3022175351053cf67d1d8df60c2 = L.featureGroup.subGroup(
#                 feature_group_fa1af32742b57f8e6aac61e2387e038b
#             );
#
#
#             var marker_f7c969fd62c3eda2b574c8f2b653a605 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_17eea3022175351053cf67d1d8df60c2);
#
#
#         var popup_47052170807e0d3486cf3aba09ddd4d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e1377b1a3cb97777bb91953ac50ea2b = $(`&lt;div id=&quot;html_8e1377b1a3cb97777bb91953ac50ea2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_47052170807e0d3486cf3aba09ddd4d3.setContent(html_8e1377b1a3cb97777bb91953ac50ea2b);
#
#
#
#         marker_f7c969fd62c3eda2b574c8f2b653a605.bindPopup(popup_47052170807e0d3486cf3aba09ddd4d3)
#         ;
#
#
#
#
#             var marker_d1c7294d174414336cabd7823fca46d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_17eea3022175351053cf67d1d8df60c2);
#
#
#         var popup_a02fecb778bc5d349f1a19e29d5162f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e65ae893280e9cd5607b9b9c7dbf611a = $(`&lt;div id=&quot;html_e65ae893280e9cd5607b9b9c7dbf611a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a02fecb778bc5d349f1a19e29d5162f4.setContent(html_e65ae893280e9cd5607b9b9c7dbf611a);
#
#
#
#         marker_d1c7294d174414336cabd7823fca46d8.bindPopup(popup_a02fecb778bc5d349f1a19e29d5162f4)
#         ;
#
#
#
#
#             var marker_b7c942a74929d67b59f1b1488244c23e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_17eea3022175351053cf67d1d8df60c2);
#
#
#         var popup_2e582650841a65397df15a6a509be086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbb15fa44cbe4dca3c2618e37f44d9ad = $(`&lt;div id=&quot;html_cbb15fa44cbe4dca3c2618e37f44d9ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2e582650841a65397df15a6a509be086.setContent(html_cbb15fa44cbe4dca3c2618e37f44d9ad);
#
#
#
#         marker_b7c942a74929d67b59f1b1488244c23e.bindPopup(popup_2e582650841a65397df15a6a509be086)
#         ;
#
#
#
#
#             var marker_43c101fe083c066340f3f1f906b120fb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_17eea3022175351053cf67d1d8df60c2);
#
#
#         var popup_31da70089b7344520a29e84f87abb8f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe228f3ea6ec3cebc27f974592458caf = $(`&lt;div id=&quot;html_fe228f3ea6ec3cebc27f974592458caf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_31da70089b7344520a29e84f87abb8f8.setContent(html_fe228f3ea6ec3cebc27f974592458caf);
#
#
#
#         marker_
