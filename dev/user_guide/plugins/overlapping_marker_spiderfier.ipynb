# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_124faeb92606229e3a6f47162894d5d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_124faeb92606229e3a6f47162894d5d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_124faeb92606229e3a6f47162894d5d3 = L.map(
#                 &quot;map_124faeb92606229e3a6f47162894d5d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d4ef69c16d7ed303eeb758c092b3b19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d4ef69c16d7ed303eeb758c092b3b19.addTo(map_124faeb92606229e3a6f47162894d5d3);
#
#
#             var marker_86e15a9a009ddfb78996fead70375eb1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_124faeb92606229e3a6f47162894d5d3);
#
#
#         var popup_8bbe102116f8edac5e3d43016f331580 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25acf56ae0bcda327c192a012afe7f41 = $(`&lt;div id=&quot;html_25acf56ae0bcda327c192a012afe7f41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8bbe102116f8edac5e3d43016f331580.setContent(html_25acf56ae0bcda327c192a012afe7f41);
#
#
#
#         marker_86e15a9a009ddfb78996fead70375eb1.bindPopup(popup_8bbe102116f8edac5e3d43016f331580)
#         ;
#
#
#
#
#             var marker_13628244af16d458edafc4452bd82fb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_124faeb92606229e3a6f47162894d5d3);
#
#
#         var popup_e0081f9cb9df9dbd28d7e03b70e44eb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4120c03cc400fdbceb3de54d1e83bb7d = $(`&lt;div id=&quot;html_4120c03cc400fdbceb3de54d1e83bb7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e0081f9cb9df9dbd28d7e03b70e44eb9.setContent(html_4120c03cc400fdbceb3de54d1e83bb7d);
#
#
#
#         marker_13628244af16d458edafc4452bd82fb0.bindPopup(popup_e0081f9cb9df9dbd28d7e03b70e44eb9)
#         ;
#
#
#
#
#             var marker_bb1088b42d5b5e3c0fa4bf1cee6b5d5d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_124faeb92606229e3a6f47162894d5d3);
#
#
#         var popup_bf7ba06ee4d72beeeca97e5600bcfb50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d5018a992dd9ff140b8cbd71806109a = $(`&lt;div id=&quot;html_4d5018a992dd9ff140b8cbd71806109a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bf7ba06ee4d72beeeca97e5600bcfb50.setContent(html_4d5018a992dd9ff140b8cbd71806109a);
#
#
#
#         marker_bb1088b42d5b5e3c0fa4bf1cee6b5d5d.bindPopup(popup_bf7ba06ee4d72beeeca97e5600bcfb50)
#         ;
#
#
#
#
#             var marker_5a714b53dbc271cb42bceb164137e04d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_124faeb92606229e3a6f47162894d5d3);
#
#
#         var popup_85c23cf4c62382e68b44b2119e5a4070 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27adfd0afe39b828566bf4f2e748ef12 = $(`&lt;div id=&quot;html_27adfd0afe39b828566bf4f2e748ef12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_85c23cf4c62382e68b44b2119e5a4070.setContent(html_27adfd0afe39b828566bf4f2e748ef12);
#
#
#
#         marker_5a714b53dbc271cb42bceb164137e04d.bindPopup(popup_85c23cf4c62382e68b44b2119e5a4070)
#         ;
#
#
#
#
#             var marker_c79a51cef8f40df777d50350e99594d8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_124faeb92606229e3a6f47162894d5d3);
#
#
#         var popup_063d212f6f03988b9ff3addabae361d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40185b11cb0cf22a776770cf30ba189c = $(`&lt;div id=&quot;html_40185b11cb0cf22a776770cf30ba189c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_063d212f6f03988b9ff3addabae361d5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59eccf92d72c267c0a48effe879fe9fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59eccf92d72c267c0a48effe879fe9fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59eccf92d72c267c0a48effe879fe9fd = L.map(
#                 &quot;map_59eccf92d72c267c0a48effe879fe9fd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_996b1fd0e4df80fc68d834c1fc47be98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_996b1fd0e4df80fc68d834c1fc47be98.addTo(map_59eccf92d72c267c0a48effe879fe9fd);
#
#
#             var feature_group_cee60946947a01c2b51d01205592bfe5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2aaf5bb3c9608cfa12ef825be94510c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cee60946947a01c2b51d01205592bfe5);
#
#
#         var popup_a743beac19ff8c5b652bb2311650b504 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_860b1f0e06a25f18588ae80f1da71f98 = $(`&lt;div id=&quot;html_860b1f0e06a25f18588ae80f1da71f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a743beac19ff8c5b652bb2311650b504.setContent(html_860b1f0e06a25f18588ae80f1da71f98);
#
#
#
#         marker_b2aaf5bb3c9608cfa12ef825be94510c.bindPopup(popup_a743beac19ff8c5b652bb2311650b504)
#         ;
#
#
#
#
#             var marker_c55b071b1d9b5a9fdfe5711f66586c9c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cee60946947a01c2b51d01205592bfe5);
#
#
#         var popup_3867a07d42346a3f44a62fec50cd2bf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f533f1a3da007fa2f53c0e905006fff7 = $(`&lt;div id=&quot;html_f533f1a3da007fa2f53c0e905006fff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3867a07d42346a3f44a62fec50cd2bf1.setContent(html_f533f1a3da007fa2f53c0e905006fff7);
#
#
#
#         marker_c55b071b1d9b5a9fdfe5711f66586c9c.bindPopup(popup_3867a07d42346a3f44a62fec50cd2bf1)
#         ;
#
#
#
#
#             var marker_df12c31e8cb41e5a0a2b3ea400019eb9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cee60946947a01c2b51d01205592bfe5);
#
#
#         var popup_cebab032d6fe7560474cf351b03ad259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a3a9f1c1b264ad3d4ece0b1fbf9de41 = $(`&lt;div id=&quot;html_4a3a9f1c1b264ad3d4ece0b1fbf9de41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cebab032d6fe7560474cf351b03ad259.setContent(html_4a3a9f1c1b264ad3d4ece0b1fbf9de41);
#
#
#
#         marker_df12c31e8cb41e5a0a2b3ea400019eb9.bindPopup(popup_cebab032d6fe7560474cf351b03ad259)
#         ;
#
#
#
#
#             var marker_cfb7717e99fa6ec0f85a3baf5c5bb404 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cee60946947a01c2b51d01205592bfe5);
#
#
#         var popup_83e35c6727f2d1a0d0536ed5bb8cafa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_178151528bf8f944fc00439216abc43b = $(`&lt;div id=&quot;html_178151528bf8f944fc00439216abc43b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_83e35c6727f2d1a0d0536ed5bb8cafa3.setContent(html_178151528bf8f944fc00439216abc43b);
#
#
#
#         marker_cfb7717e99fa6ec0f85a3baf5c5bb404.bindPopup(popup_83e35c6727f2d1a0d0536ed5bb8cafa3)
#         ;
#
#
#
#
#             var marker_25e4a0d0d94ef3e21330b2e11f283bbd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cee60946947a01c2b51d01205592bfe5);
#
#
#         var popup_f6ec94a1bbb9e4a8280d0afbcb10fb42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68c55acddd7ebd60c3ee7f56097c6802 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68c55acddd7ebd60c3ee7f56097c6802&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68c55acddd7ebd60c3ee7f56097c6802 = L.map(
#                 &quot;map_68c55acddd7ebd60c3ee7f56097c6802&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cf0def9ca98edc49e1d12b556341d7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8cf0def9ca98edc49e1d12b556341d7a.addTo(map_68c55acddd7ebd60c3ee7f56097c6802);
#
#
#             var feature_group_7dd5694da555624e975588fb43097072 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7dd5694da555624e975588fb43097072.addTo(map_68c55acddd7ebd60c3ee7f56097c6802);
#
#
#             var feature_group_sub_group_ef58ad5a0d742cd502b5d9413ee71cd2 = L.featureGroup.subGroup(
#                 feature_group_7dd5694da555624e975588fb43097072
#             );
#
#
#             var marker_145dbe189b0add1ba699d858d4de54b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef58ad5a0d742cd502b5d9413ee71cd2);
#
#
#         var popup_1452e8371eece5d9578b735e987ab55e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52a8f8b026e7ac8193b05a4720f54597 = $(`&lt;div id=&quot;html_52a8f8b026e7ac8193b05a4720f54597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1452e8371eece5d9578b735e987ab55e.setContent(html_52a8f8b026e7ac8193b05a4720f54597);
#
#
#
#         marker_145dbe189b0add1ba699d858d4de54b0.bindPopup(popup_1452e8371eece5d9578b735e987ab55e)
#         ;
#
#
#
#
#             var marker_9fd75c7c6e56b2db94353b36d782fe09 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef58ad5a0d742cd502b5d9413ee71cd2);
#
#
#         var popup_f3fcfa16e4502e45cdd9aa0801946165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93eb6068bb33f218e88d8a00ef22c2de = $(`&lt;div id=&quot;html_93eb6068bb33f218e88d8a00ef22c2de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f3fcfa16e4502e45cdd9aa0801946165.setContent(html_93eb6068bb33f218e88d8a00ef22c2de);
#
#
#
#         marker_9fd75c7c6e56b2db94353b36d782fe09.bindPopup(popup_f3fcfa16e4502e45cdd9aa0801946165)
#         ;
#
#
#
#
#             var marker_fe65429d7946b85411fc9b1253768edc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef58ad5a0d742cd502b5d9413ee71cd2);
#
#
#         var popup_336c3ed58ef680da7a6edf3ac4897d1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64673fdf5720df5d4bd2fea9be0ad1cc = $(`&lt;div id=&quot;html_64673fdf5720df5d4bd2fea9be0ad1cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_336c3ed58ef680da7a6edf3ac4897d1a.setContent(html_64673fdf5720df5d4bd2fea9be0ad1cc);
#
#
#
#         marker_fe65429d7946b85411fc9b1253768edc.bindPopup(popup_336c3ed58ef680da7a6edf3ac4897d1a)
#         ;
#
#
#
#
#             var marker_bde6ac9f7c7bbef1209242e69a6949f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef58ad5a0d742cd502b5d9413ee71cd2);
#
#
#         var popup_592f6ade31fcf87c30b946a0d406ebf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7453744a1fca4c99032d091d680b4665 = $(`&lt;div id=&quot;html_7453744a1fca4c99032d091d680b4665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_592f6ade31fcf87c30b946a0d406ebf7.setContent(html_7453744a1fca4c99032d091d680b4665);
#
#
#
#         marker_
