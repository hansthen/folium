# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94ae8db2517230294cff27169ae6d028 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94ae8db2517230294cff27169ae6d028&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94ae8db2517230294cff27169ae6d028 = L.map(
#                 &quot;map_94ae8db2517230294cff27169ae6d028&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5c1d5480ad0026bfe76375d0ebd1cc7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5c1d5480ad0026bfe76375d0ebd1cc7.addTo(map_94ae8db2517230294cff27169ae6d028);
#
#
#             var marker_d9c2180aab7431331f6b5d220df7251a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94ae8db2517230294cff27169ae6d028);
#
#
#         var popup_cee3bb9fce71ef731efed82c7f452738 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d607bf4db5756f206df99cb81396f889 = $(`&lt;div id=&quot;html_d607bf4db5756f206df99cb81396f889&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cee3bb9fce71ef731efed82c7f452738.setContent(html_d607bf4db5756f206df99cb81396f889);
#
#
#
#         marker_d9c2180aab7431331f6b5d220df7251a.bindPopup(popup_cee3bb9fce71ef731efed82c7f452738)
#         ;
#
#
#
#
#             var marker_260fbf4990fcd97853773e8d448a9ef3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94ae8db2517230294cff27169ae6d028);
#
#
#         var popup_716a2b2ee56a075e9effcde2706175c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81973a8582721711c670555c4d8af33e = $(`&lt;div id=&quot;html_81973a8582721711c670555c4d8af33e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_716a2b2ee56a075e9effcde2706175c9.setContent(html_81973a8582721711c670555c4d8af33e);
#
#
#
#         marker_260fbf4990fcd97853773e8d448a9ef3.bindPopup(popup_716a2b2ee56a075e9effcde2706175c9)
#         ;
#
#
#
#
#             var marker_7d80fdf7172189efec6ee2184e79b733 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94ae8db2517230294cff27169ae6d028);
#
#
#         var popup_0fc0c3334b03dd2f3b6f145b75cff25d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a8fdf6bcea63466b936adc9bb72c5c4 = $(`&lt;div id=&quot;html_2a8fdf6bcea63466b936adc9bb72c5c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0fc0c3334b03dd2f3b6f145b75cff25d.setContent(html_2a8fdf6bcea63466b936adc9bb72c5c4);
#
#
#
#         marker_7d80fdf7172189efec6ee2184e79b733.bindPopup(popup_0fc0c3334b03dd2f3b6f145b75cff25d)
#         ;
#
#
#
#
#             var marker_72e9e914174ef30a2b6fee950cf5ff66 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94ae8db2517230294cff27169ae6d028);
#
#
#         var popup_b724543a3ddd10b43b6265794b8ccdbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88d59bfd2965a6cd059ab18327af4791 = $(`&lt;div id=&quot;html_88d59bfd2965a6cd059ab18327af4791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b724543a3ddd10b43b6265794b8ccdbb.setContent(html_88d59bfd2965a6cd059ab18327af4791);
#
#
#
#         marker_72e9e914174ef30a2b6fee950cf5ff66.bindPopup(popup_b724543a3ddd10b43b6265794b8ccdbb)
#         ;
#
#
#
#
#             var marker_7a120188fbbd3349ee8bb760950c2e09 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94ae8db2517230294cff27169ae6d028);
#
#
#         var popup_e0dac1e968a2617f1085d545edf95f06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d22cb9db7bc14706175f49dafb2565 = $(`&lt;div id=&quot;html_12d22cb9db7bc14706175f49dafb2565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e0dac1e968a2617f1085d545edf95f06.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8471e7ff024863abcf3710d17b979a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8471e7ff024863abcf3710d17b979a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8471e7ff024863abcf3710d17b979a5b = L.map(
#                 &quot;map_8471e7ff024863abcf3710d17b979a5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f169a9bfe69c65bc7cb5968f41873568 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f169a9bfe69c65bc7cb5968f41873568.addTo(map_8471e7ff024863abcf3710d17b979a5b);
#
#
#             var feature_group_fb0551c9e18ec1ab3cd485f3f1cef773 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a6b6066cdeab47427bf939db65ac2d79 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fb0551c9e18ec1ab3cd485f3f1cef773);
#
#
#         var popup_b5b923e235294b21795b3edefe2607e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09b696ef2fc9d3dc5f2d8c707fc5904f = $(`&lt;div id=&quot;html_09b696ef2fc9d3dc5f2d8c707fc5904f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b5b923e235294b21795b3edefe2607e6.setContent(html_09b696ef2fc9d3dc5f2d8c707fc5904f);
#
#
#
#         marker_a6b6066cdeab47427bf939db65ac2d79.bindPopup(popup_b5b923e235294b21795b3edefe2607e6)
#         ;
#
#
#
#
#             var marker_74e0606095b392873fc57930479da8cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fb0551c9e18ec1ab3cd485f3f1cef773);
#
#
#         var popup_b61d3526c3ebbc8ffda2691539de0368 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ef9d96d71c911e695cb4c129367eff5 = $(`&lt;div id=&quot;html_2ef9d96d71c911e695cb4c129367eff5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b61d3526c3ebbc8ffda2691539de0368.setContent(html_2ef9d96d71c911e695cb4c129367eff5);
#
#
#
#         marker_74e0606095b392873fc57930479da8cd.bindPopup(popup_b61d3526c3ebbc8ffda2691539de0368)
#         ;
#
#
#
#
#             var marker_eebda04b6794b3ddef1cebdb87607ab3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fb0551c9e18ec1ab3cd485f3f1cef773);
#
#
#         var popup_32fc1f1ccd0b8c36ac3f1be61d5823e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e79ee52840aec58c004005ef480da8f = $(`&lt;div id=&quot;html_9e79ee52840aec58c004005ef480da8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_32fc1f1ccd0b8c36ac3f1be61d5823e8.setContent(html_9e79ee52840aec58c004005ef480da8f);
#
#
#
#         marker_eebda04b6794b3ddef1cebdb87607ab3.bindPopup(popup_32fc1f1ccd0b8c36ac3f1be61d5823e8)
#         ;
#
#
#
#
#             var marker_ef509b1a6b1f1fe8070dfc6e4f060054 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fb0551c9e18ec1ab3cd485f3f1cef773);
#
#
#         var popup_3394c8b28c03f7f9de7826a23f005633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00e6b22cdc3af39c6e9f0e2d394a40b9 = $(`&lt;div id=&quot;html_00e6b22cdc3af39c6e9f0e2d394a40b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3394c8b28c03f7f9de7826a23f005633.setContent(html_00e6b22cdc3af39c6e9f0e2d394a40b9);
#
#
#
#         marker_ef509b1a6b1f1fe8070dfc6e4f060054.bindPopup(popup_3394c8b28c03f7f9de7826a23f005633)
#         ;
#
#
#
#
#             var marker_7d64c3f35a33eecf84315d29833dea92 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fb0551c9e18ec1ab3cd485f3f1cef773);
#
#
#         var popup_7e36214c86450172bbcb0f0bb4fa1622 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b792b35e5c3980566d1b2d9cf83c8573 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b792b35e5c3980566d1b2d9cf83c8573&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b792b35e5c3980566d1b2d9cf83c8573 = L.map(
#                 &quot;map_b792b35e5c3980566d1b2d9cf83c8573&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19546981b443511dfe63ce3df5fe9a63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19546981b443511dfe63ce3df5fe9a63.addTo(map_b792b35e5c3980566d1b2d9cf83c8573);
#
#
#             var feature_group_c0e8be371500a4777497db32594291a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c0e8be371500a4777497db32594291a6.addTo(map_b792b35e5c3980566d1b2d9cf83c8573);
#
#
#             var feature_group_sub_group_fd0aad3c8f5e6052b6f038c6ac8ab02b = L.featureGroup.subGroup(
#                 feature_group_c0e8be371500a4777497db32594291a6
#             );
#
#
#             var marker_1d1b1fa33f4a27621889b8d0b02fcfe7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd0aad3c8f5e6052b6f038c6ac8ab02b);
#
#
#         var popup_de857268ba40adf2aaa4ad7e42cb1168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b366e86e6f59e902b9d58944e50ab868 = $(`&lt;div id=&quot;html_b366e86e6f59e902b9d58944e50ab868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_de857268ba40adf2aaa4ad7e42cb1168.setContent(html_b366e86e6f59e902b9d58944e50ab868);
#
#
#
#         marker_1d1b1fa33f4a27621889b8d0b02fcfe7.bindPopup(popup_de857268ba40adf2aaa4ad7e42cb1168)
#         ;
#
#
#
#
#             var marker_b3a4952f0cf4af13f35a9433633e00a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd0aad3c8f5e6052b6f038c6ac8ab02b);
#
#
#         var popup_ac0a2d9c178d4c88c42fe963bcbda265 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03390e381a3ea21d42184d08619770cf = $(`&lt;div id=&quot;html_03390e381a3ea21d42184d08619770cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ac0a2d9c178d4c88c42fe963bcbda265.setContent(html_03390e381a3ea21d42184d08619770cf);
#
#
#
#         marker_b3a4952f0cf4af13f35a9433633e00a8.bindPopup(popup_ac0a2d9c178d4c88c42fe963bcbda265)
#         ;
#
#
#
#
#             var marker_5dd4c65e09e9a90802bb3324de8772c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd0aad3c8f5e6052b6f038c6ac8ab02b);
#
#
#         var popup_9a6ff82bc8af389a095cc7c507c3e60a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_954d81261c28698ff4b1c04cc7787dec = $(`&lt;div id=&quot;html_954d81261c28698ff4b1c04cc7787dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9a6ff82bc8af389a095cc7c507c3e60a.setContent(html_954d81261c28698ff4b1c04cc7787dec);
#
#
#
#         marker_5dd4c65e09e9a90802bb3324de8772c6.bindPopup(popup_9a6ff82bc8af389a095cc7c507c3e60a)
#         ;
#
#
#
#
#             var marker_57d78e00fb11f6db2a924a04986389cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd0aad3c8f5e6052b6f038c6ac8ab02b);
#
#
#         var popup_21111643c46c94225c6f274128b317ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0aecae080e7009129dbc10649e6394d = $(`&lt;div id=&quot;html_d0aecae080e7009129dbc10649e6394d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_21111643c46c94225c6f274128b317ef.setContent(html_d0aecae080e7009129dbc10649e6394d);
#
#
#
#         marker_
