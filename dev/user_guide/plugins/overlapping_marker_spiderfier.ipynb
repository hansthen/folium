# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa2c98686e09ac7702a4b80e7cb9417f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa2c98686e09ac7702a4b80e7cb9417f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa2c98686e09ac7702a4b80e7cb9417f = L.map(
#                 &quot;map_fa2c98686e09ac7702a4b80e7cb9417f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f7dcf35d793c6aca52be7cb32a6e5c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f7dcf35d793c6aca52be7cb32a6e5c6.addTo(map_fa2c98686e09ac7702a4b80e7cb9417f);
#
#
#             var marker_1669142b01b702a1b806218529f60af4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fa2c98686e09ac7702a4b80e7cb9417f);
#
#
#         var popup_068bae5dca244aaa468b921639c676cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_979308df11eda8486c9a6dd16cbc8e1a = $(`&lt;div id=&quot;html_979308df11eda8486c9a6dd16cbc8e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_068bae5dca244aaa468b921639c676cc.setContent(html_979308df11eda8486c9a6dd16cbc8e1a);
#
#
#
#         marker_1669142b01b702a1b806218529f60af4.bindPopup(popup_068bae5dca244aaa468b921639c676cc)
#         ;
#
#
#
#
#             var marker_17d02651b70636984cdc835bb616f5bd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fa2c98686e09ac7702a4b80e7cb9417f);
#
#
#         var popup_a081c9f40bb2a42f21ce49ecf3f9164e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22398cd10feca7d96cde8fd5adca9dd9 = $(`&lt;div id=&quot;html_22398cd10feca7d96cde8fd5adca9dd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a081c9f40bb2a42f21ce49ecf3f9164e.setContent(html_22398cd10feca7d96cde8fd5adca9dd9);
#
#
#
#         marker_17d02651b70636984cdc835bb616f5bd.bindPopup(popup_a081c9f40bb2a42f21ce49ecf3f9164e)
#         ;
#
#
#
#
#             var marker_80aaf199e596542506f9994d8278012d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fa2c98686e09ac7702a4b80e7cb9417f);
#
#
#         var popup_85d2d354e6579fad1dae51553be65eec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0764d7e688cbba9eb0af1b8deca3ca72 = $(`&lt;div id=&quot;html_0764d7e688cbba9eb0af1b8deca3ca72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_85d2d354e6579fad1dae51553be65eec.setContent(html_0764d7e688cbba9eb0af1b8deca3ca72);
#
#
#
#         marker_80aaf199e596542506f9994d8278012d.bindPopup(popup_85d2d354e6579fad1dae51553be65eec)
#         ;
#
#
#
#
#             var marker_141c082dbd9dcc58857327654b4e95b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fa2c98686e09ac7702a4b80e7cb9417f);
#
#
#         var popup_0e09c660a513c98c832993931b478996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e93ead6460f5f0f7474412a96f26181d = $(`&lt;div id=&quot;html_e93ead6460f5f0f7474412a96f26181d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0e09c660a513c98c832993931b478996.setContent(html_e93ead6460f5f0f7474412a96f26181d);
#
#
#
#         marker_141c082dbd9dcc58857327654b4e95b3.bindPopup(popup_0e09c660a513c98c832993931b478996)
#         ;
#
#
#
#
#             var marker_08f0af4832cb1f5bc973e7e768cb72b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fa2c98686e09ac7702a4b80e7cb9417f);
#
#
#         var popup_ec9c3bd3c362ede8e9c6476ca9c75fd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67a56b6302cc05c25d5aa03d9d007efd = $(`&lt;div id=&quot;html_67a56b6302cc05c25d5aa03d9d007efd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ec9c3bd3c362ede8e9c6476ca9c75f

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11449cacedf8bd6af56f7c963904d25a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11449cacedf8bd6af56f7c963904d25a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11449cacedf8bd6af56f7c963904d25a = L.map(
#                 &quot;map_11449cacedf8bd6af56f7c963904d25a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_216fe9d0a5017a78183ae1fd98bbcb7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_216fe9d0a5017a78183ae1fd98bbcb7c.addTo(map_11449cacedf8bd6af56f7c963904d25a);
#
#
#             var feature_group_5af4ad7ca29faee30b0d51d2581de416 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6de5b33b989a074b475a586e017bca12 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5af4ad7ca29faee30b0d51d2581de416);
#
#
#         var popup_9cfb38ffc6506634283e1a7ae02324b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_659f805042064b022a14c75b9386c9ff = $(`&lt;div id=&quot;html_659f805042064b022a14c75b9386c9ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9cfb38ffc6506634283e1a7ae02324b2.setContent(html_659f805042064b022a14c75b9386c9ff);
#
#
#
#         marker_6de5b33b989a074b475a586e017bca12.bindPopup(popup_9cfb38ffc6506634283e1a7ae02324b2)
#         ;
#
#
#
#
#             var marker_4423815aa012a436ff8a88ffbc9af816 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5af4ad7ca29faee30b0d51d2581de416);
#
#
#         var popup_43be1d8d74928de43b2f6238bbc9aa5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dc747dc7fb1058f75c9e1c7edd8ab62 = $(`&lt;div id=&quot;html_8dc747dc7fb1058f75c9e1c7edd8ab62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_43be1d8d74928de43b2f6238bbc9aa5b.setContent(html_8dc747dc7fb1058f75c9e1c7edd8ab62);
#
#
#
#         marker_4423815aa012a436ff8a88ffbc9af816.bindPopup(popup_43be1d8d74928de43b2f6238bbc9aa5b)
#         ;
#
#
#
#
#             var marker_8ea7e5a2ce590a1ddf983ccdc050565c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5af4ad7ca29faee30b0d51d2581de416);
#
#
#         var popup_c01b51c4509fb404c6e59f2e2d709c22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de3921a5613d6dc1e1b330cd480789b4 = $(`&lt;div id=&quot;html_de3921a5613d6dc1e1b330cd480789b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c01b51c4509fb404c6e59f2e2d709c22.setContent(html_de3921a5613d6dc1e1b330cd480789b4);
#
#
#
#         marker_8ea7e5a2ce590a1ddf983ccdc050565c.bindPopup(popup_c01b51c4509fb404c6e59f2e2d709c22)
#         ;
#
#
#
#
#             var marker_5936dab5ff946b9673554cbf392da95c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5af4ad7ca29faee30b0d51d2581de416);
#
#
#         var popup_faa64e410dc8d6b81a6100e93d7ef32e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1604d1340a1a609955cb49e5d668604 = $(`&lt;div id=&quot;html_b1604d1340a1a609955cb49e5d668604&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_faa64e410dc8d6b81a6100e93d7ef32e.setContent(html_b1604d1340a1a609955cb49e5d668604);
#
#
#
#         marker_5936dab5ff946b9673554cbf392da95c.bindPopup(popup_faa64e410dc8d6b81a6100e93d7ef32e)
#         ;
#
#
#
#
#             var marker_9fb4bce85be303866c645f88f756c173 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5af4ad7ca29faee30b0d51d2581de416);
#
#
#         var popup_713b6fbfdc9caae312cfd0c9bc3e4ce1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fd66c40cbd90d8f21012ddae88e2b71 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fd66c40cbd90d8f21012ddae88e2b71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fd66c40cbd90d8f21012ddae88e2b71 = L.map(
#                 &quot;map_9fd66c40cbd90d8f21012ddae88e2b71&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fac261f4c43b141346c60ced83aac778 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fac261f4c43b141346c60ced83aac778.addTo(map_9fd66c40cbd90d8f21012ddae88e2b71);
#
#
#             var feature_group_8f42926212ea3e9040b64becbd5040be = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8f42926212ea3e9040b64becbd5040be.addTo(map_9fd66c40cbd90d8f21012ddae88e2b71);
#
#
#             var feature_group_sub_group_10c0278c0e2e335ee089e0bb5912554c = L.featureGroup.subGroup(
#                 feature_group_8f42926212ea3e9040b64becbd5040be
#             );
#
#
#             var marker_b168166e4ea6f9fb9646c433460f62fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_10c0278c0e2e335ee089e0bb5912554c);
#
#
#         var popup_30462e78fec1c35fa48b68fbb21ccf70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02071c9cb40c5e06413769d41cf9e25c = $(`&lt;div id=&quot;html_02071c9cb40c5e06413769d41cf9e25c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_30462e78fec1c35fa48b68fbb21ccf70.setContent(html_02071c9cb40c5e06413769d41cf9e25c);
#
#
#
#         marker_b168166e4ea6f9fb9646c433460f62fa.bindPopup(popup_30462e78fec1c35fa48b68fbb21ccf70)
#         ;
#
#
#
#
#             var marker_fa7ff75574453ea04e1f1c10c00e2cca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_10c0278c0e2e335ee089e0bb5912554c);
#
#
#         var popup_f2c0a243cc4ce5933e5d800ee8578d94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70c89ded005aa2095341bd331d75d827 = $(`&lt;div id=&quot;html_70c89ded005aa2095341bd331d75d827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2c0a243cc4ce5933e5d800ee8578d94.setContent(html_70c89ded005aa2095341bd331d75d827);
#
#
#
#         marker_fa7ff75574453ea04e1f1c10c00e2cca.bindPopup(popup_f2c0a243cc4ce5933e5d800ee8578d94)
#         ;
#
#
#
#
#             var marker_01cc5de938a0cd2e57ae5f1892bd9249 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_10c0278c0e2e335ee089e0bb5912554c);
#
#
#         var popup_07dddec7e9d790d51af5a2a206cb7c5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18d2814c9d572b11ff199d0d218ca7b8 = $(`&lt;div id=&quot;html_18d2814c9d572b11ff199d0d218ca7b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_07dddec7e9d790d51af5a2a206cb7c5c.setContent(html_18d2814c9d572b11ff199d0d218ca7b8);
#
#
#
#         marker_01cc5de938a0cd2e57ae5f1892bd9249.bindPopup(popup_07dddec7e9d790d51af5a2a206cb7c5c)
#         ;
#
#
#
#
#             var marker_3064e30b74fe661608e1c15918999446 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_10c0278c0e2e335ee089e0bb5912554c);
#
#
#         var popup_b14e1b1764d27c11793d15f0e778317c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3eaab40f36e9d19b866c2aa1111d682 = $(`&lt;div id=&quot;html_b3eaab40f36e9d19b866c2aa1111d682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b14e1b1764d27c11793d15f0e778317c.setContent(html_b3eaab40f36e9d19b866c2aa1111d682);
#
#
#
#         mark
