# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6eda74f486c56ea1f6482729678e4a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6eda74f486c56ea1f6482729678e4a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6eda74f486c56ea1f6482729678e4a3 = L.map(
#                 &quot;map_a6eda74f486c56ea1f6482729678e4a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_773b72036e3fb262247ac92ae96434f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_773b72036e3fb262247ac92ae96434f1.addTo(map_a6eda74f486c56ea1f6482729678e4a3);
#
#
#             var marker_b4ffd966bcee59f25a98b778f62a008a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a6eda74f486c56ea1f6482729678e4a3);
#
#
#         var popup_1abcfc95d045b3f75fc72aea167a142c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_264dd79701e7c5f2d57794d03804b4b5 = $(`&lt;div id=&quot;html_264dd79701e7c5f2d57794d03804b4b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1abcfc95d045b3f75fc72aea167a142c.setContent(html_264dd79701e7c5f2d57794d03804b4b5);
#
#
#
#         marker_b4ffd966bcee59f25a98b778f62a008a.bindPopup(popup_1abcfc95d045b3f75fc72aea167a142c)
#         ;
#
#
#
#
#             var marker_59fa23229204711a359c012f3a9df749 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a6eda74f486c56ea1f6482729678e4a3);
#
#
#         var popup_803771a4d6c796d63e8fc034297a0fe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d21b9a0d3d8d0034a931d5915ac2b52d = $(`&lt;div id=&quot;html_d21b9a0d3d8d0034a931d5915ac2b52d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_803771a4d6c796d63e8fc034297a0fe1.setContent(html_d21b9a0d3d8d0034a931d5915ac2b52d);
#
#
#
#         marker_59fa23229204711a359c012f3a9df749.bindPopup(popup_803771a4d6c796d63e8fc034297a0fe1)
#         ;
#
#
#
#
#             var marker_a108e4f60c5c6f181af4a662689e6e0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a6eda74f486c56ea1f6482729678e4a3);
#
#
#         var popup_179460f2c3efdb2fd0ccfcb18cf9c7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b198b198b72e8234c3eda1ca6e12d32e = $(`&lt;div id=&quot;html_b198b198b72e8234c3eda1ca6e12d32e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_179460f2c3efdb2fd0ccfcb18cf9c7fb.setContent(html_b198b198b72e8234c3eda1ca6e12d32e);
#
#
#
#         marker_a108e4f60c5c6f181af4a662689e6e0a.bindPopup(popup_179460f2c3efdb2fd0ccfcb18cf9c7fb)
#         ;
#
#
#
#
#             var marker_f313ae6af8c8bfe0ec88f41b00e86d8f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a6eda74f486c56ea1f6482729678e4a3);
#
#
#         var popup_d3dd28329479a729fd4a31b6a507ea2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f49d1bc22772b4f2feb89f8330f1096 = $(`&lt;div id=&quot;html_1f49d1bc22772b4f2feb89f8330f1096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d3dd28329479a729fd4a31b6a507ea2b.setContent(html_1f49d1bc22772b4f2feb89f8330f1096);
#
#
#
#         marker_f313ae6af8c8bfe0ec88f41b00e86d8f.bindPopup(popup_d3dd28329479a729fd4a31b6a507ea2b)
#         ;
#
#
#
#
#             var marker_a966b8eec93fd439838874d7a9700f16 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a6eda74f486c56ea1f6482729678e4a3);
#
#
#         var popup_d55eeebbdcdbf164c1ce77564ae46e6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ed5358e658ac067ad20341de9aef30 = $(`&lt;div id=&quot;html_38ed5358e658ac067ad20341de9aef30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d55eeebbdcdbf164c1ce77564ae46e6a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2421c2ef0ecb9d5f1b68ce3f3fde3409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2421c2ef0ecb9d5f1b68ce3f3fde3409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2421c2ef0ecb9d5f1b68ce3f3fde3409 = L.map(
#                 &quot;map_2421c2ef0ecb9d5f1b68ce3f3fde3409&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6e2e91c536d456f29d7b26c2922b5ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6e2e91c536d456f29d7b26c2922b5ef.addTo(map_2421c2ef0ecb9d5f1b68ce3f3fde3409);
#
#
#             var feature_group_c165922a97fbd9f81b736e82a14f77cb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dbdc02ffa4450acbfab31ace59299a6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c165922a97fbd9f81b736e82a14f77cb);
#
#
#         var popup_8498a82faebce3566599f0311a308802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d5346bcc1c6a7ea63326e84fa79654a = $(`&lt;div id=&quot;html_4d5346bcc1c6a7ea63326e84fa79654a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8498a82faebce3566599f0311a308802.setContent(html_4d5346bcc1c6a7ea63326e84fa79654a);
#
#
#
#         marker_dbdc02ffa4450acbfab31ace59299a6a.bindPopup(popup_8498a82faebce3566599f0311a308802)
#         ;
#
#
#
#
#             var marker_9f12e20776cf94e8b0d9735373ea1414 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c165922a97fbd9f81b736e82a14f77cb);
#
#
#         var popup_a7fcc53cad40713acedd182083a1cb86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f00c0f0c97a0fd44a8ade0bb885883da = $(`&lt;div id=&quot;html_f00c0f0c97a0fd44a8ade0bb885883da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a7fcc53cad40713acedd182083a1cb86.setContent(html_f00c0f0c97a0fd44a8ade0bb885883da);
#
#
#
#         marker_9f12e20776cf94e8b0d9735373ea1414.bindPopup(popup_a7fcc53cad40713acedd182083a1cb86)
#         ;
#
#
#
#
#             var marker_5edd28fa1f576977fdf38f50d3dec7c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c165922a97fbd9f81b736e82a14f77cb);
#
#
#         var popup_af63170b6e61ed4be4bc42c59584fe5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69360a67396cb03442c7e4a980e8727a = $(`&lt;div id=&quot;html_69360a67396cb03442c7e4a980e8727a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_af63170b6e61ed4be4bc42c59584fe5e.setContent(html_69360a67396cb03442c7e4a980e8727a);
#
#
#
#         marker_5edd28fa1f576977fdf38f50d3dec7c3.bindPopup(popup_af63170b6e61ed4be4bc42c59584fe5e)
#         ;
#
#
#
#
#             var marker_843a813144730aa258382bfaa09eac5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c165922a97fbd9f81b736e82a14f77cb);
#
#
#         var popup_a7b0918d01eaed442eb30bd021ce2afc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d235e878c0742bd80c2e3ea92b1e035 = $(`&lt;div id=&quot;html_6d235e878c0742bd80c2e3ea92b1e035&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a7b0918d01eaed442eb30bd021ce2afc.setContent(html_6d235e878c0742bd80c2e3ea92b1e035);
#
#
#
#         marker_843a813144730aa258382bfaa09eac5b.bindPopup(popup_a7b0918d01eaed442eb30bd021ce2afc)
#         ;
#
#
#
#
#             var marker_4911b1207aacc5025140a35582366944 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c165922a97fbd9f81b736e82a14f77cb);
#
#
#         var popup_b70539ac33670697a7c03b1a473f28ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd5bf2a406b5b970a12171b5f36dc967 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd5bf2a406b5b970a12171b5f36dc967&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd5bf2a406b5b970a12171b5f36dc967 = L.map(
#                 &quot;map_bd5bf2a406b5b970a12171b5f36dc967&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e46ce031dfec81317423eaf58b360809 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e46ce031dfec81317423eaf58b360809.addTo(map_bd5bf2a406b5b970a12171b5f36dc967);
#
#
#             var feature_group_b0f2360682849bc499b5b35e1c21743e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b0f2360682849bc499b5b35e1c21743e.addTo(map_bd5bf2a406b5b970a12171b5f36dc967);
#
#
#             var feature_group_sub_group_ea88bc999dfe5a74794da02428cc2c9e = L.featureGroup.subGroup(
#                 feature_group_b0f2360682849bc499b5b35e1c21743e
#             );
#
#
#             var marker_3d8cfcc5b506ff0123ef01b1d5428bd6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea88bc999dfe5a74794da02428cc2c9e);
#
#
#         var popup_7a6a2878c4bc76a73cb9e2101d6a00d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e93476f8873f98b830ea3730f9f7a684 = $(`&lt;div id=&quot;html_e93476f8873f98b830ea3730f9f7a684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7a6a2878c4bc76a73cb9e2101d6a00d5.setContent(html_e93476f8873f98b830ea3730f9f7a684);
#
#
#
#         marker_3d8cfcc5b506ff0123ef01b1d5428bd6.bindPopup(popup_7a6a2878c4bc76a73cb9e2101d6a00d5)
#         ;
#
#
#
#
#             var marker_2170f77123aa7ef5af8952aef626d6f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea88bc999dfe5a74794da02428cc2c9e);
#
#
#         var popup_580b18e8d0a6c4960b4b3b1a39efcf3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecaff48e1163defadfd1256436ab46ed = $(`&lt;div id=&quot;html_ecaff48e1163defadfd1256436ab46ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_580b18e8d0a6c4960b4b3b1a39efcf3a.setContent(html_ecaff48e1163defadfd1256436ab46ed);
#
#
#
#         marker_2170f77123aa7ef5af8952aef626d6f5.bindPopup(popup_580b18e8d0a6c4960b4b3b1a39efcf3a)
#         ;
#
#
#
#
#             var marker_a3c817b7a001b850ec7a42ef6ccb80de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea88bc999dfe5a74794da02428cc2c9e);
#
#
#         var popup_632b6cc8b9547c9040b2506e2bdf2dbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7729d4c5e9710c137561759abb387c30 = $(`&lt;div id=&quot;html_7729d4c5e9710c137561759abb387c30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_632b6cc8b9547c9040b2506e2bdf2dbc.setContent(html_7729d4c5e9710c137561759abb387c30);
#
#
#
#         marker_a3c817b7a001b850ec7a42ef6ccb80de.bindPopup(popup_632b6cc8b9547c9040b2506e2bdf2dbc)
#         ;
#
#
#
#
#             var marker_64845ccaa885df3b8902e3b2ed8e0166 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea88bc999dfe5a74794da02428cc2c9e);
#
#
#         var popup_adfd07261649d31401f2553dd4c04f44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27200792a189ae59f49bf5d828f516df = $(`&lt;div id=&quot;html_27200792a189ae59f49bf5d828f516df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_adfd07261649d31401f2553dd4c04f44.setContent(html_27200792a189ae59f49bf5d828f516df);
#
#
#
#         marker_
