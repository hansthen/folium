# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11f77910f7ad0fd7f7eb9060a718b39b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11f77910f7ad0fd7f7eb9060a718b39b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11f77910f7ad0fd7f7eb9060a718b39b = L.map(
#                 &quot;map_11f77910f7ad0fd7f7eb9060a718b39b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0ad5766294ad5b937e64edc4aa6e987 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0ad5766294ad5b937e64edc4aa6e987.addTo(map_11f77910f7ad0fd7f7eb9060a718b39b);
#
#
#             var marker_c05294d907a466c6d7dd6ab8a7895fe2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_11f77910f7ad0fd7f7eb9060a718b39b);
#
#
#         var popup_719dd545ddde0de6eaed66727689d9f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64931bf81776cacbef0eead8df7378a1 = $(`&lt;div id=&quot;html_64931bf81776cacbef0eead8df7378a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_719dd545ddde0de6eaed66727689d9f2.setContent(html_64931bf81776cacbef0eead8df7378a1);
#
#
#
#         marker_c05294d907a466c6d7dd6ab8a7895fe2.bindPopup(popup_719dd545ddde0de6eaed66727689d9f2)
#         ;
#
#
#
#
#             var marker_96f8960aa02a7191cc8ca613a31416a2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_11f77910f7ad0fd7f7eb9060a718b39b);
#
#
#         var popup_1e2b82a2046987453512518aa1951b06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3608351bb4e020debcbaf89c1cb5088e = $(`&lt;div id=&quot;html_3608351bb4e020debcbaf89c1cb5088e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1e2b82a2046987453512518aa1951b06.setContent(html_3608351bb4e020debcbaf89c1cb5088e);
#
#
#
#         marker_96f8960aa02a7191cc8ca613a31416a2.bindPopup(popup_1e2b82a2046987453512518aa1951b06)
#         ;
#
#
#
#
#             var marker_65d0fe34678768f606261592bdf76807 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_11f77910f7ad0fd7f7eb9060a718b39b);
#
#
#         var popup_ef841199e70c0110b9f777ee082e4e62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bca8da87e94eea981e411e3a893c0827 = $(`&lt;div id=&quot;html_bca8da87e94eea981e411e3a893c0827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ef841199e70c0110b9f777ee082e4e62.setContent(html_bca8da87e94eea981e411e3a893c0827);
#
#
#
#         marker_65d0fe34678768f606261592bdf76807.bindPopup(popup_ef841199e70c0110b9f777ee082e4e62)
#         ;
#
#
#
#
#             var marker_f063b19031ee12e762e4bcfa642a07cb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_11f77910f7ad0fd7f7eb9060a718b39b);
#
#
#         var popup_4e236b9e93dfd8355cb836a44daa0fd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d47672526bd1fe9122c86ca921fcaca = $(`&lt;div id=&quot;html_6d47672526bd1fe9122c86ca921fcaca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4e236b9e93dfd8355cb836a44daa0fd4.setContent(html_6d47672526bd1fe9122c86ca921fcaca);
#
#
#
#         marker_f063b19031ee12e762e4bcfa642a07cb.bindPopup(popup_4e236b9e93dfd8355cb836a44daa0fd4)
#         ;
#
#
#
#
#             var marker_f0fdab2ba98e4931cd311165c22b00be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_11f77910f7ad0fd7f7eb9060a718b39b);
#
#
#         var popup_e31e541a7e121344c50d0ef85b79e2d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c54089b8d40adcaa12b3e54026a7ac32 = $(`&lt;div id=&quot;html_c54089b8d40adcaa12b3e54026a7ac32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e31e541a7e121344c50d0ef85b79e2d9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baa0fed8e4fc7d8bb32633d162c17379 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baa0fed8e4fc7d8bb32633d162c17379&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_baa0fed8e4fc7d8bb32633d162c17379 = L.map(
#                 &quot;map_baa0fed8e4fc7d8bb32633d162c17379&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f27bcada322727e559904e09d47a583 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f27bcada322727e559904e09d47a583.addTo(map_baa0fed8e4fc7d8bb32633d162c17379);
#
#
#             var feature_group_6d126bef2424ea7cbe1cf21aa88747c7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5d0a4fe7b1a19165df861acd9dbe93ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6d126bef2424ea7cbe1cf21aa88747c7);
#
#
#         var popup_82e79257673a717c555f57b213b7ebc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29594300aaa2fe19c0e7894b358bc9eb = $(`&lt;div id=&quot;html_29594300aaa2fe19c0e7894b358bc9eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_82e79257673a717c555f57b213b7ebc6.setContent(html_29594300aaa2fe19c0e7894b358bc9eb);
#
#
#
#         marker_5d0a4fe7b1a19165df861acd9dbe93ff.bindPopup(popup_82e79257673a717c555f57b213b7ebc6)
#         ;
#
#
#
#
#             var marker_6a562b420952700d10219535c3fd99f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6d126bef2424ea7cbe1cf21aa88747c7);
#
#
#         var popup_0fedfd654b0424bf33b8b8c54f7f8aae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bf3716dc3f3f2d6030e06ba04b7ce95 = $(`&lt;div id=&quot;html_4bf3716dc3f3f2d6030e06ba04b7ce95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0fedfd654b0424bf33b8b8c54f7f8aae.setContent(html_4bf3716dc3f3f2d6030e06ba04b7ce95);
#
#
#
#         marker_6a562b420952700d10219535c3fd99f7.bindPopup(popup_0fedfd654b0424bf33b8b8c54f7f8aae)
#         ;
#
#
#
#
#             var marker_b613ecbde98660b87a3bbbabf0ed3e6d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6d126bef2424ea7cbe1cf21aa88747c7);
#
#
#         var popup_c8e7c1e1999453ac089cc80a38f16b34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6a2cbe2ce040eea02fca7b218abb3bc = $(`&lt;div id=&quot;html_c6a2cbe2ce040eea02fca7b218abb3bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c8e7c1e1999453ac089cc80a38f16b34.setContent(html_c6a2cbe2ce040eea02fca7b218abb3bc);
#
#
#
#         marker_b613ecbde98660b87a3bbbabf0ed3e6d.bindPopup(popup_c8e7c1e1999453ac089cc80a38f16b34)
#         ;
#
#
#
#
#             var marker_b1ab5c1462c1c45f63fb9a605acf887b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6d126bef2424ea7cbe1cf21aa88747c7);
#
#
#         var popup_987298d66c50079225f95dd9f2c74246 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96b0e3a0ff4a2a2d1c3736c8a480f37d = $(`&lt;div id=&quot;html_96b0e3a0ff4a2a2d1c3736c8a480f37d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_987298d66c50079225f95dd9f2c74246.setContent(html_96b0e3a0ff4a2a2d1c3736c8a480f37d);
#
#
#
#         marker_b1ab5c1462c1c45f63fb9a605acf887b.bindPopup(popup_987298d66c50079225f95dd9f2c74246)
#         ;
#
#
#
#
#             var marker_3b317efba7956974fb5a6d3c7da8e877 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6d126bef2424ea7cbe1cf21aa88747c7);
#
#
#         var popup_a82b275d4628f69592289a3c5c67dc35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24a9ea582deabb253482e52cf91f6d00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24a9ea582deabb253482e52cf91f6d00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24a9ea582deabb253482e52cf91f6d00 = L.map(
#                 &quot;map_24a9ea582deabb253482e52cf91f6d00&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53816de082e0f1d35ba56f10e06e48de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53816de082e0f1d35ba56f10e06e48de.addTo(map_24a9ea582deabb253482e52cf91f6d00);
#
#
#             var feature_group_2debc0169d851434e3efab39f64f71a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2debc0169d851434e3efab39f64f71a3.addTo(map_24a9ea582deabb253482e52cf91f6d00);
#
#
#             var feature_group_sub_group_5efbe5d8a101a8eac4fc2f405c1afedf = L.featureGroup.subGroup(
#                 feature_group_2debc0169d851434e3efab39f64f71a3
#             );
#
#
#             var marker_54f3c93713e4ed481efd19e786551d27 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5efbe5d8a101a8eac4fc2f405c1afedf);
#
#
#         var popup_4da233e148e4f5a0a6d07090d50a3f90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b190bf5fb24ac030f9d83b90df60ca91 = $(`&lt;div id=&quot;html_b190bf5fb24ac030f9d83b90df60ca91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4da233e148e4f5a0a6d07090d50a3f90.setContent(html_b190bf5fb24ac030f9d83b90df60ca91);
#
#
#
#         marker_54f3c93713e4ed481efd19e786551d27.bindPopup(popup_4da233e148e4f5a0a6d07090d50a3f90)
#         ;
#
#
#
#
#             var marker_0e82abb7d50b9e17bce41646f0982b42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5efbe5d8a101a8eac4fc2f405c1afedf);
#
#
#         var popup_e0f4e985ddd275d91d623b1bf9f2b279 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40752de0708558b05ec38f29a5c813fc = $(`&lt;div id=&quot;html_40752de0708558b05ec38f29a5c813fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0f4e985ddd275d91d623b1bf9f2b279.setContent(html_40752de0708558b05ec38f29a5c813fc);
#
#
#
#         marker_0e82abb7d50b9e17bce41646f0982b42.bindPopup(popup_e0f4e985ddd275d91d623b1bf9f2b279)
#         ;
#
#
#
#
#             var marker_656a9fd6c4de2d67a7f2c684489837dd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5efbe5d8a101a8eac4fc2f405c1afedf);
#
#
#         var popup_7528d01949bcf5d98709b443440f24d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3de3ced541e9905677bfb6a72d84a883 = $(`&lt;div id=&quot;html_3de3ced541e9905677bfb6a72d84a883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7528d01949bcf5d98709b443440f24d4.setContent(html_3de3ced541e9905677bfb6a72d84a883);
#
#
#
#         marker_656a9fd6c4de2d67a7f2c684489837dd.bindPopup(popup_7528d01949bcf5d98709b443440f24d4)
#         ;
#
#
#
#
#             var marker_8ea2ce7ef151dc66ccc31c53c4478f69 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5efbe5d8a101a8eac4fc2f405c1afedf);
#
#
#         var popup_95f0f36e359ada798a949d67affe3e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d52eae85d8da28cb891a8bbc769c85c = $(`&lt;div id=&quot;html_3d52eae85d8da28cb891a8bbc769c85c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_95f0f36e359ada798a949d67affe3e7b.setContent(html_3d52eae85d8da28cb891a8bbc769c85c);
#
#
#
#         marker_
