# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1536b03bd349d889cfbb0a54ae7a1553 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1536b03bd349d889cfbb0a54ae7a1553&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1536b03bd349d889cfbb0a54ae7a1553 = L.map(
#                 &quot;map_1536b03bd349d889cfbb0a54ae7a1553&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d840207e9e6f34465e0e2562f7514ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d840207e9e6f34465e0e2562f7514ab.addTo(map_1536b03bd349d889cfbb0a54ae7a1553);
#
#
#             var marker_38f145d257b7e01a5943c89553d6507f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1536b03bd349d889cfbb0a54ae7a1553);
#
#
#         var popup_ef731007c4e9ca4b2290b4ca853ea788 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e47133c9ae2a5ba8f39c4c4de0e3c54e = $(`&lt;div id=&quot;html_e47133c9ae2a5ba8f39c4c4de0e3c54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ef731007c4e9ca4b2290b4ca853ea788.setContent(html_e47133c9ae2a5ba8f39c4c4de0e3c54e);
#
#
#
#         marker_38f145d257b7e01a5943c89553d6507f.bindPopup(popup_ef731007c4e9ca4b2290b4ca853ea788)
#         ;
#
#
#
#
#             var marker_f91d3badca9904c9b8b8a2289752fc75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1536b03bd349d889cfbb0a54ae7a1553);
#
#
#         var popup_664490c752e2c5a1e52643c93806384a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_289155af2255d2c2d9c934f6e0a7ac05 = $(`&lt;div id=&quot;html_289155af2255d2c2d9c934f6e0a7ac05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_664490c752e2c5a1e52643c93806384a.setContent(html_289155af2255d2c2d9c934f6e0a7ac05);
#
#
#
#         marker_f91d3badca9904c9b8b8a2289752fc75.bindPopup(popup_664490c752e2c5a1e52643c93806384a)
#         ;
#
#
#
#
#             var marker_6c1b2d44accf760d6b80b77cf5ecb698 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1536b03bd349d889cfbb0a54ae7a1553);
#
#
#         var popup_b31c41986e1f938c3835436573de38fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a39f45961023cd9edbf2faf63504b8d1 = $(`&lt;div id=&quot;html_a39f45961023cd9edbf2faf63504b8d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b31c41986e1f938c3835436573de38fd.setContent(html_a39f45961023cd9edbf2faf63504b8d1);
#
#
#
#         marker_6c1b2d44accf760d6b80b77cf5ecb698.bindPopup(popup_b31c41986e1f938c3835436573de38fd)
#         ;
#
#
#
#
#             var marker_6430ea97bb28d74028ce91abdd424d45 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1536b03bd349d889cfbb0a54ae7a1553);
#
#
#         var popup_b046b12ab79e3a85ebddd40c122bd94e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e6031c8106a0aea838866aae8fba609 = $(`&lt;div id=&quot;html_1e6031c8106a0aea838866aae8fba609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b046b12ab79e3a85ebddd40c122bd94e.setContent(html_1e6031c8106a0aea838866aae8fba609);
#
#
#
#         marker_6430ea97bb28d74028ce91abdd424d45.bindPopup(popup_b046b12ab79e3a85ebddd40c122bd94e)
#         ;
#
#
#
#
#             var marker_ec31f025483fc6d2f29fc781ab64e3aa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1536b03bd349d889cfbb0a54ae7a1553);
#
#
#         var popup_cd42b625adf7a31b088a86069e9b8a82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0d518d8db281da310fdfcd3edb6a52e = $(`&lt;div id=&quot;html_f0d518d8db281da310fdfcd3edb6a52e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cd42b625adf7a31b088a86069e9b8a82.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9934e4c6f1562cf0d263fe88a82fc2bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9934e4c6f1562cf0d263fe88a82fc2bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9934e4c6f1562cf0d263fe88a82fc2bc = L.map(
#                 &quot;map_9934e4c6f1562cf0d263fe88a82fc2bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acda0ba7c62f2d239013bca82c6e3948 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acda0ba7c62f2d239013bca82c6e3948.addTo(map_9934e4c6f1562cf0d263fe88a82fc2bc);
#
#
#             var feature_group_4cafb095238fb0f2fb7d5a84655ead7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_185596e0e7091cdac53f8bea698d6012 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4cafb095238fb0f2fb7d5a84655ead7b);
#
#
#         var popup_d529e7cd7f4a787fb6183b07ac7a4681 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac233f8c2f3c2dfd55e7b0e5871b3226 = $(`&lt;div id=&quot;html_ac233f8c2f3c2dfd55e7b0e5871b3226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d529e7cd7f4a787fb6183b07ac7a4681.setContent(html_ac233f8c2f3c2dfd55e7b0e5871b3226);
#
#
#
#         marker_185596e0e7091cdac53f8bea698d6012.bindPopup(popup_d529e7cd7f4a787fb6183b07ac7a4681)
#         ;
#
#
#
#
#             var marker_56916c04975f38c028f099e9c0123e63 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4cafb095238fb0f2fb7d5a84655ead7b);
#
#
#         var popup_ef90bb6199e58125dc963152e1f5a618 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd1887f41c16d710efdf1d0a0343a4bf = $(`&lt;div id=&quot;html_bd1887f41c16d710efdf1d0a0343a4bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ef90bb6199e58125dc963152e1f5a618.setContent(html_bd1887f41c16d710efdf1d0a0343a4bf);
#
#
#
#         marker_56916c04975f38c028f099e9c0123e63.bindPopup(popup_ef90bb6199e58125dc963152e1f5a618)
#         ;
#
#
#
#
#             var marker_5689ca29ec7c22f646a67d73022c89db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4cafb095238fb0f2fb7d5a84655ead7b);
#
#
#         var popup_a9367845c3bfcc6710c02ca249ebfb79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9bd68ad8ba0645faa2119dc9ca5fd76 = $(`&lt;div id=&quot;html_f9bd68ad8ba0645faa2119dc9ca5fd76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a9367845c3bfcc6710c02ca249ebfb79.setContent(html_f9bd68ad8ba0645faa2119dc9ca5fd76);
#
#
#
#         marker_5689ca29ec7c22f646a67d73022c89db.bindPopup(popup_a9367845c3bfcc6710c02ca249ebfb79)
#         ;
#
#
#
#
#             var marker_04fef59d94f46e7ffe41b1ec011fa991 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4cafb095238fb0f2fb7d5a84655ead7b);
#
#
#         var popup_05bf92f356b46b309f0d34e4599a38f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6df7aa2998e4afec8271d8b0b048d042 = $(`&lt;div id=&quot;html_6df7aa2998e4afec8271d8b0b048d042&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_05bf92f356b46b309f0d34e4599a38f9.setContent(html_6df7aa2998e4afec8271d8b0b048d042);
#
#
#
#         marker_04fef59d94f46e7ffe41b1ec011fa991.bindPopup(popup_05bf92f356b46b309f0d34e4599a38f9)
#         ;
#
#
#
#
#             var marker_95352490085e170472286450a48aa77b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4cafb095238fb0f2fb7d5a84655ead7b);
#
#
#         var popup_eabbf00ecb7e13c80a5ecb40fc2353c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_765a4b15f348be00513171b2160fee69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_765a4b15f348be00513171b2160fee69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_765a4b15f348be00513171b2160fee69 = L.map(
#                 &quot;map_765a4b15f348be00513171b2160fee69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f08ed1f17de3f2229356185a42eb162a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f08ed1f17de3f2229356185a42eb162a.addTo(map_765a4b15f348be00513171b2160fee69);
#
#
#             var feature_group_d4d59a6efb306f072defbb6a0789dbbe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d4d59a6efb306f072defbb6a0789dbbe.addTo(map_765a4b15f348be00513171b2160fee69);
#
#
#             var feature_group_sub_group_ad53b6e9941abaee39a6d60941b5bda6 = L.featureGroup.subGroup(
#                 feature_group_d4d59a6efb306f072defbb6a0789dbbe
#             );
#
#
#             var marker_8414021e8845d64542b7f72e0e7a5386 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad53b6e9941abaee39a6d60941b5bda6);
#
#
#         var popup_ddffadff26f8c3170e57e6523d771d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_891636cb4074f4a62327e75fa1c1b60a = $(`&lt;div id=&quot;html_891636cb4074f4a62327e75fa1c1b60a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ddffadff26f8c3170e57e6523d771d6a.setContent(html_891636cb4074f4a62327e75fa1c1b60a);
#
#
#
#         marker_8414021e8845d64542b7f72e0e7a5386.bindPopup(popup_ddffadff26f8c3170e57e6523d771d6a)
#         ;
#
#
#
#
#             var marker_10c4c9d54193769cab477b84d29fc93c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad53b6e9941abaee39a6d60941b5bda6);
#
#
#         var popup_e14f737aacd2af1cd319ae925670e632 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a8011e974c5d1f23e7ea6c7c5b7bc38 = $(`&lt;div id=&quot;html_7a8011e974c5d1f23e7ea6c7c5b7bc38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e14f737aacd2af1cd319ae925670e632.setContent(html_7a8011e974c5d1f23e7ea6c7c5b7bc38);
#
#
#
#         marker_10c4c9d54193769cab477b84d29fc93c.bindPopup(popup_e14f737aacd2af1cd319ae925670e632)
#         ;
#
#
#
#
#             var marker_0a1281b5e7035cc68af3b5c5ba376270 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad53b6e9941abaee39a6d60941b5bda6);
#
#
#         var popup_2b031412723fddce93c01085e7a403eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dae878006585c35f8c36a04a7d84db28 = $(`&lt;div id=&quot;html_dae878006585c35f8c36a04a7d84db28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2b031412723fddce93c01085e7a403eb.setContent(html_dae878006585c35f8c36a04a7d84db28);
#
#
#
#         marker_0a1281b5e7035cc68af3b5c5ba376270.bindPopup(popup_2b031412723fddce93c01085e7a403eb)
#         ;
#
#
#
#
#             var marker_1cb1eee87d56bb27e4ff7ed583a1ac3e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad53b6e9941abaee39a6d60941b5bda6);
#
#
#         var popup_f5ef7571130df8843e41cde265a84c49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5852933e640abb1dc4f194dd262525f = $(`&lt;div id=&quot;html_c5852933e640abb1dc4f194dd262525f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f5ef7571130df8843e41cde265a84c49.setContent(html_c5852933e640abb1dc4f194dd262525f);
#
#
#
#         marker_
