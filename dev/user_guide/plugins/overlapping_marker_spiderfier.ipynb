# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7aa38aa13fc16940814ce5f25483d15 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7aa38aa13fc16940814ce5f25483d15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7aa38aa13fc16940814ce5f25483d15 = L.map(
#                 &quot;map_f7aa38aa13fc16940814ce5f25483d15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4117c0c4ddba3f767a2222e97867a0d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4117c0c4ddba3f767a2222e97867a0d3.addTo(map_f7aa38aa13fc16940814ce5f25483d15);
#
#
#             var marker_844eb8b7514a8bbcb7aa311d5af25661 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f7aa38aa13fc16940814ce5f25483d15);
#
#
#         var popup_bba1cfb1cdfb0b5eb7dc5257cdfdd68f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3247be6b3be90ff48d8ae1a55272e30 = $(`&lt;div id=&quot;html_f3247be6b3be90ff48d8ae1a55272e30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bba1cfb1cdfb0b5eb7dc5257cdfdd68f.setContent(html_f3247be6b3be90ff48d8ae1a55272e30);
#
#
#
#         marker_844eb8b7514a8bbcb7aa311d5af25661.bindPopup(popup_bba1cfb1cdfb0b5eb7dc5257cdfdd68f)
#         ;
#
#
#
#
#             var marker_1058dc825e19e83b5dcdb4d2493ad3a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f7aa38aa13fc16940814ce5f25483d15);
#
#
#         var popup_120738e9e327e6d7c07c71689203036f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3701fa65a4a44904fb2d2638b2bf1e9 = $(`&lt;div id=&quot;html_c3701fa65a4a44904fb2d2638b2bf1e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_120738e9e327e6d7c07c71689203036f.setContent(html_c3701fa65a4a44904fb2d2638b2bf1e9);
#
#
#
#         marker_1058dc825e19e83b5dcdb4d2493ad3a4.bindPopup(popup_120738e9e327e6d7c07c71689203036f)
#         ;
#
#
#
#
#             var marker_7ac1eb781acd066b1046500ac94debe2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f7aa38aa13fc16940814ce5f25483d15);
#
#
#         var popup_25f1a9dc0a15a8c078fabfa53e5add62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2266d3437f6bcb8904f8b31f209bc62 = $(`&lt;div id=&quot;html_d2266d3437f6bcb8904f8b31f209bc62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_25f1a9dc0a15a8c078fabfa53e5add62.setContent(html_d2266d3437f6bcb8904f8b31f209bc62);
#
#
#
#         marker_7ac1eb781acd066b1046500ac94debe2.bindPopup(popup_25f1a9dc0a15a8c078fabfa53e5add62)
#         ;
#
#
#
#
#             var marker_a0b8a5a5b93ca437a14a702de7a520bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f7aa38aa13fc16940814ce5f25483d15);
#
#
#         var popup_0e0d5a1f71efb9371eb6db1f6e12d712 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc66e7c076f6d95078f1e734dac05544 = $(`&lt;div id=&quot;html_fc66e7c076f6d95078f1e734dac05544&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0e0d5a1f71efb9371eb6db1f6e12d712.setContent(html_fc66e7c076f6d95078f1e734dac05544);
#
#
#
#         marker_a0b8a5a5b93ca437a14a702de7a520bc.bindPopup(popup_0e0d5a1f71efb9371eb6db1f6e12d712)
#         ;
#
#
#
#
#             var marker_bf095a8faf0f290eeedda9dd2c0786d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f7aa38aa13fc16940814ce5f25483d15);
#
#
#         var popup_f3137d8a539b7f9d4dbec040f9bf39c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6ab806a816d1748ae8af26bd4bcb532 = $(`&lt;div id=&quot;html_f6ab806a816d1748ae8af26bd4bcb532&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f3137d8a539b7f9d4dbec040f9bf39

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77ad361f08de5d7f9b39b3a3d43aa315 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77ad361f08de5d7f9b39b3a3d43aa315&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77ad361f08de5d7f9b39b3a3d43aa315 = L.map(
#                 &quot;map_77ad361f08de5d7f9b39b3a3d43aa315&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cb92b84c4cee32622b9b842b326c16f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cb92b84c4cee32622b9b842b326c16f.addTo(map_77ad361f08de5d7f9b39b3a3d43aa315);
#
#
#             var feature_group_96e06bec770f7cd79306b776f559f527 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d96e2e9fc9609940153ec39f52f44c6a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_96e06bec770f7cd79306b776f559f527);
#
#
#         var popup_3478fc7f040256d32c06ac6fbf8c4129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa6beb1f21fb9957910eb97bb6f46e28 = $(`&lt;div id=&quot;html_fa6beb1f21fb9957910eb97bb6f46e28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3478fc7f040256d32c06ac6fbf8c4129.setContent(html_fa6beb1f21fb9957910eb97bb6f46e28);
#
#
#
#         marker_d96e2e9fc9609940153ec39f52f44c6a.bindPopup(popup_3478fc7f040256d32c06ac6fbf8c4129)
#         ;
#
#
#
#
#             var marker_7509cc7f45ca2eb0cbfb810a7d261de3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_96e06bec770f7cd79306b776f559f527);
#
#
#         var popup_6d6243da99a74411f224979097ff1286 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe31a594e675c49c3197675a9e957ff7 = $(`&lt;div id=&quot;html_fe31a594e675c49c3197675a9e957ff7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6d6243da99a74411f224979097ff1286.setContent(html_fe31a594e675c49c3197675a9e957ff7);
#
#
#
#         marker_7509cc7f45ca2eb0cbfb810a7d261de3.bindPopup(popup_6d6243da99a74411f224979097ff1286)
#         ;
#
#
#
#
#             var marker_009f0a7d55d8956c41e2524b470661c4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_96e06bec770f7cd79306b776f559f527);
#
#
#         var popup_a0d813faa6d55a0a7ffc4cb1fb97bfe1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aeada19af72d67d577fd706eabd51074 = $(`&lt;div id=&quot;html_aeada19af72d67d577fd706eabd51074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a0d813faa6d55a0a7ffc4cb1fb97bfe1.setContent(html_aeada19af72d67d577fd706eabd51074);
#
#
#
#         marker_009f0a7d55d8956c41e2524b470661c4.bindPopup(popup_a0d813faa6d55a0a7ffc4cb1fb97bfe1)
#         ;
#
#
#
#
#             var marker_19c94be0d5800c4a14a62eb0094d70cb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_96e06bec770f7cd79306b776f559f527);
#
#
#         var popup_755a2bc3980a8da5a8373b7d3cb46349 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d1091eae052fc8f7add0561cc640804 = $(`&lt;div id=&quot;html_2d1091eae052fc8f7add0561cc640804&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_755a2bc3980a8da5a8373b7d3cb46349.setContent(html_2d1091eae052fc8f7add0561cc640804);
#
#
#
#         marker_19c94be0d5800c4a14a62eb0094d70cb.bindPopup(popup_755a2bc3980a8da5a8373b7d3cb46349)
#         ;
#
#
#
#
#             var marker_9f22af967c84cbbcd040c5bd1fb98af3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_96e06bec770f7cd79306b776f559f527);
#
#
#         var popup_48dc42c4411be3236900f65c1bd35dd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50a363aa46c9ce425a2efde646865cd5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50a363aa46c9ce425a2efde646865cd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50a363aa46c9ce425a2efde646865cd5 = L.map(
#                 &quot;map_50a363aa46c9ce425a2efde646865cd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f566488ebe849d5552ec8df89bf3327e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f566488ebe849d5552ec8df89bf3327e.addTo(map_50a363aa46c9ce425a2efde646865cd5);
#
#
#             var feature_group_da69440c02223d72657199fec522a96e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_da69440c02223d72657199fec522a96e.addTo(map_50a363aa46c9ce425a2efde646865cd5);
#
#
#             var feature_group_sub_group_616c5929f7a917bf6cbb2797d24f01d8 = L.featureGroup.subGroup(
#                 feature_group_da69440c02223d72657199fec522a96e
#             );
#
#
#             var marker_fddb2f6e72f4f485a7cf5e9c2922056e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_616c5929f7a917bf6cbb2797d24f01d8);
#
#
#         var popup_1d5eabce1e90cba8e8c6001dffafce42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08b5783c8c3de7c02250782e92384100 = $(`&lt;div id=&quot;html_08b5783c8c3de7c02250782e92384100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1d5eabce1e90cba8e8c6001dffafce42.setContent(html_08b5783c8c3de7c02250782e92384100);
#
#
#
#         marker_fddb2f6e72f4f485a7cf5e9c2922056e.bindPopup(popup_1d5eabce1e90cba8e8c6001dffafce42)
#         ;
#
#
#
#
#             var marker_9eea3ce44adbba86ded75f638477a5a9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_616c5929f7a917bf6cbb2797d24f01d8);
#
#
#         var popup_cd17d13ca2c8f8e3840448b918a4b891 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46c92d8ded768f007adba1eada78bff0 = $(`&lt;div id=&quot;html_46c92d8ded768f007adba1eada78bff0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cd17d13ca2c8f8e3840448b918a4b891.setContent(html_46c92d8ded768f007adba1eada78bff0);
#
#
#
#         marker_9eea3ce44adbba86ded75f638477a5a9.bindPopup(popup_cd17d13ca2c8f8e3840448b918a4b891)
#         ;
#
#
#
#
#             var marker_7b860aea9f1867a379538bdae4f1893e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_616c5929f7a917bf6cbb2797d24f01d8);
#
#
#         var popup_2ee0ffbd71e02a8a97890a48b3444c77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96d74a342916cad3f7d8dd9ab3dab058 = $(`&lt;div id=&quot;html_96d74a342916cad3f7d8dd9ab3dab058&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2ee0ffbd71e02a8a97890a48b3444c77.setContent(html_96d74a342916cad3f7d8dd9ab3dab058);
#
#
#
#         marker_7b860aea9f1867a379538bdae4f1893e.bindPopup(popup_2ee0ffbd71e02a8a97890a48b3444c77)
#         ;
#
#
#
#
#             var marker_f583e9fe69ab8c6d53c7b5bb88dd50f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_616c5929f7a917bf6cbb2797d24f01d8);
#
#
#         var popup_99b630c100f58329742a6018b2768630 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9edc0643f0370165de81b4098f24824c = $(`&lt;div id=&quot;html_9edc0643f0370165de81b4098f24824c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_99b630c100f58329742a6018b2768630.setContent(html_9edc0643f0370165de81b4098f24824c);
#
#
#
#         mark
