# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_928c9500bc3722256085e6cc958f3b94 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_928c9500bc3722256085e6cc958f3b94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_928c9500bc3722256085e6cc958f3b94 = L.map(
#                 &quot;map_928c9500bc3722256085e6cc958f3b94&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84636f8f7652b6a37a41b6a1f474e54d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84636f8f7652b6a37a41b6a1f474e54d.addTo(map_928c9500bc3722256085e6cc958f3b94);
#
#
#             var marker_76fa124f75333b3f9a26ee3b91eca073 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_928c9500bc3722256085e6cc958f3b94);
#
#
#         var popup_00bb077e19343cbd2441b7d6cba54eff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d4d404a8ceec98234e61c84031509a = $(`&lt;div id=&quot;html_c7d4d404a8ceec98234e61c84031509a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_00bb077e19343cbd2441b7d6cba54eff.setContent(html_c7d4d404a8ceec98234e61c84031509a);
#
#
#
#         marker_76fa124f75333b3f9a26ee3b91eca073.bindPopup(popup_00bb077e19343cbd2441b7d6cba54eff)
#         ;
#
#
#
#
#             var marker_0aed68a665215224060893bbc9e3d695 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_928c9500bc3722256085e6cc958f3b94);
#
#
#         var popup_9afeed3cdd4d12f4de667247be1f2703 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c0ce36de7dfeb9a102a6cbb773d77ae = $(`&lt;div id=&quot;html_3c0ce36de7dfeb9a102a6cbb773d77ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9afeed3cdd4d12f4de667247be1f2703.setContent(html_3c0ce36de7dfeb9a102a6cbb773d77ae);
#
#
#
#         marker_0aed68a665215224060893bbc9e3d695.bindPopup(popup_9afeed3cdd4d12f4de667247be1f2703)
#         ;
#
#
#
#
#             var marker_2c6cce220b44abca54aeeb6548f8f264 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_928c9500bc3722256085e6cc958f3b94);
#
#
#         var popup_dd3b9320b75aab5aa381c44c9a275ab3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0233a51d117ccca8b92a0f9b51441a94 = $(`&lt;div id=&quot;html_0233a51d117ccca8b92a0f9b51441a94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dd3b9320b75aab5aa381c44c9a275ab3.setContent(html_0233a51d117ccca8b92a0f9b51441a94);
#
#
#
#         marker_2c6cce220b44abca54aeeb6548f8f264.bindPopup(popup_dd3b9320b75aab5aa381c44c9a275ab3)
#         ;
#
#
#
#
#             var marker_39db02f248268dc59a2daa3b6041bfcd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_928c9500bc3722256085e6cc958f3b94);
#
#
#         var popup_11d8d143b8ee618dafc7b85b212b823f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d03f0336936649df12d4e0d85ace967 = $(`&lt;div id=&quot;html_0d03f0336936649df12d4e0d85ace967&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_11d8d143b8ee618dafc7b85b212b823f.setContent(html_0d03f0336936649df12d4e0d85ace967);
#
#
#
#         marker_39db02f248268dc59a2daa3b6041bfcd.bindPopup(popup_11d8d143b8ee618dafc7b85b212b823f)
#         ;
#
#
#
#
#             var marker_b04ecf305f558ebfbcb85380e19df8fc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_928c9500bc3722256085e6cc958f3b94);
#
#
#         var popup_2e265e12c715433480895a3365e9fec8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9e2791b8d64beb76d7388dbece7e756 = $(`&lt;div id=&quot;html_f9e2791b8d64beb76d7388dbece7e756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2e265e12c715433480895a3365e9fe

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_720d89686ffd2a2098dbaf81a149e5ca {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_720d89686ffd2a2098dbaf81a149e5ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_720d89686ffd2a2098dbaf81a149e5ca = L.map(
#                 &quot;map_720d89686ffd2a2098dbaf81a149e5ca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18fa4a9c925123f29306806c92c9a1d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18fa4a9c925123f29306806c92c9a1d5.addTo(map_720d89686ffd2a2098dbaf81a149e5ca);
#
#
#             var feature_group_7f34a42b0a1d5c1157ab279c5393a31e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_afb2bed33ffd6442a1a4c68a2bc884e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f34a42b0a1d5c1157ab279c5393a31e);
#
#
#         var popup_e3551e2e667426b7af4ce07d42e27e68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4b62b8b3cf4a967ff7916c855b07a60 = $(`&lt;div id=&quot;html_c4b62b8b3cf4a967ff7916c855b07a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e3551e2e667426b7af4ce07d42e27e68.setContent(html_c4b62b8b3cf4a967ff7916c855b07a60);
#
#
#
#         marker_afb2bed33ffd6442a1a4c68a2bc884e8.bindPopup(popup_e3551e2e667426b7af4ce07d42e27e68)
#         ;
#
#
#
#
#             var marker_3606eb5d3c2e4145e40b26a93f012221 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f34a42b0a1d5c1157ab279c5393a31e);
#
#
#         var popup_baa5438a15732282890fdcbe39cdfe4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb82d82afd5f46d84576168c39c3aa0c = $(`&lt;div id=&quot;html_bb82d82afd5f46d84576168c39c3aa0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_baa5438a15732282890fdcbe39cdfe4c.setContent(html_bb82d82afd5f46d84576168c39c3aa0c);
#
#
#
#         marker_3606eb5d3c2e4145e40b26a93f012221.bindPopup(popup_baa5438a15732282890fdcbe39cdfe4c)
#         ;
#
#
#
#
#             var marker_9a8fc302c56de753913e2a8ed32fcec8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f34a42b0a1d5c1157ab279c5393a31e);
#
#
#         var popup_7d5ac965a23d4c3f9076ee32d792a9ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_071c80d58083a1029e94df1e24039e02 = $(`&lt;div id=&quot;html_071c80d58083a1029e94df1e24039e02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7d5ac965a23d4c3f9076ee32d792a9ea.setContent(html_071c80d58083a1029e94df1e24039e02);
#
#
#
#         marker_9a8fc302c56de753913e2a8ed32fcec8.bindPopup(popup_7d5ac965a23d4c3f9076ee32d792a9ea)
#         ;
#
#
#
#
#             var marker_231b827e5c3d85976be2b4406ca1f202 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f34a42b0a1d5c1157ab279c5393a31e);
#
#
#         var popup_5168a337b6d3ddfea0b59aceb8a1b63f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b922f91f209217801e055ae0618f3cc = $(`&lt;div id=&quot;html_4b922f91f209217801e055ae0618f3cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5168a337b6d3ddfea0b59aceb8a1b63f.setContent(html_4b922f91f209217801e055ae0618f3cc);
#
#
#
#         marker_231b827e5c3d85976be2b4406ca1f202.bindPopup(popup_5168a337b6d3ddfea0b59aceb8a1b63f)
#         ;
#
#
#
#
#             var marker_882f82301cd5a095e4e3690aaee97292 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f34a42b0a1d5c1157ab279c5393a31e);
#
#
#         var popup_040feadacea7978e6f62df7225297d37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_200ca0c61c5220ff5c026934ba24bf82 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_200ca0c61c5220ff5c026934ba24bf82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_200ca0c61c5220ff5c026934ba24bf82 = L.map(
#                 &quot;map_200ca0c61c5220ff5c026934ba24bf82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f21052a1f252df6f2e727187afd438e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f21052a1f252df6f2e727187afd438e.addTo(map_200ca0c61c5220ff5c026934ba24bf82);
#
#
#             var feature_group_5503e526507b91bf8334f4e511a06c8c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5503e526507b91bf8334f4e511a06c8c.addTo(map_200ca0c61c5220ff5c026934ba24bf82);
#
#
#             var feature_group_sub_group_31c2a4d15a84f86834659ff67d2c88a5 = L.featureGroup.subGroup(
#                 feature_group_5503e526507b91bf8334f4e511a06c8c
#             );
#
#
#             var marker_e2f05190a9c32be8b8b243694163963f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_31c2a4d15a84f86834659ff67d2c88a5);
#
#
#         var popup_430a49defce23a5a4cac261daaeb9f18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25c297d28453f84ecbd0287361f90c47 = $(`&lt;div id=&quot;html_25c297d28453f84ecbd0287361f90c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_430a49defce23a5a4cac261daaeb9f18.setContent(html_25c297d28453f84ecbd0287361f90c47);
#
#
#
#         marker_e2f05190a9c32be8b8b243694163963f.bindPopup(popup_430a49defce23a5a4cac261daaeb9f18)
#         ;
#
#
#
#
#             var marker_8e57a55fbcbe992e4251bcdcd8cfd51d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_31c2a4d15a84f86834659ff67d2c88a5);
#
#
#         var popup_36a2d34f35b680660151ebe07765217b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75c3405ef1d754478390e33ca10a6a3f = $(`&lt;div id=&quot;html_75c3405ef1d754478390e33ca10a6a3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_36a2d34f35b680660151ebe07765217b.setContent(html_75c3405ef1d754478390e33ca10a6a3f);
#
#
#
#         marker_8e57a55fbcbe992e4251bcdcd8cfd51d.bindPopup(popup_36a2d34f35b680660151ebe07765217b)
#         ;
#
#
#
#
#             var marker_05f160b497c304a138a1b0488a98b80a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_31c2a4d15a84f86834659ff67d2c88a5);
#
#
#         var popup_ea1d96206143da246db0b5f242f1615b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c0491042fb6ac5c21f3fd91f1dc445b = $(`&lt;div id=&quot;html_0c0491042fb6ac5c21f3fd91f1dc445b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ea1d96206143da246db0b5f242f1615b.setContent(html_0c0491042fb6ac5c21f3fd91f1dc445b);
#
#
#
#         marker_05f160b497c304a138a1b0488a98b80a.bindPopup(popup_ea1d96206143da246db0b5f242f1615b)
#         ;
#
#
#
#
#             var marker_c3d4755767c6be497a1cedb9f1d7c94f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_31c2a4d15a84f86834659ff67d2c88a5);
#
#
#         var popup_9beb4023ff77eca095dc857528b26bb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76fe312ed85547e0ffe71373e9dbf64d = $(`&lt;div id=&quot;html_76fe312ed85547e0ffe71373e9dbf64d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9beb4023ff77eca095dc857528b26bb9.setContent(html_76fe312ed85547e0ffe71373e9dbf64d);
#
#
#
#         mark
