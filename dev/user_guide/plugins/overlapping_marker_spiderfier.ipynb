# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef960e9828db0378e46c4fbbc5f05dc8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef960e9828db0378e46c4fbbc5f05dc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef960e9828db0378e46c4fbbc5f05dc8 = L.map(
#                 &quot;map_ef960e9828db0378e46c4fbbc5f05dc8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea143de832ddd44803cfb6d3a49a36ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea143de832ddd44803cfb6d3a49a36ec.addTo(map_ef960e9828db0378e46c4fbbc5f05dc8);
#
#
#             var marker_e6413ab3b6ceed818035919709a24f7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ef960e9828db0378e46c4fbbc5f05dc8);
#
#
#         var popup_9063223a6fe42c13c9406b6d169f03f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b832230e59ab0d476eb940907ccf55a = $(`&lt;div id=&quot;html_6b832230e59ab0d476eb940907ccf55a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9063223a6fe42c13c9406b6d169f03f8.setContent(html_6b832230e59ab0d476eb940907ccf55a);
#
#
#
#         marker_e6413ab3b6ceed818035919709a24f7b.bindPopup(popup_9063223a6fe42c13c9406b6d169f03f8)
#         ;
#
#
#
#
#             var marker_9b69d59c506d366fe94bcebf3b8fea0d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ef960e9828db0378e46c4fbbc5f05dc8);
#
#
#         var popup_ed9b158fc5ffe9624e7ef5d0ee5c4e4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c42239c30955b3ccb104d196512a9199 = $(`&lt;div id=&quot;html_c42239c30955b3ccb104d196512a9199&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ed9b158fc5ffe9624e7ef5d0ee5c4e4a.setContent(html_c42239c30955b3ccb104d196512a9199);
#
#
#
#         marker_9b69d59c506d366fe94bcebf3b8fea0d.bindPopup(popup_ed9b158fc5ffe9624e7ef5d0ee5c4e4a)
#         ;
#
#
#
#
#             var marker_5e93ce198758cd1b86d93221bb871266 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ef960e9828db0378e46c4fbbc5f05dc8);
#
#
#         var popup_4a58a35876e4f3bd89e366a0ef2fe4bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aca056c98dfdc80b6fe012fb9ef1a652 = $(`&lt;div id=&quot;html_aca056c98dfdc80b6fe012fb9ef1a652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4a58a35876e4f3bd89e366a0ef2fe4bb.setContent(html_aca056c98dfdc80b6fe012fb9ef1a652);
#
#
#
#         marker_5e93ce198758cd1b86d93221bb871266.bindPopup(popup_4a58a35876e4f3bd89e366a0ef2fe4bb)
#         ;
#
#
#
#
#             var marker_97700c69fe5509b45c32e1aa3b0f7709 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ef960e9828db0378e46c4fbbc5f05dc8);
#
#
#         var popup_521989d660504c49e7a21f85767542e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7e336fa4bcf8a64eeadb84ecf5c37dc = $(`&lt;div id=&quot;html_d7e336fa4bcf8a64eeadb84ecf5c37dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_521989d660504c49e7a21f85767542e1.setContent(html_d7e336fa4bcf8a64eeadb84ecf5c37dc);
#
#
#
#         marker_97700c69fe5509b45c32e1aa3b0f7709.bindPopup(popup_521989d660504c49e7a21f85767542e1)
#         ;
#
#
#
#
#             var marker_b6f4f3bd1dba66f46aa84d6925d71a30 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ef960e9828db0378e46c4fbbc5f05dc8);
#
#
#         var popup_7cc624e2647819e54cbeca3dd7f6afaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d481232cc9a22c5e545badbe8f656f0 = $(`&lt;div id=&quot;html_7d481232cc9a22c5e545badbe8f656f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7cc624e2647819e54cbeca3dd7f6af

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b935a241cc80cc5312cfb67068d1f5b1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b935a241cc80cc5312cfb67068d1f5b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b935a241cc80cc5312cfb67068d1f5b1 = L.map(
#                 &quot;map_b935a241cc80cc5312cfb67068d1f5b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a39ea35a9c086f25efe99daa9740c1cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a39ea35a9c086f25efe99daa9740c1cd.addTo(map_b935a241cc80cc5312cfb67068d1f5b1);
#
#
#             var feature_group_cc161bd82cb0aa6160d1c38427515695 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3e0e0bb23b0404e5525d800784671d5b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cc161bd82cb0aa6160d1c38427515695);
#
#
#         var popup_79f1d99577e95623fbb640443b1b59bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d35ee5b816272dab6bd545ac86965730 = $(`&lt;div id=&quot;html_d35ee5b816272dab6bd545ac86965730&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_79f1d99577e95623fbb640443b1b59bb.setContent(html_d35ee5b816272dab6bd545ac86965730);
#
#
#
#         marker_3e0e0bb23b0404e5525d800784671d5b.bindPopup(popup_79f1d99577e95623fbb640443b1b59bb)
#         ;
#
#
#
#
#             var marker_2e8efdc8d7233e38b8c4c1c88d3586f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cc161bd82cb0aa6160d1c38427515695);
#
#
#         var popup_554fec8410de5f9625aec62752f89ff3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cba57ad335f972f2a530c9ebfb22137 = $(`&lt;div id=&quot;html_4cba57ad335f972f2a530c9ebfb22137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_554fec8410de5f9625aec62752f89ff3.setContent(html_4cba57ad335f972f2a530c9ebfb22137);
#
#
#
#         marker_2e8efdc8d7233e38b8c4c1c88d3586f5.bindPopup(popup_554fec8410de5f9625aec62752f89ff3)
#         ;
#
#
#
#
#             var marker_abdcf16879c310c670cf552ce7675020 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cc161bd82cb0aa6160d1c38427515695);
#
#
#         var popup_706845da89ab56fc31e48e8e6d94a1c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bc027cba61f474e4e56d9e6fcbbfdf6 = $(`&lt;div id=&quot;html_8bc027cba61f474e4e56d9e6fcbbfdf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_706845da89ab56fc31e48e8e6d94a1c7.setContent(html_8bc027cba61f474e4e56d9e6fcbbfdf6);
#
#
#
#         marker_abdcf16879c310c670cf552ce7675020.bindPopup(popup_706845da89ab56fc31e48e8e6d94a1c7)
#         ;
#
#
#
#
#             var marker_7c2534e80dac14c108e49eed241304f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cc161bd82cb0aa6160d1c38427515695);
#
#
#         var popup_5ef8aa8df5f577912d2cb5dfe59b37a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9452e7b342cef7666295dec7ea754b12 = $(`&lt;div id=&quot;html_9452e7b342cef7666295dec7ea754b12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ef8aa8df5f577912d2cb5dfe59b37a5.setContent(html_9452e7b342cef7666295dec7ea754b12);
#
#
#
#         marker_7c2534e80dac14c108e49eed241304f0.bindPopup(popup_5ef8aa8df5f577912d2cb5dfe59b37a5)
#         ;
#
#
#
#
#             var marker_6876a9ab3da223d84277b0c69037e05c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cc161bd82cb0aa6160d1c38427515695);
#
#
#         var popup_5fc33bce318f41a4cc6386f9f02c5c56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c437bbfbb8bc2099f419becc1a81da4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c437bbfbb8bc2099f419becc1a81da4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c437bbfbb8bc2099f419becc1a81da4 = L.map(
#                 &quot;map_7c437bbfbb8bc2099f419becc1a81da4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_004dc66487f955fa61b1cfe6b822847b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_004dc66487f955fa61b1cfe6b822847b.addTo(map_7c437bbfbb8bc2099f419becc1a81da4);
#
#
#             var feature_group_41d2bd769a65272a52027e4a42b9a0a1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_41d2bd769a65272a52027e4a42b9a0a1.addTo(map_7c437bbfbb8bc2099f419becc1a81da4);
#
#
#             var feature_group_sub_group_c62725f175e7709ed795fc0146eacf53 = L.featureGroup.subGroup(
#                 feature_group_41d2bd769a65272a52027e4a42b9a0a1
#             );
#
#
#             var marker_0fb882c9a37bd6548ee4d6d8db210567 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c62725f175e7709ed795fc0146eacf53);
#
#
#         var popup_3221bdb6a27235faabcf0e59d78fdbbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49061ade5e867da0460ec7a7d2626e08 = $(`&lt;div id=&quot;html_49061ade5e867da0460ec7a7d2626e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3221bdb6a27235faabcf0e59d78fdbbc.setContent(html_49061ade5e867da0460ec7a7d2626e08);
#
#
#
#         marker_0fb882c9a37bd6548ee4d6d8db210567.bindPopup(popup_3221bdb6a27235faabcf0e59d78fdbbc)
#         ;
#
#
#
#
#             var marker_9470aeb2ff9533e0981a29709d28c9e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c62725f175e7709ed795fc0146eacf53);
#
#
#         var popup_3871bae685dce22c491d2c344462f933 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d01a59f6f3baac694f8818b058285fda = $(`&lt;div id=&quot;html_d01a59f6f3baac694f8818b058285fda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3871bae685dce22c491d2c344462f933.setContent(html_d01a59f6f3baac694f8818b058285fda);
#
#
#
#         marker_9470aeb2ff9533e0981a29709d28c9e6.bindPopup(popup_3871bae685dce22c491d2c344462f933)
#         ;
#
#
#
#
#             var marker_e6178a5f125c6305f70f51226d85c93f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c62725f175e7709ed795fc0146eacf53);
#
#
#         var popup_e9ea967f974de601821405e1ef65e186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d045c167e321f0a96888cf59c902e7b2 = $(`&lt;div id=&quot;html_d045c167e321f0a96888cf59c902e7b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e9ea967f974de601821405e1ef65e186.setContent(html_d045c167e321f0a96888cf59c902e7b2);
#
#
#
#         marker_e6178a5f125c6305f70f51226d85c93f.bindPopup(popup_e9ea967f974de601821405e1ef65e186)
#         ;
#
#
#
#
#             var marker_73db8993b2b03307fedf5ba9c5a9f10d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c62725f175e7709ed795fc0146eacf53);
#
#
#         var popup_87b07849e0f91c56d27f6d192424d8ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9cdbd1ea072de1b0be3951402bb310f = $(`&lt;div id=&quot;html_a9cdbd1ea072de1b0be3951402bb310f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_87b07849e0f91c56d27f6d192424d8ab.setContent(html_a9cdbd1ea072de1b0be3951402bb310f);
#
#
#
#         mark
