# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72aed81de168bd1eb23157739d8333a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72aed81de168bd1eb23157739d8333a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72aed81de168bd1eb23157739d8333a1 = L.map(
#                 &quot;map_72aed81de168bd1eb23157739d8333a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_534c20623685c79f507fbcb2518a69f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_534c20623685c79f507fbcb2518a69f1.addTo(map_72aed81de168bd1eb23157739d8333a1);
#
#
#             var marker_8d6cfc50bfe81bea0717383781d9f8f5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_72aed81de168bd1eb23157739d8333a1);
#
#
#         var popup_b8002203987857a7f92f7d4d56c13739 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bed814a821665d4d1f90e105d3788fb9 = $(`&lt;div id=&quot;html_bed814a821665d4d1f90e105d3788fb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b8002203987857a7f92f7d4d56c13739.setContent(html_bed814a821665d4d1f90e105d3788fb9);
#
#
#
#         marker_8d6cfc50bfe81bea0717383781d9f8f5.bindPopup(popup_b8002203987857a7f92f7d4d56c13739)
#         ;
#
#
#
#
#             var marker_183bac4e4b4277fed290ac6451d63d4f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_72aed81de168bd1eb23157739d8333a1);
#
#
#         var popup_2ccd8a36c97672ad98899a7dca118b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfca70cbd684ad393f2467bbfe5084d5 = $(`&lt;div id=&quot;html_bfca70cbd684ad393f2467bbfe5084d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2ccd8a36c97672ad98899a7dca118b57.setContent(html_bfca70cbd684ad393f2467bbfe5084d5);
#
#
#
#         marker_183bac4e4b4277fed290ac6451d63d4f.bindPopup(popup_2ccd8a36c97672ad98899a7dca118b57)
#         ;
#
#
#
#
#             var marker_5dce3dacfa2cfc6b9bf19953329f68a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_72aed81de168bd1eb23157739d8333a1);
#
#
#         var popup_2482456b0f947f4d0af4ed34b702a537 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0579282c2e8d5f9bdd57ab19ad87e0 = $(`&lt;div id=&quot;html_3d0579282c2e8d5f9bdd57ab19ad87e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2482456b0f947f4d0af4ed34b702a537.setContent(html_3d0579282c2e8d5f9bdd57ab19ad87e0);
#
#
#
#         marker_5dce3dacfa2cfc6b9bf19953329f68a2.bindPopup(popup_2482456b0f947f4d0af4ed34b702a537)
#         ;
#
#
#
#
#             var marker_8766e76c8a42929f0bdb80ad7b1f575e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_72aed81de168bd1eb23157739d8333a1);
#
#
#         var popup_d5d5891c75dd3b2eb07bbb1b75512f7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d0feec9845fe706477145bb9cea3b0e = $(`&lt;div id=&quot;html_8d0feec9845fe706477145bb9cea3b0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d5d5891c75dd3b2eb07bbb1b75512f7a.setContent(html_8d0feec9845fe706477145bb9cea3b0e);
#
#
#
#         marker_8766e76c8a42929f0bdb80ad7b1f575e.bindPopup(popup_d5d5891c75dd3b2eb07bbb1b75512f7a)
#         ;
#
#
#
#
#             var marker_a7233b7d2b54e3242ddbe59469ad500e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_72aed81de168bd1eb23157739d8333a1);
#
#
#         var popup_e7b87b6fdc63013b0d71ff17b14df410 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a71f1f710507629a026ef82e3bef72a = $(`&lt;div id=&quot;html_7a71f1f710507629a026ef82e3bef72a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e7b87b6fdc63013b0d71ff17b14df410.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4564dc168d0a92191dfb1ad68e119375 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4564dc168d0a92191dfb1ad68e119375&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4564dc168d0a92191dfb1ad68e119375 = L.map(
#                 &quot;map_4564dc168d0a92191dfb1ad68e119375&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_623f4535ef97d847a3c641dca7ac588c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_623f4535ef97d847a3c641dca7ac588c.addTo(map_4564dc168d0a92191dfb1ad68e119375);
#
#
#             var feature_group_6e657cb315bb40f4e3d3555f003ccc86 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_097bcbdb81c0809f2638e8b18494694d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6e657cb315bb40f4e3d3555f003ccc86);
#
#
#         var popup_6fef5fbb83845425e7fbc9f48755b617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b9e2824e2e63001c6e2e407862ac224 = $(`&lt;div id=&quot;html_1b9e2824e2e63001c6e2e407862ac224&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6fef5fbb83845425e7fbc9f48755b617.setContent(html_1b9e2824e2e63001c6e2e407862ac224);
#
#
#
#         marker_097bcbdb81c0809f2638e8b18494694d.bindPopup(popup_6fef5fbb83845425e7fbc9f48755b617)
#         ;
#
#
#
#
#             var marker_299efe1102e9738355a99ac98166a4d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6e657cb315bb40f4e3d3555f003ccc86);
#
#
#         var popup_f50c6b7bfd3efead98523477a589a363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55363fa62ebb7adb37e1b8341d9b56d5 = $(`&lt;div id=&quot;html_55363fa62ebb7adb37e1b8341d9b56d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f50c6b7bfd3efead98523477a589a363.setContent(html_55363fa62ebb7adb37e1b8341d9b56d5);
#
#
#
#         marker_299efe1102e9738355a99ac98166a4d5.bindPopup(popup_f50c6b7bfd3efead98523477a589a363)
#         ;
#
#
#
#
#             var marker_5021c235128ec32e1a597398098cf9a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6e657cb315bb40f4e3d3555f003ccc86);
#
#
#         var popup_76caf3552b9eb89e96465923a877f0f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc557ce0cb11ee5dd165e3593b55c06f = $(`&lt;div id=&quot;html_bc557ce0cb11ee5dd165e3593b55c06f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_76caf3552b9eb89e96465923a877f0f5.setContent(html_bc557ce0cb11ee5dd165e3593b55c06f);
#
#
#
#         marker_5021c235128ec32e1a597398098cf9a2.bindPopup(popup_76caf3552b9eb89e96465923a877f0f5)
#         ;
#
#
#
#
#             var marker_12c654f98cb63f8053cca5d2ce2d9ec2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6e657cb315bb40f4e3d3555f003ccc86);
#
#
#         var popup_7790363c34813e6f74684957dd67e2ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b972495d0d2f8c7cb8da98da887d621b = $(`&lt;div id=&quot;html_b972495d0d2f8c7cb8da98da887d621b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7790363c34813e6f74684957dd67e2ef.setContent(html_b972495d0d2f8c7cb8da98da887d621b);
#
#
#
#         marker_12c654f98cb63f8053cca5d2ce2d9ec2.bindPopup(popup_7790363c34813e6f74684957dd67e2ef)
#         ;
#
#
#
#
#             var marker_4701d322d6b993505fa30deaa5cd5855 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6e657cb315bb40f4e3d3555f003ccc86);
#
#
#         var popup_d2f10447a0cc62a306269d60efefcb32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3e645245924ad1faaf77804f49c52bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3e645245924ad1faaf77804f49c52bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3e645245924ad1faaf77804f49c52bc = L.map(
#                 &quot;map_f3e645245924ad1faaf77804f49c52bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cf87088b96959b55f733e37ed4802c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cf87088b96959b55f733e37ed4802c4.addTo(map_f3e645245924ad1faaf77804f49c52bc);
#
#
#             var feature_group_a9fc5b6f5d2722746eb0035951d45bfa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a9fc5b6f5d2722746eb0035951d45bfa.addTo(map_f3e645245924ad1faaf77804f49c52bc);
#
#
#             var feature_group_sub_group_fae7a3b501d34bc6ed8ba25daf41a247 = L.featureGroup.subGroup(
#                 feature_group_a9fc5b6f5d2722746eb0035951d45bfa
#             );
#
#
#             var marker_3244c452a585c514b3fd288e6276102e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7a3b501d34bc6ed8ba25daf41a247);
#
#
#         var popup_5c8c597b97c1403c8e1011638f2b3b5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74c01a0726bb350498f376248c11c36e = $(`&lt;div id=&quot;html_74c01a0726bb350498f376248c11c36e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5c8c597b97c1403c8e1011638f2b3b5c.setContent(html_74c01a0726bb350498f376248c11c36e);
#
#
#
#         marker_3244c452a585c514b3fd288e6276102e.bindPopup(popup_5c8c597b97c1403c8e1011638f2b3b5c)
#         ;
#
#
#
#
#             var marker_c8d38835d347cfcb1d022fa8713028a3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7a3b501d34bc6ed8ba25daf41a247);
#
#
#         var popup_27be16dfe11541113c1487f30bfc55df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80ae4ec76a5351bb380a2a0293d3b5a1 = $(`&lt;div id=&quot;html_80ae4ec76a5351bb380a2a0293d3b5a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_27be16dfe11541113c1487f30bfc55df.setContent(html_80ae4ec76a5351bb380a2a0293d3b5a1);
#
#
#
#         marker_c8d38835d347cfcb1d022fa8713028a3.bindPopup(popup_27be16dfe11541113c1487f30bfc55df)
#         ;
#
#
#
#
#             var marker_7e5f94fba6cb4308ca6d40dc53279999 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7a3b501d34bc6ed8ba25daf41a247);
#
#
#         var popup_151c8a346360e5eb716d418da8fb0efb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d45f358cad581aabfac43085aeb635d4 = $(`&lt;div id=&quot;html_d45f358cad581aabfac43085aeb635d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_151c8a346360e5eb716d418da8fb0efb.setContent(html_d45f358cad581aabfac43085aeb635d4);
#
#
#
#         marker_7e5f94fba6cb4308ca6d40dc53279999.bindPopup(popup_151c8a346360e5eb716d418da8fb0efb)
#         ;
#
#
#
#
#             var marker_4d282095091e94260637c7e0d7f186c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fae7a3b501d34bc6ed8ba25daf41a247);
#
#
#         var popup_1aa29a26cd235f1a0944d7181a308ddb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26dd4c5317e6005ed18ea9e603226f71 = $(`&lt;div id=&quot;html_26dd4c5317e6005ed18ea9e603226f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1aa29a26cd235f1a0944d7181a308ddb.setContent(html_26dd4c5317e6005ed18ea9e603226f71);
#
#
#
#         marker_
