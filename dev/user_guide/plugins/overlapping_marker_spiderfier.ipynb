# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ed5af57fe4ca725ef6f54e1b66142dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ed5af57fe4ca725ef6f54e1b66142dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ed5af57fe4ca725ef6f54e1b66142dd = L.map(
#                 &quot;map_1ed5af57fe4ca725ef6f54e1b66142dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c1af64a3507947e39a28f6fc9579596 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c1af64a3507947e39a28f6fc9579596.addTo(map_1ed5af57fe4ca725ef6f54e1b66142dd);
#
#
#             var marker_64c479407359e6157b36e3ef3e3f178e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1ed5af57fe4ca725ef6f54e1b66142dd);
#
#
#         var popup_5732258a3fb6eea6449544df28387ea0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a4f8b16440ce9c0a4362abf2e1a7861 = $(`&lt;div id=&quot;html_2a4f8b16440ce9c0a4362abf2e1a7861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5732258a3fb6eea6449544df28387ea0.setContent(html_2a4f8b16440ce9c0a4362abf2e1a7861);
#
#
#
#         marker_64c479407359e6157b36e3ef3e3f178e.bindPopup(popup_5732258a3fb6eea6449544df28387ea0)
#         ;
#
#
#
#
#             var marker_91272a6f141268c177edb4fc1cfeb7d8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1ed5af57fe4ca725ef6f54e1b66142dd);
#
#
#         var popup_6cbcac8c33149e13aa44c1258137f258 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e18d444f75577b97dfdec30560f95217 = $(`&lt;div id=&quot;html_e18d444f75577b97dfdec30560f95217&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6cbcac8c33149e13aa44c1258137f258.setContent(html_e18d444f75577b97dfdec30560f95217);
#
#
#
#         marker_91272a6f141268c177edb4fc1cfeb7d8.bindPopup(popup_6cbcac8c33149e13aa44c1258137f258)
#         ;
#
#
#
#
#             var marker_e04be423973465191e30b887c65f54c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1ed5af57fe4ca725ef6f54e1b66142dd);
#
#
#         var popup_878dac7acdb35dafbd5bcd6608a40802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73dbd7dc8fdb21b724a4ad3ea8abb6a4 = $(`&lt;div id=&quot;html_73dbd7dc8fdb21b724a4ad3ea8abb6a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_878dac7acdb35dafbd5bcd6608a40802.setContent(html_73dbd7dc8fdb21b724a4ad3ea8abb6a4);
#
#
#
#         marker_e04be423973465191e30b887c65f54c7.bindPopup(popup_878dac7acdb35dafbd5bcd6608a40802)
#         ;
#
#
#
#
#             var marker_9a4de376421456f48daaf1adfe892d02 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1ed5af57fe4ca725ef6f54e1b66142dd);
#
#
#         var popup_8daa5ead5e573c3ca11e74946387ad0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fcb98f2c594afdefc0e74f96c4658f21 = $(`&lt;div id=&quot;html_fcb98f2c594afdefc0e74f96c4658f21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8daa5ead5e573c3ca11e74946387ad0c.setContent(html_fcb98f2c594afdefc0e74f96c4658f21);
#
#
#
#         marker_9a4de376421456f48daaf1adfe892d02.bindPopup(popup_8daa5ead5e573c3ca11e74946387ad0c)
#         ;
#
#
#
#
#             var marker_81bb5a746a7b4816bb70c69d156f17d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1ed5af57fe4ca725ef6f54e1b66142dd);
#
#
#         var popup_f054e3dbbbbb29dd12f168fcb63688d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8d03ae9f7d56ed15db1c0011f00dca7 = $(`&lt;div id=&quot;html_a8d03ae9f7d56ed15db1c0011f00dca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f054e3dbbbbb29dd12f168fcb63688d6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f35f729000eb2d7ca22dd364178ca8b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f35f729000eb2d7ca22dd364178ca8b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f35f729000eb2d7ca22dd364178ca8b9 = L.map(
#                 &quot;map_f35f729000eb2d7ca22dd364178ca8b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d240cf2e037c8b3d29f802166f8aaa45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d240cf2e037c8b3d29f802166f8aaa45.addTo(map_f35f729000eb2d7ca22dd364178ca8b9);
#
#
#             var feature_group_09a145ac525c689a313f0619a48cfd83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_24c5c12d91402f4f50e49a9bc772a911 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_09a145ac525c689a313f0619a48cfd83);
#
#
#         var popup_c3cb931cc136aaee74ab113ae7f78539 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9108d58058eb5f63ce067d8f8b71b22 = $(`&lt;div id=&quot;html_a9108d58058eb5f63ce067d8f8b71b22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c3cb931cc136aaee74ab113ae7f78539.setContent(html_a9108d58058eb5f63ce067d8f8b71b22);
#
#
#
#         marker_24c5c12d91402f4f50e49a9bc772a911.bindPopup(popup_c3cb931cc136aaee74ab113ae7f78539)
#         ;
#
#
#
#
#             var marker_897180a3265faac899d0a4f487537794 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_09a145ac525c689a313f0619a48cfd83);
#
#
#         var popup_904ce408fd7fc975c657216669260f25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ef6ff6c460405bf5883e6eb31d6321a = $(`&lt;div id=&quot;html_9ef6ff6c460405bf5883e6eb31d6321a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_904ce408fd7fc975c657216669260f25.setContent(html_9ef6ff6c460405bf5883e6eb31d6321a);
#
#
#
#         marker_897180a3265faac899d0a4f487537794.bindPopup(popup_904ce408fd7fc975c657216669260f25)
#         ;
#
#
#
#
#             var marker_eb65ee0259c40f6fc637db8748be4559 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_09a145ac525c689a313f0619a48cfd83);
#
#
#         var popup_b38eabff3907cdb438f6991ec8298020 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fa93a3fcfb96bdcb1810c5054f1ff79 = $(`&lt;div id=&quot;html_5fa93a3fcfb96bdcb1810c5054f1ff79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b38eabff3907cdb438f6991ec8298020.setContent(html_5fa93a3fcfb96bdcb1810c5054f1ff79);
#
#
#
#         marker_eb65ee0259c40f6fc637db8748be4559.bindPopup(popup_b38eabff3907cdb438f6991ec8298020)
#         ;
#
#
#
#
#             var marker_5d2a72eb70e447b0708ae2d3bc8c86d3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_09a145ac525c689a313f0619a48cfd83);
#
#
#         var popup_24be9095501579e5bd46c7f0f082f6eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bc05a99c8c56cb49743c495b59e54bb = $(`&lt;div id=&quot;html_6bc05a99c8c56cb49743c495b59e54bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_24be9095501579e5bd46c7f0f082f6eb.setContent(html_6bc05a99c8c56cb49743c495b59e54bb);
#
#
#
#         marker_5d2a72eb70e447b0708ae2d3bc8c86d3.bindPopup(popup_24be9095501579e5bd46c7f0f082f6eb)
#         ;
#
#
#
#
#             var marker_d525b16f89ff6021c084c7e1fb54dee5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_09a145ac525c689a313f0619a48cfd83);
#
#
#         var popup_844d052d05addcf15e153407a75215f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06985bbe5ceef3b223a228abaf4f51fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06985bbe5ceef3b223a228abaf4f51fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06985bbe5ceef3b223a228abaf4f51fa = L.map(
#                 &quot;map_06985bbe5ceef3b223a228abaf4f51fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4319e3ad81477bc8737c645d4876eac3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4319e3ad81477bc8737c645d4876eac3.addTo(map_06985bbe5ceef3b223a228abaf4f51fa);
#
#
#             var feature_group_204a0d993ff961ec6cbdc8480390ffee = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_204a0d993ff961ec6cbdc8480390ffee.addTo(map_06985bbe5ceef3b223a228abaf4f51fa);
#
#
#             var feature_group_sub_group_51a15dda45ccacab8a3068f7adb99e43 = L.featureGroup.subGroup(
#                 feature_group_204a0d993ff961ec6cbdc8480390ffee
#             );
#
#
#             var marker_7c82ebd54460ec83c6d35d6c5c8e9c83 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_51a15dda45ccacab8a3068f7adb99e43);
#
#
#         var popup_d8af6fab0ea814cce01848f99da50d41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4827315ad588d09309aaf94e1375fe7 = $(`&lt;div id=&quot;html_f4827315ad588d09309aaf94e1375fe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d8af6fab0ea814cce01848f99da50d41.setContent(html_f4827315ad588d09309aaf94e1375fe7);
#
#
#
#         marker_7c82ebd54460ec83c6d35d6c5c8e9c83.bindPopup(popup_d8af6fab0ea814cce01848f99da50d41)
#         ;
#
#
#
#
#             var marker_0cd8af66bf2eb5e1c789b9a94279ab04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_51a15dda45ccacab8a3068f7adb99e43);
#
#
#         var popup_f4489a730c69e82aea6f08a7529e473b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8a40ed1670ab9a5944d4febd6ec257e = $(`&lt;div id=&quot;html_c8a40ed1670ab9a5944d4febd6ec257e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f4489a730c69e82aea6f08a7529e473b.setContent(html_c8a40ed1670ab9a5944d4febd6ec257e);
#
#
#
#         marker_0cd8af66bf2eb5e1c789b9a94279ab04.bindPopup(popup_f4489a730c69e82aea6f08a7529e473b)
#         ;
#
#
#
#
#             var marker_1ec3358cf84f2424e442f937432fa1a5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_51a15dda45ccacab8a3068f7adb99e43);
#
#
#         var popup_a0771342b1c8323ef7f17aab3de2845e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36bf71243662fe58610469755769b325 = $(`&lt;div id=&quot;html_36bf71243662fe58610469755769b325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a0771342b1c8323ef7f17aab3de2845e.setContent(html_36bf71243662fe58610469755769b325);
#
#
#
#         marker_1ec3358cf84f2424e442f937432fa1a5.bindPopup(popup_a0771342b1c8323ef7f17aab3de2845e)
#         ;
#
#
#
#
#             var marker_f35cfbde81701a13f3e08733e331c768 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_51a15dda45ccacab8a3068f7adb99e43);
#
#
#         var popup_7ac7edf5824a6c4fef913ddad11da067 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d55415a4a89c514452da4de257d8d4d = $(`&lt;div id=&quot;html_4d55415a4a89c514452da4de257d8d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7ac7edf5824a6c4fef913ddad11da067.setContent(html_4d55415a4a89c514452da4de257d8d4d);
#
#
#
#         marker_
