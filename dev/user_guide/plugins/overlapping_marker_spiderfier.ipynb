# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c56df2a96bc6c924b95b6f938da5902a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c56df2a96bc6c924b95b6f938da5902a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c56df2a96bc6c924b95b6f938da5902a = L.map(
#                 &quot;map_c56df2a96bc6c924b95b6f938da5902a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_222d6c8b57785e08b12a1371aec3af54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_222d6c8b57785e08b12a1371aec3af54.addTo(map_c56df2a96bc6c924b95b6f938da5902a);
#
#
#             var marker_33ac556f900cf1dd2984a2348808672c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c56df2a96bc6c924b95b6f938da5902a);
#
#
#         var popup_34b726bc9534b1afd22ac9acca7a1d9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3aaa8237e004ad45916177718fdfd0e = $(`&lt;div id=&quot;html_f3aaa8237e004ad45916177718fdfd0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_34b726bc9534b1afd22ac9acca7a1d9a.setContent(html_f3aaa8237e004ad45916177718fdfd0e);
#
#
#
#         marker_33ac556f900cf1dd2984a2348808672c.bindPopup(popup_34b726bc9534b1afd22ac9acca7a1d9a)
#         ;
#
#
#
#
#             var marker_04669812111e037a9dfd0a0ab4d67744 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c56df2a96bc6c924b95b6f938da5902a);
#
#
#         var popup_2f81b8a4dd0962b1d66b8519a3cfc9c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14789c8119e482e8d13170d1639c20e8 = $(`&lt;div id=&quot;html_14789c8119e482e8d13170d1639c20e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2f81b8a4dd0962b1d66b8519a3cfc9c3.setContent(html_14789c8119e482e8d13170d1639c20e8);
#
#
#
#         marker_04669812111e037a9dfd0a0ab4d67744.bindPopup(popup_2f81b8a4dd0962b1d66b8519a3cfc9c3)
#         ;
#
#
#
#
#             var marker_816977ddd12f86c2a6d764b0f703a2a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c56df2a96bc6c924b95b6f938da5902a);
#
#
#         var popup_52fbcad6d276b754d276161a2fa6e803 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5aaa013771c53836a455b145eb8dbdb = $(`&lt;div id=&quot;html_d5aaa013771c53836a455b145eb8dbdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_52fbcad6d276b754d276161a2fa6e803.setContent(html_d5aaa013771c53836a455b145eb8dbdb);
#
#
#
#         marker_816977ddd12f86c2a6d764b0f703a2a3.bindPopup(popup_52fbcad6d276b754d276161a2fa6e803)
#         ;
#
#
#
#
#             var marker_3acffcca0a40113bb0a666986d906951 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c56df2a96bc6c924b95b6f938da5902a);
#
#
#         var popup_c0ebf8f1b72102ffd3c1eac8738d040b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77923d714ca0a96417fbf368acd9c8a5 = $(`&lt;div id=&quot;html_77923d714ca0a96417fbf368acd9c8a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c0ebf8f1b72102ffd3c1eac8738d040b.setContent(html_77923d714ca0a96417fbf368acd9c8a5);
#
#
#
#         marker_3acffcca0a40113bb0a666986d906951.bindPopup(popup_c0ebf8f1b72102ffd3c1eac8738d040b)
#         ;
#
#
#
#
#             var marker_bb166538a3ee099531a882be43ae0959 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c56df2a96bc6c924b95b6f938da5902a);
#
#
#         var popup_0d881ce42de960c71f7113a6a09302e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18b2456358c7046058d5bb1b73d42e3b = $(`&lt;div id=&quot;html_18b2456358c7046058d5bb1b73d42e3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0d881ce42de960c71f7113a6a09302e4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_262ee1646bbaad288d416ee30adb1e14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_262ee1646bbaad288d416ee30adb1e14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_262ee1646bbaad288d416ee30adb1e14 = L.map(
#                 &quot;map_262ee1646bbaad288d416ee30adb1e14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b4afa27026ee09b2d85dcc4d6763a24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b4afa27026ee09b2d85dcc4d6763a24.addTo(map_262ee1646bbaad288d416ee30adb1e14);
#
#
#             var feature_group_eebba316c5685fedac7db4f8a4ba600c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4086b45fd15a6cdbd79c3b693cf52e36 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_eebba316c5685fedac7db4f8a4ba600c);
#
#
#         var popup_b00b3bcdfd0c61ea2d32986b2226e63c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_546d727ca764f4af386c7fdd329f5bab = $(`&lt;div id=&quot;html_546d727ca764f4af386c7fdd329f5bab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b00b3bcdfd0c61ea2d32986b2226e63c.setContent(html_546d727ca764f4af386c7fdd329f5bab);
#
#
#
#         marker_4086b45fd15a6cdbd79c3b693cf52e36.bindPopup(popup_b00b3bcdfd0c61ea2d32986b2226e63c)
#         ;
#
#
#
#
#             var marker_123d91c77a7fdc469660632e5231000c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_eebba316c5685fedac7db4f8a4ba600c);
#
#
#         var popup_642ccf103df33532ac26a577d69805bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc13d82cf5ecca6f7920e09bdccc079d = $(`&lt;div id=&quot;html_cc13d82cf5ecca6f7920e09bdccc079d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_642ccf103df33532ac26a577d69805bb.setContent(html_cc13d82cf5ecca6f7920e09bdccc079d);
#
#
#
#         marker_123d91c77a7fdc469660632e5231000c.bindPopup(popup_642ccf103df33532ac26a577d69805bb)
#         ;
#
#
#
#
#             var marker_f93318106006e4e21be34c0e6164bc79 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_eebba316c5685fedac7db4f8a4ba600c);
#
#
#         var popup_6d381a15db12a30eb48e3e7d199fbfba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_164ef77e19b8e087585a5f7d67c11822 = $(`&lt;div id=&quot;html_164ef77e19b8e087585a5f7d67c11822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6d381a15db12a30eb48e3e7d199fbfba.setContent(html_164ef77e19b8e087585a5f7d67c11822);
#
#
#
#         marker_f93318106006e4e21be34c0e6164bc79.bindPopup(popup_6d381a15db12a30eb48e3e7d199fbfba)
#         ;
#
#
#
#
#             var marker_4ae9d1924b4fd26e264392ec3b691914 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_eebba316c5685fedac7db4f8a4ba600c);
#
#
#         var popup_04ddfe4897afa8c2deb8afc0e13cc326 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac039b87ba4e8dbd6a7954b0124a539b = $(`&lt;div id=&quot;html_ac039b87ba4e8dbd6a7954b0124a539b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_04ddfe4897afa8c2deb8afc0e13cc326.setContent(html_ac039b87ba4e8dbd6a7954b0124a539b);
#
#
#
#         marker_4ae9d1924b4fd26e264392ec3b691914.bindPopup(popup_04ddfe4897afa8c2deb8afc0e13cc326)
#         ;
#
#
#
#
#             var marker_70758f065bd405e7a0e3cb44b6fd097a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_eebba316c5685fedac7db4f8a4ba600c);
#
#
#         var popup_54adf5dd8688291811aff5fe99181dbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0a61b8a5d881ab739f2da2b0edbbbf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0a61b8a5d881ab739f2da2b0edbbbf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0a61b8a5d881ab739f2da2b0edbbbf8 = L.map(
#                 &quot;map_a0a61b8a5d881ab739f2da2b0edbbbf8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2909eae69749a6a6246d5da64dcbc341 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2909eae69749a6a6246d5da64dcbc341.addTo(map_a0a61b8a5d881ab739f2da2b0edbbbf8);
#
#
#             var feature_group_8cf161287c2d64410ff76a4fdabacac8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8cf161287c2d64410ff76a4fdabacac8.addTo(map_a0a61b8a5d881ab739f2da2b0edbbbf8);
#
#
#             var feature_group_sub_group_bf40a00cac2b9399b607b3cbdab5ebad = L.featureGroup.subGroup(
#                 feature_group_8cf161287c2d64410ff76a4fdabacac8
#             );
#
#
#             var marker_a5563ae400ab15c179e18bd7d20b4b37 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf40a00cac2b9399b607b3cbdab5ebad);
#
#
#         var popup_140772448f94dc1ac49af43b6ecf4e36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c940f0438a2b468cd00c76b735a7fc13 = $(`&lt;div id=&quot;html_c940f0438a2b468cd00c76b735a7fc13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_140772448f94dc1ac49af43b6ecf4e36.setContent(html_c940f0438a2b468cd00c76b735a7fc13);
#
#
#
#         marker_a5563ae400ab15c179e18bd7d20b4b37.bindPopup(popup_140772448f94dc1ac49af43b6ecf4e36)
#         ;
#
#
#
#
#             var marker_1040e9f03b89dde26ea27a92bed2d099 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf40a00cac2b9399b607b3cbdab5ebad);
#
#
#         var popup_733b4927771b6173fadf6e6386ed4972 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da0f4771bdb5e5a52fb62d754ff4829b = $(`&lt;div id=&quot;html_da0f4771bdb5e5a52fb62d754ff4829b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_733b4927771b6173fadf6e6386ed4972.setContent(html_da0f4771bdb5e5a52fb62d754ff4829b);
#
#
#
#         marker_1040e9f03b89dde26ea27a92bed2d099.bindPopup(popup_733b4927771b6173fadf6e6386ed4972)
#         ;
#
#
#
#
#             var marker_bd9124725e63cc5903688c2e1744cbc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf40a00cac2b9399b607b3cbdab5ebad);
#
#
#         var popup_0e7c183f57b67e374db4c5fe2149fd6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_206d7202de97a831420f78353d2741f0 = $(`&lt;div id=&quot;html_206d7202de97a831420f78353d2741f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0e7c183f57b67e374db4c5fe2149fd6d.setContent(html_206d7202de97a831420f78353d2741f0);
#
#
#
#         marker_bd9124725e63cc5903688c2e1744cbc2.bindPopup(popup_0e7c183f57b67e374db4c5fe2149fd6d)
#         ;
#
#
#
#
#             var marker_e7d80160acb3d7fe4eb6889fe0016cf5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bf40a00cac2b9399b607b3cbdab5ebad);
#
#
#         var popup_3998cadadc82bb77c6999195262d080a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2a5edc4d4a8561097f9962caac29422 = $(`&lt;div id=&quot;html_d2a5edc4d4a8561097f9962caac29422&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3998cadadc82bb77c6999195262d080a.setContent(html_d2a5edc4d4a8561097f9962caac29422);
#
#
#
#         marker_
