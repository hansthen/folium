# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2aad55d8f0d0a7e1e02b88ef97212982 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2aad55d8f0d0a7e1e02b88ef97212982&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2aad55d8f0d0a7e1e02b88ef97212982 = L.map(
#                 &quot;map_2aad55d8f0d0a7e1e02b88ef97212982&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce836beaf73422d8b6d5a6268dd9b0ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce836beaf73422d8b6d5a6268dd9b0ae.addTo(map_2aad55d8f0d0a7e1e02b88ef97212982);
#
#
#             var marker_44077267b93b70cf5f74fe9dad18ee1e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2aad55d8f0d0a7e1e02b88ef97212982);
#
#
#         var popup_0eb42d95ec7b513c74c834c9f3fb0fab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ca005bb44beafe0cbcb5151d71c0a62 = $(`&lt;div id=&quot;html_9ca005bb44beafe0cbcb5151d71c0a62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0eb42d95ec7b513c74c834c9f3fb0fab.setContent(html_9ca005bb44beafe0cbcb5151d71c0a62);
#
#
#
#         marker_44077267b93b70cf5f74fe9dad18ee1e.bindPopup(popup_0eb42d95ec7b513c74c834c9f3fb0fab)
#         ;
#
#
#
#
#             var marker_6d6dad9d919d0d29e4636a17f331d407 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2aad55d8f0d0a7e1e02b88ef97212982);
#
#
#         var popup_59dd00882cc17c6c2773ebd3f88922f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_118d7aba61e93dc7eb401519ad471053 = $(`&lt;div id=&quot;html_118d7aba61e93dc7eb401519ad471053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_59dd00882cc17c6c2773ebd3f88922f1.setContent(html_118d7aba61e93dc7eb401519ad471053);
#
#
#
#         marker_6d6dad9d919d0d29e4636a17f331d407.bindPopup(popup_59dd00882cc17c6c2773ebd3f88922f1)
#         ;
#
#
#
#
#             var marker_c564a9721393b5385d8cf2165e556dd1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2aad55d8f0d0a7e1e02b88ef97212982);
#
#
#         var popup_178562eb4c7e1d118558103933b8edc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5fe0120348be47c25ad2ad1496a9e26 = $(`&lt;div id=&quot;html_c5fe0120348be47c25ad2ad1496a9e26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_178562eb4c7e1d118558103933b8edc5.setContent(html_c5fe0120348be47c25ad2ad1496a9e26);
#
#
#
#         marker_c564a9721393b5385d8cf2165e556dd1.bindPopup(popup_178562eb4c7e1d118558103933b8edc5)
#         ;
#
#
#
#
#             var marker_1beafed37018616426c73dee485d1fb1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2aad55d8f0d0a7e1e02b88ef97212982);
#
#
#         var popup_3d45878773a7c413de3ac976f6811dbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2909ca9294d6571133617668537e1361 = $(`&lt;div id=&quot;html_2909ca9294d6571133617668537e1361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3d45878773a7c413de3ac976f6811dbc.setContent(html_2909ca9294d6571133617668537e1361);
#
#
#
#         marker_1beafed37018616426c73dee485d1fb1.bindPopup(popup_3d45878773a7c413de3ac976f6811dbc)
#         ;
#
#
#
#
#             var marker_084640f4103b0a9676b20613e586faf4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2aad55d8f0d0a7e1e02b88ef97212982);
#
#
#         var popup_6cae3ecfb16101df3a5943faa138939f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48f8cf1057a83a436d3ad82442d4affa = $(`&lt;div id=&quot;html_48f8cf1057a83a436d3ad82442d4affa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6cae3ecfb16101df3a5943faa138939f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b177c8d8b702ce03f1f9b19a2dbd5ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b177c8d8b702ce03f1f9b19a2dbd5ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b177c8d8b702ce03f1f9b19a2dbd5ee = L.map(
#                 &quot;map_8b177c8d8b702ce03f1f9b19a2dbd5ee&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c46e28932b806223f31ea5ddd3097250 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c46e28932b806223f31ea5ddd3097250.addTo(map_8b177c8d8b702ce03f1f9b19a2dbd5ee);
#
#
#             var feature_group_44d00cb911532f3b75fc73fa809b081f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_88086de6c131d0be4ec3e8a50ae0930f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_44d00cb911532f3b75fc73fa809b081f);
#
#
#         var popup_6051a90a7a3da575667b5bfe02e08401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5e7e861a94ed4a519b5a4b27005e5eb = $(`&lt;div id=&quot;html_f5e7e861a94ed4a519b5a4b27005e5eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6051a90a7a3da575667b5bfe02e08401.setContent(html_f5e7e861a94ed4a519b5a4b27005e5eb);
#
#
#
#         marker_88086de6c131d0be4ec3e8a50ae0930f.bindPopup(popup_6051a90a7a3da575667b5bfe02e08401)
#         ;
#
#
#
#
#             var marker_c6b3ca3822386ab7b752edaeb1532501 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_44d00cb911532f3b75fc73fa809b081f);
#
#
#         var popup_81d8c6e94f65f25c95a5fb393c56a5a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f22d79b89642cfb6d549f885d068374d = $(`&lt;div id=&quot;html_f22d79b89642cfb6d549f885d068374d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_81d8c6e94f65f25c95a5fb393c56a5a8.setContent(html_f22d79b89642cfb6d549f885d068374d);
#
#
#
#         marker_c6b3ca3822386ab7b752edaeb1532501.bindPopup(popup_81d8c6e94f65f25c95a5fb393c56a5a8)
#         ;
#
#
#
#
#             var marker_6bf32fe30744a0e6602017203b5081d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_44d00cb911532f3b75fc73fa809b081f);
#
#
#         var popup_c115cd578cb98026b168042c69311bcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6ff0af7702179fa7b967982f269a147 = $(`&lt;div id=&quot;html_a6ff0af7702179fa7b967982f269a147&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c115cd578cb98026b168042c69311bcb.setContent(html_a6ff0af7702179fa7b967982f269a147);
#
#
#
#         marker_6bf32fe30744a0e6602017203b5081d0.bindPopup(popup_c115cd578cb98026b168042c69311bcb)
#         ;
#
#
#
#
#             var marker_87aa1448f501293c38a98ecce55d1e95 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_44d00cb911532f3b75fc73fa809b081f);
#
#
#         var popup_e665a1569029ba36216359ee994b964e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c7757efdd3e3a5b08634754e9c7a8b5 = $(`&lt;div id=&quot;html_4c7757efdd3e3a5b08634754e9c7a8b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e665a1569029ba36216359ee994b964e.setContent(html_4c7757efdd3e3a5b08634754e9c7a8b5);
#
#
#
#         marker_87aa1448f501293c38a98ecce55d1e95.bindPopup(popup_e665a1569029ba36216359ee994b964e)
#         ;
#
#
#
#
#             var marker_b0a9f505465b8c20ead7d370243027ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_44d00cb911532f3b75fc73fa809b081f);
#
#
#         var popup_a878ae260a32d5d4cdee152bfbc99088 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa1989b32b5d257a64635a6f4d383b31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa1989b32b5d257a64635a6f4d383b31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa1989b32b5d257a64635a6f4d383b31 = L.map(
#                 &quot;map_aa1989b32b5d257a64635a6f4d383b31&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f84beb5bc8751d56159e8c6a2d1b8e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07f84beb5bc8751d56159e8c6a2d1b8e.addTo(map_aa1989b32b5d257a64635a6f4d383b31);
#
#
#             var feature_group_d50e18f863149829d37f0891a55517ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d50e18f863149829d37f0891a55517ac.addTo(map_aa1989b32b5d257a64635a6f4d383b31);
#
#
#             var feature_group_sub_group_1f8403570f807e6a609f814d6a5bce54 = L.featureGroup.subGroup(
#                 feature_group_d50e18f863149829d37f0891a55517ac
#             );
#
#
#             var marker_d3a26df9e467041f8b6572d1ec94077b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8403570f807e6a609f814d6a5bce54);
#
#
#         var popup_a8c2acc5d36b8b2aa5aa2953e8bbadc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3c64e72ab90f74af66f93ba80da3d81 = $(`&lt;div id=&quot;html_c3c64e72ab90f74af66f93ba80da3d81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a8c2acc5d36b8b2aa5aa2953e8bbadc8.setContent(html_c3c64e72ab90f74af66f93ba80da3d81);
#
#
#
#         marker_d3a26df9e467041f8b6572d1ec94077b.bindPopup(popup_a8c2acc5d36b8b2aa5aa2953e8bbadc8)
#         ;
#
#
#
#
#             var marker_ab62b8a87bff0da72519e8dc152fdee1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8403570f807e6a609f814d6a5bce54);
#
#
#         var popup_53f38c50dca980240e88e60c0cc5a860 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50b261418c5c05ee0f50018327aa7d22 = $(`&lt;div id=&quot;html_50b261418c5c05ee0f50018327aa7d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_53f38c50dca980240e88e60c0cc5a860.setContent(html_50b261418c5c05ee0f50018327aa7d22);
#
#
#
#         marker_ab62b8a87bff0da72519e8dc152fdee1.bindPopup(popup_53f38c50dca980240e88e60c0cc5a860)
#         ;
#
#
#
#
#             var marker_5b6b207650b1df44acefd8b298829de0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8403570f807e6a609f814d6a5bce54);
#
#
#         var popup_c37e01a6e36391b7a61a2db63fd1cc60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97668b042bf20c0db99acad03aff4d73 = $(`&lt;div id=&quot;html_97668b042bf20c0db99acad03aff4d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c37e01a6e36391b7a61a2db63fd1cc60.setContent(html_97668b042bf20c0db99acad03aff4d73);
#
#
#
#         marker_5b6b207650b1df44acefd8b298829de0.bindPopup(popup_c37e01a6e36391b7a61a2db63fd1cc60)
#         ;
#
#
#
#
#             var marker_c1b747c3e3b3fdedeb51a8f560df0cf9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1f8403570f807e6a609f814d6a5bce54);
#
#
#         var popup_87cc9c5f5798b3b075fb03d3eccc200b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afe4a71044191ca66742dcf6d3a173a9 = $(`&lt;div id=&quot;html_afe4a71044191ca66742dcf6d3a173a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_87cc9c5f5798b3b075fb03d3eccc200b.setContent(html_afe4a71044191ca66742dcf6d3a173a9);
#
#
#
#         marker_
