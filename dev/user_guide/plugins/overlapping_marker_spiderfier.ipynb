# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_356bd18d1bbf6589b306213ca44940a9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_356bd18d1bbf6589b306213ca44940a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_356bd18d1bbf6589b306213ca44940a9 = L.map(
#                 &quot;map_356bd18d1bbf6589b306213ca44940a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b8f938caac7d09d882a3c66dd14b5ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b8f938caac7d09d882a3c66dd14b5ec.addTo(map_356bd18d1bbf6589b306213ca44940a9);
#
#
#             var marker_9438fb442a70439b9329c04cbd8cfe20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_356bd18d1bbf6589b306213ca44940a9);
#
#
#         var popup_45d62c616c456694e02b89e34ba83de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04182d641efcd436c6cda315ad232bd8 = $(`&lt;div id=&quot;html_04182d641efcd436c6cda315ad232bd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_45d62c616c456694e02b89e34ba83de3.setContent(html_04182d641efcd436c6cda315ad232bd8);
#
#
#
#         marker_9438fb442a70439b9329c04cbd8cfe20.bindPopup(popup_45d62c616c456694e02b89e34ba83de3)
#         ;
#
#
#
#
#             var marker_bd05377646bae8e0187148b81565c65a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_356bd18d1bbf6589b306213ca44940a9);
#
#
#         var popup_d90c413ac2ce76f3f29acae8b01e6a30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce335b62601cfd01ab07c5a69617d040 = $(`&lt;div id=&quot;html_ce335b62601cfd01ab07c5a69617d040&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d90c413ac2ce76f3f29acae8b01e6a30.setContent(html_ce335b62601cfd01ab07c5a69617d040);
#
#
#
#         marker_bd05377646bae8e0187148b81565c65a.bindPopup(popup_d90c413ac2ce76f3f29acae8b01e6a30)
#         ;
#
#
#
#
#             var marker_4b74f6f6cc8679a87816fa583e7ffb31 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_356bd18d1bbf6589b306213ca44940a9);
#
#
#         var popup_70d10e672b45b55558de93c6ed4cbcc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91af8f2e9ec22e67862a9630551f4ffe = $(`&lt;div id=&quot;html_91af8f2e9ec22e67862a9630551f4ffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_70d10e672b45b55558de93c6ed4cbcc3.setContent(html_91af8f2e9ec22e67862a9630551f4ffe);
#
#
#
#         marker_4b74f6f6cc8679a87816fa583e7ffb31.bindPopup(popup_70d10e672b45b55558de93c6ed4cbcc3)
#         ;
#
#
#
#
#             var marker_9ed4938cf4587d2f89222ac723efa531 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_356bd18d1bbf6589b306213ca44940a9);
#
#
#         var popup_0be60ea94a4ec96e3eba125b2b8dabdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_258576c9e6da50ac68e3e18f44a0feb5 = $(`&lt;div id=&quot;html_258576c9e6da50ac68e3e18f44a0feb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0be60ea94a4ec96e3eba125b2b8dabdf.setContent(html_258576c9e6da50ac68e3e18f44a0feb5);
#
#
#
#         marker_9ed4938cf4587d2f89222ac723efa531.bindPopup(popup_0be60ea94a4ec96e3eba125b2b8dabdf)
#         ;
#
#
#
#
#             var marker_7acfe6a8f23ea11e6dc9c368e398be70 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_356bd18d1bbf6589b306213ca44940a9);
#
#
#         var popup_9ccb308d83355cf5980a6796bf0f656f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05ca92ef06ab64c46692a7a8fcb38985 = $(`&lt;div id=&quot;html_05ca92ef06ab64c46692a7a8fcb38985&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9ccb308d83355cf5980a6796bf0f65

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e67893fb109042083a1931f73a761e33 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e67893fb109042083a1931f73a761e33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e67893fb109042083a1931f73a761e33 = L.map(
#                 &quot;map_e67893fb109042083a1931f73a761e33&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7324e725ad32ad8f4f9ed4f4d4ee3e79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7324e725ad32ad8f4f9ed4f4d4ee3e79.addTo(map_e67893fb109042083a1931f73a761e33);
#
#
#             var feature_group_76f40fbf95af3fc3b69702fde0a9d48e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8bfdfa2c5e94cd1cf5c81e1cec781f8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_76f40fbf95af3fc3b69702fde0a9d48e);
#
#
#         var popup_5e244d2c90e0893ea66e29742bdb6d39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14dfb2f68e95331fd0744219536500f3 = $(`&lt;div id=&quot;html_14dfb2f68e95331fd0744219536500f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5e244d2c90e0893ea66e29742bdb6d39.setContent(html_14dfb2f68e95331fd0744219536500f3);
#
#
#
#         marker_8bfdfa2c5e94cd1cf5c81e1cec781f8e.bindPopup(popup_5e244d2c90e0893ea66e29742bdb6d39)
#         ;
#
#
#
#
#             var marker_81444b46c5caf187d625f73e246d7558 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_76f40fbf95af3fc3b69702fde0a9d48e);
#
#
#         var popup_b9c049173d8d4acd53dd9353e02a9a2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2990a55b82087630090e464d4ebc3148 = $(`&lt;div id=&quot;html_2990a55b82087630090e464d4ebc3148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b9c049173d8d4acd53dd9353e02a9a2d.setContent(html_2990a55b82087630090e464d4ebc3148);
#
#
#
#         marker_81444b46c5caf187d625f73e246d7558.bindPopup(popup_b9c049173d8d4acd53dd9353e02a9a2d)
#         ;
#
#
#
#
#             var marker_4c6db4c7a63f7985526243b903b6d552 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_76f40fbf95af3fc3b69702fde0a9d48e);
#
#
#         var popup_3c89d9d2da143efbf2338549e6b62b5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c18220b3cdad27a2532c8a50e2ed8456 = $(`&lt;div id=&quot;html_c18220b3cdad27a2532c8a50e2ed8456&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3c89d9d2da143efbf2338549e6b62b5e.setContent(html_c18220b3cdad27a2532c8a50e2ed8456);
#
#
#
#         marker_4c6db4c7a63f7985526243b903b6d552.bindPopup(popup_3c89d9d2da143efbf2338549e6b62b5e)
#         ;
#
#
#
#
#             var marker_06ef0104b78868658beb6581cf95c26d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_76f40fbf95af3fc3b69702fde0a9d48e);
#
#
#         var popup_ef2db239cdae6919c31212d884d8f357 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7443e666e8d0094b9e194b02d6f1bc2 = $(`&lt;div id=&quot;html_d7443e666e8d0094b9e194b02d6f1bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef2db239cdae6919c31212d884d8f357.setContent(html_d7443e666e8d0094b9e194b02d6f1bc2);
#
#
#
#         marker_06ef0104b78868658beb6581cf95c26d.bindPopup(popup_ef2db239cdae6919c31212d884d8f357)
#         ;
#
#
#
#
#             var marker_965660fc97a8dee5ee362053c04748cd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_76f40fbf95af3fc3b69702fde0a9d48e);
#
#
#         var popup_d5aca91f83b5e985e64bc518122cbfda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_156be2633acc23ca9b4b284a7a1b703d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_156be2633acc23ca9b4b284a7a1b703d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_156be2633acc23ca9b4b284a7a1b703d = L.map(
#                 &quot;map_156be2633acc23ca9b4b284a7a1b703d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_650eba6316414cd5d6ceb843915d3a44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_650eba6316414cd5d6ceb843915d3a44.addTo(map_156be2633acc23ca9b4b284a7a1b703d);
#
#
#             var feature_group_a15475317a36df810e85797291470fea = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a15475317a36df810e85797291470fea.addTo(map_156be2633acc23ca9b4b284a7a1b703d);
#
#
#             var feature_group_sub_group_e995b102504a0661c5a8d7a0e14acbc3 = L.featureGroup.subGroup(
#                 feature_group_a15475317a36df810e85797291470fea
#             );
#
#
#             var marker_3b4e508184a87be69dd7e3d596944a2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e995b102504a0661c5a8d7a0e14acbc3);
#
#
#         var popup_695b6e957f58e32c22c02ecae6c1bc95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6e3212c280819ad02bca1ccccc591df = $(`&lt;div id=&quot;html_c6e3212c280819ad02bca1ccccc591df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_695b6e957f58e32c22c02ecae6c1bc95.setContent(html_c6e3212c280819ad02bca1ccccc591df);
#
#
#
#         marker_3b4e508184a87be69dd7e3d596944a2d.bindPopup(popup_695b6e957f58e32c22c02ecae6c1bc95)
#         ;
#
#
#
#
#             var marker_e32b2a071d8568c7c3e976bdeda732ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e995b102504a0661c5a8d7a0e14acbc3);
#
#
#         var popup_d43b9dc702a7ea53ef5f9a5211b152ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e89cf1cd78263080a3f126c3c0683c8a = $(`&lt;div id=&quot;html_e89cf1cd78263080a3f126c3c0683c8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d43b9dc702a7ea53ef5f9a5211b152ef.setContent(html_e89cf1cd78263080a3f126c3c0683c8a);
#
#
#
#         marker_e32b2a071d8568c7c3e976bdeda732ed.bindPopup(popup_d43b9dc702a7ea53ef5f9a5211b152ef)
#         ;
#
#
#
#
#             var marker_0ce4450164c1dc512a8ecc877f336f88 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e995b102504a0661c5a8d7a0e14acbc3);
#
#
#         var popup_f0db474a7cda7032ed97f0657a4fa968 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4a80c469fb1a1940e68a15f571b3049 = $(`&lt;div id=&quot;html_a4a80c469fb1a1940e68a15f571b3049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f0db474a7cda7032ed97f0657a4fa968.setContent(html_a4a80c469fb1a1940e68a15f571b3049);
#
#
#
#         marker_0ce4450164c1dc512a8ecc877f336f88.bindPopup(popup_f0db474a7cda7032ed97f0657a4fa968)
#         ;
#
#
#
#
#             var marker_b03c2e1e0c39a5af5419b7b5e709543d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e995b102504a0661c5a8d7a0e14acbc3);
#
#
#         var popup_cdbd4f3c491636eca4099a4c25e69887 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ada378b533fdb3613e6ab88aeb1c5e09 = $(`&lt;div id=&quot;html_ada378b533fdb3613e6ab88aeb1c5e09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cdbd4f3c491636eca4099a4c25e69887.setContent(html_ada378b533fdb3613e6ab88aeb1c5e09);
#
#
#
#         mark
