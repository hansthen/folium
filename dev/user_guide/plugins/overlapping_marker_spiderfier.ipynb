# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19c92dfdf8fd2d408d6219838963a4e5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19c92dfdf8fd2d408d6219838963a4e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19c92dfdf8fd2d408d6219838963a4e5 = L.map(
#                 &quot;map_19c92dfdf8fd2d408d6219838963a4e5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaa3da07f089a42a6340c8fe7fac1138 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eaa3da07f089a42a6340c8fe7fac1138.addTo(map_19c92dfdf8fd2d408d6219838963a4e5);
#
#
#             var marker_d07b1ae807d87596ec81c72a7ef6ab88 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_19c92dfdf8fd2d408d6219838963a4e5);
#
#
#         var popup_f5d7d29c8eebcb337ef4cd93e58bb1bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a065627865c08ea0dcec92851ab47c06 = $(`&lt;div id=&quot;html_a065627865c08ea0dcec92851ab47c06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f5d7d29c8eebcb337ef4cd93e58bb1bf.setContent(html_a065627865c08ea0dcec92851ab47c06);
#
#
#
#         marker_d07b1ae807d87596ec81c72a7ef6ab88.bindPopup(popup_f5d7d29c8eebcb337ef4cd93e58bb1bf)
#         ;
#
#
#
#
#             var marker_83d9af6d8947d986cc40cc36b1789368 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_19c92dfdf8fd2d408d6219838963a4e5);
#
#
#         var popup_0715bf66488a83dbf6ad54609d24cdad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec9a881d5e7a39754da79ce20aa7f2fa = $(`&lt;div id=&quot;html_ec9a881d5e7a39754da79ce20aa7f2fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0715bf66488a83dbf6ad54609d24cdad.setContent(html_ec9a881d5e7a39754da79ce20aa7f2fa);
#
#
#
#         marker_83d9af6d8947d986cc40cc36b1789368.bindPopup(popup_0715bf66488a83dbf6ad54609d24cdad)
#         ;
#
#
#
#
#             var marker_a36dbf4ccf64c6ad598c167634daa1c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_19c92dfdf8fd2d408d6219838963a4e5);
#
#
#         var popup_c821958792974efeb943197bd231613d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_186ba88cd23f7e11ebdcfbf66fa4d3bd = $(`&lt;div id=&quot;html_186ba88cd23f7e11ebdcfbf66fa4d3bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c821958792974efeb943197bd231613d.setContent(html_186ba88cd23f7e11ebdcfbf66fa4d3bd);
#
#
#
#         marker_a36dbf4ccf64c6ad598c167634daa1c1.bindPopup(popup_c821958792974efeb943197bd231613d)
#         ;
#
#
#
#
#             var marker_1b59c633b1163105ffe4640ae317938b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_19c92dfdf8fd2d408d6219838963a4e5);
#
#
#         var popup_255f2c283244148b38c74eb1c0d76b9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2c734b097ff811561ef8c2b4cdf1c3a = $(`&lt;div id=&quot;html_c2c734b097ff811561ef8c2b4cdf1c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_255f2c283244148b38c74eb1c0d76b9d.setContent(html_c2c734b097ff811561ef8c2b4cdf1c3a);
#
#
#
#         marker_1b59c633b1163105ffe4640ae317938b.bindPopup(popup_255f2c283244148b38c74eb1c0d76b9d)
#         ;
#
#
#
#
#             var marker_846dbd40438192b49677ba52f2240c54 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_19c92dfdf8fd2d408d6219838963a4e5);
#
#
#         var popup_150840662f28bca54bcca1dbda8d4c5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_581dbcd4483f7b7fdd531998d2390ef7 = $(`&lt;div id=&quot;html_581dbcd4483f7b7fdd531998d2390ef7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_150840662f28bca54bcca1dbda8d4c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e36788bf5417400ea617bc37578966a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e36788bf5417400ea617bc37578966a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e36788bf5417400ea617bc37578966a = L.map(
#                 &quot;map_3e36788bf5417400ea617bc37578966a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30ac3ba486cd10a725e83114e6da5067 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30ac3ba486cd10a725e83114e6da5067.addTo(map_3e36788bf5417400ea617bc37578966a);
#
#
#             var feature_group_653d35623b2f16a889fa96af6db5c1cb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fc177fc3297be60fb2671341fea89d4e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_653d35623b2f16a889fa96af6db5c1cb);
#
#
#         var popup_95b8423fd3e3b41bca78f441cbde62be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7810b1b0d5c28c7b69b84ee3aff709a1 = $(`&lt;div id=&quot;html_7810b1b0d5c28c7b69b84ee3aff709a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_95b8423fd3e3b41bca78f441cbde62be.setContent(html_7810b1b0d5c28c7b69b84ee3aff709a1);
#
#
#
#         marker_fc177fc3297be60fb2671341fea89d4e.bindPopup(popup_95b8423fd3e3b41bca78f441cbde62be)
#         ;
#
#
#
#
#             var marker_60ac51a13c1c48e8ffd7629174977f73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_653d35623b2f16a889fa96af6db5c1cb);
#
#
#         var popup_16e057c7ab027053ac766516762fbd8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3a92acbbfe98d24c07a9a434a743f0a = $(`&lt;div id=&quot;html_c3a92acbbfe98d24c07a9a434a743f0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_16e057c7ab027053ac766516762fbd8a.setContent(html_c3a92acbbfe98d24c07a9a434a743f0a);
#
#
#
#         marker_60ac51a13c1c48e8ffd7629174977f73.bindPopup(popup_16e057c7ab027053ac766516762fbd8a)
#         ;
#
#
#
#
#             var marker_45b14038c8b4579a6ea48e29f0dc84eb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_653d35623b2f16a889fa96af6db5c1cb);
#
#
#         var popup_7b8d98d5d2109f678838309dba561fd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ecafc82ffe2cd4d1bd29f359ea0d36e = $(`&lt;div id=&quot;html_5ecafc82ffe2cd4d1bd29f359ea0d36e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7b8d98d5d2109f678838309dba561fd1.setContent(html_5ecafc82ffe2cd4d1bd29f359ea0d36e);
#
#
#
#         marker_45b14038c8b4579a6ea48e29f0dc84eb.bindPopup(popup_7b8d98d5d2109f678838309dba561fd1)
#         ;
#
#
#
#
#             var marker_ad10c46bca44cda02bd3126c220fc7fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_653d35623b2f16a889fa96af6db5c1cb);
#
#
#         var popup_34e451c7349ca6c0160478c4ffd7b006 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dc4b42664ce87f9166b573dce025081 = $(`&lt;div id=&quot;html_0dc4b42664ce87f9166b573dce025081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_34e451c7349ca6c0160478c4ffd7b006.setContent(html_0dc4b42664ce87f9166b573dce025081);
#
#
#
#         marker_ad10c46bca44cda02bd3126c220fc7fd.bindPopup(popup_34e451c7349ca6c0160478c4ffd7b006)
#         ;
#
#
#
#
#             var marker_c94b8ba04e550b1554467091d4c24908 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_653d35623b2f16a889fa96af6db5c1cb);
#
#
#         var popup_3ddbc1a8d83d2f3fd89105026ccc4de9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8ff5c806e98dedaa1bd2cc4334ef66b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8ff5c806e98dedaa1bd2cc4334ef66b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8ff5c806e98dedaa1bd2cc4334ef66b = L.map(
#                 &quot;map_d8ff5c806e98dedaa1bd2cc4334ef66b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e25eff48f09c1248166a08bdc15f43e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e25eff48f09c1248166a08bdc15f43e.addTo(map_d8ff5c806e98dedaa1bd2cc4334ef66b);
#
#
#             var feature_group_7da6d86dc9e9188ab4f509ab1ccfe3b3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7da6d86dc9e9188ab4f509ab1ccfe3b3.addTo(map_d8ff5c806e98dedaa1bd2cc4334ef66b);
#
#
#             var feature_group_sub_group_18100ebf0644839cc80c77c47b66aaa7 = L.featureGroup.subGroup(
#                 feature_group_7da6d86dc9e9188ab4f509ab1ccfe3b3
#             );
#
#
#             var marker_44965014d338729291969881bdfe3a1b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_18100ebf0644839cc80c77c47b66aaa7);
#
#
#         var popup_6698feaff24a8a2a6bf976a4619b6c4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a3132a3801a0c4096930387552e9408 = $(`&lt;div id=&quot;html_6a3132a3801a0c4096930387552e9408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6698feaff24a8a2a6bf976a4619b6c4d.setContent(html_6a3132a3801a0c4096930387552e9408);
#
#
#
#         marker_44965014d338729291969881bdfe3a1b.bindPopup(popup_6698feaff24a8a2a6bf976a4619b6c4d)
#         ;
#
#
#
#
#             var marker_5f0ff918e8739b62bfe270483076f575 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_18100ebf0644839cc80c77c47b66aaa7);
#
#
#         var popup_d403cf94544b73f7da620e911c258a9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bba188795251e1a46196c2ef05664e99 = $(`&lt;div id=&quot;html_bba188795251e1a46196c2ef05664e99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d403cf94544b73f7da620e911c258a9e.setContent(html_bba188795251e1a46196c2ef05664e99);
#
#
#
#         marker_5f0ff918e8739b62bfe270483076f575.bindPopup(popup_d403cf94544b73f7da620e911c258a9e)
#         ;
#
#
#
#
#             var marker_04137f762782962fba541421d81e3a99 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_18100ebf0644839cc80c77c47b66aaa7);
#
#
#         var popup_1bbc6f6acb7dcb818016a16303f4f8ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f844db7537d5c76ba7dd7f4da510d91 = $(`&lt;div id=&quot;html_2f844db7537d5c76ba7dd7f4da510d91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1bbc6f6acb7dcb818016a16303f4f8ab.setContent(html_2f844db7537d5c76ba7dd7f4da510d91);
#
#
#
#         marker_04137f762782962fba541421d81e3a99.bindPopup(popup_1bbc6f6acb7dcb818016a16303f4f8ab)
#         ;
#
#
#
#
#             var marker_cfad7a119585784f65fec4e23bad3429 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_18100ebf0644839cc80c77c47b66aaa7);
#
#
#         var popup_1ffae39d4add101ac59dd9127699df70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c456b29e18f3a9b939c066cd46f3a61a = $(`&lt;div id=&quot;html_c456b29e18f3a9b939c066cd46f3a61a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1ffae39d4add101ac59dd9127699df70.setContent(html_c456b29e18f3a9b939c066cd46f3a61a);
#
#
#
#         mark
