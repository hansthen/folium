# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f34c1a5f2649bba8e0ffe2920333816 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f34c1a5f2649bba8e0ffe2920333816&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f34c1a5f2649bba8e0ffe2920333816 = L.map(
#                 &quot;map_1f34c1a5f2649bba8e0ffe2920333816&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a8096ca4f02e85e424d74f66a3748677 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a8096ca4f02e85e424d74f66a3748677.addTo(map_1f34c1a5f2649bba8e0ffe2920333816);
#
#
#             var marker_56b37eb9aa1dada3b28b11fcd1ce837c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1f34c1a5f2649bba8e0ffe2920333816);
#
#
#         var popup_623abd513f1bf29f3eb47bdbd1cca366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55124a86c875b4e6a2bc7f67f617d4a7 = $(`&lt;div id=&quot;html_55124a86c875b4e6a2bc7f67f617d4a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_623abd513f1bf29f3eb47bdbd1cca366.setContent(html_55124a86c875b4e6a2bc7f67f617d4a7);
#
#
#
#         marker_56b37eb9aa1dada3b28b11fcd1ce837c.bindPopup(popup_623abd513f1bf29f3eb47bdbd1cca366)
#         ;
#
#
#
#
#             var marker_9fa4b365d5ae131acdc74e1a4cc15fd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1f34c1a5f2649bba8e0ffe2920333816);
#
#
#         var popup_48161bde2e92eac0e2551fcd10dce5c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e075c6091cbb8d80a44e17af4532f75d = $(`&lt;div id=&quot;html_e075c6091cbb8d80a44e17af4532f75d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_48161bde2e92eac0e2551fcd10dce5c9.setContent(html_e075c6091cbb8d80a44e17af4532f75d);
#
#
#
#         marker_9fa4b365d5ae131acdc74e1a4cc15fd6.bindPopup(popup_48161bde2e92eac0e2551fcd10dce5c9)
#         ;
#
#
#
#
#             var marker_9538a6a977bc3f4107633e02ca547f41 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1f34c1a5f2649bba8e0ffe2920333816);
#
#
#         var popup_d0bbd871b1b9cfa26e9e35ee353516ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef2f5214b26d080001c05d3a09521c06 = $(`&lt;div id=&quot;html_ef2f5214b26d080001c05d3a09521c06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d0bbd871b1b9cfa26e9e35ee353516ca.setContent(html_ef2f5214b26d080001c05d3a09521c06);
#
#
#
#         marker_9538a6a977bc3f4107633e02ca547f41.bindPopup(popup_d0bbd871b1b9cfa26e9e35ee353516ca)
#         ;
#
#
#
#
#             var marker_e938982e5f563adc6e999691877955f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1f34c1a5f2649bba8e0ffe2920333816);
#
#
#         var popup_0682a335a620b91b8e509b710e7f8b86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9c6606096004707192a99351fa70562 = $(`&lt;div id=&quot;html_d9c6606096004707192a99351fa70562&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0682a335a620b91b8e509b710e7f8b86.setContent(html_d9c6606096004707192a99351fa70562);
#
#
#
#         marker_e938982e5f563adc6e999691877955f7.bindPopup(popup_0682a335a620b91b8e509b710e7f8b86)
#         ;
#
#
#
#
#             var marker_907731b66349ae706622bd1a0e817fed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1f34c1a5f2649bba8e0ffe2920333816);
#
#
#         var popup_fc30dcfd9b1519785d3dbbf5f77cdf7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6be18bc32a4c185df2e42369fbb76127 = $(`&lt;div id=&quot;html_6be18bc32a4c185df2e42369fbb76127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fc30dcfd9b1519785d3dbbf5f77cdf7f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d04c77ddf21e6d705295b8770140ea20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d04c77ddf21e6d705295b8770140ea20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d04c77ddf21e6d705295b8770140ea20 = L.map(
#                 &quot;map_d04c77ddf21e6d705295b8770140ea20&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed874012ce693a991fe9fc7300649c14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed874012ce693a991fe9fc7300649c14.addTo(map_d04c77ddf21e6d705295b8770140ea20);
#
#
#             var feature_group_57ef0cdda3f5873b5dea2ebe6afe9371 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a50b0d079ae5426c8c95050b52c4bbda = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_57ef0cdda3f5873b5dea2ebe6afe9371);
#
#
#         var popup_4c00a292d752677837e041b7284d40b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f7fa674b89efbaa4b1e4fc4d45198df = $(`&lt;div id=&quot;html_5f7fa674b89efbaa4b1e4fc4d45198df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4c00a292d752677837e041b7284d40b2.setContent(html_5f7fa674b89efbaa4b1e4fc4d45198df);
#
#
#
#         marker_a50b0d079ae5426c8c95050b52c4bbda.bindPopup(popup_4c00a292d752677837e041b7284d40b2)
#         ;
#
#
#
#
#             var marker_3edd2734b28227544edadd92b9aab574 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_57ef0cdda3f5873b5dea2ebe6afe9371);
#
#
#         var popup_1e39b69eac41c5a910cd955d5d95548a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0db0d73d4cc0d1cfcbcbbfbbdf4cf7a = $(`&lt;div id=&quot;html_d0db0d73d4cc0d1cfcbcbbfbbdf4cf7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1e39b69eac41c5a910cd955d5d95548a.setContent(html_d0db0d73d4cc0d1cfcbcbbfbbdf4cf7a);
#
#
#
#         marker_3edd2734b28227544edadd92b9aab574.bindPopup(popup_1e39b69eac41c5a910cd955d5d95548a)
#         ;
#
#
#
#
#             var marker_060ceddd681ed0f60021cc3b902eff5d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_57ef0cdda3f5873b5dea2ebe6afe9371);
#
#
#         var popup_d0e95679d73c783433642b72a9bf5d4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9260b058c296383ff28bfbc3e4a85e13 = $(`&lt;div id=&quot;html_9260b058c296383ff28bfbc3e4a85e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d0e95679d73c783433642b72a9bf5d4f.setContent(html_9260b058c296383ff28bfbc3e4a85e13);
#
#
#
#         marker_060ceddd681ed0f60021cc3b902eff5d.bindPopup(popup_d0e95679d73c783433642b72a9bf5d4f)
#         ;
#
#
#
#
#             var marker_f4a047394ce3caca836e0d7d3ef04961 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_57ef0cdda3f5873b5dea2ebe6afe9371);
#
#
#         var popup_d8b7073a1a4dd8aeb5693a7fd1655ed9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eb0ac52ddc5dd1b3305638720e3b92f = $(`&lt;div id=&quot;html_5eb0ac52ddc5dd1b3305638720e3b92f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d8b7073a1a4dd8aeb5693a7fd1655ed9.setContent(html_5eb0ac52ddc5dd1b3305638720e3b92f);
#
#
#
#         marker_f4a047394ce3caca836e0d7d3ef04961.bindPopup(popup_d8b7073a1a4dd8aeb5693a7fd1655ed9)
#         ;
#
#
#
#
#             var marker_4397dfe9cb28f788ee2affe6c658b766 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_57ef0cdda3f5873b5dea2ebe6afe9371);
#
#
#         var popup_a70afdb7df776bbb66b89436ad737f1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aee9c36ab8bdf231bbd21ce848d06955 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aee9c36ab8bdf231bbd21ce848d06955&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aee9c36ab8bdf231bbd21ce848d06955 = L.map(
#                 &quot;map_aee9c36ab8bdf231bbd21ce848d06955&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_780a0d125235dc9e5e3fa0bb5cc5bdca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_780a0d125235dc9e5e3fa0bb5cc5bdca.addTo(map_aee9c36ab8bdf231bbd21ce848d06955);
#
#
#             var feature_group_af76b94e5a1200a17d022023be3681d1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_af76b94e5a1200a17d022023be3681d1.addTo(map_aee9c36ab8bdf231bbd21ce848d06955);
#
#
#             var feature_group_sub_group_b87ba54ffc04a9520219373e671eebe8 = L.featureGroup.subGroup(
#                 feature_group_af76b94e5a1200a17d022023be3681d1
#             );
#
#
#             var marker_9746c1e5227d47ff10a1ad52c3bafca4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b87ba54ffc04a9520219373e671eebe8);
#
#
#         var popup_d83ad0a8a52bbe92b8a42ded61b96ca2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a65d440ab5203acc3d2622ea63f9ceff = $(`&lt;div id=&quot;html_a65d440ab5203acc3d2622ea63f9ceff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d83ad0a8a52bbe92b8a42ded61b96ca2.setContent(html_a65d440ab5203acc3d2622ea63f9ceff);
#
#
#
#         marker_9746c1e5227d47ff10a1ad52c3bafca4.bindPopup(popup_d83ad0a8a52bbe92b8a42ded61b96ca2)
#         ;
#
#
#
#
#             var marker_aa5faf8fc83ced3c4e92acfce92797a9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b87ba54ffc04a9520219373e671eebe8);
#
#
#         var popup_8c1f058f720e3d266de0abc5513a49ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5724054ed6ceda3e5be1e4b03d86cfc = $(`&lt;div id=&quot;html_e5724054ed6ceda3e5be1e4b03d86cfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8c1f058f720e3d266de0abc5513a49ae.setContent(html_e5724054ed6ceda3e5be1e4b03d86cfc);
#
#
#
#         marker_aa5faf8fc83ced3c4e92acfce92797a9.bindPopup(popup_8c1f058f720e3d266de0abc5513a49ae)
#         ;
#
#
#
#
#             var marker_2e57d1621e45d8a792bddbca979bdfe6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b87ba54ffc04a9520219373e671eebe8);
#
#
#         var popup_31dbbf7adf7162bd4c019caee957bf09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dbb5c77151ba457abc12633bb129892 = $(`&lt;div id=&quot;html_7dbb5c77151ba457abc12633bb129892&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_31dbbf7adf7162bd4c019caee957bf09.setContent(html_7dbb5c77151ba457abc12633bb129892);
#
#
#
#         marker_2e57d1621e45d8a792bddbca979bdfe6.bindPopup(popup_31dbbf7adf7162bd4c019caee957bf09)
#         ;
#
#
#
#
#             var marker_e5f0f76b333b51e7ecaf1cb1ccf68798 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b87ba54ffc04a9520219373e671eebe8);
#
#
#         var popup_7f8e334f51808dad8cb87016ab4fe043 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc4be7dcd86eb86fa33eac69859ae7f9 = $(`&lt;div id=&quot;html_dc4be7dcd86eb86fa33eac69859ae7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7f8e334f51808dad8cb87016ab4fe043.setContent(html_dc4be7dcd86eb86fa33eac69859ae7f9);
#
#
#
#         marker_
