# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8227a5015041649ecf44ac55ccb9b572 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8227a5015041649ecf44ac55ccb9b572&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8227a5015041649ecf44ac55ccb9b572 = L.map(
#                 &quot;map_8227a5015041649ecf44ac55ccb9b572&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_296bea38ff4459267fdb5e00f28ea291 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_296bea38ff4459267fdb5e00f28ea291.addTo(map_8227a5015041649ecf44ac55ccb9b572);
#
#
#             var marker_b8fe0c7cb425a0a7e904c479a205e0f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8227a5015041649ecf44ac55ccb9b572);
#
#
#         var popup_2da366a1758368d56ea55a1c401f9559 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6a1066556cb00743dd87ea8de9de86c = $(`&lt;div id=&quot;html_a6a1066556cb00743dd87ea8de9de86c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2da366a1758368d56ea55a1c401f9559.setContent(html_a6a1066556cb00743dd87ea8de9de86c);
#
#
#
#         marker_b8fe0c7cb425a0a7e904c479a205e0f3.bindPopup(popup_2da366a1758368d56ea55a1c401f9559)
#         ;
#
#
#
#
#             var marker_06f79dd9585acb5da0a5b889a9ae7acb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8227a5015041649ecf44ac55ccb9b572);
#
#
#         var popup_56c30fc70b588f5a804be4e3652bd20f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cf88fb96f83fae9ebbda6931013be93 = $(`&lt;div id=&quot;html_0cf88fb96f83fae9ebbda6931013be93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_56c30fc70b588f5a804be4e3652bd20f.setContent(html_0cf88fb96f83fae9ebbda6931013be93);
#
#
#
#         marker_06f79dd9585acb5da0a5b889a9ae7acb.bindPopup(popup_56c30fc70b588f5a804be4e3652bd20f)
#         ;
#
#
#
#
#             var marker_328b25f9aebb6047cdbda9c0977f7245 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8227a5015041649ecf44ac55ccb9b572);
#
#
#         var popup_7a82e862a18636945e4a671ad2b782cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c7dcde30ac14c9764d503bef03876f3 = $(`&lt;div id=&quot;html_5c7dcde30ac14c9764d503bef03876f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7a82e862a18636945e4a671ad2b782cf.setContent(html_5c7dcde30ac14c9764d503bef03876f3);
#
#
#
#         marker_328b25f9aebb6047cdbda9c0977f7245.bindPopup(popup_7a82e862a18636945e4a671ad2b782cf)
#         ;
#
#
#
#
#             var marker_4e385f36570e3a2d152e909153faa13b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8227a5015041649ecf44ac55ccb9b572);
#
#
#         var popup_e5528d8294f9cbdbbbb9e483463a7bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62455736167e25cdec79a7d8f232ff71 = $(`&lt;div id=&quot;html_62455736167e25cdec79a7d8f232ff71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e5528d8294f9cbdbbbb9e483463a7bfd.setContent(html_62455736167e25cdec79a7d8f232ff71);
#
#
#
#         marker_4e385f36570e3a2d152e909153faa13b.bindPopup(popup_e5528d8294f9cbdbbbb9e483463a7bfd)
#         ;
#
#
#
#
#             var marker_b71829add71fa70031b26f61686a2fcc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8227a5015041649ecf44ac55ccb9b572);
#
#
#         var popup_7e752840e1e661fbd3aa3e3afd00e606 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e79ced1c89f1e25d760b330693256014 = $(`&lt;div id=&quot;html_e79ced1c89f1e25d760b330693256014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7e752840e1e661fbd3aa3e3afd00e606.setContent(html_e79ced1c89f1e25d760b330693256014);
#
#
#
#         marker_b71829add71fa70031b26f61686a2fcc.bindPopup(popup_7e752840e1e661fbd3aa3e3afd00e606)
#         ;
#
#
#
#
#             var marker_9e63e1ee99

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ada699841f7242674b9cb585b483b9d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ada699841f7242674b9cb585b483b9d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ada699841f7242674b9cb585b483b9d2 = L.map(
#                 &quot;map_ada699841f7242674b9cb585b483b9d2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59353108447bf19500000d2e971dd92b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59353108447bf19500000d2e971dd92b.addTo(map_ada699841f7242674b9cb585b483b9d2);
#
#
#             var feature_group_605bb6ec4f86bb5fb293c4cdd66fc7ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d0299e9d0b7987db42b796327581e7a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_605bb6ec4f86bb5fb293c4cdd66fc7ee);
#
#
#         var popup_54a07bd507732b65126442f190a52d5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e718150779227c1fcb09ede8d7a06acb = $(`&lt;div id=&quot;html_e718150779227c1fcb09ede8d7a06acb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_54a07bd507732b65126442f190a52d5a.setContent(html_e718150779227c1fcb09ede8d7a06acb);
#
#
#
#         marker_d0299e9d0b7987db42b796327581e7a3.bindPopup(popup_54a07bd507732b65126442f190a52d5a)
#         ;
#
#
#
#
#             var marker_79d7ac532080ac896b5b4eb0b8abcecd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_605bb6ec4f86bb5fb293c4cdd66fc7ee);
#
#
#         var popup_0a6c1c84264f841ef74e9a0511ff7503 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94219796fd70a4a1fa8b36de59767e5f = $(`&lt;div id=&quot;html_94219796fd70a4a1fa8b36de59767e5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0a6c1c84264f841ef74e9a0511ff7503.setContent(html_94219796fd70a4a1fa8b36de59767e5f);
#
#
#
#         marker_79d7ac532080ac896b5b4eb0b8abcecd.bindPopup(popup_0a6c1c84264f841ef74e9a0511ff7503)
#         ;
#
#
#
#
#             var marker_1a827ff9bef6c2eb997e0864fc85bfa6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_605bb6ec4f86bb5fb293c4cdd66fc7ee);
#
#
#         var popup_b6c0cc43c3830d6ddf10d464b1d339db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6455a5ab37a550cd49e275722f7286c = $(`&lt;div id=&quot;html_b6455a5ab37a550cd49e275722f7286c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b6c0cc43c3830d6ddf10d464b1d339db.setContent(html_b6455a5ab37a550cd49e275722f7286c);
#
#
#
#         marker_1a827ff9bef6c2eb997e0864fc85bfa6.bindPopup(popup_b6c0cc43c3830d6ddf10d464b1d339db)
#         ;
#
#
#
#
#             var marker_6814df35edde1f1b27290da0d01e131f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_605bb6ec4f86bb5fb293c4cdd66fc7ee);
#
#
#         var popup_88f743f99e0370cba9947a61ff80347a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dfb665e24e71b5cd02125e73810ddf5 = $(`&lt;div id=&quot;html_9dfb665e24e71b5cd02125e73810ddf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_88f743f99e0370cba9947a61ff80347a.setContent(html_9dfb665e24e71b5cd02125e73810ddf5);
#
#
#
#         marker_6814df35edde1f1b27290da0d01e131f.bindPopup(popup_88f743f99e0370cba9947a61ff80347a)
#         ;
#
#
#
#
#             var marker_b1333c9b0bf7f276005d4e585f34ef11 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_605bb6ec4f86bb5fb293c4cdd66fc7ee);
#
#
#         var popup_beecc160b0fca0fdfdb9c41ab05eabcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb8c0d2248de5d2d34cdc6ee07422c27 = $(`&lt;div id=&quot;html_eb8c0d2248de5d2d34cdc6ee07422c27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_beecc160b0fca0fdfd

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b043d026778af9ace0a6eb1eba7cd09b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b043d026778af9ace0a6eb1eba7cd09b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b043d026778af9ace0a6eb1eba7cd09b = L.map(
#                 &quot;map_b043d026778af9ace0a6eb1eba7cd09b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94f15ec7ec327a406dfc30c03972c39b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94f15ec7ec327a406dfc30c03972c39b.addTo(map_b043d026778af9ace0a6eb1eba7cd09b);
#
#
#             var feature_group_12a5a6f79276e723af5fff29709792e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_12a5a6f79276e723af5fff29709792e8.addTo(map_b043d026778af9ace0a6eb1eba7cd09b);
#
#
#             var feature_group_sub_group_fd45e41fd579de189f53966dfe1a2c46 = L.featureGroup.subGroup(
#                 feature_group_12a5a6f79276e723af5fff29709792e8
#             );
#
#
#             var marker_f7f3d50c660e0a6e9b1fe725c6a32ce7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd45e41fd579de189f53966dfe1a2c46);
#
#
#         var popup_6f32c94b194ac3f99b0258a7e1ee6741 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9a0bad8db909387f6db44e623784e01 = $(`&lt;div id=&quot;html_d9a0bad8db909387f6db44e623784e01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6f32c94b194ac3f99b0258a7e1ee6741.setContent(html_d9a0bad8db909387f6db44e623784e01);
#
#
#
#         marker_f7f3d50c660e0a6e9b1fe725c6a32ce7.bindPopup(popup_6f32c94b194ac3f99b0258a7e1ee6741)
#         ;
#
#
#
#
#             var marker_8dc038cf29a9a343cdab771ebe0d1b02 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd45e41fd579de189f53966dfe1a2c46);
#
#
#         var popup_d25e5c30226a8cd67239c30fa5556010 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dae560016e7320da4084de3e1e452b4f = $(`&lt;div id=&quot;html_dae560016e7320da4084de3e1e452b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d25e5c30226a8cd67239c30fa5556010.setContent(html_dae560016e7320da4084de3e1e452b4f);
#
#
#
#         marker_8dc038cf29a9a343cdab771ebe0d1b02.bindPopup(popup_d25e5c30226a8cd67239c30fa5556010)
#         ;
#
#
#
#
#             var marker_36d17caae5e38d333f7c1622ddf15259 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd45e41fd579de189f53966dfe1a2c46);
#
#
#         var popup_0e1a6989cdfcd2bb9f565aa13fec58a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28b563d8162ee1ab79eadca7e5cc48bf = $(`&lt;div id=&quot;html_28b563d8162ee1ab79eadca7e5cc48bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0e1a6989cdfcd2bb9f565aa13fec58a5.setContent(html_28b563d8162ee1ab79eadca7e5cc48bf);
#
#
#
#         marker_36d17caae5e38d333f7c1622ddf15259.bindPopup(popup_0e1a6989cdfcd2bb9f565aa13fec58a5)
#         ;
#
#
#
#
#             var marker_e4d9c9cd1eb4ee0b110d2d28c5eefbc7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd45e41fd579de189f53966dfe1a2c46);
#
#
#         var popup_e2e7fe739cefd27945d3b7677bce9e42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c31ea42bc48db780c37a20885fc242c3 = $(`&lt;div id=&quot;html_c31ea42bc48db780c37a20885fc242c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e2e7fe739cefd27945d3b7677bce9e42.setContent(html_c31ea42bc48db780c37a20885fc242c3);
#
#
#
#         marker_e4d9c9cd1eb4ee0b110d2d28c5eefbc7.bindPopup(popup_e2e7fe739cefd27945d3b7677bce9e42)
#         ;
#
#
#
#
#             var marker_26f5df03e4f43924b0eacbad41ffcbcd = L.marker(
#                 [45.050399999999996, 3.0504],
