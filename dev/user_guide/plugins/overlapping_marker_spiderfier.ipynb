# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_786b5febd5c226cd0816d0e5e4b42756 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_786b5febd5c226cd0816d0e5e4b42756&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_786b5febd5c226cd0816d0e5e4b42756 = L.map(
#                 &quot;map_786b5febd5c226cd0816d0e5e4b42756&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_437a701acfa67bb774ba66a00b4472aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_437a701acfa67bb774ba66a00b4472aa.addTo(map_786b5febd5c226cd0816d0e5e4b42756);
#
#
#             var marker_37cb1bfb9fb6cb6b9f1c3600391d363e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_786b5febd5c226cd0816d0e5e4b42756);
#
#
#         var popup_427f42a2eecd8c83c1518c297a75cb9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbb39383065f5cb44c9eb4f4d798b1d1 = $(`&lt;div id=&quot;html_fbb39383065f5cb44c9eb4f4d798b1d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_427f42a2eecd8c83c1518c297a75cb9a.setContent(html_fbb39383065f5cb44c9eb4f4d798b1d1);
#
#
#
#         marker_37cb1bfb9fb6cb6b9f1c3600391d363e.bindPopup(popup_427f42a2eecd8c83c1518c297a75cb9a)
#         ;
#
#
#
#
#             var marker_42a6658a240d4d32fd31bf600809d31e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_786b5febd5c226cd0816d0e5e4b42756);
#
#
#         var popup_07581a4048b83ea1dbc27eb4e80c8d51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5577ef0d0392c10fdd4a11214bbb7cdc = $(`&lt;div id=&quot;html_5577ef0d0392c10fdd4a11214bbb7cdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_07581a4048b83ea1dbc27eb4e80c8d51.setContent(html_5577ef0d0392c10fdd4a11214bbb7cdc);
#
#
#
#         marker_42a6658a240d4d32fd31bf600809d31e.bindPopup(popup_07581a4048b83ea1dbc27eb4e80c8d51)
#         ;
#
#
#
#
#             var marker_0f21ba7cfcd40621d75ff2a962447f9e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_786b5febd5c226cd0816d0e5e4b42756);
#
#
#         var popup_eef307d6ae2c72fa18a0bca2b684b33c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e3ec0645b58a59be13e7222a60fa499 = $(`&lt;div id=&quot;html_9e3ec0645b58a59be13e7222a60fa499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_eef307d6ae2c72fa18a0bca2b684b33c.setContent(html_9e3ec0645b58a59be13e7222a60fa499);
#
#
#
#         marker_0f21ba7cfcd40621d75ff2a962447f9e.bindPopup(popup_eef307d6ae2c72fa18a0bca2b684b33c)
#         ;
#
#
#
#
#             var marker_2544e378cc753519c30ae48e780f7264 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_786b5febd5c226cd0816d0e5e4b42756);
#
#
#         var popup_6b5d7a8622ca13dfe6cf60c3ec449e2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9cefa12d34d19681671309547b3025a5 = $(`&lt;div id=&quot;html_9cefa12d34d19681671309547b3025a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6b5d7a8622ca13dfe6cf60c3ec449e2c.setContent(html_9cefa12d34d19681671309547b3025a5);
#
#
#
#         marker_2544e378cc753519c30ae48e780f7264.bindPopup(popup_6b5d7a8622ca13dfe6cf60c3ec449e2c)
#         ;
#
#
#
#
#             var marker_22a58a63d0c7087b27c18f55812c76d0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_786b5febd5c226cd0816d0e5e4b42756);
#
#
#         var popup_91177234dcf657ba15af154fcb17b683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4547c22b5ad572749531cf1e974cbf11 = $(`&lt;div id=&quot;html_4547c22b5ad572749531cf1e974cbf11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_91177234dcf657ba15af154fcb17b6

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f191f3ec5f6f22e22fa7742fb73bea53 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f191f3ec5f6f22e22fa7742fb73bea53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f191f3ec5f6f22e22fa7742fb73bea53 = L.map(
#                 &quot;map_f191f3ec5f6f22e22fa7742fb73bea53&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91bbf29c4f440791012c9455fc4d9f70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91bbf29c4f440791012c9455fc4d9f70.addTo(map_f191f3ec5f6f22e22fa7742fb73bea53);
#
#
#             var feature_group_1d9b6b8b06a4ded7647d8b2321417844 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a1eab8fa96e6de8913a215c5aa8cca92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1d9b6b8b06a4ded7647d8b2321417844);
#
#
#         var popup_c4a21324466bc3b8dbb9ffb1a5ced7db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_897130cb5ef395f4186e3a27fc7edeaa = $(`&lt;div id=&quot;html_897130cb5ef395f4186e3a27fc7edeaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c4a21324466bc3b8dbb9ffb1a5ced7db.setContent(html_897130cb5ef395f4186e3a27fc7edeaa);
#
#
#
#         marker_a1eab8fa96e6de8913a215c5aa8cca92.bindPopup(popup_c4a21324466bc3b8dbb9ffb1a5ced7db)
#         ;
#
#
#
#
#             var marker_c82db4aeb8138c14b0fe44b2f0b0fa3a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1d9b6b8b06a4ded7647d8b2321417844);
#
#
#         var popup_df823a4a4529d0665402cab77c59fada = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c9e8eab863fcce0bf4ac0b745f2c74 = $(`&lt;div id=&quot;html_f5c9e8eab863fcce0bf4ac0b745f2c74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_df823a4a4529d0665402cab77c59fada.setContent(html_f5c9e8eab863fcce0bf4ac0b745f2c74);
#
#
#
#         marker_c82db4aeb8138c14b0fe44b2f0b0fa3a.bindPopup(popup_df823a4a4529d0665402cab77c59fada)
#         ;
#
#
#
#
#             var marker_6dae98bdc9542d5443e21af1163bc589 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1d9b6b8b06a4ded7647d8b2321417844);
#
#
#         var popup_607973aa6cfc0a1a9d7cefa513ceb96a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fc3dabe194de2ff51a28925b5d57dd2 = $(`&lt;div id=&quot;html_6fc3dabe194de2ff51a28925b5d57dd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_607973aa6cfc0a1a9d7cefa513ceb96a.setContent(html_6fc3dabe194de2ff51a28925b5d57dd2);
#
#
#
#         marker_6dae98bdc9542d5443e21af1163bc589.bindPopup(popup_607973aa6cfc0a1a9d7cefa513ceb96a)
#         ;
#
#
#
#
#             var marker_e3144ff076fbbf6ac7095c686cb97c65 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1d9b6b8b06a4ded7647d8b2321417844);
#
#
#         var popup_ad1bb94829bafb326f747d3f6c1015c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22b7b7bad5760bc5504d5ec65baa9dc0 = $(`&lt;div id=&quot;html_22b7b7bad5760bc5504d5ec65baa9dc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ad1bb94829bafb326f747d3f6c1015c7.setContent(html_22b7b7bad5760bc5504d5ec65baa9dc0);
#
#
#
#         marker_e3144ff076fbbf6ac7095c686cb97c65.bindPopup(popup_ad1bb94829bafb326f747d3f6c1015c7)
#         ;
#
#
#
#
#             var marker_7be87c705ec41029e1cb17a5845a3a43 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1d9b6b8b06a4ded7647d8b2321417844);
#
#
#         var popup_aabc3fcfd6aef620c0e6cbbf1d231c6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ae03720cd363a7296b31b6ade1dd2bc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ae03720cd363a7296b31b6ade1dd2bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ae03720cd363a7296b31b6ade1dd2bc = L.map(
#                 &quot;map_2ae03720cd363a7296b31b6ade1dd2bc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dce05615e2b72fd0a9f8933b80721d80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dce05615e2b72fd0a9f8933b80721d80.addTo(map_2ae03720cd363a7296b31b6ade1dd2bc);
#
#
#             var feature_group_3450a817d569c26c5aaeae829aab438a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3450a817d569c26c5aaeae829aab438a.addTo(map_2ae03720cd363a7296b31b6ade1dd2bc);
#
#
#             var feature_group_sub_group_d984432b3bdf5e1da4d8f9a9215ea17f = L.featureGroup.subGroup(
#                 feature_group_3450a817d569c26c5aaeae829aab438a
#             );
#
#
#             var marker_94c6ac96bfa6948e264bb8d0362a0b80 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d984432b3bdf5e1da4d8f9a9215ea17f);
#
#
#         var popup_dca9022f60355ca0b4b0660dd424dcc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_695b702b7ce6bedacb3bf311fa5e364c = $(`&lt;div id=&quot;html_695b702b7ce6bedacb3bf311fa5e364c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dca9022f60355ca0b4b0660dd424dcc2.setContent(html_695b702b7ce6bedacb3bf311fa5e364c);
#
#
#
#         marker_94c6ac96bfa6948e264bb8d0362a0b80.bindPopup(popup_dca9022f60355ca0b4b0660dd424dcc2)
#         ;
#
#
#
#
#             var marker_722b4bd98cc4047db3e36a85e73de071 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d984432b3bdf5e1da4d8f9a9215ea17f);
#
#
#         var popup_492ea814cfa63ba4b402ddbe2d9ddc69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48e849f2886b73c2dbf7ad964511439b = $(`&lt;div id=&quot;html_48e849f2886b73c2dbf7ad964511439b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_492ea814cfa63ba4b402ddbe2d9ddc69.setContent(html_48e849f2886b73c2dbf7ad964511439b);
#
#
#
#         marker_722b4bd98cc4047db3e36a85e73de071.bindPopup(popup_492ea814cfa63ba4b402ddbe2d9ddc69)
#         ;
#
#
#
#
#             var marker_9fce6ea829e9bf986d99a7fde7b605fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d984432b3bdf5e1da4d8f9a9215ea17f);
#
#
#         var popup_e0d08fa57e7dc0c6f7a2d155153db96e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e9780f30f90f024ae5aac8d8a6d722f = $(`&lt;div id=&quot;html_4e9780f30f90f024ae5aac8d8a6d722f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e0d08fa57e7dc0c6f7a2d155153db96e.setContent(html_4e9780f30f90f024ae5aac8d8a6d722f);
#
#
#
#         marker_9fce6ea829e9bf986d99a7fde7b605fb.bindPopup(popup_e0d08fa57e7dc0c6f7a2d155153db96e)
#         ;
#
#
#
#
#             var marker_33580e49d1359c9d1904391151a59a72 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d984432b3bdf5e1da4d8f9a9215ea17f);
#
#
#         var popup_0111741a71fa1b7eb1b677667352367c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34382aab31506b8351e35a8519b7e1af = $(`&lt;div id=&quot;html_34382aab31506b8351e35a8519b7e1af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0111741a71fa1b7eb1b677667352367c.setContent(html_34382aab31506b8351e35a8519b7e1af);
#
#
#
#         mark
