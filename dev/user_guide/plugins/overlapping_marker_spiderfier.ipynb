# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_044ef27492295c887d97468440150c90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_044ef27492295c887d97468440150c90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_044ef27492295c887d97468440150c90 = L.map(
#                 &quot;map_044ef27492295c887d97468440150c90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bf569785ea019ce0fccf670a26a9790 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bf569785ea019ce0fccf670a26a9790.addTo(map_044ef27492295c887d97468440150c90);
#
#
#             var marker_63068975f1142dacc79c899e517e3632 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_044ef27492295c887d97468440150c90);
#
#
#         var popup_a46f9442c7b11655caff89f0ed285e12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c44251570d2954347843d53efb6bde4c = $(`&lt;div id=&quot;html_c44251570d2954347843d53efb6bde4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a46f9442c7b11655caff89f0ed285e12.setContent(html_c44251570d2954347843d53efb6bde4c);
#
#
#
#         marker_63068975f1142dacc79c899e517e3632.bindPopup(popup_a46f9442c7b11655caff89f0ed285e12)
#         ;
#
#
#
#
#             var marker_c945cc5367087070e907a66e8b9abfcf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_044ef27492295c887d97468440150c90);
#
#
#         var popup_3c9e043cc9d17587bd722ad5ffbe955b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_214f1ca26117d51334a53d34db874d73 = $(`&lt;div id=&quot;html_214f1ca26117d51334a53d34db874d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3c9e043cc9d17587bd722ad5ffbe955b.setContent(html_214f1ca26117d51334a53d34db874d73);
#
#
#
#         marker_c945cc5367087070e907a66e8b9abfcf.bindPopup(popup_3c9e043cc9d17587bd722ad5ffbe955b)
#         ;
#
#
#
#
#             var marker_17557d6aed79daacb50d076bcbe0ce7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_044ef27492295c887d97468440150c90);
#
#
#         var popup_1b160d11a080a53278656f4778048f93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_101ed720e1d119c15f8ae1231fa27105 = $(`&lt;div id=&quot;html_101ed720e1d119c15f8ae1231fa27105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1b160d11a080a53278656f4778048f93.setContent(html_101ed720e1d119c15f8ae1231fa27105);
#
#
#
#         marker_17557d6aed79daacb50d076bcbe0ce7e.bindPopup(popup_1b160d11a080a53278656f4778048f93)
#         ;
#
#
#
#
#             var marker_2ea0640024237f8701ad6f0e9db8e5f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_044ef27492295c887d97468440150c90);
#
#
#         var popup_d372f5f0a6979d3479cb3b5448002513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5a1d254d288001a6a21ab37853af526 = $(`&lt;div id=&quot;html_b5a1d254d288001a6a21ab37853af526&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d372f5f0a6979d3479cb3b5448002513.setContent(html_b5a1d254d288001a6a21ab37853af526);
#
#
#
#         marker_2ea0640024237f8701ad6f0e9db8e5f2.bindPopup(popup_d372f5f0a6979d3479cb3b5448002513)
#         ;
#
#
#
#
#             var marker_711432637522ee22a78ebf2d524e56ca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_044ef27492295c887d97468440150c90);
#
#
#         var popup_1fa832c7ac1c54500122d8a3e81cc380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c361305ba2fa29fed200ff26a97cf693 = $(`&lt;div id=&quot;html_c361305ba2fa29fed200ff26a97cf693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1fa832c7ac1c54500122d8a3e81cc380.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d52c83f3469f657bdb0a8393905107e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d52c83f3469f657bdb0a8393905107e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d52c83f3469f657bdb0a8393905107e2 = L.map(
#                 &quot;map_d52c83f3469f657bdb0a8393905107e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca93562780208bcacd245c40b381be08 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca93562780208bcacd245c40b381be08.addTo(map_d52c83f3469f657bdb0a8393905107e2);
#
#
#             var feature_group_0045b119cc7e819c7884a8b70db20617 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_64adc03673e9ce93e805f5823ac2d199 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0045b119cc7e819c7884a8b70db20617);
#
#
#         var popup_62c85042e5e86d5283f2628d89898897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8c633452301c8bbf30121a01d211d3b = $(`&lt;div id=&quot;html_b8c633452301c8bbf30121a01d211d3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_62c85042e5e86d5283f2628d89898897.setContent(html_b8c633452301c8bbf30121a01d211d3b);
#
#
#
#         marker_64adc03673e9ce93e805f5823ac2d199.bindPopup(popup_62c85042e5e86d5283f2628d89898897)
#         ;
#
#
#
#
#             var marker_17d08c98e5321894160564036f686478 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0045b119cc7e819c7884a8b70db20617);
#
#
#         var popup_164637740a9f2c65e45c8d12f04e3b65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07bdad2b70ac573cce842c9b7de15fbf = $(`&lt;div id=&quot;html_07bdad2b70ac573cce842c9b7de15fbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_164637740a9f2c65e45c8d12f04e3b65.setContent(html_07bdad2b70ac573cce842c9b7de15fbf);
#
#
#
#         marker_17d08c98e5321894160564036f686478.bindPopup(popup_164637740a9f2c65e45c8d12f04e3b65)
#         ;
#
#
#
#
#             var marker_9cbcefa9204232e3a92e40f095851920 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0045b119cc7e819c7884a8b70db20617);
#
#
#         var popup_9481f69851e9a13424432322f9e23e82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e60e3f619ae736e2235fa71da61a00 = $(`&lt;div id=&quot;html_04e60e3f619ae736e2235fa71da61a00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9481f69851e9a13424432322f9e23e82.setContent(html_04e60e3f619ae736e2235fa71da61a00);
#
#
#
#         marker_9cbcefa9204232e3a92e40f095851920.bindPopup(popup_9481f69851e9a13424432322f9e23e82)
#         ;
#
#
#
#
#             var marker_d4d863b9ac58de3e1dc59dc8bdfe6418 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0045b119cc7e819c7884a8b70db20617);
#
#
#         var popup_aaa166a31b17736e57e31f42b0011b75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_136b4b8701c7f7c0567b52910b18c6dd = $(`&lt;div id=&quot;html_136b4b8701c7f7c0567b52910b18c6dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aaa166a31b17736e57e31f42b0011b75.setContent(html_136b4b8701c7f7c0567b52910b18c6dd);
#
#
#
#         marker_d4d863b9ac58de3e1dc59dc8bdfe6418.bindPopup(popup_aaa166a31b17736e57e31f42b0011b75)
#         ;
#
#
#
#
#             var marker_49bc2d313e78a75386ba5265dc7e588c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0045b119cc7e819c7884a8b70db20617);
#
#
#         var popup_6b96479542270c19205b2e83db7491e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb786e220025a0d454d6b2b043d61ff3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb786e220025a0d454d6b2b043d61ff3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb786e220025a0d454d6b2b043d61ff3 = L.map(
#                 &quot;map_eb786e220025a0d454d6b2b043d61ff3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51c27795deeae3fdbeb6351fc8cfb2bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51c27795deeae3fdbeb6351fc8cfb2bc.addTo(map_eb786e220025a0d454d6b2b043d61ff3);
#
#
#             var feature_group_83c18ee2d18c86d3eb796edb662b1f9a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_83c18ee2d18c86d3eb796edb662b1f9a.addTo(map_eb786e220025a0d454d6b2b043d61ff3);
#
#
#             var feature_group_sub_group_b3400771bbd91e9f0751430ad6e97029 = L.featureGroup.subGroup(
#                 feature_group_83c18ee2d18c86d3eb796edb662b1f9a
#             );
#
#
#             var marker_f8e344fc4a704847d41272e27afae1c2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3400771bbd91e9f0751430ad6e97029);
#
#
#         var popup_b076b7627af4a2d814a0231bf9a4ca3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea0ef03ff4292d29641ac42a23da5c32 = $(`&lt;div id=&quot;html_ea0ef03ff4292d29641ac42a23da5c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b076b7627af4a2d814a0231bf9a4ca3d.setContent(html_ea0ef03ff4292d29641ac42a23da5c32);
#
#
#
#         marker_f8e344fc4a704847d41272e27afae1c2.bindPopup(popup_b076b7627af4a2d814a0231bf9a4ca3d)
#         ;
#
#
#
#
#             var marker_8735c6b75ca760096235e883094547ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3400771bbd91e9f0751430ad6e97029);
#
#
#         var popup_379046fb3507328515ca3a2c38945c41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dd1272c90597b2fd5235c88f78842e3 = $(`&lt;div id=&quot;html_8dd1272c90597b2fd5235c88f78842e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_379046fb3507328515ca3a2c38945c41.setContent(html_8dd1272c90597b2fd5235c88f78842e3);
#
#
#
#         marker_8735c6b75ca760096235e883094547ee.bindPopup(popup_379046fb3507328515ca3a2c38945c41)
#         ;
#
#
#
#
#             var marker_ef2359ccc7cb8038aeb19b812b17d3e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3400771bbd91e9f0751430ad6e97029);
#
#
#         var popup_8847313e89b657a0b70df7f9038874fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbec3fd710537b2ae97b3e3ce27cd887 = $(`&lt;div id=&quot;html_fbec3fd710537b2ae97b3e3ce27cd887&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8847313e89b657a0b70df7f9038874fd.setContent(html_fbec3fd710537b2ae97b3e3ce27cd887);
#
#
#
#         marker_ef2359ccc7cb8038aeb19b812b17d3e8.bindPopup(popup_8847313e89b657a0b70df7f9038874fd)
#         ;
#
#
#
#
#             var marker_e64029a2603dc367e0e6372a5094f809 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b3400771bbd91e9f0751430ad6e97029);
#
#
#         var popup_113ebe982459bb3a04a5f32f41d9a816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d6c3d2abec96176687385a4167ccb5b = $(`&lt;div id=&quot;html_4d6c3d2abec96176687385a4167ccb5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_113ebe982459bb3a04a5f32f41d9a816.setContent(html_4d6c3d2abec96176687385a4167ccb5b);
#
#
#
#         marker_
