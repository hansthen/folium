# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39e85da59928bba608da91e12bbf9dd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39e85da59928bba608da91e12bbf9dd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39e85da59928bba608da91e12bbf9dd2 = L.map(
#                 &quot;map_39e85da59928bba608da91e12bbf9dd2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4297972e0a055a8221afb3dc0cd101d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4297972e0a055a8221afb3dc0cd101d7.addTo(map_39e85da59928bba608da91e12bbf9dd2);
#
#
#             var marker_5cd43be10adf20ac7d38a9925c25498a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_39e85da59928bba608da91e12bbf9dd2);
#
#
#         var popup_ccf959e1f5b6740e68154d3dcc19a6e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3abff71ebdf91dad15887535024c1833 = $(`&lt;div id=&quot;html_3abff71ebdf91dad15887535024c1833&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ccf959e1f5b6740e68154d3dcc19a6e5.setContent(html_3abff71ebdf91dad15887535024c1833);
#
#
#
#         marker_5cd43be10adf20ac7d38a9925c25498a.bindPopup(popup_ccf959e1f5b6740e68154d3dcc19a6e5)
#         ;
#
#
#
#
#             var marker_1a43f1b9273ce3d5f3496ec736bc63cc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_39e85da59928bba608da91e12bbf9dd2);
#
#
#         var popup_49f432d66ac7defc61eca9f655163b83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a03b878ebcd34c699e7cb1fbf3cb86f = $(`&lt;div id=&quot;html_1a03b878ebcd34c699e7cb1fbf3cb86f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_49f432d66ac7defc61eca9f655163b83.setContent(html_1a03b878ebcd34c699e7cb1fbf3cb86f);
#
#
#
#         marker_1a43f1b9273ce3d5f3496ec736bc63cc.bindPopup(popup_49f432d66ac7defc61eca9f655163b83)
#         ;
#
#
#
#
#             var marker_2a6137fe5d957fc1070b211e890c7daa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_39e85da59928bba608da91e12bbf9dd2);
#
#
#         var popup_f3d1912cc71ee7a2232d90b9848b33be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3882f9c8a1065cccb58c85fa752b52d2 = $(`&lt;div id=&quot;html_3882f9c8a1065cccb58c85fa752b52d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f3d1912cc71ee7a2232d90b9848b33be.setContent(html_3882f9c8a1065cccb58c85fa752b52d2);
#
#
#
#         marker_2a6137fe5d957fc1070b211e890c7daa.bindPopup(popup_f3d1912cc71ee7a2232d90b9848b33be)
#         ;
#
#
#
#
#             var marker_5b6d72b7a267a2910b53772a629cfd56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_39e85da59928bba608da91e12bbf9dd2);
#
#
#         var popup_7ab600411a6cd12cda1d34f143928306 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7717c3fb49faa2b8613b83314b3f42e7 = $(`&lt;div id=&quot;html_7717c3fb49faa2b8613b83314b3f42e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7ab600411a6cd12cda1d34f143928306.setContent(html_7717c3fb49faa2b8613b83314b3f42e7);
#
#
#
#         marker_5b6d72b7a267a2910b53772a629cfd56.bindPopup(popup_7ab600411a6cd12cda1d34f143928306)
#         ;
#
#
#
#
#             var marker_2f5969b678e6e3846caf5f7c418d8081 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_39e85da59928bba608da91e12bbf9dd2);
#
#
#         var popup_0e10e8e2b032cc98c38f5f73d3e46dec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b964af3434fdff357291dd05eaaf9613 = $(`&lt;div id=&quot;html_b964af3434fdff357291dd05eaaf9613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0e10e8e2b032cc98c38f5f73d3e46dec.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fc6c8491c3faa5616fb0835d4846c2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fc6c8491c3faa5616fb0835d4846c2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fc6c8491c3faa5616fb0835d4846c2e = L.map(
#                 &quot;map_0fc6c8491c3faa5616fb0835d4846c2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_991668d364232e8bbef706d6b4375869 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_991668d364232e8bbef706d6b4375869.addTo(map_0fc6c8491c3faa5616fb0835d4846c2e);
#
#
#             var feature_group_b50311b33b596aedf2cf2b0ae7e7f2fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_53c1ebc9372e14fd15fa602845dbb822 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b50311b33b596aedf2cf2b0ae7e7f2fa);
#
#
#         var popup_01c7ff74fd005072e29257f8759ea562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23a0e268271bcef4505354fe308fa159 = $(`&lt;div id=&quot;html_23a0e268271bcef4505354fe308fa159&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_01c7ff74fd005072e29257f8759ea562.setContent(html_23a0e268271bcef4505354fe308fa159);
#
#
#
#         marker_53c1ebc9372e14fd15fa602845dbb822.bindPopup(popup_01c7ff74fd005072e29257f8759ea562)
#         ;
#
#
#
#
#             var marker_1f0523223a82eff2867ea6f03ee33415 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b50311b33b596aedf2cf2b0ae7e7f2fa);
#
#
#         var popup_17cd6b9b39416b4702959cd44550e186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ffd28e2fb5fdc633e5dd82954d8c8b2 = $(`&lt;div id=&quot;html_6ffd28e2fb5fdc633e5dd82954d8c8b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_17cd6b9b39416b4702959cd44550e186.setContent(html_6ffd28e2fb5fdc633e5dd82954d8c8b2);
#
#
#
#         marker_1f0523223a82eff2867ea6f03ee33415.bindPopup(popup_17cd6b9b39416b4702959cd44550e186)
#         ;
#
#
#
#
#             var marker_37645d052a88815cce2afe7b85bcfdbb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b50311b33b596aedf2cf2b0ae7e7f2fa);
#
#
#         var popup_19d9e59738b96643a7730ed126b87ab3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aad62384e412b147cb29589247b37fd1 = $(`&lt;div id=&quot;html_aad62384e412b147cb29589247b37fd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_19d9e59738b96643a7730ed126b87ab3.setContent(html_aad62384e412b147cb29589247b37fd1);
#
#
#
#         marker_37645d052a88815cce2afe7b85bcfdbb.bindPopup(popup_19d9e59738b96643a7730ed126b87ab3)
#         ;
#
#
#
#
#             var marker_582628cebb437c5575836742cb07a6dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b50311b33b596aedf2cf2b0ae7e7f2fa);
#
#
#         var popup_6084fba9142bc1fdb2476eeff7183821 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac6e4cdcb7f55e4e281f2edeb57484d3 = $(`&lt;div id=&quot;html_ac6e4cdcb7f55e4e281f2edeb57484d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6084fba9142bc1fdb2476eeff7183821.setContent(html_ac6e4cdcb7f55e4e281f2edeb57484d3);
#
#
#
#         marker_582628cebb437c5575836742cb07a6dd.bindPopup(popup_6084fba9142bc1fdb2476eeff7183821)
#         ;
#
#
#
#
#             var marker_8081af412fd434e5baffca8f34356175 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b50311b33b596aedf2cf2b0ae7e7f2fa);
#
#
#         var popup_48b6cf746269a28050bc033a66d59fe2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b70d2cbacfc28c083f502f67d5a45199 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b70d2cbacfc28c083f502f67d5a45199&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b70d2cbacfc28c083f502f67d5a45199 = L.map(
#                 &quot;map_b70d2cbacfc28c083f502f67d5a45199&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_640b943c4f5d633c5e181a0095663633 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_640b943c4f5d633c5e181a0095663633.addTo(map_b70d2cbacfc28c083f502f67d5a45199);
#
#
#             var feature_group_e6ba69861360adb9ab552dc11ddea138 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e6ba69861360adb9ab552dc11ddea138.addTo(map_b70d2cbacfc28c083f502f67d5a45199);
#
#
#             var feature_group_sub_group_e12aa004aa3d583d7018b53c5bdb915f = L.featureGroup.subGroup(
#                 feature_group_e6ba69861360adb9ab552dc11ddea138
#             );
#
#
#             var marker_534d182cad8d08c5fcb924cd5769e69c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e12aa004aa3d583d7018b53c5bdb915f);
#
#
#         var popup_fdaa65f96b5dca89f864728d8fdb023b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1245d67b688be4b86640c6d9db62ade4 = $(`&lt;div id=&quot;html_1245d67b688be4b86640c6d9db62ade4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fdaa65f96b5dca89f864728d8fdb023b.setContent(html_1245d67b688be4b86640c6d9db62ade4);
#
#
#
#         marker_534d182cad8d08c5fcb924cd5769e69c.bindPopup(popup_fdaa65f96b5dca89f864728d8fdb023b)
#         ;
#
#
#
#
#             var marker_4406b2fd77c6da789e046de8feb020ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e12aa004aa3d583d7018b53c5bdb915f);
#
#
#         var popup_d777de44d4130c4e56fd754c988764ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42cd905da038e89100efb25189b17187 = $(`&lt;div id=&quot;html_42cd905da038e89100efb25189b17187&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d777de44d4130c4e56fd754c988764ed.setContent(html_42cd905da038e89100efb25189b17187);
#
#
#
#         marker_4406b2fd77c6da789e046de8feb020ae.bindPopup(popup_d777de44d4130c4e56fd754c988764ed)
#         ;
#
#
#
#
#             var marker_fd04733fff99ca1680b81483ddfde9f5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e12aa004aa3d583d7018b53c5bdb915f);
#
#
#         var popup_0aac9c83303812d035d7da614db6a468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d01d5ef10cd65948a49dc9c426c2d4 = $(`&lt;div id=&quot;html_89d01d5ef10cd65948a49dc9c426c2d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0aac9c83303812d035d7da614db6a468.setContent(html_89d01d5ef10cd65948a49dc9c426c2d4);
#
#
#
#         marker_fd04733fff99ca1680b81483ddfde9f5.bindPopup(popup_0aac9c83303812d035d7da614db6a468)
#         ;
#
#
#
#
#             var marker_829eae224759f40a7c3011248ff7c819 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e12aa004aa3d583d7018b53c5bdb915f);
#
#
#         var popup_3954eed8c4eedc43eee51d4cdc3c9d95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a1f91d2007f38617d41bf2b0909fefe = $(`&lt;div id=&quot;html_4a1f91d2007f38617d41bf2b0909fefe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3954eed8c4eedc43eee51d4cdc3c9d95.setContent(html_4a1f91d2007f38617d41bf2b0909fefe);
#
#
#
#         marker_
