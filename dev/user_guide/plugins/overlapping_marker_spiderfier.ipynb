# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d2c5a966f5b811966742951babc7a8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d2c5a966f5b811966742951babc7a8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d2c5a966f5b811966742951babc7a8f = L.map(
#                 &quot;map_8d2c5a966f5b811966742951babc7a8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4cee3ad433136e06e180b0ecfe569cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4cee3ad433136e06e180b0ecfe569cb.addTo(map_8d2c5a966f5b811966742951babc7a8f);
#
#
#             var marker_36d421c9ab9eb0bcf41d19f835a639f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8d2c5a966f5b811966742951babc7a8f);
#
#
#         var popup_0d02ec7dd592d620a3ab5a465e104c65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff2e966a623c308174b18654c47a6113 = $(`&lt;div id=&quot;html_ff2e966a623c308174b18654c47a6113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0d02ec7dd592d620a3ab5a465e104c65.setContent(html_ff2e966a623c308174b18654c47a6113);
#
#
#
#         marker_36d421c9ab9eb0bcf41d19f835a639f6.bindPopup(popup_0d02ec7dd592d620a3ab5a465e104c65)
#         ;
#
#
#
#
#             var marker_babdbf218ccac6677212fc065357a0d1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8d2c5a966f5b811966742951babc7a8f);
#
#
#         var popup_bc25f4c170ab0925d59aeb51692989c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43ff8d3c7aaceefc372b7f1001268af9 = $(`&lt;div id=&quot;html_43ff8d3c7aaceefc372b7f1001268af9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bc25f4c170ab0925d59aeb51692989c9.setContent(html_43ff8d3c7aaceefc372b7f1001268af9);
#
#
#
#         marker_babdbf218ccac6677212fc065357a0d1.bindPopup(popup_bc25f4c170ab0925d59aeb51692989c9)
#         ;
#
#
#
#
#             var marker_0fe15e62fe05419588eb135cd4f15be3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8d2c5a966f5b811966742951babc7a8f);
#
#
#         var popup_799d1005c95e9b2c52460c36f12cfb9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d7b29e74e9e07430c187b0fd6e9b57a = $(`&lt;div id=&quot;html_2d7b29e74e9e07430c187b0fd6e9b57a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_799d1005c95e9b2c52460c36f12cfb9c.setContent(html_2d7b29e74e9e07430c187b0fd6e9b57a);
#
#
#
#         marker_0fe15e62fe05419588eb135cd4f15be3.bindPopup(popup_799d1005c95e9b2c52460c36f12cfb9c)
#         ;
#
#
#
#
#             var marker_81b43619f120c132c8b6929b34228832 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8d2c5a966f5b811966742951babc7a8f);
#
#
#         var popup_fcbb9b956ce13233d63fcc677b7ad870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92e9ffe9f579eb0599ecfaf5257d388a = $(`&lt;div id=&quot;html_92e9ffe9f579eb0599ecfaf5257d388a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fcbb9b956ce13233d63fcc677b7ad870.setContent(html_92e9ffe9f579eb0599ecfaf5257d388a);
#
#
#
#         marker_81b43619f120c132c8b6929b34228832.bindPopup(popup_fcbb9b956ce13233d63fcc677b7ad870)
#         ;
#
#
#
#
#             var marker_e154ff597f6d94c5995cbefd98e2dfd2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8d2c5a966f5b811966742951babc7a8f);
#
#
#         var popup_43db632042b3850eb806e4d0f3fa83d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b84a1621ffafd1ee3b01ae17574a40ab = $(`&lt;div id=&quot;html_b84a1621ffafd1ee3b01ae17574a40ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_43db632042b3850eb806e4d0f3fa83d1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_136184fcc408ecf36d9c66475ac89608 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_136184fcc408ecf36d9c66475ac89608&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_136184fcc408ecf36d9c66475ac89608 = L.map(
#                 &quot;map_136184fcc408ecf36d9c66475ac89608&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fef39d624e357d331beabc2db768d216 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fef39d624e357d331beabc2db768d216.addTo(map_136184fcc408ecf36d9c66475ac89608);
#
#
#             var feature_group_922f467a6d8693cb1601ac4f7d190d94 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c0d6f3e54adefd5aeb488d417d39b27e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_922f467a6d8693cb1601ac4f7d190d94);
#
#
#         var popup_1633b35c7b95cddeb9dfa5c0938453bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a526a1f3f262e61cb038ff46c0499274 = $(`&lt;div id=&quot;html_a526a1f3f262e61cb038ff46c0499274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1633b35c7b95cddeb9dfa5c0938453bb.setContent(html_a526a1f3f262e61cb038ff46c0499274);
#
#
#
#         marker_c0d6f3e54adefd5aeb488d417d39b27e.bindPopup(popup_1633b35c7b95cddeb9dfa5c0938453bb)
#         ;
#
#
#
#
#             var marker_0ac7a0667da9f3915050b74c2b1f6bed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_922f467a6d8693cb1601ac4f7d190d94);
#
#
#         var popup_9828b462f504aa66b3e8e17f8c3a0fa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52e48db72a0d7701fdca330bff3c9741 = $(`&lt;div id=&quot;html_52e48db72a0d7701fdca330bff3c9741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9828b462f504aa66b3e8e17f8c3a0fa9.setContent(html_52e48db72a0d7701fdca330bff3c9741);
#
#
#
#         marker_0ac7a0667da9f3915050b74c2b1f6bed.bindPopup(popup_9828b462f504aa66b3e8e17f8c3a0fa9)
#         ;
#
#
#
#
#             var marker_799934f6fbeda2dc99aca0d6aed8f65e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_922f467a6d8693cb1601ac4f7d190d94);
#
#
#         var popup_8236840a617e4f53d25b69e0745f8e2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d70e32e60365c533a1bb411d477dbd0d = $(`&lt;div id=&quot;html_d70e32e60365c533a1bb411d477dbd0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8236840a617e4f53d25b69e0745f8e2e.setContent(html_d70e32e60365c533a1bb411d477dbd0d);
#
#
#
#         marker_799934f6fbeda2dc99aca0d6aed8f65e.bindPopup(popup_8236840a617e4f53d25b69e0745f8e2e)
#         ;
#
#
#
#
#             var marker_278db8290be16c7a08f55db1efbf4f86 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_922f467a6d8693cb1601ac4f7d190d94);
#
#
#         var popup_4eca7c3ef8fc5430931a1bfa4b8a3563 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6e5adb2579f6da14e3dbdf12b12c76d = $(`&lt;div id=&quot;html_c6e5adb2579f6da14e3dbdf12b12c76d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4eca7c3ef8fc5430931a1bfa4b8a3563.setContent(html_c6e5adb2579f6da14e3dbdf12b12c76d);
#
#
#
#         marker_278db8290be16c7a08f55db1efbf4f86.bindPopup(popup_4eca7c3ef8fc5430931a1bfa4b8a3563)
#         ;
#
#
#
#
#             var marker_32cf4133f86fa7a8e6a4f22b1d230da7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_922f467a6d8693cb1601ac4f7d190d94);
#
#
#         var popup_a7ab93cd4e312135b50ced2ba0e32b55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e05268306f762f62c07a5b9c8c759829 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e05268306f762f62c07a5b9c8c759829&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e05268306f762f62c07a5b9c8c759829 = L.map(
#                 &quot;map_e05268306f762f62c07a5b9c8c759829&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ec796ea4865727e64a5c17ffdbdeeb4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ec796ea4865727e64a5c17ffdbdeeb4.addTo(map_e05268306f762f62c07a5b9c8c759829);
#
#
#             var feature_group_646750509ceecd2b4bd9a70def269c3e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_646750509ceecd2b4bd9a70def269c3e.addTo(map_e05268306f762f62c07a5b9c8c759829);
#
#
#             var feature_group_sub_group_89952ec676490d941282569869ca8c11 = L.featureGroup.subGroup(
#                 feature_group_646750509ceecd2b4bd9a70def269c3e
#             );
#
#
#             var marker_66719d4348b76f8e7144496a810a7cb9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_89952ec676490d941282569869ca8c11);
#
#
#         var popup_7b5f76044712cf669f602d47f20bb324 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59edd849ede4e2d46ff2a70fd8222193 = $(`&lt;div id=&quot;html_59edd849ede4e2d46ff2a70fd8222193&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7b5f76044712cf669f602d47f20bb324.setContent(html_59edd849ede4e2d46ff2a70fd8222193);
#
#
#
#         marker_66719d4348b76f8e7144496a810a7cb9.bindPopup(popup_7b5f76044712cf669f602d47f20bb324)
#         ;
#
#
#
#
#             var marker_8acc43f7f061eccdd68dbf7564f0d5f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_89952ec676490d941282569869ca8c11);
#
#
#         var popup_11b9e1c40a70aff3b82d8edf0166b3ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a057e7f0d86649320b5db1673bc65ee9 = $(`&lt;div id=&quot;html_a057e7f0d86649320b5db1673bc65ee9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_11b9e1c40a70aff3b82d8edf0166b3ba.setContent(html_a057e7f0d86649320b5db1673bc65ee9);
#
#
#
#         marker_8acc43f7f061eccdd68dbf7564f0d5f7.bindPopup(popup_11b9e1c40a70aff3b82d8edf0166b3ba)
#         ;
#
#
#
#
#             var marker_b378aa85e6ccc254033b0bc657a8425f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_89952ec676490d941282569869ca8c11);
#
#
#         var popup_3ffca87d795caf7efc5b99c6b5d68c67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d548ff55b3d425a474cd1eb8be22a597 = $(`&lt;div id=&quot;html_d548ff55b3d425a474cd1eb8be22a597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3ffca87d795caf7efc5b99c6b5d68c67.setContent(html_d548ff55b3d425a474cd1eb8be22a597);
#
#
#
#         marker_b378aa85e6ccc254033b0bc657a8425f.bindPopup(popup_3ffca87d795caf7efc5b99c6b5d68c67)
#         ;
#
#
#
#
#             var marker_0910f8e464bf1e0f8fd4a08c8aaeed08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_89952ec676490d941282569869ca8c11);
#
#
#         var popup_d7eef33f8017ee61c4b53f76373688eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40822e20509fc22c6ca2f937b20ffa63 = $(`&lt;div id=&quot;html_40822e20509fc22c6ca2f937b20ffa63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d7eef33f8017ee61c4b53f76373688eb.setContent(html_40822e20509fc22c6ca2f937b20ffa63);
#
#
#
#         marker_
