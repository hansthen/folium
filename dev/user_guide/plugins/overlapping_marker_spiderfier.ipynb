# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a5daa788ac34de86954fa3a5626391d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a5daa788ac34de86954fa3a5626391d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a5daa788ac34de86954fa3a5626391d = L.map(
#                 &quot;map_3a5daa788ac34de86954fa3a5626391d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b66ccb8b5889a8d303f7374244b40285 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b66ccb8b5889a8d303f7374244b40285.addTo(map_3a5daa788ac34de86954fa3a5626391d);
#
#
#             var marker_43a0e6898ec667d8017a5ee803bba87f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3a5daa788ac34de86954fa3a5626391d);
#
#
#         var popup_59007e78229eaf428d157ec2da852503 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cee11abb6def434502be772e39c4386 = $(`&lt;div id=&quot;html_4cee11abb6def434502be772e39c4386&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_59007e78229eaf428d157ec2da852503.setContent(html_4cee11abb6def434502be772e39c4386);
#
#
#
#         marker_43a0e6898ec667d8017a5ee803bba87f.bindPopup(popup_59007e78229eaf428d157ec2da852503)
#         ;
#
#
#
#
#             var marker_80db2cc1a183a1e733d83f555daf006e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3a5daa788ac34de86954fa3a5626391d);
#
#
#         var popup_a7d2033e906e4a5744e557609304559f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb192d9f71e6c80802ee4d5f5bc9f0c7 = $(`&lt;div id=&quot;html_bb192d9f71e6c80802ee4d5f5bc9f0c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a7d2033e906e4a5744e557609304559f.setContent(html_bb192d9f71e6c80802ee4d5f5bc9f0c7);
#
#
#
#         marker_80db2cc1a183a1e733d83f555daf006e.bindPopup(popup_a7d2033e906e4a5744e557609304559f)
#         ;
#
#
#
#
#             var marker_0f01d9c3a0f550b88720decc8ef6e3fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3a5daa788ac34de86954fa3a5626391d);
#
#
#         var popup_38fd58c9ab94829fb0fb5633b1cf621c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b5a9d5c307c8ca1681e4dbe9118598b = $(`&lt;div id=&quot;html_8b5a9d5c307c8ca1681e4dbe9118598b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_38fd58c9ab94829fb0fb5633b1cf621c.setContent(html_8b5a9d5c307c8ca1681e4dbe9118598b);
#
#
#
#         marker_0f01d9c3a0f550b88720decc8ef6e3fc.bindPopup(popup_38fd58c9ab94829fb0fb5633b1cf621c)
#         ;
#
#
#
#
#             var marker_eeb368841724d76582a5ff55bd1950b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3a5daa788ac34de86954fa3a5626391d);
#
#
#         var popup_f5fc98023ce05f690a6af34faec801d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27dc9ec7a6248a8a6c75c8df00042f3f = $(`&lt;div id=&quot;html_27dc9ec7a6248a8a6c75c8df00042f3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f5fc98023ce05f690a6af34faec801d7.setContent(html_27dc9ec7a6248a8a6c75c8df00042f3f);
#
#
#
#         marker_eeb368841724d76582a5ff55bd1950b6.bindPopup(popup_f5fc98023ce05f690a6af34faec801d7)
#         ;
#
#
#
#
#             var marker_331dc60d391839dc42428c7c420469e8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3a5daa788ac34de86954fa3a5626391d);
#
#
#         var popup_234a1a2749271b85026cd11ba1e34fda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd31364b9fc84e3fa139462d2c3f571f = $(`&lt;div id=&quot;html_cd31364b9fc84e3fa139462d2c3f571f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_234a1a2749271b85026cd11ba1e34fda.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71abca795cdcc5d6eaedcdbbab973fd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71abca795cdcc5d6eaedcdbbab973fd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71abca795cdcc5d6eaedcdbbab973fd8 = L.map(
#                 &quot;map_71abca795cdcc5d6eaedcdbbab973fd8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edccb5ff70f71d2ae29066c0b03d80bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_edccb5ff70f71d2ae29066c0b03d80bd.addTo(map_71abca795cdcc5d6eaedcdbbab973fd8);
#
#
#             var feature_group_4ff94e3ad057e673b598c32d995c8b62 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_15533bda10dabb26a47565ed82db86cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4ff94e3ad057e673b598c32d995c8b62);
#
#
#         var popup_418ae38f9bca2bb1230e79ad202bbc76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89912028a0c96551a574c3ce75b96373 = $(`&lt;div id=&quot;html_89912028a0c96551a574c3ce75b96373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_418ae38f9bca2bb1230e79ad202bbc76.setContent(html_89912028a0c96551a574c3ce75b96373);
#
#
#
#         marker_15533bda10dabb26a47565ed82db86cf.bindPopup(popup_418ae38f9bca2bb1230e79ad202bbc76)
#         ;
#
#
#
#
#             var marker_210cef6afbeeb0d14de5199589a7ca16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4ff94e3ad057e673b598c32d995c8b62);
#
#
#         var popup_fa894b02fa414f83ca3dddaff37062a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f28c351f38a93dff3066225a0f991ff = $(`&lt;div id=&quot;html_2f28c351f38a93dff3066225a0f991ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fa894b02fa414f83ca3dddaff37062a0.setContent(html_2f28c351f38a93dff3066225a0f991ff);
#
#
#
#         marker_210cef6afbeeb0d14de5199589a7ca16.bindPopup(popup_fa894b02fa414f83ca3dddaff37062a0)
#         ;
#
#
#
#
#             var marker_d4966dc84d2187518542852a3de3d8da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4ff94e3ad057e673b598c32d995c8b62);
#
#
#         var popup_a120f225dd40f46580f10b4bc8654177 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ab7aa18a496e62e7686f630c6a4f20d = $(`&lt;div id=&quot;html_3ab7aa18a496e62e7686f630c6a4f20d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a120f225dd40f46580f10b4bc8654177.setContent(html_3ab7aa18a496e62e7686f630c6a4f20d);
#
#
#
#         marker_d4966dc84d2187518542852a3de3d8da.bindPopup(popup_a120f225dd40f46580f10b4bc8654177)
#         ;
#
#
#
#
#             var marker_b387fb8f6876850b8bc7af8dbf1d8af1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4ff94e3ad057e673b598c32d995c8b62);
#
#
#         var popup_3a756bd0210997073d020f99dab82d5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5227c417fe7c477777bc98b5622d4d3 = $(`&lt;div id=&quot;html_e5227c417fe7c477777bc98b5622d4d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3a756bd0210997073d020f99dab82d5e.setContent(html_e5227c417fe7c477777bc98b5622d4d3);
#
#
#
#         marker_b387fb8f6876850b8bc7af8dbf1d8af1.bindPopup(popup_3a756bd0210997073d020f99dab82d5e)
#         ;
#
#
#
#
#             var marker_41c7d064fadad619bf72c62d9e6262d5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4ff94e3ad057e673b598c32d995c8b62);
#
#
#         var popup_75f82d975cf2c07b84c70a4fd83afa17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51313cb60617d5a87d1b9c10371eb278 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51313cb60617d5a87d1b9c10371eb278&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51313cb60617d5a87d1b9c10371eb278 = L.map(
#                 &quot;map_51313cb60617d5a87d1b9c10371eb278&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5ae21556c08c5fabe71131705d24f18 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5ae21556c08c5fabe71131705d24f18.addTo(map_51313cb60617d5a87d1b9c10371eb278);
#
#
#             var feature_group_dda3d3e9c35c46aa77275bbd9f29d1fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dda3d3e9c35c46aa77275bbd9f29d1fb.addTo(map_51313cb60617d5a87d1b9c10371eb278);
#
#
#             var feature_group_sub_group_e8c34dad58a856d8dbbc91d3797092e7 = L.featureGroup.subGroup(
#                 feature_group_dda3d3e9c35c46aa77275bbd9f29d1fb
#             );
#
#
#             var marker_491c47ced7ecaf589db678cd6b62fe42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c34dad58a856d8dbbc91d3797092e7);
#
#
#         var popup_2994f1023ef6edda2bf26c6632509f5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7aad426e2586a474f3e48b7bdaddb15a = $(`&lt;div id=&quot;html_7aad426e2586a474f3e48b7bdaddb15a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2994f1023ef6edda2bf26c6632509f5c.setContent(html_7aad426e2586a474f3e48b7bdaddb15a);
#
#
#
#         marker_491c47ced7ecaf589db678cd6b62fe42.bindPopup(popup_2994f1023ef6edda2bf26c6632509f5c)
#         ;
#
#
#
#
#             var marker_49a705aa591cd8d78418cd8247e75a9e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c34dad58a856d8dbbc91d3797092e7);
#
#
#         var popup_c943a17bfbdb3fb8023d622de5b8cbc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5df3206ee6d341649ab105ed0389625 = $(`&lt;div id=&quot;html_b5df3206ee6d341649ab105ed0389625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c943a17bfbdb3fb8023d622de5b8cbc4.setContent(html_b5df3206ee6d341649ab105ed0389625);
#
#
#
#         marker_49a705aa591cd8d78418cd8247e75a9e.bindPopup(popup_c943a17bfbdb3fb8023d622de5b8cbc4)
#         ;
#
#
#
#
#             var marker_85a26319935a90a51e5c0f33bfabfe96 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c34dad58a856d8dbbc91d3797092e7);
#
#
#         var popup_9f0e992ca0da5fd80745d3abf0d8807f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e61efa29651f38edb04985e2ee6db2d2 = $(`&lt;div id=&quot;html_e61efa29651f38edb04985e2ee6db2d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9f0e992ca0da5fd80745d3abf0d8807f.setContent(html_e61efa29651f38edb04985e2ee6db2d2);
#
#
#
#         marker_85a26319935a90a51e5c0f33bfabfe96.bindPopup(popup_9f0e992ca0da5fd80745d3abf0d8807f)
#         ;
#
#
#
#
#             var marker_0a64bec598e3dbf9c0dfcef723720807 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c34dad58a856d8dbbc91d3797092e7);
#
#
#         var popup_e84c0fd8e1e98d778776cb27b7bad6b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e56346634ab4de76c01a79ac0d89606c = $(`&lt;div id=&quot;html_e56346634ab4de76c01a79ac0d89606c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e84c0fd8e1e98d778776cb27b7bad6b6.setContent(html_e56346634ab4de76c01a79ac0d89606c);
#
#
#
#         marker_
