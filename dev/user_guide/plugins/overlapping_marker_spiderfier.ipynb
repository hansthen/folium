# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6168e9f31837d1530810c3db806773b1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6168e9f31837d1530810c3db806773b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6168e9f31837d1530810c3db806773b1 = L.map(
#                 &quot;map_6168e9f31837d1530810c3db806773b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ad7851c991122087dd681e9d91615f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ad7851c991122087dd681e9d91615f9.addTo(map_6168e9f31837d1530810c3db806773b1);
#
#
#             var marker_d328da82fe14da819d10a557616ca52a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6168e9f31837d1530810c3db806773b1);
#
#
#         var popup_587b522891f6b9460720891b3fb97765 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f263bfce77279630186d0e7809f8f00d = $(`&lt;div id=&quot;html_f263bfce77279630186d0e7809f8f00d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_587b522891f6b9460720891b3fb97765.setContent(html_f263bfce77279630186d0e7809f8f00d);
#
#
#
#         marker_d328da82fe14da819d10a557616ca52a.bindPopup(popup_587b522891f6b9460720891b3fb97765)
#         ;
#
#
#
#
#             var marker_a308e9e02322c3f0731131be7cb04750 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6168e9f31837d1530810c3db806773b1);
#
#
#         var popup_f81443d2f2d40c95423c5c4f7ebc8064 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3add665e30e761dba3b831259609e4f5 = $(`&lt;div id=&quot;html_3add665e30e761dba3b831259609e4f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f81443d2f2d40c95423c5c4f7ebc8064.setContent(html_3add665e30e761dba3b831259609e4f5);
#
#
#
#         marker_a308e9e02322c3f0731131be7cb04750.bindPopup(popup_f81443d2f2d40c95423c5c4f7ebc8064)
#         ;
#
#
#
#
#             var marker_744d11a55043cea5c71fce1f878141b0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6168e9f31837d1530810c3db806773b1);
#
#
#         var popup_2508fd679b8dc2dcd4c33ca9c5dc2dda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40c4225439a64f988551f59e5c95e351 = $(`&lt;div id=&quot;html_40c4225439a64f988551f59e5c95e351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2508fd679b8dc2dcd4c33ca9c5dc2dda.setContent(html_40c4225439a64f988551f59e5c95e351);
#
#
#
#         marker_744d11a55043cea5c71fce1f878141b0.bindPopup(popup_2508fd679b8dc2dcd4c33ca9c5dc2dda)
#         ;
#
#
#
#
#             var marker_0c6c1dd31900e324fdc9cae92bbf853d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6168e9f31837d1530810c3db806773b1);
#
#
#         var popup_812e6e3ebc8658f4668e2711d2abd2e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc335f0a82636ea600451d032cca3ecb = $(`&lt;div id=&quot;html_fc335f0a82636ea600451d032cca3ecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_812e6e3ebc8658f4668e2711d2abd2e3.setContent(html_fc335f0a82636ea600451d032cca3ecb);
#
#
#
#         marker_0c6c1dd31900e324fdc9cae92bbf853d.bindPopup(popup_812e6e3ebc8658f4668e2711d2abd2e3)
#         ;
#
#
#
#
#             var marker_f5a59a8a1a8793646fee973471ad9e44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6168e9f31837d1530810c3db806773b1);
#
#
#         var popup_85fd8c79821da9f45abf661144d3a522 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d278b7c5f9a162786612e4033cbc4e72 = $(`&lt;div id=&quot;html_d278b7c5f9a162786612e4033cbc4e72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_85fd8c79821da9f45abf661144d3a5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa5c15b8407c88b540f6c4035c408890 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa5c15b8407c88b540f6c4035c408890&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa5c15b8407c88b540f6c4035c408890 = L.map(
#                 &quot;map_aa5c15b8407c88b540f6c4035c408890&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b8e785e6be7da8cb0b2c2812500eac5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b8e785e6be7da8cb0b2c2812500eac5.addTo(map_aa5c15b8407c88b540f6c4035c408890);
#
#
#             var feature_group_5a3f0c082986709e516919779f0e989e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4003bf72fc42ad8f16b0853b5c41be3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5a3f0c082986709e516919779f0e989e);
#
#
#         var popup_bd1713df0ab1fbd6db2d39ffe5309d45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34156a06e8ff19776191a34b1a4b79f3 = $(`&lt;div id=&quot;html_34156a06e8ff19776191a34b1a4b79f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bd1713df0ab1fbd6db2d39ffe5309d45.setContent(html_34156a06e8ff19776191a34b1a4b79f3);
#
#
#
#         marker_4003bf72fc42ad8f16b0853b5c41be3d.bindPopup(popup_bd1713df0ab1fbd6db2d39ffe5309d45)
#         ;
#
#
#
#
#             var marker_1419917845e3b1fd59dd9c93c983a045 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5a3f0c082986709e516919779f0e989e);
#
#
#         var popup_cedd5f4d57e592aaae729f2e1c52eddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3085c7842769a3b036f6cb6f97df2ae2 = $(`&lt;div id=&quot;html_3085c7842769a3b036f6cb6f97df2ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cedd5f4d57e592aaae729f2e1c52eddd.setContent(html_3085c7842769a3b036f6cb6f97df2ae2);
#
#
#
#         marker_1419917845e3b1fd59dd9c93c983a045.bindPopup(popup_cedd5f4d57e592aaae729f2e1c52eddd)
#         ;
#
#
#
#
#             var marker_90427df10386280868d040af8b8d08d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5a3f0c082986709e516919779f0e989e);
#
#
#         var popup_3ecb55754ae477242df68fa5f4250926 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_881973e500ed348174cbd6675d92d09f = $(`&lt;div id=&quot;html_881973e500ed348174cbd6675d92d09f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3ecb55754ae477242df68fa5f4250926.setContent(html_881973e500ed348174cbd6675d92d09f);
#
#
#
#         marker_90427df10386280868d040af8b8d08d0.bindPopup(popup_3ecb55754ae477242df68fa5f4250926)
#         ;
#
#
#
#
#             var marker_8498ad31ac2ba0c19bad9d0846ee2142 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5a3f0c082986709e516919779f0e989e);
#
#
#         var popup_f6380f5b78b95f68620e9b013aa75b02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85efe936bbe440e47e7c8996dd6668a3 = $(`&lt;div id=&quot;html_85efe936bbe440e47e7c8996dd6668a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f6380f5b78b95f68620e9b013aa75b02.setContent(html_85efe936bbe440e47e7c8996dd6668a3);
#
#
#
#         marker_8498ad31ac2ba0c19bad9d0846ee2142.bindPopup(popup_f6380f5b78b95f68620e9b013aa75b02)
#         ;
#
#
#
#
#             var marker_88cf961cbbe653d82e7d326f80ba9519 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5a3f0c082986709e516919779f0e989e);
#
#
#         var popup_e385b31b9a133e688cbf3bd342df2f5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68f0f07e1919a85b8ff118e53c177ed1 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68f0f07e1919a85b8ff118e53c177ed1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68f0f07e1919a85b8ff118e53c177ed1 = L.map(
#                 &quot;map_68f0f07e1919a85b8ff118e53c177ed1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48a25bdb9e21c2bdf481274dd11d85e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48a25bdb9e21c2bdf481274dd11d85e2.addTo(map_68f0f07e1919a85b8ff118e53c177ed1);
#
#
#             var feature_group_dec213fdff5d9b4ef3a97006fa768ec5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dec213fdff5d9b4ef3a97006fa768ec5.addTo(map_68f0f07e1919a85b8ff118e53c177ed1);
#
#
#             var feature_group_sub_group_0b2d8ca72acd2f3f19a0f1c61fe08347 = L.featureGroup.subGroup(
#                 feature_group_dec213fdff5d9b4ef3a97006fa768ec5
#             );
#
#
#             var marker_4d7bed847a3ff1b0380347f322f4af57 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b2d8ca72acd2f3f19a0f1c61fe08347);
#
#
#         var popup_f3c091c3633a554e08373353a3b49446 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8de7783f01408df134ec70bba1d7c97c = $(`&lt;div id=&quot;html_8de7783f01408df134ec70bba1d7c97c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f3c091c3633a554e08373353a3b49446.setContent(html_8de7783f01408df134ec70bba1d7c97c);
#
#
#
#         marker_4d7bed847a3ff1b0380347f322f4af57.bindPopup(popup_f3c091c3633a554e08373353a3b49446)
#         ;
#
#
#
#
#             var marker_46ba859d3c53cbb201c3c18ab46d90ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b2d8ca72acd2f3f19a0f1c61fe08347);
#
#
#         var popup_cb57542fff86796ac8f25a4934996f99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea1cfb3a2e8becfd7662652c02ce2348 = $(`&lt;div id=&quot;html_ea1cfb3a2e8becfd7662652c02ce2348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cb57542fff86796ac8f25a4934996f99.setContent(html_ea1cfb3a2e8becfd7662652c02ce2348);
#
#
#
#         marker_46ba859d3c53cbb201c3c18ab46d90ab.bindPopup(popup_cb57542fff86796ac8f25a4934996f99)
#         ;
#
#
#
#
#             var marker_ee379ec75181af6fa4d932b530e0e72f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b2d8ca72acd2f3f19a0f1c61fe08347);
#
#
#         var popup_3b595e72fe4d3f513a81fe116b5cc085 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6aca7125b9f1738d9427a3ecb7a5ce2d = $(`&lt;div id=&quot;html_6aca7125b9f1738d9427a3ecb7a5ce2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3b595e72fe4d3f513a81fe116b5cc085.setContent(html_6aca7125b9f1738d9427a3ecb7a5ce2d);
#
#
#
#         marker_ee379ec75181af6fa4d932b530e0e72f.bindPopup(popup_3b595e72fe4d3f513a81fe116b5cc085)
#         ;
#
#
#
#
#             var marker_6cec433708e05d860887bcb17e2db41b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b2d8ca72acd2f3f19a0f1c61fe08347);
#
#
#         var popup_ce17d474a0b82d1bd4feee7885f7958a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b42af645af41628eca6fddfb8b7a8b51 = $(`&lt;div id=&quot;html_b42af645af41628eca6fddfb8b7a8b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ce17d474a0b82d1bd4feee7885f7958a.setContent(html_b42af645af41628eca6fddfb8b7a8b51);
#
#
#
#         mark
