# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b590c0c7a1b2f43a667f63090b09e41f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b590c0c7a1b2f43a667f63090b09e41f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b590c0c7a1b2f43a667f63090b09e41f = L.map(
#                 &quot;map_b590c0c7a1b2f43a667f63090b09e41f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b5cffb9cddf45b8862c1df4595841ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b5cffb9cddf45b8862c1df4595841ad.addTo(map_b590c0c7a1b2f43a667f63090b09e41f);
#
#
#             var marker_b202bf1838d0ee62f15394c3994df4c0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b590c0c7a1b2f43a667f63090b09e41f);
#
#
#         var popup_2fc9aa120e2d4c96fa40e645275e75ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5485f8b38ad65df148851219a62bc052 = $(`&lt;div id=&quot;html_5485f8b38ad65df148851219a62bc052&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2fc9aa120e2d4c96fa40e645275e75ec.setContent(html_5485f8b38ad65df148851219a62bc052);
#
#
#
#         marker_b202bf1838d0ee62f15394c3994df4c0.bindPopup(popup_2fc9aa120e2d4c96fa40e645275e75ec)
#         ;
#
#
#
#
#             var marker_e7ca26ae4eb52410c416419a17bc4f3d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b590c0c7a1b2f43a667f63090b09e41f);
#
#
#         var popup_2840e3385ebdf16c7a4ca25a0b0a261c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feda49a1bc37da209c9658fbd4587520 = $(`&lt;div id=&quot;html_feda49a1bc37da209c9658fbd4587520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2840e3385ebdf16c7a4ca25a0b0a261c.setContent(html_feda49a1bc37da209c9658fbd4587520);
#
#
#
#         marker_e7ca26ae4eb52410c416419a17bc4f3d.bindPopup(popup_2840e3385ebdf16c7a4ca25a0b0a261c)
#         ;
#
#
#
#
#             var marker_31f7af29fba3977d63d0b77217761e06 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b590c0c7a1b2f43a667f63090b09e41f);
#
#
#         var popup_610241454216baca965f64452b13a036 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_488a7e6dd063b0cc24164c4efbbb0a4b = $(`&lt;div id=&quot;html_488a7e6dd063b0cc24164c4efbbb0a4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_610241454216baca965f64452b13a036.setContent(html_488a7e6dd063b0cc24164c4efbbb0a4b);
#
#
#
#         marker_31f7af29fba3977d63d0b77217761e06.bindPopup(popup_610241454216baca965f64452b13a036)
#         ;
#
#
#
#
#             var marker_2d753b90a83c2d656c0daa9898dcf238 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b590c0c7a1b2f43a667f63090b09e41f);
#
#
#         var popup_88df0f2bc926cdd2125380d563dd59ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b56998f4d3c05f3144ff862f20781a4 = $(`&lt;div id=&quot;html_6b56998f4d3c05f3144ff862f20781a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_88df0f2bc926cdd2125380d563dd59ad.setContent(html_6b56998f4d3c05f3144ff862f20781a4);
#
#
#
#         marker_2d753b90a83c2d656c0daa9898dcf238.bindPopup(popup_88df0f2bc926cdd2125380d563dd59ad)
#         ;
#
#
#
#
#             var marker_49ec740e606462dd768d8eea1ebcbd63 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b590c0c7a1b2f43a667f63090b09e41f);
#
#
#         var popup_f659fb3faf8999f980cc4bc190965a14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c12550c3fb396c008b89b94097aab78 = $(`&lt;div id=&quot;html_4c12550c3fb396c008b89b94097aab78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f659fb3faf8999f980cc4bc190965a14.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99f10db24f494d3b76ee8879b5101ddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99f10db24f494d3b76ee8879b5101ddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99f10db24f494d3b76ee8879b5101ddd = L.map(
#                 &quot;map_99f10db24f494d3b76ee8879b5101ddd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28ff1a6d94e26e474a19e93d70f17a36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28ff1a6d94e26e474a19e93d70f17a36.addTo(map_99f10db24f494d3b76ee8879b5101ddd);
#
#
#             var feature_group_9a84389b97177648d22e8c24fa504382 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_86882096671d27cb7b309c0dbb566d2d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9a84389b97177648d22e8c24fa504382);
#
#
#         var popup_60bbdeee05587d6dd00640087c3e9b42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2ac0d34dc0fc006ff0b47bb24fbde57 = $(`&lt;div id=&quot;html_c2ac0d34dc0fc006ff0b47bb24fbde57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_60bbdeee05587d6dd00640087c3e9b42.setContent(html_c2ac0d34dc0fc006ff0b47bb24fbde57);
#
#
#
#         marker_86882096671d27cb7b309c0dbb566d2d.bindPopup(popup_60bbdeee05587d6dd00640087c3e9b42)
#         ;
#
#
#
#
#             var marker_00474bb3aef757d55991f7d75b524bfd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9a84389b97177648d22e8c24fa504382);
#
#
#         var popup_c3b7766f7774b0940674c809dbda85ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f300610a9cefa096c1bcfaec569b35af = $(`&lt;div id=&quot;html_f300610a9cefa096c1bcfaec569b35af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c3b7766f7774b0940674c809dbda85ba.setContent(html_f300610a9cefa096c1bcfaec569b35af);
#
#
#
#         marker_00474bb3aef757d55991f7d75b524bfd.bindPopup(popup_c3b7766f7774b0940674c809dbda85ba)
#         ;
#
#
#
#
#             var marker_55d756662632851308a9c54784c18f50 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9a84389b97177648d22e8c24fa504382);
#
#
#         var popup_0f7547393eff0451322196c73205846c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d59b023725ff731a0023ec8dba489e3 = $(`&lt;div id=&quot;html_8d59b023725ff731a0023ec8dba489e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0f7547393eff0451322196c73205846c.setContent(html_8d59b023725ff731a0023ec8dba489e3);
#
#
#
#         marker_55d756662632851308a9c54784c18f50.bindPopup(popup_0f7547393eff0451322196c73205846c)
#         ;
#
#
#
#
#             var marker_32204af0969427d964c39325b55c7749 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9a84389b97177648d22e8c24fa504382);
#
#
#         var popup_4fc1c19b4997a6da50d111288f7049d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fb111306a9f28c10a88a8a1a067a27a = $(`&lt;div id=&quot;html_4fb111306a9f28c10a88a8a1a067a27a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4fc1c19b4997a6da50d111288f7049d7.setContent(html_4fb111306a9f28c10a88a8a1a067a27a);
#
#
#
#         marker_32204af0969427d964c39325b55c7749.bindPopup(popup_4fc1c19b4997a6da50d111288f7049d7)
#         ;
#
#
#
#
#             var marker_57fa19b1ab6d3414b497b527910b9109 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9a84389b97177648d22e8c24fa504382);
#
#
#         var popup_6423d455faa4c92afb10d333d19f2195 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59f5e27bb927e206836f104ff1ab0d83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59f5e27bb927e206836f104ff1ab0d83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59f5e27bb927e206836f104ff1ab0d83 = L.map(
#                 &quot;map_59f5e27bb927e206836f104ff1ab0d83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a42afd4ff926d0ee35b365b1fa432660 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a42afd4ff926d0ee35b365b1fa432660.addTo(map_59f5e27bb927e206836f104ff1ab0d83);
#
#
#             var feature_group_cba1da7156508d7422c7f96910abecbd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cba1da7156508d7422c7f96910abecbd.addTo(map_59f5e27bb927e206836f104ff1ab0d83);
#
#
#             var feature_group_sub_group_30ea87d5ea77befd7a8d0c34b8d6df86 = L.featureGroup.subGroup(
#                 feature_group_cba1da7156508d7422c7f96910abecbd
#             );
#
#
#             var marker_63be3195a7c3047906e22df0bcfe14bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_30ea87d5ea77befd7a8d0c34b8d6df86);
#
#
#         var popup_2db7439cee9cd8707044b474c698d766 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44d2546e8929b17e6e736b32c5c34ea6 = $(`&lt;div id=&quot;html_44d2546e8929b17e6e736b32c5c34ea6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2db7439cee9cd8707044b474c698d766.setContent(html_44d2546e8929b17e6e736b32c5c34ea6);
#
#
#
#         marker_63be3195a7c3047906e22df0bcfe14bb.bindPopup(popup_2db7439cee9cd8707044b474c698d766)
#         ;
#
#
#
#
#             var marker_5ef2e12c89dcd3883f227d0e5c090112 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_30ea87d5ea77befd7a8d0c34b8d6df86);
#
#
#         var popup_14ac7375b0995d52e346182e250fb013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8d64f20e0576b70771f8d837473b7aa = $(`&lt;div id=&quot;html_f8d64f20e0576b70771f8d837473b7aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_14ac7375b0995d52e346182e250fb013.setContent(html_f8d64f20e0576b70771f8d837473b7aa);
#
#
#
#         marker_5ef2e12c89dcd3883f227d0e5c090112.bindPopup(popup_14ac7375b0995d52e346182e250fb013)
#         ;
#
#
#
#
#             var marker_9564368d8a2ebce60130500e0b79d64e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_30ea87d5ea77befd7a8d0c34b8d6df86);
#
#
#         var popup_ea523087b9af9360e6d6394b684a2179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_459e9cb0366b2f46f310d6a89c1fb941 = $(`&lt;div id=&quot;html_459e9cb0366b2f46f310d6a89c1fb941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ea523087b9af9360e6d6394b684a2179.setContent(html_459e9cb0366b2f46f310d6a89c1fb941);
#
#
#
#         marker_9564368d8a2ebce60130500e0b79d64e.bindPopup(popup_ea523087b9af9360e6d6394b684a2179)
#         ;
#
#
#
#
#             var marker_dd7711a0e2bdf151024234860eb36ffa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_30ea87d5ea77befd7a8d0c34b8d6df86);
#
#
#         var popup_2d39c61cbf3b63221180c4924c7d2e03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a654dcfb7c4ec5dab5547806db51b228 = $(`&lt;div id=&quot;html_a654dcfb7c4ec5dab5547806db51b228&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2d39c61cbf3b63221180c4924c7d2e03.setContent(html_a654dcfb7c4ec5dab5547806db51b228);
#
#
#
#         marker_
