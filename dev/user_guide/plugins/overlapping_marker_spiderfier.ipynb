# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f76353559d06ee0b21c9e06583a1837e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f76353559d06ee0b21c9e06583a1837e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f76353559d06ee0b21c9e06583a1837e = L.map(
#                 &quot;map_f76353559d06ee0b21c9e06583a1837e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c4b50a76ed35fa2c188c3f3a8ed0fca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c4b50a76ed35fa2c188c3f3a8ed0fca.addTo(map_f76353559d06ee0b21c9e06583a1837e);
#
#
#             var marker_9d37fd7dbe847a2c51f423e636005b91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f76353559d06ee0b21c9e06583a1837e);
#
#
#         var popup_141baf4195fd7f6daf43c5ceb16508e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4477aa569369dc355ddda699014e1a0b = $(`&lt;div id=&quot;html_4477aa569369dc355ddda699014e1a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_141baf4195fd7f6daf43c5ceb16508e5.setContent(html_4477aa569369dc355ddda699014e1a0b);
#
#
#
#         marker_9d37fd7dbe847a2c51f423e636005b91.bindPopup(popup_141baf4195fd7f6daf43c5ceb16508e5)
#         ;
#
#
#
#
#             var marker_b886bec8a3914fd31c0f77fbfc0f3117 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f76353559d06ee0b21c9e06583a1837e);
#
#
#         var popup_70a73e33c30d9a998e3366bc471fc14b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cac321197d1e4d74b4aa595d2ad15d39 = $(`&lt;div id=&quot;html_cac321197d1e4d74b4aa595d2ad15d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_70a73e33c30d9a998e3366bc471fc14b.setContent(html_cac321197d1e4d74b4aa595d2ad15d39);
#
#
#
#         marker_b886bec8a3914fd31c0f77fbfc0f3117.bindPopup(popup_70a73e33c30d9a998e3366bc471fc14b)
#         ;
#
#
#
#
#             var marker_79baefabab5aedc9b7f2852d1a6e7c6e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f76353559d06ee0b21c9e06583a1837e);
#
#
#         var popup_a8ea4282080b4a34fd88d497246527d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bf736d5458b4c150d3e5d451aef72d2 = $(`&lt;div id=&quot;html_8bf736d5458b4c150d3e5d451aef72d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a8ea4282080b4a34fd88d497246527d9.setContent(html_8bf736d5458b4c150d3e5d451aef72d2);
#
#
#
#         marker_79baefabab5aedc9b7f2852d1a6e7c6e.bindPopup(popup_a8ea4282080b4a34fd88d497246527d9)
#         ;
#
#
#
#
#             var marker_6125f2e52b37fa75e38a168af3a06c2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f76353559d06ee0b21c9e06583a1837e);
#
#
#         var popup_b2406e4f62a97b12416c806420e93a45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61d5611725c30036cd25e2dc671199c8 = $(`&lt;div id=&quot;html_61d5611725c30036cd25e2dc671199c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b2406e4f62a97b12416c806420e93a45.setContent(html_61d5611725c30036cd25e2dc671199c8);
#
#
#
#         marker_6125f2e52b37fa75e38a168af3a06c2b.bindPopup(popup_b2406e4f62a97b12416c806420e93a45)
#         ;
#
#
#
#
#             var marker_e419e8f40fa469144d6be68cb44222a3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f76353559d06ee0b21c9e06583a1837e);
#
#
#         var popup_679ee9592c7de85f9032e3948127a942 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77388088f038b732de43e457cf4f3afa = $(`&lt;div id=&quot;html_77388088f038b732de43e457cf4f3afa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_679ee9592c7de85f9032e3948127a9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a2b7254263cc317c5e86168b0f065f3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a2b7254263cc317c5e86168b0f065f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a2b7254263cc317c5e86168b0f065f3 = L.map(
#                 &quot;map_3a2b7254263cc317c5e86168b0f065f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5584806b975725407e1a91b802b8ca1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5584806b975725407e1a91b802b8ca1f.addTo(map_3a2b7254263cc317c5e86168b0f065f3);
#
#
#             var feature_group_7d416e8742885fb5f4ecbbd554c98fb4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5ec44c85a6dccea717081a94ccd703ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7d416e8742885fb5f4ecbbd554c98fb4);
#
#
#         var popup_08afc3d8ff0b55843d8a7b4c09e1d501 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2820bd389b84bd8d490ecbbb24045719 = $(`&lt;div id=&quot;html_2820bd389b84bd8d490ecbbb24045719&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_08afc3d8ff0b55843d8a7b4c09e1d501.setContent(html_2820bd389b84bd8d490ecbbb24045719);
#
#
#
#         marker_5ec44c85a6dccea717081a94ccd703ea.bindPopup(popup_08afc3d8ff0b55843d8a7b4c09e1d501)
#         ;
#
#
#
#
#             var marker_e31b1e650144aa2f33f4ec52aaed0a63 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7d416e8742885fb5f4ecbbd554c98fb4);
#
#
#         var popup_f2dc10d7a70f083bebb5394745b298c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43a18b50620522d6f6821ca6769978e6 = $(`&lt;div id=&quot;html_43a18b50620522d6f6821ca6769978e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f2dc10d7a70f083bebb5394745b298c9.setContent(html_43a18b50620522d6f6821ca6769978e6);
#
#
#
#         marker_e31b1e650144aa2f33f4ec52aaed0a63.bindPopup(popup_f2dc10d7a70f083bebb5394745b298c9)
#         ;
#
#
#
#
#             var marker_a09702b3234f5ad387fead78c1970fc5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7d416e8742885fb5f4ecbbd554c98fb4);
#
#
#         var popup_7e6d4b1bf7b407fd9d855af3388b4a99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ec8e7d3962b1f18143e411ad3e67175 = $(`&lt;div id=&quot;html_3ec8e7d3962b1f18143e411ad3e67175&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7e6d4b1bf7b407fd9d855af3388b4a99.setContent(html_3ec8e7d3962b1f18143e411ad3e67175);
#
#
#
#         marker_a09702b3234f5ad387fead78c1970fc5.bindPopup(popup_7e6d4b1bf7b407fd9d855af3388b4a99)
#         ;
#
#
#
#
#             var marker_24088dbe2f9a50a149a6bcf94e9f1e4c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7d416e8742885fb5f4ecbbd554c98fb4);
#
#
#         var popup_2c0dbcd83656cc51783bfcbf87e2a733 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dc24d73468961a40e798f6f31e1370d = $(`&lt;div id=&quot;html_9dc24d73468961a40e798f6f31e1370d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c0dbcd83656cc51783bfcbf87e2a733.setContent(html_9dc24d73468961a40e798f6f31e1370d);
#
#
#
#         marker_24088dbe2f9a50a149a6bcf94e9f1e4c.bindPopup(popup_2c0dbcd83656cc51783bfcbf87e2a733)
#         ;
#
#
#
#
#             var marker_29b1c0e3bc274be2c70e9c5d5c44b2fd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7d416e8742885fb5f4ecbbd554c98fb4);
#
#
#         var popup_bc372b367e4a9218ba05d903806e7bc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c1d417c09dd0cc012e50882fd951d82 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c1d417c09dd0cc012e50882fd951d82&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c1d417c09dd0cc012e50882fd951d82 = L.map(
#                 &quot;map_0c1d417c09dd0cc012e50882fd951d82&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2075e28a8d39b3bbe4c524f563c19be2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2075e28a8d39b3bbe4c524f563c19be2.addTo(map_0c1d417c09dd0cc012e50882fd951d82);
#
#
#             var feature_group_613c72742e3c1b3d6371275818e70ee8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_613c72742e3c1b3d6371275818e70ee8.addTo(map_0c1d417c09dd0cc012e50882fd951d82);
#
#
#             var feature_group_sub_group_0f608caac70f74f22120a6b69d530572 = L.featureGroup.subGroup(
#                 feature_group_613c72742e3c1b3d6371275818e70ee8
#             );
#
#
#             var marker_ecd07fdb3f45215131d88310f31cab64 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f608caac70f74f22120a6b69d530572);
#
#
#         var popup_403ed99930294b2f5c8a674930847ea4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a1de7a58527e84a562a54f2586181a7 = $(`&lt;div id=&quot;html_8a1de7a58527e84a562a54f2586181a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_403ed99930294b2f5c8a674930847ea4.setContent(html_8a1de7a58527e84a562a54f2586181a7);
#
#
#
#         marker_ecd07fdb3f45215131d88310f31cab64.bindPopup(popup_403ed99930294b2f5c8a674930847ea4)
#         ;
#
#
#
#
#             var marker_1e114d16c6c66a4e2b6ebbfbd52edcea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f608caac70f74f22120a6b69d530572);
#
#
#         var popup_756e28624943e8fdf96738ad4da7b5e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e49747d5b5cfb834f4ac2982a0a89262 = $(`&lt;div id=&quot;html_e49747d5b5cfb834f4ac2982a0a89262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_756e28624943e8fdf96738ad4da7b5e7.setContent(html_e49747d5b5cfb834f4ac2982a0a89262);
#
#
#
#         marker_1e114d16c6c66a4e2b6ebbfbd52edcea.bindPopup(popup_756e28624943e8fdf96738ad4da7b5e7)
#         ;
#
#
#
#
#             var marker_6731e5e39642088a3e0e9e96470134b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f608caac70f74f22120a6b69d530572);
#
#
#         var popup_632715e10fc9b511937aa214c01af4fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dd4de8927b2b68beaa241f09a2bfb7c = $(`&lt;div id=&quot;html_5dd4de8927b2b68beaa241f09a2bfb7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_632715e10fc9b511937aa214c01af4fc.setContent(html_5dd4de8927b2b68beaa241f09a2bfb7c);
#
#
#
#         marker_6731e5e39642088a3e0e9e96470134b6.bindPopup(popup_632715e10fc9b511937aa214c01af4fc)
#         ;
#
#
#
#
#             var marker_7101eb679206f601567a9633dfc717d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f608caac70f74f22120a6b69d530572);
#
#
#         var popup_c20797c626f23b5c3cafae56505a0b59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef1f6867737f9eafc64bd55ffc0dfae9 = $(`&lt;div id=&quot;html_ef1f6867737f9eafc64bd55ffc0dfae9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c20797c626f23b5c3cafae56505a0b59.setContent(html_ef1f6867737f9eafc64bd55ffc0dfae9);
#
#
#
#         mark
