# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94f17356344bdb3a2043f19fd6a03e04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94f17356344bdb3a2043f19fd6a03e04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94f17356344bdb3a2043f19fd6a03e04 = L.map(
#                 &quot;map_94f17356344bdb3a2043f19fd6a03e04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f1da1d44c65d52646b77badbe018ad5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f1da1d44c65d52646b77badbe018ad5.addTo(map_94f17356344bdb3a2043f19fd6a03e04);
#
#
#             var marker_03d1347bf58a1e63edf0f095fa66936e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94f17356344bdb3a2043f19fd6a03e04);
#
#
#         var popup_9800d569d26156ea21c43e977d7a915b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b1f9e19dea89992c1c4566b904adfbb = $(`&lt;div id=&quot;html_2b1f9e19dea89992c1c4566b904adfbb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9800d569d26156ea21c43e977d7a915b.setContent(html_2b1f9e19dea89992c1c4566b904adfbb);
#
#
#
#         marker_03d1347bf58a1e63edf0f095fa66936e.bindPopup(popup_9800d569d26156ea21c43e977d7a915b)
#         ;
#
#
#
#
#             var marker_cb6ff5f9a3a1045e7062dd8123347081 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94f17356344bdb3a2043f19fd6a03e04);
#
#
#         var popup_2cde411b08d11d1a91bd98385dbf47f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40e1f05ca2fc35b640b64555d88a3f09 = $(`&lt;div id=&quot;html_40e1f05ca2fc35b640b64555d88a3f09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2cde411b08d11d1a91bd98385dbf47f0.setContent(html_40e1f05ca2fc35b640b64555d88a3f09);
#
#
#
#         marker_cb6ff5f9a3a1045e7062dd8123347081.bindPopup(popup_2cde411b08d11d1a91bd98385dbf47f0)
#         ;
#
#
#
#
#             var marker_c84815962c356fc10cf3bb9deb5402dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94f17356344bdb3a2043f19fd6a03e04);
#
#
#         var popup_3319ba008ab240301bad1819195c1a26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd0ca7963c62abaf235cfbec63d22443 = $(`&lt;div id=&quot;html_dd0ca7963c62abaf235cfbec63d22443&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3319ba008ab240301bad1819195c1a26.setContent(html_dd0ca7963c62abaf235cfbec63d22443);
#
#
#
#         marker_c84815962c356fc10cf3bb9deb5402dc.bindPopup(popup_3319ba008ab240301bad1819195c1a26)
#         ;
#
#
#
#
#             var marker_f252dcd45dd664dd63604362ca2f447d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94f17356344bdb3a2043f19fd6a03e04);
#
#
#         var popup_1bcc75a2c0065b26101dced9607f64ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f46666eee77886eaa4ff083fe32f745 = $(`&lt;div id=&quot;html_4f46666eee77886eaa4ff083fe32f745&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1bcc75a2c0065b26101dced9607f64ee.setContent(html_4f46666eee77886eaa4ff083fe32f745);
#
#
#
#         marker_f252dcd45dd664dd63604362ca2f447d.bindPopup(popup_1bcc75a2c0065b26101dced9607f64ee)
#         ;
#
#
#
#
#             var marker_0f87bfdb2b37a1cb800120648c623551 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94f17356344bdb3a2043f19fd6a03e04);
#
#
#         var popup_85ef19cc0484c0b55e5e07ef657a12ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64b1aa304ca76a0a6a5077cb17019639 = $(`&lt;div id=&quot;html_64b1aa304ca76a0a6a5077cb17019639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_85ef19cc0484c0b55e5e07ef657a12ea.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2718b2ffe0d30636e2e564558902ada {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2718b2ffe0d30636e2e564558902ada&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2718b2ffe0d30636e2e564558902ada = L.map(
#                 &quot;map_e2718b2ffe0d30636e2e564558902ada&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f9c6de653570a2af66e5bb685d3cda7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f9c6de653570a2af66e5bb685d3cda7.addTo(map_e2718b2ffe0d30636e2e564558902ada);
#
#
#             var feature_group_35578f9f908e7779cd297cb779a01a1e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5d51d9c046f6c6f9a749222963a949e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_35578f9f908e7779cd297cb779a01a1e);
#
#
#         var popup_f9a7802dc6de1f6ec0e1073bab7a2a0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1850f19a563eb8b0935df72abaaa273 = $(`&lt;div id=&quot;html_b1850f19a563eb8b0935df72abaaa273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f9a7802dc6de1f6ec0e1073bab7a2a0d.setContent(html_b1850f19a563eb8b0935df72abaaa273);
#
#
#
#         marker_d5d51d9c046f6c6f9a749222963a949e.bindPopup(popup_f9a7802dc6de1f6ec0e1073bab7a2a0d)
#         ;
#
#
#
#
#             var marker_6fa2fc7ea50f0f1342dca935b002a982 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_35578f9f908e7779cd297cb779a01a1e);
#
#
#         var popup_5b6b4f46e76600dcdd8e62dff7198c3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6de53213fa5907552b11f84294c0bcfb = $(`&lt;div id=&quot;html_6de53213fa5907552b11f84294c0bcfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5b6b4f46e76600dcdd8e62dff7198c3f.setContent(html_6de53213fa5907552b11f84294c0bcfb);
#
#
#
#         marker_6fa2fc7ea50f0f1342dca935b002a982.bindPopup(popup_5b6b4f46e76600dcdd8e62dff7198c3f)
#         ;
#
#
#
#
#             var marker_73911cce48acc8a3cf0848a1ea2276bb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_35578f9f908e7779cd297cb779a01a1e);
#
#
#         var popup_b928ff520ff49c6201f6e9c9a01a542c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db55579445b559c8cbe50f275292f21a = $(`&lt;div id=&quot;html_db55579445b559c8cbe50f275292f21a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b928ff520ff49c6201f6e9c9a01a542c.setContent(html_db55579445b559c8cbe50f275292f21a);
#
#
#
#         marker_73911cce48acc8a3cf0848a1ea2276bb.bindPopup(popup_b928ff520ff49c6201f6e9c9a01a542c)
#         ;
#
#
#
#
#             var marker_c8d10ff69f9ffb9a5fc1d459660cc3db = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_35578f9f908e7779cd297cb779a01a1e);
#
#
#         var popup_ce2f4ed60609329cdc2fa079dc2e36bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f1b16a94167fd3ae91599a9b159f69e = $(`&lt;div id=&quot;html_0f1b16a94167fd3ae91599a9b159f69e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ce2f4ed60609329cdc2fa079dc2e36bb.setContent(html_0f1b16a94167fd3ae91599a9b159f69e);
#
#
#
#         marker_c8d10ff69f9ffb9a5fc1d459660cc3db.bindPopup(popup_ce2f4ed60609329cdc2fa079dc2e36bb)
#         ;
#
#
#
#
#             var marker_0f279e121fd10ac8a86bfea57e0ccde2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_35578f9f908e7779cd297cb779a01a1e);
#
#
#         var popup_a462fac8d1e59295176e0ee8f3af0b27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5112477dfcd9eabb4cb33a53cf84c41b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5112477dfcd9eabb4cb33a53cf84c41b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5112477dfcd9eabb4cb33a53cf84c41b = L.map(
#                 &quot;map_5112477dfcd9eabb4cb33a53cf84c41b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a1bb8710c6b1ce706049d4498c1322f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a1bb8710c6b1ce706049d4498c1322f.addTo(map_5112477dfcd9eabb4cb33a53cf84c41b);
#
#
#             var feature_group_37c78788f2def630bfd2c62c379c19bb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_37c78788f2def630bfd2c62c379c19bb.addTo(map_5112477dfcd9eabb4cb33a53cf84c41b);
#
#
#             var feature_group_sub_group_a232ca878b4d80ccb8ba79514590b3f4 = L.featureGroup.subGroup(
#                 feature_group_37c78788f2def630bfd2c62c379c19bb
#             );
#
#
#             var marker_cd43f98cc5eef72fac9603c0e1ec91b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a232ca878b4d80ccb8ba79514590b3f4);
#
#
#         var popup_8aafd231b2d586c61d298b0b80480f25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65601b5d1edf84424f14427e37485f67 = $(`&lt;div id=&quot;html_65601b5d1edf84424f14427e37485f67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8aafd231b2d586c61d298b0b80480f25.setContent(html_65601b5d1edf84424f14427e37485f67);
#
#
#
#         marker_cd43f98cc5eef72fac9603c0e1ec91b5.bindPopup(popup_8aafd231b2d586c61d298b0b80480f25)
#         ;
#
#
#
#
#             var marker_dfa61ae5c4b2cb90614c726abc567298 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a232ca878b4d80ccb8ba79514590b3f4);
#
#
#         var popup_046e5c50249dacc8c18c87a4ad104519 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_374ed13a61ffe569b74ac86b036713a8 = $(`&lt;div id=&quot;html_374ed13a61ffe569b74ac86b036713a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_046e5c50249dacc8c18c87a4ad104519.setContent(html_374ed13a61ffe569b74ac86b036713a8);
#
#
#
#         marker_dfa61ae5c4b2cb90614c726abc567298.bindPopup(popup_046e5c50249dacc8c18c87a4ad104519)
#         ;
#
#
#
#
#             var marker_2abecf07d09804aba7b0f34a322fd793 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a232ca878b4d80ccb8ba79514590b3f4);
#
#
#         var popup_67c2e653dbd3ccf952fdf9e7aca2aa60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04d6c7e06c53c5552cac8d602c4ac74d = $(`&lt;div id=&quot;html_04d6c7e06c53c5552cac8d602c4ac74d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_67c2e653dbd3ccf952fdf9e7aca2aa60.setContent(html_04d6c7e06c53c5552cac8d602c4ac74d);
#
#
#
#         marker_2abecf07d09804aba7b0f34a322fd793.bindPopup(popup_67c2e653dbd3ccf952fdf9e7aca2aa60)
#         ;
#
#
#
#
#             var marker_a46cb0c4008ef0ae7eacdabd82b4ffb9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a232ca878b4d80ccb8ba79514590b3f4);
#
#
#         var popup_b1dbb3d89d1c765e7cfc1f6a34ef8b5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4938326c625ce9652229b358d0ed94c8 = $(`&lt;div id=&quot;html_4938326c625ce9652229b358d0ed94c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b1dbb3d89d1c765e7cfc1f6a34ef8b5f.setContent(html_4938326c625ce9652229b358d0ed94c8);
#
#
#
#         marker_
