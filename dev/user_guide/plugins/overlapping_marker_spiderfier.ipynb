# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf21e52a616b498c5e6659df1989c027 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf21e52a616b498c5e6659df1989c027&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf21e52a616b498c5e6659df1989c027 = L.map(
#                 &quot;map_bf21e52a616b498c5e6659df1989c027&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d37cf3c6b504e7bba8a773222c870b02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d37cf3c6b504e7bba8a773222c870b02.addTo(map_bf21e52a616b498c5e6659df1989c027);
#
#
#             var marker_c0d70a751bebe8eaf7fc6d7324842d5a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bf21e52a616b498c5e6659df1989c027);
#
#
#         var popup_9a1b8030b28cc365093885f890b71a03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_498df1280cd37d79cb77e581834f0e1c = $(`&lt;div id=&quot;html_498df1280cd37d79cb77e581834f0e1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9a1b8030b28cc365093885f890b71a03.setContent(html_498df1280cd37d79cb77e581834f0e1c);
#
#
#
#         marker_c0d70a751bebe8eaf7fc6d7324842d5a.bindPopup(popup_9a1b8030b28cc365093885f890b71a03)
#         ;
#
#
#
#
#             var marker_ad573f5e6b6e1ab64335032fb5c3ed49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bf21e52a616b498c5e6659df1989c027);
#
#
#         var popup_694c88628c2f8b0545e9db5b4a94b2c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6de393c1a7ae4342e7067cf5e4b9148 = $(`&lt;div id=&quot;html_f6de393c1a7ae4342e7067cf5e4b9148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_694c88628c2f8b0545e9db5b4a94b2c7.setContent(html_f6de393c1a7ae4342e7067cf5e4b9148);
#
#
#
#         marker_ad573f5e6b6e1ab64335032fb5c3ed49.bindPopup(popup_694c88628c2f8b0545e9db5b4a94b2c7)
#         ;
#
#
#
#
#             var marker_c0e81b667a3940a3446707b46dffe5ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bf21e52a616b498c5e6659df1989c027);
#
#
#         var popup_12b4dbbcf3d51007e07590e0ab3d5727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5abcf95f83e4e55b16178b745fd80e66 = $(`&lt;div id=&quot;html_5abcf95f83e4e55b16178b745fd80e66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_12b4dbbcf3d51007e07590e0ab3d5727.setContent(html_5abcf95f83e4e55b16178b745fd80e66);
#
#
#
#         marker_c0e81b667a3940a3446707b46dffe5ff.bindPopup(popup_12b4dbbcf3d51007e07590e0ab3d5727)
#         ;
#
#
#
#
#             var marker_261b53d48be69d83ba3d4b2c09728f54 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bf21e52a616b498c5e6659df1989c027);
#
#
#         var popup_a6bc351294963eef4fd6b624849e1eca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_240d5f61d08bd7885845e572a1bfd6ff = $(`&lt;div id=&quot;html_240d5f61d08bd7885845e572a1bfd6ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a6bc351294963eef4fd6b624849e1eca.setContent(html_240d5f61d08bd7885845e572a1bfd6ff);
#
#
#
#         marker_261b53d48be69d83ba3d4b2c09728f54.bindPopup(popup_a6bc351294963eef4fd6b624849e1eca)
#         ;
#
#
#
#
#             var marker_48c530a527634a8cd17ec08eacbd9f30 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bf21e52a616b498c5e6659df1989c027);
#
#
#         var popup_defa622f47a7778b29ed6250da18da1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84dd527fab9013eeff1c3370d9fbd63c = $(`&lt;div id=&quot;html_84dd527fab9013eeff1c3370d9fbd63c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_defa622f47a7778b29ed6250da18da1c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_938a399c2a93e5f1ed3b13296964b06d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_938a399c2a93e5f1ed3b13296964b06d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_938a399c2a93e5f1ed3b13296964b06d = L.map(
#                 &quot;map_938a399c2a93e5f1ed3b13296964b06d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b6b0f76cc2378bbd1840d7cadfa6c8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b6b0f76cc2378bbd1840d7cadfa6c8b.addTo(map_938a399c2a93e5f1ed3b13296964b06d);
#
#
#             var feature_group_89ed68e9c1987f3f2545f61145c3a40f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e26d42d71f515bf21a0e0ab2de5125df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_89ed68e9c1987f3f2545f61145c3a40f);
#
#
#         var popup_65020b1677a02b11cd3340e9efb05180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e955785c8c1301f74ff2b9cfc35b001 = $(`&lt;div id=&quot;html_7e955785c8c1301f74ff2b9cfc35b001&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_65020b1677a02b11cd3340e9efb05180.setContent(html_7e955785c8c1301f74ff2b9cfc35b001);
#
#
#
#         marker_e26d42d71f515bf21a0e0ab2de5125df.bindPopup(popup_65020b1677a02b11cd3340e9efb05180)
#         ;
#
#
#
#
#             var marker_8bc5e59a41837fbf4fb44e121416754a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_89ed68e9c1987f3f2545f61145c3a40f);
#
#
#         var popup_1c0fbd8cbded433160fe750e7e3224b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d9ffa1e0917de2e76d085693f182b6 = $(`&lt;div id=&quot;html_89d9ffa1e0917de2e76d085693f182b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c0fbd8cbded433160fe750e7e3224b6.setContent(html_89d9ffa1e0917de2e76d085693f182b6);
#
#
#
#         marker_8bc5e59a41837fbf4fb44e121416754a.bindPopup(popup_1c0fbd8cbded433160fe750e7e3224b6)
#         ;
#
#
#
#
#             var marker_074e47aebfe6ce16f6343933e7c8fff1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_89ed68e9c1987f3f2545f61145c3a40f);
#
#
#         var popup_03d6ea01e93c81f0698caeaeac0bc4f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_524a406b9a72a47cb5bb7ce868115e54 = $(`&lt;div id=&quot;html_524a406b9a72a47cb5bb7ce868115e54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_03d6ea01e93c81f0698caeaeac0bc4f6.setContent(html_524a406b9a72a47cb5bb7ce868115e54);
#
#
#
#         marker_074e47aebfe6ce16f6343933e7c8fff1.bindPopup(popup_03d6ea01e93c81f0698caeaeac0bc4f6)
#         ;
#
#
#
#
#             var marker_e49975a7f4b9bee94c9792b49ab14d2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_89ed68e9c1987f3f2545f61145c3a40f);
#
#
#         var popup_d35ff9bb0524993fecb57c737e8d89e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_346be18fb72cdb5811e3ef7ebc73cc07 = $(`&lt;div id=&quot;html_346be18fb72cdb5811e3ef7ebc73cc07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d35ff9bb0524993fecb57c737e8d89e0.setContent(html_346be18fb72cdb5811e3ef7ebc73cc07);
#
#
#
#         marker_e49975a7f4b9bee94c9792b49ab14d2b.bindPopup(popup_d35ff9bb0524993fecb57c737e8d89e0)
#         ;
#
#
#
#
#             var marker_697d7ba563941614cfd5a03c02822249 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_89ed68e9c1987f3f2545f61145c3a40f);
#
#
#         var popup_05df4325c712221ad358c557edc34223 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_64d1f74cb33106cc82f6624fd7aa793b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_64d1f74cb33106cc82f6624fd7aa793b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_64d1f74cb33106cc82f6624fd7aa793b = L.map(
#                 &quot;map_64d1f74cb33106cc82f6624fd7aa793b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b642a1c3a0ebed64edddfdea221fde5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b642a1c3a0ebed64edddfdea221fde5d.addTo(map_64d1f74cb33106cc82f6624fd7aa793b);
#
#
#             var feature_group_becbd06d40034551585fe85f093b0b42 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_becbd06d40034551585fe85f093b0b42.addTo(map_64d1f74cb33106cc82f6624fd7aa793b);
#
#
#             var feature_group_sub_group_c868ee1bfbd936c87669cb075073f865 = L.featureGroup.subGroup(
#                 feature_group_becbd06d40034551585fe85f093b0b42
#             );
#
#
#             var marker_99a4cd08decdfabe9c5a3a10f8e1e167 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c868ee1bfbd936c87669cb075073f865);
#
#
#         var popup_e60162554933985c6237b4c55b702fd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3b2c2afb1dbb30a336a15ad2ad41915 = $(`&lt;div id=&quot;html_b3b2c2afb1dbb30a336a15ad2ad41915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e60162554933985c6237b4c55b702fd3.setContent(html_b3b2c2afb1dbb30a336a15ad2ad41915);
#
#
#
#         marker_99a4cd08decdfabe9c5a3a10f8e1e167.bindPopup(popup_e60162554933985c6237b4c55b702fd3)
#         ;
#
#
#
#
#             var marker_6cad97132727e3a4b516e8c91cc4a78a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c868ee1bfbd936c87669cb075073f865);
#
#
#         var popup_11c1b4839ec137c0c562814c3e9c1c0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18c12ac1194d6f60cd68741a74ea55e1 = $(`&lt;div id=&quot;html_18c12ac1194d6f60cd68741a74ea55e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_11c1b4839ec137c0c562814c3e9c1c0f.setContent(html_18c12ac1194d6f60cd68741a74ea55e1);
#
#
#
#         marker_6cad97132727e3a4b516e8c91cc4a78a.bindPopup(popup_11c1b4839ec137c0c562814c3e9c1c0f)
#         ;
#
#
#
#
#             var marker_316df320219b3da674b92c841b5bc4db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c868ee1bfbd936c87669cb075073f865);
#
#
#         var popup_8bc2fed4793d9694acbfd5246305b4f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f84e98150eb76b94039b765e7255cfca = $(`&lt;div id=&quot;html_f84e98150eb76b94039b765e7255cfca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8bc2fed4793d9694acbfd5246305b4f7.setContent(html_f84e98150eb76b94039b765e7255cfca);
#
#
#
#         marker_316df320219b3da674b92c841b5bc4db.bindPopup(popup_8bc2fed4793d9694acbfd5246305b4f7)
#         ;
#
#
#
#
#             var marker_a950004a0071fdcd0438d67c5b04502f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c868ee1bfbd936c87669cb075073f865);
#
#
#         var popup_62a42c5ec16de7b26c5ccbbe86a5f271 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffe2968a872080ab9ea3ddbef36cd74c = $(`&lt;div id=&quot;html_ffe2968a872080ab9ea3ddbef36cd74c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_62a42c5ec16de7b26c5ccbbe86a5f271.setContent(html_ffe2968a872080ab9ea3ddbef36cd74c);
#
#
#
#         marker_
