# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_709582bf6450af230d4d56df19b62398 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_709582bf6450af230d4d56df19b62398&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_709582bf6450af230d4d56df19b62398 = L.map(
#                 &quot;map_709582bf6450af230d4d56df19b62398&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85caf63b2772ecd9020bd987550c7d54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_85caf63b2772ecd9020bd987550c7d54.addTo(map_709582bf6450af230d4d56df19b62398);
#
#
#             var marker_cluster_7b386f38a99005f2cadabcdaf73325cf = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_13d62743a81032f05e16ec334ad258f0 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_7b386f38a99005f2cadabcdaf73325cf);
#
#
#             var icon_53c4f55819a505f2fda9b73e52cea7a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13d62743a81032f05e16ec334ad258f0.setIcon(icon_53c4f55819a505f2fda9b73e52cea7a7);
#
#
#         var popup_525f002f0c91f2b0e1e614a973d90d27 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6d74c408a2a1b52b93b73b6111c7d21 = $(`&lt;div id=&quot;html_e6d74c408a2a1b52b93b73b6111c7d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_525f002f0c91f2b0e1e614a973d90d27.setContent(html_e6d74c408a2a1b52b93b73b6111c7d21);
#
#
#
#         marker_13d62743a81032f05e16ec334ad258f0.bindPopup(popup_525f002f0c91f2b0e1e614a973d90d27)
#         ;
#
#
#
#
#             var marker_817fa294b80e28b7da6b93f212086157 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_7b386f38a99005f2cadabcdaf73325cf);
#
#
#             var icon_754ff0247522565c08f76001696aa91b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_817fa294b80e28b7da6b93f212086157.setIcon(icon_754ff0247522565c08f76001696aa91b);
#
#
#         var popup_fe019bfac0b28efd08cf3bca48121639 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ace7297d55767dd0fa7703ba6e541310 = $(`&lt;div id=&quot;html_ace7297d55767dd0fa7703ba6e541310&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fe019bfac0b28efd08cf3bca48121639.setContent(html_ace7297d55767dd0fa7703ba6e541310);
#
#
#
#         marker_817fa294b80e28b7da6b93f212086157.bindPopup(popup_fe019bfac0b28efd08cf3bca48121639)
#         ;
#
#
#
#
#             var marker_1da62399f9cd85320ee29c98ac2bd5d9 = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_7b386f38a99005f2cadabcdaf73325cf);
#
#
#         var popup_cc105048302c274de1029ac723509f08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09a4b0d56dc365198f00faef5c02723a = $(`&lt;div id=&quot;html_09a4b0d56dc365198f00faef5c02723a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_cc105048302c274de1029ac723509f08.setContent(html_09a4b0d56dc365198f00faef5c02723a);
#
#
#
#         marker_1da62399f9cd85320ee29c98ac2bd5d9.bindPopup(popup_cc105048302c274de1029ac723509f08)
#         ;
#
#
#
#
#             marker_cluster_7b386f38a99005f2cadabcdaf73325cf.addTo(map_709582bf6450af230d4d56df19b62398);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0152829900ab684e96dabb5bf20527f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0152829900ab684e96dabb5bf20527f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0152829900ab684e96dabb5bf20527f6 = L.map(
#                 &quot;map_0152829900ab684e96dabb5bf20527f6&quot;,
#                 {
#                     center: [-3.73, -16.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37b34fda80f1b11e2c5fa1d4d65df9d0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_37b34fda80f1b11e2c5fa1d4d65df9d0.addTo(map_0152829900ab684e96dabb5bf20527f6);
#
#
#             var marker_cluster_dbbcc5d67492ca2cb455d07a37ec7e66 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_dbbcc5d67492ca2cb455d07a37ec7e66.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_3c75bb2df82b413ee9fcab8770bf8e34 = L.marker(
#                 [-19.0, 131.0],
#                 {}
#             ).addTo(marker_cluster_dbbcc5d67492ca2cb455d07a37ec7e66);
#
#
#         var popup_9f54c89392b3782fced6544901f1f65b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c02e46cc5f53f1bd5b89cd80c5601a7 = $(`&lt;div id=&quot;html_8c02e46cc5f53f1bd5b89cd80c5601a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:131&lt;br&gt;lat:-19&lt;/div&gt;`)[0];
#                 popup_9f54c89392b3782fced6544901f1f65b.setContent(html_8c02e46cc5f53f1bd5b89cd80c5601a7);
#
#
#
#         marker_3c75bb2df82b413ee9fcab8770bf8e34.bindPopup(popup_9f54c89392b3782fced6544901f1f65b)
#         ;
#
#
#
#
#             var marker_97bf2ddb0729b7b2edb99e49b621ebe6 = L.marker(
#                 [-18.0, -124.0],
#                 {}
#             ).addTo(marker_cluster_dbbcc5d67492ca2cb455d07a37ec7e66);
#
#
#         var popup_2e448455563fdae836241b83964b88e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_646819c677ae20f66dac7a8183f15598 = $(`&lt;div id=&quot;html_646819c677ae20f66dac7a8183f15598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-124&lt;br&gt;lat:-18&lt;/div&gt;`)[0];
#                 popup_2e448455563fdae836241b83964b88e4.setContent(html_646819c677ae20f66dac7a8183f15598);
#
#
#
#         marker_97bf2ddb0729b7b2edb99e49b621ebe6.bindPopup(popup_2e448455563fdae836241b83964b88e4)
#         ;
#
#
#
#
#             var marker_553c0bc1454c79532d1d3ce23df58fe7 = L.marker(
#                 [-85.0, -50.0],
#                 {}
#             ).addTo(marker_cluster_dbbcc5d67492ca2cb455d07a37ec7e66);
#
#
#         var popup_d8b075a79b79b8d809105431c43f5b55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d8cc45f11a8418ca3a93cb5d14f1a862 = $(`&lt;div id=&quot;html_d8cc45f11a8418ca3a93cb5d14f1a862&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-50&lt;br&gt;lat:-85&lt;/div&gt;`)[0];
#                 popup_d8b075a79b79b8d809105431c43f5b55.setContent(html_d8cc45f11a8418ca3a93cb5d14f1a862);
#
#
#
#         marker_553c0bc1454c79532d1d3ce23df58fe7.bindPopup(popup_d8b075a79b79b8d809105431c43f5b55)
#         ;
#
#
#
#
#             var marker_c391edf62ebd6de695aa5c163021b6df = L.marker(
#                 [-5.0, -80.0],
#                 {}
#             ).addTo(marker_cluster_dbbcc5d67492ca2cb455d07a37ec7e66);
#
#
#         var popup_75969f23e7dfe9ad7546c7344bb76f4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1e7f8dc1fee63309a3a91fe11bfa131 = $(`&lt;div id=&quot;html_d1e7f8dc1fee63309a3a91fe11bfa131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-80&lt;br&gt;lat:-5&lt;/div&gt;`)[0];
#                 popup_75969f23e7dfe9ad7546c7344bb76f4f.setContent(html_d1e7f8dc1fee63309a3a91fe11bfa131);
#
#
#
#         marker_c391edf62

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ac9b340e0056dfa243a7eb56b5217d9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ac9b340e0056dfa243a7eb56b5217d9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ac9b340e0056dfa243a7eb56b5217d9 = L.map(
#                 &quot;map_5ac9b340e0056dfa243a7eb56b5217d9&quot;,
#                 {
#                     center: [-3.73, -16.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a76d9497fff8e10755bc726986f41d8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a76d9497fff8e10755bc726986f41d8.addTo(map_5ac9b340e0056dfa243a7eb56b5217d9);
#
#
#             var marker_cluster_af7833508e2aaf220932bdbf7450b1c2 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_03af862fae78efb915ee487928c8d692 = L.marker(
#                 [-19.0, 131.0],
#                 {}
#             ).addTo(marker_cluster_af7833508e2aaf220932bdbf7450b1c2);
#
#
#         var popup_58c498d1b75c7e94d69aafaa7ef246f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebfecdd545611a74bf0b4cf32451a6f0 = $(`&lt;div id=&quot;html_ebfecdd545611a74bf0b4cf32451a6f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:131&lt;br&gt;lat:-19&lt;/div&gt;`)[0];
#                 popup_58c498d1b75c7e94d69aafaa7ef246f7.setContent(html_ebfecdd545611a74bf0b4cf32451a6f0);
#
#
#
#         marker_03af862fae78efb915ee487928c8d692.bindPopup(popup_58c498d1b75c7e94d69aafaa7ef246f7)
#         ;
#
#
#
#
#             var marker_272d80086777178ff850c8c9bbb09c4b = L.marker(
#                 [-18.0, -124.0],
#                 {}
#             ).addTo(marker_cluster_af7833508e2aaf220932bdbf7450b1c2);
#
#
#         var popup_0bd5aa7d836519d20fcf8f7e21453d7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_339db49d15ace0d826132f25d497b843 = $(`&lt;div id=&quot;html_339db49d15ace0d826132f25d497b843&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-124&lt;br&gt;lat:-18&lt;/div&gt;`)[0];
#                 popup_0bd5aa7d836519d20fcf8f7e21453d7f.setContent(html_339db49d15ace0d826132f25d497b843);
#
#
#
#         marker_272d80086777178ff850c8c9bbb09c4b.bindPopup(popup_0bd5aa7d836519d20fcf8f7e21453d7f)
#         ;
#
#
#
#
#             var marker_882d4fcdd22810afd51fdb8a7e59c785 = L.marker(
#                 [-85.0, -50.0],
#                 {}
#             ).addTo(marker_cluster_af7833508e2aaf220932bdbf7450b1c2);
#
#
#         var popup_9756907e9d38214ffb6ed06f1703e3a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_217bc010ae732c1a8f43f8fd594f1fac = $(`&lt;div id=&quot;html_217bc010ae732c1a8f43f8fd594f1fac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-50&lt;br&gt;lat:-85&lt;/div&gt;`)[0];
#                 popup_9756907e9d38214ffb6ed06f1703e3a0.setContent(html_217bc010ae732c1a8f43f8fd594f1fac);
#
#
#
#         marker_882d4fcdd22810afd51fdb8a7e59c785.bindPopup(popup_9756907e9d38214ffb6ed06f1703e3a0)
#         ;
#
#
#
#
#             var marker_ea4336ae036b1f17f7d9dc2026208a02 = L.marker(
#                 [-5.0, -80.0],
#                 {}
#             ).addTo(marker_cluster_af7833508e2aaf220932bdbf7450b1c2);
#
#
#         var popup_72ed9f2ed8e0d606288595349d109c93 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7dd31f81b1621314b9580944cd4158c = $(`&lt;div id=&quot;html_d7dd31f81b1621314b9580944cd4158c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-80&lt;br&gt;lat:-5&lt;/div&gt;`)[0];
#                 popup_72ed9f2ed8e0d606288595349d109c93.setContent(html_d7dd31f81b1621314b9580944cd4158c);
#
#
#
#         marker_ea4336ae036b1f17f7d9dc2026208a02.bindPopup(popup_72ed9f2ed8e0d606288595349d109c93)
#         ;
#
#
#
#
#             var marker_9b2e9b19c9c834b9459ca23e626aeea6 = L.marker(
#                 [33.0, 95.0],
#                 {}
#             ).addTo(marker_cluster_af7833508e2aaf220932bdbf7450b1c2);
#
#
#         var popup_ba58d3ef776860b5d8

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66a51e7ea9bcb0092a2688766351d751 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66a51e7ea9bcb0092a2688766351d751&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66a51e7ea9bcb0092a2688766351d751 = L.map(
#                 &quot;map_66a51e7ea9bcb0092a2688766351d751&quot;,
#                 {
#                     center: [-3.73, -16.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90e8583717636c27f66679c43639ff2a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_90e8583717636c27f66679c43639ff2a.addTo(map_66a51e7ea9bcb0092a2688766351d751);
#
#
#             var fast_marker_cluster_899344c54b3d625da58140be44e02734 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-19.0, 131.0], [-18.0, -124.0], [-85.0, -50.0], [-5.0, -80.0], [33.0, 95.0], [6.0, -71.0], [14.0, -9.0], [47.0, 139.0], [8.0, -100.0], [-86.0, 5.0], [40.0, -152.0], [30.0, -154.0], [5.0, 49.0], [20.0, -70.0], [-39.0, 158.0], [-29.0, -93.0], [-68.0, 41.0], [37.0, 40.0], [63.0, 34.0], [53.0, -175.0], [-61.0, -109.0], [-71.0, -44.0], [-50.0, -71.0], [-15.0, -16.0], [-6.0, 42.0], [-72.0, -88.0], [26.0, -100.0], [17.0, -44.0], [-77.0, 131.0], [-72.0, -25.0], [-50.0, 18.0], [89.0, -83.0], [69.0, 47.0], [58.0, 3.0], [46.0, -28.0], [1.0, 107.0], [-42.0, 159.0], [17.0, -117.0], [16.0, 37.0], [38.0, -90.0], [32.0, -60.0], [31.0, -180.0], [19.0, -121.0], [-53.0, 178.0], [44.0, -143.0], [-60.0, 62.0], [-60.0, 54.0], [48.0, -44.0], [8.0, -31.0], [-37.0, -151.0], [-70.0, -116.0], [-85.0, -74.0], [45.0, -138.0], [-53.0, -94.0], [-59.0, 174.0], [-67.0, 99.0], [-67.0, 159.0], [28.0, -149.0], [-7.0, 25.0], [-87.0, -115.0], [66.0, 76.0], [77.0, -170.0], [-20.0, 112.0], [51.0, 111.0], [-79.0, 65.0], [22.0, -177.0], [-8.0, 156.0], [34.0, 121.0], [-7.0, 156.0], [80.0, -92.0], [53.0, -126.0], [63.0, -147.0], [-20.0, 170.0], [84.0, 58.0], [-34.0, -69.0], [64.0, -30.0], [37.0, -58.0], [-32.0, -142.0], [9.0, -134.0], [78.0, -15.0], [-16.0, 64.0], [-33.0, -1.0], [-66.0, -37.0], [2.0, 85.0], [-20.0, 94.0], [-50.0, 26.0], [-24.0, -162.0], [23.0, 70.0], [-30.0, 51.0], [-67.0, -97.0], [-52.0, 87.0], [-69.0, -171.0], [23.0, 57.0], [29.0, -176.0], [67.0, 172.0], [-70.0, 20.0], [-9.0, -175.0], [58.0, -156.0], [79.0, 119.0], [-84.0, -66.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_66a51e7ea9bcb0092a2688766351d751);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_899344c54b3d625da58140be44e02734.addTo(map_66a51e7ea9bcb0092a2688766351d751);
#
#
#             var layer_control_f9a5ec9e63842626a59e7b36ba103e5d_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_90e8583717636c27f66679c43639ff2a,
#                 },
#                 overlays :  {
#                     &quot;macro_element_899344c54b3d625da58140be44e02734&quot; : fast_marker_cluster_899344c54b3d625da58140be44e02734,
#                 },
#             };
#             let layer_control_f9a5ec9e63842626a59e7b36ba103e5d = L.control.layers(
#                 layer_control_f9a5ec9e63842626a59e7b36ba103e5d_layers.base_layers,
#                 layer_control_f9a5ec9e63842626a59e7b36ba103e5d_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_66a51e7ea9bcb0092a2688766351d751);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17be285314ed174a2b1722a933eb3532 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17be285314ed174a2b1722a933eb3532&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17be285314ed174a2b1722a933eb3532 = L.map(
#                 &quot;map_17be285314ed174a2b1722a933eb3532&quot;,
#                 {
#                     center: [-3.73, -16.53],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_407d0850e683dc39d04c8e6ea52fdcc9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_407d0850e683dc39d04c8e6ea52fdcc9.addTo(map_17be285314ed174a2b1722a933eb3532);
#
#
#             var fast_marker_cluster_dee02ed955203ed103ea3c92ca94bf6d = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-19.0, 131.0], [-18.0, -124.0], [-85.0, -50.0], [-5.0, -80.0], [33.0, 95.0], [6.0, -71.0], [14.0, -9.0], [47.0, 139.0], [8.0, -100.0], [-86.0, 5.0], [40.0, -152.0], [30.0, -154.0], [5.0, 49.0], [20.0, -70.0], [-39.0, 158.0], [-29.0, -93.0], [-68.0, 41.0], [37.0, 40.0], [63.0, 34.0], [53.0, -175.0], [-61.0, -109.0], [-71.0, -44.0], [-50.0, -71.0], [-15.0, -16.0], [-6.0, 42.0], [-72.0, -88.0], [26.0, -100.0], [17.0, -44.0], [-77.0, 131.0], [-72.0, -25.0], [-50.0, 18.0], [89.0, -83.0], [69.0, 47.0], [58.0, 3.0], [46.0, -28.0], [1.0, 107.0], [-42.0, 159.0], [17.0, -117.0], [16.0, 37.0], [38.0, -90.0], [32.0, -60.0], [31.0, -180.0], [19.0, -121.0], [-53.0, 178.0], [44.0, -143.0], [-60.0, 62.0], [-60.0, 54.0], [48.0, -44.0], [8.0, -31.0], [-37.0, -151.0], [-70.0, -116.0], [-85.0, -74.0], [45.0, -138.0], [-53.0, -94.0], [-59.0, 174.0], [-67.0, 99.0], [-67.0, 159.0], [28.0, -149.0], [-7.0, 25.0], [-87.0, -115.0], [66.0, 76.0], [77.0, -170.0], [-20.0, 112.0], [51.0, 111.0], [-79.0, 65.0], [22.0, -177.0], [-8.0, 156.0], [34.0, 121.0], [-7.0, 156.0], [80.0, -92.0], [53.0, -126.0], [63.0, -147.0], [-20.0, 170.0], [84.0, 58.0], [-34.0, -69.0], [64.0, -30.0], [37.0, -58.0], [-32.0, -142.0], [9.0, -134.0], [78.0, -15.0], [-16.0, 64.0], [-33.0, -1.0], [-66.0, -37.0], [2.0, 85.0], [-20.0, 94.0], [-50.0, 26.0], [-24.0, -162.0], [23.0, 70.0], [-30.0, 51.0], [-67.0, -97.0], [-52.0, 87.0], [-69.0, -171.0], [23.0, 57.0], [29.0, -176.0], [67.0, 172.0], [-70.0, 20.0], [-9.0, -175.0], [58.0, -156.0], [79.0, 119.0], [-84.0, -66.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_17be285314ed174a2b1722a933eb3532);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_dee02ed955203ed103ea3c92ca94bf6d.addTo(map_17be285314ed174a2b1722a933eb3532);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
