# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c14da17514d11e85262d5386d59541c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c14da17514d11e85262d5386d59541c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c14da17514d11e85262d5386d59541c5 = L.map(
#                 &quot;map_c14da17514d11e85262d5386d59541c5&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb4a078a51f707cff45b7b4d6f42d30e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb4a078a51f707cff45b7b4d6f42d30e.addTo(map_c14da17514d11e85262d5386d59541c5);
#
#
#             var marker_cluster_a446127cf38ba0d4b79b52af39b4be5b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_807529e653e299bb7e6c951d5bad1fea = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a446127cf38ba0d4b79b52af39b4be5b);
#
#
#             var icon_7dac008e62deb1673eced07d39121bd8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_807529e653e299bb7e6c951d5bad1fea.setIcon(icon_7dac008e62deb1673eced07d39121bd8);
#
#
#         var popup_ac598e7f46340ad351a4fb45391efc1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81b4eb90d74746337c0de452e031be64 = $(`&lt;div id=&quot;html_81b4eb90d74746337c0de452e031be64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ac598e7f46340ad351a4fb45391efc1a.setContent(html_81b4eb90d74746337c0de452e031be64);
#
#
#
#         marker_807529e653e299bb7e6c951d5bad1fea.bindPopup(popup_ac598e7f46340ad351a4fb45391efc1a)
#         ;
#
#
#
#
#             var marker_f5d1a2edfc177141ca5c97668ff90c76 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_a446127cf38ba0d4b79b52af39b4be5b);
#
#
#             var icon_de46ce1d486656df2072383f089e0104 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f5d1a2edfc177141ca5c97668ff90c76.setIcon(icon_de46ce1d486656df2072383f089e0104);
#
#
#         var popup_ac1128e4b759dcfeeffd58793c31a33f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7742842234d936a6501fb713c1dbb173 = $(`&lt;div id=&quot;html_7742842234d936a6501fb713c1dbb173&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ac1128e4b759dcfeeffd58793c31a33f.setContent(html_7742842234d936a6501fb713c1dbb173);
#
#
#
#         marker_f5d1a2edfc177141ca5c97668ff90c76.bindPopup(popup_ac1128e4b759dcfeeffd58793c31a33f)
#         ;
#
#
#
#
#             var marker_68eee674c55d3c1f92644f7587da45ec = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_a446127cf38ba0d4b79b52af39b4be5b);
#
#
#         var popup_115116b32ba84fb46e022ff3ea4b3431 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_719d996f384939bd9b7c4b34ab46e66c = $(`&lt;div id=&quot;html_719d996f384939bd9b7c4b34ab46e66c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_115116b32ba84fb46e022ff3ea4b3431.setContent(html_719d996f384939bd9b7c4b34ab46e66c);
#
#
#
#         marker_68eee674c55d3c1f92644f7587da45ec.bindPopup(popup_115116b32ba84fb46e022ff3ea4b3431)
#         ;
#
#
#
#
#             marker_cluster_a446127cf38ba0d4b79b52af39b4be5b.addTo(map_c14da17514d11e85262d5386d59541c5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e7ccb5afc65d25bcbf6926c24509332 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e7ccb5afc65d25bcbf6926c24509332&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e7ccb5afc65d25bcbf6926c24509332 = L.map(
#                 &quot;map_1e7ccb5afc65d25bcbf6926c24509332&quot;,
#                 {
#                     center: [-0.84, 11.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e44fab93d8e17165c89c244613bc375 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1e44fab93d8e17165c89c244613bc375.addTo(map_1e7ccb5afc65d25bcbf6926c24509332);
#
#
#             var marker_cluster_8e6caf291608381992fdc57489fcc193 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_8e6caf291608381992fdc57489fcc193.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_51b91dec0d3b186c94268a2571027742 = L.marker(
#                 [-81.0, 159.0],
#                 {}
#             ).addTo(marker_cluster_8e6caf291608381992fdc57489fcc193);
#
#
#         var popup_203ce0af8a93527cead9902332249464 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22dc6c2c7d9929c041a39fa52163eead = $(`&lt;div id=&quot;html_22dc6c2c7d9929c041a39fa52163eead&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:159&lt;br&gt;lat:-81&lt;/div&gt;`)[0];
#                 popup_203ce0af8a93527cead9902332249464.setContent(html_22dc6c2c7d9929c041a39fa52163eead);
#
#
#
#         marker_51b91dec0d3b186c94268a2571027742.bindPopup(popup_203ce0af8a93527cead9902332249464)
#         ;
#
#
#
#
#             var marker_505ba03f7b8aeee7394490fbd30561c0 = L.marker(
#                 [26.0, -103.0],
#                 {}
#             ).addTo(marker_cluster_8e6caf291608381992fdc57489fcc193);
#
#
#         var popup_6c51d29f9e4dc870bce5dfec8a7079d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94475b59cb78e6d0883f2c063e987d61 = $(`&lt;div id=&quot;html_94475b59cb78e6d0883f2c063e987d61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-103&lt;br&gt;lat:26&lt;/div&gt;`)[0];
#                 popup_6c51d29f9e4dc870bce5dfec8a7079d1.setContent(html_94475b59cb78e6d0883f2c063e987d61);
#
#
#
#         marker_505ba03f7b8aeee7394490fbd30561c0.bindPopup(popup_6c51d29f9e4dc870bce5dfec8a7079d1)
#         ;
#
#
#
#
#             var marker_6f673b7948ed8a414c6dc292af6ac890 = L.marker(
#                 [58.0, -31.0],
#                 {}
#             ).addTo(marker_cluster_8e6caf291608381992fdc57489fcc193);
#
#
#         var popup_26d27989e7e3174f1ba97cf5eb67cb77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05c7b37c07419b2dcd028480b125d1f5 = $(`&lt;div id=&quot;html_05c7b37c07419b2dcd028480b125d1f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-31&lt;br&gt;lat:58&lt;/div&gt;`)[0];
#                 popup_26d27989e7e3174f1ba97cf5eb67cb77.setContent(html_05c7b37c07419b2dcd028480b125d1f5);
#
#
#
#         marker_6f673b7948ed8a414c6dc292af6ac890.bindPopup(popup_26d27989e7e3174f1ba97cf5eb67cb77)
#         ;
#
#
#
#
#             var marker_a50a0c17dbaab5693701fd9989e587b2 = L.marker(
#                 [85.0, 164.0],
#                 {}
#             ).addTo(marker_cluster_8e6caf291608381992fdc57489fcc193);
#
#
#         var popup_65c7399314976f5ca839cc224a9c296a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b69a07ff42567f7febb4a165a29d645 = $(`&lt;div id=&quot;html_9b69a07ff42567f7febb4a165a29d645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:164&lt;br&gt;lat:85&lt;/div&gt;`)[0];
#                 popup_65c7399314976f5ca839cc224a9c296a.setContent(html_9b69a07ff42567f7febb4a165a29d645);
#
#
#
#         marker_a50a0c17dbaab5

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_662c41ecd2da64c278af3977e4fc6a11 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_662c41ecd2da64c278af3977e4fc6a11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_662c41ecd2da64c278af3977e4fc6a11 = L.map(
#                 &quot;map_662c41ecd2da64c278af3977e4fc6a11&quot;,
#                 {
#                     center: [-0.84, 11.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_220697411b754f69df4707228a1aaa6e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_220697411b754f69df4707228a1aaa6e.addTo(map_662c41ecd2da64c278af3977e4fc6a11);
#
#
#             var marker_cluster_516240d025c4fff9f91eb21ded202869 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_ba4feca15437fbdca6220161e7b9c8c4 = L.marker(
#                 [-81.0, 159.0],
#                 {}
#             ).addTo(marker_cluster_516240d025c4fff9f91eb21ded202869);
#
#
#         var popup_cd5db8cd12ca0099811b28e9e17fd63d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ff2a8e39351044ae869e07de77311e2 = $(`&lt;div id=&quot;html_4ff2a8e39351044ae869e07de77311e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:159&lt;br&gt;lat:-81&lt;/div&gt;`)[0];
#                 popup_cd5db8cd12ca0099811b28e9e17fd63d.setContent(html_4ff2a8e39351044ae869e07de77311e2);
#
#
#
#         marker_ba4feca15437fbdca6220161e7b9c8c4.bindPopup(popup_cd5db8cd12ca0099811b28e9e17fd63d)
#         ;
#
#
#
#
#             var marker_351d44a42a54554610097e342a07b3bf = L.marker(
#                 [26.0, -103.0],
#                 {}
#             ).addTo(marker_cluster_516240d025c4fff9f91eb21ded202869);
#
#
#         var popup_602c2eb6337ff1e16dc38f23b2034960 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4aa17c4a486286dd6eacac21fc1d707f = $(`&lt;div id=&quot;html_4aa17c4a486286dd6eacac21fc1d707f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-103&lt;br&gt;lat:26&lt;/div&gt;`)[0];
#                 popup_602c2eb6337ff1e16dc38f23b2034960.setContent(html_4aa17c4a486286dd6eacac21fc1d707f);
#
#
#
#         marker_351d44a42a54554610097e342a07b3bf.bindPopup(popup_602c2eb6337ff1e16dc38f23b2034960)
#         ;
#
#
#
#
#             var marker_6725d8d9a9850baa0d7aa7fa00f285e4 = L.marker(
#                 [58.0, -31.0],
#                 {}
#             ).addTo(marker_cluster_516240d025c4fff9f91eb21ded202869);
#
#
#         var popup_822fc82aea48db4758eb1d32b28da35f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7f76060cb5b98a7037cbdce2d767aba = $(`&lt;div id=&quot;html_a7f76060cb5b98a7037cbdce2d767aba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-31&lt;br&gt;lat:58&lt;/div&gt;`)[0];
#                 popup_822fc82aea48db4758eb1d32b28da35f.setContent(html_a7f76060cb5b98a7037cbdce2d767aba);
#
#
#
#         marker_6725d8d9a9850baa0d7aa7fa00f285e4.bindPopup(popup_822fc82aea48db4758eb1d32b28da35f)
#         ;
#
#
#
#
#             var marker_6ab417313a022017353a1fb23329ee3f = L.marker(
#                 [85.0, 164.0],
#                 {}
#             ).addTo(marker_cluster_516240d025c4fff9f91eb21ded202869);
#
#
#         var popup_92a8f39447e836e01619c1a63dec6254 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91cd03da73801be7ce6d028decbf7eaa = $(`&lt;div id=&quot;html_91cd03da73801be7ce6d028decbf7eaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:164&lt;br&gt;lat:85&lt;/div&gt;`)[0];
#                 popup_92a8f39447e836e01619c1a63dec6254.setContent(html_91cd03da73801be7ce6d028decbf7eaa);
#
#
#
#         marker_6ab417313a022017353a1fb23329ee3f.bindPopup(popup_92a8f39447e836e01619c1a63dec6254)
#         ;
#
#
#
#
#             var marker_0e49adae392aea6eeff204dfff166dcd = L.marker(
#                 [-72.0, 92.0],
#                 {}
#             ).addTo(marker_cluster_516240d025c4fff9f91eb21ded202869);
#
#
#         var popup_61c93cb00fd89dadebfac6

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50b14cb9dcd897b3a09b543d4f9ac897 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50b14cb9dcd897b3a09b543d4f9ac897&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50b14cb9dcd897b3a09b543d4f9ac897 = L.map(
#                 &quot;map_50b14cb9dcd897b3a09b543d4f9ac897&quot;,
#                 {
#                     center: [-0.84, 11.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_115769a71797cf6ad918fa625d8fca24 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_115769a71797cf6ad918fa625d8fca24.addTo(map_50b14cb9dcd897b3a09b543d4f9ac897);
#
#
#             var fast_marker_cluster_d91f4958a5a14524803fd76072ad0103 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-81.0, 159.0], [26.0, -103.0], [58.0, -31.0], [85.0, 164.0], [-72.0, 92.0], [9.0, -172.0], [-88.0, 151.0], [70.0, -102.0], [56.0, -125.0], [-61.0, -85.0], [61.0, -9.0], [-69.0, -49.0], [-17.0, 103.0], [-31.0, 147.0], [-36.0, -64.0], [-3.0, -143.0], [-22.0, 49.0], [42.0, 135.0], [47.0, -91.0], [27.0, 24.0], [36.0, -94.0], [-32.0, 178.0], [-16.0, -94.0], [-64.0, -98.0], [-83.0, -50.0], [-52.0, -158.0], [72.0, 172.0], [-71.0, 50.0], [67.0, -168.0], [-26.0, 71.0], [3.0, 43.0], [62.0, 84.0], [-1.0, 47.0], [82.0, -114.0], [23.0, -162.0], [-58.0, -59.0], [-34.0, 91.0], [60.0, 93.0], [76.0, -176.0], [70.0, 6.0], [-85.0, -80.0], [51.0, 142.0], [-32.0, -62.0], [72.0, -72.0], [63.0, 140.0], [56.0, -50.0], [-87.0, -102.0], [15.0, -59.0], [-51.0, 117.0], [-10.0, 28.0], [-2.0, 113.0], [-14.0, -11.0], [77.0, -172.0], [-17.0, 84.0], [-39.0, 43.0], [4.0, -67.0], [-25.0, 174.0], [-64.0, 84.0], [18.0, 0.0], [14.0, -116.0], [-1.0, -22.0], [-65.0, 20.0], [-60.0, 158.0], [-12.0, 91.0], [-3.0, 142.0], [36.0, 167.0], [68.0, -18.0], [-47.0, 8.0], [-40.0, -157.0], [-2.0, -11.0], [-81.0, 73.0], [38.0, 159.0], [-24.0, 166.0], [-40.0, -63.0], [-30.0, -86.0], [-6.0, -119.0], [-13.0, 95.0], [50.0, 105.0], [-4.0, -156.0], [-67.0, 47.0], [27.0, 129.0], [85.0, -100.0], [50.0, -31.0], [25.0, 165.0], [-20.0, 70.0], [-75.0, 118.0], [59.0, -86.0], [-27.0, -42.0], [48.0, 95.0], [-81.0, 47.0], [88.0, 161.0], [73.0, -73.0], [-47.0, 101.0], [19.0, -65.0], [-35.0, -97.0], [69.0, 86.0], [-39.0, 19.0], [8.0, 140.0], [-66.0, -100.0], [-1.0, 141.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_50b14cb9dcd897b3a09b543d4f9ac897);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_d91f4958a5a14524803fd76072ad0103.addTo(map_50b14cb9dcd897b3a09b543d4f9ac897);
#
#
#             var layer_control_e6ee5b2f50018b25712e7f620c618323_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_115769a71797cf6ad918fa625d8fca24,
#                 },
#                 overlays :  {
#                     &quot;macro_element_d91f4958a5a14524803fd76072ad0103&quot; : fast_marker_cluster_d91f4958a5a14524803fd76072ad0103,
#                 },
#             };
#             let layer_control_e6ee5b2f50018b25712e7f620c618323 = L.control.layers(
#                 layer_control_e6ee5b2f50018b25712e7f620c618323_layers.base_layers,
#                 layer_control_e6ee5b2f50018b25712e7f620c618323_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_50b14cb9dcd897b3a09b543d4f9ac897);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd74b0c9018ed2423cc202f83a5d3a3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd74b0c9018ed2423cc202f83a5d3a3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd74b0c9018ed2423cc202f83a5d3a3d = L.map(
#                 &quot;map_fd74b0c9018ed2423cc202f83a5d3a3d&quot;,
#                 {
#                     center: [-0.84, 11.23],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69da5e067d57883aa44f7b561bc4066e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_69da5e067d57883aa44f7b561bc4066e.addTo(map_fd74b0c9018ed2423cc202f83a5d3a3d);
#
#
#             var fast_marker_cluster_d572476aa1e4356c12f0913ea75d190c = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-81.0, 159.0], [26.0, -103.0], [58.0, -31.0], [85.0, 164.0], [-72.0, 92.0], [9.0, -172.0], [-88.0, 151.0], [70.0, -102.0], [56.0, -125.0], [-61.0, -85.0], [61.0, -9.0], [-69.0, -49.0], [-17.0, 103.0], [-31.0, 147.0], [-36.0, -64.0], [-3.0, -143.0], [-22.0, 49.0], [42.0, 135.0], [47.0, -91.0], [27.0, 24.0], [36.0, -94.0], [-32.0, 178.0], [-16.0, -94.0], [-64.0, -98.0], [-83.0, -50.0], [-52.0, -158.0], [72.0, 172.0], [-71.0, 50.0], [67.0, -168.0], [-26.0, 71.0], [3.0, 43.0], [62.0, 84.0], [-1.0, 47.0], [82.0, -114.0], [23.0, -162.0], [-58.0, -59.0], [-34.0, 91.0], [60.0, 93.0], [76.0, -176.0], [70.0, 6.0], [-85.0, -80.0], [51.0, 142.0], [-32.0, -62.0], [72.0, -72.0], [63.0, 140.0], [56.0, -50.0], [-87.0, -102.0], [15.0, -59.0], [-51.0, 117.0], [-10.0, 28.0], [-2.0, 113.0], [-14.0, -11.0], [77.0, -172.0], [-17.0, 84.0], [-39.0, 43.0], [4.0, -67.0], [-25.0, 174.0], [-64.0, 84.0], [18.0, 0.0], [14.0, -116.0], [-1.0, -22.0], [-65.0, 20.0], [-60.0, 158.0], [-12.0, 91.0], [-3.0, 142.0], [36.0, 167.0], [68.0, -18.0], [-47.0, 8.0], [-40.0, -157.0], [-2.0, -11.0], [-81.0, 73.0], [38.0, 159.0], [-24.0, 166.0], [-40.0, -63.0], [-30.0, -86.0], [-6.0, -119.0], [-13.0, 95.0], [50.0, 105.0], [-4.0, -156.0], [-67.0, 47.0], [27.0, 129.0], [85.0, -100.0], [50.0, -31.0], [25.0, 165.0], [-20.0, 70.0], [-75.0, 118.0], [59.0, -86.0], [-27.0, -42.0], [48.0, 95.0], [-81.0, 47.0], [88.0, 161.0], [73.0, -73.0], [-47.0, 101.0], [19.0, -65.0], [-35.0, -97.0], [69.0, 86.0], [-39.0, 19.0], [8.0, 140.0], [-66.0, -100.0], [-1.0, 141.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_fd74b0c9018ed2423cc202f83a5d3a3d);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_d572476aa1e4356c12f0913ea75d190c.addTo(map_fd74b0c9018ed2423cc202f83a5d3a3d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
