# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91d1335bc471ec2381831ec25f71d0da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91d1335bc471ec2381831ec25f71d0da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91d1335bc471ec2381831ec25f71d0da = L.map(
#                 &quot;map_91d1335bc471ec2381831ec25f71d0da&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55fb59c4928894c66ce08ee2ab7851b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_55fb59c4928894c66ce08ee2ab7851b9.addTo(map_91d1335bc471ec2381831ec25f71d0da);
#
#
#             var marker_cluster_c8f5326ded2230741acf57a27a91685d = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_adcb2c86c2993ead6404e9e378df15a0 = L.marker(
#                 [40.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_c8f5326ded2230741acf57a27a91685d);
#
#
#             var icon_4da92675ade4939ae48f0993cb3207e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_adcb2c86c2993ead6404e9e378df15a0.setIcon(icon_4da92675ade4939ae48f0993cb3207e3);
#
#
#         var popup_b1d76ef40ac9e77f143f0d000425b04b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_821694dd89a36d6cf8cc8357012fc709 = $(`&lt;div id=&quot;html_821694dd89a36d6cf8cc8357012fc709&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_b1d76ef40ac9e77f143f0d000425b04b.setContent(html_821694dd89a36d6cf8cc8357012fc709);
#
#
#
#         marker_adcb2c86c2993ead6404e9e378df15a0.bindPopup(popup_b1d76ef40ac9e77f143f0d000425b04b)
#         ;
#
#
#
#
#             var marker_808c335ed27f3da5ea1d181a03055fc0 = L.marker(
#                 [44.67, -73.94],
#                 {}
#             ).addTo(marker_cluster_c8f5326ded2230741acf57a27a91685d);
#
#
#             var icon_daf51cf2b4df8685d1ea35da6d43d78c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_808c335ed27f3da5ea1d181a03055fc0.setIcon(icon_daf51cf2b4df8685d1ea35da6d43d78c);
#
#
#         var popup_d509e70d623ec9fdcc547f2c0c97f2e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98098d6a65b33f3bb8a952ed4606e65e = $(`&lt;div id=&quot;html_98098d6a65b33f3bb8a952ed4606e65e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_d509e70d623ec9fdcc547f2c0c97f2e6.setContent(html_98098d6a65b33f3bb8a952ed4606e65e);
#
#
#
#         marker_808c335ed27f3da5ea1d181a03055fc0.bindPopup(popup_d509e70d623ec9fdcc547f2c0c97f2e6)
#         ;
#
#
#
#
#             var marker_afac4f82164d2ee7018f5bc07128d5cd = L.marker(
#                 [44.67, -71.94],
#                 {}
#             ).addTo(marker_cluster_c8f5326ded2230741acf57a27a91685d);
#
#
#         var popup_8dc2c56f4fdd6272a3481cf16deb1306 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1dbc75b76baff115cea2eac0fcf1480c = $(`&lt;div id=&quot;html_1dbc75b76baff115cea2eac0fcf1480c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_8dc2c56f4fdd6272a3481cf16deb1306.setContent(html_1dbc75b76baff115cea2eac0fcf1480c);
#
#
#
#         marker_afac4f82164d2ee7018f5bc07128d5cd.bindPopup(popup_8dc2c56f4fdd6272a3481cf16deb1306)
#         ;
#
#
#
#
#             marker_cluster_c8f5326ded2230741acf57a27a91685d.addTo(map_91d1335bc471ec2381831ec25f71d0da);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallo

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b89284328bdd96cb52f18aa65391ec44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b89284328bdd96cb52f18aa65391ec44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b89284328bdd96cb52f18aa65391ec44 = L.map(
#                 &quot;map_b89284328bdd96cb52f18aa65391ec44&quot;,
#                 {
#                     center: [2.99, 1.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c562f033f91ae01063fa235795d9a84 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c562f033f91ae01063fa235795d9a84.addTo(map_b89284328bdd96cb52f18aa65391ec44);
#
#
#             var marker_cluster_df4ed99505d2124eb75d217c0e0a3b37 = L.markerClusterGroup(
#                 {}
#             );
#             marker_cluster_df4ed99505d2124eb75d217c0e0a3b37.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_bfc7f9e83df3e18bb1f5b9aebe21fcf5 = L.marker(
#                 [74.0, 45.0],
#                 {}
#             ).addTo(marker_cluster_df4ed99505d2124eb75d217c0e0a3b37);
#
#
#         var popup_00fd4c5f3652b8fb5327edde2976493e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d574abe14c0a3b9d16732b2addce6dce = $(`&lt;div id=&quot;html_d574abe14c0a3b9d16732b2addce6dce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:45&lt;br&gt;lat:74&lt;/div&gt;`)[0];
#                 popup_00fd4c5f3652b8fb5327edde2976493e.setContent(html_d574abe14c0a3b9d16732b2addce6dce);
#
#
#
#         marker_bfc7f9e83df3e18bb1f5b9aebe21fcf5.bindPopup(popup_00fd4c5f3652b8fb5327edde2976493e)
#         ;
#
#
#
#
#             var marker_695ab9fb06f2b9d05348a3dc20b28237 = L.marker(
#                 [-40.0, -51.0],
#                 {}
#             ).addTo(marker_cluster_df4ed99505d2124eb75d217c0e0a3b37);
#
#
#         var popup_5f3f536ce479cab789ae91929fbff925 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a665d5cec85ad10ddf7e3dd2beac170e = $(`&lt;div id=&quot;html_a665d5cec85ad10ddf7e3dd2beac170e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-51&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_5f3f536ce479cab789ae91929fbff925.setContent(html_a665d5cec85ad10ddf7e3dd2beac170e);
#
#
#
#         marker_695ab9fb06f2b9d05348a3dc20b28237.bindPopup(popup_5f3f536ce479cab789ae91929fbff925)
#         ;
#
#
#
#
#             var marker_4bb8d2f5d16c98f5f4852102d8a5de30 = L.marker(
#                 [-8.0, -63.0],
#                 {}
#             ).addTo(marker_cluster_df4ed99505d2124eb75d217c0e0a3b37);
#
#
#         var popup_be1728f929beb0c72c342f2a816c3299 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ab4a82badd1987205111490db001b1f = $(`&lt;div id=&quot;html_8ab4a82badd1987205111490db001b1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-63&lt;br&gt;lat:-8&lt;/div&gt;`)[0];
#                 popup_be1728f929beb0c72c342f2a816c3299.setContent(html_8ab4a82badd1987205111490db001b1f);
#
#
#
#         marker_4bb8d2f5d16c98f5f4852102d8a5de30.bindPopup(popup_be1728f929beb0c72c342f2a816c3299)
#         ;
#
#
#
#
#             var marker_912e6f68d07afb14011c52e54078c999 = L.marker(
#                 [-64.0, 80.0],
#                 {}
#             ).addTo(marker_cluster_df4ed99505d2124eb75d217c0e0a3b37);
#
#
#         var popup_e2ff08c78bbd4415cc2c589598e90883 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fc86b75897d4134535eda429c7d5c4e = $(`&lt;div id=&quot;html_5fc86b75897d4134535eda429c7d5c4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:80&lt;br&gt;lat:-64&lt;/div&gt;`)[0];
#                 popup_e2ff08c78bbd4415cc2c589598e90883.setContent(html_5fc86b75897d4134535eda429c7d5c4e);
#
#
#
#         marker_912e6f68d07afb14011c

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_156f6874bd58c723048552b1a5a7d83b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_156f6874bd58c723048552b1a5a7d83b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_156f6874bd58c723048552b1a5a7d83b = L.map(
#                 &quot;map_156f6874bd58c723048552b1a5a7d83b&quot;,
#                 {
#                     center: [2.99, 1.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b89ba2255b20ab3f909eb9ccb396b2c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b89ba2255b20ab3f909eb9ccb396b2c.addTo(map_156f6874bd58c723048552b1a5a7d83b);
#
#
#             var marker_cluster_cfd15ae0508aa80c7b19bfc8a6caf2bf = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_62a430e18ba08e870cd865bdde8f30cb = L.marker(
#                 [74.0, 45.0],
#                 {}
#             ).addTo(marker_cluster_cfd15ae0508aa80c7b19bfc8a6caf2bf);
#
#
#         var popup_a1558728a92dc6b504653017b035e16d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d7a7f54f8af63c99ec88f692a670e21 = $(`&lt;div id=&quot;html_5d7a7f54f8af63c99ec88f692a670e21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:45&lt;br&gt;lat:74&lt;/div&gt;`)[0];
#                 popup_a1558728a92dc6b504653017b035e16d.setContent(html_5d7a7f54f8af63c99ec88f692a670e21);
#
#
#
#         marker_62a430e18ba08e870cd865bdde8f30cb.bindPopup(popup_a1558728a92dc6b504653017b035e16d)
#         ;
#
#
#
#
#             var marker_c67a8ae18d1d2e9262fd1808ce351bfd = L.marker(
#                 [-40.0, -51.0],
#                 {}
#             ).addTo(marker_cluster_cfd15ae0508aa80c7b19bfc8a6caf2bf);
#
#
#         var popup_68d179777352ae542dc44e48410eeff8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47e5f90d0787e13d8e313d7ce3fc9532 = $(`&lt;div id=&quot;html_47e5f90d0787e13d8e313d7ce3fc9532&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-51&lt;br&gt;lat:-40&lt;/div&gt;`)[0];
#                 popup_68d179777352ae542dc44e48410eeff8.setContent(html_47e5f90d0787e13d8e313d7ce3fc9532);
#
#
#
#         marker_c67a8ae18d1d2e9262fd1808ce351bfd.bindPopup(popup_68d179777352ae542dc44e48410eeff8)
#         ;
#
#
#
#
#             var marker_943ca9a00fd9c5bbfa6012c11540eac2 = L.marker(
#                 [-8.0, -63.0],
#                 {}
#             ).addTo(marker_cluster_cfd15ae0508aa80c7b19bfc8a6caf2bf);
#
#
#         var popup_cef63c7dd27e14453867a5046202c045 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_792188ee720932f778e412fe51349e7e = $(`&lt;div id=&quot;html_792188ee720932f778e412fe51349e7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-63&lt;br&gt;lat:-8&lt;/div&gt;`)[0];
#                 popup_cef63c7dd27e14453867a5046202c045.setContent(html_792188ee720932f778e412fe51349e7e);
#
#
#
#         marker_943ca9a00fd9c5bbfa6012c11540eac2.bindPopup(popup_cef63c7dd27e14453867a5046202c045)
#         ;
#
#
#
#
#             var marker_aa99154003fde260d411645f3f95fb1c = L.marker(
#                 [-64.0, 80.0],
#                 {}
#             ).addTo(marker_cluster_cfd15ae0508aa80c7b19bfc8a6caf2bf);
#
#
#         var popup_b45a324465a919d3eedc6c67dcd93c19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1692bb6ed914e38dc134e7f4173e88a = $(`&lt;div id=&quot;html_b1692bb6ed914e38dc134e7f4173e88a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:80&lt;br&gt;lat:-64&lt;/div&gt;`)[0];
#                 popup_b45a324465a919d3eedc6c67dcd93c19.setContent(html_b1692bb6ed914e38dc134e7f4173e88a);
#
#
#
#         marker_aa99154003fde260d411645f3f95fb1c.bindPopup(popup_b45a324465a919d3eedc6c67dcd93c19)
#         ;
#
#
#
#
#             var marker_90b82f22c6209a1d4b48539221383857 = L.marker(
#                 [89.0, -126.0],
#                 {}
#             ).addTo(marker_cluster_cfd15ae0508aa80c7b19bfc8a6caf2bf);
#
#
#         var popup_a0cf0d876b5ab5805900c3e61f5

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_176ea457c97b5f2b50209ffae9d80e91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_176ea457c97b5f2b50209ffae9d80e91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_176ea457c97b5f2b50209ffae9d80e91 = L.map(
#                 &quot;map_176ea457c97b5f2b50209ffae9d80e91&quot;,
#                 {
#                     center: [2.99, 1.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_572e1eb5a3490b62fe45b1907d0ca9ac = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_572e1eb5a3490b62fe45b1907d0ca9ac.addTo(map_176ea457c97b5f2b50209ffae9d80e91);
#
#
#             var fast_marker_cluster_08989cde4cebfdf05261102874a52461 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[74.0, 45.0], [-40.0, -51.0], [-8.0, -63.0], [-64.0, 80.0], [89.0, -126.0], [32.0, -37.0], [24.0, 113.0], [-57.0, 99.0], [35.0, -139.0], [-15.0, -29.0], [-13.0, 152.0], [86.0, -8.0], [-86.0, -115.0], [-17.0, -70.0], [30.0, -103.0], [-28.0, -67.0], [58.0, -166.0], [80.0, 158.0], [29.0, -62.0], [-76.0, 159.0], [-56.0, 72.0], [-49.0, 147.0], [31.0, -136.0], [7.0, 69.0], [76.0, 127.0], [-25.0, -68.0], [77.0, -155.0], [80.0, -158.0], [-23.0, -179.0], [18.0, -108.0], [50.0, 54.0], [-23.0, 65.0], [-75.0, 34.0], [68.0, 43.0], [-10.0, -38.0], [54.0, 44.0], [51.0, 143.0], [-67.0, -84.0], [39.0, 56.0], [-12.0, 163.0], [61.0, -103.0], [66.0, -177.0], [42.0, 149.0], [-40.0, 1.0], [-65.0, -88.0], [-15.0, 173.0], [-67.0, -36.0], [64.0, 124.0], [-54.0, -48.0], [32.0, -118.0], [50.0, -121.0], [16.0, 6.0], [57.0, 173.0], [-13.0, -98.0], [-15.0, -124.0], [76.0, 110.0], [-59.0, -104.0], [27.0, 175.0], [66.0, 72.0], [-29.0, -18.0], [5.0, -1.0], [-51.0, -58.0], [31.0, -143.0], [-53.0, -35.0], [-6.0, -75.0], [-26.0, 44.0], [-42.0, -86.0], [-50.0, 60.0], [89.0, 160.0], [45.0, -55.0], [1.0, -21.0], [-5.0, 22.0], [-84.0, -121.0], [40.0, 107.0], [-61.0, -66.0], [-62.0, -116.0], [-85.0, -107.0], [72.0, 98.0], [-8.0, 169.0], [38.0, 155.0], [-54.0, -45.0], [72.0, 147.0], [-59.0, 178.0], [-54.0, 21.0], [-58.0, 136.0], [-72.0, -47.0], [-45.0, -7.0], [88.0, -179.0], [33.0, 9.0], [21.0, -18.0], [14.0, 95.0], [-18.0, 60.0], [-77.0, 60.0], [73.0, 83.0], [-4.0, 125.0], [75.0, 78.0], [-15.0, 71.0], [60.0, -133.0], [-24.0, -82.0], [11.0, -164.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_176ea457c97b5f2b50209ffae9d80e91);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_08989cde4cebfdf05261102874a52461.addTo(map_176ea457c97b5f2b50209ffae9d80e91);
#
#
#             var layer_control_1b13801230786a33a1097261b400b542_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_572e1eb5a3490b62fe45b1907d0ca9ac,
#                 },
#                 overlays :  {
#                     &quot;macro_element_08989cde4cebfdf05261102874a52461&quot; : fast_marker_cluster_08989cde4cebfdf05261102874a52461,
#                 },
#             };
#             let layer_control_1b13801230786a33a1097261b400b542 = L.control.layers(
#                 layer_control_1b13801230786a33a1097261b400b542_layers.base_layers,
#                 layer_control_1b13801230786a33a1097261b400b542_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_176ea457c97b5f2b50209ffae9d80e91);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0de61cbe8d117b9374220337010f95c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0de61cbe8d117b9374220337010f95c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0de61cbe8d117b9374220337010f95c2 = L.map(
#                 &quot;map_0de61cbe8d117b9374220337010f95c2&quot;,
#                 {
#                     center: [2.99, 1.28],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2807f51716d0218bc440957728584c5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d2807f51716d0218bc440957728584c5.addTo(map_0de61cbe8d117b9374220337010f95c2);
#
#
#             var fast_marker_cluster_cd16c8fcc1acf0a60bd4e2ddb5bbb6f1 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[74.0, 45.0], [-40.0, -51.0], [-8.0, -63.0], [-64.0, 80.0], [89.0, -126.0], [32.0, -37.0], [24.0, 113.0], [-57.0, 99.0], [35.0, -139.0], [-15.0, -29.0], [-13.0, 152.0], [86.0, -8.0], [-86.0, -115.0], [-17.0, -70.0], [30.0, -103.0], [-28.0, -67.0], [58.0, -166.0], [80.0, 158.0], [29.0, -62.0], [-76.0, 159.0], [-56.0, 72.0], [-49.0, 147.0], [31.0, -136.0], [7.0, 69.0], [76.0, 127.0], [-25.0, -68.0], [77.0, -155.0], [80.0, -158.0], [-23.0, -179.0], [18.0, -108.0], [50.0, 54.0], [-23.0, 65.0], [-75.0, 34.0], [68.0, 43.0], [-10.0, -38.0], [54.0, 44.0], [51.0, 143.0], [-67.0, -84.0], [39.0, 56.0], [-12.0, 163.0], [61.0, -103.0], [66.0, -177.0], [42.0, 149.0], [-40.0, 1.0], [-65.0, -88.0], [-15.0, 173.0], [-67.0, -36.0], [64.0, 124.0], [-54.0, -48.0], [32.0, -118.0], [50.0, -121.0], [16.0, 6.0], [57.0, 173.0], [-13.0, -98.0], [-15.0, -124.0], [76.0, 110.0], [-59.0, -104.0], [27.0, 175.0], [66.0, 72.0], [-29.0, -18.0], [5.0, -1.0], [-51.0, -58.0], [31.0, -143.0], [-53.0, -35.0], [-6.0, -75.0], [-26.0, 44.0], [-42.0, -86.0], [-50.0, 60.0], [89.0, 160.0], [45.0, -55.0], [1.0, -21.0], [-5.0, 22.0], [-84.0, -121.0], [40.0, 107.0], [-61.0, -66.0], [-62.0, -116.0], [-85.0, -107.0], [72.0, 98.0], [-8.0, 169.0], [38.0, 155.0], [-54.0, -45.0], [72.0, 147.0], [-59.0, 178.0], [-54.0, 21.0], [-58.0, 136.0], [-72.0, -47.0], [-45.0, -7.0], [88.0, -179.0], [33.0, 9.0], [21.0, -18.0], [14.0, 95.0], [-18.0, 60.0], [-77.0, 60.0], [73.0, 83.0], [-4.0, 125.0], [75.0, 78.0], [-15.0, 71.0], [60.0, -133.0], [-24.0, -82.0], [11.0, -164.0]];
#                 var cluster = L.markerClusterGroup({});
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_0de61cbe8d117b9374220337010f95c2);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_cd16c8fcc1acf0a60bd4e2ddb5bbb6f1.addTo(map_0de61cbe8d117b9374220337010f95c2);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
